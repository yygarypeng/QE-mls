# %%
# %reset -sf

from time import time
time_start = time()

import pandas as pd
import numpy as np
import scipy as sp
import gc
import os
from matplotlib import pyplot as plt

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import StandardScaler, MinMaxScaler, QuantileTransformer, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import tensorflow as tf

import get_data as gd
import atlas_plot as ap
plot = ap.Plotter()

print(tf.__version__)
print(tf.config.list_physical_devices())
print()
# Out:
# 2.13.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
seed = 42  # set random seed
sampling = int(1e6)
# num_folds = 2
batch_size = 1024
epochs = 512
learning_rate = 1e-4

# %%
np.random.seed(seed)
processor = gd.DataProcessor(sampling=sampling, processor=10)
path = "/root/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 10
#
# ['/root/data/truth/signal/CGLMP.npz', '/root/data/truth/signal/Higgs.npz', '/root/data/truth/signal/LeadLepton.npz', '/root/data/truth/signal/LeptonM.npz', '/root/data/truth/signal/LeptonP.npz', '/root/data/truth/signal/LmNu.npz', '/root/data/truth/signal/LpNu.npz', '/root/data/truth/signal/MET.npz', '/root/data/truth/signal/WmBoson.npz', '/root/data/truth/signal/WpBoson.npz', '/root/data/truth/signal/diLepton.npz', '/root/data/truth/signal/subLeadLepton.npz', '/root/data/truth/signal/xi_xyz.npz']

# %%
GEV = 1e3

cut_pre_pt_lead = data.LeadLep["pt"] > 22 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
cut_pre_pt_miss = data.MET["pt"] > 20 * GEV
cut_pre = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss

del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# %%
lep_p = processor.process_part(data.LepP).iloc[:, :4]
lep_p.columns = ["lep_p_" + col.lower() for col in lep_p.columns]
lep_m = processor.process_part(data.LepM).iloc[:, :4]
lep_m.columns = ["lep_m_" + col.lower() for col in lep_m.columns]
w_p = pd.DataFrame(data.Wp["m"])
w_p.columns = ["w_p_" + col.lower() for col in w_p.columns]
w_m = pd.DataFrame(data.Wm["m"])
w_m.columns = ["w_m_" + col.lower() for col in w_m.columns]
met = processor.process_MET(data.MET).iloc[:, 1:3]
met.columns = ["met_px", "met_py"]
mt = pd.DataFrame(
    {
        "mt": np.sqrt(
            np.sum(
                np.square(
                    processor.process_dipart(data.LepP, data.LepM)[["m", "px", "py"]]
                ),
                axis=1,
            )
        )
    }
)
pta = pd.DataFrame(
    {
        "pta": np.sqrt(
            np.square(lep_p["lep_p_px"])
            + np.square(lep_p["lep_p_py"])
            + np.square(lep_m["lep_m_px"])
            + np.square(lep_m["lep_m_py"])
            + np.square(met["met_px"])
            + np.square(met["met_py"])
        )
    }
)

# Sperate the two shell classes
threshold = 60 * GEV  # threshold for separating the two classes
p_sep = w_p["w_p_m"] >= threshold
m_sep = w_m["w_m_m"] >= threshold
mask1 = cut_pre & p_sep & ~m_sep
mask2 = cut_pre & ~p_sep & m_sep

obs_kin_1 = pd.concat([met, lep_p, lep_m, mt, pta], axis=1)[mask1]
obs_kin_2 = pd.concat([met, lep_p, lep_m, mt, pta], axis=1)[mask2]
print(type(obs_kin_1), type(obs_kin_2))
print("obs_kin shape:", obs_kin_1.shape, obs_kin_2.shape)
print(obs_kin_1.head(3), "\n", obs_kin_2.head(3))
print()

# int_kin_1 = pd.concat([w_p["w_p_m"], w_m["w_m_m"]], axis=1)[mask1]
# int_kin_2 = pd.concat([w_p["w_p_m"], w_m["w_m_m"]], axis=1)[mask2]
int_kin_1 = pd.concat([w_p["w_p_m"]], axis=1)[mask1]
int_kin_2 = pd.concat([w_p["w_p_m"]], axis=1)[mask2]
print(type(int_kin_1), type(int_kin_2))
print("int_kin shape:", int_kin_1.shape, int_kin_2.shape)
print(int_kin_1.head(3), "\n", int_kin_2.head(3))
print()

# del (processor, lep_p, lep_m, met, dilep_kin, mt, vx)
# gc.collect()
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.frame.DataFrame'>
# obs_kin shape: (662396, 12) (663448, 12)
#        met_px     met_py     lep_p_e   lep_p_px  lep_p_py    lep_p_pz  \
# 7   96.335650  47.095450   19.500895  -4.561588  18.92441   -1.154271
# 9  -26.992604 -70.883859  164.814766  34.397141   2.03130 -161.172625
# 21 -65.691990  34.546791  190.213375 -33.501133 -28.27757  185.092359
#
#        lep_m_e   lep_m_px   lep_m_py    lep_m_pz          mt         pta
# 7    43.361348  42.407754  -4.632000    7.767462   62.513416  117.035693
# 9    70.592648  29.001777   1.896990  -64.332027   67.559621   88.233289
# 21  192.252422 -55.010402 -18.986748  183.233031  103.036364  104.007241
#         met_px     met_py    lep_p_e   lep_p_px   lep_p_py   lep_p_pz  \
# 10  44.222846 -15.383637  47.669113 -26.605045 -17.256748  35.590859
# 13 -35.807631   4.480668  52.595516  12.459787   9.784288  50.152863
# 18   8.478388 -54.210879  31.746979  14.220096   8.616839 -27.044379
#
#        lep_m_e   lep_m_px   lep_m_py    lep_m_pz         mt        pta
# 10   90.238664 -23.868604  32.986602   80.530680  74.393166  69.683329
# 13  232.377734  32.306596  17.332070  229.467391  54.975147  53.827114
# 18   56.341547 -15.457637  39.683762  -36.886727  60.600347  71.420606
#
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.frame.DataFrame'>
# int_kin shape: (662396, 1) (663448, 1)
#            w_p_m
# 7   67132.320312
# 9   62292.464844
# 21  80840.148438
#             w_p_m
# 10  24133.898438
# 13  46434.984375
# 18  39253.847656

# %%
# plt.hist(w_p["w_p_m"]/GEV, bins=200, alpha=.8)
# plt.title(r"$m_{W^+}$")
# plt.xlabel("mass [GeV]")
# plt.ylabel("count")
# # plt.xlim([0,200])
# plt.show()
# plt.hist(w_m["w_m_m"]/GEV, bins=200, alpha=.8)
# plt.title(r"$m_{W^-}$")
# plt.xlabel("mass [GeV]")
# plt.ylabel("count")
# # plt.xlim([0,200])
# plt.show()

# %%
# plt.hist(int_kin_1["w_p_m"] / GEV, bins=100, alpha=0.8)
# plt.title(r"$m_{W^+}$ on-shell")
# plt.xlabel("mass [GeV]")
# plt.ylabel("count")
# plt.show()

# plt.hist(int_kin_1["w_m_m"] / GEV, bins=100, alpha=0.8)
# plt.title(r"$m_{W^-}$ off-shell")
# plt.xlabel("mass [GeV]")
# plt.ylabel("count")
# plt.show()

# %%
# plt.hist(int_kin_2["w_p_m"] / GEV, bins=100, alpha=0.8)
# plt.title(r"$m_{W^+}$ off-shell")
# plt.xlabel("mass [GeV]")
# plt.ylabel("count")
# plt.show()

# plt.hist(int_kin_2["w_m_m"] / GEV, bins=100, alpha=0.8)
# plt.title(r"$m_{W^-}$ on-shell")
# plt.xlabel("mass [GeV]")
# plt.ylabel("count")
# plt.show()

# %%
SCALAR_int_ru = RobustScaler()
int_kin_1 = SCALAR_int_ru.fit_transform(int_kin_1)
# SCALAR_int_mm = MinMaxScaler(feature_range=(0, 1))
# int_kin_1 = SCALAR_int_mm.fit_transform(int_kin_1)

SCALAR_obs_ru = RobustScaler()
obs_kin_1 = SCALAR_obs_ru.fit_transform(obs_kin_1)
# SCALAR_obs_mm = MinMaxScaler(feature_range=(0, 1))
# obs_kin_1 = SCALAR_obs_mm.fit_transform(obs_kin_1)

# %%
plt.hist(int_kin_1[:, 0], bins=100, alpha=.8)
plt.title("Norm." + r" $m_{W^{on}}$")
plt.xlabel("mass [unit]")
plt.ylabel("count")
# plt.xlim([0,800])
plt.show()
# plt.hist(int_kin_1[:, 1], bins=100, alpha=.8)
# plt.title("Norm." + r" $m_{W^-}$")
# plt.xlabel("mass [unit]")
# plt.ylabel("count")
# # plt.xlim([0,800])
# plt.show()

# %%
indices_arr = np.arange(int_kin_1.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.4,
    test_size=0.6,
    random_state=seed,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=42
)

train_x = obs_kin_1[train_indices]
test_x = obs_kin_1[test_indices]
valid_x = obs_kin_1[valid_indices]
train_y = int_kin_1[train_indices]
test_y = int_kin_1[test_indices]
valid_y = int_kin_1[valid_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
print()
# Out:
# X (Interest)
# Training data shape: (264958, 12);
# Validing data shape: (198719, 12);
# Testing data shape: (198719, 12).
# Y (Observed)
# Training data shape: (264958, 1);
# Validing data shape: (198719, 1);
# Testing data shape: (198719, 1).

# %%
# Define a new activation function
def custom_activation(x):
    return x*tf.keras.backend.sigmoid(x)

# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    x = tf.keras.layers.Dense(units=128, activation="elu")(x)
    x = tf.keras.layers.Dense(units=128, activation="elu")(x)
    # x = tf.keras.layers.BatchNormalization()(x)
    # x = tf.keras.layers.Dropout(rate=0.2)(x)
    x = tf.keras.layers.Dense(units=32, activation="elu")(x)
    x = tf.keras.layers.Dense(units=32, activation="elu")(x)
    x = tf.keras.layers.Dense(units=4, activation="elu")(x)
    x = tf.keras.layers.Dense(units=4, activation="elu")(x)
    # x = tf.keras.layers.BatchNormalization()(x)
    # x = tf.keras.layers.Dropout(rate=0.1)(x)
    # x = tf.keras.layers.Dense(units=16, activation="elu")(x)
    # x = tf.keras.layers.Dense(units=16, activation="elu")(x)

    # Last dense layer
    outputs = tf.keras.layers.Dense(units=train_y.shape[-1], activation="linear")(x)

    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss="mse",
    )

    # Summarize the model
    model.summary()

    return model

# %%
model = build_model()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 12)]              0
#
#  flatten_1 (Flatten)         (None, 12)                0
#
#  dense_5 (Dense)             (None, 128)               1664
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dense_7 (Dense)             (None, 32)                4128
#
#  dense_8 (Dense)             (None, 32)                1056
#
#  dense_9 (Dense)             (None, 4)                 132
#
#  dense_10 (Dense)            (None, 4)                 20
#
#  dense_11 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 23517 (91.86 KB)
# Trainable params: 23517 (91.86 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-6,
    patience=10,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)

# Fit the model
history = model.fit(
    x=train_x,
    y=train_y,
    validation_data=(valid_x, valid_y),
    epochs=epochs,
    batch_size=batch_size,
    verbose=2,
    callbacks=[stop_early],
)
# Out:
# Epoch 1/512
# 259/259 - 3s - loss: 2.8815 - val_loss: 2.8248 - 3s/epoch - 13ms/step
# Epoch 2/512
# 259/259 - 1s - loss: 2.8183 - val_loss: 2.8099 - 1s/epoch - 5ms/step
# Epoch 3/512
# 259/259 - 1s - loss: 2.8023 - val_loss: 2.7936 - 1s/epoch - 5ms/step
# Epoch 4/512
# 259/259 - 1s - loss: 2.7861 - val_loss: 2.7784 - 1s/epoch - 5ms/step
# Epoch 5/512
# 259/259 - 1s - loss: 2.7701 - val_loss: 2.7610 - 1s/epoch - 5ms/step
# Epoch 6/512
# 259/259 - 1s - loss: 2.7501 - val_loss: 2.7393 - 1s/epoch - 5ms/step
# Epoch 7/512
# 259/259 - 1s - loss: 2.7305 - val_loss: 2.7216 - 1s/epoch - 5ms/step
# Epoch 8/512
# 259/259 - 1s - loss: 2.7193 - val_loss: 2.7165 - 1s/epoch - 5ms/step
# Epoch 9/512
# 259/259 - 1s - loss: 2.7126 - val_loss: 2.7086 - 1s/epoch - 5ms/step
# Epoch 10/512
# 259/259 - 1s - loss: 2.7080 - val_loss: 2.7089 - 1s/epoch - 5ms/step
# Epoch 11/512
# 259/259 - 1s - loss: 2.7045 - val_loss: 2.7035 - 1s/epoch - 5ms/step
# Epoch 12/512
# 259/259 - 1s - loss: 2.7015 - val_loss: 2.7027 - 1s/epoch - 5ms/step
# Epoch 13/512
# 259/259 - 1s - loss: 2.6987 - val_loss: 2.6991 - 1s/epoch - 5ms/step
# Epoch 14/512
# 259/259 - 1s - loss: 2.6952 - val_loss: 2.6946 - 1s/epoch - 5ms/step
# Epoch 15/512
# 259/259 - 1s - loss: 2.6931 - val_loss: 2.6920 - 1s/epoch - 5ms/step
# Epoch 16/512
# 259/259 - 1s - loss: 2.6901 - val_loss: 2.6907 - 1s/epoch - 5ms/step
# Epoch 17/512
# 259/259 - 1s - loss: 2.6880 - val_loss: 2.6890 - 1s/epoch - 5ms/step
# Epoch 18/512
# 259/259 - 1s - loss: 2.6861 - val_loss: 2.6891 - 1s/epoch - 5ms/step
# Epoch 19/512
# 259/259 - 1s - loss: 2.6837 - val_loss: 2.6846 - 1s/epoch - 5ms/step
# Epoch 20/512
# 259/259 - 1s - loss: 2.6820 - val_loss: 2.6854 - 1s/epoch - 5ms/step
# Epoch 21/512
# 259/259 - 1s - loss: 2.6808 - val_loss: 2.6803 - 1s/epoch - 5ms/step
# Epoch 22/512
# 259/259 - 1s - loss: 2.6790 - val_loss: 2.6804 - 1s/epoch - 5ms/step
# Epoch 23/512
# 259/259 - 1s - loss: 2.6774 - val_loss: 2.6774 - 1s/epoch - 5ms/step
# Epoch 24/512
# 259/259 - 1s - loss: 2.6754 - val_loss: 2.6767 - 1s/epoch - 5ms/step
# Epoch 25/512
# 259/259 - 1s - loss: 2.6734 - val_loss: 2.6743 - 1s/epoch - 5ms/step
# Epoch 26/512
# 259/259 - 1s - loss: 2.6716 - val_loss: 2.6741 - 1s/epoch - 5ms/step
# Epoch 27/512
# 259/259 - 1s - loss: 2.6698 - val_loss: 2.6716 - 1s/epoch - 5ms/step
# Epoch 28/512
# 259/259 - 1s - loss: 2.6679 - val_loss: 2.6692 - 1s/epoch - 5ms/step
# Epoch 29/512
# 259/259 - 1s - loss: 2.6656 - val_loss: 2.6678 - 1s/epoch - 5ms/step
# Epoch 30/512
# 259/259 - 1s - loss: 2.6633 - val_loss: 2.6647 - 1s/epoch - 5ms/step
# Epoch 31/512
# 259/259 - 1s - loss: 2.6610 - val_loss: 2.6673 - 1s/epoch - 5ms/step
# Epoch 32/512
# 259/259 - 1s - loss: 2.6582 - val_loss: 2.6613 - 1s/epoch - 5ms/step
# Epoch 33/512
# 259/259 - 1s - loss: 2.6564 - val_loss: 2.6580 - 1s/epoch - 5ms/step
# Epoch 34/512
# 259/259 - 1s - loss: 2.6530 - val_loss: 2.6562 - 1s/epoch - 5ms/step
# Epoch 35/512
# 259/259 - 1s - loss: 2.6503 - val_loss: 2.6534 - 1s/epoch - 5ms/step
# Epoch 36/512
# 259/259 - 1s - loss: 2.6476 - val_loss: 2.6512 - 1s/epoch - 5ms/step
# Epoch 37/512
# 259/259 - 1s - loss: 2.6447 - val_loss: 2.6518 - 1s/epoch - 5ms/step
# Epoch 38/512
# 259/259 - 1s - loss: 2.6420 - val_loss: 2.6494 - 1s/epoch - 5ms/step
# Epoch 39/512
# 259/259 - 1s - loss: 2.6394 - val_loss: 2.6440 - 1s/epoch - 5ms/step
# Epoch 40/512
# 259/259 - 1s - loss: 2.6359 - val_loss: 2.6406 - 1s/epoch - 5ms/step
# Epoch 41/512
# 259/259 - 1s - loss: 2.6333 - val_loss: 2.6415 - 1s/epoch - 5ms/step
# Epoch 42/512
# 259/259 - 1s - loss: 2.6298 - val_loss: 2.6344 - 1s/epoch - 5ms/step
# Epoch 43/512
# 259/259 - 1s - loss: 2.6268 - val_loss: 2.6338 - 1s/epoch - 5ms/step
# Epoch 44/512
# 259/259 - 1s - loss: 2.6245 - val_loss: 2.6316 - 1s/epoch - 5ms/step
# Epoch 45/512
# 259/259 - 1s - loss: 2.6219 - val_loss: 2.6282 - 1s/epoch - 5ms/step
# Epoch 46/512
# 259/259 - 1s - loss: 2.6187 - val_loss: 2.6307 - 1s/epoch - 5ms/step
# Epoch 47/512
# 259/259 - 1s - loss: 2.6168 - val_loss: 2.6247 - 1s/epoch - 5ms/step
# Epoch 48/512
# 259/259 - 1s - loss: 2.6145 - val_loss: 2.6213 - 1s/epoch - 5ms/step
# Epoch 49/512
# 259/259 - 1s - loss: 2.6128 - val_loss: 2.6190 - 1s/epoch - 5ms/step
# Epoch 50/512
# 259/259 - 1s - loss: 2.6111 - val_loss: 2.6190 - 1s/epoch - 5ms/step
# Epoch 51/512
# 259/259 - 1s - loss: 2.6095 - val_loss: 2.6174 - 1s/epoch - 5ms/step
# Epoch 52/512
# 259/259 - 1s - loss: 2.6078 - val_loss: 2.6155 - 1s/epoch - 5ms/step
# Epoch 53/512
# 259/259 - 1s - loss: 2.6058 - val_loss: 2.6141 - 1s/epoch - 5ms/step
# Epoch 54/512
# 259/259 - 1s - loss: 2.6042 - val_loss: 2.6128 - 1s/epoch - 5ms/step
# Epoch 55/512
# 259/259 - 1s - loss: 2.6033 - val_loss: 2.6127 - 1s/epoch - 5ms/step
# Epoch 56/512
# 259/259 - 1s - loss: 2.6027 - val_loss: 2.6178 - 1s/epoch - 5ms/step
# Epoch 57/512
# 259/259 - 1s - loss: 2.6010 - val_loss: 2.6090 - 1s/epoch - 5ms/step
# Epoch 58/512
# 259/259 - 1s - loss: 2.5997 - val_loss: 2.6088 - 1s/epoch - 5ms/step
# Epoch 59/512
# 259/259 - 1s - loss: 2.5991 - val_loss: 2.6081 - 1s/epoch - 5ms/step
# Epoch 60/512
# 259/259 - 1s - loss: 2.5982 - val_loss: 2.6106 - 1s/epoch - 5ms/step
# Epoch 61/512
# 259/259 - 1s - loss: 2.5967 - val_loss: 2.6124 - 1s/epoch - 5ms/step
# Epoch 62/512
# 259/259 - 1s - loss: 2.5958 - val_loss: 2.6086 - 1s/epoch - 5ms/step
# Epoch 63/512
# 259/259 - 1s - loss: 2.5951 - val_loss: 2.6058 - 1s/epoch - 5ms/step
# Epoch 64/512
# 259/259 - 1s - loss: 2.5945 - val_loss: 2.6035 - 1s/epoch - 5ms/step
# Epoch 65/512
# 259/259 - 1s - loss: 2.5940 - val_loss: 2.6039 - 1s/epoch - 5ms/step
# Epoch 66/512
# 259/259 - 1s - loss: 2.5930 - val_loss: 2.6046 - 1s/epoch - 5ms/step
# Epoch 67/512
# 259/259 - 1s - loss: 2.5925 - val_loss: 2.6062 - 1s/epoch - 5ms/step
# Epoch 68/512
# 259/259 - 1s - loss: 2.5910 - val_loss: 2.6072 - 1s/epoch - 5ms/step
# Epoch 69/512
# 259/259 - 1s - loss: 2.5905 - val_loss: 2.6060 - 1s/epoch - 5ms/step
# Epoch 70/512
# 259/259 - 1s - loss: 2.5898 - val_loss: 2.6007 - 1s/epoch - 5ms/step
# Epoch 71/512
# 259/259 - 1s - loss: 2.5895 - val_loss: 2.6011 - 1s/epoch - 5ms/step
# Epoch 72/512
# 259/259 - 1s - loss: 2.5891 - val_loss: 2.6067 - 1s/epoch - 5ms/step
# Epoch 73/512
# 259/259 - 1s - loss: 2.5875 - val_loss: 2.6027 - 1s/epoch - 5ms/step
# Epoch 74/512
# 259/259 - 1s - loss: 2.5872 - val_loss: 2.6011 - 1s/epoch - 5ms/step
# Epoch 75/512
# 259/259 - 1s - loss: 2.5871 - val_loss: 2.5988 - 1s/epoch - 5ms/step
# Epoch 76/512
# 259/259 - 1s - loss: 2.5870 - val_loss: 2.6013 - 1s/epoch - 5ms/step
# Epoch 77/512
# 259/259 - 1s - loss: 2.5858 - val_loss: 2.5986 - 1s/epoch - 5ms/step
# Epoch 78/512
# 259/259 - 1s - loss: 2.5851 - val_loss: 2.6016 - 1s/epoch - 5ms/step
# Epoch 79/512
# 259/259 - 1s - loss: 2.5833 - val_loss: 2.5999 - 1s/epoch - 5ms/step
# Epoch 80/512
# 259/259 - 1s - loss: 2.5836 - val_loss: 2.5985 - 1s/epoch - 5ms/step
# Epoch 81/512
# 259/259 - 1s - loss: 2.5833 - val_loss: 2.5995 - 1s/epoch - 5ms/step
# Epoch 82/512
# 259/259 - 1s - loss: 2.5830 - val_loss: 2.6006 - 1s/epoch - 5ms/step
# Epoch 83/512
# 259/259 - 1s - loss: 2.5830 - val_loss: 2.5979 - 1s/epoch - 5ms/step
# Epoch 84/512
# 259/259 - 1s - loss: 2.5816 - val_loss: 2.5970 - 1s/epoch - 5ms/step
# Epoch 85/512
# 259/259 - 1s - loss: 2.5815 - val_loss: 2.5996 - 1s/epoch - 5ms/step
# Epoch 86/512
# 259/259 - 1s - loss: 2.5811 - val_loss: 2.6003 - 1s/epoch - 5ms/step
# Epoch 87/512
# 259/259 - 1s - loss: 2.5803 - val_loss: 2.5995 - 1s/epoch - 5ms/step
# Epoch 88/512
# 259/259 - 1s - loss: 2.5799 - val_loss: 2.5974 - 1s/epoch - 5ms/step
# Epoch 89/512
# 259/259 - 1s - loss: 2.5798 - val_loss: 2.5956 - 1s/epoch - 5ms/step
# Epoch 90/512
# 259/259 - 1s - loss: 2.5791 - val_loss: 2.5986 - 1s/epoch - 5ms/step
# Epoch 91/512
# 259/259 - 1s - loss: 2.5795 - val_loss: 2.5984 - 1s/epoch - 5ms/step
# Epoch 92/512
# 259/259 - 1s - loss: 2.5789 - val_loss: 2.5974 - 1s/epoch - 5ms/step
# Epoch 93/512
# 259/259 - 1s - loss: 2.5777 - val_loss: 2.5957 - 1s/epoch - 5ms/step
# Epoch 94/512
# 259/259 - 1s - loss: 2.5782 - val_loss: 2.5986 - 1s/epoch - 5ms/step
# Epoch 95/512
# 259/259 - 1s - loss: 2.5767 - val_loss: 2.5958 - 1s/epoch - 5ms/step
# Epoch 96/512
# 259/259 - 1s - loss: 2.5768 - val_loss: 2.5941 - 1s/epoch - 5ms/step
# Epoch 97/512
# 259/259 - 1s - loss: 2.5768 - val_loss: 2.5957 - 1s/epoch - 5ms/step
# Epoch 98/512
# 259/259 - 1s - loss: 2.5759 - val_loss: 2.5931 - 1s/epoch - 5ms/step
# Epoch 99/512
# 259/259 - 1s - loss: 2.5766 - val_loss: 2.5938 - 1s/epoch - 5ms/step
# Epoch 100/512
# 259/259 - 1s - loss: 2.5755 - val_loss: 2.5934 - 1s/epoch - 5ms/step
# Epoch 101/512
# 259/259 - 1s - loss: 2.5757 - val_loss: 2.5953 - 1s/epoch - 5ms/step
# Epoch 102/512
# 259/259 - 1s - loss: 2.5747 - val_loss: 2.5974 - 1s/epoch - 5ms/step
# Epoch 103/512
# 259/259 - 1s - loss: 2.5741 - val_loss: 2.5981 - 1s/epoch - 5ms/step
# Epoch 104/512
# 259/259 - 1s - loss: 2.5749 - val_loss: 2.5940 - 1s/epoch - 5ms/step
# Epoch 105/512
# 259/259 - 1s - loss: 2.5735 - val_loss: 2.5937 - 1s/epoch - 5ms/step
# Epoch 106/512
# 259/259 - 1s - loss: 2.5737 - val_loss: 2.5960 - 1s/epoch - 5ms/step
# Epoch 107/512
# 259/259 - 1s - loss: 2.5734 - val_loss: 2.5940 - 1s/epoch - 5ms/step
# Epoch 108/512
# 259/259 - 1s - loss: 2.5736 - val_loss: 2.5923 - 1s/epoch - 5ms/step
# Epoch 109/512
# 259/259 - 1s - loss: 2.5739 - val_loss: 2.5932 - 1s/epoch - 5ms/step
# Epoch 110/512
# 259/259 - 1s - loss: 2.5728 - val_loss: 2.5926 - 1s/epoch - 5ms/step
# Epoch 111/512
# 259/259 - 1s - loss: 2.5723 - val_loss: 2.5926 - 1s/epoch - 5ms/step
# Epoch 112/512
# 259/259 - 1s - loss: 2.5717 - val_loss: 2.5934 - 1s/epoch - 5ms/step
# Epoch 113/512
# 259/259 - 1s - loss: 2.5711 - val_loss: 2.5920 - 1s/epoch - 5ms/step
# Epoch 114/512
# 259/259 - 1s - loss: 2.5709 - val_loss: 2.5916 - 1s/epoch - 5ms/step
# Epoch 115/512
# 259/259 - 1s - loss: 2.5709 - val_loss: 2.5918 - 1s/epoch - 5ms/step
# Epoch 116/512
# 259/259 - 1s - loss: 2.5706 - val_loss: 2.5934 - 1s/epoch - 5ms/step
# Epoch 117/512
# 259/259 - 1s - loss: 2.5706 - val_loss: 2.5935 - 1s/epoch - 5ms/step
# Epoch 118/512
# 259/259 - 1s - loss: 2.5709 - val_loss: 2.5912 - 1s/epoch - 5ms/step
# Epoch 119/512
# 259/259 - 1s - loss: 2.5697 - val_loss: 2.5898 - 1s/epoch - 5ms/step
# Epoch 120/512
# 259/259 - 1s - loss: 2.5698 - val_loss: 2.5917 - 1s/epoch - 5ms/step
# Epoch 121/512
# 259/259 - 1s - loss: 2.5691 - val_loss: 2.5898 - 1s/epoch - 5ms/step
# Epoch 122/512
# 259/259 - 1s - loss: 2.5705 - val_loss: 2.5927 - 1s/epoch - 5ms/step
# Epoch 123/512
# 259/259 - 1s - loss: 2.5689 - val_loss: 2.5906 - 1s/epoch - 5ms/step
# Epoch 124/512
# 259/259 - 1s - loss: 2.5689 - val_loss: 2.5963 - 1s/epoch - 5ms/step
# Epoch 125/512
# 259/259 - 1s - loss: 2.5690 - val_loss: 2.5920 - 1s/epoch - 5ms/step
# Epoch 126/512
# 259/259 - 1s - loss: 2.5682 - val_loss: 2.5944 - 1s/epoch - 5ms/step
# Epoch 127/512
# 259/259 - 1s - loss: 2.5677 - val_loss: 2.5905 - 1s/epoch - 5ms/step
# Epoch 128/512
# 259/259 - 1s - loss: 2.5676 - val_loss: 2.5978 - 1s/epoch - 5ms/step
# Epoch 129/512
# 259/259 - 1s - loss: 2.5670 - val_loss: 2.5955 - 1s/epoch - 5ms/step

# %%
# save model
model.save("DNN_w_seperated.h5", save_format="h5", overwrite=True)
# predict
pred_y = model.predict(test_x)
sig_pred = pred_y
sig_truth = test_y
# Out:
#    1/6210 [..............................] - ETA: 10:19
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 6210/6210 [==============================] - 8s 1ms/step

# %%
print(f"Truth mean: {np.mean(sig_truth[:,0]):.3f}, std: {np.std(sig_truth[:,0]):.3f}, min: {np.min(sig_truth[:,0]):.3f}, max: {np.max(sig_truth[:,0]):.3f}")
# Out:
# Truth mean: -0.486, std: 1.701, min: -7.608, max: 9.643

# %%
range = [0, 1]

plot.plot_hist(
    [sig_truth[:, 0], sig_pred[:, 0]],
    [r"$m^{truth}_{W^{on}}$", r"$m^{pred}_{W^{on}}$"],
    r"On-shell $m_{W^{on}}$"
    + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth[:,0], sig_pred[:,0])):.3f}",
    xlabel=r"Norm. $m_{W^{on}}$ [unit]",
    # range=range,
)

# plot.plot_hist(
#     [sig_truth[:, 1], sig_pred[:, 1]],
#     [r"$m^{truth}_{W^-}$", r"$m^{pred}_{W^-}$"],
#     r"Off-shell $m_{W^-}$"
#     + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth[:,0], sig_pred[:,0])):.3f}",
#     xlabel=r"Norm. $m_{W^-}$ [unit]",
#     range=range,
# )

plot.plot_loss_history(history, logx=True, logy=True)

plot.plot_2d_histogram(
    sig_truth[:, 0],
    sig_pred[:, 0],
    r"On-shell $m_{W^{on}}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth[:,0], sig_pred[:,0])[0]:.3f}",
    # range=range,
)
# plot.plot_2d_histogram(
#     sig_truth[:, 1],
#     sig_pred[:, 1],
#     r"Off-shell $m_{W^-}$ "
#     + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth[:,1], sig_pred[:,1])[0]:.3f}",
#     range=range,
# )
