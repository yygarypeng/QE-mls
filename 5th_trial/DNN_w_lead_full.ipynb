# %%
# %reset -sf

import tensorflow as tf
print(tf.__version__)


# GPU(s) setups
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')
        
        # Instead of enabling memory growth, set a memory limit
        memory_limit = 16_384 # Set the memory limit in MB
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]
        )
        
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2.13.0
# 1 Physical GPUs, 1 Logical GPU
# 2024-07-28 11:56:33.141286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 16384 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
import sys
import os
import glob
HOME_PATH = os.path.abspath("../qe")
sys.path.insert(0, HOME_PATH)

import get_data as gd
import atlas_plot as ap
plot = ap.Plotter()

# INN packages
from flow import *
from utils import *

import pandas as pd
import numpy as np
import scipy as sp

from matplotlib import pyplot as plt
import matplotlib as mpl
import shap

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
SEED = 42  # set random seed (global variable)
np.random.seed(SEED)
processor = gd.DataProcessor()
path = "/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 32
# Number of used processors: 19
#
# ['/data/truth/signal/CGLMP.npz', '/data/truth/signal/Higgs.npz', '/data/truth/signal/LeadLepton.npz', '/data/truth/signal/LeptonM.npz', '/data/truth/signal/LeptonP.npz', '/data/truth/signal/LmNu.npz', '/data/truth/signal/LpNu.npz', '/data/truth/signal/MET.npz', '/data/truth/signal/WmBoson.npz', '/data/truth/signal/WpBoson.npz', '/data/truth/signal/diLepton.npz', '/data/truth/signal/subLeadLepton.npz', '/data/truth/signal/xi_xyz.npz']

# %%
## Global variables

GEV = 1e3

# cut_pre_pt_lead = data.LeadLep["pt"] > 35 * GEV
# cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
# cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
# cut_pre_pt_miss = data.MET["pt"] > 20 * GEV

cut_pre_pt_lead = data.LeadLep["pt"] > -9999 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > -9999 * GEV
cut_pre_dilep_m = data.diLep["m"] > -9999 * GEV
cut_pre_pt_miss = data.MET["pt"] > -9999 * GEV

PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

BATCH_SIZE = 4_096
EPOCHS = 1_024
LEARNING_RATE = 1e-4

# %%
## Interesting variables

# Critria for leading and subleading lepton
lead_p = data.LeadLep["m"] == data.LepP["m"]
sublead_p = ~lead_p
lead_m = sublead_p.copy()
sublead_m = lead_p.copy()

# (sub)lead W
w_lead = pd.concat([data.Wp[lead_p], data.Wm[lead_m]], axis=0).sort_index()
w_sublead = pd.concat([data.Wp[sublead_p], data.Wm[sublead_m]], axis=0).sort_index()
# print("w_lead shape:", w_lead.shape)
# print(w_lead.head(3))
# print(w_lead.describe())

# Check (sub)lead W
plt.hist(w_lead["m"] / GEV, bins=100, color="r", histtype="step", label=r"$W^{lead}$")
plt.hist(
    w_sublead["m"] / GEV, bins=100, color="b", histtype="step", label=r"$W^{sublead}$"
)
plt.title("W mass")
plt.xlabel("mass [GeV]")
plt.ylabel("count")
plt.legend(loc="best")
plt.show()
plt.close()
# # Check (sub)lead W
# plt.hist(
#     w_lead["m"][PRE_CUT] / GEV,
#     bins=100,
#     color="r",
#     histtype="step",
#     label=r"$W^{lead}$",
# )
# plt.hist(
#     w_sublead["m"][PRE_CUT] / GEV,
#     bins=100,
#     color="b",
#     histtype="step",
#     label=r"$W^{sublead}$",
# )
# plt.title("Cut W mass")
# plt.xlabel("mass [GeV]")
# plt.ylabel("count")
# plt.legend(loc="best")
# plt.show()
# plt.close()

# Kinematics of interesting variables (target for training)
int_kin = w_lead[["px", "py", "pz", "E"]][PRE_CUT] / GEV
print("int_kin shape:", int_kin.shape)
print(int_kin.describe())
ROBUST_INT = RobustScaler().fit(int_kin)
int_kin = ROBUST_INT.transform(int_kin)
# int_kin = int_kin.to_numpy() # convert to numpy array
print(type(int_kin))
# Out:
# int_kin shape: (2928862, 4)
#                  px            py            pz             E
# count  2.928862e+06  2.928862e+06  2.928862e+06  2.928862e+06
# mean  -1.788823e-02  1.700620e-02  2.688194e-01  2.283278e+02
# std    3.510948e+01  3.504798e+01  3.222953e+02  2.440128e+02
# min   -1.474598e+03 -7.555793e+02 -4.386726e+03  1.596886e+01
# 25%   -1.782399e+01 -1.778516e+01 -1.062248e+02  9.528028e+01
# 50%   -7.059609e-03  1.686714e-03  2.295375e-01  1.397490e+02
# 75%    1.782398e+01  1.782713e+01  1.065598e+02  2.580234e+02
# max    8.572401e+02  8.429514e+02  4.286328e+03  4.387744e+03
# <class 'numpy.ndarray'>

# %%
## Observing variables

met = data.MET[["px", "py"]]
lead_lep = data.LeadLep[["px", "py", "pz", "E", "pt", "eta", "phi"]]
sublead_lep = data.SubLep[["px", "py", "pz", "E", "pt", "eta", "phi"]]

# Kinematics of observing variables (inputs for training)
obs_kin = pd.concat([lead_lep, sublead_lep, met], axis=1)[PRE_CUT] / GEV
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array
ROBUST_OBS = RobustScaler()
obs_kin = ROBUST_OBS.fit_transform(obs_kin)
print(type(obs_kin))
# Out:
# int_kin shape: (2928862, 16)
# <class 'numpy.ndarray'>

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.6,
    test_size=0.4,
    random_state=SEED,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=SEED
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# X (Interest)
# Training data shape: (1757317, 16);
# Validing data shape: (585772, 16);
# Testing data shape: (585773, 16).
# Y (Observed)
# Training data shape: (1757317, 4);
# Validing data shape: (585772, 4);
# Testing data shape: (585773, 4).

# %%
# Define a new activation function


def custom_activation(x):
    return (0.73 - (-0.27)) * (tf.tanh(x) + 1) / 2 + (-0.27)


class EPConstraint(tf.keras.constraints.Constraint):
    def __call__(self, w):
        # Ensure that energy-momentum are time-like case
        px = w[:, 0]
        py = w[:, 1]
        pz = w[:, 2]
        energy = w[:, 3]
        # Calculate the constraint
        constraint = tf.maximum(0.0, energy**2 - px**2 - py**2 - pz**2)
        # Create a mask for invalid four-vectors (constraint == 0)
        mask = tf.cast(tf.not_equal(constraint, 0.0), w.dtype)
        # If constraint is zero, set the entire four-vector to zero
        adjusted_w = w * tf.expand_dims(mask, axis=-1)
        return adjusted_w

# Register the custom activation and constraint
tf.keras.utils.get_custom_objects().update({
    'EPConstraint': EPConstraint,
})


# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    x = tf.keras.layers.Dense(units=2048, activation="elu")(x)
    x = tf.keras.layers.Dense(units=2048, activation="elu")(x)
    x = tf.keras.layers.Dropout(rate=0.5)(x)
    x = tf.keras.layers.Dense(units=512, activation="elu")(x)
    x = tf.keras.layers.Dense(units=512, activation="elu")(x)
    x = tf.keras.layers.Dropout(rate=0.2)(x)
    x = tf.keras.layers.Dense(units=128, activation="elu")(x)
    x = tf.keras.layers.Dense(units=128, activation="elu")(x)
    x = tf.keras.layers.Dropout(rate=0.1)(x)
    x = tf.keras.layers.Dense(units=32, activation="elu")(x)
    x = tf.keras.layers.Dense(units=32, activation="elu")(x)

    # Last dense layer(s) --> force to constraint the four-vectors to be time-like
    # x = tf.keras.layers.Dense(units=5, activation="linear")(x)
    # x = tf.keras.layers.Dense(units=5, activation="linear", kernel_constraint=EPConstraint())(x)
    # outputs_mass = tf.keras.layers.Dense(units=1, activation="linear", name="outputs_mass")(x)
    # y = tf.keras.layers.Concatenate()([x, outputs_mass])
    # y = tf.keras.layers.Dense(units=8, activation="elu")(y)
    # y = tf.keras.layers.Dense(units=8, activation="elu")(y)
    # y = tf.keras.layers.Dense(units=4, activation="linear", kernel_constraint=EPConstraint())(y)
    # regress the wanted four-vectors parameters
    outputs_px = tf.keras.layers.Dense(units=1, activation="linear", name="outputs_px")(x)
    outputs_py = tf.keras.layers.Dense(units=1, activation="linear", name="outputs_py")(x)
    outputs_pz = tf.keras.layers.Dense(units=1, activation="linear", name="outputs_pz")(x)
    outputs_energy = tf.keras.layers.Dense(units=1, activation="linear", name="outputs_energy")(x)
    
    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=[outputs_px, outputs_py, outputs_pz, outputs_energy])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss={
            "outputs_px": "mse", 
            "outputs_py": "mse", 
            "outputs_pz": "mse", 
            "outputs_energy": "mse",
            },
        # loss=tf.losses.MeanSquaredLogarithmicError(),
    )

    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 16)]                 0         []
#
#  flatten (Flatten)           (None, 16)                   0         ['input_1[0][0]']
#
#  dense (Dense)               (None, 2048)                 34816     ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 2048)                 4196352   ['dense[0][0]']
#
#  dropout (Dropout)           (None, 2048)                 0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 512)                  1049088   ['dropout[0][0]']
#
#  dense_3 (Dense)             (None, 512)                  262656    ['dense_2[0][0]']
#
#  dropout_1 (Dropout)         (None, 512)                  0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  65664     ['dropout_1[0][0]']
#
#  dense_5 (Dense)             (None, 128)                  16512     ['dense_4[0][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 32)                   4128      ['dropout_2[0][0]']
#
#  dense_7 (Dense)             (None, 32)                   1056      ['dense_6[0][0]']
#
#  outputs_px (Dense)          (None, 1)                    33        ['dense_7[0][0]']
#
#  outputs_py (Dense)          (None, 1)                    33        ['dense_7[0][0]']
#
#  outputs_pz (Dense)          (None, 1)                    33        ['dense_7[0][0]']
#
#  outputs_energy (Dense)      (None, 1)                    33        ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 5630404 (21.48 MB)
# Trainable params: 5630404 (21.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# 2024-07-28 11:56:38.965407: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:753] failed to allocate 16.00GiB (17179869184 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-3,
    patience=20,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)


def scheduler(epoch, lr):
    if epoch < 100:
        return lr
    else:
        return lr * tf.math.exp(-0.01)


lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

# Fit the model
history = model.fit(
    x=train_x,
    y=train_y,
    validation_data=(valid_x, valid_y),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=2,
    use_multiprocessing=True,
    callbacks=[stop_early],
    # callbacks=[stop_early,lr_scheduler],
)
# Out:
# Epoch 1/1024
# 2024-07-28 11:56:39.976943: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-07-28 11:56:40.335798: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e02151c880 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-28 11:56:40.335823: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# 2024-07-28 11:56:40.435576: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-28 11:56:40.552788: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-07-28 11:56:40.965563: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 430/430 - 7s - loss: 5.4928 - outputs_px_loss: 1.3723 - outputs_py_loss: 1.3704 - outputs_pz_loss: 1.3744 - outputs_energy_loss: 1.3758 - val_loss: 5.4259 - val_outputs_px_loss: 1.3554 - val_outputs_py_loss: 1.3572 - val_outputs_pz_loss: 1.3565 - val_outputs_energy_loss: 1.3569 - 7s/epoch - 16ms/step
# Epoch 2/1024
# 430/430 - 5s - loss: 5.4404 - outputs_px_loss: 1.3597 - outputs_py_loss: 1.3596 - outputs_pz_loss: 1.3604 - outputs_energy_loss: 1.3609 - val_loss: 5.4162 - val_outputs_px_loss: 1.3540 - val_outputs_py_loss: 1.3538 - val_outputs_pz_loss: 1.3543 - val_outputs_energy_loss: 1.3542 - 5s/epoch - 11ms/step
# Epoch 3/1024
# 430/430 - 5s - loss: 5.4334 - outputs_px_loss: 1.3581 - outputs_py_loss: 1.3580 - outputs_pz_loss: 1.3586 - outputs_energy_loss: 1.3587 - val_loss: 5.4164 - val_outputs_px_loss: 1.3538 - val_outputs_py_loss: 1.3542 - val_outputs_pz_loss: 1.3540 - val_outputs_energy_loss: 1.3543 - 5s/epoch - 11ms/step
# Epoch 4/1024
# 430/430 - 5s - loss: 5.4288 - outputs_px_loss: 1.3571 - outputs_py_loss: 1.3569 - outputs_pz_loss: 1.3573 - outputs_energy_loss: 1.3574 - val_loss: 5.4104 - val_outputs_px_loss: 1.3526 - val_outputs_py_loss: 1.3527 - val_outputs_pz_loss: 1.3526 - val_outputs_energy_loss: 1.3525 - 5s/epoch - 11ms/step
# Epoch 5/1024
# 430/430 - 5s - loss: 5.4268 - outputs_px_loss: 1.3566 - outputs_py_loss: 1.3565 - outputs_pz_loss: 1.3568 - outputs_energy_loss: 1.3569 - val_loss: 5.4103 - val_outputs_px_loss: 1.3525 - val_outputs_py_loss: 1.3528 - val_outputs_pz_loss: 1.3526 - val_outputs_energy_loss: 1.3525 - 5s/epoch - 11ms/step
# Epoch 6/1024
# 430/430 - 5s - loss: 5.4231 - outputs_px_loss: 1.3557 - outputs_py_loss: 1.3556 - outputs_pz_loss: 1.3559 - outputs_energy_loss: 1.3559 - val_loss: 5.4057 - val_outputs_px_loss: 1.3513 - val_outputs_py_loss: 1.3514 - val_outputs_pz_loss: 1.3514 - val_outputs_energy_loss: 1.3515 - 5s/epoch - 11ms/step
# Epoch 7/1024
# 430/430 - 5s - loss: 5.4198 - outputs_px_loss: 1.3549 - outputs_py_loss: 1.3548 - outputs_pz_loss: 1.3551 - outputs_energy_loss: 1.3550 - val_loss: 5.4006 - val_outputs_px_loss: 1.3503 - val_outputs_py_loss: 1.3500 - val_outputs_pz_loss: 1.3502 - val_outputs_energy_loss: 1.3501 - 5s/epoch - 11ms/step
# Epoch 8/1024
# 430/430 - 5s - loss: 5.4164 - outputs_px_loss: 1.3541 - outputs_py_loss: 1.3540 - outputs_pz_loss: 1.3542 - outputs_energy_loss: 1.3542 - val_loss: 5.3969 - val_outputs_px_loss: 1.3493 - val_outputs_py_loss: 1.3491 - val_outputs_pz_loss: 1.3493 - val_outputs_energy_loss: 1.3492 - 5s/epoch - 11ms/step
# Epoch 9/1024
# 430/430 - 5s - loss: 5.4129 - outputs_px_loss: 1.3531 - outputs_py_loss: 1.3531 - outputs_pz_loss: 1.3534 - outputs_energy_loss: 1.3533 - val_loss: 5.3959 - val_outputs_px_loss: 1.3487 - val_outputs_py_loss: 1.3489 - val_outputs_pz_loss: 1.3491 - val_outputs_energy_loss: 1.3491 - 5s/epoch - 11ms/step
# Epoch 10/1024
# 430/430 - 5s - loss: 5.4099 - outputs_px_loss: 1.3524 - outputs_py_loss: 1.3524 - outputs_pz_loss: 1.3526 - outputs_energy_loss: 1.3525 - val_loss: 5.3934 - val_outputs_px_loss: 1.3486 - val_outputs_py_loss: 1.3481 - val_outputs_pz_loss: 1.3484 - val_outputs_energy_loss: 1.3483 - 5s/epoch - 11ms/step
# Epoch 11/1024
# 430/430 - 5s - loss: 5.4087 - outputs_px_loss: 1.3521 - outputs_py_loss: 1.3521 - outputs_pz_loss: 1.3523 - outputs_energy_loss: 1.3522 - val_loss: 5.3948 - val_outputs_px_loss: 1.3489 - val_outputs_py_loss: 1.3486 - val_outputs_pz_loss: 1.3486 - val_outputs_energy_loss: 1.3487 - 5s/epoch - 11ms/step
# Epoch 12/1024
# 430/430 - 5s - loss: 5.4074 - outputs_px_loss: 1.3518 - outputs_py_loss: 1.3518 - outputs_pz_loss: 1.3519 - outputs_energy_loss: 1.3519 - val_loss: 5.3894 - val_outputs_px_loss: 1.3473 - val_outputs_py_loss: 1.3473 - val_outputs_pz_loss: 1.3474 - val_outputs_energy_loss: 1.3473 - 5s/epoch - 11ms/step
# Epoch 13/1024
# 430/430 - 5s - loss: 5.4051 - outputs_px_loss: 1.3512 - outputs_py_loss: 1.3512 - outputs_pz_loss: 1.3513 - outputs_energy_loss: 1.3513 - val_loss: 5.3901 - val_outputs_px_loss: 1.3476 - val_outputs_py_loss: 1.3475 - val_outputs_pz_loss: 1.3475 - val_outputs_energy_loss: 1.3475 - 5s/epoch - 11ms/step
# Epoch 14/1024
# 430/430 - 5s - loss: 5.4039 - outputs_px_loss: 1.3509 - outputs_py_loss: 1.3509 - outputs_pz_loss: 1.3510 - outputs_energy_loss: 1.3510 - val_loss: 5.3868 - val_outputs_px_loss: 1.3466 - val_outputs_py_loss: 1.3467 - val_outputs_pz_loss: 1.3467 - val_outputs_energy_loss: 1.3468 - 5s/epoch - 11ms/step
# Epoch 15/1024
# 430/430 - 5s - loss: 5.4028 - outputs_px_loss: 1.3506 - outputs_py_loss: 1.3507 - outputs_pz_loss: 1.3507 - outputs_energy_loss: 1.3507 - val_loss: 5.3867 - val_outputs_px_loss: 1.3466 - val_outputs_py_loss: 1.3466 - val_outputs_pz_loss: 1.3467 - val_outputs_energy_loss: 1.3467 - 5s/epoch - 11ms/step
# Epoch 16/1024
# 430/430 - 5s - loss: 5.4018 - outputs_px_loss: 1.3504 - outputs_py_loss: 1.3504 - outputs_pz_loss: 1.3505 - outputs_energy_loss: 1.3505 - val_loss: 5.3857 - val_outputs_px_loss: 1.3464 - val_outputs_py_loss: 1.3464 - val_outputs_pz_loss: 1.3463 - val_outputs_energy_loss: 1.3465 - 5s/epoch - 11ms/step
# Epoch 17/1024
# 430/430 - 5s - loss: 5.4005 - outputs_px_loss: 1.3501 - outputs_py_loss: 1.3501 - outputs_pz_loss: 1.3502 - outputs_energy_loss: 1.3502 - val_loss: 5.3845 - val_outputs_px_loss: 1.3461 - val_outputs_py_loss: 1.3461 - val_outputs_pz_loss: 1.3461 - val_outputs_energy_loss: 1.3462 - 5s/epoch - 11ms/step
# Epoch 18/1024
# 430/430 - 5s - loss: 5.3995 - outputs_px_loss: 1.3498 - outputs_py_loss: 1.3498 - outputs_pz_loss: 1.3499 - outputs_energy_loss: 1.3499 - val_loss: 5.3873 - val_outputs_px_loss: 1.3470 - val_outputs_py_loss: 1.3467 - val_outputs_pz_loss: 1.3469 - val_outputs_energy_loss: 1.3468 - 5s/epoch - 11ms/step
# Epoch 19/1024
# 430/430 - 5s - loss: 5.3987 - outputs_px_loss: 1.3496 - outputs_py_loss: 1.3497 - outputs_pz_loss: 1.3497 - outputs_energy_loss: 1.3497 - val_loss: 5.3843 - val_outputs_px_loss: 1.3463 - val_outputs_py_loss: 1.3459 - val_outputs_pz_loss: 1.3461 - val_outputs_energy_loss: 1.3460 - 5s/epoch - 11ms/step
# Epoch 20/1024
# 430/430 - 5s - loss: 5.3982 - outputs_px_loss: 1.3495 - outputs_py_loss: 1.3495 - outputs_pz_loss: 1.3496 - outputs_energy_loss: 1.3496 - val_loss: 5.3825 - val_outputs_px_loss: 1.3456 - val_outputs_py_loss: 1.3457 - val_outputs_pz_loss: 1.3456 - val_outputs_energy_loss: 1.3456 - 5s/epoch - 11ms/step
# Epoch 21/1024
# 430/430 - 5s - loss: 5.3976 - outputs_px_loss: 1.3494 - outputs_py_loss: 1.3494 - outputs_pz_loss: 1.3494 - outputs_energy_loss: 1.3494 - val_loss: 5.3901 - val_outputs_px_loss: 1.3478 - val_outputs_py_loss: 1.3474 - val_outputs_pz_loss: 1.3476 - val_outputs_energy_loss: 1.3474 - 5s/epoch - 11ms/step
# Epoch 22/1024
# 430/430 - 5s - loss: 5.3971 - outputs_px_loss: 1.3493 - outputs_py_loss: 1.3492 - outputs_pz_loss: 1.3493 - outputs_energy_loss: 1.3493 - val_loss: 5.3825 - val_outputs_px_loss: 1.3456 - val_outputs_py_loss: 1.3456 - val_outputs_pz_loss: 1.3456 - val_outputs_energy_loss: 1.3456 - 5s/epoch - 11ms/step
# Epoch 23/1024
# 430/430 - 5s - loss: 5.3962 - outputs_px_loss: 1.3490 - outputs_py_loss: 1.3490 - outputs_pz_loss: 1.3491 - outputs_energy_loss: 1.3491 - val_loss: 5.3825 - val_outputs_px_loss: 1.3456 - val_outputs_py_loss: 1.3456 - val_outputs_pz_loss: 1.3457 - val_outputs_energy_loss: 1.3456 - 5s/epoch - 11ms/step
# Epoch 24/1024
# 430/430 - 5s - loss: 5.3955 - outputs_px_loss: 1.3489 - outputs_py_loss: 1.3489 - outputs_pz_loss: 1.3489 - outputs_energy_loss: 1.3489 - val_loss: 5.3803 - val_outputs_px_loss: 1.3451 - val_outputs_py_loss: 1.3451 - val_outputs_pz_loss: 1.3451 - val_outputs_energy_loss: 1.3451 - 5s/epoch - 11ms/step
# Epoch 25/1024
# 430/430 - 5s - loss: 5.3951 - outputs_px_loss: 1.3487 - outputs_py_loss: 1.3488 - outputs_pz_loss: 1.3488 - outputs_energy_loss: 1.3488 - val_loss: 5.3807 - val_outputs_px_loss: 1.3452 - val_outputs_py_loss: 1.3451 - val_outputs_pz_loss: 1.3452 - val_outputs_energy_loss: 1.3452 - 5s/epoch - 11ms/step
# Epoch 26/1024
# 430/430 - 5s - loss: 5.3947 - outputs_px_loss: 1.3487 - outputs_py_loss: 1.3487 - outputs_pz_loss: 1.3487 - outputs_energy_loss: 1.3487 - val_loss: 5.3803 - val_outputs_px_loss: 1.3452 - val_outputs_py_loss: 1.3450 - val_outputs_pz_loss: 1.3451 - val_outputs_energy_loss: 1.3450 - 5s/epoch - 11ms/step
# Epoch 27/1024
# 430/430 - 5s - loss: 5.3936 - outputs_px_loss: 1.3484 - outputs_py_loss: 1.3484 - outputs_pz_loss: 1.3484 - outputs_energy_loss: 1.3484 - val_loss: 5.3807 - val_outputs_px_loss: 1.3451 - val_outputs_py_loss: 1.3452 - val_outputs_pz_loss: 1.3452 - val_outputs_energy_loss: 1.3452 - 5s/epoch - 11ms/step
# Epoch 28/1024
# 430/430 - 5s - loss: 5.3938 - outputs_px_loss: 1.3484 - outputs_py_loss: 1.3484 - outputs_pz_loss: 1.3485 - outputs_energy_loss: 1.3485 - val_loss: 5.3789 - val_outputs_px_loss: 1.3448 - val_outputs_py_loss: 1.3447 - val_outputs_pz_loss: 1.3447 - val_outputs_energy_loss: 1.3447 - 5s/epoch - 11ms/step
# Epoch 29/1024
# 430/430 - 5s - loss: 5.3932 - outputs_px_loss: 1.3483 - outputs_py_loss: 1.3483 - outputs_pz_loss: 1.3483 - outputs_energy_loss: 1.3483 - val_loss: 5.3798 - val_outputs_px_loss: 1.3449 - val_outputs_py_loss: 1.3450 - val_outputs_pz_loss: 1.3449 - val_outputs_energy_loss: 1.3449 - 5s/epoch - 11ms/step
# Epoch 30/1024
# 430/430 - 5s - loss: 5.3930 - outputs_px_loss: 1.3482 - outputs_py_loss: 1.3482 - outputs_pz_loss: 1.3483 - outputs_energy_loss: 1.3483 - val_loss: 5.3796 - val_outputs_px_loss: 1.3450 - val_outputs_py_loss: 1.3448 - val_outputs_pz_loss: 1.3449 - val_outputs_energy_loss: 1.3449 - 5s/epoch - 11ms/step
# Epoch 31/1024
# 430/430 - 5s - loss: 5.3923 - outputs_px_loss: 1.3481 - outputs_py_loss: 1.3481 - outputs_pz_loss: 1.3481 - outputs_energy_loss: 1.3481 - val_loss: 5.3797 - val_outputs_px_loss: 1.3449 - val_outputs_py_loss: 1.3449 - val_outputs_pz_loss: 1.3449 - val_outputs_energy_loss: 1.3449 - 5s/epoch - 11ms/step
# Epoch 32/1024
# 430/430 - 5s - loss: 5.3925 - outputs_px_loss: 1.3481 - outputs_py_loss: 1.3481 - outputs_pz_loss: 1.3481 - outputs_energy_loss: 1.3481 - val_loss: 5.3788 - val_outputs_px_loss: 1.3448 - val_outputs_py_loss: 1.3446 - val_outputs_pz_loss: 1.3447 - val_outputs_energy_loss: 1.3447 - 5s/epoch - 11ms/step
# Epoch 33/1024
# 430/430 - 5s - loss: 5.3914 - outputs_px_loss: 1.3478 - outputs_py_loss: 1.3479 - outputs_pz_loss: 1.3478 - outputs_energy_loss: 1.3478 - val_loss: 5.3773 - val_outputs_px_loss: 1.3444 - val_outputs_py_loss: 1.3443 - val_outputs_pz_loss: 1.3443 - val_outputs_energy_loss: 1.3443 - 5s/epoch - 11ms/step
# Epoch 34/1024
# 430/430 - 5s - loss: 5.3915 - outputs_px_loss: 1.3478 - outputs_py_loss: 1.3479 - outputs_pz_loss: 1.3479 - outputs_energy_loss: 1.3479 - val_loss: 5.3789 - val_outputs_px_loss: 1.3448 - val_outputs_py_loss: 1.3447 - val_outputs_pz_loss: 1.3447 - val_outputs_energy_loss: 1.3447 - 5s/epoch - 11ms/step
# Epoch 35/1024
# 430/430 - 5s - loss: 5.3914 - outputs_px_loss: 1.3478 - outputs_py_loss: 1.3478 - outputs_pz_loss: 1.3478 - outputs_energy_loss: 1.3479 - val_loss: 5.3804 - val_outputs_px_loss: 1.3452 - val_outputs_py_loss: 1.3450 - val_outputs_pz_loss: 1.3451 - val_outputs_energy_loss: 1.3450 - 5s/epoch - 11ms/step
# Epoch 36/1024
# 430/430 - 5s - loss: 5.3910 - outputs_px_loss: 1.3478 - outputs_py_loss: 1.3478 - outputs_pz_loss: 1.3478 - outputs_energy_loss: 1.3478 - val_loss: 5.3826 - val_outputs_px_loss: 1.3458 - val_outputs_py_loss: 1.3456 - val_outputs_pz_loss: 1.3456 - val_outputs_energy_loss: 1.3456 - 5s/epoch - 11ms/step
# Epoch 37/1024
# 430/430 - 5s - loss: 5.3905 - outputs_px_loss: 1.3476 - outputs_py_loss: 1.3476 - outputs_pz_loss: 1.3476 - outputs_energy_loss: 1.3476 - val_loss: 5.3773 - val_outputs_px_loss: 1.3443 - val_outputs_py_loss: 1.3443 - val_outputs_pz_loss: 1.3443 - val_outputs_energy_loss: 1.3443 - 5s/epoch - 11ms/step
# Epoch 38/1024
# 430/430 - 5s - loss: 5.3897 - outputs_px_loss: 1.3474 - outputs_py_loss: 1.3474 - outputs_pz_loss: 1.3474 - outputs_energy_loss: 1.3474 - val_loss: 5.3794 - val_outputs_px_loss: 1.3449 - val_outputs_py_loss: 1.3448 - val_outputs_pz_loss: 1.3449 - val_outputs_energy_loss: 1.3448 - 5s/epoch - 11ms/step
# Epoch 39/1024
# 430/430 - 5s - loss: 5.3897 - outputs_px_loss: 1.3474 - outputs_py_loss: 1.3474 - outputs_pz_loss: 1.3474 - outputs_energy_loss: 1.3474 - val_loss: 5.3845 - val_outputs_px_loss: 1.3464 - val_outputs_py_loss: 1.3460 - val_outputs_pz_loss: 1.3461 - val_outputs_energy_loss: 1.3460 - 5s/epoch - 11ms/step
# Epoch 40/1024
# 430/430 - 5s - loss: 5.3897 - outputs_px_loss: 1.3474 - outputs_py_loss: 1.3474 - outputs_pz_loss: 1.3474 - outputs_energy_loss: 1.3474 - val_loss: 5.3801 - val_outputs_px_loss: 1.3451 - val_outputs_py_loss: 1.3450 - val_outputs_pz_loss: 1.3450 - val_outputs_energy_loss: 1.3450 - 5s/epoch - 11ms/step
# Epoch 41/1024
# 430/430 - 5s - loss: 5.3897 - outputs_px_loss: 1.3474 - outputs_py_loss: 1.3474 - outputs_pz_loss: 1.3474 - outputs_energy_loss: 1.3474 - val_loss: 5.3782 - val_outputs_px_loss: 1.3446 - val_outputs_py_loss: 1.3445 - val_outputs_pz_loss: 1.3445 - val_outputs_energy_loss: 1.3445 - 5s/epoch - 11ms/step
# Epoch 42/1024
# 430/430 - 5s - loss: 5.3889 - outputs_px_loss: 1.3472 - outputs_py_loss: 1.3472 - outputs_pz_loss: 1.3472 - outputs_energy_loss: 1.3472 - val_loss: 5.3801 - val_outputs_px_loss: 1.3452 - val_outputs_py_loss: 1.3449 - val_outputs_pz_loss: 1.3450 - val_outputs_energy_loss: 1.3450 - 5s/epoch - 11ms/step
# Epoch 43/1024
# 430/430 - 5s - loss: 5.3894 - outputs_px_loss: 1.3473 - outputs_py_loss: 1.3473 - outputs_pz_loss: 1.3473 - outputs_energy_loss: 1.3474 - val_loss: 5.3787 - val_outputs_px_loss: 1.3447 - val_outputs_py_loss: 1.3447 - val_outputs_pz_loss: 1.3447 - val_outputs_energy_loss: 1.3446 - 5s/epoch - 11ms/step
# Epoch 44/1024
# 430/430 - 5s - loss: 5.3887 - outputs_px_loss: 1.3472 - outputs_py_loss: 1.3472 - outputs_pz_loss: 1.3472 - outputs_energy_loss: 1.3472 - val_loss: 5.3772 - val_outputs_px_loss: 1.3443 - val_outputs_py_loss: 1.3443 - val_outputs_pz_loss: 1.3443 - val_outputs_energy_loss: 1.3443 - 5s/epoch - 11ms/step
# Epoch 45/1024
# 430/430 - 5s - loss: 5.3878 - outputs_px_loss: 1.3469 - outputs_py_loss: 1.3469 - outputs_pz_loss: 1.3469 - outputs_energy_loss: 1.3469 - val_loss: 5.3794 - val_outputs_px_loss: 1.3449 - val_outputs_py_loss: 1.3449 - val_outputs_pz_loss: 1.3449 - val_outputs_energy_loss: 1.3448 - 5s/epoch - 11ms/step
# Epoch 46/1024
# 430/430 - 5s - loss: 5.3885 - outputs_px_loss: 1.3471 - outputs_py_loss: 1.3471 - outputs_pz_loss: 1.3471 - outputs_energy_loss: 1.3471 - val_loss: 5.3778 - val_outputs_px_loss: 1.3445 - val_outputs_py_loss: 1.3444 - val_outputs_pz_loss: 1.3444 - val_outputs_energy_loss: 1.3444 - 5s/epoch - 11ms/step
# Epoch 47/1024
# 430/430 - 5s - loss: 5.3884 - outputs_px_loss: 1.3471 - outputs_py_loss: 1.3471 - outputs_pz_loss: 1.3471 - outputs_energy_loss: 1.3471 - val_loss: 5.3822 - val_outputs_px_loss: 1.3457 - val_outputs_py_loss: 1.3455 - val_outputs_pz_loss: 1.3455 - val_outputs_energy_loss: 1.3454 - 5s/epoch - 11ms/step
# Epoch 48/1024
# 430/430 - 5s - loss: 5.3881 - outputs_px_loss: 1.3470 - outputs_py_loss: 1.3470 - outputs_pz_loss: 1.3470 - outputs_energy_loss: 1.3470 - val_loss: 5.3783 - val_outputs_px_loss: 1.3448 - val_outputs_py_loss: 1.3445 - val_outputs_pz_loss: 1.3445 - val_outputs_energy_loss: 1.3445 - 5s/epoch - 11ms/step
# Epoch 49/1024
# 430/430 - 5s - loss: 5.3876 - outputs_px_loss: 1.3469 - outputs_py_loss: 1.3469 - outputs_pz_loss: 1.3469 - outputs_energy_loss: 1.3469 - val_loss: 5.3764 - val_outputs_px_loss: 1.3441 - val_outputs_py_loss: 1.3441 - val_outputs_pz_loss: 1.3441 - val_outputs_energy_loss: 1.3441 - 5s/epoch - 11ms/step
# Epoch 50/1024
# 430/430 - 5s - loss: 5.3872 - outputs_px_loss: 1.3468 - outputs_py_loss: 1.3468 - outputs_pz_loss: 1.3468 - outputs_energy_loss: 1.3468 - val_loss: 5.3789 - val_outputs_px_loss: 1.3449 - val_outputs_py_loss: 1.3447 - val_outputs_pz_loss: 1.3447 - val_outputs_energy_loss: 1.3446 - 5s/epoch - 11ms/step
# Epoch 51/1024
# 430/430 - 5s - loss: 5.3877 - outputs_px_loss: 1.3469 - outputs_py_loss: 1.3469 - outputs_pz_loss: 1.3469 - outputs_energy_loss: 1.3469 - val_loss: 5.3776 - val_outputs_px_loss: 1.3445 - val_outputs_py_loss: 1.3444 - val_outputs_pz_loss: 1.3444 - val_outputs_energy_loss: 1.3443 - 5s/epoch - 11ms/step
# Epoch 52/1024
# 430/430 - 5s - loss: 5.3870 - outputs_px_loss: 1.3468 - outputs_py_loss: 1.3467 - outputs_pz_loss: 1.3467 - outputs_energy_loss: 1.3467 - val_loss: 5.3784 - val_outputs_px_loss: 1.3447 - val_outputs_py_loss: 1.3445 - val_outputs_pz_loss: 1.3445 - val_outputs_energy_loss: 1.3446 - 5s/epoch - 11ms/step
# Epoch 53/1024
# 430/430 - 5s - loss: 5.3874 - outputs_px_loss: 1.3469 - outputs_py_loss: 1.3469 - outputs_pz_loss: 1.3468 - outputs_energy_loss: 1.3468 - val_loss: 5.3773 - val_outputs_px_loss: 1.3444 - val_outputs_py_loss: 1.3443 - val_outputs_pz_loss: 1.3443 - val_outputs_energy_loss: 1.3443 - 5s/epoch - 11ms/step

# %%
# Make a directory
dir_name = HOME_PATH + "4th_trial//w_lead_result/"
name = "dnn_w_lead_full_scaled"

# If the directory exists
if os.path.exists(dir_name):
    test_files = glob.glob(dir_name + "*" + name + "*")
    if test_files:
        for file in test_files:
            os.remove(file)
else:
    os.makedirs(dir_name)

# save model
model.save(dir_name + name + ".h5", save_format="h5", overwrite=True)

# predict
pred_y = model.predict(test_x)
# save predicted results
np.savez_compressed(dir_name + name + "_data.npz", pred_y=pred_y, test_y=test_y)
sig_pred = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth = np.load(dir_name + name + "_data.npz")["test_y"]
# Out:
#   136/18306 [..............................] - ETA: 6s
# /opt/miniconda3/envs/work_env/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 18306/18306 [==============================] - 8s 417us/step

# %%
test_loss = [history.history["loss"], history.history["outputs_px_loss"], history.history["outputs_py_loss"], history.history["outputs_pz_loss"], history.history["outputs_energy_loss"], history.history["outputs_mass_loss"]]
val_loss  = [history.history["val_loss"], history.history["val_outputs_px_loss"], history.history["val_outputs_py_loss"], history.history["val_outputs_pz_loss"], history.history["val_outputs_energy_loss"], history.history["val_outputs_mass_loss"]]
name = ["total", "px", "py", "pz", "energy", "mass"]
for i in range(len(name)):
	plt.plot(test_loss[i], label=name[i])
plt.legend()
plt.semilogy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 test_loss = [history.history["loss"], history.history["outputs_px_loss"], history.history["outputs_py_loss"], history.history["outputs_pz_loss"], history.history["outputs_energy_loss"], history.history["outputs_mass_loss"]]
#       2 val_loss  = [history.history["val_loss"], history.history["val_outputs_px_loss"], history.history["val_outputs_py_loss"], history.history["val_outputs_pz_loss"], history.history["val_outputs_energy_loss"], history.history["val_outputs_mass_loss"]]
#       3 name = ["total", "px", "py", "pz", "energy", "mass"]
#
# KeyError: 'outputs_mass_loss'

# %%
sig_pred.shape
# Out:
# (5, 585773, 1)

# %%
sig_truth_inv = ROBUST_INT.inverse_transform(sig_truth)
sig_pred_inv = ROBUST_INT.inverse_transform(sig_pred.reshape(sig_truth.shape))
# sig_truth_inv = sig_truth
# sig_pred_inv = sig_pred.reshape(sig_truth.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[236], line 2
#       1 sig_truth_inv = ROBUST_INT.inverse_transform(sig_truth)
# ----> 2 sig_pred_inv = ROBUST_INT.inverse_transform(sig_pred.reshape(sig_truth.shape))
#       3 # sig_truth_inv = sig_truth
#       4 # sig_pred_inv = sig_pred.reshape(sig_truth.shape)
#
# ValueError: cannot reshape array of size 2928865 into shape (585773,4)

# %%
# name the file
name = "dnn_w_lead_full"

# save predicted results
np.savez_compressed(
    dir_name + name + "_data.npz", pred_y=sig_pred_inv, test_y=sig_truth_inv
)
sig_pred_inv = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth_inv = np.load(dir_name + name + "_data.npz")["test_y"]

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,0]):.3f}, std: {np.std(sig_truth_inv[:,0]):.3f}, min: {np.min(sig_truth_inv[:,0]):.3f}, max: {np.max(sig_truth_inv[:,0]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 0], sig_pred_inv[:, 0]],
    label=r"$p_{x}^{W}$",
    title="Leading $p_{x}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,0], sig_pred_inv[:,0])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 0],
    sig_pred_inv[:, 0],
    r"Leading $p_{x}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,0], sig_pred_inv[:,0])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.017, std: 35.174, min: -680.444, max: 605.596

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,1]):.3f}, std: {np.std(sig_truth_inv[:,1]):.3f}, min: {np.min(sig_truth_inv[:,1]):.3f}, max: {np.max(sig_truth_inv[:,1]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 1], sig_pred_inv[:, 1]],
    label=r"$p_{y}^{W}$",
    title="Leading $p_{y}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,1], sig_pred_inv[:,1])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 1],
    sig_pred_inv[:, 1],
    r"Leading $p_{y}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,1], sig_pred_inv[:,1])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.052, std: 35.023, min: -633.311, max: 760.803

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,2]):.3f}, std: {np.std(sig_truth_inv[:,2]):.3f}, min: {np.min(sig_truth_inv[:,2]):.3f}, max: {np.max(sig_truth_inv[:,2]):.3f}"
)

set_range = [-800, 800]

plot.hist(
    data=[sig_truth_inv[:, 2], sig_pred_inv[:, 2]],
    label=r"$p_{z}^{W}$",
    title="Leading $p_{z}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,2], sig_pred_inv[:,2])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 2],
    sig_pred_inv[:, 2],
    r"Leading $p_{z}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,2], sig_pred_inv[:,2])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.424, std: 322.901, min: -3791.950, max: 3842.319

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,3]):.3f}, std: {np.std(sig_truth_inv[:,3]):.3f}, min: {np.min(sig_truth_inv[:,3]):.3f}, max: {np.max(sig_truth_inv[:,3]):.3f}"
)

set_range = [0, 1800]

plot.hist(
    data=[sig_truth_inv[:,3], sig_pred_inv[:,3]],
    label=r"$E^{W}$",
    title="Leading $E^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,3], sig_pred_inv[:,3])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:,3],
    sig_pred_inv[:,3],
    r"Leading $E^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,3], sig_pred_inv[:,3])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 228.412, std: 244.739, min: 18.513, max: 3843.166

# %%
w_mass = 80.377 # GeV
sig_truth_energy_full = np.sqrt(
    np.square(w_mass)
    + np.sum(np.square(w_lead[["px", "py", "pz"]][PRE_CUT].to_numpy() / GEV), axis=-1)
)
sig_truth_energy = np.sqrt(
    np.square(w_mass)
    + np.sum(np.square(sig_truth_inv), axis=-1)
)
sig_pred_energy = np.sqrt(
    np.square(w_mass)
    + np.sum(np.square(sig_pred_inv), axis=-1)
)

# %%
plt.hist(sig_truth_energy_full, bins=100, color="r", histtype="step", label="Derived")
plt.hist(w_lead[["E"]][PRE_CUT]/GEV, bins=100, color="b", histtype="step", label="Truth")
plt.legend()
plt.xlim([0, 1000])
plt.xlabel("W energy [GeV]")
plt.ylabel("Count")
plt.show()
plt.close()

plt.hist(w_lead[["m"]][PRE_CUT]/GEV, bins=100, color="b", histtype="step", label="Truth")
plt.legend()
plt.xlim([0, 120])
plt.xlabel("W mass [GeV]")
plt.ylabel("Count")
plt.show()
plt.close()

# %%
# TODO
# energy
print(
    f"Truth mean: {np.mean(sig_truth_energy):.3f}, std: {np.std(sig_truth_energy):.3f}, min: {np.min(sig_truth_energy):.3f}, max: {np.max(sig_truth_energy):.3f}"
)

set_range = [0, 1000]

plot.hist(
    data=[sig_truth_energy, sig_pred_energy],
    label=r"$E^{W}$",
    title="Leading $E^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_energy, sig_pred_energy)):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_energy,
    sig_pred_energy,
    r"Leading $E^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_energy, sig_pred_energy)[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 339.017, std: 340.097, min: 84.534, max: 5435.652

# %%
# import shap
# import matplotlib as mpl

# mpl.rcParams.update(mpl.rcParamsDefault)

# feature_names = [
#     "lead_E",
#     "lead_px",
#     "lead_py",
#     "lead_pz",
#     "lead_pt",
#     "lead_eta",
#     "lead_phi",
#     "sublead_E",
#     "sublead_px",
#     "sublead_py",
#     "sublead_pz",
#     "sublead_pt",
#     "sublead_eta",
#     "sublead_phi",
#     "met_px",
#     "met_py",
# ]
# # lead
# # Use DeepExplainer for SHAP values
# explainer = shap.DeepExplainer(model, obs_kin[:1_024])
# shap_values = explainer.shap_values(obs_kin[:1_024])
# for i in range(shap_values.shape[-1]):
#     plt.figure(figsize=(10, 6))
#     shap.summary_plot(
#         shap_values[:, :, i],
#         obs_kin[:1_024],
#         feature_names=feature_names,
    #     plot_type="dot",
    #     show=False,
    # )
    # plt.title(f"SHAP Summary Plot for Lead Output: {feature_names[i+1]}")
    # plt.show()
