# %%
# %reset -sf

import tensorflow as tf
import tf_keras
print("Tensorflow:", tf.__version__)
import tensorflow_probability as tfp
print("Tensorflow Probability:", tfp.__version__)

# GPU(s) setups
gpus = tf.config.experimental.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(gpus[0], True)
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')
        
        # Enable memory growth for the first GPU
        tf.config.experimental.set_memory_growth(gpus[0], True)
        
        # Instead of enabling memory growth, set a memory limit
        memory_limit = 16_376 / 3 # Set the memory limit in MB
        # memory_limit = -1
        if memory_limit >= 0:
            tf.config.experimental.set_virtual_device_configuration(
                gpus[0],
                [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]
            )
            
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2025-02-28 19:22:34.906649: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-28 19:22:34.930002: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow: 2.16.1
# Tensorflow Probability: 0.24.0
# 1 Physical GPUs, 1 Logical GPU
# 2025-02-28 19:22:36.538525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
import sys
import os
import glob

HOME_PATH = os.path.abspath("..")
sys.path.insert(0, HOME_PATH + "/qe")

import paper_plot as pp

plot = pp.Plotter()

import pandas as pd
import numpy as np
import scipy as sp
import ROOT
from ROOT import TLorentzVector, TVector3
import multiprocessing
WORKERS = 16

from matplotlib import pyplot as plt

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "1"  # suppress tensorflow imformation messages

from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

SEED = 42  # set random seed (global variable)
GEV = 1e-3

# %%
import full_data as data

# reco
lead_lep = data.Lead_lep()
sublead_lep = data.Sublead_lep()
met = data.Met()

# truth
truth_lead_lep = data.Truth_lead_lep()
truth_sublead_lep = data.Truth_sublead_lep()
Truth_dilep = data.Truth_dilep()
truth_met = data.Truth_met()

# target Ws
w_lead = data.Lead_w()
w_sublead = data.Sublead_w()
mc_weight = data.MC_weight()
# Out:
# ['/CGLMP', '/RecoLep0', '/RecoLep1', '/RecoMET', '/TruthCandLep0', '/TruthCandLep1', '/TruthCandMET', '/TruthHiggs', '/TruthLep0', '/TruthLep1', '/TruthLepN', '/TruthLepP', '/TruthNu0', '/TruthNu1', '/TruthNuN', '/TruthNuP', '/TruthW0', '/TruthW1', '/TruthWN', '/TruthWP', '/eventWeight', '/mcWeight', '/recoWeight', '/weight']

# %%
# define preselection cuts

cut_pre_pt_lead = lead_lep.pt > 22 # 22 ~ 40 (SY)
print(len(lead_lep.energy) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = sublead_lep.pt > 15
print(len(lead_lep.energy) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.sqrt(
        np.square(lead_lep.energy + sublead_lep.energy)
        - np.square(lead_lep.px + sublead_lep.px)
        - np.square(lead_lep.py + sublead_lep.py)
        - np.square(lead_lep.pz + sublead_lep.pz)
    )
    > 10
)
print(len(lead_lep.energy) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = met.pt > 20
print(len(lead_lep.energy) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print(len(lead_lep.energy) - np.sum(PRE_CUT * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# # define preselection cuts

# cut_pre_pt_lead = lead_lep.pt > -9999
# print(len(lead_lep.energy) - np.sum(cut_pre_pt_lead * 1))
# cut_pre_pt_sub = sublead_lep.pt > -9999
# print(len(lead_lep.energy) - np.sum(cut_pre_pt_sub * 1))
# cut_pre_dilep_m = (
#     np.sqrt(
#         np.square(lead_lep.energy + sublead_lep.energy)
#         - np.square(lead_lep.px + sublead_lep.px)
#         - np.square(lead_lep.py + sublead_lep.py)
#         - np.square(lead_lep.pz + sublead_lep.pz)
#     )
#     > -9999
# )
# print(len(lead_lep.energy) - np.sum(cut_pre_dilep_m * 1))
# cut_pre_pt_miss = met.pt > -9999
# print(len(lead_lep.energy) - np.sum(cut_pre_pt_miss * 1))
# PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
# print(len(lead_lep.energy) - np.sum(PRE_CUT * 1))
# del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)
# Out:
# 0
# 29961
# 44269
# 89634
# 157782

# %%
# truth
truth_lead_lep_px = pd.DataFrame(truth_lead_lep.px[PRE_CUT])
truth_lead_lep_py = pd.DataFrame(truth_lead_lep.py[PRE_CUT])
truth_lead_lep_pz = pd.DataFrame(truth_lead_lep.pz[PRE_CUT])
truth_lead_lep_energy = pd.DataFrame(truth_lead_lep.energy[PRE_CUT])
truth_lead_lep_p4 = pd.concat(
	[truth_lead_lep_px, truth_lead_lep_py, truth_lead_lep_pz, truth_lead_lep_energy],
	axis=1,
).to_numpy()
truth_sublead_lep_px = pd.DataFrame(truth_sublead_lep.px[PRE_CUT])
truth_sublead_lep_py = pd.DataFrame(truth_sublead_lep.py[PRE_CUT])
truth_sublead_lep_pz = pd.DataFrame(truth_sublead_lep.pz[PRE_CUT])
truth_sublead_lep_energy = pd.DataFrame(truth_sublead_lep.energy[PRE_CUT])
truth_sublead_lep_p4 = pd.concat(
	[truth_sublead_lep_px, truth_sublead_lep_py, truth_sublead_lep_pz, truth_sublead_lep_energy],
	axis=1,
).to_numpy()
# reco
lead_lep_px = pd.DataFrame(lead_lep.px[PRE_CUT])
lead_lep_py = pd.DataFrame(lead_lep.py[PRE_CUT])
lead_lep_pz = pd.DataFrame(lead_lep.pz[PRE_CUT])
lead_lep_energy = pd.DataFrame(lead_lep.energy[PRE_CUT])
lead_lep_p4 = pd.concat(
	[lead_lep_px, lead_lep_py, lead_lep_pz, lead_lep_energy],
	axis=1,
).to_numpy()
sublead_lep_px = pd.DataFrame(sublead_lep.px[PRE_CUT])
sublead_lep_py = pd.DataFrame(sublead_lep.py[PRE_CUT])
sublead_lep_pz = pd.DataFrame(sublead_lep.pz[PRE_CUT])
sublead_lep_energy = pd.DataFrame(sublead_lep.energy[PRE_CUT])
sublead_lep_p4 = pd.concat(
	[sublead_lep_px, sublead_lep_py, sublead_lep_pz, sublead_lep_energy],
	axis=1,
).to_numpy()

# %%
## Observing variables

obs_kin = np.column_stack(
    (
        lead_lep.px,
        lead_lep.py,
        lead_lep.pz,
        lead_lep.energy,
        sublead_lep.px,
        sublead_lep.py,
        sublead_lep.pz,
        sublead_lep.energy,
        # np.log(sublead_lep.energy),
        # np.log(lead_lep.energy),
        # lead_lep.eta,
        # sublead_lep.eta,
        met.px,
        met.py,
    )
)[PRE_CUT]

# weights
mc_weight = mc_weight.w.to_numpy()[PRE_CUT]

# Kinematics of observing variables (inputs for training)
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array

# ROBUST_OBS = RobustScaler()
# obs_kin = ROBUST_OBS.fit_transform(obs_kin)
# print(type(obs_kin))
# Out:
# int_kin shape: (851115, 10)

# %%
## Interesting variables

w_lead_px = pd.DataFrame(w_lead.px[PRE_CUT])
w_lead_py = pd.DataFrame(w_lead.py[PRE_CUT])
w_lead_pz = pd.DataFrame(w_lead.pz[PRE_CUT])
w_lead_e = pd.DataFrame(w_lead.energy[PRE_CUT])
w_lead_log_e = pd.DataFrame(np.log(w_lead_e))
w_lead_sqrt_e = pd.DataFrame(np.sqrt(w_lead_e))
w_sublead_px = pd.DataFrame(w_sublead.px[PRE_CUT])
w_sublead_py = pd.DataFrame(w_sublead.py[PRE_CUT])
w_sublead_pz = pd.DataFrame(w_sublead.pz[PRE_CUT])
w_sublead_e = pd.DataFrame(w_sublead.energy[PRE_CUT])
w_sublead_log_e = pd.DataFrame(np.log(w_sublead_e))
w_sublead_sqrt_e = pd.DataFrame(np.sqrt(w_sublead_e))
w_lead_m = pd.DataFrame(w_lead.m[PRE_CUT])
w_sublead_m = pd.DataFrame(w_sublead.m[PRE_CUT])

# Kinematics of interesting variables (target for training)
int_kin = np.concatenate(
    [
        w_lead_px,
        w_lead_py,
        w_lead_pz,
        w_lead_e,
        w_sublead_px,
        w_sublead_py,
        w_sublead_pz,
        w_sublead_e,
        # np.square(w_lead_m) / np.mean(w_lead_m),
        # np.square(w_sublead_m) / np.mean(w_lead_m),
        # w_lead_m,
        # w_sublead_m,
    ],
    axis=-1,
)
print("int_kin shape:", int_kin.shape)
# int_kin = int_kin.to_numpy()  # convert to numpy array
print(type(int_kin))
# Out:
# int_kin shape: (851115, 8)
# <class 'numpy.ndarray'>

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.8,
    test_size=0.2,
    random_state=SEED,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=SEED
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
# test_x = np.concatenate([test_x, valid_x], axis=0)

train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]
# test_y = np.concatenate([test_y, valid_y], axis=0)

print("Total evts:", len(indices_arr))
print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# Total evts: 851115
# X (Interest)
# Training data shape: (680892, 10);
# Validing data shape: (85111, 10);
# Testing data shape: (85112, 10).
# Y (Observed)
# Training data shape: (680892, 8);
# Validing data shape: (85111, 8);
# Testing data shape: (85112, 8).

# %%
# training variables
BATCH_SIZE = 512
EPOCHS = 1024
LEARNING_RATE = 1e-5

# create datasets
train_dataset = tf.data.Dataset.from_tensor_slices((
    tf.cast(train_x, tf.float32), 
    tf.cast(train_y, tf.float32)
)).cache().batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

valid_dataset = tf.data.Dataset.from_tensor_slices((
    tf.cast(valid_x, tf.float32), 
    tf.cast(valid_y, tf.float32)
)).cache().batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# losses

def nu_mass_loss_fn(x_batch, y_pred):
    _epsilon = 1e-10
    x_batch = tf.cast(x_batch, tf.float32) #leps info
    y_pred = tf.cast(y_pred, tf.float32)   # Ws info
    
    n0_4vect = y_pred[..., :4] - x_batch[..., :4]
    n1_4vect = y_pred[..., 4:8] - x_batch[..., 4:8]

    nu0_mass = tf.sqrt(
            tf.math.maximum(
                tf.abs( tf.square(n0_4vect[..., 3]) - 
                        tf.reduce_sum(tf.square(n0_4vect[..., :3]), axis=-1)), _epsilon
            )
        )
    nu1_mass = tf.sqrt(
            tf.math.maximum(
                tf.abs( tf.square(n1_4vect[..., 3]) - 
                        tf.reduce_sum(tf.square(n1_4vect[..., :3]), axis=-1)), _epsilon
            )
        )
    
    return tf.reduce_mean(nu0_mass + nu1_mass)

def dinu_pt_loss_fn(x_batch, y_pred):
    _epsilon = 1e-10
    x_batch = tf.cast(x_batch, tf.float32) #leps info
    y_pred = tf.cast(y_pred, tf.float32)   # Ws info
    
    n0_4vect = y_pred[..., :4] - x_batch[..., :4]
    n1_4vect = y_pred[..., 4:8] - x_batch[..., 4:8]
    
    nn_4vect = n0_4vect + n1_4vect
    nn_px = nn_4vect[..., 0]
    nn_py = nn_4vect[..., 1]
    
    nn_px_diff = tf.math.maximum(tf.abs(nn_px - x_batch[..., 8]), _epsilon)
    nn_py_diff = tf.math.maximum(tf.abs(nn_py - x_batch[..., 9]), _epsilon)
    
    return tf.reduce_mean(nn_px_diff + nn_py_diff)

def higgs_mass_loss_fn(y_pred):
    _epsilon = 1e-10
    y_pred = tf.cast(y_pred, tf.float32)
    
    w0_4Vect = y_pred[..., :4]
    w1_4Vect = y_pred[..., 4:8]
    higgs_4Vect = w0_4Vect + w1_4Vect
    
    higgs_mass = tf.sqrt(
        tf.math.maximum(
            tf.abs( tf.square(higgs_4Vect[..., 3]) - 
                    tf.reduce_sum(tf.square(higgs_4Vect[..., :3]), axis=-1)), _epsilon
        )
    )
    
    return tf.reduce_mean(tf.abs(higgs_mass - 125.0)) + _epsilon


def mae_loss_fn(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return tf.reduce_mean(tf.keras.losses.mae(y_true, y_pred))

# %%
class CustomModel(tf.keras.Model):
    def __init__(self, base_model):
        super().__init__()
        self.base_model = base_model
        self.current_epoch = tf.Variable(0.0, trainable=False)
        
        # Initialize metrics dictionary with lambda_weight
        self.metric_dict = {
            'mae1_loss': tf.keras.metrics.Mean(name='mae1_loss'),
            'mae2_loss': tf.keras.metrics.Mean(name='mae2_loss'),
            'nu_mass_loss': tf.keras.metrics.Mean(name='nu_mass_loss'),
            'higgs_mass_loss': tf.keras.metrics.Mean(name='higgs_mass_loss'),
            'dinu_pt_loss': tf.keras.metrics.Mean(name='dinu_pt_loss'),
            'fused_output_loss': tf.keras.metrics.Mean(name='fused_output_loss'),
            'loss': tf.keras.metrics.Mean(name='loss'),
            'lambda_weight': tf.keras.metrics.Mean(name='lambda_weight')  # Track mean lambda
        }

    def call(self, inputs, training=None):
        return self.base_model(inputs, training=training)
    
    def compile(self, optimizer, loss_weights=None, **kwargs):
        super().compile(optimizer=optimizer, **kwargs)
        default_weights = {
            'mae1': 1.0,
            'mae2': 1.0,
            'nu_mass': 1.0,
            'higgs_mass': 1.0,
            'dinu_pt': 1.0,
            'fused_output': 1.0
        }
        self.loss_weights = {**default_weights, **(loss_weights or {})}

    @property
    def metrics(self):
        return list(self.metric_dict.values())

    def _compute_losses(self, x, y, predictions):
        # Unpack four outputs: [fused_output, nu_mass_output, mae_output, lambda_weight]
        fused_output, nu_mass_output, mae_output, lambda_weight = predictions
        
        losses = {
            'mae1': mae_loss_fn(y, mae_output),  # Use mae_output for MAE net(adjust if needed)
            'mae2': mae_loss_fn(y, fused_output),  # Use nu_mass net  for MAE (adjust if needed)
            'nu_mass': nu_mass_loss_fn(x, fused_output),
            'higgs_mass': higgs_mass_loss_fn(fused_output),
            'dinu_pt': dinu_pt_loss_fn(x, fused_output),
            'fused_output': mae_loss_fn(y, fused_output)
        }
        
        total_loss = tf.add_n([
            self.loss_weights[name] * loss for name, loss in losses.items()
        ])
        
        return total_loss, losses, lambda_weight  # Return lambda_weight for tracking

    def _update_metrics(self, total_loss, losses, lambda_weight):
        """Helper method to update metrics"""
        self.metric_dict['loss'].update_state(total_loss)
        for name, loss in losses.items():
            self.metric_dict[f'{name}_loss'].update_state(loss)
        self.metric_dict['lambda_weight'].update_state(tf.reduce_mean(lambda_weight))  # Track mean

    def train_step(self, data):
        x, y = data
        with tf.GradientTape() as tape:
            predictions = self(x, training=True)
            total_loss, losses, lambda_weight = self._compute_losses(x, y, predictions)

        gradients = tape.gradient(total_loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        
        # self.current_epoch.assign_add(1.0)
        self._update_metrics(total_loss, losses, lambda_weight)
        
        return {name: metric.result() for name, metric in self.metric_dict.items()}

    def test_step(self, data):
        x, y = data
        predictions = self(x, training=False)
        total_loss, losses, lambda_weight = self._compute_losses(x, y, predictions)
        
        self._update_metrics(total_loss, losses, lambda_weight)
        
        return {name: metric.result() for name, metric in self.metric_dict.items()}

# %%
# Define the WBosonFourVectorLayer (as provided earlier)
class WBosonFourVectorLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(WBosonFourVectorLayer, self).__init__(**kwargs)

    def call(self, inputs):
        lep0, lep1, nu_3mom = inputs
        nu0_3mom = nu_3mom[..., :3]  # [px, py, pz] for nu0
        nu1_3mom = nu_3mom[..., 3:]  # [px, py, pz] for nu1
        nu0_p_squared = tf.reduce_sum(tf.square(nu0_3mom), axis=-1, keepdims=True)
        nu1_p_squared = tf.reduce_sum(tf.square(nu1_3mom), axis=-1, keepdims=True)
        nu0_energy = tf.sqrt(tf.maximum(nu0_p_squared, 1e-10))
        nu1_energy = tf.sqrt(tf.maximum(nu1_p_squared, 1e-10))
        nu0_4vect = tf.concat([nu0_3mom, nu0_energy], axis=-1)
        nu1_4vect = tf.concat([nu1_3mom, nu1_energy], axis=-1)
        w0_4vect = lep0 + nu0_4vect
        w1_4vect = lep1 + nu1_4vect
        return tf.concat([w0_4vect, w1_4vect], axis=-1)

    def compute_output_shape(self, input_shape):
        return (input_shape[0][0], 8)

# %%
def dense_dropout_block(x, units, activation="swish", dropout_rate=0.0, l2=0.0):
    x = tf.keras.layers.Dense(
        units=units,
        use_bias=True,
        kernel_initializer='he_normal',
        kernel_regularizer=tf.keras.regularizers.L2(l2),
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    if dropout_rate > 0:    
        x = tf.keras.layers.Dropout(rate=dropout_rate)(x)
    return x

def residual_block(x, units, activation="swish", dropout_rate=0.0, l2=0.0):
    y = dense_dropout_block(x, units, activation=activation, dropout_rate=dropout_rate, l2=l2)
    y = dense_dropout_block(y, units, activation=activation, dropout_rate=dropout_rate, l2=l2)
    if x.shape[-1] != units:
        x = tf.keras.layers.Dense(units, activation=None, use_bias=False)(x)
    z = tf.keras.layers.Add()([x, y]) 
    z = tf.keras.layers.BatchNormalization()(z) 
    z = tf.keras.layers.Activation(activation)(z)
    return z

# %%
def build_model(input_shape):
    inputs = tf.keras.layers.Input(shape=(input_shape,), dtype=tf.float32)
    x, y = inputs, inputs
    
    # Extract lepton 4-vectors for Subnet 1
    lep0 = inputs[..., :4]  # [px, py, pz, e] for leading lepton
    lep1 = inputs[..., 4:8]  # [px, py, pz, e] for subleading lepton
    
    # Subnet 1 --> Predict neutrino 3-momenta and apply physics layer
    for _ in range(2):
        x = residual_block(x, 128, dropout_rate=0.2, l2=1e-5)
        x = residual_block(x, 32, dropout_rate=0.2, l2=1e-5)
    for _ in range(2):
        x = residual_block(x, 256, dropout_rate=0.2, l2=1e-5)
    for _ in range(2):
        x = residual_block(x, 64, dropout_rate=0.2, l2=1e-5)
        x = residual_block(x, 32, dropout_rate=0.2, l2=1e-5)
    # Bottleneck
    x = tf.keras.layers.Dense(16, activation=None, kernel_initializer='he_normal')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("swish")(x)
    nu_3mom = tf.keras.layers.Dense(units=6, activation="linear", kernel_initializer='he_normal', name='nu_3mom')(x)
    outputs1 = WBosonFourVectorLayer()([lep0, lep1, nu_3mom])
    
    # Subnet 2 --> First MAE (unchanged)
    for _ in range(2):
        y = residual_block(y, 128, dropout_rate=0.2, l2=1e-5)
        y = residual_block(y, 32, dropout_rate=0.2, l2=1e-5)
    for _ in range(2):
        y = residual_block(y, 256, dropout_rate=0.2, l2=1e-5)
    for _ in range(2):
        y = residual_block(y, 64, dropout_rate=0.2, l2=1e-5)
        y = residual_block(y, 32, dropout_rate=0.2, l2=1e-5)
    # Bottleneck
    y = tf.keras.layers.Dense(16, activation=None, kernel_initializer='he_normal')(y)
    y = tf.keras.layers.BatchNormalization()(y)
    y = tf.keras.layers.Activation("swish")(y)
    outputs2 = tf.keras.layers.Dense(units=8, activation="linear", kernel_initializer='he_normal')(y)
    
    # Fusion network with trainable lambda
    lambda_inputs = tf.keras.layers.Concatenate(axis=-1)([outputs1, outputs2])  # Shape: (batch, 16)
    lambda_weight = tf.keras.layers.Dense(1, activation="linear", kernel_initializer='he_normal', name='lambda_weight')(lambda_inputs)  # Shape: (batch, 1)
    
    # Apply weighted sum
    z = outputs1 + lambda_weight * outputs2  # (batch, 8) + (batch, 1) * (batch, 8) -> (batch, 8)
    
    # Continue with the rest of the fusion network
    # z = tf.keras.layers.Dense(64, activation=None, kernel_initializer='he_normal')(z)
    # z = tf.keras.layers.BatchNormalization()(z)
    # z = tf.keras.layers.Activation("swish")(z)
    # z = tf.keras.layers.Dense(16, activation=None, kernel_initializer='he_normal')(z)
    # z = tf.keras.layers.BatchNormalization()(z)
    # z = tf.keras.layers.Activation("swish")(z)
    z = residual_block(z, 16, dropout_rate=0.0, l2=0.0)
    outputs = tf.keras.layers.Dense(units=8, activation="linear", kernel_initializer='he_normal')(z)
    
    return tf.keras.Model(inputs=inputs, outputs=[outputs, outputs1, outputs2, lambda_weight])

# %%
# # Add TensorBoard import at the top with other imports
# from datetime import datetime

# # In the callbacks section:
# current_time = datetime.now().strftime("%Y%m%d-%H%M%S")
# log_dir = f"{HOME_PATH}/10th_trial/logs/{current_time}"

# Build and compile model
base_model = build_model(train_x.shape[-1])
model = CustomModel(base_model)
model.summary()

# Model compilation with weights dictionary
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss_weights={
        'mae1': 0.5,
        'mae2': 0.5,
        'nu_mass': 0.0,
        'higgs_mass': 0.0,
        'dinu_pt': 0.0,
        'fused_output': 1.0
    },
    jit_compile=True,
    steps_per_execution=256,
)

# Updated callbacks
class EpochUpdater(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        self.model.current_epoch.assign(float(epoch))

class LambdaTracker(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        epoch_num = int(self.model.current_epoch.numpy())
        log_str = f"Epoch {epoch_num}"
        # Log all metrics
        for name, value in logs.items():
            log_str += f"; {name}: {value:.4f}"
        print(log_str)

# class DebugLogger(tf.keras.callbacks.Callback):
#     def on_epoch_end(self, epoch, logs=None):
#         current_epoch = self.model.current_epoch.numpy()
#         test_log_term = tf.math.log(tf.cast(current_epoch + 21.0, tf.float32)) - 3.0
#         print(f"Epoch {current_epoch}; Log factor: {test_log_term:.4f}; Mass loss: {logs['mass_loss']:.4f}")

callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    EpochUpdater(),
    LambdaTracker(),
    # tf.keras.callbacks.TensorBoard(
    #     log_dir=log_dir,
    #     histogram_freq=1,
    #     write_graph=True,
    #     write_images=True,
    #     update_freq='epoch',
    #     profile_batch=0,
    #     embeddings_freq=0,
    # ),
]

history = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=0,
)

# Print the weights
print("\nModel Loss Weights:")
for name, weight in model.loss_weights.items():
    print(f"{name:12s}: {weight:.3f}")
# Out:
# Model: "custom_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional (Functional)         │ ((None, 8), (None, 8), │       691,463 │
# │                                 │ (None, 8), (None, 1))  │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 691,463 (2.64 MB)
#  Trainable params: 679,015 (2.59 MB)
#  Non-trainable params: 12,448 (48.62 KB)
# Epoch 0; dinu_pt_loss: 64.5442; fused_output_loss: 67.8297; higgs_mass_loss: 124.2205; lambda_weight: 0.1157; loss: 135.6788; mae1_loss: 67.8682; mae2_loss: 67.8297; nu_mass_loss: 12.5045; val_dinu_pt_loss: 64.2188; val_fused_output_loss: 67.5156; val_higgs_mass_loss: 124.4876; val_lambda_weight: 0.1293; val_loss: 135.0507; val_mae1_loss: 67.5546; val_mae2_loss: 67.5156; val_nu_mass_loss: 9.7941
# Epoch 1; dinu_pt_loss: 64.5222; fused_output_loss: 67.7874; higgs_mass_loss: 124.1878; lambda_weight: 0.4481; loss: 135.6085; mae1_loss: 67.8551; mae2_loss: 67.7874; nu_mass_loss: 12.0639; val_dinu_pt_loss: 64.1966; val_fused_output_loss: 67.4811; val_higgs_mass_loss: 124.4038; val_lambda_weight: 0.0343; val_loss: 134.9958; val_mae1_loss: 67.5481; val_mae2_loss: 67.4811; val_nu_mass_loss: 9.6813
# Epoch 2; dinu_pt_loss: 64.4906; fused_output_loss: 67.7466; higgs_mass_loss: 124.1284; lambda_weight: 0.0463; loss: 135.5404; mae1_loss: 67.8413; mae2_loss: 67.7466; nu_mass_loss: 11.9945; val_dinu_pt_loss: 64.1763; val_fused_output_loss: 67.4467; val_higgs_mass_loss: 124.3170; val_lambda_weight: -0.6879; val_loss: 134.9398; val_mae1_loss: 67.5395; val_mae2_loss: 67.4467; val_nu_mass_loss: 9.9405
# Epoch 3; dinu_pt_loss: 64.4617; fused_output_loss: 67.7045; higgs_mass_loss: 124.0423; lambda_weight: -0.8571; loss: 135.4711; mae1_loss: 67.8287; mae2_loss: 67.7045; nu_mass_loss: 12.2369; val_dinu_pt_loss: 64.1503; val_fused_output_loss: 67.4044; val_higgs_mass_loss: 124.2042; val_lambda_weight: -1.7022; val_loss: 134.8719; val_mae1_loss: 67.5306; val_mae2_loss: 67.4044; val_nu_mass_loss: 10.5543
# Epoch 4; dinu_pt_loss: 64.4275; fused_output_loss: 67.6586; higgs_mass_loss: 123.9392; lambda_weight: -2.0001; loss: 135.3959; mae1_loss: 67.8162; mae2_loss: 67.6586; nu_mass_loss: 12.6112; val_dinu_pt_loss: 64.1171; val_fused_output_loss: 67.3572; val_higgs_mass_loss: 124.0797; val_lambda_weight: -2.8245; val_loss: 134.7961; val_mae1_loss: 67.5207; val_mae2_loss: 67.3572; val_nu_mass_loss: 11.1814
# Epoch 5; dinu_pt_loss: 64.3812; fused_output_loss: 67.6066; higgs_mass_loss: 123.7984; lambda_weight: -3.1590; loss: 135.3127; mae1_loss: 67.8054; mae2_loss: 67.6066; nu_mass_loss: 13.2031; val_dinu_pt_loss: 64.0795; val_fused_output_loss: 67.2999; val_higgs_mass_loss: 123.9045; val_lambda_weight: -3.9084; val_loss: 134.7050; val_mae1_loss: 67.5102; val_mae2_loss: 67.2999; val_nu_mass_loss: 12.0238
# Epoch 6; dinu_pt_loss: 64.3368; fused_output_loss: 67.5510; higgs_mass_loss: 123.6240; lambda_weight: -4.1902; loss: 135.2237; mae1_loss: 67.7944; mae2_loss: 67.5510; nu_mass_loss: 13.8918; val_dinu_pt_loss: 64.0410; val_fused_output_loss: 67.2426; val_higgs_mass_loss: 123.7174; val_lambda_weight: -4.7731; val_loss: 134.6129; val_mae1_loss: 67.4982; val_mae2_loss: 67.2426; val_nu_mass_loss: 12.8409
# Epoch 7; dinu_pt_loss: 64.2821; fused_output_loss: 67.4879; higgs_mass_loss: 123.4036; lambda_weight: -4.9888; loss: 135.1230; mae1_loss: 67.7827; mae2_loss: 67.4879; nu_mass_loss: 14.7184; val_dinu_pt_loss: 63.9875; val_fused_output_loss: 67.1777; val_higgs_mass_loss: 123.4998; val_lambda_weight: -5.4534; val_loss: 134.5099; val_mae1_loss: 67.4867; val_mae2_loss: 67.1777; val_nu_mass_loss: 13.7479
# Epoch 8; dinu_pt_loss: 64.2200; fused_output_loss: 67.4197; higgs_mass_loss: 123.1545; lambda_weight: -5.5217; loss: 135.0146; mae1_loss: 67.7700; mae2_loss: 67.4197; nu_mass_loss: 15.6169; val_dinu_pt_loss: 63.9261; val_fused_output_loss: 67.1068; val_higgs_mass_loss: 123.2161; val_lambda_weight: -5.7872; val_loss: 134.3974; val_mae1_loss: 67.4746; val_mae2_loss: 67.1068; val_nu_mass_loss: 14.8919
# Epoch 9; dinu_pt_loss: 64.1532; fused_output_loss: 67.3466; higgs_mass_loss: 122.8609; lambda_weight: -5.6973; loss: 134.8985; mae1_loss: 67.7572; mae2_loss: 67.3466; nu_mass_loss: 16.6690; val_dinu_pt_loss: 63.8601; val_fused_output_loss: 67.0287; val_higgs_mass_loss: 122.8735; val_lambda_weight: -5.8308; val_loss: 134.2737; val_mae1_loss: 67.4615; val_mae2_loss: 67.0287; val_nu_mass_loss: 16.1986
# Epoch 10; dinu_pt_loss: 64.0826; fused_output_loss: 67.2717; higgs_mass_loss: 122.5560; lambda_weight: -5.6638; loss: 134.7792; mae1_loss: 67.7436; mae2_loss: 67.2717; nu_mass_loss: 17.7746; val_dinu_pt_loss: 63.7921; val_fused_output_loss: 66.9510; val_higgs_mass_loss: 122.5398; val_lambda_weight: -5.7639; val_loss: 134.1502; val_mae1_loss: 67.4474; val_mae2_loss: 66.9510; val_nu_mass_loss: 17.4449
# Epoch 11; dinu_pt_loss: 64.0094; fused_output_loss: 67.1958; higgs_mass_loss: 122.2616; lambda_weight: -5.6566; loss: 134.6588; mae1_loss: 67.7301; mae2_loss: 67.1958; nu_mass_loss: 18.8040; val_dinu_pt_loss: 63.7193; val_fused_output_loss: 66.8708; val_higgs_mass_loss: 122.2072; val_lambda_weight: -5.7330; val_loss: 134.0228; val_mae1_loss: 67.4333; val_mae2_loss: 66.8708; val_nu_mass_loss: 18.6475
# Epoch 12; dinu_pt_loss: 63.9303; fused_output_loss: 67.1185; higgs_mass_loss: 121.9707; lambda_weight: -5.6505; loss: 134.5351; mae1_loss: 67.7151; mae2_loss: 67.1185; nu_mass_loss: 19.8209; val_dinu_pt_loss: 63.6408; val_fused_output_loss: 66.7899; val_higgs_mass_loss: 121.8854; val_lambda_weight: -5.6422; val_loss: 133.8937; val_mae1_loss: 67.4175; val_mae2_loss: 66.7899; val_nu_mass_loss: 19.7848
# Epoch 13; dinu_pt_loss: 63.8433; fused_output_loss: 67.0384; higgs_mass_loss: 121.6754; lambda_weight: -5.6481; loss: 134.4074; mae1_loss: 67.6995; mae2_loss: 67.0384; nu_mass_loss: 20.8074; val_dinu_pt_loss: 63.5529; val_fused_output_loss: 66.7045; val_higgs_mass_loss: 121.5541; val_lambda_weight: -5.6637; val_loss: 133.7568; val_mae1_loss: 67.4001; val_mae2_loss: 66.7045; val_nu_mass_loss: 20.9460
# Epoch 14; dinu_pt_loss: 63.7512; fused_output_loss: 66.9560; higgs_mass_loss: 121.3787; lambda_weight: -5.6985; loss: 134.2756; mae1_loss: 67.6829; mae2_loss: 66.9560; nu_mass_loss: 21.7510; val_dinu_pt_loss: 63.4599; val_fused_output_loss: 66.6168; val_higgs_mass_loss: 121.2338; val_lambda_weight: -5.6508; val_loss: 133.6150; val_mae1_loss: 67.3794; val_mae2_loss: 66.6168; val_nu_mass_loss: 21.9520
# Epoch 15; dinu_pt_loss: 63.6445; fused_output_loss: 66.8689; higgs_mass_loss: 121.0693; lambda_weight: -5.8044; loss: 134.1359; mae1_loss: 67.6649; mae2_loss: 66.8689; nu_mass_loss: 22.6894; val_dinu_pt_loss: 63.3468; val_fused_output_loss: 66.5182; val_higgs_mass_loss: 120.8727; val_lambda_weight: -5.7127; val_loss: 133.4571; val_mae1_loss: 67.3595; val_mae2_loss: 66.5182; val_nu_mass_loss: 23.0756
# Epoch 16; dinu_pt_loss: 63.5185; fused_output_loss: 66.7768; higgs_mass_loss: 120.7448; lambda_weight: -5.9501; loss: 133.9877; mae1_loss: 67.6452; mae2_loss: 66.7768; nu_mass_loss: 23.6145; val_dinu_pt_loss: 63.2134; val_fused_output_loss: 66.4175; val_higgs_mass_loss: 120.5165; val_lambda_weight: -5.8479; val_loss: 133.2941; val_mae1_loss: 67.3358; val_mae2_loss: 66.4175; val_nu_mass_loss: 24.0938
# Epoch 17; dinu_pt_loss: 63.3782; fused_output_loss: 66.6805; higgs_mass_loss: 120.4118; lambda_weight: -6.1224; loss: 133.8324; mae1_loss: 67.6232; mae2_loss: 66.6805; nu_mass_loss: 24.4916; val_dinu_pt_loss: 63.0708; val_fused_output_loss: 66.3114; val_higgs_mass_loss: 120.1431; val_lambda_weight: -6.0396; val_loss: 133.1233; val_mae1_loss: 67.3125; val_mae2_loss: 66.3114; val_nu_mass_loss: 25.0627
# Epoch 18; dinu_pt_loss: 63.2255; fused_output_loss: 66.5789; higgs_mass_loss: 120.0681; lambda_weight: -6.2212; loss: 133.6679; mae1_loss: 67.5991; mae2_loss: 66.5789; nu_mass_loss: 25.3795; val_dinu_pt_loss: 62.9038; val_fused_output_loss: 66.1915; val_higgs_mass_loss: 119.7253; val_lambda_weight: -6.1058; val_loss: 132.9289; val_mae1_loss: 67.2833; val_mae2_loss: 66.1915; val_nu_mass_loss: 26.1239
# Epoch 19; dinu_pt_loss: 63.0592; fused_output_loss: 66.4723; higgs_mass_loss: 119.7139; lambda_weight: -6.1959; loss: 133.4937; mae1_loss: 67.5705; mae2_loss: 66.4723; nu_mass_loss: 26.2298; val_dinu_pt_loss: 62.7265; val_fused_output_loss: 66.0702; val_higgs_mass_loss: 119.3144; val_lambda_weight: -6.0409; val_loss: 132.7301; val_mae1_loss: 67.2498; val_mae2_loss: 66.0702; val_nu_mass_loss: 27.0748
# Epoch 20; dinu_pt_loss: 62.8733; fused_output_loss: 66.3596; higgs_mass_loss: 119.3346; lambda_weight: -6.0070; loss: 133.3061; mae1_loss: 67.5333; mae2_loss: 66.3596; nu_mass_loss: 27.0446; val_dinu_pt_loss: 62.5336; val_fused_output_loss: 65.9445; val_higgs_mass_loss: 118.8731; val_lambda_weight: -5.7230; val_loss: 132.5186; val_mae1_loss: 67.2038; val_mae2_loss: 65.9445; val_nu_mass_loss: 28.0067
# Epoch 21; dinu_pt_loss: 62.6883; fused_output_loss: 66.2452; higgs_mass_loss: 118.9408; lambda_weight: -5.5451; loss: 133.1087; mae1_loss: 67.4814; mae2_loss: 66.2452; nu_mass_loss: 27.7548; val_dinu_pt_loss: 62.3527; val_fused_output_loss: 65.8251; val_higgs_mass_loss: 118.4452; val_lambda_weight: -5.0847; val_loss: 132.3104; val_mae1_loss: 67.1452; val_mae2_loss: 65.8251; val_nu_mass_loss: 28.7579
# Epoch 22; dinu_pt_loss: 62.5074; fused_output_loss: 66.1283; higgs_mass_loss: 118.5329; lambda_weight: -4.6868; loss: 132.9015; mae1_loss: 67.4178; mae2_loss: 66.1283; nu_mass_loss: 28.3457; val_dinu_pt_loss: 62.1928; val_fused_output_loss: 65.7046; val_higgs_mass_loss: 118.0111; val_lambda_weight: -4.0982; val_loss: 132.0980; val_mae1_loss: 67.0825; val_mae2_loss: 65.7046; val_nu_mass_loss: 29.3620
# Epoch 23; dinu_pt_loss: 62.3426; fused_output_loss: 66.0108; higgs_mass_loss: 118.1180; lambda_weight: -3.6338; loss: 132.6938; mae1_loss: 67.3551; mae2_loss: 66.0108; nu_mass_loss: 28.8174; val_dinu_pt_loss: 62.0324; val_fused_output_loss: 65.5846; val_higgs_mass_loss: 117.5879; val_lambda_weight: -3.0627; val_loss: 131.8893; val_mae1_loss: 67.0247; val_mae2_loss: 65.5846; val_nu_mass_loss: 29.8119
# Epoch 24; dinu_pt_loss: 62.1788; fused_output_loss: 65.8910; higgs_mass_loss: 117.7068; lambda_weight: -2.5740; loss: 132.4846; mae1_loss: 67.2956; mae2_loss: 65.8910; nu_mass_loss: 29.2134; val_dinu_pt_loss: 61.8813; val_fused_output_loss: 65.4688; val_higgs_mass_loss: 117.1899; val_lambda_weight: -2.0318; val_loss: 131.6870; val_mae1_loss: 66.9676; val_mae2_loss: 65.4688; val_nu_mass_loss: 30.1893
# Epoch 25; dinu_pt_loss: 62.0163; fused_output_loss: 65.7693; higgs_mass_loss: 117.2945; lambda_weight: -1.5007; loss: 132.2718; mae1_loss: 67.2357; mae2_loss: 65.7693; nu_mass_loss: 29.5752; val_dinu_pt_loss: 61.7221; val_fused_output_loss: 65.3441; val_higgs_mass_loss: 116.7692; val_lambda_weight: -0.9528; val_loss: 131.4696; val_mae1_loss: 66.9070; val_mae2_loss: 65.3441; val_nu_mass_loss: 30.5722
# Epoch 26; dinu_pt_loss: 61.8702; fused_output_loss: 65.6467; higgs_mass_loss: 116.8883; lambda_weight: -0.3665; loss: 132.0559; mae1_loss: 67.1715; mae2_loss: 65.6467; nu_mass_loss: 29.8861; val_dinu_pt_loss: 61.5772; val_fused_output_loss: 65.2250; val_higgs_mass_loss: 116.3748; val_lambda_weight: 0.2022; val_loss: 131.2599; val_mae1_loss: 66.8447; val_mae2_loss: 65.2250; val_nu_mass_loss: 30.8821
# Epoch 27; dinu_pt_loss: 61.7201; fused_output_loss: 65.5215; higgs_mass_loss: 116.4791; lambda_weight: 0.8459; loss: 131.8335; mae1_loss: 67.1029; mae2_loss: 65.5215; nu_mass_loss: 30.1889; val_dinu_pt_loss: 61.4338; val_fused_output_loss: 65.1040; val_higgs_mass_loss: 115.9789; val_lambda_weight: 1.4412; val_loss: 131.0404; val_mae1_loss: 66.7688; val_mae2_loss: 65.1040; val_nu_mass_loss: 31.1609
# Epoch 28; dinu_pt_loss: 61.5729; fused_output_loss: 65.3944; higgs_mass_loss: 116.0729; lambda_weight: 2.1462; loss: 131.6054; mae1_loss: 67.0275; mae2_loss: 65.3944; nu_mass_loss: 30.4695; val_dinu_pt_loss: 61.2858; val_fused_output_loss: 64.9740; val_higgs_mass_loss: 115.5612; val_lambda_weight: 2.8168; val_loss: 130.8053; val_mae1_loss: 66.6884; val_mae2_loss: 64.9740; val_nu_mass_loss: 31.4579
# Epoch 29; dinu_pt_loss: 61.4213; fused_output_loss: 65.2640; higgs_mass_loss: 115.6629; lambda_weight: 3.5366; loss: 131.3701; mae1_loss: 66.9482; mae2_loss: 65.2640; nu_mass_loss: 30.7646; val_dinu_pt_loss: 61.1280; val_fused_output_loss: 64.8478; val_higgs_mass_loss: 115.1803; val_lambda_weight: 4.1852; val_loss: 130.5748; val_mae1_loss: 66.6062; val_mae2_loss: 64.8478; val_nu_mass_loss: 31.7167
# Epoch 30; dinu_pt_loss: 61.2548; fused_output_loss: 65.1311; higgs_mass_loss: 115.2574; lambda_weight: 4.9134; loss: 131.1306; mae1_loss: 66.8680; mae2_loss: 65.1311; nu_mass_loss: 31.0817; val_dinu_pt_loss: 60.9477; val_fused_output_loss: 64.7153; val_higgs_mass_loss: 114.7918; val_lambda_weight: 5.5446; val_loss: 130.3340; val_mae1_loss: 66.5222; val_mae2_loss: 64.7153; val_nu_mass_loss: 32.0007
# Epoch 31; dinu_pt_loss: 61.0731; fused_output_loss: 64.9967; higgs_mass_loss: 114.8643; lambda_weight: 6.2188; loss: 130.8887; mae1_loss: 66.7873; mae2_loss: 64.9967; nu_mass_loss: 31.4209; val_dinu_pt_loss: 60.7616; val_fused_output_loss: 64.5852; val_higgs_mass_loss: 114.4342; val_lambda_weight: 6.7884; val_loss: 130.1000; val_mae1_loss: 66.4444; val_mae2_loss: 64.5852; val_nu_mass_loss: 32.2690
# Epoch 32; dinu_pt_loss: 60.8921; fused_output_loss: 64.8610; higgs_mass_loss: 114.4758; lambda_weight: 7.4404; loss: 130.6445; mae1_loss: 66.7059; mae2_loss: 64.8610; nu_mass_loss: 31.7706; val_dinu_pt_loss: 60.5700; val_fused_output_loss: 64.4470; val_higgs_mass_loss: 114.0632; val_lambda_weight: 7.9643; val_loss: 129.8517; val_mae1_loss: 66.3624; val_mae2_loss: 64.4470; val_nu_mass_loss: 32.5596
# Epoch 33; dinu_pt_loss: 60.7029; fused_output_loss: 64.7235; higgs_mass_loss: 114.0936; lambda_weight: 8.5755; loss: 130.3963; mae1_loss: 66.6223; mae2_loss: 64.7235; nu_mass_loss: 32.1123; val_dinu_pt_loss: 60.3748; val_fused_output_loss: 64.3088; val_higgs_mass_loss: 113.6955; val_lambda_weight: 9.0249; val_loss: 129.6020; val_mae1_loss: 66.2776; val_mae2_loss: 64.3088; val_nu_mass_loss: 32.8464
# Epoch 34; dinu_pt_loss: 60.5009; fused_output_loss: 64.5843; higgs_mass_loss: 113.7109; lambda_weight: 9.5798; loss: 130.1451; mae1_loss: 66.5371; mae2_loss: 64.5843; nu_mass_loss: 32.4462; val_dinu_pt_loss: 60.1703; val_fused_output_loss: 64.1675; val_higgs_mass_loss: 113.3118; val_lambda_weight: 9.9824; val_loss: 129.3456; val_mae1_loss: 66.1886; val_mae2_loss: 64.1675; val_nu_mass_loss: 33.1420
# Epoch 35; dinu_pt_loss: 60.2941; fused_output_loss: 64.4427; higgs_mass_loss: 113.3273; lambda_weight: 10.5143; loss: 129.8882; mae1_loss: 66.4481; mae2_loss: 64.4427; nu_mass_loss: 32.7785; val_dinu_pt_loss: 59.9453; val_fused_output_loss: 64.0247; val_higgs_mass_loss: 112.9339; val_lambda_weight: 10.8767; val_loss: 129.0868; val_mae1_loss: 66.0993; val_mae2_loss: 64.0247; val_nu_mass_loss: 33.4530
# Epoch 36; dinu_pt_loss: 60.0782; fused_output_loss: 64.2998; higgs_mass_loss: 112.9428; lambda_weight: 11.3762; loss: 129.6286; mae1_loss: 66.3578; mae2_loss: 64.2998; nu_mass_loss: 33.1066; val_dinu_pt_loss: 59.7250; val_fused_output_loss: 63.8759; val_higgs_mass_loss: 112.5356; val_lambda_weight: 11.7029; val_loss: 128.8162; val_mae1_loss: 66.0047; val_mae2_loss: 63.8759; val_nu_mass_loss: 33.7519
# Epoch 37; dinu_pt_loss: 59.8498; fused_output_loss: 64.1531; higgs_mass_loss: 112.5529; lambda_weight: 12.1543; loss: 129.3625; mae1_loss: 66.2659; mae2_loss: 64.1531; nu_mass_loss: 33.4305; val_dinu_pt_loss: 59.4966; val_fused_output_loss: 63.7290; val_higgs_mass_loss: 112.1521; val_lambda_weight: 12.4710; val_loss: 128.5497; val_mae1_loss: 65.9123; val_mae2_loss: 63.7290; val_nu_mass_loss: 34.0490
# Epoch 38; dinu_pt_loss: 59.6242; fused_output_loss: 64.0055; higgs_mass_loss: 112.1663; lambda_weight: 12.8848; loss: 129.0952; mae1_loss: 66.1740; mae2_loss: 64.0055; nu_mass_loss: 33.7596; val_dinu_pt_loss: 59.2707; val_fused_output_loss: 63.5800; val_higgs_mass_loss: 111.7703; val_lambda_weight: 13.1515; val_loss: 128.2779; val_mae1_loss: 65.8158; val_mae2_loss: 63.5800; val_nu_mass_loss: 34.3459
# Epoch 39; dinu_pt_loss: 59.3857; fused_output_loss: 63.8547; higgs_mass_loss: 111.7781; lambda_weight: 13.5489; loss: 128.8226; mae1_loss: 66.0810; mae2_loss: 63.8547; nu_mass_loss: 34.0727; val_dinu_pt_loss: 59.0322; val_fused_output_loss: 63.4289; val_higgs_mass_loss: 111.3905; val_lambda_weight: 13.8023; val_loss: 128.0049; val_mae1_loss: 65.7228; val_mae2_loss: 63.4289; val_nu_mass_loss: 34.6265
# Epoch 40; dinu_pt_loss: 59.1424; fused_output_loss: 63.7014; higgs_mass_loss: 111.3882; lambda_weight: 14.1827; loss: 128.5461; mae1_loss: 65.9879; mae2_loss: 63.7014; nu_mass_loss: 34.3841; val_dinu_pt_loss: 58.7915; val_fused_output_loss: 63.2727; val_higgs_mass_loss: 110.9932; val_lambda_weight: 14.4415; val_loss: 127.7224; val_mae1_loss: 65.6268; val_mae2_loss: 63.2727; val_nu_mass_loss: 34.9172
# Epoch 41; dinu_pt_loss: 58.8967; fused_output_loss: 63.5458; higgs_mass_loss: 111.0009; lambda_weight: 14.7903; loss: 128.2655; mae1_loss: 65.8936; mae2_loss: 63.5458; nu_mass_loss: 34.6935; val_dinu_pt_loss: 58.5514; val_fused_output_loss: 63.1193; val_higgs_mass_loss: 110.6226; val_lambda_weight: 15.0225; val_loss: 127.4452; val_mae1_loss: 65.5326; val_mae2_loss: 63.1193; val_nu_mass_loss: 35.1930
# Epoch 42; dinu_pt_loss: 58.6540; fused_output_loss: 63.3881; higgs_mass_loss: 110.6173; lambda_weight: 15.3527; loss: 127.9815; mae1_loss: 65.7987; mae2_loss: 63.3881; nu_mass_loss: 35.0002; val_dinu_pt_loss: 58.3139; val_fused_output_loss: 62.9609; val_higgs_mass_loss: 110.2430; val_lambda_weight: 15.5544; val_loss: 127.1602; val_mae1_loss: 65.4377; val_mae2_loss: 62.9609; val_nu_mass_loss: 35.4786
# Epoch 43; dinu_pt_loss: 58.4114; fused_output_loss: 63.2276; higgs_mass_loss: 110.2333; lambda_weight: 15.8931; loss: 127.6931; mae1_loss: 65.7031; mae2_loss: 63.2276; nu_mass_loss: 35.2951; val_dinu_pt_loss: 58.0696; val_fused_output_loss: 62.8036; val_higgs_mass_loss: 109.8712; val_lambda_weight: 16.1282; val_loss: 126.8753; val_mae1_loss: 65.3396; val_mae2_loss: 62.8036; val_nu_mass_loss: 35.7264
# Epoch 44; dinu_pt_loss: 58.1768; fused_output_loss: 63.0642; higgs_mass_loss: 109.8470; lambda_weight: 16.4497; loss: 127.3993; mae1_loss: 65.6057; mae2_loss: 63.0642; nu_mass_loss: 35.5805; val_dinu_pt_loss: 57.8407; val_fused_output_loss: 62.6356; val_higgs_mass_loss: 109.4874; val_lambda_weight: 16.6786; val_loss: 126.5753; val_mae1_loss: 65.2438; val_mae2_loss: 62.6356; val_nu_mass_loss: 35.9984
# Epoch 45; dinu_pt_loss: 57.9333; fused_output_loss: 62.8986; higgs_mass_loss: 109.4662; lambda_weight: 16.9985; loss: 127.1013; mae1_loss: 65.5072; mae2_loss: 62.8986; nu_mass_loss: 35.8648; val_dinu_pt_loss: 57.5986; val_fused_output_loss: 62.4706; val_higgs_mass_loss: 109.1167; val_lambda_weight: 17.2198; val_loss: 126.2788; val_mae1_loss: 65.1456; val_mae2_loss: 62.4706; val_nu_mass_loss: 36.2463
# Epoch 46; dinu_pt_loss: 57.6918; fused_output_loss: 62.7308; higgs_mass_loss: 109.0818; lambda_weight: 17.5378; loss: 126.7997; mae1_loss: 65.4070; mae2_loss: 62.7308; nu_mass_loss: 36.1509; val_dinu_pt_loss: 57.3668; val_fused_output_loss: 62.3105; val_higgs_mass_loss: 108.7631; val_lambda_weight: 17.7535; val_loss: 125.9879; val_mae1_loss: 65.0443; val_mae2_loss: 62.3105; val_nu_mass_loss: 36.4879
# Epoch 47; dinu_pt_loss: 57.4605; fused_output_loss: 62.5604; higgs_mass_loss: 108.7010; lambda_weight: 18.0777; loss: 126.4930; mae1_loss: 65.3046; mae2_loss: 62.5604; nu_mass_loss: 36.4275; val_dinu_pt_loss: 57.1483; val_fused_output_loss: 62.1349; val_higgs_mass_loss: 108.3614; val_lambda_weight: 18.3039; val_loss: 125.6729; val_mae1_loss: 64.9411; val_mae2_loss: 62.1349; val_nu_mass_loss: 36.7481
# Epoch 48; dinu_pt_loss: 57.2252; fused_output_loss: 62.3868; higgs_mass_loss: 108.3140; lambda_weight: 18.6192; loss: 126.1802; mae1_loss: 65.2000; mae2_loss: 62.3868; nu_mass_loss: 36.7101; val_dinu_pt_loss: 56.8842; val_fused_output_loss: 61.9598; val_higgs_mass_loss: 107.9862; val_lambda_weight: 18.8471; val_loss: 125.3589; val_mae1_loss: 64.8385; val_mae2_loss: 61.9598; val_nu_mass_loss: 37.0063
# Epoch 49; dinu_pt_loss: 56.9830; fused_output_loss: 62.2123; higgs_mass_loss: 107.9308; lambda_weight: 19.1679; loss: 125.8662; mae1_loss: 65.0954; mae2_loss: 62.2123; nu_mass_loss: 36.9804; val_dinu_pt_loss: 56.6585; val_fused_output_loss: 61.7888; val_higgs_mass_loss: 107.6189; val_lambda_weight: 19.3810; val_loss: 125.0497; val_mae1_loss: 64.7328; val_mae2_loss: 61.7888; val_nu_mass_loss: 37.2394
# Epoch 50; dinu_pt_loss: 56.7462; fused_output_loss: 62.0342; higgs_mass_loss: 107.5539; lambda_weight: 19.6994; loss: 125.5451; mae1_loss: 64.9880; mae2_loss: 62.0342; nu_mass_loss: 37.2533; val_dinu_pt_loss: 56.4181; val_fused_output_loss: 61.6161; val_higgs_mass_loss: 107.2669; val_lambda_weight: 19.9209; val_loss: 124.7375; val_mae1_loss: 64.6267; val_mae2_loss: 61.6161; val_nu_mass_loss: 37.4762
# Epoch 51; dinu_pt_loss: 56.5113; fused_output_loss: 61.8540; higgs_mass_loss: 107.1754; lambda_weight: 20.2502; loss: 125.2204; mae1_loss: 64.8786; mae2_loss: 61.8540; nu_mass_loss: 37.5361; val_dinu_pt_loss: 56.1787; val_fused_output_loss: 61.4346; val_higgs_mass_loss: 106.8914; val_lambda_weight: 20.4756; val_loss: 124.4095; val_mae1_loss: 64.5152; val_mae2_loss: 61.4346; val_nu_mass_loss: 37.7347
# Epoch 52; dinu_pt_loss: 56.2735; fused_output_loss: 61.6716; higgs_mass_loss: 106.7937; lambda_weight: 20.7853; loss: 124.8912; mae1_loss: 64.7675; mae2_loss: 61.6716; nu_mass_loss: 37.8182; val_dinu_pt_loss: 55.9330; val_fused_output_loss: 61.2527; val_higgs_mass_loss: 106.5196; val_lambda_weight: 21.0042; val_loss: 124.0811; val_mae1_loss: 64.4043; val_mae2_loss: 61.2527; val_nu_mass_loss: 37.9967
# Epoch 53; dinu_pt_loss: 56.0428; fused_output_loss: 61.4869; higgs_mass_loss: 106.4123; lambda_weight: 21.3255; loss: 124.5573; mae1_loss: 64.6544; mae2_loss: 61.4869; nu_mass_loss: 38.0969; val_dinu_pt_loss: 55.6923; val_fused_output_loss: 61.0666; val_higgs_mass_loss: 106.1410; val_lambda_weight: 21.5531; val_loss: 123.7449; val_mae1_loss: 64.2900; val_mae2_loss: 61.0666; val_nu_mass_loss: 38.2569
# Epoch 54; dinu_pt_loss: 55.7997; fused_output_loss: 61.2997; higgs_mass_loss: 106.0404; lambda_weight: 21.8646; loss: 124.2191; mae1_loss: 64.5394; mae2_loss: 61.2997; nu_mass_loss: 38.3710; val_dinu_pt_loss: 55.4668; val_fused_output_loss: 60.8824; val_higgs_mass_loss: 105.7917; val_lambda_weight: 22.0921; val_loss: 123.4094; val_mae1_loss: 64.1716; val_mae2_loss: 60.8824; val_nu_mass_loss: 38.5012
# Epoch 55; dinu_pt_loss: 55.5684; fused_output_loss: 61.1104; higgs_mass_loss: 105.6620; lambda_weight: 22.4059; loss: 123.8771; mae1_loss: 64.4230; mae2_loss: 61.1104; nu_mass_loss: 38.6521; val_dinu_pt_loss: 55.2137; val_fused_output_loss: 60.6948; val_higgs_mass_loss: 105.4251; val_lambda_weight: 22.6502; val_loss: 123.0687; val_mae1_loss: 64.0531; val_mae2_loss: 60.6948; val_nu_mass_loss: 38.7530
# Epoch 56; dinu_pt_loss: 55.3271; fused_output_loss: 60.9194; higgs_mass_loss: 105.2886; lambda_weight: 22.9505; loss: 123.5316; mae1_loss: 64.3048; mae2_loss: 60.9194; nu_mass_loss: 38.9290; val_dinu_pt_loss: 54.9732; val_fused_output_loss: 60.4978; val_higgs_mass_loss: 105.0370; val_lambda_weight: 23.1876; val_loss: 122.7151; val_mae1_loss: 63.9367; val_mae2_loss: 60.4978; val_nu_mass_loss: 39.0183
# Epoch 57; dinu_pt_loss: 55.0848; fused_output_loss: 60.7258; higgs_mass_loss: 104.9155; lambda_weight: 23.4953; loss: 123.1809; mae1_loss: 64.1846; mae2_loss: 60.7258; nu_mass_loss: 39.2081; val_dinu_pt_loss: 54.7245; val_fused_output_loss: 60.3138; val_higgs_mass_loss: 104.7051; val_lambda_weight: 23.7275; val_loss: 122.3784; val_mae1_loss: 63.8153; val_mae2_loss: 60.3138; val_nu_mass_loss: 39.2621
# Epoch 58; dinu_pt_loss: 54.8417; fused_output_loss: 60.5299; higgs_mass_loss: 104.5442; lambda_weight: 24.0372; loss: 122.8263; mae1_loss: 64.0629; mae2_loss: 60.5299; nu_mass_loss: 39.4882; val_dinu_pt_loss: 54.4958; val_fused_output_loss: 60.1152; val_higgs_mass_loss: 104.3189; val_lambda_weight: 24.2677; val_loss: 122.0183; val_mae1_loss: 63.6911; val_mae2_loss: 60.1152; val_nu_mass_loss: 39.5099
# Epoch 59; dinu_pt_loss: 54.6035; fused_output_loss: 60.3316; higgs_mass_loss: 104.1659; lambda_weight: 24.5868; loss: 122.4672; mae1_loss: 63.9396; mae2_loss: 60.3316; nu_mass_loss: 39.7708; val_dinu_pt_loss: 54.2511; val_fused_output_loss: 59.9126; val_higgs_mass_loss: 103.9342; val_lambda_weight: 24.8350; val_loss: 121.6530; val_mae1_loss: 63.5681; val_mae2_loss: 59.9126; val_nu_mass_loss: 39.8002
# Epoch 60; dinu_pt_loss: 54.3629; fused_output_loss: 60.1316; higgs_mass_loss: 103.7984; lambda_weight: 25.1525; loss: 122.1049; mae1_loss: 63.8152; mae2_loss: 60.1316; nu_mass_loss: 40.0514; val_dinu_pt_loss: 54.0059; val_fused_output_loss: 59.7204; val_higgs_mass_loss: 103.5998; val_lambda_weight: 25.3861; val_loss: 121.3024; val_mae1_loss: 63.4437; val_mae2_loss: 59.7204; val_nu_mass_loss: 40.0319
# Epoch 61; dinu_pt_loss: 54.1332; fused_output_loss: 59.9295; higgs_mass_loss: 103.4211; lambda_weight: 25.7082; loss: 121.7387; mae1_loss: 63.6889; mae2_loss: 59.9295; nu_mass_loss: 40.3317; val_dinu_pt_loss: 53.7920; val_fused_output_loss: 59.5117; val_higgs_mass_loss: 103.2180; val_lambda_weight: 25.9411; val_loss: 120.9254; val_mae1_loss: 63.3158; val_mae2_loss: 59.5117; val_nu_mass_loss: 40.2887
# Epoch 62; dinu_pt_loss: 53.8906; fused_output_loss: 59.7246; higgs_mass_loss: 103.0536; lambda_weight: 26.2647; loss: 121.3675; mae1_loss: 63.5611; mae2_loss: 59.7246; nu_mass_loss: 40.6058; val_dinu_pt_loss: 53.5234; val_fused_output_loss: 59.3088; val_higgs_mass_loss: 102.8519; val_lambda_weight: 26.4956; val_loss: 120.5567; val_mae1_loss: 63.1871; val_mae2_loss: 59.3088; val_nu_mass_loss: 40.5540
# Epoch 63; dinu_pt_loss: 53.6504; fused_output_loss: 59.5173; higgs_mass_loss: 102.6860; lambda_weight: 26.8264; loss: 120.9917; mae1_loss: 63.4316; mae2_loss: 59.5173; nu_mass_loss: 40.8914; val_dinu_pt_loss: 53.2939; val_fused_output_loss: 59.1030; val_higgs_mass_loss: 102.4965; val_lambda_weight: 27.0693; val_loss: 120.1811; val_mae1_loss: 63.0535; val_mae2_loss: 59.1030; val_nu_mass_loss: 40.8085
# Epoch 64; dinu_pt_loss: 53.4165; fused_output_loss: 59.3095; higgs_mass_loss: 102.3235; lambda_weight: 27.3951; loss: 120.6147; mae1_loss: 63.3007; mae2_loss: 59.3095; nu_mass_loss: 41.1591; val_dinu_pt_loss: 53.0464; val_fused_output_loss: 58.8900; val_higgs_mass_loss: 102.1192; val_lambda_weight: 27.6443; val_loss: 119.7967; val_mae1_loss: 62.9233; val_mae2_loss: 58.8900; val_nu_mass_loss: 41.0788
# Epoch 65; dinu_pt_loss: 53.1735; fused_output_loss: 59.0978; higgs_mass_loss: 101.9523; lambda_weight: 27.9715; loss: 120.2314; mae1_loss: 63.1691; mae2_loss: 59.0978; nu_mass_loss: 41.4533; val_dinu_pt_loss: 52.8132; val_fused_output_loss: 58.6787; val_higgs_mass_loss: 101.7511; val_lambda_weight: 28.2031; val_loss: 119.4139; val_mae1_loss: 62.7917; val_mae2_loss: 58.6787; val_nu_mass_loss: 41.3556
# Epoch 66; dinu_pt_loss: 52.9329; fused_output_loss: 58.8849; higgs_mass_loss: 101.5786; lambda_weight: 28.5407; loss: 119.8454; mae1_loss: 63.0356; mae2_loss: 58.8849; nu_mass_loss: 41.7339; val_dinu_pt_loss: 52.5749; val_fused_output_loss: 58.4642; val_higgs_mass_loss: 101.3729; val_lambda_weight: 28.7744; val_loss: 119.0219; val_mae1_loss: 62.6512; val_mae2_loss: 58.4642; val_nu_mass_loss: 41.6175
# Epoch 67; dinu_pt_loss: 52.6904; fused_output_loss: 58.6695; higgs_mass_loss: 101.2168; lambda_weight: 29.1075; loss: 119.4543; mae1_loss: 62.9002; mae2_loss: 58.6695; nu_mass_loss: 42.0136; val_dinu_pt_loss: 52.3156; val_fused_output_loss: 58.2469; val_higgs_mass_loss: 101.0186; val_lambda_weight: 29.3469; val_loss: 118.6300; val_mae1_loss: 62.5193; val_mae2_loss: 58.2469; val_nu_mass_loss: 41.8738
# Epoch 68; dinu_pt_loss: 52.4415; fused_output_loss: 58.4522; higgs_mass_loss: 100.8563; lambda_weight: 29.6861; loss: 119.0602; mae1_loss: 62.7641; mae2_loss: 58.4522; nu_mass_loss: 42.3007; val_dinu_pt_loss: 52.0650; val_fused_output_loss: 58.0332; val_higgs_mass_loss: 100.6581; val_lambda_weight: 29.9185; val_loss: 118.2411; val_mae1_loss: 62.3825; val_mae2_loss: 58.0332; val_nu_mass_loss: 42.1601
# Epoch 69; dinu_pt_loss: 52.1987; fused_output_loss: 58.2341; higgs_mass_loss: 100.4920; lambda_weight: 30.2561; loss: 118.6643; mae1_loss: 62.6262; mae2_loss: 58.2341; nu_mass_loss: 42.5928; val_dinu_pt_loss: 51.8449; val_fused_output_loss: 57.8153; val_higgs_mass_loss: 100.3104; val_lambda_weight: 30.4986; val_loss: 117.8438; val_mae1_loss: 62.2415; val_mae2_loss: 57.8153; val_nu_mass_loss: 42.4047
# Epoch 70; dinu_pt_loss: 51.9528; fused_output_loss: 58.0125; higgs_mass_loss: 100.1278; lambda_weight: 30.8312; loss: 118.2625; mae1_loss: 62.4873; mae2_loss: 58.0125; nu_mass_loss: 42.8709; val_dinu_pt_loss: 51.5832; val_fused_output_loss: 57.5867; val_higgs_mass_loss: 99.9311; val_lambda_weight: 31.0713; val_loss: 117.4312; val_mae1_loss: 62.1023; val_mae2_loss: 57.5867; val_nu_mass_loss: 42.6805
# Epoch 71; dinu_pt_loss: 51.6976; fused_output_loss: 57.7895; higgs_mass_loss: 99.7645; lambda_weight: 31.4036; loss: 117.8575; mae1_loss: 62.3464; mae2_loss: 57.7895; nu_mass_loss: 43.1561; val_dinu_pt_loss: 51.3117; val_fused_output_loss: 57.3714; val_higgs_mass_loss: 99.6115; val_lambda_weight: 31.6392; val_loss: 117.0384; val_mae1_loss: 61.9627; val_mae2_loss: 57.3714; val_nu_mass_loss: 42.9424
# Epoch 72; dinu_pt_loss: 51.4453; fused_output_loss: 57.5644; higgs_mass_loss: 99.4007; lambda_weight: 31.9783; loss: 117.4491; mae1_loss: 62.2052; mae2_loss: 57.5644; nu_mass_loss: 43.4467; val_dinu_pt_loss: 51.0836; val_fused_output_loss: 57.1361; val_higgs_mass_loss: 99.2118; val_lambda_weight: 32.2122; val_loss: 116.6127; val_mae1_loss: 61.8172; val_mae2_loss: 57.1361; val_nu_mass_loss: 43.2297
# Epoch 73; dinu_pt_loss: 51.1877; fused_output_loss: 57.3379; higgs_mass_loss: 99.0414; lambda_weight: 32.5484; loss: 117.0372; mae1_loss: 62.0612; mae2_loss: 57.3379; nu_mass_loss: 43.7287; val_dinu_pt_loss: 50.8180; val_fused_output_loss: 56.9147; val_higgs_mass_loss: 98.8515; val_lambda_weight: 32.7729; val_loss: 116.2096; val_mae1_loss: 61.6750; val_mae2_loss: 56.9147; val_nu_mass_loss: 43.5141
# Epoch 74; dinu_pt_loss: 50.9234; fused_output_loss: 57.1089; higgs_mass_loss: 98.6828; lambda_weight: 33.1197; loss: 116.6217; mae1_loss: 61.9164; mae2_loss: 57.1089; nu_mass_loss: 44.0165; val_dinu_pt_loss: 50.5503; val_fused_output_loss: 56.6773; val_higgs_mass_loss: 98.4755; val_lambda_weight: 33.3464; val_loss: 115.7805; val_mae1_loss: 61.5292; val_mae2_loss: 56.6773; val_nu_mass_loss: 43.7770
# Epoch 75; dinu_pt_loss: 50.6638; fused_output_loss: 56.8781; higgs_mass_loss: 98.3185; lambda_weight: 33.6789; loss: 116.2027; mae1_loss: 61.7712; mae2_loss: 56.8781; nu_mass_loss: 44.3077; val_dinu_pt_loss: 50.2952; val_fused_output_loss: 56.4489; val_higgs_mass_loss: 98.1241; val_lambda_weight: 33.9014; val_loss: 115.3636; val_mae1_loss: 61.3806; val_mae2_loss: 56.4489; val_nu_mass_loss: 44.0498
# Epoch 76; dinu_pt_loss: 50.4026; fused_output_loss: 56.6453; higgs_mass_loss: 97.9550; lambda_weight: 34.2385; loss: 115.7800; mae1_loss: 61.6240; mae2_loss: 56.6453; nu_mass_loss: 44.5876; val_dinu_pt_loss: 50.0280; val_fused_output_loss: 56.2166; val_higgs_mass_loss: 97.7557; val_lambda_weight: 34.4732; val_loss: 114.9417; val_mae1_loss: 61.2335; val_mae2_loss: 56.2166; val_nu_mass_loss: 44.3308
# Epoch 77; dinu_pt_loss: 50.1302; fused_output_loss: 56.4115; higgs_mass_loss: 97.5941; lambda_weight: 34.7939; loss: 115.3559; mae1_loss: 61.4769; mae2_loss: 56.4115; nu_mass_loss: 44.8669; val_dinu_pt_loss: 49.7639; val_fused_output_loss: 55.9801; val_higgs_mass_loss: 97.3938; val_lambda_weight: 35.0112; val_loss: 114.5146; val_mae1_loss: 61.0889; val_mae2_loss: 55.9801; val_nu_mass_loss: 44.5903
# Epoch 78; dinu_pt_loss: 49.8568; fused_output_loss: 56.1745; higgs_mass_loss: 97.2308; lambda_weight: 35.3414; loss: 114.9257; mae1_loss: 61.3278; mae2_loss: 56.1745; nu_mass_loss: 45.1606; val_dinu_pt_loss: 49.4802; val_fused_output_loss: 55.7441; val_higgs_mass_loss: 97.0347; val_lambda_weight: 35.5547; val_loss: 114.0855; val_mae1_loss: 60.9388; val_mae2_loss: 55.7441; val_nu_mass_loss: 44.8897
# Epoch 79; dinu_pt_loss: 49.5876; fused_output_loss: 55.9370; higgs_mass_loss: 96.8651; lambda_weight: 35.8892; loss: 114.4942; mae1_loss: 61.1777; mae2_loss: 55.9370; nu_mass_loss: 45.4385; val_dinu_pt_loss: 49.2183; val_fused_output_loss: 55.5075; val_higgs_mass_loss: 96.6954; val_lambda_weight: 36.1141; val_loss: 113.6550; val_mae1_loss: 60.7872; val_mae2_loss: 55.5075; val_nu_mass_loss: 45.0911
# Epoch 80; dinu_pt_loss: 49.3080; fused_output_loss: 55.6970; higgs_mass_loss: 96.5010; lambda_weight: 36.4302; loss: 114.0592; mae1_loss: 61.0272; mae2_loss: 55.6970; nu_mass_loss: 45.7094; val_dinu_pt_loss: 48.9238; val_fused_output_loss: 55.2716; val_higgs_mass_loss: 96.3489; val_lambda_weight: 36.6144; val_loss: 113.2287; val_mae1_loss: 60.6425; val_mae2_loss: 55.2716; val_nu_mass_loss: 45.3754
# Epoch 81; dinu_pt_loss: 49.0189; fused_output_loss: 55.4562; higgs_mass_loss: 96.1316; lambda_weight: 36.9464; loss: 113.6217; mae1_loss: 60.8751; mae2_loss: 55.4562; nu_mass_loss: 45.9936; val_dinu_pt_loss: 48.6200; val_fused_output_loss: 55.0308; val_higgs_mass_loss: 95.9885; val_lambda_weight: 37.1591; val_loss: 112.7893; val_mae1_loss: 60.4862; val_mae2_loss: 55.0308; val_nu_mass_loss: 45.6205
# Epoch 82; dinu_pt_loss: 48.7411; fused_output_loss: 55.2138; higgs_mass_loss: 95.7670; lambda_weight: 37.4668; loss: 113.1823; mae1_loss: 60.7232; mae2_loss: 55.2138; nu_mass_loss: 46.2653; val_dinu_pt_loss: 48.3532; val_fused_output_loss: 54.7867; val_higgs_mass_loss: 95.5938; val_lambda_weight: 37.6561; val_loss: 112.3482; val_mae1_loss: 60.3364; val_mae2_loss: 54.7867; val_nu_mass_loss: 45.9160
# Epoch 83; dinu_pt_loss: 48.4351; fused_output_loss: 54.9690; higgs_mass_loss: 95.4052; lambda_weight: 37.9736; loss: 112.7386; mae1_loss: 60.5701; mae2_loss: 54.9690; nu_mass_loss: 46.5498; val_dinu_pt_loss: 48.0738; val_fused_output_loss: 54.5491; val_higgs_mass_loss: 95.2578; val_lambda_weight: 38.1538; val_loss: 111.9166; val_mae1_loss: 60.1861; val_mae2_loss: 54.5491; val_nu_mass_loss: 46.1736
# Epoch 84; dinu_pt_loss: 48.1544; fused_output_loss: 54.7223; higgs_mass_loss: 95.0243; lambda_weight: 38.4734; loss: 112.2913; mae1_loss: 60.4158; mae2_loss: 54.7223; nu_mass_loss: 46.8219; val_dinu_pt_loss: 47.7802; val_fused_output_loss: 54.2871; val_higgs_mass_loss: 94.8550; val_lambda_weight: 38.6584; val_loss: 111.4463; val_mae1_loss: 60.0311; val_mae2_loss: 54.2871; val_nu_mass_loss: 46.4531
# Epoch 85; dinu_pt_loss: 47.8490; fused_output_loss: 54.4740; higgs_mass_loss: 94.6493; lambda_weight: 38.9680; loss: 111.8421; mae1_loss: 60.2623; mae2_loss: 54.4740; nu_mass_loss: 47.0935; val_dinu_pt_loss: 47.4645; val_fused_output_loss: 54.0461; val_higgs_mass_loss: 94.4720; val_lambda_weight: 39.1532; val_loss: 111.0086; val_mae1_loss: 59.8789; val_mae2_loss: 54.0461; val_nu_mass_loss: 46.7283
# Epoch 86; dinu_pt_loss: 47.5462; fused_output_loss: 54.2244; higgs_mass_loss: 94.2724; lambda_weight: 39.4522; loss: 111.3903; mae1_loss: 60.1074; mae2_loss: 54.2244; nu_mass_loss: 47.3697; val_dinu_pt_loss: 47.1748; val_fused_output_loss: 53.7995; val_higgs_mass_loss: 94.1423; val_lambda_weight: 39.6071; val_loss: 110.5647; val_mae1_loss: 59.7308; val_mae2_loss: 53.7995; val_nu_mass_loss: 46.9345
# Epoch 87; dinu_pt_loss: 47.2406; fused_output_loss: 53.9734; higgs_mass_loss: 93.8910; lambda_weight: 39.9343; loss: 110.9364; mae1_loss: 59.9526; mae2_loss: 53.9734; nu_mass_loss: 47.6240; val_dinu_pt_loss: 46.8368; val_fused_output_loss: 53.5566; val_higgs_mass_loss: 93.7737; val_lambda_weight: 40.0995; val_loss: 110.1218; val_mae1_loss: 59.5738; val_mae2_loss: 53.5566; val_nu_mass_loss: 47.1891
# Epoch 88; dinu_pt_loss: 46.9283; fused_output_loss: 53.7206; higgs_mass_loss: 93.5117; lambda_weight: 40.3921; loss: 110.4797; mae1_loss: 59.7977; mae2_loss: 53.7206; nu_mass_loss: 47.8768; val_dinu_pt_loss: 46.5542; val_fused_output_loss: 53.3046; val_higgs_mass_loss: 93.4103; val_lambda_weight: 40.5238; val_loss: 109.6693; val_mae1_loss: 59.4248; val_mae2_loss: 53.3046; val_nu_mass_loss: 47.4385
# Epoch 89; dinu_pt_loss: 46.6264; fused_output_loss: 53.4669; higgs_mass_loss: 93.1192; lambda_weight: 40.8444; loss: 110.0213; mae1_loss: 59.6420; mae2_loss: 53.4669; nu_mass_loss: 48.1380; val_dinu_pt_loss: 46.2567; val_fused_output_loss: 53.0400; val_higgs_mass_loss: 92.9920; val_lambda_weight: 40.9807; val_loss: 109.1936; val_mae1_loss: 59.2670; val_mae2_loss: 53.0400; val_nu_mass_loss: 47.7043
# Epoch 90; dinu_pt_loss: 46.3073; fused_output_loss: 53.2114; higgs_mass_loss: 92.7347; lambda_weight: 41.2875; loss: 109.5602; mae1_loss: 59.4864; mae2_loss: 53.2114; nu_mass_loss: 48.3898; val_dinu_pt_loss: 45.9550; val_fused_output_loss: 52.7909; val_higgs_mass_loss: 92.6251; val_lambda_weight: 41.4175; val_loss: 108.7424; val_mae1_loss: 59.1121; val_mae2_loss: 52.7909; val_nu_mass_loss: 47.9347
# Epoch 91; dinu_pt_loss: 46.0023; fused_output_loss: 52.9549; higgs_mass_loss: 92.3440; lambda_weight: 41.7254; loss: 109.0970; mae1_loss: 59.3295; mae2_loss: 52.9549; nu_mass_loss: 48.6459; val_dinu_pt_loss: 45.6252; val_fused_output_loss: 52.5359; val_higgs_mass_loss: 92.2082; val_lambda_weight: 41.8468; val_loss: 108.2835; val_mae1_loss: 58.9592; val_mae2_loss: 52.5359; val_nu_mass_loss: 48.1934
# Epoch 92; dinu_pt_loss: 45.6919; fused_output_loss: 52.6962; higgs_mass_loss: 91.9441; lambda_weight: 42.1465; loss: 108.6308; mae1_loss: 59.1730; mae2_loss: 52.6962; nu_mass_loss: 48.8719; val_dinu_pt_loss: 45.3095; val_fused_output_loss: 52.2880; val_higgs_mass_loss: 91.8600; val_lambda_weight: 42.2447; val_loss: 107.8362; val_mae1_loss: 58.8084; val_mae2_loss: 52.2880; val_nu_mass_loss: 48.4071
# Epoch 93; dinu_pt_loss: 45.3622; fused_output_loss: 52.4374; higgs_mass_loss: 91.5334; lambda_weight: 42.5660; loss: 108.1647; mae1_loss: 59.0171; mae2_loss: 52.4374; nu_mass_loss: 49.1198; val_dinu_pt_loss: 44.9260; val_fused_output_loss: 52.0182; val_higgs_mass_loss: 91.4481; val_lambda_weight: 42.6848; val_loss: 107.3521; val_mae1_loss: 58.6495; val_mae2_loss: 52.0182; val_nu_mass_loss: 48.6459
# Epoch 94; dinu_pt_loss: 45.0474; fused_output_loss: 52.1763; higgs_mass_loss: 91.1136; lambda_weight: 42.9808; loss: 107.6947; mae1_loss: 58.8604; mae2_loss: 52.1763; nu_mass_loss: 49.3594; val_dinu_pt_loss: 44.6033; val_fused_output_loss: 51.7559; val_higgs_mass_loss: 91.0429; val_lambda_weight: 43.0844; val_loss: 106.8820; val_mae1_loss: 58.4961; val_mae2_loss: 51.7559; val_nu_mass_loss: 48.8692
# Epoch 95; dinu_pt_loss: 44.7250; fused_output_loss: 51.9143; higgs_mass_loss: 90.6881; lambda_weight: 43.3857; loss: 107.2232; mae1_loss: 58.7039; mae2_loss: 51.9143; nu_mass_loss: 49.6051; val_dinu_pt_loss: 44.2846; val_fused_output_loss: 51.5196; val_higgs_mass_loss: 90.6832; val_lambda_weight: 43.4824; val_loss: 106.4495; val_mae1_loss: 58.3402; val_mae2_loss: 51.5196; val_nu_mass_loss: 49.0765
# Epoch 96; dinu_pt_loss: 44.4064; fused_output_loss: 51.6518; higgs_mass_loss: 90.2586; lambda_weight: 43.7782; loss: 106.7518; mae1_loss: 58.5480; mae2_loss: 51.6518; nu_mass_loss: 49.8319; val_dinu_pt_loss: 43.9809; val_fused_output_loss: 51.2259; val_higgs_mass_loss: 90.1766; val_lambda_weight: 43.8719; val_loss: 105.9322; val_mae1_loss: 58.1866; val_mae2_loss: 51.2259; val_nu_mass_loss: 49.3246
# Epoch 97; dinu_pt_loss: 44.0921; fused_output_loss: 51.3874; higgs_mass_loss: 89.8262; lambda_weight: 44.1666; loss: 106.2766; mae1_loss: 58.3913; mae2_loss: 51.3874; nu_mass_loss: 50.0561; val_dinu_pt_loss: 43.6730; val_fused_output_loss: 50.9745; val_higgs_mass_loss: 89.7874; val_lambda_weight: 44.2543; val_loss: 105.4780; val_mae1_loss: 58.0324; val_mae2_loss: 50.9745; val_nu_mass_loss: 49.5076
# Epoch 98; dinu_pt_loss: 43.7608; fused_output_loss: 51.1219; higgs_mass_loss: 89.3758; lambda_weight: 44.5516; loss: 105.8007; mae1_loss: 58.2356; mae2_loss: 51.1219; nu_mass_loss: 50.2748; val_dinu_pt_loss: 43.3492; val_fused_output_loss: 50.7076; val_higgs_mass_loss: 89.3157; val_lambda_weight: 44.6052; val_loss: 105.0021; val_mae1_loss: 57.8815; val_mae2_loss: 50.7076; val_nu_mass_loss: 49.7332
# Epoch 99; dinu_pt_loss: 43.4462; fused_output_loss: 50.8551; higgs_mass_loss: 88.9315; lambda_weight: 44.9307; loss: 105.3226; mae1_loss: 58.0799; mae2_loss: 50.8551; nu_mass_loss: 50.4763; val_dinu_pt_loss: 43.0552; val_fused_output_loss: 50.4498; val_higgs_mass_loss: 88.8946; val_lambda_weight: 44.9754; val_loss: 104.5402; val_mae1_loss: 57.7310; val_mae2_loss: 50.4498; val_nu_mass_loss: 49.9079
# Epoch 100; dinu_pt_loss: 43.1277; fused_output_loss: 50.5892; higgs_mass_loss: 88.4737; lambda_weight: 45.3046; loss: 104.8461; mae1_loss: 57.9248; mae2_loss: 50.5892; nu_mass_loss: 50.6920; val_dinu_pt_loss: 42.6960; val_fused_output_loss: 50.1833; val_higgs_mass_loss: 88.4330; val_lambda_weight: 45.3382; val_loss: 104.0630; val_mae1_loss: 57.5762; val_mae2_loss: 50.1833; val_nu_mass_loss: 50.1287
# Epoch 101; dinu_pt_loss: 42.8025; fused_output_loss: 50.3209; higgs_mass_loss: 87.9968; lambda_weight: 45.6746; loss: 104.3663; mae1_loss: 57.7696; mae2_loss: 50.3209; nu_mass_loss: 50.8971; val_dinu_pt_loss: 42.3432; val_fused_output_loss: 49.9177; val_higgs_mass_loss: 87.9835; val_lambda_weight: 45.6957; val_loss: 103.5914; val_mae1_loss: 57.4298; val_mae2_loss: 49.9177; val_nu_mass_loss: 50.3289
# Epoch 102; dinu_pt_loss: 42.4810; fused_output_loss: 50.0522; higgs_mass_loss: 87.5243; lambda_weight: 46.0390; loss: 103.8857; mae1_loss: 57.6148; mae2_loss: 50.0522; nu_mass_loss: 51.0974; val_dinu_pt_loss: 42.0723; val_fused_output_loss: 49.6406; val_higgs_mass_loss: 87.4787; val_lambda_weight: 46.0626; val_loss: 103.0971; val_mae1_loss: 57.2722; val_mae2_loss: 49.6406; val_nu_mass_loss: 50.5130
# Epoch 103; dinu_pt_loss: 42.1460; fused_output_loss: 49.7827; higgs_mass_loss: 87.0369; lambda_weight: 46.3992; loss: 103.4044; mae1_loss: 57.4608; mae2_loss: 49.7827; nu_mass_loss: 51.2771; val_dinu_pt_loss: 41.7100; val_fused_output_loss: 49.3687; val_higgs_mass_loss: 87.0068; val_lambda_weight: 46.3958; val_loss: 102.6138; val_mae1_loss: 57.1215; val_mae2_loss: 49.3687; val_nu_mass_loss: 50.6645
# Epoch 104; dinu_pt_loss: 41.8427; fused_output_loss: 49.5119; higgs_mass_loss: 86.5671; lambda_weight: 46.7475; loss: 102.9212; mae1_loss: 57.3067; mae2_loss: 49.5119; nu_mass_loss: 51.4550; val_dinu_pt_loss: 41.4075; val_fused_output_loss: 49.1009; val_higgs_mass_loss: 86.4740; val_lambda_weight: 46.7403; val_loss: 102.1363; val_mae1_loss: 56.9701; val_mae2_loss: 49.1009; val_nu_mass_loss: 50.8961
# Epoch 105; dinu_pt_loss: 41.5257; fused_output_loss: 49.2414; higgs_mass_loss: 86.0610; lambda_weight: 47.0872; loss: 102.4388; mae1_loss: 57.1532; mae2_loss: 49.2414; nu_mass_loss: 51.6328; val_dinu_pt_loss: 41.0789; val_fused_output_loss: 48.8353; val_higgs_mass_loss: 86.0042; val_lambda_weight: 47.0643; val_loss: 101.6625; val_mae1_loss: 56.8189; val_mae2_loss: 48.8353; val_nu_mass_loss: 51.0258
# Epoch 106; dinu_pt_loss: 41.2001; fused_output_loss: 48.9694; higgs_mass_loss: 85.5478; lambda_weight: 47.4319; loss: 101.9543; mae1_loss: 57.0004; mae2_loss: 48.9694; nu_mass_loss: 51.8139; val_dinu_pt_loss: 40.7274; val_fused_output_loss: 48.5637; val_higgs_mass_loss: 85.4919; val_lambda_weight: 47.3564; val_loss: 101.1830; val_mae1_loss: 56.6750; val_mae2_loss: 48.5637; val_nu_mass_loss: 51.1755
# Epoch 107; dinu_pt_loss: 40.8909; fused_output_loss: 48.6979; higgs_mass_loss: 85.0216; lambda_weight: 47.7652; loss: 101.4710; mae1_loss: 56.8482; mae2_loss: 48.6979; nu_mass_loss: 51.9724; val_dinu_pt_loss: 40.4077; val_fused_output_loss: 48.2692; val_higgs_mass_loss: 84.9361; val_lambda_weight: 47.7090; val_loss: 100.6637; val_mae1_loss: 56.5197; val_mae2_loss: 48.2692; val_nu_mass_loss: 51.3698
# Epoch 108; dinu_pt_loss: 40.5687; fused_output_loss: 48.4233; higgs_mass_loss: 84.4915; lambda_weight: 48.0903; loss: 100.9834; mae1_loss: 56.6972; mae2_loss: 48.4233; nu_mass_loss: 52.1119; val_dinu_pt_loss: 40.1551; val_fused_output_loss: 48.0194; val_higgs_mass_loss: 84.3945; val_lambda_weight: 48.0000; val_loss: 100.2199; val_mae1_loss: 56.3814; val_mae2_loss: 48.0194; val_nu_mass_loss: 51.4878
# Epoch 109; dinu_pt_loss: 40.2552; fused_output_loss: 48.1519; higgs_mass_loss: 83.9676; lambda_weight: 48.4204; loss: 100.5010; mae1_loss: 56.5464; mae2_loss: 48.1519; nu_mass_loss: 52.2772; val_dinu_pt_loss: 39.7045; val_fused_output_loss: 47.7338; val_higgs_mass_loss: 83.9551; val_lambda_weight: 48.3153; val_loss: 99.7162; val_mae1_loss: 56.2309; val_mae2_loss: 47.7338; val_nu_mass_loss: 51.6155
# Epoch 110; dinu_pt_loss: 39.9530; fused_output_loss: 47.8775; higgs_mass_loss: 83.4276; lambda_weight: 48.7457; loss: 100.0146; mae1_loss: 56.3968; mae2_loss: 47.8775; nu_mass_loss: 52.4164; val_dinu_pt_loss: 39.5096; val_fused_output_loss: 47.4590; val_higgs_mass_loss: 83.3242; val_lambda_weight: 48.6215; val_loss: 99.2307; val_mae1_loss: 56.0846; val_mae2_loss: 47.4590; val_nu_mass_loss: 51.7751
# Epoch 111; dinu_pt_loss: 39.6101; fused_output_loss: 47.6028; higgs_mass_loss: 82.8831; lambda_weight: 49.0564; loss: 99.5280; mae1_loss: 56.2478; mae2_loss: 47.6028; nu_mass_loss: 52.5493; val_dinu_pt_loss: 39.1413; val_fused_output_loss: 47.1824; val_higgs_mass_loss: 82.7929; val_lambda_weight: 48.9100; val_loss: 98.7420; val_mae1_loss: 55.9367; val_mae2_loss: 47.1824; val_nu_mass_loss: 51.9071
# Epoch 112; dinu_pt_loss: 39.3187; fused_output_loss: 47.3292; higgs_mass_loss: 82.3129; lambda_weight: 49.3766; loss: 99.0434; mae1_loss: 56.0991; mae2_loss: 47.3292; nu_mass_loss: 52.6901; val_dinu_pt_loss: 38.8402; val_fused_output_loss: 46.9363; val_higgs_mass_loss: 82.2771; val_lambda_weight: 49.1985; val_loss: 98.3008; val_mae1_loss: 55.7925; val_mae2_loss: 46.9363; val_nu_mass_loss: 52.0012
# Epoch 113; dinu_pt_loss: 39.0027; fused_output_loss: 47.0549; higgs_mass_loss: 81.7515; lambda_weight: 49.6893; loss: 98.5579; mae1_loss: 55.9511; mae2_loss: 47.0549; nu_mass_loss: 52.8120; val_dinu_pt_loss: 38.4889; val_fused_output_loss: 46.6368; val_higgs_mass_loss: 81.6939; val_lambda_weight: 49.5131; val_loss: 97.7773; val_mae1_loss: 55.6442; val_mae2_loss: 46.6368; val_nu_mass_loss: 52.1189
# Epoch 114; dinu_pt_loss: 38.7022; fused_output_loss: 46.7824; higgs_mass_loss: 81.2090; lambda_weight: 49.9906; loss: 98.0758; mae1_loss: 55.8046; mae2_loss: 46.7824; nu_mass_loss: 52.9174; val_dinu_pt_loss: 38.1842; val_fused_output_loss: 46.3734; val_higgs_mass_loss: 81.1205; val_lambda_weight: 49.7989; val_loss: 97.3118; val_mae1_loss: 55.5034; val_mae2_loss: 46.3734; val_nu_mass_loss: 52.2420
# Epoch 115; dinu_pt_loss: 38.3723; fused_output_loss: 46.5073; higgs_mass_loss: 80.6214; lambda_weight: 50.2885; loss: 97.5910; mae1_loss: 55.6603; mae2_loss: 46.5073; nu_mass_loss: 53.0317; val_dinu_pt_loss: 37.8891; val_fused_output_loss: 46.0841; val_higgs_mass_loss: 80.5027; val_lambda_weight: 50.1013; val_loss: 96.8063; val_mae1_loss: 55.3601; val_mae2_loss: 46.0841; val_nu_mass_loss: 52.3485
# Epoch 116; dinu_pt_loss: 38.0685; fused_output_loss: 46.2339; higgs_mass_loss: 80.0309; lambda_weight: 50.5887; loss: 97.1085; mae1_loss: 55.5154; mae2_loss: 46.2339; nu_mass_loss: 53.1430; val_dinu_pt_loss: 37.5247; val_fused_output_loss: 45.8216; val_higgs_mass_loss: 80.0012; val_lambda_weight: 50.3650; val_loss: 96.3414; val_mae1_loss: 55.2179; val_mae2_loss: 45.8216; val_nu_mass_loss: 52.4057
# ...
# Epoch 993; dinu_pt_loss: 17.0059; fused_output_loss: 24.6269; higgs_mass_loss: 18.1501; lambda_weight: 87.7197; loss: 56.8179; mae1_loss: 39.7549; mae2_loss: 24.6269; nu_mass_loss: 55.8790; val_dinu_pt_loss: 14.7957; val_fused_output_loss: 24.3191; val_higgs_mass_loss: 16.0352; val_lambda_weight: 87.3978; val_loss: 56.2261; val_mae1_loss: 39.4947; val_mae2_loss: 24.3191; val_nu_mass_loss: 55.3146
# Epoch 994; dinu_pt_loss: 17.0097; fused_output_loss: 24.6278; higgs_mass_loss: 18.2021; lambda_weight: 87.7429; loss: 56.8173; mae1_loss: 39.7512; mae2_loss: 24.6278; nu_mass_loss: 55.8790; val_dinu_pt_loss: 14.8647; val_fused_output_loss: 24.3385; val_higgs_mass_loss: 16.5406; val_lambda_weight: 87.4426; val_loss: 56.2543; val_mae1_loss: 39.4930; val_mae2_loss: 24.3385; val_nu_mass_loss: 54.1583
# Epoch 995; dinu_pt_loss: 16.9984; fused_output_loss: 24.6265; higgs_mass_loss: 18.1398; lambda_weight: 87.7621; loss: 56.8144; mae1_loss: 39.7495; mae2_loss: 24.6265; nu_mass_loss: 55.8468; val_dinu_pt_loss: 14.8237; val_fused_output_loss: 24.3210; val_higgs_mass_loss: 16.4049; val_lambda_weight: 87.4822; val_loss: 56.2237; val_mae1_loss: 39.4842; val_mae2_loss: 24.3210; val_nu_mass_loss: 54.0462
# Epoch 996; dinu_pt_loss: 16.9676; fused_output_loss: 24.6231; higgs_mass_loss: 18.0917; lambda_weight: 87.7873; loss: 56.8059; mae1_loss: 39.7427; mae2_loss: 24.6231; nu_mass_loss: 55.8383; val_dinu_pt_loss: 15.1532; val_fused_output_loss: 24.3358; val_higgs_mass_loss: 15.6840; val_lambda_weight: 87.5024; val_loss: 56.2424; val_mae1_loss: 39.4774; val_mae2_loss: 24.3358; val_nu_mass_loss: 54.7599
# Epoch 997; dinu_pt_loss: 16.9886; fused_output_loss: 24.6255; higgs_mass_loss: 18.1469; lambda_weight: 87.8123; loss: 56.8072; mae1_loss: 39.7379; mae2_loss: 24.6255; nu_mass_loss: 55.9132; val_dinu_pt_loss: 14.9873; val_fused_output_loss: 24.3349; val_higgs_mass_loss: 16.0875; val_lambda_weight: 87.5378; val_loss: 56.2407; val_mae1_loss: 39.4768; val_mae2_loss: 24.3349; val_nu_mass_loss: 54.4457
# Epoch 998; dinu_pt_loss: 16.9879; fused_output_loss: 24.6205; higgs_mass_loss: 18.0933; lambda_weight: 87.8419; loss: 56.7970; mae1_loss: 39.7324; mae2_loss: 24.6205; nu_mass_loss: 55.8251; val_dinu_pt_loss: 14.9321; val_fused_output_loss: 24.3360; val_higgs_mass_loss: 15.8774; val_lambda_weight: 87.5564; val_loss: 56.2400; val_mae1_loss: 39.4719; val_mae2_loss: 24.3360; val_nu_mass_loss: 54.6921
# Epoch 999; dinu_pt_loss: 16.9963; fused_output_loss: 24.6227; higgs_mass_loss: 18.1165; lambda_weight: 87.8668; loss: 56.7982; mae1_loss: 39.7283; mae2_loss: 24.6227; nu_mass_loss: 55.8503; val_dinu_pt_loss: 14.8676; val_fused_output_loss: 24.3250; val_higgs_mass_loss: 16.0512; val_lambda_weight: 87.5777; val_loss: 56.2191; val_mae1_loss: 39.4634; val_mae2_loss: 24.3250; val_nu_mass_loss: 54.7350
# Epoch 1000; dinu_pt_loss: 17.0082; fused_output_loss: 24.6211; higgs_mass_loss: 18.1055; lambda_weight: 87.8973; loss: 56.7939; mae1_loss: 39.7245; mae2_loss: 24.6211; nu_mass_loss: 55.8573; val_dinu_pt_loss: 14.8403; val_fused_output_loss: 24.3366; val_higgs_mass_loss: 16.0734; val_lambda_weight: 87.6443; val_loss: 56.2370; val_mae1_loss: 39.4643; val_mae2_loss: 24.3366; val_nu_mass_loss: 55.7455
# Epoch 1001; dinu_pt_loss: 16.9808; fused_output_loss: 24.6197; higgs_mass_loss: 18.0457; lambda_weight: 87.9233; loss: 56.7886; mae1_loss: 39.7181; mae2_loss: 24.6197; nu_mass_loss: 55.7980; val_dinu_pt_loss: 15.0885; val_fused_output_loss: 24.3377; val_higgs_mass_loss: 16.0455; val_lambda_weight: 87.6166; val_loss: 56.2381; val_mae1_loss: 39.4631; val_mae2_loss: 24.3377; val_nu_mass_loss: 55.1907
# Epoch 1002; dinu_pt_loss: 16.9899; fused_output_loss: 24.6199; higgs_mass_loss: 18.1106; lambda_weight: 87.9462; loss: 56.7870; mae1_loss: 39.7145; mae2_loss: 24.6199; nu_mass_loss: 55.8604; val_dinu_pt_loss: 15.0409; val_fused_output_loss: 24.3415; val_higgs_mass_loss: 16.5388; val_lambda_weight: 87.6847; val_loss: 56.2392; val_mae1_loss: 39.4539; val_mae2_loss: 24.3415; val_nu_mass_loss: 53.9719
# Epoch 1003; dinu_pt_loss: 17.0014; fused_output_loss: 24.6175; higgs_mass_loss: 18.0986; lambda_weight: 87.9692; loss: 56.7822; mae1_loss: 39.7118; mae2_loss: 24.6175; nu_mass_loss: 55.8029; val_dinu_pt_loss: 14.8623; val_fused_output_loss: 24.3255; val_higgs_mass_loss: 17.0111; val_lambda_weight: 87.6443; val_loss: 56.2137; val_mae1_loss: 39.4508; val_mae2_loss: 24.3255; val_nu_mass_loss: 54.6881
# Epoch 1004; dinu_pt_loss: 17.0030; fused_output_loss: 24.6162; higgs_mass_loss: 18.0988; lambda_weight: 87.9976; loss: 56.7773; mae1_loss: 39.7060; mae2_loss: 24.6162; nu_mass_loss: 55.8971; val_dinu_pt_loss: 14.8421; val_fused_output_loss: 24.3237; val_higgs_mass_loss: 16.2988; val_lambda_weight: 87.7136; val_loss: 56.2079; val_mae1_loss: 39.4445; val_mae2_loss: 24.3237; val_nu_mass_loss: 53.9332
# Epoch 1005; dinu_pt_loss: 16.9731; fused_output_loss: 24.6154; higgs_mass_loss: 18.0902; lambda_weight: 88.0220; loss: 56.7732; mae1_loss: 39.7002; mae2_loss: 24.6154; nu_mass_loss: 55.7516; val_dinu_pt_loss: 15.1104; val_fused_output_loss: 24.3398; val_higgs_mass_loss: 16.0341; val_lambda_weight: 87.6910; val_loss: 56.2337; val_mae1_loss: 39.4479; val_mae2_loss: 24.3398; val_nu_mass_loss: 55.2443
# Epoch 1006; dinu_pt_loss: 16.9629; fused_output_loss: 24.6144; higgs_mass_loss: 18.0703; lambda_weight: 88.0436; loss: 56.7700; mae1_loss: 39.6968; mae2_loss: 24.6144; nu_mass_loss: 55.7795; val_dinu_pt_loss: 15.4274; val_fused_output_loss: 24.3508; val_higgs_mass_loss: 15.9327; val_lambda_weight: 87.7127; val_loss: 56.2456; val_mae1_loss: 39.4388; val_mae2_loss: 24.3508; val_nu_mass_loss: 55.4454
# Epoch 1007; dinu_pt_loss: 16.9601; fused_output_loss: 24.6192; higgs_mass_loss: 18.0795; lambda_weight: 88.0695; loss: 56.7753; mae1_loss: 39.6930; mae2_loss: 24.6192; nu_mass_loss: 55.8091; val_dinu_pt_loss: 14.9814; val_fused_output_loss: 24.3318; val_higgs_mass_loss: 16.0184; val_lambda_weight: 87.7947; val_loss: 56.2132; val_mae1_loss: 39.4309; val_mae2_loss: 24.3318; val_nu_mass_loss: 55.2113
# Epoch 1008; dinu_pt_loss: 16.9777; fused_output_loss: 24.6162; higgs_mass_loss: 18.1043; lambda_weight: 88.0953; loss: 56.7682; mae1_loss: 39.6876; mae2_loss: 24.6162; nu_mass_loss: 55.8187; val_dinu_pt_loss: 15.1576; val_fused_output_loss: 24.3365; val_higgs_mass_loss: 15.7582; val_lambda_weight: 87.7919; val_loss: 56.2182; val_mae1_loss: 39.4270; val_mae2_loss: 24.3365; val_nu_mass_loss: 55.2296
# Epoch 1009; dinu_pt_loss: 16.9505; fused_output_loss: 24.6138; higgs_mass_loss: 18.0566; lambda_weight: 88.1266; loss: 56.7617; mae1_loss: 39.6819; mae2_loss: 24.6138; nu_mass_loss: 55.8050; val_dinu_pt_loss: 15.0695; val_fused_output_loss: 24.3300; val_higgs_mass_loss: 15.8257; val_lambda_weight: 87.8089; val_loss: 56.2065; val_mae1_loss: 39.4231; val_mae2_loss: 24.3300; val_nu_mass_loss: 54.7726
# Epoch 1010; dinu_pt_loss: 16.9532; fused_output_loss: 24.6132; higgs_mass_loss: 18.0016; lambda_weight: 88.1598; loss: 56.7593; mae1_loss: 39.6791; mae2_loss: 24.6132; nu_mass_loss: 55.8029; val_dinu_pt_loss: 14.7370; val_fused_output_loss: 24.3142; val_higgs_mass_loss: 15.9834; val_lambda_weight: 87.8466; val_loss: 56.1795; val_mae1_loss: 39.4164; val_mae2_loss: 24.3142; val_nu_mass_loss: 54.7195
# Epoch 1011; dinu_pt_loss: 16.9576; fused_output_loss: 24.6098; higgs_mass_loss: 18.0087; lambda_weight: 88.1808; loss: 56.7512; mae1_loss: 39.6729; mae2_loss: 24.6098; nu_mass_loss: 55.7913; val_dinu_pt_loss: 14.7461; val_fused_output_loss: 24.3139; val_higgs_mass_loss: 16.1190; val_lambda_weight: 87.9084; val_loss: 56.1763; val_mae1_loss: 39.4109; val_mae2_loss: 24.3139; val_nu_mass_loss: 54.9066
# Epoch 1012; dinu_pt_loss: 16.9576; fused_output_loss: 24.6116; higgs_mass_loss: 18.0206; lambda_weight: 88.2015; loss: 56.7519; mae1_loss: 39.6691; mae2_loss: 24.6116; nu_mass_loss: 55.7912; val_dinu_pt_loss: 14.8615; val_fused_output_loss: 24.3193; val_higgs_mass_loss: 15.8976; val_lambda_weight: 87.9010; val_loss: 56.1832; val_mae1_loss: 39.4084; val_mae2_loss: 24.3193; val_nu_mass_loss: 55.7121
# Epoch 1013; dinu_pt_loss: 16.9752; fused_output_loss: 24.6104; higgs_mass_loss: 18.0202; lambda_weight: 88.2269; loss: 56.7472; mae1_loss: 39.6634; mae2_loss: 24.6104; nu_mass_loss: 55.7522; val_dinu_pt_loss: 14.9545; val_fused_output_loss: 24.3255; val_higgs_mass_loss: 15.8102; val_lambda_weight: 87.9549; val_loss: 56.1899; val_mae1_loss: 39.4034; val_mae2_loss: 24.3255; val_nu_mass_loss: 55.6367
# Epoch 1014; dinu_pt_loss: 16.9659; fused_output_loss: 24.6080; higgs_mass_loss: 17.9837; lambda_weight: 88.2594; loss: 56.7418; mae1_loss: 39.6596; mae2_loss: 24.6080; nu_mass_loss: 55.7653; val_dinu_pt_loss: 15.0774; val_fused_output_loss: 24.3390; val_higgs_mass_loss: 15.8330; val_lambda_weight: 87.9798; val_loss: 56.2104; val_mae1_loss: 39.4038; val_mae2_loss: 24.3390; val_nu_mass_loss: 55.4868
# Epoch 1015; dinu_pt_loss: 16.9734; fused_output_loss: 24.6132; higgs_mass_loss: 17.9799; lambda_weight: 88.2894; loss: 56.7473; mae1_loss: 39.6550; mae2_loss: 24.6132; nu_mass_loss: 55.7812; val_dinu_pt_loss: 14.9330; val_fused_output_loss: 24.3315; val_higgs_mass_loss: 16.5247; val_lambda_weight: 88.0148; val_loss: 56.1933; val_mae1_loss: 39.3920; val_mae2_loss: 24.3315; val_nu_mass_loss: 54.0174
# Epoch 1016; dinu_pt_loss: 16.9882; fused_output_loss: 24.6104; higgs_mass_loss: 18.0721; lambda_weight: 88.3073; loss: 56.7413; mae1_loss: 39.6512; mae2_loss: 24.6104; nu_mass_loss: 55.8154; val_dinu_pt_loss: 14.8231; val_fused_output_loss: 24.3226; val_higgs_mass_loss: 16.3163; val_lambda_weight: 88.0691; val_loss: 56.1748; val_mae1_loss: 39.3819; val_mae2_loss: 24.3226; val_nu_mass_loss: 54.5380
# Epoch 1017; dinu_pt_loss: 16.9850; fused_output_loss: 24.6102; higgs_mass_loss: 17.9902; lambda_weight: 88.3326; loss: 56.7380; mae1_loss: 39.6454; mae2_loss: 24.6102; nu_mass_loss: 55.8056; val_dinu_pt_loss: 15.0727; val_fused_output_loss: 24.3315; val_higgs_mass_loss: 15.7062; val_lambda_weight: 88.0287; val_loss: 56.1896; val_mae1_loss: 39.3849; val_mae2_loss: 24.3315; val_nu_mass_loss: 54.9194
# Epoch 1018; dinu_pt_loss: 16.9798; fused_output_loss: 24.6085; higgs_mass_loss: 18.0337; lambda_weight: 88.3592; loss: 56.7335; mae1_loss: 39.6414; mae2_loss: 24.6085; nu_mass_loss: 55.8316; val_dinu_pt_loss: 15.1450; val_fused_output_loss: 24.3337; val_higgs_mass_loss: 15.6874; val_lambda_weight: 88.0552; val_loss: 56.1921; val_mae1_loss: 39.3830; val_mae2_loss: 24.3337; val_nu_mass_loss: 54.4059
# Epoch 1019; dinu_pt_loss: 16.9603; fused_output_loss: 24.6113; higgs_mass_loss: 18.0640; lambda_weight: 88.3913; loss: 56.7358; mae1_loss: 39.6376; mae2_loss: 24.6113; nu_mass_loss: 55.8038; val_dinu_pt_loss: 15.1810; val_fused_output_loss: 24.3364; val_higgs_mass_loss: 15.7234; val_lambda_weight: 88.0489; val_loss: 56.1937; val_mae1_loss: 39.3784; val_mae2_loss: 24.3364; val_nu_mass_loss: 54.5619
# Epoch 1020; dinu_pt_loss: 16.9565; fused_output_loss: 24.6093; higgs_mass_loss: 18.0294; lambda_weight: 88.4116; loss: 56.7304; mae1_loss: 39.6330; mae2_loss: 24.6093; nu_mass_loss: 55.7919; val_dinu_pt_loss: 15.2933; val_fused_output_loss: 24.3432; val_higgs_mass_loss: 15.8584; val_lambda_weight: 88.1285; val_loss: 56.1990; val_mae1_loss: 39.3686; val_mae2_loss: 24.3432; val_nu_mass_loss: 54.6046
# Epoch 1021; dinu_pt_loss: 16.9544; fused_output_loss: 24.6059; higgs_mass_loss: 17.9982; lambda_weight: 88.4331; loss: 56.7229; mae1_loss: 39.6280; mae2_loss: 24.6059; nu_mass_loss: 55.7908; val_dinu_pt_loss: 15.1848; val_fused_output_loss: 24.3377; val_higgs_mass_loss: 15.8057; val_lambda_weight: 88.1378; val_loss: 56.1925; val_mae1_loss: 39.3719; val_mae2_loss: 24.3377; val_nu_mass_loss: 55.3499
# Epoch 1022; dinu_pt_loss: 16.9634; fused_output_loss: 24.6023; higgs_mass_loss: 17.9235; lambda_weight: 88.4551; loss: 56.7152; mae1_loss: 39.6236; mae2_loss: 24.6023; nu_mass_loss: 55.7406; val_dinu_pt_loss: 15.0954; val_fused_output_loss: 24.3304; val_higgs_mass_loss: 15.7487; val_lambda_weight: 88.1631; val_loss: 56.1774; val_mae1_loss: 39.3636; val_mae2_loss: 24.3304; val_nu_mass_loss: 54.6320
# Epoch 1023; dinu_pt_loss: 16.9708; fused_output_loss: 24.6043; higgs_mass_loss: 18.0284; lambda_weight: 88.4864; loss: 56.7162; mae1_loss: 39.6193; mae2_loss: 24.6043; nu_mass_loss: 55.8020; val_dinu_pt_loss: 15.0632; val_fused_output_loss: 24.3273; val_higgs_mass_loss: 15.8754; val_lambda_weight: 88.2384; val_loss: 56.1677; val_mae1_loss: 39.3533; val_mae2_loss: 24.3273; val_nu_mass_loss: 54.7742
#
# Model Loss Weights:
# mae1        : 0.500
# mae2        : 0.500
# nu_mass     : 0.000
# higgs_mass  : 0.000
# dinu_pt     : 0.000
# fused_output: 1.000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740770575.388370  659186 service.cc:145] XLA service 0x780e380c3d60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1740770575.388389  659186 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# 2025-02-28 19:22:55.794860: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-02-28 19:22:57.467059: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740770593.007737  659996 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_12', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1740770593.090515  660012 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_8', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1740770593.267509  660000 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_16', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1740770593.307470  660002 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_12', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1740770593.375758  660006 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_16', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1740770612.505613  659186 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_81', 8 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1740770612.540820  659186 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# I0000 00:00:1740770641.670435  661714 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_15', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1740770641.916109  661713 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_16', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1740770659.902714  659204 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_81', 8 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1740770662.709541  663124 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_5', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1740770662.736561  663139 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_7', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1740770662.742659  663140 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_7', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1740770662.772196  663112 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_7', 16 bytes spill stores, 16 bytes spill loads

# %%
# Make a directory
dir_name = HOME_PATH + "/11th_trial/ww_resregressor_result/" 
savedmodel_path = dir_name + "saved_model"
name = "ww_resregressor"

# If the directory exists
if os.path.exists(dir_name):
    test_files = glob.glob(dir_name + "*" + name + "*")
    if test_files:
        for file in test_files:
            os.remove(file)
        print(f"Directory {dir_name} cleaned.")
    print(f"Directory {dir_name} exists.")
else:
    os.makedirs(dir_name)
    print(f"Directory {dir_name} created.")

# save modela
model.save(dir_name + name + ".keras", save_format="keras", overwrite=True)
tf.saved_model.save(model, savedmodel_path) # save model in saved_model format --> use in the onnx 

# predict
pred_y = model.predict(test_x)
# save predicted results
np.savez_compressed(dir_name + name + "_data.npz", pred_y=pred_y[0], test_y=test_y)
sig_pred = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth = np.load(dir_name + name + "_data.npz")["test_y"]
# Out:
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=keras
# Directory /root/work/QE-mls/11th_trial/ww_resregressor_result/ cleaned.
# Directory /root/work/QE-mls/11th_trial/ww_resregressor_result/ exists.
# INFO:tensorflow:Assets written to: /root/work/QE-mls/11th_trial/ww_resregressor_result/saved_model/assets
# INFO:tensorflow:Assets written to: /root/work/QE-mls/11th_trial/ww_resregressor_result/saved_model/assets
# 2660/2660 ━━━━━━━━━━━━━━━━━━━━ 1s 428us/step
# 2025-03-01 02:57:01.157837: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Extract loss values
loss = history.history["loss"]
val_loss = history.history["val_loss"]
mae1_loss = history.history["mae1_loss"]
val_mae1_loss = history.history["val_mae1_loss"]
mae2_loss = history.history["mae2_loss"]
val_mae2_loss = history.history["val_mae2_loss"]
higgs_mass_loss = history.history["higgs_mass_loss"]
val_higgs_mass_loss = history.history["val_higgs_mass_loss"]
dinu_pt_loss = history.history["dinu_pt_loss"]
val_dinu_pt_loss = history.history["val_dinu_pt_loss"]
fused_output_loss = history.history["fused_output_loss"]
val_fused_output_loss = history.history["val_fused_output_loss"]
nu_mass_loss = history.history["nu_mass_loss"]
val_nu_mass_loss = history.history["val_nu_mass_loss"]

# 1) Plot combined training and validation loss
plt.figure(figsize=(5, 4))
plt.plot(loss, label="Training Loss")
plt.plot(val_loss, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Combined Loss")
plt.legend()
plt.grid(False)
plt.show()

# 2) Plot mae training and validation loss
plt.figure(figsize=(5, 4))
plt.plot(mae1_loss, label="Training MAE Loss")
plt.plot(val_mae1_loss, label="Validation MAE Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("MAE1 Loss")
plt.legend()
plt.grid(False)
plt.show()

# 3) Plot mae training and validation loss
plt.figure(figsize=(5, 4))
plt.plot(mae2_loss, label="Training MAE Loss")
plt.plot(val_mae2_loss, label="Validation MAE Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("MAE2 Loss")
plt.legend()
plt.grid(False)
plt.show()

# 3) Plot higgs mass training and validation loss
plt.figure(figsize=(5, 4))
plt.plot(higgs_mass_loss, label="Training Higgs Mass Loss")
plt.plot(val_higgs_mass_loss, label="Validation Higgs Mass Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Higgs Mass Loss")
plt.legend()
plt.grid(False)
plt.show()

# 4) Plot dinu pt loss
plt.figure(figsize=(5, 4))
plt.plot(dinu_pt_loss, label="Training Dinu PT Loss")
plt.plot(val_dinu_pt_loss, label="Validation Dinu PT Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Dinu Pt Loss")
plt.legend()
plt.grid(False)
plt.show()

# 5) Plot fused output loss
plt.figure(figsize=(5, 4))
plt.plot(fused_output_loss, label="Training Fused Output Loss")
plt.plot(val_fused_output_loss, label="Validation Fused Output Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Fused Output Loss")
plt.legend()
plt.grid(False)
plt.show()

# 6) Plot nu mass loss
plt.figure(figsize=(5, 4))
plt.plot(nu_mass_loss, label="Training Nu Mass Loss")
plt.plot(val_nu_mass_loss, label="Validation Nu Mass Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Nu Mass Loss")
plt.legend()
plt.grid(False)
plt.show()

# %%
# save predicted results
np.savez_compressed(
    dir_name + name + "_data.npz",
    pred_y=sig_pred.reshape(sig_truth.shape),
    test_y=sig_truth,
)
sig_pred_inv = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth_inv = np.load(dir_name + name + "_data.npz")["test_y"]

# %%
# neutrino mass checking
nu0_4vect = sig_pred_inv[:, :4] - test_x[:, :4]
nu1_4vect = sig_pred_inv[:, 4:8] - test_x[:, 4:8]
nu0_mass_squared = np.square(nu0_4vect[:, 3]) - np.square(nu0_4vect[:, 0]) - np.square(nu0_4vect[:, 1]) - np.square(nu0_4vect[:, 2])
nu1_mass_squared = np.square(nu1_4vect[:, 3]) - np.square(nu1_4vect[:, 0]) - np.square(nu1_4vect[:, 1]) - np.square(nu1_4vect[:, 2])
# nu0_mass_squared
plt.hist(nu0_mass_squared, bins=100, histtype="step", label="nu0_mass_squared")
plt.hist(nu1_mass_squared, bins=100, histtype="step", label="nu1_mass_squared")
plt.semilogx()
plt.semilogy()
plt.legend()
plt.show()

print("nu0_mass_squared avg:", np.mean(nu0_mass_squared))
print("nu1_mass_squared avg:", np.mean(nu1_mass_squared))
# plt.hist(nu1_mass_squared, bins=100, range=(0, 100), histtype="step", label="nu1_mass_squared")
# Out:
# nu0_mass_squared avg: 901.0484275432665
# nu1_mass_squared avg: 464.17922186008786

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,0]):.3f}, std: {np.std(sig_truth_inv[:,0]):.3f}, min: {np.min(sig_truth_inv[:,0]):.3f}, max: {np.max(sig_truth_inv[:,0]):.3f}"
)

set_range = [-200, 200]

plot.hist_1d(
    sig_truth_inv[:,0], sig_pred_inv[:,0],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,0], sig_pred_inv[:,0], sample_weight=None)):.3f}",
    xlabel="$W^{0}\ p_{x}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,0], sig_pred_inv[:,0],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,0], sig_pred_inv[:,0]):.3f}",
    xlabel="True $W^{0}\ p_{x}$ [GeV]",
    ylabel="Predicted $W^{0}\ p_{x}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 0.031, std: 39.544, min: -585.857, max: 803.254

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,4]):.3f}, std: {np.std(sig_truth_inv[:,4]):.3f}, min: {np.min(sig_truth_inv[:,4]):.3f}, max: {np.max(sig_truth_inv[:,4]):.3f}"
)

set_range = [-200, 200]


plot.hist_1d(
    sig_truth_inv[:,4], sig_pred_inv[:,4],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,4], sig_pred_inv[:,4], sample_weight=None)):.3f}",
    xlabel="$W^{1}\ p_{x}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,4], sig_pred_inv[:,4],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,4], sig_pred_inv[:,4]):.3f}",
    xlabel="True $W^{1}\ p_{x}$ [GeV]",
    ylabel="Predicted $W^{1}\ p_{x}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: -0.124, std: 27.801, min: -399.814, max: 373.865

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,1]):.3f}, std: {np.std(sig_truth_inv[:,1]):.3f}, min: {np.min(sig_truth_inv[:,1]):.3f}, max: {np.max(sig_truth_inv[:,1]):.3f}"
)

set_range = [-200, 200]

plot.hist_1d(
    sig_truth_inv[:,1], sig_pred_inv[:,1],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,1], sig_pred_inv[:,1], sample_weight=None)):.3f}",
    xlabel="$W^{0}\ p_{y}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,1], sig_pred_inv[:,1],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,1], sig_pred_inv[:,1]):.3f}",
    xlabel="True $W^{0}\ p_{y}$ [GeV]",
    ylabel="Predicted $W^{0}\ p_{y}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: -0.013, std: 39.620, min: -755.579, max: 609.143

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,5]):.3f}, std: {np.std(sig_truth_inv[:,5]):.3f}, min: {np.min(sig_truth_inv[:,5]):.3f}, max: {np.max(sig_truth_inv[:,5]):.3f}"
)

set_range = [-200, 200]

plot.hist_1d(
    sig_truth_inv[:,5], sig_pred_inv[:,5],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,5], sig_pred_inv[:,5], sample_weight=None)):.3f}",
    xlabel="$W^{1}\ p_{y}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,5], sig_pred_inv[:,5],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,5], sig_pred_inv[:,5]):.3f}",
    xlabel="True $W^{1}\ p_{y}$ [GeV]",
    ylabel="Predicted $W^{1}\ p_{y}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 0.031, std: 27.968, min: -417.838, max: 580.447

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,2]):.3f}, std: {np.std(sig_truth_inv[:,2]):.3f}, min: {np.min(sig_truth_inv[:,2]):.3f}, max: {np.max(sig_truth_inv[:,2]):.3f}"
)

set_range = [-700, 700]

plot.hist_1d(
    sig_truth_inv[:,2], sig_pred_inv[:,2],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,2], sig_pred_inv[:,2], sample_weight=None)):.3f}",
    xlabel="$W^{0}\ p_{z}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,2], sig_pred_inv[:,2],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,2], sig_pred_inv[:,2]):.3f}",
    xlabel="$W^{0}\ p_{z}$ [GeV]",
    ylabel="Predicted $W^{0}\ p_{z}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 0.308, std: 170.752, min: -1446.473, max: 1754.351

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,6]):.3f}, std: {np.std(sig_truth_inv[:,6]):.3f}, min: {np.min(sig_truth_inv[:,6]):.3f}, max: {np.max(sig_truth_inv[:,6]):.3f}"
)

set_range = [-600, 600]

plot.hist_1d(
    sig_truth_inv[:,6], sig_pred_inv[:,6],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,6], sig_pred_inv[:,6], sample_weight=None)):.3f}",
    xlabel="$W^{1}\ p_{z}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,6], sig_pred_inv[:,6],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,6], sig_pred_inv[:,6]):.3f}",
    xlabel="True $W^{1}\ p_{z}$ [GeV]",
    ylabel="Predicted $W^{1}\ p_{z}$ [GeV]",
    ranges=set_range
)
# Out:
# Truth mean: -0.337, std: 110.947, min: -1170.774, max: 1427.069

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,3]):.3f}, std: {np.std(sig_truth_inv[:,3]):.3f}, min: {np.min(sig_truth_inv[:,3]):.3f}, max: {np.max(sig_truth_inv[:,3]):.3f}"
)

set_range = [0, 800]

plot.hist_1d(
    sig_truth_inv[:,3], sig_pred_inv[:,3],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,3], sig_pred_inv[:,3], sample_weight=None)):.3f}",
    xlabel="$W^{0}\ E$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,3], sig_pred_inv[:,3],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,3], sig_pred_inv[:,3]):.3f}",
    xlabel="True $W^{0}\ E$ [GeV]",
    ylabel="Predicted $W^{0}\ E$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 158.446, std: 111.648, min: 21.707, max: 1791.292

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,7]):.3f}, std: {np.std(sig_truth_inv[:,7]):.3f}, min: {np.min(sig_truth_inv[:,7]):.3f}, max: {np.max(sig_truth_inv[:,7]):.3f}"
)

set_range = [0, 800]

plot.hist_1d(
    sig_truth_inv[:,7], sig_pred_inv[:,7],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,7], sig_pred_inv[:,7], sample_weight=None)):.3f}",
    xlabel="$W^{1}\ E$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,7], sig_pred_inv[:,7],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,7], sig_pred_inv[:,7]):.3f}",
    xlabel="True $W^{1}\ E$ [GeV]",
    ylabel="Predicted $W^{1}\ E$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 98.991, std: 77.608, min: 17.001, max: 1443.825

# %%
lead_time_like = np.square(sig_pred_inv[:, 3]) - np.sum(
    np.square(sig_pred_inv[:, 0:3]), axis=1
)
lead_time_mask = (lead_time_like > 0) * 1
sublead_time_like = np.square(sig_pred_inv[:, 7]) - np.sum(
    np.square(sig_pred_inv[:, 4:7]), axis=1
)
sublead_time_mask = (sublead_time_like > 0) * 1

bin_edges = np.linspace(-5, 1.0e4, 51)
figure = plt.figure(figsize=(10, 8))
plt.hist(
    lead_time_like,
    bins=bin_edges,
    fill=False,
    color="orange",
    histtype="step",
    label=r"$W^{0}$, "
    + f"{100 * np.sum(lead_time_mask) / len(lead_time_mask):.2f} % TL",
    density=True,
    weights=None,
    linewidth=2,
)
plt.hist(
    sublead_time_like,
    bins=bin_edges,
    fill=False,
    color="tab:blue",
    histtype="step",
    label=r"$W^{1}$, "
    + f"{100 * np.sum(sublead_time_mask) / len(sublead_time_mask):.2f} % TL",
    density=True,
    weights=None,
    linewidth=2,
)
plt.hist(
    np.square(w_lead.m),
    bins=bin_edges,
    color="orange",
    fill=True,
    histtype="bar",
    alpha=0.5,
    label=r"$W_{label}^{0}$",
    density=True,
    # weights=mc_weight,
)
plt.hist(
    np.square(w_sublead.m),
    bins=bin_edges,
    color="tab:blue",
    fill=True,
    histtype="bar",
    alpha=0.5,
    label=r"$W_{label}^{1}$",
    density=True,
    # weights=mc_weight,
)
plt.vlines(0, 0, 2e-3, color="red", linestyle="--")
plt.xlim(-5e2, 1.2e4)
plt.ylim(0, 2e-3)
plt.xlabel(r"Mass$^{2}$ [GeV]$^{2}$", labelpad=20)
plt.ylabel("Normalized counts")
plt.legend(loc="upper right", prop={'size': 20})  # Adjust the size value as needed
plt.show()
print(f"m2 with {100 * np.sum(lead_time_mask * sublead_time_mask) / len(lead_time_mask):.2f} % time-like (TL) evts")
# Out:
# m2 with 94.28 % time-like (TL) evts

# %%
# TODO: 2d mass squared
pred_m2 = np.concatenate([lead_time_like, sublead_time_like], axis=-1)
truth_m2 = np.concatenate(
    [np.square(w_lead.m)[test_indices], np.square(w_sublead.m)[test_indices]], axis=-1
)

print(
    f"Truth mean: {np.mean(truth_m2):.3f}, std: {np.std(truth_m2):.3f}, min: {np.min(truth_m2):.3f}, max: {np.max(truth_m2):.3f}"
)

set_range = [-500, 10_500]


plot.hist_1d(
    truth_m2, pred_m2,
    title="",
    xlabel=r"$m_{W}^{2}$",
    xpad=25,
    ranges=set_range
)

plot.hist_2d(
    truth_m2, pred_m2,
    title="",
    xlabel="True $m_{W}^{2}$ [GeV]$^2$",
    ylabel="Predicted $m_{W}^{2}$ [GeV]$^2$",
    xpad=25,
    ranges=set_range
)
# Out:
# Truth mean: 3615.291, std: 2594.373, min: 4.010, max: 11077.988

# %%
# TODO: CGLMP

def Bij(particles):
    # Ensure ROOT is properly initialized
    ROOT.gROOT.SetBatch(True)

    def cglmp(z_xp, z_xn, z_yp, z_yn):
        """
        This is a function to calculate Bij (CGLMP values).
        :param z_xp: Angle (xi) between positive lepton and x-axis.
        :param z_xn: Angle (xi) between negative lepton and x-axis.
        :param z_yp: Angle (xi) between positive lepton and y-axis.
        :param z_xn: Angle (xi) between negative lepton and y-axis.
        """
        # count expectation value, use (27) in Alan's paper
        tr_a = (np.divide(8, np.sqrt(3))) * (z_xp * z_xn + z_yp * z_yn)
        tr_b = (
            25
            * (np.square(z_xp) - np.square(z_yp))
            * (np.square(z_xn) - np.square(z_yn))
        )
        tr_c = 100 * (z_xp * z_yp * z_xn * z_yn)
        tr = tr_a + tr_b + tr_c

        return tr

    WpBoson = TLorentzVector(*particles[:4])
    WpLepton = TLorentzVector(*particles[4:8])
    WnBoson = TLorentzVector(*particles[8:12])
    WnLepton = TLorentzVector(*particles[12:16])

    # construct Higgs 4-vector
    Higgs = WpBoson + WnBoson

    # construct a moving orthogonal basis (k,r,n)
    Beam_p = TLorentzVector(0, 0, 1, 1)  # spatial-axis

    # define boost vector
    Higgsb = Higgs.BoostVector()

    # (1) performs a boost transformation from the rod frame to the rawal one.
    # Perform boost transformation from the rod frame to the rawal one
    for vec in [WpBoson, WpLepton, WnBoson, WnLepton, Beam_p]:
        vec.Boost(-Higgsb)

    # 2. Define (k,r,n) -> definitions are in Alan's paper
    k_per = TVector3(WpBoson.X(), WpBoson.Y(), WpBoson.Z())
    p_per = TVector3(Beam_p.X(), Beam_p.Y(), Beam_p.Z())  # in the Higgs rest frame
    k = k_per.Unit()  # normalized -> unit vector
    p = p_per.Unit()
    y = p.Dot(k)
    r_length = np.sqrt(1 - y * y)
    r = (1 / r_length) * (p - y * k)
    n = (1 / r_length) * (p.Cross(k))  # (1/sin)*sin = 1 -> unit vector

    # 3. Further boost to W+ and W- frame respectively
    WpkBoost = WpBoson.BoostVector()
    WpBoson.Boost(-WpkBoost)
    WpLepton.Boost(-WpkBoost)
    WnkBoost = WnBoson.BoostVector()
    WnBoson.Boost(-WnkBoost)
    WnLepton.Boost(-WnkBoost)

    # 4. Map all particle to (k,r,n) frame
    WpLp = WpLepton.Vect()  # momentum in (k,r,n)
    WnLp = WnLepton.Vect()
    # Mapping to n-r-k basis
    WpLp_k = TLorentzVector(WpLp.Dot(n), WpLp.Dot(r), WpLp.Dot(k), WpLepton.E())
    WnLp_k = TLorentzVector(WnLp.Dot(n), WnLp.Dot(r), WnLp.Dot(k), WnLepton.E())

    # 5. Calculate directional cosines
    # directional cosine from Wp
    WpLp_Vect_Mag = WpLp_k.Vect().Mag()
    cos_n_join_p = np.divide(WpLp_k.X(), WpLp_Vect_Mag)
    cos_r_join_p = np.divide(WpLp_k.Y(), WpLp_Vect_Mag)
    cos_k_join_p = np.divide(WpLp_k.Z(), WpLp_Vect_Mag)
    # directional cosine from Wn
    WnLp_Vect_Mag = WnLp_k.Vect().Mag()
    cos_n_join_n = np.divide(WnLp_k.X(), WnLp_Vect_Mag)
    cos_r_join_n = np.divide(WnLp_k.Y(), WnLp_Vect_Mag)
    cos_k_join_n = np.divide(WnLp_k.Z(), WnLp_Vect_Mag)

    # 6. Calculate Bij (CGLMP values)
    B_xy = cglmp(cos_n_join_p, cos_n_join_n, cos_r_join_p, cos_r_join_n)
    B_yz = cglmp(cos_r_join_p, cos_r_join_n, cos_k_join_p, cos_k_join_n)
    B_zx = cglmp(cos_n_join_p, cos_n_join_n, cos_k_join_p, cos_k_join_n)

    return (
        np.array([B_xy, B_yz, B_zx]),
        np.array([cos_n_join_p, cos_r_join_p, cos_k_join_p]),
        np.array([cos_n_join_n, cos_r_join_n, cos_k_join_n]),
    )
    
def result_generator(particles):
    with multiprocessing.Pool(WORKERS) as pool:
        # Retrieve the output from the pool
        results = list(pool.map(Bij, particles))
    
    # Unpack the results
    bij, xi_p, xi_n = zip(*results)
    
    bij = np.vstack(bij)  # Flatten the nested array
    xi_p = np.vstack(xi_p)
    xi_n = np.vstack(xi_n)
    mask = np.any(np.isnan(bij), axis=1)
    return (
        bij[~mask, :],
        xi_p[~mask, :],
        xi_n[~mask, :],
    )

# %%
# reco
particles = np.concatenate(
    [
        sig_pred_inv[:, 0:4],
        lead_lep_p4[test_indices],
        sig_pred_inv[:, 4:8],
        sublead_lep_p4[test_indices],
    ],
    axis=1,
)
bij = result_generator(particles)[0][0:80_000,:]
xi_p = result_generator(particles)[1][0:80_000,:]
xi_n = result_generator(particles)[2][0:80_000,:]

# truth
particles = np.concatenate(
    [
        sig_truth_inv[:, 0:4],
        truth_lead_lep_p4[test_indices],
        sig_truth_inv[:, 4:8],
        truth_sublead_lep_p4[test_indices],
    ],
    axis=1,
)
truth_bij = result_generator(particles)[0][0:80_000,:]
truth_xi_p = result_generator(particles)[1][0:80_000,:]
truth_xi_n = result_generator(particles)[2][0:80_000,:]

# %%
print(
    f"True mean     : {np.mean(truth_bij[:,0]):.3f}, std: {np.std(truth_bij[:,0]):.3f}, min: {np.min(truth_bij[:,0]):.3f}, max: {np.max(truth_bij[:,0]):.3f}"
)
print(
    f"Predicted mean: {np.mean(bij[:,0]):.3f}, std: {np.std(bij[:,0]):.3f}, min: {np.min(bij[:,0]):.3f}, max: {np.max(bij[:,0]):.3f}"
)

set_range = [-30, 30]

plot.hist_1d(
    truth_bij[:,0], bij[:,0],
    title=rf"mean={np.mean(bij[:,0]):.2f}$\pm${sp.stats.sem(bij[:,0]):.3f}"
    + f" with truth: {np.mean(truth_bij[:,0]):.2f}$\pm${sp.stats.sem(truth_bij[:,0]):.3f}",
    xlabel=r"$B_{xy}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_bij[:,0], bij[:,0],
    title=r"$R^{2}$ = " + f"{r2_score(truth_bij[:,0], bij[:,0]):.3f}",
    xlabel="True $B_{{xy}}$ [None]",
    ylabel="Predicted $B_{{xy}}$ [None]",
    ranges=set_range
)
# Out:
# True mean     : 2.468, std: 12.019, min: -25.100, max: 29.607
# Predicted mean: 7.354, std: 8.701, min: -25.022, max: 29.430

# %%
print(
    f"True mean     : {np.mean(truth_bij[:,1]):.3f}, std: {np.std(truth_bij[:,1]):.3f}, min: {np.min(truth_bij[:,1]):.3f}, max: {np.max(truth_bij[:,1]):.3f}"
)
print(
    f"Predicted mean: {np.mean(bij[:,1]):.3f}, std: {np.std(bij[:,1]):.3f}, min: {np.min(bij[:,1]):.3f}, max: {np.max(bij[:,1]):.3f}"
)

set_range = [-30, 30]


plot.hist_1d(
    truth_bij[:,1], bij[:,1],
    title=fr"mean={np.mean(bij[:,1]):.2f}$\pm${sp.stats.sem(bij[:,1]):.3f}"
    + f" with truth: {np.mean(truth_bij[:,1]):.2f}$\pm${sp.stats.sem(truth_bij[:,1]):.3f}",
    xlabel=r"$B_{yz}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_bij[:,1], bij[:,1],
    title=r"$R^{2}$ = " + f"{r2_score(truth_bij[:,1], bij[:,1]):.3f}",
    xlabel="True $B_{{yz}}$ [None]",
    ylabel="Predicted $B_{{yz}}$ [None]",
    ranges=set_range
)
# Out:
# True mean     : 2.060, std: 8.727, min: -25.095, max: 29.572
# Predicted mean: 0.838, std: 8.125, min: -25.100, max: 29.609

# %%
print(
    f"True mean     : {np.mean(truth_bij[:,2]):.3f}, std: {np.std(truth_bij[:,2]):.3f}, min: {np.min(truth_bij[:,2]):.3f}, max: {np.max(truth_bij[:,2]):.3f}"
)
print(
    f"Predicted mean: {np.mean(bij[:,2]):.3f}, std: {np.std(bij[:,2]):.3f}, min: {np.min(bij[:,2]):.3f}, max: {np.max(bij[:,2]):.3f}"
)

set_range = [-30, 30]

plot.hist_1d(
    truth_bij[:,2], bij[:,2],
    title=rf"mean={np.mean(bij[:,2]):.2f}$\pm${sp.stats.sem(bij[:,2]):.3f}"
    + rf" with truth: {np.mean(truth_bij[:,2]):.2f}$\pm${sp.stats.sem(truth_bij[:,2]):.3f}",
    xlabel=r"$B_{zx}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_bij[:,2], bij[:,2],
    title=r"$R^{2}$ = " + f"{r2_score(truth_bij[:,2], bij[:,2]):.3f}",
    xlabel=r"True $B_{{zx}}$ [None]",
    ylabel=r"Predicted $B_{{zx}}$ [None]",
    ranges=set_range
)
# Out:
# True mean     : 3.228, std: 10.739, min: -25.073, max: 29.599
# Predicted mean: -1.334, std: 12.846, min: -25.086, max: 29.580

# %%
set_range = [-1, 1]


plot.hist_1d(
    truth_xi_p[:,0], xi_p[:,0],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_p[:,0], xi_p[:,0], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(0)}_{n}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_p[:,0], xi_p[:,0],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_p[:,0], xi_p[:,0]):.3f}",
    xlabel=r"True $\xi^{(0)}_{n}$ [None]",
    ylabel=r"Predicted $\xi^{(0)}_{n}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_p[:,1], xi_p[:,1],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_p[:,1], xi_p[:,1], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(0)}_{r}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_p[:,1], xi_p[:,1],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_p[:,1], xi_p[:,1]):.3f}",
    xlabel=r"True $\xi^{(0)}_{r}$ [None]",
    ylabel=r"Predicted $\xi^{(0)}_{r}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_p[:,2], xi_p[:,2],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_p[:,2], xi_p[:,2], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(0)}_{k}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_p[:,2], xi_p[:,2],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_p[:,2], xi_p[:,2]):.3f}",
    xlabel=r"True $\xi^{(0)}_{k}$ [None]",
    ylabel=r"Predicted $\xi^{(0)}_{k}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_n[:,0], xi_n[:,0],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_n[:,0], xi_n[:,0], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(1)}_{n}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_n[:,0], xi_n[:,0],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_n[:,0], xi_n[:,0]):.3f}",
    xlabel=r"True $\xi^{(1)}_{n}$ [None]",
    ylabel=r"Predicted $\xi^{(1)}_{n}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_n[:,1], xi_n[:,1],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_n[:,1], xi_n[:,1], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(1)}_{r}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_n[:,1], xi_n[:,1],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_n[:,1], xi_n[:,1]):.3f}",
    xlabel=r"True $\xi^{(1)}_{r}$ [None]",
    ylabel=r"Predicted $\xi^{(1)}_{r}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_n[:,2], xi_n[:,2],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_n[:,2], xi_n[:,2], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(1)}_{k}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_n[:,2], xi_n[:,2],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_n[:,2], xi_n[:,2]):.3f}",
    xlabel=r"True $\xi^{(1)}_{k}$ [None]",
    ylabel=r"Predicted $\xi^{(1)}_{k}$ [None]",
    xpad=0,
    ranges=set_range
)
