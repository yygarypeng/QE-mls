# %%
# %reset -sf

from time import time
time_start = time()

import pandas as pd
import numpy as np
import scipy as sp
import gc
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import tensorflow as tf

# from mt2 import mt2
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
tf.config.experimental.set_memory_growth(gpus[1], True)

import get_data as gd
import atlas_plot as ap
plot = ap.Plotter()

print(tf.__version__)
print(tf.config.list_physical_devices())
print()
# Out:
# 2.13.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
seed = 42  # set random seed
sampling = int(1e6)
# num_folds = 2
batch_size = 1024
epochs = 512
learning_rate = 1e-6

# %%
np.random.seed(seed)
processor = gd.DataProcessor(sampling=sampling, processor=30)
path = "/root/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 30
#
# ['/root/data/truth/signal/CGLMP.npz', '/root/data/truth/signal/Higgs.npz', '/root/data/truth/signal/LeadLepton.npz', '/root/data/truth/signal/LeptonM.npz', '/root/data/truth/signal/LeptonP.npz', '/root/data/truth/signal/LmNu.npz', '/root/data/truth/signal/LpNu.npz', '/root/data/truth/signal/MET.npz', '/root/data/truth/signal/WmBoson.npz', '/root/data/truth/signal/WpBoson.npz', '/root/data/truth/signal/diLepton.npz', '/root/data/truth/signal/subLeadLepton.npz', '/root/data/truth/signal/xi_xyz.npz']

# %%
GEV = 1e3

cut_pre_pt_lead = data.LeadLep["pt"] > 22 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
cut_pre_pt_miss = data.MET["pt"] > 20 * GEV
cut_pre = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss

del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# %%
# inputs -> observed params
lep_p = processor.process_part(data.LepP)
lep_m = processor.process_part(data.LepM)
lep_kin = pd.concat([lep_p.iloc[:,:4], lep_m.iloc[:,:4]], axis=1)
MET = processor.process_MET(data.MET)
dilep_kin = processor.process_dipart(data.LepP, data.LepM)
# mt = np.sqrt(
#     mt2(
#         lep_m["m"],
#         lep_m["px"],
#         lep_m["py"],  # Visible 1: mass, px, py
#         lep_p["m"],
#         lep_p["px"],
#         lep_p["py"],  # Visible 2: mass, px, py
#         MET["MET_px"],
#         MET["MET_py"],  # Missing transverse momentum: x, y
#         0,
#         0,  # Invisible 1 mass, invisible 2 mass
#     )
# )
# vx = 5 * pd.DataFrame({"vx": mt + 0.3 * np.sqrt(dilep_kin["m"])})
# dilep_kin.iloc[:, 0:4]
obs_kin = pd.concat([MET.iloc[:, 1:3], lep_kin], axis=1)[cut_pre]
print("obs_kin shape:", obs_kin.shape)
print(obs_kin.head(3))
print()

# targets -> interested unknowns
int_kin = pd.DataFrame(processor.process_part(data.NuP)[["pz"]])[cut_pre]
print("int_kin shape:", int_kin.shape)
print(int_kin.head(3))
print()

del (processor, lep_p, lep_m, MET, dilep_kin)
gc.collect()
# Out:
# obs_kin shape: (1378510, 10)
#        MET_px     MET_py           E         px         py          pz  \
# 7   96.335650  47.095450   19.500895  -4.561588  18.924410   -1.154271
# 9  -26.992604 -70.883859  164.814766  34.397141   2.031300 -161.172625
# 10  44.222846 -15.383637   47.669113 -26.605045 -17.256748   35.590859
#
#             E         px         py         pz
# 7   43.361348  42.407754  -4.632000   7.767462
# 9   70.592648  29.001777   1.896990 -64.332027
# 10  90.238664 -23.868604  32.986602  80.530680
#
# int_kin shape: (1378510, 1)
#             pz
# 7  -106.034867
# 9   -91.125109
# 10    3.670725
# 0

# %%
SCALAR_int_ru = RobustScaler()
int_kin = SCALAR_int_ru.fit_transform(int_kin)
SCALAR_int_mm = MinMaxScaler()
int_kin = SCALAR_int_mm.fit_transform(int_kin)

SCALAR_obs_ru = RobustScaler()
obs_kin = SCALAR_obs_ru.fit_transform(obs_kin)
SCALAR_obs_mm = MinMaxScaler()
obs_kin = SCALAR_obs_mm.fit_transform(obs_kin)

# %%
indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.4,
    test_size=0.6,
    random_state=seed,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=42
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
print()
# Out:
# X (Interest)
# Training data shape: (551404, 10);
# Validing data shape: (413553, 10);
# Testing data shape: (413553, 10).
# Y (Observed)
# Training data shape: (551404, 1);
# Validing data shape: (413553, 1);
# Testing data shape: (413553, 1).

# %%
from matplotlib import pyplot as plt

plt.hist(train_y, bins=200, alpha=.8)
plt.title(r"Norm. $p_{z}$")
plt.xlabel("null")
plt.ylabel("count")
# plt.xlim([0,0.5])
plt.show()

# %%
# Define a new activation function
def custom_activation(x):
    return x*tf.keras.backend.sigmoid(x)

# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    x = tf.keras.layers.Dense(units=16, activation="elu")(x)
    x = tf.keras.layers.Dense(units=16, activation="elu")(x)
    x = tf.keras.layers.Dropout(rate=0.1)(x)
    x = tf.keras.layers.Dense(units=4, activation="elu")(x)
    x = tf.keras.layers.Dense(units=4, activation="elu")(x)
    
    # Last dense layer
    outputs = tf.keras.layers.Dense(units=train_y.shape[-1], activation="sigmoid")(x)

    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss="mse",
    )

    # Summarize the model
    model.summary()

    return model

# %%
model = build_model()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10)]              0
#
#  flatten (Flatten)           (None, 10)                0
#
#  dense (Dense)               (None, 16)                176
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_2 (Dense)             (None, 4)                 68
#
#  dense_3 (Dense)             (None, 4)                 20
#
#  dense_4 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 541 (2.11 KB)
# Trainable params: 541 (2.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-6,
    patience=10,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)

# Fit the model
history = model.fit(
    x=train_x,
    y=train_y,
    validation_data=(valid_x, valid_y),
    epochs=epochs,
    batch_size=batch_size,
    verbose=2,
    callbacks=[stop_early],
)
# Out:
# Epoch 1/512
# 539/539 - 5s - loss: 0.0992 - val_loss: 0.0971 - 5s/epoch - 9ms/step
# Epoch 2/512
# 539/539 - 2s - loss: 0.0927 - val_loss: 0.0901 - 2s/epoch - 4ms/step
# Epoch 3/512
# 539/539 - 2s - loss: 0.0858 - val_loss: 0.0830 - 2s/epoch - 4ms/step
# Epoch 4/512
# 539/539 - 2s - loss: 0.0792 - val_loss: 0.0758 - 2s/epoch - 4ms/step
# Epoch 5/512
# 539/539 - 2s - loss: 0.0725 - val_loss: 0.0686 - 2s/epoch - 4ms/step
# Epoch 6/512
# 539/539 - 2s - loss: 0.0658 - val_loss: 0.0615 - 2s/epoch - 4ms/step
# Epoch 7/512
# 539/539 - 2s - loss: 0.0593 - val_loss: 0.0545 - 2s/epoch - 4ms/step
# Epoch 8/512
# 539/539 - 2s - loss: 0.0530 - val_loss: 0.0479 - 2s/epoch - 4ms/step
# Epoch 9/512
# 539/539 - 2s - loss: 0.0471 - val_loss: 0.0415 - 2s/epoch - 4ms/step
# Epoch 10/512
# 539/539 - 2s - loss: 0.0413 - val_loss: 0.0355 - 2s/epoch - 4ms/step
# Epoch 11/512
# 539/539 - 2s - loss: 0.0360 - val_loss: 0.0300 - 2s/epoch - 5ms/step
# Epoch 12/512
# 539/539 - 2s - loss: 0.0311 - val_loss: 0.0248 - 2s/epoch - 4ms/step
# Epoch 13/512
# 539/539 - 2s - loss: 0.0266 - val_loss: 0.0202 - 2s/epoch - 5ms/step
# Epoch 14/512
# 539/539 - 2s - loss: 0.0226 - val_loss: 0.0161 - 2s/epoch - 4ms/step
# Epoch 15/512
# 539/539 - 2s - loss: 0.0190 - val_loss: 0.0125 - 2s/epoch - 5ms/step
# Epoch 16/512
# 539/539 - 2s - loss: 0.0159 - val_loss: 0.0095 - 2s/epoch - 4ms/step
# Epoch 17/512
# 539/539 - 2s - loss: 0.0133 - val_loss: 0.0070 - 2s/epoch - 4ms/step
# Epoch 18/512
# 539/539 - 2s - loss: 0.0112 - val_loss: 0.0050 - 2s/epoch - 5ms/step
# Epoch 19/512
# 539/539 - 2s - loss: 0.0095 - val_loss: 0.0035 - 2s/epoch - 5ms/step
# Epoch 20/512
# 539/539 - 2s - loss: 0.0082 - val_loss: 0.0024 - 2s/epoch - 5ms/step
# Epoch 21/512
# 539/539 - 2s - loss: 0.0073 - val_loss: 0.0017 - 2s/epoch - 4ms/step
# Epoch 22/512
# 539/539 - 2s - loss: 0.0067 - val_loss: 0.0014 - 2s/epoch - 4ms/step
# Epoch 23/512
# 539/539 - 2s - loss: 0.0063 - val_loss: 0.0012 - 2s/epoch - 5ms/step
# Epoch 24/512
# 539/539 - 2s - loss: 0.0061 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 25/512
# 539/539 - 2s - loss: 0.0060 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 26/512
# 539/539 - 2s - loss: 0.0059 - val_loss: 0.0011 - 2s/epoch - 5ms/step
# Epoch 27/512
# 539/539 - 3s - loss: 0.0058 - val_loss: 0.0011 - 3s/epoch - 5ms/step
# Epoch 28/512
# 539/539 - 2s - loss: 0.0057 - val_loss: 0.0011 - 2s/epoch - 5ms/step
# Epoch 29/512
# 539/539 - 2s - loss: 0.0056 - val_loss: 0.0011 - 2s/epoch - 5ms/step
# Epoch 30/512
# 539/539 - 2s - loss: 0.0055 - val_loss: 0.0011 - 2s/epoch - 5ms/step
# Epoch 31/512
# 539/539 - 2s - loss: 0.0054 - val_loss: 0.0011 - 2s/epoch - 5ms/step
# Epoch 32/512
# 539/539 - 2s - loss: 0.0053 - val_loss: 0.0011 - 2s/epoch - 5ms/step
# Epoch 33/512
# 539/539 - 2s - loss: 0.0052 - val_loss: 0.0011 - 2s/epoch - 5ms/step
# Epoch 34/512
# 539/539 - 3s - loss: 0.0050 - val_loss: 0.0011 - 3s/epoch - 5ms/step
# Epoch 35/512
# 539/539 - 2s - loss: 0.0049 - val_loss: 0.0011 - 2s/epoch - 5ms/step
# Epoch 36/512
# 539/539 - 2s - loss: 0.0048 - val_loss: 0.0011 - 2s/epoch - 5ms/step
# Epoch 37/512
# 539/539 - 2s - loss: 0.0046 - val_loss: 0.0010 - 2s/epoch - 5ms/step
# Epoch 38/512
# 539/539 - 2s - loss: 0.0045 - val_loss: 0.0010 - 2s/epoch - 5ms/step
# Epoch 39/512
# 539/539 - 3s - loss: 0.0044 - val_loss: 0.0010 - 3s/epoch - 5ms/step
# Epoch 40/512
# 539/539 - 2s - loss: 0.0043 - val_loss: 0.0010 - 2s/epoch - 5ms/step
# Epoch 41/512
# 539/539 - 3s - loss: 0.0042 - val_loss: 0.0010 - 3s/epoch - 5ms/step
# Epoch 42/512
# 539/539 - 2s - loss: 0.0040 - val_loss: 0.0010 - 2s/epoch - 5ms/step
# Epoch 43/512
# 539/539 - 2s - loss: 0.0039 - val_loss: 0.0010 - 2s/epoch - 5ms/step
# Epoch 44/512
# 539/539 - 2s - loss: 0.0038 - val_loss: 0.0010 - 2s/epoch - 5ms/step
# Epoch 45/512
# 539/539 - 2s - loss: 0.0037 - val_loss: 9.9640e-04 - 2s/epoch - 5ms/step
# Epoch 46/512
# 539/539 - 2s - loss: 0.0036 - val_loss: 9.8988e-04 - 2s/epoch - 5ms/step
# Epoch 47/512
# 539/539 - 2s - loss: 0.0035 - val_loss: 9.8398e-04 - 2s/epoch - 5ms/step
# Epoch 48/512
# 539/539 - 2s - loss: 0.0034 - val_loss: 9.7783e-04 - 2s/epoch - 5ms/step
# Epoch 49/512
# 539/539 - 2s - loss: 0.0033 - val_loss: 9.7194e-04 - 2s/epoch - 5ms/step
# Epoch 50/512
# 539/539 - 2s - loss: 0.0032 - val_loss: 9.6564e-04 - 2s/epoch - 5ms/step
# Epoch 51/512
# 539/539 - 2s - loss: 0.0031 - val_loss: 9.5953e-04 - 2s/epoch - 5ms/step
# Epoch 52/512
# 539/539 - 2s - loss: 0.0031 - val_loss: 9.5389e-04 - 2s/epoch - 5ms/step
# Epoch 53/512
# 539/539 - 2s - loss: 0.0030 - val_loss: 9.4703e-04 - 2s/epoch - 5ms/step
# Epoch 54/512
# 539/539 - 2s - loss: 0.0029 - val_loss: 9.4119e-04 - 2s/epoch - 5ms/step
# Epoch 55/512
# 539/539 - 2s - loss: 0.0028 - val_loss: 9.3542e-04 - 2s/epoch - 5ms/step
# Epoch 56/512
# 539/539 - 3s - loss: 0.0027 - val_loss: 9.2916e-04 - 3s/epoch - 5ms/step
# Epoch 57/512
# 539/539 - 2s - loss: 0.0027 - val_loss: 9.2333e-04 - 2s/epoch - 5ms/step
# Epoch 58/512
# 539/539 - 2s - loss: 0.0026 - val_loss: 9.1725e-04 - 2s/epoch - 5ms/step
# Epoch 59/512
# 539/539 - 2s - loss: 0.0025 - val_loss: 9.1135e-04 - 2s/epoch - 4ms/step
# Epoch 60/512
# 539/539 - 2s - loss: 0.0024 - val_loss: 9.0566e-04 - 2s/epoch - 5ms/step
# Epoch 61/512
# 539/539 - 2s - loss: 0.0024 - val_loss: 8.9998e-04 - 2s/epoch - 5ms/step
# Epoch 62/512
# 539/539 - 3s - loss: 0.0023 - val_loss: 8.9401e-04 - 3s/epoch - 5ms/step
# Epoch 63/512
# 539/539 - 2s - loss: 0.0022 - val_loss: 8.8814e-04 - 2s/epoch - 5ms/step
# Epoch 64/512
# 539/539 - 2s - loss: 0.0022 - val_loss: 8.8241e-04 - 2s/epoch - 5ms/step
# Epoch 65/512
# 539/539 - 2s - loss: 0.0021 - val_loss: 8.7683e-04 - 2s/epoch - 5ms/step
# Epoch 66/512
# 539/539 - 2s - loss: 0.0021 - val_loss: 8.7120e-04 - 2s/epoch - 5ms/step
# Epoch 67/512
# 539/539 - 2s - loss: 0.0020 - val_loss: 8.6574e-04 - 2s/epoch - 5ms/step
# Epoch 68/512
# 539/539 - 2s - loss: 0.0020 - val_loss: 8.6029e-04 - 2s/epoch - 5ms/step
# Epoch 69/512
# 539/539 - 2s - loss: 0.0019 - val_loss: 8.5508e-04 - 2s/epoch - 5ms/step
# Epoch 70/512
# 539/539 - 2s - loss: 0.0019 - val_loss: 8.4951e-04 - 2s/epoch - 5ms/step
# Epoch 71/512
# 539/539 - 2s - loss: 0.0018 - val_loss: 8.4423e-04 - 2s/epoch - 5ms/step
# Epoch 72/512
# 539/539 - 2s - loss: 0.0018 - val_loss: 8.3890e-04 - 2s/epoch - 5ms/step
# Epoch 73/512
# 539/539 - 2s - loss: 0.0017 - val_loss: 8.3381e-04 - 2s/epoch - 5ms/step
# Epoch 74/512
# 539/539 - 2s - loss: 0.0017 - val_loss: 8.2881e-04 - 2s/epoch - 5ms/step
# Epoch 75/512
# 539/539 - 2s - loss: 0.0016 - val_loss: 8.2340e-04 - 2s/epoch - 5ms/step
# Epoch 76/512
# 539/539 - 2s - loss: 0.0016 - val_loss: 8.1836e-04 - 2s/epoch - 5ms/step
# Epoch 77/512
# 539/539 - 2s - loss: 0.0016 - val_loss: 8.1337e-04 - 2s/epoch - 5ms/step
# Epoch 78/512
# 539/539 - 2s - loss: 0.0015 - val_loss: 8.0840e-04 - 2s/epoch - 5ms/step
# Epoch 79/512
# 539/539 - 2s - loss: 0.0015 - val_loss: 8.0336e-04 - 2s/epoch - 5ms/step
# Epoch 80/512
# 539/539 - 2s - loss: 0.0015 - val_loss: 7.9846e-04 - 2s/epoch - 5ms/step
# Epoch 81/512
# 539/539 - 2s - loss: 0.0014 - val_loss: 7.9371e-04 - 2s/epoch - 5ms/step
# Epoch 82/512
# 539/539 - 2s - loss: 0.0014 - val_loss: 7.8877e-04 - 2s/epoch - 5ms/step
# Epoch 83/512
# 539/539 - 2s - loss: 0.0014 - val_loss: 7.8397e-04 - 2s/epoch - 5ms/step
# Epoch 84/512
# 539/539 - 2s - loss: 0.0013 - val_loss: 7.7928e-04 - 2s/epoch - 5ms/step
# Epoch 85/512
# 539/539 - 2s - loss: 0.0013 - val_loss: 7.7444e-04 - 2s/epoch - 4ms/step
# Epoch 86/512
# 539/539 - 2s - loss: 0.0013 - val_loss: 7.6968e-04 - 2s/epoch - 5ms/step
# Epoch 87/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 7.6505e-04 - 2s/epoch - 5ms/step
# Epoch 88/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 7.6042e-04 - 2s/epoch - 5ms/step
# Epoch 89/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 7.5583e-04 - 2s/epoch - 4ms/step
# Epoch 90/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 7.5127e-04 - 2s/epoch - 5ms/step
# Epoch 91/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 7.4659e-04 - 2s/epoch - 5ms/step
# Epoch 92/512
# 539/539 - 3s - loss: 0.0011 - val_loss: 7.4228e-04 - 3s/epoch - 5ms/step
# Epoch 93/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 7.3764e-04 - 2s/epoch - 5ms/step
# Epoch 94/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 7.3333e-04 - 2s/epoch - 5ms/step
# Epoch 95/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 7.2880e-04 - 2s/epoch - 5ms/step
# Epoch 96/512
# 539/539 - 2s - loss: 0.0010 - val_loss: 7.2434e-04 - 2s/epoch - 5ms/step
# Epoch 97/512
# 539/539 - 2s - loss: 0.0010 - val_loss: 7.1994e-04 - 2s/epoch - 5ms/step
# Epoch 98/512
# 539/539 - 2s - loss: 9.9638e-04 - val_loss: 7.1577e-04 - 2s/epoch - 5ms/step
# Epoch 99/512
# 539/539 - 2s - loss: 9.7744e-04 - val_loss: 7.1138e-04 - 2s/epoch - 4ms/step
# Epoch 100/512
# 539/539 - 2s - loss: 9.5964e-04 - val_loss: 7.0710e-04 - 2s/epoch - 4ms/step
# Epoch 101/512
# 539/539 - 2s - loss: 9.4304e-04 - val_loss: 7.0280e-04 - 2s/epoch - 5ms/step
# Epoch 102/512
# 539/539 - 2s - loss: 9.2673e-04 - val_loss: 6.9849e-04 - 2s/epoch - 5ms/step
# Epoch 103/512
# 539/539 - 2s - loss: 9.1167e-04 - val_loss: 6.9438e-04 - 2s/epoch - 5ms/step
# Epoch 104/512
# 539/539 - 2s - loss: 8.9693e-04 - val_loss: 6.8998e-04 - 2s/epoch - 5ms/step
# Epoch 105/512
# 539/539 - 2s - loss: 8.8354e-04 - val_loss: 6.8580e-04 - 2s/epoch - 4ms/step
# Epoch 106/512
# 539/539 - 2s - loss: 8.6860e-04 - val_loss: 6.8164e-04 - 2s/epoch - 5ms/step
# Epoch 107/512
# 539/539 - 2s - loss: 8.5563e-04 - val_loss: 6.7746e-04 - 2s/epoch - 5ms/step
# Epoch 108/512
# 539/539 - 2s - loss: 8.4167e-04 - val_loss: 6.7332e-04 - 2s/epoch - 5ms/step
# Epoch 109/512
# 539/539 - 2s - loss: 8.3012e-04 - val_loss: 6.6919e-04 - 2s/epoch - 5ms/step
# Epoch 110/512
# 539/539 - 2s - loss: 8.1659e-04 - val_loss: 6.6500e-04 - 2s/epoch - 5ms/step
# Epoch 111/512
# 539/539 - 2s - loss: 8.0655e-04 - val_loss: 6.6087e-04 - 2s/epoch - 5ms/step
# Epoch 112/512
# 539/539 - 2s - loss: 7.9547e-04 - val_loss: 6.5680e-04 - 2s/epoch - 5ms/step
# Epoch 113/512
# 539/539 - 2s - loss: 7.8340e-04 - val_loss: 6.5281e-04 - 2s/epoch - 5ms/step
# Epoch 114/512
# 539/539 - 2s - loss: 7.7252e-04 - val_loss: 6.4864e-04 - 2s/epoch - 5ms/step
# Epoch 115/512
# 539/539 - 2s - loss: 7.6484e-04 - val_loss: 6.4461e-04 - 2s/epoch - 5ms/step
# Epoch 116/512
# 539/539 - 2s - loss: 7.5501e-04 - val_loss: 6.4056e-04 - 2s/epoch - 5ms/step
# Epoch 117/512
# 539/539 - 2s - loss: 7.4574e-04 - val_loss: 6.3658e-04 - 2s/epoch - 5ms/step
# Epoch 118/512
# 539/539 - 2s - loss: 7.3462e-04 - val_loss: 6.3258e-04 - 2s/epoch - 5ms/step
# Epoch 119/512
# 539/539 - 2s - loss: 7.2738e-04 - val_loss: 6.2860e-04 - 2s/epoch - 5ms/step
# Epoch 120/512
# 539/539 - 2s - loss: 7.1813e-04 - val_loss: 6.2473e-04 - 2s/epoch - 5ms/step
# Epoch 121/512
# 539/539 - 2s - loss: 7.1025e-04 - val_loss: 6.2075e-04 - 2s/epoch - 5ms/step
# Epoch 122/512
# 539/539 - 2s - loss: 7.0344e-04 - val_loss: 6.1691e-04 - 2s/epoch - 5ms/step
# Epoch 123/512
# 539/539 - 2s - loss: 6.9540e-04 - val_loss: 6.1300e-04 - 2s/epoch - 5ms/step
# Epoch 124/512
# 539/539 - 2s - loss: 6.8719e-04 - val_loss: 6.0918e-04 - 2s/epoch - 4ms/step
# Epoch 125/512
# 539/539 - 3s - loss: 6.7985e-04 - val_loss: 6.0541e-04 - 3s/epoch - 5ms/step
# Epoch 126/512
# 539/539 - 3s - loss: 6.7322e-04 - val_loss: 6.0169e-04 - 3s/epoch - 5ms/step
# Epoch 127/512
# 539/539 - 3s - loss: 6.6618e-04 - val_loss: 5.9797e-04 - 3s/epoch - 5ms/step
# Epoch 128/512
# 539/539 - 3s - loss: 6.6092e-04 - val_loss: 5.9431e-04 - 3s/epoch - 5ms/step
# Epoch 129/512
# 539/539 - 3s - loss: 6.5484e-04 - val_loss: 5.9074e-04 - 3s/epoch - 5ms/step
# Epoch 130/512
# 539/539 - 2s - loss: 6.4838e-04 - val_loss: 5.8714e-04 - 2s/epoch - 5ms/step
# Epoch 131/512
# 539/539 - 3s - loss: 6.4335e-04 - val_loss: 5.8364e-04 - 3s/epoch - 5ms/step
# Epoch 132/512
# 539/539 - 2s - loss: 6.3669e-04 - val_loss: 5.8012e-04 - 2s/epoch - 5ms/step
# Epoch 133/512
# 539/539 - 3s - loss: 6.3160e-04 - val_loss: 5.7669e-04 - 3s/epoch - 5ms/step
# Epoch 134/512
# 539/539 - 2s - loss: 6.2725e-04 - val_loss: 5.7327e-04 - 2s/epoch - 5ms/step
# Epoch 135/512
# 539/539 - 3s - loss: 6.2009e-04 - val_loss: 5.6992e-04 - 3s/epoch - 5ms/step
# Epoch 136/512
# 539/539 - 3s - loss: 6.1589e-04 - val_loss: 5.6657e-04 - 3s/epoch - 5ms/step
# Epoch 137/512
# 539/539 - 2s - loss: 6.1112e-04 - val_loss: 5.6327e-04 - 2s/epoch - 4ms/step
# Epoch 138/512
# 539/539 - 2s - loss: 6.0857e-04 - val_loss: 5.6001e-04 - 2s/epoch - 5ms/step
# Epoch 139/512
# 539/539 - 3s - loss: 6.0205e-04 - val_loss: 5.5677e-04 - 3s/epoch - 5ms/step
# Epoch 140/512
# 539/539 - 3s - loss: 5.9756e-04 - val_loss: 5.5367e-04 - 3s/epoch - 5ms/step
# Epoch 141/512
# 539/539 - 3s - loss: 5.9377e-04 - val_loss: 5.5047e-04 - 3s/epoch - 5ms/step
# Epoch 142/512
# 539/539 - 3s - loss: 5.9003e-04 - val_loss: 5.4736e-04 - 3s/epoch - 5ms/step
# Epoch 143/512
# 539/539 - 2s - loss: 5.8651e-04 - val_loss: 5.4431e-04 - 2s/epoch - 5ms/step
# Epoch 144/512
# 539/539 - 3s - loss: 5.8134e-04 - val_loss: 5.4132e-04 - 3s/epoch - 5ms/step
# Epoch 145/512
# 539/539 - 2s - loss: 5.7833e-04 - val_loss: 5.3836e-04 - 2s/epoch - 5ms/step
# Epoch 146/512
# 539/539 - 3s - loss: 5.7483e-04 - val_loss: 5.3550e-04 - 3s/epoch - 5ms/step
# Epoch 147/512
# 539/539 - 2s - loss: 5.7104e-04 - val_loss: 5.3269e-04 - 2s/epoch - 5ms/step
# Epoch 148/512
# 539/539 - 3s - loss: 5.6874e-04 - val_loss: 5.2991e-04 - 3s/epoch - 5ms/step
# Epoch 149/512
# 539/539 - 3s - loss: 5.6401e-04 - val_loss: 5.2717e-04 - 3s/epoch - 5ms/step
# Epoch 150/512
# 539/539 - 3s - loss: 5.6157e-04 - val_loss: 5.2447e-04 - 3s/epoch - 5ms/step
# Epoch 151/512
# 539/539 - 2s - loss: 5.5785e-04 - val_loss: 5.2182e-04 - 2s/epoch - 5ms/step
# Epoch 152/512
# 539/539 - 3s - loss: 5.5496e-04 - val_loss: 5.1919e-04 - 3s/epoch - 5ms/step
# Epoch 153/512
# 539/539 - 3s - loss: 5.5181e-04 - val_loss: 5.1661e-04 - 3s/epoch - 5ms/step
# Epoch 154/512
# 539/539 - 3s - loss: 5.4856e-04 - val_loss: 5.1410e-04 - 3s/epoch - 5ms/step
# Epoch 155/512
# 539/539 - 3s - loss: 5.4687e-04 - val_loss: 5.1165e-04 - 3s/epoch - 5ms/step
# Epoch 156/512
# 539/539 - 3s - loss: 5.4320e-04 - val_loss: 5.0925e-04 - 3s/epoch - 5ms/step
# Epoch 157/512
# 539/539 - 3s - loss: 5.4098e-04 - val_loss: 5.0688e-04 - 3s/epoch - 5ms/step
# Epoch 158/512
# 539/539 - 3s - loss: 5.3915e-04 - val_loss: 5.0459e-04 - 3s/epoch - 5ms/step
# Epoch 159/512
# 539/539 - 2s - loss: 5.3639e-04 - val_loss: 5.0233e-04 - 2s/epoch - 5ms/step
# Epoch 160/512
# 539/539 - 2s - loss: 5.3424e-04 - val_loss: 5.0014e-04 - 2s/epoch - 5ms/step
# Epoch 161/512
# 539/539 - 2s - loss: 5.3162e-04 - val_loss: 4.9798e-04 - 2s/epoch - 5ms/step
# Epoch 162/512
# 539/539 - 3s - loss: 5.2935e-04 - val_loss: 4.9583e-04 - 3s/epoch - 5ms/step
# Epoch 163/512
# 539/539 - 3s - loss: 5.2716e-04 - val_loss: 4.9373e-04 - 3s/epoch - 5ms/step
# Epoch 164/512
# 539/539 - 2s - loss: 5.2513e-04 - val_loss: 4.9171e-04 - 2s/epoch - 5ms/step
# Epoch 165/512
# 539/539 - 3s - loss: 5.2288e-04 - val_loss: 4.8971e-04 - 3s/epoch - 5ms/step
# Epoch 166/512
# 539/539 - 3s - loss: 5.1955e-04 - val_loss: 4.8775e-04 - 3s/epoch - 5ms/step
# Epoch 167/512
# 539/539 - 3s - loss: 5.1817e-04 - val_loss: 4.8584e-04 - 3s/epoch - 5ms/step
# Epoch 168/512
# 539/539 - 2s - loss: 5.1606e-04 - val_loss: 4.8395e-04 - 2s/epoch - 5ms/step
# Epoch 169/512
# 539/539 - 2s - loss: 5.1441e-04 - val_loss: 4.8214e-04 - 2s/epoch - 5ms/step
# Epoch 170/512
# 539/539 - 3s - loss: 5.1172e-04 - val_loss: 4.8033e-04 - 3s/epoch - 5ms/step
# Epoch 171/512
# 539/539 - 2s - loss: 5.1052e-04 - val_loss: 4.7857e-04 - 2s/epoch - 5ms/step
# Epoch 172/512
# 539/539 - 3s - loss: 5.0886e-04 - val_loss: 4.7687e-04 - 3s/epoch - 5ms/step
# Epoch 173/512
# 539/539 - 2s - loss: 5.0778e-04 - val_loss: 4.7518e-04 - 2s/epoch - 5ms/step
# Epoch 174/512
# 539/539 - 3s - loss: 5.0524e-04 - val_loss: 4.7356e-04 - 3s/epoch - 5ms/step
# Epoch 175/512
# 539/539 - 3s - loss: 5.0414e-04 - val_loss: 4.7196e-04 - 3s/epoch - 5ms/step
# Epoch 176/512
# 539/539 - 3s - loss: 5.0137e-04 - val_loss: 4.7039e-04 - 3s/epoch - 5ms/step
# Epoch 177/512
# 539/539 - 3s - loss: 4.9998e-04 - val_loss: 4.6886e-04 - 3s/epoch - 5ms/step
# Epoch 178/512
# 539/539 - 2s - loss: 4.9869e-04 - val_loss: 4.6736e-04 - 2s/epoch - 5ms/step
# Epoch 179/512
# 539/539 - 2s - loss: 4.9764e-04 - val_loss: 4.6593e-04 - 2s/epoch - 5ms/step
# Epoch 180/512
# 539/539 - 2s - loss: 4.9633e-04 - val_loss: 4.6454e-04 - 2s/epoch - 5ms/step
# Epoch 181/512
# 539/539 - 2s - loss: 4.9457e-04 - val_loss: 4.6318e-04 - 2s/epoch - 5ms/step
# Epoch 182/512
# 539/539 - 2s - loss: 4.9362e-04 - val_loss: 4.6182e-04 - 2s/epoch - 5ms/step
# Epoch 183/512
# 539/539 - 2s - loss: 4.9175e-04 - val_loss: 4.6050e-04 - 2s/epoch - 4ms/step
# Epoch 184/512
# 539/539 - 2s - loss: 4.9093e-04 - val_loss: 4.5921e-04 - 2s/epoch - 5ms/step
# Epoch 185/512
# 539/539 - 3s - loss: 4.8876e-04 - val_loss: 4.5797e-04 - 3s/epoch - 5ms/step
# Epoch 186/512
# 539/539 - 3s - loss: 4.8814e-04 - val_loss: 4.5674e-04 - 3s/epoch - 5ms/step
# Epoch 187/512
# 539/539 - 3s - loss: 4.8637e-04 - val_loss: 4.5556e-04 - 3s/epoch - 5ms/step
# Epoch 188/512
# 539/539 - 2s - loss: 4.8516e-04 - val_loss: 4.5440e-04 - 2s/epoch - 5ms/step
# Epoch 189/512
# 539/539 - 2s - loss: 4.8475e-04 - val_loss: 4.5324e-04 - 2s/epoch - 5ms/step
# Epoch 190/512
# 539/539 - 3s - loss: 4.8253e-04 - val_loss: 4.5212e-04 - 3s/epoch - 5ms/step
# Epoch 191/512
# 539/539 - 2s - loss: 4.8131e-04 - val_loss: 4.5103e-04 - 2s/epoch - 5ms/step
# Epoch 192/512
# 539/539 - 3s - loss: 4.8008e-04 - val_loss: 4.4996e-04 - 3s/epoch - 5ms/step
# Epoch 193/512
# 539/539 - 2s - loss: 4.7925e-04 - val_loss: 4.4893e-04 - 2s/epoch - 5ms/step
# Epoch 194/512
# 539/539 - 2s - loss: 4.7906e-04 - val_loss: 4.4792e-04 - 2s/epoch - 5ms/step
# Epoch 195/512
# 539/539 - 2s - loss: 4.7811e-04 - val_loss: 4.4693e-04 - 2s/epoch - 5ms/step
# Epoch 196/512
# 539/539 - 3s - loss: 4.7659e-04 - val_loss: 4.4598e-04 - 3s/epoch - 5ms/step
# Epoch 197/512
# 539/539 - 2s - loss: 4.7534e-04 - val_loss: 4.4506e-04 - 2s/epoch - 5ms/step
# Epoch 198/512
# 539/539 - 3s - loss: 4.7445e-04 - val_loss: 4.4415e-04 - 3s/epoch - 5ms/step
# Epoch 199/512
# 539/539 - 3s - loss: 4.7381e-04 - val_loss: 4.4323e-04 - 3s/epoch - 5ms/step
# Epoch 200/512
# 539/539 - 2s - loss: 4.7327e-04 - val_loss: 4.4234e-04 - 2s/epoch - 5ms/step
# Epoch 201/512
# 539/539 - 2s - loss: 4.7199e-04 - val_loss: 4.4147e-04 - 2s/epoch - 5ms/step
# Epoch 202/512
# 539/539 - 2s - loss: 4.7032e-04 - val_loss: 4.4063e-04 - 2s/epoch - 5ms/step
# Epoch 203/512
# 539/539 - 2s - loss: 4.7061e-04 - val_loss: 4.3982e-04 - 2s/epoch - 5ms/step
# Epoch 204/512
# 539/539 - 3s - loss: 4.7025e-04 - val_loss: 4.3902e-04 - 3s/epoch - 5ms/step
# Epoch 205/512
# 539/539 - 2s - loss: 4.6835e-04 - val_loss: 4.3828e-04 - 2s/epoch - 5ms/step
# Epoch 206/512
# 539/539 - 2s - loss: 4.6773e-04 - val_loss: 4.3749e-04 - 2s/epoch - 5ms/step
# Epoch 207/512
# 539/539 - 2s - loss: 4.6677e-04 - val_loss: 4.3675e-04 - 2s/epoch - 5ms/step
# Epoch 208/512
# 539/539 - 2s - loss: 4.6680e-04 - val_loss: 4.3601e-04 - 2s/epoch - 4ms/step
# Epoch 209/512
# 539/539 - 2s - loss: 4.6566e-04 - val_loss: 4.3529e-04 - 2s/epoch - 5ms/step
# Epoch 210/512
# 539/539 - 2s - loss: 4.6471e-04 - val_loss: 4.3461e-04 - 2s/epoch - 5ms/step
# Epoch 211/512
# 539/539 - 2s - loss: 4.6434e-04 - val_loss: 4.3389e-04 - 2s/epoch - 5ms/step
# Epoch 212/512
# 539/539 - 3s - loss: 4.6390e-04 - val_loss: 4.3323e-04 - 3s/epoch - 5ms/step
# Epoch 213/512
# 539/539 - 2s - loss: 4.6302e-04 - val_loss: 4.3258e-04 - 2s/epoch - 4ms/step
# Epoch 214/512
# 539/539 - 3s - loss: 4.6266e-04 - val_loss: 4.3195e-04 - 3s/epoch - 5ms/step
# Epoch 215/512
# 539/539 - 2s - loss: 4.6167e-04 - val_loss: 4.3133e-04 - 2s/epoch - 5ms/step
# Epoch 216/512
# 539/539 - 3s - loss: 4.6058e-04 - val_loss: 4.3072e-04 - 3s/epoch - 5ms/step
# Epoch 217/512
# 539/539 - 3s - loss: 4.6070e-04 - val_loss: 4.3012e-04 - 3s/epoch - 5ms/step
# Epoch 218/512
# 539/539 - 2s - loss: 4.5895e-04 - val_loss: 4.2955e-04 - 2s/epoch - 5ms/step
# Epoch 219/512
# 539/539 - 3s - loss: 4.5868e-04 - val_loss: 4.2896e-04 - 3s/epoch - 5ms/step
# Epoch 220/512
# 539/539 - 3s - loss: 4.5871e-04 - val_loss: 4.2840e-04 - 3s/epoch - 5ms/step
# Epoch 221/512
# 539/539 - 3s - loss: 4.5793e-04 - val_loss: 4.2784e-04 - 3s/epoch - 5ms/step
# Epoch 222/512
# 539/539 - 2s - loss: 4.5850e-04 - val_loss: 4.2730e-04 - 2s/epoch - 4ms/step
# Epoch 223/512
# 539/539 - 3s - loss: 4.5590e-04 - val_loss: 4.2677e-04 - 3s/epoch - 5ms/step
# Epoch 224/512
# 539/539 - 2s - loss: 4.5577e-04 - val_loss: 4.2625e-04 - 2s/epoch - 5ms/step
# Epoch 225/512
# 539/539 - 2s - loss: 4.5566e-04 - val_loss: 4.2574e-04 - 2s/epoch - 5ms/step
# Epoch 226/512
# 539/539 - 2s - loss: 4.5564e-04 - val_loss: 4.2523e-04 - 2s/epoch - 5ms/step
# Epoch 227/512
# 539/539 - 3s - loss: 4.5413e-04 - val_loss: 4.2474e-04 - 3s/epoch - 5ms/step
# Epoch 228/512
# 539/539 - 2s - loss: 4.5450e-04 - val_loss: 4.2427e-04 - 2s/epoch - 5ms/step
# Epoch 229/512
# 539/539 - 2s - loss: 4.5354e-04 - val_loss: 4.2380e-04 - 2s/epoch - 5ms/step
# Epoch 230/512
# 539/539 - 3s - loss: 4.5355e-04 - val_loss: 4.2337e-04 - 3s/epoch - 5ms/step
# Epoch 231/512
# 539/539 - 2s - loss: 4.5280e-04 - val_loss: 4.2287e-04 - 2s/epoch - 5ms/step
# Epoch 232/512
# 539/539 - 2s - loss: 4.5279e-04 - val_loss: 4.2243e-04 - 2s/epoch - 5ms/step
# Epoch 233/512
# 539/539 - 2s - loss: 4.5157e-04 - val_loss: 4.2198e-04 - 2s/epoch - 5ms/step
# Epoch 234/512
# 539/539 - 2s - loss: 4.5173e-04 - val_loss: 4.2155e-04 - 2s/epoch - 5ms/step
# Epoch 235/512
# 539/539 - 2s - loss: 4.5139e-04 - val_loss: 4.2117e-04 - 2s/epoch - 5ms/step
# Epoch 236/512
# 539/539 - 2s - loss: 4.5065e-04 - val_loss: 4.2072e-04 - 2s/epoch - 5ms/step
# Epoch 237/512
# 539/539 - 2s - loss: 4.5047e-04 - val_loss: 4.2032e-04 - 2s/epoch - 5ms/step
# Epoch 238/512
# 539/539 - 3s - loss: 4.4982e-04 - val_loss: 4.1992e-04 - 3s/epoch - 5ms/step
# Epoch 239/512
# 539/539 - 3s - loss: 4.4944e-04 - val_loss: 4.1954e-04 - 3s/epoch - 5ms/step
# Epoch 240/512
# 539/539 - 3s - loss: 4.4934e-04 - val_loss: 4.1915e-04 - 3s/epoch - 5ms/step
# Epoch 241/512
# 539/539 - 2s - loss: 4.4904e-04 - val_loss: 4.1878e-04 - 2s/epoch - 5ms/step
# Epoch 242/512
# 539/539 - 2s - loss: 4.4888e-04 - val_loss: 4.1841e-04 - 2s/epoch - 5ms/step
# Epoch 243/512
# 539/539 - 2s - loss: 4.4805e-04 - val_loss: 4.1805e-04 - 2s/epoch - 5ms/step
# Epoch 244/512
# 539/539 - 2s - loss: 4.4791e-04 - val_loss: 4.1769e-04 - 2s/epoch - 4ms/step
# Epoch 245/512
# 539/539 - 3s - loss: 4.4790e-04 - val_loss: 4.1735e-04 - 3s/epoch - 5ms/step
# Epoch 246/512
# 539/539 - 2s - loss: 4.4637e-04 - val_loss: 4.1704e-04 - 2s/epoch - 5ms/step
# Epoch 247/512
# 539/539 - 3s - loss: 4.4664e-04 - val_loss: 4.1669e-04 - 3s/epoch - 5ms/step
# Epoch 248/512
# 539/539 - 2s - loss: 4.4718e-04 - val_loss: 4.1635e-04 - 2s/epoch - 4ms/step
# Epoch 249/512
# 539/539 - 2s - loss: 4.4589e-04 - val_loss: 4.1603e-04 - 2s/epoch - 5ms/step
# Epoch 250/512
# 539/539 - 2s - loss: 4.4597e-04 - val_loss: 4.1572e-04 - 2s/epoch - 5ms/step
# Epoch 251/512
# 539/539 - 3s - loss: 4.4497e-04 - val_loss: 4.1540e-04 - 3s/epoch - 5ms/step
# Epoch 252/512
# 539/539 - 2s - loss: 4.4479e-04 - val_loss: 4.1510e-04 - 2s/epoch - 5ms/step
# Epoch 253/512
# 539/539 - 2s - loss: 4.4464e-04 - val_loss: 4.1480e-04 - 2s/epoch - 5ms/step
# Epoch 254/512
# 539/539 - 2s - loss: 4.4438e-04 - val_loss: 4.1452e-04 - 2s/epoch - 5ms/step
# Epoch 255/512
# 539/539 - 2s - loss: 4.4336e-04 - val_loss: 4.1422e-04 - 2s/epoch - 5ms/step
# Epoch 256/512
# 539/539 - 3s - loss: 4.4384e-04 - val_loss: 4.1396e-04 - 3s/epoch - 5ms/step
# Epoch 257/512
# 539/539 - 2s - loss: 4.4345e-04 - val_loss: 4.1368e-04 - 2s/epoch - 5ms/step
# Epoch 258/512
# 539/539 - 3s - loss: 4.4228e-04 - val_loss: 4.1339e-04 - 3s/epoch - 5ms/step
# Epoch 259/512
# 539/539 - 2s - loss: 4.4281e-04 - val_loss: 4.1313e-04 - 2s/epoch - 4ms/step
# Epoch 260/512
# 539/539 - 2s - loss: 4.4205e-04 - val_loss: 4.1287e-04 - 2s/epoch - 5ms/step
# Epoch 261/512
# 539/539 - 2s - loss: 4.4212e-04 - val_loss: 4.1265e-04 - 2s/epoch - 5ms/step
# Epoch 262/512
# 539/539 - 2s - loss: 4.4186e-04 - val_loss: 4.1236e-04 - 2s/epoch - 5ms/step
# Epoch 263/512
# 539/539 - 2s - loss: 4.4153e-04 - val_loss: 4.1211e-04 - 2s/epoch - 5ms/step
# Epoch 264/512
# 539/539 - 2s - loss: 4.4097e-04 - val_loss: 4.1189e-04 - 2s/epoch - 5ms/step
# Epoch 265/512
# 539/539 - 2s - loss: 4.4079e-04 - val_loss: 4.1163e-04 - 2s/epoch - 5ms/step
# Epoch 266/512
# 539/539 - 2s - loss: 4.4035e-04 - val_loss: 4.1140e-04 - 2s/epoch - 5ms/step
# Epoch 267/512
# 539/539 - 3s - loss: 4.4039e-04 - val_loss: 4.1117e-04 - 3s/epoch - 5ms/step
# Epoch 268/512
# 539/539 - 2s - loss: 4.3976e-04 - val_loss: 4.1093e-04 - 2s/epoch - 4ms/step
# Epoch 269/512
# 539/539 - 2s - loss: 4.3964e-04 - val_loss: 4.1070e-04 - 2s/epoch - 5ms/step
# Epoch 270/512
# 539/539 - 3s - loss: 4.3945e-04 - val_loss: 4.1049e-04 - 3s/epoch - 5ms/step
# Epoch 271/512
# 539/539 - 2s - loss: 4.4058e-04 - val_loss: 4.1026e-04 - 2s/epoch - 4ms/step
# Epoch 272/512
# 539/539 - 2s - loss: 4.4025e-04 - val_loss: 4.1005e-04 - 2s/epoch - 4ms/step
# Epoch 273/512
# 539/539 - 2s - loss: 4.3938e-04 - val_loss: 4.0985e-04 - 2s/epoch - 5ms/step
# Epoch 274/512
# 539/539 - 2s - loss: 4.3838e-04 - val_loss: 4.0965e-04 - 2s/epoch - 5ms/step
# Epoch 275/512
# 539/539 - 2s - loss: 4.3812e-04 - val_loss: 4.0944e-04 - 2s/epoch - 5ms/step
# Epoch 276/512
# 539/539 - 2s - loss: 4.3823e-04 - val_loss: 4.0924e-04 - 2s/epoch - 5ms/step
# Epoch 277/512
# 539/539 - 2s - loss: 4.3905e-04 - val_loss: 4.0906e-04 - 2s/epoch - 4ms/step
# Epoch 278/512
# 539/539 - 2s - loss: 4.3783e-04 - val_loss: 4.0885e-04 - 2s/epoch - 5ms/step
# Epoch 279/512
# 539/539 - 2s - loss: 4.3776e-04 - val_loss: 4.0867e-04 - 2s/epoch - 4ms/step
# Epoch 280/512
# 539/539 - 2s - loss: 4.3726e-04 - val_loss: 4.0848e-04 - 2s/epoch - 5ms/step
# Epoch 281/512
# 539/539 - 2s - loss: 4.3715e-04 - val_loss: 4.0830e-04 - 2s/epoch - 4ms/step
# Epoch 282/512
# 539/539 - 2s - loss: 4.3766e-04 - val_loss: 4.0812e-04 - 2s/epoch - 5ms/step
# Epoch 283/512
# 539/539 - 2s - loss: 4.3773e-04 - val_loss: 4.0795e-04 - 2s/epoch - 5ms/step
# Epoch 284/512
# 539/539 - 2s - loss: 4.3670e-04 - val_loss: 4.0777e-04 - 2s/epoch - 5ms/step
# Epoch 285/512
# 539/539 - 2s - loss: 4.3643e-04 - val_loss: 4.0760e-04 - 2s/epoch - 5ms/step
# Epoch 286/512
# 539/539 - 3s - loss: 4.3637e-04 - val_loss: 4.0743e-04 - 3s/epoch - 5ms/step
# Epoch 287/512
# 539/539 - 2s - loss: 4.3569e-04 - val_loss: 4.0725e-04 - 2s/epoch - 5ms/step
# Epoch 288/512
# 539/539 - 2s - loss: 4.3609e-04 - val_loss: 4.0709e-04 - 2s/epoch - 5ms/step
# Epoch 289/512
# 539/539 - 2s - loss: 4.3600e-04 - val_loss: 4.0694e-04 - 2s/epoch - 5ms/step
# Epoch 290/512
# 539/539 - 2s - loss: 4.3609e-04 - val_loss: 4.0677e-04 - 2s/epoch - 5ms/step
# Epoch 291/512
# 539/539 - 2s - loss: 4.3624e-04 - val_loss: 4.0661e-04 - 2s/epoch - 5ms/step
# Epoch 292/512
# 539/539 - 2s - loss: 4.3510e-04 - val_loss: 4.0646e-04 - 2s/epoch - 5ms/step
# Epoch 293/512
# 539/539 - 2s - loss: 4.3485e-04 - val_loss: 4.0631e-04 - 2s/epoch - 5ms/step
# Epoch 294/512
# 539/539 - 2s - loss: 4.3560e-04 - val_loss: 4.0617e-04 - 2s/epoch - 4ms/step
# Epoch 295/512
# 539/539 - 3s - loss: 4.3523e-04 - val_loss: 4.0602e-04 - 3s/epoch - 5ms/step
# Epoch 296/512
# 539/539 - 2s - loss: 4.3485e-04 - val_loss: 4.0587e-04 - 2s/epoch - 5ms/step
# Epoch 297/512
# 539/539 - 2s - loss: 4.3509e-04 - val_loss: 4.0573e-04 - 2s/epoch - 5ms/step
# Epoch 298/512
# 539/539 - 2s - loss: 4.3442e-04 - val_loss: 4.0559e-04 - 2s/epoch - 5ms/step
# Epoch 299/512
# 539/539 - 2s - loss: 4.3450e-04 - val_loss: 4.0545e-04 - 2s/epoch - 5ms/step
# Epoch 300/512
# 539/539 - 2s - loss: 4.3411e-04 - val_loss: 4.0532e-04 - 2s/epoch - 5ms/step
# Epoch 301/512
# 539/539 - 2s - loss: 4.3475e-04 - val_loss: 4.0517e-04 - 2s/epoch - 4ms/step
# Epoch 302/512
# 539/539 - 2s - loss: 4.3321e-04 - val_loss: 4.0504e-04 - 2s/epoch - 5ms/step
# Epoch 303/512
# 539/539 - 2s - loss: 4.3421e-04 - val_loss: 4.0490e-04 - 2s/epoch - 5ms/step
# Epoch 304/512
# 539/539 - 3s - loss: 4.3334e-04 - val_loss: 4.0477e-04 - 3s/epoch - 5ms/step
# Epoch 305/512
# 539/539 - 2s - loss: 4.3335e-04 - val_loss: 4.0466e-04 - 2s/epoch - 5ms/step
# Epoch 306/512
# 539/539 - 2s - loss: 4.3262e-04 - val_loss: 4.0452e-04 - 2s/epoch - 5ms/step
# Epoch 307/512
# 539/539 - 2s - loss: 4.3393e-04 - val_loss: 4.0440e-04 - 2s/epoch - 5ms/step
# Epoch 308/512
# 539/539 - 2s - loss: 4.3307e-04 - val_loss: 4.0427e-04 - 2s/epoch - 5ms/step
# Epoch 309/512
# 539/539 - 2s - loss: 4.3230e-04 - val_loss: 4.0415e-04 - 2s/epoch - 5ms/step
# Epoch 310/512
# 539/539 - 2s - loss: 4.3291e-04 - val_loss: 4.0402e-04 - 2s/epoch - 5ms/step
# Epoch 311/512
# 539/539 - 2s - loss: 4.3397e-04 - val_loss: 4.0392e-04 - 2s/epoch - 5ms/step
# Epoch 312/512
# 539/539 - 2s - loss: 4.3171e-04 - val_loss: 4.0379e-04 - 2s/epoch - 5ms/step
# Epoch 313/512
# 539/539 - 2s - loss: 4.3196e-04 - val_loss: 4.0368e-04 - 2s/epoch - 5ms/step
# Epoch 314/512
# 539/539 - 2s - loss: 4.3199e-04 - val_loss: 4.0356e-04 - 2s/epoch - 5ms/step
# Epoch 315/512
# 539/539 - 2s - loss: 4.3186e-04 - val_loss: 4.0347e-04 - 2s/epoch - 5ms/step
# Epoch 316/512
# 539/539 - 2s - loss: 4.3188e-04 - val_loss: 4.0335e-04 - 2s/epoch - 4ms/step
# Epoch 317/512
# 539/539 - 2s - loss: 4.3176e-04 - val_loss: 4.0324e-04 - 2s/epoch - 5ms/step
# Epoch 318/512
# 539/539 - 2s - loss: 4.3124e-04 - val_loss: 4.0313e-04 - 2s/epoch - 5ms/step
# Epoch 319/512
# 539/539 - 3s - loss: 4.3147e-04 - val_loss: 4.0306e-04 - 3s/epoch - 5ms/step
# Epoch 320/512
# 539/539 - 2s - loss: 4.3163e-04 - val_loss: 4.0293e-04 - 2s/epoch - 4ms/step
# Epoch 321/512
# 539/539 - 2s - loss: 4.3071e-04 - val_loss: 4.0281e-04 - 2s/epoch - 5ms/step
# Epoch 322/512
# 539/539 - 3s - loss: 4.3076e-04 - val_loss: 4.0271e-04 - 3s/epoch - 5ms/step
# Epoch 323/512
# 539/539 - 2s - loss: 4.3076e-04 - val_loss: 4.0261e-04 - 2s/epoch - 5ms/step
# Epoch 324/512
# 539/539 - 2s - loss: 4.3133e-04 - val_loss: 4.0251e-04 - 2s/epoch - 5ms/step
# Epoch 325/512
# 539/539 - 3s - loss: 4.3004e-04 - val_loss: 4.0241e-04 - 3s/epoch - 5ms/step
# Epoch 326/512
# 539/539 - 2s - loss: 4.3067e-04 - val_loss: 4.0232e-04 - 2s/epoch - 5ms/step
# Epoch 327/512
# 539/539 - 2s - loss: 4.2992e-04 - val_loss: 4.0222e-04 - 2s/epoch - 5ms/step
# Epoch 328/512
# 539/539 - 2s - loss: 4.3096e-04 - val_loss: 4.0213e-04 - 2s/epoch - 4ms/step
# Epoch 329/512
# 539/539 - 2s - loss: 4.3047e-04 - val_loss: 4.0204e-04 - 2s/epoch - 4ms/step
# Epoch 330/512
# 539/539 - 2s - loss: 4.2992e-04 - val_loss: 4.0194e-04 - 2s/epoch - 5ms/step
# Epoch 331/512
# 539/539 - 2s - loss: 4.2936e-04 - val_loss: 4.0185e-04 - 2s/epoch - 5ms/step
# Epoch 332/512
# 539/539 - 2s - loss: 4.3026e-04 - val_loss: 4.0176e-04 - 2s/epoch - 5ms/step
# Epoch 333/512
# 539/539 - 2s - loss: 4.2958e-04 - val_loss: 4.0167e-04 - 2s/epoch - 5ms/step
# Epoch 334/512
# 539/539 - 3s - loss: 4.2990e-04 - val_loss: 4.0160e-04 - 3s/epoch - 5ms/step
# Epoch 335/512
# 539/539 - 2s - loss: 4.2877e-04 - val_loss: 4.0150e-04 - 2s/epoch - 4ms/step
# Epoch 336/512
# 539/539 - 2s - loss: 4.2919e-04 - val_loss: 4.0140e-04 - 2s/epoch - 5ms/step

# %%
# save model
# model.save("./DNN_pz.h5", save_format="h5", overwrite=True)
# predict
pred_y = model.predict(test_x)
sig_pred = pred_y
sig_truth = test_y
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 12924/12924 [==============================] - 16s 1ms/step

# %%
print(f"Truth mean: {np.mean(sig_truth[:,0]):.3f}, std: {np.std(sig_truth[:,0]):.3f}")
# Out:
# Truth mean: 0.475, std: 0.025

# %%
range = [0.2, 0.75]

plot.plot_hist(
    [sig_truth[:, 0], sig_pred[:, 0]],
    [r"$p_{z\ truth}^{\nu}$", r"$p_{z\ pred}^{\nu}$"],
    r"Sig. norm. $p^{\nu}_{z}$"
    + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth[:,0], sig_pred[:,0])):.3f}",
    range=range,
    xlabel=r"Norm. $p_{z}$ [unit]",
)

plot.plot_loss_history(history, logx=True, logy=True)

plot.plot_2d_histogram(
    sig_truth[:, 0],
    sig_pred[:, 0],
    r"Sig. $p_{z}^{\nu}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth[:,0], sig_pred[:,0])[0]:.3f}",
    range=range,
)

# time_end = time()
# print(f"Time cost: {time_end - time_start:.2f} s")
