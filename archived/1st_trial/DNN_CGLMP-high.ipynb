# %%
# %reset -sf

from time import time
time_start = time()

import pandas as pd
import numpy as np
import scipy as sp
import gc
import os
from matplotlib import pyplot as plt

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import StandardScaler, MinMaxScaler, QuantileTransformer, RobustScaler
from sklearn.model_selection import train_test_split, KFold

import tensorflow as tf

from mt2 import mt2

import get_data as gd
import atlas_plot as ap
plot = ap.Plotter()

print(tf.__version__)
print(tf.config.list_physical_devices())
print()
# Out:
# 2.13.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
seed = 42  # set random seed
sampling = int(5e6)
# num_folds = 2
batch_size = 512
epochs = 512
learning_rate = 1e-4

# %%
np.random.seed(seed)
processor = gd.DataProcessor(sampling=sampling, processor=10)
path = "/root/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 10
#
# ['/root/data/truth/signal/CGLMP.npz', '/root/data/truth/signal/Higgs.npz', '/root/data/truth/signal/LeadLepton.npz', '/root/data/truth/signal/LeptonM.npz', '/root/data/truth/signal/LeptonP.npz', '/root/data/truth/signal/LmNu.npz', '/root/data/truth/signal/LpNu.npz', '/root/data/truth/signal/MET.npz', '/root/data/truth/signal/WmBoson.npz', '/root/data/truth/signal/WpBoson.npz', '/root/data/truth/signal/diLepton.npz', '/root/data/truth/signal/subLeadLepton.npz', '/root/data/truth/signal/xi_xyz.npz']

# %%
GEV = 1e3

cut_pre_pt_lead = data.LeadLep["pt"] > 22 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
cut_pre_pt_miss = data.MET["pt"] > 20 * GEV
cut_pre = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss

del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# %%
# inputs -> observed params
Bxy = processor.process_CGLMP(data.CGLMP)[["Bxy"]]
lep_p = processor.process_part(data.LepP)
lep_m = processor.process_part(data.LepM)
dilep_kin = processor.process_dipart(data.LepP, data.LepM)
MET = processor.process_MET(data.MET)
mt = pd.DataFrame(
    {"mt": np.sqrt(np.sum(np.square(dilep_kin[["m", "px", "py"]]), axis=1))}
)
mT2 = pd.DataFrame(
    {
        "mT2": np.sqrt(
            mt2(
                lep_m["m"],
                lep_m["px"],
                lep_m["py"],  # Visible 1: mass, px, py
                lep_p["m"],
                lep_p["px"],
                lep_p["py"],  # Visible 2: mass, px, py
                MET["MET_px"],
                MET["MET_py"],  # Missing transverse momentum: x, y
                0,
                0,  # Invisible 1 mass, invisible 2 mass
            )
        )
    }
)
pta = pd.DataFrame(
    {
        "pta": np.sqrt(
            np.square(lep_p["pt"])
            + np.square(lep_m["pt"])
            + np.square(MET["MET_px"])
            + np.square(MET["MET_py"])
        )
    }
)
# vx = pd.DataFrame({"vx": mt + 0.3 * np.sqrt(dilep_kin["m"])})
lep_kin_deta = pd.DataFrame({"d_eta": np.abs(lep_p.iloc[:, -2] - lep_m.iloc[:, -2])})
lep_kin = pd.concat(
    [lep_p.iloc[:, :4], lep_m.iloc[:, :4]],
    axis=1,
)

mask = cut_pre

obs_kin = pd.concat(
    [
        MET.iloc[:, 1:3],
        lep_kin,
        pta,
        mt,
    ],
    axis=1,
)[mask]
print("obs_kin shape:", obs_kin.shape)
print(obs_kin.head(3))
print()

# targets -> interested unknowns
int_kin = Bxy[mask]
print("int_kin shape:", int_kin.shape)
print(int_kin.head(3))
print()

# del (processor, lep_p, lep_m, MET, dilep_kin, mt, vx)
# gc.collect()
# Out:
# obs_kin shape: (1378510, 12)
#        MET_px     MET_py           E         px         py          pz  \
# 7   96.335650  47.095450   19.500895  -4.561588  18.924410   -1.154271
# 9  -26.992604 -70.883859  164.814766  34.397141   2.031300 -161.172625
# 10  44.222846 -15.383637   47.669113 -26.605045 -17.256748   35.590859
#
#             E         px         py         pz         pta         mt
# 7   43.361348  42.407754  -4.632000   7.767462  117.035693  62.513416
# 9   70.592648  29.001777   1.896990 -64.332027   88.233289  67.559621
# 10  90.238664 -23.868604  32.986602  80.530680   69.683329  74.393166
#
# int_kin shape: (1378510, 1)
#          Bxy
# 7   -5.57360
# 9   18.68250
# 10   6.54512

# %%
plt.hist(int_kin, bins=300, alpha=.8)
plt.title(r"$B_{xy}$")
plt.xlabel(r"null")
plt.ylabel("count")
plt.show()

# %%
SCALAR_int_ru = RobustScaler()
int_kin = SCALAR_int_ru.fit_transform(int_kin)
# SCALAR_int_mm = MinMaxScaler()
# int_kin = SCALAR_int_mm.fit_transform(int_kin)

SCALAR_obs_ru = RobustScaler()
obs_kin = SCALAR_obs_ru.fit_transform(obs_kin)
# SCALAR_obs_mm = MinMaxScaler()
# obs_kin = SCALAR_obs_mm.fit_transform(obs_kin)

# %%
plt.hist(int_kin, bins=100, alpha=.8)
plt.title(r"$B_{xy}$")
plt.xlabel("null")
plt.ylabel("count")
# plt.xlim([0,0.5])
plt.show()

# %%
indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.4,
    test_size=0.6,
    random_state=seed,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=42
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
print()
# Out:
# X (Interest)
# Training data shape: (551404, 12);
# Validing data shape: (413553, 12);
# Testing data shape: (413553, 12).
# Y (Observed)
# Training data shape: (551404, 1);
# Validing data shape: (413553, 1);
# Testing data shape: (413553, 1).

# %%
# Define a new activation function
def custom_activation(x):
    return x * tf.keras.backend.sigmoid(x)


# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    x = tf.keras.layers.Dense(units=512, activation="elu")(x)
    x = tf.keras.layers.Dense(units=512, activation="elu")(x)
    x = tf.keras.layers.Dense(units=32, activation="elu")(x)
    x = tf.keras.layers.Dense(units=32, activation="elu")(x)
    x = tf.keras.layers.Dense(units=4, activation="elu")(x)
    x = tf.keras.layers.Dense(units=4, activation="elu")(x)

    # Last dense layer
    outputs = tf.keras.layers.Dense(units=train_y.shape[-1], activation="linear")(x)

    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss="mse",
    )

    # Summarize the model
    model.summary()

    return model

# %%
model = build_model()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 12)]              0
#
#  flatten (Flatten)           (None, 12)                0
#
#  dense (Dense)               (None, 512)               6656
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 32)                16416
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  dense_4 (Dense)             (None, 4)                 132
#
#  dense_5 (Dense)             (None, 4)                 20
#
#  dense_6 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 286941 (1.09 MB)
# Trainable params: 286941 (1.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-6,
    patience=10,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)

# Fit the model
history = model.fit(
    x=train_x,
    y=train_y,
    validation_data=(valid_x, valid_y),
    epochs=epochs,
    batch_size=batch_size,
    verbose=2,
    callbacks=[stop_early],
)
# Out:
# Epoch 1/512
# 1077/1077 - 8s - loss: 0.4955 - val_loss: 0.4845 - 8s/epoch - 8ms/step
# Epoch 2/512
# 1077/1077 - 5s - loss: 0.4810 - val_loss: 0.4788 - 5s/epoch - 5ms/step
# Epoch 3/512
# 1077/1077 - 5s - loss: 0.4771 - val_loss: 0.4778 - 5s/epoch - 5ms/step
# Epoch 4/512
# 1077/1077 - 5s - loss: 0.4748 - val_loss: 0.4753 - 5s/epoch - 5ms/step
# Epoch 5/512
# 1077/1077 - 5s - loss: 0.4731 - val_loss: 0.4729 - 5s/epoch - 5ms/step
# Epoch 6/512
# 1077/1077 - 5s - loss: 0.4714 - val_loss: 0.4722 - 5s/epoch - 5ms/step
# Epoch 7/512
# 1077/1077 - 5s - loss: 0.4699 - val_loss: 0.4702 - 5s/epoch - 5ms/step
# Epoch 8/512
# 1077/1077 - 5s - loss: 0.4686 - val_loss: 0.4684 - 5s/epoch - 5ms/step
# Epoch 9/512
# 1077/1077 - 5s - loss: 0.4675 - val_loss: 0.4680 - 5s/epoch - 5ms/step
# Epoch 10/512
# 1077/1077 - 5s - loss: 0.4665 - val_loss: 0.4686 - 5s/epoch - 5ms/step
# Epoch 11/512
# 1077/1077 - 5s - loss: 0.4655 - val_loss: 0.4658 - 5s/epoch - 5ms/step
# Epoch 12/512
# 1077/1077 - 5s - loss: 0.4647 - val_loss: 0.4656 - 5s/epoch - 5ms/step
# Epoch 13/512
# 1077/1077 - 6s - loss: 0.4638 - val_loss: 0.4647 - 6s/epoch - 5ms/step
# Epoch 14/512
# 1077/1077 - 5s - loss: 0.4629 - val_loss: 0.4653 - 5s/epoch - 5ms/step
# Epoch 15/512
# 1077/1077 - 5s - loss: 0.4621 - val_loss: 0.4628 - 5s/epoch - 5ms/step
# Epoch 16/512
# 1077/1077 - 5s - loss: 0.4611 - val_loss: 0.4642 - 5s/epoch - 5ms/step
# Epoch 17/512
# 1077/1077 - 5s - loss: 0.4602 - val_loss: 0.4609 - 5s/epoch - 5ms/step
# Epoch 18/512
# 1077/1077 - 5s - loss: 0.4594 - val_loss: 0.4602 - 5s/epoch - 5ms/step
# Epoch 19/512
# 1077/1077 - 5s - loss: 0.4586 - val_loss: 0.4598 - 5s/epoch - 5ms/step
# Epoch 20/512
# 1077/1077 - 5s - loss: 0.4578 - val_loss: 0.4585 - 5s/epoch - 5ms/step
# Epoch 21/512
# 1077/1077 - 5s - loss: 0.4569 - val_loss: 0.4587 - 5s/epoch - 5ms/step
# Epoch 22/512
# 1077/1077 - 5s - loss: 0.4566 - val_loss: 0.4582 - 5s/epoch - 5ms/step
# Epoch 23/512
# 1077/1077 - 5s - loss: 0.4559 - val_loss: 0.4579 - 5s/epoch - 5ms/step
# Epoch 24/512
# 1077/1077 - 5s - loss: 0.4555 - val_loss: 0.4574 - 5s/epoch - 5ms/step
# Epoch 25/512
# 1077/1077 - 5s - loss: 0.4550 - val_loss: 0.4564 - 5s/epoch - 5ms/step
# Epoch 26/512
# 1077/1077 - 5s - loss: 0.4546 - val_loss: 0.4561 - 5s/epoch - 5ms/step
# Epoch 27/512
# 1077/1077 - 5s - loss: 0.4540 - val_loss: 0.4564 - 5s/epoch - 5ms/step
# Epoch 28/512
# 1077/1077 - 5s - loss: 0.4537 - val_loss: 0.4558 - 5s/epoch - 5ms/step
# Epoch 29/512
# 1077/1077 - 5s - loss: 0.4534 - val_loss: 0.4552 - 5s/epoch - 5ms/step
# Epoch 30/512
# 1077/1077 - 5s - loss: 0.4529 - val_loss: 0.4560 - 5s/epoch - 5ms/step
# Epoch 31/512
# 1077/1077 - 5s - loss: 0.4526 - val_loss: 0.4543 - 5s/epoch - 5ms/step
# Epoch 32/512
# 1077/1077 - 5s - loss: 0.4520 - val_loss: 0.4541 - 5s/epoch - 5ms/step
# Epoch 33/512
# 1077/1077 - 5s - loss: 0.4518 - val_loss: 0.4542 - 5s/epoch - 5ms/step
# Epoch 34/512
# 1077/1077 - 5s - loss: 0.4515 - val_loss: 0.4538 - 5s/epoch - 5ms/step
# Epoch 35/512
# 1077/1077 - 5s - loss: 0.4512 - val_loss: 0.4534 - 5s/epoch - 5ms/step
# Epoch 36/512
# 1077/1077 - 5s - loss: 0.4510 - val_loss: 0.4530 - 5s/epoch - 5ms/step
# Epoch 37/512
# 1077/1077 - 5s - loss: 0.4505 - val_loss: 0.4536 - 5s/epoch - 5ms/step
# Epoch 38/512
# 1077/1077 - 5s - loss: 0.4503 - val_loss: 0.4525 - 5s/epoch - 5ms/step
# Epoch 39/512
# 1077/1077 - 5s - loss: 0.4499 - val_loss: 0.4536 - 5s/epoch - 5ms/step
# Epoch 40/512
# 1077/1077 - 5s - loss: 0.4497 - val_loss: 0.4540 - 5s/epoch - 5ms/step
# Epoch 41/512
# 1077/1077 - 5s - loss: 0.4494 - val_loss: 0.4526 - 5s/epoch - 5ms/step
# Epoch 42/512
# 1077/1077 - 5s - loss: 0.4492 - val_loss: 0.4521 - 5s/epoch - 5ms/step
# Epoch 43/512
# 1077/1077 - 5s - loss: 0.4490 - val_loss: 0.4526 - 5s/epoch - 5ms/step
# Epoch 44/512
# 1077/1077 - 5s - loss: 0.4487 - val_loss: 0.4508 - 5s/epoch - 5ms/step
# Epoch 45/512
# 1077/1077 - 5s - loss: 0.4486 - val_loss: 0.4529 - 5s/epoch - 5ms/step
# Epoch 46/512
# 1077/1077 - 5s - loss: 0.4484 - val_loss: 0.4504 - 5s/epoch - 5ms/step
# Epoch 47/512
# 1077/1077 - 5s - loss: 0.4482 - val_loss: 0.4508 - 5s/epoch - 5ms/step
# Epoch 48/512
# 1077/1077 - 5s - loss: 0.4480 - val_loss: 0.4503 - 5s/epoch - 5ms/step
# Epoch 49/512
# 1077/1077 - 5s - loss: 0.4479 - val_loss: 0.4506 - 5s/epoch - 5ms/step
# Epoch 50/512
# 1077/1077 - 5s - loss: 0.4477 - val_loss: 0.4506 - 5s/epoch - 5ms/step
# Epoch 51/512
# 1077/1077 - 5s - loss: 0.4475 - val_loss: 0.4504 - 5s/epoch - 5ms/step
# Epoch 52/512
# 1077/1077 - 5s - loss: 0.4473 - val_loss: 0.4501 - 5s/epoch - 5ms/step
# Epoch 53/512
# 1077/1077 - 5s - loss: 0.4471 - val_loss: 0.4506 - 5s/epoch - 5ms/step
# Epoch 54/512
# 1077/1077 - 5s - loss: 0.4470 - val_loss: 0.4502 - 5s/epoch - 5ms/step
# Epoch 55/512
# 1077/1077 - 5s - loss: 0.4467 - val_loss: 0.4500 - 5s/epoch - 5ms/step
# Epoch 56/512
# 1077/1077 - 5s - loss: 0.4465 - val_loss: 0.4503 - 5s/epoch - 5ms/step
# Epoch 57/512
# 1077/1077 - 5s - loss: 0.4463 - val_loss: 0.4514 - 5s/epoch - 5ms/step
# Epoch 58/512
# 1077/1077 - 5s - loss: 0.4462 - val_loss: 0.4495 - 5s/epoch - 5ms/step
# Epoch 59/512
# 1077/1077 - 5s - loss: 0.4462 - val_loss: 0.4486 - 5s/epoch - 5ms/step
# Epoch 60/512
# 1077/1077 - 5s - loss: 0.4458 - val_loss: 0.4494 - 5s/epoch - 5ms/step
# Epoch 61/512
# 1077/1077 - 5s - loss: 0.4457 - val_loss: 0.4498 - 5s/epoch - 5ms/step
# Epoch 62/512
# 1077/1077 - 5s - loss: 0.4456 - val_loss: 0.4497 - 5s/epoch - 5ms/step
# Epoch 63/512
# 1077/1077 - 5s - loss: 0.4453 - val_loss: 0.4488 - 5s/epoch - 5ms/step
# Epoch 64/512
# 1077/1077 - 5s - loss: 0.4453 - val_loss: 0.4495 - 5s/epoch - 5ms/step
# Epoch 65/512
# 1077/1077 - 5s - loss: 0.4451 - val_loss: 0.4482 - 5s/epoch - 5ms/step
# Epoch 66/512
# 1077/1077 - 5s - loss: 0.4451 - val_loss: 0.4486 - 5s/epoch - 5ms/step
# Epoch 67/512
# 1077/1077 - 6s - loss: 0.4448 - val_loss: 0.4480 - 6s/epoch - 5ms/step
# Epoch 68/512
# 1077/1077 - 5s - loss: 0.4448 - val_loss: 0.4479 - 5s/epoch - 5ms/step
# Epoch 69/512
# 1077/1077 - 5s - loss: 0.4445 - val_loss: 0.4485 - 5s/epoch - 5ms/step
# Epoch 70/512
# 1077/1077 - 5s - loss: 0.4443 - val_loss: 0.4491 - 5s/epoch - 5ms/step
# Epoch 71/512
# 1077/1077 - 5s - loss: 0.4441 - val_loss: 0.4479 - 5s/epoch - 5ms/step
# Epoch 72/512
# 1077/1077 - 5s - loss: 0.4439 - val_loss: 0.4479 - 5s/epoch - 5ms/step
# Epoch 73/512
# 1077/1077 - 5s - loss: 0.4439 - val_loss: 0.4480 - 5s/epoch - 5ms/step
# Epoch 74/512
# 1077/1077 - 5s - loss: 0.4438 - val_loss: 0.4481 - 5s/epoch - 5ms/step
# Epoch 75/512
# 1077/1077 - 5s - loss: 0.4434 - val_loss: 0.4470 - 5s/epoch - 5ms/step
# Epoch 76/512
# 1077/1077 - 5s - loss: 0.4433 - val_loss: 0.4482 - 5s/epoch - 5ms/step
# Epoch 77/512
# 1077/1077 - 5s - loss: 0.4431 - val_loss: 0.4472 - 5s/epoch - 5ms/step
# Epoch 78/512
# 1077/1077 - 5s - loss: 0.4430 - val_loss: 0.4468 - 5s/epoch - 5ms/step
# Epoch 79/512
# 1077/1077 - 5s - loss: 0.4429 - val_loss: 0.4471 - 5s/epoch - 5ms/step
# Epoch 80/512
# 1077/1077 - 5s - loss: 0.4427 - val_loss: 0.4473 - 5s/epoch - 5ms/step
# Epoch 81/512
# 1077/1077 - 5s - loss: 0.4427 - val_loss: 0.4462 - 5s/epoch - 5ms/step
# Epoch 82/512
# 1077/1077 - 5s - loss: 0.4424 - val_loss: 0.4474 - 5s/epoch - 5ms/step
# Epoch 83/512
# 1077/1077 - 5s - loss: 0.4422 - val_loss: 0.4464 - 5s/epoch - 5ms/step
# Epoch 84/512
# 1077/1077 - 5s - loss: 0.4420 - val_loss: 0.4462 - 5s/epoch - 5ms/step
# Epoch 85/512
# 1077/1077 - 5s - loss: 0.4419 - val_loss: 0.4469 - 5s/epoch - 5ms/step
# Epoch 86/512
# 1077/1077 - 5s - loss: 0.4418 - val_loss: 0.4460 - 5s/epoch - 5ms/step
# Epoch 87/512
# 1077/1077 - 5s - loss: 0.4416 - val_loss: 0.4460 - 5s/epoch - 5ms/step
# Epoch 88/512
# 1077/1077 - 5s - loss: 0.4416 - val_loss: 0.4453 - 5s/epoch - 5ms/step
# Epoch 89/512
# 1077/1077 - 5s - loss: 0.4415 - val_loss: 0.4470 - 5s/epoch - 5ms/step
# Epoch 90/512
# 1077/1077 - 5s - loss: 0.4412 - val_loss: 0.4459 - 5s/epoch - 5ms/step
# Epoch 91/512
# 1077/1077 - 5s - loss: 0.4411 - val_loss: 0.4461 - 5s/epoch - 5ms/step
# Epoch 92/512
# 1077/1077 - 5s - loss: 0.4409 - val_loss: 0.4454 - 5s/epoch - 5ms/step
# Epoch 93/512
# 1077/1077 - 5s - loss: 0.4409 - val_loss: 0.4471 - 5s/epoch - 5ms/step
# Epoch 94/512
# 1077/1077 - 5s - loss: 0.4407 - val_loss: 0.4455 - 5s/epoch - 5ms/step
# Epoch 95/512
# 1077/1077 - 5s - loss: 0.4405 - val_loss: 0.4451 - 5s/epoch - 5ms/step
# Epoch 96/512
# 1077/1077 - 5s - loss: 0.4403 - val_loss: 0.4452 - 5s/epoch - 5ms/step
# Epoch 97/512
# 1077/1077 - 5s - loss: 0.4403 - val_loss: 0.4452 - 5s/epoch - 5ms/step
# Epoch 98/512
# 1077/1077 - 5s - loss: 0.4401 - val_loss: 0.4443 - 5s/epoch - 5ms/step
# Epoch 99/512
# 1077/1077 - 5s - loss: 0.4400 - val_loss: 0.4443 - 5s/epoch - 5ms/step
# Epoch 100/512
# 1077/1077 - 5s - loss: 0.4399 - val_loss: 0.4446 - 5s/epoch - 5ms/step
# Epoch 101/512
# 1077/1077 - 5s - loss: 0.4398 - val_loss: 0.4443 - 5s/epoch - 5ms/step
# Epoch 102/512
# 1077/1077 - 5s - loss: 0.4396 - val_loss: 0.4441 - 5s/epoch - 5ms/step
# Epoch 103/512
# 1077/1077 - 5s - loss: 0.4396 - val_loss: 0.4441 - 5s/epoch - 5ms/step
# Epoch 104/512
# 1077/1077 - 5s - loss: 0.4394 - val_loss: 0.4443 - 5s/epoch - 5ms/step
# Epoch 105/512
# 1077/1077 - 5s - loss: 0.4393 - val_loss: 0.4446 - 5s/epoch - 5ms/step
# Epoch 106/512
# 1077/1077 - 5s - loss: 0.4391 - val_loss: 0.4447 - 5s/epoch - 5ms/step
# Epoch 107/512
# 1077/1077 - 5s - loss: 0.4391 - val_loss: 0.4441 - 5s/epoch - 5ms/step
# Epoch 108/512
# 1077/1077 - 5s - loss: 0.4389 - val_loss: 0.4439 - 5s/epoch - 5ms/step
# Epoch 109/512
# 1077/1077 - 5s - loss: 0.4388 - val_loss: 0.4436 - 5s/epoch - 5ms/step
# Epoch 110/512
# 1077/1077 - 5s - loss: 0.4386 - val_loss: 0.4442 - 5s/epoch - 5ms/step
# Epoch 111/512
# 1077/1077 - 5s - loss: 0.4386 - val_loss: 0.4438 - 5s/epoch - 5ms/step
# Epoch 112/512
# 1077/1077 - 5s - loss: 0.4384 - val_loss: 0.4436 - 5s/epoch - 5ms/step
# Epoch 113/512
# 1077/1077 - 5s - loss: 0.4383 - val_loss: 0.4447 - 5s/epoch - 5ms/step
# Epoch 114/512
# 1077/1077 - 5s - loss: 0.4383 - val_loss: 0.4433 - 5s/epoch - 5ms/step
# Epoch 115/512
# 1077/1077 - 5s - loss: 0.4381 - val_loss: 0.4434 - 5s/epoch - 5ms/step
# Epoch 116/512
# 1077/1077 - 5s - loss: 0.4380 - val_loss: 0.4438 - 5s/epoch - 5ms/step
# Epoch 117/512
# 1077/1077 - 5s - loss: 0.4378 - val_loss: 0.4441 - 5s/epoch - 5ms/step
# Epoch 118/512
# 1077/1077 - 5s - loss: 0.4376 - val_loss: 0.4431 - 5s/epoch - 5ms/step
# Epoch 119/512
# 1077/1077 - 5s - loss: 0.4376 - val_loss: 0.4433 - 5s/epoch - 5ms/step
# Epoch 120/512
# 1077/1077 - 5s - loss: 0.4376 - val_loss: 0.4428 - 5s/epoch - 5ms/step
# Epoch 121/512
# 1077/1077 - 5s - loss: 0.4374 - val_loss: 0.4429 - 5s/epoch - 5ms/step
# Epoch 122/512
# 1077/1077 - 5s - loss: 0.4372 - val_loss: 0.4432 - 5s/epoch - 5ms/step
# Epoch 123/512
# 1077/1077 - 5s - loss: 0.4373 - val_loss: 0.4427 - 5s/epoch - 5ms/step
# Epoch 124/512
# 1077/1077 - 6s - loss: 0.4372 - val_loss: 0.4429 - 6s/epoch - 5ms/step
# Epoch 125/512
# 1077/1077 - 6s - loss: 0.4370 - val_loss: 0.4444 - 6s/epoch - 5ms/step
# Epoch 126/512
# 1077/1077 - 6s - loss: 0.4369 - val_loss: 0.4430 - 6s/epoch - 5ms/step
# Epoch 127/512
# 1077/1077 - 6s - loss: 0.4369 - val_loss: 0.4422 - 6s/epoch - 5ms/step
# Epoch 128/512
# 1077/1077 - 5s - loss: 0.4367 - val_loss: 0.4428 - 5s/epoch - 5ms/step
# Epoch 129/512
# 1077/1077 - 6s - loss: 0.4366 - val_loss: 0.4429 - 6s/epoch - 5ms/step
# Epoch 130/512
# 1077/1077 - 5s - loss: 0.4364 - val_loss: 0.4425 - 5s/epoch - 5ms/step
# Epoch 131/512
# 1077/1077 - 5s - loss: 0.4364 - val_loss: 0.4416 - 5s/epoch - 5ms/step
# Epoch 132/512
# 1077/1077 - 6s - loss: 0.4362 - val_loss: 0.4430 - 6s/epoch - 5ms/step
# Epoch 133/512
# 1077/1077 - 6s - loss: 0.4361 - val_loss: 0.4427 - 6s/epoch - 5ms/step
# Epoch 134/512
# 1077/1077 - 5s - loss: 0.4361 - val_loss: 0.4422 - 5s/epoch - 5ms/step
# Epoch 135/512
# 1077/1077 - 5s - loss: 0.4361 - val_loss: 0.4429 - 5s/epoch - 5ms/step
# Epoch 136/512
# 1077/1077 - 5s - loss: 0.4359 - val_loss: 0.4431 - 5s/epoch - 5ms/step
# Epoch 137/512
# 1077/1077 - 6s - loss: 0.4359 - val_loss: 0.4422 - 6s/epoch - 5ms/step
# Epoch 138/512
# 1077/1077 - 5s - loss: 0.4357 - val_loss: 0.4420 - 5s/epoch - 5ms/step
# Epoch 139/512
# 1077/1077 - 6s - loss: 0.4356 - val_loss: 0.4421 - 6s/epoch - 5ms/step
# Epoch 140/512
# 1077/1077 - 5s - loss: 0.4356 - val_loss: 0.4421 - 5s/epoch - 5ms/step
# Epoch 141/512
# 1077/1077 - 5s - loss: 0.4353 - val_loss: 0.4417 - 5s/epoch - 5ms/step

# %%
# save model
model.save("DNN_modified_m.h5", save_format="h5", overwrite=True)
# predict
pred_y = model.predict(test_x)
sig_pred = pred_y
sig_truth = test_y
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 12924/12924 [==============================] - 17s 1ms/step

# %%
print(f"Truth mean: {np.mean(sig_truth[:,0]):.3f}, std: {np.std(sig_truth[:,0]):.3f}, min: {np.min(sig_truth[:,0]):.3f}, max: {np.max(sig_truth[:,0]):.3f}")
# Out:
# Truth mean: 0.062, std: 0.732, min: -1.612, max: 1.721

# %%
from sklearn.metrics import mean_squared_error

range = [-1.3, 2.4]

plot.plot_hist(
    [sig_truth[:, 0], sig_pred[:, 0]],
    [r"$B_{xy}^{truth}$", r"$B_{xy}^{pred}$"],
    r"Sig. norm. $B_{xy}$"
    + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth[:,0], sig_pred[:,0])):.3f}",
    # range=range,
    xlabel=r"null",
)

plot.plot_loss_history(history, logx=True, logy=True)

plot.plot_2d_histogram(
    sig_truth[:, 0],
    sig_pred[:, 0],
    r"Sig. norm. $B_{xy}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth[:,0], sig_pred[:,0])[0]:.3f}",
    # range=range,
)

# %%
# TODO
STOP
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # TODO
# ----> 2 STOP
#
# NameError: name 'STOP' is not defined

# %%
# from sklearn.metrics import mean_squared_error

# range = [0.43, 0.57]
35042

# plot.plot_hist(
#     [sig_truth[:, 0], sig_pred[:, 0]],
#     [r"$p_{z\ truth}^{\nu\nu}$", r"$p_{z\ pred}^{\nu\nu}$"],
#     r"Sig. norm. $p^{\nu\nu}_{z}$" + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth[:,0], sig_pred[:,0])):.3f}",
#     range=range,
#     xlabel=r"[Norm. $p_{z}$ unit]",
# )

# plot.plot_loss_history(history, logx=True, logy=True)

# plot.plot_2d_histogram(
#     sig_truth[:, 0],
#     sig_pred[:, 0],
#     r"Sig. $p_{z}^{\nu\nu}$ "
#     + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth[:,0], sig_pred[:,0])[0]:.3f}",
#     range=range,
# )

# %%
# Background
processor = gd.DataProcessor(sampling=sampling, processor=10)
path = "/root/data/truth/background/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))

# %%
# inputs -> observed params
lep_p = processor.process_part(data.LepP)[cut_pre]
lep_m = processor.process_part(data.LepM)[cut_pre]
lep_kin = pd.concat([lep_p, lep_m], axis=1)
MET = processor.process_MET(data.MET).iloc[:, 1:3][cut_pre]
obs_kin = pd.concat([MET, lep_kin], axis=1)
print("obs_kin shape:", obs_kin.shape)
print(obs_kin.head(3))
print()

# targets -> interested unknowns
int_kin = pd.DataFrame(
    processor.process_dipart(data.NuP, data.NuM)[["pz"]][cut_pre]
)
print("int_kin shape:", int_kin.shape)
print(int_kin.head(3))
print()

del (processor, lep_p, lep_m, MET)
gc.collect()

# %%
# SCALAR_obs_std_bkg = StandardScaler()
# obs_kin = SCALAR_obs_std_bkg.fit_transform(obs_kin)
SCALAR_obs_qt_bkg = QuantileTransformer(output_distribution='normal')
obs_kin = SCALAR_obs_qt_bkg.fit_transform(obs_kin)

# SCALAR_int_std_bkg = StandardScaler()
# int_kin = SCALAR_int_std_bkg.fit_transform(int_kin)
SCALAR_int_qt_bkg = QuantileTransformer(output_distribution='normal')
int_kin = SCALAR_int_qt_bkg.fit_transform(int_kin)

x, y = obs_kin[indices_arr], int_kin[indices_arr]

print(f"X:\ndata shape: {x.shape};\nY:\ndata shape: {y.shape}.")
print()

# %%
y_pred = model.predict(x)
bkg_pred = y_pred
bkg_truth = y

# %%
range = [
    np.max([bkg_pred[:, 0].min(), bkg_truth[:, 0].min()]),
    np.min([bkg_pred[:, 0].max(), bkg_truth[:, 0].max()]),
]

plot.plot_hist(
    [bkg_truth[:, 0], bkg_pred[:, 0]],
    [r"$E_{truth}^{\nu\nu}$", r"$E_{pred}^{\nu\nu}$"],
    "Non-resnt WW: " + r"Normalized $E$ of $\nu\nu$",
    range=range,
    xlabel=r"$E$ [GeV]",
)

plot.plot_2d_histogram(
    bkg_pred[:, 0],
    bkg_truth[:, 0],
    "Non-resnt WW: "
    + r"$E^{\nu\nu}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(bkg_truth[:,0], bkg_pred[:,0])[0]:.3f}",
    range=range,
)

# %%
range = [
    np.max([bkg_pred[:, 1].min(), bkg_truth[:, 1].min()]),
    np.min([bkg_pred[:, 1].max(), bkg_truth[:, 1].max()]),
]

plot.plot_hist(
    [bkg_truth[:, 1], bkg_pred[:, 1]],
    [r"$p_{z\ truth}^{\nu\nu}$", r"$p_{z\ pred}^{\nu\nu}$"],
    r"Non-resnt WW: Normalized $p_{z}$ of $\nu\nu$",
    range=range,
    xlabel=r"$p_{z}$ [GeV]",
)

plot.plot_2d_histogram(
    bkg_truth[:, 1],
    bkg_pred[:, 1],
    "Non-resnt WW: "
    + r"$p_{z}^{\nu\nu}$"
    + f" with Pearson coeff: {sp.stats.pearsonr(bkg_truth[:,1], bkg_pred[:,1])[0]:.3f}",
    range=range,
)

time_end = time()
print(f"Time cost: {(time_end - time_start):.2f} s.")
