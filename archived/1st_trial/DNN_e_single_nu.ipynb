# %%
# %reset -sf

from time import time
time_start = time()

import pandas as pd
import numpy as np
import scipy as sp
import gc
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import tensorflow as tf

# from mt2 import mt2
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)
tf.config.experimental.set_memory_growth(gpus[1], True)

import get_data as gd
import atlas_plot as ap
plot = ap.Plotter()

print(tf.__version__)
print(tf.config.list_physical_devices())
print()
# Out:
# 2.13.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
seed = 42  # set random seed
sampling = int(1e6)
# num_folds = 2
batch_size = 1024
epochs = 512
learning_rate = 1e-6

# %%
np.random.seed(seed)
processor = gd.DataProcessor(sampling=sampling, processor=30)
path = "/root/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 30
#
# ['/root/data/truth/signal/CGLMP.npz', '/root/data/truth/signal/Higgs.npz', '/root/data/truth/signal/LeadLepton.npz', '/root/data/truth/signal/LeptonM.npz', '/root/data/truth/signal/LeptonP.npz', '/root/data/truth/signal/LmNu.npz', '/root/data/truth/signal/LpNu.npz', '/root/data/truth/signal/MET.npz', '/root/data/truth/signal/WmBoson.npz', '/root/data/truth/signal/WpBoson.npz', '/root/data/truth/signal/diLepton.npz', '/root/data/truth/signal/subLeadLepton.npz', '/root/data/truth/signal/xi_xyz.npz']

# %%
GEV = 1e3

cut_pre_pt_lead = data.LeadLep["pt"] > 22 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
cut_pre_pt_miss = data.MET["pt"] > 20 * GEV
cut_pre = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss

del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# %%
# inputs -> observed params
lep_p = processor.process_part(data.LepP)
lep_m = processor.process_part(data.LepM)
lep_kin = pd.concat([lep_p.iloc[:,:4], lep_m.iloc[:,:4]], axis=1)
MET = processor.process_MET(data.MET)
dilep_kin = processor.process_dipart(data.LepP, data.LepM)
# mt = np.sqrt(
#     mt2(
#         lep_m["m"],
#         lep_m["px"],
#         lep_m["py"],  # Visible 1: mass, px, py
#         lep_p["m"],
#         lep_p["px"],
#         lep_p["py"],  # Visible 2: mass, px, py
#         MET["MET_px"],
#         MET["MET_py"],  # Missing transverse momentum: x, y
#         0,
#         0,  # Invisible 1 mass, invisible 2 mass
#     )
# )
# vx = 5 * pd.DataFrame({"vx": mt + 0.3 * np.sqrt(dilep_kin["m"])})
# dilep_kin.iloc[:, 0:4]

mask = (processor.process_part(data.NuP)[["E"]].values.reshape(-1) < 300) & cut_pre

obs_kin = pd.concat([MET.iloc[:, 1:3], lep_kin], axis=1)[mask]
print("obs_kin shape:", obs_kin.shape)
print(obs_kin.head(3))
print()

# targets -> interested unknowns
int_kin = processor.process_part(data.NuP)[["E"]][mask]
print("int_kin shape:", int_kin.shape)
print(int_kin.head(3))
print()

# del (processor, lep_p, lep_m, MET, dilep_kin)
# gc.collect()
# Out:
# obs_kin shape: (1314414, 10)
#        MET_px     MET_py           E         px         py          pz  \
# 7   96.335650  47.095450   19.500895  -4.561588  18.924410   -1.154271
# 9  -26.992604 -70.883859  164.814766  34.397141   2.031300 -161.172625
# 10  44.222846 -15.383637   47.669113 -26.605045 -17.256748   35.590859
#
#             E         px         py         pz
# 7   43.361348  42.407754  -4.632000   7.767462
# 9   70.592648  29.001777   1.896990 -64.332027
# 10  90.238664 -23.868604  32.986602  80.530680
#
# int_kin shape: (1314414, 1)
#              E
# 7   145.583531
# 9    97.954078
# 10    7.424128

# %%
from matplotlib import pyplot as plt

plt.hist(processor.process_part(data.NuP)[["E"]], bins=200, alpha=.8)
plt.title(r"Norm. $E$")
plt.xlabel("null")
plt.ylabel("count")
# plt.xlim([0,0.5])
plt.show()

# %%
plt.hist(int_kin, bins=200, alpha=.8)
plt.title(r"Norm. $E$")
plt.xlabel("null")
plt.ylabel("count")
# plt.xlim([0,0.5])
plt.show()

# %%
SCALAR_int_ru = RobustScaler()
int_kin = SCALAR_int_ru.fit_transform(int_kin)
SCALAR_int_mm = MinMaxScaler()
int_kin = SCALAR_int_mm.fit_transform(int_kin)

SCALAR_obs_ru = RobustScaler()
obs_kin = SCALAR_obs_ru.fit_transform(obs_kin)
SCALAR_obs_mm = MinMaxScaler()
obs_kin = SCALAR_obs_mm.fit_transform(obs_kin)

# %%
indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.4,
    test_size=0.6,
    random_state=seed,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=42
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
print()
# Out:
# X (Interest)
# Training data shape: (525765, 10);
# Validing data shape: (394324, 10);
# Testing data shape: (394325, 10).
# Y (Observed)
# Training data shape: (525765, 1);
# Validing data shape: (394324, 1);
# Testing data shape: (394325, 1).

# %%
plt.hist(train_y, bins=200, alpha=.8)
plt.title(r"Norm. $E$")
plt.xlabel("null")
plt.ylabel("count")
# plt.xlim([0,0.5])
plt.show()

# %%
# Define a new activation function
def custom_activation(x):
    return x*tf.keras.backend.sigmoid(x)

# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    x = tf.keras.layers.Dense(units=64, activation="elu")(x)
    x = tf.keras.layers.Dense(units=64, activation="elu")(x)
    x = tf.keras.layers.Dropout(rate=0.1)(x)
    x = tf.keras.layers.Dense(units=16, activation="elu")(x)
    x = tf.keras.layers.Dense(units=16, activation="elu")(x)
    
    # Last dense layer
    outputs = tf.keras.layers.Dense(units=train_y.shape[-1], activation="sigmoid")(x)

    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss="mse",
    )

    # Summarize the model
    model.summary()

    return model

# %%
model = build_model()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10)]              0
#
#  flatten (Flatten)           (None, 10)                0
#
#  dense (Dense)               (None, 64)                704
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 16)                1040
#
#  dense_3 (Dense)             (None, 16)                272
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 6193 (24.19 KB)
# Trainable params: 6193 (24.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-6,
    patience=10,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)

# Fit the model
history = model.fit(
    x=train_x,
    y=train_y,
    validation_data=(valid_x, valid_y),
    epochs=epochs,
    batch_size=batch_size,
    verbose=2,
    callbacks=[stop_early],
)
# Out:
# Epoch 1/512
# 514/514 - 5s - loss: 0.0683 - val_loss: 0.0631 - 5s/epoch - 10ms/step
# Epoch 2/512
# 514/514 - 2s - loss: 0.0603 - val_loss: 0.0562 - 2s/epoch - 4ms/step
# Epoch 3/512
# 514/514 - 2s - loss: 0.0542 - val_loss: 0.0509 - 2s/epoch - 4ms/step
# Epoch 4/512
# 514/514 - 2s - loss: 0.0496 - val_loss: 0.0468 - 2s/epoch - 4ms/step
# Epoch 5/512
# 514/514 - 2s - loss: 0.0461 - val_loss: 0.0438 - 2s/epoch - 4ms/step
# Epoch 6/512
# 514/514 - 2s - loss: 0.0435 - val_loss: 0.0417 - 2s/epoch - 4ms/step
# Epoch 7/512
# 514/514 - 2s - loss: 0.0416 - val_loss: 0.0402 - 2s/epoch - 4ms/step
# Epoch 8/512
# 514/514 - 2s - loss: 0.0403 - val_loss: 0.0392 - 2s/epoch - 5ms/step
# Epoch 9/512
# 514/514 - 2s - loss: 0.0395 - val_loss: 0.0385 - 2s/epoch - 5ms/step
# Epoch 10/512
# 514/514 - 2s - loss: 0.0390 - val_loss: 0.0381 - 2s/epoch - 5ms/step
# Epoch 11/512
# 514/514 - 2s - loss: 0.0387 - val_loss: 0.0379 - 2s/epoch - 4ms/step
# Epoch 12/512
# 514/514 - 2s - loss: 0.0385 - val_loss: 0.0379 - 2s/epoch - 5ms/step
# Epoch 13/512
# 514/514 - 2s - loss: 0.0384 - val_loss: 0.0378 - 2s/epoch - 5ms/step
# Epoch 14/512
# 514/514 - 2s - loss: 0.0384 - val_loss: 0.0378 - 2s/epoch - 4ms/step
# Epoch 15/512
# 514/514 - 2s - loss: 0.0384 - val_loss: 0.0378 - 2s/epoch - 4ms/step
# Epoch 16/512
# 514/514 - 2s - loss: 0.0383 - val_loss: 0.0378 - 2s/epoch - 4ms/step
# Epoch 17/512
# 514/514 - 2s - loss: 0.0383 - val_loss: 0.0377 - 2s/epoch - 4ms/step
# Epoch 18/512
# 514/514 - 2s - loss: 0.0383 - val_loss: 0.0377 - 2s/epoch - 4ms/step
# Epoch 19/512
# 514/514 - 2s - loss: 0.0383 - val_loss: 0.0377 - 2s/epoch - 4ms/step
# Epoch 20/512
# 514/514 - 2s - loss: 0.0382 - val_loss: 0.0376 - 2s/epoch - 4ms/step
# Epoch 21/512
# 514/514 - 2s - loss: 0.0382 - val_loss: 0.0376 - 2s/epoch - 4ms/step
# Epoch 22/512
# 514/514 - 2s - loss: 0.0382 - val_loss: 0.0376 - 2s/epoch - 4ms/step
# Epoch 23/512
# 514/514 - 2s - loss: 0.0381 - val_loss: 0.0376 - 2s/epoch - 4ms/step
# Epoch 24/512
# 514/514 - 2s - loss: 0.0381 - val_loss: 0.0375 - 2s/epoch - 4ms/step
# Epoch 25/512
# 514/514 - 2s - loss: 0.0381 - val_loss: 0.0375 - 2s/epoch - 4ms/step
# Epoch 26/512
# 514/514 - 2s - loss: 0.0380 - val_loss: 0.0375 - 2s/epoch - 4ms/step
# Epoch 27/512
# 514/514 - 2s - loss: 0.0380 - val_loss: 0.0374 - 2s/epoch - 4ms/step
# Epoch 28/512
# 514/514 - 2s - loss: 0.0380 - val_loss: 0.0374 - 2s/epoch - 4ms/step
# Epoch 29/512
# 514/514 - 2s - loss: 0.0379 - val_loss: 0.0374 - 2s/epoch - 4ms/step
# Epoch 30/512
# 514/514 - 2s - loss: 0.0379 - val_loss: 0.0373 - 2s/epoch - 4ms/step
# Epoch 31/512
# 514/514 - 2s - loss: 0.0378 - val_loss: 0.0373 - 2s/epoch - 4ms/step
# Epoch 32/512
# 514/514 - 2s - loss: 0.0378 - val_loss: 0.0373 - 2s/epoch - 4ms/step
# Epoch 33/512
# 514/514 - 2s - loss: 0.0378 - val_loss: 0.0373 - 2s/epoch - 4ms/step
# Epoch 34/512
# 514/514 - 2s - loss: 0.0377 - val_loss: 0.0372 - 2s/epoch - 4ms/step
# Epoch 35/512
# 514/514 - 2s - loss: 0.0377 - val_loss: 0.0372 - 2s/epoch - 4ms/step
# Epoch 36/512
# 514/514 - 2s - loss: 0.0377 - val_loss: 0.0372 - 2s/epoch - 4ms/step
# Epoch 37/512
# 514/514 - 2s - loss: 0.0377 - val_loss: 0.0371 - 2s/epoch - 4ms/step
# Epoch 38/512
# 514/514 - 2s - loss: 0.0376 - val_loss: 0.0371 - 2s/epoch - 4ms/step
# Epoch 39/512
# 514/514 - 2s - loss: 0.0376 - val_loss: 0.0371 - 2s/epoch - 4ms/step
# Epoch 40/512
# 514/514 - 2s - loss: 0.0375 - val_loss: 0.0370 - 2s/epoch - 4ms/step
# Epoch 41/512
# 514/514 - 2s - loss: 0.0375 - val_loss: 0.0370 - 2s/epoch - 4ms/step
# Epoch 42/512
# 514/514 - 2s - loss: 0.0375 - val_loss: 0.0370 - 2s/epoch - 4ms/step
# Epoch 43/512
# 514/514 - 2s - loss: 0.0374 - val_loss: 0.0369 - 2s/epoch - 4ms/step
# Epoch 44/512
# 514/514 - 2s - loss: 0.0374 - val_loss: 0.0369 - 2s/epoch - 4ms/step
# Epoch 45/512
# 514/514 - 2s - loss: 0.0374 - val_loss: 0.0369 - 2s/epoch - 4ms/step
# Epoch 46/512
# 514/514 - 2s - loss: 0.0373 - val_loss: 0.0368 - 2s/epoch - 4ms/step
# Epoch 47/512
# 514/514 - 2s - loss: 0.0373 - val_loss: 0.0368 - 2s/epoch - 4ms/step
# Epoch 48/512
# 514/514 - 2s - loss: 0.0372 - val_loss: 0.0368 - 2s/epoch - 4ms/step
# Epoch 49/512
# 514/514 - 2s - loss: 0.0372 - val_loss: 0.0367 - 2s/epoch - 4ms/step
# Epoch 50/512
# 514/514 - 2s - loss: 0.0372 - val_loss: 0.0367 - 2s/epoch - 4ms/step
# Epoch 51/512
# 514/514 - 2s - loss: 0.0371 - val_loss: 0.0367 - 2s/epoch - 4ms/step
# Epoch 52/512
# 514/514 - 2s - loss: 0.0371 - val_loss: 0.0366 - 2s/epoch - 4ms/step
# Epoch 53/512
# 514/514 - 2s - loss: 0.0371 - val_loss: 0.0366 - 2s/epoch - 4ms/step
# Epoch 54/512
# 514/514 - 2s - loss: 0.0370 - val_loss: 0.0366 - 2s/epoch - 4ms/step
# Epoch 55/512
# 514/514 - 2s - loss: 0.0370 - val_loss: 0.0365 - 2s/epoch - 4ms/step
# Epoch 56/512
# 514/514 - 2s - loss: 0.0369 - val_loss: 0.0365 - 2s/epoch - 4ms/step
# Epoch 57/512
# 514/514 - 2s - loss: 0.0369 - val_loss: 0.0365 - 2s/epoch - 4ms/step
# Epoch 58/512
# 514/514 - 2s - loss: 0.0369 - val_loss: 0.0364 - 2s/epoch - 4ms/step
# Epoch 59/512
# 514/514 - 2s - loss: 0.0369 - val_loss: 0.0364 - 2s/epoch - 4ms/step
# Epoch 60/512
# 514/514 - 2s - loss: 0.0368 - val_loss: 0.0364 - 2s/epoch - 4ms/step
# Epoch 61/512
# 514/514 - 2s - loss: 0.0368 - val_loss: 0.0363 - 2s/epoch - 4ms/step
# Epoch 62/512
# 514/514 - 2s - loss: 0.0367 - val_loss: 0.0363 - 2s/epoch - 4ms/step
# Epoch 63/512
# 514/514 - 2s - loss: 0.0367 - val_loss: 0.0362 - 2s/epoch - 4ms/step
# Epoch 64/512
# 514/514 - 2s - loss: 0.0367 - val_loss: 0.0362 - 2s/epoch - 4ms/step
# Epoch 65/512
# 514/514 - 2s - loss: 0.0366 - val_loss: 0.0362 - 2s/epoch - 4ms/step
# Epoch 66/512
# 514/514 - 2s - loss: 0.0366 - val_loss: 0.0361 - 2s/epoch - 4ms/step
# Epoch 67/512
# 514/514 - 2s - loss: 0.0365 - val_loss: 0.0361 - 2s/epoch - 4ms/step
# Epoch 68/512
# 514/514 - 2s - loss: 0.0365 - val_loss: 0.0361 - 2s/epoch - 4ms/step
# Epoch 69/512
# 514/514 - 2s - loss: 0.0365 - val_loss: 0.0360 - 2s/epoch - 4ms/step
# Epoch 70/512
# 514/514 - 2s - loss: 0.0364 - val_loss: 0.0360 - 2s/epoch - 4ms/step
# Epoch 71/512
# 514/514 - 2s - loss: 0.0364 - val_loss: 0.0360 - 2s/epoch - 4ms/step
# Epoch 72/512
# 514/514 - 2s - loss: 0.0364 - val_loss: 0.0359 - 2s/epoch - 4ms/step
# Epoch 73/512
# 514/514 - 2s - loss: 0.0363 - val_loss: 0.0359 - 2s/epoch - 4ms/step
# Epoch 74/512
# 514/514 - 2s - loss: 0.0363 - val_loss: 0.0358 - 2s/epoch - 4ms/step
# Epoch 75/512
# 514/514 - 2s - loss: 0.0362 - val_loss: 0.0358 - 2s/epoch - 5ms/step
# Epoch 76/512
# 514/514 - 2s - loss: 0.0362 - val_loss: 0.0358 - 2s/epoch - 5ms/step
# Epoch 77/512
# 514/514 - 2s - loss: 0.0362 - val_loss: 0.0357 - 2s/epoch - 4ms/step
# Epoch 78/512
# 514/514 - 2s - loss: 0.0361 - val_loss: 0.0357 - 2s/epoch - 5ms/step
# Epoch 79/512
# 514/514 - 2s - loss: 0.0361 - val_loss: 0.0357 - 2s/epoch - 4ms/step
# Epoch 80/512
# 514/514 - 2s - loss: 0.0360 - val_loss: 0.0356 - 2s/epoch - 5ms/step
# Epoch 81/512
# 514/514 - 2s - loss: 0.0360 - val_loss: 0.0356 - 2s/epoch - 4ms/step
# Epoch 82/512
# 514/514 - 2s - loss: 0.0360 - val_loss: 0.0356 - 2s/epoch - 4ms/step
# Epoch 83/512
# 514/514 - 2s - loss: 0.0360 - val_loss: 0.0355 - 2s/epoch - 4ms/step
# Epoch 84/512
# 514/514 - 2s - loss: 0.0359 - val_loss: 0.0355 - 2s/epoch - 4ms/step
# Epoch 85/512
# 514/514 - 2s - loss: 0.0359 - val_loss: 0.0355 - 2s/epoch - 4ms/step
# Epoch 86/512
# 514/514 - 2s - loss: 0.0359 - val_loss: 0.0354 - 2s/epoch - 4ms/step
# Epoch 87/512
# 514/514 - 2s - loss: 0.0358 - val_loss: 0.0354 - 2s/epoch - 4ms/step
# Epoch 88/512
# 514/514 - 2s - loss: 0.0358 - val_loss: 0.0354 - 2s/epoch - 4ms/step
# Epoch 89/512
# 514/514 - 2s - loss: 0.0358 - val_loss: 0.0354 - 2s/epoch - 4ms/step
# Epoch 90/512
# 514/514 - 2s - loss: 0.0357 - val_loss: 0.0353 - 2s/epoch - 4ms/step
# Epoch 91/512
# 514/514 - 2s - loss: 0.0357 - val_loss: 0.0353 - 2s/epoch - 4ms/step
# Epoch 92/512
# 514/514 - 2s - loss: 0.0357 - val_loss: 0.0353 - 2s/epoch - 4ms/step
# Epoch 93/512
# 514/514 - 2s - loss: 0.0356 - val_loss: 0.0353 - 2s/epoch - 4ms/step
# Epoch 94/512
# 514/514 - 2s - loss: 0.0356 - val_loss: 0.0352 - 2s/epoch - 4ms/step
# Epoch 95/512
# 514/514 - 2s - loss: 0.0356 - val_loss: 0.0352 - 2s/epoch - 4ms/step
# Epoch 96/512
# 514/514 - 2s - loss: 0.0356 - val_loss: 0.0352 - 2s/epoch - 4ms/step
# Epoch 97/512
# 514/514 - 2s - loss: 0.0355 - val_loss: 0.0352 - 2s/epoch - 4ms/step
# Epoch 98/512
# 514/514 - 2s - loss: 0.0355 - val_loss: 0.0351 - 2s/epoch - 4ms/step
# Epoch 99/512
# 514/514 - 2s - loss: 0.0355 - val_loss: 0.0351 - 2s/epoch - 4ms/step
# Epoch 100/512
# 514/514 - 2s - loss: 0.0355 - val_loss: 0.0351 - 2s/epoch - 4ms/step
# Epoch 101/512
# 514/514 - 2s - loss: 0.0355 - val_loss: 0.0351 - 2s/epoch - 4ms/step
# Epoch 102/512
# 514/514 - 2s - loss: 0.0354 - val_loss: 0.0351 - 2s/epoch - 4ms/step
# Epoch 103/512
# 514/514 - 2s - loss: 0.0354 - val_loss: 0.0351 - 2s/epoch - 4ms/step
# Epoch 104/512
# 514/514 - 2s - loss: 0.0354 - val_loss: 0.0350 - 2s/epoch - 4ms/step
# Epoch 105/512
# 514/514 - 2s - loss: 0.0354 - val_loss: 0.0350 - 2s/epoch - 4ms/step
# Epoch 106/512
# 514/514 - 2s - loss: 0.0354 - val_loss: 0.0350 - 2s/epoch - 4ms/step
# Epoch 107/512
# 514/514 - 2s - loss: 0.0353 - val_loss: 0.0350 - 2s/epoch - 4ms/step
# Epoch 108/512
# 514/514 - 2s - loss: 0.0353 - val_loss: 0.0350 - 2s/epoch - 4ms/step
# Epoch 109/512
# 514/514 - 2s - loss: 0.0353 - val_loss: 0.0350 - 2s/epoch - 4ms/step
# Epoch 110/512
# 514/514 - 2s - loss: 0.0353 - val_loss: 0.0350 - 2s/epoch - 4ms/step
# Epoch 111/512
# 514/514 - 2s - loss: 0.0353 - val_loss: 0.0349 - 2s/epoch - 4ms/step
# Epoch 112/512
# 514/514 - 2s - loss: 0.0353 - val_loss: 0.0349 - 2s/epoch - 4ms/step
# Epoch 113/512
# 514/514 - 2s - loss: 0.0352 - val_loss: 0.0349 - 2s/epoch - 4ms/step
# Epoch 114/512
# 514/514 - 2s - loss: 0.0352 - val_loss: 0.0349 - 2s/epoch - 4ms/step
# Epoch 115/512
# 514/514 - 2s - loss: 0.0352 - val_loss: 0.0349 - 2s/epoch - 4ms/step
# Epoch 116/512
# 514/514 - 2s - loss: 0.0352 - val_loss: 0.0349 - 2s/epoch - 4ms/step
# Epoch 117/512
# 514/514 - 2s - loss: 0.0352 - val_loss: 0.0349 - 2s/epoch - 4ms/step
# Epoch 118/512
# 514/514 - 2s - loss: 0.0352 - val_loss: 0.0349 - 2s/epoch - 4ms/step
# Epoch 119/512
# 514/514 - 2s - loss: 0.0352 - val_loss: 0.0349 - 2s/epoch - 4ms/step
# Epoch 120/512
# 514/514 - 2s - loss: 0.0352 - val_loss: 0.0349 - 2s/epoch - 4ms/step
# Epoch 121/512
# 514/514 - 2s - loss: 0.0352 - val_loss: 0.0349 - 2s/epoch - 4ms/step
# Epoch 122/512
# 514/514 - 2s - loss: 0.0352 - val_loss: 0.0349 - 2s/epoch - 4ms/step
# Epoch 123/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 124/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 125/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 126/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 127/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 128/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 129/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 130/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 131/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 132/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 133/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 134/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 135/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 136/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 137/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 138/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 139/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 140/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 141/512
# 514/514 - 2s - loss: 0.0351 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 142/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 143/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 144/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 145/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 146/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 147/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 148/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 149/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 150/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 151/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 152/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 153/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 154/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 155/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 156/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0348 - 2s/epoch - 4ms/step
# Epoch 157/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 158/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 159/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 160/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 161/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 162/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 163/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 164/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 165/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 166/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 167/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 168/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 169/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 170/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 171/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 172/512
# 514/514 - 2s - loss: 0.0350 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 173/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 174/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 175/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 176/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 177/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 178/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 179/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 180/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 181/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 182/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 183/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 184/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 185/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 186/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 187/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 188/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 189/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 190/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 191/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 192/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 193/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 194/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 195/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 196/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 197/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 198/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 199/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 200/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 201/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 202/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 203/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 204/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 205/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 206/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 207/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 208/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 209/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 210/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 211/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 212/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 213/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 214/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 215/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 216/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 217/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 218/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 219/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 220/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 221/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 222/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 223/512
# 514/514 - 2s - loss: 0.0349 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 224/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 225/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 226/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 227/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 228/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 229/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 230/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 231/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 232/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 233/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0347 - 2s/epoch - 4ms/step
# Epoch 234/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 235/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 236/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 237/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 238/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 239/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 240/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 241/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 242/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 243/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 244/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 245/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 246/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 247/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 248/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 249/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 250/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 251/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 252/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 253/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 254/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 255/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 256/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 257/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 258/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 259/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 260/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 261/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 262/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 263/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 264/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 265/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 266/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 267/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 268/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 269/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 270/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 271/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 272/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 273/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 274/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 275/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 276/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 277/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 278/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 279/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 280/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 281/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 282/512
# 514/514 - 2s - loss: 0.0348 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 283/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 284/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 285/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 286/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 287/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 288/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 289/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 290/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 291/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 292/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 293/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 294/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 295/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 296/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 297/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 298/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 299/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 300/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 301/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 302/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 303/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 304/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0346 - 2s/epoch - 4ms/step
# Epoch 305/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 306/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 307/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 308/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 309/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 310/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 311/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 312/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 313/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 314/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 315/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 316/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 317/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 318/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 319/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 320/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 321/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 322/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 323/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 324/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 325/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 326/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 327/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 328/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 329/512
# 514/514 - 2s - loss: 0.0347 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 330/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 331/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 332/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 333/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 5ms/step
# Epoch 334/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 335/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 336/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 337/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 338/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 339/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 340/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 341/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 342/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 343/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 344/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 345/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 346/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 347/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 348/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 349/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 350/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 351/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0345 - 2s/epoch - 4ms/step
# Epoch 352/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 353/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 354/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 355/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 356/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 357/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 358/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 359/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 360/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 361/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 362/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 363/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 364/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 365/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 366/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 367/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 368/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 369/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 370/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 371/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 372/512
# 514/514 - 2s - loss: 0.0346 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 373/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 374/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 375/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 376/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 377/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 378/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 379/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 380/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 381/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 382/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 383/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 384/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 385/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 386/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 387/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0344 - 2s/epoch - 4ms/step
# Epoch 388/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 389/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 390/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 391/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 392/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 393/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 394/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 395/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 396/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 397/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 398/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 399/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 400/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 401/512
# 514/514 - 2s - loss: 0.0345 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 402/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 403/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 404/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 405/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 5ms/step
# Epoch 406/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 407/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 408/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 409/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 410/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 411/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 412/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 413/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 414/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 415/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 416/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 417/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 418/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 419/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 420/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 421/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0343 - 2s/epoch - 4ms/step
# Epoch 422/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 423/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 424/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 425/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 426/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 427/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 428/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 429/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 430/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 431/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 432/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 433/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 434/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 435/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 436/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 437/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 438/512
# 514/514 - 2s - loss: 0.0344 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 439/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 440/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 441/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 442/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 443/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 444/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 445/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 446/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 447/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 448/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 449/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 450/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 451/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 452/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 453/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 454/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 455/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0342 - 2s/epoch - 4ms/step
# Epoch 456/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 457/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 458/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 459/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 460/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 461/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 462/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 463/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 464/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 465/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 466/512
# 514/514 - 2s - loss: 0.0343 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 467/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 468/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 469/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 470/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 471/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 472/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 473/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 474/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 475/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 476/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 477/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 478/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 479/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 480/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 481/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 482/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 483/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 484/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0341 - 2s/epoch - 4ms/step
# Epoch 485/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 486/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 487/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 488/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 489/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0340 - 2s/epoch - 5ms/step
# Epoch 490/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 491/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 492/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0340 - 2s/epoch - 5ms/step
# Epoch 493/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0340 - 2s/epoch - 5ms/step
# Epoch 494/512
# 514/514 - 2s - loss: 0.0342 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 495/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 496/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 497/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 5ms/step
# Epoch 498/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 5ms/step
# Epoch 499/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 5ms/step
# Epoch 500/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 5ms/step
# Epoch 501/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 502/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 503/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 504/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 505/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 506/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 507/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 508/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 509/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 510/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0340 - 2s/epoch - 4ms/step
# Epoch 511/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0339 - 2s/epoch - 4ms/step
# Epoch 512/512
# 514/514 - 2s - loss: 0.0341 - val_loss: 0.0339 - 2s/epoch - 4ms/step

# %%
# save model
# model.save("./DNN_pz.h5", save_format="h5", overwrite=True)
# predict
pred_y = model.predict(test_x)
sig_pred = pred_y                                                                                      
sig_truth = test_y
# Out:
# 12323/12323 [==============================] - 14s 1ms/step

# %%
print(f"Truth mean: {np.mean(sig_truth[:,0]):.3f}, std: {np.std(sig_truth[:,0]):.3f}")
# Out:
# Truth mean: 0.207, std: 0.195

# %%
range = [0.43, 0.57]

plot.plot_hist(
    [sig_truth[:, 0], sig_pred[:, 0]],
    [r"$p_{z\ truth}^{\nu}$", r"$p_{z\ pred}^{\nu}$"],
    r"Sig. norm. $p^{\nu}_{z}$"
    + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth[:,0], sig_pred[:,0])):.3f}",
    # range=range,
    xlabel=r"Norm. $E$ [unit]",
)

plot.plot_loss_history(history, logx=True, logy=True)

plot.plot_2d_histogram(
    sig_truth[:, 0],
    sig_pred[:, 0],
    r"Sig. $E^{\nu}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth[:,0], sig_pred[:,0])[0]:.3f}",
    # range=range,
)

# time_end = time()
# print(f"Time cost: {time_end - time_start:.2f} s")
