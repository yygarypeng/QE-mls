# %%
# %reset -sf

import sys
sys.path.insert(0, '../qe')
import get_data as gd
import atlas_plot as ap
plot = ap.Plotter()

import pandas as pd
import numpy as np
import scipy as sp

import os
import glob

from matplotlib import pyplot as plt

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import StandardScaler, RobustScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import tensorflow as tf
print(tf.__version__)


# GPU(s) setups
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[1], 'GPU')
        
        # Instead of enabling memory growth, set a memory limit
        memory_limit = 32_768 # Set the memory limit in MB
        tf.config.experimental.set_virtual_device_configuration(
            gpus[1],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]
        )
        
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2.13.0
# 2 Physical GPUs, 1 Logical GPU

# %%
SEED = 42  # set random seed (global variable)
np.random.seed(SEED)
processor = gd.DataProcessor()
path = "/root/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 76
#
# ['/root/data/truth/signal/CGLMP.npz', '/root/data/truth/signal/Higgs.npz', '/root/data/truth/signal/LeadLepton.npz', '/root/data/truth/signal/LeptonM.npz', '/root/data/truth/signal/LeptonP.npz', '/root/data/truth/signal/LmNu.npz', '/root/data/truth/signal/LpNu.npz', '/root/data/truth/signal/MET.npz', '/root/data/truth/signal/WmBoson.npz', '/root/data/truth/signal/WpBoson.npz', '/root/data/truth/signal/diLepton.npz', '/root/data/truth/signal/subLeadLepton.npz', '/root/data/truth/signal/xi_xyz.npz']

# %%
## Global variables

GEV = 1e3

# cut_pre_pt_lead = data.LeadLep["pt"] > 35 * GEV
# cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
# cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
# cut_pre_pt_miss = data.MET["pt"] > 20 * GEV

cut_pre_pt_lead = data.LeadLep["pt"] > -9999 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > -9999 * GEV
cut_pre_dilep_m = data.diLep["m"] > -9999 * GEV
cut_pre_pt_miss = data.MET["pt"] > -9999 * GEV

PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

BATCH_SIZE = 4_096
EPOCHS = 1_024
LEARNING_RATE = 1e-4

# %%
## Interesting variables

# Critria for leading and subleading lepton
lead_p = data.LeadLep["m"] == data.LepP["m"]
sublead_p = ~lead_p
lead_m = sublead_p.copy()
sublead_m = lead_p.copy()

# (sub)lead W
w_lead = pd.concat([data.Wp[lead_p], data.Wm[lead_m]], axis=0).sort_index()
w_sublead = pd.concat([data.Wp[sublead_p], data.Wm[sublead_m]], axis=0).sort_index()
print("w_lead shape:", w_lead.shape)
print(w_lead.head(3))
print(w_lead.describe())

# Check (sub)lead W
plt.hist(w_lead["m"] / GEV, bins=100, color="r", histtype="step", label=r"$W^{lead}$")
plt.hist(
    w_sublead["m"] / GEV, bins=100, color="b", histtype="step", label=r"$W^{sublead}$"
)
plt.title("W mass")
plt.xlabel("mass [GeV]")
plt.ylabel("count")
plt.legend(loc="best")
plt.show()
plt.close()
# Check (sub)lead W
plt.hist(
    w_lead["m"][PRE_CUT] / GEV,
    bins=100,
    color="r",
    histtype="step",
    label=r"$W^{lead}$",
)
plt.hist(
    w_sublead["m"][PRE_CUT] / GEV,
    bins=100,
    color="b",
    histtype="step",
    label=r"$W^{sublead}$",
)
plt.title("Cut W mass")
plt.xlabel("mass [GeV]")
plt.ylabel("count")
plt.legend(loc="best")
plt.show()
plt.close()

# Kinematics of interesting variables (target for training)
int_kin = w_lead[["E", "px", "py", "pz", "pt", "eta", "phi"]][PRE_CUT] / GEV
print("int_kin shape:", int_kin.shape)
print(int_kin.describe())
# int_kin = int_kin.to_numpy() # convert to numpy array
# STDSCALAR_INT = StandardScaler()
# int_kin = STDSCALAR_INT.fit_transform(int_kin)
ROBUST_INT = RobustScaler()
int_kin = ROBUST_INT.fit_transform(int_kin)
# ROBUST_INT = RobustScaler()
# int_kin = ROBUST_INT.fit_transform(int_kin)
print(type(int_kin))
# Out:
# w_lead shape: (2928862, 9)
#                E            px            py             pz             m  \
# 0  114813.382812 -16190.328125  63319.132812   50221.468750  79927.953125
# 1  450737.750000  70425.804688   3821.072266  438394.468750  77462.359375
# 2  102566.046875 -10254.437500  45208.792969   79655.101562  45009.675781
#
#              pt       eta       phi         y
# 0  65356.249165  0.707823  1.821127  0.469034
# 1  70529.387911  2.526646  0.054204  2.138567
# 2  46357.183371  1.310057  1.793846  1.036803
#                   E            px            py            pz             m  \
# count  2.928862e+06  2.928862e+06  2.928862e+06  2.928862e+06  2.928862e+06
# mean   2.283278e+05 -1.788823e+01  1.700620e+01  2.688194e+02  7.062466e+04
# std    2.440128e+05  3.510948e+04  3.504798e+04  3.222953e+05  1.877761e+04
# min    1.596886e+04 -1.474598e+06 -7.555793e+05 -4.386726e+06  2.000148e+03
# 25%    9.528028e+04 -1.782399e+04 -1.778516e+04 -1.062248e+05  7.283715e+04
# 50%    1.397490e+05 -7.059609e+00  1.686714e+00  2.295375e+02  7.960655e+04
# 75%    2.580234e+05  1.782398e+04  1.782713e+04  1.065598e+05  8.073579e+04
# max    4.387744e+06  8.572401e+05  8.429514e+05  4.286328e+06  1.160078e+05
#
#                  pt           eta           phi             y
# count  2.928862e+06  2.928862e+06  2.928862e+06  2.928862e+06
# mean   3.827814e+04  3.248780e-03  8.722714e-05  2.046535e-03
# std    3.155663e+04  2.378962e+00  1.814154e+00  1.486413e+00
# min    2.616221e+01 -9.765148e+00 -3.141592e+00 -5.059197e+00
# 25%    1.923133e+04 -1.942529e+00 -1.570932e+00 -1.084277e+00
# 50%    3.036986e+04  6.457000e-03  1.625000e-04  2.910500e-03
# 75%    4.686173e+04  1.948682e+00  1.571399e+00  1.087191e+00
# max    1.480359e+06  1.018382e+01  3.141590e+00  4.917896e+00
# int_kin shape: (2928862, 7)
#                   E            px            py            pz            pt  \
# count  2.928862e+06  2.928862e+06  2.928862e+06  2.928862e+06  2.928862e+06
# mean   2.283278e+02 -1.788823e-02  1.700620e-02  2.688194e-01  3.827814e+01
# std    2.440128e+02  3.510948e+01  3.504798e+01  3.222953e+02  3.155663e+01
# min    1.596886e+01 -1.474598e+03 -7.555793e+02 -4.386726e+03  2.616221e-02
# 25%    9.528028e+01 -1.782399e+01 -1.778516e+01 -1.062248e+02  1.923133e+01
# 50%    1.397490e+02 -7.059609e-03  1.686714e-03  2.295375e-01  3.036986e+01
# 75%    2.580234e+02  1.782398e+01  1.782713e+01  1.065598e+02  4.686173e+01
# max    4.387744e+03  8.572401e+02  8.429514e+02  4.286328e+03  1.480359e+03
#
#                 eta           phi
# count  2.928862e+06  2.928862e+06
# mean   3.248780e-06  8.722714e-08
# std    2.378962e-03  1.814154e-03
# min   -9.765148e-03 -3.141592e-03
# 25%   -1.942529e-03 -1.570932e-03
# 50%    6.457000e-06  1.625000e-07
# 75%    1.948682e-03  1.571399e-03
# max    1.018382e-02  3.141590e-03
# <class 'numpy.ndarray'>

# %%
## Observing variables

met = data.MET[["px", "py"]]
lead_lep = data.LeadLep[["E", "px", "py", "pz", "pt", "eta", "phi"]]
sublead_lep = data.SubLep[["E", "px", "py", "pz", "pt", "eta", "phi"]]

# Kinematics of observing variables (inputs for training)
obs_kin = pd.concat([lead_lep, sublead_lep, met], axis=1)[PRE_CUT] / GEV
print("int_kin shape:", obs_kin.shape)
print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array
ROBUST_OBS = RobustScaler()
obs_kin = ROBUST_OBS.fit_transform(obs_kin)
print(type(obs_kin))
# Out:
# int_kin shape: (2928862, 16)
#                   E            px            py            pz            pt  \
# count  2.928862e+06  2.928862e+06  2.928862e+06  2.928862e+06  2.928862e+06
# mean   1.197425e+02 -3.234511e-02  8.371231e-03  1.433632e-01  3.977981e+01
# std    1.498027e+02  3.141150e+01  3.138210e+01  1.865678e+02  1.972528e+01
# min    9.996190e-04 -8.960873e+02 -5.162718e+02 -3.097812e+03  3.322850e-04
# 25%    4.268904e+01 -2.281384e+01 -2.279909e+01 -5.112502e+01  2.793390e+01
# 50%    6.802523e+01 -4.159428e-02  3.938607e-02  5.318093e-02  3.595172e+01
# 75%    1.321814e+02  2.278163e+01  2.279003e+01  5.142163e+01  4.599537e+01
# max    3.199309e+03  8.355693e+02  5.822423e+02  3.199011e+03  8.970521e+02
#
#                 eta           phi             E            px            py  \
# count  2.928862e+06  2.928862e+06  2.928862e+06  2.928862e+06  2.928862e+06
# mean   1.854006e-06  1.128448e-06  6.328954e+01 -1.347791e-02 -9.528050e-03
# std    1.585678e-03  1.814440e-03  9.004996e+01  1.484416e+01  1.482693e+01
# min   -5.355181e-03 -3.141590e-03  9.161970e-04 -4.559332e+02 -2.842514e+02
# 25%   -1.133032e-03 -1.570449e-03  1.967983e+01 -9.904810e+00 -9.897398e+00
# 50%    1.607500e-06  2.342000e-06  3.313258e+01 -7.823901e-03 -2.778289e-02
# 75%    1.137263e-03  1.573570e-03  6.752385e+01  9.875597e+00  9.898291e+00
# max    5.267880e-03  3.141592e-03  2.640130e+03  2.492520e+02  2.642053e+02
#
#                  pz            pt           eta           phi            px  \
# count  2.928862e+06  2.928862e+06  2.928862e+06  2.928862e+06  2.928862e+06
# mean   6.949290e-02  1.833648e+01  1.734885e-06 -1.999300e-06  3.031304e-03
# std    1.080480e+02  1.019611e+01  1.705588e-03  1.814681e-03  3.826868e+01
# min   -2.292841e+03  2.120700e-04 -8.197855e-03 -3.141592e-03 -7.140328e+02
# 25%   -2.497558e+01  1.153132e+01 -1.201579e-03 -1.572739e-03 -2.601995e+01
# 50%    2.032285e-02  1.665609e+01  1.744000e-06 -4.936500e-06  2.764087e-02
# 75%    2.508894e+01  2.278523e+01  1.205163e-03  1.570298e-03  2.599545e+01
# max    2.639727e+03  4.566786e+02  9.739050e-03  3.141590e-03  7.917826e+02
#
#                  py
# count  2.928862e+06
# mean   1.529233e-03
# std    3.823335e+01
# min   -1.011480e+03
# 25%   -2.595961e+01
# 50%    6.623570e-04
# 75%    2.597993e+01
# max    8.692037e+02
# None
# <class 'numpy.ndarray'>

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.6,
    test_size=0.4,
    random_state=SEED,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=SEED
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# X (Interest)
# Training data shape: (1757317, 16);
# Validing data shape: (585772, 16);
# Testing data shape: (585773, 16).
# Y (Observed)
# Training data shape: (1757317, 7);
# Validing data shape: (585772, 7);
# Testing data shape: (585773, 7).

# %%
# Define a new activation function


def custom_activation(x):
    return (0.73 - (-0.27)) * (tf.tanh(x) + 1) / 2 + (-0.27)


# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    x = tf.keras.layers.Dense(units=8192, activation="elu")(x)
    x = tf.keras.layers.Dense(units=8192, activation="elu")(x)
    x = tf.keras.layers.Dropout(rate=0.5)(x)
    x = tf.keras.layers.Dense(units=512, activation="elu")(x)
    x = tf.keras.layers.Dense(units=512, activation="elu")(x)
    x = tf.keras.layers.Dropout(rate=0.3)(x)
    x = tf.keras.layers.Dense(units=64, activation="elu")(x)
    x = tf.keras.layers.Dense(units=64, activation="elu")(x)

    # Last dense layer
    outputs = tf.keras.layers.Dense(units=train_y.shape[-1], activation="linear")(x)

    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss="mse",
    )

    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 16)]              0
#
#  flatten (Flatten)           (None, 16)                0
#
#  dense (Dense)               (None, 8192)              139264
#
#  dense_1 (Dense)             (None, 8192)              67117056
#
#  dropout (Dropout)           (None, 8192)              0
#
#  dense_2 (Dense)             (None, 512)               4194816
#
#  dense_3 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 64)                32832
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dense_6 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 71751239 (273.71 MB)
# Trainable params: 71751239 (273.71 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-6,
    patience=20,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)


def scheduler(epoch, lr):
    if epoch < 100:
        return lr
    else:
        return lr * tf.math.exp(-0.01)


lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

# Fit the model
history = model.fit(
    x=train_x,
    y=train_y,
    validation_data=(valid_x, valid_y),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=2,
    use_multiprocessing=True,
    callbacks=[stop_early],
    # callbacks=[stop_early,lr_scheduler],
)
# Out:
# Epoch 1/1024
# 430/430 - 28s - loss: 0.3120 - val_loss: 0.2715 - 28s/epoch - 64ms/step
# Epoch 2/1024
# 430/430 - 20s - loss: 0.2782 - val_loss: 0.2613 - 20s/epoch - 47ms/step
# Epoch 3/1024
# 430/430 - 20s - loss: 0.2713 - val_loss: 0.2585 - 20s/epoch - 47ms/step
# Epoch 4/1024
# 430/430 - 21s - loss: 0.2660 - val_loss: 0.2533 - 21s/epoch - 48ms/step
# Epoch 5/1024
# 430/430 - 21s - loss: 0.2624 - val_loss: 0.2527 - 21s/epoch - 48ms/step
# Epoch 6/1024
# 430/430 - 21s - loss: 0.2594 - val_loss: 0.2484 - 21s/epoch - 48ms/step
# Epoch 7/1024
# 430/430 - 21s - loss: 0.2572 - val_loss: 0.2471 - 21s/epoch - 48ms/step
# Epoch 8/1024
# 430/430 - 21s - loss: 0.2557 - val_loss: 0.2463 - 21s/epoch - 48ms/step
# Epoch 9/1024
# 430/430 - 21s - loss: 0.2539 - val_loss: 0.2457 - 21s/epoch - 48ms/step
# Epoch 10/1024
# 430/430 - 21s - loss: 0.2527 - val_loss: 0.2448 - 21s/epoch - 48ms/step
# Epoch 11/1024
# 430/430 - 21s - loss: 0.2515 - val_loss: 0.2465 - 21s/epoch - 48ms/step
# Epoch 12/1024
# 430/430 - 21s - loss: 0.2513 - val_loss: 0.2429 - 21s/epoch - 48ms/step
# Epoch 13/1024
# 430/430 - 21s - loss: 0.2498 - val_loss: 0.2423 - 21s/epoch - 48ms/step
# Epoch 14/1024
# 430/430 - 20s - loss: 0.2493 - val_loss: 0.2435 - 20s/epoch - 47ms/step
# Epoch 15/1024
# 430/430 - 20s - loss: 0.2489 - val_loss: 0.2415 - 20s/epoch - 46ms/step
# Epoch 16/1024
# 430/430 - 19s - loss: 0.2479 - val_loss: 0.2437 - 19s/epoch - 45ms/step
# Epoch 17/1024
# 430/430 - 20s - loss: 0.2477 - val_loss: 0.2412 - 20s/epoch - 46ms/step
# Epoch 18/1024
# 430/430 - 21s - loss: 0.2470 - val_loss: 0.2417 - 21s/epoch - 48ms/step
# Epoch 19/1024
# 430/430 - 21s - loss: 0.2466 - val_loss: 0.2410 - 21s/epoch - 48ms/step
# Epoch 20/1024
# 430/430 - 21s - loss: 0.2461 - val_loss: 0.2404 - 21s/epoch - 48ms/step
# Epoch 21/1024
# 430/430 - 21s - loss: 0.2456 - val_loss: 0.2391 - 21s/epoch - 48ms/step
# Epoch 22/1024
# 430/430 - 21s - loss: 0.2453 - val_loss: 0.2399 - 21s/epoch - 48ms/step
# Epoch 23/1024
# 430/430 - 21s - loss: 0.2451 - val_loss: 0.2390 - 21s/epoch - 48ms/step
# Epoch 24/1024
# 430/430 - 21s - loss: 0.2447 - val_loss: 0.2399 - 21s/epoch - 48ms/step
# Epoch 25/1024
# 430/430 - 21s - loss: 0.2443 - val_loss: 0.2381 - 21s/epoch - 48ms/step
# Epoch 26/1024
# 430/430 - 21s - loss: 0.2439 - val_loss: 0.2388 - 21s/epoch - 48ms/step
# Epoch 27/1024
# 430/430 - 21s - loss: 0.2437 - val_loss: 0.2397 - 21s/epoch - 48ms/step
# Epoch 28/1024
# 430/430 - 21s - loss: 0.2435 - val_loss: 0.2390 - 21s/epoch - 49ms/step
# Epoch 29/1024
# 430/430 - 21s - loss: 0.2431 - val_loss: 0.2398 - 21s/epoch - 48ms/step
# Epoch 30/1024
# 430/430 - 21s - loss: 0.2428 - val_loss: 0.2385 - 21s/epoch - 49ms/step
# Epoch 31/1024
# 430/430 - 21s - loss: 0.2426 - val_loss: 0.2400 - 21s/epoch - 48ms/step
# Epoch 32/1024
# 430/430 - 21s - loss: 0.2425 - val_loss: 0.2369 - 21s/epoch - 48ms/step
# Epoch 33/1024
# 430/430 - 21s - loss: 0.2420 - val_loss: 0.2397 - 21s/epoch - 48ms/step
# Epoch 34/1024
# 430/430 - 21s - loss: 0.2420 - val_loss: 0.2373 - 21s/epoch - 48ms/step
# Epoch 35/1024
# 430/430 - 21s - loss: 0.2417 - val_loss: 0.2369 - 21s/epoch - 48ms/step
# Epoch 36/1024
# 430/430 - 21s - loss: 0.2415 - val_loss: 0.2365 - 21s/epoch - 48ms/step
# Epoch 37/1024
# 430/430 - 21s - loss: 0.2410 - val_loss: 0.2374 - 21s/epoch - 48ms/step
# Epoch 38/1024
# 430/430 - 21s - loss: 0.2411 - val_loss: 0.2366 - 21s/epoch - 48ms/step
# Epoch 39/1024
# 430/430 - 21s - loss: 0.2409 - val_loss: 0.2355 - 21s/epoch - 48ms/step
# Epoch 40/1024
# 430/430 - 21s - loss: 0.2404 - val_loss: 0.2348 - 21s/epoch - 48ms/step
# Epoch 41/1024
# 430/430 - 21s - loss: 0.2404 - val_loss: 0.2363 - 21s/epoch - 48ms/step
# Epoch 42/1024
# 430/430 - 21s - loss: 0.2406 - val_loss: 0.2366 - 21s/epoch - 48ms/step
# Epoch 43/1024
# 430/430 - 21s - loss: 0.2402 - val_loss: 0.2352 - 21s/epoch - 48ms/step
# Epoch 44/1024
# 430/430 - 21s - loss: 0.2399 - val_loss: 0.2354 - 21s/epoch - 48ms/step
# Epoch 45/1024
# 430/430 - 21s - loss: 0.2398 - val_loss: 0.2350 - 21s/epoch - 48ms/step
# Epoch 46/1024
# 430/430 - 21s - loss: 0.2395 - val_loss: 0.2363 - 21s/epoch - 48ms/step
# Epoch 47/1024
# 430/430 - 21s - loss: 0.2397 - val_loss: 0.2364 - 21s/epoch - 48ms/step
# Epoch 48/1024
# 430/430 - 20s - loss: 0.2394 - val_loss: 0.2360 - 20s/epoch - 47ms/step
# Epoch 49/1024
# 430/430 - 20s - loss: 0.2392 - val_loss: 0.2356 - 20s/epoch - 46ms/step
# Epoch 50/1024
# 430/430 - 19s - loss: 0.2392 - val_loss: 0.2365 - 19s/epoch - 45ms/step
# Epoch 51/1024
# 430/430 - 19s - loss: 0.2392 - val_loss: 0.2361 - 19s/epoch - 45ms/step
# Epoch 52/1024
# 430/430 - 20s - loss: 0.2387 - val_loss: 0.2362 - 20s/epoch - 47ms/step
# Epoch 53/1024
# 430/430 - 21s - loss: 0.2387 - val_loss: 0.2376 - 21s/epoch - 48ms/step
# Epoch 54/1024
# 430/430 - 21s - loss: 0.2386 - val_loss: 0.2347 - 21s/epoch - 48ms/step
# Epoch 55/1024
# 430/430 - 21s - loss: 0.2384 - val_loss: 0.2344 - 21s/epoch - 48ms/step
# Epoch 56/1024
# 430/430 - 21s - loss: 0.2381 - val_loss: 0.2368 - 21s/epoch - 48ms/step
# Epoch 57/1024
# 430/430 - 21s - loss: 0.2387 - val_loss: 0.2342 - 21s/epoch - 48ms/step
# Epoch 58/1024
# 430/430 - 21s - loss: 0.2380 - val_loss: 0.2369 - 21s/epoch - 48ms/step
# Epoch 59/1024
# 430/430 - 21s - loss: 0.2383 - val_loss: 0.2349 - 21s/epoch - 48ms/step
# Epoch 60/1024
# 430/430 - 21s - loss: 0.2377 - val_loss: 0.2342 - 21s/epoch - 48ms/step
# Epoch 61/1024
# 430/430 - 21s - loss: 0.2374 - val_loss: 0.2347 - 21s/epoch - 49ms/step
# Epoch 62/1024
# 430/430 - 21s - loss: 0.2375 - val_loss: 0.2340 - 21s/epoch - 48ms/step
# Epoch 63/1024
# 430/430 - 21s - loss: 0.2375 - val_loss: 0.2345 - 21s/epoch - 48ms/step
# Epoch 64/1024
# 430/430 - 21s - loss: 0.2372 - val_loss: 0.2361 - 21s/epoch - 48ms/step
# Epoch 65/1024
# 430/430 - 21s - loss: 0.2374 - val_loss: 0.2339 - 21s/epoch - 48ms/step
# Epoch 66/1024
# 430/430 - 21s - loss: 0.2368 - val_loss: 0.2329 - 21s/epoch - 48ms/step
# Epoch 67/1024
# 430/430 - 21s - loss: 0.2368 - val_loss: 0.2334 - 21s/epoch - 48ms/step
# Epoch 68/1024
# 430/430 - 21s - loss: 0.2369 - val_loss: 0.2340 - 21s/epoch - 48ms/step
# Epoch 69/1024
# 430/430 - 21s - loss: 0.2368 - val_loss: 0.2345 - 21s/epoch - 48ms/step
# Epoch 70/1024
# 430/430 - 21s - loss: 0.2367 - val_loss: 0.2340 - 21s/epoch - 48ms/step
# Epoch 71/1024
# 430/430 - 21s - loss: 0.2367 - val_loss: 0.2336 - 21s/epoch - 48ms/step
# Epoch 72/1024
# 430/430 - 21s - loss: 0.2364 - val_loss: 0.2336 - 21s/epoch - 48ms/step
# Epoch 73/1024
# 430/430 - 21s - loss: 0.2365 - val_loss: 0.2354 - 21s/epoch - 48ms/step
# Epoch 74/1024
# 430/430 - 21s - loss: 0.2364 - val_loss: 0.2328 - 21s/epoch - 48ms/step
# Epoch 75/1024
# 430/430 - 21s - loss: 0.2362 - val_loss: 0.2342 - 21s/epoch - 48ms/step
# Epoch 76/1024
# 430/430 - 21s - loss: 0.2361 - val_loss: 0.2332 - 21s/epoch - 48ms/step
# Epoch 77/1024
# 430/430 - 21s - loss: 0.2362 - val_loss: 0.2336 - 21s/epoch - 48ms/step
# Epoch 78/1024
# 430/430 - 21s - loss: 0.2359 - val_loss: 0.2339 - 21s/epoch - 48ms/step
# Epoch 79/1024
# 430/430 - 21s - loss: 0.2357 - val_loss: 0.2342 - 21s/epoch - 48ms/step
# Epoch 80/1024
# 430/430 - 21s - loss: 0.2357 - val_loss: 0.2329 - 21s/epoch - 48ms/step
# Epoch 81/1024
# 430/430 - 21s - loss: 0.2356 - val_loss: 0.2335 - 21s/epoch - 49ms/step
# Epoch 82/1024
# 430/430 - 21s - loss: 0.2356 - val_loss: 0.2330 - 21s/epoch - 48ms/step
# Epoch 83/1024
# 430/430 - 20s - loss: 0.2353 - val_loss: 0.2329 - 20s/epoch - 46ms/step
# Epoch 84/1024
# 430/430 - 19s - loss: 0.2354 - val_loss: 0.2339 - 19s/epoch - 45ms/step
# Epoch 85/1024
# 430/430 - 19s - loss: 0.2356 - val_loss: 0.2326 - 19s/epoch - 45ms/step
# Epoch 86/1024
# 430/430 - 20s - loss: 0.2352 - val_loss: 0.2347 - 20s/epoch - 47ms/step
# Epoch 87/1024
# 430/430 - 21s - loss: 0.2353 - val_loss: 0.2335 - 21s/epoch - 48ms/step
# Epoch 88/1024
# 430/430 - 21s - loss: 0.2351 - val_loss: 0.2329 - 21s/epoch - 48ms/step
# Epoch 89/1024
# 430/430 - 21s - loss: 0.2348 - val_loss: 0.2332 - 21s/epoch - 48ms/step
# Epoch 90/1024
# 430/430 - 21s - loss: 0.2349 - val_loss: 0.2349 - 21s/epoch - 48ms/step
# Epoch 91/1024
# 430/430 - 21s - loss: 0.2348 - val_loss: 0.2332 - 21s/epoch - 48ms/step
# Epoch 92/1024
# 430/430 - 21s - loss: 0.2347 - val_loss: 0.2326 - 21s/epoch - 49ms/step
# Epoch 93/1024
# 430/430 - 21s - loss: 0.2347 - val_loss: 0.2325 - 21s/epoch - 48ms/step
# Epoch 94/1024
# 430/430 - 21s - loss: 0.2346 - val_loss: 0.2343 - 21s/epoch - 49ms/step
# Epoch 95/1024
# 430/430 - 21s - loss: 0.2345 - val_loss: 0.2338 - 21s/epoch - 48ms/step
# Epoch 96/1024
# 430/430 - 21s - loss: 0.2346 - val_loss: 0.2327 - 21s/epoch - 48ms/step
# Epoch 97/1024
# 430/430 - 21s - loss: 0.2342 - val_loss: 0.2327 - 21s/epoch - 49ms/step
# Epoch 98/1024
# 430/430 - 21s - loss: 0.2343 - val_loss: 0.2326 - 21s/epoch - 48ms/step
# Epoch 99/1024
# 430/430 - 21s - loss: 0.2343 - val_loss: 0.2335 - 21s/epoch - 49ms/step
# Epoch 100/1024
# 430/430 - 21s - loss: 0.2341 - val_loss: 0.2329 - 21s/epoch - 48ms/step
# Epoch 101/1024
# 430/430 - 21s - loss: 0.2340 - val_loss: 0.2329 - 21s/epoch - 48ms/step
# Epoch 102/1024
# 430/430 - 21s - loss: 0.2341 - val_loss: 0.2330 - 21s/epoch - 49ms/step
# Epoch 103/1024
# 430/430 - 21s - loss: 0.2341 - val_loss: 0.2333 - 21s/epoch - 48ms/step
# Epoch 104/1024
# 430/430 - 21s - loss: 0.2338 - val_loss: 0.2322 - 21s/epoch - 48ms/step
# Epoch 105/1024
# 430/430 - 21s - loss: 0.2336 - val_loss: 0.2325 - 21s/epoch - 48ms/step
# Epoch 106/1024
# 430/430 - 21s - loss: 0.2335 - val_loss: 0.2325 - 21s/epoch - 48ms/step
# Epoch 107/1024
# 430/430 - 21s - loss: 0.2335 - val_loss: 0.2328 - 21s/epoch - 49ms/step
# Epoch 108/1024
# 430/430 - 21s - loss: 0.2334 - val_loss: 0.2322 - 21s/epoch - 48ms/step
# Epoch 109/1024
# 430/430 - 21s - loss: 0.2335 - val_loss: 0.2330 - 21s/epoch - 48ms/step
# Epoch 110/1024
# 430/430 - 21s - loss: 0.2335 - val_loss: 0.2323 - 21s/epoch - 48ms/step
# Epoch 111/1024
# 430/430 - 21s - loss: 0.2333 - val_loss: 0.2319 - 21s/epoch - 48ms/step
# Epoch 112/1024
# 430/430 - 21s - loss: 0.2331 - val_loss: 0.2323 - 21s/epoch - 48ms/step
# Epoch 113/1024
# 430/430 - 21s - loss: 0.2331 - val_loss: 0.2328 - 21s/epoch - 48ms/step
# Epoch 114/1024
# 430/430 - 21s - loss: 0.2332 - val_loss: 0.2325 - 21s/epoch - 48ms/step
# Epoch 115/1024
# 430/430 - 21s - loss: 0.2330 - val_loss: 0.2320 - 21s/epoch - 48ms/step
# Epoch 116/1024
# 430/430 - 21s - loss: 0.2328 - val_loss: 0.2328 - 21s/epoch - 48ms/step
# Epoch 117/1024
# 430/430 - 20s - loss: 0.2328 - val_loss: 0.2324 - 20s/epoch - 47ms/step
# Epoch 118/1024
# 430/430 - 20s - loss: 0.2327 - val_loss: 0.2323 - 20s/epoch - 46ms/step
# Epoch 119/1024
# 430/430 - 19s - loss: 0.2325 - val_loss: 0.2324 - 19s/epoch - 45ms/step
# Epoch 120/1024
# 430/430 - 20s - loss: 0.2327 - val_loss: 0.2323 - 20s/epoch - 46ms/step
# Epoch 121/1024
# 430/430 - 21s - loss: 0.2325 - val_loss: 0.2325 - 21s/epoch - 48ms/step
# Epoch 122/1024
# 430/430 - 21s - loss: 0.2325 - val_loss: 0.2327 - 21s/epoch - 48ms/step
# Epoch 123/1024
# 430/430 - 21s - loss: 0.2324 - val_loss: 0.2323 - 21s/epoch - 48ms/step
# Epoch 124/1024
# 430/430 - 21s - loss: 0.2325 - val_loss: 0.2323 - 21s/epoch - 48ms/step
# Epoch 125/1024
# 430/430 - 21s - loss: 0.2324 - val_loss: 0.2324 - 21s/epoch - 48ms/step
# Epoch 126/1024
# 430/430 - 21s - loss: 0.2322 - val_loss: 0.2323 - 21s/epoch - 48ms/step
# Epoch 127/1024
# 430/430 - 21s - loss: 0.2323 - val_loss: 0.2317 - 21s/epoch - 48ms/step
# Epoch 128/1024
# 430/430 - 21s - loss: 0.2320 - val_loss: 0.2320 - 21s/epoch - 48ms/step
# Epoch 129/1024
# 430/430 - 21s - loss: 0.2321 - val_loss: 0.2319 - 21s/epoch - 48ms/step
# Epoch 130/1024
# 430/430 - 21s - loss: 0.2319 - val_loss: 0.2317 - 21s/epoch - 48ms/step
# Epoch 131/1024
# 430/430 - 21s - loss: 0.2317 - val_loss: 0.2325 - 21s/epoch - 48ms/step
# Epoch 132/1024
# 430/430 - 21s - loss: 0.2319 - val_loss: 0.2327 - 21s/epoch - 48ms/step
# Epoch 133/1024
# 430/430 - 21s - loss: 0.2318 - val_loss: 0.2323 - 21s/epoch - 48ms/step
# Epoch 134/1024
# 430/430 - 21s - loss: 0.2317 - val_loss: 0.2324 - 21s/epoch - 48ms/step
# Epoch 135/1024
# 430/430 - 21s - loss: 0.2318 - val_loss: 0.2325 - 21s/epoch - 48ms/step
# Epoch 136/1024
# 430/430 - 21s - loss: 0.2315 - val_loss: 0.2327 - 21s/epoch - 48ms/step
# Epoch 137/1024
# 430/430 - 21s - loss: 0.2315 - val_loss: 0.2330 - 21s/epoch - 48ms/step
# Epoch 138/1024
# 430/430 - 21s - loss: 0.2312 - val_loss: 0.2326 - 21s/epoch - 48ms/step
# Epoch 139/1024
# 430/430 - 21s - loss: 0.2316 - val_loss: 0.2324 - 21s/epoch - 48ms/step
# Epoch 140/1024
# 430/430 - 21s - loss: 0.2313 - val_loss: 0.2323 - 21s/epoch - 48ms/step
# Epoch 141/1024
# 430/430 - 21s - loss: 0.2311 - val_loss: 0.2326 - 21s/epoch - 48ms/step
# Epoch 142/1024
# 430/430 - 21s - loss: 0.2311 - val_loss: 0.2317 - 21s/epoch - 48ms/step
# Epoch 143/1024
# 430/430 - 21s - loss: 0.2311 - val_loss: 0.2343 - 21s/epoch - 48ms/step
# Epoch 144/1024
# 430/430 - 21s - loss: 0.2311 - val_loss: 0.2323 - 21s/epoch - 48ms/step
# Epoch 145/1024
# 430/430 - 21s - loss: 0.2312 - val_loss: 0.2323 - 21s/epoch - 48ms/step
# Epoch 146/1024
# 430/430 - 21s - loss: 0.2308 - val_loss: 0.2320 - 21s/epoch - 48ms/step
# Epoch 147/1024
# 430/430 - 21s - loss: 0.2307 - val_loss: 0.2320 - 21s/epoch - 48ms/step
# Epoch 148/1024
# 430/430 - 21s - loss: 0.2307 - val_loss: 0.2323 - 21s/epoch - 48ms/step
# Epoch 149/1024
# 430/430 - 21s - loss: 0.2305 - val_loss: 0.2318 - 21s/epoch - 48ms/step
# Epoch 150/1024
# 430/430 - 20s - loss: 0.2305 - val_loss: 0.2325 - 20s/epoch - 48ms/step
# Epoch 151/1024
# 430/430 - 20s - loss: 0.2307 - val_loss: 0.2320 - 20s/epoch - 47ms/step
# Epoch 152/1024
# 430/430 - 20s - loss: 0.2304 - val_loss: 0.2324 - 20s/epoch - 46ms/step
# Epoch 153/1024
# 430/430 - 19s - loss: 0.2305 - val_loss: 0.2328 - 19s/epoch - 45ms/step
# Epoch 154/1024
# 430/430 - 20s - loss: 0.2303 - val_loss: 0.2326 - 20s/epoch - 46ms/step
# Epoch 155/1024
# 430/430 - 21s - loss: 0.2301 - val_loss: 0.2322 - 21s/epoch - 48ms/step
# Epoch 156/1024
# 430/430 - 21s - loss: 0.2301 - val_loss: 0.2326 - 21s/epoch - 48ms/step
# Epoch 157/1024
# 430/430 - 21s - loss: 0.2303 - val_loss: 0.2323 - 21s/epoch - 48ms/step
# Epoch 158/1024
# 430/430 - 21s - loss: 0.2299 - val_loss: 0.2322 - 21s/epoch - 48ms/step
# Epoch 159/1024
# 430/430 - 21s - loss: 0.2301 - val_loss: 0.2329 - 21s/epoch - 48ms/step
# Epoch 160/1024
# 430/430 - 21s - loss: 0.2298 - val_loss: 0.2321 - 21s/epoch - 49ms/step
# Epoch 161/1024
# 430/430 - 21s - loss: 0.2299 - val_loss: 0.2321 - 21s/epoch - 49ms/step
# Epoch 162/1024
# 430/430 - 21s - loss: 0.2297 - val_loss: 0.2320 - 21s/epoch - 49ms/step

# %%
# Make a directory
dir_name = "./w_lead_result/"
name = "dnn_w_lead_full_scaled"

# If the directory exists
if os.path.exists(dir_name):
    test_files = glob.glob(dir_name + "*" + name + "*")
    if test_files:
        for file in test_files:
            os.remove(file)
else:
    os.makedirs(dir_name)

# save model
model.save(dir_name + name + ".h5", save_format="h5", overwrite=True)

# predict
pred_y = model.predict(test_x)
# save predicted results
np.savez_compressed(dir_name + name + "_data.npz", pred_y=pred_y, test_y=test_y)
sig_pred = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth = np.load(dir_name + name + "_data.npz")["test_y"]
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 18306/18306 [==============================] - 73s 4ms/step

# %%
plot.plot_loss_history(history, logx=False, logy=True)

# %%
sig_truth_inv = ROBUST_INT.inverse_transform(sig_truth)
sig_pred_inv = ROBUST_INT.inverse_transform(sig_pred)

# %%
# Make a directory
dir_name = "./w_lead_result/"
name = "dnn_w_lead_full"

# save predicted results
np.savez_compressed(
    dir_name + name + "_data.npz", pred_y=sig_pred_inv, test_y=sig_truth_inv
)
sig_pred_inv = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth_inv = np.load(dir_name + name + "_data.npz")["test_y"]

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,0]):.3f}, std: {np.std(sig_truth_inv[:,0]):.3f}, min: {np.min(sig_truth_inv[:,0]):.3f}, max: {np.max(sig_truth_inv[:,0]):.3f}"
)

set_range = [0, 600]

plot.hist(
    data=[sig_truth_inv[:, 0], sig_pred_inv[:, 0]],
    label=r"$E^{W}$",
    title="Leading $E^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,0], sig_pred_inv[:,0])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 0],
    sig_pred_inv[:, 0],
    r"Leading $E^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,0], sig_pred_inv[:,0])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 228.412, std: 244.739, min: 18.513, max: 3843.166

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,1]):.3f}, std: {np.std(sig_truth_inv[:,1]):.3f}, min: {np.min(sig_truth_inv[:,1]):.3f}, max: {np.max(sig_truth_inv[:,1]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 1], sig_pred_inv[:, 1]],
    label=r"$p_{x}^{W}$",
    title="Leading $p_{x}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,1], sig_pred_inv[:,1])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 1],
    sig_pred_inv[:, 1],
    r"Leading $p_{x}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,1], sig_pred_inv[:,1])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.017, std: 35.174, min: -680.444, max: 605.596

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,2]):.3f}, std: {np.std(sig_truth_inv[:,2]):.3f}, min: {np.min(sig_truth_inv[:,2]):.3f}, max: {np.max(sig_truth_inv[:,2]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 2], sig_pred_inv[:, 2]],
    label=r"$p_{y}^{W}$",
    title="Leading $p_{y}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,2], sig_pred_inv[:,2])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 2],
    sig_pred_inv[:, 2],
    r"Leading $p_{y}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,2], sig_pred_inv[:,2])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.052, std: 35.023, min: -633.311, max: 760.803

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,3]):.3f}, std: {np.std(sig_truth_inv[:,3]):.3f}, min: {np.min(sig_truth_inv[:,3]):.3f}, max: {np.max(sig_truth_inv[:,3]):.3f}"
)

set_range = [-1000, 1000]

plot.hist(
    data=[sig_truth_inv[:, 3], sig_pred_inv[:, 3]],
    label=r"$p_{z}^{W}$",
    title="Leading $p_{z}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,3], sig_pred_inv[:,3])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 3],
    sig_pred_inv[:, 3],
    r"Leading $p_{z}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,3], sig_pred_inv[:,3])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.424, std: 322.901, min: -3791.950, max: 3842.319

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,4]):.3f}, std: {np.std(sig_truth_inv[:,4]):.3f}, min: {np.min(sig_truth_inv[:,4]):.3f}, max: {np.max(sig_truth_inv[:,4]):.3f}"
)

set_range = [-10, 500] 

plot.hist(
    data=[sig_truth_inv[:,4], sig_pred_inv[:,4]],
    label=r"$p_{T}^{W}$",
    title="Leading $p_{T}^{W}$"
    + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,4], sig_pred_inv[:,4])):.3f}",
    range=set_range,
    unit="[null]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:,4],
    sig_pred_inv[:,4],
    r"Leading $p_{T}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,4], sig_pred_inv[:,4])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 38.272, std: 31.609, min: 0.048, max: 847.167

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,5]*GEV):.3f}, std: {np.std(sig_truth_inv[:,5]*GEV):.3f}, min: {np.min(sig_truth_inv[:,5]*GEV):.3f}, max: {np.max(sig_truth_inv[:,5]*GEV):.3f}"
)

set_range = [-10, 10] 

plot.hist(
    data=[sig_truth_inv[:,5]*GEV, sig_pred_inv[:,5]*GEV],
    label=r"$\eta^{W}$",
    title="Leading $\eta^{W}$"
    + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,5]*GEV, sig_pred_inv[:,5]*GEV)):.3f}",
    range=set_range,
    unit="[null]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:,5]*GEV,
    sig_pred_inv[:,5]*GEV,
    r"Leading $\eta^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,5]*GEV, sig_pred_inv[:,5]*GEV)[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.003, std: 2.379, min: -9.192, max: 9.015

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,6]*GEV):.3f}, std: {np.std(sig_truth_inv[:,6]*GEV):.3f}, min: {np.min(sig_truth_inv[:,6]*GEV):.3f}, max: {np.max(sig_truth_inv[:,6]*GEV):.3f}"
)

set_range = [-3.5, 3.5] 

plot.hist(
    data=[sig_truth_inv[:,6]*GEV, sig_pred_inv[:,6]*GEV],
    label=r"$\phi^{W}$",
    title="Leading $\phi^{W}$"
    + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,6]*GEV, sig_pred_inv[:,6]*GEV)):.3f}",
    range=set_range,
    unit="[rad]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:,6]*GEV,
    sig_pred_inv[:,6]*GEV,
    r"Leading $\phi^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,6]*GEV, sig_pred_inv[:,6]*GEV)[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.002, std: 1.811, min: -3.142, max: 3.142

# %%
import shap 
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

feature_names = [
    "lead_E",
    "lead_px",
    "lead_py",
    "lead_pz",
    "lead_pt",
    "lead_eta",
    "lead_phi",
    "sublead_E",
    "sublead_px",
    "sublead_py",
    "sublead_pz",
    "sublead_pt",
    "sublead_eta",
    "sublead_phi",
    "met_px",
    "met_py",
]
# lead
# Use DeepExplainer for SHAP values
explainer = shap.DeepExplainer(model, obs_kin[:1_024])
shap_values = explainer.shap_values(obs_kin[:1_024])
for i in range(shap_values.shape[-1]):
    plt.figure(figsize=(10, 6))
    shap.summary_plot(
        shap_values[:, :, i], obs_kin[:1_024],
        feature_names=feature_names,
        plot_type="dot",
        show=False
    )
    plt.title(f"SHAP Summary Plot for Lead Output: {feature_names[i]}") 
    plt.show()
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
