# %%
# %reset -sf

import tensorflow as tf
import tf_keras
print("Tensorflow:", tf.__version__)
import tensorflow_probability as tfp
print("Tensorflow Probability:", tfp.__version__)

# GPU(s) setups
gpus = tf.config.experimental.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(gpus[0], True)
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')
        
        # Enable memory growth for the first GPU
        tf.config.experimental.set_memory_growth(gpus[0], True)
        
        # Instead of enabling memory growth, set a memory limit
        memory_limit = 16_376 / 4 # Set the memory limit in MB
        # memory_limit = -1
        if memory_limit >= 0:
            tf.config.experimental.set_virtual_device_configuration(
                gpus[0],
                [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]
            )
            
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2025-03-07 13:30:44.763879: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-07 13:30:44.786831: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow: 2.16.1
# Tensorflow Probability: 0.24.0
# 1 Physical GPUs, 1 Logical GPU
# 2025-03-07 13:30:46.110886: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4094 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
import sys
import os
import glob

HOME_PATH = os.path.abspath("..")
sys.path.insert(0, HOME_PATH + "/qe")

import paper_plot as pp

plot = pp.Plotter()

import pandas as pd
import numpy as np
import scipy as sp
import ROOT
from ROOT import TLorentzVector, TVector3
import multiprocessing
WORKERS = 16

from matplotlib import pyplot as plt

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "1"  # suppress tensorflow imformation messages

from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

SEED = 42  # set random seed (global variable)
GEV = 1e-3

# %%
import full_data as data

# reco
lead_lep = data.Lead_lep()
sublead_lep = data.Sublead_lep()
met = data.Met()

# truth
truth_lead_lep = data.Truth_lead_lep()
truth_sublead_lep = data.Truth_sublead_lep()
Truth_dilep = data.Truth_dilep()
truth_met = data.Truth_met()

# target Ws
w_lead = data.Lead_w()
w_sublead = data.Sublead_w()
mc_weight = data.MC_weight()
# Out:
# ['/CGLMP', '/RecoLep0', '/RecoLep1', '/RecoMET', '/TruthCandLep0', '/TruthCandLep1', '/TruthCandMET', '/TruthHiggs', '/TruthLep0', '/TruthLep1', '/TruthLepN', '/TruthLepP', '/TruthNu0', '/TruthNu1', '/TruthNuN', '/TruthNuP', '/TruthW0', '/TruthW1', '/TruthWN', '/TruthWP', '/eventWeight', '/mcWeight', '/recoWeight', '/weight']

# %%
# define preselection cuts

cut_pre_pt_lead = lead_lep.pt > 22 # 22 ~ 40 (SY)
print(len(lead_lep.energy) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = sublead_lep.pt > 15
print(len(lead_lep.energy) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.sqrt(
        np.square(lead_lep.energy + sublead_lep.energy)
        - np.square(lead_lep.px + sublead_lep.px)
        - np.square(lead_lep.py + sublead_lep.py)
        - np.square(lead_lep.pz + sublead_lep.pz)
    )
    > 10
)
print(len(lead_lep.energy) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = met.pt > 20
print(len(lead_lep.energy) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print(len(lead_lep.energy) - np.sum(PRE_CUT * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# # define preselection cuts

# cut_pre_pt_lead = lead_lep.pt > -9999
# print(len(lead_lep.energy) - np.sum(cut_pre_pt_lead * 1))
# cut_pre_pt_sub = sublead_lep.pt > -9999
# print(len(lead_lep.energy) - np.sum(cut_pre_pt_sub * 1))
# cut_pre_dilep_m = (
#     np.sqrt(
#         np.square(lead_lep.energy + sublead_lep.energy)
#         - np.square(lead_lep.px + sublead_lep.px)
#         - np.square(lead_lep.py + sublead_lep.py)
#         - np.square(lead_lep.pz + sublead_lep.pz)
#     )
#     > -9999
# )
# print(len(lead_lep.energy) - np.sum(cut_pre_dilep_m * 1))
# cut_pre_pt_miss = met.pt > -9999
# print(len(lead_lep.energy) - np.sum(cut_pre_pt_miss * 1))
# PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
# print(len(lead_lep.energy) - np.sum(PRE_CUT * 1))
# del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)
# Out:
# 0
# 29961
# 44269
# 89634
# 157782

# %%
# truth
truth_lead_lep_px = pd.DataFrame(truth_lead_lep.px[PRE_CUT])
truth_lead_lep_py = pd.DataFrame(truth_lead_lep.py[PRE_CUT])
truth_lead_lep_pz = pd.DataFrame(truth_lead_lep.pz[PRE_CUT])
truth_lead_lep_energy = pd.DataFrame(truth_lead_lep.energy[PRE_CUT])
truth_lead_lep_p4 = pd.concat(
	[truth_lead_lep_px, truth_lead_lep_py, truth_lead_lep_pz, truth_lead_lep_energy],
	axis=1,
).to_numpy()
truth_sublead_lep_px = pd.DataFrame(truth_sublead_lep.px[PRE_CUT])
truth_sublead_lep_py = pd.DataFrame(truth_sublead_lep.py[PRE_CUT])
truth_sublead_lep_pz = pd.DataFrame(truth_sublead_lep.pz[PRE_CUT])
truth_sublead_lep_energy = pd.DataFrame(truth_sublead_lep.energy[PRE_CUT])
truth_sublead_lep_p4 = pd.concat(
	[truth_sublead_lep_px, truth_sublead_lep_py, truth_sublead_lep_pz, truth_sublead_lep_energy],
	axis=1,
).to_numpy()
# reco
lead_lep_px = pd.DataFrame(lead_lep.px[PRE_CUT])
lead_lep_py = pd.DataFrame(lead_lep.py[PRE_CUT])
lead_lep_pz = pd.DataFrame(lead_lep.pz[PRE_CUT])
lead_lep_energy = pd.DataFrame(lead_lep.energy[PRE_CUT])
lead_lep_p4 = pd.concat(
	[lead_lep_px, lead_lep_py, lead_lep_pz, lead_lep_energy],
	axis=1,
).to_numpy()
sublead_lep_px = pd.DataFrame(sublead_lep.px[PRE_CUT])
sublead_lep_py = pd.DataFrame(sublead_lep.py[PRE_CUT])
sublead_lep_pz = pd.DataFrame(sublead_lep.pz[PRE_CUT])
sublead_lep_energy = pd.DataFrame(sublead_lep.energy[PRE_CUT])
sublead_lep_p4 = pd.concat(
	[sublead_lep_px, sublead_lep_py, sublead_lep_pz, sublead_lep_energy],
	axis=1,
).to_numpy()

# %%
## Observing variables

obs_kin = np.column_stack(
    (
        lead_lep.px,
        lead_lep.py,
        lead_lep.pz,
        lead_lep.energy,
        sublead_lep.px,
        sublead_lep.py,
        sublead_lep.pz,
        sublead_lep.energy,
        # np.log(sublead_lep.energy),
        # np.log(lead_lep.energy),
        # lead_lep.eta,
        # sublead_lep.eta,
        met.px,
        met.py,
    )
)[PRE_CUT]

# weights
mc_weight = mc_weight.w.to_numpy()[PRE_CUT]

# Kinematics of observing variables (inputs for training)
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array

# ROBUST_OBS = RobustScaler()
# obs_kin = ROBUST_OBS.fit_transform(obs_kin)
# print(type(obs_kin))
# Out:
# int_kin shape: (851115, 10)

# %%
## Interesting variables

w_lead_px = pd.DataFrame(w_lead.px[PRE_CUT])
w_lead_py = pd.DataFrame(w_lead.py[PRE_CUT])
w_lead_pz = pd.DataFrame(w_lead.pz[PRE_CUT])
w_lead_e = pd.DataFrame(w_lead.energy[PRE_CUT])
w_lead_log_e = pd.DataFrame(np.log(w_lead_e))
w_lead_sqrt_e = pd.DataFrame(np.sqrt(w_lead_e))
w_sublead_px = pd.DataFrame(w_sublead.px[PRE_CUT])
w_sublead_py = pd.DataFrame(w_sublead.py[PRE_CUT])
w_sublead_pz = pd.DataFrame(w_sublead.pz[PRE_CUT])
w_sublead_e = pd.DataFrame(w_sublead.energy[PRE_CUT])
w_sublead_log_e = pd.DataFrame(np.log(w_sublead_e))
w_sublead_sqrt_e = pd.DataFrame(np.sqrt(w_sublead_e))
w_lead_m = pd.DataFrame(w_lead.m[PRE_CUT])
w_sublead_m = pd.DataFrame(w_sublead.m[PRE_CUT])

# Kinematics of interesting variables (target for training)
int_kin = np.concatenate(
    [
        w_lead_px,
        w_lead_py,
        w_lead_pz,
        w_lead_e,
        w_sublead_px,
        w_sublead_py,
        w_sublead_pz,
        w_sublead_e,
        # np.square(w_lead_m) / np.mean(w_lead_m),
        # np.square(w_sublead_m) / np.mean(w_lead_m),
        # w_lead_m,
        # w_sublead_m,
    ],
    axis=-1,
)
print("int_kin shape:", int_kin.shape)
# int_kin = int_kin.to_numpy()  # convert to numpy array
print(type(int_kin))
# Out:
# int_kin shape: (851115, 8)
# <class 'numpy.ndarray'>

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.8,
    test_size=0.2,
    random_state=SEED,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=SEED
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
# test_x = np.concatenate([test_x, valid_x], axis=0)

train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]
# test_y = np.concatenate([test_y, valid_y], axis=0)

print("Total evts:", len(indices_arr))
print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# Total evts: 851115
# X (Interest)
# Training data shape: (680892, 10);
# Validing data shape: (85111, 10);
# Testing data shape: (85112, 10).
# Y (Observed)
# Training data shape: (680892, 8);
# Validing data shape: (85111, 8);
# Testing data shape: (85112, 8).

# %%
# training variables
BATCH_SIZE = 512
EPOCHS = 1024
LEARNING_RATE = 1e-5

# create datasets
train_dataset = tf.data.Dataset.from_tensor_slices((
    tf.cast(train_x, tf.float32), 
    tf.cast(train_y, tf.float32)
)).cache().batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

valid_dataset = tf.data.Dataset.from_tensor_slices((
    tf.cast(valid_x, tf.float32), 
    tf.cast(valid_y, tf.float32)
)).cache().batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
# Out:
# 2025-03-07 13:30:50.778684: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 4.00GiB (4292870144 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-03-07 13:30:50.778781: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 3.60GiB (3863582976 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-03-07 13:30:50.778857: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 3.24GiB (3477224704 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-03-07 13:30:50.778929: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 2.91GiB (3129502208 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-03-07 13:30:50.779001: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 2.62GiB (2816551936 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-03-07 13:30:50.779071: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 2.36GiB (2534896640 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-03-07 13:30:50.779138: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 2.12GiB (2281406976 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-03-07 13:30:50.779206: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 1.91GiB (2053266176 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-03-07 13:30:50.779274: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 1.72GiB (1847939584 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-03-07 13:30:50.779339: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 1.55GiB (1663145728 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-03-07 13:30:50.779407: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 1.39GiB (1496831232 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-03-07 13:30:50.779479: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 1.25GiB (1347148032 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory

# %%
# losses

def nu_mass_loss_fn(x_batch, y_pred):
    _epsilon = 1e-10
    x_batch = tf.cast(x_batch, tf.float32) #leps info
    y_pred = tf.cast(y_pred, tf.float32)   # Ws info
    
    n0_4vect = y_pred[..., :4] - x_batch[..., :4]
    n1_4vect = y_pred[..., 4:8] - x_batch[..., 4:8]

    nu0_mass = tf.sqrt(
            tf.math.maximum(
                tf.abs( tf.square(n0_4vect[..., 3]) - 
                        tf.reduce_sum(tf.square(n0_4vect[..., :3]), axis=-1)), _epsilon
            )
        )
    nu1_mass = tf.sqrt(
            tf.math.maximum(
                tf.abs( tf.square(n1_4vect[..., 3]) - 
                        tf.reduce_sum(tf.square(n1_4vect[..., :3]), axis=-1)), _epsilon
            )
        )
    
    return tf.reduce_mean(nu0_mass + nu1_mass)

def dinu_pt_loss_fn(x_batch, y_pred):
    _epsilon = 1e-10
    x_batch = tf.cast(x_batch, tf.float32) #leps info
    y_pred = tf.cast(y_pred, tf.float32)   # Ws info
    
    n0_4vect = y_pred[..., :4] - x_batch[..., :4]
    n1_4vect = y_pred[..., 4:8] - x_batch[..., 4:8]
    
    nn_4vect = n0_4vect + n1_4vect
    nn_px = nn_4vect[..., 0]
    nn_py = nn_4vect[..., 1]
    
    nn_px_diff = tf.math.maximum(tf.abs(nn_px - x_batch[..., 8]), _epsilon)
    nn_py_diff = tf.math.maximum(tf.abs(nn_py - x_batch[..., 9]), _epsilon)
    
    return tf.reduce_mean(nn_px_diff + nn_py_diff)

def higgs_mass_loss_fn(y_pred):
    _epsilon = 1e-10
    y_pred = tf.cast(y_pred, tf.float32)
    
    w0_4Vect = y_pred[..., :4]
    w1_4Vect = y_pred[..., 4:8]
    higgs_4Vect = w0_4Vect + w1_4Vect
    
    higgs_mass = tf.sqrt(
        tf.math.maximum(
            tf.abs( tf.square(higgs_4Vect[..., 3]) - 
                    tf.reduce_sum(tf.square(higgs_4Vect[..., :3]), axis=-1)), _epsilon
        )
    )
    
    return tf.reduce_mean(tf.abs(higgs_mass - 125.0)) + _epsilon


def mae_loss_fn(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return tf.reduce_mean(tf.keras.losses.mae(y_true, y_pred))

# %%
class CustomModel(tf.keras.Model):
    def __init__(self, base_model):
        super().__init__()
        self.base_model = base_model
        self.current_epoch = tf.Variable(0.0, trainable=False)
        
        self.metric_dict = {
            'nu_mass_loss': tf.keras.metrics.Mean(name='nu_mass_loss'),
            'higgs_mass_loss': tf.keras.metrics.Mean(name='higgs_mass_loss'),
            'dinu_pt_loss': tf.keras.metrics.Mean(name='dinu_pt_loss'),
            'fused_output_loss': tf.keras.metrics.Mean(name='fused_output_loss'),
            'loss': tf.keras.metrics.Mean(name='loss'),
        }

    def call(self, inputs, training=None):
        return self.base_model(inputs, training=training)
    
    def compile(self, optimizer, loss_weights=None, **kwargs):
        super().compile(optimizer=optimizer, **kwargs)
        default_weights = {
            'mae1': 0.0,
            'mae2': 0.0,
            'nu_mass': 0.0,
            'higgs_mass': 0.0,
            'dinu_pt': 0.0,
            'fused_output': 0.0
        }
        self.loss_weights = {**default_weights, **(loss_weights or {})}

    @property
    def metrics(self):
        return list(self.metric_dict.values())

    def _compute_losses(self, x, y, predictions):
        fused_output = predictions
        
        losses = {
            'nu_mass': nu_mass_loss_fn(x, fused_output),
            'higgs_mass': higgs_mass_loss_fn(fused_output),
            'dinu_pt': dinu_pt_loss_fn(x, fused_output),
            'fused_output': mae_loss_fn(y, fused_output)
        }
        
        total_loss = tf.add_n([
            self.loss_weights[name] * loss for name, loss in losses.items()
        ])
        
        return total_loss, losses

    def _update_metrics(self, total_loss, losses):
        """Helper method to update metrics"""
        self.metric_dict['loss'].update_state(total_loss)
        for name, loss in losses.items():
            self.metric_dict[f'{name}_loss'].update_state(loss)
        # self.metric_dict['lambda_weight'].update_state(tf.reduce_mean(lambda_weight))  # Track mean

    def train_step(self, data):
        x, y = data
        with tf.GradientTape() as tape:
            predictions = self(x, training=True)
            total_loss, losses = self._compute_losses(x, y, predictions)
            
        gradients = tape.gradient(total_loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        self._update_metrics(total_loss, losses)
        # self.current_epoch.assign_add(1.0)
        
        return {name: metric.result() for name, metric in self.metric_dict.items()}

    def test_step(self, data):
        x, y = data
        predictions = self(x, training=False)
        total_loss, losses = self._compute_losses(x, y, predictions)
        self._update_metrics(total_loss, losses)
        
        return {name: metric.result() for name, metric in self.metric_dict.items()}

# %%
# Define the WBosonFourVectorLayer (as provided earlier)
class WBosonFourVectorLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(WBosonFourVectorLayer, self).__init__(**kwargs)

    def call(self, inputs):
        lep0, lep1, nu_3mom = inputs
        nu0_3mom = nu_3mom[..., :3]  # [px, py, pz] for nu0
        nu1_3mom = nu_3mom[..., 3:]  # [px, py, pz] for nu1
        nu0_p_squared = tf.reduce_sum(tf.square(nu0_3mom), axis=-1, keepdims=True)
        nu1_p_squared = tf.reduce_sum(tf.square(nu1_3mom), axis=-1, keepdims=True)
        nu0_energy = tf.sqrt(tf.maximum(nu0_p_squared, 1e-10))
        nu1_energy = tf.sqrt(tf.maximum(nu1_p_squared, 1e-10))
        nu0_4vect = tf.concat([nu0_3mom, nu0_energy], axis=-1)
        nu1_4vect = tf.concat([nu1_3mom, nu1_energy], axis=-1)
        w0_4vect = lep0 + nu0_4vect
        w1_4vect = lep1 + nu1_4vect
        return tf.concat([w0_4vect, w1_4vect], axis=-1)

    def compute_output_shape(self, input_shape):
        return (input_shape[0][0], 8)

# %%
def dense_dropout_block(x, units, activation="swish", dropout_rate=0.0, l2=0.0):
    x = tf.keras.layers.Dense(
        units=units,
        use_bias=True,
        kernel_initializer='he_normal',
        kernel_regularizer=tf.keras.regularizers.L2(l2),
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    if dropout_rate > 0:    
        x = tf.keras.layers.Dropout(rate=dropout_rate)(x)
    return x

def residual_block(x, units, activation="swish", dropout_rate=0.0, l2=0.0):
    y = dense_dropout_block(x, units, activation=activation, dropout_rate=dropout_rate, l2=l2)
    y = dense_dropout_block(y, units, activation=activation, dropout_rate=dropout_rate, l2=l2)
    if x.shape[-1] != units:
        x = tf.keras.layers.Dense(units, activation=None, use_bias=False)(x)
    z = tf.keras.layers.Add()([x, y]) 
    z = tf.keras.layers.BatchNormalization()(z) 
    z = tf.keras.layers.Activation(activation)(z)
    return z

# %%
def build_model(input_shape):
    inputs = tf.keras.layers.Input(shape=(input_shape,), dtype=tf.float32)
    x = inputs
    
    # Subnet 1 --> Predict neutrino 3-momenta and apply physics layer
    for _ in range(2):
        x = residual_block(x, 128, dropout_rate=0.4, l2=1e-4)
        x = residual_block(x, 64, dropout_rate=0.4, l2=1e-4)
    for _ in range(2):
        # x = residual_block(x, 512, dropout_rate=0.4, l2=1e-4)
        x = residual_block(x, 256, dropout_rate=0.4, l2=1e-4)
        x = residual_block(x, 256, dropout_rate=0.4, l2=1e-4)
    for _ in range(2):
        x = residual_block(x, 64, dropout_rate=0.4, l2=1e-4)
        x = residual_block(x, 32, dropout_rate=0.4, l2=1e-4)
    # Bottleneck
    x = tf.keras.layers.Dense(16, activation=None, kernel_initializer='he_normal')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("swish")(x)
    
    outputs = tf.keras.layers.Dense(units=8, activation="linear", kernel_initializer='he_normal')(x)
    
    return tf.keras.Model(inputs=inputs, outputs=[outputs])

# %%
# # Add TensorBoard import at the top with other imports
# from datetime import datetime

# # In the callbacks section:
# current_time = datetime.now().strftime("%Y%m%d-%H%M%S")
# log_dir = f"{HOME_PATH}/10th_trial/logs/{current_time}"

# Build and compile model
base_model = build_model(train_x.shape[-1])
model = CustomModel(base_model)
model.summary()

# Model compilation with weights dictionary
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss_weights={
        'nu_mass': 0.0,
        'higgs_mass': 0.0,
        'dinu_pt': 0.0,
        'fused_output': 1.0
    },
    jit_compile=True,
    steps_per_execution=256,
)

# Updated callbacks
class EpochUpdater(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        self.model.current_epoch.assign(float(epoch))

class LambdaTracker(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        epoch_num = int(self.model.current_epoch.numpy())
        log_str = f"Epoch {epoch_num}"
        # Log all metrics
        for name, value in logs.items():
            log_str += f"; {name}: {value:.4f}"
        print(log_str)

# class DebugLogger(tf.keras.callbacks.Callback):
#     def on_epoch_end(self, epoch, logs=None):
#         current_epoch = self.model.current_epoch.numpy()
#         test_log_term = tf.math.log(tf.cast(current_epoch + 21.0, tf.float32)) - 3.0
#         print(f"Epoch {current_epoch}; Log factor: {test_log_term:.4f}; Mass loss: {logs['mass_loss']:.4f}")

callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    EpochUpdater(),
    LambdaTracker(),
    # tf.keras.callbacks.TensorBoard(
    #     log_dir=log_dir,
    #     histogram_freq=1,
    #     write_graph=True,
    #     write_images=True,
    #     update_freq='epoch',
    #     profile_batch=0,
    #     embeddings_freq=0,
    # ),
]

history = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=0,
)

# Print the weights
print("\nModel Loss Weights:")
for name, weight in model.loss_weights.items():
    print(f"{name:12s}: {weight:.3f}")
# Out:
# Model: "custom_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional (Functional)         │ (None, 8)              │       662,616 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 662,616 (2.53 MB)
#  Trainable params: 652,984 (2.49 MB)
#  Non-trainable params: 9,632 (37.62 KB)
# Epoch 0; dinu_pt_loss: 64.5415; fused_output_loss: 67.8430; higgs_mass_loss: 124.5190; loss: 67.8430; nu_mass_loss: 10.8601; val_dinu_pt_loss: 64.2217; val_fused_output_loss: 67.5898; val_higgs_mass_loss: 124.8720; val_loss: 67.5898; val_nu_mass_loss: 7.0240
# Epoch 1; dinu_pt_loss: 64.5322; fused_output_loss: 67.8262; higgs_mass_loss: 124.5329; loss: 67.8262; nu_mass_loss: 10.3248; val_dinu_pt_loss: 64.2216; val_fused_output_loss: 67.5811; val_higgs_mass_loss: 124.9140; val_loss: 67.5811; val_nu_mass_loss: 6.2478
# Epoch 2; dinu_pt_loss: 64.5227; fused_output_loss: 67.8091; higgs_mass_loss: 124.4894; loss: 67.8091; nu_mass_loss: 10.1074; val_dinu_pt_loss: 64.2218; val_fused_output_loss: 67.5716; val_higgs_mass_loss: 124.8310; val_loss: 67.5716; val_nu_mass_loss: 6.1022
# Epoch 3; dinu_pt_loss: 64.5129; fused_output_loss: 67.7911; higgs_mass_loss: 124.4114; loss: 67.7911; nu_mass_loss: 10.3734; val_dinu_pt_loss: 64.2223; val_fused_output_loss: 67.5616; val_higgs_mass_loss: 124.7819; val_loss: 67.5616; val_nu_mass_loss: 6.6899
# Epoch 4; dinu_pt_loss: 64.4961; fused_output_loss: 67.7707; higgs_mass_loss: 124.3536; loss: 67.7707; nu_mass_loss: 11.0244; val_dinu_pt_loss: 64.2231; val_fused_output_loss: 67.5511; val_higgs_mass_loss: 124.7441; val_loss: 67.5511; val_nu_mass_loss: 7.6400
# Epoch 5; dinu_pt_loss: 64.4837; fused_output_loss: 67.7473; higgs_mass_loss: 124.3074; loss: 67.7473; nu_mass_loss: 11.8477; val_dinu_pt_loss: 64.2242; val_fused_output_loss: 67.5393; val_higgs_mass_loss: 124.7139; val_loss: 67.5393; val_nu_mass_loss: 8.7789
# Epoch 6; dinu_pt_loss: 64.4624; fused_output_loss: 67.7198; higgs_mass_loss: 124.2697; loss: 67.7198; nu_mass_loss: 12.6771; val_dinu_pt_loss: 64.2255; val_fused_output_loss: 67.5277; val_higgs_mass_loss: 124.6819; val_loss: 67.5277; val_nu_mass_loss: 9.7724
# Epoch 7; dinu_pt_loss: 64.4331; fused_output_loss: 67.6873; higgs_mass_loss: 124.2268; loss: 67.6873; nu_mass_loss: 13.3815; val_dinu_pt_loss: 64.2267; val_fused_output_loss: 67.5157; val_higgs_mass_loss: 124.6546; val_loss: 67.5157; val_nu_mass_loss: 10.6274
# Epoch 8; dinu_pt_loss: 64.4078; fused_output_loss: 67.6492; higgs_mass_loss: 124.1714; loss: 67.6492; nu_mass_loss: 13.9732; val_dinu_pt_loss: 64.2277; val_fused_output_loss: 67.5031; val_higgs_mass_loss: 124.5957; val_loss: 67.5031; val_nu_mass_loss: 11.4729
# Epoch 9; dinu_pt_loss: 64.3767; fused_output_loss: 67.6039; higgs_mass_loss: 124.0418; loss: 67.6039; nu_mass_loss: 14.4272; val_dinu_pt_loss: 64.2288; val_fused_output_loss: 67.4941; val_higgs_mass_loss: 124.4591; val_loss: 67.4941; val_nu_mass_loss: 12.1161
# Epoch 10; dinu_pt_loss: 64.3412; fused_output_loss: 67.5521; higgs_mass_loss: 123.8159; loss: 67.5521; nu_mass_loss: 14.7823; val_dinu_pt_loss: 64.2304; val_fused_output_loss: 67.4857; val_higgs_mass_loss: 124.3006; val_loss: 67.4857; val_nu_mass_loss: 12.7567
# Epoch 11; dinu_pt_loss: 64.3018; fused_output_loss: 67.4944; higgs_mass_loss: 123.5688; loss: 67.4944; nu_mass_loss: 15.2280; val_dinu_pt_loss: 64.2325; val_fused_output_loss: 67.4744; val_higgs_mass_loss: 124.1469; val_loss: 67.4744; val_nu_mass_loss: 13.6186
# Epoch 12; dinu_pt_loss: 64.2537; fused_output_loss: 67.4313; higgs_mass_loss: 123.2800; loss: 67.4313; nu_mass_loss: 15.8065; val_dinu_pt_loss: 64.2358; val_fused_output_loss: 67.4616; val_higgs_mass_loss: 123.9357; val_loss: 67.4616; val_nu_mass_loss: 14.7096
# Epoch 13; dinu_pt_loss: 64.2090; fused_output_loss: 67.3570; higgs_mass_loss: 122.9097; loss: 67.3570; nu_mass_loss: 16.4430; val_dinu_pt_loss: 64.2407; val_fused_output_loss: 67.4469; val_higgs_mass_loss: 123.6204; val_loss: 67.4469; val_nu_mass_loss: 16.0850
# Epoch 14; dinu_pt_loss: 64.1774; fused_output_loss: 67.2625; higgs_mass_loss: 122.3985; loss: 67.2625; nu_mass_loss: 17.3409; val_dinu_pt_loss: 64.2481; val_fused_output_loss: 67.4262; val_higgs_mass_loss: 123.0576; val_loss: 67.4262; val_nu_mass_loss: 18.1433
# Epoch 15; dinu_pt_loss: 64.1951; fused_output_loss: 67.1247; higgs_mass_loss: 121.6494; loss: 67.1247; nu_mass_loss: 18.7846; val_dinu_pt_loss: 64.2258; val_fused_output_loss: 67.3628; val_higgs_mass_loss: 122.0548; val_loss: 67.3628; val_nu_mass_loss: 21.2482
# Epoch 16; dinu_pt_loss: 64.2437; fused_output_loss: 66.9394; higgs_mass_loss: 120.7469; loss: 66.9394; nu_mass_loss: 20.6866; val_dinu_pt_loss: 64.0402; val_fused_output_loss: 67.1179; val_higgs_mass_loss: 121.1856; val_loss: 67.1179; val_nu_mass_loss: 22.0032
# Epoch 17; dinu_pt_loss: 64.2930; fused_output_loss: 66.7731; higgs_mass_loss: 120.0124; loss: 66.7731; nu_mass_loss: 22.0207; val_dinu_pt_loss: 63.9611; val_fused_output_loss: 66.8598; val_higgs_mass_loss: 120.8013; val_loss: 66.8598; val_nu_mass_loss: 21.2243
# Epoch 18; dinu_pt_loss: 64.3176; fused_output_loss: 66.6411; higgs_mass_loss: 119.4657; loss: 66.6411; nu_mass_loss: 22.8024; val_dinu_pt_loss: 63.9697; val_fused_output_loss: 66.7095; val_higgs_mass_loss: 120.5209; val_loss: 66.7095; val_nu_mass_loss: 20.9457
# Epoch 19; dinu_pt_loss: 64.3131; fused_output_loss: 66.5243; higgs_mass_loss: 118.9949; loss: 66.5243; nu_mass_loss: 23.4254; val_dinu_pt_loss: 63.9789; val_fused_output_loss: 66.6081; val_higgs_mass_loss: 120.2743; val_loss: 66.6081; val_nu_mass_loss: 21.0181
# Epoch 20; dinu_pt_loss: 64.2936; fused_output_loss: 66.4152; higgs_mass_loss: 118.5612; loss: 66.4152; nu_mass_loss: 23.9866; val_dinu_pt_loss: 63.9749; val_fused_output_loss: 66.5361; val_higgs_mass_loss: 120.0837; val_loss: 66.5361; val_nu_mass_loss: 21.1644
# Epoch 21; dinu_pt_loss: 64.2673; fused_output_loss: 66.3097; higgs_mass_loss: 118.1546; loss: 66.3097; nu_mass_loss: 24.4920; val_dinu_pt_loss: 63.9587; val_fused_output_loss: 66.4712; val_higgs_mass_loss: 119.8917; val_loss: 66.4712; val_nu_mass_loss: 21.3465
# Epoch 22; dinu_pt_loss: 64.2313; fused_output_loss: 66.2039; higgs_mass_loss: 117.7590; loss: 66.2039; nu_mass_loss: 24.9249; val_dinu_pt_loss: 63.9371; val_fused_output_loss: 66.4122; val_higgs_mass_loss: 119.6994; val_loss: 66.4122; val_nu_mass_loss: 21.4750
# Epoch 23; dinu_pt_loss: 64.2113; fused_output_loss: 66.0997; higgs_mass_loss: 117.3692; loss: 66.0997; nu_mass_loss: 25.3138; val_dinu_pt_loss: 63.9088; val_fused_output_loss: 66.3397; val_higgs_mass_loss: 119.4712; val_loss: 66.3397; val_nu_mass_loss: 21.6203
# Epoch 24; dinu_pt_loss: 64.1991; fused_output_loss: 65.9934; higgs_mass_loss: 116.9868; loss: 65.9934; nu_mass_loss: 25.6541; val_dinu_pt_loss: 63.8704; val_fused_output_loss: 66.2646; val_higgs_mass_loss: 119.2389; val_loss: 66.2646; val_nu_mass_loss: 21.7518
# Epoch 25; dinu_pt_loss: 64.1926; fused_output_loss: 65.8865; higgs_mass_loss: 116.6054; loss: 65.8865; nu_mass_loss: 25.9906; val_dinu_pt_loss: 63.8371; val_fused_output_loss: 66.1811; val_higgs_mass_loss: 118.9705; val_loss: 66.1811; val_nu_mass_loss: 21.9258
# Epoch 26; dinu_pt_loss: 64.1867; fused_output_loss: 65.7781; higgs_mass_loss: 116.2300; loss: 65.7781; nu_mass_loss: 26.3184; val_dinu_pt_loss: 63.8011; val_fused_output_loss: 66.0917; val_higgs_mass_loss: 118.6900; val_loss: 66.0917; val_nu_mass_loss: 22.1403
# Epoch 27; dinu_pt_loss: 64.1896; fused_output_loss: 65.6688; higgs_mass_loss: 115.8605; loss: 65.6688; nu_mass_loss: 26.6448; val_dinu_pt_loss: 63.7741; val_fused_output_loss: 65.9866; val_higgs_mass_loss: 118.3641; val_loss: 65.9866; val_nu_mass_loss: 22.4838
# Epoch 28; dinu_pt_loss: 64.2013; fused_output_loss: 65.5573; higgs_mass_loss: 115.4940; loss: 65.5573; nu_mass_loss: 27.0069; val_dinu_pt_loss: 63.7439; val_fused_output_loss: 65.8812; val_higgs_mass_loss: 118.0429; val_loss: 65.8812; val_nu_mass_loss: 22.8255
# Epoch 29; dinu_pt_loss: 64.2141; fused_output_loss: 65.4437; higgs_mass_loss: 115.1372; loss: 65.4437; nu_mass_loss: 27.3718; val_dinu_pt_loss: 63.7187; val_fused_output_loss: 65.7730; val_higgs_mass_loss: 117.7243; val_loss: 65.7730; val_nu_mass_loss: 23.1985
# Epoch 30; dinu_pt_loss: 64.2280; fused_output_loss: 65.3283; higgs_mass_loss: 114.7985; loss: 65.3283; nu_mass_loss: 27.7596; val_dinu_pt_loss: 63.7058; val_fused_output_loss: 65.6615; val_higgs_mass_loss: 117.4156; val_loss: 65.6615; val_nu_mass_loss: 23.6291
# Epoch 31; dinu_pt_loss: 64.2432; fused_output_loss: 65.2114; higgs_mass_loss: 114.4674; loss: 65.2114; nu_mass_loss: 28.1612; val_dinu_pt_loss: 63.6907; val_fused_output_loss: 65.5403; val_higgs_mass_loss: 117.0854; val_loss: 65.5403; val_nu_mass_loss: 24.1264
# Epoch 32; dinu_pt_loss: 64.2571; fused_output_loss: 65.0923; higgs_mass_loss: 114.1443; loss: 65.0923; nu_mass_loss: 28.5883; val_dinu_pt_loss: 63.6793; val_fused_output_loss: 65.4147; val_higgs_mass_loss: 116.7615; val_loss: 65.4147; val_nu_mass_loss: 24.6463
# Epoch 33; dinu_pt_loss: 64.2656; fused_output_loss: 64.9701; higgs_mass_loss: 113.8426; loss: 64.9701; nu_mass_loss: 29.0147; val_dinu_pt_loss: 63.6807; val_fused_output_loss: 65.2888; val_higgs_mass_loss: 116.4572; val_loss: 65.2888; val_nu_mass_loss: 25.1735
# Epoch 34; dinu_pt_loss: 64.2718; fused_output_loss: 64.8459; higgs_mass_loss: 113.5535; loss: 64.8459; nu_mass_loss: 29.4466; val_dinu_pt_loss: 63.6772; val_fused_output_loss: 65.1592; val_higgs_mass_loss: 116.1540; val_loss: 65.1592; val_nu_mass_loss: 25.6904
# Epoch 35; dinu_pt_loss: 64.2852; fused_output_loss: 64.7195; higgs_mass_loss: 113.2780; loss: 64.7195; nu_mass_loss: 29.8740; val_dinu_pt_loss: 63.6748; val_fused_output_loss: 65.0189; val_higgs_mass_loss: 115.8313; val_loss: 65.0189; val_nu_mass_loss: 26.2606
# Epoch 36; dinu_pt_loss: 64.2782; fused_output_loss: 64.5895; higgs_mass_loss: 113.0195; loss: 64.5895; nu_mass_loss: 30.2911; val_dinu_pt_loss: 63.6846; val_fused_output_loss: 64.8804; val_higgs_mass_loss: 115.5352; val_loss: 64.8804; val_nu_mass_loss: 26.7832
# Epoch 37; dinu_pt_loss: 64.2738; fused_output_loss: 64.4569; higgs_mass_loss: 112.7760; loss: 64.4569; nu_mass_loss: 30.6910; val_dinu_pt_loss: 63.6779; val_fused_output_loss: 64.7456; val_higgs_mass_loss: 115.2816; val_loss: 64.7456; val_nu_mass_loss: 27.2421
# Epoch 38; dinu_pt_loss: 64.2559; fused_output_loss: 64.3221; higgs_mass_loss: 112.5449; loss: 64.3221; nu_mass_loss: 31.0715; val_dinu_pt_loss: 63.6754; val_fused_output_loss: 64.6092; val_higgs_mass_loss: 115.0264; val_loss: 64.6092; val_nu_mass_loss: 27.6558
# Epoch 39; dinu_pt_loss: 64.2409; fused_output_loss: 64.1841; higgs_mass_loss: 112.3202; loss: 64.1841; nu_mass_loss: 31.4114; val_dinu_pt_loss: 63.6791; val_fused_output_loss: 64.4620; val_higgs_mass_loss: 114.7496; val_loss: 64.4620; val_nu_mass_loss: 28.0718
# Epoch 40; dinu_pt_loss: 64.2207; fused_output_loss: 64.0434; higgs_mass_loss: 112.1014; loss: 64.0434; nu_mass_loss: 31.7335; val_dinu_pt_loss: 63.6721; val_fused_output_loss: 64.3233; val_higgs_mass_loss: 114.5275; val_loss: 64.3233; val_nu_mass_loss: 28.4379
# Epoch 41; dinu_pt_loss: 64.1962; fused_output_loss: 63.8999; higgs_mass_loss: 111.8778; loss: 63.8999; nu_mass_loss: 32.0383; val_dinu_pt_loss: 63.6605; val_fused_output_loss: 64.1888; val_higgs_mass_loss: 114.3026; val_loss: 64.1888; val_nu_mass_loss: 28.7049
# Epoch 42; dinu_pt_loss: 64.1647; fused_output_loss: 63.7536; higgs_mass_loss: 111.6471; loss: 63.7536; nu_mass_loss: 32.3283; val_dinu_pt_loss: 63.6447; val_fused_output_loss: 64.0492; val_higgs_mass_loss: 114.0406; val_loss: 64.0492; val_nu_mass_loss: 29.0060
# Epoch 43; dinu_pt_loss: 64.1314; fused_output_loss: 63.6049; higgs_mass_loss: 111.3971; loss: 63.6049; nu_mass_loss: 32.5900; val_dinu_pt_loss: 63.6189; val_fused_output_loss: 63.9071; val_higgs_mass_loss: 113.7291; val_loss: 63.9071; val_nu_mass_loss: 29.2702
# Epoch 44; dinu_pt_loss: 64.0817; fused_output_loss: 63.4520; higgs_mass_loss: 111.1366; loss: 63.4520; nu_mass_loss: 32.8443; val_dinu_pt_loss: 63.5679; val_fused_output_loss: 63.7562; val_higgs_mass_loss: 113.4542; val_loss: 63.7562; val_nu_mass_loss: 29.5759
# Epoch 45; dinu_pt_loss: 64.0173; fused_output_loss: 63.2970; higgs_mass_loss: 110.8738; loss: 63.2970; nu_mass_loss: 33.1105; val_dinu_pt_loss: 63.5128; val_fused_output_loss: 63.6011; val_higgs_mass_loss: 113.1667; val_loss: 63.6011; val_nu_mass_loss: 29.9186
# Epoch 46; dinu_pt_loss: 63.9497; fused_output_loss: 63.1401; higgs_mass_loss: 110.6074; loss: 63.1401; nu_mass_loss: 33.4010; val_dinu_pt_loss: 63.4532; val_fused_output_loss: 63.4432; val_higgs_mass_loss: 112.8770; val_loss: 63.4432; val_nu_mass_loss: 30.2977
# Epoch 47; dinu_pt_loss: 63.8842; fused_output_loss: 62.9807; higgs_mass_loss: 110.3401; loss: 62.9807; nu_mass_loss: 33.7279; val_dinu_pt_loss: 63.3861; val_fused_output_loss: 63.2817; val_higgs_mass_loss: 112.5847; val_loss: 63.2817; val_nu_mass_loss: 30.7361
# Epoch 48; dinu_pt_loss: 63.8161; fused_output_loss: 62.8190; higgs_mass_loss: 110.0697; loss: 62.8190; nu_mass_loss: 34.0653; val_dinu_pt_loss: 63.3117; val_fused_output_loss: 63.1241; val_higgs_mass_loss: 112.3339; val_loss: 63.1241; val_nu_mass_loss: 31.1255
# Epoch 49; dinu_pt_loss: 63.7369; fused_output_loss: 62.6550; higgs_mass_loss: 109.7975; loss: 62.6550; nu_mass_loss: 34.4270; val_dinu_pt_loss: 63.2451; val_fused_output_loss: 62.9579; val_higgs_mass_loss: 112.0308; val_loss: 62.9579; val_nu_mass_loss: 31.5781
# Epoch 50; dinu_pt_loss: 63.6567; fused_output_loss: 62.4885; higgs_mass_loss: 109.5256; loss: 62.4885; nu_mass_loss: 34.8021; val_dinu_pt_loss: 63.1717; val_fused_output_loss: 62.7898; val_higgs_mass_loss: 111.7329; val_loss: 62.7898; val_nu_mass_loss: 31.9905
# Epoch 51; dinu_pt_loss: 63.5695; fused_output_loss: 62.3201; higgs_mass_loss: 109.2531; loss: 62.3201; nu_mass_loss: 35.1822; val_dinu_pt_loss: 63.0859; val_fused_output_loss: 62.6250; val_higgs_mass_loss: 111.4649; val_loss: 62.6250; val_nu_mass_loss: 32.3977
# Epoch 52; dinu_pt_loss: 63.4740; fused_output_loss: 62.1485; higgs_mass_loss: 108.9812; loss: 62.1485; nu_mass_loss: 35.5609; val_dinu_pt_loss: 62.9992; val_fused_output_loss: 62.4513; val_higgs_mass_loss: 111.1797; val_loss: 62.4513; val_nu_mass_loss: 32.8281
# Epoch 53; dinu_pt_loss: 63.3683; fused_output_loss: 61.9750; higgs_mass_loss: 108.6999; loss: 61.9750; nu_mass_loss: 35.9480; val_dinu_pt_loss: 62.9146; val_fused_output_loss: 62.2769; val_higgs_mass_loss: 110.8843; val_loss: 62.2769; val_nu_mass_loss: 33.2322
# Epoch 54; dinu_pt_loss: 63.2602; fused_output_loss: 61.7988; higgs_mass_loss: 108.4179; loss: 61.7988; nu_mass_loss: 36.3277; val_dinu_pt_loss: 62.8107; val_fused_output_loss: 62.1052; val_higgs_mass_loss: 110.6018; val_loss: 62.1052; val_nu_mass_loss: 33.6281
# Epoch 55; dinu_pt_loss: 63.1475; fused_output_loss: 61.6198; higgs_mass_loss: 108.1294; loss: 61.6198; nu_mass_loss: 36.7130; val_dinu_pt_loss: 62.7147; val_fused_output_loss: 61.9236; val_higgs_mass_loss: 110.2683; val_loss: 61.9236; val_nu_mass_loss: 34.0374
# Epoch 56; dinu_pt_loss: 63.0260; fused_output_loss: 61.4394; higgs_mass_loss: 107.8392; loss: 61.4394; nu_mass_loss: 37.0888; val_dinu_pt_loss: 62.6093; val_fused_output_loss: 61.7431; val_higgs_mass_loss: 109.9631; val_loss: 61.7431; val_nu_mass_loss: 34.4481
# Epoch 57; dinu_pt_loss: 62.8998; fused_output_loss: 61.2560; higgs_mass_loss: 107.5349; loss: 61.2560; nu_mass_loss: 37.4845; val_dinu_pt_loss: 62.4900; val_fused_output_loss: 61.5566; val_higgs_mass_loss: 109.6403; val_loss: 61.5566; val_nu_mass_loss: 34.8913
# Epoch 58; dinu_pt_loss: 62.7690; fused_output_loss: 61.0700; higgs_mass_loss: 107.2249; loss: 61.0700; nu_mass_loss: 37.8778; val_dinu_pt_loss: 62.3761; val_fused_output_loss: 61.3672; val_higgs_mass_loss: 109.3042; val_loss: 61.3672; val_nu_mass_loss: 35.2972
# Epoch 59; dinu_pt_loss: 62.6410; fused_output_loss: 60.8828; higgs_mass_loss: 106.9057; loss: 60.8828; nu_mass_loss: 38.2751; val_dinu_pt_loss: 62.2531; val_fused_output_loss: 61.1714; val_higgs_mass_loss: 108.9478; val_loss: 61.1714; val_nu_mass_loss: 35.7485
# Epoch 60; dinu_pt_loss: 62.5005; fused_output_loss: 60.6932; higgs_mass_loss: 106.5742; loss: 60.6932; nu_mass_loss: 38.6732; val_dinu_pt_loss: 62.1292; val_fused_output_loss: 60.9753; val_higgs_mass_loss: 108.5773; val_loss: 60.9753; val_nu_mass_loss: 36.1978
# Epoch 61; dinu_pt_loss: 62.3643; fused_output_loss: 60.4996; higgs_mass_loss: 106.2309; loss: 60.4996; nu_mass_loss: 39.0805; val_dinu_pt_loss: 62.0079; val_fused_output_loss: 60.7843; val_higgs_mass_loss: 108.2069; val_loss: 60.7843; val_nu_mass_loss: 36.6000
# Epoch 62; dinu_pt_loss: 62.2187; fused_output_loss: 60.3055; higgs_mass_loss: 105.8772; loss: 60.3055; nu_mass_loss: 39.4880; val_dinu_pt_loss: 61.8782; val_fused_output_loss: 60.5876; val_higgs_mass_loss: 107.8398; val_loss: 60.5876; val_nu_mass_loss: 37.0242
# Epoch 63; dinu_pt_loss: 62.0805; fused_output_loss: 60.1090; higgs_mass_loss: 105.5130; loss: 60.1090; nu_mass_loss: 39.8953; val_dinu_pt_loss: 61.7437; val_fused_output_loss: 60.3821; val_higgs_mass_loss: 107.4140; val_loss: 60.3821; val_nu_mass_loss: 37.4821
# Epoch 64; dinu_pt_loss: 61.9224; fused_output_loss: 59.9103; higgs_mass_loss: 105.1487; loss: 59.9103; nu_mass_loss: 40.2997; val_dinu_pt_loss: 61.6080; val_fused_output_loss: 60.1771; val_higgs_mass_loss: 107.0371; val_loss: 60.1771; val_nu_mass_loss: 37.9176
# Epoch 65; dinu_pt_loss: 61.7730; fused_output_loss: 59.7088; higgs_mass_loss: 104.7755; loss: 59.7088; nu_mass_loss: 40.7172; val_dinu_pt_loss: 61.4596; val_fused_output_loss: 59.9661; val_higgs_mass_loss: 106.6374; val_loss: 59.9661; val_nu_mass_loss: 38.3745
# Epoch 66; dinu_pt_loss: 61.6125; fused_output_loss: 59.5059; higgs_mass_loss: 104.3998; loss: 59.5059; nu_mass_loss: 41.1363; val_dinu_pt_loss: 61.3079; val_fused_output_loss: 59.7562; val_higgs_mass_loss: 106.2366; val_loss: 59.7562; val_nu_mass_loss: 38.8245
# Epoch 67; dinu_pt_loss: 61.4539; fused_output_loss: 59.3003; higgs_mass_loss: 104.0235; loss: 59.3003; nu_mass_loss: 41.5516; val_dinu_pt_loss: 61.1475; val_fused_output_loss: 59.5521; val_higgs_mass_loss: 105.8555; val_loss: 59.5521; val_nu_mass_loss: 39.2545
# Epoch 68; dinu_pt_loss: 61.2898; fused_output_loss: 59.0935; higgs_mass_loss: 103.6371; loss: 59.0935; nu_mass_loss: 41.9804; val_dinu_pt_loss: 60.9954; val_fused_output_loss: 59.3288; val_higgs_mass_loss: 105.4113; val_loss: 59.3288; val_nu_mass_loss: 39.7549
# Epoch 69; dinu_pt_loss: 61.1166; fused_output_loss: 58.8840; higgs_mass_loss: 103.2517; loss: 58.8840; nu_mass_loss: 42.4058; val_dinu_pt_loss: 60.8392; val_fused_output_loss: 59.1182; val_higgs_mass_loss: 105.0154; val_loss: 59.1182; val_nu_mass_loss: 40.1875
# Epoch 70; dinu_pt_loss: 60.9528; fused_output_loss: 58.6734; higgs_mass_loss: 102.8571; loss: 58.6734; nu_mass_loss: 42.8408; val_dinu_pt_loss: 60.6762; val_fused_output_loss: 58.8925; val_higgs_mass_loss: 104.5896; val_loss: 58.8925; val_nu_mass_loss: 40.6796
# Epoch 71; dinu_pt_loss: 60.7782; fused_output_loss: 58.4600; higgs_mass_loss: 102.4658; loss: 58.4600; nu_mass_loss: 43.2677; val_dinu_pt_loss: 60.5083; val_fused_output_loss: 58.6791; val_higgs_mass_loss: 104.1854; val_loss: 58.6791; val_nu_mass_loss: 41.1308
# Epoch 72; dinu_pt_loss: 60.6060; fused_output_loss: 58.2453; higgs_mass_loss: 102.0611; loss: 58.2453; nu_mass_loss: 43.7072; val_dinu_pt_loss: 60.3279; val_fused_output_loss: 58.4574; val_higgs_mass_loss: 103.7664; val_loss: 58.4574; val_nu_mass_loss: 41.6045
# Epoch 73; dinu_pt_loss: 60.4307; fused_output_loss: 58.0289; higgs_mass_loss: 101.6570; loss: 58.0289; nu_mass_loss: 44.1528; val_dinu_pt_loss: 60.1538; val_fused_output_loss: 58.2388; val_higgs_mass_loss: 103.3480; val_loss: 58.2388; val_nu_mass_loss: 42.0711
# Epoch 74; dinu_pt_loss: 60.2478; fused_output_loss: 57.8099; higgs_mass_loss: 101.2509; loss: 57.8099; nu_mass_loss: 44.6003; val_dinu_pt_loss: 59.9870; val_fused_output_loss: 58.0095; val_higgs_mass_loss: 102.9146; val_loss: 58.0095; val_nu_mass_loss: 42.5649
# Epoch 75; dinu_pt_loss: 60.0672; fused_output_loss: 57.5889; higgs_mass_loss: 100.8331; loss: 57.5889; nu_mass_loss: 45.0524; val_dinu_pt_loss: 59.8041; val_fused_output_loss: 57.7814; val_higgs_mass_loss: 102.4854; val_loss: 57.7814; val_nu_mass_loss: 43.0521
# Epoch 76; dinu_pt_loss: 59.8896; fused_output_loss: 57.3667; higgs_mass_loss: 100.4059; loss: 57.3667; nu_mass_loss: 45.5080; val_dinu_pt_loss: 59.6392; val_fused_output_loss: 57.5607; val_higgs_mass_loss: 102.0577; val_loss: 57.5607; val_nu_mass_loss: 43.5211
# Epoch 77; dinu_pt_loss: 59.7071; fused_output_loss: 57.1434; higgs_mass_loss: 99.9769; loss: 57.1434; nu_mass_loss: 45.9727; val_dinu_pt_loss: 59.4471; val_fused_output_loss: 57.3222; val_higgs_mass_loss: 101.5668; val_loss: 57.3222; val_nu_mass_loss: 44.0334
# Epoch 78; dinu_pt_loss: 59.5305; fused_output_loss: 56.9180; higgs_mass_loss: 99.5352; loss: 56.9180; nu_mass_loss: 46.4359; val_dinu_pt_loss: 59.2712; val_fused_output_loss: 57.0951; val_higgs_mass_loss: 101.1400; val_loss: 57.0951; val_nu_mass_loss: 44.5139
# Epoch 79; dinu_pt_loss: 59.3439; fused_output_loss: 56.6899; higgs_mass_loss: 99.0938; loss: 56.6899; nu_mass_loss: 46.9024; val_dinu_pt_loss: 59.0971; val_fused_output_loss: 56.8699; val_higgs_mass_loss: 100.7092; val_loss: 56.8699; val_nu_mass_loss: 44.9810
# Epoch 80; dinu_pt_loss: 59.1616; fused_output_loss: 56.4620; higgs_mass_loss: 98.6409; loss: 56.4620; nu_mass_loss: 47.3694; val_dinu_pt_loss: 58.9026; val_fused_output_loss: 56.6193; val_higgs_mass_loss: 100.1922; val_loss: 56.6193; val_nu_mass_loss: 45.5228
# Epoch 81; dinu_pt_loss: 58.9831; fused_output_loss: 56.2316; higgs_mass_loss: 98.1840; loss: 56.2316; nu_mass_loss: 47.8412; val_dinu_pt_loss: 58.7383; val_fused_output_loss: 56.3909; val_higgs_mass_loss: 99.7151; val_loss: 56.3909; val_nu_mass_loss: 46.0091
# Epoch 82; dinu_pt_loss: 58.8074; fused_output_loss: 55.9995; higgs_mass_loss: 97.7264; loss: 55.9995; nu_mass_loss: 48.3111; val_dinu_pt_loss: 58.5461; val_fused_output_loss: 56.1462; val_higgs_mass_loss: 99.2437; val_loss: 56.1462; val_nu_mass_loss: 46.5282
# Epoch 83; dinu_pt_loss: 58.6247; fused_output_loss: 55.7661; higgs_mass_loss: 97.2566; loss: 55.7661; nu_mass_loss: 48.7812; val_dinu_pt_loss: 58.3706; val_fused_output_loss: 55.8991; val_higgs_mass_loss: 98.7353; val_loss: 55.8991; val_nu_mass_loss: 47.0474
# Epoch 84; dinu_pt_loss: 58.4427; fused_output_loss: 55.5308; higgs_mass_loss: 96.7780; loss: 55.5308; nu_mass_loss: 49.2618; val_dinu_pt_loss: 58.1755; val_fused_output_loss: 55.6577; val_higgs_mass_loss: 98.2339; val_loss: 55.6577; val_nu_mass_loss: 47.5521
# Epoch 85; dinu_pt_loss: 58.2685; fused_output_loss: 55.2947; higgs_mass_loss: 96.2890; loss: 55.2947; nu_mass_loss: 49.7434; val_dinu_pt_loss: 58.0135; val_fused_output_loss: 55.4184; val_higgs_mass_loss: 97.7309; val_loss: 55.4184; val_nu_mass_loss: 48.0605
# Epoch 86; dinu_pt_loss: 58.0933; fused_output_loss: 55.0567; higgs_mass_loss: 95.7949; loss: 55.0567; nu_mass_loss: 50.2109; val_dinu_pt_loss: 57.8318; val_fused_output_loss: 55.1736; val_higgs_mass_loss: 97.2430; val_loss: 55.1736; val_nu_mass_loss: 48.5641
# Epoch 87; dinu_pt_loss: 57.9237; fused_output_loss: 54.8178; higgs_mass_loss: 95.2890; loss: 54.8178; nu_mass_loss: 50.6847; val_dinu_pt_loss: 57.6664; val_fused_output_loss: 54.9261; val_higgs_mass_loss: 96.6949; val_loss: 54.9261; val_nu_mass_loss: 49.0723
# Epoch 88; dinu_pt_loss: 57.7536; fused_output_loss: 54.5768; higgs_mass_loss: 94.7787; loss: 54.5768; nu_mass_loss: 51.1726; val_dinu_pt_loss: 57.4732; val_fused_output_loss: 54.6762; val_higgs_mass_loss: 96.1516; val_loss: 54.6762; val_nu_mass_loss: 49.5953
# Epoch 89; dinu_pt_loss: 57.5727; fused_output_loss: 54.3351; higgs_mass_loss: 94.2692; loss: 54.3351; nu_mass_loss: 51.6508; val_dinu_pt_loss: 57.3223; val_fused_output_loss: 54.4289; val_higgs_mass_loss: 95.6197; val_loss: 54.4289; val_nu_mass_loss: 50.0943
# Epoch 90; dinu_pt_loss: 57.4065; fused_output_loss: 54.0915; higgs_mass_loss: 93.7387; loss: 54.0915; nu_mass_loss: 52.1029; val_dinu_pt_loss: 57.1348; val_fused_output_loss: 54.1790; val_higgs_mass_loss: 95.0857; val_loss: 54.1790; val_nu_mass_loss: 50.5943
# Epoch 91; dinu_pt_loss: 57.2463; fused_output_loss: 53.8477; higgs_mass_loss: 93.1902; loss: 53.8477; nu_mass_loss: 52.5840; val_dinu_pt_loss: 56.9749; val_fused_output_loss: 53.9291; val_higgs_mass_loss: 94.5013; val_loss: 53.9291; val_nu_mass_loss: 51.0833
# Epoch 92; dinu_pt_loss: 57.0732; fused_output_loss: 53.6019; higgs_mass_loss: 92.6376; loss: 53.6019; nu_mass_loss: 53.0503; val_dinu_pt_loss: 56.8115; val_fused_output_loss: 53.6766; val_higgs_mass_loss: 93.9346; val_loss: 53.6766; val_nu_mass_loss: 51.5715
# Epoch 93; dinu_pt_loss: 56.9190; fused_output_loss: 53.3548; higgs_mass_loss: 92.0744; loss: 53.3548; nu_mass_loss: 53.5165; val_dinu_pt_loss: 56.6450; val_fused_output_loss: 53.4151; val_higgs_mass_loss: 93.3158; val_loss: 53.4151; val_nu_mass_loss: 52.0910
# Epoch 94; dinu_pt_loss: 56.7603; fused_output_loss: 53.1076; higgs_mass_loss: 91.4910; loss: 53.1076; nu_mass_loss: 53.9970; val_dinu_pt_loss: 56.4880; val_fused_output_loss: 53.1671; val_higgs_mass_loss: 92.7188; val_loss: 53.1671; val_nu_mass_loss: 52.5819
# Epoch 95; dinu_pt_loss: 56.6034; fused_output_loss: 52.8580; higgs_mass_loss: 90.8937; loss: 52.8580; nu_mass_loss: 54.4664; val_dinu_pt_loss: 56.3128; val_fused_output_loss: 52.8962; val_higgs_mass_loss: 92.0645; val_loss: 52.8962; val_nu_mass_loss: 53.1070
# Epoch 96; dinu_pt_loss: 56.4607; fused_output_loss: 52.6077; higgs_mass_loss: 90.2797; loss: 52.6077; nu_mass_loss: 54.9304; val_dinu_pt_loss: 56.1712; val_fused_output_loss: 52.6446; val_higgs_mass_loss: 91.4396; val_loss: 52.6446; val_nu_mass_loss: 53.5807
# Epoch 97; dinu_pt_loss: 56.3128; fused_output_loss: 52.3576; higgs_mass_loss: 89.6537; loss: 52.3576; nu_mass_loss: 55.3853; val_dinu_pt_loss: 56.0235; val_fused_output_loss: 52.3877; val_higgs_mass_loss: 90.7523; val_loss: 52.3877; val_nu_mass_loss: 54.0673
# Epoch 98; dinu_pt_loss: 56.1713; fused_output_loss: 52.1048; higgs_mass_loss: 89.0008; loss: 52.1048; nu_mass_loss: 55.8421; val_dinu_pt_loss: 55.8865; val_fused_output_loss: 52.1243; val_higgs_mass_loss: 90.0536; val_loss: 52.1243; val_nu_mass_loss: 54.5610
# Epoch 99; dinu_pt_loss: 56.0351; fused_output_loss: 51.8517; higgs_mass_loss: 88.3357; loss: 51.8517; nu_mass_loss: 56.3016; val_dinu_pt_loss: 55.7392; val_fused_output_loss: 51.8675; val_higgs_mass_loss: 89.3817; val_loss: 51.8675; val_nu_mass_loss: 55.0361
# Epoch 100; dinu_pt_loss: 55.8996; fused_output_loss: 51.5971; higgs_mass_loss: 87.6204; loss: 51.5971; nu_mass_loss: 56.7587; val_dinu_pt_loss: 55.5795; val_fused_output_loss: 51.6008; val_higgs_mass_loss: 88.6108; val_loss: 51.6008; val_nu_mass_loss: 55.5343
# Epoch 101; dinu_pt_loss: 55.7612; fused_output_loss: 51.3412; higgs_mass_loss: 86.8930; loss: 51.3412; nu_mass_loss: 57.2055; val_dinu_pt_loss: 55.4587; val_fused_output_loss: 51.3436; val_higgs_mass_loss: 87.8432; val_loss: 51.3436; val_nu_mass_loss: 55.9947
# Epoch 102; dinu_pt_loss: 55.6385; fused_output_loss: 51.0849; higgs_mass_loss: 86.1161; loss: 51.0849; nu_mass_loss: 57.6551; val_dinu_pt_loss: 55.3219; val_fused_output_loss: 51.0747; val_higgs_mass_loss: 87.0211; val_loss: 51.0747; val_nu_mass_loss: 56.4630
# Epoch 103; dinu_pt_loss: 55.5086; fused_output_loss: 50.8268; higgs_mass_loss: 85.3084; loss: 50.8268; nu_mass_loss: 58.0860; val_dinu_pt_loss: 55.2076; val_fused_output_loss: 50.8159; val_higgs_mass_loss: 86.1608; val_loss: 50.8159; val_nu_mass_loss: 56.8982
# Epoch 104; dinu_pt_loss: 55.3883; fused_output_loss: 50.5673; higgs_mass_loss: 84.4264; loss: 50.5673; nu_mass_loss: 58.4920; val_dinu_pt_loss: 55.0580; val_fused_output_loss: 50.5384; val_higgs_mass_loss: 85.1814; val_loss: 50.5384; val_nu_mass_loss: 57.3559
# Epoch 105; dinu_pt_loss: 55.2781; fused_output_loss: 50.3054; higgs_mass_loss: 83.4595; loss: 50.3054; nu_mass_loss: 58.9068; val_dinu_pt_loss: 54.9440; val_fused_output_loss: 50.2723; val_higgs_mass_loss: 84.1611; val_loss: 50.2723; val_nu_mass_loss: 57.7849
# Epoch 106; dinu_pt_loss: 55.1629; fused_output_loss: 50.0407; higgs_mass_loss: 82.3566; loss: 50.0407; nu_mass_loss: 59.2873; val_dinu_pt_loss: 54.8245; val_fused_output_loss: 50.0118; val_higgs_mass_loss: 83.0293; val_loss: 50.0118; val_nu_mass_loss: 58.1664
# Epoch 107; dinu_pt_loss: 55.0597; fused_output_loss: 49.7727; higgs_mass_loss: 81.0994; loss: 49.7727; nu_mass_loss: 59.6038; val_dinu_pt_loss: 54.7214; val_fused_output_loss: 49.7326; val_higgs_mass_loss: 81.6857; val_loss: 49.7326; val_nu_mass_loss: 58.4932
# Epoch 108; dinu_pt_loss: 54.9670; fused_output_loss: 49.5049; higgs_mass_loss: 79.7034; loss: 49.5049; nu_mass_loss: 59.8295; val_dinu_pt_loss: 54.6227; val_fused_output_loss: 49.4772; val_higgs_mass_loss: 80.3625; val_loss: 49.4772; val_nu_mass_loss: 58.6603
# Epoch 109; dinu_pt_loss: 54.8435; fused_output_loss: 49.2352; higgs_mass_loss: 78.3776; loss: 49.2352; nu_mass_loss: 59.9672; val_dinu_pt_loss: 54.4742; val_fused_output_loss: 49.2032; val_higgs_mass_loss: 79.1162; val_loss: 49.2032; val_nu_mass_loss: 58.8360
# Epoch 110; dinu_pt_loss: 54.7204; fused_output_loss: 48.9680; higgs_mass_loss: 77.2389; loss: 48.9680; nu_mass_loss: 60.0985; val_dinu_pt_loss: 54.3581; val_fused_output_loss: 48.9342; val_higgs_mass_loss: 78.0548; val_loss: 48.9342; val_nu_mass_loss: 59.0160
# Epoch 111; dinu_pt_loss: 54.5759; fused_output_loss: 48.7018; higgs_mass_loss: 76.2435; loss: 48.7018; nu_mass_loss: 60.2701; val_dinu_pt_loss: 54.2225; val_fused_output_loss: 48.6704; val_higgs_mass_loss: 77.1196; val_loss: 48.6704; val_nu_mass_loss: 59.2206
# Epoch 112; dinu_pt_loss: 54.4316; fused_output_loss: 48.4374; higgs_mass_loss: 75.3475; loss: 48.4374; nu_mass_loss: 60.4539; val_dinu_pt_loss: 54.0794; val_fused_output_loss: 48.4118; val_higgs_mass_loss: 76.2569; val_loss: 48.4118; val_nu_mass_loss: 59.3932
# Epoch 113; dinu_pt_loss: 54.2993; fused_output_loss: 48.1729; higgs_mass_loss: 74.5387; loss: 48.1729; nu_mass_loss: 60.6640; val_dinu_pt_loss: 53.9598; val_fused_output_loss: 48.1369; val_higgs_mass_loss: 75.4200; val_loss: 48.1369; val_nu_mass_loss: 59.6198
# Epoch 114; dinu_pt_loss: 54.1804; fused_output_loss: 47.9098; higgs_mass_loss: 73.7619; loss: 47.9098; nu_mass_loss: 60.8824; val_dinu_pt_loss: 53.8237; val_fused_output_loss: 47.8733; val_higgs_mass_loss: 74.6769; val_loss: 47.8733; val_nu_mass_loss: 59.8556
# Epoch 115; dinu_pt_loss: 54.0353; fused_output_loss: 47.6487; higgs_mass_loss: 73.0421; loss: 47.6487; nu_mass_loss: 61.1331; val_dinu_pt_loss: 53.6919; val_fused_output_loss: 47.6112; val_higgs_mass_loss: 73.9149; val_loss: 47.6112; val_nu_mass_loss: 60.0932
# Epoch 116; dinu_pt_loss: 53.9031; fused_output_loss: 47.3863; higgs_mass_loss: 72.3355; loss: 47.3863; nu_mass_loss: 61.3652; val_dinu_pt_loss: 53.5791; val_fused_output_loss: 47.3522; val_higgs_mass_loss: 73.1870; val_loss: 47.3522; val_nu_mass_loss: 60.3205
# Epoch 117; dinu_pt_loss: 53.7862; fused_output_loss: 47.1275; higgs_mass_loss: 71.6653; loss: 47.1275; nu_mass_loss: 61.6022; val_dinu_pt_loss: 53.4572; val_fused_output_loss: 47.0914; val_higgs_mass_loss: 72.4742; val_loss: 47.0914; val_nu_mass_loss: 60.5479
# Epoch 118; dinu_pt_loss: 53.6582; fused_output_loss: 46.8676; higgs_mass_loss: 70.9911; loss: 46.8676; nu_mass_loss: 61.8477; val_dinu_pt_loss: 53.3406; val_fused_output_loss: 46.8228; val_higgs_mass_loss: 71.8082; val_loss: 46.8228; val_nu_mass_loss: 60.7939
# Epoch 119; dinu_pt_loss: 53.5309; fused_output_loss: 46.6093; higgs_mass_loss: 70.3655; loss: 46.6093; nu_mass_loss: 62.0904; val_dinu_pt_loss: 53.2076; val_fused_output_loss: 46.5710; val_higgs_mass_loss: 71.2088; val_loss: 46.5710; val_nu_mass_loss: 61.0470
# Epoch 120; dinu_pt_loss: 53.4110; fused_output_loss: 46.3534; higgs_mass_loss: 69.7334; loss: 46.3534; nu_mass_loss: 62.3351; val_dinu_pt_loss: 53.0997; val_fused_output_loss: 46.3139; val_higgs_mass_loss: 70.5297; val_loss: 46.3139; val_nu_mass_loss: 61.2712
# Epoch 121; dinu_pt_loss: 53.3088; fused_output_loss: 46.0972; higgs_mass_loss: 69.1430; loss: 46.0972; nu_mass_loss: 62.5669; val_dinu_pt_loss: 52.9775; val_fused_output_loss: 46.0571; val_higgs_mass_loss: 69.9128; val_loss: 46.0571; val_nu_mass_loss: 61.4982
# Epoch 122; dinu_pt_loss: 53.1818; fused_output_loss: 45.8433; higgs_mass_loss: 68.5684; loss: 45.8433; nu_mass_loss: 62.8068; val_dinu_pt_loss: 52.8500; val_fused_output_loss: 45.8000; val_higgs_mass_loss: 69.3546; val_loss: 45.8000; val_nu_mass_loss: 61.7428
# Epoch 123; dinu_pt_loss: 53.0742; fused_output_loss: 45.5892; higgs_mass_loss: 68.0155; loss: 45.5892; nu_mass_loss: 63.0460; val_dinu_pt_loss: 52.7483; val_fused_output_loss: 45.5486; val_higgs_mass_loss: 68.7823; val_loss: 45.5486; val_nu_mass_loss: 61.9516
# Epoch 124; dinu_pt_loss: 52.9538; fused_output_loss: 45.3375; higgs_mass_loss: 67.4810; loss: 45.3375; nu_mass_loss: 63.2874; val_dinu_pt_loss: 52.6066; val_fused_output_loss: 45.2897; val_higgs_mass_loss: 68.1877; val_loss: 45.2897; val_nu_mass_loss: 62.2048
# Epoch 125; dinu_pt_loss: 52.8347; fused_output_loss: 45.0864; higgs_mass_loss: 66.9780; loss: 45.0864; nu_mass_loss: 63.5035; val_dinu_pt_loss: 52.5130; val_fused_output_loss: 45.0373; val_higgs_mass_loss: 67.6848; val_loss: 45.0373; val_nu_mass_loss: 62.4014
# Epoch 126; dinu_pt_loss: 52.7526; fused_output_loss: 44.8390; higgs_mass_loss: 66.5123; loss: 44.8390; nu_mass_loss: 63.7119; val_dinu_pt_loss: 52.4213; val_fused_output_loss: 44.7814; val_higgs_mass_loss: 67.2021; val_loss: 44.7814; val_nu_mass_loss: 62.5944
# Epoch 127; dinu_pt_loss: 52.6369; fused_output_loss: 44.5934; higgs_mass_loss: 66.1174; loss: 44.5934; nu_mass_loss: 63.9226; val_dinu_pt_loss: 52.3327; val_fused_output_loss: 44.5445; val_higgs_mass_loss: 66.8232; val_loss: 44.5445; val_nu_mass_loss: 62.7948
# Epoch 128; dinu_pt_loss: 52.5527; fused_output_loss: 44.3477; higgs_mass_loss: 65.7404; loss: 44.3477; nu_mass_loss: 64.1169; val_dinu_pt_loss: 52.2190; val_fused_output_loss: 44.2971; val_higgs_mass_loss: 66.3824; val_loss: 44.2971; val_nu_mass_loss: 62.9793
# Epoch 129; dinu_pt_loss: 52.4404; fused_output_loss: 44.1047; higgs_mass_loss: 65.3907; loss: 44.1047; nu_mass_loss: 64.3176; val_dinu_pt_loss: 52.0970; val_fused_output_loss: 44.0529; val_higgs_mass_loss: 66.0289; val_loss: 44.0529; val_nu_mass_loss: 63.1523
# Epoch 130; dinu_pt_loss: 52.3454; fused_output_loss: 43.8630; higgs_mass_loss: 65.1115; loss: 43.8630; nu_mass_loss: 64.4914; val_dinu_pt_loss: 52.0059; val_fused_output_loss: 43.8035; val_higgs_mass_loss: 65.7392; val_loss: 43.8035; val_nu_mass_loss: 63.3146
# Epoch 131; dinu_pt_loss: 52.2479; fused_output_loss: 43.6222; higgs_mass_loss: 64.8749; loss: 43.6222; nu_mass_loss: 64.6354; val_dinu_pt_loss: 51.9486; val_fused_output_loss: 43.5715; val_higgs_mass_loss: 65.4285; val_loss: 43.5715; val_nu_mass_loss: 63.4206
# Epoch 132; dinu_pt_loss: 52.1527; fused_output_loss: 43.3849; higgs_mass_loss: 64.6744; loss: 43.3849; nu_mass_loss: 64.7731; val_dinu_pt_loss: 51.8129; val_fused_output_loss: 43.3339; val_higgs_mass_loss: 65.1767; val_loss: 43.3339; val_nu_mass_loss: 63.5718
# Epoch 133; dinu_pt_loss: 52.0686; fused_output_loss: 43.1495; higgs_mass_loss: 64.4656; loss: 43.1495; nu_mass_loss: 64.9088; val_dinu_pt_loss: 51.7409; val_fused_output_loss: 43.0958; val_higgs_mass_loss: 64.9832; val_loss: 43.0958; val_nu_mass_loss: 63.6953
# Epoch 134; dinu_pt_loss: 51.9833; fused_output_loss: 42.9151; higgs_mass_loss: 64.2726; loss: 42.9151; nu_mass_loss: 65.0295; val_dinu_pt_loss: 51.6358; val_fused_output_loss: 42.8438; val_higgs_mass_loss: 64.6194; val_loss: 42.8438; val_nu_mass_loss: 63.8072
# Epoch 135; dinu_pt_loss: 51.9009; fused_output_loss: 42.6828; higgs_mass_loss: 64.0285; loss: 42.6828; nu_mass_loss: 65.1079; val_dinu_pt_loss: 51.5531; val_fused_output_loss: 42.6213; val_higgs_mass_loss: 64.3241; val_loss: 42.6213; val_nu_mass_loss: 63.8650
# Epoch 136; dinu_pt_loss: 51.8112; fused_output_loss: 42.4518; higgs_mass_loss: 63.7015; loss: 42.4518; nu_mass_loss: 65.1587; val_dinu_pt_loss: 51.4845; val_fused_output_loss: 42.3832; val_higgs_mass_loss: 63.8984; val_loss: 42.3832; val_nu_mass_loss: 63.9228
# Epoch 137; dinu_pt_loss: 51.7341; fused_output_loss: 42.2238; higgs_mass_loss: 63.2665; loss: 42.2238; nu_mass_loss: 65.1870; val_dinu_pt_loss: 51.3894; val_fused_output_loss: 42.1448; val_higgs_mass_loss: 63.2898; val_loss: 42.1448; val_nu_mass_loss: 63.9930
# Epoch 138; dinu_pt_loss: 51.6568; fused_output_loss: 41.9970; higgs_mass_loss: 62.6634; loss: 41.9970; nu_mass_loss: 65.2029; val_dinu_pt_loss: 51.2961; val_fused_output_loss: 41.9223; val_higgs_mass_loss: 62.4017; val_loss: 41.9223; val_nu_mass_loss: 63.9610
# Epoch 139; dinu_pt_loss: 51.5785; fused_output_loss: 41.7725; higgs_mass_loss: 61.8356; loss: 41.7725; nu_mass_loss: 65.1671; val_dinu_pt_loss: 51.2019; val_fused_output_loss: 41.6905; val_higgs_mass_loss: 61.4388; val_loss: 41.6905; val_nu_mass_loss: 63.9619
# Epoch 140; dinu_pt_loss: 51.4949; fused_output_loss: 41.5498; higgs_mass_loss: 60.8825; loss: 41.5498; nu_mass_loss: 65.1046; val_dinu_pt_loss: 51.1526; val_fused_output_loss: 41.4789; val_higgs_mass_loss: 60.4366; val_loss: 41.4789; val_nu_mass_loss: 63.8848
# Epoch 141; dinu_pt_loss: 51.4322; fused_output_loss: 41.3297; higgs_mass_loss: 59.8576; loss: 41.3297; nu_mass_loss: 65.0553; val_dinu_pt_loss: 51.0998; val_fused_output_loss: 41.2505; val_higgs_mass_loss: 59.3039; val_loss: 41.2505; val_nu_mass_loss: 63.8397
# Epoch 142; dinu_pt_loss: 51.3623; fused_output_loss: 41.1118; higgs_mass_loss: 58.7406; loss: 41.1118; nu_mass_loss: 64.9887; val_dinu_pt_loss: 50.9957; val_fused_output_loss: 41.0552; val_higgs_mass_loss: 58.1577; val_loss: 41.0552; val_nu_mass_loss: 63.7541
# Epoch 143; dinu_pt_loss: 51.2766; fused_output_loss: 40.8978; higgs_mass_loss: 57.5749; loss: 40.8978; nu_mass_loss: 64.9413; val_dinu_pt_loss: 50.9026; val_fused_output_loss: 40.8308; val_higgs_mass_loss: 57.0195; val_loss: 40.8308; val_nu_mass_loss: 63.7446
# Epoch 144; dinu_pt_loss: 51.2093; fused_output_loss: 40.6843; higgs_mass_loss: 56.3426; loss: 40.6843; nu_mass_loss: 64.8935; val_dinu_pt_loss: 50.8357; val_fused_output_loss: 40.6302; val_higgs_mass_loss: 55.8057; val_loss: 40.6302; val_nu_mass_loss: 63.6656
# Epoch 145; dinu_pt_loss: 51.1368; fused_output_loss: 40.4750; higgs_mass_loss: 55.0823; loss: 40.4750; nu_mass_loss: 64.8714; val_dinu_pt_loss: 50.7539; val_fused_output_loss: 40.4193; val_higgs_mass_loss: 54.5365; val_loss: 40.4193; val_nu_mass_loss: 63.6572
# Epoch 146; dinu_pt_loss: 51.0744; fused_output_loss: 40.2690; higgs_mass_loss: 53.8364; loss: 40.2690; nu_mass_loss: 64.9005; val_dinu_pt_loss: 50.6806; val_fused_output_loss: 40.1929; val_higgs_mass_loss: 53.2766; val_loss: 40.1929; val_nu_mass_loss: 63.6907
# Epoch 147; dinu_pt_loss: 51.0090; fused_output_loss: 40.0626; higgs_mass_loss: 52.6228; loss: 40.0626; nu_mass_loss: 64.9305; val_dinu_pt_loss: 50.6006; val_fused_output_loss: 39.9902; val_higgs_mass_loss: 52.1083; val_loss: 39.9902; val_nu_mass_loss: 63.7316
# Epoch 148; dinu_pt_loss: 50.9377; fused_output_loss: 39.8617; higgs_mass_loss: 51.4279; loss: 39.8617; nu_mass_loss: 65.0142; val_dinu_pt_loss: 50.5320; val_fused_output_loss: 39.7914; val_higgs_mass_loss: 50.9677; val_loss: 39.7914; val_nu_mass_loss: 63.7992
# Epoch 149; dinu_pt_loss: 50.8727; fused_output_loss: 39.6613; higgs_mass_loss: 50.2696; loss: 39.6613; nu_mass_loss: 65.1021; val_dinu_pt_loss: 50.4557; val_fused_output_loss: 39.5949; val_higgs_mass_loss: 49.8209; val_loss: 39.5949; val_nu_mass_loss: 63.8887
# Epoch 150; dinu_pt_loss: 50.8149; fused_output_loss: 39.4643; higgs_mass_loss: 49.0762; loss: 39.4643; nu_mass_loss: 65.2056; val_dinu_pt_loss: 50.4082; val_fused_output_loss: 39.3957; val_higgs_mass_loss: 48.6869; val_loss: 39.3957; val_nu_mass_loss: 63.9913
# Epoch 151; dinu_pt_loss: 50.7432; fused_output_loss: 39.2689; higgs_mass_loss: 48.0122; loss: 39.2689; nu_mass_loss: 65.3715; val_dinu_pt_loss: 50.3097; val_fused_output_loss: 39.1948; val_higgs_mass_loss: 47.5682; val_loss: 39.1948; val_nu_mass_loss: 64.1685
# Epoch 152; dinu_pt_loss: 50.6745; fused_output_loss: 39.0790; higgs_mass_loss: 46.9192; loss: 39.0790; nu_mass_loss: 65.5122; val_dinu_pt_loss: 50.2410; val_fused_output_loss: 39.0068; val_higgs_mass_loss: 46.5782; val_loss: 39.0068; val_nu_mass_loss: 64.2909
# Epoch 153; dinu_pt_loss: 50.6081; fused_output_loss: 38.8891; higgs_mass_loss: 45.9037; loss: 38.8891; nu_mass_loss: 65.6949; val_dinu_pt_loss: 50.1716; val_fused_output_loss: 38.8153; val_higgs_mass_loss: 45.4962; val_loss: 38.8153; val_nu_mass_loss: 64.4658
# Epoch 154; dinu_pt_loss: 50.5431; fused_output_loss: 38.7035; higgs_mass_loss: 44.8773; loss: 38.7035; nu_mass_loss: 65.8858; val_dinu_pt_loss: 50.0695; val_fused_output_loss: 38.6296; val_higgs_mass_loss: 44.6235; val_loss: 38.6296; val_nu_mass_loss: 64.6145
# Epoch 155; dinu_pt_loss: 50.4727; fused_output_loss: 38.5209; higgs_mass_loss: 43.9608; loss: 38.5209; nu_mass_loss: 66.0727; val_dinu_pt_loss: 50.0353; val_fused_output_loss: 38.4432; val_higgs_mass_loss: 43.6147; val_loss: 38.4432; val_nu_mass_loss: 64.7849
# Epoch 156; dinu_pt_loss: 50.4103; fused_output_loss: 38.3387; higgs_mass_loss: 43.0336; loss: 38.3387; nu_mass_loss: 66.2642; val_dinu_pt_loss: 49.9297; val_fused_output_loss: 38.2667; val_higgs_mass_loss: 42.7462; val_loss: 38.2667; val_nu_mass_loss: 64.9537
# Epoch 157; dinu_pt_loss: 50.3402; fused_output_loss: 38.1600; higgs_mass_loss: 42.2254; loss: 38.1600; nu_mass_loss: 66.4601; val_dinu_pt_loss: 49.8682; val_fused_output_loss: 38.0853; val_higgs_mass_loss: 41.9686; val_loss: 38.0853; val_nu_mass_loss: 65.1072
# Epoch 158; dinu_pt_loss: 50.2602; fused_output_loss: 37.9870; higgs_mass_loss: 41.4402; loss: 37.9870; nu_mass_loss: 66.6323; val_dinu_pt_loss: 49.7646; val_fused_output_loss: 37.9014; val_higgs_mass_loss: 41.1916; val_loss: 37.9014; val_nu_mass_loss: 65.2671
# Epoch 159; dinu_pt_loss: 50.1692; fused_output_loss: 37.8098; higgs_mass_loss: 40.6924; loss: 37.8098; nu_mass_loss: 66.8002; val_dinu_pt_loss: 49.6551; val_fused_output_loss: 37.7238; val_higgs_mass_loss: 40.4362; val_loss: 37.7238; val_nu_mass_loss: 65.4234
# Epoch 160; dinu_pt_loss: 50.0812; fused_output_loss: 37.6393; higgs_mass_loss: 40.0273; loss: 37.6393; nu_mass_loss: 66.9583; val_dinu_pt_loss: 49.5829; val_fused_output_loss: 37.5614; val_higgs_mass_loss: 39.7952; val_loss: 37.5614; val_nu_mass_loss: 65.5324
# Epoch 161; dinu_pt_loss: 49.9884; fused_output_loss: 37.4682; higgs_mass_loss: 39.3371; loss: 37.4682; nu_mass_loss: 67.1107; val_dinu_pt_loss: 49.4573; val_fused_output_loss: 37.3809; val_higgs_mass_loss: 39.0394; val_loss: 37.3809; val_nu_mass_loss: 65.6662
# Epoch 162; dinu_pt_loss: 49.8816; fused_output_loss: 37.3010; higgs_mass_loss: 38.6996; loss: 37.3010; nu_mass_loss: 67.2034; val_dinu_pt_loss: 49.3499; val_fused_output_loss: 37.2105; val_higgs_mass_loss: 38.4179; val_loss: 37.2105; val_nu_mass_loss: 65.7530
# Epoch 163; dinu_pt_loss: 49.7764; fused_output_loss: 37.1340; higgs_mass_loss: 38.0977; loss: 37.1340; nu_mass_loss: 67.2871; val_dinu_pt_loss: 49.2352; val_fused_output_loss: 37.0400; val_higgs_mass_loss: 37.7227; val_loss: 37.0400; val_nu_mass_loss: 65.7825
# Epoch 164; dinu_pt_loss: 49.6448; fused_output_loss: 36.9689; higgs_mass_loss: 37.5414; loss: 36.9689; nu_mass_loss: 67.3410; val_dinu_pt_loss: 49.1096; val_fused_output_loss: 36.8741; val_higgs_mass_loss: 37.1468; val_loss: 36.8741; val_nu_mass_loss: 65.8328
# Epoch 165; dinu_pt_loss: 49.5244; fused_output_loss: 36.8067; higgs_mass_loss: 36.9608; loss: 36.8067; nu_mass_loss: 67.3760; val_dinu_pt_loss: 48.9520; val_fused_output_loss: 36.7242; val_higgs_mass_loss: 36.6443; val_loss: 36.7242; val_nu_mass_loss: 65.8248
# Epoch 166; dinu_pt_loss: 49.3679; fused_output_loss: 36.6432; higgs_mass_loss: 36.4621; loss: 36.6432; nu_mass_loss: 67.3828; val_dinu_pt_loss: 48.7785; val_fused_output_loss: 36.5565; val_higgs_mass_loss: 35.9874; val_loss: 36.5565; val_nu_mass_loss: 65.7809
# Epoch 167; dinu_pt_loss: 49.2149; fused_output_loss: 36.4843; higgs_mass_loss: 35.9106; loss: 36.4843; nu_mass_loss: 67.3689; val_dinu_pt_loss: 48.6389; val_fused_output_loss: 36.3817; val_higgs_mass_loss: 35.4338; val_loss: 36.3817; val_nu_mass_loss: 65.7719
# Epoch 168; dinu_pt_loss: 49.0281; fused_output_loss: 36.3218; higgs_mass_loss: 35.3942; loss: 36.3218; nu_mass_loss: 67.3217; val_dinu_pt_loss: 48.4341; val_fused_output_loss: 36.2301; val_higgs_mass_loss: 34.9227; val_loss: 36.2301; val_nu_mass_loss: 65.6863
# Epoch 169; dinu_pt_loss: 48.8483; fused_output_loss: 36.1632; higgs_mass_loss: 34.8813; loss: 36.1632; nu_mass_loss: 67.2379; val_dinu_pt_loss: 48.2351; val_fused_output_loss: 36.0509; val_higgs_mass_loss: 34.2643; val_loss: 36.0509; val_nu_mass_loss: 65.5971
# Epoch 170; dinu_pt_loss: 48.6268; fused_output_loss: 36.0078; higgs_mass_loss: 34.3694; loss: 36.0078; nu_mass_loss: 67.1525; val_dinu_pt_loss: 48.0196; val_fused_output_loss: 35.9127; val_higgs_mass_loss: 33.8064; val_loss: 35.9127; val_nu_mass_loss: 65.4588
# Epoch 171; dinu_pt_loss: 48.4035; fused_output_loss: 35.8493; higgs_mass_loss: 33.8359; loss: 35.8493; nu_mass_loss: 66.9986; val_dinu_pt_loss: 47.7570; val_fused_output_loss: 35.7499; val_higgs_mass_loss: 33.2253; val_loss: 35.7499; val_nu_mass_loss: 65.3517
# Epoch 172; dinu_pt_loss: 48.1387; fused_output_loss: 35.6928; higgs_mass_loss: 33.3664; loss: 35.6928; nu_mass_loss: 66.8533; val_dinu_pt_loss: 47.4869; val_fused_output_loss: 35.5922; val_higgs_mass_loss: 32.6978; val_loss: 35.5922; val_nu_mass_loss: 65.1702
# Epoch 173; dinu_pt_loss: 47.8821; fused_output_loss: 35.5396; higgs_mass_loss: 32.9124; loss: 35.5396; nu_mass_loss: 66.6828; val_dinu_pt_loss: 47.1910; val_fused_output_loss: 35.4234; val_higgs_mass_loss: 32.2063; val_loss: 35.4234; val_nu_mass_loss: 65.0398
# Epoch 174; dinu_pt_loss: 47.6023; fused_output_loss: 35.3841; higgs_mass_loss: 32.4680; loss: 35.3841; nu_mass_loss: 66.4597; val_dinu_pt_loss: 46.9120; val_fused_output_loss: 35.2562; val_higgs_mass_loss: 31.7077; val_loss: 35.2562; val_nu_mass_loss: 64.8300
# Epoch 175; dinu_pt_loss: 47.3161; fused_output_loss: 35.2324; higgs_mass_loss: 32.0385; loss: 35.2324; nu_mass_loss: 66.2261; val_dinu_pt_loss: 46.5953; val_fused_output_loss: 35.1093; val_higgs_mass_loss: 31.3524; val_loss: 35.1093; val_nu_mass_loss: 64.6027
# Epoch 176; dinu_pt_loss: 46.9870; fused_output_loss: 35.0823; higgs_mass_loss: 31.6714; loss: 35.0823; nu_mass_loss: 65.9889; val_dinu_pt_loss: 46.2902; val_fused_output_loss: 34.9580; val_higgs_mass_loss: 30.8195; val_loss: 34.9580; val_nu_mass_loss: 64.3330
# Epoch 177; dinu_pt_loss: 46.6791; fused_output_loss: 34.9305; higgs_mass_loss: 31.2503; loss: 34.9305; nu_mass_loss: 65.7284; val_dinu_pt_loss: 45.9266; val_fused_output_loss: 34.8057; val_higgs_mass_loss: 30.3247; val_loss: 34.8057; val_nu_mass_loss: 64.0650
# Epoch 178; dinu_pt_loss: 46.3265; fused_output_loss: 34.7792; higgs_mass_loss: 30.8908; loss: 34.7792; nu_mass_loss: 65.4304; val_dinu_pt_loss: 45.5463; val_fused_output_loss: 34.6461; val_higgs_mass_loss: 29.9945; val_loss: 34.6461; val_nu_mass_loss: 63.8418
# Epoch 179; dinu_pt_loss: 45.9710; fused_output_loss: 34.6340; higgs_mass_loss: 30.4592; loss: 34.6340; nu_mass_loss: 65.1089; val_dinu_pt_loss: 45.1919; val_fused_output_loss: 34.4989; val_higgs_mass_loss: 29.4455; val_loss: 34.4989; val_nu_mass_loss: 63.4967
# Epoch 180; dinu_pt_loss: 45.6086; fused_output_loss: 34.4833; higgs_mass_loss: 30.0841; loss: 34.4833; nu_mass_loss: 64.8048; val_dinu_pt_loss: 44.8088; val_fused_output_loss: 34.3497; val_higgs_mass_loss: 29.0391; val_loss: 34.3497; val_nu_mass_loss: 63.2088
# Epoch 181; dinu_pt_loss: 45.2034; fused_output_loss: 34.3354; higgs_mass_loss: 29.7487; loss: 34.3354; nu_mass_loss: 64.5262; val_dinu_pt_loss: 44.3752; val_fused_output_loss: 34.2137; val_higgs_mass_loss: 28.6579; val_loss: 34.2137; val_nu_mass_loss: 62.9296
# ...
# Epoch 974; dinu_pt_loss: 16.8278; fused_output_loss: 24.7408; higgs_mass_loss: 12.9426; loss: 24.7408; nu_mass_loss: 53.1965; val_dinu_pt_loss: 14.3961; val_fused_output_loss: 24.3072; val_higgs_mass_loss: 11.3411; val_loss: 24.3072; val_nu_mass_loss: 53.2843
# Epoch 975; dinu_pt_loss: 16.8307; fused_output_loss: 24.7410; higgs_mass_loss: 12.9846; loss: 24.7410; nu_mass_loss: 53.1633; val_dinu_pt_loss: 14.3952; val_fused_output_loss: 24.3074; val_higgs_mass_loss: 11.3294; val_loss: 24.3074; val_nu_mass_loss: 53.1241
# Epoch 976; dinu_pt_loss: 16.8285; fused_output_loss: 24.7385; higgs_mass_loss: 12.9242; loss: 24.7385; nu_mass_loss: 53.2355; val_dinu_pt_loss: 14.4178; val_fused_output_loss: 24.3061; val_higgs_mass_loss: 11.2771; val_loss: 24.3061; val_nu_mass_loss: 53.1072
# Epoch 977; dinu_pt_loss: 16.8347; fused_output_loss: 24.7417; higgs_mass_loss: 12.9664; loss: 24.7417; nu_mass_loss: 53.2594; val_dinu_pt_loss: 14.4212; val_fused_output_loss: 24.3063; val_higgs_mass_loss: 11.3207; val_loss: 24.3063; val_nu_mass_loss: 53.2577
# Epoch 978; dinu_pt_loss: 16.8221; fused_output_loss: 24.7387; higgs_mass_loss: 12.9504; loss: 24.7387; nu_mass_loss: 53.2875; val_dinu_pt_loss: 14.4119; val_fused_output_loss: 24.3059; val_higgs_mass_loss: 11.3277; val_loss: 24.3059; val_nu_mass_loss: 53.2368
# Epoch 979; dinu_pt_loss: 16.8361; fused_output_loss: 24.7386; higgs_mass_loss: 12.9368; loss: 24.7386; nu_mass_loss: 53.1885; val_dinu_pt_loss: 14.3988; val_fused_output_loss: 24.3047; val_higgs_mass_loss: 11.2910; val_loss: 24.3047; val_nu_mass_loss: 53.1523
# Epoch 980; dinu_pt_loss: 16.8299; fused_output_loss: 24.7365; higgs_mass_loss: 12.9073; loss: 24.7365; nu_mass_loss: 53.1588; val_dinu_pt_loss: 14.4001; val_fused_output_loss: 24.3035; val_higgs_mass_loss: 11.3074; val_loss: 24.3035; val_nu_mass_loss: 53.1885
# Epoch 981; dinu_pt_loss: 16.8301; fused_output_loss: 24.7374; higgs_mass_loss: 12.9192; loss: 24.7374; nu_mass_loss: 53.1008; val_dinu_pt_loss: 14.4219; val_fused_output_loss: 24.3046; val_higgs_mass_loss: 11.2814; val_loss: 24.3046; val_nu_mass_loss: 53.1901
# Epoch 982; dinu_pt_loss: 16.8177; fused_output_loss: 24.7375; higgs_mass_loss: 12.8729; loss: 24.7375; nu_mass_loss: 53.2117; val_dinu_pt_loss: 14.4149; val_fused_output_loss: 24.3044; val_higgs_mass_loss: 11.2920; val_loss: 24.3044; val_nu_mass_loss: 53.3023
# Epoch 983; dinu_pt_loss: 16.8063; fused_output_loss: 24.7362; higgs_mass_loss: 12.8839; loss: 24.7362; nu_mass_loss: 53.2158; val_dinu_pt_loss: 14.3894; val_fused_output_loss: 24.3046; val_higgs_mass_loss: 11.3135; val_loss: 24.3046; val_nu_mass_loss: 53.2183
# Epoch 984; dinu_pt_loss: 16.7871; fused_output_loss: 24.7371; higgs_mass_loss: 12.9278; loss: 24.7371; nu_mass_loss: 53.1924; val_dinu_pt_loss: 14.3731; val_fused_output_loss: 24.3032; val_higgs_mass_loss: 11.2707; val_loss: 24.3032; val_nu_mass_loss: 53.1362
# Epoch 985; dinu_pt_loss: 16.7970; fused_output_loss: 24.7356; higgs_mass_loss: 12.8715; loss: 24.7356; nu_mass_loss: 53.1757; val_dinu_pt_loss: 14.4205; val_fused_output_loss: 24.3038; val_higgs_mass_loss: 11.2570; val_loss: 24.3038; val_nu_mass_loss: 53.1659
# Epoch 986; dinu_pt_loss: 16.7981; fused_output_loss: 24.7344; higgs_mass_loss: 12.8728; loss: 24.7344; nu_mass_loss: 53.1951; val_dinu_pt_loss: 14.3937; val_fused_output_loss: 24.3016; val_higgs_mass_loss: 11.2809; val_loss: 24.3016; val_nu_mass_loss: 53.2213
# Epoch 987; dinu_pt_loss: 16.8147; fused_output_loss: 24.7315; higgs_mass_loss: 12.8685; loss: 24.7315; nu_mass_loss: 53.1574; val_dinu_pt_loss: 14.4205; val_fused_output_loss: 24.3016; val_higgs_mass_loss: 11.2760; val_loss: 24.3016; val_nu_mass_loss: 53.2259
# Epoch 988; dinu_pt_loss: 16.8156; fused_output_loss: 24.7349; higgs_mass_loss: 12.8561; loss: 24.7349; nu_mass_loss: 53.1767; val_dinu_pt_loss: 14.3819; val_fused_output_loss: 24.3005; val_higgs_mass_loss: 11.2056; val_loss: 24.3005; val_nu_mass_loss: 53.0947
# Epoch 989; dinu_pt_loss: 16.8039; fused_output_loss: 24.7318; higgs_mass_loss: 12.8766; loss: 24.7318; nu_mass_loss: 53.1396; val_dinu_pt_loss: 14.4001; val_fused_output_loss: 24.3029; val_higgs_mass_loss: 11.2606; val_loss: 24.3029; val_nu_mass_loss: 53.4190
# Epoch 990; dinu_pt_loss: 16.7974; fused_output_loss: 24.7302; higgs_mass_loss: 12.8424; loss: 24.7302; nu_mass_loss: 53.1761; val_dinu_pt_loss: 14.3757; val_fused_output_loss: 24.3008; val_higgs_mass_loss: 11.2701; val_loss: 24.3008; val_nu_mass_loss: 53.2618
# Epoch 991; dinu_pt_loss: 16.8085; fused_output_loss: 24.7306; higgs_mass_loss: 12.8633; loss: 24.7306; nu_mass_loss: 53.2230; val_dinu_pt_loss: 14.3990; val_fused_output_loss: 24.3004; val_higgs_mass_loss: 11.3023; val_loss: 24.3004; val_nu_mass_loss: 53.4353
# Epoch 992; dinu_pt_loss: 16.8053; fused_output_loss: 24.7309; higgs_mass_loss: 12.8589; loss: 24.7309; nu_mass_loss: 53.1617; val_dinu_pt_loss: 14.3838; val_fused_output_loss: 24.2992; val_higgs_mass_loss: 11.2179; val_loss: 24.2992; val_nu_mass_loss: 53.1802
# Epoch 993; dinu_pt_loss: 16.7798; fused_output_loss: 24.7262; higgs_mass_loss: 12.8304; loss: 24.7262; nu_mass_loss: 53.1612; val_dinu_pt_loss: 14.3625; val_fused_output_loss: 24.2993; val_higgs_mass_loss: 11.1857; val_loss: 24.2993; val_nu_mass_loss: 53.1232
# Epoch 994; dinu_pt_loss: 16.8061; fused_output_loss: 24.7296; higgs_mass_loss: 12.8284; loss: 24.7296; nu_mass_loss: 53.1488; val_dinu_pt_loss: 14.4042; val_fused_output_loss: 24.2992; val_higgs_mass_loss: 11.2007; val_loss: 24.2992; val_nu_mass_loss: 53.0716
# Epoch 995; dinu_pt_loss: 16.7929; fused_output_loss: 24.7285; higgs_mass_loss: 12.8032; loss: 24.7285; nu_mass_loss: 53.1249; val_dinu_pt_loss: 14.3889; val_fused_output_loss: 24.2975; val_higgs_mass_loss: 11.2291; val_loss: 24.2975; val_nu_mass_loss: 53.2968
# Epoch 996; dinu_pt_loss: 16.7961; fused_output_loss: 24.7279; higgs_mass_loss: 12.7890; loss: 24.7279; nu_mass_loss: 53.1289; val_dinu_pt_loss: 14.3908; val_fused_output_loss: 24.2984; val_higgs_mass_loss: 11.1735; val_loss: 24.2984; val_nu_mass_loss: 53.0525
# Epoch 997; dinu_pt_loss: 16.7968; fused_output_loss: 24.7261; higgs_mass_loss: 12.8210; loss: 24.7261; nu_mass_loss: 53.0927; val_dinu_pt_loss: 14.4260; val_fused_output_loss: 24.2981; val_higgs_mass_loss: 11.2056; val_loss: 24.2981; val_nu_mass_loss: 53.0838
# Epoch 998; dinu_pt_loss: 16.7865; fused_output_loss: 24.7256; higgs_mass_loss: 12.8662; loss: 24.7256; nu_mass_loss: 53.2494; val_dinu_pt_loss: 14.3681; val_fused_output_loss: 24.2982; val_higgs_mass_loss: 11.2205; val_loss: 24.2982; val_nu_mass_loss: 53.3219
# Epoch 999; dinu_pt_loss: 16.7774; fused_output_loss: 24.7256; higgs_mass_loss: 12.8215; loss: 24.7256; nu_mass_loss: 53.2099; val_dinu_pt_loss: 14.3744; val_fused_output_loss: 24.2984; val_higgs_mass_loss: 11.1883; val_loss: 24.2984; val_nu_mass_loss: 53.2234
# Epoch 1000; dinu_pt_loss: 16.7991; fused_output_loss: 24.7228; higgs_mass_loss: 12.8181; loss: 24.7228; nu_mass_loss: 53.1615; val_dinu_pt_loss: 14.3800; val_fused_output_loss: 24.2963; val_higgs_mass_loss: 11.1956; val_loss: 24.2963; val_nu_mass_loss: 53.3496
# Epoch 1001; dinu_pt_loss: 16.7924; fused_output_loss: 24.7237; higgs_mass_loss: 12.8009; loss: 24.7237; nu_mass_loss: 53.1426; val_dinu_pt_loss: 14.4204; val_fused_output_loss: 24.2978; val_higgs_mass_loss: 11.1972; val_loss: 24.2978; val_nu_mass_loss: 53.2727
# Epoch 1002; dinu_pt_loss: 16.7914; fused_output_loss: 24.7240; higgs_mass_loss: 12.8036; loss: 24.7240; nu_mass_loss: 53.1471; val_dinu_pt_loss: 14.3652; val_fused_output_loss: 24.2961; val_higgs_mass_loss: 11.1960; val_loss: 24.2961; val_nu_mass_loss: 53.3081
# Epoch 1003; dinu_pt_loss: 16.7889; fused_output_loss: 24.7232; higgs_mass_loss: 12.8051; loss: 24.7232; nu_mass_loss: 53.1362; val_dinu_pt_loss: 14.3670; val_fused_output_loss: 24.2966; val_higgs_mass_loss: 11.1726; val_loss: 24.2966; val_nu_mass_loss: 53.0557
# Epoch 1004; dinu_pt_loss: 16.7854; fused_output_loss: 24.7219; higgs_mass_loss: 12.8220; loss: 24.7219; nu_mass_loss: 53.1494; val_dinu_pt_loss: 14.3648; val_fused_output_loss: 24.2948; val_higgs_mass_loss: 11.1694; val_loss: 24.2948; val_nu_mass_loss: 53.2354
# Epoch 1005; dinu_pt_loss: 16.7620; fused_output_loss: 24.7200; higgs_mass_loss: 12.7927; loss: 24.7200; nu_mass_loss: 53.1940; val_dinu_pt_loss: 14.3800; val_fused_output_loss: 24.2955; val_higgs_mass_loss: 11.1506; val_loss: 24.2955; val_nu_mass_loss: 53.0719
# Epoch 1006; dinu_pt_loss: 16.7616; fused_output_loss: 24.7201; higgs_mass_loss: 12.7491; loss: 24.7201; nu_mass_loss: 53.1326; val_dinu_pt_loss: 14.3584; val_fused_output_loss: 24.2949; val_higgs_mass_loss: 11.1318; val_loss: 24.2949; val_nu_mass_loss: 53.3034
# Epoch 1007; dinu_pt_loss: 16.7721; fused_output_loss: 24.7177; higgs_mass_loss: 12.7840; loss: 24.7177; nu_mass_loss: 53.0865; val_dinu_pt_loss: 14.3688; val_fused_output_loss: 24.2938; val_higgs_mass_loss: 11.1058; val_loss: 24.2938; val_nu_mass_loss: 52.9935
# Epoch 1008; dinu_pt_loss: 16.7667; fused_output_loss: 24.7217; higgs_mass_loss: 12.7190; loss: 24.7217; nu_mass_loss: 53.0994; val_dinu_pt_loss: 14.3556; val_fused_output_loss: 24.2944; val_higgs_mass_loss: 11.1380; val_loss: 24.2944; val_nu_mass_loss: 53.1023
# Epoch 1009; dinu_pt_loss: 16.7582; fused_output_loss: 24.7181; higgs_mass_loss: 12.7655; loss: 24.7181; nu_mass_loss: 53.1436; val_dinu_pt_loss: 14.3832; val_fused_output_loss: 24.2946; val_higgs_mass_loss: 11.1919; val_loss: 24.2946; val_nu_mass_loss: 53.3705
# Epoch 1010; dinu_pt_loss: 16.7581; fused_output_loss: 24.7210; higgs_mass_loss: 12.7815; loss: 24.7210; nu_mass_loss: 53.1932; val_dinu_pt_loss: 14.3458; val_fused_output_loss: 24.2924; val_higgs_mass_loss: 11.2032; val_loss: 24.2924; val_nu_mass_loss: 53.1764
# Epoch 1011; dinu_pt_loss: 16.7534; fused_output_loss: 24.7175; higgs_mass_loss: 12.7417; loss: 24.7175; nu_mass_loss: 53.1513; val_dinu_pt_loss: 14.3596; val_fused_output_loss: 24.2923; val_higgs_mass_loss: 11.1369; val_loss: 24.2923; val_nu_mass_loss: 53.2172
# Epoch 1012; dinu_pt_loss: 16.7690; fused_output_loss: 24.7155; higgs_mass_loss: 12.7478; loss: 24.7155; nu_mass_loss: 53.0811; val_dinu_pt_loss: 14.3665; val_fused_output_loss: 24.2916; val_higgs_mass_loss: 11.0996; val_loss: 24.2916; val_nu_mass_loss: 53.1340
# Epoch 1013; dinu_pt_loss: 16.7801; fused_output_loss: 24.7163; higgs_mass_loss: 12.7707; loss: 24.7163; nu_mass_loss: 53.1290; val_dinu_pt_loss: 14.3532; val_fused_output_loss: 24.2914; val_higgs_mass_loss: 11.1316; val_loss: 24.2914; val_nu_mass_loss: 53.2383
# Epoch 1014; dinu_pt_loss: 16.7571; fused_output_loss: 24.7160; higgs_mass_loss: 12.7384; loss: 24.7160; nu_mass_loss: 53.1556; val_dinu_pt_loss: 14.3591; val_fused_output_loss: 24.2915; val_higgs_mass_loss: 11.1926; val_loss: 24.2915; val_nu_mass_loss: 53.4175
# Epoch 1015; dinu_pt_loss: 16.7473; fused_output_loss: 24.7139; higgs_mass_loss: 12.7134; loss: 24.7139; nu_mass_loss: 53.0807; val_dinu_pt_loss: 14.3593; val_fused_output_loss: 24.2914; val_higgs_mass_loss: 11.0944; val_loss: 24.2914; val_nu_mass_loss: 53.1855
# Epoch 1016; dinu_pt_loss: 16.7671; fused_output_loss: 24.7126; higgs_mass_loss: 12.7126; loss: 24.7126; nu_mass_loss: 53.1580; val_dinu_pt_loss: 14.3880; val_fused_output_loss: 24.2919; val_higgs_mass_loss: 11.1190; val_loss: 24.2919; val_nu_mass_loss: 53.2144
# Epoch 1017; dinu_pt_loss: 16.7487; fused_output_loss: 24.7113; higgs_mass_loss: 12.7246; loss: 24.7113; nu_mass_loss: 53.1573; val_dinu_pt_loss: 14.3374; val_fused_output_loss: 24.2910; val_higgs_mass_loss: 11.1110; val_loss: 24.2910; val_nu_mass_loss: 53.0792
# Epoch 1018; dinu_pt_loss: 16.7377; fused_output_loss: 24.7143; higgs_mass_loss: 12.7189; loss: 24.7143; nu_mass_loss: 53.2134; val_dinu_pt_loss: 14.3385; val_fused_output_loss: 24.2903; val_higgs_mass_loss: 11.1695; val_loss: 24.2903; val_nu_mass_loss: 53.3898
# Epoch 1019; dinu_pt_loss: 16.7449; fused_output_loss: 24.7122; higgs_mass_loss: 12.7228; loss: 24.7122; nu_mass_loss: 53.1665; val_dinu_pt_loss: 14.3489; val_fused_output_loss: 24.2904; val_higgs_mass_loss: 11.0786; val_loss: 24.2904; val_nu_mass_loss: 53.1914
# Epoch 1020; dinu_pt_loss: 16.7300; fused_output_loss: 24.7126; higgs_mass_loss: 12.7165; loss: 24.7126; nu_mass_loss: 53.2078; val_dinu_pt_loss: 14.3346; val_fused_output_loss: 24.2903; val_higgs_mass_loss: 11.0822; val_loss: 24.2903; val_nu_mass_loss: 53.1367
# Epoch 1021; dinu_pt_loss: 16.7297; fused_output_loss: 24.7116; higgs_mass_loss: 12.7135; loss: 24.7116; nu_mass_loss: 53.1681; val_dinu_pt_loss: 14.3216; val_fused_output_loss: 24.2893; val_higgs_mass_loss: 11.0946; val_loss: 24.2893; val_nu_mass_loss: 53.1576
# Epoch 1022; dinu_pt_loss: 16.7277; fused_output_loss: 24.7114; higgs_mass_loss: 12.7040; loss: 24.7114; nu_mass_loss: 53.1397; val_dinu_pt_loss: 14.3107; val_fused_output_loss: 24.2896; val_higgs_mass_loss: 11.0663; val_loss: 24.2896; val_nu_mass_loss: 53.2580
# Epoch 1023; dinu_pt_loss: 16.7300; fused_output_loss: 24.7115; higgs_mass_loss: 12.6876; loss: 24.7115; nu_mass_loss: 53.1720; val_dinu_pt_loss: 14.3144; val_fused_output_loss: 24.2886; val_higgs_mass_loss: 11.1118; val_loss: 24.2886; val_nu_mass_loss: 53.2838
#
# Model Loss Weights:
# mae1        : 0.000
# mae2        : 0.000
# nu_mass     : 0.000
# higgs_mass  : 0.000
# dinu_pt     : 0.000
# fused_output: 1.000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741354260.913387 1795227 service.cc:145] XLA service 0x7f039c06de90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741354260.913406 1795227 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# 2025-03-07 13:31:01.203221: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-07 13:31:02.284030: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741354274.771516 1797185 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1741354274.877344 1797207 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_5', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1741354275.064684 1797199 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_9', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1741354275.315687 1797206 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_5', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1741354275.341899 1797194 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_9', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1741354286.874672 1795227 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_53', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1741354286.897365 1795227 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# I0000 00:00:1741354315.049196 1800853 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_5', 328 bytes spill stores, 328 bytes spill loads
#
# I0000 00:00:1741354315.253795 1800859 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_9', 328 bytes spill stores, 328 bytes spill loads
#
# I0000 00:00:1741354327.899520 1795237 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_53', 8 bytes spill stores, 8 bytes spill loads

# %%
# Make a directory
dir_name = HOME_PATH + "/11th_trial/ww_resregressor_result/" 
savedmodel_path = dir_name + "saved_model"
name = "ww_resregressor"

# If the directory exists
if os.path.exists(dir_name):
    test_files = glob.glob(dir_name + "*" + name + "*")
    if test_files:
        for file in test_files:
            os.remove(file)
        print(f"Directory {dir_name} cleaned.")
    print(f"Directory {dir_name} exists.")
else:
    os.makedirs(dir_name)
    print(f"Directory {dir_name} created.")

# save modela
model.save(dir_name + name + ".keras", save_format="keras", overwrite=True)
tf.saved_model.save(model, savedmodel_path) # save model in saved_model format --> use in the onnx 

# predict
pred_y = model.predict(test_x)
# save predicted results
np.savez_compressed(dir_name + name + "_data.npz", pred_y=pred_y, test_y=test_y)
sig_pred = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth = np.load(dir_name + name + "_data.npz")["test_y"]
# Out:
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=keras
# Directory /root/work/QE-mls/11th_trial/ww_resregressor_result/ cleaned.
# Directory /root/work/QE-mls/11th_trial/ww_resregressor_result/ exists.
# INFO:tensorflow:Assets written to: /root/work/QE-mls/11th_trial/ww_resregressor_result/saved_model/assets
# INFO:tensorflow:Assets written to: /root/work/QE-mls/11th_trial/ww_resregressor_result/saved_model/assets
# 2660/2660 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 2025-03-07 19:09:09.753835: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Extract loss values
loss = history.history["loss"]
val_loss = history.history["val_loss"]
# mae1_loss = history.history["mae1_loss"]
# val_mae1_loss = history.history["val_mae1_loss"]
# mae2_loss = history.history["mae2_loss"]
# val_mae2_loss = history.history["val_mae2_loss"]
higgs_mass_loss = history.history["higgs_mass_loss"]
val_higgs_mass_loss = history.history["val_higgs_mass_loss"]
dinu_pt_loss = history.history["dinu_pt_loss"]
val_dinu_pt_loss = history.history["val_dinu_pt_loss"]
fused_output_loss = history.history["fused_output_loss"]
val_fused_output_loss = history.history["val_fused_output_loss"]
nu_mass_loss = history.history["nu_mass_loss"]
val_nu_mass_loss = history.history["val_nu_mass_loss"]

# 1) Plot combined training and validation loss
plt.figure(figsize=(5, 4))
plt.plot(loss, label="Training Loss")
plt.plot(val_loss, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Combined Loss")
plt.legend()
plt.grid(False)
plt.show()

# # 2) Plot mae training and validation loss
# plt.figure(figsize=(5, 4))
# plt.plot(mae1_loss, label="Training MAE Loss")
# plt.plot(val_mae1_loss, label="Validation MAE Loss")
# plt.xlabel("Epochs")
# plt.ylabel("Loss")
# plt.title("MAE1 Loss")
# plt.legend()
# plt.grid(False)
# plt.show()

# # 3) Plot mae training and validation loss
# plt.figure(figsize=(5, 4))
# plt.plot(mae2_loss, label="Training MAE Loss")
# plt.plot(val_mae2_loss, label="Validation MAE Loss")
# plt.xlabel("Epochs")
# plt.ylabel("Loss")
# plt.title("MAE2 Loss")
# plt.legend()
# plt.grid(False)
# plt.show()

# 3) Plot higgs mass training and validation loss
plt.figure(figsize=(5, 4))
plt.plot(higgs_mass_loss, label="Training Higgs Mass Loss")
plt.plot(val_higgs_mass_loss, label="Validation Higgs Mass Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Higgs Mass Loss")
plt.legend()
plt.grid(False)
plt.show()

# 4) Plot dinu pt loss
plt.figure(figsize=(5, 4))
plt.plot(dinu_pt_loss, label="Training Dinu PT Loss")
plt.plot(val_dinu_pt_loss, label="Validation Dinu PT Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Dinu Pt Loss")
plt.legend()
plt.grid(False)
plt.show()

# 5) Plot fused output loss
plt.figure(figsize=(5, 4))
plt.plot(fused_output_loss, label="Training Fused Output Loss")
plt.plot(val_fused_output_loss, label="Validation Fused Output Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Fused Output Loss")
plt.legend()
plt.grid(False)
plt.show()

# 6) Plot nu mass loss
plt.figure(figsize=(5, 4))
plt.plot(nu_mass_loss, label="Training Nu Mass Loss")
plt.plot(val_nu_mass_loss, label="Validation Nu Mass Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Nu Mass Loss")
plt.legend()
plt.grid(False)
plt.show()

# %%
sig_pred.shape
# Out:
# (85112, 8)

# %%
# save predicted results
np.savez_compressed(
    dir_name + name + "_data.npz",
    pred_y=sig_pred.reshape(sig_truth.shape),
    test_y=sig_truth,
)
sig_pred_inv = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth_inv = np.load(dir_name + name + "_data.npz")["test_y"]

# %%
# neutrino mass checking
nu0_4vect = sig_pred_inv[:, :4] - test_x[:, :4]
nu1_4vect = sig_pred_inv[:, 4:8] - test_x[:, 4:8]
nu0_mass_squared = np.square(nu0_4vect[:, 3]) - np.square(nu0_4vect[:, 0]) - np.square(nu0_4vect[:, 1]) - np.square(nu0_4vect[:, 2])
nu1_mass_squared = np.square(nu1_4vect[:, 3]) - np.square(nu1_4vect[:, 0]) - np.square(nu1_4vect[:, 1]) - np.square(nu1_4vect[:, 2])
# nu0_mass_squared
plt.hist(nu0_mass_squared, bins=100, histtype="step", label="nu0_mass_squared")
plt.hist(nu1_mass_squared, bins=100, histtype="step", label="nu1_mass_squared")
plt.semilogx()
plt.semilogy()
plt.legend()
plt.show()

print("nu0_mass_squared avg:", np.mean(nu0_mass_squared))
print("nu1_mass_squared avg:", np.mean(nu1_mass_squared))
# plt.hist(nu1_mass_squared, bins=100, range=(0, 100), histtype="step", label="nu1_mass_squared")
# Out:
# nu0_mass_squared avg: 1029.6307353547245
# nu1_mass_squared avg: 639.7855221943781

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,0]):.3f}, std: {np.std(sig_truth_inv[:,0]):.3f}, min: {np.min(sig_truth_inv[:,0]):.3f}, max: {np.max(sig_truth_inv[:,0]):.3f}"
)

set_range = [-200, 200]

plot.hist_1d(
    sig_truth_inv[:,0], sig_pred_inv[:,0],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,0], sig_pred_inv[:,0], sample_weight=None)):.3f}",
    xlabel="$W^{0}\ p_{x}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,0], sig_pred_inv[:,0],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,0], sig_pred_inv[:,0]):.3f}",
    xlabel="True $W^{0}\ p_{x}$ [GeV]",
    ylabel="Predicted $W^{0}\ p_{x}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 0.031, std: 39.544, min: -585.857, max: 803.254

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,4]):.3f}, std: {np.std(sig_truth_inv[:,4]):.3f}, min: {np.min(sig_truth_inv[:,4]):.3f}, max: {np.max(sig_truth_inv[:,4]):.3f}"
)

set_range = [-200, 200]


plot.hist_1d(
    sig_truth_inv[:,4], sig_pred_inv[:,4],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,4], sig_pred_inv[:,4], sample_weight=None)):.3f}",
    xlabel="$W^{1}\ p_{x}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,4], sig_pred_inv[:,4],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,4], sig_pred_inv[:,4]):.3f}",
    xlabel="True $W^{1}\ p_{x}$ [GeV]",
    ylabel="Predicted $W^{1}\ p_{x}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: -0.124, std: 27.801, min: -399.814, max: 373.865

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,1]):.3f}, std: {np.std(sig_truth_inv[:,1]):.3f}, min: {np.min(sig_truth_inv[:,1]):.3f}, max: {np.max(sig_truth_inv[:,1]):.3f}"
)

set_range = [-200, 200]

plot.hist_1d(
    sig_truth_inv[:,1], sig_pred_inv[:,1],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,1], sig_pred_inv[:,1], sample_weight=None)):.3f}",
    xlabel="$W^{0}\ p_{y}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,1], sig_pred_inv[:,1],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,1], sig_pred_inv[:,1]):.3f}",
    xlabel="True $W^{0}\ p_{y}$ [GeV]",
    ylabel="Predicted $W^{0}\ p_{y}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: -0.013, std: 39.620, min: -755.579, max: 609.143

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,5]):.3f}, std: {np.std(sig_truth_inv[:,5]):.3f}, min: {np.min(sig_truth_inv[:,5]):.3f}, max: {np.max(sig_truth_inv[:,5]):.3f}"
)

set_range = [-200, 200]

plot.hist_1d(
    sig_truth_inv[:,5], sig_pred_inv[:,5],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,5], sig_pred_inv[:,5], sample_weight=None)):.3f}",
    xlabel="$W^{1}\ p_{y}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,5], sig_pred_inv[:,5],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,5], sig_pred_inv[:,5]):.3f}",
    xlabel="True $W^{1}\ p_{y}$ [GeV]",
    ylabel="Predicted $W^{1}\ p_{y}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 0.031, std: 27.968, min: -417.838, max: 580.447

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,2]):.3f}, std: {np.std(sig_truth_inv[:,2]):.3f}, min: {np.min(sig_truth_inv[:,2]):.3f}, max: {np.max(sig_truth_inv[:,2]):.3f}"
)

set_range = [-700, 700]

plot.hist_1d(
    sig_truth_inv[:,2], sig_pred_inv[:,2],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,2], sig_pred_inv[:,2], sample_weight=None)):.3f}",
    xlabel="$W^{0}\ p_{z}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,2], sig_pred_inv[:,2],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,2], sig_pred_inv[:,2]):.3f}",
    xlabel="$W^{0}\ p_{z}$ [GeV]",
    ylabel="Predicted $W^{0}\ p_{z}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 0.308, std: 170.752, min: -1446.473, max: 1754.351

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,6]):.3f}, std: {np.std(sig_truth_inv[:,6]):.3f}, min: {np.min(sig_truth_inv[:,6]):.3f}, max: {np.max(sig_truth_inv[:,6]):.3f}"
)

set_range = [-600, 600]

plot.hist_1d(
    sig_truth_inv[:,6], sig_pred_inv[:,6],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,6], sig_pred_inv[:,6], sample_weight=None)):.3f}",
    xlabel="$W^{1}\ p_{z}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,6], sig_pred_inv[:,6],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,6], sig_pred_inv[:,6]):.3f}",
    xlabel="True $W^{1}\ p_{z}$ [GeV]",
    ylabel="Predicted $W^{1}\ p_{z}$ [GeV]",
    ranges=set_range
)
# Out:
# Truth mean: -0.337, std: 110.947, min: -1170.774, max: 1427.069

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,3]):.3f}, std: {np.std(sig_truth_inv[:,3]):.3f}, min: {np.min(sig_truth_inv[:,3]):.3f}, max: {np.max(sig_truth_inv[:,3]):.3f}"
)

set_range = [0, 800]

plot.hist_1d(
    sig_truth_inv[:,3], sig_pred_inv[:,3],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,3], sig_pred_inv[:,3], sample_weight=None)):.3f}",
    xlabel="$W^{0}\ E$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,3], sig_pred_inv[:,3],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,3], sig_pred_inv[:,3]):.3f}",
    xlabel="True $W^{0}\ E$ [GeV]",
    ylabel="Predicted $W^{0}\ E$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 158.446, std: 111.648, min: 21.707, max: 1791.292

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,7]):.3f}, std: {np.std(sig_truth_inv[:,7]):.3f}, min: {np.min(sig_truth_inv[:,7]):.3f}, max: {np.max(sig_truth_inv[:,7]):.3f}"
)

set_range = [0, 800]

plot.hist_1d(
    sig_truth_inv[:,7], sig_pred_inv[:,7],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,7], sig_pred_inv[:,7], sample_weight=None)):.3f}",
    xlabel="$W^{1}\ E$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,7], sig_pred_inv[:,7],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,7], sig_pred_inv[:,7]):.3f}",
    xlabel="True $W^{1}\ E$ [GeV]",
    ylabel="Predicted $W^{1}\ E$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 98.991, std: 77.608, min: 17.001, max: 1443.825

# %%
lead_time_like = np.square(sig_pred_inv[:, 3]) - np.sum(
    np.square(sig_pred_inv[:, 0:3]), axis=1
)
lead_time_mask = (lead_time_like > 0) * 1
sublead_time_like = np.square(sig_pred_inv[:, 7]) - np.sum(
    np.square(sig_pred_inv[:, 4:7]), axis=1
)
sublead_time_mask = (sublead_time_like > 0) * 1

bin_edges = np.linspace(-5, 1.0e4, 51)
figure = plt.figure(figsize=(10, 8))
plt.hist(
    lead_time_like,
    bins=bin_edges,
    fill=False,
    color="orange",
    histtype="step",
    label=r"$W^{0}$, "
    + f"{100 * np.sum(lead_time_mask) / len(lead_time_mask):.2f} % TL",
    density=True,
    weights=None,
    linewidth=2,
)
plt.hist(
    sublead_time_like,
    bins=bin_edges,
    fill=False,
    color="tab:blue",
    histtype="step",
    label=r"$W^{1}$, "
    + f"{100 * np.sum(sublead_time_mask) / len(sublead_time_mask):.2f} % TL",
    density=True,
    weights=None,
    linewidth=2,
)
plt.hist(
    np.square(w_lead.m),
    bins=bin_edges,
    color="orange",
    fill=True,
    histtype="bar",
    alpha=0.5,
    label=r"$W_{label}^{0}$",
    density=True,
    # weights=mc_weight,
)
plt.hist(
    np.square(w_sublead.m),
    bins=bin_edges,
    color="tab:blue",
    fill=True,
    histtype="bar",
    alpha=0.5,
    label=r"$W_{label}^{1}$",
    density=True,
    # weights=mc_weight,
)
plt.vlines(0, 0, 2e-3, color="red", linestyle="--")
plt.xlim(-5e2, 1.2e4)
plt.ylim(0, 2e-3)
plt.xlabel(r"Mass$^{2}$ [GeV]$^{2}$", labelpad=20)
plt.ylabel("Normalized counts")
plt.legend(loc="upper right", prop={'size': 20})  # Adjust the size value as needed
plt.show()
print(f"m2 with {100 * np.sum(lead_time_mask * sublead_time_mask) / len(lead_time_mask):.2f} % time-like (TL) evts")
# Out:
# m2 with 98.08 % time-like (TL) evts

# %%
# TODO: 2d mass squared
pred_m2 = np.concatenate([lead_time_like, sublead_time_like], axis=-1)
truth_m2 = np.concatenate(
    [np.square(w_lead.m)[test_indices], np.square(w_sublead.m)[test_indices]], axis=-1
)

print(
    f"Truth mean: {np.mean(truth_m2):.3f}, std: {np.std(truth_m2):.3f}, min: {np.min(truth_m2):.3f}, max: {np.max(truth_m2):.3f}"
)

set_range = [-500, 10_500]


plot.hist_1d(
    truth_m2, pred_m2,
    title="",
    xlabel=r"$m_{W}^{2}$",
    xpad=25,
    ranges=set_range
)

plot.hist_2d(
    truth_m2, pred_m2,
    title="",
    xlabel="True $m_{W}^{2}$ [GeV]$^2$",
    ylabel="Predicted $m_{W}^{2}$ [GeV]$^2$",
    xpad=25,
    ranges=set_range
)
# Out:
# Truth mean: 3615.291, std: 2594.373, min: 4.010, max: 11077.988

# %%
# TODO: CGLMP

def Bij(particles):
    # Ensure ROOT is properly initialized
    ROOT.gROOT.SetBatch(True)

    def cglmp(z_xp, z_xn, z_yp, z_yn):
        """
        This is a function to calculate Bij (CGLMP values).
        :param z_xp: Angle (xi) between positive lepton and x-axis.
        :param z_xn: Angle (xi) between negative lepton and x-axis.
        :param z_yp: Angle (xi) between positive lepton and y-axis.
        :param z_xn: Angle (xi) between negative lepton and y-axis.
        """
        # count expectation value, use (27) in Alan's paper
        tr_a = (np.divide(8, np.sqrt(3))) * (z_xp * z_xn + z_yp * z_yn)
        tr_b = (
            25
            * (np.square(z_xp) - np.square(z_yp))
            * (np.square(z_xn) - np.square(z_yn))
        )
        tr_c = 100 * (z_xp * z_yp * z_xn * z_yn)
        tr = tr_a + tr_b + tr_c

        return tr

    WpBoson = TLorentzVector(*particles[:4])
    WpLepton = TLorentzVector(*particles[4:8])
    WnBoson = TLorentzVector(*particles[8:12])
    WnLepton = TLorentzVector(*particles[12:16])

    # construct Higgs 4-vector
    Higgs = WpBoson + WnBoson

    # construct a moving orthogonal basis (k,r,n)
    Beam_p = TLorentzVector(0, 0, 1, 1)  # spatial-axis

    # define boost vector
    Higgsb = Higgs.BoostVector()

    # (1) performs a boost transformation from the rod frame to the rawal one.
    # Perform boost transformation from the rod frame to the rawal one
    for vec in [WpBoson, WpLepton, WnBoson, WnLepton, Beam_p]:
        vec.Boost(-Higgsb)

    # 2. Define (k,r,n) -> definitions are in Alan's paper
    k_per = TVector3(WpBoson.X(), WpBoson.Y(), WpBoson.Z())
    p_per = TVector3(Beam_p.X(), Beam_p.Y(), Beam_p.Z())  # in the Higgs rest frame
    k = k_per.Unit()  # normalized -> unit vector
    p = p_per.Unit()
    y = p.Dot(k)
    r_length = np.sqrt(1 - y * y)
    r = (1 / r_length) * (p - y * k)
    n = (1 / r_length) * (p.Cross(k))  # (1/sin)*sin = 1 -> unit vector

    # 3. Further boost to W+ and W- frame respectively
    WpkBoost = WpBoson.BoostVector()
    WpBoson.Boost(-WpkBoost)
    WpLepton.Boost(-WpkBoost)
    WnkBoost = WnBoson.BoostVector()
    WnBoson.Boost(-WnkBoost)
    WnLepton.Boost(-WnkBoost)

    # 4. Map all particle to (k,r,n) frame
    WpLp = WpLepton.Vect()  # momentum in (k,r,n)
    WnLp = WnLepton.Vect()
    # Mapping to n-r-k basis
    WpLp_k = TLorentzVector(WpLp.Dot(n), WpLp.Dot(r), WpLp.Dot(k), WpLepton.E())
    WnLp_k = TLorentzVector(WnLp.Dot(n), WnLp.Dot(r), WnLp.Dot(k), WnLepton.E())

    # 5. Calculate directional cosines
    # directional cosine from Wp
    WpLp_Vect_Mag = WpLp_k.Vect().Mag()
    cos_n_join_p = np.divide(WpLp_k.X(), WpLp_Vect_Mag)
    cos_r_join_p = np.divide(WpLp_k.Y(), WpLp_Vect_Mag)
    cos_k_join_p = np.divide(WpLp_k.Z(), WpLp_Vect_Mag)
    # directional cosine from Wn
    WnLp_Vect_Mag = WnLp_k.Vect().Mag()
    cos_n_join_n = np.divide(WnLp_k.X(), WnLp_Vect_Mag)
    cos_r_join_n = np.divide(WnLp_k.Y(), WnLp_Vect_Mag)
    cos_k_join_n = np.divide(WnLp_k.Z(), WnLp_Vect_Mag)

    # 6. Calculate Bij (CGLMP values)
    B_xy = cglmp(cos_n_join_p, cos_n_join_n, cos_r_join_p, cos_r_join_n)
    B_yz = cglmp(cos_r_join_p, cos_r_join_n, cos_k_join_p, cos_k_join_n)
    B_zx = cglmp(cos_n_join_p, cos_n_join_n, cos_k_join_p, cos_k_join_n)

    return (
        np.array([B_xy, B_yz, B_zx]),
        np.array([cos_n_join_p, cos_r_join_p, cos_k_join_p]),
        np.array([cos_n_join_n, cos_r_join_n, cos_k_join_n]),
    )
    
def result_generator(particles):
    with multiprocessing.Pool(WORKERS) as pool:
        # Retrieve the output from the pool
        results = list(pool.map(Bij, particles))
    
    # Unpack the results
    bij, xi_p, xi_n = zip(*results)
    
    bij = np.vstack(bij)  # Flatten the nested array
    xi_p = np.vstack(xi_p)
    xi_n = np.vstack(xi_n)
    mask = np.any(np.isnan(bij), axis=1)
    return (
        bij[~mask, :],
        xi_p[~mask, :],
        xi_n[~mask, :],
    )

# %%
# reco
particles = np.concatenate(
    [
        sig_pred_inv[:, 0:4],
        lead_lep_p4[test_indices],
        sig_pred_inv[:, 4:8],
        sublead_lep_p4[test_indices],
    ],
    axis=1,
)
bij = result_generator(particles)[0][0:80_000,:]
xi_p = result_generator(particles)[1][0:80_000,:]
xi_n = result_generator(particles)[2][0:80_000,:]

# truth
particles = np.concatenate(
    [
        sig_truth_inv[:, 0:4],
        truth_lead_lep_p4[test_indices],
        sig_truth_inv[:, 4:8],
        truth_sublead_lep_p4[test_indices],
    ],
    axis=1,
)
truth_bij = result_generator(particles)[0][0:80_000,:]
truth_xi_p = result_generator(particles)[1][0:80_000,:]
truth_xi_n = result_generator(particles)[2][0:80_000,:]

# %%
print(
    f"True mean     : {np.mean(truth_bij[:,0]):.3f}, std: {np.std(truth_bij[:,0]):.3f}, min: {np.min(truth_bij[:,0]):.3f}, max: {np.max(truth_bij[:,0]):.3f}"
)
print(
    f"Predicted mean: {np.mean(bij[:,0]):.3f}, std: {np.std(bij[:,0]):.3f}, min: {np.min(bij[:,0]):.3f}, max: {np.max(bij[:,0]):.3f}"
)

set_range = [-30, 30]

plot.hist_1d(
    truth_bij[:,0], bij[:,0],
    title=rf"mean={np.mean(bij[:,0]):.2f}$\pm${sp.stats.sem(bij[:,0]):.3f}"
    + f" with truth: {np.mean(truth_bij[:,0]):.2f}$\pm${sp.stats.sem(truth_bij[:,0]):.3f}",
    xlabel=r"$B_{xy}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_bij[:,0], bij[:,0],
    title=r"$R^{2}$ = " + f"{r2_score(truth_bij[:,0], bij[:,0]):.3f}",
    xlabel="True $B_{{xy}}$ [None]",
    ylabel="Predicted $B_{{xy}}$ [None]",
    ranges=set_range
)
# Out:
# True mean     : 2.468, std: 12.019, min: -25.100, max: 29.607
# Predicted mean: 9.749, std: 7.528, min: -24.240, max: 29.462

# %%
print(
    f"True mean     : {np.mean(truth_bij[:,1]):.3f}, std: {np.std(truth_bij[:,1]):.3f}, min: {np.min(truth_bij[:,1]):.3f}, max: {np.max(truth_bij[:,1]):.3f}"
)
print(
    f"Predicted mean: {np.mean(bij[:,1]):.3f}, std: {np.std(bij[:,1]):.3f}, min: {np.min(bij[:,1]):.3f}, max: {np.max(bij[:,1]):.3f}"
)

set_range = [-30, 30]


plot.hist_1d(
    truth_bij[:,1], bij[:,1],
    title=fr"mean={np.mean(bij[:,1]):.2f}$\pm${sp.stats.sem(bij[:,1]):.3f}"
    + f" with truth: {np.mean(truth_bij[:,1]):.2f}$\pm${sp.stats.sem(truth_bij[:,1]):.3f}",
    xlabel=r"$B_{yz}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_bij[:,1], bij[:,1],
    title=r"$R^{2}$ = " + f"{r2_score(truth_bij[:,1], bij[:,1]):.3f}",
    xlabel="True $B_{{yz}}$ [None]",
    ylabel="Predicted $B_{{yz}}$ [None]",
    ranges=set_range
)
# Out:
# True mean     : 2.060, std: 8.727, min: -25.095, max: 29.572
# Predicted mean: 0.752, std: 7.830, min: -25.046, max: 29.467

# %%
print(
    f"True mean     : {np.mean(truth_bij[:,2]):.3f}, std: {np.std(truth_bij[:,2]):.3f}, min: {np.min(truth_bij[:,2]):.3f}, max: {np.max(truth_bij[:,2]):.3f}"
)
print(
    f"Predicted mean: {np.mean(bij[:,2]):.3f}, std: {np.std(bij[:,2]):.3f}, min: {np.min(bij[:,2]):.3f}, max: {np.max(bij[:,2]):.3f}"
)

set_range = [-30, 30]

plot.hist_1d(
    truth_bij[:,2], bij[:,2],
    title=rf"mean={np.mean(bij[:,2]):.2f}$\pm${sp.stats.sem(bij[:,2]):.3f}"
    + rf" with truth: {np.mean(truth_bij[:,2]):.2f}$\pm${sp.stats.sem(truth_bij[:,2]):.3f}",
    xlabel=r"$B_{zx}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_bij[:,2], bij[:,2],
    title=r"$R^{2}$ = " + f"{r2_score(truth_bij[:,2], bij[:,2]):.3f}",
    xlabel=r"True $B_{{zx}}$ [None]",
    ylabel=r"Predicted $B_{{zx}}$ [None]",
    ranges=set_range
)
# Out:
# True mean     : 3.228, std: 10.739, min: -25.073, max: 29.599
# Predicted mean: -2.102, std: 13.073, min: -25.100, max: 29.444

# %%
set_range = [-1, 1]


plot.hist_1d(
    truth_xi_p[:,0], xi_p[:,0],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_p[:,0], xi_p[:,0], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(0)}_{n}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_p[:,0], xi_p[:,0],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_p[:,0], xi_p[:,0]):.3f}",
    xlabel=r"True $\xi^{(0)}_{n}$ [None]",
    ylabel=r"Predicted $\xi^{(0)}_{n}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_p[:,1], xi_p[:,1],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_p[:,1], xi_p[:,1], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(0)}_{r}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_p[:,1], xi_p[:,1],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_p[:,1], xi_p[:,1]):.3f}",
    xlabel=r"True $\xi^{(0)}_{r}$ [None]",
    ylabel=r"Predicted $\xi^{(0)}_{r}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_p[:,2], xi_p[:,2],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_p[:,2], xi_p[:,2], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(0)}_{k}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_p[:,2], xi_p[:,2],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_p[:,2], xi_p[:,2]):.3f}",
    xlabel=r"True $\xi^{(0)}_{k}$ [None]",
    ylabel=r"Predicted $\xi^{(0)}_{k}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_n[:,0], xi_n[:,0],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_n[:,0], xi_n[:,0], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(1)}_{n}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_n[:,0], xi_n[:,0],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_n[:,0], xi_n[:,0]):.3f}",
    xlabel=r"True $\xi^{(1)}_{n}$ [None]",
    ylabel=r"Predicted $\xi^{(1)}_{n}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_n[:,1], xi_n[:,1],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_n[:,1], xi_n[:,1], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(1)}_{r}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_n[:,1], xi_n[:,1],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_n[:,1], xi_n[:,1]):.3f}",
    xlabel=r"True $\xi^{(1)}_{r}$ [None]",
    ylabel=r"Predicted $\xi^{(1)}_{r}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_n[:,2], xi_n[:,2],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_n[:,2], xi_n[:,2], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(1)}_{k}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_n[:,2], xi_n[:,2],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_n[:,2], xi_n[:,2]):.3f}",
    xlabel=r"True $\xi^{(1)}_{k}$ [None]",
    ylabel=r"Predicted $\xi^{(1)}_{k}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
w_plot_true = [
    sig_truth_inv[:,0],
	sig_truth_inv[:,2],
	sig_truth_inv[:,3],
	sig_truth_inv[:,4],
	sig_truth_inv[:,6],
	sig_truth_inv[:,7],
]
w_plot_pred = [
    sig_pred_inv[:,0],
	sig_pred_inv[:,2],
	sig_pred_inv[:,3],
	sig_pred_inv[:,4],
	sig_pred_inv[:,6],
	sig_pred_inv[:,7],
]
w_plot_ranges = [
	[-200, 200],
	[-700, 700],
	[0, 800],
	[-200, 200],
	[-600, 600],
	[0, 800],
]
w_plot_labels = [
	r"$W^{0}\ p_{x}$",
	r"$W^{0}\ p_{z}$",
	r"$W^{0}\ E$",
	r"$W^{1}\ p_{x}$",
	r"$W^{1}\ p_{z}$",
	r"$W^{1}\ E$",
]
plot.hist_1d_grid(
	w_plot_true, w_plot_pred,
	title=w_plot_labels,
	ranges=w_plot_ranges,
 	xlabel="[GeV]",
)
plot.hist_2d_grid(
	w_plot_true, w_plot_pred,
	title=w_plot_labels,
	ranges=w_plot_ranges,
	xlabel="True [GeV]",
	ylabel="Predicted [GeV]",
)

# %%
xi_plot_true = [
	truth_xi_p[:,0],
	truth_xi_p[:,1],
	truth_xi_p[:,2],
	truth_xi_n[:,0],
	truth_xi_n[:,1],
	truth_xi_n[:,2],
]
xi_plot_pred = [
	xi_p[:,0],
	xi_p[:,1],
	xi_p[:,2],
	xi_n[:,0],
	xi_n[:,1],
	xi_n[:,2],
]
xi_plot_ranges = [[-1, 1]]*6
xi_plot_labels = [
	r"$\xi^{(0)}_{n}$",
	r"$\xi^{(0)}_{r}$",
	r"$\xi^{(0)}_{k}$",
	r"$\xi^{(1)}_{n}$",
	r"$\xi^{(1)}_{r}$",
	r"$\xi^{(1)}_{k}$",
]
plot.hist_1d_grid(
	xi_plot_true, xi_plot_pred,
	title=xi_plot_labels,
	ranges=xi_plot_ranges,
	xlabel="[None]",
)
plot.hist_2d_grid(
	xi_plot_true, xi_plot_pred,
	title=xi_plot_labels,
	ranges=xi_plot_ranges,
	xlabel="True [None]",
	ylabel="Predicted [None]",
)
