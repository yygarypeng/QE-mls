# %%
# %reset -sf

import tensorflow as tf
print(tf.__version__)


# GPU(s) setups
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')
        
        # Instead of enabling memory growth, set a memory limit
        memory_limit = 16_384*2 # Set the memory limit in MB
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]
        )
        
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2024-08-16 19:02:38.381752: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.13.0
# 2 Physical GPUs, 1 Logical GPU
# 2024-08-16 19:02:41.491531: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 32768 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
import sys
import os
import glob
HOME_PATH = os.path.abspath("..")
sys.path.insert(0, HOME_PATH+"/qe")

import get_data as gd
import atlas_plot as ap
plot = ap.Plotter()

# INN packages
from flow import *
from utils import *

import pandas as pd
import numpy as np
import scipy as sp

from matplotlib import pyplot as plt
import matplotlib as mpl
import shap

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

# %%
SEED = 42  # set random seed (global variable)
np.random.seed(SEED)
processor = gd.DataProcessor()
path = "/root/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 76
#
# ['/root/data/truth/signal/CGLMP.npz', '/root/data/truth/signal/Higgs.npz', '/root/data/truth/signal/LeadLepton.npz', '/root/data/truth/signal/LeptonM.npz', '/root/data/truth/signal/LeptonP.npz', '/root/data/truth/signal/LmNu.npz', '/root/data/truth/signal/LpNu.npz', '/root/data/truth/signal/MET.npz', '/root/data/truth/signal/WmBoson.npz', '/root/data/truth/signal/WpBoson.npz', '/root/data/truth/signal/diLepton.npz', '/root/data/truth/signal/subLeadLepton.npz', '/root/data/truth/signal/xi_xyz.npz']

# %%
## Global variables

GEV = 1e3

cut_pre_pt_lead = data.LeadLep["pt"] > 22 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
cut_pre_pt_miss = data.MET["pt"] > 20 * GEV

PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

BATCH_SIZE = 8192
EPOCHS = 1_024
LEARNING_RATE = 5e-5

# %%
## Interesting variables

# Critria for leading and subleading lepton
lead_p = data.LeadLep["m"] == data.LepP["m"]
sublead_p = ~lead_p
lead_m = sublead_p.copy()
sublead_m = lead_p.copy()

# sperate onshell and offshell W
w_lead = pd.concat([data.Wp[lead_p], data.Wm[lead_m]], axis=0).sort_index()
w_sublead = pd.concat([data.Wp[sublead_p], data.Wm[sublead_m]], axis=0).sort_index()
onshell_mask = (w_lead["m"] > w_sublead["m"]).to_numpy()
cut_onshell_mask = (w_lead[PRE_CUT]["m"] > w_sublead[PRE_CUT]["m"]).to_numpy()
base_acc = w_lead[onshell_mask].shape[0] / w_lead.shape[0]
cut_acc  = w_lead[PRE_CUT][cut_onshell_mask].shape[0] / w_lead[PRE_CUT].shape[0]
print(f"Base accuracy: {base_acc:.2f}")
print(f"Cut  accuracy: {cut_acc:.2f}")
print(f"Cuts improve: {100 * (cut_acc - base_acc):.2f}%")

# Check (sub)lead W
plt.hist(w_lead["m"] / GEV, bins=100, color="r", histtype="step", label=r"$W^{lead}$")
plt.hist(
    w_sublead["m"] / GEV, bins=100, color="b", histtype="step", label=r"$W^{sublead}$"
)
plt.title("W mass")
plt.xlabel("mass [GeV]")
plt.ylabel("count")
plt.legend(loc="best")
plt.show()
plt.close()

# Kinematics of interesting variables (target for training)
int_kin = onshell_mask.astype(int)[PRE_CUT]
print("int_kin shape:", int_kin.shape)
print(type(int_kin))
# Out:
# Base accuracy: 0.83
# Cut  accuracy: 0.81
# Cuts improve: -1.75%
# int_kin shape: (1378510,)
# <class 'numpy.ndarray'>

# %%
## Observing variables

met = data.MET[["px", "py", "pt", "phi"]]
lead_lep = data.LeadLep[["px", "py", "pz", "E", "pt", "eta", "phi"]]
sublead_lep = data.SubLep[["px", "py", "pz", "E", "pt", "eta", "phi"]]

# Kinematics of observing variables (inputs for training)
obs_kin = pd.concat([lead_lep, sublead_lep, met], axis=1)[PRE_CUT] / GEV
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array
ROBUST_OBS = RobustScaler()
obs_kin = ROBUST_OBS.fit_transform(obs_kin)
print(type(obs_kin))
# Out:
# int_kin shape: (1378510, 18)
# <class 'numpy.ndarray'>

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.4,
    test_size=0.6,
    random_state=SEED,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=SEED
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# X (Interest)
# Training data shape: (551404, 18);
# Validing data shape: (413553, 18);
# Testing data shape: (413553, 18).
# Y (Observed)
# Training data shape: (551404,);
# Validing data shape: (413553,);
# Testing data shape: (413553,).

# %%
# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    x = tf.keras.layers.Dense(units=128, activation="selu")(x)
    x = tf.keras.layers.Dense(units=256, activation="selu")(x)
    x = tf.keras.layers.Dropout(rate=0.1)(x)
    x = tf.keras.layers.Dense(units=512, activation="selu")(x)
    x = tf.keras.layers.Dropout(rate=0.3)(x)
    x = tf.keras.layers.Dense(units=512, activation="selu")(x)
    x = tf.keras.layers.Dropout(rate=0.3)(x)
    x = tf.keras.layers.Dense(units=128, activation="selu")(x)
    x = tf.keras.layers.Dense(units=64, activation="selu")(x)

    outputs = tf.keras.layers.Dense(units=1, activation="sigmoid")(x)
    
    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss=tf.losses.binary_crossentropy,
        metrics=["accuracy"],
    )

    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 18)]              0
#
#  flatten (Flatten)           (None, 18)                0
#
#  dense (Dense)               (None, 128)               2432
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 503681 (1.92 MB)
# Trainable params: 503681 (1.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2024-08-16 19:02:54.180655: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:753] failed to allocate 32.00GiB (34359738368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-3,
    patience=32,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)


def scheduler(epoch, lr):
    if epoch < 128:
        return lr
    else:
        return lr * tf.math.exp(-0.001)


lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

# Fit the model
history = model.fit(
    x=train_x,
    y=train_y,
    validation_data=(valid_x, valid_y),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=2,
    callbacks=[stop_early,lr_scheduler],
)
# Out:
# Epoch 1/1024
# 2024-08-16 19:02:56.402124: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-08-16 19:02:56.407234: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f9f08020870 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-08-16 19:02:56.407266: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-08-16 19:02:56.414584: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-08-16 19:02:56.556152: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-08-16 19:02:56.681046: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 68/68 - 4s - loss: 0.5017 - accuracy: 0.7657 - val_loss: 0.4139 - val_accuracy: 0.8144 - lr: 5.0000e-05 - 4s/epoch - 57ms/step
# Epoch 2/1024
# 68/68 - 0s - loss: 0.4276 - accuracy: 0.8089 - val_loss: 0.3894 - val_accuracy: 0.8259 - lr: 5.0000e-05 - 497ms/epoch - 7ms/step
# Epoch 3/1024
# 68/68 - 0s - loss: 0.4018 - accuracy: 0.8197 - val_loss: 0.3703 - val_accuracy: 0.8343 - lr: 5.0000e-05 - 497ms/epoch - 7ms/step
# Epoch 4/1024
# 68/68 - 1s - loss: 0.3815 - accuracy: 0.8288 - val_loss: 0.3521 - val_accuracy: 0.8443 - lr: 5.0000e-05 - 504ms/epoch - 7ms/step
# Epoch 5/1024
# 68/68 - 1s - loss: 0.3660 - accuracy: 0.8373 - val_loss: 0.3386 - val_accuracy: 0.8518 - lr: 5.0000e-05 - 508ms/epoch - 7ms/step
# Epoch 6/1024
# 68/68 - 0s - loss: 0.3535 - accuracy: 0.8436 - val_loss: 0.3294 - val_accuracy: 0.8560 - lr: 5.0000e-05 - 499ms/epoch - 7ms/step
# Epoch 7/1024
# 68/68 - 1s - loss: 0.3450 - accuracy: 0.8473 - val_loss: 0.3250 - val_accuracy: 0.8578 - lr: 5.0000e-05 - 505ms/epoch - 7ms/step
# Epoch 8/1024
# 68/68 - 0s - loss: 0.3405 - accuracy: 0.8492 - val_loss: 0.3227 - val_accuracy: 0.8587 - lr: 5.0000e-05 - 496ms/epoch - 7ms/step
# Epoch 9/1024
# 68/68 - 1s - loss: 0.3380 - accuracy: 0.8503 - val_loss: 0.3210 - val_accuracy: 0.8592 - lr: 5.0000e-05 - 504ms/epoch - 7ms/step
# Epoch 10/1024
# 68/68 - 0s - loss: 0.3349 - accuracy: 0.8518 - val_loss: 0.3197 - val_accuracy: 0.8599 - lr: 5.0000e-05 - 500ms/epoch - 7ms/step
# Epoch 11/1024
# 68/68 - 0s - loss: 0.3337 - accuracy: 0.8526 - val_loss: 0.3182 - val_accuracy: 0.8605 - lr: 5.0000e-05 - 493ms/epoch - 7ms/step
# Epoch 12/1024
# 68/68 - 0s - loss: 0.3318 - accuracy: 0.8529 - val_loss: 0.3171 - val_accuracy: 0.8606 - lr: 5.0000e-05 - 497ms/epoch - 7ms/step
# Epoch 13/1024
# 68/68 - 0s - loss: 0.3306 - accuracy: 0.8535 - val_loss: 0.3167 - val_accuracy: 0.8607 - lr: 5.0000e-05 - 494ms/epoch - 7ms/step
# Epoch 14/1024
# 68/68 - 0s - loss: 0.3291 - accuracy: 0.8543 - val_loss: 0.3155 - val_accuracy: 0.8611 - lr: 5.0000e-05 - 496ms/epoch - 7ms/step
# Epoch 15/1024
# 68/68 - 0s - loss: 0.3275 - accuracy: 0.8545 - val_loss: 0.3146 - val_accuracy: 0.8617 - lr: 5.0000e-05 - 490ms/epoch - 7ms/step
# Epoch 16/1024
# 68/68 - 0s - loss: 0.3265 - accuracy: 0.8554 - val_loss: 0.3140 - val_accuracy: 0.8616 - lr: 5.0000e-05 - 489ms/epoch - 7ms/step
# Epoch 17/1024
# 68/68 - 0s - loss: 0.3256 - accuracy: 0.8555 - val_loss: 0.3134 - val_accuracy: 0.8618 - lr: 5.0000e-05 - 487ms/epoch - 7ms/step
# Epoch 18/1024
# 68/68 - 0s - loss: 0.3248 - accuracy: 0.8562 - val_loss: 0.3124 - val_accuracy: 0.8622 - lr: 5.0000e-05 - 487ms/epoch - 7ms/step
# Epoch 19/1024
# 68/68 - 0s - loss: 0.3239 - accuracy: 0.8565 - val_loss: 0.3121 - val_accuracy: 0.8623 - lr: 5.0000e-05 - 483ms/epoch - 7ms/step
# Epoch 20/1024
# 68/68 - 0s - loss: 0.3228 - accuracy: 0.8569 - val_loss: 0.3116 - val_accuracy: 0.8625 - lr: 5.0000e-05 - 496ms/epoch - 7ms/step
# Epoch 21/1024
# 68/68 - 0s - loss: 0.3222 - accuracy: 0.8572 - val_loss: 0.3113 - val_accuracy: 0.8625 - lr: 5.0000e-05 - 490ms/epoch - 7ms/step
# Epoch 22/1024
# 68/68 - 0s - loss: 0.3221 - accuracy: 0.8569 - val_loss: 0.3110 - val_accuracy: 0.8629 - lr: 5.0000e-05 - 494ms/epoch - 7ms/step
# Epoch 23/1024
# 68/68 - 0s - loss: 0.3214 - accuracy: 0.8577 - val_loss: 0.3108 - val_accuracy: 0.8626 - lr: 5.0000e-05 - 492ms/epoch - 7ms/step
# Epoch 24/1024
# 68/68 - 0s - loss: 0.3208 - accuracy: 0.8577 - val_loss: 0.3100 - val_accuracy: 0.8631 - lr: 5.0000e-05 - 495ms/epoch - 7ms/step
# Epoch 25/1024
# 68/68 - 0s - loss: 0.3206 - accuracy: 0.8576 - val_loss: 0.3099 - val_accuracy: 0.8629 - lr: 5.0000e-05 - 487ms/epoch - 7ms/step
# Epoch 26/1024
# 68/68 - 0s - loss: 0.3197 - accuracy: 0.8582 - val_loss: 0.3100 - val_accuracy: 0.8630 - lr: 5.0000e-05 - 493ms/epoch - 7ms/step
# Epoch 27/1024
# 68/68 - 0s - loss: 0.3194 - accuracy: 0.8583 - val_loss: 0.3096 - val_accuracy: 0.8629 - lr: 5.0000e-05 - 491ms/epoch - 7ms/step
# Epoch 28/1024
# 68/68 - 0s - loss: 0.3188 - accuracy: 0.8586 - val_loss: 0.3098 - val_accuracy: 0.8629 - lr: 5.0000e-05 - 498ms/epoch - 7ms/step
# Epoch 29/1024
# 68/68 - 0s - loss: 0.3185 - accuracy: 0.8588 - val_loss: 0.3088 - val_accuracy: 0.8631 - lr: 5.0000e-05 - 488ms/epoch - 7ms/step
# Epoch 30/1024
# 68/68 - 0s - loss: 0.3181 - accuracy: 0.8591 - val_loss: 0.3091 - val_accuracy: 0.8631 - lr: 5.0000e-05 - 486ms/epoch - 7ms/step
# Epoch 31/1024
# 68/68 - 0s - loss: 0.3177 - accuracy: 0.8588 - val_loss: 0.3082 - val_accuracy: 0.8634 - lr: 5.0000e-05 - 486ms/epoch - 7ms/step
# Epoch 32/1024
# 68/68 - 0s - loss: 0.3174 - accuracy: 0.8590 - val_loss: 0.3082 - val_accuracy: 0.8637 - lr: 5.0000e-05 - 492ms/epoch - 7ms/step
# Epoch 33/1024
# 68/68 - 0s - loss: 0.3166 - accuracy: 0.8594 - val_loss: 0.3081 - val_accuracy: 0.8635 - lr: 5.0000e-05 - 492ms/epoch - 7ms/step
# Epoch 34/1024
# 68/68 - 1s - loss: 0.3163 - accuracy: 0.8598 - val_loss: 0.3079 - val_accuracy: 0.8638 - lr: 5.0000e-05 - 501ms/epoch - 7ms/step
# Epoch 35/1024
# 68/68 - 1s - loss: 0.3162 - accuracy: 0.8598 - val_loss: 0.3079 - val_accuracy: 0.8637 - lr: 5.0000e-05 - 505ms/epoch - 7ms/step
# Epoch 36/1024
# 68/68 - 0s - loss: 0.3159 - accuracy: 0.8598 - val_loss: 0.3073 - val_accuracy: 0.8636 - lr: 5.0000e-05 - 498ms/epoch - 7ms/step
# Epoch 37/1024
# 68/68 - 1s - loss: 0.3155 - accuracy: 0.8599 - val_loss: 0.3072 - val_accuracy: 0.8638 - lr: 5.0000e-05 - 506ms/epoch - 7ms/step
# Epoch 38/1024
# 68/68 - 0s - loss: 0.3151 - accuracy: 0.8602 - val_loss: 0.3068 - val_accuracy: 0.8641 - lr: 5.0000e-05 - 496ms/epoch - 7ms/step
# Epoch 39/1024
# 68/68 - 1s - loss: 0.3148 - accuracy: 0.8596 - val_loss: 0.3066 - val_accuracy: 0.8642 - lr: 5.0000e-05 - 504ms/epoch - 7ms/step
# Epoch 40/1024
# 68/68 - 0s - loss: 0.3146 - accuracy: 0.8599 - val_loss: 0.3065 - val_accuracy: 0.8643 - lr: 5.0000e-05 - 499ms/epoch - 7ms/step
# Epoch 41/1024
# 68/68 - 0s - loss: 0.3142 - accuracy: 0.8603 - val_loss: 0.3065 - val_accuracy: 0.8644 - lr: 5.0000e-05 - 483ms/epoch - 7ms/step
# Epoch 42/1024
# 68/68 - 0s - loss: 0.3142 - accuracy: 0.8605 - val_loss: 0.3066 - val_accuracy: 0.8641 - lr: 5.0000e-05 - 483ms/epoch - 7ms/step
# Epoch 43/1024
# 68/68 - 0s - loss: 0.3138 - accuracy: 0.8607 - val_loss: 0.3061 - val_accuracy: 0.8645 - lr: 5.0000e-05 - 488ms/epoch - 7ms/step
# Epoch 44/1024
# 68/68 - 0s - loss: 0.3140 - accuracy: 0.8602 - val_loss: 0.3059 - val_accuracy: 0.8643 - lr: 5.0000e-05 - 490ms/epoch - 7ms/step
# Epoch 45/1024
# 68/68 - 1s - loss: 0.3134 - accuracy: 0.8609 - val_loss: 0.3057 - val_accuracy: 0.8644 - lr: 5.0000e-05 - 513ms/epoch - 8ms/step
# Epoch 46/1024
# 68/68 - 0s - loss: 0.3130 - accuracy: 0.8611 - val_loss: 0.3054 - val_accuracy: 0.8646 - lr: 5.0000e-05 - 500ms/epoch - 7ms/step
# Epoch 47/1024
# 68/68 - 0s - loss: 0.3131 - accuracy: 0.8606 - val_loss: 0.3053 - val_accuracy: 0.8648 - lr: 5.0000e-05 - 492ms/epoch - 7ms/step
# Epoch 48/1024
# 68/68 - 0s - loss: 0.3126 - accuracy: 0.8611 - val_loss: 0.3052 - val_accuracy: 0.8647 - lr: 5.0000e-05 - 489ms/epoch - 7ms/step
# Epoch 49/1024
# 68/68 - 1s - loss: 0.3122 - accuracy: 0.8614 - val_loss: 0.3051 - val_accuracy: 0.8648 - lr: 5.0000e-05 - 513ms/epoch - 8ms/step
# Epoch 50/1024
# 68/68 - 1s - loss: 0.3122 - accuracy: 0.8617 - val_loss: 0.3054 - val_accuracy: 0.8649 - lr: 5.0000e-05 - 540ms/epoch - 8ms/step
# Epoch 51/1024
# 68/68 - 1s - loss: 0.3121 - accuracy: 0.8608 - val_loss: 0.3048 - val_accuracy: 0.8650 - lr: 5.0000e-05 - 534ms/epoch - 8ms/step
# Epoch 52/1024
# 68/68 - 1s - loss: 0.3120 - accuracy: 0.8613 - val_loss: 0.3049 - val_accuracy: 0.8652 - lr: 5.0000e-05 - 557ms/epoch - 8ms/step
# Epoch 53/1024
# 68/68 - 1s - loss: 0.3118 - accuracy: 0.8615 - val_loss: 0.3047 - val_accuracy: 0.8651 - lr: 5.0000e-05 - 573ms/epoch - 8ms/step
# Epoch 54/1024
# 68/68 - 1s - loss: 0.3114 - accuracy: 0.8615 - val_loss: 0.3044 - val_accuracy: 0.8652 - lr: 5.0000e-05 - 506ms/epoch - 7ms/step
# Epoch 55/1024
# 68/68 - 1s - loss: 0.3115 - accuracy: 0.8614 - val_loss: 0.3043 - val_accuracy: 0.8654 - lr: 5.0000e-05 - 521ms/epoch - 8ms/step
# Epoch 56/1024
# 68/68 - 1s - loss: 0.3113 - accuracy: 0.8616 - val_loss: 0.3047 - val_accuracy: 0.8651 - lr: 5.0000e-05 - 544ms/epoch - 8ms/step
# Epoch 57/1024
# 68/68 - 1s - loss: 0.3110 - accuracy: 0.8621 - val_loss: 0.3044 - val_accuracy: 0.8651 - lr: 5.0000e-05 - 554ms/epoch - 8ms/step
# Epoch 58/1024
# 68/68 - 1s - loss: 0.3110 - accuracy: 0.8620 - val_loss: 0.3042 - val_accuracy: 0.8653 - lr: 5.0000e-05 - 511ms/epoch - 8ms/step
# Epoch 59/1024
# 68/68 - 1s - loss: 0.3105 - accuracy: 0.8621 - val_loss: 0.3041 - val_accuracy: 0.8652 - lr: 5.0000e-05 - 514ms/epoch - 8ms/step
# Epoch 60/1024
# 68/68 - 1s - loss: 0.3105 - accuracy: 0.8619 - val_loss: 0.3039 - val_accuracy: 0.8653 - lr: 5.0000e-05 - 506ms/epoch - 7ms/step
# Epoch 61/1024
# 68/68 - 1s - loss: 0.3104 - accuracy: 0.8619 - val_loss: 0.3038 - val_accuracy: 0.8654 - lr: 5.0000e-05 - 545ms/epoch - 8ms/step
# Epoch 62/1024
# 68/68 - 1s - loss: 0.3100 - accuracy: 0.8622 - val_loss: 0.3037 - val_accuracy: 0.8657 - lr: 5.0000e-05 - 513ms/epoch - 8ms/step
# Epoch 63/1024
# 68/68 - 1s - loss: 0.3101 - accuracy: 0.8624 - val_loss: 0.3037 - val_accuracy: 0.8655 - lr: 5.0000e-05 - 512ms/epoch - 8ms/step
# Epoch 64/1024
# 68/68 - 1s - loss: 0.3104 - accuracy: 0.8620 - val_loss: 0.3036 - val_accuracy: 0.8653 - lr: 5.0000e-05 - 515ms/epoch - 8ms/step
# Epoch 65/1024
# 68/68 - 1s - loss: 0.3100 - accuracy: 0.8625 - val_loss: 0.3037 - val_accuracy: 0.8651 - lr: 5.0000e-05 - 511ms/epoch - 8ms/step
# Epoch 66/1024
# 68/68 - 0s - loss: 0.3100 - accuracy: 0.8624 - val_loss: 0.3037 - val_accuracy: 0.8655 - lr: 5.0000e-05 - 491ms/epoch - 7ms/step
# Epoch 67/1024
# 68/68 - 1s - loss: 0.3095 - accuracy: 0.8625 - val_loss: 0.3035 - val_accuracy: 0.8654 - lr: 5.0000e-05 - 506ms/epoch - 7ms/step
# Epoch 68/1024
# 68/68 - 1s - loss: 0.3094 - accuracy: 0.8623 - val_loss: 0.3037 - val_accuracy: 0.8657 - lr: 5.0000e-05 - 517ms/epoch - 8ms/step
# Epoch 69/1024
# 68/68 - 1s - loss: 0.3096 - accuracy: 0.8623 - val_loss: 0.3034 - val_accuracy: 0.8656 - lr: 5.0000e-05 - 522ms/epoch - 8ms/step
# Epoch 70/1024
# 68/68 - 0s - loss: 0.3092 - accuracy: 0.8624 - val_loss: 0.3032 - val_accuracy: 0.8657 - lr: 5.0000e-05 - 494ms/epoch - 7ms/step
# Epoch 71/1024
# 68/68 - 1s - loss: 0.3092 - accuracy: 0.8624 - val_loss: 0.3032 - val_accuracy: 0.8656 - lr: 5.0000e-05 - 505ms/epoch - 7ms/step
# Epoch 72/1024
# 68/68 - 0s - loss: 0.3090 - accuracy: 0.8624 - val_loss: 0.3038 - val_accuracy: 0.8653 - lr: 5.0000e-05 - 492ms/epoch - 7ms/step
# Epoch 73/1024
# 68/68 - 0s - loss: 0.3093 - accuracy: 0.8628 - val_loss: 0.3032 - val_accuracy: 0.8654 - lr: 5.0000e-05 - 500ms/epoch - 7ms/step
# Epoch 74/1024
# 68/68 - 1s - loss: 0.3088 - accuracy: 0.8628 - val_loss: 0.3031 - val_accuracy: 0.8657 - lr: 5.0000e-05 - 533ms/epoch - 8ms/step
# Epoch 75/1024
# 68/68 - 1s - loss: 0.3088 - accuracy: 0.8627 - val_loss: 0.3032 - val_accuracy: 0.8656 - lr: 5.0000e-05 - 517ms/epoch - 8ms/step
# Epoch 76/1024
# 68/68 - 0s - loss: 0.3090 - accuracy: 0.8629 - val_loss: 0.3029 - val_accuracy: 0.8657 - lr: 5.0000e-05 - 481ms/epoch - 7ms/step
# Epoch 77/1024
# 68/68 - 0s - loss: 0.3084 - accuracy: 0.8631 - val_loss: 0.3031 - val_accuracy: 0.8655 - lr: 5.0000e-05 - 497ms/epoch - 7ms/step
# Epoch 78/1024
# 68/68 - 1s - loss: 0.3085 - accuracy: 0.8630 - val_loss: 0.3034 - val_accuracy: 0.8655 - lr: 5.0000e-05 - 510ms/epoch - 7ms/step
# Epoch 79/1024
# 68/68 - 0s - loss: 0.3084 - accuracy: 0.8627 - val_loss: 0.3027 - val_accuracy: 0.8658 - lr: 5.0000e-05 - 499ms/epoch - 7ms/step
# Epoch 80/1024
# 68/68 - 1s - loss: 0.3082 - accuracy: 0.8629 - val_loss: 0.3029 - val_accuracy: 0.8656 - lr: 5.0000e-05 - 506ms/epoch - 7ms/step
# Epoch 81/1024
# 68/68 - 1s - loss: 0.3083 - accuracy: 0.8631 - val_loss: 0.3027 - val_accuracy: 0.8659 - lr: 5.0000e-05 - 509ms/epoch - 7ms/step
# Epoch 82/1024
# 68/68 - 1s - loss: 0.3083 - accuracy: 0.8632 - val_loss: 0.3024 - val_accuracy: 0.8657 - lr: 5.0000e-05 - 508ms/epoch - 7ms/step
# Epoch 83/1024
# 68/68 - 0s - loss: 0.3078 - accuracy: 0.8631 - val_loss: 0.3028 - val_accuracy: 0.8658 - lr: 5.0000e-05 - 497ms/epoch - 7ms/step
# Epoch 84/1024
# 68/68 - 0s - loss: 0.3082 - accuracy: 0.8632 - val_loss: 0.3024 - val_accuracy: 0.8660 - lr: 5.0000e-05 - 498ms/epoch - 7ms/step
# Epoch 85/1024
# 68/68 - 1s - loss: 0.3076 - accuracy: 0.8634 - val_loss: 0.3023 - val_accuracy: 0.8661 - lr: 5.0000e-05 - 534ms/epoch - 8ms/step
# Epoch 86/1024
# 68/68 - 1s - loss: 0.3078 - accuracy: 0.8634 - val_loss: 0.3026 - val_accuracy: 0.8659 - lr: 5.0000e-05 - 514ms/epoch - 8ms/step
# Epoch 87/1024
# 68/68 - 1s - loss: 0.3076 - accuracy: 0.8633 - val_loss: 0.3025 - val_accuracy: 0.8658 - lr: 5.0000e-05 - 507ms/epoch - 7ms/step
# Epoch 88/1024
# 68/68 - 1s - loss: 0.3075 - accuracy: 0.8634 - val_loss: 0.3024 - val_accuracy: 0.8658 - lr: 5.0000e-05 - 510ms/epoch - 8ms/step
# Epoch 89/1024
# 68/68 - 1s - loss: 0.3075 - accuracy: 0.8632 - val_loss: 0.3027 - val_accuracy: 0.8659 - lr: 5.0000e-05 - 504ms/epoch - 7ms/step
# Epoch 90/1024
# 68/68 - 1s - loss: 0.3074 - accuracy: 0.8636 - val_loss: 0.3023 - val_accuracy: 0.8660 - lr: 5.0000e-05 - 507ms/epoch - 7ms/step
# Epoch 91/1024
# 68/68 - 1s - loss: 0.3072 - accuracy: 0.8636 - val_loss: 0.3020 - val_accuracy: 0.8659 - lr: 5.0000e-05 - 505ms/epoch - 7ms/step
# Epoch 92/1024
# 68/68 - 0s - loss: 0.3073 - accuracy: 0.8635 - val_loss: 0.3020 - val_accuracy: 0.8659 - lr: 5.0000e-05 - 498ms/epoch - 7ms/step
# Epoch 93/1024
# 68/68 - 0s - loss: 0.3071 - accuracy: 0.8635 - val_loss: 0.3021 - val_accuracy: 0.8660 - lr: 5.0000e-05 - 496ms/epoch - 7ms/step
# Epoch 94/1024
# 68/68 - 1s - loss: 0.3072 - accuracy: 0.8635 - val_loss: 0.3022 - val_accuracy: 0.8658 - lr: 5.0000e-05 - 507ms/epoch - 7ms/step
# Epoch 95/1024
# 68/68 - 0s - loss: 0.3071 - accuracy: 0.8635 - val_loss: 0.3019 - val_accuracy: 0.8662 - lr: 5.0000e-05 - 498ms/epoch - 7ms/step
# Epoch 96/1024
# 68/68 - 1s - loss: 0.3072 - accuracy: 0.8637 - val_loss: 0.3024 - val_accuracy: 0.8658 - lr: 5.0000e-05 - 512ms/epoch - 8ms/step
# Epoch 97/1024
# 68/68 - 1s - loss: 0.3071 - accuracy: 0.8633 - val_loss: 0.3017 - val_accuracy: 0.8661 - lr: 5.0000e-05 - 505ms/epoch - 7ms/step
# Epoch 98/1024
# 68/68 - 1s - loss: 0.3069 - accuracy: 0.8639 - val_loss: 0.3020 - val_accuracy: 0.8660 - lr: 5.0000e-05 - 505ms/epoch - 7ms/step
# Epoch 99/1024
# 68/68 - 1s - loss: 0.3070 - accuracy: 0.8640 - val_loss: 0.3018 - val_accuracy: 0.8660 - lr: 5.0000e-05 - 505ms/epoch - 7ms/step
# Epoch 100/1024
# 68/68 - 0s - loss: 0.3068 - accuracy: 0.8639 - val_loss: 0.3020 - val_accuracy: 0.8661 - lr: 5.0000e-05 - 495ms/epoch - 7ms/step
# Epoch 101/1024
# 68/68 - 0s - loss: 0.3067 - accuracy: 0.8639 - val_loss: 0.3020 - val_accuracy: 0.8661 - lr: 5.0000e-05 - 497ms/epoch - 7ms/step
# Epoch 102/1024
# 68/68 - 0s - loss: 0.3066 - accuracy: 0.8637 - val_loss: 0.3018 - val_accuracy: 0.8659 - lr: 5.0000e-05 - 497ms/epoch - 7ms/step
# Epoch 103/1024
# 68/68 - 1s - loss: 0.3065 - accuracy: 0.8639 - val_loss: 0.3018 - val_accuracy: 0.8662 - lr: 5.0000e-05 - 505ms/epoch - 7ms/step
# Epoch 104/1024
# 68/68 - 1s - loss: 0.3065 - accuracy: 0.8637 - val_loss: 0.3018 - val_accuracy: 0.8659 - lr: 5.0000e-05 - 514ms/epoch - 8ms/step
# Epoch 105/1024
# 68/68 - 1s - loss: 0.3061 - accuracy: 0.8640 - val_loss: 0.3020 - val_accuracy: 0.8658 - lr: 5.0000e-05 - 512ms/epoch - 8ms/step
# Epoch 106/1024
# 68/68 - 1s - loss: 0.3065 - accuracy: 0.8637 - val_loss: 0.3017 - val_accuracy: 0.8662 - lr: 5.0000e-05 - 506ms/epoch - 7ms/step
# Epoch 107/1024
# 68/68 - 0s - loss: 0.3061 - accuracy: 0.8641 - val_loss: 0.3017 - val_accuracy: 0.8661 - lr: 5.0000e-05 - 498ms/epoch - 7ms/step
# Epoch 108/1024
# 68/68 - 0s - loss: 0.3062 - accuracy: 0.8638 - val_loss: 0.3014 - val_accuracy: 0.8661 - lr: 5.0000e-05 - 497ms/epoch - 7ms/step
# Epoch 109/1024
# 68/68 - 0s - loss: 0.3062 - accuracy: 0.8637 - val_loss: 0.3019 - val_accuracy: 0.8659 - lr: 5.0000e-05 - 498ms/epoch - 7ms/step
# Epoch 110/1024
# 68/68 - 1s - loss: 0.3062 - accuracy: 0.8640 - val_loss: 0.3013 - val_accuracy: 0.8664 - lr: 5.0000e-05 - 500ms/epoch - 7ms/step
# Epoch 111/1024
# 68/68 - 1s - loss: 0.3060 - accuracy: 0.8643 - val_loss: 0.3015 - val_accuracy: 0.8660 - lr: 5.0000e-05 - 506ms/epoch - 7ms/step
# Epoch 112/1024
# 68/68 - 1s - loss: 0.3059 - accuracy: 0.8644 - val_loss: 0.3014 - val_accuracy: 0.8661 - lr: 5.0000e-05 - 506ms/epoch - 7ms/step
# Epoch 113/1024
# 68/68 - 1s - loss: 0.3060 - accuracy: 0.8640 - val_loss: 0.3016 - val_accuracy: 0.8662 - lr: 5.0000e-05 - 507ms/epoch - 7ms/step
# Epoch 114/1024
# 68/68 - 1s - loss: 0.3060 - accuracy: 0.8641 - val_loss: 0.3015 - val_accuracy: 0.8661 - lr: 5.0000e-05 - 510ms/epoch - 7ms/step
# Epoch 115/1024
# 68/68 - 1s - loss: 0.3060 - accuracy: 0.8640 - val_loss: 0.3015 - val_accuracy: 0.8663 - lr: 5.0000e-05 - 502ms/epoch - 7ms/step
# Epoch 116/1024
# 68/68 - 0s - loss: 0.3059 - accuracy: 0.8641 - val_loss: 0.3013 - val_accuracy: 0.8663 - lr: 5.0000e-05 - 499ms/epoch - 7ms/step
# Epoch 117/1024
# 68/68 - 1s - loss: 0.3054 - accuracy: 0.8643 - val_loss: 0.3015 - val_accuracy: 0.8660 - lr: 5.0000e-05 - 506ms/epoch - 7ms/step
# Epoch 118/1024
# 68/68 - 0s - loss: 0.3055 - accuracy: 0.8643 - val_loss: 0.3016 - val_accuracy: 0.8662 - lr: 5.0000e-05 - 497ms/epoch - 7ms/step
# Epoch 119/1024
# 68/68 - 1s - loss: 0.3056 - accuracy: 0.8645 - val_loss: 0.3016 - val_accuracy: 0.8660 - lr: 5.0000e-05 - 509ms/epoch - 7ms/step
# Epoch 120/1024
# 68/68 - 1s - loss: 0.3055 - accuracy: 0.8642 - val_loss: 0.3012 - val_accuracy: 0.8664 - lr: 5.0000e-05 - 509ms/epoch - 7ms/step
# Epoch 121/1024
# 68/68 - 1s - loss: 0.3055 - accuracy: 0.8639 - val_loss: 0.3013 - val_accuracy: 0.8663 - lr: 5.0000e-05 - 507ms/epoch - 7ms/step
# Epoch 122/1024
# 68/68 - 1s - loss: 0.3053 - accuracy: 0.8646 - val_loss: 0.3013 - val_accuracy: 0.8663 - lr: 5.0000e-05 - 500ms/epoch - 7ms/step
# Epoch 123/1024
# 68/68 - 1s - loss: 0.3053 - accuracy: 0.8647 - val_loss: 0.3011 - val_accuracy: 0.8662 - lr: 5.0000e-05 - 530ms/epoch - 8ms/step

# %%
# Make a directory
dir_name = HOME_PATH + "/5th_trial/classifier/"
name = "shell_classifier"

# If the directory exists
if os.path.exists(dir_name):
    test_files = glob.glob(dir_name + "*" + name + "*")
    if test_files:
        for file in test_files:
            os.remove(file)
        print(f"Directory {dir_name} cleaned.")
    print(f"Directory {dir_name} exists.")
else:
    os.makedirs(dir_name)
    print(f"Directory {dir_name} created.")

# save model
model.save(dir_name + name + ".keras", save_format="keras", overwrite=True)

# predict
pred_y = model.predict(test_x)
# save predicted results
np.savez_compressed(dir_name + name + "_data.npz", pred_y=pred_y, test_y=test_y)
sig_pred = np.load(dir_name + name + "_data.npz")["pred_y"].flatten()
sig_truth = np.load(dir_name + name + "_data.npz")["test_y"].flatten()
# Out:
# Directory /root/work/QE-mls/5th_trial/classifier/ cleaned.
# Directory /root/work/QE-mls/5th_trial/classifier/ exists.
# 12924/12924 [==============================] - 17s 1ms/step

# %%
fig = plt.figure(figsize=(6,6), dpi=80)
plt.subplot(2,1,1)
plt.plot(history.history['loss'], lw=3, label='Train')
plt.plot(history.history['val_loss'], lw=3, label='Validation')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.legend()
plt.subplot(2,1,2)
plt.plot(history.history['accuracy'], lw=3, label='Train')
plt.plot(history.history['val_accuracy'], lw=3, label='Validation')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend()
plt.show()

predicted = tf.squeeze(sig_pred) # ensure the dimension is correct (dim-1)
predicted = np.where(predicted >= 0.5, 1, 0)
labeled = np.where(sig_truth >= 0.5, 1, 0)
actual = np.array(sig_truth)

conf_mat = confusion_matrix(actual, predicted)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat, display_labels=["Off-shell", "On-shell"]) 
displ.plot(cmap='Blues')

# %%
pred_lead_w_m = w_lead["m"][test_indices].reset_index()
pred_sublead_w_m = w_sublead["m"][test_indices].reset_index()
truth_lead_w_m = w_lead["m"][test_indices].reset_index()
truth_sublead_w_m = w_sublead["m"][test_indices].reset_index()
pred_lead_on_mask = predicted.astype(bool)
pred_sublead_on_mask = ~predicted.astype(bool)
label_lead_on_mask = labeled.astype(bool)
label_sublead_on_mask = ~labeled.astype(bool)
pred_w_onshell = pd.concat([pred_lead_w_m[pred_lead_on_mask],pred_sublead_w_m[pred_sublead_on_mask]], axis=0).sort_index()
pred_w_offshell = pd.concat([pred_lead_w_m[pred_sublead_on_mask],pred_sublead_w_m[pred_lead_on_mask]], axis=0).sort_index()
w_onshell = pd.concat([truth_lead_w_m[label_lead_on_mask], truth_sublead_w_m[label_sublead_on_mask]], axis=0).sort_index()
w_offshell = pd.concat([truth_lead_w_m[label_sublead_on_mask], truth_sublead_w_m[label_lead_on_mask]], axis=0).sort_index()

ml_acc = np.sum(predicted*1) / len(predicted)
print(f"ML accuracy: {ml_acc:0.2f}")
print(f"ML (base) improve: {100 * (ml_acc - base_acc):.2f}%")
print(f"ML (cuts) improve: {100 * (ml_acc - cut_acc):.2f}%")


figure = plt.figure(figsize=(10, 6), dpi=120)
bin_edges = np.linspace(0, 110, 121)
plt.hist(w_onshell["m"] / GEV, bins=bin_edges, color="r", histtype="step", label=r"Labeled   $W^{on}$")
plt.hist(w_offshell["m"] / GEV, bins=bin_edges, color="b", histtype="step", label=r"Labeled   $W^{off}$")
plt.hist(pred_w_onshell["m"] / GEV, bins=bin_edges, color="tab:red", histtype="bar", alpha=0.3, label=r"Predicted $W^{on}$")
plt.hist(pred_w_offshell["m"] / GEV, bins=bin_edges, color="tab:blue", histtype="bar", alpha=0.3, label=r"Predicted $W^{off}$")
plt.title("W mass")
plt.xlabel("mass [GeV]")
plt.ylabel("count")
plt.legend(loc="best")
plt.show()
plt.close()
# Out:
# ML accuracy: 0.88
# ML (base) improve: 4.67%
# ML (cuts) improve: 6.43%

# %%
import shap
import matplotlib as mpl

mpl.rcParams.update(mpl.rcParamsDefault)

feature_names = [
    "lead_px",
    "lead_py",
    "lead_pz",
    "lead_E",
    "lead_pt",
    "lead_eta",
    "lead_phi",
    "sublead_px",
    "sublead_py",
    "sublead_pz",
    "sublead_E",
    "sublead_pt",
    "sublead_eta",
    "sublead_phi",
    "met_px",
    "met_py",
    "met_pt",
    "met_phi"
]

# Use DeepExplainer for SHAP values
explainer = shap.DeepExplainer(model, obs_kin[:1_024])
shap_values = explainer.shap_values(obs_kin[:1_024])
for i in range(shap_values.shape[-1]):
    plt.figure(figsize=(10, 6))
    shap.summary_plot(
        shap_values[:, :, i],
        obs_kin[:1_024],
        feature_names=feature_names,
        plot_type="dot",
        show=False,
    )
    plt.title(f"SHAP Summary Plot for on-off Classifications")
    plt.show()
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
