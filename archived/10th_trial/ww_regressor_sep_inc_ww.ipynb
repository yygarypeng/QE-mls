# %%
# %reset -sf

import tensorflow as tf
import tf_keras
print("Tensorflow:", tf.__version__)

# GPU(s) setups
gpus = tf.config.experimental.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(gpus[0], True)
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')
        
        # Enable memory growth for the first GPU
        tf.config.experimental.set_memory_growth(gpus[0], True)
        
        # Instead of enabling memory growth, set a memory limit
        memory_limit = 16_376 / 2 # Set the memory limit in MB
        # memory_limit = -1
        if memory_limit >= 0:
            tf.config.experimental.set_virtual_device_configuration(
                gpus[0],
                [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]
            )
            
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2025-02-16 11:20:17.194003: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-16 11:20:17.216459: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow: 2.16.1
# 1 Physical GPUs, 1 Logical GPU
# 2025-02-16 11:20:18.308252: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8188 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
import sys
import os
import glob

HOME_PATH = os.path.abspath("..")
sys.path.insert(0, HOME_PATH + "/qe")

import atlas_plot as ap

plot = ap.Plotter()

import pandas as pd
import numpy as np
import scipy as sp
import ROOT
from ROOT import TLorentzVector, TVector3
import multiprocessing
WORKERS = 16

from matplotlib import pyplot as plt

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "1"  # suppress tensorflow imformation messages

from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error


SEED = 42  # set random seed (global variable)
GEV = 1e-3

# %%
import full_data as data

# reco
lead_lep = data.Lead_lep()
sublead_lep = data.Sublead_lep()
met = data.Met()

# truth
truth_lead_lep = data.Truth_lead_lep()
truth_sublead_lep = data.Truth_sublead_lep()
Truth_dilep = data.Truth_dilep()
truth_met = data.Truth_met()

# target Ws
w_lead = data.Lead_w()
w_sublead = data.Sublead_w()
mc_weight = data.MC_weight()
# Out:
# ['/CGLMP', '/RecoLep0', '/RecoLep1', '/RecoMET', '/TruthCandLep0', '/TruthCandLep1', '/TruthCandMET', '/TruthHiggs', '/TruthLep0', '/TruthLep1', '/TruthLepN', '/TruthLepP', '/TruthNu0', '/TruthNu1', '/TruthNuN', '/TruthNuP', '/TruthW0', '/TruthW1', '/TruthWN', '/TruthWP', '/eventWeight', '/mcWeight', '/recoWeight', '/weight']

# %%
# define preselection cuts

cut_pre_pt_lead = lead_lep.pt > 22
print(len(lead_lep.energy) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = sublead_lep.pt > 15
print(len(lead_lep.energy) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.sqrt(
        np.square(lead_lep.energy + sublead_lep.energy)
        - np.square(lead_lep.px + sublead_lep.px)
        - np.square(lead_lep.py + sublead_lep.py)
        - np.square(lead_lep.pz + sublead_lep.pz)
    )
    > 10
)
print(len(lead_lep.energy) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = met.pt > 20
print(len(lead_lep.energy) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print(len(lead_lep.energy) - np.sum(PRE_CUT * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)
# Out:
# 0
# 29961
# 44269
# 89634
# 157782

# %%
# truth
truth_lead_lep_px = pd.DataFrame(truth_lead_lep.px[PRE_CUT])
truth_lead_lep_py = pd.DataFrame(truth_lead_lep.py[PRE_CUT])
truth_lead_lep_pz = pd.DataFrame(truth_lead_lep.pz[PRE_CUT])
truth_lead_lep_energy = pd.DataFrame(truth_lead_lep.energy[PRE_CUT])
truth_lead_lep_p4 = pd.concat(
	[truth_lead_lep_px, truth_lead_lep_py, truth_lead_lep_pz, truth_lead_lep_energy],
	axis=1,
).to_numpy()
truth_lead_lep_pt = pd.DataFrame(truth_lead_lep.pt[PRE_CUT])
truth_lead_lep_eta = pd.DataFrame(truth_lead_lep.eta[PRE_CUT])
truth_lead_lep_phi = pd.DataFrame(truth_lead_lep.phi[PRE_CUT])

truth_sublead_lep_px = pd.DataFrame(truth_sublead_lep.px[PRE_CUT])
truth_sublead_lep_py = pd.DataFrame(truth_sublead_lep.py[PRE_CUT])
truth_sublead_lep_pz = pd.DataFrame(truth_sublead_lep.pz[PRE_CUT])
truth_sublead_lep_energy = pd.DataFrame(truth_sublead_lep.energy[PRE_CUT])
truth_sublead_lep_p4 = pd.concat(
	[truth_sublead_lep_px, truth_sublead_lep_py, truth_sublead_lep_pz, truth_sublead_lep_energy],
	axis=1,
).to_numpy()
truth_sublead_lep_pt = pd.DataFrame(truth_sublead_lep.pt[PRE_CUT])
truth_sublead_lep_eta = pd.DataFrame(truth_sublead_lep.eta[PRE_CUT])
truth_sublead_lep_phi = pd.DataFrame(truth_sublead_lep.phi[PRE_CUT])

# reco
lead_lep_px = pd.DataFrame(lead_lep.px[PRE_CUT])
lead_lep_py = pd.DataFrame(lead_lep.py[PRE_CUT])
lead_lep_pz = pd.DataFrame(lead_lep.pz[PRE_CUT])
lead_lep_energy = pd.DataFrame(lead_lep.energy[PRE_CUT])
lead_lep_p4 = pd.concat(
	[lead_lep_px, lead_lep_py, lead_lep_pz, lead_lep_energy],
	axis=1,
).to_numpy()
lead_lep_pt = pd.DataFrame(lead_lep.pt[PRE_CUT])
lead_lep_eta = pd.DataFrame(lead_lep.eta[PRE_CUT])
lead_lep_phi = pd.DataFrame(lead_lep.phi[PRE_CUT])

sublead_lep_px = pd.DataFrame(sublead_lep.px[PRE_CUT])
sublead_lep_py = pd.DataFrame(sublead_lep.py[PRE_CUT])
sublead_lep_pz = pd.DataFrame(sublead_lep.pz[PRE_CUT])
sublead_lep_energy = pd.DataFrame(sublead_lep.energy[PRE_CUT])
sublead_lep_p4 = pd.concat(
	[sublead_lep_px, sublead_lep_py, sublead_lep_pz, sublead_lep_energy],
	axis=1,
).to_numpy()
sublead_lep_pt = pd.DataFrame(sublead_lep.pt[PRE_CUT])
sublead_lep_eta = pd.DataFrame(sublead_lep.eta[PRE_CUT])
sublead_lep_phi = pd.DataFrame(sublead_lep.phi[PRE_CUT])

met_px = pd.DataFrame(met.px[PRE_CUT])
met_py = pd.DataFrame(met.py[PRE_CUT])
met_pt = pd.DataFrame(met.pt[PRE_CUT])
met_phi = pd.DataFrame(met.phi[PRE_CUT])

# %%
## Interesting variables
# lead_lep w
w_lead_px = pd.DataFrame(w_lead.px[PRE_CUT])
w_lead_py = pd.DataFrame(w_lead.py[PRE_CUT])
w_lead_pz = pd.DataFrame(w_lead.pz[PRE_CUT])
w_lead_e = pd.DataFrame(w_lead.energy[PRE_CUT])
w_lead_pt = pd.DataFrame(w_lead.pt[PRE_CUT])
w_lead_eta = pd.DataFrame(w_lead.eta[PRE_CUT])
w_lead_phi = pd.DataFrame(w_lead.phi[PRE_CUT])
w_lead_m = pd.DataFrame(w_lead.m[PRE_CUT])

w_sublead_px = pd.DataFrame(w_sublead.px[PRE_CUT])
w_sublead_py = pd.DataFrame(w_sublead.py[PRE_CUT])
w_sublead_pz = pd.DataFrame(w_sublead.pz[PRE_CUT])
w_sublead_e = pd.DataFrame(w_sublead.energy[PRE_CUT])
w_sublead_pt = pd.DataFrame(w_sublead.pt[PRE_CUT])
w_sublead_eta = pd.DataFrame(w_sublead.eta[PRE_CUT])
w_sublead_phi = pd.DataFrame(w_sublead.phi[PRE_CUT])
w_sublead_m = pd.DataFrame(w_sublead.m[PRE_CUT])

# pure lead w (consider pt)
leadlep_lead = w_lead.pt > w_sublead.pt
lead_w_px = pd.concat([pd.DataFrame(w_lead.px)[leadlep_lead], pd.DataFrame(w_sublead.px)[~leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
lead_w_py = pd.concat([pd.DataFrame(w_lead.py)[leadlep_lead], pd.DataFrame(w_sublead.py)[~leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
lead_w_pz = pd.concat([pd.DataFrame(w_lead.pz)[leadlep_lead], pd.DataFrame(w_sublead.pz)[~leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
lead_w_e = pd.concat([pd.DataFrame(w_lead.energy)[leadlep_lead], pd.DataFrame(w_sublead.energy)[~leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
sublead_w_px = pd.concat([pd.DataFrame(w_lead.px)[~leadlep_lead], pd.DataFrame(w_sublead.px)[leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]  
sublead_w_py = pd.concat([pd.DataFrame(w_lead.py)[~leadlep_lead], pd.DataFrame(w_sublead.py)[leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
sublead_w_pz = pd.concat([pd.DataFrame(w_lead.pz)[~leadlep_lead], pd.DataFrame(w_sublead.pz)[leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
sublead_w_e = pd.concat([pd.DataFrame(w_lead.energy)[~leadlep_lead], pd.DataFrame(w_sublead.energy)[leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
lead_w_m = pd.concat([pd.DataFrame(w_lead.m)[leadlep_lead], pd.DataFrame(w_sublead.m)[~leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
sublead_w_m = pd.concat([pd.DataFrame(w_lead.m)[~leadlep_lead], pd.DataFrame(w_sublead.m)[leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]  

bin_test = leadlep_lead.astype("int").to_numpy()
plt.hist(bin_test)
plt.title(r"$W^{0}$ is on-shell: " + f"{bin_test.sum() / len(bin_test) * 100:.2f} %")
plt.gca().set_xticks([0, 1], minor=False)
plt.xlim(-0.5, 1.5)
plt.show()
plt.close()

# check them wiht histograms
bin_edges = np.linspace(0, 100, 51)
figure = plt.figure(figsize=(10, 8))
plt.hist(
    w_lead_m.values.ravel(),
    bins=bin_edges,
    color="tab:blue",
    alpha=0.5,
    label=r"$W^{\ell_0}$",
    histtype="stepfilled",
    stacked=False,
    density=False
)
plt.hist(
    lead_w_m.values.ravel(),
    bins=bin_edges,
    color="orange",
    label=r"$W^{0}$",
    histtype="step",
    linewidth=2,
    stacked=False,
    density=False
)
plt.ylim(0, 3e5)
plt.xlabel(r"Mass [GeV]", labelpad=10)
plt.ylabel("Counts")
plt.title(r"$m_{W^{0}}$", fontsize=26)
plt.legend(loc="best", prop={'size': 20})
plt.show()

bin_edges = np.linspace(0, 100, 51)
figure = plt.figure(figsize=(10, 8))
plt.hist(
    w_sublead_m.values.ravel(),
    bins=bin_edges,
    color="tab:blue",
    alpha=0.5,
    label=r"$W^{\ell_1}$",
    histtype="stepfilled",
    stacked=False,
    density=False
)
plt.hist(
    sublead_w_m.values.ravel(),
    bins=bin_edges,
    color="orange",
    label=r"$W^{1}$",
    histtype="step",
    linewidth=2,
    stacked=False,
    density=False
)
plt.ylim(0, 3e5)
plt.xlabel(r"Mass [GeV]", labelpad=10)
plt.ylabel("Counts")
plt.title(r"$m_{W^{1}}$", fontsize=26)
plt.legend(loc="best", prop={'size': 20})
plt.show()

# %%
higgs_4vect = data.Lead_w().p4 + data.Sublead_w().p4
bin_edges = np.linspace(-1000, 1000, 101)
higgs_px = pd.DataFrame(higgs_4vect[..., 0]).hist(bins=bin_edges)
higgs_py = pd.DataFrame(higgs_4vect[..., 1]).hist(bins=bin_edges)
higgs_pz = pd.DataFrame(higgs_4vect[..., 2]).hist(bins=bin_edges)
higgs_px[0][0].set_title(f"$WW^* p_x$ with $\sigma=${higgs_4vect[...,0].std():.2f}")
higgs_py[0][0].set_title(f"$WW^* p_y$ with $\sigma=${higgs_4vect[...,1].std():.2f}")
higgs_pz[0][0].set_title(f"$WW^* p_z$ with $\sigma=${higgs_4vect[...,2].std():.2f}")
# higgs_e = pd.DataFrame(higgs_4vect[..., 3]).hist()
# Out:
# Text(0.5, 1.0, '$WW^* p_z$ with $\\sigma=$268.77')

# %%
print(pd.DataFrame(w_lead.m)[leadlep_lead])
print(pd.DataFrame(w_sublead.m)[~leadlep_lead])
# Out:
#                  M
# 0        79.207671
# 1        83.107065
# 2        80.802239
# 3        33.926270
# 4        78.114473
# ...            ...
# 1008892  79.807251
# 1008893  80.296141
# 1008894  52.321170
# 1008895  80.096518
# 1008896  82.681320
#
# [637929 rows x 1 columns]
#                  M
# 9        18.748472
# 12       34.780985
# 13       80.397800
# 14       31.068298
# 17       74.872002
# ...            ...
# 1008882  39.083395
# 1008885  77.659562
# 1008887  72.571746
# 1008888  37.708678
# 1008889  28.570675
#
# [370968 rows x 1 columns]

# %%
## Observing variables

obs_kin = np.column_stack(
    (
        lead_lep_px,
        lead_lep_py,
        lead_lep_pz,
        lead_lep_energy,
        lead_lep_pt,
        lead_lep_eta,
        lead_lep_phi,
        sublead_lep_px,
        sublead_lep_py,
        sublead_lep_pz,
        sublead_lep_energy,
        sublead_lep_pt,
        sublead_lep_eta,
        sublead_lep_phi,
        met_px,
        met_py,
        met_pt,
        met_phi,
        # ---------------
        w_lead_px,
        w_lead_py,
        w_lead_pz,
        w_lead_e,
        w_lead_pt,
        w_lead_eta,
        w_lead_phi,
        w_sublead_px,
        w_sublead_py,
        w_sublead_pz,
        w_sublead_e,
        w_sublead_pt,
        w_sublead_eta,
        w_sublead_phi,
    )
)

# Kinematics of observing variables (inputs for training)
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array

ROBUST_OBS = RobustScaler()
obs_kin = ROBUST_OBS.fit_transform(obs_kin)
# print(type(obs_kin))
# Out:
# int_kin shape: (851115, 32)

# %%
# target variables on-(off-)shell Ws

lead_onshell_mask = w_lead_m > w_sublead_m
onshell_w_m = pd.concat(
		[
			w_lead_m[lead_onshell_mask].dropna(), 
			w_sublead_m[~lead_onshell_mask].dropna(),
		], ignore_index=False
    ).sort_index()
offshell_w_m = pd.concat(
		[
			w_lead_m[~lead_onshell_mask].dropna(), 
			w_sublead_m[lead_onshell_mask].dropna(),
		], ignore_index=False
	).sort_index()

# check them with histograms
bin_edges = np.linspace(0, 100, 51)
figure = plt.figure(figsize=(10, 8))
plt.hist(
	onshell_w_m.values.ravel(),
	bins=bin_edges,
	color="tab:blue",
	alpha=0.5,
	label=r"$W^{on}$",
	histtype="stepfilled",
	stacked=False,
	density=False,
)
plt.hist(
	offshell_w_m.values.ravel(),
	bins=bin_edges,
	color="tab:orange",
	alpha=0.5,
	label=r"$W^{off}$",
	histtype="stepfilled",
	stacked=False,
	density=False,
)
plt.xlabel(r"Mass [GeV]", labelpad=10)
plt.ylabel("Counts")
plt.title(r"$m_{W}$", fontsize=26)
plt.legend(loc="best", prop={'size': 20})
plt.show()
plt.close()

# %%
# Kinematics of interesting variables (target for training)
int_kin = np.concatenate(
    [
        lead_onshell_mask.astype(int),
    ],
    axis=-1,
)
print("int_kin shape:", int_kin.shape)
# int_kin = int_kin.to_numpy()  # convert to numpy array
print(type(int_kin))
# Out:
# int_kin shape: (851115, 1)
# <class 'numpy.ndarray'>

# %%
plt.hist(int_kin)
plt.title(r"$W^{\ell_0}$ is on-shell: " + f"{int_kin.sum() / len(int_kin) * 100:.2f} %")
plt.gca().set_xticks([0, 1], minor=False)
plt.xlim(-0.5, 1.5)
plt.show()
plt.close()

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.8,
    test_size=0.2,
    random_state=SEED,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=SEED
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
# test_x = np.concatenate([test_x, valid_x], axis=0)

train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]
# test_y = np.concatenate([test_y, valid_y], axis=0)

print("Total evts:", len(indices_arr))
print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# Total evts: 851115
# X (Interest)
# Training data shape: (680892, 32);
# Validing data shape: (85111, 32);
# Testing data shape: (85112, 32).
# Y (Observed)
# Training data shape: (680892, 1);
# Validing data shape: (85111, 1);
# Testing data shape: (85112, 1).

# %%
# training variables
BATCH_SIZE = 256
EPOCHS = 1024
LEARNING_RATE = 1e-5

# create datasets
train_dataset = tf.data.Dataset.from_tensor_slices((
    tf.cast(train_x, tf.float32), 
    tf.cast(train_y, tf.float32)
)).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

valid_dataset = tf.data.Dataset.from_tensor_slices((
    tf.cast(valid_x, tf.float32), 
    tf.cast(valid_y, tf.float32)
)).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
# Out:
# 2025-02-14 07:58:09.674307: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 8.00GiB (8585740288 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2025-02-14 07:58:09.674408: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1566] failed to allocate 7.20GiB (7727165952 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory

# %%
def dense_dropout_block(x, units, activation="selu", dropout_rate=0.0, l2=1e-6):
    x = tf.keras.layers.Dense(
        units=units,
        use_bias=False,
        kernel_regularizer=tf.keras.regularizers.L2(l2),
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    if dropout_rate > 0:
        x = tf.keras.layers.Dropout(rate=dropout_rate)(x)
    return x

def residual_block(x, units, activation="selu", dropout_rate=0.0, l2=0.0):
    y = dense_dropout_block(x, units, activation=activation, dropout_rate=dropout_rate, l2=l2)
    y = dense_dropout_block(y, units, activation=activation, dropout_rate=dropout_rate, l2=l2)
    if x.shape[-1] != units:
        x = tf.keras.layers.Dense(units, activation=None, use_bias=False)(x)
    z = tf.keras.layers.Add()([x, y]) 
    z = tf.keras.layers.BatchNormalization()(z) 
    z = tf.keras.layers.Activation(activation)(z)
    return z

def build_model(input_shape):
    inputs = tf.keras.layers.Input(shape=(input_shape,), dtype=tf.float32)
    x = inputs

    # Stack residual blocks
    for _ in range(2):
        x = residual_block(x, 1024, dropout_rate=0.5)
        x = residual_block(x, 128, dropout_rate=0.0, l2=1e-4)
    for _ in range(2):
        x = residual_block(x, 512, dropout_rate=0.05)
        x = residual_block(x, 64, dropout_rate=0.0)

    # Bottleneck
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dense(8, activation="selu")(x)

    outputs = tf.keras.layers.Dense(units=1, activation="sigmoid")(x)
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
model = build_model(train_x.shape[-1])
# model.summary()

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.losses.binary_crossentropy,
    metrics=["accuracy"],
)

# Early stopping and learning rate scheduler
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-3,
    patience=20,
    mode="auto",
    restore_best_weights=False,
)


def scheduler(epoch, lr):
    if epoch < 512:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-0.1 * LEARNING_RATE))


lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

# Fit the model using generators
history = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    callbacks=[stop_early, lr_scheduler],
    verbose=2,
)
# Out:
# Epoch 1/1024
# 2660/2660 - 33s - 13ms/step - accuracy: 0.8982 - loss: 0.3139 - val_accuracy: 0.9563 - val_loss: 0.1989 - learning_rate: 1.0000e-05
# Epoch 2/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9505 - loss: 0.2086 - val_accuracy: 0.9621 - val_loss: 0.1796 - learning_rate: 1.0000e-05
# Epoch 3/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9568 - loss: 0.1902 - val_accuracy: 0.9687 - val_loss: 0.1595 - learning_rate: 1.0000e-05
# Epoch 4/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9604 - loss: 0.1779 - val_accuracy: 0.9716 - val_loss: 0.1479 - learning_rate: 1.0000e-05
# Epoch 5/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9633 - loss: 0.1677 - val_accuracy: 0.9737 - val_loss: 0.1394 - learning_rate: 1.0000e-05
# Epoch 6/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9649 - loss: 0.1606 - val_accuracy: 0.9756 - val_loss: 0.1313 - learning_rate: 1.0000e-05
# Epoch 7/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9667 - loss: 0.1536 - val_accuracy: 0.9768 - val_loss: 0.1256 - learning_rate: 1.0000e-05
# Epoch 8/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9679 - loss: 0.1479 - val_accuracy: 0.9775 - val_loss: 0.1207 - learning_rate: 1.0000e-05
# Epoch 9/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9690 - loss: 0.1424 - val_accuracy: 0.9784 - val_loss: 0.1159 - learning_rate: 1.0000e-05
# Epoch 10/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9703 - loss: 0.1372 - val_accuracy: 0.9798 - val_loss: 0.1103 - learning_rate: 1.0000e-05
# Epoch 11/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9709 - loss: 0.1331 - val_accuracy: 0.9807 - val_loss: 0.1060 - learning_rate: 1.0000e-05
# Epoch 12/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9717 - loss: 0.1285 - val_accuracy: 0.9816 - val_loss: 0.1019 - learning_rate: 1.0000e-05
# Epoch 13/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9724 - loss: 0.1248 - val_accuracy: 0.9823 - val_loss: 0.0975 - learning_rate: 1.0000e-05
# Epoch 14/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9732 - loss: 0.1211 - val_accuracy: 0.9829 - val_loss: 0.0945 - learning_rate: 1.0000e-05
# Epoch 15/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9739 - loss: 0.1172 - val_accuracy: 0.9836 - val_loss: 0.0906 - learning_rate: 1.0000e-05
# Epoch 16/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9745 - loss: 0.1140 - val_accuracy: 0.9840 - val_loss: 0.0879 - learning_rate: 1.0000e-05
# Epoch 17/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9750 - loss: 0.1112 - val_accuracy: 0.9845 - val_loss: 0.0848 - learning_rate: 1.0000e-05
# Epoch 18/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9756 - loss: 0.1079 - val_accuracy: 0.9850 - val_loss: 0.0824 - learning_rate: 1.0000e-05
# Epoch 19/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9763 - loss: 0.1055 - val_accuracy: 0.9856 - val_loss: 0.0795 - learning_rate: 1.0000e-05
# Epoch 20/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9767 - loss: 0.1025 - val_accuracy: 0.9858 - val_loss: 0.0779 - learning_rate: 1.0000e-05
# Epoch 21/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9773 - loss: 0.1001 - val_accuracy: 0.9865 - val_loss: 0.0752 - learning_rate: 1.0000e-05
# Epoch 22/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9777 - loss: 0.0976 - val_accuracy: 0.9867 - val_loss: 0.0734 - learning_rate: 1.0000e-05
# Epoch 23/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9783 - loss: 0.0950 - val_accuracy: 0.9870 - val_loss: 0.0714 - learning_rate: 1.0000e-05
# Epoch 24/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9784 - loss: 0.0934 - val_accuracy: 0.9871 - val_loss: 0.0696 - learning_rate: 1.0000e-05
# Epoch 25/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9789 - loss: 0.0909 - val_accuracy: 0.9877 - val_loss: 0.0680 - learning_rate: 1.0000e-05
# Epoch 26/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9793 - loss: 0.0891 - val_accuracy: 0.9881 - val_loss: 0.0661 - learning_rate: 1.0000e-05
# Epoch 27/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9794 - loss: 0.0875 - val_accuracy: 0.9883 - val_loss: 0.0646 - learning_rate: 1.0000e-05
# Epoch 28/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9798 - loss: 0.0858 - val_accuracy: 0.9884 - val_loss: 0.0631 - learning_rate: 1.0000e-05
# Epoch 29/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9803 - loss: 0.0836 - val_accuracy: 0.9889 - val_loss: 0.0613 - learning_rate: 1.0000e-05
# Epoch 30/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9805 - loss: 0.0819 - val_accuracy: 0.9891 - val_loss: 0.0602 - learning_rate: 1.0000e-05
# Epoch 31/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9810 - loss: 0.0804 - val_accuracy: 0.9892 - val_loss: 0.0591 - learning_rate: 1.0000e-05
# Epoch 32/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9811 - loss: 0.0790 - val_accuracy: 0.9894 - val_loss: 0.0579 - learning_rate: 1.0000e-05
# Epoch 33/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9816 - loss: 0.0773 - val_accuracy: 0.9896 - val_loss: 0.0569 - learning_rate: 1.0000e-05
# Epoch 34/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9818 - loss: 0.0761 - val_accuracy: 0.9896 - val_loss: 0.0559 - learning_rate: 1.0000e-05
# Epoch 35/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9820 - loss: 0.0748 - val_accuracy: 0.9900 - val_loss: 0.0546 - learning_rate: 1.0000e-05
# Epoch 36/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9823 - loss: 0.0733 - val_accuracy: 0.9897 - val_loss: 0.0542 - learning_rate: 1.0000e-05
# Epoch 37/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9825 - loss: 0.0721 - val_accuracy: 0.9903 - val_loss: 0.0527 - learning_rate: 1.0000e-05
# Epoch 38/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9828 - loss: 0.0707 - val_accuracy: 0.9902 - val_loss: 0.0521 - learning_rate: 1.0000e-05
# Epoch 39/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9829 - loss: 0.0698 - val_accuracy: 0.9904 - val_loss: 0.0512 - learning_rate: 1.0000e-05
# Epoch 40/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9831 - loss: 0.0686 - val_accuracy: 0.9902 - val_loss: 0.0504 - learning_rate: 1.0000e-05
# Epoch 41/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9835 - loss: 0.0672 - val_accuracy: 0.9906 - val_loss: 0.0493 - learning_rate: 1.0000e-05
# Epoch 42/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9835 - loss: 0.0662 - val_accuracy: 0.9903 - val_loss: 0.0494 - learning_rate: 1.0000e-05
# Epoch 43/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9836 - loss: 0.0654 - val_accuracy: 0.9910 - val_loss: 0.0478 - learning_rate: 1.0000e-05
# Epoch 44/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9841 - loss: 0.0643 - val_accuracy: 0.9908 - val_loss: 0.0473 - learning_rate: 1.0000e-05
# Epoch 45/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9840 - loss: 0.0635 - val_accuracy: 0.9911 - val_loss: 0.0465 - learning_rate: 1.0000e-05
# Epoch 46/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9843 - loss: 0.0626 - val_accuracy: 0.9908 - val_loss: 0.0461 - learning_rate: 1.0000e-05
# Epoch 47/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9846 - loss: 0.0616 - val_accuracy: 0.9910 - val_loss: 0.0455 - learning_rate: 1.0000e-05
# Epoch 48/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9845 - loss: 0.0612 - val_accuracy: 0.9909 - val_loss: 0.0455 - learning_rate: 1.0000e-05
# Epoch 49/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9849 - loss: 0.0599 - val_accuracy: 0.9909 - val_loss: 0.0446 - learning_rate: 1.0000e-05
# Epoch 50/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9847 - loss: 0.0593 - val_accuracy: 0.9911 - val_loss: 0.0442 - learning_rate: 1.0000e-05
# Epoch 51/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9851 - loss: 0.0585 - val_accuracy: 0.9915 - val_loss: 0.0431 - learning_rate: 1.0000e-05
# Epoch 52/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9853 - loss: 0.0576 - val_accuracy: 0.9916 - val_loss: 0.0428 - learning_rate: 1.0000e-05
# Epoch 53/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9852 - loss: 0.0571 - val_accuracy: 0.9913 - val_loss: 0.0421 - learning_rate: 1.0000e-05
# Epoch 54/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9854 - loss: 0.0566 - val_accuracy: 0.9911 - val_loss: 0.0422 - learning_rate: 1.0000e-05
# Epoch 55/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9854 - loss: 0.0560 - val_accuracy: 0.9916 - val_loss: 0.0412 - learning_rate: 1.0000e-05
# Epoch 56/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9859 - loss: 0.0548 - val_accuracy: 0.9911 - val_loss: 0.0416 - learning_rate: 1.0000e-05
# Epoch 57/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9860 - loss: 0.0542 - val_accuracy: 0.9915 - val_loss: 0.0403 - learning_rate: 1.0000e-05
# Epoch 58/1024
# 2660/2660 - 9s - 3ms/step - accuracy: 0.9860 - loss: 0.0538 - val_accuracy: 0.9914 - val_loss: 0.0401 - learning_rate: 1.0000e-05
# Epoch 59/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9861 - loss: 0.0530 - val_accuracy: 0.9913 - val_loss: 0.0400 - learning_rate: 1.0000e-05
# Epoch 60/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9862 - loss: 0.0525 - val_accuracy: 0.9917 - val_loss: 0.0392 - learning_rate: 1.0000e-05
# Epoch 61/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9863 - loss: 0.0520 - val_accuracy: 0.9915 - val_loss: 0.0392 - learning_rate: 1.0000e-05
# Epoch 62/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9862 - loss: 0.0516 - val_accuracy: 0.9917 - val_loss: 0.0385 - learning_rate: 1.0000e-05
# Epoch 63/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9865 - loss: 0.0508 - val_accuracy: 0.9917 - val_loss: 0.0380 - learning_rate: 1.0000e-05
# Epoch 64/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9865 - loss: 0.0507 - val_accuracy: 0.9916 - val_loss: 0.0381 - learning_rate: 1.0000e-05
# Epoch 65/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9868 - loss: 0.0496 - val_accuracy: 0.9915 - val_loss: 0.0378 - learning_rate: 1.0000e-05
# Epoch 66/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9867 - loss: 0.0492 - val_accuracy: 0.9919 - val_loss: 0.0368 - learning_rate: 1.0000e-05
# Epoch 67/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9868 - loss: 0.0489 - val_accuracy: 0.9917 - val_loss: 0.0369 - learning_rate: 1.0000e-05
# Epoch 68/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9872 - loss: 0.0482 - val_accuracy: 0.9919 - val_loss: 0.0363 - learning_rate: 1.0000e-05
# Epoch 69/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9869 - loss: 0.0479 - val_accuracy: 0.9919 - val_loss: 0.0363 - learning_rate: 1.0000e-05
# Epoch 70/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9870 - loss: 0.0475 - val_accuracy: 0.9920 - val_loss: 0.0355 - learning_rate: 1.0000e-05
# Epoch 71/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9871 - loss: 0.0470 - val_accuracy: 0.9917 - val_loss: 0.0356 - learning_rate: 1.0000e-05
# Epoch 72/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9874 - loss: 0.0464 - val_accuracy: 0.9920 - val_loss: 0.0350 - learning_rate: 1.0000e-05
# Epoch 73/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9874 - loss: 0.0460 - val_accuracy: 0.9922 - val_loss: 0.0343 - learning_rate: 1.0000e-05
# Epoch 74/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9873 - loss: 0.0460 - val_accuracy: 0.9922 - val_loss: 0.0343 - learning_rate: 1.0000e-05
# Epoch 75/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9876 - loss: 0.0452 - val_accuracy: 0.9921 - val_loss: 0.0342 - learning_rate: 1.0000e-05
# Epoch 76/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9875 - loss: 0.0448 - val_accuracy: 0.9923 - val_loss: 0.0333 - learning_rate: 1.0000e-05
# Epoch 77/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9877 - loss: 0.0444 - val_accuracy: 0.9923 - val_loss: 0.0334 - learning_rate: 1.0000e-05
# Epoch 78/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9877 - loss: 0.0441 - val_accuracy: 0.9922 - val_loss: 0.0330 - learning_rate: 1.0000e-05
# Epoch 79/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9877 - loss: 0.0438 - val_accuracy: 0.9921 - val_loss: 0.0329 - learning_rate: 1.0000e-05
# Epoch 80/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9879 - loss: 0.0431 - val_accuracy: 0.9921 - val_loss: 0.0330 - learning_rate: 1.0000e-05
# Epoch 81/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9880 - loss: 0.0429 - val_accuracy: 0.9921 - val_loss: 0.0323 - learning_rate: 1.0000e-05
# Epoch 82/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9880 - loss: 0.0424 - val_accuracy: 0.9929 - val_loss: 0.0316 - learning_rate: 1.0000e-05
# Epoch 83/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9881 - loss: 0.0423 - val_accuracy: 0.9920 - val_loss: 0.0321 - learning_rate: 1.0000e-05
# Epoch 84/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9881 - loss: 0.0419 - val_accuracy: 0.9921 - val_loss: 0.0320 - learning_rate: 1.0000e-05
# Epoch 85/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9883 - loss: 0.0414 - val_accuracy: 0.9921 - val_loss: 0.0317 - learning_rate: 1.0000e-05
# Epoch 86/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9883 - loss: 0.0412 - val_accuracy: 0.9926 - val_loss: 0.0310 - learning_rate: 1.0000e-05
# Epoch 87/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9885 - loss: 0.0408 - val_accuracy: 0.9925 - val_loss: 0.0310 - learning_rate: 1.0000e-05
# Epoch 88/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9884 - loss: 0.0404 - val_accuracy: 0.9918 - val_loss: 0.0315 - learning_rate: 1.0000e-05
# Epoch 89/1024
# 2660/2660 - 9s - 3ms/step - accuracy: 0.9884 - loss: 0.0402 - val_accuracy: 0.9925 - val_loss: 0.0304 - learning_rate: 1.0000e-05
# Epoch 90/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9888 - loss: 0.0395 - val_accuracy: 0.9926 - val_loss: 0.0300 - learning_rate: 1.0000e-05
# Epoch 91/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9885 - loss: 0.0396 - val_accuracy: 0.9925 - val_loss: 0.0302 - learning_rate: 1.0000e-05
# Epoch 92/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9887 - loss: 0.0393 - val_accuracy: 0.9925 - val_loss: 0.0297 - learning_rate: 1.0000e-05
# Epoch 93/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9888 - loss: 0.0389 - val_accuracy: 0.9927 - val_loss: 0.0292 - learning_rate: 1.0000e-05
# Epoch 94/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9889 - loss: 0.0386 - val_accuracy: 0.9927 - val_loss: 0.0288 - learning_rate: 1.0000e-05
# Epoch 95/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9889 - loss: 0.0384 - val_accuracy: 0.9927 - val_loss: 0.0290 - learning_rate: 1.0000e-05
# Epoch 96/1024
# 2660/2660 - 9s - 4ms/step - accuracy: 0.9890 - loss: 0.0380 - val_accuracy: 0.9929 - val_loss: 0.0286 - learning_rate: 1.0000e-05
# Epoch 97/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9891 - loss: 0.0377 - val_accuracy: 0.9923 - val_loss: 0.0295 - learning_rate: 1.0000e-05
# Epoch 98/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9890 - loss: 0.0376 - val_accuracy: 0.9926 - val_loss: 0.0285 - learning_rate: 1.0000e-05
# Epoch 99/1024
# 2660/2660 - 9s - 4ms/step - accuracy: 0.9892 - loss: 0.0372 - val_accuracy: 0.9921 - val_loss: 0.0293 - learning_rate: 1.0000e-05
# Epoch 100/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9891 - loss: 0.0370 - val_accuracy: 0.9928 - val_loss: 0.0283 - learning_rate: 1.0000e-05
# Epoch 101/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9890 - loss: 0.0368 - val_accuracy: 0.9928 - val_loss: 0.0282 - learning_rate: 1.0000e-05
# Epoch 102/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9894 - loss: 0.0364 - val_accuracy: 0.9926 - val_loss: 0.0283 - learning_rate: 1.0000e-05
# Epoch 103/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9893 - loss: 0.0363 - val_accuracy: 0.9930 - val_loss: 0.0275 - learning_rate: 1.0000e-05
# Epoch 104/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9894 - loss: 0.0361 - val_accuracy: 0.9928 - val_loss: 0.0274 - learning_rate: 1.0000e-05
# Epoch 105/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9895 - loss: 0.0355 - val_accuracy: 0.9927 - val_loss: 0.0274 - learning_rate: 1.0000e-05
# Epoch 106/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9895 - loss: 0.0355 - val_accuracy: 0.9928 - val_loss: 0.0272 - learning_rate: 1.0000e-05
# Epoch 107/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9893 - loss: 0.0354 - val_accuracy: 0.9924 - val_loss: 0.0277 - learning_rate: 1.0000e-05
# Epoch 108/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9895 - loss: 0.0351 - val_accuracy: 0.9928 - val_loss: 0.0271 - learning_rate: 1.0000e-05
# Epoch 109/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9896 - loss: 0.0346 - val_accuracy: 0.9930 - val_loss: 0.0265 - learning_rate: 1.0000e-05
# Epoch 110/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9895 - loss: 0.0347 - val_accuracy: 0.9929 - val_loss: 0.0264 - learning_rate: 1.0000e-05
# Epoch 111/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9898 - loss: 0.0343 - val_accuracy: 0.9927 - val_loss: 0.0268 - learning_rate: 1.0000e-05
# Epoch 112/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9897 - loss: 0.0343 - val_accuracy: 0.9926 - val_loss: 0.0267 - learning_rate: 1.0000e-05
# Epoch 113/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9897 - loss: 0.0340 - val_accuracy: 0.9928 - val_loss: 0.0264 - learning_rate: 1.0000e-05
# Epoch 114/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9898 - loss: 0.0337 - val_accuracy: 0.9928 - val_loss: 0.0260 - learning_rate: 1.0000e-05
# Epoch 115/1024
# 2660/2660 - 12s - 5ms/step - accuracy: 0.9898 - loss: 0.0336 - val_accuracy: 0.9929 - val_loss: 0.0263 - learning_rate: 1.0000e-05
# Epoch 116/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9901 - loss: 0.0330 - val_accuracy: 0.9930 - val_loss: 0.0257 - learning_rate: 1.0000e-05
# Epoch 117/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9900 - loss: 0.0330 - val_accuracy: 0.9932 - val_loss: 0.0255 - learning_rate: 1.0000e-05
# Epoch 118/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9900 - loss: 0.0328 - val_accuracy: 0.9930 - val_loss: 0.0255 - learning_rate: 1.0000e-05
# Epoch 119/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9900 - loss: 0.0327 - val_accuracy: 0.9930 - val_loss: 0.0254 - learning_rate: 1.0000e-05
# Epoch 120/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9901 - loss: 0.0326 - val_accuracy: 0.9930 - val_loss: 0.0253 - learning_rate: 1.0000e-05
# Epoch 121/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9902 - loss: 0.0322 - val_accuracy: 0.9932 - val_loss: 0.0251 - learning_rate: 1.0000e-05
# Epoch 122/1024
# 2660/2660 - 9s - 4ms/step - accuracy: 0.9904 - loss: 0.0318 - val_accuracy: 0.9930 - val_loss: 0.0250 - learning_rate: 1.0000e-05
# Epoch 123/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9902 - loss: 0.0320 - val_accuracy: 0.9927 - val_loss: 0.0252 - learning_rate: 1.0000e-05
# Epoch 124/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9903 - loss: 0.0318 - val_accuracy: 0.9933 - val_loss: 0.0244 - learning_rate: 1.0000e-05
# Epoch 125/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9904 - loss: 0.0318 - val_accuracy: 0.9927 - val_loss: 0.0251 - learning_rate: 1.0000e-05
# Epoch 126/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9903 - loss: 0.0314 - val_accuracy: 0.9931 - val_loss: 0.0245 - learning_rate: 1.0000e-05
# Epoch 127/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9904 - loss: 0.0313 - val_accuracy: 0.9929 - val_loss: 0.0247 - learning_rate: 1.0000e-05
# Epoch 128/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9905 - loss: 0.0309 - val_accuracy: 0.9932 - val_loss: 0.0244 - learning_rate: 1.0000e-05
# Epoch 129/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9904 - loss: 0.0309 - val_accuracy: 0.9933 - val_loss: 0.0237 - learning_rate: 1.0000e-05
# Epoch 130/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9906 - loss: 0.0307 - val_accuracy: 0.9930 - val_loss: 0.0242 - learning_rate: 1.0000e-05
# Epoch 131/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9908 - loss: 0.0303 - val_accuracy: 0.9934 - val_loss: 0.0236 - learning_rate: 1.0000e-05
# Epoch 132/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9905 - loss: 0.0303 - val_accuracy: 0.9932 - val_loss: 0.0238 - learning_rate: 1.0000e-05
# Epoch 133/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9907 - loss: 0.0301 - val_accuracy: 0.9937 - val_loss: 0.0232 - learning_rate: 1.0000e-05
# Epoch 134/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9907 - loss: 0.0300 - val_accuracy: 0.9926 - val_loss: 0.0247 - learning_rate: 1.0000e-05
# Epoch 135/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9906 - loss: 0.0299 - val_accuracy: 0.9931 - val_loss: 0.0237 - learning_rate: 1.0000e-05
# Epoch 136/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9907 - loss: 0.0296 - val_accuracy: 0.9939 - val_loss: 0.0227 - learning_rate: 1.0000e-05
# Epoch 137/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9907 - loss: 0.0296 - val_accuracy: 0.9929 - val_loss: 0.0235 - learning_rate: 1.0000e-05
# Epoch 138/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9908 - loss: 0.0293 - val_accuracy: 0.9937 - val_loss: 0.0227 - learning_rate: 1.0000e-05
# Epoch 139/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9909 - loss: 0.0292 - val_accuracy: 0.9937 - val_loss: 0.0225 - learning_rate: 1.0000e-05
# Epoch 140/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9908 - loss: 0.0291 - val_accuracy: 0.9935 - val_loss: 0.0227 - learning_rate: 1.0000e-05
# Epoch 141/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9910 - loss: 0.0287 - val_accuracy: 0.9938 - val_loss: 0.0224 - learning_rate: 1.0000e-05
# Epoch 142/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9910 - loss: 0.0287 - val_accuracy: 0.9936 - val_loss: 0.0226 - learning_rate: 1.0000e-05
# Epoch 143/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9910 - loss: 0.0285 - val_accuracy: 0.9933 - val_loss: 0.0225 - learning_rate: 1.0000e-05
# Epoch 144/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9911 - loss: 0.0284 - val_accuracy: 0.9936 - val_loss: 0.0223 - learning_rate: 1.0000e-05
# Epoch 145/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9911 - loss: 0.0284 - val_accuracy: 0.9933 - val_loss: 0.0225 - learning_rate: 1.0000e-05
# Epoch 146/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9911 - loss: 0.0281 - val_accuracy: 0.9935 - val_loss: 0.0223 - learning_rate: 1.0000e-05
# Epoch 147/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9912 - loss: 0.0280 - val_accuracy: 0.9938 - val_loss: 0.0220 - learning_rate: 1.0000e-05
# Epoch 148/1024
# 2660/2660 - 12s - 5ms/step - accuracy: 0.9914 - loss: 0.0277 - val_accuracy: 0.9934 - val_loss: 0.0221 - learning_rate: 1.0000e-05
# Epoch 149/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9912 - loss: 0.0277 - val_accuracy: 0.9934 - val_loss: 0.0223 - learning_rate: 1.0000e-05
# Epoch 150/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9913 - loss: 0.0276 - val_accuracy: 0.9939 - val_loss: 0.0216 - learning_rate: 1.0000e-05
# Epoch 151/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9912 - loss: 0.0274 - val_accuracy: 0.9935 - val_loss: 0.0220 - learning_rate: 1.0000e-05
# Epoch 152/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9914 - loss: 0.0273 - val_accuracy: 0.9933 - val_loss: 0.0222 - learning_rate: 1.0000e-05
# Epoch 153/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9914 - loss: 0.0272 - val_accuracy: 0.9935 - val_loss: 0.0220 - learning_rate: 1.0000e-05
# Epoch 154/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9913 - loss: 0.0271 - val_accuracy: 0.9932 - val_loss: 0.0224 - learning_rate: 1.0000e-05
# Epoch 155/1024
# 2660/2660 - 9s - 4ms/step - accuracy: 0.9917 - loss: 0.0265 - val_accuracy: 0.9939 - val_loss: 0.0212 - learning_rate: 1.0000e-05
# Epoch 156/1024
# 2660/2660 - 7s - 3ms/step - accuracy: 0.9915 - loss: 0.0269 - val_accuracy: 0.9934 - val_loss: 0.0217 - learning_rate: 1.0000e-05
# Epoch 157/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9914 - loss: 0.0266 - val_accuracy: 0.9937 - val_loss: 0.0214 - learning_rate: 1.0000e-05
# Epoch 158/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9916 - loss: 0.0264 - val_accuracy: 0.9934 - val_loss: 0.0217 - learning_rate: 1.0000e-05
# Epoch 159/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9916 - loss: 0.0264 - val_accuracy: 0.9937 - val_loss: 0.0214 - learning_rate: 1.0000e-05
# Epoch 160/1024
# 2660/2660 - 8s - 3ms/step - accuracy: 0.9916 - loss: 0.0264 - val_accuracy: 0.9937 - val_loss: 0.0210 - learning_rate: 1.0000e-05
# Epoch 161/1024
# 2660/2660 - 9s - 3ms/step - accuracy: 0.9916 - loss: 0.0260 - val_accuracy: 0.9936 - val_loss: 0.0213 - learning_rate: 1.0000e-05
# Epoch 162/1024
# 2660/2660 - 9s - 3ms/step - accuracy: 0.9916 - loss: 0.0258 - val_accuracy: 0.9935 - val_loss: 0.0210 - learning_rate: 1.0000e-05
# Epoch 163/1024
# 2660/2660 - 9s - 4ms/step - accuracy: 0.9917 - loss: 0.0260 - val_accuracy: 0.9941 - val_loss: 0.0205 - learning_rate: 1.0000e-05
# Epoch 164/1024
# 2660/2660 - 7s - 3ms/step - accuracy: 0.9917 - loss: 0.0258 - val_accuracy: 0.9933 - val_loss: 0.0213 - learning_rate: 1.0000e-05
# Epoch 165/1024
# 2660/2660 - 6s - 2ms/step - accuracy: 0.9918 - loss: 0.0254 - val_accuracy: 0.9942 - val_loss: 0.0201 - learning_rate: 1.0000e-05
# Epoch 166/1024
# 2660/2660 - 7s - 3ms/step - accuracy: 0.9917 - loss: 0.0256 - val_accuracy: 0.9931 - val_loss: 0.0219 - learning_rate: 1.0000e-05
# Epoch 167/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9917 - loss: 0.0254 - val_accuracy: 0.9934 - val_loss: 0.0211 - learning_rate: 1.0000e-05
# Epoch 168/1024
# 2660/2660 - 9s - 4ms/step - accuracy: 0.9918 - loss: 0.0253 - val_accuracy: 0.9937 - val_loss: 0.0206 - learning_rate: 1.0000e-05
# Epoch 169/1024
# 2660/2660 - 7s - 3ms/step - accuracy: 0.9919 - loss: 0.0251 - val_accuracy: 0.9936 - val_loss: 0.0208 - learning_rate: 1.0000e-05
# Epoch 170/1024
# 2660/2660 - 6s - 2ms/step - accuracy: 0.9919 - loss: 0.0250 - val_accuracy: 0.9938 - val_loss: 0.0205 - learning_rate: 1.0000e-05
# Epoch 171/1024
# 2660/2660 - 7s - 3ms/step - accuracy: 0.9919 - loss: 0.0250 - val_accuracy: 0.9939 - val_loss: 0.0201 - learning_rate: 1.0000e-05
# Epoch 172/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9918 - loss: 0.0252 - val_accuracy: 0.9938 - val_loss: 0.0203 - learning_rate: 1.0000e-05
# Epoch 173/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9919 - loss: 0.0249 - val_accuracy: 0.9940 - val_loss: 0.0199 - learning_rate: 1.0000e-05
# Epoch 174/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9919 - loss: 0.0247 - val_accuracy: 0.9941 - val_loss: 0.0200 - learning_rate: 1.0000e-05
# Epoch 175/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9921 - loss: 0.0243 - val_accuracy: 0.9936 - val_loss: 0.0203 - learning_rate: 1.0000e-05
# Epoch 176/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9920 - loss: 0.0248 - val_accuracy: 0.9942 - val_loss: 0.0195 - learning_rate: 1.0000e-05
# Epoch 177/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9920 - loss: 0.0244 - val_accuracy: 0.9941 - val_loss: 0.0194 - learning_rate: 1.0000e-05
# Epoch 178/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9922 - loss: 0.0240 - val_accuracy: 0.9941 - val_loss: 0.0194 - learning_rate: 1.0000e-05
# Epoch 179/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9921 - loss: 0.0241 - val_accuracy: 0.9941 - val_loss: 0.0195 - learning_rate: 1.0000e-05
# Epoch 180/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9922 - loss: 0.0240 - val_accuracy: 0.9938 - val_loss: 0.0197 - learning_rate: 1.0000e-05
# Epoch 181/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9921 - loss: 0.0239 - val_accuracy: 0.9943 - val_loss: 0.0191 - learning_rate: 1.0000e-05
# Epoch 182/1024
# 2660/2660 - 9s - 3ms/step - accuracy: 0.9924 - loss: 0.0236 - val_accuracy: 0.9941 - val_loss: 0.0193 - learning_rate: 1.0000e-05
# Epoch 183/1024
# 2660/2660 - 9s - 3ms/step - accuracy: 0.9922 - loss: 0.0240 - val_accuracy: 0.9940 - val_loss: 0.0194 - learning_rate: 1.0000e-05
# Epoch 184/1024
# 2660/2660 - 9s - 3ms/step - accuracy: 0.9921 - loss: 0.0238 - val_accuracy: 0.9942 - val_loss: 0.0189 - learning_rate: 1.0000e-05
# Epoch 185/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9924 - loss: 0.0235 - val_accuracy: 0.9941 - val_loss: 0.0193 - learning_rate: 1.0000e-05
# Epoch 186/1024
# 2660/2660 - 9s - 3ms/step - accuracy: 0.9924 - loss: 0.0233 - val_accuracy: 0.9941 - val_loss: 0.0192 - learning_rate: 1.0000e-05
# Epoch 187/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9924 - loss: 0.0232 - val_accuracy: 0.9940 - val_loss: 0.0193 - learning_rate: 1.0000e-05
# Epoch 188/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9923 - loss: 0.0232 - val_accuracy: 0.9939 - val_loss: 0.0192 - learning_rate: 1.0000e-05
# Epoch 189/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9925 - loss: 0.0230 - val_accuracy: 0.9941 - val_loss: 0.0191 - learning_rate: 1.0000e-05
# Epoch 190/1024
# 2660/2660 - 9s - 3ms/step - accuracy: 0.9925 - loss: 0.0227 - val_accuracy: 0.9939 - val_loss: 0.0192 - learning_rate: 1.0000e-05
# Epoch 191/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9925 - loss: 0.0230 - val_accuracy: 0.9943 - val_loss: 0.0185 - learning_rate: 1.0000e-05
# Epoch 192/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9926 - loss: 0.0227 - val_accuracy: 0.9943 - val_loss: 0.0185 - learning_rate: 1.0000e-05
# Epoch 193/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9927 - loss: 0.0224 - val_accuracy: 0.9942 - val_loss: 0.0185 - learning_rate: 1.0000e-05
# Epoch 194/1024
# 2660/2660 - 12s - 4ms/step - accuracy: 0.9926 - loss: 0.0226 - val_accuracy: 0.9939 - val_loss: 0.0191 - learning_rate: 1.0000e-05
# Epoch 195/1024
# 2660/2660 - 11s - 4ms/step - accuracy: 0.9925 - loss: 0.0226 - val_accuracy: 0.9938 - val_loss: 0.0192 - learning_rate: 1.0000e-05
# Epoch 196/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9926 - loss: 0.0223 - val_accuracy: 0.9942 - val_loss: 0.0190 - learning_rate: 1.0000e-05
# Epoch 197/1024
# 2660/2660 - 10s - 4ms/step - accuracy: 0.9927 - loss: 0.0224 - val_accuracy: 0.9939 - val_loss: 0.0193 - learning_rate: 1.0000e-05
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1739519894.300213  313923 service.cc:145] XLA service 0x72a5f0003ff0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1739519894.300233  313923 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# 2025-02-14 07:58:14.421487: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-02-14 07:58:14.851222: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1739519897.102451  314466 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_5', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1739519897.770393  314460 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_5', 1616 bytes spill stores, 1780 bytes spill loads
#
# I0000 00:00:1739519898.308797  314478 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_8', 120 bytes spill stores, 120 bytes spill loads
#
# I0000 00:00:1739519898.359642  314468 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_6', 120 bytes spill stores, 120 bytes spill loads
#
# I0000 00:00:1739519898.481814  314471 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_12', 120 bytes spill stores, 120 bytes spill loads
#
# I0000 00:00:1739519902.786112  313923 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_9', 56 bytes spill stores, 56 bytes spill loads
#
# I0000 00:00:1739519902.797221  313923 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# I0000 00:00:1739519915.408491  315323 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_5', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1739519915.614414  315310 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_5', 12 bytes spill stores, 12 bytes spill loads
#
# I0000 00:00:1739519915.755717  315313 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_5', 36 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1739519915.911187  315309 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_3', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1739519915.953057  315301 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_11', 24 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1739519916.000341  315320 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_4', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1739519916.143757  315323 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_3', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1739519916.300166  315304 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_8', 160 bytes spill stores, 152 bytes spill loads
#
# I0000 00:00:1739519916.513207  315305 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_7', 24 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1739519916.952411  315318 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_16', 316 bytes spill stores, 316 bytes spill loads
#
# I0000 00:00:1739519917.108450  315326 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_12', 160 bytes spill stores, 152 bytes spill loads
#
# I0000 00:00:1739519921.015512  313921 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_9', 56 bytes spill stores, 56 bytes spill loads
#
# I0000 00:00:1739519922.736759  315973 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1739519922.791997  315964 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1739519922.804107  315952 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1739519922.890210  315975 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1739519923.007353  315959 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_3', 24 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1739519923.223346  315960 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 12 bytes spill stores, 12 bytes spill loads
#
# I0000 00:00:1739519923.299478  315958 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_5', 24 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1739519923.344032  315983 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 4 bytes spill stores, 4 bytes spill loads

# %%
# Make a directory
dir_name = HOME_PATH + "/10th_trial/ww_classification_result/"
savedmodel_path = dir_name + "saved_model"
name = "ww_classifier"

# If the directory exists
if os.path.exists(dir_name):
    test_files = glob.glob(dir_name + "*" + name + "*")
    if test_files:
        for file in test_files:
            os.remove(file)
        print(f"Directory {dir_name} cleaned.")
    print(f"Directory {dir_name} exists.")
else:
    os.makedirs(dir_name)
    print(f"Directory {dir_name} created.")

# save modela
model.save(dir_name + name + ".keras", save_format="keras", overwrite=True)
tf.saved_model.save(model, savedmodel_path) # save model in saved_model format --> use in the onnx 

# predict
pred_y = model.predict(test_x)
# save predicted results
np.savez_compressed(dir_name + name + "_data.npz", pred_y=pred_y, test_y=test_y)
sig_pred = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth = np.load(dir_name + name + "_data.npz")["test_y"]
# Out:
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=keras
# Directory /root/work/QE-mls/10th_trial/ww_classification_result/ cleaned.
# Directory /root/work/QE-mls/10th_trial/ww_classification_result/ exists.
# INFO:tensorflow:Assets written to: /root/work/QE-mls/10th_trial/ww_classification_result/saved_model/assets
# INFO:tensorflow:Assets written to: /root/work/QE-mls/10th_trial/ww_classification_result/saved_model/assets
# 2660/2660 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# I0000 00:00:1739522007.266499  413194 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1739522009.785858  413400 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1739522009.999940  413383 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 8 bytes spill stores, 8 bytes spill loads

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

fig = plt.figure(figsize=(6,6), dpi=80)
plt.subplot(2,1,1)
plt.plot(history.history['loss'], lw=3, label='Train')
plt.plot(history.history['val_loss'], lw=3, label='Validation')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.legend()
plt.subplot(2,1,2)
plt.plot(history.history['accuracy'], lw=3, label='Train')
plt.plot(history.history['val_accuracy'], lw=3, label='Validation')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend()
plt.show()

predicted = tf.squeeze(sig_pred) # ensure the dimension is correct (dim-1)
predicted = np.where(predicted >= 0.5, 1, 0)
labeled = np.where(sig_truth >= 0.5, 1, 0)
actual = np.array(sig_truth)

conf_mat = confusion_matrix(actual, predicted)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat, display_labels=["Off-shell", "On-shell"]) 
displ.plot(cmap='Blues')

# %%
import shap
import matplotlib as mpl

mpl.rcParams.update(mpl.rcParamsDefault)

feature_names = [
    "lead_px",
    "lead_py",
    "lead_pz",
    "lead_E",
    "lead_pt",
    "lead_eta",
    "lead_phi",
    "sublead_px",
    "sublead_py",
    "sublead_pz",
    "sublead_E",
    "sublead_pt",
    "sublead_eta",
    "sublead_phi",
    "met_px",
    "met_py",
    "met_pt",
    "met_phi",
    # ---------------
    "w_lead_px",
    "w_lead_py",
    "w_lead_pz",
    "w_lead_E",
    "w_lead_pt",
    "w_lead_eta",
    "w_lead_phi",
    "w_sublead_px",
    "w_sublead_py",
    "w_sublead_pz",
    "w_sublead_E",
    "w_sublead_pt",
    "w_sublead_eta",
    "w_sublead_phi",
]

# Use DeepExplainer for SHAP values
explainer = shap.DeepExplainer(model, obs_kin[:2_048])
shap_values = explainer.shap_values(obs_kin[:2_048])
for i in range(shap_values.shape[-1]):
    plt.figure(figsize=(7, 6), dpi=180)
    shap.summary_plot(
        shap_values[:, :, i],
        obs_kin[:2_048],
        feature_names=feature_names,
        plot_type="dot",
        show=False,
    )
    plt.title(f"SHAP summary for on-off shell classifications")
    plt.show()
# Out:
# /root/miniconda3/envs/tf/lib/python3.11/site-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# /root/miniconda3/envs/tf/lib/python3.11/site-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(2048, 32))']
#   warnings.warn(msg)
# /root/miniconda3/envs/tf/lib/python3.11/site-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(4096, 32))']
#   warnings.warn(msg)
