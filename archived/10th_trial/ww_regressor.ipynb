# %%
# %reset -sf

import tensorflow as tf
import tf_keras
print("Tensorflow:", tf.__version__)
import tensorflow_probability as tfp
print("Tensorflow Probability:", tfp.__version__)

# GPU(s) setups
gpus = tf.config.experimental.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(gpus[0], True)
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')
        
        # Enable memory growth for the first GPU
        tf.config.experimental.set_memory_growth(gpus[0], True)
        
        # Instead of enabling memory growth, set a memory limit
        memory_limit = 16_376 / 3 # Set the memory limit in MB
        # memory_limit = -1
        if memory_limit >= 0:
            tf.config.experimental.set_virtual_device_configuration(
                gpus[0],
                [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]
            )
            
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2025-02-28 13:49:05.694860: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-28 13:49:05.717975: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow: 2.16.1
# Tensorflow Probability: 0.24.0
# 1 Physical GPUs, 1 Logical GPU
# 2025-02-28 13:49:07.212527: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
import sys
import os
import glob

HOME_PATH = os.path.abspath("..")
sys.path.insert(0, HOME_PATH + "/qe")

import paper_plot as pp

plot = pp.Plotter()

import pandas as pd
import numpy as np
import scipy as sp
import ROOT
from ROOT import TLorentzVector, TVector3
import multiprocessing
WORKERS = 16

from matplotlib import pyplot as plt

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "1"  # suppress tensorflow imformation messages

from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

SEED = 42  # set random seed (global variable)
GEV = 1e-3

# %%
import full_data as data

# reco
lead_lep = data.Lead_lep()
sublead_lep = data.Sublead_lep()
met = data.Met()

# truth
truth_lead_lep = data.Truth_lead_lep()
truth_sublead_lep = data.Truth_sublead_lep()
Truth_dilep = data.Truth_dilep()
truth_met = data.Truth_met()

# target Ws
w_lead = data.Lead_w()
w_sublead = data.Sublead_w()
mc_weight = data.MC_weight()
# Out:
# ['/CGLMP', '/RecoLep0', '/RecoLep1', '/RecoMET', '/TruthCandLep0', '/TruthCandLep1', '/TruthCandMET', '/TruthHiggs', '/TruthLep0', '/TruthLep1', '/TruthLepN', '/TruthLepP', '/TruthNu0', '/TruthNu1', '/TruthNuN', '/TruthNuP', '/TruthW0', '/TruthW1', '/TruthWN', '/TruthWP', '/eventWeight', '/mcWeight', '/recoWeight', '/weight']

# %%
# define preselection cuts

cut_pre_pt_lead = lead_lep.pt > 22 # 22 ~ 40 (SY)
print(len(lead_lep.energy) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = sublead_lep.pt > 15
print(len(lead_lep.energy) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.sqrt(
        np.square(lead_lep.energy + sublead_lep.energy)
        - np.square(lead_lep.px + sublead_lep.px)
        - np.square(lead_lep.py + sublead_lep.py)
        - np.square(lead_lep.pz + sublead_lep.pz)
    )
    > 10
)
print(len(lead_lep.energy) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = met.pt > 20
print(len(lead_lep.energy) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print(len(lead_lep.energy) - np.sum(PRE_CUT * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# # define preselection cuts

# cut_pre_pt_lead = lead_lep.pt > -9999
# print(len(lead_lep.energy) - np.sum(cut_pre_pt_lead * 1))
# cut_pre_pt_sub = sublead_lep.pt > -9999
# print(len(lead_lep.energy) - np.sum(cut_pre_pt_sub * 1))
# cut_pre_dilep_m = (
#     np.sqrt(
#         np.square(lead_lep.energy + sublead_lep.energy)
#         - np.square(lead_lep.px + sublead_lep.px)
#         - np.square(lead_lep.py + sublead_lep.py)
#         - np.square(lead_lep.pz + sublead_lep.pz)
#     )
#     > -9999
# )
# print(len(lead_lep.energy) - np.sum(cut_pre_dilep_m * 1))
# cut_pre_pt_miss = met.pt > -9999
# print(len(lead_lep.energy) - np.sum(cut_pre_pt_miss * 1))
# PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
# print(len(lead_lep.energy) - np.sum(PRE_CUT * 1))
# del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)
# Out:
# 0
# 29961
# 44269
# 89634
# 157782

# %%
# truth
truth_lead_lep_px = pd.DataFrame(truth_lead_lep.px[PRE_CUT])
truth_lead_lep_py = pd.DataFrame(truth_lead_lep.py[PRE_CUT])
truth_lead_lep_pz = pd.DataFrame(truth_lead_lep.pz[PRE_CUT])
truth_lead_lep_energy = pd.DataFrame(truth_lead_lep.energy[PRE_CUT])
truth_lead_lep_p4 = pd.concat(
	[truth_lead_lep_px, truth_lead_lep_py, truth_lead_lep_pz, truth_lead_lep_energy],
	axis=1,
).to_numpy()
truth_sublead_lep_px = pd.DataFrame(truth_sublead_lep.px[PRE_CUT])
truth_sublead_lep_py = pd.DataFrame(truth_sublead_lep.py[PRE_CUT])
truth_sublead_lep_pz = pd.DataFrame(truth_sublead_lep.pz[PRE_CUT])
truth_sublead_lep_energy = pd.DataFrame(truth_sublead_lep.energy[PRE_CUT])
truth_sublead_lep_p4 = pd.concat(
	[truth_sublead_lep_px, truth_sublead_lep_py, truth_sublead_lep_pz, truth_sublead_lep_energy],
	axis=1,
).to_numpy()
# reco
lead_lep_px = pd.DataFrame(lead_lep.px[PRE_CUT])
lead_lep_py = pd.DataFrame(lead_lep.py[PRE_CUT])
lead_lep_pz = pd.DataFrame(lead_lep.pz[PRE_CUT])
lead_lep_energy = pd.DataFrame(lead_lep.energy[PRE_CUT])
lead_lep_p4 = pd.concat(
	[lead_lep_px, lead_lep_py, lead_lep_pz, lead_lep_energy],
	axis=1,
).to_numpy()
sublead_lep_px = pd.DataFrame(sublead_lep.px[PRE_CUT])
sublead_lep_py = pd.DataFrame(sublead_lep.py[PRE_CUT])
sublead_lep_pz = pd.DataFrame(sublead_lep.pz[PRE_CUT])
sublead_lep_energy = pd.DataFrame(sublead_lep.energy[PRE_CUT])
sublead_lep_p4 = pd.concat(
	[sublead_lep_px, sublead_lep_py, sublead_lep_pz, sublead_lep_energy],
	axis=1,
).to_numpy()

# %%
## Observing variables

obs_kin = np.column_stack(
    (
        lead_lep.px,
        lead_lep.py,
        lead_lep.pz,
        lead_lep.energy,
        sublead_lep.px,
        sublead_lep.py,
        sublead_lep.pz,
        sublead_lep.energy,
        # np.log(sublead_lep.energy),
        # np.log(lead_lep.energy),
        # lead_lep.eta,
        # sublead_lep.eta,
        met.px,
        met.py,
    )
)[PRE_CUT]

# weights
mc_weight = mc_weight.w.to_numpy()[PRE_CUT]

# Kinematics of observing variables (inputs for training)
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array

# ROBUST_OBS = RobustScaler()
# obs_kin = ROBUST_OBS.fit_transform(obs_kin)
# print(type(obs_kin))
# Out:
# int_kin shape: (851115, 10)

# %%
## Interesting variables

w_lead_px = pd.DataFrame(w_lead.px[PRE_CUT])
w_lead_py = pd.DataFrame(w_lead.py[PRE_CUT])
w_lead_pz = pd.DataFrame(w_lead.pz[PRE_CUT])
w_lead_e = pd.DataFrame(w_lead.energy[PRE_CUT])
w_lead_log_e = pd.DataFrame(np.log(w_lead_e))
w_lead_sqrt_e = pd.DataFrame(np.sqrt(w_lead_e))
w_sublead_px = pd.DataFrame(w_sublead.px[PRE_CUT])
w_sublead_py = pd.DataFrame(w_sublead.py[PRE_CUT])
w_sublead_pz = pd.DataFrame(w_sublead.pz[PRE_CUT])
w_sublead_e = pd.DataFrame(w_sublead.energy[PRE_CUT])
w_sublead_log_e = pd.DataFrame(np.log(w_sublead_e))
w_sublead_sqrt_e = pd.DataFrame(np.sqrt(w_sublead_e))
w_lead_m = pd.DataFrame(w_lead.m[PRE_CUT])
w_sublead_m = pd.DataFrame(w_sublead.m[PRE_CUT])

# Kinematics of interesting variables (target for training)
int_kin = np.concatenate(
    [
        w_lead_px,
        w_lead_py,
        w_lead_pz,
        w_lead_e,
        w_sublead_px,
        w_sublead_py,
        w_sublead_pz,
        w_sublead_e,
        # np.square(w_lead_m) / np.mean(w_lead_m),
        # np.square(w_sublead_m) / np.mean(w_lead_m),
        # w_lead_m,
        # w_sublead_m,
    ],
    axis=-1,
)
print("int_kin shape:", int_kin.shape)
# int_kin = int_kin.to_numpy()  # convert to numpy array
print(type(int_kin))
# Out:
# int_kin shape: (851115, 8)
# <class 'numpy.ndarray'>

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.8,
    test_size=0.2,
    random_state=SEED,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=SEED
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
# test_x = np.concatenate([test_x, valid_x], axis=0)

train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]
# test_y = np.concatenate([test_y, valid_y], axis=0)

print("Total evts:", len(indices_arr))
print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# Total evts: 851115
# X (Interest)
# Training data shape: (680892, 10);
# Validing data shape: (85111, 10);
# Testing data shape: (85112, 10).
# Y (Observed)
# Training data shape: (680892, 8);
# Validing data shape: (85111, 8);
# Testing data shape: (85112, 8).

# %%
# training variables
BATCH_SIZE = 512
EPOCHS = 1024
LEARNING_RATE = 1e-5

# create datasets
train_dataset = tf.data.Dataset.from_tensor_slices((
    tf.cast(train_x, tf.float32), 
    tf.cast(train_y, tf.float32)
)).cache().batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

valid_dataset = tf.data.Dataset.from_tensor_slices((
    tf.cast(valid_x, tf.float32), 
    tf.cast(valid_y, tf.float32)
)).cache().batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# losses

def nu_mass_loss_fn(x_batch, y_pred):
    _epsilon = 1e-10
    x_batch = tf.cast(x_batch, tf.float32) #leps info
    y_pred = tf.cast(y_pred, tf.float32)   # Ws info
    
    n0_4vect = y_pred[..., :4] - x_batch[..., :4]
    n1_4vect = y_pred[..., 4:8] - x_batch[..., 4:8]

    nu0_mass = tf.sqrt(
            tf.math.maximum(
                tf.abs( tf.square(n0_4vect[..., 3]) - 
                        tf.reduce_sum(tf.square(n0_4vect[..., :3]), axis=-1)), _epsilon
            )
        )
    nu1_mass = tf.sqrt(
            tf.math.maximum(
                tf.abs( tf.square(n1_4vect[..., 3]) - 
                        tf.reduce_sum(tf.square(n1_4vect[..., :3]), axis=-1)), _epsilon
            )
        )
    
    return tf.reduce_mean(nu0_mass + nu1_mass)

def dinu_pt_loss_fn(x_batch, y_pred):
    _epsilon = 1e-10
    x_batch = tf.cast(x_batch, tf.float32) #leps info
    y_pred = tf.cast(y_pred, tf.float32)   # Ws info
    
    n0_4vect = y_pred[..., :4] - x_batch[..., :4]
    n1_4vect = y_pred[..., 4:8] - x_batch[..., 4:8]
    
    nn_4vect = n0_4vect + n1_4vect
    nn_px = nn_4vect[..., 0]
    nn_py = nn_4vect[..., 1]
    
    nn_px_diff = tf.math.maximum(tf.abs(nn_px - x_batch[..., 8]), _epsilon)
    nn_py_diff = tf.math.maximum(tf.abs(nn_py - x_batch[..., 9]), _epsilon)
    
    return tf.reduce_mean(nn_px_diff + nn_py_diff)

def higgs_mass_loss_fn(y_pred):
    _epsilon = 1e-10
    y_pred = tf.cast(y_pred, tf.float32)
    
    w0_4Vect = y_pred[..., :4]
    w1_4Vect = y_pred[..., 4:8]
    higgs_4Vect = w0_4Vect + w1_4Vect
    
    higgs_mass = tf.sqrt(
        tf.math.maximum(
            tf.abs( tf.square(higgs_4Vect[..., 3]) - 
                    tf.reduce_sum(tf.square(higgs_4Vect[..., :3]), axis=-1)), _epsilon
        )
    )
    
    return tf.reduce_mean(tf.abs(higgs_mass - 125.0)) + _epsilon


def mae_loss_fn(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return tf.reduce_mean(tf.keras.losses.mae(y_true, y_pred))

# %%
class CustomModel(tf.keras.Model):
    def __init__(self, base_model):
        super().__init__()
        self.base_model = base_model
        self.current_epoch = tf.Variable(0.0, trainable=False)
        
        # Initialize metrics dictionary
        self.metric_dict = {
            'mae_loss': tf.keras.metrics.Mean(name='mae_loss'),
            'nu_mass_loss': tf.keras.metrics.Mean(name='nu_mass_loss'),
            'higgs_mass_loss': tf.keras.metrics.Mean(name='higgs_mass_loss'),
            'dinu_pt_loss': tf.keras.metrics.Mean(name='dinu_pt_loss'),
            'fused_output_loss': tf.keras.metrics.Mean(name='fused_output_loss'),
            'loss': tf.keras.metrics.Mean(name='loss'), # total loss
        }

    def call(self, inputs, training=None):
        return self.base_model(inputs, training=training)
    
    def compile(self, optimizer, loss_weights=None, **kwargs):
        super().compile(optimizer=optimizer, **kwargs)
        default_weights = {
            'mae': 1.0,
            'nu_mass': 1.0,
            'higgs_mass': 1.0,
            'dinu_pt': 1.0,
            'fused_output': 1.0
        }
        self.loss_weights = {**default_weights, **(loss_weights or {})}

    @property
    def metrics(self):
        return list(self.metric_dict.values())

    def _compute_losses(self, x, y, predictions):
        # predictions is a list: [outputs, outputs1, outputs2]
        fused_output, nu_mass_output, mae_output = predictions
        
        losses = {
            'mae': mae_loss_fn(y, mae_output),
            'nu_mass': nu_mass_loss_fn(x, nu_mass_output),
            'higgs_mass': higgs_mass_loss_fn(fused_output),
            'dinu_pt': dinu_pt_loss_fn(x, fused_output),
            'fused_output': mae_loss_fn(y, fused_output)
        }
        
        # Compute weighted sum of losses with safe handling
        total_loss = tf.add_n([
            self.loss_weights[name] * loss for name, loss in losses.items()
        ])
        
        return total_loss, losses

    def _update_metrics(self, total_loss, losses):
        """Helper method to update metrics"""
        loss_tracker = self.metric_dict['loss']
        loss_tracker.update_state(total_loss)
        
        for name, loss in losses.items():
            self.metric_dict[f'{name}_loss'].update_state(loss)

    def train_step(self, data):
        x, y = data
        with tf.GradientTape() as tape:
            predictions = self(x, training=True)
            total_loss, losses = self._compute_losses(x, y, predictions)

        gradients = tape.gradient(total_loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        
        self._update_metrics(total_loss, losses)
        
        return {name: metric.result() for name, metric in self.metric_dict.items()}

    def test_step(self, data):
        x, y = data
        predictions = self(x, training=False)
        total_loss, losses = self._compute_losses(x, y, predictions)
        
        self._update_metrics(total_loss, losses)
        
        return {name: metric.result() for name, metric in self.metric_dict.items()}

# %%
# Define the WBosonFourVectorLayer (as provided earlier)
class WBosonFourVectorLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(WBosonFourVectorLayer, self).__init__(**kwargs)

    def call(self, inputs):
        lep0, lep1, nu_3mom = inputs
        nu0_3mom = nu_3mom[..., :3]  # [px, py, pz] for nu0
        nu1_3mom = nu_3mom[..., 3:]  # [px, py, pz] for nu1
        nu0_p_squared = tf.reduce_sum(tf.square(nu0_3mom), axis=-1, keepdims=True)
        nu1_p_squared = tf.reduce_sum(tf.square(nu1_3mom), axis=-1, keepdims=True)
        nu0_energy = tf.sqrt(tf.maximum(nu0_p_squared, 1e-10))
        nu1_energy = tf.sqrt(tf.maximum(nu1_p_squared, 1e-10))
        nu0_4vect = tf.concat([nu0_3mom, nu0_energy], axis=-1)
        nu1_4vect = tf.concat([nu1_3mom, nu1_energy], axis=-1)
        w0_4vect = lep0 + nu0_4vect
        w1_4vect = lep1 + nu1_4vect
        return tf.concat([w0_4vect, w1_4vect], axis=-1)

    def compute_output_shape(self, input_shape):
        return (input_shape[0][0], 8)

# %%
def dense_dropout_block(x, units, activation="swish", dropout_rate=0.0, l2=0.0):
    x = tf.keras.layers.Dense(
        units=units,
        use_bias=True,
        kernel_initializer='he_normal',
        kernel_regularizer=tf.keras.regularizers.L2(l2),
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    if dropout_rate > 0:    
        x = tf.keras.layers.Dropout(rate=dropout_rate)(x)
    return x

def residual_block(x, units, activation="swish", dropout_rate=0.0, l2=1e-6):
    y = dense_dropout_block(x, units, activation=activation, dropout_rate=dropout_rate, l2=l2)
    y = dense_dropout_block(y, units, activation=activation, dropout_rate=dropout_rate, l2=l2)
    if x.shape[-1] != units:
        x = tf.keras.layers.Dense(units, activation=None, use_bias=False)(x)
    z = tf.keras.layers.Add()([x, y]) 
    z = tf.keras.layers.BatchNormalization()(z) 
    z = tf.keras.layers.Activation(activation)(z)
    return z


# Updated build_model
def build_model(input_shape):
    inputs = tf.keras.layers.Input(shape=(input_shape,), dtype=tf.float32)
    x, y = inputs, inputs
    
    # Extract lepton 4-vectors for Subnet 1
    lep0 = inputs[..., :4]  # [px, py, pz, e] for leading lepton
    lep1 = inputs[..., 4:8]  # [px, py, pz, e] for subleading lepton
    
    # Subnet 1 --> Predict neutrino 3-momenta and apply physics layer
    x = dense_dropout_block(x, 64, activation="swish", dropout_rate=0.1, l2=1e-6)  # Added depth
    x = dense_dropout_block(x, 32, activation="swish", dropout_rate=0.1, l2=1e-6)
    nu_3mom = tf.keras.layers.Dense(units=6, activation="linear", kernel_initializer='he_normal', name='nu_3mom')(x)  # [nu0_px, nu0_py, nu0_pz, nu1_px, nu1_py, nu1_pz]
    outputs1 = WBosonFourVectorLayer()([lep0, lep1, nu_3mom])  # Outputs W boson 4-vectors
    
    # Subnet 2 --> First MAE (unchanged)
    for _ in range(2):
        y = residual_block(y, 128, dropout_rate=0.2, l2=1e-6)
        y = residual_block(y, 32, dropout_rate=0.2, l2=1e-6)
    for _ in range(1):
        y = residual_block(y, 256, dropout_rate=0.2, l2=1e-6)
    for _ in range(2):
        y = residual_block(y, 64, dropout_rate=0.2, l2=1e-6)
        y = residual_block(y, 32, dropout_rate=0.2, l2=1e-6)
    # Bottleneck
    y = tf.keras.layers.Dense(16, activation=None, kernel_initializer='he_normal')(y)
    y = tf.keras.layers.BatchNormalization()(y)
    y = tf.keras.layers.Activation("swish")(y)
    outputs2 = tf.keras.layers.Dense(units=8, activation="linear", kernel_initializer='he_normal')(y)
    
    # Fusion network (unchanged)
    z = tf.keras.layers.Concatenate()([outputs1, outputs2]) # add weight sum here!
    z = tf.keras.layers.Dense(64, activation=None, kernel_initializer='he_normal')(z)
    z = tf.keras.layers.BatchNormalization()(z)
    z = tf.keras.layers.Activation("swish")(z)
    z = tf.keras.layers.Dense(16, activation=None, kernel_initializer='he_normal')(z)
    z = tf.keras.layers.BatchNormalization()(z)
    z = tf.keras.layers.Activation("swish")(z)
    outputs = tf.keras.layers.Dense(units=8, activation="linear", kernel_initializer='he_normal')(z)
    
    return tf.keras.Model(inputs=inputs, outputs=[outputs, outputs1, outputs2])

# %%
def build_model(input_shape):
    inputs = tf.keras.layers.Input(shape=(input_shape,), dtype=tf.float32)
    x, y = inputs, inputs
    
    # Extract lepton 4-vectors for Subnet 1
    lep0 = inputs[..., :4]  # [px, py, pz, e] for leading lepton
    lep1 = inputs[..., 4:8]  # [px, py, pz, e] for subleading lepton
    
    # Subnet 1 --> Predict neutrino 3-momenta and apply physics layer
    x = dense_dropout_block(x, 64, activation="swish", dropout_rate=0.1, l2=1e-6)
    x = dense_dropout_block(x, 32, activation="swish", dropout_rate=0.1, l2=1e-6)
    nu_3mom = tf.keras.layers.Dense(units=6, activation="linear", kernel_initializer='he_normal', name='nu_3mom')(x)
    outputs1 = WBosonFourVectorLayer()([lep0, lep1, nu_3mom])
    
    # Subnet 2 --> First MAE (unchanged)
    for _ in range(2):
        y = residual_block(y, 128, dropout_rate=0.2, l2=1e-6)
        y = residual_block(y, 32, dropout_rate=0.2, l2=1e-6)
    for _ in range(1):
        y = residual_block(y, 256, dropout_rate=0.2, l2=1e-6)
    for _ in range(2):
        y = residual_block(y, 64, dropout_rate=0.2, l2=1e-6)
        y = residual_block(y, 32, dropout_rate=0.2, l2=1e-6)
    # Bottleneck
    y = tf.keras.layers.Dense(16, activation=None, kernel_initializer='he_normal')(y)
    y = tf.keras.layers.BatchNormalization()(y)
    y = tf.keras.layers.Activation("swish")(y)
    outputs2 = tf.keras.layers.Dense(units=8, activation="linear", kernel_initializer='he_normal')(y)
    
    # Fusion network with weighted sum 
    # Use a trainable weighted sum with a dense layer
    # Stack outputs along a new axis to apply weights across both outputs
    stacked_outputs = tf.stack([outputs1, outputs2], axis=1)  # Shape: (batch, 2, 8)
    
    # Learn weights for the combination
    weights = tf.keras.layers.Dense(1, activation="softmax", use_bias=False, kernel_initializer='he_normal')(
        tf.ones_like(stacked_outputs[:, :, 0:1])  # Shape: (batch, 2, 1)
    )  # Output shape: (batch, 2, 1), weights sum to 1
    
    # Apply weights and sum
    z = tf.reduce_sum(stacked_outputs * weights, axis=1)  # Shape: (batch, 8)
    
    # Continue with the rest of the fusion network
    z = tf.keras.layers.Dense(64, activation=None, kernel_initializer='he_normal')(z)
    z = tf.keras.layers.BatchNormalization()(z)
    z = tf.keras.layers.Activation("swish")(z)
    z = tf.keras.layers.Dense(16, activation=None, kernel_initializer='he_normal')(z)
    z = tf.keras.layers.BatchNormalization()(z)
    z = tf.keras.layers.Activation("swish")(z)
    outputs = tf.keras.layers.Dense(units=8, activation="linear", kernel_initializer='he_normal')(z)
    
    return tf.keras.Model(inputs=inputs, outputs=[outputs, outputs1, outputs2])
# Out:
# Model: "custom_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional (Functional)         │ ((None, 8), (None, 8), │       216,598 │
# │                                 │ (None, 8))             │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 216,598 (846.09 KB)
#  Trainable params: 211,606 (826.59 KB)
#  Non-trainable params: 4,992 (19.50 KB)
# Epoch 1/1024
# Epoch 0; Mass loss: 0.0033
# 1330/1330 - 53s - 40ms/step - dinu_pt_loss: 64.5224 - fused_output_loss: 67.8091 - higgs_mass_loss: 123.5329 - loss: 135.6493 - mae_loss: 67.8403 - nu_mass_loss: 0.0033 - val_dinu_pt_loss: 64.0425 - val_fused_output_loss: 67.4475 - val_higgs_mass_loss: 123.5535 - val_loss: 134.9852 - val_mae_loss: 67.5377 - val_nu_mass_loss: 0.0031
# Epoch 2/1024
# Epoch 1; Mass loss: 0.0035
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 64.2184 - fused_output_loss: 67.6746 - higgs_mass_loss: 123.4504 - loss: 135.4794 - mae_loss: 67.8047 - nu_mass_loss: 0.0035 - val_dinu_pt_loss: 63.7694 - val_fused_output_loss: 67.3195 - val_higgs_mass_loss: 123.3531 - val_loss: 134.8494 - val_mae_loss: 67.5300 - val_nu_mass_loss: 0.0033
# Epoch 3/1024
# Epoch 2; Mass loss: 0.0036
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 63.9571 - fused_output_loss: 67.5553 - higgs_mass_loss: 123.1806 - loss: 135.3114 - mae_loss: 67.7562 - nu_mass_loss: 0.0036 - val_dinu_pt_loss: 63.5215 - val_fused_output_loss: 67.2098 - val_higgs_mass_loss: 123.0307 - val_loss: 134.7256 - val_mae_loss: 67.5158 - val_nu_mass_loss: 0.0035
# Epoch 4/1024
# Epoch 3; Mass loss: 0.0038
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 63.6972 - fused_output_loss: 67.4494 - higgs_mass_loss: 122.8342 - loss: 135.1374 - mae_loss: 67.6879 - nu_mass_loss: 0.0038 - val_dinu_pt_loss: 63.2597 - val_fused_output_loss: 67.1103 - val_higgs_mass_loss: 122.6928 - val_loss: 134.5811 - val_mae_loss: 67.4708 - val_nu_mass_loss: 0.0037
# Epoch 5/1024
# Epoch 4; Mass loss: 0.0040
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 63.4299 - fused_output_loss: 67.3506 - higgs_mass_loss: 122.4851 - loss: 134.9071 - mae_loss: 67.5565 - nu_mass_loss: 0.0040 - val_dinu_pt_loss: 63.0072 - val_fused_output_loss: 67.0153 - val_higgs_mass_loss: 122.3476 - val_loss: 134.2848 - val_mae_loss: 67.2695 - val_nu_mass_loss: 0.0039
# Epoch 6/1024
# Epoch 5; Mass loss: 0.0042
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 63.1792 - fused_output_loss: 67.2569 - higgs_mass_loss: 122.1357 - loss: 134.6331 - mae_loss: 67.3762 - nu_mass_loss: 0.0042 - val_dinu_pt_loss: 62.7678 - val_fused_output_loss: 66.9228 - val_higgs_mass_loss: 121.9943 - val_loss: 133.9823 - val_mae_loss: 67.0594 - val_nu_mass_loss: 0.0041
# Epoch 7/1024
# Epoch 6; Mass loss: 0.0044
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 62.9430 - fused_output_loss: 67.1663 - higgs_mass_loss: 121.7870 - loss: 134.4166 - mae_loss: 67.2503 - nu_mass_loss: 0.0044 - val_dinu_pt_loss: 62.5410 - val_fused_output_loss: 66.8339 - val_higgs_mass_loss: 121.6505 - val_loss: 133.7751 - val_mae_loss: 66.9412 - val_nu_mass_loss: 0.0043
# Epoch 8/1024
# Epoch 7; Mass loss: 0.0046
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 62.7211 - fused_output_loss: 67.0773 - higgs_mass_loss: 121.4449 - loss: 134.2292 - mae_loss: 67.1520 - nu_mass_loss: 0.0046 - val_dinu_pt_loss: 62.3296 - val_fused_output_loss: 66.7465 - val_higgs_mass_loss: 121.3199 - val_loss: 133.6017 - val_mae_loss: 66.8552 - val_nu_mass_loss: 0.0045
# Epoch 9/1024
# Epoch 8; Mass loss: 0.0048
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 62.5139 - fused_output_loss: 66.9890 - higgs_mass_loss: 121.1169 - loss: 134.0502 - mae_loss: 67.0612 - nu_mass_loss: 0.0048 - val_dinu_pt_loss: 62.1304 - val_fused_output_loss: 66.6593 - val_higgs_mass_loss: 121.0044 - val_loss: 133.4313 - val_mae_loss: 66.7720 - val_nu_mass_loss: 0.0048
# Epoch 10/1024
# Epoch 9; Mass loss: 0.0051
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 62.3187 - fused_output_loss: 66.9013 - higgs_mass_loss: 120.8050 - loss: 133.8717 - mae_loss: 66.9704 - nu_mass_loss: 0.0051 - val_dinu_pt_loss: 61.9404 - val_fused_output_loss: 66.5727 - val_higgs_mass_loss: 120.7031 - val_loss: 133.2630 - val_mae_loss: 66.6902 - val_nu_mass_loss: 0.0050
# Epoch 11/1024
# Epoch 10; Mass loss: 0.0053
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 62.1315 - fused_output_loss: 66.8138 - higgs_mass_loss: 120.5033 - loss: 133.6871 - mae_loss: 66.8734 - nu_mass_loss: 0.0053 - val_dinu_pt_loss: 61.7566 - val_fused_output_loss: 66.4858 - val_higgs_mass_loss: 120.4078 - val_loss: 133.0831 - val_mae_loss: 66.5973 - val_nu_mass_loss: 0.0053
# Epoch 12/1024
# Epoch 11; Mass loss: 0.0056
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 61.9472 - fused_output_loss: 66.7258 - higgs_mass_loss: 120.2029 - loss: 133.4982 - mae_loss: 66.7724 - nu_mass_loss: 0.0056 - val_dinu_pt_loss: 61.5727 - val_fused_output_loss: 66.3986 - val_higgs_mass_loss: 120.1113 - val_loss: 132.9010 - val_mae_loss: 66.5023 - val_nu_mass_loss: 0.0055
# Epoch 13/1024
# Epoch 12; Mass loss: 0.0058
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 61.7626 - fused_output_loss: 66.6366 - higgs_mass_loss: 119.8981 - loss: 133.3070 - mae_loss: 66.6703 - nu_mass_loss: 0.0058 - val_dinu_pt_loss: 61.3898 - val_fused_output_loss: 66.3098 - val_higgs_mass_loss: 119.8090 - val_loss: 132.7112 - val_mae_loss: 66.4014 - val_nu_mass_loss: 0.0058
# Epoch 14/1024
# Epoch 13; Mass loss: 0.0061
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 61.5771 - fused_output_loss: 66.5462 - higgs_mass_loss: 119.5888 - loss: 133.1088 - mae_loss: 66.5628 - nu_mass_loss: 0.0061 - val_dinu_pt_loss: 61.2028 - val_fused_output_loss: 66.2202 - val_higgs_mass_loss: 119.5048 - val_loss: 132.5128 - val_mae_loss: 66.2926 - val_nu_mass_loss: 0.0061
# Epoch 15/1024
# Epoch 14; Mass loss: 0.0063
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 61.3866 - fused_output_loss: 66.4543 - higgs_mass_loss: 119.2784 - loss: 132.9007 - mae_loss: 66.4464 - nu_mass_loss: 0.0063 - val_dinu_pt_loss: 61.0134 - val_fused_output_loss: 66.1284 - val_higgs_mass_loss: 119.1949 - val_loss: 132.2992 - val_mae_loss: 66.1708 - val_nu_mass_loss: 0.0063
# Epoch 16/1024
# Epoch 15; Mass loss: 0.0065
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 61.1911 - fused_output_loss: 66.3609 - higgs_mass_loss: 118.9656 - loss: 132.6928 - mae_loss: 66.3319 - nu_mass_loss: 0.0065 - val_dinu_pt_loss: 60.8147 - val_fused_output_loss: 66.0341 - val_higgs_mass_loss: 118.8768 - val_loss: 132.0899 - val_mae_loss: 66.0557 - val_nu_mass_loss: 0.0065
# Epoch 17/1024
# Epoch 16; Mass loss: 0.0067
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 60.9884 - fused_output_loss: 66.2655 - higgs_mass_loss: 118.6517 - loss: 132.4862 - mae_loss: 66.2207 - nu_mass_loss: 0.0067 - val_dinu_pt_loss: 60.6081 - val_fused_output_loss: 65.9380 - val_higgs_mass_loss: 118.5633 - val_loss: 131.8828 - val_mae_loss: 65.9448 - val_nu_mass_loss: 0.0067
# Epoch 18/1024
# Epoch 17; Mass loss: 0.0070
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 60.7734 - fused_output_loss: 66.1678 - higgs_mass_loss: 118.3345 - loss: 132.2792 - mae_loss: 66.1116 - nu_mass_loss: 0.0070 - val_dinu_pt_loss: 60.3888 - val_fused_output_loss: 65.8386 - val_higgs_mass_loss: 118.2416 - val_loss: 131.6689 - val_mae_loss: 65.8302 - val_nu_mass_loss: 0.0070
# Epoch 19/1024
# Epoch 18; Mass loss: 0.0072
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 60.5492 - fused_output_loss: 66.0676 - higgs_mass_loss: 118.0164 - loss: 132.0703 - mae_loss: 66.0027 - nu_mass_loss: 0.0072 - val_dinu_pt_loss: 60.1604 - val_fused_output_loss: 65.7387 - val_higgs_mass_loss: 117.9285 - val_loss: 131.4656 - val_mae_loss: 65.7269 - val_nu_mass_loss: 0.0072
# Epoch 20/1024
# Epoch 19; Mass loss: 0.0074
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 60.3154 - fused_output_loss: 65.9651 - higgs_mass_loss: 117.6967 - loss: 131.8587 - mae_loss: 65.8937 - nu_mass_loss: 0.0074 - val_dinu_pt_loss: 59.9254 - val_fused_output_loss: 65.6355 - val_higgs_mass_loss: 117.6088 - val_loss: 131.2543 - val_mae_loss: 65.6188 - val_nu_mass_loss: 0.0074
# Epoch 21/1024
# Epoch 20; Mass loss: 0.0076
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 60.0739 - fused_output_loss: 65.8601 - higgs_mass_loss: 117.3737 - loss: 131.6433 - mae_loss: 65.7832 - nu_mass_loss: 0.0076 - val_dinu_pt_loss: 59.6804 - val_fused_output_loss: 65.5292 - val_higgs_mass_loss: 117.2858 - val_loss: 131.0365 - val_mae_loss: 65.5073 - val_nu_mass_loss: 0.0076
# Epoch 22/1024
# Epoch 21; Mass loss: 0.0078
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 59.8232 - fused_output_loss: 65.7526 - higgs_mass_loss: 117.0471 - loss: 131.4243 - mae_loss: 65.6717 - nu_mass_loss: 0.0078 - val_dinu_pt_loss: 59.4309 - val_fused_output_loss: 65.4219 - val_higgs_mass_loss: 116.9628 - val_loss: 130.8204 - val_mae_loss: 65.3984 - val_nu_mass_loss: 0.0078
# Epoch 23/1024
# Epoch 22; Mass loss: 0.0080
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 59.5647 - fused_output_loss: 65.6422 - higgs_mass_loss: 116.7151 - loss: 131.2006 - mae_loss: 65.5583 - nu_mass_loss: 0.0080 - val_dinu_pt_loss: 59.1689 - val_fused_output_loss: 65.3108 - val_higgs_mass_loss: 116.6310 - val_loss: 130.5966 - val_mae_loss: 65.2859 - val_nu_mass_loss: 0.0080
# Epoch 24/1024
# Epoch 23; Mass loss: 0.0083
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 59.2978 - fused_output_loss: 65.5293 - higgs_mass_loss: 116.3809 - loss: 130.9730 - mae_loss: 65.4439 - nu_mass_loss: 0.0083 - val_dinu_pt_loss: 58.9017 - val_fused_output_loss: 65.1976 - val_higgs_mass_loss: 116.3005 - val_loss: 130.3710 - val_mae_loss: 65.1733 - val_nu_mass_loss: 0.0083
# Epoch 25/1024
# Epoch 24; Mass loss: 0.0085
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 59.0249 - fused_output_loss: 65.4137 - higgs_mass_loss: 116.0430 - loss: 130.7414 - mae_loss: 65.3277 - nu_mass_loss: 0.0085 - val_dinu_pt_loss: 58.6289 - val_fused_output_loss: 65.0802 - val_higgs_mass_loss: 115.9618 - val_loss: 130.1320 - val_mae_loss: 65.0518 - val_nu_mass_loss: 0.0085
# Epoch 26/1024
# Epoch 25; Mass loss: 0.0087
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 58.7451 - fused_output_loss: 65.2954 - higgs_mass_loss: 115.7019 - loss: 130.5050 - mae_loss: 65.2096 - nu_mass_loss: 0.0087 - val_dinu_pt_loss: 58.3472 - val_fused_output_loss: 64.9613 - val_higgs_mass_loss: 115.6215 - val_loss: 129.8980 - val_mae_loss: 64.9367 - val_nu_mass_loss: 0.0087
# Epoch 27/1024
# Epoch 26; Mass loss: 0.0089
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 58.4609 - fused_output_loss: 65.1747 - higgs_mass_loss: 115.3584 - loss: 130.2639 - mae_loss: 65.0892 - nu_mass_loss: 0.0089 - val_dinu_pt_loss: 58.0648 - val_fused_output_loss: 64.8386 - val_higgs_mass_loss: 115.2761 - val_loss: 129.6510 - val_mae_loss: 64.8124 - val_nu_mass_loss: 0.0089
# Epoch 28/1024
# Epoch 27; Mass loss: 0.0091
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 58.1700 - fused_output_loss: 65.0512 - higgs_mass_loss: 115.0110 - loss: 130.0180 - mae_loss: 64.9668 - nu_mass_loss: 0.0091 - val_dinu_pt_loss: 57.7733 - val_fused_output_loss: 64.7150 - val_higgs_mass_loss: 114.9340 - val_loss: 129.4034 - val_mae_loss: 64.6885 - val_nu_mass_loss: 0.0091
# Epoch 29/1024
# Epoch 28; Mass loss: 0.0094
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 57.8734 - fused_output_loss: 64.9252 - higgs_mass_loss: 114.6606 - loss: 129.7669 - mae_loss: 64.8418 - nu_mass_loss: 0.0094 - val_dinu_pt_loss: 57.4717 - val_fused_output_loss: 64.5873 - val_higgs_mass_loss: 114.5826 - val_loss: 129.1491 - val_mae_loss: 64.5618 - val_nu_mass_loss: 0.0094
# Epoch 30/1024
# Epoch 29; Mass loss: 0.0096
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 57.5720 - fused_output_loss: 64.7964 - higgs_mass_loss: 114.3073 - loss: 129.5111 - mae_loss: 64.7146 - nu_mass_loss: 0.0096 - val_dinu_pt_loss: 57.1694 - val_fused_output_loss: 64.4572 - val_higgs_mass_loss: 114.2308 - val_loss: 128.8909 - val_mae_loss: 64.4336 - val_nu_mass_loss: 0.0096
# Epoch 31/1024
# Epoch 30; Mass loss: 0.0098
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 57.2712 - fused_output_loss: 64.6655 - higgs_mass_loss: 113.9492 - loss: 129.2503 - mae_loss: 64.5848 - nu_mass_loss: 0.0098 - val_dinu_pt_loss: 56.8694 - val_fused_output_loss: 64.3255 - val_higgs_mass_loss: 113.8741 - val_loss: 128.6248 - val_mae_loss: 64.2993 - val_nu_mass_loss: 0.0098
# Epoch 32/1024
# Epoch 31; Mass loss: 0.0100
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 56.9631 - fused_output_loss: 64.5316 - higgs_mass_loss: 113.5888 - loss: 128.9841 - mae_loss: 64.4526 - nu_mass_loss: 0.0100 - val_dinu_pt_loss: 56.5574 - val_fused_output_loss: 64.1899 - val_higgs_mass_loss: 113.5167 - val_loss: 128.3563 - val_mae_loss: 64.1663 - val_nu_mass_loss: 0.0100
# Epoch 33/1024
# Epoch 32; Mass loss: 0.0102
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 56.6563 - fused_output_loss: 64.3955 - higgs_mass_loss: 113.2250 - loss: 128.7134 - mae_loss: 64.3179 - nu_mass_loss: 0.0102 - val_dinu_pt_loss: 56.2511 - val_fused_output_loss: 64.0525 - val_higgs_mass_loss: 113.1481 - val_loss: 128.0831 - val_mae_loss: 64.0306 - val_nu_mass_loss: 0.0102
# Epoch 34/1024
# Epoch 33; Mass loss: 0.0104
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 56.3462 - fused_output_loss: 64.2566 - higgs_mass_loss: 112.8572 - loss: 128.4372 - mae_loss: 64.1808 - nu_mass_loss: 0.0104 - val_dinu_pt_loss: 55.9328 - val_fused_output_loss: 63.9111 - val_higgs_mass_loss: 112.7785 - val_loss: 127.7992 - val_mae_loss: 63.8880 - val_nu_mass_loss: 0.0104
# Epoch 35/1024
# Epoch 34; Mass loss: 0.0106
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 56.0386 - fused_output_loss: 64.1152 - higgs_mass_loss: 112.4858 - loss: 128.1553 - mae_loss: 64.0403 - nu_mass_loss: 0.0106 - val_dinu_pt_loss: 55.6245 - val_fused_output_loss: 63.7684 - val_higgs_mass_loss: 112.4104 - val_loss: 127.5149 - val_mae_loss: 63.7466 - val_nu_mass_loss: 0.0106
# Epoch 36/1024
# Epoch 35; Mass loss: 0.0108
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 55.7354 - fused_output_loss: 63.9717 - higgs_mass_loss: 112.1122 - loss: 127.8701 - mae_loss: 63.8985 - nu_mass_loss: 0.0108 - val_dinu_pt_loss: 55.3253 - val_fused_output_loss: 63.6236 - val_higgs_mass_loss: 112.0402 - val_loss: 127.2259 - val_mae_loss: 63.6023 - val_nu_mass_loss: 0.0107
# Epoch 37/1024
# Epoch 36; Mass loss: 0.0110
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 55.4289 - fused_output_loss: 63.8254 - higgs_mass_loss: 111.7356 - loss: 127.5797 - mae_loss: 63.7541 - nu_mass_loss: 0.0110 - val_dinu_pt_loss: 55.0156 - val_fused_output_loss: 63.4765 - val_higgs_mass_loss: 111.6574 - val_loss: 126.9336 - val_mae_loss: 63.4570 - val_nu_mass_loss: 0.0109
# Epoch 38/1024
# Epoch 37; Mass loss: 0.0111
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 55.1295 - fused_output_loss: 63.6767 - higgs_mass_loss: 111.3560 - loss: 127.2832 - mae_loss: 63.6064 - nu_mass_loss: 0.0111 - val_dinu_pt_loss: 54.7162 - val_fused_output_loss: 63.3280 - val_higgs_mass_loss: 111.2821 - val_loss: 126.6384 - val_mae_loss: 63.3104 - val_nu_mass_loss: 0.0111
# Epoch 39/1024
# Epoch 38; Mass loss: 0.0113
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 54.8227 - fused_output_loss: 63.5257 - higgs_mass_loss: 110.9712 - loss: 126.9823 - mae_loss: 63.4567 - nu_mass_loss: 0.0113 - val_dinu_pt_loss: 54.4063 - val_fused_output_loss: 63.1734 - val_higgs_mass_loss: 110.8999 - val_loss: 126.3300 - val_mae_loss: 63.1567 - val_nu_mass_loss: 0.0113
# Epoch 40/1024
# Epoch 39; Mass loss: 0.0114
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 54.5286 - fused_output_loss: 63.3717 - higgs_mass_loss: 110.5858 - loss: 126.6751 - mae_loss: 63.3034 - nu_mass_loss: 0.0114 - val_dinu_pt_loss: 54.1075 - val_fused_output_loss: 63.0172 - val_higgs_mass_loss: 110.5089 - val_loss: 126.0166 - val_mae_loss: 62.9994 - val_nu_mass_loss: 0.0114
# Epoch 41/1024
# Epoch 40; Mass loss: 0.0116
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 54.2339 - fused_output_loss: 63.2158 - higgs_mass_loss: 110.1982 - loss: 126.3650 - mae_loss: 63.1491 - nu_mass_loss: 0.0116 - val_dinu_pt_loss: 53.8100 - val_fused_output_loss: 62.8591 - val_higgs_mass_loss: 110.1160 - val_loss: 125.7006 - val_mae_loss: 62.8415 - val_nu_mass_loss: 0.0115
# Epoch 42/1024
# Epoch 41; Mass loss: 0.0117
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 53.9358 - fused_output_loss: 63.0569 - higgs_mass_loss: 109.8068 - loss: 126.0480 - mae_loss: 62.9912 - nu_mass_loss: 0.0117 - val_dinu_pt_loss: 53.5090 - val_fused_output_loss: 62.7005 - val_higgs_mass_loss: 109.7323 - val_loss: 125.3803 - val_mae_loss: 62.6798 - val_nu_mass_loss: 0.0117
# Epoch 43/1024
# Epoch 42; Mass loss: 0.0119
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 53.6446 - fused_output_loss: 62.8958 - higgs_mass_loss: 109.4145 - loss: 125.7266 - mae_loss: 62.8308 - nu_mass_loss: 0.0119 - val_dinu_pt_loss: 53.2190 - val_fused_output_loss: 62.5391 - val_higgs_mass_loss: 109.3431 - val_loss: 125.0600 - val_mae_loss: 62.5209 - val_nu_mass_loss: 0.0118
# Epoch 44/1024
# Epoch 43; Mass loss: 0.0120
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 53.3568 - fused_output_loss: 62.7323 - higgs_mass_loss: 109.0188 - loss: 125.4008 - mae_loss: 62.6684 - nu_mass_loss: 0.0120 - val_dinu_pt_loss: 52.9265 - val_fused_output_loss: 62.3712 - val_higgs_mass_loss: 108.9316 - val_loss: 124.7254 - val_mae_loss: 62.3542 - val_nu_mass_loss: 0.0119
# Epoch 45/1024
# Epoch 44; Mass loss: 0.0121
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 53.0677 - fused_output_loss: 62.5664 - higgs_mass_loss: 108.6243 - loss: 125.0700 - mae_loss: 62.5036 - nu_mass_loss: 0.0121 - val_dinu_pt_loss: 52.6362 - val_fused_output_loss: 62.2051 - val_higgs_mass_loss: 108.5501 - val_loss: 124.3938 - val_mae_loss: 62.1887 - val_nu_mass_loss: 0.0120
# Epoch 46/1024
# Epoch 45; Mass loss: 0.0122
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 52.7866 - fused_output_loss: 62.3983 - higgs_mass_loss: 108.2286 - loss: 124.7347 - mae_loss: 62.3363 - nu_mass_loss: 0.0122 - val_dinu_pt_loss: 52.3569 - val_fused_output_loss: 62.0340 - val_higgs_mass_loss: 108.1453 - val_loss: 124.0517 - val_mae_loss: 62.0177 - val_nu_mass_loss: 0.0122
# Epoch 47/1024
# Epoch 46; Mass loss: 0.0123
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 52.5057 - fused_output_loss: 62.2276 - higgs_mass_loss: 107.8308 - loss: 124.3943 - mae_loss: 62.1664 - nu_mass_loss: 0.0123 - val_dinu_pt_loss: 52.0628 - val_fused_output_loss: 61.8616 - val_higgs_mass_loss: 107.7467 - val_loss: 123.7046 - val_mae_loss: 61.8430 - val_nu_mass_loss: 0.0123
# Epoch 48/1024
# Epoch 47; Mass loss: 0.0124
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 52.2264 - fused_output_loss: 62.0542 - higgs_mass_loss: 107.4315 - loss: 124.0482 - mae_loss: 61.9940 - nu_mass_loss: 0.0124 - val_dinu_pt_loss: 51.7868 - val_fused_output_loss: 61.6848 - val_higgs_mass_loss: 107.3401 - val_loss: 123.3540 - val_mae_loss: 61.6692 - val_nu_mass_loss: 0.0124
# Epoch 49/1024
# Epoch 48; Mass loss: 0.0125
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 51.9444 - fused_output_loss: 61.8787 - higgs_mass_loss: 107.0324 - loss: 123.6978 - mae_loss: 61.8191 - nu_mass_loss: 0.0125 - val_dinu_pt_loss: 51.4930 - val_fused_output_loss: 61.5056 - val_higgs_mass_loss: 106.9406 - val_loss: 122.9969 - val_mae_loss: 61.4914 - val_nu_mass_loss: 0.0124
# Epoch 50/1024
# Epoch 49; Mass loss: 0.0126
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 51.6704 - fused_output_loss: 61.7006 - higgs_mass_loss: 106.6351 - loss: 123.3424 - mae_loss: 61.6418 - nu_mass_loss: 0.0126 - val_dinu_pt_loss: 51.2180 - val_fused_output_loss: 61.3286 - val_higgs_mass_loss: 106.5507 - val_loss: 122.6406 - val_mae_loss: 61.3121 - val_nu_mass_loss: 0.0125
# Epoch 51/1024
# Epoch 50; Mass loss: 0.0127
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 51.3990 - fused_output_loss: 61.5207 - higgs_mass_loss: 106.2366 - loss: 122.9836 - mae_loss: 61.4630 - nu_mass_loss: 0.0127 - val_dinu_pt_loss: 50.9419 - val_fused_output_loss: 61.1455 - val_higgs_mass_loss: 106.1461 - val_loss: 122.2751 - val_mae_loss: 61.1295 - val_nu_mass_loss: 0.0126
# Epoch 52/1024
# Epoch 51; Mass loss: 0.0128
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 51.1223 - fused_output_loss: 61.3378 - higgs_mass_loss: 105.8361 - loss: 122.6189 - mae_loss: 61.2812 - nu_mass_loss: 0.0128 - val_dinu_pt_loss: 50.6706 - val_fused_output_loss: 60.9627 - val_higgs_mass_loss: 105.7507 - val_loss: 121.9134 - val_mae_loss: 60.9507 - val_nu_mass_loss: 0.0127
# Epoch 53/1024
# Epoch 52; Mass loss: 0.0129
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 50.8534 - fused_output_loss: 61.1527 - higgs_mass_loss: 105.4390 - loss: 122.2491 - mae_loss: 61.0965 - nu_mass_loss: 0.0129 - val_dinu_pt_loss: 50.3899 - val_fused_output_loss: 60.7757 - val_higgs_mass_loss: 105.3530 - val_loss: 121.5368 - val_mae_loss: 60.7611 - val_nu_mass_loss: 0.0128
# Epoch 54/1024
# Epoch 53; Mass loss: 0.0130
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 50.5824 - fused_output_loss: 60.9657 - higgs_mass_loss: 105.0390 - loss: 121.8759 - mae_loss: 60.9103 - nu_mass_loss: 0.0130 - val_dinu_pt_loss: 50.1147 - val_fused_output_loss: 60.5870 - val_higgs_mass_loss: 104.9580 - val_loss: 121.1623 - val_mae_loss: 60.5753 - val_nu_mass_loss: 0.0129
# Epoch 55/1024
# Epoch 54; Mass loss: 0.0131
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 50.3047 - fused_output_loss: 60.7762 - higgs_mass_loss: 104.6385 - loss: 121.4979 - mae_loss: 60.7219 - nu_mass_loss: 0.0131 - val_dinu_pt_loss: 49.8367 - val_fused_output_loss: 60.3934 - val_higgs_mass_loss: 104.5553 - val_loss: 120.7735 - val_mae_loss: 60.3801 - val_nu_mass_loss: 0.0130
# Epoch 56/1024
# Epoch 55; Mass loss: 0.0131
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 50.0349 - fused_output_loss: 60.5844 - higgs_mass_loss: 104.2426 - loss: 121.1149 - mae_loss: 60.5306 - nu_mass_loss: 0.0131 - val_dinu_pt_loss: 49.5807 - val_fused_output_loss: 60.2025 - val_higgs_mass_loss: 104.1617 - val_loss: 120.3990 - val_mae_loss: 60.1964 - val_nu_mass_loss: 0.0130
# Epoch 57/1024
# Epoch 56; Mass loss: 0.0132
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 49.7662 - fused_output_loss: 60.3904 - higgs_mass_loss: 103.8452 - loss: 120.7283 - mae_loss: 60.3379 - nu_mass_loss: 0.0132 - val_dinu_pt_loss: 49.2848 - val_fused_output_loss: 60.0057 - val_higgs_mass_loss: 103.7568 - val_loss: 120.0016 - val_mae_loss: 59.9960 - val_nu_mass_loss: 0.0130
# Epoch 58/1024
# Epoch 57; Mass loss: 0.0133
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 49.4957 - fused_output_loss: 60.1939 - higgs_mass_loss: 103.4483 - loss: 120.3361 - mae_loss: 60.1422 - nu_mass_loss: 0.0133 - val_dinu_pt_loss: 49.0053 - val_fused_output_loss: 59.8074 - val_higgs_mass_loss: 103.3593 - val_loss: 119.6070 - val_mae_loss: 59.7996 - val_nu_mass_loss: 0.0132
# Epoch 59/1024
# Epoch 58; Mass loss: 0.0133
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 49.2215 - fused_output_loss: 59.9954 - higgs_mass_loss: 103.0559 - loss: 119.9396 - mae_loss: 59.9442 - nu_mass_loss: 0.0133 - val_dinu_pt_loss: 48.7505 - val_fused_output_loss: 59.6071 - val_higgs_mass_loss: 102.9658 - val_loss: 119.2067 - val_mae_loss: 59.5996 - val_nu_mass_loss: 0.0132
# Epoch 60/1024
# Epoch 59; Mass loss: 0.0134
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 48.9590 - fused_output_loss: 59.7950 - higgs_mass_loss: 102.6597 - loss: 119.5403 - mae_loss: 59.7453 - nu_mass_loss: 0.0134 - val_dinu_pt_loss: 48.4632 - val_fused_output_loss: 59.4042 - val_higgs_mass_loss: 102.5694 - val_loss: 118.8016 - val_mae_loss: 59.3973 - val_nu_mass_loss: 0.0133
# Epoch 61/1024
# Epoch 60; Mass loss: 0.0134
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 48.6856 - fused_output_loss: 59.5919 - higgs_mass_loss: 102.2685 - loss: 119.1351 - mae_loss: 59.5431 - nu_mass_loss: 0.0134 - val_dinu_pt_loss: 48.1986 - val_fused_output_loss: 59.1999 - val_higgs_mass_loss: 102.1808 - val_loss: 118.3948 - val_mae_loss: 59.1949 - val_nu_mass_loss: 0.0133
# Epoch 62/1024
# Epoch 61; Mass loss: 0.0135
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 48.4170 - fused_output_loss: 59.3876 - higgs_mass_loss: 101.8763 - loss: 118.7269 - mae_loss: 59.3393 - nu_mass_loss: 0.0135 - val_dinu_pt_loss: 47.9296 - val_fused_output_loss: 58.9948 - val_higgs_mass_loss: 101.7817 - val_loss: 117.9870 - val_mae_loss: 58.9921 - val_nu_mass_loss: 0.0134
# Epoch 63/1024
# Epoch 62; Mass loss: 0.0135
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 48.1579 - fused_output_loss: 59.1802 - higgs_mass_loss: 101.4844 - loss: 118.3135 - mae_loss: 59.1333 - nu_mass_loss: 0.0135 - val_dinu_pt_loss: 47.6695 - val_fused_output_loss: 58.7879 - val_higgs_mass_loss: 101.3966 - val_loss: 117.5749 - val_mae_loss: 58.7871 - val_nu_mass_loss: 0.0134
# Epoch 64/1024
# Epoch 63; Mass loss: 0.0136
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 47.8922 - fused_output_loss: 58.9710 - higgs_mass_loss: 101.0964 - loss: 117.8965 - mae_loss: 58.9255 - nu_mass_loss: 0.0136 - val_dinu_pt_loss: 47.3979 - val_fused_output_loss: 58.5765 - val_higgs_mass_loss: 101.0010 - val_loss: 117.1523 - val_mae_loss: 58.5757 - val_nu_mass_loss: 0.0135
# Epoch 65/1024
# Epoch 64; Mass loss: 0.0137
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 47.6210 - fused_output_loss: 58.7596 - higgs_mass_loss: 100.7104 - loss: 117.4745 - mae_loss: 58.7149 - nu_mass_loss: 0.0137 - val_dinu_pt_loss: 47.1212 - val_fused_output_loss: 58.3653 - val_higgs_mass_loss: 100.6353 - val_loss: 116.7353 - val_mae_loss: 58.3700 - val_nu_mass_loss: 0.0135
# Epoch 66/1024
# Epoch 65; Mass loss: 0.0137
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 47.3539 - fused_output_loss: 58.5465 - higgs_mass_loss: 100.3231 - loss: 117.0497 - mae_loss: 58.5032 - nu_mass_loss: 0.0137 - val_dinu_pt_loss: 46.8485 - val_fused_output_loss: 58.1497 - val_higgs_mass_loss: 100.2335 - val_loss: 116.3038 - val_mae_loss: 58.1542 - val_nu_mass_loss: 0.0136
# Epoch 67/1024
# Epoch 66; Mass loss: 0.0138
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 47.0836 - fused_output_loss: 58.3309 - higgs_mass_loss: 99.9382 - loss: 116.6200 - mae_loss: 58.2890 - nu_mass_loss: 0.0138 - val_dinu_pt_loss: 46.5744 - val_fused_output_loss: 57.9347 - val_higgs_mass_loss: 99.8603 - val_loss: 115.8731 - val_mae_loss: 57.9384 - val_nu_mass_loss: 0.0136
# Epoch 68/1024
# Epoch 67; Mass loss: 0.0138
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 46.8162 - fused_output_loss: 58.1142 - higgs_mass_loss: 99.5539 - loss: 116.1880 - mae_loss: 58.0737 - nu_mass_loss: 0.0138 - val_dinu_pt_loss: 46.3086 - val_fused_output_loss: 57.7155 - val_higgs_mass_loss: 99.4704 - val_loss: 115.4376 - val_mae_loss: 57.7221 - val_nu_mass_loss: 0.0137
# Epoch 69/1024
# Epoch 68; Mass loss: 0.0138
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 46.5517 - fused_output_loss: 57.8946 - higgs_mass_loss: 99.1707 - loss: 115.7498 - mae_loss: 57.8553 - nu_mass_loss: 0.0138 - val_dinu_pt_loss: 46.0162 - val_fused_output_loss: 57.4937 - val_higgs_mass_loss: 99.0686 - val_loss: 114.9937 - val_mae_loss: 57.5001 - val_nu_mass_loss: 0.0137
# Epoch 70/1024
# Epoch 69; Mass loss: 0.0139
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 46.2773 - fused_output_loss: 57.6733 - higgs_mass_loss: 98.7849 - loss: 115.3096 - mae_loss: 57.6362 - nu_mass_loss: 0.0139 - val_dinu_pt_loss: 45.7568 - val_fused_output_loss: 57.2732 - val_higgs_mass_loss: 98.6934 - val_loss: 114.5573 - val_mae_loss: 57.2841 - val_nu_mass_loss: 0.0138
# Epoch 71/1024
# Epoch 70; Mass loss: 0.0139
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 46.0114 - fused_output_loss: 57.4501 - higgs_mass_loss: 98.4082 - loss: 114.8651 - mae_loss: 57.4150 - nu_mass_loss: 0.0139 - val_dinu_pt_loss: 45.4740 - val_fused_output_loss: 57.0465 - val_higgs_mass_loss: 98.3017 - val_loss: 114.1051 - val_mae_loss: 57.0586 - val_nu_mass_loss: 0.0138
# Epoch 72/1024
# Epoch 71; Mass loss: 0.0140
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 45.7393 - fused_output_loss: 57.2248 - higgs_mass_loss: 98.0290 - loss: 114.4165 - mae_loss: 57.1918 - nu_mass_loss: 0.0140 - val_dinu_pt_loss: 45.2014 - val_fused_output_loss: 56.8219 - val_higgs_mass_loss: 97.9338 - val_loss: 113.6588 - val_mae_loss: 56.8369 - val_nu_mass_loss: 0.0139
# Epoch 73/1024
# Epoch 72; Mass loss: 0.0140
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 45.4787 - fused_output_loss: 56.9981 - higgs_mass_loss: 97.6531 - loss: 113.9646 - mae_loss: 56.9666 - nu_mass_loss: 0.0140 - val_dinu_pt_loss: 44.9476 - val_fused_output_loss: 56.5956 - val_higgs_mass_loss: 97.5519 - val_loss: 113.2098 - val_mae_loss: 56.6141 - val_nu_mass_loss: 0.0139
# Epoch 74/1024
# Epoch 73; Mass loss: 0.0140
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 45.2031 - fused_output_loss: 56.7694 - higgs_mass_loss: 97.2685 - loss: 113.5100 - mae_loss: 56.7407 - nu_mass_loss: 0.0140 - val_dinu_pt_loss: 44.6779 - val_fused_output_loss: 56.3649 - val_higgs_mass_loss: 97.1818 - val_loss: 112.7517 - val_mae_loss: 56.3868 - val_nu_mass_loss: 0.0139
# Epoch 75/1024
# Epoch 74; Mass loss: 0.0141
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 44.9306 - fused_output_loss: 56.5387 - higgs_mass_loss: 96.8965 - loss: 113.0514 - mae_loss: 56.5126 - nu_mass_loss: 0.0141 - val_dinu_pt_loss: 44.3893 - val_fused_output_loss: 56.1324 - val_higgs_mass_loss: 96.8015 - val_loss: 112.2884 - val_mae_loss: 56.1560 - val_nu_mass_loss: 0.0140
# Epoch 76/1024
# Epoch 75; Mass loss: 0.0141
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 44.6649 - fused_output_loss: 56.3069 - higgs_mass_loss: 96.5194 - loss: 112.5896 - mae_loss: 56.2828 - nu_mass_loss: 0.0141 - val_dinu_pt_loss: 44.1152 - val_fused_output_loss: 55.8986 - val_higgs_mass_loss: 96.4116 - val_loss: 111.8204 - val_mae_loss: 55.9218 - val_nu_mass_loss: 0.0140
# Epoch 77/1024
# Epoch 76; Mass loss: 0.0141
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 44.3937 - fused_output_loss: 56.0727 - higgs_mass_loss: 96.1479 - loss: 112.1246 - mae_loss: 56.0519 - nu_mass_loss: 0.0141 - val_dinu_pt_loss: 43.8572 - val_fused_output_loss: 55.6662 - val_higgs_mass_loss: 96.0445 - val_loss: 111.3635 - val_mae_loss: 55.6974 - val_nu_mass_loss: 0.0140
# Epoch 78/1024
# Epoch 77; Mass loss: 0.0142
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 44.1200 - fused_output_loss: 55.8371 - higgs_mass_loss: 95.7737 - loss: 111.6565 - mae_loss: 55.8194 - nu_mass_loss: 0.0142 - val_dinu_pt_loss: 43.5693 - val_fused_output_loss: 55.4303 - val_higgs_mass_loss: 95.6762 - val_loss: 110.8935 - val_mae_loss: 55.4632 - val_nu_mass_loss: 0.0140
# Epoch 79/1024
# Epoch 78; Mass loss: 0.0142
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 43.8536 - fused_output_loss: 55.5999 - higgs_mass_loss: 95.3984 - loss: 111.1846 - mae_loss: 55.5848 - nu_mass_loss: 0.0142 - val_dinu_pt_loss: 43.3087 - val_fused_output_loss: 55.1915 - val_higgs_mass_loss: 95.2890 - val_loss: 110.4195 - val_mae_loss: 55.2279 - val_nu_mass_loss: 0.0141
# Epoch 80/1024
# Epoch 79; Mass loss: 0.0143
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 43.5897 - fused_output_loss: 55.3613 - higgs_mass_loss: 95.0208 - loss: 110.7108 - mae_loss: 55.3494 - nu_mass_loss: 0.0143 - val_dinu_pt_loss: 43.0236 - val_fused_output_loss: 54.9476 - val_higgs_mass_loss: 94.8955 - val_loss: 109.9325 - val_mae_loss: 54.9850 - val_nu_mass_loss: 0.0141
# Epoch 81/1024
# Epoch 80; Mass loss: 0.0143
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 43.3147 - fused_output_loss: 55.1210 - higgs_mass_loss: 94.6491 - loss: 110.2336 - mae_loss: 55.1127 - nu_mass_loss: 0.0143 - val_dinu_pt_loss: 42.7565 - val_fused_output_loss: 54.7103 - val_higgs_mass_loss: 94.5445 - val_loss: 109.4634 - val_mae_loss: 54.7531 - val_nu_mass_loss: 0.0142
# Epoch 82/1024
# Epoch 81; Mass loss: 0.0143
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 43.0382 - fused_output_loss: 54.8785 - higgs_mass_loss: 94.2744 - loss: 109.7517 - mae_loss: 54.8732 - nu_mass_loss: 0.0143 - val_dinu_pt_loss: 42.4560 - val_fused_output_loss: 54.4633 - val_higgs_mass_loss: 94.1547 - val_loss: 108.9719 - val_mae_loss: 54.5087 - val_nu_mass_loss: 0.0142
# Epoch 83/1024
# Epoch 82; Mass loss: 0.0143
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 42.7685 - fused_output_loss: 54.6357 - higgs_mass_loss: 93.9014 - loss: 109.2696 - mae_loss: 54.6338 - nu_mass_loss: 0.0143 - val_dinu_pt_loss: 42.1906 - val_fused_output_loss: 54.2200 - val_higgs_mass_loss: 93.8021 - val_loss: 108.4920 - val_mae_loss: 54.2720 - val_nu_mass_loss: 0.0142
# Epoch 84/1024
# Epoch 83; Mass loss: 0.0144
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 42.4942 - fused_output_loss: 54.3903 - higgs_mass_loss: 93.5254 - loss: 108.7822 - mae_loss: 54.3918 - nu_mass_loss: 0.0144 - val_dinu_pt_loss: 41.9092 - val_fused_output_loss: 53.9736 - val_higgs_mass_loss: 93.3858 - val_loss: 107.9991 - val_mae_loss: 54.0255 - val_nu_mass_loss: 0.0143
# Epoch 85/1024
# Epoch 84; Mass loss: 0.0144
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 42.2242 - fused_output_loss: 54.1440 - higgs_mass_loss: 93.1434 - loss: 108.2939 - mae_loss: 54.1498 - nu_mass_loss: 0.0144 - val_dinu_pt_loss: 41.6284 - val_fused_output_loss: 53.7302 - val_higgs_mass_loss: 93.0204 - val_loss: 107.5192 - val_mae_loss: 53.7891 - val_nu_mass_loss: 0.0143
# Epoch 86/1024
# Epoch 85; Mass loss: 0.0144
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 41.9523 - fused_output_loss: 53.8962 - higgs_mass_loss: 92.7692 - loss: 107.8021 - mae_loss: 53.9058 - nu_mass_loss: 0.0144 - val_dinu_pt_loss: 41.3591 - val_fused_output_loss: 53.4818 - val_higgs_mass_loss: 92.6589 - val_loss: 107.0283 - val_mae_loss: 53.5465 - val_nu_mass_loss: 0.0143
# Epoch 87/1024
# Epoch 86; Mass loss: 0.0145
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 41.6802 - fused_output_loss: 53.6475 - higgs_mass_loss: 92.3970 - loss: 107.3091 - mae_loss: 53.6616 - nu_mass_loss: 0.0145 - val_dinu_pt_loss: 41.0694 - val_fused_output_loss: 53.2264 - val_higgs_mass_loss: 92.2452 - val_loss: 106.5209 - val_mae_loss: 53.2945 - val_nu_mass_loss: 0.0143
# Epoch 88/1024
# Epoch 87; Mass loss: 0.0145
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 41.4121 - fused_output_loss: 53.3972 - higgs_mass_loss: 92.0173 - loss: 106.8128 - mae_loss: 53.4157 - nu_mass_loss: 0.0145 - val_dinu_pt_loss: 40.8000 - val_fused_output_loss: 52.9815 - val_higgs_mass_loss: 91.8860 - val_loss: 106.0368 - val_mae_loss: 53.0553 - val_nu_mass_loss: 0.0144
# Epoch 89/1024
# Epoch 88; Mass loss: 0.0145
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 41.1325 - fused_output_loss: 53.1463 - higgs_mass_loss: 91.6299 - loss: 106.3153 - mae_loss: 53.1691 - nu_mass_loss: 0.0145 - val_dinu_pt_loss: 40.5213 - val_fused_output_loss: 52.7259 - val_higgs_mass_loss: 91.5042 - val_loss: 105.5277 - val_mae_loss: 52.8018 - val_nu_mass_loss: 0.0144
# Epoch 90/1024
# Epoch 89; Mass loss: 0.0145
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 40.8540 - fused_output_loss: 52.8929 - higgs_mass_loss: 91.2469 - loss: 105.8137 - mae_loss: 52.9208 - nu_mass_loss: 0.0145 - val_dinu_pt_loss: 40.2267 - val_fused_output_loss: 52.4731 - val_higgs_mass_loss: 91.0955 - val_loss: 105.0266 - val_mae_loss: 52.5535 - val_nu_mass_loss: 0.0144
# Epoch 91/1024
# Epoch 90; Mass loss: 0.0146
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 40.5867 - fused_output_loss: 52.6391 - higgs_mass_loss: 90.8588 - loss: 105.3115 - mae_loss: 52.6723 - nu_mass_loss: 0.0146 - val_dinu_pt_loss: 39.9562 - val_fused_output_loss: 52.2200 - val_higgs_mass_loss: 90.7005 - val_loss: 104.5271 - val_mae_loss: 52.3071 - val_nu_mass_loss: 0.0145
# Epoch 92/1024
# Epoch 91; Mass loss: 0.0146
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 40.3188 - fused_output_loss: 52.3838 - higgs_mass_loss: 90.4703 - loss: 104.8050 - mae_loss: 52.4212 - nu_mass_loss: 0.0146 - val_dinu_pt_loss: 39.6974 - val_fused_output_loss: 51.9648 - val_higgs_mass_loss: 90.3248 - val_loss: 104.0225 - val_mae_loss: 52.0576 - val_nu_mass_loss: 0.0144
# Epoch 93/1024
# Epoch 92; Mass loss: 0.0146
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 40.0442 - fused_output_loss: 52.1275 - higgs_mass_loss: 90.0727 - loss: 104.2974 - mae_loss: 52.1699 - nu_mass_loss: 0.0146 - val_dinu_pt_loss: 39.3841 - val_fused_output_loss: 51.7050 - val_higgs_mass_loss: 89.9033 - val_loss: 103.5044 - val_mae_loss: 51.7995 - val_nu_mass_loss: 0.0145
# Epoch 94/1024
# Epoch 93; Mass loss: 0.0146
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 39.7686 - fused_output_loss: 51.8705 - higgs_mass_loss: 89.6696 - loss: 103.7889 - mae_loss: 51.9183 - nu_mass_loss: 0.0146 - val_dinu_pt_loss: 39.1042 - val_fused_output_loss: 51.4442 - val_higgs_mass_loss: 89.4886 - val_loss: 102.9898 - val_mae_loss: 51.5456 - val_nu_mass_loss: 0.0145
# Epoch 95/1024
# Epoch 94; Mass loss: 0.0147
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 39.4937 - fused_output_loss: 51.6127 - higgs_mass_loss: 89.2659 - loss: 103.2781 - mae_loss: 51.6654 - nu_mass_loss: 0.0147 - val_dinu_pt_loss: 38.8487 - val_fused_output_loss: 51.1932 - val_higgs_mass_loss: 89.1025 - val_loss: 102.4966 - val_mae_loss: 51.3033 - val_nu_mass_loss: 0.0145
# Epoch 96/1024
# Epoch 95; Mass loss: 0.0147
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 39.2232 - fused_output_loss: 51.3532 - higgs_mass_loss: 88.8510 - loss: 102.7650 - mae_loss: 51.4118 - nu_mass_loss: 0.0147 - val_dinu_pt_loss: 38.5472 - val_fused_output_loss: 50.9346 - val_higgs_mass_loss: 88.6619 - val_loss: 101.9860 - val_mae_loss: 51.0514 - val_nu_mass_loss: 0.0146
# Epoch 97/1024
# Epoch 96; Mass loss: 0.0147
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 38.9464 - fused_output_loss: 51.0930 - higgs_mass_loss: 88.4332 - loss: 102.2501 - mae_loss: 51.1571 - nu_mass_loss: 0.0147 - val_dinu_pt_loss: 38.2596 - val_fused_output_loss: 50.6702 - val_higgs_mass_loss: 88.2318 - val_loss: 101.4604 - val_mae_loss: 50.7902 - val_nu_mass_loss: 0.0146
# Epoch 98/1024
# Epoch 97; Mass loss: 0.0147
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 38.6696 - fused_output_loss: 50.8323 - higgs_mass_loss: 87.9987 - loss: 101.7348 - mae_loss: 50.9026 - nu_mass_loss: 0.0147 - val_dinu_pt_loss: 38.0063 - val_fused_output_loss: 50.4128 - val_higgs_mass_loss: 87.7975 - val_loss: 100.9559 - val_mae_loss: 50.5431 - val_nu_mass_loss: 0.0146
# Epoch 99/1024
# Epoch 98; Mass loss: 0.0148
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 38.4049 - fused_output_loss: 50.5705 - higgs_mass_loss: 87.5658 - loss: 101.2169 - mae_loss: 50.6464 - nu_mass_loss: 0.0148 - val_dinu_pt_loss: 37.7267 - val_fused_output_loss: 50.1556 - val_higgs_mass_loss: 87.3814 - val_loss: 100.4509 - val_mae_loss: 50.2953 - val_nu_mass_loss: 0.0146
# Epoch 100/1024
# Epoch 99; Mass loss: 0.0148
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 38.1352 - fused_output_loss: 50.3076 - higgs_mass_loss: 87.1160 - loss: 100.6973 - mae_loss: 50.3896 - nu_mass_loss: 0.0148 - val_dinu_pt_loss: 37.4382 - val_fused_output_loss: 49.8905 - val_higgs_mass_loss: 86.9150 - val_loss: 99.9263 - val_mae_loss: 50.0358 - val_nu_mass_loss: 0.0146
# Epoch 101/1024
# Epoch 100; Mass loss: 0.0148
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 37.8590 - fused_output_loss: 50.0443 - higgs_mass_loss: 86.6569 - loss: 100.1770 - mae_loss: 50.1327 - nu_mass_loss: 0.0148 - val_dinu_pt_loss: 37.1458 - val_fused_output_loss: 49.6223 - val_higgs_mass_loss: 86.4325 - val_loss: 99.3936 - val_mae_loss: 49.7713 - val_nu_mass_loss: 0.0147
# Epoch 102/1024
# Epoch 101; Mass loss: 0.0148
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 37.5863 - fused_output_loss: 49.7810 - higgs_mass_loss: 86.1841 - loss: 99.6566 - mae_loss: 49.8757 - nu_mass_loss: 0.0148 - val_dinu_pt_loss: 36.8614 - val_fused_output_loss: 49.3589 - val_higgs_mass_loss: 85.9712 - val_loss: 98.8722 - val_mae_loss: 49.5133 - val_nu_mass_loss: 0.0147
# Epoch 103/1024
# Epoch 102; Mass loss: 0.0148
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 37.3112 - fused_output_loss: 49.5156 - higgs_mass_loss: 85.6970 - loss: 99.1313 - mae_loss: 49.6157 - nu_mass_loss: 0.0148 - val_dinu_pt_loss: 36.5920 - val_fused_output_loss: 49.1006 - val_higgs_mass_loss: 85.4817 - val_loss: 98.3621 - val_mae_loss: 49.2615 - val_nu_mass_loss: 0.0147
# Epoch 104/1024
# Epoch 103; Mass loss: 0.0149
# 1330/1330 - 5s - 3ms/step - dinu_pt_loss: 37.0485 - fused_output_loss: 49.2502 - higgs_mass_loss: 85.2018 - loss: 98.6078 - mae_loss: 49.3576 - nu_mass_loss: 0.0149 - val_dinu_pt_loss: 36.3373 - val_fused_output_loss: 48.8334 - val_higgs_mass_loss: 84.9633 - val_loss: 97.8360 - val_mae_loss: 49.0025 - val_nu_mass_loss: 0.0148
# Epoch 105/1024
# Epoch 104; Mass loss: 0.0149
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 36.7858 - fused_output_loss: 48.9854 - higgs_mass_loss: 84.6965 - loss: 98.0836 - mae_loss: 49.0983 - nu_mass_loss: 0.0149 - val_dinu_pt_loss: 36.0562 - val_fused_output_loss: 48.5610 - val_higgs_mass_loss: 84.4458 - val_loss: 97.2966 - val_mae_loss: 48.7356 - val_nu_mass_loss: 0.0148
# Epoch 106/1024
# Epoch 105; Mass loss: 0.0149
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 36.5208 - fused_output_loss: 48.7185 - higgs_mass_loss: 84.1803 - loss: 97.5571 - mae_loss: 48.8386 - nu_mass_loss: 0.0149 - val_dinu_pt_loss: 35.7839 - val_fused_output_loss: 48.2979 - val_higgs_mass_loss: 83.9549 - val_loss: 96.7796 - val_mae_loss: 48.4817 - val_nu_mass_loss: 0.0148
# Epoch 107/1024
# Epoch 106; Mass loss: 0.0149
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 36.2528 - fused_output_loss: 48.4520 - higgs_mass_loss: 83.6505 - loss: 97.0313 - mae_loss: 48.5792 - nu_mass_loss: 0.0149 - val_dinu_pt_loss: 35.4987 - val_fused_output_loss: 48.0327 - val_higgs_mass_loss: 83.3977 - val_loss: 96.2581 - val_mae_loss: 48.2255 - val_nu_mass_loss: 0.0148
# Epoch 108/1024
# Epoch 107; Mass loss: 0.0150
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 35.9859 - fused_output_loss: 48.1853 - higgs_mass_loss: 83.0943 - loss: 96.5056 - mae_loss: 48.3202 - nu_mass_loss: 0.0150 - val_dinu_pt_loss: 35.2228 - val_fused_output_loss: 47.7680 - val_higgs_mass_loss: 82.8479 - val_loss: 95.7365 - val_mae_loss: 47.9684 - val_nu_mass_loss: 0.0148
# Epoch 109/1024
# Epoch 108; Mass loss: 0.0150
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 35.7196 - fused_output_loss: 47.9175 - higgs_mass_loss: 82.5350 - loss: 95.9769 - mae_loss: 48.0593 - nu_mass_loss: 0.0150 - val_dinu_pt_loss: 34.9584 - val_fused_output_loss: 47.5003 - val_higgs_mass_loss: 82.2875 - val_loss: 95.2118 - val_mae_loss: 47.7116 - val_nu_mass_loss: 0.0149
# Epoch 110/1024
# Epoch 109; Mass loss: 0.0150
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 35.4562 - fused_output_loss: 47.6497 - higgs_mass_loss: 81.9709 - loss: 95.4497 - mae_loss: 47.7999 - nu_mass_loss: 0.0150 - val_dinu_pt_loss: 34.6670 - val_fused_output_loss: 47.2314 - val_higgs_mass_loss: 81.7339 - val_loss: 94.6800 - val_mae_loss: 47.4485 - val_nu_mass_loss: 0.0149
# Epoch 111/1024
# Epoch 110; Mass loss: 0.0150
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 35.1862 - fused_output_loss: 47.3823 - higgs_mass_loss: 81.3902 - loss: 94.9237 - mae_loss: 47.5415 - nu_mass_loss: 0.0150 - val_dinu_pt_loss: 34.4023 - val_fused_output_loss: 46.9697 - val_higgs_mass_loss: 81.1593 - val_loss: 94.1640 - val_mae_loss: 47.1943 - val_nu_mass_loss: 0.0149
# Epoch 112/1024
# Epoch 111; Mass loss: 0.0151
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 34.9348 - fused_output_loss: 47.1147 - higgs_mass_loss: 80.8007 - loss: 94.3977 - mae_loss: 47.2830 - nu_mass_loss: 0.0151 - val_dinu_pt_loss: 34.1391 - val_fused_output_loss: 46.6959 - val_higgs_mass_loss: 80.5605 - val_loss: 93.6285 - val_mae_loss: 46.9326 - val_nu_mass_loss: 0.0149
# Epoch 113/1024
# Epoch 112; Mass loss: 0.0151
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 34.6654 - fused_output_loss: 46.8463 - higgs_mass_loss: 80.1972 - loss: 93.8693 - mae_loss: 47.0230 - nu_mass_loss: 0.0151 - val_dinu_pt_loss: 33.8508 - val_fused_output_loss: 46.4332 - val_higgs_mass_loss: 79.9612 - val_loss: 93.1100 - val_mae_loss: 46.6768 - val_nu_mass_loss: 0.0150
# Epoch 114/1024
# Epoch 113; Mass loss: 0.0151
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 34.4091 - fused_output_loss: 46.5783 - higgs_mass_loss: 79.5783 - loss: 93.3422 - mae_loss: 46.7639 - nu_mass_loss: 0.0151 - val_dinu_pt_loss: 33.5833 - val_fused_output_loss: 46.1655 - val_higgs_mass_loss: 79.3442 - val_loss: 92.5811 - val_mae_loss: 46.4156 - val_nu_mass_loss: 0.0150
# Epoch 115/1024
# Epoch 114; Mass loss: 0.0152
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 34.1523 - fused_output_loss: 46.3103 - higgs_mass_loss: 78.9599 - loss: 92.8159 - mae_loss: 46.5056 - nu_mass_loss: 0.0152 - val_dinu_pt_loss: 33.3282 - val_fused_output_loss: 45.8885 - val_higgs_mass_loss: 78.7220 - val_loss: 92.0405 - val_mae_loss: 46.1520 - val_nu_mass_loss: 0.0150
# Epoch 116/1024
# Epoch 115; Mass loss: 0.0152
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 33.9055 - fused_output_loss: 46.0428 - higgs_mass_loss: 78.3272 - loss: 92.2904 - mae_loss: 46.2477 - nu_mass_loss: 0.0152 - val_dinu_pt_loss: 33.0472 - val_fused_output_loss: 45.6251 - val_higgs_mass_loss: 78.1086 - val_loss: 91.5176 - val_mae_loss: 45.8924 - val_nu_mass_loss: 0.0150
# Epoch 117/1024
# Epoch 116; Mass loss: 0.0152
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 33.6439 - fused_output_loss: 45.7754 - higgs_mass_loss: 77.7049 - loss: 91.7653 - mae_loss: 45.9899 - nu_mass_loss: 0.0152 - val_dinu_pt_loss: 32.7896 - val_fused_output_loss: 45.3604 - val_higgs_mass_loss: 77.5146 - val_loss: 91.0056 - val_mae_loss: 45.6452 - val_nu_mass_loss: 0.0151
# Epoch 118/1024
# Epoch 117; Mass loss: 0.0152
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 33.3980 - fused_output_loss: 45.5079 - higgs_mass_loss: 77.0591 - loss: 91.2396 - mae_loss: 45.7317 - nu_mass_loss: 0.0152 - val_dinu_pt_loss: 32.5357 - val_fused_output_loss: 45.0897 - val_higgs_mass_loss: 76.8411 - val_loss: 90.4694 - val_mae_loss: 45.3798 - val_nu_mass_loss: 0.0151
# Epoch 119/1024
# Epoch 118; Mass loss: 0.0153
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 33.1352 - fused_output_loss: 45.2405 - higgs_mass_loss: 76.4152 - loss: 90.7149 - mae_loss: 45.4744 - nu_mass_loss: 0.0153 - val_dinu_pt_loss: 32.2507 - val_fused_output_loss: 44.8177 - val_higgs_mass_loss: 76.1951 - val_loss: 89.9305 - val_mae_loss: 45.1128 - val_nu_mass_loss: 0.0152
# Epoch 120/1024
# Epoch 119; Mass loss: 0.0153
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 32.8931 - fused_output_loss: 44.9739 - higgs_mass_loss: 75.7788 - loss: 90.1906 - mae_loss: 45.2166 - nu_mass_loss: 0.0153 - val_dinu_pt_loss: 32.0174 - val_fused_output_loss: 44.5584 - val_higgs_mass_loss: 75.6051 - val_loss: 89.4254 - val_mae_loss: 44.8671 - val_nu_mass_loss: 0.0152
# Epoch 121/1024
# Epoch 120; Mass loss: 0.0153
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 32.6528 - fused_output_loss: 44.7072 - higgs_mass_loss: 75.1424 - loss: 89.6666 - mae_loss: 44.9595 - nu_mass_loss: 0.0153 - val_dinu_pt_loss: 31.7609 - val_fused_output_loss: 44.2872 - val_higgs_mass_loss: 74.9578 - val_loss: 88.8861 - val_mae_loss: 44.5989 - val_nu_mass_loss: 0.0152
# Epoch 122/1024
# Epoch 121; Mass loss: 0.0153
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 32.4078 - fused_output_loss: 44.4435 - higgs_mass_loss: 74.5069 - loss: 89.1479 - mae_loss: 44.7044 - nu_mass_loss: 0.0153 - val_dinu_pt_loss: 31.4651 - val_fused_output_loss: 44.0188 - val_higgs_mass_loss: 74.3789 - val_loss: 88.3570 - val_mae_loss: 44.3383 - val_nu_mass_loss: 0.0152
# Epoch 123/1024
# Epoch 122; Mass loss: 0.0154
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 32.1634 - fused_output_loss: 44.1794 - higgs_mass_loss: 73.8893 - loss: 88.6285 - mae_loss: 44.4491 - nu_mass_loss: 0.0154 - val_dinu_pt_loss: 31.2530 - val_fused_output_loss: 43.7500 - val_higgs_mass_loss: 73.7515 - val_loss: 87.8253 - val_mae_loss: 44.0752 - val_nu_mass_loss: 0.0152
# Epoch 124/1024
# Epoch 123; Mass loss: 0.0154
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 31.9216 - fused_output_loss: 43.9157 - higgs_mass_loss: 73.2942 - loss: 88.1094 - mae_loss: 44.1937 - nu_mass_loss: 0.0154 - val_dinu_pt_loss: 30.9440 - val_fused_output_loss: 43.4886 - val_higgs_mass_loss: 73.1745 - val_loss: 87.3131 - val_mae_loss: 43.8245 - val_nu_mass_loss: 0.0152
# Epoch 125/1024
# Epoch 124; Mass loss: 0.0154
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 31.6835 - fused_output_loss: 43.6518 - higgs_mass_loss: 72.7110 - loss: 87.5912 - mae_loss: 43.9394 - nu_mass_loss: 0.0154 - val_dinu_pt_loss: 30.6957 - val_fused_output_loss: 43.2296 - val_higgs_mass_loss: 72.6178 - val_loss: 86.8022 - val_mae_loss: 43.5726 - val_nu_mass_loss: 0.0153
# Epoch 126/1024
# Epoch 125; Mass loss: 0.0155
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 31.4359 - fused_output_loss: 43.3892 - higgs_mass_loss: 72.1632 - loss: 87.0750 - mae_loss: 43.6857 - nu_mass_loss: 0.0155 - val_dinu_pt_loss: 30.4408 - val_fused_output_loss: 42.9631 - val_higgs_mass_loss: 72.0465 - val_loss: 86.2743 - val_mae_loss: 43.3112 - val_nu_mass_loss: 0.0153
# Epoch 127/1024
# Epoch 126; Mass loss: 0.0155
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 31.1926 - fused_output_loss: 43.1297 - higgs_mass_loss: 71.6397 - loss: 86.5654 - mae_loss: 43.4356 - nu_mass_loss: 0.0155 - val_dinu_pt_loss: 30.2136 - val_fused_output_loss: 42.7050 - val_higgs_mass_loss: 71.5743 - val_loss: 85.7643 - val_mae_loss: 43.0592 - val_nu_mass_loss: 0.0154
# Epoch 128/1024
# ...
# Epoch 669; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.5175 - fused_output_loss: 24.9606 - higgs_mass_loss: 13.8001 - loss: 49.9748 - mae_loss: 25.0143 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8961 - val_fused_output_loss: 24.4606 - val_higgs_mass_loss: 12.2216 - val_loss: 48.9550 - val_mae_loss: 24.4944 - val_nu_mass_loss: 0.0166
# Epoch 671/1024
# Epoch 670; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.5060 - fused_output_loss: 24.9579 - higgs_mass_loss: 13.8213 - loss: 49.9684 - mae_loss: 25.0105 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8787 - val_fused_output_loss: 24.4601 - val_higgs_mass_loss: 12.1968 - val_loss: 48.9541 - val_mae_loss: 24.4940 - val_nu_mass_loss: 0.0167
# Epoch 672/1024
# Epoch 671; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.5125 - fused_output_loss: 24.9553 - higgs_mass_loss: 13.7924 - loss: 49.9644 - mae_loss: 25.0090 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.9169 - val_fused_output_loss: 24.4590 - val_higgs_mass_loss: 12.1551 - val_loss: 48.9515 - val_mae_loss: 24.4925 - val_nu_mass_loss: 0.0166
# Epoch 673/1024
# Epoch 672; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.5134 - fused_output_loss: 24.9558 - higgs_mass_loss: 13.7534 - loss: 49.9662 - mae_loss: 25.0104 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8765 - val_fused_output_loss: 24.4590 - val_higgs_mass_loss: 12.1443 - val_loss: 48.9516 - val_mae_loss: 24.4926 - val_nu_mass_loss: 0.0167
# Epoch 674/1024
# Epoch 673; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.5036 - fused_output_loss: 24.9578 - higgs_mass_loss: 13.7478 - loss: 49.9688 - mae_loss: 25.0111 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8940 - val_fused_output_loss: 24.4561 - val_higgs_mass_loss: 12.1598 - val_loss: 48.9454 - val_mae_loss: 24.4893 - val_nu_mass_loss: 0.0167
# Epoch 675/1024
# Epoch 674; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.5065 - fused_output_loss: 24.9530 - higgs_mass_loss: 13.7462 - loss: 49.9601 - mae_loss: 25.0070 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8874 - val_fused_output_loss: 24.4559 - val_higgs_mass_loss: 12.1436 - val_loss: 48.9444 - val_mae_loss: 24.4884 - val_nu_mass_loss: 0.0167
# Epoch 676/1024
# Epoch 675; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.5143 - fused_output_loss: 24.9546 - higgs_mass_loss: 13.7268 - loss: 49.9631 - mae_loss: 25.0086 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.9093 - val_fused_output_loss: 24.4549 - val_higgs_mass_loss: 12.1163 - val_loss: 48.9423 - val_mae_loss: 24.4874 - val_nu_mass_loss: 0.0168
# Epoch 677/1024
# Epoch 676; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.5020 - fused_output_loss: 24.9495 - higgs_mass_loss: 13.7108 - loss: 49.9511 - mae_loss: 25.0016 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8717 - val_fused_output_loss: 24.4538 - val_higgs_mass_loss: 12.0783 - val_loss: 48.9405 - val_mae_loss: 24.4866 - val_nu_mass_loss: 0.0166
# Epoch 678/1024
# Epoch 677; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4945 - fused_output_loss: 24.9481 - higgs_mass_loss: 13.7158 - loss: 49.9498 - mae_loss: 25.0018 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8710 - val_fused_output_loss: 24.4519 - val_higgs_mass_loss: 12.1247 - val_loss: 48.9354 - val_mae_loss: 24.4835 - val_nu_mass_loss: 0.0167
# Epoch 679/1024
# Epoch 678; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4862 - fused_output_loss: 24.9502 - higgs_mass_loss: 13.7193 - loss: 49.9512 - mae_loss: 25.0010 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8674 - val_fused_output_loss: 24.4511 - val_higgs_mass_loss: 12.1168 - val_loss: 48.9342 - val_mae_loss: 24.4831 - val_nu_mass_loss: 0.0166
# Epoch 680/1024
# Epoch 679; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4951 - fused_output_loss: 24.9468 - higgs_mass_loss: 13.7213 - loss: 49.9447 - mae_loss: 24.9978 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8807 - val_fused_output_loss: 24.4509 - val_higgs_mass_loss: 12.0936 - val_loss: 48.9338 - val_mae_loss: 24.4829 - val_nu_mass_loss: 0.0167
# Epoch 681/1024
# Epoch 680; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4902 - fused_output_loss: 24.9450 - higgs_mass_loss: 13.6888 - loss: 49.9421 - mae_loss: 24.9971 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8830 - val_fused_output_loss: 24.4493 - val_higgs_mass_loss: 12.0705 - val_loss: 48.9291 - val_mae_loss: 24.4798 - val_nu_mass_loss: 0.0166
# Epoch 682/1024
# Epoch 681; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4982 - fused_output_loss: 24.9444 - higgs_mass_loss: 13.6821 - loss: 49.9407 - mae_loss: 24.9963 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8389 - val_fused_output_loss: 24.4489 - val_higgs_mass_loss: 12.1063 - val_loss: 48.9283 - val_mae_loss: 24.4794 - val_nu_mass_loss: 0.0167
# Epoch 683/1024
# Epoch 682; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4699 - fused_output_loss: 24.9442 - higgs_mass_loss: 13.6797 - loss: 49.9400 - mae_loss: 24.9957 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.9151 - val_fused_output_loss: 24.4479 - val_higgs_mass_loss: 12.0859 - val_loss: 48.9264 - val_mae_loss: 24.4785 - val_nu_mass_loss: 0.0166
# Epoch 684/1024
# Epoch 683; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4777 - fused_output_loss: 24.9424 - higgs_mass_loss: 13.6767 - loss: 49.9335 - mae_loss: 24.9912 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8856 - val_fused_output_loss: 24.4465 - val_higgs_mass_loss: 12.0495 - val_loss: 48.9229 - val_mae_loss: 24.4764 - val_nu_mass_loss: 0.0167
# Epoch 685/1024
# Epoch 684; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4829 - fused_output_loss: 24.9453 - higgs_mass_loss: 13.6874 - loss: 49.9418 - mae_loss: 24.9966 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8900 - val_fused_output_loss: 24.4458 - val_higgs_mass_loss: 12.0464 - val_loss: 48.9219 - val_mae_loss: 24.4761 - val_nu_mass_loss: 0.0166
# Epoch 686/1024
# Epoch 685; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4643 - fused_output_loss: 24.9401 - higgs_mass_loss: 13.6471 - loss: 49.9294 - mae_loss: 24.9893 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8731 - val_fused_output_loss: 24.4458 - val_higgs_mass_loss: 12.0438 - val_loss: 48.9212 - val_mae_loss: 24.4754 - val_nu_mass_loss: 0.0167
# Epoch 687/1024
# Epoch 686; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4795 - fused_output_loss: 24.9403 - higgs_mass_loss: 13.6589 - loss: 49.9291 - mae_loss: 24.9889 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8388 - val_fused_output_loss: 24.4437 - val_higgs_mass_loss: 12.0071 - val_loss: 48.9162 - val_mae_loss: 24.4726 - val_nu_mass_loss: 0.0167
# Epoch 688/1024
# Epoch 687; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4563 - fused_output_loss: 24.9358 - higgs_mass_loss: 13.6308 - loss: 49.9211 - mae_loss: 24.9853 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8384 - val_fused_output_loss: 24.4424 - val_higgs_mass_loss: 12.0028 - val_loss: 48.9140 - val_mae_loss: 24.4716 - val_nu_mass_loss: 0.0167
# Epoch 689/1024
# Epoch 688; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4538 - fused_output_loss: 24.9354 - higgs_mass_loss: 13.6201 - loss: 49.9185 - mae_loss: 24.9831 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8438 - val_fused_output_loss: 24.4406 - val_higgs_mass_loss: 11.9987 - val_loss: 48.9102 - val_mae_loss: 24.4696 - val_nu_mass_loss: 0.0167
# Epoch 690/1024
# Epoch 689; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4497 - fused_output_loss: 24.9340 - higgs_mass_loss: 13.6101 - loss: 49.9158 - mae_loss: 24.9818 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8337 - val_fused_output_loss: 24.4402 - val_higgs_mass_loss: 11.9594 - val_loss: 48.9088 - val_mae_loss: 24.4686 - val_nu_mass_loss: 0.0166
# Epoch 691/1024
# Epoch 690; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4472 - fused_output_loss: 24.9314 - higgs_mass_loss: 13.6062 - loss: 49.9123 - mae_loss: 24.9809 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8414 - val_fused_output_loss: 24.4396 - val_higgs_mass_loss: 12.0049 - val_loss: 48.9079 - val_mae_loss: 24.4683 - val_nu_mass_loss: 0.0167
# Epoch 692/1024
# Epoch 691; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4522 - fused_output_loss: 24.9308 - higgs_mass_loss: 13.5949 - loss: 49.9098 - mae_loss: 24.9791 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8665 - val_fused_output_loss: 24.4376 - val_higgs_mass_loss: 11.9758 - val_loss: 48.9036 - val_mae_loss: 24.4660 - val_nu_mass_loss: 0.0167
# Epoch 693/1024
# Epoch 692; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4563 - fused_output_loss: 24.9314 - higgs_mass_loss: 13.5991 - loss: 49.9095 - mae_loss: 24.9782 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8482 - val_fused_output_loss: 24.4374 - val_higgs_mass_loss: 11.9390 - val_loss: 48.9036 - val_mae_loss: 24.4662 - val_nu_mass_loss: 0.0167
# Epoch 694/1024
# Epoch 693; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4531 - fused_output_loss: 24.9292 - higgs_mass_loss: 13.5965 - loss: 49.9043 - mae_loss: 24.9751 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8581 - val_fused_output_loss: 24.4365 - val_higgs_mass_loss: 11.9389 - val_loss: 48.9000 - val_mae_loss: 24.4635 - val_nu_mass_loss: 0.0167
# Epoch 695/1024
# Epoch 694; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4367 - fused_output_loss: 24.9297 - higgs_mass_loss: 13.5793 - loss: 49.9058 - mae_loss: 24.9761 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8371 - val_fused_output_loss: 24.4353 - val_higgs_mass_loss: 11.9443 - val_loss: 48.8980 - val_mae_loss: 24.4626 - val_nu_mass_loss: 0.0167
# Epoch 696/1024
# Epoch 695; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4408 - fused_output_loss: 24.9298 - higgs_mass_loss: 13.5544 - loss: 49.9069 - mae_loss: 24.9772 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8553 - val_fused_output_loss: 24.4342 - val_higgs_mass_loss: 11.9303 - val_loss: 48.8953 - val_mae_loss: 24.4611 - val_nu_mass_loss: 0.0167
# Epoch 697/1024
# Epoch 696; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4431 - fused_output_loss: 24.9266 - higgs_mass_loss: 13.5441 - loss: 49.8988 - mae_loss: 24.9722 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8402 - val_fused_output_loss: 24.4325 - val_higgs_mass_loss: 11.8835 - val_loss: 48.8926 - val_mae_loss: 24.4601 - val_nu_mass_loss: 0.0166
# Epoch 698/1024
# Epoch 697; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4361 - fused_output_loss: 24.9245 - higgs_mass_loss: 13.5385 - loss: 49.8959 - mae_loss: 24.9713 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8331 - val_fused_output_loss: 24.4335 - val_higgs_mass_loss: 11.9364 - val_loss: 48.8947 - val_mae_loss: 24.4612 - val_nu_mass_loss: 0.0166
# Epoch 699/1024
# Epoch 698; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4275 - fused_output_loss: 24.9227 - higgs_mass_loss: 13.5446 - loss: 49.8912 - mae_loss: 24.9684 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8499 - val_fused_output_loss: 24.4317 - val_higgs_mass_loss: 11.9159 - val_loss: 48.8899 - val_mae_loss: 24.4582 - val_nu_mass_loss: 0.0166
# Epoch 700/1024
# Epoch 699; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4240 - fused_output_loss: 24.9225 - higgs_mass_loss: 13.5497 - loss: 49.8900 - mae_loss: 24.9675 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8079 - val_fused_output_loss: 24.4298 - val_higgs_mass_loss: 11.9146 - val_loss: 48.8871 - val_mae_loss: 24.4573 - val_nu_mass_loss: 0.0167
# Epoch 701/1024
# Epoch 700; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4266 - fused_output_loss: 24.9211 - higgs_mass_loss: 13.5307 - loss: 49.8886 - mae_loss: 24.9675 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8329 - val_fused_output_loss: 24.4294 - val_higgs_mass_loss: 11.8846 - val_loss: 48.8851 - val_mae_loss: 24.4556 - val_nu_mass_loss: 0.0167
# Epoch 702/1024
# Epoch 701; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4289 - fused_output_loss: 24.9234 - higgs_mass_loss: 13.5183 - loss: 49.8923 - mae_loss: 24.9690 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8369 - val_fused_output_loss: 24.4283 - val_higgs_mass_loss: 11.8513 - val_loss: 48.8820 - val_mae_loss: 24.4537 - val_nu_mass_loss: 0.0167
# Epoch 703/1024
# Epoch 702; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4275 - fused_output_loss: 24.9211 - higgs_mass_loss: 13.4873 - loss: 49.8867 - mae_loss: 24.9656 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8395 - val_fused_output_loss: 24.4284 - val_higgs_mass_loss: 11.8650 - val_loss: 48.8826 - val_mae_loss: 24.4542 - val_nu_mass_loss: 0.0166
# Epoch 704/1024
# Epoch 703; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4175 - fused_output_loss: 24.9182 - higgs_mass_loss: 13.4718 - loss: 49.8825 - mae_loss: 24.9642 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8435 - val_fused_output_loss: 24.4273 - val_higgs_mass_loss: 11.8587 - val_loss: 48.8809 - val_mae_loss: 24.4536 - val_nu_mass_loss: 0.0167
# Epoch 705/1024
# Epoch 704; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4310 - fused_output_loss: 24.9169 - higgs_mass_loss: 13.4960 - loss: 49.8788 - mae_loss: 24.9620 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8226 - val_fused_output_loss: 24.4261 - val_higgs_mass_loss: 11.8140 - val_loss: 48.8775 - val_mae_loss: 24.4515 - val_nu_mass_loss: 0.0167
# Epoch 706/1024
# Epoch 705; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4236 - fused_output_loss: 24.9164 - higgs_mass_loss: 13.4782 - loss: 49.8767 - mae_loss: 24.9602 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8272 - val_fused_output_loss: 24.4241 - val_higgs_mass_loss: 11.8004 - val_loss: 48.8740 - val_mae_loss: 24.4498 - val_nu_mass_loss: 0.0166
# Epoch 707/1024
# Epoch 706; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4246 - fused_output_loss: 24.9138 - higgs_mass_loss: 13.4781 - loss: 49.8702 - mae_loss: 24.9565 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8289 - val_fused_output_loss: 24.4255 - val_higgs_mass_loss: 11.8171 - val_loss: 48.8760 - val_mae_loss: 24.4505 - val_nu_mass_loss: 0.0167
# Epoch 708/1024
# Epoch 707; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4106 - fused_output_loss: 24.9136 - higgs_mass_loss: 13.4639 - loss: 49.8725 - mae_loss: 24.9589 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8121 - val_fused_output_loss: 24.4230 - val_higgs_mass_loss: 11.7741 - val_loss: 48.8713 - val_mae_loss: 24.4482 - val_nu_mass_loss: 0.0167
# Epoch 709/1024
# Epoch 708; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4217 - fused_output_loss: 24.9115 - higgs_mass_loss: 13.4390 - loss: 49.8666 - mae_loss: 24.9551 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8260 - val_fused_output_loss: 24.4226 - val_higgs_mass_loss: 11.7650 - val_loss: 48.8698 - val_mae_loss: 24.4472 - val_nu_mass_loss: 0.0166
# Epoch 710/1024
# Epoch 709; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4204 - fused_output_loss: 24.9133 - higgs_mass_loss: 13.4493 - loss: 49.8694 - mae_loss: 24.9561 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8166 - val_fused_output_loss: 24.4215 - val_higgs_mass_loss: 11.7657 - val_loss: 48.8671 - val_mae_loss: 24.4456 - val_nu_mass_loss: 0.0167
# Epoch 711/1024
# Epoch 710; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4113 - fused_output_loss: 24.9068 - higgs_mass_loss: 13.4263 - loss: 49.8576 - mae_loss: 24.9508 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8057 - val_fused_output_loss: 24.4195 - val_higgs_mass_loss: 11.7635 - val_loss: 48.8638 - val_mae_loss: 24.4442 - val_nu_mass_loss: 0.0167
# Epoch 712/1024
# Epoch 711; Mass loss: 0.0169
# 1330/1330 - 4s - 3ms/step - dinu_pt_loss: 17.4037 - fused_output_loss: 24.9112 - higgs_mass_loss: 13.4313 - loss: 49.8648 - mae_loss: 24.9536 - nu_mass_loss: 0.0169 - val_dinu_pt_loss: 14.8111 - val_fused_output_loss: 24.4192 - val_higgs_mass_loss: 11.7369 - val_loss: 48.8624 - val_mae_loss: 24.4432 - val_nu_mass_loss: 0.0166
# Epoch 713/1024

# %%
# Make a directory
dir_name = HOME_PATH + "/10th_trial/ww_resregressor_result/" 
savedmodel_path = dir_name + "saved_model"
name = "ww_resregressor"

# If the directory exists
if os.path.exists(dir_name):
    test_files = glob.glob(dir_name + "*" + name + "*")
    if test_files:
        for file in test_files:
            os.remove(file)
        print(f"Directory {dir_name} cleaned.")
    print(f"Directory {dir_name} exists.")
else:
    os.makedirs(dir_name)
    print(f"Directory {dir_name} created.")

# save modela
model.save(dir_name + name + ".keras", save_format="keras", overwrite=True)
tf.saved_model.save(model, savedmodel_path) # save model in saved_model format --> use in the onnx 

# predict
pred_y = model.predict(test_x)
# save predicted results
np.savez_compressed(dir_name + name + "_data.npz", pred_y=pred_y, test_y=test_y)
sig_pred = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth = np.load(dir_name + name + "_data.npz")["test_y"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Make a directory
# ----> 2 dir_name = HOME_PATH + "/10th_trial/ww_resregressor_result/"
#       3 savedmodel_path = dir_name + "saved_model"
#       4 name = "ww_resregressor"
#
# NameError: name 'HOME_PATH' is not defined

# %%
# Extract loss values
loss = history.history["loss"]
val_loss = history.history["val_loss"]
mae_loss = history.history["mae_loss"]
val_mae_loss = history.history["val_mae_loss"]
higgs_mass_loss = history.history["higgs_mass_loss"]
val_higgs_mass_loss = history.history["val_higgs_mass_loss"]
dinu_pt_loss = history.history["dinu_pt_loss"]
val_dinu_pt_loss = history.history["val_dinu_pt_loss"]
fused_output_loss = history.history["fused_output_loss"]
val_fused_output_loss = history.history["val_fused_output_loss"]
nu_mass_loss = history.history["nu_mass_loss"]
val_nu_mass_loss = history.history["val_nu_mass_loss"]

# Print the losses
print(f"dinu_pt_loss: {dinu_pt_loss[-1]:.4f}")
print(f"fused_output_loss: {fused_output_loss[-1]:.4f}")
print(f"higgs_mass_loss: {higgs_mass_loss[-1]:.4f}")
print(f"loss: {loss[-1]:.4f}")
print(f"mae_loss: {mae_loss[-1]:.4f}")
print(f"nu_mass_loss: {nu_mass_loss[-1]:.4f}")
print(f"val_dinu_pt_loss: {val_dinu_pt_loss[-1]:.4f}")
print(f"val_fused_output_loss: {val_fused_output_loss[-1]:.4f}")
print(f"val_higgs_mass_loss: {val_higgs_mass_loss[-1]:.4f}")
print(f"val_loss: {val_loss[-1]:.4f}")
print(f"val_mae_loss: {val_mae_loss[-1]:.4f}")
print(f"val_nu_mass_loss: {val_nu_mass_loss[-1]:.4f}")

# 1) Plot combined training and validation loss
plt.figure(figsize=(5, 4))
plt.plot(loss, label="Training Loss")
plt.plot(val_loss, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Combined Loss")
plt.legend()
plt.grid(False)
plt.show()

# 2) Plot mae training and validation loss
plt.figure(figsize=(5, 4))
plt.plot(mae_loss, label="Training MAE Loss")
plt.plot(val_mae_loss, label="Validation MAE Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("MAE Loss")
plt.legend()
plt.grid(False)
plt.show()

# 3) Plot higgs mass training and validation loss
plt.figure(figsize=(5, 4))
plt.plot(higgs_mass_loss, label="Training Higgs Mass Loss")
plt.plot(val_higgs_mass_loss, label="Validation Higgs Mass Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Higgs Mass Loss")
plt.legend()
plt.grid(False)
plt.show()

# 4) Plot dinu pt loss
plt.figure(figsize=(5, 4))
plt.plot(dinu_pt_loss, label="Training Dinu PT Loss")
plt.plot(val_dinu_pt_loss, label="Validation Dinu PT Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Dinu Pt Loss")
plt.legend()
plt.grid(False)
plt.show()

# 5) Plot fused output loss
plt.figure(figsize=(5, 4))
plt.plot(fused_output_loss, label="Training Fused Output Loss")
plt.plot(val_fused_output_loss, label="Validation Fused Output Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Fused Output Loss")
plt.legend()
plt.grid(False)
plt.show()

# 6) Plot nu mass loss
plt.figure(figsize=(5, 4))
plt.plot(nu_mass_loss, label="Training Nu Mass Loss")
plt.plot(val_nu_mass_loss, label="Validation Nu Mass Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Nu Mass Loss")
plt.legend()
plt.grid(False)
plt.show()
# Out:
# dinu_pt_loss: 18.6975
# fused_output_loss: 20.7928
# higgs_mass_loss: 15.5198
# loss: 125.0097
# mae_loss: 38.7795
# nu_mass_loss: 6.1177
# val_dinu_pt_loss: 16.8045
# val_fused_output_loss: 25.7985
# val_higgs_mass_loss: 11.5791
# val_loss: 146.0984
# val_mae_loss: 40.2166
# val_nu_mass_loss: 5.3755

# %%
# save predicted results
np.savez_compressed(
    dir_name + name + "_data.npz",
    pred_y=sig_pred[0].reshape(sig_truth.shape),
    test_y=sig_truth,
)
sig_pred_inv = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth_inv = np.load(dir_name + name + "_data.npz")["test_y"]

# %%
# neutrino mass checking
nu0_4vect = sig_pred_inv[:, :4] - test_x[:, :4]
nu1_4vect = sig_pred_inv[:, 4:8] - test_x[:, 4:8]
nu0_mass_squared = np.square(nu0_4vect[:, 3]) - np.square(nu0_4vect[:, 0]) - np.square(nu0_4vect[:, 1]) - np.square(nu0_4vect[:, 2])
nu1_mass_squared = np.square(nu1_4vect[:, 3]) - np.square(nu1_4vect[:, 0]) - np.square(nu1_4vect[:, 1]) - np.square(nu1_4vect[:, 2])
# nu0_mass_squared
plt.hist(nu0_mass_squared, bins=100, histtype="step", label="nu0_mass_squared")
plt.hist(nu1_mass_squared, bins=100, histtype="step", label="nu1_mass_squared")
plt.semilogx()
plt.semilogy()
plt.legend()
plt.show()

print("nu0_mass_squared avg:", np.mean(nu0_mass_squared))
print("nu1_mass_squared avg:", np.mean(nu1_mass_squared))
# plt.hist(nu1_mass_squared, bins=100, range=(0, 100), histtype="step", label="nu1_mass_squared")
# Out:
# nu0_mass_squared avg: 906.7118101582845
# nu1_mass_squared avg: 551.7872783463921

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,0]):.3f}, std: {np.std(sig_truth_inv[:,0]):.3f}, min: {np.min(sig_truth_inv[:,0]):.3f}, max: {np.max(sig_truth_inv[:,0]):.3f}"
)

set_range = [-200, 200]

plot.hist_1d(
    sig_truth_inv[:,0], sig_pred_inv[:,0],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,0], sig_pred_inv[:,0], sample_weight=None)):.3f}",
    xlabel="$W^{0}\ p_{x}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,0], sig_pred_inv[:,0],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,0], sig_pred_inv[:,0]):.3f}",
    xlabel="True $W^{0}\ p_{x}$ [GeV]",
    ylabel="Predicted $W^{0}\ p_{x}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 0.031, std: 39.544, min: -585.857, max: 803.254

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,4]):.3f}, std: {np.std(sig_truth_inv[:,4]):.3f}, min: {np.min(sig_truth_inv[:,4]):.3f}, max: {np.max(sig_truth_inv[:,4]):.3f}"
)

set_range = [-200, 200]


plot.hist_1d(
    sig_truth_inv[:,4], sig_pred_inv[:,4],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,4], sig_pred_inv[:,4], sample_weight=None)):.3f}",
    xlabel="$W^{1}\ p_{x}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,4], sig_pred_inv[:,4],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,4], sig_pred_inv[:,4]):.3f}",
    xlabel="True $W^{1}\ p_{x}$ [GeV]",
    ylabel="Predicted $W^{1}\ p_{x}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: -0.124, std: 27.801, min: -399.814, max: 373.865

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,1]):.3f}, std: {np.std(sig_truth_inv[:,1]):.3f}, min: {np.min(sig_truth_inv[:,1]):.3f}, max: {np.max(sig_truth_inv[:,1]):.3f}"
)

set_range = [-200, 200]

plot.hist_1d(
    sig_truth_inv[:,1], sig_pred_inv[:,1],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,1], sig_pred_inv[:,1], sample_weight=None)):.3f}",
    xlabel="$W^{0}\ p_{y}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,1], sig_pred_inv[:,1],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,1], sig_pred_inv[:,1]):.3f}",
    xlabel="True $W^{0}\ p_{y}$ [GeV]",
    ylabel="Predicted $W^{0}\ p_{y}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: -0.013, std: 39.620, min: -755.579, max: 609.143

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,5]):.3f}, std: {np.std(sig_truth_inv[:,5]):.3f}, min: {np.min(sig_truth_inv[:,5]):.3f}, max: {np.max(sig_truth_inv[:,5]):.3f}"
)

set_range = [-200, 200]

plot.hist_1d(
    sig_truth_inv[:,5], sig_pred_inv[:,5],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,5], sig_pred_inv[:,5], sample_weight=None)):.3f}",
    xlabel="$W^{1}\ p_{y}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,5], sig_pred_inv[:,5],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,5], sig_pred_inv[:,5]):.3f}",
    xlabel="True $W^{1}\ p_{y}$ [GeV]",
    ylabel="Predicted $W^{1}\ p_{y}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 0.031, std: 27.968, min: -417.838, max: 580.447

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,2]):.3f}, std: {np.std(sig_truth_inv[:,2]):.3f}, min: {np.min(sig_truth_inv[:,2]):.3f}, max: {np.max(sig_truth_inv[:,2]):.3f}"
)

set_range = [-700, 700]

plot.hist_1d(
    sig_truth_inv[:,2], sig_pred_inv[:,2],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,2], sig_pred_inv[:,2], sample_weight=None)):.3f}",
    xlabel="$W^{0}\ p_{z}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,2], sig_pred_inv[:,2],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,2], sig_pred_inv[:,2]):.3f}",
    xlabel="$W^{0}\ p_{z}$ [GeV]",
    ylabel="Predicted $W^{0}\ p_{z}$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 0.308, std: 170.752, min: -1446.473, max: 1754.351

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,6]):.3f}, std: {np.std(sig_truth_inv[:,6]):.3f}, min: {np.min(sig_truth_inv[:,6]):.3f}, max: {np.max(sig_truth_inv[:,6]):.3f}"
)

set_range = [-600, 600]

plot.hist_1d(
    sig_truth_inv[:,6], sig_pred_inv[:,6],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,6], sig_pred_inv[:,6], sample_weight=None)):.3f}",
    xlabel="$W^{1}\ p_{z}$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,6], sig_pred_inv[:,6],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,6], sig_pred_inv[:,6]):.3f}",
    xlabel="True $W^{1}\ p_{z}$ [GeV]",
    ylabel="Predicted $W^{1}\ p_{z}$ [GeV]",
    ranges=set_range
)
# Out:
# Truth mean: -0.337, std: 110.947, min: -1170.774, max: 1427.069

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,3]):.3f}, std: {np.std(sig_truth_inv[:,3]):.3f}, min: {np.min(sig_truth_inv[:,3]):.3f}, max: {np.max(sig_truth_inv[:,3]):.3f}"
)

set_range = [0, 800]

plot.hist_1d(
    sig_truth_inv[:,3], sig_pred_inv[:,3],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,3], sig_pred_inv[:,3], sample_weight=None)):.3f}",
    xlabel="$W^{0}\ E$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,3], sig_pred_inv[:,3],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,3], sig_pred_inv[:,3]):.3f}",
    xlabel="True $W^{0}\ E$ [GeV]",
    ylabel="Predicted $W^{0}\ E$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 158.446, std: 111.648, min: 21.707, max: 1791.292

# %%
print(
    f"True mean: {np.mean(sig_truth_inv[:,7]):.3f}, std: {np.std(sig_truth_inv[:,7]):.3f}, min: {np.min(sig_truth_inv[:,7]):.3f}, max: {np.max(sig_truth_inv[:,7]):.3f}"
)

set_range = [0, 800]

plot.hist_1d(
    sig_truth_inv[:,7], sig_pred_inv[:,7],
    title=f"RMSE = {np.sqrt(mean_squared_error(sig_truth_inv[:,7], sig_pred_inv[:,7], sample_weight=None)):.3f}",
    xlabel="$W^{1}\ E$ [GeV]",
    ranges=set_range
)

plot.hist_2d(
    sig_truth_inv[:,7], sig_pred_inv[:,7],
    title=r"$R^{2}$ = " + f"{r2_score(sig_truth_inv[:,7], sig_pred_inv[:,7]):.3f}",
    xlabel="True $W^{1}\ E$ [GeV]",
    ylabel="Predicted $W^{1}\ E$ [GeV]",
    ranges=set_range
)
# Out:
# True mean: 98.991, std: 77.608, min: 17.001, max: 1443.825

# %%
lead_time_like = np.square(sig_pred_inv[:, 3]) - np.sum(
    np.square(sig_pred_inv[:, 0:3]), axis=1
)
lead_time_mask = (lead_time_like > 0) * 1
sublead_time_like = np.square(sig_pred_inv[:, 7]) - np.sum(
    np.square(sig_pred_inv[:, 4:7]), axis=1
)
sublead_time_mask = (sublead_time_like > 0) * 1

bin_edges = np.linspace(-5, 1.0e4, 51)
figure = plt.figure(figsize=(10, 8))
plt.hist(
    lead_time_like,
    bins=bin_edges,
    fill=False,
    color="orange",
    histtype="step",
    label=r"$W^{0}$, "
    + f"{100 * np.sum(lead_time_mask) / len(lead_time_mask):.2f} % TL",
    density=True,
    weights=None,
    linewidth=2,
)
plt.hist(
    sublead_time_like,
    bins=bin_edges,
    fill=False,
    color="tab:blue",
    histtype="step",
    label=r"$W^{1}$, "
    + f"{100 * np.sum(sublead_time_mask) / len(sublead_time_mask):.2f} % TL",
    density=True,
    weights=None,
    linewidth=2,
)
plt.hist(
    np.square(w_lead.m),
    bins=bin_edges,
    color="orange",
    fill=True,
    histtype="bar",
    alpha=0.5,
    label=r"$W_{label}^{0}$",
    density=True,
    # weights=mc_weight,
)
plt.hist(
    np.square(w_sublead.m),
    bins=bin_edges,
    color="tab:blue",
    fill=True,
    histtype="bar",
    alpha=0.5,
    label=r"$W_{label}^{1}$",
    density=True,
    # weights=mc_weight,
)
plt.vlines(0, 0, 2e-3, color="red", linestyle="--")
plt.xlim(-5e2, 1.2e4)
plt.ylim(0, 2e-3)
plt.xlabel(r"Mass$^{2}$ [GeV]$^{2}$", labelpad=20)
plt.ylabel("Normalized counts")
plt.legend(loc="upper right", prop={'size': 20})  # Adjust the size value as needed
plt.show()
print(f"m2 with {100 * np.sum(lead_time_mask * sublead_time_mask) / len(lead_time_mask):.2f} % time-like (TL) evts")
# Out:
# m2 with 97.07 % time-like (TL) evts

# %%
# TODO: 2d mass squared
pred_m2 = np.concatenate([lead_time_like, sublead_time_like], axis=-1)
truth_m2 = np.concatenate(
    [np.square(w_lead.m)[test_indices], np.square(w_sublead.m)[test_indices]], axis=-1
)

print(
    f"Truth mean: {np.mean(truth_m2):.3f}, std: {np.std(truth_m2):.3f}, min: {np.min(truth_m2):.3f}, max: {np.max(truth_m2):.3f}"
)

set_range = [-500, 10_500]


plot.hist_1d(
    truth_m2, pred_m2,
    title="",
    xlabel=r"$m_{W}^{2}$",
    xpad=25,
    ranges=set_range
)

plot.hist_2d(
    truth_m2, pred_m2,
    title="",
    xlabel="True $m_{W}^{2}$ [GeV]$^2$",
    ylabel="Predicted $m_{W}^{2}$ [GeV]$^2$",
    xpad=25,
    ranges=set_range
)
# Out:
# Truth mean: 3615.291, std: 2594.373, min: 4.010, max: 11077.988

# %%
# TODO: CGLMP

def Bij(particles):
    # Ensure ROOT is properly initialized
    ROOT.gROOT.SetBatch(True)

    def cglmp(z_xp, z_xn, z_yp, z_yn):
        """
        This is a function to calculate Bij (CGLMP values).
        :param z_xp: Angle (xi) between positive lepton and x-axis.
        :param z_xn: Angle (xi) between negative lepton and x-axis.
        :param z_yp: Angle (xi) between positive lepton and y-axis.
        :param z_xn: Angle (xi) between negative lepton and y-axis.
        """
        # count expectation value, use (27) in Alan's paper
        tr_a = (np.divide(8, np.sqrt(3))) * (z_xp * z_xn + z_yp * z_yn)
        tr_b = (
            25
            * (np.square(z_xp) - np.square(z_yp))
            * (np.square(z_xn) - np.square(z_yn))
        )
        tr_c = 100 * (z_xp * z_yp * z_xn * z_yn)
        tr = tr_a + tr_b + tr_c

        return tr

    WpBoson = TLorentzVector(*particles[:4])
    WpLepton = TLorentzVector(*particles[4:8])
    WnBoson = TLorentzVector(*particles[8:12])
    WnLepton = TLorentzVector(*particles[12:16])

    # construct Higgs 4-vector
    Higgs = WpBoson + WnBoson

    # construct a moving orthogonal basis (k,r,n)
    Beam_p = TLorentzVector(0, 0, 1, 1)  # spatial-axis

    # define boost vector
    Higgsb = Higgs.BoostVector()

    # (1) performs a boost transformation from the rod frame to the rawal one.
    # Perform boost transformation from the rod frame to the rawal one
    for vec in [WpBoson, WpLepton, WnBoson, WnLepton, Beam_p]:
        vec.Boost(-Higgsb)

    # 2. Define (k,r,n) -> definitions are in Alan's paper
    k_per = TVector3(WpBoson.X(), WpBoson.Y(), WpBoson.Z())
    p_per = TVector3(Beam_p.X(), Beam_p.Y(), Beam_p.Z())  # in the Higgs rest frame
    k = k_per.Unit()  # normalized -> unit vector
    p = p_per.Unit()
    y = p.Dot(k)
    r_length = np.sqrt(1 - y * y)
    r = (1 / r_length) * (p - y * k)
    n = (1 / r_length) * (p.Cross(k))  # (1/sin)*sin = 1 -> unit vector

    # 3. Further boost to W+ and W- frame respectively
    WpkBoost = WpBoson.BoostVector()
    WpBoson.Boost(-WpkBoost)
    WpLepton.Boost(-WpkBoost)
    WnkBoost = WnBoson.BoostVector()
    WnBoson.Boost(-WnkBoost)
    WnLepton.Boost(-WnkBoost)

    # 4. Map all particle to (k,r,n) frame
    WpLp = WpLepton.Vect()  # momentum in (k,r,n)
    WnLp = WnLepton.Vect()
    # Mapping to n-r-k basis
    WpLp_k = TLorentzVector(WpLp.Dot(n), WpLp.Dot(r), WpLp.Dot(k), WpLepton.E())
    WnLp_k = TLorentzVector(WnLp.Dot(n), WnLp.Dot(r), WnLp.Dot(k), WnLepton.E())

    # 5. Calculate directional cosines
    # directional cosine from Wp
    WpLp_Vect_Mag = WpLp_k.Vect().Mag()
    cos_n_join_p = np.divide(WpLp_k.X(), WpLp_Vect_Mag)
    cos_r_join_p = np.divide(WpLp_k.Y(), WpLp_Vect_Mag)
    cos_k_join_p = np.divide(WpLp_k.Z(), WpLp_Vect_Mag)
    # directional cosine from Wn
    WnLp_Vect_Mag = WnLp_k.Vect().Mag()
    cos_n_join_n = np.divide(WnLp_k.X(), WnLp_Vect_Mag)
    cos_r_join_n = np.divide(WnLp_k.Y(), WnLp_Vect_Mag)
    cos_k_join_n = np.divide(WnLp_k.Z(), WnLp_Vect_Mag)

    # 6. Calculate Bij (CGLMP values)
    B_xy = cglmp(cos_n_join_p, cos_n_join_n, cos_r_join_p, cos_r_join_n)
    B_yz = cglmp(cos_r_join_p, cos_r_join_n, cos_k_join_p, cos_k_join_n)
    B_zx = cglmp(cos_n_join_p, cos_n_join_n, cos_k_join_p, cos_k_join_n)

    return (
        np.array([B_xy, B_yz, B_zx]),
        np.array([cos_n_join_p, cos_r_join_p, cos_k_join_p]),
        np.array([cos_n_join_n, cos_r_join_n, cos_k_join_n]),
    )
    
def result_generator(particles):
    with multiprocessing.Pool(WORKERS) as pool:
        # Retrieve the output from the pool
        results = list(pool.map(Bij, particles))
    
    # Unpack the results
    bij, xi_p, xi_n = zip(*results)
    
    bij = np.vstack(bij)  # Flatten the nested array
    xi_p = np.vstack(xi_p)
    xi_n = np.vstack(xi_n)
    mask = np.any(np.isnan(bij), axis=1)
    return (
        bij[~mask, :],
        xi_p[~mask, :],
        xi_n[~mask, :],
    )

# %%
# reco
particles = np.concatenate(
    [
        sig_pred_inv[:, 0:4],
        lead_lep_p4[test_indices],
        sig_pred_inv[:, 4:8],
        sublead_lep_p4[test_indices],
    ],
    axis=1,
)
bij = result_generator(particles)[0][0:80_000,:]
xi_p = result_generator(particles)[1][0:80_000,:]
xi_n = result_generator(particles)[2][0:80_000,:]

# truth
particles = np.concatenate(
    [
        sig_truth_inv[:, 0:4],
        truth_lead_lep_p4[test_indices],
        sig_truth_inv[:, 4:8],
        truth_sublead_lep_p4[test_indices],
    ],
    axis=1,
)
truth_bij = result_generator(particles)[0][0:80_000,:]
truth_xi_p = result_generator(particles)[1][0:80_000,:]
truth_xi_n = result_generator(particles)[2][0:80_000,:]

# %%
print(
    f"True mean     : {np.mean(truth_bij[:,0]):.3f}, std: {np.std(truth_bij[:,0]):.3f}, min: {np.min(truth_bij[:,0]):.3f}, max: {np.max(truth_bij[:,0]):.3f}"
)
print(
    f"Predicted mean: {np.mean(bij[:,0]):.3f}, std: {np.std(bij[:,0]):.3f}, min: {np.min(bij[:,0]):.3f}, max: {np.max(bij[:,0]):.3f}"
)

set_range = [-30, 30]

plot.hist_1d(
    truth_bij[:,0], bij[:,0],
    title=rf"mean={np.mean(bij[:,0]):.2f}$\pm${sp.stats.sem(bij[:,0]):.3f}"
    + f" with truth: {np.mean(truth_bij[:,0]):.2f}$\pm${sp.stats.sem(truth_bij[:,0]):.3f}",
    xlabel=r"$B_{xy}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_bij[:,0], bij[:,0],
    title=r"$R^{2}$ = " + f"{r2_score(truth_bij[:,0], bij[:,0]):.3f}",
    xlabel="True $B_{{xy}}$ [None]",
    ylabel="Predicted $B_{{xy}}$ [None]",
    ranges=set_range
)
# Out:
# True mean     : 2.468, std: 12.019, min: -25.100, max: 29.607
# Predicted mean: 4.540, std: 8.757, min: -25.060, max: 29.476

# %%
print(
    f"True mean     : {np.mean(truth_bij[:,1]):.3f}, std: {np.std(truth_bij[:,1]):.3f}, min: {np.min(truth_bij[:,1]):.3f}, max: {np.max(truth_bij[:,1]):.3f}"
)
print(
    f"Predicted mean: {np.mean(bij[:,1]):.3f}, std: {np.std(bij[:,1]):.3f}, min: {np.min(bij[:,1]):.3f}, max: {np.max(bij[:,1]):.3f}"
)

set_range = [-30, 30]


plot.hist_1d(
    truth_bij[:,1], bij[:,1],
    title=fr"mean={np.mean(bij[:,1]):.2f}$\pm${sp.stats.sem(bij[:,1]):.3f}"
    + f" with truth: {np.mean(truth_bij[:,1]):.2f}$\pm${sp.stats.sem(truth_bij[:,1]):.3f}",
    xlabel=r"$B_{yz}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_bij[:,1], bij[:,1],
    title=r"$R^{2}$ = " + f"{r2_score(truth_bij[:,1], bij[:,1]):.3f}",
    xlabel="True $B_{{yz}}$ [None]",
    ylabel="Predicted $B_{{yz}}$ [None]",
    ranges=set_range
)
# Out:
# True mean     : 2.060, std: 8.727, min: -25.095, max: 29.572
# Predicted mean: 1.190, std: 8.503, min: -25.079, max: 29.236

# %%
print(
    f"True mean     : {np.mean(truth_bij[:,2]):.3f}, std: {np.std(truth_bij[:,2]):.3f}, min: {np.min(truth_bij[:,2]):.3f}, max: {np.max(truth_bij[:,2]):.3f}"
)
print(
    f"Predicted mean: {np.mean(bij[:,2]):.3f}, std: {np.std(bij[:,2]):.3f}, min: {np.min(bij[:,2]):.3f}, max: {np.max(bij[:,2]):.3f}"
)

set_range = [-30, 30]

plot.hist_1d(
    truth_bij[:,2], bij[:,2],
    title=rf"mean={np.mean(bij[:,2]):.2f}$\pm${sp.stats.sem(bij[:,2]):.3f}"
    + rf" with truth: {np.mean(truth_bij[:,2]):.2f}$\pm${sp.stats.sem(truth_bij[:,2]):.3f}",
    xlabel=r"$B_{zx}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_bij[:,2], bij[:,2],
    title=r"$R^{2}$ = " + f"{r2_score(truth_bij[:,2], bij[:,2]):.3f}",
    xlabel=r"True $B_{{zx}}$ [None]",
    ylabel=r"Predicted $B_{{zx}}$ [None]",
    ranges=set_range
)
# Out:
# True mean     : 3.228, std: 10.739, min: -25.073, max: 29.599
# Predicted mean: -1.422, std: 12.255, min: -25.096, max: 29.448

# %%
set_range = [-1, 1]


plot.hist_1d(
    truth_xi_p[:,0], xi_p[:,0],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_p[:,0], xi_p[:,0], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(0)}_{n}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_p[:,0], xi_p[:,0],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_p[:,0], xi_p[:,0]):.3f}",
    xlabel=r"True $\xi^{(0)}_{n}$ [None]",
    ylabel=r"Predicted $\xi^{(0)}_{n}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_p[:,1], xi_p[:,1],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_p[:,1], xi_p[:,1], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(0)}_{r}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_p[:,1], xi_p[:,1],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_p[:,1], xi_p[:,1]):.3f}",
    xlabel=r"True $\xi^{(0)}_{r}$ [None]",
    ylabel=r"Predicted $\xi^{(0)}_{r}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_p[:,2], xi_p[:,2],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_p[:,2], xi_p[:,2], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(0)}_{k}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_p[:,2], xi_p[:,2],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_p[:,2], xi_p[:,2]):.3f}",
    xlabel=r"True $\xi^{(0)}_{k}$ [None]",
    ylabel=r"Predicted $\xi^{(0)}_{k}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_n[:,0], xi_n[:,0],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_n[:,0], xi_n[:,0], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(1)}_{n}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_n[:,0], xi_n[:,0],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_n[:,0], xi_n[:,0]):.3f}",
    xlabel=r"True $\xi^{(1)}_{n}$ [None]",
    ylabel=r"Predicted $\xi^{(1)}_{n}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_n[:,1], xi_n[:,1],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_n[:,1], xi_n[:,1], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(1)}_{r}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_n[:,1], xi_n[:,1],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_n[:,1], xi_n[:,1]):.3f}",
    xlabel=r"True $\xi^{(1)}_{r}$ [None]",
    ylabel=r"Predicted $\xi^{(1)}_{r}$ [None]",
    xpad=0,
    ranges=set_range
)

# %%
set_range = [-1, 1]

plot.hist_1d(
    truth_xi_n[:,2], xi_n[:,2],
    title=f"RMSE = {np.sqrt(mean_squared_error(truth_xi_n[:,2], xi_n[:,2], sample_weight=None)):.3f}",
    xlabel=r"$\xi^{(1)}_{k}$ [None]",
    ranges=set_range
)

plot.hist_2d(
    truth_xi_n[:,2], xi_n[:,2],
    title=r"$R^{2}$ = " + f"{r2_score(truth_xi_n[:,2], xi_n[:,2]):.3f}",
    xlabel=r"True $\xi^{(1)}_{k}$ [None]",
    ylabel=r"Predicted $\xi^{(1)}_{k}$ [None]",
    xpad=0,
    ranges=set_range
)
