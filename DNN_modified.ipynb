# %%
# %reset -sf

from time import time
time_start = time()

import pandas as pd
import numpy as np
import scipy as sp
import gc
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import StandardScaler, MinMaxScaler, QuantileTransformer, RobustScaler
from sklearn.model_selection import train_test_split, KFold

import tensorflow as tf

from pylorentz import Momentum4
from mt2 import mt2

import get_data as gd
import atlas_plot as ap
plot = ap.Plotter()

print(tf.__version__)
print(tf.config.list_physical_devices())
print()
# Out:
# 2.13.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
seed = 42  # set random seed
sampling = int(1e6)
# num_folds = 2
batch_size = 1024
epochs = 512
learning_rate = 1e-5

# %%
np.random.seed(seed)
processor = gd.DataProcessor(sampling=sampling, processor=10)
path = "/root/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 10
#
# ['/root/data/truth/signal/CGLMP.npz', '/root/data/truth/signal/Higgs.npz', '/root/data/truth/signal/LeadLepton.npz', '/root/data/truth/signal/LeptonM.npz', '/root/data/truth/signal/LeptonP.npz', '/root/data/truth/signal/LmNu.npz', '/root/data/truth/signal/LpNu.npz', '/root/data/truth/signal/MET.npz', '/root/data/truth/signal/WmBoson.npz', '/root/data/truth/signal/WpBoson.npz', '/root/data/truth/signal/diLepton.npz', '/root/data/truth/signal/subLeadLepton.npz', '/root/data/truth/signal/xi_xyz.npz']

# %%
GEV = 1e3

cut_pre_pt_lead = data.LeadLep["pt"] > 22 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
cut_pre_pt_miss = data.MET["pt"] > 20 * GEV
cut_pre = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss

del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# %%
# inputs -> observed params
lep_p = processor.process_part(data.LepP)
lep_m = processor.process_part(data.LepM)
lep_kin = pd.concat([lep_p.iloc[:,:4], lep_m.iloc[:,:4]], axis=1)
MET = processor.process_MET(data.MET)
dilep_kin = processor.process_dipart(data.LepP, data.LepM)
mt = np.sqrt(
    mt2(
        lep_m["m"],
        lep_m["px"],
        lep_m["py"],  # Visible 1: mass, px, py
        lep_p["m"],
        lep_p["px"],
        lep_p["py"],  # Visible 2: mass, px, py
        MET["MET_px"],
        MET["MET_py"],  # Missing transverse momentum: x, y
        0,
        0,  # Invisible 1 mass, invisible 2 mass
    )
)
vx = 5 * pd.DataFrame({"vx": mt + 0.3 * np.sqrt(dilep_kin["m"])})
# dilep_kin.iloc[:, 0:4]
obs_kin = pd.concat([MET.iloc[:, 1:3], lep_kin], axis=1)[cut_pre]
print("obs_kin shape:", obs_kin.shape)
print(obs_kin.head(3))
print()

# targets -> interested unknowns
int_kin = pd.DataFrame(processor.process_dipart(data.NuP, data.NuM)[["pz"]])[cut_pre]
print("int_kin shape:", int_kin.shape)
print(int_kin.head(3))
print()

# del (processor, lep_p, lep_m, MET, dilep_kin, mt, vx)
# gc.collect()
# Out:
# obs_kin shape: (469444, 10)
#       MET_px     MET_py          E         px         py         pz  \
# 2  40.640285 -34.491089  27.938791  -5.350397  24.723715   2.596087
# 3 -22.370650 -13.660752  39.585180  34.181531  29.223672  54.450734
# 5   6.461073  18.680782  40.562547 -20.670785  -5.966123  -9.269961
#
#            E         px         py         pz
# 2  81.878680  -7.258286  16.174219  -1.476904
# 3  38.543746   3.505171  -9.634045   7.043200
# 5   7.339792 -11.362465 -20.160047 -25.274869
#
# int_kin shape: (469444, 1)
#            pz
# 2   70.605004
# 3  104.461062
# 5   60.332366

# %%
SCALAR_int_ru = RobustScaler()
int_kin = SCALAR_int_ru.fit_transform(int_kin)
SCALAR_int_mm = MinMaxScaler()
int_kin = SCALAR_int_mm.fit_transform(int_kin)

SCALAR_obs_ru = RobustScaler()
obs_kin = SCALAR_obs_ru.fit_transform(obs_kin)
SCALAR_obs_mm = MinMaxScaler()
obs_kin = SCALAR_obs_mm.fit_transform(obs_kin)

# %%
indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.4,
    test_size=0.6,
    random_state=seed,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=42
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
print()
# Out:
# X (Interest)
# Training data shape: (187777, 10);
# Validing data shape: (140833, 10);
# Testing data shape: (140834, 10).
# Y (Observed)
# Training data shape: (187777, 1);
# Validing data shape: (140833, 1);
# Testing data shape: (140834, 1).

# %%
# # Define the generator function of the dataset.
# def data_gen(X_data, y_data, indices):
#     while True:
#         for start in range(0, len(indices), batch_size):
#             end = min(start + batch_size, len(indices))
#             # print(f"start: {start}, end: {end}, indices: {indices[start:end]}")
#             # print(f"X_data shape: {X_data.shape}, y_data shape: {y_data.shape}")
#             yield X_data[indices[start:end]], y_data[indices[start:end]]

# %%
# Define a new activation function
def custom_activation(x):
    return x*tf.keras.backend.sigmoid(x)

# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    x = tf.keras.layers.Dense(units=32, activation="elu")(x)
    x = tf.keras.layers.Dense(units=32, activation="elu")(x)
    x = tf.keras.layers.Dropout(rate=0.2)(x)
    x = tf.keras.layers.Dense(units=4, activation="elu")(x)
    x = tf.keras.layers.Dense(units=4, activation="elu")(x)
    # x = tf.keras.layers.Dense(units=4, activation="elu")(x)
    # x = tf.keras.layers.Dense(units=4, activation="elu")(x)
    # x = tf.keras.layers.Dense(units=2, activation="elu")(x)
    # x = tf.keras.layers.Dense(units=2, activation="elu")(x)
    # x = tf.keras.layers.Dropout(rate=0.2)(x)
    # x = tf.keras.layers.Dense(u÷activation="relu")(x)
    
    # Last dense layer
    outputs = tf.keras.layers.Dense(units=train_y.shape[-1], activation="sigmoid")(x)

    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss="mse",
    )

    # Summarize the model
    model.summary()

    return model

# %%
model = build_model()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 10)]              0
#
#  flatten_1 (Flatten)         (None, 10)                0
#
#  dense_5 (Dense)             (None, 32)                352
#
#  dense_6 (Dense)             (None, 32)                1056
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 4)                 132
#
#  dense_8 (Dense)             (None, 4)                 20
#
#  dense_9 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 1565 (6.11 KB)
# Trainable params: 1565 (6.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-6,
    patience=10,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)

# Fit the model
history = model.fit(
    x=train_x,
    y=train_y,
    validation_data=(valid_x, valid_y),
    epochs=epochs,
    batch_size=batch_size,
    verbose=2,
    callbacks=[stop_early],
)
# Out:
# Epoch 1/512
# 184/184 - 2s - loss: 0.0138 - val_loss: 0.0075 - 2s/epoch - 12ms/step
# Epoch 2/512
# 184/184 - 1s - loss: 0.0074 - val_loss: 0.0032 - 798ms/epoch - 4ms/step
# Epoch 3/512
# 184/184 - 1s - loss: 0.0046 - val_loss: 0.0017 - 842ms/epoch - 5ms/step
# Epoch 4/512
# 184/184 - 1s - loss: 0.0036 - val_loss: 0.0013 - 817ms/epoch - 4ms/step
# Epoch 5/512
# 184/184 - 1s - loss: 0.0033 - val_loss: 0.0013 - 820ms/epoch - 4ms/step
# Epoch 6/512
# 184/184 - 1s - loss: 0.0031 - val_loss: 0.0013 - 851ms/epoch - 5ms/step
# Epoch 7/512
# 184/184 - 1s - loss: 0.0029 - val_loss: 0.0013 - 821ms/epoch - 4ms/step
# Epoch 8/512
# 184/184 - 1s - loss: 0.0028 - val_loss: 0.0013 - 836ms/epoch - 5ms/step
# Epoch 9/512
# 184/184 - 1s - loss: 0.0027 - val_loss: 0.0013 - 822ms/epoch - 4ms/step
# Epoch 10/512
# 184/184 - 1s - loss: 0.0026 - val_loss: 0.0012 - 827ms/epoch - 4ms/step
# Epoch 11/512
# 184/184 - 1s - loss: 0.0025 - val_loss: 0.0012 - 823ms/epoch - 4ms/step
# Epoch 12/512
# 184/184 - 1s - loss: 0.0023 - val_loss: 0.0012 - 806ms/epoch - 4ms/step
# Epoch 13/512
# 184/184 - 1s - loss: 0.0022 - val_loss: 0.0012 - 828ms/epoch - 5ms/step
# Epoch 14/512
# 184/184 - 1s - loss: 0.0021 - val_loss: 0.0012 - 837ms/epoch - 5ms/step
# Epoch 15/512
# 184/184 - 1s - loss: 0.0021 - val_loss: 0.0012 - 841ms/epoch - 5ms/step
# Epoch 16/512
# 184/184 - 1s - loss: 0.0020 - val_loss: 0.0012 - 849ms/epoch - 5ms/step
# Epoch 17/512
# 184/184 - 1s - loss: 0.0019 - val_loss: 0.0012 - 830ms/epoch - 5ms/step
# Epoch 18/512
# 184/184 - 1s - loss: 0.0018 - val_loss: 0.0012 - 856ms/epoch - 5ms/step
# Epoch 19/512
# 184/184 - 1s - loss: 0.0018 - val_loss: 0.0012 - 836ms/epoch - 5ms/step
# Epoch 20/512
# 184/184 - 1s - loss: 0.0017 - val_loss: 0.0012 - 817ms/epoch - 4ms/step
# Epoch 21/512
# 184/184 - 1s - loss: 0.0016 - val_loss: 0.0012 - 832ms/epoch - 5ms/step
# Epoch 22/512
# 184/184 - 1s - loss: 0.0016 - val_loss: 0.0012 - 819ms/epoch - 4ms/step
# Epoch 23/512
# 184/184 - 1s - loss: 0.0015 - val_loss: 0.0012 - 836ms/epoch - 5ms/step
# Epoch 24/512
# 184/184 - 1s - loss: 0.0015 - val_loss: 0.0011 - 833ms/epoch - 5ms/step
# Epoch 25/512
# 184/184 - 1s - loss: 0.0015 - val_loss: 0.0011 - 847ms/epoch - 5ms/step
# Epoch 26/512
# 184/184 - 1s - loss: 0.0014 - val_loss: 0.0011 - 841ms/epoch - 5ms/step
# Epoch 27/512
# 184/184 - 1s - loss: 0.0014 - val_loss: 0.0011 - 837ms/epoch - 5ms/step
# Epoch 28/512
# 184/184 - 1s - loss: 0.0014 - val_loss: 0.0011 - 827ms/epoch - 4ms/step
# Epoch 29/512
# 184/184 - 1s - loss: 0.0013 - val_loss: 0.0011 - 833ms/epoch - 5ms/step
# Epoch 30/512
# 184/184 - 1s - loss: 0.0013 - val_loss: 0.0011 - 839ms/epoch - 5ms/step
# Epoch 31/512
# 184/184 - 1s - loss: 0.0013 - val_loss: 0.0011 - 840ms/epoch - 5ms/step
# Epoch 32/512
# 184/184 - 1s - loss: 0.0013 - val_loss: 0.0011 - 824ms/epoch - 4ms/step
# Epoch 33/512
# 184/184 - 1s - loss: 0.0012 - val_loss: 0.0011 - 826ms/epoch - 4ms/step
# Epoch 34/512
# 184/184 - 1s - loss: 0.0012 - val_loss: 0.0011 - 845ms/epoch - 5ms/step
# Epoch 35/512
# 184/184 - 1s - loss: 0.0012 - val_loss: 0.0011 - 836ms/epoch - 5ms/step
# Epoch 36/512
# 184/184 - 1s - loss: 0.0012 - val_loss: 0.0011 - 829ms/epoch - 5ms/step
# Epoch 37/512
# 184/184 - 1s - loss: 0.0012 - val_loss: 0.0011 - 839ms/epoch - 5ms/step
# Epoch 38/512
# 184/184 - 1s - loss: 0.0011 - val_loss: 0.0010 - 847ms/epoch - 5ms/step
# Epoch 39/512
# 184/184 - 1s - loss: 0.0011 - val_loss: 0.0010 - 832ms/epoch - 5ms/step
# Epoch 40/512
# 184/184 - 1s - loss: 0.0011 - val_loss: 0.0010 - 806ms/epoch - 4ms/step
# Epoch 41/512
# 184/184 - 1s - loss: 0.0011 - val_loss: 0.0010 - 815ms/epoch - 4ms/step
# Epoch 42/512
# 184/184 - 1s - loss: 0.0011 - val_loss: 0.0010 - 834ms/epoch - 5ms/step
# Epoch 43/512
# 184/184 - 1s - loss: 0.0011 - val_loss: 0.0010 - 841ms/epoch - 5ms/step
# Epoch 44/512
# 184/184 - 1s - loss: 0.0011 - val_loss: 9.9640e-04 - 826ms/epoch - 4ms/step
# Epoch 45/512
# 184/184 - 1s - loss: 0.0010 - val_loss: 9.8698e-04 - 839ms/epoch - 5ms/step
# Epoch 46/512
# 184/184 - 1s - loss: 0.0010 - val_loss: 9.7721e-04 - 840ms/epoch - 5ms/step
# Epoch 47/512
# 184/184 - 1s - loss: 0.0010 - val_loss: 9.6618e-04 - 833ms/epoch - 5ms/step
# Epoch 48/512
# 184/184 - 1s - loss: 0.0010 - val_loss: 9.5528e-04 - 819ms/epoch - 4ms/step
# Epoch 49/512
# 184/184 - 1s - loss: 9.9545e-04 - val_loss: 9.4460e-04 - 838ms/epoch - 5ms/step
# Epoch 50/512
# 184/184 - 1s - loss: 9.8281e-04 - val_loss: 9.3188e-04 - 827ms/epoch - 4ms/step
# Epoch 51/512
# 184/184 - 1s - loss: 9.6880e-04 - val_loss: 9.2068e-04 - 846ms/epoch - 5ms/step
# Epoch 52/512
# 184/184 - 1s - loss: 9.5608e-04 - val_loss: 9.0827e-04 - 834ms/epoch - 5ms/step
# Epoch 53/512
# 184/184 - 1s - loss: 9.4469e-04 - val_loss: 8.9564e-04 - 825ms/epoch - 4ms/step
# Epoch 54/512
# 184/184 - 1s - loss: 9.2954e-04 - val_loss: 8.8352e-04 - 829ms/epoch - 5ms/step
# Epoch 55/512
# 184/184 - 1s - loss: 9.1795e-04 - val_loss: 8.7148e-04 - 839ms/epoch - 5ms/step
# Epoch 56/512
# 184/184 - 1s - loss: 9.0565e-04 - val_loss: 8.5971e-04 - 828ms/epoch - 5ms/step
# Epoch 57/512
# 184/184 - 1s - loss: 8.9234e-04 - val_loss: 8.4838e-04 - 823ms/epoch - 4ms/step
# Epoch 58/512
# 184/184 - 1s - loss: 8.7952e-04 - val_loss: 8.3759e-04 - 830ms/epoch - 5ms/step
# Epoch 59/512
# 184/184 - 1s - loss: 8.7310e-04 - val_loss: 8.2750e-04 - 837ms/epoch - 5ms/step
# Epoch 60/512
# 184/184 - 1s - loss: 8.6239e-04 - val_loss: 8.1838e-04 - 849ms/epoch - 5ms/step
# Epoch 61/512
# 184/184 - 1s - loss: 8.5257e-04 - val_loss: 8.1027e-04 - 829ms/epoch - 5ms/step
# Epoch 62/512
# 184/184 - 1s - loss: 8.4521e-04 - val_loss: 8.0238e-04 - 826ms/epoch - 4ms/step
# Epoch 63/512
# 184/184 - 1s - loss: 8.3894e-04 - val_loss: 7.9595e-04 - 834ms/epoch - 5ms/step
# Epoch 64/512
# 184/184 - 1s - loss: 8.3442e-04 - val_loss: 7.8993e-04 - 827ms/epoch - 4ms/step
# Epoch 65/512
# 184/184 - 1s - loss: 8.2681e-04 - val_loss: 7.8484e-04 - 850ms/epoch - 5ms/step
# Epoch 66/512
# 184/184 - 1s - loss: 8.2300e-04 - val_loss: 7.8052e-04 - 839ms/epoch - 5ms/step
# Epoch 67/512
# 184/184 - 1s - loss: 8.1781e-04 - val_loss: 7.7677e-04 - 844ms/epoch - 5ms/step
# Epoch 68/512
# 184/184 - 1s - loss: 8.1396e-04 - val_loss: 7.7354e-04 - 846ms/epoch - 5ms/step
# Epoch 69/512
# 184/184 - 1s - loss: 8.1173e-04 - val_loss: 7.7145e-04 - 838ms/epoch - 5ms/step
# Epoch 70/512
# 184/184 - 1s - loss: 8.0994e-04 - val_loss: 7.6880e-04 - 828ms/epoch - 4ms/step
# Epoch 71/512
# 184/184 - 1s - loss: 8.0838e-04 - val_loss: 7.6680e-04 - 839ms/epoch - 5ms/step
# Epoch 72/512
# 184/184 - 1s - loss: 8.0615e-04 - val_loss: 7.6522e-04 - 813ms/epoch - 4ms/step
# Epoch 73/512
# 184/184 - 1s - loss: 8.0420e-04 - val_loss: 7.6363e-04 - 842ms/epoch - 5ms/step
# Epoch 74/512
# 184/184 - 1s - loss: 8.0288e-04 - val_loss: 7.6305e-04 - 846ms/epoch - 5ms/step
# Epoch 75/512
# 184/184 - 1s - loss: 8.0179e-04 - val_loss: 7.6164e-04 - 844ms/epoch - 5ms/step
# Epoch 76/512
# 184/184 - 1s - loss: 7.9981e-04 - val_loss: 7.6005e-04 - 830ms/epoch - 5ms/step
# Epoch 77/512
# 184/184 - 1s - loss: 7.9863e-04 - val_loss: 7.5911e-04 - 828ms/epoch - 4ms/step
# Epoch 78/512
# 184/184 - 1s - loss: 7.9660e-04 - val_loss: 7.5836e-04 - 807ms/epoch - 4ms/step
# Epoch 79/512
# 184/184 - 1s - loss: 7.9483e-04 - val_loss: 7.5737e-04 - 820ms/epoch - 4ms/step
# Epoch 80/512
# 184/184 - 1s - loss: 7.9441e-04 - val_loss: 7.5660e-04 - 853ms/epoch - 5ms/step
# Epoch 81/512
# 184/184 - 1s - loss: 7.9683e-04 - val_loss: 7.5630e-04 - 817ms/epoch - 4ms/step
# Epoch 82/512
# 184/184 - 1s - loss: 7.9354e-04 - val_loss: 7.5520e-04 - 828ms/epoch - 5ms/step
# Epoch 83/512
# 184/184 - 1s - loss: 7.9384e-04 - val_loss: 7.5457e-04 - 835ms/epoch - 5ms/step
# Epoch 84/512
# 184/184 - 1s - loss: 7.9262e-04 - val_loss: 7.5455e-04 - 848ms/epoch - 5ms/step
# Epoch 85/512
# 184/184 - 1s - loss: 7.9119e-04 - val_loss: 7.5340e-04 - 823ms/epoch - 4ms/step
# Epoch 86/512
# 184/184 - 1s - loss: 7.9060e-04 - val_loss: 7.5294e-04 - 829ms/epoch - 5ms/step
# Epoch 87/512
# 184/184 - 1s - loss: 7.9011e-04 - val_loss: 7.5232e-04 - 823ms/epoch - 4ms/step
# Epoch 88/512
# 184/184 - 1s - loss: 7.8841e-04 - val_loss: 7.5181e-04 - 823ms/epoch - 4ms/step
# Epoch 89/512
# 184/184 - 1s - loss: 7.8997e-04 - val_loss: 7.5139e-04 - 829ms/epoch - 5ms/step
# Epoch 90/512
# 184/184 - 1s - loss: 7.8800e-04 - val_loss: 7.5076e-04 - 838ms/epoch - 5ms/step
# Epoch 91/512
# 184/184 - 1s - loss: 7.8816e-04 - val_loss: 7.5056e-04 - 819ms/epoch - 4ms/step
# Epoch 92/512
# 184/184 - 1s - loss: 7.8654e-04 - val_loss: 7.4991e-04 - 813ms/epoch - 4ms/step
# Epoch 93/512
# 184/184 - 1s - loss: 7.8611e-04 - val_loss: 7.5039e-04 - 814ms/epoch - 4ms/step
# Epoch 94/512
# 184/184 - 1s - loss: 7.8540e-04 - val_loss: 7.4895e-04 - 832ms/epoch - 5ms/step
# Epoch 95/512
# 184/184 - 1s - loss: 7.8649e-04 - val_loss: 7.4872e-04 - 809ms/epoch - 4ms/step
# Epoch 96/512
# 184/184 - 1s - loss: 7.8527e-04 - val_loss: 7.4814e-04 - 796ms/epoch - 4ms/step
# Epoch 97/512
# 184/184 - 1s - loss: 7.8593e-04 - val_loss: 7.4781e-04 - 819ms/epoch - 4ms/step
# Epoch 98/512
# 184/184 - 1s - loss: 7.8253e-04 - val_loss: 7.4726e-04 - 822ms/epoch - 4ms/step
# Epoch 99/512
# 184/184 - 1s - loss: 7.8368e-04 - val_loss: 7.4718e-04 - 841ms/epoch - 5ms/step
# Epoch 100/512
# 184/184 - 1s - loss: 7.8121e-04 - val_loss: 7.4644e-04 - 836ms/epoch - 5ms/step
# Epoch 101/512
# 184/184 - 1s - loss: 7.8138e-04 - val_loss: 7.4609e-04 - 824ms/epoch - 4ms/step
# Epoch 102/512
# 184/184 - 1s - loss: 7.8156e-04 - val_loss: 7.4570e-04 - 852ms/epoch - 5ms/step
# Epoch 103/512
# 184/184 - 1s - loss: 7.8128e-04 - val_loss: 7.4532e-04 - 820ms/epoch - 4ms/step
# Epoch 104/512
# 184/184 - 1s - loss: 7.8018e-04 - val_loss: 7.4505e-04 - 838ms/epoch - 5ms/step
# Epoch 105/512
# 184/184 - 1s - loss: 7.8030e-04 - val_loss: 7.4475e-04 - 845ms/epoch - 5ms/step
# Epoch 106/512
# 184/184 - 1s - loss: 7.7967e-04 - val_loss: 7.4447e-04 - 829ms/epoch - 5ms/step
# Epoch 107/512
# 184/184 - 1s - loss: 7.7880e-04 - val_loss: 7.4390e-04 - 827ms/epoch - 4ms/step
# Epoch 108/512
# 184/184 - 1s - loss: 7.7756e-04 - val_loss: 7.4381e-04 - 828ms/epoch - 4ms/step
# Epoch 109/512
# 184/184 - 1s - loss: 7.7845e-04 - val_loss: 7.4358e-04 - 833ms/epoch - 5ms/step
# Epoch 110/512
# 184/184 - 1s - loss: 7.7771e-04 - val_loss: 7.4286e-04 - 849ms/epoch - 5ms/step
# Epoch 111/512
# 184/184 - 1s - loss: 7.7585e-04 - val_loss: 7.4255e-04 - 835ms/epoch - 5ms/step
# Epoch 112/512
# 184/184 - 1s - loss: 7.7726e-04 - val_loss: 7.4217e-04 - 844ms/epoch - 5ms/step
# Epoch 113/512
# 184/184 - 1s - loss: 7.7660e-04 - val_loss: 7.4189e-04 - 847ms/epoch - 5ms/step
# Epoch 114/512
# 184/184 - 1s - loss: 7.7586e-04 - val_loss: 7.4174e-04 - 831ms/epoch - 5ms/step
# Epoch 115/512
# 184/184 - 1s - loss: 7.7608e-04 - val_loss: 7.4123e-04 - 820ms/epoch - 4ms/step
# Epoch 116/512
# 184/184 - 1s - loss: 7.7473e-04 - val_loss: 7.4088e-04 - 834ms/epoch - 5ms/step
# Epoch 117/512
# 184/184 - 1s - loss: 7.7486e-04 - val_loss: 7.4056e-04 - 839ms/epoch - 5ms/step
# Epoch 118/512
# 184/184 - 1s - loss: 7.7447e-04 - val_loss: 7.4025e-04 - 835ms/epoch - 5ms/step
# Epoch 119/512
# 184/184 - 1s - loss: 7.7392e-04 - val_loss: 7.3995e-04 - 859ms/epoch - 5ms/step
# Epoch 120/512
# 184/184 - 1s - loss: 7.7406e-04 - val_loss: 7.3964e-04 - 838ms/epoch - 5ms/step
# Epoch 121/512
# 184/184 - 1s - loss: 7.7326e-04 - val_loss: 7.3943e-04 - 860ms/epoch - 5ms/step
# Epoch 122/512
# 184/184 - 1s - loss: 7.7350e-04 - val_loss: 7.3920e-04 - 843ms/epoch - 5ms/step
# Epoch 123/512
# 184/184 - 1s - loss: 7.7150e-04 - val_loss: 7.3884e-04 - 827ms/epoch - 4ms/step
# Epoch 124/512
# 184/184 - 1s - loss: 7.7186e-04 - val_loss: 7.3841e-04 - 820ms/epoch - 4ms/step
# Epoch 125/512
# 184/184 - 1s - loss: 7.7144e-04 - val_loss: 7.3812e-04 - 831ms/epoch - 5ms/step
# Epoch 126/512
# 184/184 - 1s - loss: 7.7057e-04 - val_loss: 7.3839e-04 - 812ms/epoch - 4ms/step
# Epoch 127/512
# 184/184 - 1s - loss: 7.7051e-04 - val_loss: 7.3776e-04 - 837ms/epoch - 5ms/step
# Epoch 128/512
# 184/184 - 1s - loss: 7.7121e-04 - val_loss: 7.3765e-04 - 860ms/epoch - 5ms/step
# Epoch 129/512
# 184/184 - 1s - loss: 7.6956e-04 - val_loss: 7.3693e-04 - 852ms/epoch - 5ms/step
# Epoch 130/512
# 184/184 - 1s - loss: 7.6991e-04 - val_loss: 7.3662e-04 - 829ms/epoch - 5ms/step
# Epoch 131/512
# 184/184 - 1s - loss: 7.6934e-04 - val_loss: 7.3652e-04 - 832ms/epoch - 5ms/step
# Epoch 132/512
# 184/184 - 1s - loss: 7.7043e-04 - val_loss: 7.3736e-04 - 835ms/epoch - 5ms/step
# Epoch 133/512
# 184/184 - 1s - loss: 7.6795e-04 - val_loss: 7.3576e-04 - 848ms/epoch - 5ms/step
# Epoch 134/512
# 184/184 - 1s - loss: 7.6969e-04 - val_loss: 7.3547e-04 - 821ms/epoch - 4ms/step
# Epoch 135/512
# 184/184 - 1s - loss: 7.6889e-04 - val_loss: 7.3524e-04 - 843ms/epoch - 5ms/step
# Epoch 136/512
# 184/184 - 1s - loss: 7.6753e-04 - val_loss: 7.3526e-04 - 867ms/epoch - 5ms/step
# Epoch 137/512
# 184/184 - 1s - loss: 7.6750e-04 - val_loss: 7.3473e-04 - 837ms/epoch - 5ms/step
# Epoch 138/512
# 184/184 - 1s - loss: 7.6891e-04 - val_loss: 7.3435e-04 - 843ms/epoch - 5ms/step
# Epoch 139/512
# 184/184 - 1s - loss: 7.6669e-04 - val_loss: 7.3419e-04 - 848ms/epoch - 5ms/step
# Epoch 140/512
# 184/184 - 1s - loss: 7.6484e-04 - val_loss: 7.3378e-04 - 844ms/epoch - 5ms/step
# Epoch 141/512
# 184/184 - 1s - loss: 7.6578e-04 - val_loss: 7.3387e-04 - 861ms/epoch - 5ms/step
# Epoch 142/512
# 184/184 - 1s - loss: 7.6569e-04 - val_loss: 7.3400e-04 - 839ms/epoch - 5ms/step
# Epoch 143/512
# 184/184 - 1s - loss: 7.6522e-04 - val_loss: 7.3295e-04 - 820ms/epoch - 4ms/step
# Epoch 144/512
# 184/184 - 1s - loss: 7.6482e-04 - val_loss: 7.3314e-04 - 836ms/epoch - 5ms/step
# Epoch 145/512
# 184/184 - 1s - loss: 7.6561e-04 - val_loss: 7.3240e-04 - 834ms/epoch - 5ms/step
# Epoch 146/512
# 184/184 - 1s - loss: 7.6445e-04 - val_loss: 7.3268e-04 - 829ms/epoch - 5ms/step
# Epoch 147/512
# 184/184 - 1s - loss: 7.6407e-04 - val_loss: 7.3196e-04 - 819ms/epoch - 4ms/step
# Epoch 148/512
# 184/184 - 1s - loss: 7.6290e-04 - val_loss: 7.3161e-04 - 828ms/epoch - 5ms/step
# Epoch 149/512
# 184/184 - 1s - loss: 7.6447e-04 - val_loss: 7.3162e-04 - 843ms/epoch - 5ms/step
# Epoch 150/512
# 184/184 - 1s - loss: 7.6427e-04 - val_loss: 7.3099e-04 - 856ms/epoch - 5ms/step
# Epoch 151/512
# 184/184 - 1s - loss: 7.6213e-04 - val_loss: 7.3074e-04 - 843ms/epoch - 5ms/step
# Epoch 152/512
# 184/184 - 1s - loss: 7.6194e-04 - val_loss: 7.3044e-04 - 831ms/epoch - 5ms/step
# Epoch 153/512
# 184/184 - 1s - loss: 7.6099e-04 - val_loss: 7.3015e-04 - 837ms/epoch - 5ms/step
# Epoch 154/512
# 184/184 - 1s - loss: 7.6268e-04 - val_loss: 7.2989e-04 - 829ms/epoch - 5ms/step
# Epoch 155/512
# 184/184 - 1s - loss: 7.6121e-04 - val_loss: 7.2963e-04 - 828ms/epoch - 4ms/step
# Epoch 156/512
# 184/184 - 1s - loss: 7.6058e-04 - val_loss: 7.2940e-04 - 834ms/epoch - 5ms/step
# Epoch 157/512
# 184/184 - 1s - loss: 7.6039e-04 - val_loss: 7.2917e-04 - 840ms/epoch - 5ms/step
# Epoch 158/512
# 184/184 - 1s - loss: 7.5980e-04 - val_loss: 7.2921e-04 - 816ms/epoch - 4ms/step
# Epoch 159/512
# 184/184 - 1s - loss: 7.6119e-04 - val_loss: 7.2865e-04 - 832ms/epoch - 5ms/step
# Epoch 160/512
# 184/184 - 1s - loss: 7.5781e-04 - val_loss: 7.2840e-04 - 821ms/epoch - 4ms/step
# Epoch 161/512
# 184/184 - 1s - loss: 7.6059e-04 - val_loss: 7.2864e-04 - 841ms/epoch - 5ms/step
# Epoch 162/512
# 184/184 - 1s - loss: 7.6038e-04 - val_loss: 7.2795e-04 - 831ms/epoch - 5ms/step
# Epoch 163/512
# 184/184 - 1s - loss: 7.5861e-04 - val_loss: 7.2749e-04 - 841ms/epoch - 5ms/step
# Epoch 164/512
# 184/184 - 1s - loss: 7.5764e-04 - val_loss: 7.2724e-04 - 830ms/epoch - 5ms/step
# Epoch 165/512
# 184/184 - 1s - loss: 7.5632e-04 - val_loss: 7.2694e-04 - 838ms/epoch - 5ms/step
# Epoch 166/512
# 184/184 - 1s - loss: 7.5721e-04 - val_loss: 7.2681e-04 - 827ms/epoch - 4ms/step
# Epoch 167/512
# 184/184 - 1s - loss: 7.5702e-04 - val_loss: 7.2639e-04 - 838ms/epoch - 5ms/step
# Epoch 168/512
# 184/184 - 1s - loss: 7.5698e-04 - val_loss: 7.2615e-04 - 848ms/epoch - 5ms/step
# Epoch 169/512
# 184/184 - 1s - loss: 7.5695e-04 - val_loss: 7.2587e-04 - 842ms/epoch - 5ms/step
# Epoch 170/512
# 184/184 - 1s - loss: 7.5496e-04 - val_loss: 7.2559e-04 - 825ms/epoch - 4ms/step
# Epoch 171/512
# 184/184 - 1s - loss: 7.5415e-04 - val_loss: 7.2613e-04 - 824ms/epoch - 4ms/step
# Epoch 172/512
# 184/184 - 1s - loss: 7.5484e-04 - val_loss: 7.2509e-04 - 844ms/epoch - 5ms/step
# Epoch 173/512
# 184/184 - 1s - loss: 7.5594e-04 - val_loss: 7.2572e-04 - 834ms/epoch - 5ms/step
# Epoch 174/512
# 184/184 - 1s - loss: 7.5513e-04 - val_loss: 7.2458e-04 - 843ms/epoch - 5ms/step
# Epoch 175/512
# 184/184 - 1s - loss: 7.5436e-04 - val_loss: 7.2432e-04 - 825ms/epoch - 4ms/step
# Epoch 176/512
# 184/184 - 1s - loss: 7.5480e-04 - val_loss: 7.2403e-04 - 850ms/epoch - 5ms/step
# Epoch 177/512
# 184/184 - 1s - loss: 7.5452e-04 - val_loss: 7.2380e-04 - 836ms/epoch - 5ms/step
# Epoch 178/512
# 184/184 - 1s - loss: 7.5406e-04 - val_loss: 7.2361e-04 - 813ms/epoch - 4ms/step
# Epoch 179/512
# 184/184 - 1s - loss: 7.5302e-04 - val_loss: 7.2358e-04 - 818ms/epoch - 4ms/step
# Epoch 180/512
# 184/184 - 1s - loss: 7.5315e-04 - val_loss: 7.2305e-04 - 838ms/epoch - 5ms/step
# Epoch 181/512
# 184/184 - 1s - loss: 7.5398e-04 - val_loss: 7.2277e-04 - 815ms/epoch - 4ms/step
# Epoch 182/512
# 184/184 - 1s - loss: 7.5153e-04 - val_loss: 7.2253e-04 - 851ms/epoch - 5ms/step
# Epoch 183/512
# 184/184 - 1s - loss: 7.5281e-04 - val_loss: 7.2233e-04 - 840ms/epoch - 5ms/step
# Epoch 184/512
# 184/184 - 1s - loss: 7.5263e-04 - val_loss: 7.2233e-04 - 843ms/epoch - 5ms/step
# Epoch 185/512
# 184/184 - 1s - loss: 7.5171e-04 - val_loss: 7.2187e-04 - 830ms/epoch - 5ms/step
# Epoch 186/512
# 184/184 - 1s - loss: 7.5092e-04 - val_loss: 7.2156e-04 - 837ms/epoch - 5ms/step
# Epoch 187/512
# 184/184 - 1s - loss: 7.5203e-04 - val_loss: 7.2125e-04 - 842ms/epoch - 5ms/step
# Epoch 188/512
# 184/184 - 1s - loss: 7.5198e-04 - val_loss: 7.2110e-04 - 841ms/epoch - 5ms/step
# Epoch 189/512
# 184/184 - 1s - loss: 7.5081e-04 - val_loss: 7.2161e-04 - 845ms/epoch - 5ms/step
# Epoch 190/512
# 184/184 - 1s - loss: 7.5054e-04 - val_loss: 7.2063e-04 - 833ms/epoch - 5ms/step
# Epoch 191/512
# 184/184 - 1s - loss: 7.5022e-04 - val_loss: 7.2073e-04 - 847ms/epoch - 5ms/step
# Epoch 192/512
# 184/184 - 1s - loss: 7.5000e-04 - val_loss: 7.2011e-04 - 839ms/epoch - 5ms/step
# Epoch 193/512
# 184/184 - 1s - loss: 7.4945e-04 - val_loss: 7.1979e-04 - 836ms/epoch - 5ms/step
# Epoch 194/512
# 184/184 - 1s - loss: 7.5027e-04 - val_loss: 7.1962e-04 - 839ms/epoch - 5ms/step
# Epoch 195/512
# 184/184 - 1s - loss: 7.4910e-04 - val_loss: 7.1930e-04 - 842ms/epoch - 5ms/step
# Epoch 196/512
# 184/184 - 1s - loss: 7.5035e-04 - val_loss: 7.1915e-04 - 842ms/epoch - 5ms/step
# Epoch 197/512
# 184/184 - 1s - loss: 7.4886e-04 - val_loss: 7.1891e-04 - 827ms/epoch - 4ms/step
# Epoch 198/512
# 184/184 - 1s - loss: 7.4801e-04 - val_loss: 7.1864e-04 - 841ms/epoch - 5ms/step
# Epoch 199/512
# 184/184 - 1s - loss: 7.4741e-04 - val_loss: 7.1839e-04 - 844ms/epoch - 5ms/step
# Epoch 200/512
# 184/184 - 1s - loss: 7.4777e-04 - val_loss: 7.1810e-04 - 802ms/epoch - 4ms/step
# Epoch 201/512
# 184/184 - 1s - loss: 7.4685e-04 - val_loss: 7.1787e-04 - 834ms/epoch - 5ms/step
# Epoch 202/512
# 184/184 - 1s - loss: 7.4600e-04 - val_loss: 7.1762e-04 - 842ms/epoch - 5ms/step
# Epoch 203/512
# 184/184 - 1s - loss: 7.4697e-04 - val_loss: 7.1741e-04 - 837ms/epoch - 5ms/step
# Epoch 204/512
# 184/184 - 1s - loss: 7.4607e-04 - val_loss: 7.1752e-04 - 838ms/epoch - 5ms/step
# Epoch 205/512
# 184/184 - 1s - loss: 7.4534e-04 - val_loss: 7.1694e-04 - 845ms/epoch - 5ms/step
# Epoch 206/512
# 184/184 - 1s - loss: 7.4724e-04 - val_loss: 7.1697e-04 - 829ms/epoch - 5ms/step
# Epoch 207/512
# 184/184 - 1s - loss: 7.4715e-04 - val_loss: 7.1646e-04 - 847ms/epoch - 5ms/step
# Epoch 208/512
# 184/184 - 1s - loss: 7.4585e-04 - val_loss: 7.1628e-04 - 843ms/epoch - 5ms/step
# Epoch 209/512
# 184/184 - 1s - loss: 7.4498e-04 - val_loss: 7.1600e-04 - 850ms/epoch - 5ms/step
# Epoch 210/512
# 184/184 - 1s - loss: 7.4469e-04 - val_loss: 7.1581e-04 - 847ms/epoch - 5ms/step
# Epoch 211/512
# 184/184 - 1s - loss: 7.4484e-04 - val_loss: 7.1553e-04 - 832ms/epoch - 5ms/step
# Epoch 212/512
# 184/184 - 1s - loss: 7.4429e-04 - val_loss: 7.1531e-04 - 840ms/epoch - 5ms/step
# Epoch 213/512
# 184/184 - 1s - loss: 7.4494e-04 - val_loss: 7.1566e-04 - 850ms/epoch - 5ms/step
# Epoch 214/512
# 184/184 - 1s - loss: 7.4341e-04 - val_loss: 7.1484e-04 - 841ms/epoch - 5ms/step
# Epoch 215/512
# 184/184 - 1s - loss: 7.4362e-04 - val_loss: 7.1462e-04 - 840ms/epoch - 5ms/step
# Epoch 216/512
# 184/184 - 1s - loss: 7.4294e-04 - val_loss: 7.1438e-04 - 825ms/epoch - 4ms/step
# Epoch 217/512
# 184/184 - 1s - loss: 7.4244e-04 - val_loss: 7.1452e-04 - 843ms/epoch - 5ms/step
# Epoch 218/512
# 184/184 - 1s - loss: 7.4106e-04 - val_loss: 7.1397e-04 - 841ms/epoch - 5ms/step
# Epoch 219/512
# 184/184 - 1s - loss: 7.4393e-04 - val_loss: 7.1373e-04 - 866ms/epoch - 5ms/step
# Epoch 220/512
# 184/184 - 1s - loss: 7.4242e-04 - val_loss: 7.1345e-04 - 802ms/epoch - 4ms/step
# Epoch 221/512
# 184/184 - 1s - loss: 7.4197e-04 - val_loss: 7.1352e-04 - 813ms/epoch - 4ms/step
# Epoch 222/512
# 184/184 - 1s - loss: 7.4110e-04 - val_loss: 7.1320e-04 - 844ms/epoch - 5ms/step
# Epoch 223/512
# 184/184 - 1s - loss: 7.4139e-04 - val_loss: 7.1284e-04 - 839ms/epoch - 5ms/step
# Epoch 224/512
# 184/184 - 1s - loss: 7.4215e-04 - val_loss: 7.1266e-04 - 821ms/epoch - 4ms/step
# Epoch 225/512
# 184/184 - 1s - loss: 7.4076e-04 - val_loss: 7.1241e-04 - 831ms/epoch - 5ms/step
# Epoch 226/512
# 184/184 - 1s - loss: 7.4079e-04 - val_loss: 7.1214e-04 - 852ms/epoch - 5ms/step
# Epoch 227/512
# 184/184 - 1s - loss: 7.4172e-04 - val_loss: 7.1191e-04 - 826ms/epoch - 4ms/step
# Epoch 228/512
# 184/184 - 1s - loss: 7.4016e-04 - val_loss: 7.1171e-04 - 858ms/epoch - 5ms/step
# Epoch 229/512
# 184/184 - 1s - loss: 7.3966e-04 - val_loss: 7.1148e-04 - 852ms/epoch - 5ms/step
# Epoch 230/512
# 184/184 - 1s - loss: 7.3865e-04 - val_loss: 7.1132e-04 - 851ms/epoch - 5ms/step
# Epoch 231/512
# 184/184 - 1s - loss: 7.4083e-04 - val_loss: 7.1116e-04 - 850ms/epoch - 5ms/step
# Epoch 232/512
# 184/184 - 1s - loss: 7.3985e-04 - val_loss: 7.1101e-04 - 839ms/epoch - 5ms/step
# Epoch 233/512
# 184/184 - 1s - loss: 7.3805e-04 - val_loss: 7.1060e-04 - 841ms/epoch - 5ms/step
# Epoch 234/512
# 184/184 - 1s - loss: 7.3832e-04 - val_loss: 7.1046e-04 - 839ms/epoch - 5ms/step
# Epoch 235/512
# 184/184 - 1s - loss: 7.3927e-04 - val_loss: 7.1021e-04 - 836ms/epoch - 5ms/step
# Epoch 236/512
# 184/184 - 1s - loss: 7.3775e-04 - val_loss: 7.1010e-04 - 838ms/epoch - 5ms/step
# Epoch 237/512
# 184/184 - 1s - loss: 7.3855e-04 - val_loss: 7.1098e-04 - 847ms/epoch - 5ms/step
# Epoch 238/512
# 184/184 - 1s - loss: 7.3787e-04 - val_loss: 7.0944e-04 - 848ms/epoch - 5ms/step
# Epoch 239/512
# 184/184 - 1s - loss: 7.3866e-04 - val_loss: 7.0936e-04 - 826ms/epoch - 4ms/step
# Epoch 240/512
# 184/184 - 1s - loss: 7.3721e-04 - val_loss: 7.0904e-04 - 834ms/epoch - 5ms/step
# Epoch 241/512
# 184/184 - 1s - loss: 7.3678e-04 - val_loss: 7.0882e-04 - 842ms/epoch - 5ms/step
# Epoch 242/512
# 184/184 - 1s - loss: 7.3616e-04 - val_loss: 7.0861e-04 - 828ms/epoch - 5ms/step
# Epoch 243/512
# 184/184 - 1s - loss: 7.3777e-04 - val_loss: 7.0851e-04 - 836ms/epoch - 5ms/step
# Epoch 244/512
# 184/184 - 1s - loss: 7.3604e-04 - val_loss: 7.0822e-04 - 833ms/epoch - 5ms/step
# Epoch 245/512
# 184/184 - 1s - loss: 7.3678e-04 - val_loss: 7.0817e-04 - 842ms/epoch - 5ms/step
# Epoch 246/512
# 184/184 - 1s - loss: 7.3705e-04 - val_loss: 7.0782e-04 - 820ms/epoch - 4ms/step
# Epoch 247/512
# 184/184 - 1s - loss: 7.3581e-04 - val_loss: 7.0755e-04 - 822ms/epoch - 4ms/step
# Epoch 248/512
# 184/184 - 1s - loss: 7.3465e-04 - val_loss: 7.0739e-04 - 833ms/epoch - 5ms/step
# Epoch 249/512
# 184/184 - 1s - loss: 7.3508e-04 - val_loss: 7.0713e-04 - 820ms/epoch - 4ms/step
# Epoch 250/512
# 184/184 - 1s - loss: 7.3551e-04 - val_loss: 7.0692e-04 - 833ms/epoch - 5ms/step
# Epoch 251/512
# 184/184 - 1s - loss: 7.3558e-04 - val_loss: 7.0683e-04 - 833ms/epoch - 5ms/step
# Epoch 252/512
# 184/184 - 1s - loss: 7.3553e-04 - val_loss: 7.0653e-04 - 838ms/epoch - 5ms/step
# Epoch 253/512
# 184/184 - 1s - loss: 7.3486e-04 - val_loss: 7.0641e-04 - 844ms/epoch - 5ms/step
# Epoch 254/512
# 184/184 - 1s - loss: 7.3443e-04 - val_loss: 7.0615e-04 - 852ms/epoch - 5ms/step
# Epoch 255/512
# 184/184 - 1s - loss: 7.3396e-04 - val_loss: 7.0590e-04 - 865ms/epoch - 5ms/step
# Epoch 256/512
# 184/184 - 1s - loss: 7.3369e-04 - val_loss: 7.0587e-04 - 837ms/epoch - 5ms/step
# Epoch 257/512
# 184/184 - 1s - loss: 7.3443e-04 - val_loss: 7.0550e-04 - 842ms/epoch - 5ms/step
# Epoch 258/512
# 184/184 - 1s - loss: 7.3345e-04 - val_loss: 7.0537e-04 - 853ms/epoch - 5ms/step
# Epoch 259/512
# 184/184 - 1s - loss: 7.3318e-04 - val_loss: 7.0582e-04 - 845ms/epoch - 5ms/step
# Epoch 260/512
# 184/184 - 1s - loss: 7.3206e-04 - val_loss: 7.0490e-04 - 849ms/epoch - 5ms/step
# Epoch 261/512
# 184/184 - 1s - loss: 7.3167e-04 - val_loss: 7.0474e-04 - 815ms/epoch - 4ms/step
# Epoch 262/512
# 184/184 - 1s - loss: 7.3218e-04 - val_loss: 7.0447e-04 - 834ms/epoch - 5ms/step
# Epoch 263/512
# 184/184 - 1s - loss: 7.3217e-04 - val_loss: 7.0430e-04 - 829ms/epoch - 5ms/step
# Epoch 264/512
# 184/184 - 1s - loss: 7.3292e-04 - val_loss: 7.0436e-04 - 818ms/epoch - 4ms/step
# Epoch 265/512
# 184/184 - 1s - loss: 7.3122e-04 - val_loss: 7.0403e-04 - 834ms/epoch - 5ms/step
# Epoch 266/512
# 184/184 - 1s - loss: 7.3161e-04 - val_loss: 7.0367e-04 - 830ms/epoch - 5ms/step
# Epoch 267/512
# 184/184 - 1s - loss: 7.3160e-04 - val_loss: 7.0349e-04 - 823ms/epoch - 4ms/step
# Epoch 268/512
# 184/184 - 1s - loss: 7.3035e-04 - val_loss: 7.0341e-04 - 827ms/epoch - 4ms/step
# Epoch 269/512
# 184/184 - 1s - loss: 7.3102e-04 - val_loss: 7.0327e-04 - 842ms/epoch - 5ms/step
# Epoch 270/512
# 184/184 - 1s - loss: 7.3000e-04 - val_loss: 7.0310e-04 - 844ms/epoch - 5ms/step
# Epoch 271/512
# 184/184 - 1s - loss: 7.3067e-04 - val_loss: 7.0270e-04 - 827ms/epoch - 4ms/step
# Epoch 272/512
# 184/184 - 1s - loss: 7.3082e-04 - val_loss: 7.0406e-04 - 836ms/epoch - 5ms/step
# Epoch 273/512
# 184/184 - 1s - loss: 7.3025e-04 - val_loss: 7.0235e-04 - 836ms/epoch - 5ms/step
# Epoch 274/512
# 184/184 - 1s - loss: 7.2841e-04 - val_loss: 7.0213e-04 - 786ms/epoch - 4ms/step
# Epoch 275/512
# 184/184 - 1s - loss: 7.3016e-04 - val_loss: 7.0194e-04 - 843ms/epoch - 5ms/step
# Epoch 276/512
# 184/184 - 1s - loss: 7.2968e-04 - val_loss: 7.0183e-04 - 810ms/epoch - 4ms/step
# Epoch 277/512
# 184/184 - 1s - loss: 7.2912e-04 - val_loss: 7.0174e-04 - 834ms/epoch - 5ms/step
# Epoch 278/512
# 184/184 - 1s - loss: 7.2889e-04 - val_loss: 7.0145e-04 - 836ms/epoch - 5ms/step
# Epoch 279/512
# 184/184 - 1s - loss: 7.2933e-04 - val_loss: 7.0120e-04 - 831ms/epoch - 5ms/step
# Epoch 280/512
# 184/184 - 1s - loss: 7.2701e-04 - val_loss: 7.0132e-04 - 861ms/epoch - 5ms/step
# Epoch 281/512
# 184/184 - 1s - loss: 7.2843e-04 - val_loss: 7.0088e-04 - 836ms/epoch - 5ms/step
# Epoch 282/512
# 184/184 - 1s - loss: 7.2830e-04 - val_loss: 7.0082e-04 - 830ms/epoch - 5ms/step
# Epoch 283/512
# 184/184 - 1s - loss: 7.2792e-04 - val_loss: 7.0060e-04 - 818ms/epoch - 4ms/step
# Epoch 284/512
# 184/184 - 1s - loss: 7.2800e-04 - val_loss: 7.0030e-04 - 829ms/epoch - 5ms/step
# Epoch 285/512
# 184/184 - 1s - loss: 7.2543e-04 - val_loss: 7.0007e-04 - 837ms/epoch - 5ms/step
# Epoch 286/512
# 184/184 - 1s - loss: 7.2653e-04 - val_loss: 6.9998e-04 - 833ms/epoch - 5ms/step
# Epoch 287/512
# 184/184 - 1s - loss: 7.2718e-04 - val_loss: 6.9970e-04 - 863ms/epoch - 5ms/step
# Epoch 288/512
# 184/184 - 1s - loss: 7.2778e-04 - val_loss: 6.9955e-04 - 840ms/epoch - 5ms/step
# Epoch 289/512
# 184/184 - 1s - loss: 7.2498e-04 - val_loss: 6.9936e-04 - 828ms/epoch - 5ms/step
# Epoch 290/512
# 184/184 - 1s - loss: 7.2759e-04 - val_loss: 6.9980e-04 - 805ms/epoch - 4ms/step
# Epoch 291/512
# 184/184 - 1s - loss: 7.2567e-04 - val_loss: 6.9919e-04 - 855ms/epoch - 5ms/step
# Epoch 292/512
# 184/184 - 1s - loss: 7.2540e-04 - val_loss: 6.9910e-04 - 837ms/epoch - 5ms/step
# Epoch 293/512
# 184/184 - 1s - loss: 7.2677e-04 - val_loss: 6.9865e-04 - 860ms/epoch - 5ms/step
# Epoch 294/512
# 184/184 - 1s - loss: 7.2572e-04 - val_loss: 6.9910e-04 - 852ms/epoch - 5ms/step
# Epoch 295/512
# 184/184 - 1s - loss: 7.2599e-04 - val_loss: 6.9866e-04 - 831ms/epoch - 5ms/step
# Epoch 296/512
# 184/184 - 1s - loss: 7.2588e-04 - val_loss: 6.9828e-04 - 828ms/epoch - 5ms/step
# Epoch 297/512
# 184/184 - 1s - loss: 7.2573e-04 - val_loss: 6.9829e-04 - 834ms/epoch - 5ms/step
# Epoch 298/512
# 184/184 - 1s - loss: 7.2350e-04 - val_loss: 6.9795e-04 - 830ms/epoch - 5ms/step
# Epoch 299/512
# 184/184 - 1s - loss: 7.2315e-04 - val_loss: 6.9758e-04 - 847ms/epoch - 5ms/step
# Epoch 300/512
# 184/184 - 1s - loss: 7.2445e-04 - val_loss: 6.9742e-04 - 836ms/epoch - 5ms/step
# Epoch 301/512
# 184/184 - 1s - loss: 7.2485e-04 - val_loss: 6.9735e-04 - 828ms/epoch - 4ms/step
# Epoch 302/512
# 184/184 - 1s - loss: 7.2345e-04 - val_loss: 6.9715e-04 - 846ms/epoch - 5ms/step
# Epoch 303/512
# 184/184 - 1s - loss: 7.2383e-04 - val_loss: 6.9696e-04 - 840ms/epoch - 5ms/step
# Epoch 304/512
# 184/184 - 1s - loss: 7.2293e-04 - val_loss: 6.9677e-04 - 829ms/epoch - 5ms/step
# Epoch 305/512
# 184/184 - 1s - loss: 7.2341e-04 - val_loss: 6.9681e-04 - 835ms/epoch - 5ms/step
# Epoch 306/512
# 184/184 - 1s - loss: 7.2395e-04 - val_loss: 6.9646e-04 - 822ms/epoch - 4ms/step
# Epoch 307/512
# 184/184 - 1s - loss: 7.2293e-04 - val_loss: 6.9639e-04 - 851ms/epoch - 5ms/step
# Epoch 308/512
# 184/184 - 1s - loss: 7.2192e-04 - val_loss: 6.9609e-04 - 836ms/epoch - 5ms/step
# Epoch 309/512
# 184/184 - 1s - loss: 7.2269e-04 - val_loss: 6.9595e-04 - 838ms/epoch - 5ms/step
# Epoch 310/512
# 184/184 - 1s - loss: 7.2157e-04 - val_loss: 6.9579e-04 - 834ms/epoch - 5ms/step
# Epoch 311/512
# 184/184 - 1s - loss: 7.2248e-04 - val_loss: 6.9563e-04 - 827ms/epoch - 4ms/step
# Epoch 312/512
# 184/184 - 1s - loss: 7.2249e-04 - val_loss: 6.9565e-04 - 843ms/epoch - 5ms/step
# Epoch 313/512
# 184/184 - 1s - loss: 7.2229e-04 - val_loss: 6.9529e-04 - 835ms/epoch - 5ms/step
# Epoch 314/512
# 184/184 - 1s - loss: 7.2278e-04 - val_loss: 6.9515e-04 - 838ms/epoch - 5ms/step
# Epoch 315/512
# 184/184 - 1s - loss: 7.2129e-04 - val_loss: 6.9516e-04 - 834ms/epoch - 5ms/step
# Epoch 316/512
# 184/184 - 1s - loss: 7.2070e-04 - val_loss: 6.9499e-04 - 842ms/epoch - 5ms/step
# Epoch 317/512
# 184/184 - 1s - loss: 7.2092e-04 - val_loss: 6.9501e-04 - 833ms/epoch - 5ms/step
# Epoch 318/512
# 184/184 - 1s - loss: 7.2187e-04 - val_loss: 6.9456e-04 - 843ms/epoch - 5ms/step
# Epoch 319/512
# 184/184 - 1s - loss: 7.2056e-04 - val_loss: 6.9454e-04 - 820ms/epoch - 4ms/step
# Epoch 320/512
# 184/184 - 1s - loss: 7.2069e-04 - val_loss: 6.9423e-04 - 845ms/epoch - 5ms/step
# Epoch 321/512
# 184/184 - 1s - loss: 7.2149e-04 - val_loss: 6.9416e-04 - 826ms/epoch - 4ms/step
# Epoch 322/512
# 184/184 - 1s - loss: 7.2142e-04 - val_loss: 6.9420e-04 - 834ms/epoch - 5ms/step
# Epoch 323/512
# 184/184 - 1s - loss: 7.2114e-04 - val_loss: 6.9375e-04 - 833ms/epoch - 5ms/step
# Epoch 324/512
# 184/184 - 1s - loss: 7.2017e-04 - val_loss: 6.9359e-04 - 837ms/epoch - 5ms/step
# Epoch 325/512
# 184/184 - 1s - loss: 7.2013e-04 - val_loss: 6.9367e-04 - 847ms/epoch - 5ms/step
# Epoch 326/512
# 184/184 - 1s - loss: 7.1984e-04 - val_loss: 6.9353e-04 - 815ms/epoch - 4ms/step
# Epoch 327/512
# 184/184 - 1s - loss: 7.1958e-04 - val_loss: 6.9317e-04 - 839ms/epoch - 5ms/step
# Epoch 328/512
# 184/184 - 1s - loss: 7.1989e-04 - val_loss: 6.9305e-04 - 865ms/epoch - 5ms/step
# Epoch 329/512
# 184/184 - 1s - loss: 7.1783e-04 - val_loss: 6.9286e-04 - 822ms/epoch - 4ms/step
# Epoch 330/512
# 184/184 - 1s - loss: 7.1888e-04 - val_loss: 6.9269e-04 - 821ms/epoch - 4ms/step
# Epoch 331/512
# 184/184 - 1s - loss: 7.1893e-04 - val_loss: 6.9290e-04 - 862ms/epoch - 5ms/step
# Epoch 332/512
# 184/184 - 1s - loss: 7.1850e-04 - val_loss: 6.9278e-04 - 824ms/epoch - 4ms/step
# Epoch 333/512
# 184/184 - 1s - loss: 7.1843e-04 - val_loss: 6.9225e-04 - 852ms/epoch - 5ms/step
# Epoch 334/512
# 184/184 - 1s - loss: 7.1876e-04 - val_loss: 6.9211e-04 - 826ms/epoch - 4ms/step
# Epoch 335/512
# 184/184 - 1s - loss: 7.1862e-04 - val_loss: 6.9195e-04 - 837ms/epoch - 5ms/step
# Epoch 336/512
# 184/184 - 1s - loss: 7.1809e-04 - val_loss: 6.9237e-04 - 824ms/epoch - 4ms/step
# Epoch 337/512
# 184/184 - 1s - loss: 7.1816e-04 - val_loss: 6.9182e-04 - 861ms/epoch - 5ms/step
# Epoch 338/512
# 184/184 - 1s - loss: 7.1736e-04 - val_loss: 6.9179e-04 - 818ms/epoch - 4ms/step
# Epoch 339/512
# 184/184 - 1s - loss: 7.1807e-04 - val_loss: 6.9141e-04 - 849ms/epoch - 5ms/step
# Epoch 340/512
# 184/184 - 1s - loss: 7.1583e-04 - val_loss: 6.9196e-04 - 848ms/epoch - 5ms/step
# Epoch 341/512
# 184/184 - 1s - loss: 7.1746e-04 - val_loss: 6.9116e-04 - 850ms/epoch - 5ms/step
# Epoch 342/512
# 184/184 - 1s - loss: 7.1706e-04 - val_loss: 6.9097e-04 - 830ms/epoch - 5ms/step
# Epoch 343/512
# 184/184 - 1s - loss: 7.1608e-04 - val_loss: 6.9101e-04 - 842ms/epoch - 5ms/step
# Epoch 344/512
# 184/184 - 1s - loss: 7.1656e-04 - val_loss: 6.9070e-04 - 828ms/epoch - 5ms/step
# Epoch 345/512
# 184/184 - 1s - loss: 7.1698e-04 - val_loss: 6.9090e-04 - 846ms/epoch - 5ms/step
# Epoch 346/512
# 184/184 - 1s - loss: 7.1660e-04 - val_loss: 6.9047e-04 - 861ms/epoch - 5ms/step
# Epoch 347/512
# 184/184 - 1s - loss: 7.1557e-04 - val_loss: 6.9026e-04 - 826ms/epoch - 4ms/step
# Epoch 348/512
# 184/184 - 1s - loss: 7.1688e-04 - val_loss: 6.9017e-04 - 822ms/epoch - 4ms/step
# Epoch 349/512
# 184/184 - 1s - loss: 7.1582e-04 - val_loss: 6.9003e-04 - 827ms/epoch - 4ms/step
# Epoch 350/512
# 184/184 - 1s - loss: 7.1589e-04 - val_loss: 6.9057e-04 - 820ms/epoch - 4ms/step
# Epoch 351/512
# 184/184 - 1s - loss: 7.1423e-04 - val_loss: 6.8978e-04 - 842ms/epoch - 5ms/step
# Epoch 352/512
# 184/184 - 1s - loss: 7.1598e-04 - val_loss: 6.8963e-04 - 869ms/epoch - 5ms/step
# Epoch 353/512
# 184/184 - 1s - loss: 7.1557e-04 - val_loss: 6.8946e-04 - 809ms/epoch - 4ms/step
# Epoch 354/512
# 184/184 - 1s - loss: 7.1558e-04 - val_loss: 6.8937e-04 - 854ms/epoch - 5ms/step
# Epoch 355/512
# 184/184 - 1s - loss: 7.1471e-04 - val_loss: 6.9029e-04 - 825ms/epoch - 4ms/step
# Epoch 356/512
# 184/184 - 1s - loss: 7.1481e-04 - val_loss: 6.8913e-04 - 837ms/epoch - 5ms/step
# Epoch 357/512
# 184/184 - 1s - loss: 7.1525e-04 - val_loss: 6.8915e-04 - 844ms/epoch - 5ms/step
# Epoch 358/512
# 184/184 - 1s - loss: 7.1456e-04 - val_loss: 6.8884e-04 - 851ms/epoch - 5ms/step
# Epoch 359/512
# 184/184 - 1s - loss: 7.1455e-04 - val_loss: 6.8864e-04 - 849ms/epoch - 5ms/step
# Epoch 360/512
# 184/184 - 1s - loss: 7.1356e-04 - val_loss: 6.8872e-04 - 841ms/epoch - 5ms/step
# Epoch 361/512
# 184/184 - 1s - loss: 7.1473e-04 - val_loss: 6.8867e-04 - 836ms/epoch - 5ms/step
# Epoch 362/512
# 184/184 - 1s - loss: 7.1416e-04 - val_loss: 6.8828e-04 - 851ms/epoch - 5ms/step
# Epoch 363/512
# 184/184 - 1s - loss: 7.1456e-04 - val_loss: 6.8900e-04 - 831ms/epoch - 5ms/step
# Epoch 364/512
# 184/184 - 1s - loss: 7.1300e-04 - val_loss: 6.8801e-04 - 827ms/epoch - 4ms/step
# Epoch 365/512
# 184/184 - 1s - loss: 7.1299e-04 - val_loss: 6.8796e-04 - 835ms/epoch - 5ms/step
# Epoch 366/512
# 184/184 - 1s - loss: 7.1341e-04 - val_loss: 6.8777e-04 - 848ms/epoch - 5ms/step
# Epoch 367/512
# 184/184 - 1s - loss: 7.1292e-04 - val_loss: 6.8763e-04 - 838ms/epoch - 5ms/step
# Epoch 368/512
# 184/184 - 1s - loss: 7.1358e-04 - val_loss: 6.8761e-04 - 818ms/epoch - 4ms/step
# Epoch 369/512
# 184/184 - 1s - loss: 7.1285e-04 - val_loss: 6.8739e-04 - 828ms/epoch - 5ms/step
# Epoch 370/512
# 184/184 - 1s - loss: 7.1299e-04 - val_loss: 6.8728e-04 - 835ms/epoch - 5ms/step
# Epoch 371/512
# 184/184 - 1s - loss: 7.1166e-04 - val_loss: 6.8716e-04 - 841ms/epoch - 5ms/step
# Epoch 372/512
# 184/184 - 1s - loss: 7.1279e-04 - val_loss: 6.8706e-04 - 847ms/epoch - 5ms/step
# Epoch 373/512
# 184/184 - 1s - loss: 7.1262e-04 - val_loss: 6.8695e-04 - 815ms/epoch - 4ms/step
# Epoch 374/512
# 184/184 - 1s - loss: 7.1101e-04 - val_loss: 6.8713e-04 - 802ms/epoch - 4ms/step
# Epoch 375/512
# 184/184 - 1s - loss: 7.1234e-04 - val_loss: 6.8697e-04 - 822ms/epoch - 4ms/step
# Epoch 376/512
# 184/184 - 1s - loss: 7.1177e-04 - val_loss: 6.8697e-04 - 845ms/epoch - 5ms/step
# Epoch 377/512
# 184/184 - 1s - loss: 7.1152e-04 - val_loss: 6.8642e-04 - 845ms/epoch - 5ms/step
# Epoch 378/512
# 184/184 - 1s - loss: 7.1309e-04 - val_loss: 6.8689e-04 - 829ms/epoch - 5ms/step
# Epoch 379/512
# 184/184 - 1s - loss: 7.1123e-04 - val_loss: 6.8626e-04 - 838ms/epoch - 5ms/step
# Epoch 380/512
# 184/184 - 1s - loss: 7.1250e-04 - val_loss: 6.8627e-04 - 844ms/epoch - 5ms/step
# Epoch 381/512
# 184/184 - 1s - loss: 7.1168e-04 - val_loss: 6.8632e-04 - 808ms/epoch - 4ms/step
# Epoch 382/512
# 184/184 - 1s - loss: 7.1137e-04 - val_loss: 6.8595e-04 - 847ms/epoch - 5ms/step
# Epoch 383/512
# 184/184 - 1s - loss: 7.1145e-04 - val_loss: 6.8590e-04 - 832ms/epoch - 5ms/step
# Epoch 384/512
# 184/184 - 1s - loss: 7.1069e-04 - val_loss: 6.8567e-04 - 838ms/epoch - 5ms/step
# Epoch 385/512
# 184/184 - 1s - loss: 7.1048e-04 - val_loss: 6.8549e-04 - 847ms/epoch - 5ms/step
# Epoch 386/512
# 184/184 - 1s - loss: 7.1088e-04 - val_loss: 6.8540e-04 - 831ms/epoch - 5ms/step
# Epoch 387/512
# 184/184 - 1s - loss: 7.1114e-04 - val_loss: 6.8529e-04 - 828ms/epoch - 5ms/step
# Epoch 388/512
# 184/184 - 1s - loss: 7.1192e-04 - val_loss: 6.8548e-04 - 830ms/epoch - 5ms/step
# Epoch 389/512
# 184/184 - 1s - loss: 7.1017e-04 - val_loss: 6.8556e-04 - 827ms/epoch - 4ms/step
# Epoch 390/512
# 184/184 - 1s - loss: 7.1014e-04 - val_loss: 6.8513e-04 - 825ms/epoch - 4ms/step
# Epoch 391/512
# 184/184 - 1s - loss: 7.0885e-04 - val_loss: 6.8489e-04 - 837ms/epoch - 5ms/step
# Epoch 392/512
# 184/184 - 1s - loss: 7.0896e-04 - val_loss: 6.8495e-04 - 853ms/epoch - 5ms/step
# Epoch 393/512
# 184/184 - 1s - loss: 7.1100e-04 - val_loss: 6.8476e-04 - 843ms/epoch - 5ms/step
# Epoch 394/512
# 184/184 - 1s - loss: 7.0961e-04 - val_loss: 6.8461e-04 - 829ms/epoch - 5ms/step
# Epoch 395/512
# 184/184 - 1s - loss: 7.0937e-04 - val_loss: 6.8488e-04 - 832ms/epoch - 5ms/step
# Epoch 396/512
# 184/184 - 1s - loss: 7.0890e-04 - val_loss: 6.8426e-04 - 819ms/epoch - 4ms/step
# Epoch 397/512
# 184/184 - 1s - loss: 7.0859e-04 - val_loss: 6.8452e-04 - 866ms/epoch - 5ms/step
# Epoch 398/512
# 184/184 - 1s - loss: 7.0887e-04 - val_loss: 6.8402e-04 - 819ms/epoch - 4ms/step
# Epoch 399/512
# 184/184 - 1s - loss: 7.0913e-04 - val_loss: 6.8404e-04 - 828ms/epoch - 4ms/step
# Epoch 400/512
# 184/184 - 1s - loss: 7.0802e-04 - val_loss: 6.8425e-04 - 861ms/epoch - 5ms/step
# Epoch 401/512
# 184/184 - 1s - loss: 7.0828e-04 - val_loss: 6.8383e-04 - 851ms/epoch - 5ms/step
# Epoch 402/512
# 184/184 - 1s - loss: 7.0961e-04 - val_loss: 6.8359e-04 - 831ms/epoch - 5ms/step
# Epoch 403/512
# 184/184 - 1s - loss: 7.0831e-04 - val_loss: 6.8355e-04 - 825ms/epoch - 4ms/step
# Epoch 404/512
# 184/184 - 1s - loss: 7.0791e-04 - val_loss: 6.8342e-04 - 865ms/epoch - 5ms/step
# Epoch 405/512
# 184/184 - 1s - loss: 7.0858e-04 - val_loss: 6.8338e-04 - 853ms/epoch - 5ms/step
# Epoch 406/512
# 184/184 - 1s - loss: 7.0712e-04 - val_loss: 6.8320e-04 - 844ms/epoch - 5ms/step
# Epoch 407/512
# 184/184 - 1s - loss: 7.0900e-04 - val_loss: 6.8327e-04 - 851ms/epoch - 5ms/step
# Epoch 408/512
# 184/184 - 1s - loss: 7.0849e-04 - val_loss: 6.8298e-04 - 827ms/epoch - 4ms/step
# Epoch 409/512
# 184/184 - 1s - loss: 7.0782e-04 - val_loss: 6.8295e-04 - 852ms/epoch - 5ms/step
# Epoch 410/512
# 184/184 - 1s - loss: 7.0704e-04 - val_loss: 6.8271e-04 - 849ms/epoch - 5ms/step
# Epoch 411/512
# 184/184 - 1s - loss: 7.0641e-04 - val_loss: 6.8262e-04 - 845ms/epoch - 5ms/step
# Epoch 412/512
# 184/184 - 1s - loss: 7.0707e-04 - val_loss: 6.8257e-04 - 838ms/epoch - 5ms/step
# Epoch 413/512
# 184/184 - 1s - loss: 7.0591e-04 - val_loss: 6.8317e-04 - 859ms/epoch - 5ms/step
# Epoch 414/512
# 184/184 - 1s - loss: 7.0761e-04 - val_loss: 6.8240e-04 - 850ms/epoch - 5ms/step
# Epoch 415/512
# 184/184 - 1s - loss: 7.0609e-04 - val_loss: 6.8300e-04 - 847ms/epoch - 5ms/step
# Epoch 416/512
# 184/184 - 1s - loss: 7.0697e-04 - val_loss: 6.8210e-04 - 856ms/epoch - 5ms/step
# Epoch 417/512
# 184/184 - 1s - loss: 7.0648e-04 - val_loss: 6.8198e-04 - 845ms/epoch - 5ms/step
# Epoch 418/512
# 184/184 - 1s - loss: 7.0642e-04 - val_loss: 6.8191e-04 - 844ms/epoch - 5ms/step
# Epoch 419/512
# 184/184 - 1s - loss: 7.0619e-04 - val_loss: 6.8189e-04 - 845ms/epoch - 5ms/step
# Epoch 420/512
# 184/184 - 1s - loss: 7.0656e-04 - val_loss: 6.8182e-04 - 828ms/epoch - 5ms/step
# Epoch 421/512
# 184/184 - 1s - loss: 7.0532e-04 - val_loss: 6.8166e-04 - 829ms/epoch - 5ms/step
# Epoch 422/512
# 184/184 - 1s - loss: 7.0567e-04 - val_loss: 6.8152e-04 - 845ms/epoch - 5ms/step
# Epoch 423/512
# 184/184 - 1s - loss: 7.0622e-04 - val_loss: 6.8143e-04 - 812ms/epoch - 4ms/step
# Epoch 424/512
# 184/184 - 1s - loss: 7.0598e-04 - val_loss: 6.8147e-04 - 802ms/epoch - 4ms/step
# Epoch 425/512
# 184/184 - 1s - loss: 7.0524e-04 - val_loss: 6.8116e-04 - 829ms/epoch - 5ms/step
# Epoch 426/512
# 184/184 - 1s - loss: 7.0471e-04 - val_loss: 6.8104e-04 - 812ms/epoch - 4ms/step
# Epoch 427/512
# 184/184 - 1s - loss: 7.0535e-04 - val_loss: 6.8108e-04 - 827ms/epoch - 4ms/step
# Epoch 428/512
# 184/184 - 1s - loss: 7.0545e-04 - val_loss: 6.8129e-04 - 844ms/epoch - 5ms/step
# Epoch 429/512
# 184/184 - 1s - loss: 7.0493e-04 - val_loss: 6.8081e-04 - 845ms/epoch - 5ms/step
# Epoch 430/512
# 184/184 - 1s - loss: 7.0545e-04 - val_loss: 6.8089e-04 - 843ms/epoch - 5ms/step
# Epoch 431/512
# 184/184 - 1s - loss: 7.0513e-04 - val_loss: 6.8064e-04 - 830ms/epoch - 5ms/step
# Epoch 432/512
# 184/184 - 1s - loss: 7.0624e-04 - val_loss: 6.8050e-04 - 831ms/epoch - 5ms/step
# Epoch 433/512
# 184/184 - 1s - loss: 7.0368e-04 - val_loss: 6.8039e-04 - 841ms/epoch - 5ms/step
# Epoch 434/512
# 184/184 - 1s - loss: 7.0484e-04 - val_loss: 6.8064e-04 - 843ms/epoch - 5ms/step
# Epoch 435/512
# 184/184 - 1s - loss: 7.0528e-04 - val_loss: 6.8023e-04 - 824ms/epoch - 4ms/step
# Epoch 436/512
# 184/184 - 1s - loss: 7.0488e-04 - val_loss: 6.8054e-04 - 835ms/epoch - 5ms/step

# %%
# # Define per-fold score containers
# acc_per_fold = []
# loss_per_fold = []

# # Define the K-fold Cross Validator
# kfold = KFold(n_splits=num_folds, shuffle=True)

# # K-fold Cross Validation model evaluation
# fold_no = 1
# best_model = None
# best_loss = np.inf

# # Settting up early stopping callbacks
# stop_early = tf.keras.callbacks.EarlyStopping(
#     monitor="val_loss",
#     min_delta=1e-4,
#     patience=10,
#     mode="auto",
#     baseline=None,
#     restore_best_weights=True,
# )

# # Check and find the best model form k-fold cross validation (or detect wether it's overtrining or not).
# for train, valid in kfold.split(train_x, train_y):
#     # Define the model architecture
#     model = build_model()

#     # Generate a print
#     print(f"Training for fold {fold_no} ...")

#     # Fit the model
#     history = model.fit(
#         data_gen(train_x, train_y, train),
#         steps_per_epoch=len(train) // batch_size,
#         validation_data=data_gen(train_x, train_y, valid),
#         validation_steps=len(valid) // batch_size,
#         epochs=epochs,
#         verbose=0,
#         callbacks=[stop_early],
#     )

#     # Generate generalization metrics
#     scores = model.evaluate(train_x[valid], train_y[valid], verbose=0)
#     print(
#         f"Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%"
#     )
#     acc_per_fold.append(scores[1] * 100)
#     loss_per_fold.append(scores[0])

#     # Check if this model is better than the previous best model
#     if scores[0] < best_loss:
#         best_loss = scores[0]
#         best_model = model
#         best_history = history

#     # Plotting training results
#     print(f"Plotting fold {fold_no} loss history...")
#     plot.plot_loss_history(history, logy=True)

#     # Increase fold number
#     fold_no = fold_no + 1

# # == Provide average scores ==
# best_model.summary()
# print(
#     f"""{'-'*72}
# Score per fold"""
# )
# for i in range(0, len(acc_per_fold)):
#     print(
#         f"""{'-'*72}
# > Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%"""
#     )
# print(
#     f"""{'-'*72}
# Average scores for all folds:
# > Accuracy: {np.mean(acc_per_fold)}% (+- {np.std(acc_per_fold)})
# > Loss: {np.mean(loss_per_fold)}
# {'-'*72}"""
# )

# %%
# save model
model.save("DNN_modified.h5", save_format="h5", overwrite=True)
# predict
pred_y = model.predict(test_x)
sig_pred = pred_y
sig_truth = test_y
# Out:
#    1/4402 [..............................] - ETA: 4:59
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4402/4402 [==============================] - 5s 1ms/step

# %%
# range = [0.4, 0.6]

# plot.plot_hist(
#     [sig_truth[:, 0], sig_pred[:, 0]],
#     [r"$E_{truth}^{\nu\nu}$", r"$E_{pred}^{\nu\nu}$"],
#     r"Signal: Normalized $E$ of $\nu\nu$",
#     # range=range,
#     xlabel=r"$E$ [GeV]",
# )

# plot.plot_loss_history(history, logy=False)

# plot.plot_2d_histogram(
#     sig_pred[:, 0],
#     sig_truth[:, 0],
#     "Signal: "
#     + r"$E^{\nu\nu}$ "
#     + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth[:,0], sig_pred[:,0])[0]:.3f}",
#     # range=range,
# )

# %%
print(f"Truth mean: {np.mean(sig_truth[:,0]):.3f}, std: {np.std(sig_truth[:,0]):.3f}")
# Out:
# Truth mean: 0.498, std: 0.035

# %%
from sklearn.metrics import mean_squared_error

range = [0.43, 0.57]

plot.plot_hist(
    [sig_truth[:, 0], sig_pred[:, 0]],
    [r"$p_{z\ truth}^{\nu\nu}$", r"$p_{z\ pred}^{\nu\nu}$"],
    r"Sig. norm. $p^{\nu\nu}_{z}$" + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth[:,0], sig_pred[:,0])):.3f}",
    range=range,
    xlabel=r"[Norm. $p_{z}$ unit]",
)

plot.plot_loss_history(history, logx=True, logy=True)

plot.plot_2d_histogram(
    sig_truth[:, 0],
    sig_pred[:, 0],
    r"Sig. $p_{z}^{\nu\nu}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth[:,0], sig_pred[:,0])[0]:.3f}",
    range=range,
)

# %%
STOP IT
# Out:
#   Cell In[32], line 1
#     STOP IT
#          ^
# SyntaxError: invalid syntax

# %%
# Background
processor = gd.DataProcessor(sampling=sampling, processor=10)
path = "/root/data/truth/background/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 10
#
# ['/root/data/truth/background/CGLMP.npz', '/root/data/truth/background/Higgs.npz', '/root/data/truth/background/LeadLepton.npz', '/root/data/truth/background/LeptonM.npz', '/root/data/truth/background/LeptonP.npz', '/root/data/truth/background/LmNu.npz', '/root/data/truth/background/LpNu.npz', '/root/data/truth/background/MET.npz', '/root/data/truth/background/WmBoson.npz', '/root/data/truth/background/WpBoson.npz', '/root/data/truth/background/diLepton.npz', '/root/data/truth/background/subLeadLepton.npz', '/root/data/truth/background/xi_xyz.npz']

# %%
# inputs -> observed params
lep_p = processor.process_part(data.LepP)[cut_pre]
lep_m = processor.process_part(data.LepM)[cut_pre]
lep_kin = pd.concat([lep_p, lep_m], axis=1)
MET = processor.process_MET(data.MET).iloc[:, 1:3][cut_pre]
obs_kin = pd.concat([MET, lep_kin], axis=1)
print("obs_kin shape:", obs_kin.shape)
print(obs_kin.head(3))
print()

# targets -> interested unknowns
int_kin = pd.DataFrame(
    processor.process_dipart(data.NuP, data.NuM)[["pz"]][cut_pre]
)
print("int_kin shape:", int_kin.shape)
print(int_kin.head(3))
print()

del (processor, lep_p, lep_m, MET)
gc.collect()
# Out:
# obs_kin shape: (469444, 10)
#       MET_px     MET_py           E         px         py          pz  \
# 2  -5.946616   4.867948   47.815059 -83.703953 -24.220172  272.909312
# 3  18.223839  25.588102   43.335184 -43.176113 -11.674435  146.792906
# 5 -34.948406  25.908608  573.844687  18.904609  -1.221495  144.971016
#
#             E         px         py          pz
# 2   17.210883  34.787719  17.783029  240.510469
# 3  181.251000  40.249180 -13.152956  586.455063
# 5   22.750127  28.911910 -22.002918  339.354000
#
# int_kin shape: (469444, 2)
#             E           pz
# 2  132.413469   661.401672
# 3  158.960164   416.509203
# 5  904.437250  1338.291234
# 53340

# %%
# SCALAR_obs_std_bkg = StandardScaler()
# obs_kin = SCALAR_obs_std_bkg.fit_transform(obs_kin)
SCALAR_obs_qt_bkg = QuantileTransformer(output_distribution='normal')
obs_kin = SCALAR_obs_qt_bkg.fit_transform(obs_kin)

# SCALAR_int_std_bkg = StandardScaler()
# int_kin = SCALAR_int_std_bkg.fit_transform(int_kin)
SCALAR_int_qt_bkg = QuantileTransformer(output_distribution='normal')
int_kin = SCALAR_int_qt_bkg.fit_transform(int_kin)

x, y = obs_kin[indices_arr], int_kin[indices_arr]

print(f"X:\ndata shape: {x.shape};\nY:\ndata shape: {y.shape}.")
print()
# Out:
# X:
# data shape: (469444, 10);
# Y:
# data shape: (469444, 2).

# %%
y_pred = model.predict(x)
bkg_pred = y_pred
bkg_truth = y
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[317], line 1
# ----> 1 y_pred = model.predict(x)
#       2 bkg_pred = y_pred
#       3 bkg_truth = y
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'model_14/dense_76/MatMul' defined at (most recent call last):
#     File "/root/miniconda3/envs/tf/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/root/miniconda3/envs/tf/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#       app.start()
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#       self.io_loop.start()
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/root/miniconda3/envs/tf/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#       self._run_once()
#     File "/root/miniconda3/envs/tf/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#       handle._run()
#     File "/root/miniconda3/envs/tf/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#       await self.process_one()
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#       await dispatch(*args)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#       await result
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#       reply_content = await reply_content
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#       result = self._run_cell(
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#       result = runner(coro)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_1651407/1758149819.py", line 1, in <module>
#       y_pred = model.predict(x)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py", line 2554, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py", line 2341, in predict_function
#       return step_function(self, iterator)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py", line 2327, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py", line 2315, in run_step
#       outputs = model.predict_step(data)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py", line 2283, in predict_step
#       return self(x, training=False)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py", line 569, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1150, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/functional.py", line 512, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/functional.py", line 669, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/base_layer.py", line 1150, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/layers/core/dense.py", line 241, in call
#       outputs = tf.matmul(a=inputs, b=self.kernel)
# Node: 'model_14/dense_76/MatMul'
# Matrix size-incompatible: In[0]: [32,10], In[1]: [14,512]
# 	 [[{{node model_14/dense_76/MatMul}}]] [Op:__inference_predict_function_1253131]

# %%
range = [
    np.max([bkg_pred[:, 0].min(), bkg_truth[:, 0].min()]),
    np.min([bkg_pred[:, 0].max(), bkg_truth[:, 0].max()]),
]

plot.plot_hist(
    [bkg_truth[:, 0], bkg_pred[:, 0]],
    [r"$E_{truth}^{\nu\nu}$", r"$E_{pred}^{\nu\nu}$"],
    "Non-resnt WW: " + r"Normalized $E$ of $\nu\nu$",
    range=range,
    xlabel=r"$E$ [GeV]",
)

plot.plot_2d_histogram(
    bkg_pred[:, 0],
    bkg_truth[:, 0],
    "Non-resnt WW: "
    + r"$E^{\nu\nu}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(bkg_truth[:,0], bkg_pred[:,0])[0]:.3f}",
    range=range,
)

# %%
range = [
    np.max([bkg_pred[:, 1].min(), bkg_truth[:, 1].min()]),
    np.min([bkg_pred[:, 1].max(), bkg_truth[:, 1].max()]),
]

plot.plot_hist(
    [bkg_truth[:, 1], bkg_pred[:, 1]],
    [r"$p_{z\ truth}^{\nu\nu}$", r"$p_{z\ pred}^{\nu\nu}$"],
    r"Non-resnt WW: Normalized $p_{z}$ of $\nu\nu$",
    range=range,
    xlabel=r"$p_{z}$ [GeV]",
)

plot.plot_2d_histogram(
    bkg_truth[:, 1],
    bkg_pred[:, 1],
    "Non-resnt WW: "
    + r"$p_{z}^{\nu\nu}$"
    + f" with Pearson coeff: {sp.stats.pearsonr(bkg_truth[:,1], bkg_pred[:,1])[0]:.3f}",
    range=range,
)

time_end = time()
print(f"Time cost: {(time_end - time_start):.2f} s.")
# Out:
# Time cost: 151.15 s.
