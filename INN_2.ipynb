# %%
# %reset -sf

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from flow import *
from utils import *
import get_data as gd
import gc

import tensorflow as tf

print(tf.__version__)
print(tf.config.list_physical_devices())
print()
# Out:
# 2023-11-22 09:00:00.838562: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.13.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
import mplhep as hep

hep.style.use("ATLAS")

# %% [markdown]
# ### Load data

# %%
processor = gd.DataProcessor()
path = "/root/work/truth/signal/*npz"
processor.load_files(path)

(
    CGLMP,
    Higgs,
    LeadLep,
    LepM,
    LepP,
    NuM,
    NuP,
    MET,
    Wm,
    Wp,
    diLep,
    SubLep,
    Xi,
) = processor.files
GEV = 1e3
# Out:
# ['/root/work/truth/signal/CGLMP.npz', '/root/work/truth/signal/Higgs.npz', '/root/work/truth/signal/LeadLepton.npz', '/root/work/truth/signal/LeptonM.npz', '/root/work/truth/signal/LeptonP.npz', '/root/work/truth/signal/LmNu.npz', '/root/work/truth/signal/LpNu.npz', '/root/work/truth/signal/MET.npz', '/root/work/truth/signal/WmBoson.npz', '/root/work/truth/signal/WpBoson.npz', '/root/work/truth/signal/diLepton.npz', '/root/work/truth/signal/subLeadLepton.npz', '/root/work/truth/signal/xi_xyz.npz']

# %%
cut_pre_pt_lead = LeadLep["pt"] > 22 * GEV
cut_pre_pt_sub = SubLep["pt"] > 15 * GEV
cut_pre_dilep_m = diLep["m"] > 10 * GEV
cut_pre_pt_miss = MET["pt"] > 20 * GEV
cut_pre = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss

del cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss

# %%
def hist(
    data=None,
    label=None,
    title=r"Normalized $p^{miss}_{x}$ of MET",
    range=None,
    unit="GeV",
):
    if data is None:
        data = [MET["px"], MET[cut_pre]["px"]]
    if label is None:
        label = [r"$MET_{x}$", r"$MET^{cut}_{x}$"]
    if range is None:
        min_val = np.min(data[0])
        max_val = np.max(data[0])
        range_val = [min_val, max_val]
    else:
        range_val = range

    n_bins = 100
    fig, axs = plt.subplots(
        2,
        1,
        figsize=(6, 6),
        dpi=100,
        sharex=True,
        gridspec_kw={"height_ratios": [3, 1], "hspace": 0.1},
    )  # adjust hspace
    arr0 = axs[0].hist(
        data[0],
        bins=n_bins,
        histtype="step",
        density=True,
        color="red",
        linewidth=2,
        label=label[0],
        range=range_val,
    )
    arr1 = axs[0].hist(
        data[1],
        bins=n_bins,
        histtype="step",
        density=True,
        color="blue",
        linewidth=2,
        label=label[1],
        range=range_val,
    )
    axs[0].legend()
    axs[0].set_title(title, fontsize=20)
    axs[0].tick_params(
        axis="x", which="both", bottom=False, top=False, labelbottom=False
    )  # remove x-ticks
    axs[0].set_ylabel("(Normalized) counts", fontsize=14)

    ratio = np.divide(arr1[0], arr0[0], where=(arr0[0] != 0))
    axs[1].set_xlabel(label[0] + f" [{unit}]", fontsize=14)
    axs[1].plot(arr0[1][:-1], ratio, "--", color="black", linewidth=1)
    axs[1].axhline(
        y=1, color="grey", linestyle="--", alpha=0.5
    )  # add horizontal line at y=1
    axs[1].set_ylabel("ratio", fontsize=14)
    axs[1].tick_params(axis="x", which="both", pad=10)  # adjust pad
    plt.show()
    plt.close()

# %%
hist(
    [MET["px"] / GEV, MET[cut_pre]["px"] / GEV],
    [r"$MET_{x}$", r"$MET^{cut}_{x}$"],
    r"Normalized $p^{miss}_{x}$ of MET",
    [-150, 150],
)
hist(
    [MET["py"] / GEV, MET[cut_pre]["py"] / GEV],
    [r"$MET_{y}$", r"$MET^{cut}_{y}$"],
    r"Normalized $p^{miss}_{y}$ of MET",
    [-150, 150],
)

# %%
hist(
    [CGLMP["Bxy"], CGLMP[cut_pre]["Bxy"]],
    [r"$B_{xy}$", r"$B_{xy}^{cut}$"],
    r"Normalized $B_{xy}$ of CGLMP",
    unit="null",
)
hist(
    [CGLMP["Bzx"], CGLMP[cut_pre]["Bzx"]],
    [r"$B_{zx}$", r"$B_{zx}^{cut}$"],
    r"Normalized $B_{zx}$ of CGLMP",
    unit="null",
)
hist(
    [CGLMP["Byz"], CGLMP[cut_pre]["Byz"]],
    [r"$B_{yz}$", r"$B_{yz}^{cut}$"],
    r"Normalized $B_{yz}$ of CGLMP",
    unit="null",
)

# %%
dinu = NuP + NuM
hist(
    [dinu["E"] / GEV, dinu[cut_pre]["E"] / GEV],
    [r"$E$", r"$E^{cut}$"],
    r"Normalized $E$ of $\nu\nu$",
    [0, 0.6e3],
)
hist(
    [dinu["px"] / GEV, dinu[cut_pre]["px"] / GEV],
    [r"$p_{x}$", r"$p^{cut}_{x}$"],
    r"Normalized $p_{x}$ of $\nu\nu$",
    [-150, 150],
)
hist(
    [dinu["py"] / GEV, dinu[cut_pre]["py"] / GEV],
    [r"$p_{y}$", r"$p^{cut}_{y}$"],
    r"Normalized $p_{y}$ of $\nu\nu$",
    [-150, 150],
)
hist(
    [dinu["pz"] / GEV, dinu[cut_pre]["pz"] / GEV],
    [r"$p_{z}$", r"$p^{cut}_{z}$"],
    r"Normalized $p_{z}$ of $\nu\nu$",
    [-400, 400],
)

# %%
# observed (Y)
## leps
lep_kin = (
    pd.concat([LepP[cut_pre].iloc[:, 0:4], LepM[cut_pre].iloc[:, 0:4]], axis=1) / GEV
)
lep_kin_exp = pd.concat(
    [
        LepP[cut_pre].iloc[:, 4:6] / GEV,
        LepP[cut_pre].iloc[:, 6:-1],
        LepM[cut_pre].iloc[:, 4:6] / GEV,
        LepM[cut_pre].iloc[:, 6:-1],
    ],  # discard the last column (y) owing to inf problems when stdscalar
    axis=1,
)
## MET
MET_kin = MET[cut_pre].iloc[:, 1:3] / GEV
CGLMP = CGLMP[cut_pre]
# y -> observed params
MET_kin = pd.concat([MET_kin, lep_kin], axis=1)
print("MET_kin shape:", MET_kin.shape)
print(MET_kin.head(3))
print()

# interest (X)
# x -> interested unknowns
## neus
nu_kin = dinu[cut_pre].iloc[:, 0:4] / GEV
nu_kin_exp = pd.concat(
    [
        NuP[cut_pre].iloc[:, 4:6] / GEV,
        NuP[cut_pre].iloc[:, 6:-1],
        NuM[cut_pre].iloc[:, 4:6] / GEV,
        NuM[cut_pre].iloc[:, 6:-1],
    ],  # discard the last column (y) owing to inf problems when stdscalar
    axis=1,
)
dinu_kin = pd.concat(
    [
        nu_kin,
    ],
    axis=1,
)
print("dinu_kin shape:", dinu_kin.shape)
print(dinu_kin.head(3))
print()

del processor  # Clear the instance
del (
    CGLMP,
    Higgs,
    LeadLep,
    LepM,
    LepP,
    NuM,
    NuP,
    MET,
    Wm,
    Wp,
    diLep,
    SubLep,
    Xi,
)  # Clear the dataframes
del (lep_kin, nu_kin, nu_kin_exp)
gc.collect()
# Out:
# MET_kin shape: (1378510, 10)
#            px         py           E         px         py          pz  \
# 7   96.335650  47.095450   19.500895  -4.561588  18.924410   -1.154271
# 9  -26.992604 -70.883859  164.814766  34.397141   2.031300 -161.172625
# 10  44.222846 -15.383637   47.669113 -26.605045 -17.256748   35.590859
#
#             E         px         py         pz
# 7   43.361348  42.407754  -4.632000   7.767462
# 9   70.592648  29.001777   1.896990 -64.332027
# 10  90.238664 -23.868604  32.986602  80.530680
#
# dinu_kin shape: (1378510, 4)
#              E         px         py          pz
# 7   153.433431  96.335650  47.095450 -105.565620
# 9   187.088398 -26.992604 -70.883859 -170.813820
# 10  105.357433  44.222846 -15.383637   92.722389
# 54457

# %% [markdown]
# ### Preprocessing

# %%
from sklearn.model_selection import train_test_split

# sampling
np.random.seed(42)  # set random seed
indices_arr = np.arange(dinu_kin.shape[0], dtype="int")
indices_arr = np.random.choice(indices_arr, int(1e3))

# normalize
from sklearn.preprocessing import StandardScaler

SCALAR_int = StandardScaler()
dinu_kin = SCALAR_int.fit_transform(dinu_kin.iloc[indices_arr])
print(f"mean: {dinu_kin.mean()}; std: {dinu_kin.std()}")

SCALAR_MET = StandardScaler()
MET_kin = SCALAR_MET.fit_transform(MET_kin.iloc[indices_arr])
print(f"mean: {MET_kin.mean()}; std: {MET_kin.std()}")

train_indices, test_indices = train_test_split(
    np.arange(len(indices_arr.flatten())),
    train_size=0.8,
    test_size=0.2,
    random_state=42,
)

train_x = dinu_kin[train_indices]
test_x = dinu_kin[test_indices]
train_y = MET_kin[train_indices]
test_y = MET_kin[test_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nTesting data shape: {test_y.shape}."
)
print()
# Out:
# mean: -2.176037128265307e-17; std: 1.0
# mean: 1.2434497875801753e-18; std: 1.0
# X (Interest)
# Training data shape: (800, 4);
# Testing data shape: (200, 4).
# Y (Observed)
# Training data shape: (800, 10);
# Testing data shape: (200, 10).

# %% [markdown]
# ### Setup

# %%
# setup

# *hyperparameter
n_couple_layer = 3
n_hid_layer = 3
n_hid_dim = 512
learning_rate = 1e-5

# * hyperparameter
n_batch = 256
n_epoch = 64
n_display = n_batch

# * hyperparameter
w1 = 1.0  # related to pred loss
w2 = 5.0  # related to latent loss
w3 = 5.0  # related to rev loss
loss_factor = 1.0  # related to rev loss

# interest (momentum)
x_dim = train_x.shape[1]
# observed (MET)
y_dim = train_y.shape[1]

# * hyperparameter
# z_dim = x_dim - y_dim # we only take intrinsic dimension into account
z_dim = 2

tot_dim = y_dim + z_dim
pad_dim = tot_dim - x_dim

# Preprocess
## Pad data
X = train_x.reshape((-1, x_dim))
# print("pad_dim", pad_dim)
pad_x = np.zeros((X.shape[0], pad_dim))
print("pad_x", pad_x.shape)
# print("pad_x", pad_x.shape)
x = np.concatenate([X, pad_x], axis=-1).astype("float32")
print("x", x.shape)
z = np.random.multivariate_normal([0.0] * z_dim, np.eye(z_dim), X.shape[0]).astype(
    "float32"
)
y_hat = train_y.reshape(-1, y_dim)
print("y", y_hat.shape)
print("z", z.shape)
y = np.concatenate([z, y_hat], axis=-1).astype("float32")

print(f"Input dataset shape -> X:{x.shape}, Y: {y.shape}")

n_sample = X.shape[0]
print("n_sample", n_sample)
n_data = n_sample * train_y.shape[1]
print("n_data", n_data)
print()

# Make dataset generator
x_data = tf.data.Dataset.from_tensor_slices(x)
y_data = tf.data.Dataset.from_tensor_slices(y)
dataset = (
    tf.data.Dataset.zip((x_data, y_data))
    .shuffle(buffer_size=X.shape[0])
    .batch(n_batch, drop_remainder=True)
    .repeat()
)
# Out:
# pad_x (800, 8)
# x (800, 12)
# y (800, 10)
# z (800, 2)
# Input dataset shape -> X:(800, 12), Y: (800, 12)
# n_sample 800
# n_data 8000
# 2023-11-22 09:00:21.606183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46696 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-22 09:00:21.607036: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46696 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:25:00.0, compute capability: 8.6

# %% [markdown]
# ### Initialize the model

# %%
model = NVP(tot_dim, n_couple_layer, n_hid_layer, n_hid_dim, name="NVP")
x = tfk.Input((tot_dim,))
model(x)
model.summary()
# Out:
# Model: "NVP"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer0 (TwoNVPCouplingLaye  multiple                  1070116
#  rs)
#
#  Layer1 (TwoNVPCouplingLaye  multiple                  1070116
#  rs)
#
#  Layer2 (TwoNVPCouplingLaye  multiple                  1070116
#  rs)
#
# =================================================================
# Total params: 3210348 (12.25 MB)
# Trainable params: 3210312 (12.25 MB)
# Non-trainable params: 36 (288.00 Byte)
# _________________________________________________________________

# %%
class Trainer(tfk.Model):
    def __init__(
        self,
        model,
        x_dim,
        y_dim,
        z_dim,
        tot_dim,
        n_couple_layer,
        n_hid_layer,
        n_hid_dim,
        shuffle_type="reverse",
    ):
        super(Trainer, self).__init__()
        self.model = model
        self.x_dim = x_dim
        self.y_dim = y_dim
        self.z_dim = z_dim
        self.tot_dim = tot_dim
        self.x_pad_dim = tot_dim - x_dim
        self.y_pad_dim = tot_dim - (y_dim + z_dim)
        self.n_couple_layer = n_couple_layer
        self.n_hid_layer = n_hid_layer
        self.n_hid_dim = n_hid_dim
        self.shuffle_type = shuffle_type

        self.w1 = w1  # related to pred loss
        self.w2 = w2  # related to latent loss
        self.w3 = w3  # related to rev loss
        self.loss_factor = loss_factor  # related to rev loss
        self.loss_fit = MSE
        self.loss_latent = MMD_multiscale
        self.loss_backward = MMD_multiscale

    def train_step(self, data):
        x_data, y_data = data
        x = x_data[:, : self.x_dim]
        y = y_data[:, -self.y_dim :]
        z = y_data[:, : self.z_dim]
        y_short = tf.concat([z, y], axis=-1)

        # Forward loss
        with tf.GradientTape() as tape:
            y_out = self.model(x_data)
            pred_loss = self.w1 * self.loss_fit(
                y_data[:, self.z_dim :], y_out[:, self.z_dim :]
            )  # [zeros, y] <=> [zeros, yhat]
            output_block_grad = tf.concat(
                [y_out[:, : self.z_dim], y_out[:, -self.y_dim :]], axis=-1
            )  # take out [z, y] only (not zeros)
            latent_loss = self.w2 * self.loss_latent(
                y_short, output_block_grad
            )  # [z, y] <=> [zhat, yhat]
            forward_loss = pred_loss + latent_loss
        grads_forward = tape.gradient(forward_loss, self.model.trainable_weights)
        self.optimizer.apply_gradients(zip(grads_forward, self.model.trainable_weights))

        # Backward loss
        with tf.GradientTape() as tape:
            x_rev = self.model.inverse(y_data)
            # rev_loss = self.w3 * self.loss_factor * self.loss_fit(x_rev, x_data)
            rev_loss = self.w3 * self.loss_factor * self.loss_backward(x_rev, x_data)
        grads_backward = tape.gradient(rev_loss, self.model.trainable_weights)
        self.optimizer.apply_gradients(
            zip(grads_backward, self.model.trainable_weights)
        )

        total_loss = forward_loss + latent_loss + rev_loss
        return {
            "total_loss": total_loss,
            "forward_loss": forward_loss,
            "latent_loss": latent_loss,
            "rev_loss": rev_loss,
        }

    def test_step(self, data):
        x_data, y_data = data
        return NotImplementedError

# %%
trainer = Trainer(
    model, x_dim, y_dim, z_dim, tot_dim, n_couple_layer, n_hid_layer, n_hid_dim
)
trainer.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate))

# %% [markdown]
# ### Training

# %%
# Load the TensorBoard notebook extension.
import datetime


LossFactor = UpdateLossFactor(n_epoch)
logger = NBatchLogger(n_display, n_epoch)

# set log file
# %rm -r ./logs
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# set callback of tensorboard
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=5, write_graph=True, write_images=False,)

hist = trainer.fit(
    dataset,
    batch_size=n_batch,
    epochs=n_epoch,
    steps_per_epoch=n_data // n_batch,
    callbacks=[logger, LossFactor, tensorboard_callback],
    verbose=2,
)
# Out:
# === Started at 2023-11-22 09h:00m:22s ===
# Epoch 1/64
# 2023-11-22 09:00:27.596918: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-22 09:00:27.603947: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f9fe002a650 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-22 09:00:27.603989: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-11-22 09:00:27.604006: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-11-22 09:00:27.610796: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-22 09:00:27.750564: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-11-22 09:00:27.876105: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  2023-11-22 09h:00m:33s | Epoch: 01/64 | total_loss=3.911577 forward_loss=2.244601 latent_loss=0.916210 rev_loss=0.750765
# 31/31 - 11s - total_loss: 3.9116 - forward_loss: 2.2446 - latent_loss: 0.9162 - rev_loss: 0.7508 - 11s/epoch - 360ms/step
# Epoch 2/64
# 31/31 - 1s - total_loss: 3.2434 - forward_loss: 1.9810 - latent_loss: 0.7145 - rev_loss: 0.5478 - 682ms/epoch - 22ms/step
# Epoch 3/64
# 31/31 - 1s - total_loss: 2.5899 - forward_loss: 1.6650 - latent_loss: 0.5268 - rev_loss: 0.3981 - 684ms/epoch - 22ms/step
# Epoch 4/64
# 31/31 - 1s - total_loss: 2.5284 - forward_loss: 1.6975 - latent_loss: 0.4873 - rev_loss: 0.3436 - 687ms/epoch - 22ms/step
# Epoch 5/64
# 31/31 - 1s - total_loss: 2.4020 - forward_loss: 1.6044 - latent_loss: 0.4806 - rev_loss: 0.3171 - 646ms/epoch - 21ms/step
# Epoch 6/64
# 31/31 - 1s - total_loss: 2.1886 - forward_loss: 1.5536 - latent_loss: 0.3970 - rev_loss: 0.2380 - 1s/epoch - 40ms/step
# Epoch 7/64
# 31/31 - 1s - total_loss: 1.9303 - forward_loss: 1.3635 - latent_loss: 0.3686 - rev_loss: 0.1981 - 708ms/epoch - 23ms/step
# Epoch 8/64
# 31/31 - 1s - total_loss: 1.6837 - forward_loss: 1.1038 - latent_loss: 0.3714 - rev_loss: 0.2084 - 688ms/epoch - 22ms/step
# Epoch 9/64
# 31/31 - 1s - total_loss: 1.7741 - forward_loss: 1.2886 - latent_loss: 0.3184 - rev_loss: 0.1671 - 663ms/epoch - 21ms/step
# Epoch 10/64
# 31/31 - 1s - total_loss: 1.4114 - forward_loss: 1.0006 - latent_loss: 0.2695 - rev_loss: 0.1414 - 705ms/epoch - 23ms/step
# Epoch 11/64
# 31/31 - 1s - total_loss: 1.3891 - forward_loss: 1.0215 - latent_loss: 0.2602 - rev_loss: 0.1074 - 1s/epoch - 41ms/step
# Epoch 12/64
# 31/31 - 1s - total_loss: 1.3194 - forward_loss: 0.9640 - latent_loss: 0.2533 - rev_loss: 0.1021 - 694ms/epoch - 22ms/step
# Epoch 13/64
# 31/31 - 1s - total_loss: 1.0956 - forward_loss: 0.7968 - latent_loss: 0.2194 - rev_loss: 0.0794 - 712ms/epoch - 23ms/step
# Epoch 14/64
# 31/31 - 1s - total_loss: 1.3079 - forward_loss: 0.9924 - latent_loss: 0.2254 - rev_loss: 0.0901 - 738ms/epoch - 24ms/step
# Epoch 15/64
# 31/31 - 1s - total_loss: 1.2679 - forward_loss: 0.9524 - latent_loss: 0.2278 - rev_loss: 0.0877 - 732ms/epoch - 24ms/step
# Epoch 16/64
# 31/31 - 1s - total_loss: 1.1442 - forward_loss: 0.8633 - latent_loss: 0.2073 - rev_loss: 0.0736 - 1s/epoch - 42ms/step
# Epoch 17/64
# 31/31 - 1s - total_loss: 1.1473 - forward_loss: 0.8719 - latent_loss: 0.1960 - rev_loss: 0.0794 - 704ms/epoch - 23ms/step
# Epoch 18/64
# 31/31 - 1s - total_loss: 1.0207 - forward_loss: 0.7778 - latent_loss: 0.1864 - rev_loss: 0.0565 - 726ms/epoch - 23ms/step
# Epoch 19/64
# 31/31 - 1s - total_loss: 1.0568 - forward_loss: 0.7908 - latent_loss: 0.1918 - rev_loss: 0.0742 - 721ms/epoch - 23ms/step
# Epoch 20/64
# 31/31 - 1s - total_loss: 0.9800 - forward_loss: 0.7320 - latent_loss: 0.1821 - rev_loss: 0.0659 - 717ms/epoch - 23ms/step
# Epoch 21/64
# 31/31 - 1s - total_loss: 1.0416 - forward_loss: 0.7894 - latent_loss: 0.1890 - rev_loss: 0.0632 - 1s/epoch - 41ms/step
# Epoch 22/64
# 31/31 - 1s - total_loss: 1.0328 - forward_loss: 0.7930 - latent_loss: 0.1836 - rev_loss: 0.0562 - 703ms/epoch - 23ms/step
# Epoch 23/64
# 31/31 - 1s - total_loss: 0.8440 - forward_loss: 0.6351 - latent_loss: 0.1523 - rev_loss: 0.0566 - 710ms/epoch - 23ms/step
# Epoch 24/64
# 31/31 - 1s - total_loss: 0.9887 - forward_loss: 0.7793 - latent_loss: 0.1553 - rev_loss: 0.0541 - 719ms/epoch - 23ms/step
# Epoch 25/64
# 31/31 - 1s - total_loss: 0.9253 - forward_loss: 0.7125 - latent_loss: 0.1605 - rev_loss: 0.0523 - 717ms/epoch - 23ms/step
# Epoch 26/64
# 31/31 - 1s - total_loss: 0.9502 - forward_loss: 0.7266 - latent_loss: 0.1611 - rev_loss: 0.0626 - 1s/epoch - 41ms/step
# Epoch 27/64
# 31/31 - 1s - total_loss: 0.9478 - forward_loss: 0.7578 - latent_loss: 0.1448 - rev_loss: 0.0452 - 680ms/epoch - 22ms/step
# Epoch 28/64
# 31/31 - 1s - total_loss: 0.9094 - forward_loss: 0.7041 - latent_loss: 0.1494 - rev_loss: 0.0559 - 698ms/epoch - 23ms/step
# Epoch 29/64
# 31/31 - 1s - total_loss: 0.9868 - forward_loss: 0.7955 - latent_loss: 0.1469 - rev_loss: 0.0443 - 702ms/epoch - 23ms/step
# Epoch 30/64
# 31/31 - 1s - total_loss: 0.9768 - forward_loss: 0.7852 - latent_loss: 0.1499 - rev_loss: 0.0416 - 690ms/epoch - 22ms/step
# Epoch 31/64
# 31/31 - 1s - total_loss: 0.9548 - forward_loss: 0.7643 - latent_loss: 0.1433 - rev_loss: 0.0472 - 1s/epoch - 41ms/step
# Epoch 32/64
# 31/31 - 1s - total_loss: 0.9350 - forward_loss: 0.7516 - latent_loss: 0.1394 - rev_loss: 0.0441 - 691ms/epoch - 22ms/step
# Epoch 33/64
# 31/31 - 1s - total_loss: 0.9093 - forward_loss: 0.7213 - latent_loss: 0.1412 - rev_loss: 0.0468 - 731ms/epoch - 24ms/step
# Epoch 34/64
# 31/31 - 1s - total_loss: 0.7581 - forward_loss: 0.5945 - latent_loss: 0.1239 - rev_loss: 0.0397 - 721ms/epoch - 23ms/step
# Epoch 35/64
# 31/31 - 1s - total_loss: 0.8495 - forward_loss: 0.6648 - latent_loss: 0.1447 - rev_loss: 0.0399 - 695ms/epoch - 22ms/step
# Epoch 36/64
# 31/31 - 1s - total_loss: 0.8503 - forward_loss: 0.6584 - latent_loss: 0.1534 - rev_loss: 0.0385 - 1s/epoch - 42ms/step
# Epoch 37/64
# 31/31 - 1s - total_loss: 0.8712 - forward_loss: 0.6891 - latent_loss: 0.1412 - rev_loss: 0.0408 - 656ms/epoch - 21ms/step
# Epoch 38/64
# 31/31 - 1s - total_loss: 0.8248 - forward_loss: 0.6520 - latent_loss: 0.1300 - rev_loss: 0.0427 - 683ms/epoch - 22ms/step
# Epoch 39/64
# 31/31 - 1s - total_loss: 0.8541 - forward_loss: 0.6746 - latent_loss: 0.1401 - rev_loss: 0.0394 - 671ms/epoch - 22ms/step
# Epoch 40/64
# 31/31 - 1s - total_loss: 0.9188 - forward_loss: 0.7406 - latent_loss: 0.1421 - rev_loss: 0.0361 - 687ms/epoch - 22ms/step
# Epoch 41/64
# 31/31 - 1s - total_loss: 0.8116 - forward_loss: 0.6395 - latent_loss: 0.1318 - rev_loss: 0.0403 - 1s/epoch - 39ms/step
# Epoch 42/64
# 31/31 - 1s - total_loss: 0.9043 - forward_loss: 0.7260 - latent_loss: 0.1367 - rev_loss: 0.0416 - 663ms/epoch - 21ms/step
# Epoch 43/64
# 31/31 - 1s - total_loss: 0.7545 - forward_loss: 0.5854 - latent_loss: 0.1334 - rev_loss: 0.0358 - 657ms/epoch - 21ms/step
# Epoch 44/64
# 31/31 - 1s - total_loss: 0.8143 - forward_loss: 0.6572 - latent_loss: 0.1224 - rev_loss: 0.0347 - 717ms/epoch - 23ms/step
# Epoch 45/64
# 31/31 - 1s - total_loss: 0.8127 - forward_loss: 0.6436 - latent_loss: 0.1283 - rev_loss: 0.0408 - 676ms/epoch - 22ms/step
# Epoch 46/64
# 31/31 - 1s - total_loss: 0.8445 - forward_loss: 0.6743 - latent_loss: 0.1305 - rev_loss: 0.0398 - 1s/epoch - 40ms/step
# Epoch 47/64
# 31/31 - 1s - total_loss: 0.7693 - forward_loss: 0.6089 - latent_loss: 0.1293 - rev_loss: 0.0312 - 666ms/epoch - 21ms/step
# Epoch 48/64
# 31/31 - 1s - total_loss: 0.8349 - forward_loss: 0.6735 - latent_loss: 0.1266 - rev_loss: 0.0349 - 657ms/epoch - 21ms/step
# Epoch 49/64
# 31/31 - 1s - total_loss: 0.7673 - forward_loss: 0.6130 - latent_loss: 0.1205 - rev_loss: 0.0338 - 647ms/epoch - 21ms/step
# Epoch 50/64
# 31/31 - 1s - total_loss: 0.7806 - forward_loss: 0.6293 - latent_loss: 0.1171 - rev_loss: 0.0342 - 631ms/epoch - 20ms/step
# Epoch 51/64
# 31/31 - 1s - total_loss: 0.7762 - forward_loss: 0.6270 - latent_loss: 0.1132 - rev_loss: 0.0359 - 1s/epoch - 39ms/step
# Epoch 52/64
# 31/31 - 1s - total_loss: 0.8036 - forward_loss: 0.6489 - latent_loss: 0.1211 - rev_loss: 0.0336 - 670ms/epoch - 22ms/step
# Epoch 53/64
# 31/31 - 1s - total_loss: 0.8702 - forward_loss: 0.6970 - latent_loss: 0.1351 - rev_loss: 0.0381 - 654ms/epoch - 21ms/step
# Epoch 54/64
# 31/31 - 1s - total_loss: 0.8784 - forward_loss: 0.7083 - latent_loss: 0.1339 - rev_loss: 0.0362 - 679ms/epoch - 22ms/step
# Epoch 55/64
# 31/31 - 1s - total_loss: 0.7113 - forward_loss: 0.5643 - latent_loss: 0.1164 - rev_loss: 0.0306 - 682ms/epoch - 22ms/step
# Epoch 56/64
# 31/31 - 1s - total_loss: 0.7056 - forward_loss: 0.5526 - latent_loss: 0.1253 - rev_loss: 0.0277 - 1s/epoch - 39ms/step
# Epoch 57/64
# 31/31 - 1s - total_loss: 0.6558 - forward_loss: 0.5205 - latent_loss: 0.1061 - rev_loss: 0.0292 - 686ms/epoch - 22ms/step
# Epoch 58/64
# 31/31 - 1s - total_loss: 0.6531 - forward_loss: 0.5166 - latent_loss: 0.1081 - rev_loss: 0.0284 - 664ms/epoch - 21ms/step
# Epoch 59/64
# 31/31 - 1s - total_loss: 0.7087 - forward_loss: 0.5650 - latent_loss: 0.1127 - rev_loss: 0.0309 - 682ms/epoch - 22ms/step
# Epoch 60/64
# 31/31 - 1s - total_loss: 0.7302 - forward_loss: 0.5819 - latent_loss: 0.1154 - rev_loss: 0.0329 - 689ms/epoch - 22ms/step
# Epoch 61/64
# 31/31 - 1s - total_loss: 0.7662 - forward_loss: 0.6186 - latent_loss: 0.1183 - rev_loss: 0.0292 - 1s/epoch - 39ms/step
# Epoch 62/64
# 31/31 - 1s - total_loss: 0.7264 - forward_loss: 0.5746 - latent_loss: 0.1183 - rev_loss: 0.0336 - 678ms/epoch - 22ms/step
# Epoch 63/64
# 31/31 - 1s - total_loss: 0.7377 - forward_loss: 0.5896 - latent_loss: 0.1187 - rev_loss: 0.0294 - 700ms/epoch - 23ms/step
# Epoch 64/64
# 31/31 - 1s - total_loss: 0.7301 - forward_loss: 0.5815 - latent_loss: 0.1142 - rev_loss: 0.0344 - 736ms/epoch - 24ms/step
# === Time elapsed: 1.0300 min ===

# %% [markdown]
# ### Results

# %%
fig, ax = plt.subplots(1, facecolor="white", figsize=(8, 5))
ax.plot(hist.history["total_loss"], "k.-", label="total_loss")
ax.plot(hist.history["forward_loss"], "b.-", label="forward_loss")
ax.plot(hist.history["latent_loss"], "g.-", label="latent_loss")
ax.plot(hist.history["rev_loss"], "r.-", label="inverse_loss")
# plt.semilogy()
plt.legend()
plt.title("Learning curves", fontsize = 20)
plt.xlabel("Epoch", fontsize = 14)
plt.ylabel("Loss", fontsize = 14)
plt.savefig("loss.png")
plt.show()
plt.close()

# %%
# # Preprocess
# z = np.random.multivariate_normal([1.0] * z_dim, np.eye(z_dim), test_y.shape[0])
# y = np.concatenate([z, test_y], axis=-1).astype("float32")
# x_pred = model.inverse(y).numpy()
# print("x_pred", x_pred.shape)
# pz_pred = x_pred[:, 3] + x_pred[:, 7]
# pt_pred = np.sqrt(
#     np.square(x_pred[:, 1] + x_pred[:, 5]) + np.square(x_pred[:, 2] + x_pred[:, 6])
# )
# E_pred = x_pred[:, 0] + x_pred[:, 4]

# pz_truth = test_x[:, 3] + test_x[:, 7]
# pt_truth = np.sqrt(
#     np.square(test_x[:, 1] + test_x[:, 5]) + np.square(test_x[:, 2] + test_x[:, 6])
# )
# E_truth = test_x[:, 0] + test_x[:, 4]

# %%
# Preprocess
z = np.random.multivariate_normal([1.0] * z_dim, np.eye(z_dim), test_y.shape[0])
y = np.concatenate([z, test_y], axis=-1).astype("float32")
x_pred = model.inverse(y).numpy()
print("x_pred", x_pred.shape)
pz_pred = x_pred[:, 3]
pt_pred = np.sqrt(np.square(x_pred[:, 1]) + np.square(x_pred[:, 2]))
E_pred = x_pred[:, 0]

pz_truth = test_x[:, 3]
pt_truth = np.sqrt(np.square(test_x[:, 1]) + np.square(test_x[:, 2]))
E_truth = test_x[:, 0]
# Out:
# x_pred (200, 12)

# %%
def plot_2d_histogram(pred, truth, title, save_name, bins=150, range=None):
    fig = plt.figure(figsize=(7, 6), dpi=120)
    plt.hist2d(
        pred.flatten(), truth, bins=bins, range=[range, range], cmap="viridis", cmin=1
    )
    cbar = plt.colorbar()
    cbar.set_label("Frequency", fontsize = 12)
    plt.title(title, fontsize = 16)
    plt.xlabel("Prediction", fontsize = 12)
    plt.ylabel("Truth", fontsize = 12)
    plt.plot(range, range, color="grey", linestyle="--", alpha=0.8)  # add y=x line
    plt.xlim(range)
    plt.ylim(range)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.savefig(save_name)
    plt.show()
    plt.close()


# Plot the results
import scipy as sp

print(f"pz -> Pearson coeff: {sp.stats.pearsonr(pz_truth, pz_pred)[0]:.3f}")
print(f"E  -> Pearson coeff: {sp.stats.pearsonr(E_truth, E_pred)[0]:.3f}")
print(f"pt -> Pearson coeff: {sp.stats.pearsonr(pt_truth, pt_pred)[0]:.3f}")
plot_2d_histogram(
    pz_truth, pz_pred, r"$p^{\nu\nu}_{z}$", save_name="pz.png", range=[-6, 6]
)
plot_2d_histogram(
    E_truth, E_pred, r"$E^{\nu\nu}$", save_name="energy.png", range=[-1.2, 5]
)
plot_2d_histogram(
    pt_truth, pt_pred, r"$p^{\nu\nu}_{T}$", save_name="pt.png", range=[0, 5]
)

print("====================== Finished!! ======================")

# tensorboard --logdir logs/fit
# Out:
# pz -> Pearson coeff: -0.096
# E  -> Pearson coeff: 0.368
# pt -> Pearson coeff: 0.520
# ====================== Finished!! ======================
