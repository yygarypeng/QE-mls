# %%
# %reset -sf

import tensorflow as tf
import tf_keras
print("Tensorflow:", tf.__version__)

# GPU(s) setups
gpus = tf.config.experimental.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(gpus[0], True)
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')
        
        # Enable memory growth for the first GPU
        tf.config.experimental.set_memory_growth(gpus[0], True)
        
        # Instead of enabling memory growth, set a memory limit
        # memory_limit = 16_376 / 2 # Set the memory limit in MB
        memory_limit = -1
        if memory_limit >= 0:
            tf.config.experimental.set_virtual_device_configuration(
                gpus[0],
                [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]
            )
            
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2025-04-06 06:39:21.709176: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-06 06:39:21.732117: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow: 2.16.1
# 1 Physical GPUs, 1 Logical GPU
# 2025-04-06 06:39:22.825698: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13218 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
import sys
import os
import glob

HOME_PATH = os.path.abspath("/root/work/QE-mls") # path to QE_mls
sys.path.append(HOME_PATH + "/qe")

import paper_plot as pp

plot = pp.Plotter()

import pandas as pd
import numpy as np
import scipy as sp
import ROOT
from ROOT import TLorentzVector, TVector3
import multiprocessing
WORKERS = 16

from matplotlib import pyplot as plt

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "1"  # suppress tensorflow imformation messages

from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error


SEED = 42  # set random seed (global variable)
GEV = 1e-3

# %%
import full_data as data

# reco
lead_lep = data.Lead_lep()
sublead_lep = data.Sublead_lep()
met = data.Met()

# truth
truth_lead_lep = data.Truth_lead_lep()
truth_sublead_lep = data.Truth_sublead_lep()
Truth_dilep = data.Truth_dilep()
truth_met = data.Truth_met()

# target Ws
w_lead = data.Lead_w()
w_sublead = data.Sublead_w()
mc_weight = data.MC_weight()
# Out:
# ['/CGLMP', '/RecoLep0', '/RecoLep1', '/RecoMET', '/TruthCandLep0', '/TruthCandLep1', '/TruthCandMET', '/TruthHiggs', '/TruthLep0', '/TruthLep1', '/TruthLepN', '/TruthLepP', '/TruthNu0', '/TruthNu1', '/TruthNuN', '/TruthNuP', '/TruthW0', '/TruthW1', '/TruthWN', '/TruthWP', '/eventWeight', '/mcWeight', '/recoWeight', '/weight']

# %%
# define preselection cuts

cut_pre_pt_lead = lead_lep.pt > 22
print(len(lead_lep.energy) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = sublead_lep.pt > 15
print(len(lead_lep.energy) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.sqrt(
        np.square(lead_lep.energy + sublead_lep.energy)
        - np.square(lead_lep.px + sublead_lep.px)
        - np.square(lead_lep.py + sublead_lep.py)
        - np.square(lead_lep.pz + sublead_lep.pz)
    )
    > 10
)
print(len(lead_lep.energy) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = met.pt > 20
print(len(lead_lep.energy) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print(len(lead_lep.energy) - np.sum(PRE_CUT * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)
# Out:
# 0
# 29961
# 44269
# 89634
# 157782

# %%
# truth
truth_lead_lep_px = pd.DataFrame(truth_lead_lep.px[PRE_CUT])
truth_lead_lep_py = pd.DataFrame(truth_lead_lep.py[PRE_CUT])
truth_lead_lep_pz = pd.DataFrame(truth_lead_lep.pz[PRE_CUT])
truth_lead_lep_energy = pd.DataFrame(truth_lead_lep.energy[PRE_CUT])
truth_lead_lep_p4 = pd.concat(
	[truth_lead_lep_px, truth_lead_lep_py, truth_lead_lep_pz, truth_lead_lep_energy],
	axis=1,
).to_numpy()
truth_lead_lep_pt = pd.DataFrame(truth_lead_lep.pt[PRE_CUT])
truth_lead_lep_eta = pd.DataFrame(truth_lead_lep.eta[PRE_CUT])
truth_lead_lep_phi = pd.DataFrame(truth_lead_lep.phi[PRE_CUT])

truth_sublead_lep_px = pd.DataFrame(truth_sublead_lep.px[PRE_CUT])
truth_sublead_lep_py = pd.DataFrame(truth_sublead_lep.py[PRE_CUT])
truth_sublead_lep_pz = pd.DataFrame(truth_sublead_lep.pz[PRE_CUT])
truth_sublead_lep_energy = pd.DataFrame(truth_sublead_lep.energy[PRE_CUT])
truth_sublead_lep_p4 = pd.concat(
	[truth_sublead_lep_px, truth_sublead_lep_py, truth_sublead_lep_pz, truth_sublead_lep_energy],
	axis=1,
).to_numpy()
truth_sublead_lep_pt = pd.DataFrame(truth_sublead_lep.pt[PRE_CUT])
truth_sublead_lep_eta = pd.DataFrame(truth_sublead_lep.eta[PRE_CUT])
truth_sublead_lep_phi = pd.DataFrame(truth_sublead_lep.phi[PRE_CUT])

# reco
lead_lep_px = pd.DataFrame(lead_lep.px[PRE_CUT])
lead_lep_py = pd.DataFrame(lead_lep.py[PRE_CUT])
lead_lep_pz = pd.DataFrame(lead_lep.pz[PRE_CUT])
lead_lep_energy = pd.DataFrame(lead_lep.energy[PRE_CUT])
lead_lep_p4 = pd.concat(
	[lead_lep_px, lead_lep_py, lead_lep_pz, lead_lep_energy],
	axis=1,
).to_numpy()
lead_lep_pt = pd.DataFrame(lead_lep.pt[PRE_CUT])
lead_lep_eta = pd.DataFrame(lead_lep.eta[PRE_CUT])
lead_lep_phi = pd.DataFrame(lead_lep.phi[PRE_CUT])
lead_lep_charge = pd.DataFrame(lead_lep.q[PRE_CUT])

sublead_lep_px = pd.DataFrame(sublead_lep.px[PRE_CUT])
sublead_lep_py = pd.DataFrame(sublead_lep.py[PRE_CUT])
sublead_lep_pz = pd.DataFrame(sublead_lep.pz[PRE_CUT])
sublead_lep_energy = pd.DataFrame(sublead_lep.energy[PRE_CUT])
sublead_lep_p4 = pd.concat(
	[sublead_lep_px, sublead_lep_py, sublead_lep_pz, sublead_lep_energy],
	axis=1,
).to_numpy()
sublead_lep_pt = pd.DataFrame(sublead_lep.pt[PRE_CUT])
sublead_lep_eta = pd.DataFrame(sublead_lep.eta[PRE_CUT])
sublead_lep_phi = pd.DataFrame(sublead_lep.phi[PRE_CUT])
sublead_lep_charge = pd.DataFrame(sublead_lep.q[PRE_CUT])

met_px = pd.DataFrame(met.px[PRE_CUT])
met_py = pd.DataFrame(met.py[PRE_CUT])
met_pt = pd.DataFrame(met.pt[PRE_CUT])
met_phi = pd.DataFrame(met.phi[PRE_CUT])

# %%
## Interesting variables
# lead_lep w
w_lead_px = pd.DataFrame(w_lead.px[PRE_CUT])
w_lead_py = pd.DataFrame(w_lead.py[PRE_CUT])
w_lead_pz = pd.DataFrame(w_lead.pz[PRE_CUT])
w_lead_e = pd.DataFrame(w_lead.energy[PRE_CUT])
w_lead_pt = pd.DataFrame(w_lead.pt[PRE_CUT])
w_lead_eta = pd.DataFrame(w_lead.eta[PRE_CUT])
w_lead_phi = pd.DataFrame(w_lead.phi[PRE_CUT])
w_lead_m = pd.DataFrame(w_lead.m[PRE_CUT])

w_sublead_px = pd.DataFrame(w_sublead.px[PRE_CUT])
w_sublead_py = pd.DataFrame(w_sublead.py[PRE_CUT])
w_sublead_pz = pd.DataFrame(w_sublead.pz[PRE_CUT])
w_sublead_e = pd.DataFrame(w_sublead.energy[PRE_CUT])
w_sublead_pt = pd.DataFrame(w_sublead.pt[PRE_CUT])
w_sublead_eta = pd.DataFrame(w_sublead.eta[PRE_CUT])
w_sublead_phi = pd.DataFrame(w_sublead.phi[PRE_CUT])
w_sublead_m = pd.DataFrame(w_sublead.m[PRE_CUT])

# pure lead w (consider pt)
leadlep_lead = w_lead.pt > w_sublead.pt
lead_w_px = pd.concat([pd.DataFrame(w_lead.px)[leadlep_lead], pd.DataFrame(w_sublead.px)[~leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
lead_w_py = pd.concat([pd.DataFrame(w_lead.py)[leadlep_lead], pd.DataFrame(w_sublead.py)[~leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
lead_w_pz = pd.concat([pd.DataFrame(w_lead.pz)[leadlep_lead], pd.DataFrame(w_sublead.pz)[~leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
lead_w_e = pd.concat([pd.DataFrame(w_lead.energy)[leadlep_lead], pd.DataFrame(w_sublead.energy)[~leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
sublead_w_px = pd.concat([pd.DataFrame(w_lead.px)[~leadlep_lead], pd.DataFrame(w_sublead.px)[leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]  
sublead_w_py = pd.concat([pd.DataFrame(w_lead.py)[~leadlep_lead], pd.DataFrame(w_sublead.py)[leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
sublead_w_pz = pd.concat([pd.DataFrame(w_lead.pz)[~leadlep_lead], pd.DataFrame(w_sublead.pz)[leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
sublead_w_e = pd.concat([pd.DataFrame(w_lead.energy)[~leadlep_lead], pd.DataFrame(w_sublead.energy)[leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
lead_w_m = pd.concat([pd.DataFrame(w_lead.m)[leadlep_lead], pd.DataFrame(w_sublead.m)[~leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]
sublead_w_m = pd.concat([pd.DataFrame(w_lead.m)[~leadlep_lead], pd.DataFrame(w_sublead.m)[leadlep_lead]], ignore_index=False).sort_index()[PRE_CUT]  

# check them wiht histograms
bin_edges = np.linspace(0, 100, 51)
figure = plt.figure(figsize=(10, 8))
plt.hist(
    w_lead_m.values.ravel(),
    bins=bin_edges,
    color="tab:blue",
    alpha=0.5,
    label=r"$W^{0}_{lep}$",
    histtype="stepfilled",
    stacked=False,
    density=False
)
plt.hist(
    lead_w_m.values.ravel(),
    bins=bin_edges,
    color="orange",
    label=r"$W^{0}$",
    histtype="step",
    linewidth=2,
    stacked=False,
    density=False
)
plt.xlabel(r"Mass [GeV]", labelpad=10)
plt.ylabel("Counts")
plt.title(r"$m_{W^{0}}$", fontsize=26)
plt.legend(loc="best", prop={'size': 20})
plt.show()

bin_edges = np.linspace(0, 100, 51)
figure = plt.figure(figsize=(10, 8))
plt.hist(
    w_sublead_m.values.ravel(),
    bins=bin_edges,
    color="tab:blue",
    alpha=0.5,
    label=r"$W^{1}_{lep}$",
    histtype="stepfilled",
    stacked=False,
    density=False
)
plt.hist(
    sublead_w_m.values.ravel(),
    bins=bin_edges,
    color="orange",
    label=r"$W^{1}$",
    histtype="step",
    linewidth=2,
    stacked=False,
    density=False
)
plt.xlabel(r"Mass [GeV]", labelpad=10)
plt.ylabel("Counts")
plt.title(r"$m_{W^{1}}$", fontsize=26)
plt.legend(loc="best", prop={'size': 20})
plt.show()

# %%
## Observing variables

obs_kin = np.column_stack(
    (
        lead_lep_px,
        lead_lep_py,
        lead_lep_pz,
        lead_lep_energy,
        lead_lep_pt,
        lead_lep_eta,
        lead_lep_phi,
        lead_lep_charge,
        sublead_lep_px,
        sublead_lep_py,
        sublead_lep_pz,
        sublead_lep_energy,
        sublead_lep_pt,
        sublead_lep_eta,
        sublead_lep_phi,
        sublead_lep_charge,
        met_px,
        met_py,
        met_pt,
        met_phi,
    )
)

# Kinematics of observing variables (inputs for training)
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array

ROBUST_OBS = RobustScaler()
obs_kin = ROBUST_OBS.fit_transform(obs_kin)
# print(type(obs_kin))
# Out:
# int_kin shape: (851115, 20)

# %%
# target variables on-(off-)shell Ws

lead_onshell_mask = w_lead_m > w_sublead_m
onshell_w_m = pd.concat(
		[
			w_lead_m[lead_onshell_mask].dropna(), 
			w_sublead_m[~lead_onshell_mask].dropna(),
		], ignore_index=False
    ).sort_index()
offshell_w_m = pd.concat(
		[
			w_lead_m[~lead_onshell_mask].dropna(), 
			w_sublead_m[lead_onshell_mask].dropna(),
		], ignore_index=False
	).sort_index()

# check them with histograms
bin_edges = np.linspace(0, 100, 51)
figure = plt.figure(figsize=(10, 8), dpi=300)
plt.hist(
	onshell_w_m.values.ravel(),
	bins=bin_edges,
	color="tab:blue",
	alpha=0.5,
	label=r"$W^{on}$",
	histtype="stepfilled",
	stacked=False,
	density=False,
)
plt.hist(
	offshell_w_m.values.ravel(),
	bins=bin_edges,
	color="tab:orange",
	alpha=0.5,
	label=r"$W^{off}$",
	histtype="stepfilled",
	stacked=False,
	density=False,
)
plt.hist(
	w_lead_m,
	bins=bin_edges,
	color="blue",
	alpha=1.0,
	linewidth=2,
	label=r"$W_0$",
	histtype="step",
	stacked=False,
	density=False,
)
plt.hist(
	w_sublead_m,
	bins=bin_edges,
	color="red",
	alpha=1.0,
	linewidth=2,
	label=r"$W_1$",
	histtype="step",
	stacked=False,
	density=False,
)
plt.xlabel(r"[GeV]", labelpad=10)
plt.ylabel("Counts")
plt.title(r"$m_{W}$", fontsize=20, loc="right")
plt.legend(loc="best", prop={'size': 20}, ncol=2)
plt.show()
plt.close()

# %%
# Kinematics of interesting variables (target for training)
int_kin = np.concatenate(
    [
        lead_onshell_mask.astype(int),
    ],
    axis=-1,
)
print("int_kin shape:", int_kin.shape)
# int_kin = int_kin.to_numpy()  # convert to numpy array
print(type(int_kin))
# Out:
# int_kin shape: (851115, 1)
# <class 'numpy.ndarray'>

# %%
print("Leading W is on-shell:", int_kin.sum() / len(int_kin))  # check the ratio of on-shell W
# Out:
# Leading W is on-shell: 0.8203110038008965

# %%
plt.hist(int_kin)
plt.show()

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.8,
    test_size=0.2,
    random_state=SEED,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=SEED
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
# test_x = np.concatenate([test_x, valid_x], axis=0)

train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]
# test_y = np.concatenate([test_y, valid_y], axis=0)

print("Total evts:", len(indices_arr))
print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# Total evts: 851115
# X (Interest)
# Training data shape: (680892, 20);
# Validing data shape: (85111, 20);
# Testing data shape: (85112, 20).
# Y (Observed)
# Training data shape: (680892, 1);
# Validing data shape: (85111, 1);
# Testing data shape: (85112, 1).

# %%
# training variables
BATCH_SIZE = 512
EPOCHS = 1024
LEARNING_RATE = 1e-5

# create datasets
train_dataset = tf.data.Dataset.from_tensor_slices((
    tf.cast(train_x, tf.float32), 
    tf.cast(train_y, tf.float32)
)).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

valid_dataset = tf.data.Dataset.from_tensor_slices((
    tf.cast(valid_x, tf.float32), 
    tf.cast(valid_y, tf.float32)
)).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
def dense_dropout_block(x, units, activation="swish", dropout_rate=0.0, l2=1e-6):
    x = tf.keras.layers.Dense(
        units=units,
        use_bias=False,
        kernel_regularizer=tf.keras.regularizers.L2(l2),
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    if dropout_rate > 0:
        x = tf.keras.layers.Dropout(rate=dropout_rate)(x)
    return x

def residual_block(x, units, activation="swish", dropout_rate=0.0, l2=0.0):
    y = dense_dropout_block(x, units, activation=activation, dropout_rate=dropout_rate, l2=l2)
    y = dense_dropout_block(y, units, activation=activation, dropout_rate=dropout_rate, l2=l2)
    if x.shape[-1] != units:
        x = tf.keras.layers.Dense(units, activation=None, use_bias=False)(x)
    z = tf.keras.layers.Add()([x, y]) 
    z = tf.keras.layers.BatchNormalization()(z) 
    z = tf.keras.layers.Activation(activation)(z)
    return z

def build_model(input_shape):
    inputs = tf.keras.layers.Input(shape=(input_shape,), dtype=tf.float32)
    x = inputs

    # Stack residual blocks
    for _ in range(2):
        x = residual_block(x, 256, dropout_rate=0.2)
        x = residual_block(x, 128, dropout_rate=0.2)
    for _ in range(2):
        x = residual_block(x, 128, dropout_rate=0.2)
        x = residual_block(x, 64, dropout_rate=0.2)

    # Bottleneck
    # x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dense(8, activation="swish")(x)

    outputs = tf.keras.layers.Dense(units=1, activation="sigmoid")(x)
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
model = build_model(train_x.shape[-1])
model.summary()

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss=tf.losses.binary_crossentropy,
    metrics=["accuracy"],
)

# Early stopping and learning rate scheduler
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    # min_delta=1e-3,
    patience=10,
    mode="auto",
    restore_best_weights=False,
)


def scheduler(epoch, lr):
    if epoch < 512:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-0.1 * LEARNING_RATE))


lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

# Fit the model using generators
history = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    callbacks=[stop_early, lr_scheduler],
    verbose=2,
)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 20)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │      5,120 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256)       │      1,024 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │     65,536 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │      5,120 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 256)       │          0 │ dense_2[0][0],    │
# │                     │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ add[0][0]         │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 256)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │     32,768 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │     16,384 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │     32,768 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 128)       │          0 │ dense_5[0][0],    │
# │                     │                   │            │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ add_1[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │     32,768 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_6[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 256)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 256)       │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 256)       │     65,536 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_7[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 256)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 256)       │     32,768 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 256)       │          0 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 256)       │          0 │ dense_8[0][0],    │
# │                     │                   │            │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ add_2[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 256)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 128)       │     32,768 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_9[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128)       │          0 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 128)       │     16,384 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_10[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 128)       │     32,768 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128)       │          0 │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 128)       │          0 │ dense_11[0][0],   │
# │                     │                   │            │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ add_3[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 128)       │     16,384 │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_12[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 128)       │          0 │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 128)       │     16,384 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_13[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 128)       │          0 │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 128)       │          0 │ activation_11[0]… │
# │                     │                   │            │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ add_4[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 64)        │      8,192 │ activation_14[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_14[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 64)        │          0 │ activation_15[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 64)        │      4,096 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_15[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 64)        │      8,192 │ activation_14[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 64)        │          0 │ activation_16[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 64)        │          0 │ dense_16[0][0],   │
# │                     │                   │            │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ add_5[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 128)       │      8,192 │ activation_17[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_17[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 128)       │          0 │ activation_18[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 128)       │     16,384 │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_18[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 128)       │      8,192 │ activation_17[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 128)       │          0 │ activation_19[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 128)       │          0 │ dense_19[0][0],   │
# │                     │                   │            │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ add_6[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 64)        │      8,192 │ activation_20[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_20[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 64)        │          0 │ activation_21[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 64)        │      4,096 │ dropout_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_21[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 64)        │      8,192 │ activation_20[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 64)        │          0 │ activation_22[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 64)        │          0 │ dense_22[0][0],   │
# │                     │                   │            │ dropout_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ add_7[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 8)         │        520 │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 1)         │          9 │ dense_23[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 491,537 (1.88 MB)
#  Trainable params: 484,625 (1.85 MB)
#  Non-trainable params: 6,912 (27.00 KB)
# Epoch 1/1024
# 1330/1330 - 37s - 28ms/step - accuracy: 0.6513 - loss: 0.7154 - val_accuracy: 0.8173 - val_loss: 0.6583 - learning_rate: 1.0000e-05
# Epoch 2/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.7986 - loss: 0.6459 - val_accuracy: 0.8186 - val_loss: 0.6086 - learning_rate: 1.0000e-05
# Epoch 3/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8034 - loss: 0.6006 - val_accuracy: 0.8189 - val_loss: 0.5676 - learning_rate: 1.0000e-05
# Epoch 4/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8059 - loss: 0.5617 - val_accuracy: 0.8198 - val_loss: 0.5295 - learning_rate: 1.0000e-05
# Epoch 5/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8088 - loss: 0.5271 - val_accuracy: 0.8207 - val_loss: 0.4972 - learning_rate: 1.0000e-05
# Epoch 6/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8128 - loss: 0.4992 - val_accuracy: 0.8211 - val_loss: 0.4733 - learning_rate: 1.0000e-05
# Epoch 7/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8163 - loss: 0.4728 - val_accuracy: 0.8212 - val_loss: 0.4401 - learning_rate: 1.0000e-05
# Epoch 8/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8171 - loss: 0.4407 - val_accuracy: 0.8215 - val_loss: 0.4100 - learning_rate: 1.0000e-05
# Epoch 9/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8186 - loss: 0.4235 - val_accuracy: 0.8217 - val_loss: 0.4014 - learning_rate: 1.0000e-05
# Epoch 10/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8195 - loss: 0.4134 - val_accuracy: 0.8218 - val_loss: 0.3959 - learning_rate: 1.0000e-05
# Epoch 11/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8198 - loss: 0.4058 - val_accuracy: 0.8219 - val_loss: 0.3912 - learning_rate: 1.0000e-05
# Epoch 12/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8204 - loss: 0.3994 - val_accuracy: 0.8227 - val_loss: 0.3855 - learning_rate: 1.0000e-05
# Epoch 13/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8219 - loss: 0.3943 - val_accuracy: 0.8248 - val_loss: 0.3807 - learning_rate: 1.0000e-05
# Epoch 14/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8237 - loss: 0.3895 - val_accuracy: 0.8269 - val_loss: 0.3759 - learning_rate: 1.0000e-05
# Epoch 15/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8264 - loss: 0.3851 - val_accuracy: 0.8289 - val_loss: 0.3716 - learning_rate: 1.0000e-05
# Epoch 16/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8287 - loss: 0.3815 - val_accuracy: 0.8308 - val_loss: 0.3683 - learning_rate: 1.0000e-05
# Epoch 17/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8304 - loss: 0.3787 - val_accuracy: 0.8325 - val_loss: 0.3655 - learning_rate: 1.0000e-05
# Epoch 18/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8317 - loss: 0.3759 - val_accuracy: 0.8341 - val_loss: 0.3631 - learning_rate: 1.0000e-05
# Epoch 19/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8333 - loss: 0.3737 - val_accuracy: 0.8358 - val_loss: 0.3610 - learning_rate: 1.0000e-05
# Epoch 20/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8343 - loss: 0.3713 - val_accuracy: 0.8370 - val_loss: 0.3590 - learning_rate: 1.0000e-05
# Epoch 21/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8352 - loss: 0.3700 - val_accuracy: 0.8380 - val_loss: 0.3574 - learning_rate: 1.0000e-05
# Epoch 22/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8364 - loss: 0.3681 - val_accuracy: 0.8389 - val_loss: 0.3557 - learning_rate: 1.0000e-05
# Epoch 23/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8370 - loss: 0.3662 - val_accuracy: 0.8401 - val_loss: 0.3546 - learning_rate: 1.0000e-05
# Epoch 24/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8379 - loss: 0.3655 - val_accuracy: 0.8406 - val_loss: 0.3534 - learning_rate: 1.0000e-05
# Epoch 25/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8383 - loss: 0.3638 - val_accuracy: 0.8411 - val_loss: 0.3523 - learning_rate: 1.0000e-05
# Epoch 26/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8389 - loss: 0.3632 - val_accuracy: 0.8417 - val_loss: 0.3511 - learning_rate: 1.0000e-05
# Epoch 27/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8393 - loss: 0.3618 - val_accuracy: 0.8423 - val_loss: 0.3501 - learning_rate: 1.0000e-05
# Epoch 28/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8399 - loss: 0.3607 - val_accuracy: 0.8428 - val_loss: 0.3492 - learning_rate: 1.0000e-05
# Epoch 29/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8404 - loss: 0.3601 - val_accuracy: 0.8433 - val_loss: 0.3482 - learning_rate: 1.0000e-05
# Epoch 30/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8407 - loss: 0.3592 - val_accuracy: 0.8437 - val_loss: 0.3476 - learning_rate: 1.0000e-05
# Epoch 31/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8410 - loss: 0.3587 - val_accuracy: 0.8439 - val_loss: 0.3471 - learning_rate: 1.0000e-05
# Epoch 32/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8412 - loss: 0.3576 - val_accuracy: 0.8442 - val_loss: 0.3465 - learning_rate: 1.0000e-05
# Epoch 33/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8419 - loss: 0.3571 - val_accuracy: 0.8448 - val_loss: 0.3461 - learning_rate: 1.0000e-05
# Epoch 34/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8421 - loss: 0.3564 - val_accuracy: 0.8448 - val_loss: 0.3454 - learning_rate: 1.0000e-05
# Epoch 35/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8428 - loss: 0.3559 - val_accuracy: 0.8453 - val_loss: 0.3449 - learning_rate: 1.0000e-05
# Epoch 36/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8428 - loss: 0.3553 - val_accuracy: 0.8457 - val_loss: 0.3442 - learning_rate: 1.0000e-05
# Epoch 37/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8431 - loss: 0.3546 - val_accuracy: 0.8458 - val_loss: 0.3439 - learning_rate: 1.0000e-05
# Epoch 38/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8429 - loss: 0.3547 - val_accuracy: 0.8462 - val_loss: 0.3434 - learning_rate: 1.0000e-05
# Epoch 39/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8432 - loss: 0.3538 - val_accuracy: 0.8466 - val_loss: 0.3431 - learning_rate: 1.0000e-05
# Epoch 40/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8437 - loss: 0.3537 - val_accuracy: 0.8470 - val_loss: 0.3427 - learning_rate: 1.0000e-05
# Epoch 41/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8440 - loss: 0.3531 - val_accuracy: 0.8471 - val_loss: 0.3423 - learning_rate: 1.0000e-05
# Epoch 42/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8442 - loss: 0.3523 - val_accuracy: 0.8473 - val_loss: 0.3419 - learning_rate: 1.0000e-05
# Epoch 43/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8442 - loss: 0.3524 - val_accuracy: 0.8475 - val_loss: 0.3417 - learning_rate: 1.0000e-05
# Epoch 44/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8445 - loss: 0.3519 - val_accuracy: 0.8474 - val_loss: 0.3415 - learning_rate: 1.0000e-05
# Epoch 45/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8450 - loss: 0.3513 - val_accuracy: 0.8478 - val_loss: 0.3412 - learning_rate: 1.0000e-05
# Epoch 46/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8450 - loss: 0.3509 - val_accuracy: 0.8480 - val_loss: 0.3408 - learning_rate: 1.0000e-05
# Epoch 47/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8450 - loss: 0.3506 - val_accuracy: 0.8479 - val_loss: 0.3406 - learning_rate: 1.0000e-05
# Epoch 48/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8453 - loss: 0.3504 - val_accuracy: 0.8483 - val_loss: 0.3402 - learning_rate: 1.0000e-05
# Epoch 49/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8452 - loss: 0.3505 - val_accuracy: 0.8484 - val_loss: 0.3400 - learning_rate: 1.0000e-05
# Epoch 50/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8457 - loss: 0.3497 - val_accuracy: 0.8489 - val_loss: 0.3396 - learning_rate: 1.0000e-05
# Epoch 51/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8459 - loss: 0.3497 - val_accuracy: 0.8487 - val_loss: 0.3396 - learning_rate: 1.0000e-05
# Epoch 52/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8459 - loss: 0.3493 - val_accuracy: 0.8490 - val_loss: 0.3393 - learning_rate: 1.0000e-05
# Epoch 53/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8461 - loss: 0.3488 - val_accuracy: 0.8493 - val_loss: 0.3390 - learning_rate: 1.0000e-05
# Epoch 54/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8460 - loss: 0.3489 - val_accuracy: 0.8491 - val_loss: 0.3391 - learning_rate: 1.0000e-05
# Epoch 55/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8459 - loss: 0.3487 - val_accuracy: 0.8493 - val_loss: 0.3389 - learning_rate: 1.0000e-05
# Epoch 56/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8465 - loss: 0.3484 - val_accuracy: 0.8494 - val_loss: 0.3387 - learning_rate: 1.0000e-05
# Epoch 57/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8458 - loss: 0.3483 - val_accuracy: 0.8496 - val_loss: 0.3383 - learning_rate: 1.0000e-05
# Epoch 58/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8464 - loss: 0.3478 - val_accuracy: 0.8496 - val_loss: 0.3383 - learning_rate: 1.0000e-05
# Epoch 59/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8467 - loss: 0.3478 - val_accuracy: 0.8493 - val_loss: 0.3383 - learning_rate: 1.0000e-05
# Epoch 60/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8465 - loss: 0.3475 - val_accuracy: 0.8497 - val_loss: 0.3379 - learning_rate: 1.0000e-05
# Epoch 61/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8468 - loss: 0.3474 - val_accuracy: 0.8497 - val_loss: 0.3380 - learning_rate: 1.0000e-05
# Epoch 62/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8471 - loss: 0.3468 - val_accuracy: 0.8498 - val_loss: 0.3378 - learning_rate: 1.0000e-05
# Epoch 63/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8469 - loss: 0.3467 - val_accuracy: 0.8498 - val_loss: 0.3377 - learning_rate: 1.0000e-05
# Epoch 64/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8470 - loss: 0.3466 - val_accuracy: 0.8498 - val_loss: 0.3376 - learning_rate: 1.0000e-05
# Epoch 65/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8470 - loss: 0.3466 - val_accuracy: 0.8503 - val_loss: 0.3374 - learning_rate: 1.0000e-05
# Epoch 66/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8471 - loss: 0.3462 - val_accuracy: 0.8504 - val_loss: 0.3373 - learning_rate: 1.0000e-05
# Epoch 67/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8474 - loss: 0.3461 - val_accuracy: 0.8504 - val_loss: 0.3372 - learning_rate: 1.0000e-05
# Epoch 68/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8474 - loss: 0.3461 - val_accuracy: 0.8503 - val_loss: 0.3370 - learning_rate: 1.0000e-05
# Epoch 69/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8473 - loss: 0.3459 - val_accuracy: 0.8506 - val_loss: 0.3368 - learning_rate: 1.0000e-05
# Epoch 70/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8475 - loss: 0.3456 - val_accuracy: 0.8505 - val_loss: 0.3369 - learning_rate: 1.0000e-05
# Epoch 71/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8476 - loss: 0.3453 - val_accuracy: 0.8507 - val_loss: 0.3366 - learning_rate: 1.0000e-05
# Epoch 72/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8479 - loss: 0.3455 - val_accuracy: 0.8506 - val_loss: 0.3366 - learning_rate: 1.0000e-05
# Epoch 73/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8478 - loss: 0.3452 - val_accuracy: 0.8508 - val_loss: 0.3364 - learning_rate: 1.0000e-05
# Epoch 74/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8477 - loss: 0.3450 - val_accuracy: 0.8509 - val_loss: 0.3364 - learning_rate: 1.0000e-05
# Epoch 75/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8477 - loss: 0.3450 - val_accuracy: 0.8509 - val_loss: 0.3362 - learning_rate: 1.0000e-05
# Epoch 76/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8475 - loss: 0.3448 - val_accuracy: 0.8511 - val_loss: 0.3363 - learning_rate: 1.0000e-05
# Epoch 77/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8478 - loss: 0.3449 - val_accuracy: 0.8511 - val_loss: 0.3360 - learning_rate: 1.0000e-05
# Epoch 78/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8481 - loss: 0.3445 - val_accuracy: 0.8511 - val_loss: 0.3361 - learning_rate: 1.0000e-05
# Epoch 79/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8479 - loss: 0.3443 - val_accuracy: 0.8510 - val_loss: 0.3359 - learning_rate: 1.0000e-05
# Epoch 80/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8482 - loss: 0.3443 - val_accuracy: 0.8513 - val_loss: 0.3357 - learning_rate: 1.0000e-05
# Epoch 81/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8479 - loss: 0.3442 - val_accuracy: 0.8510 - val_loss: 0.3358 - learning_rate: 1.0000e-05
# Epoch 82/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8481 - loss: 0.3439 - val_accuracy: 0.8512 - val_loss: 0.3358 - learning_rate: 1.0000e-05
# Epoch 83/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8482 - loss: 0.3438 - val_accuracy: 0.8511 - val_loss: 0.3358 - learning_rate: 1.0000e-05
# Epoch 84/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8485 - loss: 0.3437 - val_accuracy: 0.8513 - val_loss: 0.3355 - learning_rate: 1.0000e-05
# Epoch 85/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8483 - loss: 0.3435 - val_accuracy: 0.8513 - val_loss: 0.3355 - learning_rate: 1.0000e-05
# Epoch 86/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8484 - loss: 0.3434 - val_accuracy: 0.8513 - val_loss: 0.3353 - learning_rate: 1.0000e-05
# Epoch 87/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8487 - loss: 0.3435 - val_accuracy: 0.8512 - val_loss: 0.3354 - learning_rate: 1.0000e-05
# Epoch 88/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8486 - loss: 0.3431 - val_accuracy: 0.8514 - val_loss: 0.3354 - learning_rate: 1.0000e-05
# Epoch 89/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8485 - loss: 0.3432 - val_accuracy: 0.8514 - val_loss: 0.3352 - learning_rate: 1.0000e-05
# Epoch 90/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8486 - loss: 0.3433 - val_accuracy: 0.8514 - val_loss: 0.3351 - learning_rate: 1.0000e-05
# Epoch 91/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8490 - loss: 0.3430 - val_accuracy: 0.8515 - val_loss: 0.3350 - learning_rate: 1.0000e-05
# Epoch 92/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8487 - loss: 0.3430 - val_accuracy: 0.8516 - val_loss: 0.3349 - learning_rate: 1.0000e-05
# Epoch 93/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8488 - loss: 0.3428 - val_accuracy: 0.8515 - val_loss: 0.3350 - learning_rate: 1.0000e-05
# Epoch 94/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8488 - loss: 0.3429 - val_accuracy: 0.8515 - val_loss: 0.3348 - learning_rate: 1.0000e-05
# Epoch 95/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8488 - loss: 0.3426 - val_accuracy: 0.8514 - val_loss: 0.3348 - learning_rate: 1.0000e-05
# Epoch 96/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8488 - loss: 0.3424 - val_accuracy: 0.8515 - val_loss: 0.3347 - learning_rate: 1.0000e-05
# Epoch 97/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8491 - loss: 0.3425 - val_accuracy: 0.8515 - val_loss: 0.3347 - learning_rate: 1.0000e-05
# Epoch 98/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8491 - loss: 0.3423 - val_accuracy: 0.8515 - val_loss: 0.3347 - learning_rate: 1.0000e-05
# Epoch 99/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8489 - loss: 0.3423 - val_accuracy: 0.8516 - val_loss: 0.3347 - learning_rate: 1.0000e-05
# Epoch 100/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8493 - loss: 0.3422 - val_accuracy: 0.8515 - val_loss: 0.3346 - learning_rate: 1.0000e-05
# Epoch 101/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8491 - loss: 0.3421 - val_accuracy: 0.8516 - val_loss: 0.3345 - learning_rate: 1.0000e-05
# Epoch 102/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8493 - loss: 0.3417 - val_accuracy: 0.8516 - val_loss: 0.3343 - learning_rate: 1.0000e-05
# Epoch 103/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8492 - loss: 0.3420 - val_accuracy: 0.8516 - val_loss: 0.3344 - learning_rate: 1.0000e-05
# Epoch 104/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8490 - loss: 0.3419 - val_accuracy: 0.8516 - val_loss: 0.3343 - learning_rate: 1.0000e-05
# Epoch 105/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8491 - loss: 0.3418 - val_accuracy: 0.8516 - val_loss: 0.3342 - learning_rate: 1.0000e-05
# Epoch 106/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8492 - loss: 0.3417 - val_accuracy: 0.8517 - val_loss: 0.3342 - learning_rate: 1.0000e-05
# Epoch 107/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8490 - loss: 0.3418 - val_accuracy: 0.8516 - val_loss: 0.3341 - learning_rate: 1.0000e-05
# Epoch 108/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8492 - loss: 0.3416 - val_accuracy: 0.8517 - val_loss: 0.3341 - learning_rate: 1.0000e-05
# Epoch 109/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8493 - loss: 0.3416 - val_accuracy: 0.8518 - val_loss: 0.3340 - learning_rate: 1.0000e-05
# Epoch 110/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8493 - loss: 0.3415 - val_accuracy: 0.8518 - val_loss: 0.3339 - learning_rate: 1.0000e-05
# Epoch 111/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8494 - loss: 0.3412 - val_accuracy: 0.8518 - val_loss: 0.3339 - learning_rate: 1.0000e-05
# Epoch 112/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8495 - loss: 0.3411 - val_accuracy: 0.8518 - val_loss: 0.3339 - learning_rate: 1.0000e-05
# Epoch 113/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8496 - loss: 0.3411 - val_accuracy: 0.8517 - val_loss: 0.3339 - learning_rate: 1.0000e-05
# Epoch 114/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8492 - loss: 0.3412 - val_accuracy: 0.8520 - val_loss: 0.3338 - learning_rate: 1.0000e-05
# Epoch 115/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8493 - loss: 0.3410 - val_accuracy: 0.8521 - val_loss: 0.3337 - learning_rate: 1.0000e-05
# Epoch 116/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8496 - loss: 0.3408 - val_accuracy: 0.8521 - val_loss: 0.3337 - learning_rate: 1.0000e-05
# Epoch 117/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8496 - loss: 0.3410 - val_accuracy: 0.8519 - val_loss: 0.3337 - learning_rate: 1.0000e-05
# Epoch 118/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8494 - loss: 0.3408 - val_accuracy: 0.8520 - val_loss: 0.3338 - learning_rate: 1.0000e-05
# Epoch 119/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8497 - loss: 0.3406 - val_accuracy: 0.8520 - val_loss: 0.3335 - learning_rate: 1.0000e-05
# Epoch 120/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8498 - loss: 0.3404 - val_accuracy: 0.8520 - val_loss: 0.3337 - learning_rate: 1.0000e-05
# Epoch 121/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8496 - loss: 0.3406 - val_accuracy: 0.8520 - val_loss: 0.3337 - learning_rate: 1.0000e-05
# Epoch 122/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8496 - loss: 0.3407 - val_accuracy: 0.8520 - val_loss: 0.3335 - learning_rate: 1.0000e-05
# Epoch 123/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8499 - loss: 0.3405 - val_accuracy: 0.8522 - val_loss: 0.3335 - learning_rate: 1.0000e-05
# Epoch 124/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8497 - loss: 0.3406 - val_accuracy: 0.8520 - val_loss: 0.3335 - learning_rate: 1.0000e-05
# Epoch 125/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8498 - loss: 0.3402 - val_accuracy: 0.8521 - val_loss: 0.3334 - learning_rate: 1.0000e-05
# Epoch 126/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8496 - loss: 0.3402 - val_accuracy: 0.8523 - val_loss: 0.3334 - learning_rate: 1.0000e-05
# Epoch 127/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8498 - loss: 0.3403 - val_accuracy: 0.8523 - val_loss: 0.3333 - learning_rate: 1.0000e-05
# Epoch 128/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8498 - loss: 0.3400 - val_accuracy: 0.8523 - val_loss: 0.3334 - learning_rate: 1.0000e-05
# Epoch 129/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8500 - loss: 0.3401 - val_accuracy: 0.8523 - val_loss: 0.3332 - learning_rate: 1.0000e-05
# Epoch 130/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8498 - loss: 0.3402 - val_accuracy: 0.8522 - val_loss: 0.3333 - learning_rate: 1.0000e-05
# Epoch 131/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8499 - loss: 0.3399 - val_accuracy: 0.8523 - val_loss: 0.3331 - learning_rate: 1.0000e-05
# Epoch 132/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8498 - loss: 0.3400 - val_accuracy: 0.8523 - val_loss: 0.3331 - learning_rate: 1.0000e-05
# Epoch 133/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8500 - loss: 0.3401 - val_accuracy: 0.8524 - val_loss: 0.3330 - learning_rate: 1.0000e-05
# Epoch 134/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8503 - loss: 0.3397 - val_accuracy: 0.8525 - val_loss: 0.3331 - learning_rate: 1.0000e-05
# Epoch 135/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8501 - loss: 0.3396 - val_accuracy: 0.8525 - val_loss: 0.3330 - learning_rate: 1.0000e-05
# Epoch 136/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8501 - loss: 0.3397 - val_accuracy: 0.8525 - val_loss: 0.3330 - learning_rate: 1.0000e-05
# Epoch 137/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8501 - loss: 0.3398 - val_accuracy: 0.8525 - val_loss: 0.3330 - learning_rate: 1.0000e-05
# Epoch 138/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8499 - loss: 0.3397 - val_accuracy: 0.8526 - val_loss: 0.3329 - learning_rate: 1.0000e-05
# Epoch 139/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8503 - loss: 0.3397 - val_accuracy: 0.8525 - val_loss: 0.3330 - learning_rate: 1.0000e-05
# Epoch 140/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8502 - loss: 0.3395 - val_accuracy: 0.8525 - val_loss: 0.3330 - learning_rate: 1.0000e-05
# Epoch 141/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8500 - loss: 0.3395 - val_accuracy: 0.8524 - val_loss: 0.3329 - learning_rate: 1.0000e-05
# Epoch 142/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8502 - loss: 0.3395 - val_accuracy: 0.8526 - val_loss: 0.3329 - learning_rate: 1.0000e-05
# Epoch 143/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8502 - loss: 0.3395 - val_accuracy: 0.8526 - val_loss: 0.3329 - learning_rate: 1.0000e-05
# Epoch 144/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8503 - loss: 0.3392 - val_accuracy: 0.8526 - val_loss: 0.3328 - learning_rate: 1.0000e-05
# Epoch 145/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8503 - loss: 0.3393 - val_accuracy: 0.8526 - val_loss: 0.3328 - learning_rate: 1.0000e-05
# Epoch 146/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8502 - loss: 0.3392 - val_accuracy: 0.8527 - val_loss: 0.3328 - learning_rate: 1.0000e-05
# Epoch 147/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8503 - loss: 0.3391 - val_accuracy: 0.8528 - val_loss: 0.3328 - learning_rate: 1.0000e-05
# Epoch 148/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8503 - loss: 0.3392 - val_accuracy: 0.8528 - val_loss: 0.3328 - learning_rate: 1.0000e-05
# Epoch 149/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8502 - loss: 0.3392 - val_accuracy: 0.8527 - val_loss: 0.3328 - learning_rate: 1.0000e-05
# Epoch 150/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8501 - loss: 0.3390 - val_accuracy: 0.8528 - val_loss: 0.3327 - learning_rate: 1.0000e-05
# Epoch 151/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8507 - loss: 0.3388 - val_accuracy: 0.8529 - val_loss: 0.3327 - learning_rate: 1.0000e-05
# Epoch 152/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8504 - loss: 0.3390 - val_accuracy: 0.8528 - val_loss: 0.3326 - learning_rate: 1.0000e-05
# Epoch 153/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8503 - loss: 0.3390 - val_accuracy: 0.8528 - val_loss: 0.3326 - learning_rate: 1.0000e-05
# Epoch 154/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8503 - loss: 0.3391 - val_accuracy: 0.8528 - val_loss: 0.3326 - learning_rate: 1.0000e-05
# Epoch 155/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8503 - loss: 0.3389 - val_accuracy: 0.8529 - val_loss: 0.3326 - learning_rate: 1.0000e-05
# Epoch 156/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8506 - loss: 0.3386 - val_accuracy: 0.8531 - val_loss: 0.3324 - learning_rate: 1.0000e-05
# Epoch 157/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8505 - loss: 0.3389 - val_accuracy: 0.8529 - val_loss: 0.3325 - learning_rate: 1.0000e-05
# Epoch 158/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8505 - loss: 0.3387 - val_accuracy: 0.8530 - val_loss: 0.3325 - learning_rate: 1.0000e-05
# Epoch 159/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8505 - loss: 0.3388 - val_accuracy: 0.8530 - val_loss: 0.3324 - learning_rate: 1.0000e-05
# Epoch 160/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8504 - loss: 0.3386 - val_accuracy: 0.8529 - val_loss: 0.3324 - learning_rate: 1.0000e-05
# Epoch 161/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8505 - loss: 0.3387 - val_accuracy: 0.8529 - val_loss: 0.3324 - learning_rate: 1.0000e-05
# Epoch 162/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8505 - loss: 0.3385 - val_accuracy: 0.8530 - val_loss: 0.3323 - learning_rate: 1.0000e-05
# Epoch 163/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8506 - loss: 0.3385 - val_accuracy: 0.8531 - val_loss: 0.3322 - learning_rate: 1.0000e-05
# Epoch 164/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8507 - loss: 0.3384 - val_accuracy: 0.8529 - val_loss: 0.3323 - learning_rate: 1.0000e-05
# Epoch 165/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8509 - loss: 0.3382 - val_accuracy: 0.8531 - val_loss: 0.3323 - learning_rate: 1.0000e-05
# Epoch 166/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8505 - loss: 0.3382 - val_accuracy: 0.8532 - val_loss: 0.3322 - learning_rate: 1.0000e-05
# Epoch 167/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8507 - loss: 0.3382 - val_accuracy: 0.8530 - val_loss: 0.3322 - learning_rate: 1.0000e-05
# Epoch 168/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8504 - loss: 0.3384 - val_accuracy: 0.8531 - val_loss: 0.3322 - learning_rate: 1.0000e-05
# Epoch 169/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8508 - loss: 0.3382 - val_accuracy: 0.8530 - val_loss: 0.3322 - learning_rate: 1.0000e-05
# Epoch 170/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8509 - loss: 0.3380 - val_accuracy: 0.8529 - val_loss: 0.3322 - learning_rate: 1.0000e-05
# Epoch 171/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8510 - loss: 0.3381 - val_accuracy: 0.8531 - val_loss: 0.3322 - learning_rate: 1.0000e-05
# Epoch 172/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8509 - loss: 0.3380 - val_accuracy: 0.8530 - val_loss: 0.3322 - learning_rate: 1.0000e-05
# Epoch 173/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8508 - loss: 0.3382 - val_accuracy: 0.8531 - val_loss: 0.3322 - learning_rate: 1.0000e-05
# Epoch 174/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8510 - loss: 0.3380 - val_accuracy: 0.8532 - val_loss: 0.3321 - learning_rate: 1.0000e-05
# Epoch 175/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8508 - loss: 0.3379 - val_accuracy: 0.8533 - val_loss: 0.3320 - learning_rate: 1.0000e-05
# Epoch 176/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8508 - loss: 0.3379 - val_accuracy: 0.8533 - val_loss: 0.3320 - learning_rate: 1.0000e-05
# Epoch 177/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8508 - loss: 0.3380 - val_accuracy: 0.8531 - val_loss: 0.3321 - learning_rate: 1.0000e-05
# Epoch 178/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8508 - loss: 0.3379 - val_accuracy: 0.8533 - val_loss: 0.3320 - learning_rate: 1.0000e-05
# Epoch 179/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8511 - loss: 0.3377 - val_accuracy: 0.8532 - val_loss: 0.3320 - learning_rate: 1.0000e-05
# Epoch 180/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8509 - loss: 0.3379 - val_accuracy: 0.8534 - val_loss: 0.3319 - learning_rate: 1.0000e-05
# Epoch 181/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8508 - loss: 0.3378 - val_accuracy: 0.8534 - val_loss: 0.3319 - learning_rate: 1.0000e-05
# Epoch 182/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8509 - loss: 0.3376 - val_accuracy: 0.8536 - val_loss: 0.3320 - learning_rate: 1.0000e-05
# Epoch 183/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8509 - loss: 0.3375 - val_accuracy: 0.8532 - val_loss: 0.3320 - learning_rate: 1.0000e-05
# Epoch 184/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8511 - loss: 0.3375 - val_accuracy: 0.8534 - val_loss: 0.3319 - learning_rate: 1.0000e-05
# Epoch 185/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8509 - loss: 0.3376 - val_accuracy: 0.8534 - val_loss: 0.3320 - learning_rate: 1.0000e-05
# Epoch 186/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8510 - loss: 0.3377 - val_accuracy: 0.8532 - val_loss: 0.3319 - learning_rate: 1.0000e-05
# Epoch 187/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8510 - loss: 0.3375 - val_accuracy: 0.8534 - val_loss: 0.3319 - learning_rate: 1.0000e-05
# Epoch 188/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8509 - loss: 0.3376 - val_accuracy: 0.8535 - val_loss: 0.3318 - learning_rate: 1.0000e-05
# Epoch 189/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8510 - loss: 0.3372 - val_accuracy: 0.8536 - val_loss: 0.3319 - learning_rate: 1.0000e-05
# Epoch 190/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8512 - loss: 0.3375 - val_accuracy: 0.8535 - val_loss: 0.3319 - learning_rate: 1.0000e-05
# Epoch 191/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8512 - loss: 0.3374 - val_accuracy: 0.8536 - val_loss: 0.3317 - learning_rate: 1.0000e-05
# Epoch 192/1024
# ...
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8512 - loss: 0.3371 - val_accuracy: 0.8537 - val_loss: 0.3318 - learning_rate: 1.0000e-05
# Epoch 200/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8509 - loss: 0.3372 - val_accuracy: 0.8535 - val_loss: 0.3317 - learning_rate: 1.0000e-05
# Epoch 201/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8512 - loss: 0.3370 - val_accuracy: 0.8535 - val_loss: 0.3317 - learning_rate: 1.0000e-05
# Epoch 202/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8514 - loss: 0.3371 - val_accuracy: 0.8535 - val_loss: 0.3316 - learning_rate: 1.0000e-05
# Epoch 203/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8512 - loss: 0.3368 - val_accuracy: 0.8536 - val_loss: 0.3317 - learning_rate: 1.0000e-05
# Epoch 204/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8511 - loss: 0.3370 - val_accuracy: 0.8536 - val_loss: 0.3315 - learning_rate: 1.0000e-05
# Epoch 205/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8513 - loss: 0.3368 - val_accuracy: 0.8535 - val_loss: 0.3316 - learning_rate: 1.0000e-05
# Epoch 206/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8513 - loss: 0.3368 - val_accuracy: 0.8538 - val_loss: 0.3316 - learning_rate: 1.0000e-05
# Epoch 207/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8514 - loss: 0.3367 - val_accuracy: 0.8538 - val_loss: 0.3315 - learning_rate: 1.0000e-05
# Epoch 208/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8513 - loss: 0.3369 - val_accuracy: 0.8534 - val_loss: 0.3316 - learning_rate: 1.0000e-05
# Epoch 209/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8514 - loss: 0.3366 - val_accuracy: 0.8536 - val_loss: 0.3315 - learning_rate: 1.0000e-05
# Epoch 210/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8515 - loss: 0.3367 - val_accuracy: 0.8537 - val_loss: 0.3316 - learning_rate: 1.0000e-05
# Epoch 211/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8514 - loss: 0.3368 - val_accuracy: 0.8537 - val_loss: 0.3316 - learning_rate: 1.0000e-05
# Epoch 212/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8515 - loss: 0.3367 - val_accuracy: 0.8536 - val_loss: 0.3316 - learning_rate: 1.0000e-05
# Epoch 213/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8515 - loss: 0.3366 - val_accuracy: 0.8538 - val_loss: 0.3315 - learning_rate: 1.0000e-05
# Epoch 214/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8514 - loss: 0.3366 - val_accuracy: 0.8536 - val_loss: 0.3315 - learning_rate: 1.0000e-05
# Epoch 215/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8514 - loss: 0.3367 - val_accuracy: 0.8536 - val_loss: 0.3315 - learning_rate: 1.0000e-05
# Epoch 216/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8512 - loss: 0.3365 - val_accuracy: 0.8535 - val_loss: 0.3316 - learning_rate: 1.0000e-05
# Epoch 217/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8514 - loss: 0.3364 - val_accuracy: 0.8537 - val_loss: 0.3315 - learning_rate: 1.0000e-05
# Epoch 218/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8515 - loss: 0.3364 - val_accuracy: 0.8536 - val_loss: 0.3315 - learning_rate: 1.0000e-05
# Epoch 219/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8515 - loss: 0.3365 - val_accuracy: 0.8537 - val_loss: 0.3314 - learning_rate: 1.0000e-05
# Epoch 220/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8517 - loss: 0.3363 - val_accuracy: 0.8538 - val_loss: 0.3315 - learning_rate: 1.0000e-05
# Epoch 221/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8517 - loss: 0.3362 - val_accuracy: 0.8538 - val_loss: 0.3313 - learning_rate: 1.0000e-05
# Epoch 222/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8515 - loss: 0.3364 - val_accuracy: 0.8539 - val_loss: 0.3314 - learning_rate: 1.0000e-05
# Epoch 223/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8516 - loss: 0.3365 - val_accuracy: 0.8538 - val_loss: 0.3314 - learning_rate: 1.0000e-05
# Epoch 224/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8514 - loss: 0.3362 - val_accuracy: 0.8536 - val_loss: 0.3315 - learning_rate: 1.0000e-05
# Epoch 225/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8517 - loss: 0.3363 - val_accuracy: 0.8539 - val_loss: 0.3314 - learning_rate: 1.0000e-05
# Epoch 226/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8514 - loss: 0.3363 - val_accuracy: 0.8536 - val_loss: 0.3314 - learning_rate: 1.0000e-05
# Epoch 227/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8516 - loss: 0.3363 - val_accuracy: 0.8539 - val_loss: 0.3313 - learning_rate: 1.0000e-05
# Epoch 228/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8517 - loss: 0.3363 - val_accuracy: 0.8538 - val_loss: 0.3314 - learning_rate: 1.0000e-05
# Epoch 229/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8514 - loss: 0.3362 - val_accuracy: 0.8537 - val_loss: 0.3314 - learning_rate: 1.0000e-05
# Epoch 230/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8515 - loss: 0.3362 - val_accuracy: 0.8537 - val_loss: 0.3313 - learning_rate: 1.0000e-05
# Epoch 231/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8516 - loss: 0.3360 - val_accuracy: 0.8538 - val_loss: 0.3313 - learning_rate: 1.0000e-05
# Epoch 232/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8514 - loss: 0.3362 - val_accuracy: 0.8538 - val_loss: 0.3313 - learning_rate: 1.0000e-05
# Epoch 233/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8517 - loss: 0.3360 - val_accuracy: 0.8538 - val_loss: 0.3314 - learning_rate: 1.0000e-05
# Epoch 234/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8517 - loss: 0.3361 - val_accuracy: 0.8537 - val_loss: 0.3313 - learning_rate: 1.0000e-05
# Epoch 235/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8517 - loss: 0.3360 - val_accuracy: 0.8538 - val_loss: 0.3313 - learning_rate: 1.0000e-05
# Epoch 236/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8518 - loss: 0.3361 - val_accuracy: 0.8537 - val_loss: 0.3313 - learning_rate: 1.0000e-05
# Epoch 237/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8518 - loss: 0.3360 - val_accuracy: 0.8541 - val_loss: 0.3312 - learning_rate: 1.0000e-05
# Epoch 238/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8519 - loss: 0.3358 - val_accuracy: 0.8537 - val_loss: 0.3313 - learning_rate: 1.0000e-05
# Epoch 239/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8517 - loss: 0.3359 - val_accuracy: 0.8539 - val_loss: 0.3312 - learning_rate: 1.0000e-05
# Epoch 240/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8516 - loss: 0.3360 - val_accuracy: 0.8536 - val_loss: 0.3312 - learning_rate: 1.0000e-05
# Epoch 241/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8515 - loss: 0.3361 - val_accuracy: 0.8539 - val_loss: 0.3312 - learning_rate: 1.0000e-05
# Epoch 242/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8518 - loss: 0.3360 - val_accuracy: 0.8538 - val_loss: 0.3312 - learning_rate: 1.0000e-05
# Epoch 243/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8516 - loss: 0.3357 - val_accuracy: 0.8538 - val_loss: 0.3312 - learning_rate: 1.0000e-05
# Epoch 244/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8515 - loss: 0.3357 - val_accuracy: 0.8538 - val_loss: 0.3312 - learning_rate: 1.0000e-05
# Epoch 245/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8519 - loss: 0.3357 - val_accuracy: 0.8539 - val_loss: 0.3312 - learning_rate: 1.0000e-05
# Epoch 246/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8518 - loss: 0.3355 - val_accuracy: 0.8539 - val_loss: 0.3312 - learning_rate: 1.0000e-05
# Epoch 247/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8521 - loss: 0.3358 - val_accuracy: 0.8538 - val_loss: 0.3312 - learning_rate: 1.0000e-05
# Epoch 248/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8518 - loss: 0.3357 - val_accuracy: 0.8540 - val_loss: 0.3311 - learning_rate: 1.0000e-05
# Epoch 249/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8518 - loss: 0.3358 - val_accuracy: 0.8539 - val_loss: 0.3311 - learning_rate: 1.0000e-05
# Epoch 250/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8517 - loss: 0.3357 - val_accuracy: 0.8538 - val_loss: 0.3311 - learning_rate: 1.0000e-05
# Epoch 251/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8518 - loss: 0.3357 - val_accuracy: 0.8538 - val_loss: 0.3311 - learning_rate: 1.0000e-05
# Epoch 252/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8519 - loss: 0.3355 - val_accuracy: 0.8539 - val_loss: 0.3311 - learning_rate: 1.0000e-05
# Epoch 253/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8520 - loss: 0.3356 - val_accuracy: 0.8540 - val_loss: 0.3311 - learning_rate: 1.0000e-05
# Epoch 254/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8515 - loss: 0.3355 - val_accuracy: 0.8540 - val_loss: 0.3311 - learning_rate: 1.0000e-05
# Epoch 255/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8520 - loss: 0.3357 - val_accuracy: 0.8539 - val_loss: 0.3311 - learning_rate: 1.0000e-05
# Epoch 256/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8519 - loss: 0.3354 - val_accuracy: 0.8539 - val_loss: 0.3310 - learning_rate: 1.0000e-05
# Epoch 257/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8519 - loss: 0.3352 - val_accuracy: 0.8540 - val_loss: 0.3310 - learning_rate: 1.0000e-05
# Epoch 258/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8516 - loss: 0.3355 - val_accuracy: 0.8540 - val_loss: 0.3310 - learning_rate: 1.0000e-05
# Epoch 259/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8518 - loss: 0.3354 - val_accuracy: 0.8538 - val_loss: 0.3311 - learning_rate: 1.0000e-05
# Epoch 260/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8519 - loss: 0.3353 - val_accuracy: 0.8539 - val_loss: 0.3311 - learning_rate: 1.0000e-05
# Epoch 261/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8518 - loss: 0.3355 - val_accuracy: 0.8540 - val_loss: 0.3310 - learning_rate: 1.0000e-05
# Epoch 262/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8520 - loss: 0.3353 - val_accuracy: 0.8540 - val_loss: 0.3310 - learning_rate: 1.0000e-05
# Epoch 263/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8518 - loss: 0.3354 - val_accuracy: 0.8540 - val_loss: 0.3310 - learning_rate: 1.0000e-05
# Epoch 264/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8521 - loss: 0.3354 - val_accuracy: 0.8541 - val_loss: 0.3310 - learning_rate: 1.0000e-05
# Epoch 265/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8518 - loss: 0.3355 - val_accuracy: 0.8539 - val_loss: 0.3310 - learning_rate: 1.0000e-05
# Epoch 266/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8521 - loss: 0.3352 - val_accuracy: 0.8540 - val_loss: 0.3310 - learning_rate: 1.0000e-05
# Epoch 267/1024
# 1330/1330 - 5s - 4ms/step - accuracy: 0.8521 - loss: 0.3352 - val_accuracy: 0.8539 - val_loss: 0.3310 - learning_rate: 1.0000e-05
# Epoch 268/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8520 - loss: 0.3353 - val_accuracy: 0.8541 - val_loss: 0.3310 - learning_rate: 1.0000e-05
# Epoch 269/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8521 - loss: 0.3353 - val_accuracy: 0.8539 - val_loss: 0.3311 - learning_rate: 1.0000e-05
# Epoch 270/1024
# 1330/1330 - 5s - 3ms/step - accuracy: 0.8521 - loss: 0.3351 - val_accuracy: 0.8541 - val_loss: 0.3310 - learning_rate: 1.0000e-05
# Epoch 271/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8519 - loss: 0.3352 - val_accuracy: 0.8540 - val_loss: 0.3310 - learning_rate: 1.0000e-05
# Epoch 272/1024
# 1330/1330 - 4s - 3ms/step - accuracy: 0.8520 - loss: 0.3349 - val_accuracy: 0.8541 - val_loss: 0.3311 - learning_rate: 1.0000e-05
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743921574.702640  955297 service.cc:145] XLA service 0x709040040640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1743921574.702656  955297 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# 2025-04-06 06:39:34.830301: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-04-06 06:39:35.361408: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743921580.312287  955661 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_5', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1743921580.469575  955661 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_7', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1743921580.531853  955660 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_7', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1743921580.538993  955657 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_9', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1743921580.778807  955671 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_15', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1743921581.121994  955677 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_9', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1743921581.148509  955678 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_15', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1743921587.883447  955297 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_subtract_fusion_15', 344 bytes spill stores, 1160 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function '__cuda_sm3x_div_rn_noftz_f32_slowpath', 92 bytes spill stores, 88 bytes spill loads
#
# I0000 00:00:1743921587.897892  955297 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# I0000 00:00:1743921597.787549  956021 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_8', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1743921597.901033  956022 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_8', 24 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1743921598.098170  956013 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_5', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1743921598.175434  956030 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_15', 328 bytes spill stores, 328 bytes spill loads
#
# I0000 00:00:1743921598.576654  956021 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_4', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1743921598.610518  956020 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_9', 160 bytes spill stores, 152 bytes spill loads
#
# I0000 00:00:1743921598.864870  956028 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_7', 240 bytes spill stores, 240 bytes spill loads
#
# I0000 00:00:1743921598.961555  956016 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_9', 240 bytes spill stores, 240 bytes spill loads
#
# I0000 00:00:1743921605.321313  955310 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_subtract_fusion_15', 344 bytes spill stores, 1160 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function '__cuda_sm3x_div_rn_noftz_f32_slowpath', 92 bytes spill stores, 88 bytes spill loads
#
# I0000 00:00:1743921606.936612  956568 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1743921607.034656  956573 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1743921607.069177  956579 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1743921607.251443  956581 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_3', 24 bytes spill stores, 24 bytes spill loads

# %%
# Make a directory
dir_name = HOME_PATH + "/10th_trial/ww_classification_result/"
savedmodel_path = dir_name + "saved_model"
name = "ww_classifier"

# If the directory exists
if os.path.exists(dir_name):
    test_files = glob.glob(dir_name + "*" + name + "*")
    if test_files:
        for file in test_files:
            os.remove(file)
        print(f"Directory {dir_name} cleaned.")
    print(f"Directory {dir_name} exists.")
else:
    os.makedirs(dir_name)
    print(f"Directory {dir_name} created.")

# save modela
model.save(dir_name + name + ".keras", save_format="keras", overwrite=True)
tf.saved_model.save(model, savedmodel_path) # save model in saved_model format --> use in the onnx 

# predict
pred_y = model.predict(test_x)
# save predicted results
np.savez_compressed(dir_name + name + "_data.npz", pred_y=pred_y, test_y=test_y)
sig_pred = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth = np.load(dir_name + name + "_data.npz")["test_y"]
# Out:
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=keras
# Directory /root/work/QE-mls/10th_trial/ww_classification_result/ cleaned.
# Directory /root/work/QE-mls/10th_trial/ww_classification_result/ exists.
# INFO:tensorflow:Assets written to: /root/work/QE-mls/10th_trial/ww_classification_result/saved_model/assets
# INFO:tensorflow:Assets written to: /root/work/QE-mls/10th_trial/ww_classification_result/saved_model/assets
# 2660/2660 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# I0000 00:00:1743922798.628280 1006872 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1743922802.197274 1007024 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_2', 8 bytes spill stores, 8 bytes spill loads

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

print("Accuracy:", np.mean(np.round(sig_pred) == sig_truth))

# Set global font sizes
plt.rcParams.update({
    'font.size': 18,
    'axes.titlesize': 18,
    'axes.labelsize': 18,
    'xtick.labelsize': 16,
    'ytick.labelsize': 16,
    'legend.fontsize': 16,
})

fig = plt.figure(figsize=(10,10), dpi=300)
plt.subplot(2,1,1)
plt.plot(history.history['loss'], lw=3, label='Train')
plt.plot(history.history['val_loss'], lw=3, label='Validation')
plt.xlabel('')
plt.ylabel('Loss')
plt.legend()
plt.subplot(2,1,2)
plt.plot(history.history['accuracy'], lw=3, label='Train')
plt.plot(history.history['val_accuracy'], lw=3, label='Validation')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend()
plt.show()

predicted = tf.squeeze(sig_pred) # ensure the dimension is correct (dim-1)
predicted = np.where(predicted >= 0.5, 1, 0)
labeled = np.where(sig_truth >= 0.5, 1, 0)
actual = np.array(sig_truth)
print("actual:", actual.sum())
print("predicted:", predicted.sum())

conf_mat = confusion_matrix(actual, predicted)
fig, ax = plt.subplots(figsize=(10, 10), dpi=300)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat, display_labels=["Off-shell", "On-shell"])
displ.plot(ax=ax, cmap='Blues', colorbar=False)
ax.set_xlabel('Predicted label')
ax.set_ylabel('True label')
plt.show()
# Out:
# Accuracy: 0.8529232070683335
# actual: 69831
# predicted: 79011

# %%
import shap
import matplotlib as mpl

mpl.rcParams.update(mpl.rcParamsDefault)

feature_names = [
    r"$p^{\ell_0}_{x}$",
    r"$p^{\ell_0}_{y}$",
    r"$p^{\ell_0}_{z}$",
    r"$E^{\ell_0}$",
    r"$p^{\ell_0}_{T}$",
    r"$\eta^{\ell_0}$",
    r"$\phi^{\ell_0}$",
    r"$q^{\ell_0}$",
    r"$p^{\ell_1}_{x}$",
    r"$p^{\ell_1}_{y}$",
    r"$p^{\ell_1}_{z}$",
    r"$E^{\ell_1}$",
    r"$p^{\ell_1}_{T}$",
    r"$\eta^{\ell_1}$",
    r"$\phi^{\ell_1}$",
    r"$q^{\ell_1}$",
    r"$p^{miss}_{x}$",
    r"$p^{miss}_{y}$",
    r"$p^{miss}_{T}$",
    r"$\phi^{miss}$"
]

# Use DeepExplainer for SHAP values
explainer = shap.DeepExplainer(model, obs_kin[1_024:3_072])
shap_values = explainer.shap_values(obs_kin[1_024:3_072], check_additivity=False)

fig = plt.figure(figsize=(7, 6), dpi=500)
for i in range(shap_values.shape[-1]):
    shap.summary_plot(
        shap_values[:, :, i],
        obs_kin[1_024:3_072],
        feature_names=feature_names,
        plot_type="dot",
        show=False,
    )
# plt.title(f"SHAP summary for on-off shell classifications")
plt.show()
# Out:
# /root/miniconda3/envs/tf/lib/python3.11/site-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# /root/miniconda3/envs/tf/lib/python3.11/site-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(2048, 20))']
#   warnings.warn(msg)
# /root/miniconda3/envs/tf/lib/python3.11/site-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(4096, 20))']
#   warnings.warn(msg)
# '-amx-complex' is not a recognized feature for this target (ignoring feature)
# '-amx-fp16' is not a recognized feature for this target (ignoring feature)
# '-avx10.1-256' is not a recognized feature for this target (ignoring feature)
# '-avx10.1-512' is not a recognized feature for this target (ignoring feature)
# '-avxifma' is not a recognized feature for this target (ignoring feature)
# '-avxneconvert' is not a recognized feature for this target (ignoring feature)
# '-avxvnniint16' is not a recognized feature for this target (ignoring feature)
# '-avxvnniint8' is not a recognized feature for this target (ignoring feature)
# '-cmpccxadd' is not a recognized feature for this target (ignoring feature)
# '-prefetchi' is not a recognized feature for this target (ignoring feature)
# '-raoint' is not a recognized feature for this target (ignoring feature)
# '-rdpru' is not a recognized feature for this target (ignoring feature)
# '-sha512' is not a recognized feature for this target (ignoring feature)
# '-sm3' is not a recognized feature for this target (ignoring feature)
# '-sm4' is not a recognized feature for this target (ignoring feature)
# '-usermsr' is not a recognized feature for this target (ignoring feature)
