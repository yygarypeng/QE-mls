# %%
# %reset -sf

import tensorflow as tf
print("Tensorflow:", tf.__version__)


# GPU(s) setups
gpus = tf.config.experimental.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(gpus[0], True)
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')
        
        # Enable memory growth for the first GPU
        tf.config.experimental.set_memory_growth(gpus[0], True)
        
        # Instead of enabling memory growth, set a memory limit
        memory_limit = 16_376 # Set the memory limit in MB
        # memory_limit = -1
        if memory_limit >= 0:
            tf.config.experimental.set_virtual_device_configuration(
                gpus[0],
                [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]
            )
            
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2024-11-06 08:48:18.873559: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-06 08:48:18.893045: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow: 2.13.0
# 1 Physical GPUs, 1 Logical GPU
# 2024-11-06 08:48:20.198483: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 16376 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
import sys
import os
import glob

HOME_PATH = os.path.abspath("..")
sys.path.insert(0, HOME_PATH + "/qe")

import atlas_plot as ap

plot = ap.Plotter()

import pandas as pd
import numpy as np
import scipy as sp

from matplotlib import pyplot as plt

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "1"  # suppress tensorflow imformation messages

from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error


# ONNX
import tf2onnx
import onnx
import onnxruntime as ort

SEED = 42  # set random seed (global variable)
GEV = 1e-3

# %%
from dataclasses import dataclass

data_path = "/root/data/recotruth/full_345324_data.h5"


def pt(px, py):
    return np.sqrt(np.square(px) + np.square(py))


def eta(px, py, pz):
    pt = np.sqrt(np.square(px) + np.square(py))
    return np.arcsinh(np.divide(pz, pt))


def phi(px, py):
    return np.arctan2(py, px)


def m(p4):
    return np.sqrt(
        np.square(p4[:, 3])
        - np.square(p4[:, 0])
        - np.square(p4[:, 1])
        - np.square(p4[:, 2])
    )


@dataclass
class Lead_lep:
    px = pd.read_hdf(data_path, "reco_leadlep")["RecoLeadLepPx"] * GEV
    py = pd.read_hdf(data_path, "reco_leadlep")["RecoLeadLepPy"] * GEV
    pz = pd.read_hdf(data_path, "reco_leadlep")["RecoLeadLepPz"] * GEV
    energy = pd.read_hdf(data_path, "reco_leadlep")["RecoLeadLepE"] * GEV
    pt = pd.read_hdf(data_path, "reco_leadlep")["RecoLeadLepPt"] * GEV
    eta = pd.read_hdf(data_path, "reco_leadlep")["RecoLeadLepEta"]
    phi = pd.read_hdf(data_path, "reco_leadlep")["RecoLeadLepPhi"]
    p4 = np.array([px, py, pz, energy]).T
    p3 = np.array([px, py, pz]).T


@dataclass
class Sublead_lep:
    px = pd.read_hdf(data_path, "reco_subleadlep")["RecoSubleadLepPx"] * GEV
    py = pd.read_hdf(data_path, "reco_subleadlep")["RecoSubleadLepPy"] * GEV
    pz = pd.read_hdf(data_path, "reco_subleadlep")["RecoSubleadLepPz"] * GEV
    energy = pd.read_hdf(data_path, "reco_subleadlep")["RecoSubleadLepE"] * GEV
    pt = pd.read_hdf(data_path, "reco_subleadlep")["RecoSubleadLepPt"] * GEV
    eta = pd.read_hdf(data_path, "reco_subleadlep")["RecoSubleadLepEta"]
    phi = pd.read_hdf(data_path, "reco_subleadlep")["RecoSubleadLepPhi"]
    p4 = np.array([px, py, pz, energy]).T
    p3 = np.array([px, py, pz]).T


@dataclass
class Dilep:
    lead = Lead_lep()
    sublead = Sublead_lep()
    p4 = Lead_lep.p4 + Sublead_lep.p4
    p3 = p4[:, :3]
    px = p4[:, 0]
    py = p4[:, 1]
    pz = p4[:, 2]
    energy = p4[:, 3]
    pt = pt(px, py)
    eta = eta(px, py, pz)
    phi = phi(px, py)
    m = m(p4)


@dataclass
class Met:
    px = pd.read_hdf(data_path, "reco_met")["RecoMETPx"] * GEV
    py = pd.read_hdf(data_path, "reco_met")["RecoMETPy"] * GEV
    phi = pd.read_hdf(data_path, "reco_met")["RecoMETPhi"]
    pt = pt(px, py)


@dataclass
class Truth_lead_lep:
    px = pd.read_hdf(data_path, "truth_leadlep")["TruthRecoLeadLepPx"] * GEV
    py = pd.read_hdf(data_path, "truth_leadlep")["TruthRecoLeadLepPy"] * GEV
    pz = pd.read_hdf(data_path, "truth_leadlep")["TruthRecoLeadLepPz"] * GEV
    energy = pd.read_hdf(data_path, "truth_leadlep")["TruthRecoLeadLepE"] * GEV
    pt = pd.read_hdf(data_path, "truth_leadlep")["TruthRecoLeadLepPt"] * GEV
    eta = pd.read_hdf(data_path, "truth_leadlep")["TruthRecoLeadLepEta"]
    phi = pd.read_hdf(data_path, "truth_leadlep")["TruthRecoLeadLepPhi"]
    p4 = np.array([px, py, pz, energy]).T
    p3 = np.array([px, py, pz]).T


@dataclass
class Truth_sublead_lep:
    px = pd.read_hdf(data_path, "truth_subleadlep")["TruthRecoSubleadLepPx"] * GEV
    py = pd.read_hdf(data_path, "truth_subleadlep")["TruthRecoSubleadLepPy"] * GEV
    pz = pd.read_hdf(data_path, "truth_subleadlep")["TruthRecoSubleadLepPz"] * GEV
    energy = pd.read_hdf(data_path, "truth_subleadlep")["TruthRecoSubleadLepE"] * GEV
    pt = pd.read_hdf(data_path, "truth_subleadlep")["TruthRecoSubleadLepPt"] * GEV
    eta = pd.read_hdf(data_path, "truth_subleadlep")["TruthRecoSubleadLepEta"]
    phi = pd.read_hdf(data_path, "truth_subleadlep")["TruthRecoSubleadLepPhi"]
    p4 = np.array([px, py, pz, energy]).T
    p3 = np.array([px, py, pz]).T


@dataclass
class Truth_dilep:
    lead = Truth_lead_lep()
    sublead = Truth_sublead_lep()
    p4 = Lead_lep.p4 + Sublead_lep.p4
    p3 = p4[:, :3]
    px = p4[:, 0]
    py = p4[:, 1]
    pz = p4[:, 2]
    energy = p4[:, 3]
    pt = pt(px, py)
    eta = eta(px, py, pz)
    phi = phi(px, py)
    m = m(p4)


@dataclass
class Truth_met:
    px = pd.read_hdf(data_path, "truth_met")["TruthRecoMETPx"] * GEV
    py = pd.read_hdf(data_path, "truth_met")["TruthRecoMETPy"] * GEV
    phi = pd.read_hdf(data_path, "truth_met")["TruthRecoMETPhi"]
    pt = pt(px, py)


@dataclass
class Lead_w:
    px = pd.read_hdf(data_path, "truth_leadw")["TruthRecoLeadWPx"] * GEV
    py = pd.read_hdf(data_path, "truth_leadw")["TruthRecoLeadWPy"] * GEV
    pz = pd.read_hdf(data_path, "truth_leadw")["TruthRecoLeadWPz"] * GEV
    energy = pd.read_hdf(data_path, "truth_leadw")["TruthRecoLeadWE"] * GEV
    pt = pd.read_hdf(data_path, "truth_leadw")["TruthRecoLeadWPt"] * GEV
    eta = pd.read_hdf(data_path, "truth_leadw")["TruthRecoLeadWEta"]
    phi = pd.read_hdf(data_path, "truth_leadw")["TruthRecoLeadWPhi"]
    m = pd.read_hdf(data_path, "truth_leadw")["TruthRecoLeadWM"] * GEV
    p4 = np.array([px, py, pz, energy]).T
    p3 = np.array([px, py, pz]).T


@dataclass
class Sublead_w:
    px = pd.read_hdf(data_path, "truth_subleadw")["TruthRecoSubleadWPx"] * GEV
    py = pd.read_hdf(data_path, "truth_subleadw")["TruthRecoSubleadWPy"] * GEV
    pz = pd.read_hdf(data_path, "truth_subleadw")["TruthRecoSubleadWPz"] * GEV
    energy = pd.read_hdf(data_path, "truth_subleadw")["TruthRecoSubleadWE"] * GEV
    pt = pd.read_hdf(data_path, "truth_subleadw")["TruthRecoSubleadWPt"] * GEV
    eta = pd.read_hdf(data_path, "truth_subleadw")["TruthRecoSubleadWEta"]
    phi = pd.read_hdf(data_path, "truth_subleadw")["TruthRecoSubleadWPhi"]
    m = pd.read_hdf(data_path, "truth_subleadw")["TruthRecoSubleadWM"] * GEV
    p4 = np.array([px, py, pz, energy]).T
    p3 = np.array([px, py, pz]).T

# %%
# reco
lead_lep = Lead_lep()
sublead_lep = Sublead_lep()
dilep = Dilep()
met = Met()

# truth
truth_lead_lep = Truth_lead_lep()
truth_sublead_lep = Truth_sublead_lep()
Truth_dilep = Truth_dilep()
truth_met = Truth_met()

# target Ws
w_lead = Lead_w()
w_sublead = Sublead_w()

# %%
# define preselection cuts

# cut_pre_pt_lead = lead_lep.pt > 22
# print(len(lead_lep.energy) - np.sum(cut_pre_pt_lead * 1))
# cut_pre_pt_sub = sublead_lep.pt > 15
# print(len(lead_lep.energy) - np.sum(cut_pre_pt_sub * 1))
# cut_pre_dilep_m = (
#     np.sqrt(
#         np.square(lead_lep.energy + sublead_lep.energy)
#         - np.square(lead_lep.px + sublead_lep.px)
#         - np.square(lead_lep.py + sublead_lep.py)
#         - np.square(lead_lep.pz + sublead_lep.pz)
#     )
#     > 10
# )
# print(len(lead_lep.energy) - np.sum(cut_pre_dilep_m * 1))
# cut_pre_pt_miss = met.pt > 20
# print(len(lead_lep.energy) - np.sum(cut_pre_pt_miss * 1))
# PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
# print(len(lead_lep.energy) - np.sum(PRE_CUT * 1))
# del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# define preselection cuts

cut_pre_pt_lead = lead_lep.pt > -999999
print(len(lead_lep.energy) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = sublead_lep.pt > -999999
print(len(lead_lep.energy) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.sqrt(
        np.square(lead_lep.energy + sublead_lep.energy)
        - np.square(lead_lep.px + sublead_lep.px)
        - np.square(lead_lep.py + sublead_lep.py)
        - np.square(lead_lep.pz + sublead_lep.pz)
    )
    > -999999
)
print(len(lead_lep.energy) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = met.pt > -999999
print(len(lead_lep.energy) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print(len(lead_lep.energy) - np.sum(PRE_CUT * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
## Observing variables

obs_kin = np.column_stack(
    (
        lead_lep.px,
        lead_lep.py,
        # lead_lep.pz,
        # lead_lep.energy,
        np.log(lead_lep.energy),
        # np.log(lead_lep.pt),
        lead_lep.eta,
        # lead_lep.phi,
        sublead_lep.px,
        sublead_lep.py,
        # sublead_lep.pz,
        # sublead_lep.energy,
        np.log(sublead_lep.energy),
        # np.log(sublead_lep.pt),
        sublead_lep.eta,
        # sublead_lep.phi,
        met.px,
        met.py,
        # met.pt,
        # met.phi,
        # dilep.px,
        # dilep.py,
        # dilep.pz,
        # np.log(dilep.energy),
        # dilep.pt,
        # dilep.eta,
        # dilep.phi,
        # dilep.m,
    )
)[PRE_CUT]

# Kinematics of observing variables (inputs for training)
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array

ROBUST_OBS = StandardScaler()
obs_kin = ROBUST_OBS.fit_transform(obs_kin)
print(type(obs_kin))
# Out:
# int_kin shape: (358015, 10)
# <class 'numpy.ndarray'>

# %%
## Interesting variables

w_lead_px = pd.DataFrame(w_lead.px[PRE_CUT])
w_lead_py = pd.DataFrame(w_lead.py[PRE_CUT])
w_lead_pz = pd.DataFrame(w_lead.pz[PRE_CUT])
w_lead_e = pd.DataFrame(w_lead.energy[PRE_CUT])
w_lead_log_e = pd.DataFrame(np.log(w_lead_e))
w_lead_sqrt_e = pd.DataFrame(np.sqrt(w_lead_e))
w_sublead_px = pd.DataFrame(w_sublead.px[PRE_CUT])
w_sublead_py = pd.DataFrame(w_sublead.py[PRE_CUT])
w_sublead_pz = pd.DataFrame(w_sublead.pz[PRE_CUT])
w_sublead_e = pd.DataFrame(w_sublead.energy[PRE_CUT])
w_sublead_log_e = pd.DataFrame(np.log(w_sublead_e))
w_sublead_sqrt_e = pd.DataFrame(np.sqrt(w_sublead_e))
w_lead_m = pd.DataFrame(w_lead.m[PRE_CUT])
w_sublead_m = pd.DataFrame(w_sublead.m[PRE_CUT])

# Kinematics of interesting variables (target for training)
int_kin = np.concatenate(
    [
        w_lead_px,
        w_lead_py,
        w_lead_pz,
        w_lead_e,
        w_sublead_px,
        w_sublead_py,
        w_sublead_pz,
        w_sublead_e,
        # np.square(w_lead_m) / np.mean(w_lead_m),
        # np.square(w_sublead_m) / np.mean(w_lead_m),
        # w_lead_m,
        # w_sublead_m,
    ],
    axis=-1,
)
print("int_kin shape:", int_kin.shape)
# int_kin = int_kin.to_numpy()  # convert to numpy array
print(type(int_kin))
# Out:
# int_kin shape: (358015, 8)
# <class 'numpy.ndarray'>

# %%
# lead_w_m2 = plt.hist([np.square(np.array(w_lead_m).flatten()) / np.mean(w_lead_m), np.square(np.array(w_sublead_m).flatten()) / np.mean(w_lead_m)], bins=81, stacked=True)
# plt.show()
# lead_w_m2 = plt.hist([np.array(w_lead_m).flatten(), np.array(w_sublead_m).flatten()], bins=81, stacked=True)

# %%
bin_edge = np.linspace(-3, 3, 81)
sublead_px = plt.hist(
    obs_kin[:, 0], bins=bin_edge, alpha=0.8, label="px", histtype="step", density=True
)
lead_py = plt.hist(
    obs_kin[:, 1], bins=bin_edge, alpha=0.8, label="py", histtype="step", density=True
)
lead_log_e = plt.hist(
    obs_kin[:, 2],
    bins=bin_edge,
    alpha=0.8,
    label="log_energy",
    histtype="step",
    density=True,
)
# lead_px = plt.hist(w_lead_px, bins=bin_edge, alpha=.8)
lead_pz = plt.hist(
    obs_kin[:, 3], bins=bin_edge, alpha=0.8, label="eta", histtype="step", density=True
)
# lead_px = plt.hist(w_lead_m, bins=bin_edge, alpha=.8)
# plt.yscale("log")
plt.title("Lead lep")
plt.legend()
plt.show()

sublead_px = plt.hist(
    obs_kin[:, 4], bins=bin_edge, alpha=0.8, label="px", histtype="step", density=True
)
sublead_py = plt.hist(
    obs_kin[:, 5], bins=bin_edge, alpha=0.8, label="py", histtype="step", density=True
)
sublead_log_e = plt.hist(
    obs_kin[:, 6],
    bins=bin_edge,
    alpha=0.8,
    label="log_energy",
    histtype="step",
    density=True,
)
sublead_pz = plt.hist(
    obs_kin[:, 7], bins=bin_edge, alpha=0.8, label="eta", histtype="step", density=True
)
# sublead_px = plt.hist(w_sublead_px, bins=bin_edge, alpha=.8)
# sublead_px = plt.hist(w_sublead_m, bins=bin_edge, alpha=.8)
# plt.yscale("log")
plt.title("Sublead lep")
plt.legend()
plt.show()


lead_energy = plt.hist(lead_lep.energy, bins=80, alpha=0.8, label="eta", histtype="step", density=True)
plt.title("Lead lep energy")
plt.show()
lead_log_energy = plt.hist(np.log(lead_lep.energy), bins=80, alpha=0.8, label="eta", histtype="step", density=True)
plt.title("Lead lep log(energy)")
plt.show()

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.8,
    test_size=0.2,
    random_state=SEED,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=SEED
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
# test_x = np.concatenate([test_x, valid_x], axis=0)
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]
# test_y = np.concatenate([test_y, valid_y], axis=0)

print("Total evts:", len(indices_arr))
print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# Total evts: 358015
# X (Interest)
# Training data shape: (286412, 10);
# Validing data shape: (35801, 10);
# Testing data shape: (35802, 10).
# Y (Observed)
# Training data shape: (286412, 8);
# Validing data shape: (35801, 8);
# Testing data shape: (35802, 8).

# %%
# training variables
BATCH_SIZE = 1024
EPOCHS = 1024
LEARNING_RATE = 1e-4

# %%
def dense_dropout_block(x, units, activation="elu", dropout_rate=0.2, l2=0.0):
    x = tf.keras.layers.Dense(
        units=units,
        activation=activation,
        kernel_regularizer=tf.keras.regularizers.L2(l2=l2),
    )(x)
    if dropout_rate > 0:
        x = tf.keras.layers.Dropout(rate=dropout_rate)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    return x


def residual_block(x, units, activation="elu", dropout_rate=0.0, l2=0.0):
    x = dense_dropout_block(x, units, dropout_rate=dropout_rate, activation=activation, l2=l2)
    y = dense_dropout_block(x, units // 2, dropout_rate=dropout_rate, activation=activation, l2=l2/2)
    y = dense_dropout_block(y, units, dropout_rate=dropout_rate, activation=activation, l2=l2)
    z = tf.keras.layers.Add()([x, y])
    z = tf.keras.layers.Activation(activation)(z)
    z = tf.keras.layers.BatchNormalization()(z)
    return z

def build_model():
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # construct the model
    for _ in range(5):
        x = residual_block(x, 256, dropout_rate=0.02, l2=0.0)
        x = residual_block(x, 512, dropout_rate=0.03, l2=0.0) # 0.04
        x = residual_block(x, 128, dropout_rate=0.01, l2=0.0)
        
    outputs = tf.keras.layers.Dense(units=train_y.shape[-1], activation="linear")(x)

    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
model = build_model()
model.summary()
# tf.keras.utils.plot_model(model, to_file="WWResDNNRegressor.png", show_shapes=True, show_layer_names=False)
# Out:
# 2024-11-06 08:48:21.794978: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:753] failed to allocate 15.99GiB (17171480576 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 10)]                 0         []
#
#  flatten (Flatten)           (None, 10)                   0         ['input_1[0][0]']
#
#  dense (Dense)               (None, 256)                  2816      ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 256)                  0         ['dense[0][0]']
#
#  batch_normalization (Batch  (None, 256)                  1024      ['dropout[0][0]']
#  Normalization)
#
#  dense_1 (Dense)             (None, 128)                  32896     ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['dense_1[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128)                  512       ['dropout_1[0][0]']
#  chNormalization)
#
#  dense_2 (Dense)             (None, 256)                  33024     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 256)                  0         ['dense_2[0][0]']
#
#  batch_normalization_2 (Bat  (None, 256)                  1024      ['dropout_2[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 256)                  0         ['batch_normalization[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation (Activation)     (None, 256)                  0         ['add[0][0]']
#
#  batch_normalization_3 (Bat  (None, 256)                  1024      ['activation[0][0]']
#  chNormalization)
#
#  dense_3 (Dense)             (None, 512)                  131584    ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 512)                  0         ['dense_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 512)                  2048      ['dropout_3[0][0]']
#  chNormalization)
#
#  dense_4 (Dense)             (None, 256)                  131328    ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 256)                  0         ['dense_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 256)                  1024      ['dropout_4[0][0]']
#  chNormalization)
#
#  dense_5 (Dense)             (None, 512)                  131584    ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_5 (Dropout)         (None, 512)                  0         ['dense_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 512)                  2048      ['dropout_5[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 512)                  0         ['batch_normalization_4[0][0]'
#                                                                     , 'batch_normalization_6[0][0]
#                                                                     ']
#
#  activation_1 (Activation)   (None, 512)                  0         ['add_1[0][0]']
#
#  batch_normalization_7 (Bat  (None, 512)                  2048      ['activation_1[0][0]']
#  chNormalization)
#
#  dense_6 (Dense)             (None, 128)                  65664     ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 128)                  0         ['dense_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 128)                  512       ['dropout_6[0][0]']
#  chNormalization)
#
#  dense_7 (Dense)             (None, 64)                   8256      ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 64)                   0         ['dense_7[0][0]']
#
#  batch_normalization_9 (Bat  (None, 64)                   256       ['dropout_7[0][0]']
#  chNormalization)
#
#  dense_8 (Dense)             (None, 128)                  8320      ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_8 (Dropout)         (None, 128)                  0         ['dense_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 128)                  512       ['dropout_8[0][0]']
#  tchNormalization)
#
#  add_2 (Add)                 (None, 128)                  0         ['batch_normalization_8[0][0]'
#                                                                     , 'batch_normalization_10[0][0
#                                                                     ]']
#
#  activation_2 (Activation)   (None, 128)                  0         ['add_2[0][0]']
#
#  batch_normalization_11 (Ba  (None, 128)                  512       ['activation_2[0][0]']
#  tchNormalization)
#
#  dense_9 (Dense)             (None, 256)                  33024     ['batch_normalization_11[0][0]
#                                                                     ']
#
#  dropout_9 (Dropout)         (None, 256)                  0         ['dense_9[0][0]']
#
#  batch_normalization_12 (Ba  (None, 256)                  1024      ['dropout_9[0][0]']
#  tchNormalization)
#
#  dense_10 (Dense)            (None, 128)                  32896     ['batch_normalization_12[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 128)                  0         ['dense_10[0][0]']
#
#  batch_normalization_13 (Ba  (None, 128)                  512       ['dropout_10[0][0]']
#  tchNormalization)
#
#  dense_11 (Dense)            (None, 256)                  33024     ['batch_normalization_13[0][0]
#                                                                     ']
#
#  dropout_11 (Dropout)        (None, 256)                  0         ['dense_11[0][0]']
#
#  batch_normalization_14 (Ba  (None, 256)                  1024      ['dropout_11[0][0]']
#  tchNormalization)
#
#  add_3 (Add)                 (None, 256)                  0         ['batch_normalization_12[0][0]
#                                                                     ',
#                                                                      'batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_3 (Activation)   (None, 256)                  0         ['add_3[0][0]']
#
#  batch_normalization_15 (Ba  (None, 256)                  1024      ['activation_3[0][0]']
#  tchNormalization)
#
#  dense_12 (Dense)            (None, 512)                  131584    ['batch_normalization_15[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 512)                  0         ['dense_12[0][0]']
#
#  batch_normalization_16 (Ba  (None, 512)                  2048      ['dropout_12[0][0]']
#  tchNormalization)
#
#  dense_13 (Dense)            (None, 256)                  131328    ['batch_normalization_16[0][0]
#                                                                     ']
#
#  dropout_13 (Dropout)        (None, 256)                  0         ['dense_13[0][0]']
#
#  batch_normalization_17 (Ba  (None, 256)                  1024      ['dropout_13[0][0]']
#  tchNormalization)
#
#  dense_14 (Dense)            (None, 512)                  131584    ['batch_normalization_17[0][0]
#                                                                     ']
#
#  dropout_14 (Dropout)        (None, 512)                  0         ['dense_14[0][0]']
#
#  batch_normalization_18 (Ba  (None, 512)                  2048      ['dropout_14[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 512)                  0         ['batch_normalization_16[0][0]
#                                                                     ',
#                                                                      'batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_4 (Activation)   (None, 512)                  0         ['add_4[0][0]']
#
#  batch_normalization_19 (Ba  (None, 512)                  2048      ['activation_4[0][0]']
#  tchNormalization)
#
#  dense_15 (Dense)            (None, 128)                  65664     ['batch_normalization_19[0][0]
#                                                                     ']
#
#  dropout_15 (Dropout)        (None, 128)                  0         ['dense_15[0][0]']
#
#  batch_normalization_20 (Ba  (None, 128)                  512       ['dropout_15[0][0]']
#  tchNormalization)
#
#  dense_16 (Dense)            (None, 64)                   8256      ['batch_normalization_20[0][0]
#                                                                     ']
#
#  dropout_16 (Dropout)        (None, 64)                   0         ['dense_16[0][0]']
#
#  batch_normalization_21 (Ba  (None, 64)                   256       ['dropout_16[0][0]']
#  tchNormalization)
#
#  dense_17 (Dense)            (None, 128)                  8320      ['batch_normalization_21[0][0]
#                                                                     ']
#
#  dropout_17 (Dropout)        (None, 128)                  0         ['dense_17[0][0]']
#
#  batch_normalization_22 (Ba  (None, 128)                  512       ['dropout_17[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 128)                  0         ['batch_normalization_20[0][0]
#                                                                     ',
#                                                                      'batch_normalization_22[0][0]
#                                                                     ']
#
#  activation_5 (Activation)   (None, 128)                  0         ['add_5[0][0]']
#
#  batch_normalization_23 (Ba  (None, 128)                  512       ['activation_5[0][0]']
#  tchNormalization)
#
#  dense_18 (Dense)            (None, 256)                  33024     ['batch_normalization_23[0][0]
#                                                                     ']
#
#  dropout_18 (Dropout)        (None, 256)                  0         ['dense_18[0][0]']
#
#  batch_normalization_24 (Ba  (None, 256)                  1024      ['dropout_18[0][0]']
#  tchNormalization)
#
#  dense_19 (Dense)            (None, 128)                  32896     ['batch_normalization_24[0][0]
#                                                                     ']
#
#  dropout_19 (Dropout)        (None, 128)                  0         ['dense_19[0][0]']
#
#  batch_normalization_25 (Ba  (None, 128)                  512       ['dropout_19[0][0]']
#  tchNormalization)
#
#  dense_20 (Dense)            (None, 256)                  33024     ['batch_normalization_25[0][0]
#                                                                     ']
#
#  dropout_20 (Dropout)        (None, 256)                  0         ['dense_20[0][0]']
#
#  batch_normalization_26 (Ba  (None, 256)                  1024      ['dropout_20[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 256)                  0         ['batch_normalization_24[0][0]
#                                                                     ',
#                                                                      'batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_6 (Activation)   (None, 256)                  0         ['add_6[0][0]']
#
#  batch_normalization_27 (Ba  (None, 256)                  1024      ['activation_6[0][0]']
#  tchNormalization)
#
#  dense_21 (Dense)            (None, 512)                  131584    ['batch_normalization_27[0][0]
#                                                                     ']
#
#  dropout_21 (Dropout)        (None, 512)                  0         ['dense_21[0][0]']
#
#  batch_normalization_28 (Ba  (None, 512)                  2048      ['dropout_21[0][0]']
#  tchNormalization)
#
#  dense_22 (Dense)            (None, 256)                  131328    ['batch_normalization_28[0][0]
#                                                                     ']
#
#  dropout_22 (Dropout)        (None, 256)                  0         ['dense_22[0][0]']
#
#  batch_normalization_29 (Ba  (None, 256)                  1024      ['dropout_22[0][0]']
#  tchNormalization)
#
#  dense_23 (Dense)            (None, 512)                  131584    ['batch_normalization_29[0][0]
#                                                                     ']
#
#  dropout_23 (Dropout)        (None, 512)                  0         ['dense_23[0][0]']
#
#  batch_normalization_30 (Ba  (None, 512)                  2048      ['dropout_23[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 512)                  0         ['batch_normalization_28[0][0]
#                                                                     ',
#                                                                      'batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_7 (Activation)   (None, 512)                  0         ['add_7[0][0]']
#
#  batch_normalization_31 (Ba  (None, 512)                  2048      ['activation_7[0][0]']
#  tchNormalization)
#
#  dense_24 (Dense)            (None, 128)                  65664     ['batch_normalization_31[0][0]
#                                                                     ']
#
#  dropout_24 (Dropout)        (None, 128)                  0         ['dense_24[0][0]']
#
#  batch_normalization_32 (Ba  (None, 128)                  512       ['dropout_24[0][0]']
#  tchNormalization)
#
#  dense_25 (Dense)            (None, 64)                   8256      ['batch_normalization_32[0][0]
#                                                                     ']
#
#  dropout_25 (Dropout)        (None, 64)                   0         ['dense_25[0][0]']
#
#  batch_normalization_33 (Ba  (None, 64)                   256       ['dropout_25[0][0]']
#  tchNormalization)
#
#  dense_26 (Dense)            (None, 128)                  8320      ['batch_normalization_33[0][0]
#                                                                     ']
#
#  dropout_26 (Dropout)        (None, 128)                  0         ['dense_26[0][0]']
#
#  batch_normalization_34 (Ba  (None, 128)                  512       ['dropout_26[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 128)                  0         ['batch_normalization_32[0][0]
#                                                                     ',
#                                                                      'batch_normalization_34[0][0]
#                                                                     ']
#
#  activation_8 (Activation)   (None, 128)                  0         ['add_8[0][0]']
#
#  batch_normalization_35 (Ba  (None, 128)                  512       ['activation_8[0][0]']
#  tchNormalization)
#
#  dense_27 (Dense)            (None, 256)                  33024     ['batch_normalization_35[0][0]
#                                                                     ']
#
#  dropout_27 (Dropout)        (None, 256)                  0         ['dense_27[0][0]']
#
#  batch_normalization_36 (Ba  (None, 256)                  1024      ['dropout_27[0][0]']
#  tchNormalization)
#
#  dense_28 (Dense)            (None, 128)                  32896     ['batch_normalization_36[0][0]
#                                                                     ']
#
#  dropout_28 (Dropout)        (None, 128)                  0         ['dense_28[0][0]']
#
#  batch_normalization_37 (Ba  (None, 128)                  512       ['dropout_28[0][0]']
#  tchNormalization)
#
#  dense_29 (Dense)            (None, 256)                  33024     ['batch_normalization_37[0][0]
#                                                                     ']
#
#  dropout_29 (Dropout)        (None, 256)                  0         ['dense_29[0][0]']
#
#  batch_normalization_38 (Ba  (None, 256)                  1024      ['dropout_29[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 256)                  0         ['batch_normalization_36[0][0]
#                                                                     ',
#                                                                      'batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_9 (Activation)   (None, 256)                  0         ['add_9[0][0]']
#
#  batch_normalization_39 (Ba  (None, 256)                  1024      ['activation_9[0][0]']
#  tchNormalization)
#
#  dense_30 (Dense)            (None, 512)                  131584    ['batch_normalization_39[0][0]
#                                                                     ']
#
#  dropout_30 (Dropout)        (None, 512)                  0         ['dense_30[0][0]']
#
#  batch_normalization_40 (Ba  (None, 512)                  2048      ['dropout_30[0][0]']
#  tchNormalization)
#
#  dense_31 (Dense)            (None, 256)                  131328    ['batch_normalization_40[0][0]
#                                                                     ']
#
#  dropout_31 (Dropout)        (None, 256)                  0         ['dense_31[0][0]']
#
#  batch_normalization_41 (Ba  (None, 256)                  1024      ['dropout_31[0][0]']
#  tchNormalization)
#
#  dense_32 (Dense)            (None, 512)                  131584    ['batch_normalization_41[0][0]
#                                                                     ']
#
#  dropout_32 (Dropout)        (None, 512)                  0         ['dense_32[0][0]']
#
#  batch_normalization_42 (Ba  (None, 512)                  2048      ['dropout_32[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 512)                  0         ['batch_normalization_40[0][0]
#                                                                     ',
#                                                                      'batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_10 (Activation)  (None, 512)                  0         ['add_10[0][0]']
#
#  batch_normalization_43 (Ba  (None, 512)                  2048      ['activation_10[0][0]']
#  tchNormalization)
#
#  dense_33 (Dense)            (None, 128)                  65664     ['batch_normalization_43[0][0]
#                                                                     ']
#
#  dropout_33 (Dropout)        (None, 128)                  0         ['dense_33[0][0]']
#
#  batch_normalization_44 (Ba  (None, 128)                  512       ['dropout_33[0][0]']
#  tchNormalization)
#
#  dense_34 (Dense)            (None, 64)                   8256      ['batch_normalization_44[0][0]
#                                                                     ']
#
#  dropout_34 (Dropout)        (None, 64)                   0         ['dense_34[0][0]']
#
#  batch_normalization_45 (Ba  (None, 64)                   256       ['dropout_34[0][0]']
#  tchNormalization)
#
#  dense_35 (Dense)            (None, 128)                  8320      ['batch_normalization_45[0][0]
#                                                                     ']
#
#  dropout_35 (Dropout)        (None, 128)                  0         ['dense_35[0][0]']
#
#  batch_normalization_46 (Ba  (None, 128)                  512       ['dropout_35[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 128)                  0         ['batch_normalization_44[0][0]
#                                                                     ',
#                                                                      'batch_normalization_46[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 128)                  0         ['add_11[0][0]']
#
#  batch_normalization_47 (Ba  (None, 128)                  512       ['activation_11[0][0]']
#  tchNormalization)
#
#  dense_36 (Dense)            (None, 256)                  33024     ['batch_normalization_47[0][0]
#                                                                     ']
#
#  dropout_36 (Dropout)        (None, 256)                  0         ['dense_36[0][0]']
#
#  batch_normalization_48 (Ba  (None, 256)                  1024      ['dropout_36[0][0]']
#  tchNormalization)
#
#  dense_37 (Dense)            (None, 128)                  32896     ['batch_normalization_48[0][0]
#                                                                     ']
#
#  dropout_37 (Dropout)        (None, 128)                  0         ['dense_37[0][0]']
#
#  batch_normalization_49 (Ba  (None, 128)                  512       ['dropout_37[0][0]']
#  tchNormalization)
#
#  dense_38 (Dense)            (None, 256)                  33024     ['batch_normalization_49[0][0]
#                                                                     ']
#
#  dropout_38 (Dropout)        (None, 256)                  0         ['dense_38[0][0]']
#
#  batch_normalization_50 (Ba  (None, 256)                  1024      ['dropout_38[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 256)                  0         ['batch_normalization_48[0][0]
#                                                                     ',
#                                                                      'batch_normalization_50[0][0]
#                                                                     ']
#
#  activation_12 (Activation)  (None, 256)                  0         ['add_12[0][0]']
#
#  batch_normalization_51 (Ba  (None, 256)                  1024      ['activation_12[0][0]']
#  tchNormalization)
#
#  dense_39 (Dense)            (None, 512)                  131584    ['batch_normalization_51[0][0]
#                                                                     ']
#
#  dropout_39 (Dropout)        (None, 512)                  0         ['dense_39[0][0]']
#
#  batch_normalization_52 (Ba  (None, 512)                  2048      ['dropout_39[0][0]']
#  tchNormalization)
#
#  dense_40 (Dense)            (None, 256)                  131328    ['batch_normalization_52[0][0]
#                                                                     ']
#
#  dropout_40 (Dropout)        (None, 256)                  0         ['dense_40[0][0]']
#
#  batch_normalization_53 (Ba  (None, 256)                  1024      ['dropout_40[0][0]']
#  tchNormalization)
#
#  dense_41 (Dense)            (None, 512)                  131584    ['batch_normalization_53[0][0]
#                                                                     ']
#
#  dropout_41 (Dropout)        (None, 512)                  0         ['dense_41[0][0]']
#
#  batch_normalization_54 (Ba  (None, 512)                  2048      ['dropout_41[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 512)                  0         ['batch_normalization_52[0][0]
#                                                                     ',
#                                                                      'batch_normalization_54[0][0]
#                                                                     ']
#
#  activation_13 (Activation)  (None, 512)                  0         ['add_13[0][0]']
#
#  batch_normalization_55 (Ba  (None, 512)                  2048      ['activation_13[0][0]']
#  tchNormalization)
#
#  dense_42 (Dense)            (None, 128)                  65664     ['batch_normalization_55[0][0]
#                                                                     ']
#
#  dropout_42 (Dropout)        (None, 128)                  0         ['dense_42[0][0]']
#
#  batch_normalization_56 (Ba  (None, 128)                  512       ['dropout_42[0][0]']
#  tchNormalization)
#
#  dense_43 (Dense)            (None, 64)                   8256      ['batch_normalization_56[0][0]
#                                                                     ']
#
#  dropout_43 (Dropout)        (None, 64)                   0         ['dense_43[0][0]']
#
#  batch_normalization_57 (Ba  (None, 64)                   256       ['dropout_43[0][0]']
#  tchNormalization)
#
#  dense_44 (Dense)            (None, 128)                  8320      ['batch_normalization_57[0][0]
#                                                                     ']
#
#  dropout_44 (Dropout)        (None, 128)                  0         ['dense_44[0][0]']
#
#  batch_normalization_58 (Ba  (None, 128)                  512       ['dropout_44[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 128)                  0         ['batch_normalization_56[0][0]
#                                                                     ',
#                                                                      'batch_normalization_58[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 128)                  0         ['add_14[0][0]']
#
#  batch_normalization_59 (Ba  (None, 128)                  512       ['activation_14[0][0]']
#  tchNormalization)
#
#  dense_45 (Dense)            (None, 8)                    1032      ['batch_normalization_59[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 2911944 (11.11 MB)
# Trainable params: 2880584 (10.99 MB)
# Non-trainable params: 31360 (122.50 KB)
# __________________________________________________________________________________________________

# %%
# Define data generators with reduced batch size
def data_generator(x, y, batch_size):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = (
        dataset.shuffle(buffer_size=len(x))
        .batch(batch_size)
        .prefetch(tf.data.experimental.AUTOTUNE)
    )
    return dataset


# Create training and validation generators
train_generator = data_generator(train_x, train_y, BATCH_SIZE)
valid_generator = data_generator(valid_x, valid_y, BATCH_SIZE)

# Compile the model
model.compile(
    loss="mae",
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
)

# Early stopping and learning rate scheduler
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-3,
    patience=8,
    mode="auto",
    restore_best_weights=False,
)


def scheduler(epoch, lr):
    if epoch < 512:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-0.1 * LEARNING_RATE))


lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

# Fit the model using generators
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=valid_generator,
    callbacks=[stop_early, lr_scheduler],
    verbose=2,
)
# Out:
# Epoch 1/1024
# 2024-11-06 08:48:28.815990: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-11-06 08:48:28.837737: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5c534b728930 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-06 08:48:28.837752: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# 2024-11-06 08:48:28.840549: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-06 08:48:28.848028: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-11-06 08:48:28.907216: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 280/280 - 19s - loss: 64.3722 - val_loss: 62.0772 - lr: 1.0000e-04 - 19s/epoch - 69ms/step
# Epoch 2/1024
# 280/280 - 6s - loss: 62.7067 - val_loss: 60.9860 - lr: 1.0000e-04 - 6s/epoch - 23ms/step
# Epoch 3/1024
# 280/280 - 6s - loss: 61.3305 - val_loss: 59.5450 - lr: 1.0000e-04 - 6s/epoch - 23ms/step
# Epoch 4/1024
# 280/280 - 7s - loss: 59.8574 - val_loss: 58.0968 - lr: 1.0000e-04 - 7s/epoch - 23ms/step
# Epoch 5/1024
# 280/280 - 6s - loss: 58.3011 - val_loss: 56.4774 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 6/1024
# 280/280 - 5s - loss: 56.6774 - val_loss: 54.8665 - lr: 1.0000e-04 - 5s/epoch - 20ms/step
# Epoch 7/1024
# 280/280 - 5s - loss: 55.0123 - val_loss: 53.1727 - lr: 1.0000e-04 - 5s/epoch - 18ms/step
# Epoch 8/1024
# 280/280 - 6s - loss: 53.3047 - val_loss: 51.5047 - lr: 1.0000e-04 - 6s/epoch - 23ms/step
# Epoch 9/1024
# 280/280 - 6s - loss: 51.5730 - val_loss: 49.8043 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 10/1024
# 280/280 - 6s - loss: 49.8464 - val_loss: 47.9868 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 11/1024
# 280/280 - 6s - loss: 48.1251 - val_loss: 46.4354 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 12/1024
# 280/280 - 6s - loss: 46.4180 - val_loss: 44.6922 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 13/1024
# 280/280 - 6s - loss: 44.7225 - val_loss: 43.2033 - lr: 1.0000e-04 - 6s/epoch - 23ms/step
# Epoch 14/1024
# 280/280 - 6s - loss: 43.0714 - val_loss: 41.5898 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 15/1024
# 280/280 - 7s - loss: 41.4559 - val_loss: 40.2177 - lr: 1.0000e-04 - 7s/epoch - 24ms/step
# Epoch 16/1024
# 280/280 - 5s - loss: 39.8857 - val_loss: 38.4738 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 17/1024
# 280/280 - 6s - loss: 38.4134 - val_loss: 37.0563 - lr: 1.0000e-04 - 6s/epoch - 20ms/step
# Epoch 18/1024
# 280/280 - 6s - loss: 37.0251 - val_loss: 35.5564 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 19/1024
# 280/280 - 7s - loss: 35.7584 - val_loss: 34.4156 - lr: 1.0000e-04 - 7s/epoch - 23ms/step
# Epoch 20/1024
# 280/280 - 6s - loss: 34.6156 - val_loss: 33.3051 - lr: 1.0000e-04 - 6s/epoch - 23ms/step
# Epoch 21/1024
# 280/280 - 5s - loss: 33.6104 - val_loss: 32.3226 - lr: 1.0000e-04 - 5s/epoch - 17ms/step
# Epoch 22/1024
# 280/280 - 6s - loss: 32.7280 - val_loss: 31.5664 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 23/1024
# 280/280 - 6s - loss: 31.8936 - val_loss: 30.5429 - lr: 1.0000e-04 - 6s/epoch - 20ms/step
# Epoch 24/1024
# 280/280 - 5s - loss: 31.1360 - val_loss: 29.9457 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 25/1024
# 280/280 - 6s - loss: 30.4035 - val_loss: 29.3482 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 26/1024
# 280/280 - 6s - loss: 29.7078 - val_loss: 28.6486 - lr: 1.0000e-04 - 6s/epoch - 23ms/step
# Epoch 27/1024
# 280/280 - 6s - loss: 29.0070 - val_loss: 27.9112 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 28/1024
# 280/280 - 5s - loss: 28.3871 - val_loss: 27.3597 - lr: 1.0000e-04 - 5s/epoch - 20ms/step
# Epoch 29/1024
# 280/280 - 5s - loss: 27.8744 - val_loss: 26.8383 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 30/1024
# 280/280 - 5s - loss: 27.4352 - val_loss: 26.6033 - lr: 1.0000e-04 - 5s/epoch - 18ms/step
# Epoch 31/1024
# 280/280 - 6s - loss: 27.1332 - val_loss: 26.3017 - lr: 1.0000e-04 - 6s/epoch - 20ms/step
# Epoch 32/1024
# 280/280 - 7s - loss: 26.8995 - val_loss: 26.0713 - lr: 1.0000e-04 - 7s/epoch - 24ms/step
# Epoch 33/1024
# 280/280 - 6s - loss: 26.7357 - val_loss: 26.0399 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 34/1024
# 280/280 - 6s - loss: 26.6277 - val_loss: 25.8900 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 35/1024
# 280/280 - 5s - loss: 26.5253 - val_loss: 25.7878 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 36/1024
# 280/280 - 6s - loss: 26.4621 - val_loss: 25.7488 - lr: 1.0000e-04 - 6s/epoch - 20ms/step
# Epoch 37/1024
# 280/280 - 5s - loss: 26.3919 - val_loss: 25.7456 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 38/1024
# 280/280 - 7s - loss: 26.3749 - val_loss: 25.7342 - lr: 1.0000e-04 - 7s/epoch - 25ms/step
# Epoch 39/1024
# 280/280 - 6s - loss: 26.3424 - val_loss: 25.6282 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 40/1024
# 280/280 - 5s - loss: 26.3112 - val_loss: 25.6837 - lr: 1.0000e-04 - 5s/epoch - 20ms/step
# Epoch 41/1024
# 280/280 - 5s - loss: 26.2906 - val_loss: 25.6250 - lr: 1.0000e-04 - 5s/epoch - 18ms/step
# Epoch 42/1024
# 280/280 - 6s - loss: 26.2649 - val_loss: 25.6126 - lr: 1.0000e-04 - 6s/epoch - 20ms/step
# Epoch 43/1024
# 280/280 - 5s - loss: 26.2417 - val_loss: 25.6994 - lr: 1.0000e-04 - 5s/epoch - 17ms/step
# Epoch 44/1024
# 280/280 - 6s - loss: 26.2298 - val_loss: 25.6699 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 45/1024
# 280/280 - 5s - loss: 26.2164 - val_loss: 25.6824 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 46/1024
# 280/280 - 6s - loss: 26.2206 - val_loss: 25.6736 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 47/1024
# 280/280 - 6s - loss: 26.1838 - val_loss: 25.6774 - lr: 1.0000e-04 - 6s/epoch - 23ms/step
# Epoch 48/1024
# 280/280 - 5s - loss: 26.1729 - val_loss: 25.6464 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 49/1024
# 280/280 - 5s - loss: 26.1676 - val_loss: 25.6878 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 50/1024
# 280/280 - 5s - loss: 26.1440 - val_loss: 25.5789 - lr: 1.0000e-04 - 5s/epoch - 18ms/step
# Epoch 51/1024
# 280/280 - 6s - loss: 26.1313 - val_loss: 25.6010 - lr: 1.0000e-04 - 6s/epoch - 20ms/step
# Epoch 52/1024
# 280/280 - 6s - loss: 26.1354 - val_loss: 25.6165 - lr: 1.0000e-04 - 6s/epoch - 20ms/step
# Epoch 53/1024
# 280/280 - 6s - loss: 26.1133 - val_loss: 25.6257 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 54/1024
# 280/280 - 5s - loss: 26.1057 - val_loss: 25.5648 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 55/1024
# 280/280 - 6s - loss: 26.0807 - val_loss: 25.5758 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 56/1024
# 280/280 - 6s - loss: 26.0994 - val_loss: 25.5778 - lr: 1.0000e-04 - 6s/epoch - 20ms/step
# Epoch 57/1024
# 280/280 - 6s - loss: 26.0750 - val_loss: 25.5983 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 58/1024
# 280/280 - 6s - loss: 26.0737 - val_loss: 25.5826 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 59/1024
# 280/280 - 5s - loss: 26.0531 - val_loss: 25.6242 - lr: 1.0000e-04 - 5s/epoch - 17ms/step
# Epoch 60/1024
# 280/280 - 5s - loss: 26.0447 - val_loss: 25.5423 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 61/1024
# 280/280 - 5s - loss: 26.0306 - val_loss: 25.5972 - lr: 1.0000e-04 - 5s/epoch - 19ms/step
# Epoch 62/1024
# 280/280 - 6s - loss: 26.0119 - val_loss: 25.5933 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 63/1024
# 280/280 - 6s - loss: 26.0110 - val_loss: 25.5354 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 64/1024
# 280/280 - 6s - loss: 26.0115 - val_loss: 25.6512 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 65/1024
# 280/280 - 5s - loss: 25.9989 - val_loss: 25.5871 - lr: 1.0000e-04 - 5s/epoch - 18ms/step
# Epoch 66/1024
# 280/280 - 6s - loss: 25.9790 - val_loss: 25.5754 - lr: 1.0000e-04 - 6s/epoch - 20ms/step
# Epoch 67/1024
# 280/280 - 6s - loss: 25.9674 - val_loss: 25.5095 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 68/1024
# 280/280 - 6s - loss: 25.9661 - val_loss: 25.5546 - lr: 1.0000e-04 - 6s/epoch - 22ms/step
# Epoch 69/1024
# 280/280 - 7s - loss: 25.9476 - val_loss: 25.5736 - lr: 1.0000e-04 - 7s/epoch - 23ms/step
# Epoch 70/1024
# 280/280 - 6s - loss: 25.9538 - val_loss: 25.5840 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 71/1024
# 280/280 - 6s - loss: 25.9429 - val_loss: 25.5835 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 72/1024
# 280/280 - 6s - loss: 25.9366 - val_loss: 25.6286 - lr: 1.0000e-04 - 6s/epoch - 20ms/step
# Epoch 73/1024
# 280/280 - 6s - loss: 25.9277 - val_loss: 25.6433 - lr: 1.0000e-04 - 6s/epoch - 21ms/step
# Epoch 74/1024
# 280/280 - 5s - loss: 25.9341 - val_loss: 25.5794 - lr: 1.0000e-04 - 5s/epoch - 17ms/step
# Epoch 75/1024
# 280/280 - 6s - loss: 25.9084 - val_loss: 25.6166 - lr: 1.0000e-04 - 6s/epoch - 21ms/step

# %%
# Make a directory
dir_name = HOME_PATH + "/7th_trial/ww_resregressor_result/"
name = "ww_resregressor"

# If the directory exists
if os.path.exists(dir_name):
    test_files = glob.glob(dir_name + "*" + name + "*")
    if test_files:
        for file in test_files:
            os.remove(file)
        print(f"Directory {dir_name} cleaned.")
    print(f"Directory {dir_name} exists.")
else:
    os.makedirs(dir_name)
    print(f"Directory {dir_name} created.")

# save modela
model.save(dir_name + name + ".keras", save_format="keras", overwrite=True)
# TODO
# ! ONNX save and load

# predict
pred_y = model.predict(test_x)
# save predicted results
np.savez_compressed(dir_name + name + "_data.npz", pred_y=pred_y, test_y=test_y)
sig_pred = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth = np.load(dir_name + name + "_data.npz")["test_y"]
# Out:
# Directory /root/work/QE-mls/7th_trial/ww_resregressor_result/ cleaned.
# Directory /root/work/QE-mls/7th_trial/ww_resregressor_result/ exists.
# 1119/1119 [==============================] - 10s 8ms/step

# %%
# Extract loss values
loss = history.history["loss"]
val_loss = history.history["val_loss"]

# Plot training and validation losses
plt.figure(figsize=(10, 8))
plt.plot(loss, label="Training Loss")
plt.plot(val_loss, label="Validation Loss")
plt.yscale("log")
plt.xlabel("Epochs")
plt.ylabel("Loss (MAE)")
plt.title("Learning Curve")
plt.legend()
plt.grid(False)
plt.show()

# %%
# save predicted results
np.savez_compressed(
    dir_name + name + "_data.npz",
    pred_y=sig_pred.reshape(sig_truth.shape),
    test_y=sig_truth,
)
sig_pred_inv = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth_inv = np.load(dir_name + name + "_data.npz")["test_y"]

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,0]):.3f}, std: {np.std(sig_truth_inv[:,0]):.3f}, min: {np.min(sig_truth_inv[:,0]):.3f}, max: {np.max(sig_truth_inv[:,0]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 0], sig_pred_inv[:, 0]],
    label=r"$p_{x}$",
    title="$W^{0}$ $p_{x}$",
    # # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,0], sig_pred_inv[:,0])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 0],
    sig_pred_inv[:, 0],
    r"$W^{0}$ $p_{x}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,0], sig_pred_inv[:,0])):.3f}",
    range=set_range,
    # bins = 50
)
# Out:
# Truth mean: -0.023, std: 38.265, min: -530.475, max: 360.579

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,4]):.3f}, std: {np.std(sig_truth_inv[:,4]):.3f}, min: {np.min(sig_truth_inv[:,4]):.3f}, max: {np.max(sig_truth_inv[:,4]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 4], sig_pred_inv[:, 4]],
    label=r"$p_{x}$",
    title="$W^{1}$ $p_{x}$",
    # # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,4], sig_pred_inv[:,4])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 4],
    sig_pred_inv[:, 4],
    r"$W^{1}$ $p_{x}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,4], sig_pred_inv[:,4])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.120, std: 26.034, min: -268.233, max: 314.854

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,1]):.3f}, std: {np.std(sig_truth_inv[:,1]):.3f}, min: {np.min(sig_truth_inv[:,1]):.3f}, max: {np.max(sig_truth_inv[:,1]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 1], sig_pred_inv[:, 1]],
    label=r"$p_{y}$",
    title="$W^{0}$ $p_{y}$",
    # # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,1], sig_pred_inv[:,1])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 1],
    sig_pred_inv[:, 1],
    r"$W^{0}$ $p_{y}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,1], sig_pred_inv[:,1])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.037, std: 37.939, min: -664.730, max: 497.169

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,5]):.3f}, std: {np.std(sig_truth_inv[:,5]):.3f}, min: {np.min(sig_truth_inv[:,5]):.3f}, max: {np.max(sig_truth_inv[:,5]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 5], sig_pred_inv[:, 5]],
    label=r"$p_{y}$",
    title="$W^{1}$ $p_{y}$",
    # # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,5], sig_pred_inv[:,5])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 5],
    sig_pred_inv[:, 5],
    r"$W^{1}$ $p_{y}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,5], sig_pred_inv[:,5])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.062, std: 26.255, min: -479.083, max: 402.986

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,2]):.3f}, std: {np.std(sig_truth_inv[:,2]):.3f}, min: {np.min(sig_truth_inv[:,2]):.3f}, max: {np.max(sig_truth_inv[:,2]):.3f}"
)

set_range = [-700, 700]

plot.hist(
    data=[sig_truth_inv[:, 2], sig_pred_inv[:, 2]],
    label=r"$p_{z}$",
    title="$W^{0}$ $p_{z}$",
    # # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,2], sig_pred_inv[:,2])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 2],
    sig_pred_inv[:, 2],
    r"$W^{0}$ $p_{z}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,2], sig_pred_inv[:,2])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.160, std: 174.511, min: -1473.301, max: 1762.406

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,6]):.3f}, std: {np.std(sig_truth_inv[:,6]):.3f}, min: {np.min(sig_truth_inv[:,6]):.3f}, max: {np.max(sig_truth_inv[:,6]):.3f}"
)

set_range = [-600, 600]

plot.hist(
    data=[sig_truth_inv[:, 6], sig_pred_inv[:, 6]],
    label=r"$p_{z}$",
    title="$W^{1}$ $p_{z}$",
    # # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,6], sig_pred_inv[:,6])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 6],
    sig_pred_inv[:, 6],
    r"$W^{1}$ $p_{z}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,6], sig_pred_inv[:,6])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.438, std: 110.528, min: -1291.521, max: 1292.541

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,3]):.3f}, std: {np.std(sig_truth_inv[:,3]):.3f}, min: {np.min(sig_truth_inv[:,3]):.3f}, max: {np.max(sig_truth_inv[:,3]):.3f}"
)

set_range = [0, 800]

plot.hist(
    data=[sig_truth_inv[:, 3], sig_pred_inv[:, 3]],
    label=r"$E$",
    title="$W^{0}$ $E$",
    # # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,3], sig_pred_inv[:,3])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 3],
    sig_pred_inv[:, 3],
    r"$W^{0}$ $E$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,3], sig_pred_inv[:,3])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: 159.947, std: 114.795, min: 30.075, max: 1764.353

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,7]):.3f}, std: {np.std(sig_truth_inv[:,7]):.3f}, min: {np.min(sig_truth_inv[:,7]):.3f}, max: {np.max(sig_truth_inv[:,7]):.3f}"
)

set_range = [0, 800]

plot.hist(
    data=[sig_truth_inv[:, 7], sig_pred_inv[:, 7]],
    label=r"$E$",
    title="$W^{1}$ $E$",
    # # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,7], sig_pred_inv[:,7])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 7],
    sig_pred_inv[:, 7],
    r"$W^{1}$ $E$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,7], sig_pred_inv[:,7])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: 95.973, std: 78.722, min: 13.802, max: 1296.332

# %%
lead_time_like = np.square(sig_pred_inv[:, 3]) - np.sum(
    np.square(sig_pred_inv[:, 0:3]), axis=1
)
lead_time_mask = (lead_time_like > 0) * 1
sublead_time_like = np.square(sig_pred_inv[:, 7]) - np.sum(
    np.square(sig_pred_inv[:, 4:7]), axis=1
)
sublead_time_mask = (sublead_time_like > 0) * 1

bin_edges = np.linspace(-5, 1.0e4, 81)
figure = plt.figure(figsize=(10, 8))
plt.hist(
    lead_time_like,
    bins=bin_edges,
    fill=False,
    color="orange",
    histtype="step",
    label=r"$W^{0}$ "
    + f"time-like with {100 * np.sum(lead_time_mask) / len(lead_time_mask):.2f} %",
    density=True,
)
plt.hist(
    sublead_time_like,
    bins=bin_edges,
    fill=False,
    color="tab:blue",
    histtype="step",
    label=r"$W^{1}$ "
    + f"time-like with {100 * np.sum(sublead_time_mask) / len(sublead_time_mask):.2f} %",
    density=True,
)
plt.hist(
    np.square(w_lead.m),
    bins=bin_edges,
    color="orange",
    fill=True,
    histtype="bar",
    alpha=0.2,
    label=r"$W_{label}^{0}$",
    density=True,
)
plt.hist(
    np.square(w_sublead.m),
    bins=bin_edges,
    color="tab:blue",
    fill=True,
    histtype="bar",
    alpha=0.2,
    label=r"$W_{label}^{1}$",
    density=True,
)
plt.vlines(0, 0, 2e-3, color="red", linestyle="--")
plt.xlim(-5e2, 1.2e4)
plt.ylim(0, 2e-3)
plt.xlabel(r"Mass$^{2}$ [GeV]$^{2}$", labelpad=20)
plt.ylabel("Normalized counts")
plt.title(
    r"$m^{2}_{W}$ "
    + f" with {100 * np.sum(lead_time_mask * sublead_time_mask) / len(lead_time_mask): .2f} % time-like evts"
)
plt.legend(loc="upper right")
plt.show()

# %%
# TODO: 2d mass squared
pred_m2 = np.concatenate([lead_time_like, sublead_time_like], axis=-1)
truth_m2 = np.concatenate(
    [np.square(w_lead.m)[test_indices], np.square(w_sublead.m)[test_indices]], axis=-1
)

print(
    f"Truth mean: {np.mean(truth_m2):.3f}, std: {np.std(truth_m2):.3f}, min: {np.min(truth_m2):.3f}, max: {np.max(truth_m2):.3f}"
)

set_range = [-500, 10_500]

plot.hist(
    data=[truth_m2, pred_m2],
    label=r"$m_{W}^{2}$",
    title="$m_{W}^{2}$",
    # # + f" with RMSE: {np.sqrt(mean_squared_error(truth_m2, pred_m2)):.3f}",
    range=set_range,
    unit=r"[GEV$^{2}$]",
    xpad=24,
)

plot.plot_2d_histogram(
    truth_m2,
    pred_m2,
    r"$m_{W}^{2}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(truth_m2, pred_m2)):.3f}",
    range=set_range,
    xpad=24,
)
# Out:
# Truth mean: 3613.617, std: 2615.675, min: 4.001, max: 10448.098

# %%
# validate by truth data

truth_lead_lep = Truth_lead_lep()
truth_sublead_lep = Truth_sublead_lep()
truth_met = Truth_met()

# %%
truth_obs_var = np.column_stack(
    (
        truth_lead_lep.px,
        truth_lead_lep.py,
        # truth_lead_lep.pz,
        np.log(truth_lead_lep.energy),
        # truth_lead_lep.pt,
        truth_lead_lep.eta,
        # truth_lead_lep.phi,
        truth_sublead_lep.px,
        truth_sublead_lep.py,
        # truth_sublead_lep.pz,
        np.log(truth_sublead_lep.energy),
        # truth_sublead_lep.pt,
        truth_sublead_lep.eta,
        # truth_sublead_lep.phi,
        truth_met.px,
        truth_met.py,
        # truth_met.pt,
        # truth_met.phi,
        # Truth_dilep.px,
        # Truth_dilep.py,
        # Truth_dilep.pz,
        # Truth_dilep.energy,
        # Truth_dilep.pt,
        # Truth_dilep.eta,
        # Truth_dilep.phi,
        # Truth_dilep.m,
    ),
)[PRE_CUT][test_indices]

# truth labels
w_lead_truth_p4 = pd.DataFrame(w_lead.p4[PRE_CUT][test_indices])
w_sublead_truth_p4 = pd.DataFrame(w_sublead.p4[PRE_CUT][test_indices])
print(w_lead_truth_p4.shape)
print(w_sublead_truth_p4.shape)
TRUTH_ROBUST_OBS = StandardScaler()
truth_obs_var = TRUTH_ROBUST_OBS.fit_transform(truth_obs_var)
print(truth_obs_var.shape)
# Out:
# (35802, 4)
# (35802, 4)
# (35802, 10)

# %%
truth_pred_int = model.predict(truth_obs_var)
# truth_pred_int = np.concatenate([truth_pred_int[0], truth_pred_int[1]], axis=-1)

truth_pred_w_lead_px = truth_pred_int[:, 0]
truth_pred_w_lead_py = truth_pred_int[:, 1]
truth_pred_w_lead_pz = truth_pred_int[:, 2]
truth_pred_w_lead_energy = truth_pred_int[:, 3]
truth_pred_w_lead_p4 = np.vstack(
    [
        truth_pred_w_lead_px,
        truth_pred_w_lead_py,
        truth_pred_w_lead_pz,
        truth_pred_w_lead_energy,
    ]
).T
truth_pred_w_sublead_px = truth_pred_int[:, 4]
truth_pred_w_sublead_py = truth_pred_int[:, 5]
truth_pred_w_sublead_pz = truth_pred_int[:, 6]
truth_pred_w_sublead_energy = truth_pred_int[:, 7]
truth_pred_w_sublead_p4 = np.vstack(
    [
        truth_pred_w_sublead_px,
        truth_pred_w_sublead_py,
        truth_pred_w_sublead_pz,
        truth_pred_w_sublead_energy,
    ]
).T
# Out:
#    1/1119 [..............................] - ETA: 10s
# 1119/1119 [==============================] - 7s 6ms/step

# %%
truth_lead_time_like = np.square(truth_pred_w_lead_p4[:, 3]) - np.sum(
    np.square(truth_pred_w_lead_p4[:, 0:-1]), axis=1
)
truth_lead_time_mask = (truth_lead_time_like >= 0) * 1
truth_sublead_time_like = np.square(truth_pred_w_sublead_p4[:, 3]) - np.sum(
    np.square(truth_pred_w_sublead_p4[:, 0:-1]), axis=1
)
truth_sublead_time_mask = (truth_sublead_time_like >= 0) * 1

bin_edges = np.linspace(-5, 1.0e4, 81)
figure = plt.figure(figsize=(10, 8))
plt.hist(
    truth_lead_time_like,
    bins=bin_edges,
    fill=False,
    color="orange",
    histtype="step",
    label=r"$W^{0}$ "
    + f"time-like with {100 * np.sum(truth_lead_time_mask) / len(truth_lead_time_mask):.2f} %",
    density=True,
)
plt.hist(
    truth_sublead_time_like,
    bins=bin_edges,
    fill=False,
    color="tab:blue",
    histtype="step",
    label=r"$W^{1}$ "
    + f"time-like with {100 * np.sum(truth_sublead_time_mask) / len(truth_sublead_time_mask):.2f} %",
    density=True,
)
plt.hist(
    np.square(w_lead.m),
    bins=bin_edges,
    color="orange",
    fill=True,
    histtype="bar",
    alpha=0.2,
    label=r"$W_{label}^{0}$",
    density=True,
)
plt.hist(
    np.square(w_sublead.m),
    bins=bin_edges,
    color="tab:blue",
    fill=True,
    histtype="bar",
    alpha=0.2,
    label=r"$W_{label}^{1}$",
    density=True,
)
plt.vlines(0, 0, 2e-3, color="red", linestyle="--")
plt.xlim(-5e2, 1.2e4)
plt.ylim(0, 2e-3)
plt.xlabel(r"Mass$^{2}$ [GeV]$^{2}$", labelpad=20)
plt.ylabel("Normalized counts")
plt.title(
    r"Truth $m^{2}_{W}$ "
    + f" with {100 * np.sum(truth_lead_time_mask * truth_sublead_time_mask) / len(truth_lead_time_mask): .2f} % time-like evts"
)
plt.legend(loc="upper right")
plt.show()

# %%
print(
    f"Truth mean: {np.mean(w_lead_truth_p4[0]):.3f}, std: {np.std(w_lead_truth_p4[0]):.3f}, min: {np.min(w_lead_truth_p4[0]):.3f}, max: {np.max(w_lead_truth_p4[0]):.3f}"
)

set_range = [-250, 250]

plot.hist(
    data=[w_lead_truth_p4[0], truth_pred_w_lead_p4[:, 0]],
    label=r"$p_{x}$",
    title="$W^{0}$ $p_{x}$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_lead_truth_p4[0],
    truth_pred_w_lead_p4[:, 0],
    r"$W^{0}$ $p_{x}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_lead_truth_p4[0], truth_pred_w_lead_p4[:, 0])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.023, std: 38.265, min: -530.475, max: 360.579

# %%
print(
    f"Truth mean: {np.mean(w_lead_truth_p4[1]):.3f}, std: {np.std(w_lead_truth_p4[1]):.3f}, min: {np.min(w_lead_truth_p4[1]):.3f}, max: {np.max(w_lead_truth_p4[1]):.3f}"
)

set_range = [-250, 250]

plot.hist(
    data=[w_lead_truth_p4[1], truth_pred_w_lead_p4[:, 1]],
    label=r"$p_{y}$",
    title="$W^{0}$ $p_{y}$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_lead_truth_p4[1],
    truth_pred_w_lead_p4[:, 1],
    r"$W^{0}$ $p_{y}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_lead_truth_p4[1], truth_pred_w_lead_p4[:, 1])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.037, std: 37.939, min: -664.730, max: 497.169

# %%
print(
    f"Truth mean: {np.mean(w_lead_truth_p4[2]):.3f}, std: {np.std(w_lead_truth_p4[2]):.3f}, min: {np.min(w_lead_truth_p4[2]):.3f}, max: {np.max(w_lead_truth_p4[2]):.3f}"
)

set_range = [-800, 800]

plot.hist(
    data=[w_lead_truth_p4[2], truth_pred_w_lead_p4[:, 2]],
    label=r"$p_{z}$",
    title="$W^{0}$ $p_{z}$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_lead_truth_p4[2],
    truth_pred_w_lead_p4[:, 2],
    r"$W^{0}$ $p_{z}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_lead_truth_p4[2], truth_pred_w_lead_p4[:, 2])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.160, std: 174.511, min: -1473.301, max: 1762.406

# %%
print(
    f"Truth mean: {np.mean(w_lead_truth_p4[3]):.3f}, std: {np.std(w_lead_truth_p4[3]):.3f}, min: {np.min(w_lead_truth_p4[3]):.3f}, max: {np.max(w_lead_truth_p4[3]):.3f}"
)

set_range = [0, 800]

plot.hist(
    data=[w_lead_truth_p4[3], truth_pred_w_lead_p4[:, 3]],
    label=r"$E$",
    title="$W^{0}$ $E$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_lead_truth_p4[3],
    truth_pred_w_lead_p4[:, 3],
    r"$W^{0}$ $E$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_lead_truth_p4[3], truth_pred_w_lead_p4[:, 3])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: 159.947, std: 114.795, min: 30.075, max: 1764.353

# %%
print(
    f"Truth mean: {np.mean(w_sublead_truth_p4[0]):.3f}, std: {np.std(w_sublead_truth_p4[0]):.3f}, min: {np.min(w_sublead_truth_p4[0]):.3f}, max: {np.max(w_sublead_truth_p4[0]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[w_sublead_truth_p4[0], truth_pred_w_sublead_p4[:, 0]],
    label=r"$p_{x}$",
    title="$W^{1}\ p_{x}$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_sublead_truth_p4[0],
    truth_pred_w_sublead_p4[:, 0],
    r"$W^{1}\ p_{x}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_sublead_truth_p4[0], truth_pred_w_sublead_p4[:, 0])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.120, std: 26.034, min: -268.233, max: 314.854

# %%
print(
    f"Truth mean: {np.mean(w_sublead_truth_p4[1]):.3f}, std: {np.std(w_sublead_truth_p4[1]):.3f}, min: {np.min(w_sublead_truth_p4[1]):.3f}, max: {np.max(w_sublead_truth_p4[1]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[w_sublead_truth_p4[1], truth_pred_w_sublead_p4[:, 1]],
    label=r"$p_{y}$",
    title="$W^{1}\ p_{y}$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_sublead_truth_p4[1],
    truth_pred_w_sublead_p4[:, 1],
    r"$W^{1}\ p_{y}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_sublead_truth_p4[1], truth_pred_w_sublead_p4[:, 1])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.062, std: 26.255, min: -479.083, max: 402.986

# %%
print(
    f"Truth mean: {np.mean(w_sublead_truth_p4[2]):.3f}, std: {np.std(w_sublead_truth_p4[2]):.3f}, min: {np.min(w_sublead_truth_p4[2]):.3f}, max: {np.max(w_sublead_truth_p4[2]):.3f}"
)

set_range = [-600, 600]

plot.hist(
    data=[w_sublead_truth_p4[2], truth_pred_w_sublead_p4[:, 2]],
    label=r"$p_{z}$",
    title="$W^{1}$ $p_{z}$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_sublead_truth_p4[2],
    truth_pred_w_sublead_p4[:, 2],
    r"$W^{1}$ $p_{z}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_sublead_truth_p4[2], truth_pred_w_sublead_p4[:, 2])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.438, std: 110.528, min: -1291.521, max: 1292.541

# %%
print(
    f"Truth mean: {np.mean(w_sublead_truth_p4[3]):.3f}, std: {np.std(w_sublead_truth_p4[3]):.3f}, min: {np.min(w_sublead_truth_p4[3]):.3f}, max: {np.max(w_sublead_truth_p4[3]):.3f}"
)

set_range = [0, 600]

plot.hist(
    data=[w_sublead_truth_p4[3], truth_pred_w_sublead_p4[:, 3]],
    label=r"$E$",
    title="$W^{1}$ $E$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_sublead_truth_p4[3],
    truth_pred_w_sublead_p4[:, 3],
    r"$W^{1}$ $E$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_sublead_truth_p4[3], truth_pred_w_sublead_p4[:, 3])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: 95.973, std: 78.722, min: 13.802, max: 1296.332

# %%
set_range = [0, 600]

plot.hist(
    data=[sig_pred_inv[:, 3], truth_pred_w_lead_p4[:, 3]],
    label=r"$E$",
    title="Response $W^{0}\ E$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_pred_inv[:, 3],
    truth_pred_w_lead_p4[:, 3],
    r"Response $W^{0}\ E$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_pred_inv[:, 3], truth_pred_w_lead_p4[:, 3])):.3f}",
    range=set_range,
    xlabel=r"Reco",
    ylabel=r"True",
)

# %%
set_range = [0, 600]

plot.hist(
    data=[sig_pred_inv[:, 7], truth_pred_w_sublead_p4[:, 3]],
    label=r"$E$",
    title="Response $W^{1}\ E$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_pred_inv[:, 7],
    truth_pred_w_sublead_p4[:, 3],
    r"Response $W^{1}\ E$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_pred_inv[:, 7], truth_pred_w_lead_p4[:, 3])):.3f}",
    range=set_range,
    xlabel=r"Reco",
    ylabel=r"True",
)

# %%
set_range = [-500, 500]

plot.hist(
    data=[sig_pred_inv[:, 6], truth_pred_w_sublead_p4[:, 2]],
    label=r"$E$",
    title="Response $W^{0}\ p_{z}$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_pred_inv[:, 6],
    truth_pred_w_sublead_p4[:, 2],
    r"Response $W^{0}\ p_{z}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_pred_inv[:, 6], truth_pred_w_lead_p4[:, 2])):.3f}",
    range=set_range,
    xlabel=r"Reco",
    ylabel=r"True",
)

# %%
# Test other tags

data_path = "/root/data/recotruth/r10201.h5"


def pt(px, py):
    return np.sqrt(np.square(px) + np.square(py))


def eta(px, py, pz):
    pt = np.sqrt(np.square(px) + np.square(py))
    return np.arcsinh(np.divide(pz, pt))


def phi(px, py):
    return np.arctan2(py, px)


def m(p4):
    return np.sqrt(
        np.square(p4[:, 3])
        - np.square(p4[:, 0])
        - np.square(p4[:, 1])
        - np.square(p4[:, 2])
    )


@dataclass
class Lead_lep:
    px = pd.read_hdf(data_path, "RecoLep0")["Px"] * GEV
    py = pd.read_hdf(data_path, "RecoLep0")["Py"] * GEV
    pz = pd.read_hdf(data_path, "RecoLep0")["Pz"] * GEV
    energy = pd.read_hdf(data_path, "RecoLep0")["E"] * GEV
    pt = pd.read_hdf(data_path, "RecoLep0")["Pt"] * GEV
    eta = pd.read_hdf(data_path, "RecoLep0")["Eta"]
    phi = pd.read_hdf(data_path, "RecoLep0")["Phi"]
    p4 = np.array([px, py, pz, energy]).T
    p3 = np.array([px, py, pz]).T


@dataclass
class Sublead_lep:
    px = pd.read_hdf(data_path, "RecoLep1")["Px"] * GEV
    py = pd.read_hdf(data_path, "RecoLep1")["Py"] * GEV
    pz = pd.read_hdf(data_path, "RecoLep1")["Pz"] * GEV
    energy = pd.read_hdf(data_path, "RecoLep1")["E"] * GEV
    pt = pd.read_hdf(data_path, "RecoLep1")["Pt"] * GEV
    eta = pd.read_hdf(data_path, "RecoLep1")["Eta"]
    phi = pd.read_hdf(data_path, "RecoLep1")["Phi"]
    p4 = np.array([px, py, pz, energy]).T
    p3 = np.array([px, py, pz]).T


@dataclass
class Dilep:
    lead = Lead_lep()
    sublead = Sublead_lep()
    p4 = Lead_lep.p4 + Sublead_lep.p4
    p3 = p4[:, :3]
    px = p4[:, 0]
    py = p4[:, 1]
    pz = p4[:, 2]
    energy = p4[:, 3]
    pt = pt(px, py)
    eta = eta(px, py, pz)
    phi = phi(px, py)
    m = m(p4)


@dataclass
class Met:
    px = pd.read_hdf(data_path, "RecoMET")["Px"] * GEV
    py = pd.read_hdf(data_path, "RecoMET")["Py"] * GEV
    phi = pd.read_hdf(data_path, "RecoMET")["Phi"]
    pt = pt(px, py)


@dataclass
class Truth_lead_lep:
    px = pd.read_hdf(data_path, "TruthLep0")["Px"] * GEV
    py = pd.read_hdf(data_path, "TruthLep0")["Py"] * GEV
    pz = pd.read_hdf(data_path, "TruthLep0")["Pz"] * GEV
    energy = pd.read_hdf(data_path, "TruthLep0")["E"] * GEV
    pt = pd.read_hdf(data_path, "TruthLep0")["Pt"] * GEV
    eta = pd.read_hdf(data_path, "TruthLep0")["Eta"]
    phi = pd.read_hdf(data_path, "TruthLep0")["Phi"]
    p4 = np.array([px, py, pz, energy]).T
    p3 = np.array([px, py, pz]).T


@dataclass
class Truth_sublead_lep:
    px = pd.read_hdf(data_path, "TruthLep1")["Px"] * GEV
    py = pd.read_hdf(data_path, "TruthLep1")["Py"] * GEV
    pz = pd.read_hdf(data_path, "TruthLep1")["Pz"] * GEV
    energy = pd.read_hdf(data_path, "TruthLep1")["E"] * GEV
    pt = pd.read_hdf(data_path, "TruthLep1")["Pt"] * GEV
    eta = pd.read_hdf(data_path, "TruthLep1")["Eta"]
    phi = pd.read_hdf(data_path, "TruthLep1")["Phi"]
    p4 = np.array([px, py, pz, energy]).T
    p3 = np.array([px, py, pz]).T


@dataclass
class Truth_dilep:
    lead = Truth_lead_lep()
    sublead = Truth_sublead_lep()
    p4 = Lead_lep.p4 + Sublead_lep.p4
    p3 = p4[:, :3]
    px = p4[:, 0]
    py = p4[:, 1]
    pz = p4[:, 2]
    energy = p4[:, 3]
    pt = pt(px, py)
    eta = eta(px, py, pz)
    phi = phi(px, py)
    m = m(p4)


@dataclass
class Truth_met:
    px = pd.read_hdf(data_path, "TruthMET")["Px"] * GEV
    py = pd.read_hdf(data_path, "TruthMET")["Py"] * GEV
    phi = pd.read_hdf(data_path, "TruthMET")["Phi"]
    pt = pt(px, py)


@dataclass
class Lead_w:
    px = pd.read_hdf(data_path, "TruthW0")["Px"] * GEV
    py = pd.read_hdf(data_path, "TruthW0")["Py"] * GEV
    pz = pd.read_hdf(data_path, "TruthW0")["Pz"] * GEV
    energy = pd.read_hdf(data_path, "TruthW0")["E"] * GEV
    pt = pd.read_hdf(data_path, "TruthW0")["Pt"] * GEV
    eta = pd.read_hdf(data_path, "TruthW0")["Eta"]
    phi = pd.read_hdf(data_path, "TruthW0")["Phi"]
    m = pd.read_hdf(data_path, "TruthW0")["M"] * GEV
    p4 = np.array([px, py, pz, energy]).T
    p3 = np.array([px, py, pz]).T


@dataclass
class Sublead_w:
    px = pd.read_hdf(data_path, "TruthW1")["Px"] * GEV
    py = pd.read_hdf(data_path, "TruthW1")["Py"] * GEV
    pz = pd.read_hdf(data_path, "TruthW1")["Pz"] * GEV
    energy = pd.read_hdf(data_path, "TruthW1")["E"] * GEV
    pt = pd.read_hdf(data_path, "TruthW1")["Pt"] * GEV
    eta = pd.read_hdf(data_path, "TruthW1")["Eta"]
    phi = pd.read_hdf(data_path, "TruthW1")["Phi"]
    m = pd.read_hdf(data_path, "TruthW1")["M"] * GEV
    p4 = np.array([px, py, pz, energy]).T
    p3 = np.array([px, py, pz]).T

# %%
## Observing variables

obs_kin = np.column_stack(
    (
        lead_lep.px,
        lead_lep.py,
        # lead_lep.pz,
        # lead_lep.energy,
        np.log(lead_lep.energy),
        # np.log(lead_lep.pt),
        lead_lep.eta,
        # lead_lep.phi,
        sublead_lep.px,
        sublead_lep.py,
        # sublead_lep.pz,
        # sublead_lep.energy,
        np.log(sublead_lep.energy),
        # np.log(sublead_lep.pt),
        sublead_lep.eta,
        # sublead_lep.phi,
        met.px,
        met.py,
        # met.pt,
        # met.phi,
        # dilep.px,
        # dilep.py,
        # dilep.pz,
        # np.log(dilep.energy),
        # dilep.pt,
        # dilep.eta,
        # dilep.phi,
        # dilep.m,
    )
)[PRE_CUT]

# Kinematics of observing variables (inputs for training)
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array

ROBUST_OBS = StandardScaler()
obs_kin = ROBUST_OBS.fit_transform(obs_kin)
print(type(obs_kin))
# Out:
# int_kin shape: (358015, 10)
# <class 'numpy.ndarray'>

# %%
# reco
lead_lep = Lead_lep()
sublead_lep = Sublead_lep()
dilep = Dilep()
met = Met()

# truth
truth_lead_lep = Truth_lead_lep()
truth_sublead_lep = Truth_sublead_lep()
Truth_dilep = Truth_dilep()
truth_met = Truth_met()

# target Ws
w_lead = Lead_w()
w_sublead = Sublead_w()

# %%
## Interesting variables

w_lead_px = pd.DataFrame(w_lead.px)
w_lead_py = pd.DataFrame(w_lead.py)
w_lead_pz = pd.DataFrame(w_lead.pz)
w_lead_e = pd.DataFrame(w_lead.energy)
w_lead_log_e = pd.DataFrame(np.log(w_lead_e))
w_lead_sqrt_e = pd.DataFrame(np.sqrt(w_lead_e))
w_sublead_px = pd.DataFrame(w_sublead.px)
w_sublead_py = pd.DataFrame(w_sublead.py)
w_sublead_pz = pd.DataFrame(w_sublead.pz)
w_sublead_e = pd.DataFrame(w_sublead.energy)
w_sublead_log_e = pd.DataFrame(np.log(w_sublead_e))
w_sublead_sqrt_e = pd.DataFrame(np.sqrt(w_sublead_e))
w_lead_m = pd.DataFrame(w_lead.m)
w_sublead_m = pd.DataFrame(w_sublead.m)

# Kinematics of interesting variables (target for training)
int_kin = np.concatenate(
    [
        w_lead_px,
        w_lead_py,
        w_lead_pz,
        w_lead_e,
        w_sublead_px,
        w_sublead_py,
        w_sublead_pz,
        w_sublead_e,
        # np.square(w_lead_m) / np.mean(w_lead_m),
        # np.square(w_sublead_m) / np.mean(w_lead_m),
        # w_lead_m,
        # w_sublead_m,
    ],
    axis=-1,
)
print("int_kin shape:", int_kin.shape)
# int_kin = int_kin.to_numpy()  # convert to numpy array
print(type(int_kin))
# Out:
# int_kin shape: (366035, 8)
# <class 'numpy.ndarray'>

# %%
## Observing variables

obs_kin = np.column_stack(
    (
        lead_lep.px,
        lead_lep.py,
        # lead_lep.pz,
        # lead_lep.energy,
        np.log(lead_lep.energy),
        # np.log(lead_lep.pt),
        lead_lep.eta,
        # lead_lep.phi,
        sublead_lep.px,
        sublead_lep.py,
        # sublead_lep.pz,
        # sublead_lep.energy,
        np.log(sublead_lep.energy),
        # np.log(sublead_lep.pt),
        sublead_lep.eta,
        # sublead_lep.phi,
        met.px,
        met.py,
        # met.pt,
        # met.phi,
        # dilep.px,
        # dilep.py,
        # dilep.pz,
        # np.log(dilep.energy),
        # dilep.pt,
        # dilep.eta,
        # dilep.phi,
        # dilep.m,
    )
)

# Kinematics of observing variables (inputs for training)
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array

ROBUST_OBS = StandardScaler()
obs_kin = ROBUST_OBS.fit_transform(obs_kin)
print(type(obs_kin))
# Out:
# int_kin shape: (366035, 10)
# <class 'numpy.ndarray'>

# %%
bin_edge = np.linspace(-3, 3, 81)
sublead_px = plt.hist(
    obs_kin[:, 0], bins=bin_edge, alpha=0.8, label="px", histtype="step", density=True
)
lead_py = plt.hist(
    obs_kin[:, 1], bins=bin_edge, alpha=0.8, label="py", histtype="step", density=True
)
lead_log_e = plt.hist(
    obs_kin[:, 2],
    bins=bin_edge,
    alpha=0.8,
    label="log_energy",
    histtype="step",
    density=True,
)
# lead_px = plt.hist(w_lead_px, bins=bin_edge, alpha=.8)
lead_pz = plt.hist(
    obs_kin[:, 3], bins=bin_edge, alpha=0.8, label="eta", histtype="step", density=True
)
# lead_px = plt.hist(w_lead_m, bins=bin_edge, alpha=.8)
# plt.yscale("log")
plt.title("Lead lep")
plt.legend()
plt.show()

sublead_px = plt.hist(
    obs_kin[:, 4], bins=bin_edge, alpha=0.8, label="px", histtype="step", density=True
)
sublead_py = plt.hist(
    obs_kin[:, 5], bins=bin_edge, alpha=0.8, label="py", histtype="step", density=True
)
sublead_log_e = plt.hist(
    obs_kin[:, 6],
    bins=bin_edge,
    alpha=0.8,
    label="log_energy",
    histtype="step",
    density=True,
)
sublead_pz = plt.hist(
    obs_kin[:, 7], bins=bin_edge, alpha=0.8, label="eta", histtype="step", density=True
)
# sublead_px = plt.hist(w_sublead_px, bins=bin_edge, alpha=.8)
# sublead_px = plt.hist(w_sublead_m, bins=bin_edge, alpha=.8)
# plt.yscale("log")
plt.title("Sublead lep")
plt.legend()
plt.show()


lead_energy = plt.hist(lead_lep.energy, bins=80, alpha=0.8, label="eta", histtype="step", density=True)
plt.title("Lead lep energy")
plt.show()
lead_log_energy = plt.hist(np.log(lead_lep.energy), bins=80, alpha=0.8, label="eta", histtype="step", density=True)
plt.title("Lead lep log(energy)")
plt.show()

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, test_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.8,
    test_size=0.2,
    random_state=SEED,
    shuffle=True,
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
# test_x = np.concatenate([test_x, valid_x], axis=0)
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
# test_y = np.concatenate([test_y, valid_y], axis=0)

w_lead_truth_p4 = pd.DataFrame(w_lead.p4[test_indices])
w_sublead_truth_p4 = pd.DataFrame(w_sublead.p4[test_indices])

print("Total evts:", len(indices_arr))
print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# Total evts: 366035
# X (Interest)
# Training data shape: (292828, 10);
# Testing data shape: (73207, 10).
# Y (Observed)
# Training data shape: (292828, 8);
# Testing data shape: (73207, 8).

# %%
r10201_pred_int = model.predict(test_x)
# r10201_pred_int = np.concatenate([r10201_pred_int[0], r10201_pred_int[1]], axis=-1)

r10201_pred_w_lead_px = r10201_pred_int[:, 0]
r10201_pred_w_lead_py = r10201_pred_int[:, 1]
r10201_pred_w_lead_pz = r10201_pred_int[:, 2]
r10201_pred_w_lead_energy = r10201_pred_int[:, 3]
r10201_pred_w_lead_p4 = np.vstack(
    [
        r10201_pred_w_lead_px,
        r10201_pred_w_lead_py,
        r10201_pred_w_lead_pz,
        r10201_pred_w_lead_energy,
    ]
).T
r10201_pred_w_sublead_px = r10201_pred_int[:, 4]
r10201_pred_w_sublead_py = r10201_pred_int[:, 5]
r10201_pred_w_sublead_pz = r10201_pred_int[:, 6]
r10201_pred_w_sublead_energy = r10201_pred_int[:, 7]
r10201_pred_w_sublead_p4 = np.vstack(
    [
        r10201_pred_w_sublead_px,
        r10201_pred_w_sublead_py,
        r10201_pred_w_sublead_pz,
        r10201_pred_w_sublead_energy,
    ]
).T
# Out:
# 2288/2288 [==============================] - 11s 5ms/step

# %%
r10201_lead_time_like = np.square(r10201_pred_w_lead_p4[:, 3]) - np.sum(
    np.square(r10201_pred_w_lead_p4[:, 0:-1]), axis=1
)
r10201_lead_time_mask = (r10201_lead_time_like >= 0) * 1
r10201_sublead_time_like = np.square(r10201_pred_w_sublead_p4[:, 3]) - np.sum(
    np.square(r10201_pred_w_sublead_p4[:, 0:-1]), axis=1
)
r10201_sublead_time_mask = (r10201_sublead_time_like >= 0) * 1

bin_edges = np.linspace(-5, 1.0e4, 81)
figure = plt.figure(figsize=(10, 8))
plt.hist(
    r10201_lead_time_like,
    bins=bin_edges,
    fill=False,
    color="orange",
    histtype="step",
    label=r"$W^{0}$ "
    + f"time-like with {100 * np.sum(r10201_lead_time_mask) / len(r10201_lead_time_mask):.2f} %",
    density=True,
)
plt.hist(
    r10201_sublead_time_like,
    bins=bin_edges,
    fill=False,
    color="tab:blue",
    histtype="step",
    label=r"$W^{1}$ "
    + f"time-like with {100 * np.sum(r10201_sublead_time_mask) / len(r10201_sublead_time_mask):.2f} %",
    density=True,
)
plt.hist(
    np.square(w_lead.m),
    bins=bin_edges,
    color="orange",
    fill=True,
    histtype="bar",
    alpha=0.2,
    label=r"$W_{label}^{0}$",
    density=True,
)
plt.hist(
    np.square(w_sublead.m),
    bins=bin_edges,
    color="tab:blue",
    fill=True,
    histtype="bar",
    alpha=0.2,
    label=r"$W_{label}^{1}$",
    density=True,
)
plt.vlines(0, 0, 2e-3, color="red", linestyle="--")
plt.xlim(-5e2, 1.2e4)
plt.ylim(0, 2e-3)
plt.xlabel(r"Mass$^{2}$ [GeV]$^{2}$", labelpad=20)
plt.ylabel("Normalized counts")
plt.title(
    r"Truth $m^{2}_{W}$ "
    + f" with {100 * np.sum(r10201_lead_time_mask * r10201_sublead_time_mask) / len(r10201_lead_time_mask): .2f} % time-like evts"
)
plt.legend(loc="upper right")
plt.show()

# %%
print(
    f"Truth mean: {np.mean(w_lead_truth_p4[0]):.3f}, std: {np.std(w_lead_truth_p4[0]):.3f}, min: {np.min(w_lead_truth_p4[0]):.3f}, max: {np.max(w_lead_truth_p4[0]):.3f}"
)

set_range = [-250, 250]

plot.hist(
    data=[w_lead_truth_p4[0], r10201_pred_w_lead_p4[:, 0]],
    label=r"$p_{x}$",
    title="$W^{0}$ $p_{x}$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_lead_truth_p4[0],
    r10201_pred_w_lead_p4[:, 0],
    r"$W^{0}$ $p_{x}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_lead_truth_p4[0], r10201_pred_w_lead_p4[:, 0])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.218, std: 38.214, min: -477.486, max: 446.960

# %%
print(
    f"Truth mean: {np.mean(w_lead_truth_p4[1]):.3f}, std: {np.std(w_lead_truth_p4[1]):.3f}, min: {np.min(w_lead_truth_p4[1]):.3f}, max: {np.max(w_lead_truth_p4[1]):.3f}"
)

set_range = [-250, 250]

plot.hist(
    data=[w_lead_truth_p4[1], r10201_pred_w_lead_p4[:, 1]],
    label=r"$p_{y}$",
    title="$W^{0}$ $p_{y}$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_lead_truth_p4[1],
    r10201_pred_w_lead_p4[:, 1],
    r"$W^{0}$ $p_{y}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_lead_truth_p4[1], r10201_pred_w_lead_p4[:, 1])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.081, std: 37.988, min: -505.662, max: 603.143

# %%
print(
    f"Truth mean: {np.mean(w_lead_truth_p4[2]):.3f}, std: {np.std(w_lead_truth_p4[2]):.3f}, min: {np.min(w_lead_truth_p4[2]):.3f}, max: {np.max(w_lead_truth_p4[2]):.3f}"
)

set_range = [-800, 800]

plot.hist(
    data=[w_lead_truth_p4[2], r10201_pred_w_lead_p4[:, 2]],
    label=r"$p_{z}$",
    title="$W^{0}$ $p_{z}$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_lead_truth_p4[2],
    r10201_pred_w_lead_p4[:, 2],
    r"$W^{0}$ $p_{z}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_lead_truth_p4[2], r10201_pred_w_lead_p4[:, 2])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.126, std: 174.341, min: -1505.982, max: 1466.966

# %%
print(
    f"Truth mean: {np.mean(w_lead_truth_p4[3]):.3f}, std: {np.std(w_lead_truth_p4[3]):.3f}, min: {np.min(w_lead_truth_p4[3]):.3f}, max: {np.max(w_lead_truth_p4[3]):.3f}"
)

set_range = [0, 800]

plot.hist(
    data=[w_lead_truth_p4[3], r10201_pred_w_lead_p4[:, 3]],
    label=r"$E$",
    title="$W^{0}$ $E$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_lead_truth_p4[3],
    r10201_pred_w_lead_p4[:, 3],
    r"$W^{0}$ $E$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_lead_truth_p4[3], r10201_pred_w_lead_p4[:, 3])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: 159.852, std: 114.659, min: 27.590, max: 1511.516

# %%
print(
    f"Truth mean: {np.mean(w_sublead_truth_p4[0]):.3f}, std: {np.std(w_sublead_truth_p4[0]):.3f}, min: {np.min(w_sublead_truth_p4[0]):.3f}, max: {np.max(w_sublead_truth_p4[0]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[w_sublead_truth_p4[0], r10201_pred_w_sublead_p4[:, 0]],
    label=r"$p_{x}$",
    title="$W^{1}\ p_{x}$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_sublead_truth_p4[0],
    r10201_pred_w_sublead_p4[:, 0],
    r"$W^{1}\ p_{x}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_sublead_truth_p4[0], r10201_pred_w_sublead_p4[:, 0])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.217, std: 26.094, min: -413.614, max: 244.919

# %%
print(
    f"Truth mean: {np.mean(w_sublead_truth_p4[1]):.3f}, std: {np.std(w_sublead_truth_p4[1]):.3f}, min: {np.min(w_sublead_truth_p4[1]):.3f}, max: {np.max(w_sublead_truth_p4[1]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[w_sublead_truth_p4[1], r10201_pred_w_sublead_p4[:, 1]],
    label=r"$p_{y}$",
    title="$W^{1}\ p_{y}$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_sublead_truth_p4[1],
    r10201_pred_w_sublead_p4[:, 1],
    r"$W^{1}\ p_{y}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_sublead_truth_p4[1], r10201_pred_w_sublead_p4[:, 1])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.002, std: 26.222, min: -421.058, max: 444.205

# %%
print(
    f"Truth mean: {np.mean(w_sublead_truth_p4[2]):.3f}, std: {np.std(w_sublead_truth_p4[2]):.3f}, min: {np.min(w_sublead_truth_p4[2]):.3f}, max: {np.max(w_sublead_truth_p4[2]):.3f}"
)

set_range = [-600, 600]

plot.hist(
    data=[w_sublead_truth_p4[2], r10201_pred_w_sublead_p4[:, 2]],
    label=r"$p_{z}$",
    title="$W^{1}$ $p_{z}$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_sublead_truth_p4[2],
    r10201_pred_w_sublead_p4[:, 2],
    r"$W^{1}$ $p_{z}$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_sublead_truth_p4[2], r10201_pred_w_sublead_p4[:, 2])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.274, std: 109.811, min: -1536.335, max: 1289.851

# %%
print(
    f"Truth mean: {np.mean(w_sublead_truth_p4[3]):.3f}, std: {np.std(w_sublead_truth_p4[3]):.3f}, min: {np.min(w_sublead_truth_p4[3]):.3f}, max: {np.max(w_sublead_truth_p4[3]):.3f}"
)

set_range = [0, 600]

plot.hist(
    data=[w_sublead_truth_p4[3], r10201_pred_w_sublead_p4[:, 3]],
    label=r"$E$",
    title="$W^{1}$ $E$",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    w_sublead_truth_p4[3],
    r10201_pred_w_sublead_p4[:, 3],
    r"$W^{1}$ $E$ ",
    # + f" with RMSE: {np.sqrt(mean_squared_error(w_sublead_truth_p4[3], r10201_pred_w_sublead_p4[:, 3])):.3f}",
    range=set_range,
)
# Out:
# Truth mean: 95.742, std: 78.003, min: 14.923, max: 1538.988
