# %%
# %reset -sf

from time import time
time_start = time()

import pandas as pd
import numpy as np
import scipy as sp
import gc
import os
from matplotlib import pyplot as plt

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import StandardScaler, MinMaxScaler, QuantileTransformer, RobustScaler
from sklearn.model_selection import train_test_split, KFold

import tensorflow as tf

# from pylorentz import Momentum4
# from mt2 import mt2

import get_data as gd
import atlas_plot as ap
plot = ap.Plotter()

print(tf.__version__)
print(tf.config.list_physical_devices())
print()
# Out:
# 2.13.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
seed = 42  # set random seed
sampling = int(3e5)
# num_folds = 2
batch_size = 1024
epochs = 512
learning_rate = 1e-4

# %%
np.random.seed(seed)
processor = gd.DataProcessor(sampling=sampling, processor=10)
path = "/root/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 10
#
# ['/root/data/truth/signal/CGLMP.npz', '/root/data/truth/signal/Higgs.npz', '/root/data/truth/signal/LeadLepton.npz', '/root/data/truth/signal/LeptonM.npz', '/root/data/truth/signal/LeptonP.npz', '/root/data/truth/signal/LmNu.npz', '/root/data/truth/signal/LpNu.npz', '/root/data/truth/signal/MET.npz', '/root/data/truth/signal/WmBoson.npz', '/root/data/truth/signal/WpBoson.npz', '/root/data/truth/signal/diLepton.npz', '/root/data/truth/signal/subLeadLepton.npz', '/root/data/truth/signal/xi_xyz.npz']

# %%
GEV = 1e3

cut_pre_pt_lead = data.LeadLep["pt"] > 22 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
cut_pre_pt_miss = data.MET["pt"] > 20 * GEV
cut_pre = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss

del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# %%
# inputs -> observed params
lep_p = processor.process_part(data.LepP)
lep_m = processor.process_part(data.LepM)
lep_kin = pd.concat([lep_p.iloc[:, :4], lep_m.iloc[:, :4]], axis=1)
MET = processor.process_MET(data.MET)
dilep_kin = processor.process_dipart(data.LepP, data.LepM)
# mt2 = np.sqrt(
#     mt2(
#         lep_m["m"],
#         lep_m["px"],
#         lep_m["py"],  # Visible 1: mass, px, py
#         lep_p["m"],
#         lep_p["px"],
#         lep_p["py"],  # Visible 2: mass, px, py
#         MET["MET_px"],
#         MET["MET_py"],  # Missing transverse momentum: x, y
#         0,
#         0,  # Invisible 1 mass, invisible 2 mass
#     )
# )
# vx = 5 * pd.DataFrame({"vx": mt2 + 0.3 * np.sqrt(dilep_kin["m"])})
# dilep_kin.iloc[:, 0:4]
mt = pd.DataFrame(
    {"mt": np.sqrt(np.sum(np.square(dilep_kin[["m", "px", "py"]]), axis=1))}
)
pta = pd.DataFrame(
    {
        "pta": np.sqrt(
            np.square(lep_p["pt"])
            + np.square(lep_m["pt"])
            + np.square(MET["MET_px"])
            + np.square(MET["MET_py"])
        )
    }
)
mask = (
    ~processor.process_dipart(data.NuP, data.NuM)[["m"]].isna().values.reshape(-1)
    * processor.process_dipart(data.NuP, data.NuM)[["m"]].values.reshape(-1) < 100
) & cut_pre

obs_kin = pd.concat([MET.iloc[:, 1:3], lep_kin, pta, mt], axis=1)[mask]
print("obs_kin shape:", obs_kin.shape)
print(obs_kin.head(3))
print()

# targets -> interested unknowns
int_kin = pd.DataFrame(processor.process_dipart(data.NuP, data.NuM)[["m"]])[mask]
print("int_kin shape:", int_kin.shape)
print(int_kin.head(3))
print()

# del (processor, lep_p, lep_m, MET, dilep_kin, mt, vx)
# gc.collect()
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# obs_kin shape: (1371156, 12)
#        MET_px     MET_py           E         px         py          pz  \
# 7   96.335650  47.095450   19.500895  -4.561588  18.924410   -1.154271
# 9  -26.992604 -70.883859  164.814766  34.397141   2.031300 -161.172625
# 10  44.222846 -15.383637   47.669113 -26.605045 -17.256748   35.590859
#
#             E         px         py         pz         pta         mt
# 7   43.361348  42.407754  -4.632000   7.767462  117.035693  62.513416
# 9   70.592648  29.001777   1.896990 -64.332027   88.233289  67.559621
# 10  90.238664 -23.868604  32.986602  80.530680   69.683329  74.393166
#
# int_kin shape: (1371156, 1)
#             m
# 7   29.986310
# 9    8.460819
# 10  17.619046
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.hist(int_kin, bins=100, alpha=.8)
print(int_kin.describe())
plt.title(r"$m_{\nu\nu}$")
plt.xlabel("mass [MeV]")
plt.ylabel("count")
plt.xlim([0,100])
plt.show()
# Out:
#                   m
# count  1.371156e+06
# mean   2.942960e+01
# std    1.558633e+01
# min    1.209723e-02
# 25%    1.755326e+01
# 50%    2.837546e+01
# 75%    3.998729e+01
# max    9.999846e+01

# %%
plt.hist(processor.process_dipart(data.NuP, data.NuM)[["m"]], bins=800, alpha=.8)
print(processor.process_dipart(data.NuP, data.NuM)[["m"]].describe())
plt.title(r"$m_{\nu\nu}$")
plt.xlabel("mass [MeV]")
plt.ylabel("count")
plt.xlim([0,500])
plt.show()

plt.hist(processor.process_dipart(data.NuP, data.NuM)[["E"]], bins=800, alpha=.8)
print(processor.process_dipart(data.NuP, data.NuM)[["E"]].describe())
plt.title(r"$E_{\nu\nu}$")
plt.xlabel("Energy [MeV]")
plt.ylabel("count")
plt.xlim([0,1000])
plt.show()
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                   m
# count  2.928859e+06
# mean   3.358438e+01
# std    2.172876e+01
# min    1.265130e-03
# 25%    1.957780e+01
# 50%    3.181856e+01
# 75%    4.494666e+01
# max    2.019120e+03
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                   E
# count  2.928862e+06
# mean   1.737254e+02
# std    2.127326e+02
# min    1.582629e-01
# 25%    6.514866e+01
# 50%    1.002625e+02
# 75%    1.924503e+02
# max    4.389521e+03

# %%
SCALAR_int_ru = RobustScaler()
int_kin = SCALAR_int_ru.fit_transform(int_kin)
# SCALAR_int_mm = MinMaxScaler()
# int_kin = SCALAR_int_mm.fit_transform(int_kin)

SCALAR_obs_ru = RobustScaler()
obs_kin = SCALAR_obs_ru.fit_transform(obs_kin)
# SCALAR_obs_mm = MinMaxScaler()
# obs_kin = SCALAR_obs_mm.fit_transform(obs_kin)

# %%
plt.hist(int_kin, bins=100, alpha=.8)
plt.title(r"$m_{\nu\nu}$")
plt.xlabel("Norm. Energy [unit]")
plt.ylabel("count")
# plt.xlim([0,0.5])
plt.show()

# %%
indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.4,
    test_size=0.6,
    random_state=seed,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=42
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
print()
# Out:
# X (Interest)
# Training data shape: (548462, 12);
# Validing data shape: (411347, 12);
# Testing data shape: (411347, 12).
# Y (Observed)
# Training data shape: (548462, 1);
# Validing data shape: (411347, 1);
# Testing data shape: (411347, 1).

# %%
# # Define the generator function of the dataset.
# def data_gen(X_data, y_data, indices):
#     while True:
#         for start in range(0, len(indices), batch_size):
#             end = min(start + batch_size, len(indices))
#             # print(f"start: {start}, end: {end}, indices: {indices[start:end]}")
#             # print(f"X_data shape: {X_data.shape}, y_data shape: {y_data.shape}")
#             yield X_data[indices[start:end]], y_data[indices[start:end]]

# %%
# Define a new activation function
def custom_activation(x):
    return x*tf.keras.backend.sigmoid(x)

# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    x = tf.keras.layers.Dense(units=1024, activation="elu")(x)
    x = tf.keras.layers.Dense(units=1024, activation="elu")(x)
    # x = tf.keras.layers.Dropout(rate=0.2)(x)
    x = tf.keras.layers.Dense(units=32, activation="elu")(x)
    x = tf.keras.layers.Dense(units=32, activation="elu")(x)
    # x = tf.keras.layers.Dense(units=4, activation="elu")(x)
    # x = tf.keras.layers.Dropout(rate=0.2)(x)
    x = tf.keras.layers.Dense(units=1024, activation="elu")(x)
    x = tf.keras.layers.Dense(units=1024, activation="elu")(x)
    # x = tf.keras.layers.Dropout(rate=0.1)(x)
    # x = tf.keras.layers.Dense(units=2, activation="elu")(x)
    # x = tf.keras.layers.Dense(units=2, activation="elu")(x)
    
    # Last dense layer
    outputs = tf.keras.layers.Dense(units=train_y.shape[-1], activation="linear")(x)

    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss="mse",
    )

    # Summarize the model
    model.summary()

    return model

# %%
model = build_model()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 12)]              0
#
#  flatten_1 (Flatten)         (None, 12)                0
#
#  dense_7 (Dense)             (None, 1024)              13312
#
#  dense_8 (Dense)             (None, 1024)              1049600
#
#  dense_9 (Dense)             (None, 32)                32800
#
#  dense_10 (Dense)            (None, 32)                1056
#
#  dense_11 (Dense)            (None, 1024)              33792
#
#  dense_12 (Dense)            (None, 1024)              1049600
#
#  dense_13 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 2181185 (8.32 MB)
# Trainable params: 2181185 (8.32 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-6,
    patience=10,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)

# Fit the model
history = model.fit(
    x=train_x,
    y=train_y,
    validation_data=(valid_x, valid_y),
    epochs=epochs,
    batch_size=batch_size,
    verbose=2,
    callbacks=[stop_early],
)
# Out:
# Epoch 1/512
# 536/536 - 5s - loss: 0.4142 - val_loss: 0.4006 - 5s/epoch - 9ms/step
# Epoch 2/512
# 536/536 - 3s - loss: 0.3967 - val_loss: 0.3915 - 3s/epoch - 5ms/step
# Epoch 3/512
# 536/536 - 3s - loss: 0.3911 - val_loss: 0.3890 - 3s/epoch - 5ms/step
# Epoch 4/512
# 536/536 - 3s - loss: 0.3884 - val_loss: 0.3873 - 3s/epoch - 5ms/step
# Epoch 5/512
# 536/536 - 3s - loss: 0.3864 - val_loss: 0.3864 - 3s/epoch - 5ms/step
# Epoch 6/512
# 536/536 - 3s - loss: 0.3849 - val_loss: 0.3858 - 3s/epoch - 5ms/step
# Epoch 7/512
# 536/536 - 3s - loss: 0.3842 - val_loss: 0.3856 - 3s/epoch - 5ms/step
# Epoch 8/512
# 536/536 - 3s - loss: 0.3838 - val_loss: 0.3855 - 3s/epoch - 5ms/step
# Epoch 9/512
# 536/536 - 3s - loss: 0.3824 - val_loss: 0.3842 - 3s/epoch - 5ms/step
# Epoch 10/512
# 536/536 - 3s - loss: 0.3819 - val_loss: 0.3859 - 3s/epoch - 5ms/step
# Epoch 11/512
# 536/536 - 3s - loss: 0.3819 - val_loss: 0.3848 - 3s/epoch - 5ms/step
# Epoch 12/512
# 536/536 - 3s - loss: 0.3814 - val_loss: 0.3852 - 3s/epoch - 5ms/step
# Epoch 13/512
# 536/536 - 3s - loss: 0.3810 - val_loss: 0.3815 - 3s/epoch - 5ms/step
# Epoch 14/512
# 536/536 - 3s - loss: 0.3808 - val_loss: 0.3825 - 3s/epoch - 5ms/step
# Epoch 15/512
# 536/536 - 3s - loss: 0.3801 - val_loss: 0.3840 - 3s/epoch - 5ms/step
# Epoch 16/512
# 536/536 - 3s - loss: 0.3799 - val_loss: 0.3816 - 3s/epoch - 5ms/step
# Epoch 17/512
# 536/536 - 3s - loss: 0.3796 - val_loss: 0.3830 - 3s/epoch - 5ms/step
# Epoch 18/512
# 536/536 - 3s - loss: 0.3797 - val_loss: 0.3818 - 3s/epoch - 5ms/step
# Epoch 19/512
# 536/536 - 3s - loss: 0.3793 - val_loss: 0.3819 - 3s/epoch - 5ms/step
# Epoch 20/512
# 536/536 - 3s - loss: 0.3792 - val_loss: 0.3815 - 3s/epoch - 5ms/step
# Epoch 21/512
# 536/536 - 3s - loss: 0.3790 - val_loss: 0.3817 - 3s/epoch - 5ms/step
# Epoch 22/512
# 536/536 - 3s - loss: 0.3785 - val_loss: 0.3815 - 3s/epoch - 5ms/step
# Epoch 23/512
# 536/536 - 3s - loss: 0.3787 - val_loss: 0.3819 - 3s/epoch - 5ms/step
# Epoch 24/512
# 536/536 - 3s - loss: 0.3784 - val_loss: 0.3828 - 3s/epoch - 5ms/step
# Epoch 25/512
# 536/536 - 3s - loss: 0.3781 - val_loss: 0.3822 - 3s/epoch - 5ms/step
# Epoch 26/512
# 536/536 - 3s - loss: 0.3779 - val_loss: 0.3799 - 3s/epoch - 5ms/step
# Epoch 27/512
# 536/536 - 3s - loss: 0.3778 - val_loss: 0.3804 - 3s/epoch - 5ms/step
# Epoch 28/512
# 536/536 - 3s - loss: 0.3776 - val_loss: 0.3807 - 3s/epoch - 5ms/step
# Epoch 29/512
# 536/536 - 3s - loss: 0.3774 - val_loss: 0.3808 - 3s/epoch - 5ms/step
# Epoch 30/512
# 536/536 - 3s - loss: 0.3772 - val_loss: 0.3803 - 3s/epoch - 5ms/step
# Epoch 31/512
# 536/536 - 3s - loss: 0.3772 - val_loss: 0.3801 - 3s/epoch - 5ms/step
# Epoch 32/512
# 536/536 - 3s - loss: 0.3769 - val_loss: 0.3799 - 3s/epoch - 5ms/step
# Epoch 33/512
# 536/536 - 3s - loss: 0.3769 - val_loss: 0.3796 - 3s/epoch - 5ms/step
# Epoch 34/512
# 536/536 - 3s - loss: 0.3766 - val_loss: 0.3798 - 3s/epoch - 5ms/step
# Epoch 35/512
# 536/536 - 3s - loss: 0.3766 - val_loss: 0.3791 - 3s/epoch - 5ms/step
# Epoch 36/512
# 536/536 - 3s - loss: 0.3763 - val_loss: 0.3803 - 3s/epoch - 5ms/step
# Epoch 37/512
# 536/536 - 3s - loss: 0.3764 - val_loss: 0.3802 - 3s/epoch - 5ms/step
# Epoch 38/512
# 536/536 - 3s - loss: 0.3760 - val_loss: 0.3790 - 3s/epoch - 5ms/step
# Epoch 39/512
# 536/536 - 3s - loss: 0.3760 - val_loss: 0.3803 - 3s/epoch - 5ms/step
# Epoch 40/512
# 536/536 - 3s - loss: 0.3759 - val_loss: 0.3789 - 3s/epoch - 5ms/step
# Epoch 41/512
# 536/536 - 3s - loss: 0.3756 - val_loss: 0.3785 - 3s/epoch - 5ms/step
# Epoch 42/512
# 536/536 - 3s - loss: 0.3755 - val_loss: 0.3789 - 3s/epoch - 5ms/step
# Epoch 43/512
# 536/536 - 3s - loss: 0.3753 - val_loss: 0.3801 - 3s/epoch - 5ms/step
# Epoch 44/512
# 536/536 - 3s - loss: 0.3752 - val_loss: 0.3800 - 3s/epoch - 5ms/step
# Epoch 45/512
# 536/536 - 3s - loss: 0.3751 - val_loss: 0.3785 - 3s/epoch - 5ms/step
# Epoch 46/512
# 536/536 - 3s - loss: 0.3749 - val_loss: 0.3794 - 3s/epoch - 5ms/step
# Epoch 47/512
# 536/536 - 3s - loss: 0.3749 - val_loss: 0.3796 - 3s/epoch - 5ms/step
# Epoch 48/512
# 536/536 - 3s - loss: 0.3749 - val_loss: 0.3784 - 3s/epoch - 5ms/step
# Epoch 49/512
# 536/536 - 3s - loss: 0.3744 - val_loss: 0.3786 - 3s/epoch - 5ms/step
# Epoch 50/512
# 536/536 - 3s - loss: 0.3744 - val_loss: 0.3778 - 3s/epoch - 5ms/step
# Epoch 51/512
# 536/536 - 3s - loss: 0.3745 - val_loss: 0.3782 - 3s/epoch - 5ms/step
# Epoch 52/512
# 536/536 - 3s - loss: 0.3742 - val_loss: 0.3784 - 3s/epoch - 5ms/step
# Epoch 53/512
# 536/536 - 3s - loss: 0.3741 - val_loss: 0.3786 - 3s/epoch - 5ms/step
# Epoch 54/512
# 536/536 - 3s - loss: 0.3739 - val_loss: 0.3784 - 3s/epoch - 5ms/step
# Epoch 55/512
# 536/536 - 3s - loss: 0.3739 - val_loss: 0.3781 - 3s/epoch - 5ms/step
# Epoch 56/512
# 536/536 - 3s - loss: 0.3737 - val_loss: 0.3778 - 3s/epoch - 5ms/step
# Epoch 57/512
# 536/536 - 3s - loss: 0.3735 - val_loss: 0.3773 - 3s/epoch - 5ms/step
# Epoch 58/512
# 536/536 - 3s - loss: 0.3734 - val_loss: 0.3767 - 3s/epoch - 5ms/step
# Epoch 59/512
# 536/536 - 3s - loss: 0.3731 - val_loss: 0.3775 - 3s/epoch - 5ms/step
# Epoch 60/512
# 536/536 - 3s - loss: 0.3729 - val_loss: 0.3789 - 3s/epoch - 5ms/step
# Epoch 61/512
# 536/536 - 3s - loss: 0.3730 - val_loss: 0.3776 - 3s/epoch - 5ms/step
# Epoch 62/512
# 536/536 - 3s - loss: 0.3729 - val_loss: 0.3773 - 3s/epoch - 5ms/step
# Epoch 63/512
# 536/536 - 3s - loss: 0.3726 - val_loss: 0.3772 - 3s/epoch - 5ms/step
# Epoch 64/512
# 536/536 - 3s - loss: 0.3725 - val_loss: 0.3771 - 3s/epoch - 5ms/step
# Epoch 65/512
# 536/536 - 3s - loss: 0.3722 - val_loss: 0.3769 - 3s/epoch - 5ms/step
# Epoch 66/512
# 536/536 - 3s - loss: 0.3722 - val_loss: 0.3763 - 3s/epoch - 5ms/step
# Epoch 67/512
# 536/536 - 3s - loss: 0.3720 - val_loss: 0.3759 - 3s/epoch - 5ms/step
# Epoch 68/512
# 536/536 - 3s - loss: 0.3720 - val_loss: 0.3769 - 3s/epoch - 5ms/step
# Epoch 69/512
# 536/536 - 3s - loss: 0.3716 - val_loss: 0.3764 - 3s/epoch - 5ms/step
# Epoch 70/512
# 536/536 - 3s - loss: 0.3717 - val_loss: 0.3776 - 3s/epoch - 5ms/step
# Epoch 71/512
# 536/536 - 3s - loss: 0.3714 - val_loss: 0.3758 - 3s/epoch - 5ms/step
# Epoch 72/512
# 536/536 - 3s - loss: 0.3712 - val_loss: 0.3760 - 3s/epoch - 5ms/step
# Epoch 73/512
# 536/536 - 3s - loss: 0.3713 - val_loss: 0.3762 - 3s/epoch - 5ms/step
# Epoch 74/512
# 536/536 - 3s - loss: 0.3710 - val_loss: 0.3759 - 3s/epoch - 5ms/step
# Epoch 75/512
# 536/536 - 3s - loss: 0.3709 - val_loss: 0.3755 - 3s/epoch - 5ms/step
# Epoch 76/512
# 536/536 - 3s - loss: 0.3709 - val_loss: 0.3753 - 3s/epoch - 5ms/step
# Epoch 77/512
# 536/536 - 3s - loss: 0.3707 - val_loss: 0.3754 - 3s/epoch - 5ms/step
# Epoch 78/512
# 536/536 - 3s - loss: 0.3708 - val_loss: 0.3756 - 3s/epoch - 5ms/step
# Epoch 79/512
# 536/536 - 3s - loss: 0.3706 - val_loss: 0.3753 - 3s/epoch - 5ms/step
# Epoch 80/512
# 536/536 - 3s - loss: 0.3704 - val_loss: 0.3756 - 3s/epoch - 5ms/step
# Epoch 81/512
# 536/536 - 3s - loss: 0.3704 - val_loss: 0.3753 - 3s/epoch - 5ms/step
# Epoch 82/512
# 536/536 - 3s - loss: 0.3703 - val_loss: 0.3754 - 3s/epoch - 5ms/step
# Epoch 83/512
# 536/536 - 3s - loss: 0.3702 - val_loss: 0.3751 - 3s/epoch - 5ms/step
# Epoch 84/512
# 536/536 - 3s - loss: 0.3700 - val_loss: 0.3749 - 3s/epoch - 5ms/step
# Epoch 85/512
# 536/536 - 3s - loss: 0.3699 - val_loss: 0.3753 - 3s/epoch - 5ms/step
# Epoch 86/512
# 536/536 - 3s - loss: 0.3699 - val_loss: 0.3753 - 3s/epoch - 5ms/step
# Epoch 87/512
# 536/536 - 3s - loss: 0.3699 - val_loss: 0.3747 - 3s/epoch - 5ms/step
# Epoch 88/512
# 536/536 - 3s - loss: 0.3697 - val_loss: 0.3756 - 3s/epoch - 5ms/step
# Epoch 89/512
# 536/536 - 3s - loss: 0.3697 - val_loss: 0.3751 - 3s/epoch - 5ms/step
# Epoch 90/512
# 536/536 - 3s - loss: 0.3697 - val_loss: 0.3750 - 3s/epoch - 5ms/step
# Epoch 91/512
# 536/536 - 3s - loss: 0.3694 - val_loss: 0.3747 - 3s/epoch - 5ms/step
# Epoch 92/512
# 536/536 - 3s - loss: 0.3695 - val_loss: 0.3750 - 3s/epoch - 5ms/step
# Epoch 93/512
# 536/536 - 3s - loss: 0.3694 - val_loss: 0.3756 - 3s/epoch - 5ms/step
# Epoch 94/512
# 536/536 - 3s - loss: 0.3693 - val_loss: 0.3749 - 3s/epoch - 5ms/step
# Epoch 95/512
# 536/536 - 3s - loss: 0.3692 - val_loss: 0.3756 - 3s/epoch - 5ms/step
# Epoch 96/512
# 536/536 - 3s - loss: 0.3692 - val_loss: 0.3747 - 3s/epoch - 5ms/step
# Epoch 97/512
# 536/536 - 3s - loss: 0.3689 - val_loss: 0.3751 - 3s/epoch - 5ms/step
# Epoch 98/512
# 536/536 - 3s - loss: 0.3689 - val_loss: 0.3746 - 3s/epoch - 5ms/step
# Epoch 99/512
# 536/536 - 3s - loss: 0.3688 - val_loss: 0.3747 - 3s/epoch - 5ms/step
# Epoch 100/512
# 536/536 - 3s - loss: 0.3688 - val_loss: 0.3748 - 3s/epoch - 5ms/step
# Epoch 101/512
# 536/536 - 3s - loss: 0.3687 - val_loss: 0.3742 - 3s/epoch - 5ms/step
# Epoch 102/512
# 536/536 - 3s - loss: 0.3686 - val_loss: 0.3744 - 3s/epoch - 5ms/step
# Epoch 103/512
# 536/536 - 3s - loss: 0.3686 - val_loss: 0.3743 - 3s/epoch - 5ms/step
# Epoch 104/512
# 536/536 - 3s - loss: 0.3686 - val_loss: 0.3743 - 3s/epoch - 5ms/step
# Epoch 105/512
# 536/536 - 3s - loss: 0.3684 - val_loss: 0.3745 - 3s/epoch - 5ms/step
# Epoch 106/512
# 536/536 - 3s - loss: 0.3685 - val_loss: 0.3742 - 3s/epoch - 5ms/step
# Epoch 107/512
# 536/536 - 3s - loss: 0.3682 - val_loss: 0.3740 - 3s/epoch - 5ms/step
# Epoch 108/512
# 536/536 - 3s - loss: 0.3683 - val_loss: 0.3743 - 3s/epoch - 5ms/step
# Epoch 109/512
# 536/536 - 3s - loss: 0.3682 - val_loss: 0.3749 - 3s/epoch - 5ms/step
# Epoch 110/512
# 536/536 - 3s - loss: 0.3680 - val_loss: 0.3752 - 3s/epoch - 5ms/step
# Epoch 111/512
# 536/536 - 3s - loss: 0.3682 - val_loss: 0.3747 - 3s/epoch - 5ms/step
# Epoch 112/512
# 536/536 - 3s - loss: 0.3680 - val_loss: 0.3750 - 3s/epoch - 5ms/step
# Epoch 113/512
# 536/536 - 3s - loss: 0.3680 - val_loss: 0.3751 - 3s/epoch - 5ms/step
# Epoch 114/512
# 536/536 - 3s - loss: 0.3679 - val_loss: 0.3743 - 3s/epoch - 5ms/step
# Epoch 115/512
# 536/536 - 3s - loss: 0.3679 - val_loss: 0.3747 - 3s/epoch - 5ms/step
# Epoch 116/512
# 536/536 - 3s - loss: 0.3677 - val_loss: 0.3745 - 3s/epoch - 5ms/step
# Epoch 117/512
# 536/536 - 3s - loss: 0.3678 - val_loss: 0.3753 - 3s/epoch - 5ms/step

# %%
# # Define per-fold score containers
# acc_per_fold = []
# loss_per_fold = []

# # Define the K-fold Cross Validator
# kfold = KFold(n_splits=num_folds, shuffle=True)

# # K-fold Cross Validation model evaluation
# fold_no = 1
# best_model = None
# best_loss = np.inf

# # Settting up early stopping callbacks
# stop_early = tf.keras.callbacks.EarlyStopping(
#     monitor="val_loss",
#     min_delta=1e-4,
#     patience=10,
#     mode="auto",
#     baseline=None,
#     restore_best_weights=True,
# )

# # Check and find the best model form k-fold cross validation (or detect wether it's overtrining or not).
# for train, valid in kfold.split(train_x, train_y):
#     # Define the model architecture
#     model = build_model()

#     # Generate a print
#     print(f"Training for fold {fold_no} ...")

#     # Fit the model
#     history = model.fit(
#         data_gen(train_x, train_y, train),
#         steps_per_epoch=len(train) // batch_size,
#         validation_data=data_gen(train_x, train_y, valid),
#         validation_steps=len(valid) // batch_size,
#         epochs=epochs,
#         verbose=0,
#         callbacks=[stop_early],
#     )

#     # Generate generalization metrics
#     scores = model.evaluate(train_x[valid], train_y[valid], verbose=0)
#     print(
#         f"Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%"
#     )
#     acc_per_fold.append(scores[1] * 100)
#     loss_per_fold.append(scores[0])

#     # Check if this model is better than the previous best model
#     if scores[0] < best_loss:
#         best_loss = scores[0]
#         best_model = model
#         best_history = history

#     # Plotting training results
#     print(f"Plotting fold {fold_no} loss history...")
#     plot.plot_loss_history(history, logy=True)

#     # Increase fold number
#     fold_no = fold_no + 1

# # == Provide average scores ==
# best_model.summary()
# print(
#     f"""{'-'*72}
# Score per fold"""
# )
# for i in range(0, len(acc_per_fold)):
#     print(
#         f"""{'-'*72}
# > Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%"""
#     )
# print(
#     f"""{'-'*72}
# Average scores for all folds:
# > Accuracy: {np.mean(acc_per_fold)}% (+- {np.std(acc_per_fold)})
# > Loss: {np.mean(loss_per_fold)}
# {'-'*72}"""
# )

# %%
# save model
model.save("DNN_modified_e.h5", save_format="h5", overwrite=True)
# predict
pred_y = model.predict(test_x)
sig_pred = pred_y
sig_truth = test_y
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 12855/12855 [==============================] - 17s 1ms/step

# %%
print(f"Truth mean: {np.mean(sig_truth[:,0]):.3f}, std: {np.std(sig_truth[:,0]):.3f}, min: {np.min(sig_truth[:,0]):.3f}, max: {np.max(sig_truth[:,0]):.3f}")
# Out:
# Truth mean: 0.047, std: 0.693, min: -1.264, max: 3.193

# %%
from sklearn.metrics import mean_squared_error

range = [-1.3, 3.2]

plot.plot_hist(
    [sig_truth[:, 0], sig_pred[:, 0]],
    [r"$m_{truth}^{\nu\nu}$", r"$m_{pred}^{\nu\nu}$"],
    r"Sig. norm. $m^{\nu\nu}$"
    + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth[:,0], sig_pred[:,0])):.3f}",
    range=range,
    xlabel=r"Norm. $m$ [unit]",
)

plot.plot_loss_history(history, logx=True, logy=True)

plot.plot_2d_histogram(
    sig_truth[:, 0],
    sig_pred[:, 0],
    r"Sig. $m^{\nu\nu}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth[:,0], sig_pred[:,0])[0]:.3f}",
    range=range,
)

# %%
# TODO

# %%
# from sklearn.metrics import mean_squared_error

# range = [0.43, 0.57]
35042

# plot.plot_hist(
#     [sig_truth[:, 0], sig_pred[:, 0]],
#     [r"$p_{z\ truth}^{\nu\nu}$", r"$p_{z\ pred}^{\nu\nu}$"],
#     r"Sig. norm. $p^{\nu\nu}_{z}$" + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth[:,0], sig_pred[:,0])):.3f}",
#     range=range,
#     xlabel=r"[Norm. $p_{z}$ unit]",
# )

# plot.plot_loss_history(history, logx=True, logy=True)

# plot.plot_2d_histogram(
#     sig_truth[:, 0],
#     sig_pred[:, 0],
#     r"Sig. $p_{z}^{\nu\nu}$ "
#     + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth[:,0], sig_pred[:,0])[0]:.3f}",
#     range=range,
# )
# Out:
# 35042

# %%
# Background
processor = gd.DataProcessor(sampling=sampling, processor=10)
path = "/root/data/truth/background/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 10
#
# ['/root/data/truth/background/CGLMP.npz', '/root/data/truth/background/Higgs.npz', '/root/data/truth/background/LeadLepton.npz', '/root/data/truth/background/LeptonM.npz', '/root/data/truth/background/LeptonP.npz', '/root/data/truth/background/LmNu.npz', '/root/data/truth/background/LpNu.npz', '/root/data/truth/background/MET.npz', '/root/data/truth/background/WmBoson.npz', '/root/data/truth/background/WpBoson.npz', '/root/data/truth/background/diLepton.npz', '/root/data/truth/background/subLeadLepton.npz', '/root/data/truth/background/xi_xyz.npz']

# %%
# inputs -> observed params
lep_p = processor.process_part(data.LepP)[cut_pre]
lep_m = processor.process_part(data.LepM)[cut_pre]
lep_kin = pd.concat([lep_p, lep_m], axis=1)
MET = processor.process_MET(data.MET).iloc[:, 1:3][cut_pre]
obs_kin = pd.concat([MET, lep_kin], axis=1)
print("obs_kin shape:", obs_kin.shape)
print(obs_kin.head(3))
print()

# targets -> interested unknowns
int_kin = pd.DataFrame(
    processor.process_dipart(data.NuP, data.NuM)[["pz"]][cut_pre]
)
print("int_kin shape:", int_kin.shape)
print(int_kin.head(3))
print()

del (processor, lep_p, lep_m, MET)
gc.collect()
# Out:
# /tmp/ipykernel_4647/3122629841.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   lep_p = processor.process_part(data.LepP)[cut_pre]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[51], line 2
#       1 # inputs -> observed params
# ----> 2 lep_p = processor.process_part(data.LepP)[cut_pre]
#       3 lep_m = processor.process_part(data.LepM)[cut_pre]
#       4 lep_kin = pd.concat([lep_p, lep_m], axis=1)
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/frame.py:3887, in DataFrame.__getitem__(self, key)
#    3885 # Do we have a (boolean) 1d indexer?
#    3886 if com.is_bool_indexer(key):
# -> 3887     return self._getitem_bool_array(key)
#    3889 # We are left with two options: a single key, and a collection of keys,
#    3890 # We interpret tuples as collections only for non-MultiIndex
#    3891 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/frame.py:3943, in DataFrame._getitem_bool_array(self, key)
#    3937     raise ValueError(
#    3938         f"Item wrong length {len(key)} instead of {len(self.index)}."
#    3939     )
#    3941 # check_bool_indexer will throw exception if Series key cannot
#    3942 # be reindexed to match DataFrame rows
# -> 3943 key = check_bool_indexer(self.index, key)
#    3945 if key.all():
#    3946     return self.copy(deep=None)
#
# File ~/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/indexing.py:2575, in check_bool_indexer(index, key)
#    2573 indexer = result.index.get_indexer_for(index)
#    2574 if -1 in indexer:
# -> 2575     raise IndexingError(
#    2576         "Unalignable boolean Series provided as "
#    2577         "indexer (index of the boolean Series and of "
#    2578         "the indexed object do not match)."
#    2579     )
#    2581 result = result.take(indexer)
#    2583 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
# SCALAR_obs_std_bkg = StandardScaler()
# obs_kin = SCALAR_obs_std_bkg.fit_transform(obs_kin)
SCALAR_obs_qt_bkg = QuantileTransformer(output_distribution='normal')
obs_kin = SCALAR_obs_qt_bkg.fit_transform(obs_kin)

# SCALAR_int_std_bkg = StandardScaler()
# int_kin = SCALAR_int_std_bkg.fit_transform(int_kin)
SCALAR_int_qt_bkg = QuantileTransformer(output_distribution='normal')
int_kin = SCALAR_int_qt_bkg.fit_transform(int_kin)

x, y = obs_kin[indices_arr], int_kin[indices_arr]

print(f"X:\ndata shape: {x.shape};\nY:\ndata shape: {y.shape}.")
print()

# %%
y_pred = model.predict(x)
bkg_pred = y_pred
bkg_truth = y

# %%
range = [
    np.max([bkg_pred[:, 0].min(), bkg_truth[:, 0].min()]),
    np.min([bkg_pred[:, 0].max(), bkg_truth[:, 0].max()]),
]

plot.plot_hist(
    [bkg_truth[:, 0], bkg_pred[:, 0]],
    [r"$E_{truth}^{\nu\nu}$", r"$E_{pred}^{\nu\nu}$"],
    "Non-resnt WW: " + r"Normalized $E$ of $\nu\nu$",
    range=range,
    xlabel=r"$E$ [GeV]",
)

plot.plot_2d_histogram(
    bkg_pred[:, 0],
    bkg_truth[:, 0],
    "Non-resnt WW: "
    + r"$E^{\nu\nu}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(bkg_truth[:,0], bkg_pred[:,0])[0]:.3f}",
    range=range,
)

# %%
range = [
    np.max([bkg_pred[:, 1].min(), bkg_truth[:, 1].min()]),
    np.min([bkg_pred[:, 1].max(), bkg_truth[:, 1].max()]),
]

plot.plot_hist(
    [bkg_truth[:, 1], bkg_pred[:, 1]],
    [r"$p_{z\ truth}^{\nu\nu}$", r"$p_{z\ pred}^{\nu\nu}$"],
    r"Non-resnt WW: Normalized $p_{z}$ of $\nu\nu$",
    range=range,
    xlabel=r"$p_{z}$ [GeV]",
)

plot.plot_2d_histogram(
    bkg_truth[:, 1],
    bkg_pred[:, 1],
    "Non-resnt WW: "
    + r"$p_{z}^{\nu\nu}$"
    + f" with Pearson coeff: {sp.stats.pearsonr(bkg_truth[:,1], bkg_pred[:,1])[0]:.3f}",
    range=range,
)

time_end = time()
print(f"Time cost: {(time_end - time_start):.2f} s.")
