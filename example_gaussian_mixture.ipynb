# %%
from numpy import cos, sin, pi, sqrt

deg = pi / 8

x = (
    -((cos(deg) - sin(deg)) / (8 * sin(deg) ** 3))
    + (cos(deg) / sqrt(2))
    -((3 * cos(deg) + sin(deg)) / (8 * cos(deg) ** 3))
    + (cos(deg) / 4)
)
print("x:", x)

y = (
    -((3 * sin(deg) - cos(deg)) / (8 * sin(deg) ** 3))
    + (sin(deg) / sqrt(2))
    -((cos(deg) + sin(deg)) / (8 * cos(deg) ** 3))
    + (sin(deg) / 4)
)
print("y:", y)
# Out:
# x: -0.8228554156205372
# y: -0.34083787302217655

# %% [markdown]
# # Example: Gaussian Mixture
#
# - 2020-11-29 first uploaded
# - 2021-04-08 backward loss updated

# %%
from IPython.display import HTML
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import itertools
from flow import *
from utils import *
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
print(tf.__version__)
# !python --version
# Out:
# 2023-11-19 08:24:04.823215: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.13.0
# Python 3.10.12

# %% [markdown]
# ## Settings

# %%
n_means = 8
radius = 14
sd = 1
labels = ['red','gold','green','chocolate','blue','magenta','pink','purple']
# labels = ['red','red','red','red','blue','blue','green','purple']
assert len(labels) == n_means

x_dim = 2
y_dim = len(list(set(labels)))
z_dim = 2
tot_dim = y_dim + z_dim
pad_dim = tot_dim - x_dim
n_sample = 200
n_data = n_sample * n_means
n_couple_layer = 3
n_hid_layer = 3
n_hid_dim = 512

n_batch = 50
n_epoch = 100
n_display = 10

# %%
# Make data
X_raw = np.zeros((n_means, n_sample, x_dim), dtype='float32')
for i in range(n_means):
    th = 2*np.pi / n_means * (i+1)
    mean = [radius*np.cos(th), radius*np.sin(th)]
    X_raw[i, :, :] = np.random.multivariate_normal(mean, np.identity(x_dim)*sd, size=n_sample)

fig, ax = plt.subplots(figsize=(5,5), facecolor='white')
for i in range(n_means):
    ax.scatter(X_raw[i,:,0], X_raw[i,:,1], s=1)
print(X_raw.shape)
# Out:
# (8, 200, 2)

# %%
# Preprocess
uq_labels = list(set(labels))
idx2lab = {i:lab for i, lab in enumerate(uq_labels)}
lab2idx = {idx2lab[key]:i for i, key in enumerate(idx2lab.keys())}

X = X_raw.reshape((-1, x_dim))
print(X.shape)
X = StandardScaler().fit_transform(X)
y = [[lab2idx[lab]]*n_sample for lab in labels]
y = list(itertools.chain.from_iterable(y)) # flatten
y_onehot = np.eye(len(uq_labels))[y].astype('int')

fig, ax = plt.subplots(figsize=(5,5), facecolor='white')
for i, color in zip(idx2lab.keys(), lab2idx.keys()):
    idx = [True if j==i else False for j in y]
    ax.scatter(X[idx,0], X[idx,1], s=1, c=color)
# Out:
# (1600, 2)

# %%
# Pad data
pad_x = np.zeros((X.shape[0], pad_dim))
x_data = np.concatenate([X, pad_x], axis=-1).astype('float32')
z = np.random.multivariate_normal([0.]*z_dim, np.eye(z_dim), X.shape[0]).astype('float32')
print(x_data.shape)
print(y_onehot.shape)
print(z.shape)
y_data = np.concatenate([z, y_onehot], axis=-1).astype('float32')

# Make dataset generator
x_data = tf.data.Dataset.from_tensor_slices(x_data)
y_data = tf.data.Dataset.from_tensor_slices(y_data)
dataset = (tf.data.Dataset.zip((x_data, y_data))
           .shuffle(buffer_size=X.shape[0])
           .batch(n_batch, drop_remainder=True)
           .repeat())
# Out:
# (1600, 10)
# (1600, 8)
# (1600, 2)
# 2023-11-19 08:24:11.913344: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46696 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-19 08:24:11.914868: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46696 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:25:00.0, compute capability: 8.6

# %% [markdown]
# ## Initialize the model

# %%
model = NVP(tot_dim, n_couple_layer, n_hid_layer, n_hid_dim, name='NVP')
x = tfk.Input((tot_dim,))
model(x);
model.summary()
# tf.keras.utils.plot_model(model, expand_nested=True, show_shapes=True, dpi=64)
# Out:
# Model: "NVP"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Layer0 (TwoNVPCouplingLaye  multiple                  1067038
#  rs)
#
#  Layer1 (TwoNVPCouplingLaye  multiple                  1067038
#  rs)
#
#  Layer2 (TwoNVPCouplingLaye  multiple                  1067038
#  rs)
#
# =================================================================
# Total params: 3201114 (12.21 MB)
# Trainable params: 3201084 (12.21 MB)
# Non-trainable params: 30 (240.00 Byte)
# _________________________________________________________________

# %%
class Trainer(tfk.Model):
    def __init__(self, model, x_dim, y_dim, z_dim, tot_dim, 
                 n_couple_layer, n_hid_layer, n_hid_dim, shuffle_type='reverse'):
        super(Trainer, self).__init__()
        self.model = model
        self.x_dim = x_dim
        self.y_dim = y_dim
        self.z_dim = z_dim
        self.tot_dim = tot_dim
        self.x_pad_dim = tot_dim - x_dim
        self.y_pad_dim = tot_dim - (y_dim + z_dim)
        self.n_couple_layer = n_couple_layer
        self.n_hid_layer = n_hid_layer
        self.n_hid_dim = n_hid_dim
        self.shuffle_type = shuffle_type

        self.w1 = 5.
        self.w2 = 1.
        self.w3 = 10.
        self.loss_factor = 1.
        self.loss_fit = MSE
        self.loss_latent = MMD_multiscale
        self.loss_backward = MMD_multiscale

    def train_step(self, data):
        x_data, y_data = data
        x = x_data[:, :self.x_dim]
        y = y_data[:, -self.y_dim:]
        z = y_data[:, :self.z_dim]
        print("x", x.shape)
        print("y", y.shape)
        print("z", z.shape)
        y_short = tf.concat([z, y], axis=-1)
        print("x_data", x_data.shape)
        print("y_short", y_short.shape)

        # Forward loss
        with tf.GradientTape() as tape:
            y_out = self.model(x_data)    
            pred_loss = self.w1 * self.loss_fit(y_data[:,self.z_dim:], y_out[:,self.z_dim:]) # [zeros, y] <=> [zeros, yhat]
            print(y_out)
            print("!!!!!!!")
            print("z_dim", z_dim)
            print("y_dim", y_dim)
            print(y_out[:, :self.z_dim])
            print(y_out[:, -self.y_dim:])
            output_block_grad = tf.concat([y_out[:, :self.z_dim], y_out[:, -self.y_dim:]], axis=-1) # take out [z, y] only (not zeros)
            print(y_short)
            print(output_block_grad)
            latent_loss = self.w2 * self.loss_latent(y_short, output_block_grad) # [z, y] <=> [zhat, yhat]
            forward_loss = pred_loss + latent_loss
            # print(latent_loss)
            # print(forward_loss)
        grads_forward = tape.gradient(forward_loss, self.model.trainable_weights)
        self.optimizer.apply_gradients(zip(grads_forward, self.model.trainable_weights))

        # Backward loss
        with tf.GradientTape() as tape:
            x_rev = self.model.inverse(y_data)
            #rev_loss = self.w3 * self.loss_factor * self.loss_fit(x_rev, x_data)
            rev_loss = self.w3 * self.loss_factor * self.loss_backward(x_rev, x_data)
        grads_backward = tape.gradient(rev_loss, self.model.trainable_weights)
        self.optimizer.apply_gradients(zip(grads_backward, self.model.trainable_weights)) 

        total_loss = forward_loss + latent_loss + rev_loss
        return {'total_loss': total_loss,
                'forward_loss': forward_loss,
                'latent_loss': latent_loss,
                'rev_loss': rev_loss}

    def test_step(self, data):
        x_data, y_data = data
        return NotImplementedError

# %%
trainer = Trainer(model, x_dim, y_dim, z_dim, tot_dim, n_couple_layer, n_hid_layer, n_hid_dim)
trainer.compile(optimizer='Adam')

# %% [markdown]
# ## Train the model

# %%
# Load the TensorBoard notebook extension.
import datetime


LossFactor = UpdateLossFactor(n_epoch)
logger = NBatchLogger(n_display, n_epoch)

# set log file
# %rm -r ./logs
log_dir = "gau_eg_logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# set callback of tensorboard
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False,)

hist = trainer.fit(
    dataset,
    batch_size=n_batch,
    epochs=n_epoch,
    steps_per_epoch=n_data // n_batch,
    callbacks=[logger, LossFactor, tensorboard_callback],
    verbose=2,
)
# Out:
# === Started at 2023-11-19 08h:24m:14s ===
# Epoch 1/100
# x (50, 2)
# y (50, 8)
# z (50, 2)
# x_data (50, 10)
# y_short (50, 10)
# Tensor("NVP/Layer2/concat:0", shape=(50, 10), dtype=float32)
# !!!!!!!
# z_dim 2
# y_dim 8
# Tensor("strided_slice_5:0", shape=(50, 2), dtype=float32)
# Tensor("strided_slice_6:0", shape=(50, 8), dtype=float32)
# Tensor("concat:0", shape=(50, 10), dtype=float32)
# Tensor("concat_1:0", shape=(50, 10), dtype=float32)
# x (50, 2)
# y (50, 8)
# z (50, 2)
# x_data (50, 10)
# y_short (50, 10)
# Tensor("NVP/Layer2/concat:0", shape=(50, 10), dtype=float32)
# !!!!!!!
# z_dim 2
# y_dim 8
# Tensor("strided_slice_5:0", shape=(50, 2), dtype=float32)
# Tensor("strided_slice_6:0", shape=(50, 8), dtype=float32)
# Tensor("concat:0", shape=(50, 10), dtype=float32)
# Tensor("concat_1:0", shape=(50, 10), dtype=float32)
# 2023-11-19 08:24:24.122333: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-19 08:24:24.154287: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f1434131720 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-19 08:24:24.154368: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-11-19 08:24:24.154384: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-11-19 08:24:24.164737: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-19 08:24:24.437314: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-11-19 08:24:24.606683: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  2023-11-19 08h:24m:35s | Epoch: 001/100 | total_loss=2.645106 forward_loss=0.341208 latent_loss=0.248962 rev_loss=2.054937
# 32/32 - 22s - total_loss: 2.6451 - forward_loss: 0.3412 - latent_loss: 0.2490 - rev_loss: 2.0549 - 22s/epoch - 680ms/step
# Epoch 2/100
# 32/32 - 3s - total_loss: 1.9282 - forward_loss: 0.2727 - latent_loss: 0.2249 - rev_loss: 1.4307 - 3s/epoch - 89ms/step
# Epoch 3/100
# 32/32 - 3s - total_loss: 1.8598 - forward_loss: 0.2772 - latent_loss: 0.2122 - rev_loss: 1.3703 - 3s/epoch - 89ms/step
# Epoch 4/100
# 32/32 - 3s - total_loss: 1.5448 - forward_loss: 0.2572 - latent_loss: 0.1756 - rev_loss: 1.1119 - 3s/epoch - 84ms/step
# Epoch 5/100
# 32/32 - 3s - total_loss: 1.8842 - forward_loss: 0.2477 - latent_loss: 0.1954 - rev_loss: 1.4412 - 3s/epoch - 92ms/step
# Epoch 6/100
# 32/32 - 3s - total_loss: 1.6303 - forward_loss: 0.2638 - latent_loss: 0.1998 - rev_loss: 1.1667 - 3s/epoch - 95ms/step
# Epoch 7/100
# 32/32 - 3s - total_loss: 1.3450 - forward_loss: 0.2116 - latent_loss: 0.1776 - rev_loss: 0.9558 - 3s/epoch - 102ms/step
# Epoch 8/100
# 32/32 - 3s - total_loss: 1.5313 - forward_loss: 0.2177 - latent_loss: 0.1641 - rev_loss: 1.1495 - 3s/epoch - 107ms/step
# Epoch 9/100
# 32/32 - 3s - total_loss: 1.5031 - forward_loss: 0.2125 - latent_loss: 0.1771 - rev_loss: 1.1135 - 3s/epoch - 102ms/step
# Epoch 10/100
#  2023-11-19 08h:25m:02s | Epoch: 010/100 | total_loss=1.193271 forward_loss=0.183641 latent_loss=0.133328 rev_loss=0.876301
# 32/32 - 3s - total_loss: 1.1933 - forward_loss: 0.1836 - latent_loss: 0.1333 - rev_loss: 0.8763 - 3s/epoch - 100ms/step
# Epoch 11/100
# 32/32 - 3s - total_loss: 1.4737 - forward_loss: 0.2000 - latent_loss: 0.1562 - rev_loss: 1.1174 - 3s/epoch - 97ms/step
# Epoch 12/100
# 32/32 - 3s - total_loss: 1.3271 - forward_loss: 0.1819 - latent_loss: 0.1447 - rev_loss: 1.0005 - 3s/epoch - 100ms/step
# Epoch 13/100
# 32/32 - 3s - total_loss: 1.1697 - forward_loss: 0.1834 - latent_loss: 0.1318 - rev_loss: 0.8545 - 3s/epoch - 97ms/step
# Epoch 14/100
# 32/32 - 3s - total_loss: 1.5088 - forward_loss: 0.1860 - latent_loss: 0.1533 - rev_loss: 1.1695 - 3s/epoch - 95ms/step
# Epoch 15/100
# 32/32 - 3s - total_loss: 1.0188 - forward_loss: 0.1531 - latent_loss: 0.1221 - rev_loss: 0.7435 - 3s/epoch - 107ms/step
# Epoch 16/100
# 32/32 - 3s - total_loss: 1.0562 - forward_loss: 0.2008 - latent_loss: 0.1547 - rev_loss: 0.7007 - 3s/epoch - 83ms/step
# Epoch 17/100
# 32/32 - 3s - total_loss: 1.0517 - forward_loss: 0.1627 - latent_loss: 0.1282 - rev_loss: 0.7609 - 3s/epoch - 86ms/step
# Epoch 18/100
# 32/32 - 3s - total_loss: 1.0451 - forward_loss: 0.1784 - latent_loss: 0.1485 - rev_loss: 0.7182 - 3s/epoch - 99ms/step
# Epoch 19/100
# 32/32 - 3s - total_loss: 0.9548 - forward_loss: 0.1416 - latent_loss: 0.1229 - rev_loss: 0.6903 - 3s/epoch - 97ms/step
# Epoch 20/100
#  2023-11-19 08h:25m:33s | Epoch: 020/100 | total_loss=1.397338 forward_loss=0.165946 latent_loss=0.148941 rev_loss=1.082450
# 32/32 - 3s - total_loss: 1.3973 - forward_loss: 0.1659 - latent_loss: 0.1489 - rev_loss: 1.0824 - 3s/epoch - 97ms/step
# Epoch 21/100
# 32/32 - 3s - total_loss: 1.3962 - forward_loss: 0.1853 - latent_loss: 0.1634 - rev_loss: 1.0475 - 3s/epoch - 97ms/step
# Epoch 22/100
# 32/32 - 3s - total_loss: 1.1953 - forward_loss: 0.1957 - latent_loss: 0.1658 - rev_loss: 0.8338 - 3s/epoch - 82ms/step
# Epoch 23/100
# 32/32 - 3s - total_loss: 0.8146 - forward_loss: 0.1339 - latent_loss: 0.1203 - rev_loss: 0.5604 - 3s/epoch - 100ms/step
# Epoch 24/100
# 32/32 - 3s - total_loss: 0.8907 - forward_loss: 0.1276 - latent_loss: 0.1162 - rev_loss: 0.6469 - 3s/epoch - 99ms/step
# Epoch 25/100
# 32/32 - 3s - total_loss: 0.9075 - forward_loss: 0.1500 - latent_loss: 0.1359 - rev_loss: 0.6215 - 3s/epoch - 100ms/step
# Epoch 26/100
# 32/32 - 3s - total_loss: 1.0429 - forward_loss: 0.1435 - latent_loss: 0.1298 - rev_loss: 0.7696 - 3s/epoch - 88ms/step
# Epoch 27/100
# 32/32 - 3s - total_loss: 0.9417 - forward_loss: 0.1501 - latent_loss: 0.1299 - rev_loss: 0.6617 - 3s/epoch - 104ms/step
# Epoch 28/100
# 32/32 - 3s - total_loss: 1.0534 - forward_loss: 0.1454 - latent_loss: 0.1269 - rev_loss: 0.7812 - 3s/epoch - 89ms/step
# Epoch 29/100
# 32/32 - 3s - total_loss: 0.8549 - forward_loss: 0.1309 - latent_loss: 0.1130 - rev_loss: 0.6110 - 3s/epoch - 88ms/step
# Epoch 30/100
#  2023-11-19 08h:26m:03s | Epoch: 030/100 | total_loss=1.279128 forward_loss=0.164383 latent_loss=0.149693 rev_loss=0.965052
# 32/32 - 3s - total_loss: 1.2791 - forward_loss: 0.1644 - latent_loss: 0.1497 - rev_loss: 0.9651 - 3s/epoch - 83ms/step
# Epoch 31/100
# 32/32 - 3s - total_loss: 0.9954 - forward_loss: 0.1336 - latent_loss: 0.1260 - rev_loss: 0.7358 - 3s/epoch - 93ms/step
# Epoch 32/100
# 32/32 - 3s - total_loss: 0.8379 - forward_loss: 0.1322 - latent_loss: 0.1219 - rev_loss: 0.5838 - 3s/epoch - 89ms/step
# Epoch 33/100
# 32/32 - 3s - total_loss: 0.7478 - forward_loss: 0.1295 - latent_loss: 0.1138 - rev_loss: 0.5045 - 3s/epoch - 101ms/step
# Epoch 34/100
# 32/32 - 3s - total_loss: 0.9773 - forward_loss: 0.1575 - latent_loss: 0.1453 - rev_loss: 0.6744 - 3s/epoch - 85ms/step
# Epoch 35/100
# 32/32 - 3s - total_loss: 0.9595 - forward_loss: 0.1370 - latent_loss: 0.1202 - rev_loss: 0.7022 - 3s/epoch - 88ms/step
# Epoch 36/100
# 32/32 - 3s - total_loss: 1.1391 - forward_loss: 0.1385 - latent_loss: 0.1224 - rev_loss: 0.8781 - 3s/epoch - 92ms/step
# Epoch 37/100
# 32/32 - 3s - total_loss: 0.8544 - forward_loss: 0.1355 - latent_loss: 0.1219 - rev_loss: 0.5971 - 3s/epoch - 98ms/step
# Epoch 38/100
# 32/32 - 3s - total_loss: 0.8911 - forward_loss: 0.1310 - latent_loss: 0.1200 - rev_loss: 0.6401 - 3s/epoch - 95ms/step
# Epoch 39/100
# 32/32 - 3s - total_loss: 0.9378 - forward_loss: 0.1343 - latent_loss: 0.1205 - rev_loss: 0.6830 - 3s/epoch - 92ms/step
# Epoch 40/100
#  2023-11-19 08h:26m:32s | Epoch: 040/100 | total_loss=0.945424 forward_loss=0.135826 latent_loss=0.124604 rev_loss=0.684994
# 32/32 - 2s - total_loss: 0.9454 - forward_loss: 0.1358 - latent_loss: 0.1246 - rev_loss: 0.6850 - 2s/epoch - 70ms/step
# Epoch 41/100
# 32/32 - 2s - total_loss: 0.9325 - forward_loss: 0.1346 - latent_loss: 0.1268 - rev_loss: 0.6712 - 2s/epoch - 75ms/step
# Epoch 42/100
# 32/32 - 3s - total_loss: 0.9341 - forward_loss: 0.1325 - latent_loss: 0.1205 - rev_loss: 0.6811 - 3s/epoch - 100ms/step
# Epoch 43/100
# 32/32 - 3s - total_loss: 0.8800 - forward_loss: 0.1265 - latent_loss: 0.1131 - rev_loss: 0.6404 - 3s/epoch - 96ms/step
# Epoch 44/100
# 32/32 - 3s - total_loss: 0.9194 - forward_loss: 0.1369 - latent_loss: 0.1236 - rev_loss: 0.6590 - 3s/epoch - 97ms/step
# Epoch 45/100
# 32/32 - 3s - total_loss: 0.7868 - forward_loss: 0.1244 - latent_loss: 0.1119 - rev_loss: 0.5505 - 3s/epoch - 93ms/step
# Epoch 46/100
# 32/32 - 3s - total_loss: 0.8791 - forward_loss: 0.1243 - latent_loss: 0.1124 - rev_loss: 0.6424 - 3s/epoch - 89ms/step
# Epoch 47/100
# 32/32 - 3s - total_loss: 0.8483 - forward_loss: 0.1261 - latent_loss: 0.1087 - rev_loss: 0.6135 - 3s/epoch - 92ms/step
# Epoch 48/100
# 32/32 - 3s - total_loss: 0.9237 - forward_loss: 0.1260 - latent_loss: 0.1162 - rev_loss: 0.6815 - 3s/epoch - 90ms/step
# Epoch 49/100
# 32/32 - 3s - total_loss: 1.0458 - forward_loss: 0.1465 - latent_loss: 0.1274 - rev_loss: 0.7719 - 3s/epoch - 87ms/step
# Epoch 50/100
#  2023-11-19 08h:27m:01s | Epoch: 050/100 | total_loss=0.690857 forward_loss=0.112822 latent_loss=0.103314 rev_loss=0.474721
# 32/32 - 3s - total_loss: 0.6909 - forward_loss: 0.1128 - latent_loss: 0.1033 - rev_loss: 0.4747 - 3s/epoch - 85ms/step
# Epoch 51/100
# 32/32 - 3s - total_loss: 1.0105 - forward_loss: 0.1271 - latent_loss: 0.1195 - rev_loss: 0.7639 - 3s/epoch - 87ms/step
# Epoch 52/100
# 32/32 - 3s - total_loss: 0.8746 - forward_loss: 0.1164 - latent_loss: 0.1078 - rev_loss: 0.6504 - 3s/epoch - 79ms/step
# Epoch 53/100
# 32/32 - 3s - total_loss: 0.8150 - forward_loss: 0.1192 - latent_loss: 0.1087 - rev_loss: 0.5871 - 3s/epoch - 103ms/step
# Epoch 54/100
# 32/32 - 3s - total_loss: 0.7810 - forward_loss: 0.1187 - latent_loss: 0.1103 - rev_loss: 0.5519 - 3s/epoch - 99ms/step
# Epoch 55/100
# 32/32 - 3s - total_loss: 1.1148 - forward_loss: 0.1388 - latent_loss: 0.1283 - rev_loss: 0.8477 - 3s/epoch - 93ms/step
# Epoch 56/100
# 32/32 - 3s - total_loss: 0.8495 - forward_loss: 0.1247 - latent_loss: 0.1081 - rev_loss: 0.6167 - 3s/epoch - 96ms/step
# Epoch 57/100
# 32/32 - 3s - total_loss: 0.9384 - forward_loss: 0.1396 - latent_loss: 0.1224 - rev_loss: 0.6765 - 3s/epoch - 88ms/step
# Epoch 58/100
# 32/32 - 3s - total_loss: 1.0555 - forward_loss: 0.1298 - latent_loss: 0.1232 - rev_loss: 0.8026 - 3s/epoch - 97ms/step
# Epoch 59/100
# 32/32 - 3s - total_loss: 0.7637 - forward_loss: 0.1139 - latent_loss: 0.1012 - rev_loss: 0.5486 - 3s/epoch - 94ms/step
# Epoch 60/100
#  2023-11-19 08h:27m:30s | Epoch: 060/100 | total_loss=0.979653 forward_loss=0.161739 latent_loss=0.119608 rev_loss=0.698306
# 32/32 - 3s - total_loss: 0.9797 - forward_loss: 0.1617 - latent_loss: 0.1196 - rev_loss: 0.6983 - 3s/epoch - 81ms/step
# Epoch 61/100
# 32/32 - 3s - total_loss: 0.8381 - forward_loss: 0.1242 - latent_loss: 0.1124 - rev_loss: 0.6015 - 3s/epoch - 94ms/step
# Epoch 62/100
# 32/32 - 3s - total_loss: 0.9231 - forward_loss: 0.1189 - latent_loss: 0.1104 - rev_loss: 0.6937 - 3s/epoch - 86ms/step
# Epoch 63/100
# 32/32 - 3s - total_loss: 0.8617 - forward_loss: 0.1254 - latent_loss: 0.1168 - rev_loss: 0.6195 - 3s/epoch - 83ms/step
# Epoch 64/100
# 32/32 - 3s - total_loss: 1.0055 - forward_loss: 0.1364 - latent_loss: 0.1197 - rev_loss: 0.7494 - 3s/epoch - 97ms/step
# Epoch 65/100
# 32/32 - 3s - total_loss: 0.8095 - forward_loss: 0.1148 - latent_loss: 0.1077 - rev_loss: 0.5870 - 3s/epoch - 92ms/step
# Epoch 66/100
# 32/32 - 3s - total_loss: 0.9180 - forward_loss: 0.1298 - latent_loss: 0.1158 - rev_loss: 0.6725 - 3s/epoch - 90ms/step
# Epoch 67/100
# 32/32 - 3s - total_loss: 0.9542 - forward_loss: 0.1463 - latent_loss: 0.1224 - rev_loss: 0.6856 - 3s/epoch - 97ms/step
# Epoch 68/100
# 32/32 - 3s - total_loss: 0.9262 - forward_loss: 0.1254 - latent_loss: 0.1109 - rev_loss: 0.6899 - 3s/epoch - 79ms/step
# Epoch 69/100
# 32/32 - 3s - total_loss: 1.1144 - forward_loss: 0.1411 - latent_loss: 0.1323 - rev_loss: 0.8410 - 3s/epoch - 89ms/step
# Epoch 70/100
#  2023-11-19 08h:27m:59s | Epoch: 070/100 | total_loss=0.791590 forward_loss=0.136339 latent_loss=0.109300 rev_loss=0.545951
# 32/32 - 3s - total_loss: 0.7916 - forward_loss: 0.1363 - latent_loss: 0.1093 - rev_loss: 0.5460 - 3s/epoch - 88ms/step
# Epoch 71/100
# 32/32 - 3s - total_loss: 0.9458 - forward_loss: 0.1292 - latent_loss: 0.1199 - rev_loss: 0.6968 - 3s/epoch - 103ms/step
# Epoch 72/100
# 32/32 - 3s - total_loss: 0.8587 - forward_loss: 0.1223 - latent_loss: 0.1142 - rev_loss: 0.6221 - 3s/epoch - 96ms/step
# Epoch 73/100
# 32/32 - 3s - total_loss: 0.9628 - forward_loss: 0.1332 - latent_loss: 0.1227 - rev_loss: 0.7069 - 3s/epoch - 81ms/step
# Epoch 74/100
# 32/32 - 2s - total_loss: 0.6678 - forward_loss: 0.1106 - latent_loss: 0.1029 - rev_loss: 0.4543 - 2s/epoch - 77ms/step
# Epoch 75/100
# 32/32 - 2s - total_loss: 0.8833 - forward_loss: 0.1233 - latent_loss: 0.1173 - rev_loss: 0.6426 - 2s/epoch - 73ms/step
# Epoch 76/100
# 32/32 - 3s - total_loss: 0.7369 - forward_loss: 0.1139 - latent_loss: 0.1064 - rev_loss: 0.5166 - 3s/epoch - 82ms/step
# Epoch 77/100
# 32/32 - 3s - total_loss: 0.8609 - forward_loss: 0.1287 - latent_loss: 0.1196 - rev_loss: 0.6126 - 3s/epoch - 92ms/step
# Epoch 78/100
# 32/32 - 3s - total_loss: 0.8166 - forward_loss: 0.1154 - latent_loss: 0.1080 - rev_loss: 0.5931 - 3s/epoch - 86ms/step
# Epoch 79/100
# 32/32 - 3s - total_loss: 0.8705 - forward_loss: 0.1283 - latent_loss: 0.1185 - rev_loss: 0.6237 - 3s/epoch - 81ms/step
# Epoch 80/100
#  2023-11-19 08h:28m:26s | Epoch: 080/100 | total_loss=0.870652 forward_loss=0.115464 latent_loss=0.106759 rev_loss=0.648430
# 32/32 - 3s - total_loss: 0.8707 - forward_loss: 0.1155 - latent_loss: 0.1068 - rev_loss: 0.6484 - 3s/epoch - 79ms/step
# Epoch 81/100
# 32/32 - 3s - total_loss: 0.7731 - forward_loss: 0.1245 - latent_loss: 0.1127 - rev_loss: 0.5360 - 3s/epoch - 81ms/step
# Epoch 82/100
# 32/32 - 3s - total_loss: 0.8357 - forward_loss: 0.1162 - latent_loss: 0.1076 - rev_loss: 0.6119 - 3s/epoch - 93ms/step
# Epoch 83/100
# 32/32 - 3s - total_loss: 0.7642 - forward_loss: 0.1126 - latent_loss: 0.1079 - rev_loss: 0.5437 - 3s/epoch - 88ms/step
# Epoch 84/100
# 32/32 - 3s - total_loss: 0.8218 - forward_loss: 0.1166 - latent_loss: 0.1062 - rev_loss: 0.5990 - 3s/epoch - 85ms/step
# Epoch 85/100
# 32/32 - 3s - total_loss: 0.9715 - forward_loss: 0.1272 - latent_loss: 0.1229 - rev_loss: 0.7215 - 3s/epoch - 82ms/step
# Epoch 86/100
# 32/32 - 3s - total_loss: 0.7252 - forward_loss: 0.1107 - latent_loss: 0.1036 - rev_loss: 0.5109 - 3s/epoch - 98ms/step
# Epoch 87/100
# 32/32 - 3s - total_loss: 0.7608 - forward_loss: 0.1128 - latent_loss: 0.1059 - rev_loss: 0.5420 - 3s/epoch - 82ms/step
# Epoch 88/100
# 32/32 - 2s - total_loss: 1.0866 - forward_loss: 0.1434 - latent_loss: 0.1209 - rev_loss: 0.8224 - 2s/epoch - 64ms/step
# Epoch 89/100
# 32/32 - 3s - total_loss: 0.8333 - forward_loss: 0.1151 - latent_loss: 0.1094 - rev_loss: 0.6088 - 3s/epoch - 91ms/step
# Epoch 90/100
#  2023-11-19 08h:28m:54s | Epoch: 090/100 | total_loss=0.897349 forward_loss=0.133129 latent_loss=0.125424 rev_loss=0.638796
# 32/32 - 3s - total_loss: 0.8973 - forward_loss: 0.1331 - latent_loss: 0.1254 - rev_loss: 0.6388 - 3s/epoch - 87ms/step
# Epoch 91/100
# 32/32 - 3s - total_loss: 0.9809 - forward_loss: 0.1356 - latent_loss: 0.1292 - rev_loss: 0.7160 - 3s/epoch - 90ms/step
# Epoch 92/100
# 32/32 - 3s - total_loss: 0.8585 - forward_loss: 0.1243 - latent_loss: 0.1188 - rev_loss: 0.6154 - 3s/epoch - 97ms/step
# Epoch 93/100
# 32/32 - 2s - total_loss: 0.7895 - forward_loss: 0.1253 - latent_loss: 0.1172 - rev_loss: 0.5470 - 2s/epoch - 69ms/step
# Epoch 94/100
# 32/32 - 2s - total_loss: 0.8038 - forward_loss: 0.1200 - latent_loss: 0.1142 - rev_loss: 0.5697 - 2s/epoch - 69ms/step
# Epoch 95/100
# 32/32 - 3s - total_loss: 0.6588 - forward_loss: 0.1067 - latent_loss: 0.1000 - rev_loss: 0.4521 - 3s/epoch - 88ms/step
# Epoch 96/100
# 32/32 - 3s - total_loss: 0.9194 - forward_loss: 0.1300 - latent_loss: 0.1163 - rev_loss: 0.6730 - 3s/epoch - 93ms/step
# Epoch 97/100
# 32/32 - 3s - total_loss: 0.9356 - forward_loss: 0.1143 - latent_loss: 0.1060 - rev_loss: 0.7153 - 3s/epoch - 85ms/step
# Epoch 98/100
# 32/32 - 3s - total_loss: 1.0826 - forward_loss: 0.1247 - latent_loss: 0.1166 - rev_loss: 0.8413 - 3s/epoch - 104ms/step
# Epoch 99/100
# 32/32 - 3s - total_loss: 0.8328 - forward_loss: 0.1265 - latent_loss: 0.1084 - rev_loss: 0.5979 - 3s/epoch - 99ms/step
# Epoch 100/100
#  2023-11-19 08h:29m:23s | Epoch: 100/100 | total_loss=0.979455 forward_loss=0.138258 latent_loss=0.132797 rev_loss=0.708401
# 32/32 - 4s - total_loss: 0.9795 - forward_loss: 0.1383 - latent_loss: 0.1328 - rev_loss: 0.7084 - 4s/epoch - 113ms/step
# === Time elapsed: 5.1648 min ===

# %% [markdown]
# ## Check results

# %%
fig, ax = plt.subplots(1, facecolor='white', figsize=(8,5))
ax.plot(hist.history['total_loss'], 'k.-', label='total_loss')
ax.plot(hist.history['forward_loss'], 'b.-', label='forward_loss')
ax.plot(hist.history['latent_loss'], 'g.-', label='latent_loss')
ax.plot(hist.history['rev_loss'], 'r.-', label='inverse_loss')
plt.legend()

# %%
z = np.random.multivariate_normal([0.]*z_dim, np.eye(z_dim), y_onehot.shape[0])
y = np.concatenate([z, y_onehot], axis=-1).astype('float32')
x_pred = model.inverse(y).numpy()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5), facecolor='white', sharex=True, sharey=True)
for i, color in zip(idx2lab.keys(), lab2idx.keys()):
    idx = [True if j==i else False for j in y_onehot.argmax(axis=-1)]
    ax1.scatter(X[idx,0], X[idx,1], s=1, c=color)
    ax2.scatter(x_pred[idx,0], x_pred[idx,1], s=1, c=color)
    ax2.set_xlim([-2, 2])
    ax2.set_ylim([-2, 2])
plt.suptitle('Original (left)                       Prediction (right)', fontsize=20);
