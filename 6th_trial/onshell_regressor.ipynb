# %%
# %reset -sf

import tensorflow as tf
print(tf.__version__)


# GPU(s) setups
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')
        
        # Instead of enabling memory growth, set a memory limit
        memory_limit = 16_384 # Set the memory limit in MB
        # tf.config.experimental.set_virtual_device_configuration(
        #     gpus[0],
        #     [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]
        # )
        
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2024-08-31 13:17:03.711055: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.13.0
# 2 Physical GPUs, 1 Logical GPU
# 2024-08-31 13:17:07.737381: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46696 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
import sys
import os
import glob
HOME_PATH = os.path.abspath("..")
sys.path.insert(0, HOME_PATH+"/qe")

import get_data as gd
import atlas_plot as ap
plot = ap.Plotter()

# INN packages
from flow import *
from utils import *

import pandas as pd
import numpy as np
import scipy as sp

from matplotlib import pyplot as plt
import matplotlib as mpl
import shap

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
SEED = 42  # set random seed (global variable)
np.random.seed(SEED)
processor = gd.DataProcessor()
path = "/root/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 76
#
# ['/root/data/truth/signal/CGLMP.npz', '/root/data/truth/signal/Higgs.npz', '/root/data/truth/signal/LeadLepton.npz', '/root/data/truth/signal/LeptonM.npz', '/root/data/truth/signal/LeptonP.npz', '/root/data/truth/signal/LmNu.npz', '/root/data/truth/signal/LpNu.npz', '/root/data/truth/signal/MET.npz', '/root/data/truth/signal/WmBoson.npz', '/root/data/truth/signal/WpBoson.npz', '/root/data/truth/signal/diLepton.npz', '/root/data/truth/signal/subLeadLepton.npz', '/root/data/truth/signal/xi_xyz.npz']

# %%
## Global variables

GEV = 1e3

cut_pre_pt_lead = data.LeadLep["pt"] > 22 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
cut_pre_pt_miss = data.MET["pt"] > 20 * GEV

PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

BATCH_SIZE = 8_192 * 2
EPOCHS = 1_024
LEARNING_RATE = 1e-4

# %%
## Observing variables

lead_lep = data.LeadLep[["px", "py", "pz", "E", "pt", "eta", "phi"]]
sublead_lep = data.SubLep[["px", "py", "pz", "E", "pt", "eta", "phi"]]
met = data.MET[["px", "py", "pt", "phi"]]
di_lep = data.diLep[["px", "py", "pz", "E", "pt", "eta", "phi", "m"]]

# Kinematics of observing variables (inputs for training)
obs_kin = pd.concat([lead_lep, sublead_lep, met, di_lep], axis=1)[PRE_CUT]
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array
ROBUST_OBS = RobustScaler()
obs_kin = ROBUST_OBS.fit_transform(obs_kin)
print(type(obs_kin))
# Out:
# int_kin shape: (1378510, 26)
# <class 'numpy.ndarray'>

# %%
cla = tf.keras.models.load_model('./classifier/shell_classifier.keras')
cla.summary()
pred_onshell_label = cla.predict(obs_kin)
pred_onshell_label = np.squeeze(np.where(pred_onshell_label >= 0.5, 1, 0))
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 26)]              0
#
#  flatten_3 (Flatten)         (None, 26)                0
#
#  dense_21 (Dense)            (None, 128)               3456
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_22 (Dense)            (None, 512)               66048
#
#  dropout_13 (Dropout)        (None, 512)               0
#
#  dense_23 (Dense)            (None, 512)               262656
#
#  dropout_14 (Dropout)        (None, 512)               0
#
#  dense_24 (Dense)            (None, 64)                32832
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_25 (Dense)            (None, 16)                1040
#
#  dropout_16 (Dropout)        (None, 16)                0
#
#  dense_26 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 366049 (1.40 MB)
# Trainable params: 366049 (1.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#    98/43079 [..............................] - ETA: 1:07
# 2024-08-31 13:17:29.980553: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 43079/43079 [==============================] - 65s 1ms/step

# %%
## Interesting variables

# Critria for leading and subleading lepton
lead_p = data.LeadLep["m"] == data.LepP["m"]
sublead_p = ~lead_p
lead_m = sublead_p.copy()
sublead_m = lead_p.copy()

# (sub)lead W
w_lead = pd.concat([data.Wp[lead_p], data.Wm[lead_m]], axis=0).sort_index()
w_sublead = pd.concat([data.Wp[sublead_p], data.Wm[sublead_m]], axis=0).sort_index()
w_onshell = pd.concat([w_lead[PRE_CUT][pred_onshell_label.astype(bool)], w_sublead[PRE_CUT][~pred_onshell_label.astype(bool)]], axis=0).sort_index()
w_offshell = pd.concat([w_lead[PRE_CUT][~pred_onshell_label.astype(bool)], w_sublead[PRE_CUT][pred_onshell_label.astype(bool)]], axis=0).sort_index()

# Kinematics of interesting variables (target for training)
int_kin = w_onshell[["px", "py", "pz", "E"]] / GEV
print("int_kin shape:", int_kin.shape)
int_kin = int_kin.to_numpy() # convert to numpy array
print(type(int_kin))
# Out:
# int_kin shape: (1378510, 4)
# <class 'numpy.ndarray'>

# %%
# Analyze the classifier for onshell and offshell W

base_acc = w_lead[w_lead["m"] > w_sublead["m"]].shape[0] / w_lead.shape[0]
cut_acc  = w_lead[(w_lead["m"] > w_sublead["m"]) & PRE_CUT].shape[0] / w_lead[PRE_CUT].shape[0]
print(f"Base accuracy: {base_acc:.2f}")
print(f"Cut  accuracy: {cut_acc:.2f}")
print(f">> Cuts improve: {100 * (cut_acc - base_acc):.2f}%")
ml_acc = np.sum(pred_onshell_label) / len(pred_onshell_label.astype(bool))
print(f"ML accuracy: {ml_acc:0.2f}")
print(f">> ML (base) improve: {100 * (ml_acc - base_acc):.2f}%")
print(f">> ML (cuts) improve: {100 * (ml_acc - cut_acc):.2f}%")


figure = plt.figure(figsize=(10, 6), dpi=120)
bin_edges = np.linspace(0, 110, 121)
plt.hist(w_lead["m"] / GEV, bins=bin_edges, color="r", histtype="step", density=True, label=r"Labeled   $W^{on}$")
plt.hist(w_sublead["m"] / GEV, bins=bin_edges, color="b", histtype="step", density=True, label=r"Labeled   $W^{off}$")
plt.hist(w_onshell["m"] / GEV, bins=bin_edges, color="tab:red", histtype="bar", density=True, alpha=0.3, label=r"Predicted $W^{on}$")
plt.hist(w_offshell["m"] / GEV, bins=bin_edges, color="tab:blue", histtype="bar", density=True, alpha=0.3, label=r"Predicted $W^{off}$")
plt.title("W mass")
plt.xlabel("mass [GeV]")
plt.ylabel("normalized count")
plt.legend(loc="best")
plt.show()
plt.close()
# Out:
# Base accuracy: 0.83
# Cut  accuracy: 0.81
# >> Cuts improve: -1.75%
# ML accuracy: 0.88
# >> ML (base) improve: 5.12%
# >> ML (cuts) improve: 6.88%

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.4,
    test_size=0.6,
    random_state=SEED,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=SEED
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# X (Interest)
# Training data shape: (551404, 26);
# Validing data shape: (413553, 26);
# Testing data shape: (413553, 26).
# Y (Observed)
# Training data shape: (551404, 4);
# Validing data shape: (413553, 4);
# Testing data shape: (413553, 4).

# %%
# Define a new activation function


def custom_activation(x):
    return (0.73 - (-0.27)) * (tf.tanh(x) + 1) / 2 + (-0.27)


class EPConstraint(tf.keras.constraints.Constraint):
    def __call__(self, w):
        # Ensure that energy-momentum are time-like case
        px = w[:, 0]
        py = w[:, 1]
        pz = w[:, 2]
        energy = w[:, 3]
        # Calculate the constraint
        constraint = tf.maximum(0.0, energy**2 - px**2 - py**2 - pz**2)
        # Create a mask for invalid four-vectors (constraint == 0)
        mask = tf.cast(tf.not_equal(constraint, 0.0), w.dtype)
        # If constraint is zero, set the entire four-vector to zero
        adjusted_w = w * tf.expand_dims(mask, axis=-1)
        return adjusted_w

# Register the custom activation and constraint
tf.keras.utils.get_custom_objects().update({
    'EPConstraint': EPConstraint,
})


# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    x = tf.keras.layers.Dense(units=256, activation="selu")(x)
    x = tf.keras.layers.Dense(units=256, activation="selu")(x)
    # x = tf.keras.layers.Dropout(rate=0.1)(x)
    for _ in range(3):
        x = tf.keras.layers.Dense(units=2048, activation="selu")(x)
        x = tf.keras.layers.Dropout(rate=0.3)(x)
        x = tf.keras.layers.Dense(units=2048, activation="selu")(x)
        x = tf.keras.layers.Dropout(rate=0.3)(x)
    x = tf.keras.layers.Dense(units=128, activation="selu")(x)
    x = tf.keras.layers.Dense(units=128, activation="selu")(x)

    outputs = tf.keras.layers.Dense(units=4, activation="linear", kernel_constraint=EPConstraint())(x)
    
    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss=tf.losses.mean_absolute_error,
    )

    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 26)]              0
#
#  flatten_1 (Flatten)         (None, 26)                0
#
#  dense_11 (Dense)            (None, 256)               6912
#
#  dense_12 (Dense)            (None, 256)               65792
#
#  dense_13 (Dense)            (None, 2048)              526336
#
#  dropout_6 (Dropout)         (None, 2048)              0
#
#  dense_14 (Dense)            (None, 2048)              4196352
#
#  dropout_7 (Dropout)         (None, 2048)              0
#
#  dense_15 (Dense)            (None, 2048)              4196352
#
#  dropout_8 (Dropout)         (None, 2048)              0
#
#  dense_16 (Dense)            (None, 2048)              4196352
#
#  dropout_9 (Dropout)         (None, 2048)              0
#
#  dense_17 (Dense)            (None, 2048)              4196352
#
#  dropout_10 (Dropout)        (None, 2048)              0
#
#  dense_18 (Dense)            (None, 2048)              4196352
#
#  dropout_11 (Dropout)        (None, 2048)              0
#
#  dense_19 (Dense)            (None, 128)               262272
#
#  dense_20 (Dense)            (None, 128)               16512
#
#  dense_21 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 21860100 (83.39 MB)
# Trainable params: 21860100 (83.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-3,
    patience=32,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)


def scheduler(epoch, lr):
    if epoch < 256:
        return lr
    else:
        return lr * tf.math.exp(-0.001)


lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

# Fit the model
history = model.fit(
    x=train_x,
    y=train_y,
    validation_data=(valid_x, valid_y),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=2,
    callbacks=[stop_early,lr_scheduler],
)
# Out:
# Epoch 1/1024
# 34/34 - 6s - loss: 96.7785 - val_loss: 77.8782 - lr: 1.0000e-04 - 6s/epoch - 190ms/step
# Epoch 2/1024
# 34/34 - 3s - loss: 61.6751 - val_loss: 46.8869 - lr: 1.0000e-04 - 3s/epoch - 78ms/step
# Epoch 3/1024
# 34/34 - 3s - loss: 44.2504 - val_loss: 38.9552 - lr: 1.0000e-04 - 3s/epoch - 78ms/step
# Epoch 4/1024
# 34/34 - 3s - loss: 39.1218 - val_loss: 37.0325 - lr: 1.0000e-04 - 3s/epoch - 78ms/step
# Epoch 5/1024
# 34/34 - 3s - loss: 38.0350 - val_loss: 36.4358 - lr: 1.0000e-04 - 3s/epoch - 78ms/step
# Epoch 6/1024
# 34/34 - 3s - loss: 37.6144 - val_loss: 36.2270 - lr: 1.0000e-04 - 3s/epoch - 78ms/step
# Epoch 7/1024
# 34/34 - 3s - loss: 37.3577 - val_loss: 36.0048 - lr: 1.0000e-04 - 3s/epoch - 78ms/step
# Epoch 8/1024
# 34/34 - 3s - loss: 37.1485 - val_loss: 35.9125 - lr: 1.0000e-04 - 3s/epoch - 78ms/step
# Epoch 9/1024
# 34/34 - 3s - loss: 37.0201 - val_loss: 35.8926 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 10/1024
# 34/34 - 3s - loss: 36.8757 - val_loss: 35.7947 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 11/1024
# 34/34 - 3s - loss: 36.7755 - val_loss: 35.6567 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 12/1024
# 34/34 - 3s - loss: 36.6716 - val_loss: 35.7132 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 13/1024
# 34/34 - 3s - loss: 36.6017 - val_loss: 35.5529 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 14/1024
# 34/34 - 3s - loss: 36.5392 - val_loss: 35.5272 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 15/1024
# 34/34 - 3s - loss: 36.5123 - val_loss: 35.5284 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 16/1024
# 34/34 - 3s - loss: 36.4584 - val_loss: 35.5024 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 17/1024
# 34/34 - 3s - loss: 36.3658 - val_loss: 35.4888 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 18/1024
# 34/34 - 3s - loss: 36.2966 - val_loss: 35.4132 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 19/1024
# 34/34 - 3s - loss: 36.2746 - val_loss: 35.5040 - lr: 1.0000e-04 - 3s/epoch - 78ms/step
# Epoch 20/1024
# 34/34 - 3s - loss: 36.2106 - val_loss: 35.3602 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 21/1024
# 34/34 - 3s - loss: 36.1874 - val_loss: 35.3395 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 22/1024
# 34/34 - 3s - loss: 36.1261 - val_loss: 35.2833 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 23/1024
# 34/34 - 3s - loss: 36.0835 - val_loss: 35.3227 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 24/1024
# 34/34 - 3s - loss: 36.0549 - val_loss: 35.2525 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 25/1024
# 34/34 - 3s - loss: 36.0572 - val_loss: 35.4806 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 26/1024
# 34/34 - 3s - loss: 36.0096 - val_loss: 35.2924 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 27/1024
# 34/34 - 3s - loss: 35.9867 - val_loss: 35.2284 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 28/1024
# 34/34 - 3s - loss: 35.9615 - val_loss: 35.2252 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 29/1024
# 34/34 - 3s - loss: 35.9074 - val_loss: 35.1918 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 30/1024
# 34/34 - 3s - loss: 35.9115 - val_loss: 35.2172 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 31/1024
# 34/34 - 3s - loss: 35.8695 - val_loss: 35.1721 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 32/1024
# 34/34 - 3s - loss: 35.8151 - val_loss: 35.1423 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 33/1024
# 34/34 - 3s - loss: 35.8357 - val_loss: 35.1010 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 34/1024
# 34/34 - 3s - loss: 35.8120 - val_loss: 35.1516 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 35/1024
# 34/34 - 3s - loss: 35.7893 - val_loss: 35.0517 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 36/1024
# 34/34 - 3s - loss: 35.7506 - val_loss: 35.0705 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 37/1024
# 34/34 - 3s - loss: 35.7262 - val_loss: 35.0270 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 38/1024
# 34/34 - 3s - loss: 35.6994 - val_loss: 35.1001 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 39/1024
# 34/34 - 3s - loss: 35.6917 - val_loss: 35.1222 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 40/1024
# 34/34 - 3s - loss: 35.7421 - val_loss: 35.0780 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 41/1024
# 34/34 - 3s - loss: 35.6737 - val_loss: 35.0303 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 42/1024
# 34/34 - 3s - loss: 35.6522 - val_loss: 34.9698 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 43/1024
# 34/34 - 3s - loss: 35.6423 - val_loss: 35.1066 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 44/1024
# 34/34 - 3s - loss: 35.6434 - val_loss: 34.9466 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 45/1024
# 34/34 - 3s - loss: 35.6022 - val_loss: 34.9725 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 46/1024
# 34/34 - 3s - loss: 35.5974 - val_loss: 35.0482 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 47/1024
# 34/34 - 3s - loss: 35.6234 - val_loss: 35.0322 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 48/1024
# 34/34 - 3s - loss: 35.5991 - val_loss: 35.0466 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 49/1024
# 34/34 - 3s - loss: 35.6025 - val_loss: 34.9256 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 50/1024
# 34/34 - 3s - loss: 35.5233 - val_loss: 35.0343 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 51/1024
# 34/34 - 3s - loss: 35.5239 - val_loss: 34.9423 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 52/1024
# 34/34 - 3s - loss: 35.4897 - val_loss: 34.9624 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 53/1024
# 34/34 - 3s - loss: 35.4930 - val_loss: 35.0525 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 54/1024
# 34/34 - 3s - loss: 35.4652 - val_loss: 34.9341 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 55/1024
# 34/34 - 3s - loss: 35.4488 - val_loss: 35.0208 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 56/1024
# 34/34 - 3s - loss: 35.4676 - val_loss: 34.9416 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 57/1024
# 34/34 - 3s - loss: 35.4401 - val_loss: 34.8094 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 58/1024
# 34/34 - 3s - loss: 35.4386 - val_loss: 34.8161 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 59/1024
# 34/34 - 3s - loss: 35.4112 - val_loss: 34.9012 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 60/1024
# 34/34 - 3s - loss: 35.3571 - val_loss: 34.8054 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 61/1024
# 34/34 - 3s - loss: 35.3597 - val_loss: 34.8440 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 62/1024
# 34/34 - 3s - loss: 35.3514 - val_loss: 34.8312 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 63/1024
# 34/34 - 3s - loss: 35.3515 - val_loss: 34.8234 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 64/1024
# 34/34 - 3s - loss: 35.3649 - val_loss: 34.9275 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 65/1024
# 34/34 - 3s - loss: 35.3559 - val_loss: 34.9006 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 66/1024
# 34/34 - 3s - loss: 35.3196 - val_loss: 34.7863 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 67/1024
# 34/34 - 3s - loss: 35.3279 - val_loss: 34.7719 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 68/1024
# 34/34 - 3s - loss: 35.3012 - val_loss: 34.8886 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 69/1024
# 34/34 - 3s - loss: 35.3164 - val_loss: 34.8366 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 70/1024
# 34/34 - 3s - loss: 35.3104 - val_loss: 34.7399 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 71/1024
# 34/34 - 3s - loss: 35.2540 - val_loss: 34.9723 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 72/1024
# 34/34 - 3s - loss: 35.3022 - val_loss: 34.9558 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 73/1024
# 34/34 - 3s - loss: 35.2594 - val_loss: 34.9221 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 74/1024
# 34/34 - 3s - loss: 35.2519 - val_loss: 34.7183 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 75/1024
# 34/34 - 3s - loss: 35.1973 - val_loss: 34.6758 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 76/1024
# 34/34 - 3s - loss: 35.1919 - val_loss: 34.6362 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 77/1024
# 34/34 - 3s - loss: 35.1902 - val_loss: 34.7585 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 78/1024
# 34/34 - 3s - loss: 35.2236 - val_loss: 34.7080 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 79/1024
# 34/34 - 3s - loss: 35.1796 - val_loss: 34.6332 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 80/1024
# 34/34 - 3s - loss: 35.1881 - val_loss: 34.6335 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 81/1024
# 34/34 - 3s - loss: 35.1910 - val_loss: 34.7446 - lr: 1.0000e-04 - 3s/epoch - 81ms/step
# Epoch 82/1024
# 34/34 - 3s - loss: 35.1381 - val_loss: 34.6766 - lr: 1.0000e-04 - 3s/epoch - 81ms/step
# Epoch 83/1024
# 34/34 - 3s - loss: 35.1157 - val_loss: 34.5902 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 84/1024
# 34/34 - 3s - loss: 35.1476 - val_loss: 34.6359 - lr: 1.0000e-04 - 3s/epoch - 81ms/step
# Epoch 85/1024
# 34/34 - 3s - loss: 35.1355 - val_loss: 34.5989 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 86/1024
# 34/34 - 3s - loss: 35.1272 - val_loss: 34.6488 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 87/1024
# 34/34 - 3s - loss: 35.1152 - val_loss: 34.6509 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 88/1024
# 34/34 - 3s - loss: 35.1012 - val_loss: 34.7242 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 89/1024
# 34/34 - 3s - loss: 35.0905 - val_loss: 34.6211 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 90/1024
# 34/34 - 3s - loss: 35.0639 - val_loss: 34.7007 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 91/1024
# 34/34 - 3s - loss: 35.0414 - val_loss: 34.5490 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 92/1024
# 34/34 - 3s - loss: 35.0349 - val_loss: 34.6725 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 93/1024
# 34/34 - 3s - loss: 35.0753 - val_loss: 34.6314 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 94/1024
# 34/34 - 3s - loss: 35.0050 - val_loss: 34.7474 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 95/1024
# 34/34 - 3s - loss: 35.0090 - val_loss: 34.5895 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 96/1024
# 34/34 - 3s - loss: 35.0128 - val_loss: 34.5606 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 97/1024
# 34/34 - 3s - loss: 35.5518 - val_loss: 50.8230 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 98/1024
# 34/34 - 3s - loss: 38.4262 - val_loss: 34.9065 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 99/1024
# 34/34 - 3s - loss: 35.1995 - val_loss: 34.5846 - lr: 1.0000e-04 - 3s/epoch - 81ms/step
# Epoch 100/1024
# 34/34 - 3s - loss: 35.1067 - val_loss: 34.4742 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 101/1024
# 34/34 - 3s - loss: 35.0535 - val_loss: 34.5437 - lr: 1.0000e-04 - 3s/epoch - 81ms/step
# Epoch 102/1024
# 34/34 - 3s - loss: 35.0112 - val_loss: 34.5286 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 103/1024
# 34/34 - 3s - loss: 34.9912 - val_loss: 34.5321 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 104/1024
# 34/34 - 3s - loss: 34.9931 - val_loss: 34.4346 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 105/1024
# 34/34 - 3s - loss: 34.9897 - val_loss: 34.5675 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 106/1024
# 34/34 - 3s - loss: 35.0030 - val_loss: 34.5103 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 107/1024
# 34/34 - 3s - loss: 34.9602 - val_loss: 34.5402 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 108/1024
# 34/34 - 3s - loss: 34.9530 - val_loss: 34.4249 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 109/1024
# 34/34 - 3s - loss: 34.9436 - val_loss: 34.4783 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 110/1024
# 34/34 - 3s - loss: 34.9142 - val_loss: 34.5205 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 111/1024
# 34/34 - 3s - loss: 34.9615 - val_loss: 34.5316 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 112/1024
# 34/34 - 3s - loss: 34.9316 - val_loss: 34.4118 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 113/1024
# 34/34 - 3s - loss: 34.8620 - val_loss: 34.3498 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 114/1024
# 34/34 - 3s - loss: 34.9450 - val_loss: 34.4141 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 115/1024
# 34/34 - 3s - loss: 34.8713 - val_loss: 34.4647 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 116/1024
# 34/34 - 3s - loss: 34.8711 - val_loss: 34.4074 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 117/1024
# 34/34 - 3s - loss: 34.8583 - val_loss: 34.4083 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 118/1024
# 34/34 - 3s - loss: 34.8948 - val_loss: 34.3602 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 119/1024
# 34/34 - 3s - loss: 34.8154 - val_loss: 34.3799 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 120/1024
# 34/34 - 3s - loss: 34.8487 - val_loss: 34.5182 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 121/1024
# 34/34 - 3s - loss: 34.8300 - val_loss: 34.5566 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 122/1024
# 34/34 - 3s - loss: 34.8265 - val_loss: 34.3958 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 123/1024
# 34/34 - 3s - loss: 34.7832 - val_loss: 34.3853 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 124/1024
# 34/34 - 3s - loss: 34.7716 - val_loss: 34.3752 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 125/1024
# 34/34 - 3s - loss: 34.7894 - val_loss: 34.4268 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 126/1024
# 34/34 - 3s - loss: 34.7737 - val_loss: 34.4013 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 127/1024
# 34/34 - 3s - loss: 34.7719 - val_loss: 34.3318 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 128/1024
# 34/34 - 3s - loss: 34.8163 - val_loss: 34.3678 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 129/1024
# 34/34 - 3s - loss: 34.7909 - val_loss: 34.3227 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 130/1024
# 34/34 - 3s - loss: 34.7394 - val_loss: 34.2707 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 131/1024
# 34/34 - 3s - loss: 34.7899 - val_loss: 34.3698 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 132/1024
# 34/34 - 3s - loss: 34.7468 - val_loss: 34.4809 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 133/1024
# 34/34 - 3s - loss: 34.7325 - val_loss: 34.3540 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 134/1024
# 34/34 - 3s - loss: 34.7415 - val_loss: 34.3443 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 135/1024
# 34/34 - 3s - loss: 34.7570 - val_loss: 34.4035 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 136/1024
# 34/34 - 3s - loss: 34.7327 - val_loss: 34.4538 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 137/1024
# 34/34 - 3s - loss: 34.7327 - val_loss: 34.2963 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 138/1024
# 34/34 - 3s - loss: 34.7039 - val_loss: 34.2888 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 139/1024
# 34/34 - 3s - loss: 34.6898 - val_loss: 34.2984 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 140/1024
# 34/34 - 3s - loss: 34.6624 - val_loss: 34.3172 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 141/1024
# 34/34 - 3s - loss: 34.6866 - val_loss: 34.2991 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 142/1024
# 34/34 - 3s - loss: 34.6465 - val_loss: 34.2438 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 143/1024
# 34/34 - 3s - loss: 34.6489 - val_loss: 34.3783 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 144/1024
# 34/34 - 3s - loss: 34.6375 - val_loss: 34.2623 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 145/1024
# 34/34 - 3s - loss: 34.6572 - val_loss: 34.3578 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 146/1024
# 34/34 - 3s - loss: 34.6186 - val_loss: 34.2218 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 147/1024
# 34/34 - 3s - loss: 34.6430 - val_loss: 34.2213 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 148/1024
# 34/34 - 3s - loss: 34.6469 - val_loss: 34.2639 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 149/1024
# 34/34 - 3s - loss: 34.6263 - val_loss: 34.2383 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 150/1024
# 34/34 - 3s - loss: 34.6165 - val_loss: 34.2719 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 151/1024
# 34/34 - 3s - loss: 34.6125 - val_loss: 34.2529 - lr: 1.0000e-04 - 3s/epoch - 81ms/step
# Epoch 152/1024
# 34/34 - 3s - loss: 34.6307 - val_loss: 34.4828 - lr: 1.0000e-04 - 3s/epoch - 81ms/step
# Epoch 153/1024
# 34/34 - 3s - loss: 34.6017 - val_loss: 34.2793 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 154/1024
# 34/34 - 3s - loss: 34.6306 - val_loss: 34.4016 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 155/1024
# 34/34 - 3s - loss: 34.5969 - val_loss: 34.1686 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 156/1024
# 34/34 - 3s - loss: 34.5492 - val_loss: 34.1760 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 157/1024
# 34/34 - 3s - loss: 34.5482 - val_loss: 34.2386 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 158/1024
# 34/34 - 3s - loss: 34.5414 - val_loss: 34.2246 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 159/1024
# 34/34 - 3s - loss: 34.5534 - val_loss: 34.2064 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 160/1024
# 34/34 - 3s - loss: 34.5307 - val_loss: 34.2000 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 161/1024
# 34/34 - 3s - loss: 34.5441 - val_loss: 34.1702 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 162/1024
# 34/34 - 3s - loss: 34.5546 - val_loss: 34.2344 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 163/1024
# 34/34 - 3s - loss: 34.5675 - val_loss: 34.2985 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 164/1024
# 34/34 - 3s - loss: 34.5770 - val_loss: 34.2804 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 165/1024
# 34/34 - 3s - loss: 34.5566 - val_loss: 34.2944 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 166/1024
# 34/34 - 3s - loss: 34.5322 - val_loss: 34.1028 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 167/1024
# 34/34 - 3s - loss: 34.5033 - val_loss: 34.1704 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 168/1024
# 34/34 - 3s - loss: 34.5232 - val_loss: 34.1286 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 169/1024
# 34/34 - 3s - loss: 34.4819 - val_loss: 34.1924 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 170/1024
# 34/34 - 3s - loss: 34.4877 - val_loss: 34.1663 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 171/1024
# 34/34 - 3s - loss: 34.5095 - val_loss: 34.1395 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 172/1024
# 34/34 - 3s - loss: 34.5200 - val_loss: 34.1656 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 173/1024
# 34/34 - 3s - loss: 34.5258 - val_loss: 34.0637 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 174/1024
# 34/34 - 3s - loss: 34.4894 - val_loss: 34.1315 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 175/1024
# 34/34 - 3s - loss: 34.4645 - val_loss: 34.0789 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 176/1024
# 34/34 - 3s - loss: 34.4277 - val_loss: 34.2145 - lr: 1.0000e-04 - 3s/epoch - 81ms/step
# Epoch 177/1024
# 34/34 - 3s - loss: 34.4403 - val_loss: 34.0712 - lr: 1.0000e-04 - 3s/epoch - 81ms/step
# Epoch 178/1024
# 34/34 - 3s - loss: 34.4439 - val_loss: 34.1367 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 179/1024
# 34/34 - 3s - loss: 34.4231 - val_loss: 34.1284 - lr: 1.0000e-04 - 3s/epoch - 81ms/step
# Epoch 180/1024
# 34/34 - 3s - loss: 34.4302 - val_loss: 34.2050 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 181/1024
# 34/34 - 3s - loss: 34.4177 - val_loss: 34.1005 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 182/1024
# 34/34 - 3s - loss: 34.4276 - val_loss: 34.1838 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 183/1024
# 34/34 - 3s - loss: 34.4572 - val_loss: 34.0801 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 184/1024
# 34/34 - 3s - loss: 34.4271 - val_loss: 34.2095 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 185/1024
# 34/34 - 3s - loss: 34.3680 - val_loss: 34.0432 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 186/1024
# 34/34 - 3s - loss: 34.3536 - val_loss: 34.0938 - lr: 1.0000e-04 - 3s/epoch - 81ms/step
# Epoch 187/1024
# 34/34 - 3s - loss: 34.3664 - val_loss: 34.0915 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 188/1024
# 34/34 - 3s - loss: 34.3786 - val_loss: 34.0142 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 189/1024
# 34/34 - 3s - loss: 34.3431 - val_loss: 34.0736 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 190/1024
# 34/34 - 3s - loss: 34.3801 - val_loss: 34.0457 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 191/1024
# 34/34 - 3s - loss: 34.3683 - val_loss: 34.0961 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 192/1024
# 34/34 - 3s - loss: 34.3703 - val_loss: 34.0423 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 193/1024
# 34/34 - 3s - loss: 34.3522 - val_loss: 34.0840 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 194/1024
# 34/34 - 3s - loss: 35.2654 - val_loss: 36.1824 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 195/1024
# 34/34 - 3s - loss: 35.1672 - val_loss: 34.1431 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 196/1024
# 34/34 - 3s - loss: 34.3910 - val_loss: 34.0925 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 197/1024
# 34/34 - 3s - loss: 34.3436 - val_loss: 33.9588 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 198/1024
# 34/34 - 3s - loss: 34.3365 - val_loss: 34.0750 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 199/1024
# 34/34 - 3s - loss: 34.3158 - val_loss: 34.0481 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 200/1024
# 34/34 - 3s - loss: 34.3242 - val_loss: 33.9983 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 201/1024
# 34/34 - 3s - loss: 34.3147 - val_loss: 34.0858 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 202/1024
# 34/34 - 3s - loss: 34.2836 - val_loss: 33.9819 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 203/1024
# 34/34 - 3s - loss: 34.3101 - val_loss: 34.0770 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 204/1024
# 34/34 - 3s - loss: 34.2996 - val_loss: 34.0089 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 205/1024
# 34/34 - 3s - loss: 34.2742 - val_loss: 34.0744 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 206/1024
# 34/34 - 3s - loss: 34.2993 - val_loss: 33.9819 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 207/1024
# 34/34 - 3s - loss: 34.2832 - val_loss: 34.0001 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 208/1024
# 34/34 - 3s - loss: 34.2803 - val_loss: 33.9891 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 209/1024
# 34/34 - 3s - loss: 34.2795 - val_loss: 33.9678 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 210/1024
# 34/34 - 3s - loss: 34.2797 - val_loss: 33.9467 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 211/1024
# 34/34 - 3s - loss: 34.2543 - val_loss: 33.9396 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 212/1024
# 34/34 - 3s - loss: 34.2396 - val_loss: 33.9903 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 213/1024
# 34/34 - 3s - loss: 34.3017 - val_loss: 33.9054 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 214/1024
# 34/34 - 3s - loss: 34.2364 - val_loss: 33.9403 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 215/1024
# 34/34 - 3s - loss: 34.2395 - val_loss: 34.1015 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 216/1024
# 34/34 - 3s - loss: 34.2622 - val_loss: 34.0169 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 217/1024
# 34/34 - 3s - loss: 34.1935 - val_loss: 34.0135 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 218/1024
# 34/34 - 3s - loss: 34.2286 - val_loss: 34.1769 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 219/1024
# 34/34 - 3s - loss: 34.2362 - val_loss: 33.9466 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 220/1024
# 34/34 - 3s - loss: 34.1959 - val_loss: 33.9491 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 221/1024
# 34/34 - 3s - loss: 34.2285 - val_loss: 34.1158 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 222/1024
# 34/34 - 3s - loss: 34.2105 - val_loss: 34.0506 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 223/1024
# 34/34 - 3s - loss: 34.1756 - val_loss: 34.0295 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 224/1024
# 34/34 - 3s - loss: 34.2293 - val_loss: 34.0193 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 225/1024
# 34/34 - 3s - loss: 34.2077 - val_loss: 33.9177 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 226/1024
# 34/34 - 3s - loss: 34.1662 - val_loss: 33.8859 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 227/1024
# 34/34 - 3s - loss: 34.1946 - val_loss: 33.8663 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 228/1024
# 34/34 - 3s - loss: 34.1520 - val_loss: 33.8619 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 229/1024
# 34/34 - 3s - loss: 34.1797 - val_loss: 33.9396 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 230/1024
# 34/34 - 3s - loss: 34.1556 - val_loss: 33.8929 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 231/1024
# 34/34 - 3s - loss: 34.1495 - val_loss: 33.9579 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 232/1024
# 34/34 - 3s - loss: 34.1318 - val_loss: 33.9228 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 233/1024
# 34/34 - 3s - loss: 34.1526 - val_loss: 33.9270 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 234/1024
# 34/34 - 3s - loss: 34.1660 - val_loss: 34.0397 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 235/1024
# 34/34 - 3s - loss: 34.1536 - val_loss: 33.8730 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 236/1024
# 34/34 - 3s - loss: 34.1260 - val_loss: 33.9667 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 237/1024
# 34/34 - 3s - loss: 34.1430 - val_loss: 33.9866 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 238/1024
# 34/34 - 3s - loss: 34.1171 - val_loss: 33.9488 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 239/1024
# 34/34 - 3s - loss: 34.1217 - val_loss: 33.9364 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 240/1024
# 34/34 - 3s - loss: 34.1330 - val_loss: 33.8687 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 241/1024
# 34/34 - 3s - loss: 34.1477 - val_loss: 34.0097 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 242/1024
# 34/34 - 3s - loss: 34.1613 - val_loss: 33.9573 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 243/1024
# 34/34 - 3s - loss: 34.1401 - val_loss: 33.9488 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 244/1024
# 34/34 - 3s - loss: 34.0811 - val_loss: 33.8830 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 245/1024
# 34/34 - 3s - loss: 34.1205 - val_loss: 33.8951 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 246/1024
# 34/34 - 3s - loss: 34.0953 - val_loss: 33.8992 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 247/1024
# 34/34 - 3s - loss: 34.0910 - val_loss: 33.8799 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 248/1024
# 34/34 - 3s - loss: 34.0455 - val_loss: 33.9388 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 249/1024
# 34/34 - 3s - loss: 34.0712 - val_loss: 33.9496 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 250/1024
# 34/34 - 3s - loss: 34.0520 - val_loss: 33.9003 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 251/1024
# 34/34 - 3s - loss: 34.1196 - val_loss: 34.0044 - lr: 1.0000e-04 - 3s/epoch - 79ms/step
# Epoch 252/1024
# 34/34 - 3s - loss: 34.1061 - val_loss: 33.9001 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 253/1024
# 34/34 - 3s - loss: 34.0744 - val_loss: 33.9440 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 254/1024
# 34/34 - 3s - loss: 34.0745 - val_loss: 33.8977 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 255/1024
# 34/34 - 3s - loss: 34.0851 - val_loss: 33.9332 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 256/1024
# 34/34 - 3s - loss: 34.0300 - val_loss: 33.8742 - lr: 1.0000e-04 - 3s/epoch - 80ms/step
# Epoch 257/1024
# 34/34 - 3s - loss: 34.0105 - val_loss: 33.9073 - lr: 9.9900e-05 - 3s/epoch - 80ms/step
# Epoch 258/1024
# 34/34 - 3s - loss: 34.0654 - val_loss: 33.8895 - lr: 9.9800e-05 - 3s/epoch - 81ms/step
# Epoch 259/1024
# 34/34 - 3s - loss: 34.0828 - val_loss: 33.8951 - lr: 9.9700e-05 - 3s/epoch - 80ms/step
# Epoch 260/1024
# 34/34 - 3s - loss: 34.0341 - val_loss: 33.9055 - lr: 9.9601e-05 - 3s/epoch - 80ms/step

# %%
# Make a directory
dir_name = HOME_PATH + "/5th_trial/w_lead_result/"
name = "dnn_w_onshell"

# If the directory exists
if os.path.exists(dir_name):
    test_files = glob.glob(dir_name + "*" + name + "*")
    if test_files:
        for file in test_files:
            os.remove(file)
        print(f"Directory {dir_name} cleaned.")
    print(f"Directory {dir_name} exists.")
else:
    os.makedirs(dir_name)
    print(f"Directory {dir_name} created.")

# save model
model.save(dir_name + name + ".keras", save_format="keras", overwrite=True)

# predict
pred_y = model.predict(test_x)
# save predicted results
np.savez_compressed(dir_name + name + "_data.npz", pred_y=pred_y, test_y=test_y)
sig_pred = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth = np.load(dir_name + name + "_data.npz")["test_y"]
# Out:
# Directory /root/work/QE-mls/5th_trial/w_lead_result/ cleaned.
# Directory /root/work/QE-mls/5th_trial/w_lead_result/ exists.
# 12924/12924 [==============================] - 23s 2ms/step

# %%
plot.plot_loss_history(history, logx=False, logy=False, loss_name="MAE")

# %%
# name the file
name = "dnn_w_onshell"

# save predicted results
np.savez_compressed(
    dir_name + name + "_data.npz", pred_y=sig_pred.reshape(sig_truth.shape), test_y=sig_truth
)
sig_pred_inv = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth_inv = np.load(dir_name + name + "_data.npz")["test_y"]

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,0]):.3f}, std: {np.std(sig_truth_inv[:,0]):.3f}, min: {np.min(sig_truth_inv[:,0]):.3f}, max: {np.max(sig_truth_inv[:,0]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 0], sig_pred_inv[:, 0]],
    label=r"$p_{x}^{W}$",
    title="On-shell $p_{x}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,0], sig_pred_inv[:,0])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 0],
    sig_pred_inv[:, 0],
    r"On-shell $p_{x}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,0], sig_pred_inv[:,0])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.027, std: 36.419, min: -574.491, max: 857.240

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,1]):.3f}, std: {np.std(sig_truth_inv[:,1]):.3f}, min: {np.min(sig_truth_inv[:,1]):.3f}, max: {np.max(sig_truth_inv[:,1]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 1], sig_pred_inv[:, 1]],
    label=r"$p_{y}^{W}$",
    title="On-shell $p_{y}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,1], sig_pred_inv[:,1])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 1],
    sig_pred_inv[:, 1],
    r"On-shell $p_{y}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,1], sig_pred_inv[:,1])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.029, std: 36.276, min: -620.586, max: 573.168

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,2]):.3f}, std: {np.std(sig_truth_inv[:,2]):.3f}, min: {np.min(sig_truth_inv[:,2]):.3f}, max: {np.max(sig_truth_inv[:,2]):.3f}"
)

set_range = [-1200, 1200]

plot.hist(
    data=[sig_truth_inv[:, 2], sig_pred_inv[:, 2]],
    label=r"$p_{z}^{W}$",
    title="On-shell $p_{z}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,2], sig_pred_inv[:,2])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 2],
    sig_pred_inv[:, 2],
    r"On-shell $p_{z}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,2], sig_pred_inv[:,2])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 1.032, std: 323.502, min: -3473.245, max: 3477.602

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,3]):.3f}, std: {np.std(sig_truth_inv[:,3]):.3f}, min: {np.min(sig_truth_inv[:,3]):.3f}, max: {np.max(sig_truth_inv[:,3]):.3f}"
)

set_range = [0, 1800]

plot.hist(
    data=[sig_truth_inv[:,3], sig_pred_inv[:,3]],
    label=r"$E^{W}$",
    title="On-shell $E^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,3], sig_pred_inv[:,3])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:,3],
    sig_pred_inv[:,3],
    r"On-shell $E^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,3], sig_pred_inv[:,3])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 231.850, std: 243.034, min: 19.373, max: 3478.761

# %%
truth_time_like = np.square(sig_pred_inv[:, 3]) - np.sum(
    np.square(sig_pred_inv[:, 0:-1]), axis=1
)
truth_time_mask = truth_time_like >= 0
plt.hist(truth_time_like, bins=120, fill=True)
plt.title(f"Total-like W mass with {len(truth_time_like)}")
plt.show()
plt.hist(truth_time_like[truth_time_mask], bins=120, fill=True)
plt.title(f"Time-like W mass with {len(truth_time_like[truth_time_mask])}")
plt.show()

# %%
import shap
import matplotlib as mpl

mpl.rcParams.update(mpl.rcParamsDefault)

feature_names = [
    "lead_px",
    "lead_py",
    "lead_pz",
    "lead_E",
    "lead_pt",
    "lead_eta",
    "lead_phi",
    "sublead_px",
    "sublead_py",
    "sublead_pz",
    "sublead_E",
    "sublead_pt",
    "sublead_eta",
    "sublead_phi",
    "met_px",
    "met_py",
    "met_pt",
    "met_phi",
    "dilep_px",
    "dilep_py",
    "dilep_pz",
    "dilep_E",
    "dilep_pt",
    "dilep_eta",
    "dilep_phi",
    "dilep_m",
]
title_name = ["px", "py", "pz", "E"]
# lead
# Use DeepExplainer for SHAP values
explainer = shap.DeepExplainer(model, obs_kin[:1024])
shap_values = explainer.shap_values(obs_kin[:1024], check_additivity=False)
for i in range(shap_values.shape[-1]):
    plt.figure(figsize=(10, 6))
    shap.summary_plot(
        shap_values[:, :, i],
        obs_kin[:1024],
        feature_names=feature_names,
        plot_type="dot",
        show=False,
    )
    plt.title(f"SHAP Summary Plot for On-shell Regression Output: {title_name[i]}")
    plt.show()
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
