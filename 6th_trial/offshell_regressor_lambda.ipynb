# %%
# %reset -sf

import tensorflow as tf
print(tf.__version__)


# GPU(s) setups
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[1], 'GPU')
        
        # Instead of enabling memory growth, set a memory limit
        memory_limit = 16_384*2 # Set the memory limit in MB
        # tf.config.experimental.set_virtual_device_configuration(
        #     gpus[1],
        #     [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]
        # )
        
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2024-08-19 18:32:56.838541: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.13.0
# 2 Physical GPUs, 1 Logical GPU
# 2024-08-19 18:32:59.169899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46252 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:25:00.0, compute capability: 8.6

# %%
import sys
import os
import glob
HOME_PATH = os.path.abspath("..")
sys.path.insert(0, HOME_PATH+"/qe")

import get_data as gd
import atlas_plot as ap
plot = ap.Plotter()

# INN packages
from flow import *
from utils import *

import pandas as pd
import numpy as np
import scipy as sp

from matplotlib import pyplot as plt
import matplotlib as mpl
import shap

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
SEED = 42  # set random seed (global variable)
np.random.seed(SEED)
processor = gd.DataProcessor()
path = "/root/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 76
#
# ['/root/data/truth/signal/CGLMP.npz', '/root/data/truth/signal/Higgs.npz', '/root/data/truth/signal/LeadLepton.npz', '/root/data/truth/signal/LeptonM.npz', '/root/data/truth/signal/LeptonP.npz', '/root/data/truth/signal/LmNu.npz', '/root/data/truth/signal/LpNu.npz', '/root/data/truth/signal/MET.npz', '/root/data/truth/signal/WmBoson.npz', '/root/data/truth/signal/WpBoson.npz', '/root/data/truth/signal/diLepton.npz', '/root/data/truth/signal/subLeadLepton.npz', '/root/data/truth/signal/xi_xyz.npz']

# %%
## Global variables

GEV = 1e3

cut_pre_pt_lead = data.LeadLep["pt"] > 22 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
cut_pre_pt_miss = data.MET["pt"] > 20 * GEV

PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# %%
## Observing variables

lead_lep = data.LeadLep[["px", "py", "pz", "E", "pt", "eta", "phi"]]
sublead_lep = data.SubLep[["px", "py", "pz", "E", "pt", "eta", "phi"]]
met = data.MET[["px", "py", "pt", "phi"]]

# Kinematics of observing variables (inputs for training)
obs_kin = pd.concat([lead_lep, sublead_lep, met], axis=1)[PRE_CUT] / GEV
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array
ROBUST_OBS = RobustScaler()
obs_kin = ROBUST_OBS.fit_transform(obs_kin)
print(type(obs_kin))
# Out:
# int_kin shape: (1378510, 18)
# <class 'numpy.ndarray'>

# %%
cla = tf.keras.models.load_model('./classifier/shell_classifier.keras')
cla.summary()
pred_onshell_label = cla.predict(obs_kin)
pred_onshell_label = np.squeeze(np.where(pred_onshell_label >= 0.5, 1, 0))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 18)]              0
#
#  flatten (Flatten)           (None, 18)                0
#
#  dense (Dense)               (None, 128)               2432
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 503681 (1.92 MB)
# Trainable params: 503681 (1.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#   112/43079 [..............................] - ETA: 58s
# 2024-08-19 18:33:09.733737: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 43079/43079 [==============================] - 56s 1ms/step

# %%
## Interesting variables

# Critria for leading and subleading lepton
lead_p = data.LeadLep["m"] == data.LepP["m"]
sublead_p = ~lead_p
lead_m = sublead_p.copy()
sublead_m = lead_p.copy()

# (sub)lead W
w_lead = pd.concat([data.Wp[lead_p], data.Wm[lead_m]], axis=0).sort_index()
w_sublead = pd.concat([data.Wp[sublead_p], data.Wm[sublead_m]], axis=0).sort_index()
w_onshell = pd.concat([w_lead[PRE_CUT][pred_onshell_label.astype(bool)], w_sublead[PRE_CUT][~pred_onshell_label.astype(bool)]], axis=0).sort_index()
w_offshell = pd.concat([w_lead[PRE_CUT][~pred_onshell_label.astype(bool)], w_sublead[PRE_CUT][pred_onshell_label.astype(bool)]], axis=0).sort_index()

# Kinematics of interesting variables (target for training)
int_kin = w_offshell[["px", "py", "pz", "E"]] / GEV
print("int_kin shape:", int_kin.shape)
int_kin = int_kin.to_numpy() # convert to numpy array
print(type(int_kin))
# Out:
# int_kin shape: (1378510, 4)
# <class 'numpy.ndarray'>

# %%
# Analyze the classifier for onshell and offshell W

base_acc = w_lead[w_lead["m"] > w_sublead["m"]].shape[0] / w_lead.shape[0]
cut_acc  = w_lead[(w_lead["m"] > w_sublead["m"]) & PRE_CUT].shape[0] / w_lead[PRE_CUT].shape[0]
print(f"Base accuracy: {base_acc:.2f}")
print(f"Cut  accuracy: {cut_acc:.2f}")
print(f">> Cuts improve: {100 * (cut_acc - base_acc):.2f}%")
ml_acc = np.sum(pred_onshell_label) / len(pred_onshell_label.astype(bool))
print(f"ML accuracy: {ml_acc:0.2f}")
print(f">> ML (base) improve: {100 * (ml_acc - base_acc):.2f}%")
print(f">> ML (cuts) improve: {100 * (ml_acc - cut_acc):.2f}%")


figure = plt.figure(figsize=(10, 6), dpi=120)
bin_edges = np.linspace(0, 110, 121)
plt.hist(w_lead["m"] / GEV, bins=bin_edges, color="r", histtype="step", density=True, label=r"Labeled   $W^{on}$")
plt.hist(w_sublead["m"] / GEV, bins=bin_edges, color="b", histtype="step", density=True, label=r"Labeled   $W^{off}$")
plt.hist(w_onshell["m"] / GEV, bins=bin_edges, color="tab:red", histtype="bar", density=True, alpha=0.3, label=r"Predicted $W^{on}$")
plt.hist(w_offshell["m"] / GEV, bins=bin_edges, color="tab:blue", histtype="bar", density=True, alpha=0.3, label=r"Predicted $W^{off}$")
plt.title("W mass")
plt.xlabel("mass [GeV]")
plt.ylabel("normalized count")
plt.legend(loc="best")
plt.show()
plt.close()
# Out:
# Base accuracy: 0.83
# Cut  accuracy: 0.81
# >> Cuts improve: -1.75%
# ML accuracy: 0.88
# >> ML (base) improve: 4.66%
# >> ML (cuts) improve: 6.41%

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.4,
    test_size=0.6,
    random_state=SEED,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=SEED
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# X (Interest)
# Training data shape: (551404, 18);
# Validing data shape: (413553, 18);
# Testing data shape: (413553, 18).
# Y (Observed)
# Training data shape: (551404, 4);
# Validing data shape: (413553, 4);
# Testing data shape: (413553, 4).

# %%
@tf.function
def force_timelike(x):
    x = tf.cast(x, tf.float64)  # Cast input to float64 for higher precision
    px, py, pz, energy = x[:, 0], x[:, 1], x[:, 2], x[:, 3]
    condition = tf.greater_equal(energy**2, px**2 + py**2 + pz**2)

    valid_sets = tf.where(condition[:, tf.newaxis], x, tf.zeros_like(x))
    tf.print("valid_set\n", valid_sets) 
    nearest_valid_indices = tf.cast(tf.where(condition)[:, 0], tf.int32)
    nearest_valid_rows = tf.gather(valid_sets, nearest_valid_indices)
    tf.print("nearst_valid_row\n", nearest_valid_rows)
    range_tensor = tf.range(tf.shape(x)[0], dtype=tf.int32)
    tf.print("range_tensor\n", range_tensor)
    padded_result = tf.where(condition[:, tf.newaxis], valid_sets, 
                            tf.gather(
                                    nearest_valid_rows, 
                                    tf.argmin(
                                        tf.abs(tf.cast(range_tensor, tf.int32)[:, tf.newaxis] - nearest_valid_indices), 
                                        axis=1
                                        )
                                    )
                            )
    tf.print("range tensor\n",  tf.cast(range_tensor, tf.int32)[:, tf.newaxis])
    tf.print("nearest_valid_indices\n", nearest_valid_indices)
    tf.print("check (distance)\n", tf.abs(tf.cast(range_tensor, tf.int32)[:, tf.newaxis] - nearest_valid_indices))
    tf.print("argmin (nearest index)\n", 
            tf.argmin(
                    tf.abs(tf.cast(range_tensor, tf.int32)[:, tf.newaxis] - nearest_valid_indices), 
                    axis=1
                    )
            )
    return tf.cast(padded_result, tf.float64)  # Cast result back to float64 if needed

# Mini test code
x = tf.constant([
    [100, 2, 2, 2],  # space-like
    [-1, 2, 1, 10],  # time-like
    [-2, 2, 1, 10],  # time-like
    [100, 2, 2, 2],  # space-like
    [-3, 2, 3, 11],  # time-like
    # [1, 20000, 5, 12],  # space-like :: pressure test
    [-4, 2, 4, 100000],  # time-like :: pressure test
    # [1, 20000, 5, 12],  # space-like :: pressure test
], dtype=tf.float64)

result = force_timelike(x)
print("Modified result", result)
# Out:
# valid_set
#  [[0 0 0 0]
#  [-1 2 1 10]
#  [-2 2 1 10]
#  [0 0 0 0]
#  [-3 2 3 11]
#  [-4 2 4 100000]]
# nearst_valid_row
#  [[-1 2 1 10]
#  [-2 2 1 10]
#  [-3 2 3 11]
#  [-4 2 4 100000]]
# range_tensor
#  [0 1 2 3 4 5]
# range tensor
#  [[0]
#  [1]
#  [2]
#  [3]
#  [4]
#  [5]]
# nearest_valid_indices
#  [1 2 4 5]
# check (distance)
#  [[1 2 4 5]
#  [0 1 3 4]
#  [1 0 2 3]
#  [2 1 1 2]
#  [3 2 0 1]
#  [4 3 1 0]]
# argmin (nearest index)
#  [0 0 1 1 2 3]
# Modified result tf.Tensor(
# [[-1.0e+00  2.0e+00  1.0e+00  1.0e+01]
#  [-1.0e+00  2.0e+00  1.0e+00  1.0e+01]
#  [-2.0e+00  2.0e+00  1.0e+00  1.0e+01]
#  [-2.0e+00  2.0e+00  1.0e+00  1.0e+01]
#  [-3.0e+00  2.0e+00  3.0e+00  1.1e+01]
#  [-4.0e+00  2.0e+00  4.0e+00  1.0e+05]], shape=(6, 4), dtype=float64)

# %%
EPOCHS = 1_024
LEARNING_RATE = 3e-5
BATCH_SIZE = 8192

# Define a new activation function
def custom_activation(x):
    return (0.73 - (-0.27)) * (tf.tanh(x) + 1) / 2 + (-0.27)


# TODO: create a custom constraint to force the "weight" of four-vectors to be time-like
class EPConstraint(tf.keras.constraints.Constraint):
    def __call__(self, w):
        # Ensure that energy-momentum are time-like case
        px = w[:, 0]
        py = w[:, 1]
        pz = w[:, 2]
        energy = w[:, 3]
        # Calculate the constraint
        constraint = tf.maximum(0.0, energy**2 - px**2 - py**2 - pz**2)
        # Create a mask for invalid four-vectors (constraint == 0)
        mask = tf.cast(tf.not_equal(constraint, 0.0), w.dtype)
        # If constraint is zero, set the entire four-vector to zero
        adjusted_w = w * tf.expand_dims(mask, axis=-1)
        return adjusted_w

# TODO: create a lanbda layer to force the four-vector to be time-like
@tf.function
def force_timelike(x):
    x = tf.cast(x, tf.float64)  # Cast input to float64 for higher precision
    px, py, pz, energy = x[:, 0], x[:, 1], x[:, 2], x[:, 3]
    condition = tf.greater_equal(energy**2, px**2 + py**2 + pz**2)

    valid_sets = tf.where(condition[:, tf.newaxis], x, tf.zeros_like(x)) 
    nearest_valid_indices = tf.cast(tf.where(condition)[:, 0], tf.int32)
    nearest_valid_rows = tf.gather(valid_sets, nearest_valid_indices)
    range_tensor = tf.range(tf.shape(x)[0], dtype=tf.int32)
    padded_result = tf.where(condition[:, tf.newaxis], valid_sets, 
                            tf.gather(
                                    nearest_valid_rows, 
                                    tf.argmin(
                                        tf.abs(tf.cast(range_tensor, tf.int32)[:, tf.newaxis] - nearest_valid_indices), 
                                        axis=1
                                        )
                                    )
                            )
    return tf.cast(padded_result, tf.float64)  # Cast result back to float64 if needed



# Register the custom activation and constraint
tf.keras.utils.get_custom_objects().update({
    'EPConstraint': EPConstraint,
})


# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    # y = tf.keras.layers.Dense(units=4, activation="linear", kernel_constraint=EPConstraint())(x)
    for _ in range(1):
        # y = tf.ker2s.layers.Dense(units=4, activation="linear", kernel_constraint=EPConstraint())(y)
        x = tf.keras.layers.Dense(units=256, activation="selu")(x)
        # x = tf.keras.layers.Dropout(rate=0.1)(x)
        x = tf.keras.layers.Dense(units=512, activation="selu")(x)
    # x = tf.keras.layers.Concatenate()([x, y])
    for _ in range(3):
        x = tf.keras.layers.Dense(units=2048, activation="selu")(x)
        # x = tf.keras.layers.Dropout(rate=0.4)(x)
        x = tf.keras.layers.Dense(units=1024, activation="selu")(x)
        x = tf.keras.layers.Dropout(rate=0.2)(x)
    # x = tf.keras.layers.Dropout(rate=0.2)(x)
        # x = tf.keras.layers.Dense(units=4, activation="linear", kernel_constraint=EPConstraint())(x)
    for _ in range(1):
        # y = tf.keras.layers.Dense(units=4, activation="linear", kernel_constraint=EPConstraint())(x)
        x = tf.keras.layers.Dense(units=128, activation="selu")(x)
        # x = tf.keras.layers.Dropout(rate=0.1)(x)
        x = tf.keras.layers.Dense(units=64, activation="linear")(x)
    # x = tf.keras.layers.Concatenate()([x, y])
    
    # x = tf.keras.layers.Dense(units=128, activation="selu")(x)
    # x = tf.keras.layers.Dense(units=128, activation="selu")(x)
    # x = tf.keras.layers.Dense(units=4, activation="linear", kernel_constraint=EPConstraint())(x)
    x = tf.keras.layers.Dense(units=16, activation="linear")(x)
    x = tf.keras.layers.Dense(units=4, activation="linear")(x)
    outputs = tf.keras.layers.Lambda(force_timelike)(x)
    
    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss=tf.losses.mean_absolute_error,
    )

    return model

# %%
model = build_model()
model.summary()
# tf.keras.utils.plot_model(model)
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 18)]              0
#
#  flatten_7 (Flatten)         (None, 18)                0
#
#  dense_110 (Dense)           (None, 256)               4864
#
#  dense_111 (Dense)           (None, 512)               131584
#
#  dense_112 (Dense)           (None, 2048)              1050624
#
#  dense_113 (Dense)           (None, 1024)              2098176
#
#  dropout_42 (Dropout)        (None, 1024)              0
#
#  dense_114 (Dense)           (None, 2048)              2099200
#
#  dense_115 (Dense)           (None, 1024)              2098176
#
#  dropout_43 (Dropout)        (None, 1024)              0
#
#  dense_116 (Dense)           (None, 2048)              2099200
#
#  dense_117 (Dense)           (None, 1024)              2098176
#
#  dropout_44 (Dropout)        (None, 1024)              0
#
#  dense_118 (Dense)           (None, 128)               131200
#
#  dense_119 (Dense)           (None, 64)                8256
#
#  dense_120 (Dense)           (None, 16)                1040
#
#  dense_121 (Dense)           (None, 4)                 68
#
#  lambda_7 (Lambda)           (None, 4)                 0
#
# =================================================================
# Total params: 11820564 (45.09 MB)
# Trainable params: 11820564 (45.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Enable mixed precision training
# tf.keras.mixed_precision.set_global_policy('mixed_float16')

# Enable XLA
tf.config.optimizer.set_jit(True)

# Optimize data pipeline
train_dataset = tf.data.Dataset.from_tensor_slices((train_x, train_y))
train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE)

valid_dataset = tf.data.Dataset.from_tensor_slices((valid_x, valid_y))
valid_dataset = valid_dataset.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-3,
    patience=32,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)


def scheduler(epoch, lr):
    if epoch < 100:
        return lr
    else:
        return lr * tf.math.exp(-0.001)


lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

# Fit the model
history = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=EPOCHS,
    verbose=2,
    callbacks=[stop_early,lr_scheduler],
)
# Out:
# Epoch 1/1024
# 68/68 - 10s - loss: 59.3662 - val_loss: 47.6401 - lr: 3.0000e-05 - 10s/epoch - 149ms/step
# Epoch 2/1024
# 68/68 - 5s - loss: 45.2251 - val_loss: 47.2728 - lr: 3.0000e-05 - 5s/epoch - 78ms/step
# Epoch 3/1024
# 68/68 - 2s - loss: 43.6310 - val_loss: 43.7947 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 4/1024
# 68/68 - 2s - loss: 42.2337 - val_loss: 42.9802 - lr: 3.0000e-05 - 2s/epoch - 26ms/step
# Epoch 5/1024
# 68/68 - 2s - loss: 41.8927 - val_loss: 42.8384 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 6/1024
# 68/68 - 2s - loss: 41.7825 - val_loss: 41.8356 - lr: 3.0000e-05 - 2s/epoch - 26ms/step
# Epoch 7/1024
# 68/68 - 2s - loss: 41.5633 - val_loss: 40.6649 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 8/1024
# 68/68 - 2s - loss: 41.3929 - val_loss: 40.6971 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 9/1024
# 68/68 - 2s - loss: 41.1114 - val_loss: 40.5615 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 10/1024
# 68/68 - 2s - loss: 40.8606 - val_loss: 40.4036 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 11/1024
# 68/68 - 2s - loss: 40.8342 - val_loss: 40.2010 - lr: 3.0000e-05 - 2s/epoch - 30ms/step
# Epoch 12/1024
# 68/68 - 2s - loss: 40.5673 - val_loss: 40.1188 - lr: 3.0000e-05 - 2s/epoch - 30ms/step
# Epoch 13/1024
# 68/68 - 2s - loss: 40.2891 - val_loss: 39.6376 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 14/1024
# 68/68 - 2s - loss: 40.3268 - val_loss: 39.9923 - lr: 3.0000e-05 - 2s/epoch - 30ms/step
# Epoch 15/1024
# 68/68 - 2s - loss: 40.1208 - val_loss: 39.6099 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 16/1024
# 68/68 - 2s - loss: 40.1761 - val_loss: 40.0077 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 17/1024
# 68/68 - 2s - loss: 40.2047 - val_loss: 39.9194 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 18/1024
# 68/68 - 2s - loss: 40.0321 - val_loss: 39.9223 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 19/1024
# 68/68 - 2s - loss: 40.1506 - val_loss: 39.4669 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 20/1024
# 68/68 - 2s - loss: 39.8157 - val_loss: 39.5788 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 21/1024
# 68/68 - 2s - loss: 39.6766 - val_loss: 39.2899 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 22/1024
# 68/68 - 2s - loss: 39.8628 - val_loss: 38.8159 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 23/1024
# 68/68 - 2s - loss: 39.7023 - val_loss: 39.3382 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 24/1024
# 68/68 - 2s - loss: 39.3515 - val_loss: 38.9854 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 25/1024
# 68/68 - 2s - loss: 39.4535 - val_loss: 38.5282 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 26/1024
# 68/68 - 2s - loss: 39.5553 - val_loss: 38.9744 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 27/1024
# 68/68 - 2s - loss: 39.5032 - val_loss: 39.7939 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 28/1024
# 68/68 - 2s - loss: 39.4518 - val_loss: 38.6966 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 29/1024
# 68/68 - 2s - loss: 39.4164 - val_loss: 38.5117 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 30/1024
# 68/68 - 2s - loss: 39.2829 - val_loss: 38.3030 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 31/1024
# 68/68 - 2s - loss: 39.0862 - val_loss: 38.2685 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 32/1024
# 68/68 - 2s - loss: 38.9086 - val_loss: 38.1501 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 33/1024
# 68/68 - 2s - loss: 39.2692 - val_loss: 38.5669 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 34/1024
# 68/68 - 2s - loss: 39.1471 - val_loss: 39.1257 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 35/1024
# 68/68 - 2s - loss: 38.8947 - val_loss: 38.7012 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 36/1024
# 68/68 - 2s - loss: 39.0144 - val_loss: 38.1458 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 37/1024
# 68/68 - 2s - loss: 39.0439 - val_loss: 38.2917 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 38/1024
# 68/68 - 2s - loss: 38.8788 - val_loss: 37.9278 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 39/1024
# 68/68 - 2s - loss: 38.7178 - val_loss: 37.8767 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 40/1024
# 68/68 - 2s - loss: 38.6858 - val_loss: 37.6217 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 41/1024
# 68/68 - 2s - loss: 38.7404 - val_loss: 37.6233 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 42/1024
# 68/68 - 2s - loss: 38.6227 - val_loss: 38.0381 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 43/1024
# 68/68 - 2s - loss: 38.7221 - val_loss: 37.7977 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 44/1024
# 68/68 - 2s - loss: 38.6502 - val_loss: 37.8954 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 45/1024
# 68/68 - 2s - loss: 38.4729 - val_loss: 38.2337 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 46/1024
# 68/68 - 2s - loss: 38.5199 - val_loss: 38.2874 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 47/1024
# 68/68 - 2s - loss: 38.4426 - val_loss: 37.8921 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 48/1024
# 68/68 - 2s - loss: 38.4282 - val_loss: 37.6368 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 49/1024
# 68/68 - 2s - loss: 38.3630 - val_loss: 38.1287 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 50/1024
# 68/68 - 2s - loss: 38.1686 - val_loss: 37.4015 - lr: 3.0000e-05 - 2s/epoch - 30ms/step
# Epoch 51/1024
# 68/68 - 2s - loss: 38.3962 - val_loss: 37.4968 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 52/1024
# 68/68 - 2s - loss: 38.5018 - val_loss: 37.8882 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 53/1024
# 68/68 - 2s - loss: 38.1970 - val_loss: 36.9041 - lr: 3.0000e-05 - 2s/epoch - 31ms/step
# Epoch 54/1024
# 68/68 - 2s - loss: 38.3618 - val_loss: 37.5332 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 55/1024
# 68/68 - 2s - loss: 38.3376 - val_loss: 37.6508 - lr: 3.0000e-05 - 2s/epoch - 31ms/step
# Epoch 56/1024
# 68/68 - 2s - loss: 38.2226 - val_loss: 38.1232 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 57/1024
# 68/68 - 2s - loss: 38.3035 - val_loss: 37.6174 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 58/1024
# 68/68 - 2s - loss: 38.2383 - val_loss: 37.1842 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 59/1024
# 68/68 - 2s - loss: 38.1866 - val_loss: 37.9813 - lr: 3.0000e-05 - 2s/epoch - 30ms/step
# Epoch 60/1024
# 68/68 - 2s - loss: 38.1811 - val_loss: 38.0124 - lr: 3.0000e-05 - 2s/epoch - 30ms/step
# Epoch 61/1024
# 68/68 - 2s - loss: 38.1396 - val_loss: 37.3570 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 62/1024
# 68/68 - 2s - loss: 38.0954 - val_loss: 37.9999 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 63/1024
# 68/68 - 2s - loss: 37.9934 - val_loss: 37.3398 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 64/1024
# 68/68 - 2s - loss: 37.9973 - val_loss: 37.5859 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 65/1024
# 68/68 - 2s - loss: 37.9893 - val_loss: 37.0360 - lr: 3.0000e-05 - 2s/epoch - 30ms/step
# Epoch 66/1024
# 68/68 - 2s - loss: 37.7733 - val_loss: 38.1025 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 67/1024
# 68/68 - 2s - loss: 38.1134 - val_loss: 37.8218 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 68/1024
# 68/68 - 2s - loss: 37.8839 - val_loss: 37.4030 - lr: 3.0000e-05 - 2s/epoch - 32ms/step
# Epoch 69/1024
# 68/68 - 2s - loss: 37.8117 - val_loss: 37.3696 - lr: 3.0000e-05 - 2s/epoch - 30ms/step
# Epoch 70/1024
# 68/68 - 2s - loss: 37.6846 - val_loss: 36.9843 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 71/1024
# 68/68 - 2s - loss: 37.7761 - val_loss: 37.3096 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 72/1024
# 68/68 - 2s - loss: 37.8317 - val_loss: 37.5028 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 73/1024
# 68/68 - 2s - loss: 37.7152 - val_loss: 37.3124 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 74/1024
# 68/68 - 2s - loss: 37.6597 - val_loss: 37.3723 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 75/1024
# 68/68 - 2s - loss: 37.6023 - val_loss: 37.0138 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 76/1024
# 68/68 - 2s - loss: 37.6612 - val_loss: 37.4546 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 77/1024
# 68/68 - 2s - loss: 37.5061 - val_loss: 37.4055 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 78/1024
# 68/68 - 2s - loss: 37.7085 - val_loss: 37.0763 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 79/1024
# 68/68 - 2s - loss: 37.5681 - val_loss: 36.7671 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 80/1024
# 68/68 - 2s - loss: 37.5349 - val_loss: 36.8302 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 81/1024
# 68/68 - 2s - loss: 37.4692 - val_loss: 36.6722 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 82/1024
# 68/68 - 2s - loss: 37.5245 - val_loss: 37.1822 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 83/1024
# 68/68 - 2s - loss: 37.4867 - val_loss: 36.8683 - lr: 3.0000e-05 - 2s/epoch - 30ms/step
# Epoch 84/1024
# 68/68 - 2s - loss: 37.4361 - val_loss: 36.4981 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 85/1024
# 68/68 - 2s - loss: 37.3970 - val_loss: 36.7086 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 86/1024
# 68/68 - 2s - loss: 37.4300 - val_loss: 36.3391 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 87/1024
# 68/68 - 2s - loss: 37.5088 - val_loss: 37.6736 - lr: 3.0000e-05 - 2s/epoch - 30ms/step
# Epoch 88/1024
# 68/68 - 2s - loss: 37.6087 - val_loss: 37.0174 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 89/1024
# 68/68 - 2s - loss: 37.4659 - val_loss: 36.5792 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 90/1024
# 68/68 - 2s - loss: 37.3786 - val_loss: 36.5583 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 91/1024
# 68/68 - 2s - loss: 37.3673 - val_loss: 36.4228 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 92/1024
# 68/68 - 2s - loss: 37.3705 - val_loss: 36.8114 - lr: 3.0000e-05 - 2s/epoch - 29ms/step
# Epoch 93/1024
# 68/68 - 2s - loss: 37.3709 - val_loss: 36.0562 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 94/1024
# 68/68 - 2s - loss: 37.1473 - val_loss: 36.1620 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 95/1024
# 68/68 - 2s - loss: 37.1641 - val_loss: 36.5989 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 96/1024
# 68/68 - 2s - loss: 37.4393 - val_loss: 37.0409 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 97/1024
# 68/68 - 2s - loss: 37.4040 - val_loss: 36.9553 - lr: 3.0000e-05 - 2s/epoch - 32ms/step
# Epoch 98/1024
# 68/68 - 2s - loss: 37.4595 - val_loss: 36.7308 - lr: 3.0000e-05 - 2s/epoch - 27ms/step
# Epoch 99/1024
# 68/68 - 2s - loss: 37.1727 - val_loss: 36.7433 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 100/1024
# 68/68 - 2s - loss: 37.1392 - val_loss: 36.7566 - lr: 3.0000e-05 - 2s/epoch - 28ms/step
# Epoch 101/1024
# 68/68 - 2s - loss: 37.3548 - val_loss: 36.5398 - lr: 2.9970e-05 - 2s/epoch - 27ms/step
# Epoch 102/1024
# 68/68 - 2s - loss: 37.3604 - val_loss: 36.7321 - lr: 2.9940e-05 - 2s/epoch - 29ms/step
# Epoch 103/1024
# 68/68 - 2s - loss: 37.1613 - val_loss: 36.6138 - lr: 2.9910e-05 - 2s/epoch - 28ms/step
# Epoch 104/1024
# 68/68 - 2s - loss: 37.1972 - val_loss: 37.0457 - lr: 2.9880e-05 - 2s/epoch - 30ms/step
# Epoch 105/1024
# 68/68 - 2s - loss: 37.1445 - val_loss: 37.2349 - lr: 2.9850e-05 - 2s/epoch - 29ms/step
# Epoch 106/1024
# 68/68 - 2s - loss: 37.1941 - val_loss: 36.2252 - lr: 2.9821e-05 - 2s/epoch - 28ms/step
# Epoch 107/1024
# 68/68 - 2s - loss: 37.1269 - val_loss: 36.8053 - lr: 2.9791e-05 - 2s/epoch - 28ms/step
# Epoch 108/1024
# 68/68 - 2s - loss: 37.2386 - val_loss: 36.9365 - lr: 2.9761e-05 - 2s/epoch - 28ms/step
# Epoch 109/1024
# 68/68 - 2s - loss: 37.2163 - val_loss: 37.3423 - lr: 2.9731e-05 - 2s/epoch - 28ms/step
# Epoch 110/1024
# 68/68 - 2s - loss: 37.3791 - val_loss: 36.9638 - lr: 2.9702e-05 - 2s/epoch - 29ms/step
# Epoch 111/1024
# 68/68 - 2s - loss: 37.3430 - val_loss: 36.2549 - lr: 2.9672e-05 - 2s/epoch - 28ms/step
# Epoch 112/1024
# 68/68 - 2s - loss: 36.9970 - val_loss: 36.8175 - lr: 2.9642e-05 - 2s/epoch - 28ms/step
# Epoch 113/1024
# 68/68 - 2s - loss: 37.0279 - val_loss: 36.6808 - lr: 2.9613e-05 - 2s/epoch - 28ms/step
# Epoch 114/1024
# 68/68 - 2s - loss: 37.1860 - val_loss: 36.6482 - lr: 2.9583e-05 - 2s/epoch - 28ms/step
# Epoch 115/1024
# 68/68 - 2s - loss: 36.9589 - val_loss: 36.4910 - lr: 2.9553e-05 - 2s/epoch - 29ms/step
# Epoch 116/1024
# 68/68 - 2s - loss: 36.8831 - val_loss: 36.2155 - lr: 2.9524e-05 - 2s/epoch - 27ms/step
# Epoch 117/1024
# 68/68 - 2s - loss: 37.1130 - val_loss: 37.0459 - lr: 2.9494e-05 - 2s/epoch - 27ms/step
# Epoch 118/1024
# 68/68 - 2s - loss: 37.3019 - val_loss: 36.5696 - lr: 2.9465e-05 - 2s/epoch - 28ms/step
# Epoch 119/1024
# 68/68 - 2s - loss: 36.9945 - val_loss: 36.1709 - lr: 2.9435e-05 - 2s/epoch - 27ms/step
# Epoch 120/1024
# 68/68 - 2s - loss: 37.0153 - val_loss: 36.6525 - lr: 2.9406e-05 - 2s/epoch - 30ms/step
# Epoch 121/1024
# 68/68 - 2s - loss: 36.9828 - val_loss: 36.5137 - lr: 2.9377e-05 - 2s/epoch - 28ms/step
# Epoch 122/1024
# 68/68 - 2s - loss: 36.7547 - val_loss: 36.4298 - lr: 2.9347e-05 - 2s/epoch - 28ms/step
# Epoch 123/1024
# 68/68 - 2s - loss: 36.8158 - val_loss: 36.9651 - lr: 2.9318e-05 - 2s/epoch - 28ms/step
# Epoch 124/1024
# 68/68 - 2s - loss: 37.0315 - val_loss: 36.5142 - lr: 2.9289e-05 - 2s/epoch - 28ms/step
# Epoch 125/1024
# 68/68 - 2s - loss: 36.7115 - val_loss: 36.1217 - lr: 2.9259e-05 - 2s/epoch - 28ms/step

# %%
plot.plot_loss_history(history, logx=False, logy=False, loss_name="MAE")

# %%
# Make a directory
dir_name = HOME_PATH + "/5th_trial/w_sublead_result/"
name = "dnn_w_offshell_lambda"

# If the directory exists
if os.path.exists(dir_name):
    test_files = glob.glob(dir_name + "*" + name + "*")
    if test_files:
        for file in test_files:
            os.remove(file)
        print(f"Directory {dir_name} cleaned.")
    print(f"Directory {dir_name} exists.")
else:
    os.makedirs(dir_name)
    print(f"Directory {dir_name} created.")

# save model
model.save(dir_name + name + ".keras", save_format="keras", overwrite=True)

# predict
pred_y = model.predict(test_x)
# save predicted results
np.savez_compressed(dir_name + name + "_data.npz", pred_y=pred_y, test_y=test_y)
sig_pred = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth = np.load(dir_name + name + "_data.npz")["test_y"]
# Out:
# Directory /root/work/QE-mls/5th_trial/w_sublead_result/ cleaned.
# Directory /root/work/QE-mls/5th_trial/w_sublead_result/ exists.
# 12924/12924 [==============================] - 21s 2ms/step

# %%
# name the file
name = "dnn_w_offshell"

# save predicted results
np.savez_compressed(
    dir_name + name + "_data.npz", pred_y=sig_pred.reshape(sig_truth.shape), test_y=sig_truth
)
sig_pred_inv = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth_inv = np.load(dir_name + name + "_data.npz")["test_y"]

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,0]):.3f}, std: {np.std(sig_truth_inv[:,0]):.3f}, min: {np.min(sig_truth_inv[:,0]):.3f}, max: {np.max(sig_truth_inv[:,0]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 0], sig_pred_inv[:, 0]],
    label=r"$p_{x}^{W}$",
    title="Off-shell $p_{x}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,0], sig_pred_inv[:,0])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 0],
    sig_pred_inv[:, 0],
    r"Off-shell $p_{x}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,0], sig_pred_inv[:,0])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.075, std: 27.786, min: -691.161, max: 637.177

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,1]):.3f}, std: {np.std(sig_truth_inv[:,1]):.3f}, min: {np.min(sig_truth_inv[:,1]):.3f}, max: {np.max(sig_truth_inv[:,1]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 1], sig_pred_inv[:, 1]],
    label=r"$p_{y}^{W}$",
    title="Off-shell $p_{y}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,1], sig_pred_inv[:,1])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 1],
    sig_pred_inv[:, 1],
    r"Off-shell $p_{y}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,1], sig_pred_inv[:,1])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.111, std: 27.868, min: -620.586, max: 532.806

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,2]):.3f}, std: {np.std(sig_truth_inv[:,2]):.3f}, min: {np.min(sig_truth_inv[:,2]):.3f}, max: {np.max(sig_truth_inv[:,2]):.3f}"
)

set_range = [-1200, 1200]

plot.hist(
    data=[sig_truth_inv[:, 2], sig_pred_inv[:, 2]],
    label=r"$p_{z}^{W}$",
    title="Off-shell $p_{z}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,2], sig_pred_inv[:,2])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 2],
    sig_pred_inv[:, 2],
    r"Off-shell $p_{z}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,2], sig_pred_inv[:,2])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.458, std: 205.111, min: -3293.224, max: 3210.099

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,3]):.3f}, std: {np.std(sig_truth_inv[:,3]):.3f}, min: {np.min(sig_truth_inv[:,3]):.3f}, max: {np.max(sig_truth_inv[:,3]):.3f}"
)

set_range = [0, 1800]

plot.hist(
    data=[sig_truth_inv[:,3], sig_pred_inv[:,3]],
    label=r"$E^{W}$",
    title="Off-shell $E^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,3], sig_pred_inv[:,3])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:,3],
    sig_pred_inv[:,3],
    r"Off-shell $E^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,3], sig_pred_inv[:,3])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 141.322, std: 159.253, min: 17.567, max: 3294.626

# %%
truth_time_like = np.square(sig_pred_inv[:, 3]) - np.sum(
    np.square(sig_pred_inv[:, 0:-1]), axis=1
)
truth_time_mask = truth_time_like >= 0
plt.hist(truth_time_like, bins=120, fill=True)
plt.title(r"Total-like $W^{2}$ mass with" + f"{len(truth_time_like)}")
plt.xlabel(r"mass$^{2}$ [GeV$^2$]")
plt.ylabel("count")
plt.show()

bin_edge = np.linspace(0, 110, 121)
plt.hist(np.sqrt(truth_time_like[truth_time_mask]), bins=bin_edge, fill=True, density=True, label="Predicted")
plt.hist(w_offshell["m"] / GEV, bins=bin_edge, histtype="step", density=True, label="Truth")
plt.title(f"Time-like W mass with {len(truth_time_like[truth_time_mask])}")
plt.xlabel("mass [GeV]")
plt.ylabel("normalized count")
plt.legend(loc="best")
plt.show()
plt.close()

# %%
import shap
import matplotlib as mpl

mpl.rcParams.update(mpl.rcParamsDefault)

feature_names = [
    "lead_px",
    "lead_py",
    "lead_pz",
    "lead_E",
    "lead_pt",
    "lead_eta",
    "lead_phi",
    "sublead_px",
    "sublead_py",
    "sublead_pz",
    "sublead_E",
    "sublead_pt",
    "sublead_eta",
    "sublead_phi",
    "met_px",
    "met_py",
    "met_pt",
    "met_phi"
]
title_name = ["px", "py", "pz", "E"]
# lead
# Use DeepExplainer for SHAP values
explainer = shap.DeepExplainer(model, obs_kin[:1024])
shap_values = explainer.shap_values(obs_kin[:1024], check_additivity=False)
for i in range(shap_values.shape[-1]):
    plt.figure(figsize=(10, 6))
    shap.summary_plot(
        shap_values[:, :, i],
        obs_kin[:1024],
        feature_names=feature_names,
        plot_type="dot",
        show=False,
    )
    plt.title(f"SHAP Summary Plot for Off-shell Regression Output: {title_name[i]}")
    plt.show()
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
