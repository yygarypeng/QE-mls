# %%
# %reset -sf

import tensorflow as tf
print(tf.__version__)


# GPU(s) setups
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')
        
        # Instead of enabling memory growth, set a memory limit
        memory_limit = 16_384*2 # Set the memory limit in MB
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]
        )
        
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2024-08-31 14:16:32.020353: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.13.0
# 2 Physical GPUs, 1 Logical GPU
# 2024-08-31 14:16:34.901686: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 32768 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
import sys
import os
import glob
HOME_PATH = os.path.abspath("..")
sys.path.insert(0, HOME_PATH+"/qe")

import get_data as gd
import atlas_plot as ap
plot = ap.Plotter()

# INN packages
from flow import *
from utils import *

import pandas as pd
import numpy as np
import scipy as sp

from matplotlib import pyplot as plt
import matplotlib as mpl
import shap

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

# %%
SEED = 42  # set random seed (global variable)
np.random.seed(SEED)
processor = gd.DataProcessor()
path = "/root/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 76
#
# ['/root/data/truth/signal/CGLMP.npz', '/root/data/truth/signal/Higgs.npz', '/root/data/truth/signal/LeadLepton.npz', '/root/data/truth/signal/LeptonM.npz', '/root/data/truth/signal/LeptonP.npz', '/root/data/truth/signal/LmNu.npz', '/root/data/truth/signal/LpNu.npz', '/root/data/truth/signal/MET.npz', '/root/data/truth/signal/WmBoson.npz', '/root/data/truth/signal/WpBoson.npz', '/root/data/truth/signal/diLepton.npz', '/root/data/truth/signal/subLeadLepton.npz', '/root/data/truth/signal/xi_xyz.npz']

# %%
## Global variables

GEV = 1e3

cut_pre_pt_lead = data.LeadLep["pt"] > 22 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
cut_pre_pt_miss = data.MET["pt"] > 20 * GEV

PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

BATCH_SIZE = 8192
EPOCHS = 1_024
LEARNING_RATE = 1e-4

# %%
## Interesting variables

# Critria for leading and subleading lepton
lead_p = data.LeadLep["m"] == data.LepP["m"]
sublead_p = ~lead_p
lead_m = sublead_p.copy()
sublead_m = lead_p.copy()

# sperate onshell and offshell W
w_lead = pd.concat([data.Wp[lead_p], data.Wm[lead_m]], axis=0).sort_index()
w_sublead = pd.concat([data.Wp[sublead_p], data.Wm[sublead_m]], axis=0).sort_index()
onshell_mask = (w_lead["m"] > w_sublead["m"]).to_numpy()
cut_onshell_mask = (w_lead[PRE_CUT]["m"] > w_sublead[PRE_CUT]["m"]).to_numpy()
base_acc = w_lead[onshell_mask].shape[0] / w_lead.shape[0]
cut_acc  = w_lead[PRE_CUT][cut_onshell_mask].shape[0] / w_lead[PRE_CUT].shape[0]
print(f"Base accuracy: {base_acc:.2f}")
print(f"Cut  accuracy: {cut_acc:.2f}")
print(f"Cuts improve: {100 * (cut_acc - base_acc):.2f}%")

# Check (sub)lead W
plt.hist(w_lead["m"] / GEV, bins=100, color="r", histtype="step", label=r"$W^{lead}$")
plt.hist(
    w_sublead["m"] / GEV, bins=100, color="b", histtype="step", label=r"$W^{sublead}$"
)
plt.title("W mass")
plt.xlabel("mass [GeV]")
plt.ylabel("count")
plt.legend(loc="best")
plt.show()
plt.close()

# Kinematics of interesting variables (target for training)
int_kin = onshell_mask.astype(int)[PRE_CUT]
print("int_kin shape:", int_kin.shape)
print(type(int_kin))
# Out:
# Base accuracy: 0.83
# Cut  accuracy: 0.81
# Cuts improve: -1.75%
# int_kin shape: (1378510,)
# <class 'numpy.ndarray'>

# %%
## Observing variables

lead_lep = data.LeadLep[["px", "py", "pz", "E", "pt", "eta", "phi"]]
sublead_lep = data.SubLep[["px", "py", "pz", "E", "pt", "eta", "phi"]]
met = data.MET[["px", "py", "pt", "phi"]]
di_lep = data.diLep[["px", "py", "pz", "E", "pt", "eta", "phi", "m"]]

# Kinematics of observing variables (inputs for training)
obs_kin = pd.concat([lead_lep, sublead_lep, met, di_lep], axis=1)[PRE_CUT]
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array
ROBUST_OBS = RobustScaler()
obs_kin = ROBUST_OBS.fit_transform(obs_kin)
print(type(obs_kin))
# Out:
# int_kin shape: (1378510, 26)
# <class 'numpy.ndarray'>

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.4,
    test_size=0.6,
    random_state=SEED,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=SEED
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# X (Interest)
# Training data shape: (551404, 26);
# Validing data shape: (413553, 26);
# Testing data shape: (413553, 26).
# Y (Observed)
# Training data shape: (551404,);
# Validing data shape: (413553,);
# Testing data shape: (413553,).

# %%
# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    x = tf.keras.layers.Dense(units=128, activation="selu")(x)
    x = tf.keras.layers.Dropout(rate=0.3)(x)
    x = tf.keras.layers.Dense(units=512, activation="selu")(x)
    x = tf.keras.layers.Dropout(rate=0.5)(x)
    x = tf.keras.layers.Dense(units=512, activation="selu")(x)
    x = tf.keras.layers.Dropout(rate=0.5)(x)
    x = tf.keras.layers.Dense(units=64, activation="selu")(x)
    x = tf.keras.layers.Dropout(rate=0.1)(x)
    x = tf.keras.layers.Dense(units=16, activation="selu")(x)
    x = tf.keras.layers.Dropout(rate=0.1)(x)

    outputs = tf.keras.layers.Dense(units=1, activation="sigmoid")(x)
    
    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss=tf.losses.binary_crossentropy,
        metrics=["accuracy"],
    )

    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 26)]              0
#
#  flatten (Flatten)           (None, 26)                0
#
#  dense (Dense)               (None, 128)               3456
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 512)               66048
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 64)                32832
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 16)                1040
#
#  dropout_4 (Dropout)         (None, 16)                0
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 366049 (1.40 MB)
# Trainable params: 366049 (1.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-3,
    patience=32,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)


def scheduler(epoch, lr):
    if epoch < 128:
        return lr
    else:
        return lr * tf.math.exp(-0.0001)


lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

# Fit the model
history = model.fit(
    x=train_x,
    y=train_y,
    validation_data=(valid_x, valid_y),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=2,
    callbacks=[stop_early,lr_scheduler],
)
# Out:
# Epoch 1/1024
# 2024-08-31 14:16:59.900848: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-08-31 14:16:59.906741: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5655112ad620 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-08-31 14:16:59.906809: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-08-31 14:16:59.914486: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-08-31 14:17:00.130890: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-08-31 14:17:00.272737: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 68/68 - 5s - loss: 0.6641 - accuracy: 0.7186 - val_loss: 0.4303 - val_accuracy: 0.8123 - lr: 1.0000e-04 - 5s/epoch - 70ms/step
# Epoch 2/1024
# 68/68 - 1s - loss: 0.5213 - accuracy: 0.7716 - val_loss: 0.4090 - val_accuracy: 0.8148 - lr: 1.0000e-04 - 515ms/epoch - 8ms/step
# Epoch 3/1024
# 68/68 - 1s - loss: 0.4919 - accuracy: 0.7821 - val_loss: 0.3992 - val_accuracy: 0.8183 - lr: 1.0000e-04 - 559ms/epoch - 8ms/step
# Epoch 4/1024
# 68/68 - 1s - loss: 0.4738 - accuracy: 0.7886 - val_loss: 0.3898 - val_accuracy: 0.8231 - lr: 1.0000e-04 - 538ms/epoch - 8ms/step
# Epoch 5/1024
# 68/68 - 1s - loss: 0.4610 - accuracy: 0.7941 - val_loss: 0.3812 - val_accuracy: 0.8286 - lr: 1.0000e-04 - 541ms/epoch - 8ms/step
# Epoch 6/1024
# 68/68 - 1s - loss: 0.4486 - accuracy: 0.7999 - val_loss: 0.3696 - val_accuracy: 0.8351 - lr: 1.0000e-04 - 536ms/epoch - 8ms/step
# Epoch 7/1024
# 68/68 - 1s - loss: 0.4372 - accuracy: 0.8052 - val_loss: 0.3589 - val_accuracy: 0.8407 - lr: 1.0000e-04 - 551ms/epoch - 8ms/step
# Epoch 8/1024
# 68/68 - 1s - loss: 0.4292 - accuracy: 0.8089 - val_loss: 0.3507 - val_accuracy: 0.8447 - lr: 1.0000e-04 - 566ms/epoch - 8ms/step
# Epoch 9/1024
# 68/68 - 1s - loss: 0.4207 - accuracy: 0.8129 - val_loss: 0.3464 - val_accuracy: 0.8475 - lr: 1.0000e-04 - 535ms/epoch - 8ms/step
# Epoch 10/1024
# 68/68 - 1s - loss: 0.4145 - accuracy: 0.8165 - val_loss: 0.3429 - val_accuracy: 0.8498 - lr: 1.0000e-04 - 532ms/epoch - 8ms/step
# Epoch 11/1024
# 68/68 - 1s - loss: 0.4084 - accuracy: 0.8190 - val_loss: 0.3401 - val_accuracy: 0.8513 - lr: 1.0000e-04 - 539ms/epoch - 8ms/step
# Epoch 12/1024
# 68/68 - 1s - loss: 0.4046 - accuracy: 0.8212 - val_loss: 0.3370 - val_accuracy: 0.8533 - lr: 1.0000e-04 - 522ms/epoch - 8ms/step
# Epoch 13/1024
# 68/68 - 1s - loss: 0.4000 - accuracy: 0.8227 - val_loss: 0.3350 - val_accuracy: 0.8542 - lr: 1.0000e-04 - 535ms/epoch - 8ms/step
# Epoch 14/1024
# 68/68 - 1s - loss: 0.3963 - accuracy: 0.8245 - val_loss: 0.3324 - val_accuracy: 0.8552 - lr: 1.0000e-04 - 560ms/epoch - 8ms/step
# Epoch 15/1024
# 68/68 - 1s - loss: 0.3938 - accuracy: 0.8260 - val_loss: 0.3316 - val_accuracy: 0.8556 - lr: 1.0000e-04 - 559ms/epoch - 8ms/step
# Epoch 16/1024
# 68/68 - 1s - loss: 0.3901 - accuracy: 0.8279 - val_loss: 0.3294 - val_accuracy: 0.8569 - lr: 1.0000e-04 - 548ms/epoch - 8ms/step
# Epoch 17/1024
# 68/68 - 1s - loss: 0.3876 - accuracy: 0.8282 - val_loss: 0.3289 - val_accuracy: 0.8575 - lr: 1.0000e-04 - 573ms/epoch - 8ms/step
# Epoch 18/1024
# 68/68 - 1s - loss: 0.3843 - accuracy: 0.8303 - val_loss: 0.3274 - val_accuracy: 0.8579 - lr: 1.0000e-04 - 543ms/epoch - 8ms/step
# Epoch 19/1024
# 68/68 - 1s - loss: 0.3821 - accuracy: 0.8311 - val_loss: 0.3265 - val_accuracy: 0.8583 - lr: 1.0000e-04 - 551ms/epoch - 8ms/step
# Epoch 20/1024
# 68/68 - 1s - loss: 0.3797 - accuracy: 0.8322 - val_loss: 0.3265 - val_accuracy: 0.8584 - lr: 1.0000e-04 - 585ms/epoch - 9ms/step
# Epoch 21/1024
# 68/68 - 1s - loss: 0.3772 - accuracy: 0.8331 - val_loss: 0.3257 - val_accuracy: 0.8586 - lr: 1.0000e-04 - 560ms/epoch - 8ms/step
# Epoch 22/1024
# 68/68 - 1s - loss: 0.3751 - accuracy: 0.8345 - val_loss: 0.3246 - val_accuracy: 0.8590 - lr: 1.0000e-04 - 532ms/epoch - 8ms/step
# Epoch 23/1024
# 68/68 - 1s - loss: 0.3737 - accuracy: 0.8354 - val_loss: 0.3242 - val_accuracy: 0.8594 - lr: 1.0000e-04 - 585ms/epoch - 9ms/step
# Epoch 24/1024
# 68/68 - 1s - loss: 0.3720 - accuracy: 0.8359 - val_loss: 0.3228 - val_accuracy: 0.8600 - lr: 1.0000e-04 - 518ms/epoch - 8ms/step
# Epoch 25/1024
# 68/68 - 1s - loss: 0.3701 - accuracy: 0.8369 - val_loss: 0.3232 - val_accuracy: 0.8597 - lr: 1.0000e-04 - 540ms/epoch - 8ms/step
# Epoch 26/1024
# 68/68 - 1s - loss: 0.3689 - accuracy: 0.8377 - val_loss: 0.3223 - val_accuracy: 0.8601 - lr: 1.0000e-04 - 556ms/epoch - 8ms/step
# Epoch 27/1024
# 68/68 - 1s - loss: 0.3671 - accuracy: 0.8386 - val_loss: 0.3213 - val_accuracy: 0.8604 - lr: 1.0000e-04 - 536ms/epoch - 8ms/step
# Epoch 28/1024
# 68/68 - 1s - loss: 0.3650 - accuracy: 0.8390 - val_loss: 0.3210 - val_accuracy: 0.8607 - lr: 1.0000e-04 - 549ms/epoch - 8ms/step
# Epoch 29/1024
# 68/68 - 1s - loss: 0.3641 - accuracy: 0.8396 - val_loss: 0.3208 - val_accuracy: 0.8605 - lr: 1.0000e-04 - 523ms/epoch - 8ms/step
# Epoch 30/1024
# 68/68 - 1s - loss: 0.3630 - accuracy: 0.8400 - val_loss: 0.3204 - val_accuracy: 0.8608 - lr: 1.0000e-04 - 505ms/epoch - 7ms/step
# Epoch 31/1024
# 68/68 - 0s - loss: 0.3613 - accuracy: 0.8408 - val_loss: 0.3189 - val_accuracy: 0.8614 - lr: 1.0000e-04 - 494ms/epoch - 7ms/step
# Epoch 32/1024
# 68/68 - 1s - loss: 0.3601 - accuracy: 0.8413 - val_loss: 0.3188 - val_accuracy: 0.8615 - lr: 1.0000e-04 - 532ms/epoch - 8ms/step
# Epoch 33/1024
# 68/68 - 1s - loss: 0.3592 - accuracy: 0.8418 - val_loss: 0.3185 - val_accuracy: 0.8616 - lr: 1.0000e-04 - 562ms/epoch - 8ms/step
# Epoch 34/1024
# 68/68 - 1s - loss: 0.3578 - accuracy: 0.8423 - val_loss: 0.3180 - val_accuracy: 0.8616 - lr: 1.0000e-04 - 534ms/epoch - 8ms/step
# Epoch 35/1024
# 68/68 - 1s - loss: 0.3570 - accuracy: 0.8427 - val_loss: 0.3176 - val_accuracy: 0.8617 - lr: 1.0000e-04 - 563ms/epoch - 8ms/step
# Epoch 36/1024
# 68/68 - 1s - loss: 0.3556 - accuracy: 0.8435 - val_loss: 0.3173 - val_accuracy: 0.8617 - lr: 1.0000e-04 - 557ms/epoch - 8ms/step
# Epoch 37/1024
# 68/68 - 1s - loss: 0.3546 - accuracy: 0.8435 - val_loss: 0.3169 - val_accuracy: 0.8618 - lr: 1.0000e-04 - 542ms/epoch - 8ms/step
# Epoch 38/1024
# 68/68 - 1s - loss: 0.3534 - accuracy: 0.8438 - val_loss: 0.3165 - val_accuracy: 0.8617 - lr: 1.0000e-04 - 513ms/epoch - 8ms/step
# Epoch 39/1024
# 68/68 - 1s - loss: 0.3522 - accuracy: 0.8447 - val_loss: 0.3158 - val_accuracy: 0.8621 - lr: 1.0000e-04 - 536ms/epoch - 8ms/step
# Epoch 40/1024
# 68/68 - 1s - loss: 0.3524 - accuracy: 0.8443 - val_loss: 0.3155 - val_accuracy: 0.8619 - lr: 1.0000e-04 - 532ms/epoch - 8ms/step
# Epoch 41/1024
# 68/68 - 1s - loss: 0.3506 - accuracy: 0.8456 - val_loss: 0.3151 - val_accuracy: 0.8621 - lr: 1.0000e-04 - 548ms/epoch - 8ms/step
# Epoch 42/1024
# 68/68 - 1s - loss: 0.3495 - accuracy: 0.8457 - val_loss: 0.3154 - val_accuracy: 0.8622 - lr: 1.0000e-04 - 574ms/epoch - 8ms/step
# Epoch 43/1024
# 68/68 - 1s - loss: 0.3490 - accuracy: 0.8461 - val_loss: 0.3146 - val_accuracy: 0.8622 - lr: 1.0000e-04 - 561ms/epoch - 8ms/step
# Epoch 44/1024
# 68/68 - 1s - loss: 0.3480 - accuracy: 0.8465 - val_loss: 0.3138 - val_accuracy: 0.8625 - lr: 1.0000e-04 - 575ms/epoch - 8ms/step
# Epoch 45/1024
# 68/68 - 1s - loss: 0.3477 - accuracy: 0.8469 - val_loss: 0.3139 - val_accuracy: 0.8623 - lr: 1.0000e-04 - 559ms/epoch - 8ms/step
# Epoch 46/1024
# 68/68 - 1s - loss: 0.3470 - accuracy: 0.8473 - val_loss: 0.3131 - val_accuracy: 0.8628 - lr: 1.0000e-04 - 574ms/epoch - 8ms/step
# Epoch 47/1024
# 68/68 - 1s - loss: 0.3458 - accuracy: 0.8472 - val_loss: 0.3131 - val_accuracy: 0.8628 - lr: 1.0000e-04 - 551ms/epoch - 8ms/step
# Epoch 48/1024
# 68/68 - 1s - loss: 0.3448 - accuracy: 0.8479 - val_loss: 0.3131 - val_accuracy: 0.8628 - lr: 1.0000e-04 - 567ms/epoch - 8ms/step
# Epoch 49/1024
# 68/68 - 1s - loss: 0.3448 - accuracy: 0.8477 - val_loss: 0.3124 - val_accuracy: 0.8631 - lr: 1.0000e-04 - 558ms/epoch - 8ms/step
# Epoch 50/1024
# 68/68 - 1s - loss: 0.3432 - accuracy: 0.8486 - val_loss: 0.3122 - val_accuracy: 0.8633 - lr: 1.0000e-04 - 560ms/epoch - 8ms/step
# Epoch 51/1024
# 68/68 - 1s - loss: 0.3428 - accuracy: 0.8487 - val_loss: 0.3124 - val_accuracy: 0.8630 - lr: 1.0000e-04 - 557ms/epoch - 8ms/step
# Epoch 52/1024
# 68/68 - 1s - loss: 0.3430 - accuracy: 0.8486 - val_loss: 0.3116 - val_accuracy: 0.8633 - lr: 1.0000e-04 - 529ms/epoch - 8ms/step
# Epoch 53/1024
# 68/68 - 1s - loss: 0.3416 - accuracy: 0.8491 - val_loss: 0.3114 - val_accuracy: 0.8633 - lr: 1.0000e-04 - 546ms/epoch - 8ms/step
# Epoch 54/1024
# 68/68 - 1s - loss: 0.3417 - accuracy: 0.8490 - val_loss: 0.3118 - val_accuracy: 0.8634 - lr: 1.0000e-04 - 539ms/epoch - 8ms/step
# Epoch 55/1024
# 68/68 - 1s - loss: 0.3410 - accuracy: 0.8495 - val_loss: 0.3109 - val_accuracy: 0.8636 - lr: 1.0000e-04 - 504ms/epoch - 7ms/step
# Epoch 56/1024
# 68/68 - 1s - loss: 0.3403 - accuracy: 0.8498 - val_loss: 0.3109 - val_accuracy: 0.8638 - lr: 1.0000e-04 - 528ms/epoch - 8ms/step
# Epoch 57/1024
# 68/68 - 0s - loss: 0.3390 - accuracy: 0.8505 - val_loss: 0.3111 - val_accuracy: 0.8636 - lr: 1.0000e-04 - 495ms/epoch - 7ms/step
# Epoch 58/1024
# 68/68 - 1s - loss: 0.3394 - accuracy: 0.8501 - val_loss: 0.3104 - val_accuracy: 0.8638 - lr: 1.0000e-04 - 502ms/epoch - 7ms/step
# Epoch 59/1024
# 68/68 - 0s - loss: 0.3385 - accuracy: 0.8507 - val_loss: 0.3102 - val_accuracy: 0.8640 - lr: 1.0000e-04 - 487ms/epoch - 7ms/step
# Epoch 60/1024
# 68/68 - 1s - loss: 0.3374 - accuracy: 0.8511 - val_loss: 0.3101 - val_accuracy: 0.8640 - lr: 1.0000e-04 - 524ms/epoch - 8ms/step
# Epoch 61/1024
# 68/68 - 1s - loss: 0.3375 - accuracy: 0.8512 - val_loss: 0.3101 - val_accuracy: 0.8638 - lr: 1.0000e-04 - 530ms/epoch - 8ms/step
# Epoch 62/1024
# 68/68 - 1s - loss: 0.3366 - accuracy: 0.8510 - val_loss: 0.3097 - val_accuracy: 0.8640 - lr: 1.0000e-04 - 551ms/epoch - 8ms/step
# Epoch 63/1024
# 68/68 - 1s - loss: 0.3361 - accuracy: 0.8519 - val_loss: 0.3096 - val_accuracy: 0.8642 - lr: 1.0000e-04 - 560ms/epoch - 8ms/step
# Epoch 64/1024
# 68/68 - 1s - loss: 0.3355 - accuracy: 0.8524 - val_loss: 0.3096 - val_accuracy: 0.8643 - lr: 1.0000e-04 - 562ms/epoch - 8ms/step
# Epoch 65/1024
# 68/68 - 1s - loss: 0.3356 - accuracy: 0.8515 - val_loss: 0.3097 - val_accuracy: 0.8641 - lr: 1.0000e-04 - 505ms/epoch - 7ms/step
# Epoch 66/1024
# 68/68 - 1s - loss: 0.3350 - accuracy: 0.8521 - val_loss: 0.3095 - val_accuracy: 0.8642 - lr: 1.0000e-04 - 528ms/epoch - 8ms/step
# Epoch 67/1024
# 68/68 - 1s - loss: 0.3350 - accuracy: 0.8522 - val_loss: 0.3092 - val_accuracy: 0.8643 - lr: 1.0000e-04 - 547ms/epoch - 8ms/step
# Epoch 68/1024
# 68/68 - 1s - loss: 0.3348 - accuracy: 0.8522 - val_loss: 0.3094 - val_accuracy: 0.8645 - lr: 1.0000e-04 - 545ms/epoch - 8ms/step
# Epoch 69/1024
# 68/68 - 1s - loss: 0.3339 - accuracy: 0.8526 - val_loss: 0.3086 - val_accuracy: 0.8647 - lr: 1.0000e-04 - 521ms/epoch - 8ms/step
# Epoch 70/1024
# 68/68 - 1s - loss: 0.3334 - accuracy: 0.8528 - val_loss: 0.3091 - val_accuracy: 0.8647 - lr: 1.0000e-04 - 525ms/epoch - 8ms/step
# Epoch 71/1024
# 68/68 - 1s - loss: 0.3330 - accuracy: 0.8528 - val_loss: 0.3088 - val_accuracy: 0.8645 - lr: 1.0000e-04 - 544ms/epoch - 8ms/step
# Epoch 72/1024
# 68/68 - 1s - loss: 0.3326 - accuracy: 0.8535 - val_loss: 0.3091 - val_accuracy: 0.8643 - lr: 1.0000e-04 - 506ms/epoch - 7ms/step
# Epoch 73/1024
# 68/68 - 1s - loss: 0.3324 - accuracy: 0.8535 - val_loss: 0.3085 - val_accuracy: 0.8648 - lr: 1.0000e-04 - 525ms/epoch - 8ms/step
# Epoch 74/1024
# 68/68 - 1s - loss: 0.3323 - accuracy: 0.8538 - val_loss: 0.3079 - val_accuracy: 0.8648 - lr: 1.0000e-04 - 534ms/epoch - 8ms/step
# Epoch 75/1024
# 68/68 - 1s - loss: 0.3315 - accuracy: 0.8541 - val_loss: 0.3082 - val_accuracy: 0.8646 - lr: 1.0000e-04 - 565ms/epoch - 8ms/step
# Epoch 76/1024
# 68/68 - 1s - loss: 0.3317 - accuracy: 0.8536 - val_loss: 0.3085 - val_accuracy: 0.8646 - lr: 1.0000e-04 - 534ms/epoch - 8ms/step
# Epoch 77/1024
# 68/68 - 1s - loss: 0.3314 - accuracy: 0.8538 - val_loss: 0.3079 - val_accuracy: 0.8650 - lr: 1.0000e-04 - 534ms/epoch - 8ms/step
# Epoch 78/1024
# 68/68 - 1s - loss: 0.3304 - accuracy: 0.8546 - val_loss: 0.3078 - val_accuracy: 0.8647 - lr: 1.0000e-04 - 560ms/epoch - 8ms/step
# Epoch 79/1024
# 68/68 - 1s - loss: 0.3304 - accuracy: 0.8539 - val_loss: 0.3081 - val_accuracy: 0.8648 - lr: 1.0000e-04 - 531ms/epoch - 8ms/step
# Epoch 80/1024
# 68/68 - 1s - loss: 0.3302 - accuracy: 0.8545 - val_loss: 0.3075 - val_accuracy: 0.8649 - lr: 1.0000e-04 - 518ms/epoch - 8ms/step
# Epoch 81/1024
# 68/68 - 1s - loss: 0.3301 - accuracy: 0.8544 - val_loss: 0.3076 - val_accuracy: 0.8649 - lr: 1.0000e-04 - 566ms/epoch - 8ms/step
# Epoch 82/1024
# 68/68 - 1s - loss: 0.3298 - accuracy: 0.8550 - val_loss: 0.3077 - val_accuracy: 0.8649 - lr: 1.0000e-04 - 544ms/epoch - 8ms/step
# Epoch 83/1024
# 68/68 - 1s - loss: 0.3297 - accuracy: 0.8542 - val_loss: 0.3075 - val_accuracy: 0.8650 - lr: 1.0000e-04 - 567ms/epoch - 8ms/step
# Epoch 84/1024
# 68/68 - 1s - loss: 0.3292 - accuracy: 0.8544 - val_loss: 0.3076 - val_accuracy: 0.8650 - lr: 1.0000e-04 - 591ms/epoch - 9ms/step
# Epoch 85/1024
# 68/68 - 1s - loss: 0.3296 - accuracy: 0.8549 - val_loss: 0.3071 - val_accuracy: 0.8650 - lr: 1.0000e-04 - 564ms/epoch - 8ms/step
# Epoch 86/1024
# 68/68 - 1s - loss: 0.3284 - accuracy: 0.8548 - val_loss: 0.3072 - val_accuracy: 0.8650 - lr: 1.0000e-04 - 589ms/epoch - 9ms/step
# Epoch 87/1024
# 68/68 - 1s - loss: 0.3285 - accuracy: 0.8550 - val_loss: 0.3071 - val_accuracy: 0.8649 - lr: 1.0000e-04 - 562ms/epoch - 8ms/step
# Epoch 88/1024
# 68/68 - 1s - loss: 0.3281 - accuracy: 0.8553 - val_loss: 0.3073 - val_accuracy: 0.8651 - lr: 1.0000e-04 - 553ms/epoch - 8ms/step
# Epoch 89/1024
# 68/68 - 1s - loss: 0.3275 - accuracy: 0.8555 - val_loss: 0.3066 - val_accuracy: 0.8651 - lr: 1.0000e-04 - 575ms/epoch - 8ms/step
# Epoch 90/1024
# 68/68 - 1s - loss: 0.3282 - accuracy: 0.8550 - val_loss: 0.3069 - val_accuracy: 0.8650 - lr: 1.0000e-04 - 557ms/epoch - 8ms/step
# Epoch 91/1024
# 68/68 - 1s - loss: 0.3274 - accuracy: 0.8555 - val_loss: 0.3069 - val_accuracy: 0.8653 - lr: 1.0000e-04 - 524ms/epoch - 8ms/step
# Epoch 92/1024
# 68/68 - 1s - loss: 0.3271 - accuracy: 0.8554 - val_loss: 0.3064 - val_accuracy: 0.8655 - lr: 1.0000e-04 - 563ms/epoch - 8ms/step
# Epoch 93/1024
# 68/68 - 1s - loss: 0.3270 - accuracy: 0.8558 - val_loss: 0.3064 - val_accuracy: 0.8651 - lr: 1.0000e-04 - 580ms/epoch - 9ms/step
# Epoch 94/1024
# 68/68 - 1s - loss: 0.3268 - accuracy: 0.8557 - val_loss: 0.3065 - val_accuracy: 0.8653 - lr: 1.0000e-04 - 597ms/epoch - 9ms/step
# Epoch 95/1024
# 68/68 - 1s - loss: 0.3266 - accuracy: 0.8557 - val_loss: 0.3063 - val_accuracy: 0.8651 - lr: 1.0000e-04 - 540ms/epoch - 8ms/step
# Epoch 96/1024
# 68/68 - 1s - loss: 0.3263 - accuracy: 0.8559 - val_loss: 0.3064 - val_accuracy: 0.8654 - lr: 1.0000e-04 - 551ms/epoch - 8ms/step
# Epoch 97/1024
# 68/68 - 1s - loss: 0.3266 - accuracy: 0.8563 - val_loss: 0.3066 - val_accuracy: 0.8652 - lr: 1.0000e-04 - 502ms/epoch - 7ms/step
# Epoch 98/1024
# 68/68 - 0s - loss: 0.3257 - accuracy: 0.8566 - val_loss: 0.3061 - val_accuracy: 0.8657 - lr: 1.0000e-04 - 495ms/epoch - 7ms/step
# Epoch 99/1024
# 68/68 - 1s - loss: 0.3255 - accuracy: 0.8566 - val_loss: 0.3060 - val_accuracy: 0.8653 - lr: 1.0000e-04 - 517ms/epoch - 8ms/step
# Epoch 100/1024
# 68/68 - 1s - loss: 0.3253 - accuracy: 0.8564 - val_loss: 0.3063 - val_accuracy: 0.8654 - lr: 1.0000e-04 - 514ms/epoch - 8ms/step
# Epoch 101/1024
# 68/68 - 1s - loss: 0.3250 - accuracy: 0.8564 - val_loss: 0.3062 - val_accuracy: 0.8653 - lr: 1.0000e-04 - 530ms/epoch - 8ms/step
# Epoch 102/1024
# 68/68 - 1s - loss: 0.3253 - accuracy: 0.8568 - val_loss: 0.3060 - val_accuracy: 0.8654 - lr: 1.0000e-04 - 539ms/epoch - 8ms/step
# Epoch 103/1024
# 68/68 - 1s - loss: 0.3246 - accuracy: 0.8570 - val_loss: 0.3057 - val_accuracy: 0.8655 - lr: 1.0000e-04 - 542ms/epoch - 8ms/step
# Epoch 104/1024
# 68/68 - 1s - loss: 0.3248 - accuracy: 0.8566 - val_loss: 0.3057 - val_accuracy: 0.8655 - lr: 1.0000e-04 - 547ms/epoch - 8ms/step
# Epoch 105/1024
# 68/68 - 1s - loss: 0.3244 - accuracy: 0.8564 - val_loss: 0.3059 - val_accuracy: 0.8657 - lr: 1.0000e-04 - 523ms/epoch - 8ms/step
# Epoch 106/1024
# 68/68 - 1s - loss: 0.3244 - accuracy: 0.8567 - val_loss: 0.3053 - val_accuracy: 0.8657 - lr: 1.0000e-04 - 539ms/epoch - 8ms/step
# Epoch 107/1024
# 68/68 - 1s - loss: 0.3242 - accuracy: 0.8570 - val_loss: 0.3055 - val_accuracy: 0.8657 - lr: 1.0000e-04 - 508ms/epoch - 7ms/step
# Epoch 108/1024
# 68/68 - 0s - loss: 0.3240 - accuracy: 0.8573 - val_loss: 0.3056 - val_accuracy: 0.8655 - lr: 1.0000e-04 - 499ms/epoch - 7ms/step
# Epoch 109/1024
# 68/68 - 1s - loss: 0.3235 - accuracy: 0.8575 - val_loss: 0.3054 - val_accuracy: 0.8659 - lr: 1.0000e-04 - 517ms/epoch - 8ms/step
# Epoch 110/1024
# 68/68 - 0s - loss: 0.3238 - accuracy: 0.8574 - val_loss: 0.3051 - val_accuracy: 0.8659 - lr: 1.0000e-04 - 496ms/epoch - 7ms/step
# Epoch 111/1024
# 68/68 - 0s - loss: 0.3235 - accuracy: 0.8571 - val_loss: 0.3053 - val_accuracy: 0.8654 - lr: 1.0000e-04 - 497ms/epoch - 7ms/step
# Epoch 112/1024
# 68/68 - 0s - loss: 0.3234 - accuracy: 0.8573 - val_loss: 0.3052 - val_accuracy: 0.8655 - lr: 1.0000e-04 - 478ms/epoch - 7ms/step
# Epoch 113/1024
# 68/68 - 0s - loss: 0.3228 - accuracy: 0.8572 - val_loss: 0.3049 - val_accuracy: 0.8657 - lr: 1.0000e-04 - 469ms/epoch - 7ms/step
# Epoch 114/1024
# 68/68 - 0s - loss: 0.3229 - accuracy: 0.8579 - val_loss: 0.3050 - val_accuracy: 0.8656 - lr: 1.0000e-04 - 483ms/epoch - 7ms/step
# Epoch 115/1024
# 68/68 - 0s - loss: 0.3228 - accuracy: 0.8575 - val_loss: 0.3049 - val_accuracy: 0.8659 - lr: 1.0000e-04 - 490ms/epoch - 7ms/step
# Epoch 116/1024
# 68/68 - 1s - loss: 0.3227 - accuracy: 0.8578 - val_loss: 0.3050 - val_accuracy: 0.8656 - lr: 1.0000e-04 - 514ms/epoch - 8ms/step
# Epoch 117/1024
# 68/68 - 1s - loss: 0.3230 - accuracy: 0.8574 - val_loss: 0.3047 - val_accuracy: 0.8658 - lr: 1.0000e-04 - 513ms/epoch - 8ms/step
# Epoch 118/1024
# 68/68 - 0s - loss: 0.3227 - accuracy: 0.8578 - val_loss: 0.3048 - val_accuracy: 0.8658 - lr: 1.0000e-04 - 487ms/epoch - 7ms/step
# Epoch 119/1024
# 68/68 - 1s - loss: 0.3226 - accuracy: 0.8575 - val_loss: 0.3047 - val_accuracy: 0.8660 - lr: 1.0000e-04 - 515ms/epoch - 8ms/step
# Epoch 120/1024
# 68/68 - 0s - loss: 0.3219 - accuracy: 0.8578 - val_loss: 0.3046 - val_accuracy: 0.8660 - lr: 1.0000e-04 - 499ms/epoch - 7ms/step
# Epoch 121/1024
# 68/68 - 1s - loss: 0.3219 - accuracy: 0.8579 - val_loss: 0.3048 - val_accuracy: 0.8658 - lr: 1.0000e-04 - 515ms/epoch - 8ms/step
# Epoch 122/1024
# 68/68 - 1s - loss: 0.3216 - accuracy: 0.8581 - val_loss: 0.3048 - val_accuracy: 0.8660 - lr: 1.0000e-04 - 534ms/epoch - 8ms/step
# Epoch 123/1024
# 68/68 - 1s - loss: 0.3219 - accuracy: 0.8579 - val_loss: 0.3047 - val_accuracy: 0.8661 - lr: 1.0000e-04 - 520ms/epoch - 8ms/step
# Epoch 124/1024
# 68/68 - 0s - loss: 0.3214 - accuracy: 0.8585 - val_loss: 0.3045 - val_accuracy: 0.8659 - lr: 1.0000e-04 - 498ms/epoch - 7ms/step
# Epoch 125/1024
# 68/68 - 1s - loss: 0.3214 - accuracy: 0.8583 - val_loss: 0.3044 - val_accuracy: 0.8661 - lr: 1.0000e-04 - 510ms/epoch - 8ms/step
# Epoch 126/1024
# 68/68 - 1s - loss: 0.3211 - accuracy: 0.8583 - val_loss: 0.3042 - val_accuracy: 0.8662 - lr: 1.0000e-04 - 508ms/epoch - 7ms/step
# Epoch 127/1024
# 68/68 - 1s - loss: 0.3216 - accuracy: 0.8582 - val_loss: 0.3040 - val_accuracy: 0.8661 - lr: 1.0000e-04 - 506ms/epoch - 7ms/step
# Epoch 128/1024
# 68/68 - 1s - loss: 0.3212 - accuracy: 0.8583 - val_loss: 0.3041 - val_accuracy: 0.8661 - lr: 1.0000e-04 - 511ms/epoch - 8ms/step
# Epoch 129/1024
# 68/68 - 1s - loss: 0.3212 - accuracy: 0.8583 - val_loss: 0.3043 - val_accuracy: 0.8661 - lr: 9.9990e-05 - 508ms/epoch - 7ms/step
# Epoch 130/1024
# 68/68 - 1s - loss: 0.3209 - accuracy: 0.8582 - val_loss: 0.3041 - val_accuracy: 0.8661 - lr: 9.9980e-05 - 519ms/epoch - 8ms/step
# Epoch 131/1024
# 68/68 - 1s - loss: 0.3206 - accuracy: 0.8581 - val_loss: 0.3040 - val_accuracy: 0.8660 - lr: 9.9970e-05 - 556ms/epoch - 8ms/step
# Epoch 132/1024
# 68/68 - 1s - loss: 0.3204 - accuracy: 0.8587 - val_loss: 0.3039 - val_accuracy: 0.8662 - lr: 9.9960e-05 - 551ms/epoch - 8ms/step
# Epoch 133/1024
# 68/68 - 1s - loss: 0.3203 - accuracy: 0.8585 - val_loss: 0.3041 - val_accuracy: 0.8659 - lr: 9.9950e-05 - 521ms/epoch - 8ms/step
# Epoch 134/1024
# 68/68 - 1s - loss: 0.3200 - accuracy: 0.8588 - val_loss: 0.3040 - val_accuracy: 0.8660 - lr: 9.9940e-05 - 534ms/epoch - 8ms/step
# Epoch 135/1024
# 68/68 - 0s - loss: 0.3200 - accuracy: 0.8587 - val_loss: 0.3038 - val_accuracy: 0.8663 - lr: 9.9930e-05 - 498ms/epoch - 7ms/step
# Epoch 136/1024
# 68/68 - 1s - loss: 0.3200 - accuracy: 0.8589 - val_loss: 0.3037 - val_accuracy: 0.8662 - lr: 9.9920e-05 - 526ms/epoch - 8ms/step
# Epoch 137/1024
# 68/68 - 1s - loss: 0.3199 - accuracy: 0.8591 - val_loss: 0.3038 - val_accuracy: 0.8660 - lr: 9.9910e-05 - 515ms/epoch - 8ms/step
# Epoch 138/1024
# 68/68 - 0s - loss: 0.3199 - accuracy: 0.8591 - val_loss: 0.3035 - val_accuracy: 0.8663 - lr: 9.9900e-05 - 497ms/epoch - 7ms/step
# Epoch 139/1024
# 68/68 - 1s - loss: 0.3197 - accuracy: 0.8588 - val_loss: 0.3036 - val_accuracy: 0.8660 - lr: 9.9890e-05 - 552ms/epoch - 8ms/step
# Epoch 140/1024
# 68/68 - 1s - loss: 0.3196 - accuracy: 0.8594 - val_loss: 0.3037 - val_accuracy: 0.8660 - lr: 9.9880e-05 - 548ms/epoch - 8ms/step
# Epoch 141/1024
# 68/68 - 1s - loss: 0.3197 - accuracy: 0.8592 - val_loss: 0.3035 - val_accuracy: 0.8663 - lr: 9.9870e-05 - 552ms/epoch - 8ms/step
# Epoch 142/1024
# 68/68 - 1s - loss: 0.3197 - accuracy: 0.8590 - val_loss: 0.3034 - val_accuracy: 0.8664 - lr: 9.9860e-05 - 575ms/epoch - 8ms/step
# Epoch 143/1024
# 68/68 - 1s - loss: 0.3197 - accuracy: 0.8591 - val_loss: 0.3034 - val_accuracy: 0.8665 - lr: 9.9850e-05 - 549ms/epoch - 8ms/step
# Epoch 144/1024
# 68/68 - 1s - loss: 0.3192 - accuracy: 0.8594 - val_loss: 0.3032 - val_accuracy: 0.8664 - lr: 9.9840e-05 - 565ms/epoch - 8ms/step
# Epoch 145/1024
# 68/68 - 1s - loss: 0.3193 - accuracy: 0.8588 - val_loss: 0.3032 - val_accuracy: 0.8665 - lr: 9.9830e-05 - 518ms/epoch - 8ms/step
# Epoch 146/1024
# 68/68 - 1s - loss: 0.3193 - accuracy: 0.8593 - val_loss: 0.3032 - val_accuracy: 0.8663 - lr: 9.9820e-05 - 539ms/epoch - 8ms/step
# Epoch 147/1024
# 68/68 - 1s - loss: 0.3190 - accuracy: 0.8592 - val_loss: 0.3032 - val_accuracy: 0.8664 - lr: 9.9810e-05 - 590ms/epoch - 9ms/step
# Epoch 148/1024
# 68/68 - 1s - loss: 0.3191 - accuracy: 0.8587 - val_loss: 0.3035 - val_accuracy: 0.8664 - lr: 9.9800e-05 - 558ms/epoch - 8ms/step
# Epoch 149/1024
# 68/68 - 1s - loss: 0.3189 - accuracy: 0.8592 - val_loss: 0.3030 - val_accuracy: 0.8662 - lr: 9.9790e-05 - 528ms/epoch - 8ms/step
# Epoch 150/1024
# 68/68 - 1s - loss: 0.3187 - accuracy: 0.8594 - val_loss: 0.3030 - val_accuracy: 0.8662 - lr: 9.9780e-05 - 545ms/epoch - 8ms/step
# Epoch 151/1024
# 68/68 - 1s - loss: 0.3187 - accuracy: 0.8595 - val_loss: 0.3030 - val_accuracy: 0.8663 - lr: 9.9770e-05 - 536ms/epoch - 8ms/step
# Epoch 152/1024
# 68/68 - 1s - loss: 0.3184 - accuracy: 0.8596 - val_loss: 0.3030 - val_accuracy: 0.8662 - lr: 9.9760e-05 - 541ms/epoch - 8ms/step
# Epoch 153/1024
# 68/68 - 1s - loss: 0.3190 - accuracy: 0.8593 - val_loss: 0.3028 - val_accuracy: 0.8665 - lr: 9.9750e-05 - 532ms/epoch - 8ms/step
# Epoch 154/1024
# 68/68 - 1s - loss: 0.3186 - accuracy: 0.8594 - val_loss: 0.3026 - val_accuracy: 0.8665 - lr: 9.9740e-05 - 510ms/epoch - 8ms/step
# Epoch 155/1024
# 68/68 - 1s - loss: 0.3187 - accuracy: 0.8593 - val_loss: 0.3028 - val_accuracy: 0.8666 - lr: 9.9730e-05 - 547ms/epoch - 8ms/step
# Epoch 156/1024
# 68/68 - 1s - loss: 0.3186 - accuracy: 0.8594 - val_loss: 0.3027 - val_accuracy: 0.8664 - lr: 9.9720e-05 - 579ms/epoch - 9ms/step
# Epoch 157/1024
# 68/68 - 1s - loss: 0.3183 - accuracy: 0.8593 - val_loss: 0.3026 - val_accuracy: 0.8665 - lr: 9.9711e-05 - 588ms/epoch - 9ms/step
# Epoch 158/1024
# 68/68 - 1s - loss: 0.3181 - accuracy: 0.8594 - val_loss: 0.3028 - val_accuracy: 0.8665 - lr: 9.9701e-05 - 546ms/epoch - 8ms/step
# Epoch 159/1024
# 68/68 - 1s - loss: 0.3176 - accuracy: 0.8600 - val_loss: 0.3025 - val_accuracy: 0.8665 - lr: 9.9691e-05 - 538ms/epoch - 8ms/step
# Epoch 160/1024
# 68/68 - 1s - loss: 0.3181 - accuracy: 0.8593 - val_loss: 0.3027 - val_accuracy: 0.8665 - lr: 9.9681e-05 - 505ms/epoch - 7ms/step
# Epoch 161/1024
# 68/68 - 0s - loss: 0.3179 - accuracy: 0.8596 - val_loss: 0.3026 - val_accuracy: 0.8664 - lr: 9.9671e-05 - 499ms/epoch - 7ms/step
# Epoch 162/1024
# 68/68 - 0s - loss: 0.3179 - accuracy: 0.8597 - val_loss: 0.3024 - val_accuracy: 0.8664 - lr: 9.9661e-05 - 489ms/epoch - 7ms/step
# Epoch 163/1024
# 68/68 - 0s - loss: 0.3176 - accuracy: 0.8601 - val_loss: 0.3027 - val_accuracy: 0.8664 - lr: 9.9651e-05 - 488ms/epoch - 7ms/step
# Epoch 164/1024
# 68/68 - 0s - loss: 0.3177 - accuracy: 0.8595 - val_loss: 0.3023 - val_accuracy: 0.8666 - lr: 9.9641e-05 - 489ms/epoch - 7ms/step
# Epoch 165/1024
# 68/68 - 1s - loss: 0.3174 - accuracy: 0.8597 - val_loss: 0.3022 - val_accuracy: 0.8665 - lr: 9.9631e-05 - 514ms/epoch - 8ms/step
# Epoch 166/1024
# 68/68 - 1s - loss: 0.3171 - accuracy: 0.8600 - val_loss: 0.3022 - val_accuracy: 0.8664 - lr: 9.9621e-05 - 537ms/epoch - 8ms/step
# Epoch 167/1024
# 68/68 - 1s - loss: 0.3174 - accuracy: 0.8596 - val_loss: 0.3021 - val_accuracy: 0.8664 - lr: 9.9611e-05 - 618ms/epoch - 9ms/step
# Epoch 168/1024
# 68/68 - 1s - loss: 0.3174 - accuracy: 0.8599 - val_loss: 0.3024 - val_accuracy: 0.8664 - lr: 9.9601e-05 - 554ms/epoch - 8ms/step
# Epoch 169/1024
# 68/68 - 1s - loss: 0.3170 - accuracy: 0.8602 - val_loss: 0.3020 - val_accuracy: 0.8665 - lr: 9.9591e-05 - 572ms/epoch - 8ms/step
# Epoch 170/1024
# 68/68 - 1s - loss: 0.3174 - accuracy: 0.8597 - val_loss: 0.3021 - val_accuracy: 0.8665 - lr: 9.9581e-05 - 590ms/epoch - 9ms/step
# Epoch 171/1024
# 68/68 - 1s - loss: 0.3175 - accuracy: 0.8599 - val_loss: 0.3021 - val_accuracy: 0.8664 - lr: 9.9571e-05 - 566ms/epoch - 8ms/step
# Epoch 172/1024
# 68/68 - 1s - loss: 0.3171 - accuracy: 0.8598 - val_loss: 0.3022 - val_accuracy: 0.8665 - lr: 9.9561e-05 - 560ms/epoch - 8ms/step
# Epoch 173/1024
# 68/68 - 1s - loss: 0.3170 - accuracy: 0.8602 - val_loss: 0.3019 - val_accuracy: 0.8666 - lr: 9.9551e-05 - 535ms/epoch - 8ms/step
# Epoch 174/1024
# 68/68 - 1s - loss: 0.3167 - accuracy: 0.8601 - val_loss: 0.3021 - val_accuracy: 0.8665 - lr: 9.9541e-05 - 530ms/epoch - 8ms/step
# Epoch 175/1024
# 68/68 - 1s - loss: 0.3169 - accuracy: 0.8600 - val_loss: 0.3020 - val_accuracy: 0.8666 - lr: 9.9531e-05 - 558ms/epoch - 8ms/step
# Epoch 176/1024
# 68/68 - 1s - loss: 0.3169 - accuracy: 0.8597 - val_loss: 0.3019 - val_accuracy: 0.8666 - lr: 9.9521e-05 - 574ms/epoch - 8ms/step
# Epoch 177/1024
# 68/68 - 1s - loss: 0.3165 - accuracy: 0.8602 - val_loss: 0.3020 - val_accuracy: 0.8666 - lr: 9.9511e-05 - 558ms/epoch - 8ms/step
# Epoch 178/1024
# 68/68 - 1s - loss: 0.3164 - accuracy: 0.8605 - val_loss: 0.3019 - val_accuracy: 0.8665 - lr: 9.9501e-05 - 536ms/epoch - 8ms/step
# Epoch 179/1024
# 68/68 - 1s - loss: 0.3164 - accuracy: 0.8601 - val_loss: 0.3017 - val_accuracy: 0.8666 - lr: 9.9491e-05 - 524ms/epoch - 8ms/step
# Epoch 180/1024
# 68/68 - 1s - loss: 0.3163 - accuracy: 0.8608 - val_loss: 0.3019 - val_accuracy: 0.8666 - lr: 9.9482e-05 - 523ms/epoch - 8ms/step
# Epoch 181/1024
# 68/68 - 1s - loss: 0.3164 - accuracy: 0.8600 - val_loss: 0.3018 - val_accuracy: 0.8665 - lr: 9.9472e-05 - 541ms/epoch - 8ms/step
# Epoch 182/1024
# 68/68 - 1s - loss: 0.3164 - accuracy: 0.8601 - val_loss: 0.3017 - val_accuracy: 0.8666 - lr: 9.9462e-05 - 519ms/epoch - 8ms/step
# Epoch 183/1024
# 68/68 - 1s - loss: 0.3163 - accuracy: 0.8601 - val_loss: 0.3018 - val_accuracy: 0.8665 - lr: 9.9452e-05 - 533ms/epoch - 8ms/step
# Epoch 184/1024
# 68/68 - 1s - loss: 0.3162 - accuracy: 0.8604 - val_loss: 0.3018 - val_accuracy: 0.8666 - lr: 9.9442e-05 - 562ms/epoch - 8ms/step
# Epoch 185/1024
# 68/68 - 1s - loss: 0.3164 - accuracy: 0.8602 - val_loss: 0.3015 - val_accuracy: 0.8666 - lr: 9.9432e-05 - 563ms/epoch - 8ms/step
# Epoch 186/1024
# 68/68 - 1s - loss: 0.3159 - accuracy: 0.8604 - val_loss: 0.3018 - val_accuracy: 0.8665 - lr: 9.9422e-05 - 509ms/epoch - 7ms/step
# Epoch 187/1024
# 68/68 - 1s - loss: 0.3162 - accuracy: 0.8606 - val_loss: 0.3015 - val_accuracy: 0.8667 - lr: 9.9412e-05 - 505ms/epoch - 7ms/step
# Epoch 188/1024
# 68/68 - 1s - loss: 0.3162 - accuracy: 0.8602 - val_loss: 0.3016 - val_accuracy: 0.8667 - lr: 9.9402e-05 - 515ms/epoch - 8ms/step
# Epoch 189/1024
# 68/68 - 1s - loss: 0.3161 - accuracy: 0.8608 - val_loss: 0.3017 - val_accuracy: 0.8667 - lr: 9.9392e-05 - 514ms/epoch - 8ms/step
# Epoch 190/1024
# 68/68 - 0s - loss: 0.3158 - accuracy: 0.8606 - val_loss: 0.3015 - val_accuracy: 0.8666 - lr: 9.9382e-05 - 492ms/epoch - 7ms/step
# Epoch 191/1024
# 68/68 - 1s - loss: 0.3159 - accuracy: 0.8605 - val_loss: 0.3016 - val_accuracy: 0.8666 - lr: 9.9372e-05 - 563ms/epoch - 8ms/step
# Epoch 192/1024
# 68/68 - 1s - loss: 0.3156 - accuracy: 0.8605 - val_loss: 0.3014 - val_accuracy: 0.8667 - lr: 9.9362e-05 - 558ms/epoch - 8ms/step
# Epoch 193/1024
# 68/68 - 1s - loss: 0.3158 - accuracy: 0.8606 - val_loss: 0.3016 - val_accuracy: 0.8668 - lr: 9.9352e-05 - 588ms/epoch - 9ms/step
# Epoch 194/1024
# 68/68 - 1s - loss: 0.3156 - accuracy: 0.8608 - val_loss: 0.3012 - val_accuracy: 0.8668 - lr: 9.9342e-05 - 581ms/epoch - 9ms/step
# Epoch 195/1024
# 68/68 - 1s - loss: 0.3153 - accuracy: 0.8608 - val_loss: 0.3014 - val_accuracy: 0.8667 - lr: 9.9332e-05 - 574ms/epoch - 8ms/step
# Epoch 196/1024
# 68/68 - 1s - loss: 0.3151 - accuracy: 0.8610 - val_loss: 0.3014 - val_accuracy: 0.8666 - lr: 9.9323e-05 - 566ms/epoch - 8ms/step
# Epoch 197/1024
# 68/68 - 1s - loss: 0.3152 - accuracy: 0.8607 - val_loss: 0.3013 - val_accuracy: 0.8668 - lr: 9.9313e-05 - 576ms/epoch - 8ms/step
# Epoch 198/1024
# 68/68 - 1s - loss: 0.3153 - accuracy: 0.8604 - val_loss: 0.3015 - val_accuracy: 0.8667 - lr: 9.9303e-05 - 539ms/epoch - 8ms/step
# Epoch 199/1024
# 68/68 - 1s - loss: 0.3152 - accuracy: 0.8607 - val_loss: 0.3013 - val_accuracy: 0.8667 - lr: 9.9293e-05 - 549ms/epoch - 8ms/step
# Epoch 200/1024
# 68/68 - 1s - loss: 0.3151 - accuracy: 0.8611 - val_loss: 0.3011 - val_accuracy: 0.8669 - lr: 9.9283e-05 - 566ms/epoch - 8ms/step
# Epoch 201/1024
# 68/68 - 1s - loss: 0.3152 - accuracy: 0.8602 - val_loss: 0.3012 - val_accuracy: 0.8668 - lr: 9.9273e-05 - 582ms/epoch - 9ms/step
# Epoch 202/1024
# 68/68 - 1s - loss: 0.3152 - accuracy: 0.8610 - val_loss: 0.3010 - val_accuracy: 0.8667 - lr: 9.9263e-05 - 559ms/epoch - 8ms/step
# Epoch 203/1024
# 68/68 - 1s - loss: 0.3149 - accuracy: 0.8607 - val_loss: 0.3009 - val_accuracy: 0.8666 - lr: 9.9253e-05 - 516ms/epoch - 8ms/step
# Epoch 204/1024
# 68/68 - 1s - loss: 0.3153 - accuracy: 0.8605 - val_loss: 0.3010 - val_accuracy: 0.8666 - lr: 9.9243e-05 - 560ms/epoch - 8ms/step
# Epoch 205/1024
# 68/68 - 1s - loss: 0.3147 - accuracy: 0.8611 - val_loss: 0.3010 - val_accuracy: 0.8668 - lr: 9.9233e-05 - 521ms/epoch - 8ms/step

# %%
# Make a directory
dir_name = HOME_PATH + "/6th_trial/classifier/"
name = "shell_classifier"

# If the directory exists
if os.path.exists(dir_name):
    test_files = glob.glob(dir_name + "*" + name + "*")
    if test_files:
        for file in test_files:
            os.remove(file)
        print(f"Directory {dir_name} cleaned.")
    print(f"Directory {dir_name} exists.")
else:
    os.makedirs(dir_name)
    print(f"Directory {dir_name} created.")

# save model
model.save(dir_name + name + ".keras", save_format="keras", overwrite=True)

# predict
pred_y = model.predict(test_x)
# save predicted results
np.savez_compressed(dir_name + name + "_data.npz", pred_y=pred_y, test_y=test_y)
sig_pred = np.load(dir_name + name + "_data.npz")["pred_y"].flatten()
sig_truth = np.load(dir_name + name + "_data.npz")["test_y"].flatten()
# Out:
# Directory /root/work/QE-mls/6th_trial/classifier/ cleaned.
# Directory /root/work/QE-mls/6th_trial/classifier/ exists.
# 12924/12924 [==============================] - 18s 1ms/step

# %%
fig = plt.figure(figsize=(6,6), dpi=80)
plt.subplot(2,1,1)
plt.plot(history.history['loss'], lw=3, label='Train')
plt.plot(history.history['val_loss'], lw=3, label='Validation')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.legend()
plt.subplot(2,1,2)
plt.plot(history.history['accuracy'], lw=3, label='Train')
plt.plot(history.history['val_accuracy'], lw=3, label='Validation')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend()
plt.show()

predicted = tf.squeeze(sig_pred) # ensure the dimension is correct (dim-1)
predicted = np.where(predicted >= 0.5, 1, 0)
labeled = np.where(sig_truth >= 0.5, 1, 0)
actual = np.array(sig_truth)

conf_mat = confusion_matrix(actual, predicted)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat, display_labels=["Off-shell", "On-shell"]) 
displ.plot(cmap='Blues')

# %%
pred_lead_w_m = w_lead["m"][test_indices].reset_index()
pred_sublead_w_m = w_sublead["m"][test_indices].reset_index()
truth_lead_w_m = w_lead["m"][test_indices].reset_index()
truth_sublead_w_m = w_sublead["m"][test_indices].reset_index()
pred_lead_on_mask = predicted.astype(bool)
pred_sublead_on_mask = ~predicted.astype(bool)
label_lead_on_mask = labeled.astype(bool)
label_sublead_on_mask = ~labeled.astype(bool)
pred_w_onshell = pd.concat([pred_lead_w_m[pred_lead_on_mask],pred_sublead_w_m[pred_sublead_on_mask]], axis=0).sort_index()
pred_w_offshell = pd.concat([pred_lead_w_m[pred_sublead_on_mask],pred_sublead_w_m[pred_lead_on_mask]], axis=0).sort_index()
w_onshell = pd.concat([truth_lead_w_m[label_lead_on_mask], truth_sublead_w_m[label_sublead_on_mask]], axis=0).sort_index()
w_offshell = pd.concat([truth_lead_w_m[label_sublead_on_mask], truth_sublead_w_m[label_lead_on_mask]], axis=0).sort_index()

ml_acc = np.sum(predicted*1) / len(predicted)
print(f"ML accuracy: {ml_acc:0.2f}")
print(f"ML (base) improve: {100 * (ml_acc - base_acc):.2f}%")
print(f"ML (cuts) improve: {100 * (ml_acc - cut_acc):.2f}%")


figure = plt.figure(figsize=(10, 6), dpi=120)
bin_edges = np.linspace(0, 110, 121)
plt.hist(w_onshell["m"] / GEV, bins=bin_edges, color="r", histtype="step", label=r"Labeled   $W^{on}$")
plt.hist(w_offshell["m"] / GEV, bins=bin_edges, color="b", histtype="step", label=r"Labeled   $W^{off}$")
plt.hist(pred_w_onshell["m"] / GEV, bins=bin_edges, color="tab:red", histtype="bar", alpha=0.3, label=r"Predicted $W^{on}$")
plt.hist(pred_w_offshell["m"] / GEV, bins=bin_edges, color="tab:blue", histtype="bar", alpha=0.3, label=r"Predicted $W^{off}$")
plt.title("W mass")
plt.xlabel("mass [GeV]")
plt.ylabel("count")
plt.legend(loc="best")
plt.show()
plt.close()
# Out:
# ML accuracy: 0.88
# ML (base) improve: 5.15%
# ML (cuts) improve: 6.90%

# %%
import shap
import matplotlib as mpl

mpl.rcParams.update(mpl.rcParamsDefault)

feature_names = [
    "lead_px",
    "lead_py",
    "lead_pz",
    "lead_E",
    "lead_pt",
    "lead_eta",
    "lead_phi",
    "sublead_px",
    "sublead_py",
    "sublead_pz",
    "sublead_E",
    "sublead_pt",
    "sublead_eta",
    "sublead_phi",
    "met_px",
    "met_py",
    "met_pt",
    "met_phi",
    "dilep_px",
    "dilep_py",
    "dilep_pz",
    "dilep_E",
    "dilep_pt",
    "dilep_eta",
    "dilep_phi",
    "dilep_m",
]

# Use DeepExplainer for SHAP values
explainer = shap.DeepExplainer(model, obs_kin[:1_024])
shap_values = explainer.shap_values(obs_kin[:1_024])
for i in range(shap_values.shape[-1]):
    plt.figure(figsize=(10, 6))
    shap.summary_plot(
        shap_values[:, :, i],
        obs_kin[:1_024],
        feature_names=feature_names,
        plot_type="dot",
        show=False,
    )
    plt.title(f"SHAP Summary Plot for on-off Classifications")
    plt.show()
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
