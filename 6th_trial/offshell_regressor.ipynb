# %%
# %reset -sf

import tensorflow as tf
print(tf.__version__)


# GPU(s) setups
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the first GPU
        tf.config.set_visible_devices(gpus[1], 'GPU')
        
        # Instead of enabling memory growth, set a memory limit
        memory_limit = 16_384*2 # Set the memory limit in MB
        # tf.config.experimental.set_virtual_device_configuration(
        #     gpus[1],
        #     [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)]
        # )
        
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2024-08-31 13:18:24.873412: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.13.0
# 2 Physical GPUs, 1 Logical GPU
# 2024-08-31 13:18:29.624257: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 42314 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:25:00.0, compute capability: 8.6

# %%
import sys
import os
import glob
HOME_PATH = os.path.abspath("..")
sys.path.insert(0, HOME_PATH+"/qe")

import get_data as gd
import atlas_plot as ap
plot = ap.Plotter()

# INN packages
from flow import *
from utils import *

import pandas as pd
import numpy as np
import scipy as sp

from matplotlib import pyplot as plt
import matplotlib as mpl
import shap

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
SEED = 42  # set random seed (global variable)
np.random.seed(SEED)
processor = gd.DataProcessor()
path = "/root/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 76
#
# ['/root/data/truth/signal/CGLMP.npz', '/root/data/truth/signal/Higgs.npz', '/root/data/truth/signal/LeadLepton.npz', '/root/data/truth/signal/LeptonM.npz', '/root/data/truth/signal/LeptonP.npz', '/root/data/truth/signal/LmNu.npz', '/root/data/truth/signal/LpNu.npz', '/root/data/truth/signal/MET.npz', '/root/data/truth/signal/WmBoson.npz', '/root/data/truth/signal/WpBoson.npz', '/root/data/truth/signal/diLepton.npz', '/root/data/truth/signal/subLeadLepton.npz', '/root/data/truth/signal/xi_xyz.npz']

# %%
## Global variables

GEV = 1e3

cut_pre_pt_lead = data.LeadLep["pt"] > 22 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
cut_pre_pt_miss = data.MET["pt"] > 20 * GEV

PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

BATCH_SIZE = 8_192*2
EPOCHS = 1_024
LEARNING_RATE = 1e-4

# %%
## Observing variables

lead_lep = data.LeadLep[["px", "py", "pz", "E", "pt", "eta", "phi"]]
sublead_lep = data.SubLep[["px", "py", "pz", "E", "pt", "eta", "phi"]]
met = data.MET[["px", "py", "pt", "phi"]]
di_lep = data.diLep[["px", "py", "pz", "E", "pt", "eta", "phi", "m"]]

# Kinematics of observing variables (inputs for training)
obs_kin = pd.concat([lead_lep, sublead_lep, met, di_lep], axis=1)[PRE_CUT]
print("int_kin shape:", obs_kin.shape)
# print(print(obs_kin.describe()))
# obs_kin = obs_kin.to_numpy() # convert to numpy array
ROBUST_OBS = RobustScaler()
obs_kin = ROBUST_OBS.fit_transform(obs_kin)
print(type(obs_kin))
# Out:
# int_kin shape: (1378510, 26)
# <class 'numpy.ndarray'>

# %%
cla = tf.keras.models.load_model('./classifier/shell_classifier.keras')
cla.summary()
pred_onshell_label = cla.predict(obs_kin)
pred_onshell_label = np.squeeze(np.where(pred_onshell_label >= 0.5, 1, 0))
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 26)]              0
#
#  flatten_3 (Flatten)         (None, 26)                0
#
#  dense_21 (Dense)            (None, 128)               3456
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_22 (Dense)            (None, 512)               66048
#
#  dropout_13 (Dropout)        (None, 512)               0
#
#  dense_23 (Dense)            (None, 512)               262656
#
#  dropout_14 (Dropout)        (None, 512)               0
#
#  dense_24 (Dense)            (None, 64)                32832
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_25 (Dense)            (None, 16)                1040
#
#  dropout_16 (Dropout)        (None, 16)                0
#
#  dense_26 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 366049 (1.40 MB)
# Trainable params: 366049 (1.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#    39/43079 [..............................] - ETA: 2:55
# 2024-08-31 13:18:51.152729: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 43079/43079 [==============================] - 171s 4ms/step

# %%
## Interesting variables

# Critria for leading and subleading lepton
lead_p = data.LeadLep["m"] == data.LepP["m"]
sublead_p = ~lead_p
lead_m = sublead_p.copy()
sublead_m = lead_p.copy()

# (sub)lead W
w_lead = pd.concat([data.Wp[lead_p], data.Wm[lead_m]], axis=0).sort_index()
w_sublead = pd.concat([data.Wp[sublead_p], data.Wm[sublead_m]], axis=0).sort_index()
w_onshell = pd.concat([w_lead[PRE_CUT] [pred_onshell_label.astype(bool)], w_sublead[PRE_CUT] [~pred_onshell_label.astype(bool)]], axis=0).sort_index()
w_offshell = pd.concat([w_lead[PRE_CUT] [~pred_onshell_label.astype(bool)], w_sublead[PRE_CUT] [pred_onshell_label.astype(bool)]], axis=0).sort_index()

# Kinematics of interesting variables (target for training)
int_kin = w_offshell[["px", "py", "pz", "E"]] / GEV
print("int_kin shape:", int_kin.shape)
int_kin = int_kin.to_numpy() # convert to numpy array
print(type(int_kin))
# Out:
# int_kin shape: (1378510, 4)
# <class 'numpy.ndarray'>

# %%
# Analyze the classifier for onshell and offshell W

base_acc = w_lead[w_lead["m"] > w_sublead["m"]].shape[0] / w_lead.shape[0]
cut_acc  = w_lead[(w_lead["m"] > w_sublead["m"]) & PRE_CUT].shape[0] / w_lead[PRE_CUT].shape[0]
print(f"Base accuracy: {base_acc:.2f}")
print(f"Cut  accuracy: {cut_acc:.2f}")
print(f">> Cuts improve: {100 * (cut_acc - base_acc):.2f}%")
ml_acc = np.sum(pred_onshell_label) / len(pred_onshell_label.astype(bool))
print(f"ML accuracy: {ml_acc:0.2f}")
print(f">> ML (base) improve: {100 * (ml_acc - base_acc):.2f}%")
print(f">> ML (cuts) improve: {100 * (ml_acc - cut_acc):.2f}%")


figure = plt.figure(figsize=(10, 6), dpi=120)
bin_edges = np.linspace(0, 110, 121)
plt.hist(w_lead["m"] / GEV, bins=bin_edges, color="r", histtype="step", density=True, label=r"Labeled   $W^{on}$")
plt.hist(w_sublead["m"] / GEV, bins=bin_edges, color="b", histtype="step", density=True, label=r"Labeled   $W^{off}$")
plt.hist(w_onshell["m"] / GEV, bins=bin_edges, color="tab:red", histtype="bar", density=True, alpha=0.3, label=r"Predicted $W^{on}$")
plt.hist(w_offshell["m"] / GEV, bins=bin_edges, color="tab:blue", histtype="bar", density=True, alpha=0.3, label=r"Predicted $W^{off}$")
plt.title("W mass")
plt.xlabel("mass [GeV]")
plt.ylabel("normalized count")
plt.legend(loc="best")
plt.show()
plt.close()
# Out:
# Base accuracy: 0.83
# Cut  accuracy: 0.81
# >> Cuts improve: -1.75%
# ML accuracy: 0.88
# >> ML (base) improve: 5.12%
# >> ML (cuts) improve: 6.88%

# %%
# Train test split

indices_arr = np.arange(int_kin.shape[0], dtype="int")
train_indices, temp_indices = train_test_split(
    indices_arr.flatten(),
    train_size=0.4,
    test_size=0.6,
    random_state=SEED,
    shuffle=True,
)
valid_indices, test_indices = train_test_split(
    temp_indices, train_size=0.5, test_size=0.5, random_state=SEED
)

train_x = obs_kin[train_indices]
test_x = obs_kin[test_indices]
valid_x = obs_kin[valid_indices]
train_y = int_kin[train_indices]
test_y = int_kin[test_indices]
valid_y = int_kin[valid_indices]

print(
    f"X (Interest)\nTraining data shape: {train_x.shape};\nValiding data shape: {valid_x.shape};\nTesting data shape: {test_x.shape}."
)
print(
    f"Y (Observed)\nTraining data shape: {train_y.shape};\nValiding data shape: {valid_y.shape};\nTesting data shape: {test_y.shape}."
)
# Out:
# X (Interest)
# Training data shape: (551404, 26);
# Validing data shape: (413553, 26);
# Testing data shape: (413553, 26).
# Y (Observed)
# Training data shape: (551404, 4);
# Validing data shape: (413553, 4);
# Testing data shape: (413553, 4).

# %%
# TODO: test force time-like function

@tf.function
def force_timelike(x):
    px = x[:, 0]
    py = x[:, 1]
    pz = x[:, 2]
    energy = x[:, 3]
    e_squared = energy**2
    p_squared = px**2 + py**2 + pz**2
    condition = tf.greater_equal(e_squared, p_squared)
    penalty = tf.where(condition, 1.0, 0.0)  # Ensure penalty is float32
    penalty = tf.expand_dims(penalty, axis=-1)  # Expand dimensions to match x
    return penalty * x

# Mini example
x = tf.constant([
    [1, 2, 2, 2], # space-like
    [1, 2, 3, 10], # time-like
    ], dtype=tf.float32)
result = force_timelike(x)
print(result)
# Out:
# tf.Tensor(
# [[ 0.  0.  0.  0.]
#  [ 1.  2.  3. 10.]], shape=(2, 4), dtype=float32)

# %%
# Define a new activation function


def custom_activation(x):
    return (0.73 - (-0.27)) * (tf.tanh(x) + 1) / 2 + (-0.27)


class EPConstraint(tf.keras.constraints.Constraint):
    def __call__(self, w):
        # Ensure that energy-momentum are time-like case
        px = w[:, 0]
        py = w[:, 1]
        pz = w[:, 2]
        energy = w[:, 3]
        # Calculate the constraint
        constraint = tf.maximum(0.0, energy**2 - px**2 - py**2 - pz**2)
        # Create a mask for invalid four-vectors (constraint == 0)
        mask = tf.cast(tf.not_equal(constraint, 0.0), w.dtype)
        # If constraint is zero, set the entire four-vector to zero
        adjusted_w = w * tf.expand_dims(mask, axis=-1)
        return adjusted_w

@tf.function
def force_timelike(x):
    px = x[:, 0]
    py = x[:, 1]
    pz = x[:, 2]
    energy = x[:, 3]
    e_squared = energy**2
    p_squared = px**2 + py**2 + pz**2
    condition = tf.greater_equal(e_squared, p_squared)
    penalty = tf.where(condition, 1.0, 0.0)
    penalty = tf.expand_dims(penalty, axis=-1)  # Expand dimensions to match x
    return penalty * x

# Register the custom activation and constraint
tf.keras.utils.get_custom_objects().update({
    'EPConstraint': EPConstraint,
})


# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    # y = tf.keras.layers.Dense(units=4, activation="linear", kernel_constraint=EPConstraint())(x)
    for _ in range(1):
        # y = tf.keras.layers.Dense(units=4, activation="linear", kernel_constraint=EPConstraint())(y)
        x = tf.keras.layers.Dense(units=256, activation="selu")(x)
        # x = tf.keras.layers.Dropout(rate=0.1)(x)
        x = tf.keras.layers.Dense(units=256, activation="selu")(x)
    # x = tf.keras.layers.Concatenate()([x, y])
    for _ in range(3):
        x = tf.keras.layers.Dense(units=2048, activation="selu")(x)
        x = tf.keras.layers.Dropout(rate=0.3)(x)
        x = tf.keras.layers.Dense(units=2048, activation="selu")(x)
        x = tf.keras.layers.Dropout(rate=0.3)(x)
    # x = tf.keras.layers.Dropout(rate=0.2)(x)
        # x = tf.keras.layers.Dense(units=4, activation="linear", kernel_constraint=EPConstraint())(x)
    for _ in range(1):
        # y = tf.keras.layers.Dense(units=4, activation="linear", kernel_constraint=EPConstraint())(x)
        x = tf.keras.layers.Dense(units=128, activation="selu")(x)
        # x = tf.keras.layers.Dropout(rate=0.1)(x)
        x = tf.keras.layers.Dense(units=128, activation="selu")(x)
    # x = tf.keras.layers.Concatenate()([x, y])
    
    # x = tf.keras.layers.Dense(units=128, activation="selu")(x)
    # x = tf.keras.layers.Dense(units=128, activation="selu")(x)
    # x = tf.keras.layers.Dense(units=4, activation="linear", kernel_constraint=EPConstraint())(x)
    outputs = tf.keras.layers.Dense(units=4, activation="linear", kernel_constraint=EPConstraint())(x)
    # outputs = tf.keras.layers.Lambda(force_timelike)(x)
    
    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss=tf.losses.mean_absolute_error,
    )

    return model

# %%
model = build_model()
model.summary()
# tf.keras.utils.plot_model(model)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 26)]              0
#
#  flatten_1 (Flatten)         (None, 26)                0
#
#  dense_11 (Dense)            (None, 256)               6912
#
#  dense_12 (Dense)            (None, 256)               65792
#
#  dense_13 (Dense)            (None, 2048)              526336
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  dense_14 (Dense)            (None, 2048)              4196352
#
#  dropout_4 (Dropout)         (None, 2048)              0
#
#  dense_15 (Dense)            (None, 2048)              4196352
#
#  dropout_5 (Dropout)         (None, 2048)              0
#
#  dense_16 (Dense)            (None, 2048)              4196352
#
#  dropout_6 (Dropout)         (None, 2048)              0
#
#  dense_17 (Dense)            (None, 2048)              4196352
#
#  dropout_7 (Dropout)         (None, 2048)              0
#
#  dense_18 (Dense)            (None, 2048)              4196352
#
#  dropout_8 (Dropout)         (None, 2048)              0
#
#  dense_19 (Dense)            (None, 128)               262272
#
#  dense_20 (Dense)            (None, 128)               16512
#
#  dense_21 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 21860100 (83.39 MB)
# Trainable params: 21860100 (83.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-3,
    patience=32,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)


def scheduler(epoch, lr):
    if epoch < 256:
        return lr
    else:
        return lr * tf.math.exp(-0.001)


lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

# Fit the model
history = model.fit(
    x=train_x,
    y=train_y,
    validation_data=(valid_x, valid_y),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=2,
    callbacks=[stop_early,lr_scheduler],
)
# Out:
# Epoch 1/1024
# 34/34 - 9s - loss: 58.3330 - val_loss: 44.1227 - lr: 1.0000e-04 - 9s/epoch - 272ms/step
# Epoch 2/1024
# 34/34 - 5s - loss: 37.0306 - val_loss: 32.7160 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 3/1024
# 34/34 - 5s - loss: 34.1694 - val_loss: 31.8458 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 4/1024
# 34/34 - 5s - loss: 31.5583 - val_loss: 29.9053 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 5/1024
# 34/34 - 5s - loss: 30.3416 - val_loss: 29.3365 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 6/1024
# 34/34 - 5s - loss: 30.0267 - val_loss: 29.1965 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 7/1024
# 34/34 - 5s - loss: 29.9205 - val_loss: 29.0955 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 8/1024
# 34/34 - 5s - loss: 29.8051 - val_loss: 29.0129 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 9/1024
# 34/34 - 5s - loss: 29.7252 - val_loss: 28.9630 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 10/1024
# 34/34 - 5s - loss: 29.6801 - val_loss: 28.9223 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 11/1024
# 34/34 - 5s - loss: 29.6237 - val_loss: 28.9105 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 12/1024
# 34/34 - 5s - loss: 29.5789 - val_loss: 28.8587 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 13/1024
# 34/34 - 5s - loss: 29.5183 - val_loss: 28.8787 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 14/1024
# 34/34 - 5s - loss: 29.5208 - val_loss: 28.7994 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 15/1024
# 34/34 - 5s - loss: 29.4494 - val_loss: 28.7521 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 16/1024
# 34/34 - 5s - loss: 29.4068 - val_loss: 28.7828 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 17/1024
# 34/34 - 5s - loss: 29.3813 - val_loss: 28.6741 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 18/1024
# 34/34 - 5s - loss: 29.3133 - val_loss: 28.6486 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 19/1024
# 34/34 - 5s - loss: 29.2698 - val_loss: 28.6507 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 20/1024
# 34/34 - 5s - loss: 29.2773 - val_loss: 28.6145 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 21/1024
# 34/34 - 5s - loss: 29.2080 - val_loss: 28.6411 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 22/1024
# 34/34 - 5s - loss: 29.2160 - val_loss: 28.5100 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 23/1024
# 34/34 - 5s - loss: 29.1513 - val_loss: 28.4753 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 24/1024
# 34/34 - 5s - loss: 29.1375 - val_loss: 28.4393 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 25/1024
# 34/34 - 5s - loss: 29.0733 - val_loss: 28.4037 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 26/1024
# 34/34 - 5s - loss: 29.6246 - val_loss: 29.6200 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 27/1024
# 34/34 - 5s - loss: 29.4230 - val_loss: 28.4429 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 28/1024
# 34/34 - 5s - loss: 29.0133 - val_loss: 28.3952 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 29/1024
# 34/34 - 5s - loss: 28.9638 - val_loss: 28.2682 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 30/1024
# 34/34 - 5s - loss: 28.9448 - val_loss: 28.2231 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 31/1024
# 34/34 - 5s - loss: 28.8818 - val_loss: 28.3055 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 32/1024
# 34/34 - 5s - loss: 28.8341 - val_loss: 28.1649 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 33/1024
# 34/34 - 5s - loss: 28.7874 - val_loss: 28.1697 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 34/1024
# 34/34 - 5s - loss: 28.7437 - val_loss: 28.0940 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 35/1024
# 34/34 - 5s - loss: 28.7048 - val_loss: 28.0339 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 36/1024
# 34/34 - 5s - loss: 32.4425 - val_loss: 29.1437 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 37/1024
# 34/34 - 5s - loss: 29.1031 - val_loss: 28.0773 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 38/1024
# 34/34 - 5s - loss: 28.6996 - val_loss: 27.9398 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 39/1024
# 34/34 - 5s - loss: 28.6476 - val_loss: 27.9273 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 40/1024
# 34/34 - 5s - loss: 28.5774 - val_loss: 27.8546 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 41/1024
# 34/34 - 5s - loss: 28.5498 - val_loss: 27.7808 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 42/1024
# 34/34 - 5s - loss: 28.4703 - val_loss: 27.7264 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 43/1024
# 34/34 - 5s - loss: 28.4223 - val_loss: 27.7610 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 44/1024
# 34/34 - 5s - loss: 28.3796 - val_loss: 27.6279 - lr: 1.0000e-04 - 5s/epoch - 157ms/step
# Epoch 45/1024
# 34/34 - 5s - loss: 28.3026 - val_loss: 27.6134 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 46/1024
# 34/34 - 5s - loss: 28.2659 - val_loss: 27.5023 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 47/1024
# 34/34 - 5s - loss: 28.2159 - val_loss: 27.5002 - lr: 1.0000e-04 - 5s/epoch - 157ms/step
# Epoch 48/1024
# 34/34 - 5s - loss: 28.1840 - val_loss: 27.4433 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 49/1024
# 34/34 - 5s - loss: 28.1614 - val_loss: 27.4325 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 50/1024
# 34/34 - 5s - loss: 28.1306 - val_loss: 27.4326 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 51/1024
# 34/34 - 5s - loss: 28.0891 - val_loss: 27.3441 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 52/1024
# 34/34 - 5s - loss: 28.0473 - val_loss: 27.2928 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 53/1024
# 34/34 - 5s - loss: 27.9940 - val_loss: 27.3498 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 54/1024
# 34/34 - 5s - loss: 27.9838 - val_loss: 27.2650 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 55/1024
# 34/34 - 5s - loss: 27.9422 - val_loss: 27.2048 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 56/1024
# 34/34 - 5s - loss: 27.9218 - val_loss: 27.2352 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 57/1024
# 34/34 - 5s - loss: 27.8988 - val_loss: 27.1904 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 58/1024
# 34/34 - 5s - loss: 27.8678 - val_loss: 27.2217 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 59/1024
# 34/34 - 5s - loss: 27.8701 - val_loss: 27.1861 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 60/1024
# 34/34 - 5s - loss: 27.8368 - val_loss: 27.0931 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 61/1024
# 34/34 - 5s - loss: 27.8352 - val_loss: 27.1487 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 62/1024
# 34/34 - 5s - loss: 27.8169 - val_loss: 27.0717 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 63/1024
# 34/34 - 5s - loss: 27.7510 - val_loss: 27.2337 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 64/1024
# 34/34 - 5s - loss: 27.7694 - val_loss: 27.1014 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 65/1024
# 34/34 - 5s - loss: 27.7591 - val_loss: 27.0061 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 66/1024
# 34/34 - 5s - loss: 27.7645 - val_loss: 26.9894 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 67/1024
# 34/34 - 5s - loss: 27.6921 - val_loss: 26.9871 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 68/1024
# 34/34 - 5s - loss: 27.6729 - val_loss: 26.9543 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 69/1024
# 34/34 - 5s - loss: 27.6528 - val_loss: 26.9505 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 70/1024
# 34/34 - 5s - loss: 27.6445 - val_loss: 26.9364 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 71/1024
# 34/34 - 5s - loss: 27.6388 - val_loss: 26.9302 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 72/1024
# 34/34 - 5s - loss: 27.6162 - val_loss: 26.9180 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 73/1024
# 34/34 - 5s - loss: 27.6279 - val_loss: 26.9380 - lr: 1.0000e-04 - 5s/epoch - 157ms/step
# Epoch 74/1024
# 34/34 - 5s - loss: 27.5971 - val_loss: 26.9270 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 75/1024
# 34/34 - 5s - loss: 27.5539 - val_loss: 26.8989 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 76/1024
# 34/34 - 5s - loss: 27.5391 - val_loss: 26.8953 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 77/1024
# 34/34 - 5s - loss: 27.5508 - val_loss: 26.8648 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 78/1024
# 34/34 - 5s - loss: 27.5046 - val_loss: 26.8946 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 79/1024
# 34/34 - 5s - loss: 27.5026 - val_loss: 26.8104 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 80/1024
# 34/34 - 5s - loss: 27.4947 - val_loss: 26.8935 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 81/1024
# 34/34 - 5s - loss: 27.4888 - val_loss: 26.8078 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 82/1024
# 34/34 - 5s - loss: 27.4476 - val_loss: 26.8160 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 83/1024
# 34/34 - 5s - loss: 27.4415 - val_loss: 26.8859 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 84/1024
# 34/34 - 5s - loss: 27.4621 - val_loss: 26.7310 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 85/1024
# 34/34 - 5s - loss: 27.4259 - val_loss: 26.7747 - lr: 1.0000e-04 - 5s/epoch - 157ms/step
# Epoch 86/1024
# 34/34 - 5s - loss: 27.4270 - val_loss: 26.7253 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 87/1024
# 34/34 - 5s - loss: 27.4104 - val_loss: 26.7898 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 88/1024
# 34/34 - 5s - loss: 27.4037 - val_loss: 26.7535 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 89/1024
# 34/34 - 5s - loss: 27.3715 - val_loss: 26.7420 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 90/1024
# 34/34 - 5s - loss: 27.3628 - val_loss: 26.7659 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 91/1024
# 34/34 - 5s - loss: 27.3415 - val_loss: 26.7339 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 92/1024
# 34/34 - 5s - loss: 27.3565 - val_loss: 26.7393 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 93/1024
# 34/34 - 5s - loss: 27.3363 - val_loss: 26.6900 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 94/1024
# 34/34 - 5s - loss: 27.3254 - val_loss: 26.6990 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 95/1024
# 34/34 - 5s - loss: 27.3283 - val_loss: 26.6599 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 96/1024
# 34/34 - 5s - loss: 27.3096 - val_loss: 26.6886 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 97/1024
# 34/34 - 5s - loss: 27.2930 - val_loss: 26.6706 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 98/1024
# 34/34 - 5s - loss: 27.3035 - val_loss: 26.6308 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 99/1024
# 34/34 - 5s - loss: 27.2534 - val_loss: 26.7021 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 100/1024
# 34/34 - 5s - loss: 27.2732 - val_loss: 26.6619 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 101/1024
# 34/34 - 5s - loss: 27.2879 - val_loss: 26.7530 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 102/1024
# 34/34 - 5s - loss: 27.2660 - val_loss: 26.6326 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 103/1024
# 34/34 - 5s - loss: 27.2020 - val_loss: 26.6484 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 104/1024
# 34/34 - 5s - loss: 27.2266 - val_loss: 26.7036 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 105/1024
# 34/34 - 5s - loss: 27.2459 - val_loss: 26.6510 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 106/1024
# 34/34 - 5s - loss: 27.2060 - val_loss: 26.6556 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 107/1024
# 34/34 - 5s - loss: 27.2073 - val_loss: 26.6756 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 108/1024
# 34/34 - 5s - loss: 27.2447 - val_loss: 26.7488 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 109/1024
# 34/34 - 5s - loss: 27.2207 - val_loss: 26.6165 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 110/1024
# 34/34 - 5s - loss: 27.1890 - val_loss: 26.6146 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 111/1024
# 34/34 - 5s - loss: 27.1806 - val_loss: 26.6466 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 112/1024
# 34/34 - 5s - loss: 27.1761 - val_loss: 26.5946 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 113/1024
# 34/34 - 5s - loss: 27.1675 - val_loss: 26.5949 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 114/1024
# 34/34 - 5s - loss: 27.1391 - val_loss: 26.5925 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 115/1024
# 34/34 - 5s - loss: 27.1603 - val_loss: 26.5679 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 116/1024
# 34/34 - 5s - loss: 27.1500 - val_loss: 26.5612 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 117/1024
# 34/34 - 5s - loss: 27.1330 - val_loss: 26.6308 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 118/1024
# 34/34 - 5s - loss: 27.1383 - val_loss: 26.5993 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 119/1024
# 34/34 - 5s - loss: 27.1414 - val_loss: 26.6677 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 120/1024
# 34/34 - 5s - loss: 27.1298 - val_loss: 26.5775 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 121/1024
# 34/34 - 5s - loss: 27.1233 - val_loss: 26.6315 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 122/1024
# 34/34 - 5s - loss: 27.1170 - val_loss: 26.5912 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 123/1024
# 34/34 - 5s - loss: 27.1154 - val_loss: 26.6243 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 124/1024
# 34/34 - 5s - loss: 27.0832 - val_loss: 26.5815 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 125/1024
# 34/34 - 5s - loss: 27.0780 - val_loss: 26.5971 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 126/1024
# 34/34 - 5s - loss: 27.0789 - val_loss: 26.5758 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 127/1024
# 34/34 - 5s - loss: 27.0678 - val_loss: 26.5625 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 128/1024
# 34/34 - 5s - loss: 27.0870 - val_loss: 26.5857 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 129/1024
# 34/34 - 5s - loss: 27.0816 - val_loss: 26.6121 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 130/1024
# 34/34 - 5s - loss: 27.0950 - val_loss: 26.6185 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 131/1024
# 34/34 - 5s - loss: 27.0935 - val_loss: 26.5881 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 132/1024
# 34/34 - 5s - loss: 27.0374 - val_loss: 26.6522 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 133/1024
# 34/34 - 5s - loss: 27.0622 - val_loss: 26.5744 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 134/1024
# 34/34 - 5s - loss: 27.0371 - val_loss: 26.6028 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 135/1024
# 34/34 - 5s - loss: 27.0268 - val_loss: 26.5897 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 136/1024
# 34/34 - 5s - loss: 26.9938 - val_loss: 26.5373 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 137/1024
# 34/34 - 5s - loss: 27.0304 - val_loss: 26.5326 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 138/1024
# 34/34 - 5s - loss: 26.9958 - val_loss: 26.5436 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 139/1024
# 34/34 - 5s - loss: 26.9964 - val_loss: 26.5834 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 140/1024
# 34/34 - 5s - loss: 27.0233 - val_loss: 26.5623 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 141/1024
# 34/34 - 5s - loss: 27.0323 - val_loss: 26.5948 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 142/1024
# 34/34 - 5s - loss: 26.9953 - val_loss: 26.5724 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 143/1024
# 34/34 - 5s - loss: 26.9934 - val_loss: 26.5584 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 144/1024
# 34/34 - 5s - loss: 27.0040 - val_loss: 26.6177 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 145/1024
# 34/34 - 5s - loss: 26.9552 - val_loss: 26.6289 - lr: 1.0000e-04 - 5s/epoch - 157ms/step
# Epoch 146/1024
# 34/34 - 5s - loss: 26.9804 - val_loss: 26.5199 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 147/1024
# 34/34 - 5s - loss: 26.9557 - val_loss: 26.5472 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 148/1024
# 34/34 - 5s - loss: 26.9498 - val_loss: 26.4996 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 149/1024
# 34/34 - 5s - loss: 26.9406 - val_loss: 26.5118 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 150/1024
# 34/34 - 5s - loss: 26.9425 - val_loss: 26.6407 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 151/1024
# 34/34 - 5s - loss: 26.9484 - val_loss: 26.5533 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 152/1024
# 34/34 - 5s - loss: 26.9553 - val_loss: 26.6259 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 153/1024
# 34/34 - 5s - loss: 26.9725 - val_loss: 26.5227 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 154/1024
# 34/34 - 5s - loss: 26.9343 - val_loss: 26.5528 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 155/1024
# 34/34 - 5s - loss: 26.9454 - val_loss: 26.5707 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 156/1024
# 34/34 - 5s - loss: 26.9243 - val_loss: 26.5504 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 157/1024
# 34/34 - 5s - loss: 26.8986 - val_loss: 26.5828 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 158/1024
# 34/34 - 5s - loss: 26.8955 - val_loss: 26.5979 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 159/1024
# 34/34 - 5s - loss: 26.9316 - val_loss: 26.5384 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 160/1024
# 34/34 - 5s - loss: 26.9297 - val_loss: 26.5456 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 161/1024
# 34/34 - 5s - loss: 26.9007 - val_loss: 26.5245 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 162/1024
# 34/34 - 5s - loss: 26.8997 - val_loss: 26.5398 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 163/1024
# 34/34 - 5s - loss: 26.9149 - val_loss: 26.5379 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 164/1024
# 34/34 - 5s - loss: 26.9103 - val_loss: 26.5364 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 165/1024
# 34/34 - 5s - loss: 26.8983 - val_loss: 26.5367 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 166/1024
# 34/34 - 5s - loss: 26.8685 - val_loss: 26.5401 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 167/1024
# 34/34 - 5s - loss: 26.8771 - val_loss: 26.6097 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 168/1024
# 34/34 - 5s - loss: 26.8917 - val_loss: 26.5471 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 169/1024
# 34/34 - 5s - loss: 26.8740 - val_loss: 26.6000 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 170/1024
# 34/34 - 5s - loss: 26.8902 - val_loss: 26.6438 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 171/1024
# 34/34 - 5s - loss: 26.8784 - val_loss: 26.5261 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 172/1024
# 34/34 - 5s - loss: 26.8439 - val_loss: 26.5145 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 173/1024
# 34/34 - 5s - loss: 26.8468 - val_loss: 26.5711 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 174/1024
# 34/34 - 5s - loss: 26.8453 - val_loss: 26.5306 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 175/1024
# 34/34 - 5s - loss: 26.8273 - val_loss: 26.5536 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 176/1024
# 34/34 - 5s - loss: 26.8617 - val_loss: 26.5526 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 177/1024
# 34/34 - 5s - loss: 26.8316 - val_loss: 26.5902 - lr: 1.0000e-04 - 5s/epoch - 159ms/step
# Epoch 178/1024
# 34/34 - 5s - loss: 26.8538 - val_loss: 26.5710 - lr: 1.0000e-04 - 5s/epoch - 158ms/step
# Epoch 179/1024
# 34/34 - 5s - loss: 26.8549 - val_loss: 26.6777 - lr: 1.0000e-04 - 5s/epoch - 160ms/step
# Epoch 180/1024
# 34/34 - 5s - loss: 26.8256 - val_loss: 26.5067 - lr: 1.0000e-04 - 5s/epoch - 159ms/step

# %%
plot.plot_loss_history(history, logx=False, logy=False, loss_name="MAE")

# %%
# Make a directory
dir_name = HOME_PATH + "/5th_trial/w_sublead_result/"
name = "dnn_w_offshell"

# If the directory exists
if os.path.exists(dir_name):
    test_files = glob.glob(dir_name + "*" + name + "*")
    if test_files:
        for file in test_files:
            os.remove(file)
        print(f"Directory {dir_name} cleaned.")
    print(f"Directory {dir_name} exists.")
else:
    os.makedirs(dir_name)
    print(f"Directory {dir_name} created.")

# save model
model.save(dir_name + name + ".keras", save_format="keras", overwrite=True)

# predict
pred_y = model.predict(test_x)
# save predicted results
np.savez_compressed(dir_name + name + "_data.npz", pred_y=pred_y, test_y=test_y)
sig_pred = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth = np.load(dir_name + name + "_data.npz")["test_y"]
# Out:
# Directory /root/work/QE-mls/5th_trial/w_sublead_result/ cleaned.
# Directory /root/work/QE-mls/5th_trial/w_sublead_result/ exists.
# 12924/12924 [==============================] - 55s 4ms/step

# %%
# name the file
name = "dnn_w_offshell"

# save predicted results
np.savez_compressed(
    dir_name + name + "_data.npz", pred_y=sig_pred.reshape(sig_truth.shape), test_y=sig_truth
)
sig_pred_inv = np.load(dir_name + name + "_data.npz")["pred_y"]
sig_truth_inv = np.load(dir_name + name + "_data.npz")["test_y"]

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,0]):.3f}, std: {np.std(sig_truth_inv[:,0]):.3f}, min: {np.min(sig_truth_inv[:,0]):.3f}, max: {np.max(sig_truth_inv[:,0]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 0], sig_pred_inv[:, 0]],
    label=r"$p_{x}^{W}$",
    title="Off-shell $p_{x}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,0], sig_pred_inv[:,0])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 0],
    sig_pred_inv[:, 0],
    r"Off-shell $p_{x}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,0], sig_pred_inv[:,0])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.024, std: 27.804, min: -691.161, max: 473.069

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,1]):.3f}, std: {np.std(sig_truth_inv[:,1]):.3f}, min: {np.min(sig_truth_inv[:,1]):.3f}, max: {np.max(sig_truth_inv[:,1]):.3f}"
)

set_range = [-200, 200]

plot.hist(
    data=[sig_truth_inv[:, 1], sig_pred_inv[:, 1]],
    label=r"$p_{y}^{W}$",
    title="Off-shell $p_{y}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,1], sig_pred_inv[:,1])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 1],
    sig_pred_inv[:, 1],
    r"Off-shell $p_{y}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,1], sig_pred_inv[:,1])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: -0.085, std: 27.860, min: -542.501, max: 575.958

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,2]):.3f}, std: {np.std(sig_truth_inv[:,2]):.3f}, min: {np.min(sig_truth_inv[:,2]):.3f}, max: {np.max(sig_truth_inv[:,2]):.3f}"
)

set_range = [-1200, 1200]

plot.hist(
    data=[sig_truth_inv[:, 2], sig_pred_inv[:, 2]],
    label=r"$p_{z}^{W}$",
    title="Off-shell $p_{z}^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,2], sig_pred_inv[:,2])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:, 2],
    sig_pred_inv[:, 2],
    r"Off-shell $p_{z}^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,2], sig_pred_inv[:,2])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 0.350, std: 204.696, min: -3293.224, max: 2726.786

# %%
print(
    f"Truth mean: {np.mean(sig_truth_inv[:,3]):.3f}, std: {np.std(sig_truth_inv[:,3]):.3f}, min: {np.min(sig_truth_inv[:,3]):.3f}, max: {np.max(sig_truth_inv[:,3]):.3f}"
)

set_range = [0, 1800]

plot.hist(
    data=[sig_truth_inv[:,3], sig_pred_inv[:,3]],
    label=r"$E^{W}$",
    title="Off-shell $E^{W}$",
    # + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth_inv[:,3], sig_pred_inv[:,3])):.3f}",
    range=set_range,
    unit="[GeV]",
)

plot.plot_2d_histogram(
    sig_truth_inv[:,3],
    sig_pred_inv[:,3],
    r"Off-shell $E^{W}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth_inv[:,3], sig_pred_inv[:,3])[0]:.3f}",
    range=set_range,
)
# Out:
# Truth mean: 141.231, std: 158.804, min: 17.567, max: 3294.626

# %%
truth_time_like = np.square(sig_pred_inv[:, 3]) - np.sum(
    np.square(sig_pred_inv[:, 0:-1]), axis=1
)
truth_time_mask = truth_time_like >= 0
plt.hist(truth_time_like, bins=120, fill=True)
plt.title(f"Total-like W mass with {len(truth_time_like)}")
plt.show()
plt.hist(truth_time_like[truth_time_mask], bins=120, fill=True)
plt.title(f"Time-like W mass with {len(truth_time_like[truth_time_mask])}")
plt.show()

# %%
import shap
import matplotlib as mpl

mpl.rcParams.update(mpl.rcParamsDefault)

feature_names = [
    "lead_px",
    "lead_py",
    "lead_pz",
    "lead_E",
    "lead_pt",
    "lead_eta",
    "lead_phi",
    "sublead_px",
    "sublead_py",
    "sublead_pz",
    "sublead_E",
    "sublead_pt",
    "sublead_eta",
    "sublead_phi",
    "met_px",
    "met_py",
    "met_pt",
    "met_phi",
    "dilep_px",
    "dilep_py",
    "dilep_pz",
    "dilep_E",
    "dilep_pt",
    "dilep_eta",
    "dilep_phi",
    "dilep_m",
]
title_name = ["px", "py", "pz", "E"]
# lead
# Use DeepExplainer for SHAP values
explainer = shap.DeepExplainer(model, obs_kin[:1024])
shap_values = explainer.shap_values(obs_kin[:1024], check_additivity=False)
for i in range(shap_values.shape[-1]):
    plt.figure(figsize=(10, 6))
    shap.summary_plot(
        shap_values[:, :, i],
        obs_kin[:1024],
        feature_names=feature_names,
        plot_type="dot",
        show=False,
    )
    plt.title(f"SHAP Summary Plot for Off-shell Regression Output: {title_name[i]}")
    plt.show()
# Out:
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
