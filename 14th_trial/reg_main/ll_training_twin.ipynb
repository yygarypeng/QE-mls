# %%
import time
t_start = time.time()

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"  # suppress tensorflow information messages

import sys
import numpy as np
from scipy import stats
import scipy as sp
import multiprocessing
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm, Normalize
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbModelCheckpoint

HOME_PATH = os.path.abspath("/root/work/QE-mls") # path to QE_mls
sys.path.append(HOME_PATH + "/qe")
print("Home path:", HOME_PATH)

# custom modules
import paper_plot as pp
# Import the W boson regressor module
import nn
nn.BATCH_SIZE = 2048
# Out:
# Home path: /root/work/QE-mls

# %%
# ROOT need to be imported after tensorflow
import ROOT
from ROOT import TLorentzVector, TVector3

# some global variables
dir_name = HOME_PATH + "/14th_trial/reg_main/ww_resregressor_result/"
plot = pp.Plotter()
WORKERS = 20

# %%
import h5py


def load_particles_from_h5(filename="mc20_truth.h5"):
    """
    Load particle data from an HDF5 file

    Args:
        filename: Path to the HDF5 file

    Returns:
        Dictionary with the loaded data
    """
    result = {}

    with h5py.File(filename, "r") as f:
        # For each group in the file
        for group_name in f.keys():
            group_data = {}

            # Load datasets (numpy arrays)
            for dataset_name in f[group_name].keys():
                group_data[dataset_name] = f[group_name][dataset_name][:]

            # Load attributes (scalars)
            for attr_name, attr_value in f[group_name].attrs.items():
                group_data[attr_name] = attr_value

            result[group_name] = group_data

    return result

# %%
mc20_data = load_particles_from_h5("/root/data/mc20_truth.h5")
mc20_data.keys()
# Out:
# dict_keys(['higgs', 'lead_w', 'sublead_w', 'truth_dilep', 'truth_dilep_car', 'truth_lead_lep', 'truth_lead_lep_car', 'truth_lead_nu', 'truth_lead_nu_car', 'truth_sublead_lep', 'truth_sublead_lep_car', 'truth_sublead_nu', 'truth_sublead_nu_car'])

# %%
# SM truth
truth_lead_lep = mc20_data["truth_lead_lep"]
truth_sublead_lep = mc20_data["truth_sublead_lep"]
truth_lead_nu = mc20_data["truth_lead_nu"]
truth_sublead_nu = mc20_data["truth_sublead_nu"]
truth_lead_lep_p4 = mc20_data["truth_lead_lep"]["p4"]
truth_sublead_lep_p4 = mc20_data["truth_sublead_lep"]["p4"]
truth_lead_nu_p4 = mc20_data["truth_lead_nu"]["p4"]
truth_sublead_nu_p4 = mc20_data["truth_sublead_nu"]["p4"]
truth_met_pt = np.sqrt(np.square((truth_lead_nu_p4 + truth_sublead_nu_p4)[...,0:2]).sum(axis=-1))

# CAR truth
truth_lead_lep_car = mc20_data["truth_lead_lep_car"]
truth_sublead_lep_car = mc20_data["truth_sublead_lep_car"]
truth_lead_nu_car = mc20_data["truth_lead_nu_car"]
truth_sublead_nu_car = mc20_data["truth_sublead_nu_car"]
truth_lead_lep_car_p4 = mc20_data["truth_lead_lep_car"]["p4"]
truth_sublead_lep_car_p4 = mc20_data["truth_sublead_lep_car"]["p4"]
truth_lead_nu_car_p4 = mc20_data["truth_lead_nu_car"]["p4"]
truth_sublead_nu_car_p4 = mc20_data["truth_sublead_nu_car"]["p4"]
truth_met_pt_car = np.sqrt(np.square((truth_lead_nu_car_p4 + truth_sublead_nu_car_p4)[...,0:2]).sum(axis=-1))

# W bosons (SM and CAR use the same W bosons data)
w_lead_p4 = mc20_data["lead_w"]["p4"]
w_sublead_p4 = mc20_data["sublead_w"]["p4"]

# %%
print("Truth: pre-cut")
cut_pre_pt_lead = truth_lead_lep["pt"] > 22
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = truth_sublead_lep["pt"] > 15
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.square(truth_lead_lep["energy"] + truth_sublead_lep["energy"])
    - np.square(truth_lead_lep["px"] + truth_sublead_lep["px"])
    - np.square(truth_lead_lep["py"] + truth_sublead_lep["py"])
    - np.square(truth_lead_lep["pz"] + truth_sublead_lep["pz"])
    > 10**2
)
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = truth_met_pt > 20
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print("Total", len(truth_lead_lep["energy"]) - np.sum(PRE_CUT * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# CAR
print("")
print("CAR: pre-cut")
cut_pre_pt_lead = truth_lead_lep_car["pt"] > 22
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = truth_sublead_lep_car["pt"] > 15
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.square(truth_lead_lep_car["energy"] + truth_sublead_lep_car["energy"])
    - np.square(truth_lead_lep_car["px"] + truth_sublead_lep_car["px"])
    - np.square(truth_lead_lep_car["py"] + truth_sublead_lep_car["py"])
    - np.square(truth_lead_lep_car["pz"] + truth_sublead_lep_car["pz"])
    > 10**2
)
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = truth_met_pt_car > 20
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT_CAR = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print("Total", len(truth_lead_lep_car["energy"]) - np.sum(PRE_CUT_CAR * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)
# Out:
# Truth: pre-cut
# 260653
# 1174171
# 148392
# 287355
# Total 1502903
#
# CAR: pre-cut
# 336735
# 1292162
# 65248
# 441435
# Total 1634918

# %%
# force to use the same cuts for both truth and CAR

PRE_CUT_INST = PRE_CUT_CAR & PRE_CUT
print("Total", np.sum(PRE_CUT_INST * 1))
# Out:
# Total 700374

# %%
# training objects
lead_lep_px = truth_lead_lep_car["px"][PRE_CUT_INST]
lead_lep_py = truth_lead_lep_car["py"][PRE_CUT_INST]
lead_lep_pz = truth_lead_lep_car["pz"][PRE_CUT_INST]
lead_lep_energy = truth_lead_lep_car["energy"][PRE_CUT_INST]
sublead_lep_px = truth_sublead_lep_car["px"][PRE_CUT_INST]
sublead_lep_py = truth_sublead_lep_car["py"][PRE_CUT_INST]
sublead_lep_pz = truth_sublead_lep_car["pz"][PRE_CUT_INST]
sublead_lep_energy = truth_sublead_lep_car["energy"][PRE_CUT_INST]
lead_nu_px = truth_lead_nu_car["px"][PRE_CUT_INST]
lead_nu_py = truth_lead_nu_car["py"][PRE_CUT_INST]
sublead_nu_px = truth_sublead_nu_car["px"][PRE_CUT_INST]
sublead_nu_py = truth_sublead_nu_car["py"][PRE_CUT_INST]
met_px = lead_nu_px + sublead_nu_px
met_py = lead_nu_py + sublead_nu_py

np.random.seed(nn.SEED)
shuffle_ind = np.random.permutation(len(lead_lep_px))

train = np.column_stack(
    (
        lead_lep_px,
        lead_lep_py,
        lead_lep_pz,
        lead_lep_energy,
        sublead_lep_px,
        sublead_lep_py,
        sublead_lep_pz,
        sublead_lep_energy,
        met_px,
        met_py,
    )
)

# train = train[shuffle_ind]
print("Training objects shape:", train.shape)
# Out:
# Training objects shape: (700374, 10)

# %%
# target objects

w_lead = mc20_data["lead_w"]
w_sublead = mc20_data["sublead_w"]
target = np.column_stack(
    (
        w_lead["px"][PRE_CUT_INST],
        w_lead["py"][PRE_CUT_INST],
        w_lead["pz"][PRE_CUT_INST],
        w_lead["energy"][PRE_CUT_INST],
        w_sublead["px"][PRE_CUT_INST],
        w_sublead["py"][PRE_CUT_INST],
        w_sublead["pz"][PRE_CUT_INST],
        w_sublead["energy"][PRE_CUT_INST],
        w_lead["m"][PRE_CUT_INST],
        w_sublead["m"][PRE_CUT_INST],
    )
)

# target = target[shuffle_ind]
print("Target objects shape:", target.shape)
# Out:
# Target objects shape: (700374, 10)

# %%
# Train-test split
if len(train) == len(target):
	indices = np.arange(len(train))
else:
	sys.exit("Error: train and targe shapes do not match!")

train_idx, temp_idx = train_test_split(
	indices, train_size=0.8, random_state=nn.SEED
)
valid_idx, test_idx = train_test_split(
	temp_idx, train_size=0.5, random_state=nn.SEED
)

train_x, valid_x, test_x = train[train_idx], train[valid_idx], train[test_idx]
train_y, valid_y, test_y = target[train_idx], target[valid_idx], target[test_idx]

print("Train shape:", train_x.shape, "Valid shape:", valid_x.shape, "Test shape:", test_x.shape)
# Out:
# Train shape: (560299, 10) Valid shape: (70037, 10) Test shape: (70038, 10)

# %%
# W&B initialization
wandb.init(
    project='PcRes regressor ll training', 
    name='batch_size: %d' % nn.BATCH_SIZE)
config = wandb.config
config.batch_size = nn.BATCH_SIZE

# Create datasets
train_dataset = (
	tf.data.Dataset.from_tensor_slices((train_x, train_y))
	.cache()
	.batch(nn.BATCH_SIZE)
	.prefetch(tf.data.AUTOTUNE)
)
valid_dataset = (
	tf.data.Dataset.from_tensor_slices((valid_x, valid_y))
	.cache()
	.batch(nn.BATCH_SIZE)
	.prefetch(tf.data.AUTOTUNE)
)

# Build and train model
base_model = nn.build_model(input_shape=train_x.shape[-1])
model = nn.CustomModel(base_model)
model.summary()
model.compile(
	optimizer=tf.keras.optimizers.Adam(learning_rate=nn.LEARNING_RATE),
	loss_weights=nn.LOSS_WEIGHTS,
)

callbacks = [
	tf.keras.callbacks.EarlyStopping(
		monitor="val_loss", patience=10, restore_best_weights=True
	),
	nn.EpochUpdater(),
	nn.LambdaTracker(),
	WandbMetricsLogger(), 
    # WandbModelCheckpoint(
    #     "best_val_loss.weights.h5",
    #     monitor="val_loss",
    # ),
]

history = model.fit(
	train_dataset,
	validation_data=valid_dataset,
	epochs=nn.EPOCHS,
	callbacks=callbacks,
	verbose=0,
)
# Out:
# wandb: Currently logged in as: yygarypeng (nthu-expt-hep) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/root/work/QE-mls/14th_trial/reg_main/wandb/run-20250710_053646-q88300o3</code>
# Syncing run <strong><a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training/runs/q88300o3' target="_blank">batch_size: 2048</a></strong> to <a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training' target="_blank">https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training</a>
#  View run at <a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training/runs/q88300o3' target="_blank">https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training/runs/q88300o3</a>
# Model: "custom_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional (Functional)         │ (None, 8)              │       990,822 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 990,822 (3.78 MB)
#  Trainable params: 979,238 (3.74 MB)
#  Non-trainable params: 11,584 (45.25 KB)
# Epoch 0; dinu_pt_loss: 6.205E+01; higgs_mass_loss: 6.799E+01; loss: 1.417E+02; mae_loss: 5.517E+01; neg_r2_loss: -6.470E-01; nu_mass_loss: 4.376E-03; val_dinu_pt_loss: 6.187E+01; val_higgs_mass_loss: 5.589E+01; val_loss: 1.290E+02; val_mae_loss: 5.515E+01; val_neg_r2_loss: -6.514E-01; val_nu_mass_loss: 5.603E-03; val_w0_mass_mae_loss: 4.654E+01; val_w1_mass_mae_loss: 2.539E+01; val_w_mass_mmd0_loss: 1.735E+00; val_w_mass_mmd1_loss: 6.006E-01; w0_mass_mae_loss: 5.459E+01; w1_mass_mae_loss: 3.117E+01; w_mass_mmd0_loss: 2.421E+00; w_mass_mmd1_loss: 1.496E+00
# Epoch 1; dinu_pt_loss: 6.194E+01; higgs_mass_loss: 5.152E+01; loss: 1.255E+02; mae_loss: 5.504E+01; neg_r2_loss: -6.470E-01; nu_mass_loss: 6.634E-03; val_dinu_pt_loss: 6.185E+01; val_higgs_mass_loss: 4.845E+01; val_loss: 1.235E+02; val_mae_loss: 5.499E+01; val_neg_r2_loss: -6.521E-01; val_nu_mass_loss: 7.604E-03; val_w0_mass_mae_loss: 4.191E+01; val_w1_mass_mae_loss: 2.323E+01; val_w_mass_mmd0_loss: 1.414E+00; val_w_mass_mmd1_loss: 2.801E-01; w0_mass_mae_loss: 4.352E+01; w1_mass_mae_loss: 2.377E+01; w_mass_mmd0_loss: 1.536E+00; w_mass_mmd1_loss: 3.896E-01
# Epoch 2; dinu_pt_loss: 6.186E+01; higgs_mass_loss: 4.707E+01; loss: 1.226E+02; mae_loss: 5.495E+01; neg_r2_loss: -6.473E-01; nu_mass_loss: 7.395E-03; val_dinu_pt_loss: 6.168E+01; val_higgs_mass_loss: 4.522E+01; val_loss: 1.217E+02; val_mae_loss: 5.489E+01; val_neg_r2_loss: -6.525E-01; val_nu_mass_loss: 8.080E-03; val_w0_mass_mae_loss: 4.003E+01; val_w1_mass_mae_loss: 2.199E+01; val_w_mass_mmd0_loss: 1.292E+00; val_w_mass_mmd1_loss: 1.975E-01; w0_mass_mae_loss: 4.097E+01; w1_mass_mae_loss: 2.231E+01; w_mass_mmd0_loss: 1.345E+00; w_mass_mmd1_loss: 2.445E-01
# Epoch 3; dinu_pt_loss: 6.168E+01; higgs_mass_loss: 4.403E+01; loss: 1.206E+02; mae_loss: 5.483E+01; neg_r2_loss: -6.476E-01; nu_mass_loss: 7.989E-03; val_dinu_pt_loss: 6.149E+01; val_higgs_mass_loss: 4.296E+01; val_loss: 1.199E+02; val_mae_loss: 5.476E+01; val_neg_r2_loss: -6.529E-01; val_nu_mass_loss: 8.558E-03; val_w0_mass_mae_loss: 3.831E+01; val_w1_mass_mae_loss: 2.141E+01; val_w_mass_mmd0_loss: 1.144E+00; val_w_mass_mmd1_loss: 1.551E-01; w0_mass_mae_loss: 3.902E+01; w1_mass_mae_loss: 2.150E+01; w_mass_mmd0_loss: 1.187E+00; w_mass_mmd1_loss: 1.818E-01
# Epoch 4; dinu_pt_loss: 6.145E+01; higgs_mass_loss: 4.176E+01; loss: 1.189E+02; mae_loss: 5.470E+01; neg_r2_loss: -6.480E-01; nu_mass_loss: 8.531E-03; val_dinu_pt_loss: 6.120E+01; val_higgs_mass_loss: 4.156E+01; val_loss: 1.184E+02; val_mae_loss: 5.461E+01; val_neg_r2_loss: -6.535E-01; val_nu_mass_loss: 9.015E-03; val_w0_mass_mae_loss: 3.684E+01; val_w1_mass_mae_loss: 2.120E+01; val_w_mass_mmd0_loss: 1.016E+00; val_w_mass_mmd1_loss: 1.342E-01; w0_mass_mae_loss: 3.726E+01; w1_mass_mae_loss: 2.108E+01; w_mass_mmd0_loss: 1.039E+00; w_mass_mmd1_loss: 1.477E-01
# Epoch 5; dinu_pt_loss: 6.106E+01; higgs_mass_loss: 3.999E+01; loss: 1.173E+02; mae_loss: 5.453E+01; neg_r2_loss: -6.485E-01; nu_mass_loss: 9.029E-03; val_dinu_pt_loss: 6.054E+01; val_higgs_mass_loss: 4.026E+01; val_loss: 1.167E+02; val_mae_loss: 5.439E+01; val_neg_r2_loss: -6.542E-01; val_nu_mass_loss: 9.518E-03; val_w0_mass_mae_loss: 3.541E+01; val_w1_mass_mae_loss: 2.089E+01; val_w_mass_mmd0_loss: 8.766E-01; val_w_mass_mmd1_loss: 1.143E-01; w0_mass_mae_loss: 3.570E+01; w1_mass_mae_loss: 2.081E+01; w_mass_mmd0_loss: 9.090E-01; w_mass_mmd1_loss: 1.256E-01
# Epoch 6; dinu_pt_loss: 6.044E+01; higgs_mass_loss: 3.866E+01; loss: 1.159E+02; mae_loss: 5.431E+01; neg_r2_loss: -6.491E-01; nu_mass_loss: 9.521E-03; val_dinu_pt_loss: 5.977E+01; val_higgs_mass_loss: 3.903E+01; val_loss: 1.154E+02; val_mae_loss: 5.414E+01; val_neg_r2_loss: -6.550E-01; val_nu_mass_loss: 1.002E-02; val_w0_mass_mae_loss: 3.410E+01; val_w1_mass_mae_loss: 2.069E+01; val_w_mass_mmd0_loss: 7.941E-01; val_w_mass_mmd1_loss: 9.845E-02; w0_mass_mae_loss: 3.433E+01; w1_mass_mae_loss: 2.066E+01; w_mass_mmd0_loss: 8.012E-01; w_mass_mmd1_loss: 1.114E-01
# Epoch 7; dinu_pt_loss: 5.968E+01; higgs_mass_loss: 3.757E+01; loss: 1.146E+02; mae_loss: 5.407E+01; neg_r2_loss: -6.498E-01; nu_mass_loss: 1.000E-02; val_dinu_pt_loss: 5.891E+01; val_higgs_mass_loss: 3.799E+01; val_loss: 1.140E+02; val_mae_loss: 5.387E+01; val_neg_r2_loss: -6.558E-01; val_nu_mass_loss: 1.048E-02; val_w0_mass_mae_loss: 3.276E+01; val_w1_mass_mae_loss: 2.064E+01; val_w_mass_mmd0_loss: 6.950E-01; val_w_mass_mmd1_loss: 8.666E-02; w0_mass_mae_loss: 3.312E+01; w1_mass_mae_loss: 2.061E+01; w_mass_mmd0_loss: 7.050E-01; w_mass_mmd1_loss: 1.012E-01
# Epoch 8; dinu_pt_loss: 5.893E+01; higgs_mass_loss: 3.650E+01; loss: 1.134E+02; mae_loss: 5.383E+01; neg_r2_loss: -6.506E-01; nu_mass_loss: 1.050E-02; val_dinu_pt_loss: 5.830E+01; val_higgs_mass_loss: 3.670E+01; val_loss: 1.126E+02; val_mae_loss: 5.367E+01; val_neg_r2_loss: -6.565E-01; val_nu_mass_loss: 1.097E-02; val_w0_mass_mae_loss: 3.148E+01; val_w1_mass_mae_loss: 2.060E+01; val_w_mass_mmd0_loss: 5.758E-01; val_w_mass_mmd1_loss: 8.000E-02; w0_mass_mae_loss: 3.197E+01; w1_mass_mae_loss: 2.058E+01; w_mass_mmd0_loss: 6.251E-01; w_mass_mmd1_loss: 9.092E-02
# Epoch 9; dinu_pt_loss: 5.848E+01; higgs_mass_loss: 3.543E+01; loss: 1.124E+02; mae_loss: 5.363E+01; neg_r2_loss: -6.514E-01; nu_mass_loss: 1.100E-02; val_dinu_pt_loss: 5.782E+01; val_higgs_mass_loss: 3.533E+01; val_loss: 1.119E+02; val_mae_loss: 5.342E+01; val_neg_r2_loss: -6.575E-01; val_nu_mass_loss: 1.156E-02; val_w0_mass_mae_loss: 3.020E+01; val_w1_mass_mae_loss: 2.051E+01; val_w_mass_mmd0_loss: 5.616E-01; val_w_mass_mmd1_loss: 7.435E-02; w0_mass_mae_loss: 3.088E+01; w1_mass_mae_loss: 2.053E+01; w_mass_mmd0_loss: 5.559E-01; w_mass_mmd1_loss: 8.208E-02
# Epoch 10; dinu_pt_loss: 5.797E+01; higgs_mass_loss: 3.426E+01; loss: 1.115E+02; mae_loss: 5.344E+01; neg_r2_loss: -6.522E-01; nu_mass_loss: 1.144E-02; val_dinu_pt_loss: 5.748E+01; val_higgs_mass_loss: 3.447E+01; val_loss: 1.112E+02; val_mae_loss: 5.325E+01; val_neg_r2_loss: -6.582E-01; val_nu_mass_loss: 1.194E-02; val_w0_mass_mae_loss: 2.936E+01; val_w1_mass_mae_loss: 2.049E+01; val_w_mass_mmd0_loss: 5.178E-01; val_w_mass_mmd1_loss: 6.909E-02; w0_mass_mae_loss: 2.987E+01; w1_mass_mae_loss: 2.047E+01; w_mass_mmd0_loss: 4.990E-01; w_mass_mmd1_loss: 7.667E-02
# Epoch 11; dinu_pt_loss: 5.751E+01; higgs_mass_loss: 3.331E+01; loss: 1.107E+02; mae_loss: 5.324E+01; neg_r2_loss: -6.530E-01; nu_mass_loss: 1.188E-02; val_dinu_pt_loss: 5.686E+01; val_higgs_mass_loss: 3.327E+01; val_loss: 1.101E+02; val_mae_loss: 5.311E+01; val_neg_r2_loss: -6.588E-01; val_nu_mass_loss: 1.228E-02; val_w0_mass_mae_loss: 2.847E+01; val_w1_mass_mae_loss: 2.043E+01; val_w_mass_mmd0_loss: 4.252E-01; val_w_mass_mmd1_loss: 6.308E-02; w0_mass_mae_loss: 2.904E+01; w1_mass_mae_loss: 2.039E+01; w_mass_mmd0_loss: 4.624E-01; w_mass_mmd1_loss: 7.066E-02
# Epoch 12; dinu_pt_loss: 5.704E+01; higgs_mass_loss: 3.223E+01; loss: 1.101E+02; mae_loss: 5.309E+01; neg_r2_loss: -6.536E-01; nu_mass_loss: 1.226E-02; val_dinu_pt_loss: 5.625E+01; val_higgs_mass_loss: 3.208E+01; val_loss: 1.096E+02; val_mae_loss: 5.288E+01; val_neg_r2_loss: -6.598E-01; val_nu_mass_loss: 1.274E-02; val_w0_mass_mae_loss: 2.762E+01; val_w1_mass_mae_loss: 2.040E+01; val_w_mass_mmd0_loss: 4.155E-01; val_w_mass_mmd1_loss: 6.061E-02; w0_mass_mae_loss: 2.815E+01; w1_mass_mae_loss: 2.036E+01; w_mass_mmd0_loss: 4.182E-01; w_mass_mmd1_loss: 6.753E-02
# Epoch 13; dinu_pt_loss: 5.666E+01; higgs_mass_loss: 3.109E+01; loss: 1.095E+02; mae_loss: 5.293E+01; neg_r2_loss: -6.543E-01; nu_mass_loss: 1.262E-02; val_dinu_pt_loss: 5.596E+01; val_higgs_mass_loss: 3.060E+01; val_loss: 1.085E+02; val_mae_loss: 5.277E+01; val_neg_r2_loss: -6.602E-01; val_nu_mass_loss: 1.308E-02; val_w0_mass_mae_loss: 2.663E+01; val_w1_mass_mae_loss: 2.028E+01; val_w_mass_mmd0_loss: 3.169E-01; val_w_mass_mmd1_loss: 5.798E-02; w0_mass_mae_loss: 2.738E+01; w1_mass_mae_loss: 2.031E+01; w_mass_mmd0_loss: 3.899E-01; w_mass_mmd1_loss: 6.385E-02
# Epoch 14; dinu_pt_loss: 5.619E+01; higgs_mass_loss: 3.020E+01; loss: 1.090E+02; mae_loss: 5.277E+01; neg_r2_loss: -6.551E-01; nu_mass_loss: 1.294E-02; val_dinu_pt_loss: 5.568E+01; val_higgs_mass_loss: 2.992E+01; val_loss: 1.086E+02; val_mae_loss: 5.259E+01; val_neg_r2_loss: -6.612E-01; val_nu_mass_loss: 1.343E-02; val_w0_mass_mae_loss: 2.626E+01; val_w1_mass_mae_loss: 2.031E+01; val_w_mass_mmd0_loss: 3.743E-01; val_w_mass_mmd1_loss: 5.637E-02; w0_mass_mae_loss: 2.679E+01; w1_mass_mae_loss: 2.030E+01; w_mass_mmd0_loss: 3.653E-01; w_mass_mmd1_loss: 6.179E-02
# Epoch 15; dinu_pt_loss: 5.579E+01; higgs_mass_loss: 2.940E+01; loss: 1.084E+02; mae_loss: 5.259E+01; neg_r2_loss: -6.560E-01; nu_mass_loss: 1.328E-02; val_dinu_pt_loss: 5.489E+01; val_higgs_mass_loss: 2.880E+01; val_loss: 1.076E+02; val_mae_loss: 5.242E+01; val_neg_r2_loss: -6.618E-01; val_nu_mass_loss: 1.368E-02; val_w0_mass_mae_loss: 2.563E+01; val_w1_mass_mae_loss: 2.020E+01; val_w_mass_mmd0_loss: 2.894E-01; val_w_mass_mmd1_loss: 5.693E-02; w0_mass_mae_loss: 2.623E+01; w1_mass_mae_loss: 2.031E+01; w_mass_mmd0_loss: 3.472E-01; w_mass_mmd1_loss: 6.139E-02
# Epoch 16; dinu_pt_loss: 5.514E+01; higgs_mass_loss: 2.866E+01; loss: 1.079E+02; mae_loss: 5.240E+01; neg_r2_loss: -6.569E-01; nu_mass_loss: 1.358E-02; val_dinu_pt_loss: 5.464E+01; val_higgs_mass_loss: 2.815E+01; val_loss: 1.074E+02; val_mae_loss: 5.226E+01; val_neg_r2_loss: -6.627E-01; val_nu_mass_loss: 1.400E-02; val_w0_mass_mae_loss: 2.520E+01; val_w1_mass_mae_loss: 2.027E+01; val_w_mass_mmd0_loss: 3.015E-01; val_w_mass_mmd1_loss: 5.597E-02; w0_mass_mae_loss: 2.582E+01; w1_mass_mae_loss: 2.027E+01; w_mass_mmd0_loss: 3.308E-01; w_mass_mmd1_loss: 6.036E-02
# Epoch 17; dinu_pt_loss: 5.459E+01; higgs_mass_loss: 2.800E+01; loss: 1.074E+02; mae_loss: 5.222E+01; neg_r2_loss: -6.577E-01; nu_mass_loss: 1.387E-02; val_dinu_pt_loss: 5.391E+01; val_higgs_mass_loss: 2.780E+01; val_loss: 1.070E+02; val_mae_loss: 5.206E+01; val_neg_r2_loss: -6.638E-01; val_nu_mass_loss: 1.428E-02; val_w0_mass_mae_loss: 2.495E+01; val_w1_mass_mae_loss: 2.035E+01; val_w_mass_mmd0_loss: 3.088E-01; val_w_mass_mmd1_loss: 5.509E-02; w0_mass_mae_loss: 2.541E+01; w1_mass_mae_loss: 2.028E+01; w_mass_mmd0_loss: 3.164E-01; w_mass_mmd1_loss: 5.893E-02
# Epoch 18; dinu_pt_loss: 5.428E+01; higgs_mass_loss: 2.756E+01; loss: 1.069E+02; mae_loss: 5.204E+01; neg_r2_loss: -6.588E-01; nu_mass_loss: 1.419E-02; val_dinu_pt_loss: 5.367E+01; val_higgs_mass_loss: 2.755E+01; val_loss: 1.064E+02; val_mae_loss: 5.181E+01; val_neg_r2_loss: -6.655E-01; val_nu_mass_loss: 1.466E-02; val_w0_mass_mae_loss: 2.467E+01; val_w1_mass_mae_loss: 2.056E+01; val_w_mass_mmd0_loss: 2.873E-01; val_w_mass_mmd1_loss: 5.523E-02; w0_mass_mae_loss: 2.502E+01; w1_mass_mae_loss: 2.037E+01; w_mass_mmd0_loss: 2.985E-01; w_mass_mmd1_loss: 5.867E-02
# Epoch 19; dinu_pt_loss: 5.381E+01; higgs_mass_loss: 2.702E+01; loss: 1.065E+02; mae_loss: 5.189E+01; neg_r2_loss: -6.596E-01; nu_mass_loss: 1.449E-02; val_dinu_pt_loss: 5.352E+01; val_higgs_mass_loss: 2.734E+01; val_loss: 1.065E+02; val_mae_loss: 5.175E+01; val_neg_r2_loss: -6.657E-01; val_nu_mass_loss: 1.489E-02; val_w0_mass_mae_loss: 2.431E+01; val_w1_mass_mae_loss: 2.052E+01; val_w_mass_mmd0_loss: 3.173E-01; val_w_mass_mmd1_loss: 5.405E-02; w0_mass_mae_loss: 2.453E+01; w1_mass_mae_loss: 2.040E+01; w_mass_mmd0_loss: 2.783E-01; w_mass_mmd1_loss: 5.781E-02
# Epoch 20; dinu_pt_loss: 5.341E+01; higgs_mass_loss: 2.674E+01; loss: 1.060E+02; mae_loss: 5.170E+01; neg_r2_loss: -6.608E-01; nu_mass_loss: 1.481E-02; val_dinu_pt_loss: 5.279E+01; val_higgs_mass_loss: 2.625E+01; val_loss: 1.057E+02; val_mae_loss: 5.157E+01; val_neg_r2_loss: -6.666E-01; val_nu_mass_loss: 1.525E-02; val_w0_mass_mae_loss: 2.365E+01; val_w1_mass_mae_loss: 2.048E+01; val_w_mass_mmd0_loss: 2.614E-01; val_w_mass_mmd1_loss: 5.718E-02; w0_mass_mae_loss: 2.421E+01; w1_mass_mae_loss: 2.050E+01; w_mass_mmd0_loss: 2.675E-01; w_mass_mmd1_loss: 5.712E-02
# Epoch 21; dinu_pt_loss: 5.306E+01; higgs_mass_loss: 2.632E+01; loss: 1.056E+02; mae_loss: 5.155E+01; neg_r2_loss: -6.618E-01; nu_mass_loss: 1.512E-02; val_dinu_pt_loss: 5.294E+01; val_higgs_mass_loss: 2.615E+01; val_loss: 1.049E+02; val_mae_loss: 5.132E+01; val_neg_r2_loss: -6.687E-01; val_nu_mass_loss: 1.564E-02; val_w0_mass_mae_loss: 2.340E+01; val_w1_mass_mae_loss: 2.071E+01; val_w_mass_mmd0_loss: 2.269E-01; val_w_mass_mmd1_loss: 5.416E-02; w0_mass_mae_loss: 2.391E+01; w1_mass_mae_loss: 2.051E+01; w_mass_mmd0_loss: 2.508E-01; w_mass_mmd1_loss: 5.637E-02
# Epoch 22; dinu_pt_loss: 5.293E+01; higgs_mass_loss: 2.584E+01; loss: 1.051E+02; mae_loss: 5.140E+01; neg_r2_loss: -6.627E-01; nu_mass_loss: 1.544E-02; val_dinu_pt_loss: 5.227E+01; val_higgs_mass_loss: 2.524E+01; val_loss: 1.044E+02; val_mae_loss: 5.127E+01; val_neg_r2_loss: -6.684E-01; val_nu_mass_loss: 1.578E-02; val_w0_mass_mae_loss: 2.270E+01; val_w1_mass_mae_loss: 2.049E+01; val_w_mass_mmd0_loss: 1.732E-01; val_w_mass_mmd1_loss: 5.445E-02; w0_mass_mae_loss: 2.342E+01; w1_mass_mae_loss: 2.053E+01; w_mass_mmd0_loss: 2.349E-01; w_mass_mmd1_loss: 5.633E-02
# Epoch 23; dinu_pt_loss: 5.225E+01; higgs_mass_loss: 2.564E+01; loss: 1.047E+02; mae_loss: 5.126E+01; neg_r2_loss: -6.635E-01; nu_mass_loss: 1.572E-02; val_dinu_pt_loss: 5.206E+01; val_higgs_mass_loss: 2.585E+01; val_loss: 1.040E+02; val_mae_loss: 5.109E+01; val_neg_r2_loss: -6.699E-01; val_nu_mass_loss: 1.621E-02; val_w0_mass_mae_loss: 2.252E+01; val_w1_mass_mae_loss: 2.077E+01; val_w_mass_mmd0_loss: 1.754E-01; val_w_mass_mmd1_loss: 5.266E-02; w0_mass_mae_loss: 2.307E+01; w1_mass_mae_loss: 2.059E+01; w_mass_mmd0_loss: 2.176E-01; w_mass_mmd1_loss: 5.556E-02
# Epoch 24; dinu_pt_loss: 5.213E+01; higgs_mass_loss: 2.524E+01; loss: 1.043E+02; mae_loss: 5.112E+01; neg_r2_loss: -6.646E-01; nu_mass_loss: 1.602E-02; val_dinu_pt_loss: 5.188E+01; val_higgs_mass_loss: 2.422E+01; val_loss: 1.035E+02; val_mae_loss: 5.103E+01; val_neg_r2_loss: -6.698E-01; val_nu_mass_loss: 1.631E-02; val_w0_mass_mae_loss: 2.167E+01; val_w1_mass_mae_loss: 2.057E+01; val_w_mass_mmd0_loss: 1.240E-01; val_w_mass_mmd1_loss: 5.510E-02; w0_mass_mae_loss: 2.271E+01; w1_mass_mae_loss: 2.064E+01; w_mass_mmd0_loss: 2.043E-01; w_mass_mmd1_loss: 5.523E-02
# Epoch 25; dinu_pt_loss: 5.205E+01; higgs_mass_loss: 2.483E+01; loss: 1.040E+02; mae_loss: 5.100E+01; neg_r2_loss: -6.653E-01; nu_mass_loss: 1.627E-02; val_dinu_pt_loss: 5.208E+01; val_higgs_mass_loss: 2.406E+01; val_loss: 1.032E+02; val_mae_loss: 5.091E+01; val_neg_r2_loss: -6.709E-01; val_nu_mass_loss: 1.663E-02; val_w0_mass_mae_loss: 2.147E+01; val_w1_mass_mae_loss: 2.059E+01; val_w_mass_mmd0_loss: 1.196E-01; val_w_mass_mmd1_loss: 5.545E-02; w0_mass_mae_loss: 2.232E+01; w1_mass_mae_loss: 2.064E+01; w_mass_mmd0_loss: 1.926E-01; w_mass_mmd1_loss: 5.538E-02
# Epoch 26; dinu_pt_loss: 5.178E+01; higgs_mass_loss: 2.420E+01; loss: 1.036E+02; mae_loss: 5.092E+01; neg_r2_loss: -6.652E-01; nu_mass_loss: 1.642E-02; val_dinu_pt_loss: 5.124E+01; val_higgs_mass_loss: 2.424E+01; val_loss: 1.030E+02; val_mae_loss: 5.076E+01; val_neg_r2_loss: -6.716E-01; val_nu_mass_loss: 1.682E-02; val_w0_mass_mae_loss: 2.161E+01; val_w1_mass_mae_loss: 2.051E+01; val_w_mass_mmd0_loss: 1.368E-01; val_w_mass_mmd1_loss: 5.334E-02; w0_mass_mae_loss: 2.191E+01; w1_mass_mae_loss: 2.043E+01; w_mass_mmd0_loss: 1.710E-01; w_mass_mmd1_loss: 5.536E-02
# Epoch 27; dinu_pt_loss: 5.117E+01; higgs_mass_loss: 2.399E+01; loss: 1.033E+02; mae_loss: 5.077E+01; neg_r2_loss: -6.662E-01; nu_mass_loss: 1.670E-02; val_dinu_pt_loss: 5.091E+01; val_higgs_mass_loss: 2.387E+01; val_loss: 1.028E+02; val_mae_loss: 5.064E+01; val_neg_r2_loss: -6.725E-01; val_nu_mass_loss: 1.704E-02; val_w0_mass_mae_loss: 2.144E+01; val_w1_mass_mae_loss: 2.049E+01; val_w_mass_mmd0_loss: 1.337E-01; val_w_mass_mmd1_loss: 5.395E-02; w0_mass_mae_loss: 2.172E+01; w1_mass_mae_loss: 2.047E+01; w_mass_mmd0_loss: 1.648E-01; w_mass_mmd1_loss: 5.542E-02
# Epoch 28; dinu_pt_loss: 5.120E+01; higgs_mass_loss: 2.383E+01; loss: 1.030E+02; mae_loss: 5.062E+01; neg_r2_loss: -6.676E-01; nu_mass_loss: 1.699E-02; val_dinu_pt_loss: 5.075E+01; val_higgs_mass_loss: 2.306E+01; val_loss: 1.024E+02; val_mae_loss: 5.053E+01; val_neg_r2_loss: -6.729E-01; val_nu_mass_loss: 1.733E-02; val_w0_mass_mae_loss: 2.079E+01; val_w1_mass_mae_loss: 2.044E+01; val_w_mass_mmd0_loss: 1.117E-01; val_w_mass_mmd1_loss: 5.566E-02; w0_mass_mae_loss: 2.164E+01; w1_mass_mae_loss: 2.044E+01; w_mass_mmd0_loss: 1.639E-01; w_mass_mmd1_loss: 5.548E-02
# Epoch 29; dinu_pt_loss: 5.106E+01; higgs_mass_loss: 2.372E+01; loss: 1.027E+02; mae_loss: 5.050E+01; neg_r2_loss: -6.683E-01; nu_mass_loss: 1.726E-02; val_dinu_pt_loss: 5.116E+01; val_higgs_mass_loss: 2.374E+01; val_loss: 1.021E+02; val_mae_loss: 5.039E+01; val_neg_r2_loss: -6.745E-01; val_nu_mass_loss: 1.760E-02; val_w0_mass_mae_loss: 2.092E+01; val_w1_mass_mae_loss: 2.061E+01; val_w_mass_mmd0_loss: 1.124E-01; val_w_mass_mmd1_loss: 5.374E-02; w0_mass_mae_loss: 2.141E+01; w1_mass_mae_loss: 2.047E+01; w_mass_mmd0_loss: 1.563E-01; w_mass_mmd1_loss: 5.592E-02
# Epoch 30; dinu_pt_loss: 5.106E+01; higgs_mass_loss: 2.341E+01; loss: 1.024E+02; mae_loss: 5.040E+01; neg_r2_loss: -6.690E-01; nu_mass_loss: 1.752E-02; val_dinu_pt_loss: 5.079E+01; val_higgs_mass_loss: 2.289E+01; val_loss: 1.018E+02; val_mae_loss: 5.031E+01; val_neg_r2_loss: -6.746E-01; val_nu_mass_loss: 1.783E-02; val_w0_mass_mae_loss: 2.065E+01; val_w1_mass_mae_loss: 2.042E+01; val_w_mass_mmd0_loss: 1.001E-01; val_w_mass_mmd1_loss: 5.434E-02; w0_mass_mae_loss: 2.117E+01; w1_mass_mae_loss: 2.042E+01; w_mass_mmd0_loss: 1.463E-01; w_mass_mmd1_loss: 5.584E-02
# Epoch 31; dinu_pt_loss: 5.067E+01; higgs_mass_loss: 2.321E+01; loss: 1.022E+02; mae_loss: 5.027E+01; neg_r2_loss: -6.696E-01; nu_mass_loss: 1.776E-02; val_dinu_pt_loss: 5.039E+01; val_higgs_mass_loss: 2.310E+01; val_loss: 1.013E+02; val_mae_loss: 5.017E+01; val_neg_r2_loss: -6.756E-01; val_nu_mass_loss: 1.808E-02; val_w0_mass_mae_loss: 2.061E+01; val_w1_mass_mae_loss: 2.043E+01; val_w_mass_mmd0_loss: 6.556E-02; val_w_mass_mmd1_loss: 5.349E-02; w0_mass_mae_loss: 2.108E+01; w1_mass_mae_loss: 2.040E+01; w_mass_mmd0_loss: 1.454E-01; w_mass_mmd1_loss: 5.611E-02
# Epoch 32; dinu_pt_loss: 5.072E+01; higgs_mass_loss: 2.324E+01; loss: 1.019E+02; mae_loss: 5.015E+01; neg_r2_loss: -6.709E-01; nu_mass_loss: 1.808E-02; val_dinu_pt_loss: 5.075E+01; val_higgs_mass_loss: 2.314E+01; val_loss: 1.015E+02; val_mae_loss: 5.004E+01; val_neg_r2_loss: -6.774E-01; val_nu_mass_loss: 1.857E-02; val_w0_mass_mae_loss: 2.059E+01; val_w1_mass_mae_loss: 2.047E+01; val_w_mass_mmd0_loss: 1.231E-01; val_w_mass_mmd1_loss: 5.422E-02; w0_mass_mae_loss: 2.102E+01; w1_mass_mae_loss: 2.043E+01; w_mass_mmd0_loss: 1.436E-01; w_mass_mmd1_loss: 5.579E-02
# Epoch 33; dinu_pt_loss: 5.123E+01; higgs_mass_loss: 2.309E+01; loss: 1.016E+02; mae_loss: 5.003E+01; neg_r2_loss: -6.721E-01; nu_mass_loss: 1.843E-02; val_dinu_pt_loss: 5.171E+01; val_higgs_mass_loss: 2.296E+01; val_loss: 1.009E+02; val_mae_loss: 4.994E+01; val_neg_r2_loss: -6.787E-01; val_nu_mass_loss: 1.882E-02; val_w0_mass_mae_loss: 2.028E+01; val_w1_mass_mae_loss: 2.052E+01; val_w_mass_mmd0_loss: 7.706E-02; val_w_mass_mmd1_loss: 5.487E-02; w0_mass_mae_loss: 2.083E+01; w1_mass_mae_loss: 2.042E+01; w_mass_mmd0_loss: 1.362E-01; w_mass_mmd1_loss: 5.628E-02
# Epoch 34; dinu_pt_loss: 5.135E+01; higgs_mass_loss: 2.303E+01; loss: 1.013E+02; mae_loss: 4.992E+01; neg_r2_loss: -6.731E-01; nu_mass_loss: 1.869E-02; val_dinu_pt_loss: 5.103E+01; val_higgs_mass_loss: 2.254E+01; val_loss: 1.006E+02; val_mae_loss: 4.983E+01; val_neg_r2_loss: -6.790E-01; val_nu_mass_loss: 1.897E-02; val_w0_mass_mae_loss: 2.027E+01; val_w1_mass_mae_loss: 2.034E+01; val_w_mass_mmd0_loss: 6.256E-02; val_w_mass_mmd1_loss: 5.476E-02; w0_mass_mae_loss: 2.073E+01; w1_mass_mae_loss: 2.042E+01; w_mass_mmd0_loss: 1.318E-01; w_mass_mmd1_loss: 5.591E-02
# Epoch 35; dinu_pt_loss: 5.114E+01; higgs_mass_loss: 2.263E+01; loss: 1.011E+02; mae_loss: 4.982E+01; neg_r2_loss: -6.736E-01; nu_mass_loss: 1.890E-02; val_dinu_pt_loss: 5.150E+01; val_higgs_mass_loss: 2.302E+01; val_loss: 1.004E+02; val_mae_loss: 4.972E+01; val_neg_r2_loss: -6.802E-01; val_nu_mass_loss: 1.915E-02; val_w0_mass_mae_loss: 2.032E+01; val_w1_mass_mae_loss: 2.042E+01; val_w_mass_mmd0_loss: 5.940E-02; val_w_mass_mmd1_loss: 5.463E-02; w0_mass_mae_loss: 2.052E+01; w1_mass_mae_loss: 2.032E+01; w_mass_mmd0_loss: 1.261E-01; w_mass_mmd1_loss: 5.643E-02
# Epoch 36; dinu_pt_loss: 5.118E+01; higgs_mass_loss: 2.267E+01; loss: 1.008E+02; mae_loss: 4.970E+01; neg_r2_loss: -6.746E-01; nu_mass_loss: 1.917E-02; val_dinu_pt_loss: 5.114E+01; val_higgs_mass_loss: 2.240E+01; val_loss: 1.000E+02; val_mae_loss: 4.959E+01; val_neg_r2_loss: -6.810E-01; val_nu_mass_loss: 1.952E-02; val_w0_mass_mae_loss: 1.998E+01; val_w1_mass_mae_loss: 2.031E+01; val_w_mass_mmd0_loss: 5.333E-02; val_w_mass_mmd1_loss: 5.472E-02; w0_mass_mae_loss: 2.049E+01; w1_mass_mae_loss: 2.031E+01; w_mass_mmd0_loss: 1.234E-01; w_mass_mmd1_loss: 5.618E-02
# Epoch 37; dinu_pt_loss: 5.148E+01; higgs_mass_loss: 2.272E+01; loss: 1.006E+02; mae_loss: 4.957E+01; neg_r2_loss: -6.761E-01; nu_mass_loss: 1.952E-02; val_dinu_pt_loss: 5.119E+01; val_higgs_mass_loss: 2.269E+01; val_loss: 9.985E+01; val_mae_loss: 4.953E+01; val_neg_r2_loss: -6.814E-01; val_nu_mass_loss: 1.965E-02; val_w0_mass_mae_loss: 1.998E+01; val_w1_mass_mae_loss: 2.044E+01; val_w_mass_mmd0_loss: 4.584E-02; val_w_mass_mmd1_loss: 5.413E-02; w0_mass_mae_loss: 2.048E+01; w1_mass_mae_loss: 2.034E+01; w_mass_mmd0_loss: 1.203E-01; w_mass_mmd1_loss: 5.626E-02
# Epoch 38; dinu_pt_loss: 5.145E+01; higgs_mass_loss: 2.280E+01; loss: 1.003E+02; mae_loss: 4.944E+01; neg_r2_loss: -6.771E-01; nu_mass_loss: 1.981E-02; val_dinu_pt_loss: 5.144E+01; val_higgs_mass_loss: 2.262E+01; val_loss: 9.964E+01; val_mae_loss: 4.932E+01; val_neg_r2_loss: -6.836E-01; val_nu_mass_loss: 2.016E-02; val_w0_mass_mae_loss: 2.026E+01; val_w1_mass_mae_loss: 2.027E+01; val_w_mass_mmd0_loss: 7.007E-02; val_w_mass_mmd1_loss: 5.484E-02; w0_mass_mae_loss: 2.049E+01; w1_mass_mae_loss: 2.039E+01; w_mass_mmd0_loss: 1.196E-01; w_mass_mmd1_loss: 5.618E-02
# Epoch 39; dinu_pt_loss: 5.167E+01; higgs_mass_loss: 2.272E+01; loss: 1.000E+02; mae_loss: 4.930E+01; neg_r2_loss: -6.788E-01; nu_mass_loss: 2.012E-02; val_dinu_pt_loss: 5.175E+01; val_higgs_mass_loss: 2.277E+01; val_loss: 9.933E+01; val_mae_loss: 4.918E+01; val_neg_r2_loss: -6.858E-01; val_nu_mass_loss: 2.058E-02; val_w0_mass_mae_loss: 2.033E+01; val_w1_mass_mae_loss: 2.035E+01; val_w_mass_mmd0_loss: 6.556E-02; val_w_mass_mmd1_loss: 5.547E-02; w0_mass_mae_loss: 2.054E+01; w1_mass_mae_loss: 2.032E+01; w_mass_mmd0_loss: 1.195E-01; w_mass_mmd1_loss: 5.687E-02
# Epoch 40; dinu_pt_loss: 5.196E+01; higgs_mass_loss: 2.250E+01; loss: 9.974E+01; mae_loss: 4.916E+01; neg_r2_loss: -6.808E-01; nu_mass_loss: 2.052E-02; val_dinu_pt_loss: 5.202E+01; val_higgs_mass_loss: 2.258E+01; val_loss: 9.901E+01; val_mae_loss: 4.908E+01; val_neg_r2_loss: -6.873E-01; val_nu_mass_loss: 2.078E-02; val_w0_mass_mae_loss: 2.060E+01; val_w1_mass_mae_loss: 2.003E+01; val_w_mass_mmd0_loss: 4.967E-02; val_w_mass_mmd1_loss: 5.604E-02; w0_mass_mae_loss: 2.061E+01; w1_mass_mae_loss: 2.018E+01; w_mass_mmd0_loss: 1.187E-01; w_mass_mmd1_loss: 5.738E-02
# Epoch 41; dinu_pt_loss: 5.202E+01; higgs_mass_loss: 2.267E+01; loss: 9.948E+01; mae_loss: 4.904E+01; neg_r2_loss: -6.821E-01; nu_mass_loss: 2.080E-02; val_dinu_pt_loss: 5.259E+01; val_higgs_mass_loss: 2.255E+01; val_loss: 9.871E+01; val_mae_loss: 4.890E+01; val_neg_r2_loss: -6.901E-01; val_nu_mass_loss: 2.142E-02; val_w0_mass_mae_loss: 2.054E+01; val_w1_mass_mae_loss: 2.014E+01; val_w_mass_mmd0_loss: 5.793E-02; val_w_mass_mmd1_loss: 5.613E-02; w0_mass_mae_loss: 2.074E+01; w1_mass_mae_loss: 2.019E+01; w_mass_mmd0_loss: 1.171E-01; w_mass_mmd1_loss: 5.771E-02
# Epoch 42; dinu_pt_loss: 5.252E+01; higgs_mass_loss: 2.262E+01; loss: 9.917E+01; mae_loss: 4.887E+01; neg_r2_loss: -6.843E-01; nu_mass_loss: 2.123E-02; val_dinu_pt_loss: 5.330E+01; val_higgs_mass_loss: 2.279E+01; val_loss: 9.858E+01; val_mae_loss: 4.871E+01; val_neg_r2_loss: -6.931E-01; val_nu_mass_loss: 2.192E-02; val_w0_mass_mae_loss: 2.097E+01; val_w1_mass_mae_loss: 1.999E+01; val_w_mass_mmd0_loss: 8.836E-02; val_w_mass_mmd1_loss: 5.682E-02; w0_mass_mae_loss: 2.089E+01; w1_mass_mae_loss: 2.007E+01; w_mass_mmd0_loss: 1.216E-01; w_mass_mmd1_loss: 5.881E-02
# Epoch 43; dinu_pt_loss: 5.291E+01; higgs_mass_loss: 2.252E+01; loss: 9.889E+01; mae_loss: 4.871E+01; neg_r2_loss: -6.868E-01; nu_mass_loss: 2.170E-02; val_dinu_pt_loss: 5.238E+01; val_higgs_mass_loss: 2.208E+01; val_loss: 9.822E+01; val_mae_loss: 4.863E+01; val_neg_r2_loss: -6.926E-01; val_nu_mass_loss: 2.187E-02; val_w0_mass_mae_loss: 2.063E+01; val_w1_mass_mae_loss: 1.980E+01; val_w_mass_mmd0_loss: 6.042E-02; val_w_mass_mmd1_loss: 5.888E-02; w0_mass_mae_loss: 2.107E+01; w1_mass_mae_loss: 1.989E+01; w_mass_mmd0_loss: 1.234E-01; w_mass_mmd1_loss: 6.025E-02
# Epoch 44; dinu_pt_loss: 5.267E+01; higgs_mass_loss: 2.238E+01; loss: 9.858E+01; mae_loss: 4.857E+01; neg_r2_loss: -6.880E-01; nu_mass_loss: 2.199E-02; val_dinu_pt_loss: 5.291E+01; val_higgs_mass_loss: 2.210E+01; val_loss: 9.793E+01; val_mae_loss: 4.850E+01; val_neg_r2_loss: -6.945E-01; val_nu_mass_loss: 2.242E-02; val_w0_mass_mae_loss: 2.066E+01; val_w1_mass_mae_loss: 1.985E+01; val_w_mass_mmd0_loss: 5.739E-02; val_w_mass_mmd1_loss: 5.918E-02; w0_mass_mae_loss: 2.096E+01; w1_mass_mae_loss: 1.992E+01; w_mass_mmd0_loss: 1.186E-01; w_mass_mmd1_loss: 6.096E-02
# Epoch 45; dinu_pt_loss: 5.245E+01; higgs_mass_loss: 2.231E+01; loss: 9.827E+01; mae_loss: 4.842E+01; neg_r2_loss: -6.894E-01; nu_mass_loss: 2.232E-02; val_dinu_pt_loss: 5.312E+01; val_higgs_mass_loss: 2.236E+01; val_loss: 9.767E+01; val_mae_loss: 4.829E+01; val_neg_r2_loss: -6.968E-01; val_nu_mass_loss: 2.284E-02; val_w0_mass_mae_loss: 2.107E+01; val_w1_mass_mae_loss: 1.972E+01; val_w_mass_mmd0_loss: 7.487E-02; val_w_mass_mmd1_loss: 6.057E-02; w0_mass_mae_loss: 2.096E+01; w1_mass_mae_loss: 1.985E+01; w_mass_mmd0_loss: 1.163E-01; w_mass_mmd1_loss: 6.192E-02
# Epoch 46; dinu_pt_loss: 5.253E+01; higgs_mass_loss: 2.222E+01; loss: 9.798E+01; mae_loss: 4.828E+01; neg_r2_loss: -6.908E-01; nu_mass_loss: 2.269E-02; val_dinu_pt_loss: 5.231E+01; val_higgs_mass_loss: 2.191E+01; val_loss: 9.734E+01; val_mae_loss: 4.819E+01; val_neg_r2_loss: -6.967E-01; val_nu_mass_loss: 2.282E-02; val_w0_mass_mae_loss: 2.042E+01; val_w1_mass_mae_loss: 1.981E+01; val_w_mass_mmd0_loss: 5.798E-02; val_w_mass_mmd1_loss: 6.168E-02; w0_mass_mae_loss: 2.083E+01; w1_mass_mae_loss: 1.988E+01; w_mass_mmd0_loss: 1.142E-01; w_mass_mmd1_loss: 6.198E-02
# Epoch 47; dinu_pt_loss: 5.288E+01; higgs_mass_loss: 2.219E+01; loss: 9.766E+01; mae_loss: 4.810E+01; neg_r2_loss: -6.929E-01; nu_mass_loss: 2.309E-02; val_dinu_pt_loss: 5.268E+01; val_higgs_mass_loss: 2.187E+01; val_loss: 9.698E+01; val_mae_loss: 4.801E+01; val_neg_r2_loss: -6.992E-01; val_nu_mass_loss: 2.336E-02; val_w0_mass_mae_loss: 2.066E+01; val_w1_mass_mae_loss: 1.963E+01; val_w_mass_mmd0_loss: 5.680E-02; val_w_mass_mmd1_loss: 6.248E-02; w0_mass_mae_loss: 2.096E+01; w1_mass_mae_loss: 1.975E+01; w_mass_mmd0_loss: 1.192E-01; w_mass_mmd1_loss: 6.340E-02
# Epoch 48; dinu_pt_loss: 5.264E+01; higgs_mass_loss: 2.198E+01; loss: 9.734E+01; mae_loss: 4.797E+01; neg_r2_loss: -6.942E-01; nu_mass_loss: 2.339E-02; val_dinu_pt_loss: 5.241E+01; val_higgs_mass_loss: 2.147E+01; val_loss: 9.666E+01; val_mae_loss: 4.790E+01; val_neg_r2_loss: -7.001E-01; val_nu_mass_loss: 2.353E-02; val_w0_mass_mae_loss: 2.042E+01; val_w1_mass_mae_loss: 1.956E+01; val_w_mass_mmd0_loss: 4.551E-02; val_w_mass_mmd1_loss: 6.282E-02; w0_mass_mae_loss: 2.081E+01; w1_mass_mae_loss: 1.974E+01; w_mass_mmd0_loss: 1.121E-01; w_mass_mmd1_loss: 6.407E-02
# Epoch 49; dinu_pt_loss: 5.284E+01; higgs_mass_loss: 2.188E+01; loss: 9.704E+01; mae_loss: 4.780E+01; neg_r2_loss: -6.961E-01; nu_mass_loss: 2.373E-02; val_dinu_pt_loss: 5.270E+01; val_higgs_mass_loss: 2.101E+01; val_loss: 9.630E+01; val_mae_loss: 4.772E+01; val_neg_r2_loss: -7.020E-01; val_nu_mass_loss: 2.392E-02; val_w0_mass_mae_loss: 2.031E+01; val_w1_mass_mae_loss: 1.936E+01; val_w_mass_mmd0_loss: 4.228E-02; val_w_mass_mmd1_loss: 6.475E-02; w0_mass_mae_loss: 2.088E+01; w1_mass_mae_loss: 1.964E+01; w_mass_mmd0_loss: 1.145E-01; w_mass_mmd1_loss: 6.495E-02
# Epoch 50; dinu_pt_loss: 5.287E+01; higgs_mass_loss: 2.165E+01; loss: 9.672E+01; mae_loss: 4.764E+01; neg_r2_loss: -6.978E-01; nu_mass_loss: 2.405E-02; val_dinu_pt_loss: 5.327E+01; val_higgs_mass_loss: 2.116E+01; val_loss: 9.606E+01; val_mae_loss: 4.755E+01; val_neg_r2_loss: -7.041E-01; val_nu_mass_loss: 2.432E-02; val_w0_mass_mae_loss: 2.057E+01; val_w1_mass_mae_loss: 1.929E+01; val_w_mass_mmd0_loss: 5.430E-02; val_w_mass_mmd1_loss: 6.745E-02; w0_mass_mae_loss: 2.089E+01; w1_mass_mae_loss: 1.944E+01; w_mass_mmd0_loss: 1.118E-01; w_mass_mmd1_loss: 6.666E-02
# Epoch 51; dinu_pt_loss: 5.305E+01; higgs_mass_loss: 2.147E+01; loss: 9.642E+01; mae_loss: 4.749E+01; neg_r2_loss: -6.994E-01; nu_mass_loss: 2.441E-02; val_dinu_pt_loss: 5.284E+01; val_higgs_mass_loss: 2.160E+01; val_loss: 9.576E+01; val_mae_loss: 4.738E+01; val_neg_r2_loss: -7.059E-01; val_nu_mass_loss: 2.452E-02; val_w0_mass_mae_loss: 2.076E+01; val_w1_mass_mae_loss: 1.941E+01; val_w_mass_mmd0_loss: 5.846E-02; val_w_mass_mmd1_loss: 6.735E-02; w0_mass_mae_loss: 2.079E+01; w1_mass_mae_loss: 1.944E+01; w_mass_mmd0_loss: 1.109E-01; w_mass_mmd1_loss: 6.792E-02
# Epoch 52; dinu_pt_loss: 5.264E+01; higgs_mass_loss: 2.150E+01; loss: 9.607E+01; mae_loss: 4.734E+01; neg_r2_loss: -7.009E-01; nu_mass_loss: 2.471E-02; val_dinu_pt_loss: 5.200E+01; val_higgs_mass_loss: 2.100E+01; val_loss: 9.541E+01; val_mae_loss: 4.727E+01; val_neg_r2_loss: -7.060E-01; val_nu_mass_loss: 2.480E-02; val_w0_mass_mae_loss: 2.026E+01; val_w1_mass_mae_loss: 1.939E+01; val_w_mass_mmd0_loss: 4.189E-02; val_w_mass_mmd1_loss: 6.742E-02; w0_mass_mae_loss: 2.072E+01; w1_mass_mae_loss: 1.951E+01; w_mass_mmd0_loss: 1.054E-01; w_mass_mmd1_loss: 6.789E-02
# Epoch 53; dinu_pt_loss: 5.226E+01; higgs_mass_loss: 2.152E+01; loss: 9.578E+01; mae_loss: 4.719E+01; neg_r2_loss: -7.023E-01; nu_mass_loss: 2.502E-02; val_dinu_pt_loss: 5.175E+01; val_higgs_mass_loss: 2.114E+01; val_loss: 9.512E+01; val_mae_loss: 4.709E+01; val_neg_r2_loss: -7.082E-01; val_nu_mass_loss: 2.519E-02; val_w0_mass_mae_loss: 2.031E+01; val_w1_mass_mae_loss: 1.947E+01; val_w_mass_mmd0_loss: 5.014E-02; val_w_mass_mmd1_loss: 6.637E-02; w0_mass_mae_loss: 2.078E+01; w1_mass_mae_loss: 1.952E+01; w_mass_mmd0_loss: 1.080E-01; w_mass_mmd1_loss: 6.825E-02
# Epoch 54; dinu_pt_loss: 5.147E+01; higgs_mass_loss: 2.156E+01; loss: 9.544E+01; mae_loss: 4.704E+01; neg_r2_loss: -7.035E-01; nu_mass_loss: 2.532E-02; val_dinu_pt_loss: 5.133E+01; val_higgs_mass_loss: 2.130E+01; val_loss: 9.482E+01; val_mae_loss: 4.694E+01; val_neg_r2_loss: -7.094E-01; val_nu_mass_loss: 2.548E-02; val_w0_mass_mae_loss: 2.026E+01; val_w1_mass_mae_loss: 1.951E+01; val_w_mass_mmd0_loss: 5.182E-02; val_w_mass_mmd1_loss: 6.718E-02; w0_mass_mae_loss: 2.066E+01; w1_mass_mae_loss: 1.959E+01; w_mass_mmd0_loss: 1.025E-01; w_mass_mmd1_loss: 6.804E-02
# Epoch 55; dinu_pt_loss: 5.176E+01; higgs_mass_loss: 2.149E+01; loss: 9.514E+01; mae_loss: 4.686E+01; neg_r2_loss: -7.054E-01; nu_mass_loss: 2.569E-02; val_dinu_pt_loss: 5.168E+01; val_higgs_mass_loss: 2.048E+01; val_loss: 9.443E+01; val_mae_loss: 4.678E+01; val_neg_r2_loss: -7.110E-01; val_nu_mass_loss: 2.584E-02; val_w0_mass_mae_loss: 1.995E+01; val_w1_mass_mae_loss: 1.936E+01; val_w_mass_mmd0_loss: 3.996E-02; val_w_mass_mmd1_loss: 6.884E-02; w0_mass_mae_loss: 2.071E+01; w1_mass_mae_loss: 1.954E+01; w_mass_mmd0_loss: 1.080E-01; w_mass_mmd1_loss: 6.952E-02
# Epoch 56; dinu_pt_loss: 5.185E+01; higgs_mass_loss: 2.121E+01; loss: 9.483E+01; mae_loss: 4.671E+01; neg_r2_loss: -7.071E-01; nu_mass_loss: 2.596E-02; val_dinu_pt_loss: 5.203E+01; val_higgs_mass_loss: 2.081E+01; val_loss: 9.418E+01; val_mae_loss: 4.659E+01; val_neg_r2_loss: -7.131E-01; val_nu_mass_loss: 2.618E-02; val_w0_mass_mae_loss: 2.047E+01; val_w1_mass_mae_loss: 1.929E+01; val_w_mass_mmd0_loss: 5.170E-02; val_w_mass_mmd1_loss: 7.329E-02; w0_mass_mae_loss: 2.062E+01; w1_mass_mae_loss: 1.941E+01; w_mass_mmd0_loss: 1.056E-01; w_mass_mmd1_loss: 7.068E-02
# Epoch 57; dinu_pt_loss: 5.180E+01; higgs_mass_loss: 2.113E+01; loss: 9.449E+01; mae_loss: 4.654E+01; neg_r2_loss: -7.088E-01; nu_mass_loss: 2.633E-02; val_dinu_pt_loss: 5.181E+01; val_higgs_mass_loss: 2.072E+01; val_loss: 9.389E+01; val_mae_loss: 4.648E+01; val_neg_r2_loss: -7.143E-01; val_nu_mass_loss: 2.640E-02; val_w0_mass_mae_loss: 2.025E+01; val_w1_mass_mae_loss: 1.931E+01; val_w_mass_mmd0_loss: 4.455E-02; val_w_mass_mmd1_loss: 7.235E-02; w0_mass_mae_loss: 2.068E+01; w1_mass_mae_loss: 1.936E+01; w_mass_mmd0_loss: 1.050E-01; w_mass_mmd1_loss: 7.152E-02
# Epoch 58; dinu_pt_loss: 5.163E+01; higgs_mass_loss: 2.102E+01; loss: 9.417E+01; mae_loss: 4.638E+01; neg_r2_loss: -7.105E-01; nu_mass_loss: 2.666E-02; val_dinu_pt_loss: 5.041E+01; val_higgs_mass_loss: 1.998E+01; val_loss: 9.353E+01; val_mae_loss: 4.635E+01; val_neg_r2_loss: -7.149E-01; val_nu_mass_loss: 2.651E-02; val_w0_mass_mae_loss: 1.957E+01; val_w1_mass_mae_loss: 1.925E+01; val_w_mass_mmd0_loss: 3.318E-02; val_w_mass_mmd1_loss: 7.036E-02; w0_mass_mae_loss: 2.060E+01; w1_mass_mae_loss: 1.929E+01; w_mass_mmd0_loss: 1.041E-01; w_mass_mmd1_loss: 7.182E-02
# Epoch 59; dinu_pt_loss: 5.070E+01; higgs_mass_loss: 2.082E+01; loss: 9.384E+01; mae_loss: 4.622E+01; neg_r2_loss: -7.117E-01; nu_mass_loss: 2.688E-02; val_dinu_pt_loss: 5.045E+01; val_higgs_mass_loss: 2.047E+01; val_loss: 9.322E+01; val_mae_loss: 4.614E+01; val_neg_r2_loss: -7.172E-01; val_nu_mass_loss: 2.685E-02; val_w0_mass_mae_loss: 2.021E+01; val_w1_mass_mae_loss: 1.916E+01; val_w_mass_mmd0_loss: 4.338E-02; val_w_mass_mmd1_loss: 7.316E-02; w0_mass_mae_loss: 2.047E+01; w1_mass_mae_loss: 1.929E+01; w_mass_mmd0_loss: 1.026E-01; w_mass_mmd1_loss: 7.147E-02
# Epoch 60; dinu_pt_loss: 5.059E+01; higgs_mass_loss: 2.071E+01; loss: 9.349E+01; mae_loss: 4.606E+01; neg_r2_loss: -7.135E-01; nu_mass_loss: 2.720E-02; val_dinu_pt_loss: 4.985E+01; val_higgs_mass_loss: 1.990E+01; val_loss: 9.284E+01; val_mae_loss: 4.597E+01; val_neg_r2_loss: -7.186E-01; val_nu_mass_loss: 2.727E-02; val_w0_mass_mae_loss: 1.976E+01; val_w1_mass_mae_loss: 1.910E+01; val_w_mass_mmd0_loss: 4.095E-02; val_w_mass_mmd1_loss: 7.301E-02; w0_mass_mae_loss: 2.048E+01; w1_mass_mae_loss: 1.918E+01; w_mass_mmd0_loss: 9.907E-02; w_mass_mmd1_loss: 7.248E-02
# Epoch 61; dinu_pt_loss: 4.998E+01; higgs_mass_loss: 2.070E+01; loss: 9.319E+01; mae_loss: 4.587E+01; neg_r2_loss: -7.149E-01; nu_mass_loss: 2.750E-02; val_dinu_pt_loss: 4.958E+01; val_higgs_mass_loss: 2.010E+01; val_loss: 9.257E+01; val_mae_loss: 4.579E+01; val_neg_r2_loss: -7.200E-01; val_nu_mass_loss: 2.756E-02; val_w0_mass_mae_loss: 2.022E+01; val_w1_mass_mae_loss: 1.903E+01; val_w_mass_mmd0_loss: 4.867E-02; val_w_mass_mmd1_loss: 7.360E-02; w0_mass_mae_loss: 2.064E+01; w1_mass_mae_loss: 1.910E+01; w_mass_mmd0_loss: 1.075E-01; w_mass_mmd1_loss: 7.359E-02
# Epoch 62; dinu_pt_loss: 4.936E+01; higgs_mass_loss: 2.060E+01; loss: 9.284E+01; mae_loss: 4.570E+01; neg_r2_loss: -7.162E-01; nu_mass_loss: 2.778E-02; val_dinu_pt_loss: 4.894E+01; val_higgs_mass_loss: 2.008E+01; val_loss: 9.213E+01; val_mae_loss: 4.559E+01; val_neg_r2_loss: -7.217E-01; val_nu_mass_loss: 2.794E-02; val_w0_mass_mae_loss: 2.010E+01; val_w1_mass_mae_loss: 1.908E+01; val_w_mass_mmd0_loss: 4.544E-02; val_w_mass_mmd1_loss: 7.380E-02; w0_mass_mae_loss: 2.054E+01; w1_mass_mae_loss: 1.916E+01; w_mass_mmd0_loss: 1.051E-01; w_mass_mmd1_loss: 7.388E-02
# Epoch 63; dinu_pt_loss: 4.898E+01; higgs_mass_loss: 2.052E+01; loss: 9.247E+01; mae_loss: 4.554E+01; neg_r2_loss: -7.179E-01; nu_mass_loss: 2.808E-02; val_dinu_pt_loss: 4.811E+01; val_higgs_mass_loss: 1.993E+01; val_loss: 9.180E+01; val_mae_loss: 4.544E+01; val_neg_r2_loss: -7.235E-01; val_nu_mass_loss: 2.826E-02; val_w0_mass_mae_loss: 2.005E+01; val_w1_mass_mae_loss: 1.902E+01; val_w_mass_mmd0_loss: 4.225E-02; val_w_mass_mmd1_loss: 7.377E-02; w0_mass_mae_loss: 2.055E+01; w1_mass_mae_loss: 1.909E+01; w_mass_mmd0_loss: 9.971E-02; w_mass_mmd1_loss: 7.417E-02
# Epoch 64; dinu_pt_loss: 4.868E+01; higgs_mass_loss: 2.039E+01; loss: 9.219E+01; mae_loss: 4.537E+01; neg_r2_loss: -7.196E-01; nu_mass_loss: 2.842E-02; val_dinu_pt_loss: 4.788E+01; val_higgs_mass_loss: 1.985E+01; val_loss: 9.150E+01; val_mae_loss: 4.526E+01; val_neg_r2_loss: -7.251E-01; val_nu_mass_loss: 2.852E-02; val_w0_mass_mae_loss: 2.016E+01; val_w1_mass_mae_loss: 1.897E+01; val_w_mass_mmd0_loss: 4.833E-02; val_w_mass_mmd1_loss: 7.519E-02; w0_mass_mae_loss: 2.063E+01; w1_mass_mae_loss: 1.899E+01; w_mass_mmd0_loss: 1.056E-01; w_mass_mmd1_loss: 7.552E-02
# Epoch 65; dinu_pt_loss: 4.815E+01; higgs_mass_loss: 2.029E+01; loss: 9.184E+01; mae_loss: 4.522E+01; neg_r2_loss: -7.211E-01; nu_mass_loss: 2.868E-02; val_dinu_pt_loss: 4.768E+01; val_higgs_mass_loss: 1.953E+01; val_loss: 9.124E+01; val_mae_loss: 4.514E+01; val_neg_r2_loss: -7.264E-01; val_nu_mass_loss: 2.858E-02; val_w0_mass_mae_loss: 1.984E+01; val_w1_mass_mae_loss: 1.893E+01; val_w_mass_mmd0_loss: 4.419E-02; val_w_mass_mmd1_loss: 7.578E-02; w0_mass_mae_loss: 2.046E+01; w1_mass_mae_loss: 1.897E+01; w_mass_mmd0_loss: 9.944E-02; w_mass_mmd1_loss: 7.514E-02
# Epoch 66; dinu_pt_loss: 4.783E+01; higgs_mass_loss: 1.998E+01; loss: 9.151E+01; mae_loss: 4.505E+01; neg_r2_loss: -7.229E-01; nu_mass_loss: 2.901E-02; val_dinu_pt_loss: 4.735E+01; val_higgs_mass_loss: 1.933E+01; val_loss: 9.084E+01; val_mae_loss: 4.494E+01; val_neg_r2_loss: -7.285E-01; val_nu_mass_loss: 2.918E-02; val_w0_mass_mae_loss: 2.005E+01; val_w1_mass_mae_loss: 1.876E+01; val_w_mass_mmd0_loss: 4.239E-02; val_w_mass_mmd1_loss: 7.759E-02; w0_mass_mae_loss: 2.040E+01; w1_mass_mae_loss: 1.885E+01; w_mass_mmd0_loss: 1.001E-01; w_mass_mmd1_loss: 7.695E-02
# Epoch 67; dinu_pt_loss: 4.783E+01; higgs_mass_loss: 2.000E+01; loss: 9.118E+01; mae_loss: 4.488E+01; neg_r2_loss: -7.247E-01; nu_mass_loss: 2.936E-02; val_dinu_pt_loss: 4.728E+01; val_higgs_mass_loss: 1.897E+01; val_loss: 9.047E+01; val_mae_loss: 4.476E+01; val_neg_r2_loss: -7.304E-01; val_nu_mass_loss: 2.958E-02; val_w0_mass_mae_loss: 1.992E+01; val_w1_mass_mae_loss: 1.869E+01; val_w_mass_mmd0_loss: 4.111E-02; val_w_mass_mmd1_loss: 7.925E-02; w0_mass_mae_loss: 2.053E+01; w1_mass_mae_loss: 1.878E+01; w_mass_mmd0_loss: 9.981E-02; w_mass_mmd1_loss: 7.865E-02
# Epoch 68; dinu_pt_loss: 4.737E+01; higgs_mass_loss: 1.965E+01; loss: 9.088E+01; mae_loss: 4.473E+01; neg_r2_loss: -7.264E-01; nu_mass_loss: 2.964E-02; val_dinu_pt_loss: 4.663E+01; val_higgs_mass_loss: 1.880E+01; val_loss: 9.044E+01; val_mae_loss: 4.472E+01; val_neg_r2_loss: -7.306E-01; val_nu_mass_loss: 2.947E-02; val_w0_mass_mae_loss: 1.969E+01; val_w1_mass_mae_loss: 1.867E+01; val_w_mass_mmd0_loss: 4.421E-02; val_w_mass_mmd1_loss: 7.942E-02; w0_mass_mae_loss: 2.031E+01; w1_mass_mae_loss: 1.868E+01; w_mass_mmd0_loss: 9.784E-02; w_mass_mmd1_loss: 7.958E-02
# Epoch 69; dinu_pt_loss: 4.686E+01; higgs_mass_loss: 1.962E+01; loss: 9.053E+01; mae_loss: 4.455E+01; neg_r2_loss: -7.281E-01; nu_mass_loss: 2.996E-02; val_dinu_pt_loss: 4.595E+01; val_higgs_mass_loss: 1.899E+01; val_loss: 8.990E+01; val_mae_loss: 4.447E+01; val_neg_r2_loss: -7.326E-01; val_nu_mass_loss: 2.991E-02; val_w0_mass_mae_loss: 1.999E+01; val_w1_mass_mae_loss: 1.866E+01; val_w_mass_mmd0_loss: 4.139E-02; val_w_mass_mmd1_loss: 7.847E-02; w0_mass_mae_loss: 2.047E+01; w1_mass_mae_loss: 1.862E+01; w_mass_mmd0_loss: 9.734E-02; w_mass_mmd1_loss: 8.027E-02
# Epoch 70; dinu_pt_loss: 4.633E+01; higgs_mass_loss: 1.955E+01; loss: 9.021E+01; mae_loss: 4.440E+01; neg_r2_loss: -7.296E-01; nu_mass_loss: 3.024E-02; val_dinu_pt_loss: 4.597E+01; val_higgs_mass_loss: 1.896E+01; val_loss: 8.963E+01; val_mae_loss: 4.430E+01; val_neg_r2_loss: -7.351E-01; val_nu_mass_loss: 3.052E-02; val_w0_mass_mae_loss: 2.015E+01; val_w1_mass_mae_loss: 1.854E+01; val_w_mass_mmd0_loss: 4.719E-02; val_w_mass_mmd1_loss: 8.071E-02; w0_mass_mae_loss: 2.046E+01; w1_mass_mae_loss: 1.860E+01; w_mass_mmd0_loss: 9.736E-02; w_mass_mmd1_loss: 8.035E-02
# Epoch 71; dinu_pt_loss: 4.595E+01; higgs_mass_loss: 1.954E+01; loss: 8.991E+01; mae_loss: 4.423E+01; neg_r2_loss: -7.313E-01; nu_mass_loss: 3.057E-02; val_dinu_pt_loss: 4.576E+01; val_higgs_mass_loss: 1.888E+01; val_loss: 8.935E+01; val_mae_loss: 4.413E+01; val_neg_r2_loss: -7.371E-01; val_nu_mass_loss: 3.075E-02; val_w0_mass_mae_loss: 2.020E+01; val_w1_mass_mae_loss: 1.838E+01; val_w_mass_mmd0_loss: 5.358E-02; val_w_mass_mmd1_loss: 8.294E-02; w0_mass_mae_loss: 2.056E+01; w1_mass_mae_loss: 1.852E+01; w_mass_mmd0_loss: 9.994E-02; w_mass_mmd1_loss: 8.105E-02
# Epoch 72; dinu_pt_loss: 4.611E+01; higgs_mass_loss: 1.936E+01; loss: 8.958E+01; mae_loss: 4.406E+01; neg_r2_loss: -7.335E-01; nu_mass_loss: 3.094E-02; val_dinu_pt_loss: 4.561E+01; val_higgs_mass_loss: 1.887E+01; val_loss: 8.903E+01; val_mae_loss: 4.399E+01; val_neg_r2_loss: -7.383E-01; val_nu_mass_loss: 3.104E-02; val_w0_mass_mae_loss: 2.022E+01; val_w1_mass_mae_loss: 1.836E+01; val_w_mass_mmd0_loss: 4.773E-02; val_w_mass_mmd1_loss: 8.272E-02; w0_mass_mae_loss: 2.056E+01; w1_mass_mae_loss: 1.839E+01; w_mass_mmd0_loss: 9.943E-02; w_mass_mmd1_loss: 8.315E-02
# Epoch 73; dinu_pt_loss: 4.528E+01; higgs_mass_loss: 1.913E+01; loss: 8.925E+01; mae_loss: 4.391E+01; neg_r2_loss: -7.350E-01; nu_mass_loss: 3.127E-02; val_dinu_pt_loss: 4.476E+01; val_higgs_mass_loss: 1.840E+01; val_loss: 8.873E+01; val_mae_loss: 4.383E+01; val_neg_r2_loss: -7.397E-01; val_nu_mass_loss: 3.124E-02; val_w0_mass_mae_loss: 2.004E+01; val_w1_mass_mae_loss: 1.830E+01; val_w_mass_mmd0_loss: 5.104E-02; val_w_mass_mmd1_loss: 8.292E-02; w0_mass_mae_loss: 2.049E+01; w1_mass_mae_loss: 1.836E+01; w_mass_mmd0_loss: 9.660E-02; w_mass_mmd1_loss: 8.255E-02
# Epoch 74; dinu_pt_loss: 4.475E+01; higgs_mass_loss: 1.897E+01; loss: 8.892E+01; mae_loss: 4.376E+01; neg_r2_loss: -7.362E-01; nu_mass_loss: 3.151E-02; val_dinu_pt_loss: 4.412E+01; val_higgs_mass_loss: 1.849E+01; val_loss: 8.839E+01; val_mae_loss: 4.370E+01; val_neg_r2_loss: -7.407E-01; val_nu_mass_loss: 3.136E-02; val_w0_mass_mae_loss: 2.000E+01; val_w1_mass_mae_loss: 1.831E+01; val_w_mass_mmd0_loss: 4.209E-02; val_w_mass_mmd1_loss: 8.233E-02; w0_mass_mae_loss: 2.036E+01; w1_mass_mae_loss: 1.837E+01; w_mass_mmd0_loss: 9.237E-02; w_mass_mmd1_loss: 8.216E-02
# Epoch 75; dinu_pt_loss: 4.436E+01; higgs_mass_loss: 1.889E+01; loss: 8.861E+01; mae_loss: 4.360E+01; neg_r2_loss: -7.380E-01; nu_mass_loss: 3.184E-02; val_dinu_pt_loss: 4.329E+01; val_higgs_mass_loss: 1.827E+01; val_loss: 8.807E+01; val_mae_loss: 4.350E+01; val_neg_r2_loss: -7.429E-01; val_nu_mass_loss: 3.192E-02; val_w0_mass_mae_loss: 2.012E+01; val_w1_mass_mae_loss: 1.823E+01; val_w_mass_mmd0_loss: 5.127E-02; val_w_mass_mmd1_loss: 8.333E-02; w0_mass_mae_loss: 2.038E+01; w1_mass_mae_loss: 1.830E+01; w_mass_mmd0_loss: 9.273E-02; w_mass_mmd1_loss: 8.301E-02
# Epoch 76; dinu_pt_loss: 4.353E+01; higgs_mass_loss: 1.866E+01; loss: 8.829E+01; mae_loss: 4.344E+01; neg_r2_loss: -7.394E-01; nu_mass_loss: 3.208E-02; val_dinu_pt_loss: 4.287E+01; val_higgs_mass_loss: 1.810E+01; val_loss: 8.782E+01; val_mae_loss: 4.342E+01; val_neg_r2_loss: -7.431E-01; val_nu_mass_loss: 3.190E-02; val_w0_mass_mae_loss: 1.991E+01; val_w1_mass_mae_loss: 1.828E+01; val_w_mass_mmd0_loss: 4.074E-02; val_w_mass_mmd1_loss: 8.147E-02; w0_mass_mae_loss: 2.026E+01; w1_mass_mae_loss: 1.830E+01; w_mass_mmd0_loss: 9.314E-02; w_mass_mmd1_loss: 8.227E-02
# Epoch 77; dinu_pt_loss: 4.334E+01; higgs_mass_loss: 1.876E+01; loss: 8.798E+01; mae_loss: 4.329E+01; neg_r2_loss: -7.411E-01; nu_mass_loss: 3.245E-02; val_dinu_pt_loss: 4.253E+01; val_higgs_mass_loss: 1.821E+01; val_loss: 8.751E+01; val_mae_loss: 4.319E+01; val_neg_r2_loss: -7.455E-01; val_nu_mass_loss: 3.248E-02; val_w0_mass_mae_loss: 2.020E+01; val_w1_mass_mae_loss: 1.817E+01; val_w_mass_mmd0_loss: 5.709E-02; val_w_mass_mmd1_loss: 8.265E-02; w0_mass_mae_loss: 2.044E+01; w1_mass_mae_loss: 1.823E+01; w_mass_mmd0_loss: 9.387E-02; w_mass_mmd1_loss: 8.229E-02
# Epoch 78; dinu_pt_loss: 4.285E+01; higgs_mass_loss: 1.854E+01; loss: 8.764E+01; mae_loss: 4.314E+01; neg_r2_loss: -7.426E-01; nu_mass_loss: 3.272E-02; val_dinu_pt_loss: 4.218E+01; val_higgs_mass_loss: 1.806E+01; val_loss: 8.710E+01; val_mae_loss: 4.305E+01; val_neg_r2_loss: -7.472E-01; val_nu_mass_loss: 3.278E-02; val_w0_mass_mae_loss: 1.998E+01; val_w1_mass_mae_loss: 1.814E+01; val_w_mass_mmd0_loss: 4.155E-02; val_w_mass_mmd1_loss: 8.327E-02; w0_mass_mae_loss: 2.029E+01; w1_mass_mae_loss: 1.821E+01; w_mass_mmd0_loss: 8.839E-02; w_mass_mmd1_loss: 8.228E-02
# Epoch 79; dinu_pt_loss: 4.216E+01; higgs_mass_loss: 1.845E+01; loss: 8.734E+01; mae_loss: 4.299E+01; neg_r2_loss: -7.441E-01; nu_mass_loss: 3.299E-02; val_dinu_pt_loss: 4.154E+01; val_higgs_mass_loss: 1.818E+01; val_loss: 8.689E+01; val_mae_loss: 4.289E+01; val_neg_r2_loss: -7.489E-01; val_nu_mass_loss: 3.311E-02; val_w0_mass_mae_loss: 2.018E+01; val_w1_mass_mae_loss: 1.816E+01; val_w_mass_mmd0_loss: 5.605E-02; val_w_mass_mmd1_loss: 8.149E-02; w0_mass_mae_loss: 2.027E+01; w1_mass_mae_loss: 1.819E+01; w_mass_mmd0_loss: 8.844E-02; w_mass_mmd1_loss: 8.168E-02
# Epoch 80; dinu_pt_loss: 4.170E+01; higgs_mass_loss: 1.844E+01; loss: 8.705E+01; mae_loss: 4.285E+01; neg_r2_loss: -7.454E-01; nu_mass_loss: 3.327E-02; val_dinu_pt_loss: 4.118E+01; val_higgs_mass_loss: 1.780E+01; val_loss: 8.657E+01; val_mae_loss: 4.276E+01; val_neg_r2_loss: -7.506E-01; val_nu_mass_loss: 3.345E-02; val_w0_mass_mae_loss: 1.998E+01; val_w1_mass_mae_loss: 1.809E+01; val_w_mass_mmd0_loss: 5.157E-02; val_w_mass_mmd1_loss: 8.060E-02; w0_mass_mae_loss: 2.026E+01; w1_mass_mae_loss: 1.820E+01; w_mass_mmd0_loss: 8.968E-02; w_mass_mmd1_loss: 8.086E-02
# Epoch 81; dinu_pt_loss: 4.150E+01; higgs_mass_loss: 1.834E+01; loss: 8.674E+01; mae_loss: 4.270E+01; neg_r2_loss: -7.472E-01; nu_mass_loss: 3.364E-02; val_dinu_pt_loss: 4.092E+01; val_higgs_mass_loss: 1.802E+01; val_loss: 8.622E+01; val_mae_loss: 4.260E+01; val_neg_r2_loss: -7.517E-01; val_nu_mass_loss: 3.350E-02; val_w0_mass_mae_loss: 2.011E+01; val_w1_mass_mae_loss: 1.804E+01; val_w_mass_mmd0_loss: 4.407E-02; val_w_mass_mmd1_loss: 8.232E-02; w0_mass_mae_loss: 2.032E+01; w1_mass_mae_loss: 1.811E+01; w_mass_mmd0_loss: 8.744E-02; w_mass_mmd1_loss: 8.047E-02
# ...
# Epoch 221; dinu_pt_loss: 8.894E+00; higgs_mass_loss: 1.106E+01; loss: 6.703E+01; mae_loss: 3.331E+01; neg_r2_loss: -8.376E-01; nu_mass_loss: 4.807E-02; val_dinu_pt_loss: 8.264E+00; val_higgs_mass_loss: 1.064E+01; val_loss: 6.763E+01; val_mae_loss: 3.358E+01; val_neg_r2_loss: -8.387E-01; val_nu_mass_loss: 4.815E-02; val_w0_mass_mae_loss: 1.494E+01; val_w1_mass_mae_loss: 1.865E+01; val_w_mass_mmd0_loss: 3.290E-02; val_w_mass_mmd1_loss: 2.552E-02; w0_mass_mae_loss: 1.508E+01; w1_mass_mae_loss: 1.878E+01; w_mass_mmd0_loss: 2.594E-02; w_mass_mmd1_loss: 2.489E-02
# Epoch 222; dinu_pt_loss: 8.908E+00; higgs_mass_loss: 1.107E+01; loss: 6.704E+01; mae_loss: 3.331E+01; neg_r2_loss: -8.376E-01; nu_mass_loss: 4.823E-02; val_dinu_pt_loss: 8.280E+00; val_higgs_mass_loss: 1.075E+01; val_loss: 6.760E+01; val_mae_loss: 3.359E+01; val_neg_r2_loss: -8.382E-01; val_nu_mass_loss: 4.821E-02; val_w0_mass_mae_loss: 1.496E+01; val_w1_mass_mae_loss: 1.871E+01; val_w_mass_mmd0_loss: 2.654E-02; val_w_mass_mmd1_loss: 2.550E-02; w0_mass_mae_loss: 1.509E+01; w1_mass_mae_loss: 1.879E+01; w_mass_mmd0_loss: 2.891E-02; w_mass_mmd1_loss: 2.455E-02
# Epoch 223; dinu_pt_loss: 8.905E+00; higgs_mass_loss: 1.097E+01; loss: 6.703E+01; mae_loss: 3.330E+01; neg_r2_loss: -8.377E-01; nu_mass_loss: 4.814E-02; val_dinu_pt_loss: 8.297E+00; val_higgs_mass_loss: 1.065E+01; val_loss: 6.770E+01; val_mae_loss: 3.360E+01; val_neg_r2_loss: -8.385E-01; val_nu_mass_loss: 4.841E-02; val_w0_mass_mae_loss: 1.500E+01; val_w1_mass_mae_loss: 1.866E+01; val_w_mass_mmd0_loss: 3.747E-02; val_w_mass_mmd1_loss: 2.538E-02; w0_mass_mae_loss: 1.510E+01; w1_mass_mae_loss: 1.870E+01; w_mass_mmd0_loss: 2.886E-02; w_mass_mmd1_loss: 2.469E-02
# Epoch 224; dinu_pt_loss: 8.867E+00; higgs_mass_loss: 1.100E+01; loss: 6.704E+01; mae_loss: 3.330E+01; neg_r2_loss: -8.376E-01; nu_mass_loss: 4.822E-02; val_dinu_pt_loss: 8.238E+00; val_higgs_mass_loss: 1.060E+01; val_loss: 6.773E+01; val_mae_loss: 3.361E+01; val_neg_r2_loss: -8.375E-01; val_nu_mass_loss: 4.761E-02; val_w0_mass_mae_loss: 1.501E+01; val_w1_mass_mae_loss: 1.868E+01; val_w_mass_mmd0_loss: 3.837E-02; val_w_mass_mmd1_loss: 2.561E-02; w0_mass_mae_loss: 1.510E+01; w1_mass_mae_loss: 1.874E+01; w_mass_mmd0_loss: 2.984E-02; w_mass_mmd1_loss: 2.466E-02
# Epoch 225; dinu_pt_loss: 8.895E+00; higgs_mass_loss: 1.104E+01; loss: 6.700E+01; mae_loss: 3.329E+01; neg_r2_loss: -8.379E-01; nu_mass_loss: 4.805E-02; val_dinu_pt_loss: 8.163E+00; val_higgs_mass_loss: 1.091E+01; val_loss: 6.758E+01; val_mae_loss: 3.358E+01; val_neg_r2_loss: -8.385E-01; val_nu_mass_loss: 4.814E-02; val_w0_mass_mae_loss: 1.496E+01; val_w1_mass_mae_loss: 1.876E+01; val_w_mass_mmd0_loss: 2.640E-02; val_w_mass_mmd1_loss: 2.607E-02; w0_mass_mae_loss: 1.511E+01; w1_mass_mae_loss: 1.878E+01; w_mass_mmd0_loss: 2.883E-02; w_mass_mmd1_loss: 2.465E-02
# Epoch 226; dinu_pt_loss: 8.935E+00; higgs_mass_loss: 1.113E+01; loss: 6.698E+01; mae_loss: 3.328E+01; neg_r2_loss: -8.381E-01; nu_mass_loss: 4.816E-02; val_dinu_pt_loss: 8.146E+00; val_higgs_mass_loss: 1.084E+01; val_loss: 6.752E+01; val_mae_loss: 3.359E+01; val_neg_r2_loss: -8.378E-01; val_nu_mass_loss: 4.822E-02; val_w0_mass_mae_loss: 1.494E+01; val_w1_mass_mae_loss: 1.871E+01; val_w_mass_mmd0_loss: 1.796E-02; val_w_mass_mmd1_loss: 2.505E-02; w0_mass_mae_loss: 1.510E+01; w1_mass_mae_loss: 1.881E+01; w_mass_mmd0_loss: 2.899E-02; w_mass_mmd1_loss: 2.440E-02
# Epoch 227; dinu_pt_loss: 8.887E+00; higgs_mass_loss: 1.114E+01; loss: 6.697E+01; mae_loss: 3.328E+01; neg_r2_loss: -8.379E-01; nu_mass_loss: 4.811E-02; val_dinu_pt_loss: 8.237E+00; val_higgs_mass_loss: 1.093E+01; val_loss: 6.761E+01; val_mae_loss: 3.359E+01; val_neg_r2_loss: -8.381E-01; val_nu_mass_loss: 4.807E-02; val_w0_mass_mae_loss: 1.499E+01; val_w1_mass_mae_loss: 1.888E+01; val_w_mass_mmd0_loss: 2.904E-02; val_w_mass_mmd1_loss: 2.495E-02; w0_mass_mae_loss: 1.510E+01; w1_mass_mae_loss: 1.884E+01; w_mass_mmd0_loss: 2.811E-02; w_mass_mmd1_loss: 2.439E-02
# Epoch 228; dinu_pt_loss: 8.903E+00; higgs_mass_loss: 1.112E+01; loss: 6.696E+01; mae_loss: 3.327E+01; neg_r2_loss: -8.380E-01; nu_mass_loss: 4.819E-02; val_dinu_pt_loss: 8.332E+00; val_higgs_mass_loss: 1.092E+01; val_loss: 6.762E+01; val_mae_loss: 3.359E+01; val_neg_r2_loss: -8.383E-01; val_nu_mass_loss: 4.814E-02; val_w0_mass_mae_loss: 1.497E+01; val_w1_mass_mae_loss: 1.886E+01; val_w_mass_mmd0_loss: 3.039E-02; val_w_mass_mmd1_loss: 2.554E-02; w0_mass_mae_loss: 1.511E+01; w1_mass_mae_loss: 1.884E+01; w_mass_mmd0_loss: 2.847E-02; w_mass_mmd1_loss: 2.427E-02
# Epoch 229; dinu_pt_loss: 8.909E+00; higgs_mass_loss: 1.113E+01; loss: 6.694E+01; mae_loss: 3.326E+01; neg_r2_loss: -8.381E-01; nu_mass_loss: 4.824E-02; val_dinu_pt_loss: 8.290E+00; val_higgs_mass_loss: 1.081E+01; val_loss: 6.757E+01; val_mae_loss: 3.358E+01; val_neg_r2_loss: -8.384E-01; val_nu_mass_loss: 4.852E-02; val_w0_mass_mae_loss: 1.495E+01; val_w1_mass_mae_loss: 1.874E+01; val_w_mass_mmd0_loss: 2.700E-02; val_w_mass_mmd1_loss: 2.547E-02; w0_mass_mae_loss: 1.511E+01; w1_mass_mae_loss: 1.880E+01; w_mass_mmd0_loss: 2.744E-02; w_mass_mmd1_loss: 2.437E-02
# Epoch 230; dinu_pt_loss: 8.891E+00; higgs_mass_loss: 1.110E+01; loss: 6.692E+01; mae_loss: 3.325E+01; neg_r2_loss: -8.382E-01; nu_mass_loss: 4.813E-02; val_dinu_pt_loss: 8.257E+00; val_higgs_mass_loss: 1.092E+01; val_loss: 6.764E+01; val_mae_loss: 3.360E+01; val_neg_r2_loss: -8.381E-01; val_nu_mass_loss: 4.832E-02; val_w0_mass_mae_loss: 1.499E+01; val_w1_mass_mae_loss: 1.886E+01; val_w_mass_mmd0_loss: 2.861E-02; val_w_mass_mmd1_loss: 2.542E-02; w0_mass_mae_loss: 1.511E+01; w1_mass_mae_loss: 1.882E+01; w_mass_mmd0_loss: 2.733E-02; w_mass_mmd1_loss: 2.411E-02
# Epoch 231; dinu_pt_loss: 8.917E+00; higgs_mass_loss: 1.108E+01; loss: 6.691E+01; mae_loss: 3.324E+01; neg_r2_loss: -8.384E-01; nu_mass_loss: 4.820E-02; val_dinu_pt_loss: 8.109E+00; val_higgs_mass_loss: 1.085E+01; val_loss: 6.751E+01; val_mae_loss: 3.359E+01; val_neg_r2_loss: -8.382E-01; val_nu_mass_loss: 4.805E-02; val_w0_mass_mae_loss: 1.495E+01; val_w1_mass_mae_loss: 1.876E+01; val_w_mass_mmd0_loss: 1.736E-02; val_w_mass_mmd1_loss: 2.479E-02; w0_mass_mae_loss: 1.510E+01; w1_mass_mae_loss: 1.880E+01; w_mass_mmd0_loss: 2.816E-02; w_mass_mmd1_loss: 2.435E-02
# Epoch 232; dinu_pt_loss: 8.895E+00; higgs_mass_loss: 1.114E+01; loss: 6.689E+01; mae_loss: 3.324E+01; neg_r2_loss: -8.384E-01; nu_mass_loss: 4.817E-02; val_dinu_pt_loss: 8.246E+00; val_higgs_mass_loss: 1.085E+01; val_loss: 6.754E+01; val_mae_loss: 3.360E+01; val_neg_r2_loss: -8.382E-01; val_nu_mass_loss: 4.838E-02; val_w0_mass_mae_loss: 1.497E+01; val_w1_mass_mae_loss: 1.874E+01; val_w_mass_mmd0_loss: 1.899E-02; val_w_mass_mmd1_loss: 2.494E-02; w0_mass_mae_loss: 1.511E+01; w1_mass_mae_loss: 1.886E+01; w_mass_mmd0_loss: 2.790E-02; w_mass_mmd1_loss: 2.412E-02
# Epoch 233; dinu_pt_loss: 8.892E+00; higgs_mass_loss: 1.115E+01; loss: 6.687E+01; mae_loss: 3.323E+01; neg_r2_loss: -8.385E-01; nu_mass_loss: 4.820E-02; val_dinu_pt_loss: 8.204E+00; val_higgs_mass_loss: 1.062E+01; val_loss: 6.757E+01; val_mae_loss: 3.358E+01; val_neg_r2_loss: -8.383E-01; val_nu_mass_loss: 4.855E-02; val_w0_mass_mae_loss: 1.495E+01; val_w1_mass_mae_loss: 1.864E+01; val_w_mass_mmd0_loss: 2.392E-02; val_w_mass_mmd1_loss: 2.565E-02; w0_mass_mae_loss: 1.511E+01; w1_mass_mae_loss: 1.884E+01; w_mass_mmd0_loss: 2.657E-02; w_mass_mmd1_loss: 2.398E-02
# Epoch 234; dinu_pt_loss: 8.889E+00; higgs_mass_loss: 1.105E+01; loss: 6.685E+01; mae_loss: 3.322E+01; neg_r2_loss: -8.385E-01; nu_mass_loss: 4.822E-02; val_dinu_pt_loss: 8.196E+00; val_higgs_mass_loss: 1.087E+01; val_loss: 6.753E+01; val_mae_loss: 3.359E+01; val_neg_r2_loss: -8.377E-01; val_nu_mass_loss: 4.812E-02; val_w0_mass_mae_loss: 1.495E+01; val_w1_mass_mae_loss: 1.870E+01; val_w_mass_mmd0_loss: 1.887E-02; val_w_mass_mmd1_loss: 2.448E-02; w0_mass_mae_loss: 1.509E+01; w1_mass_mae_loss: 1.880E+01; w_mass_mmd0_loss: 2.669E-02; w_mass_mmd1_loss: 2.389E-02
# Epoch 235; dinu_pt_loss: 8.884E+00; higgs_mass_loss: 1.102E+01; loss: 6.683E+01; mae_loss: 3.321E+01; neg_r2_loss: -8.387E-01; nu_mass_loss: 4.821E-02; val_dinu_pt_loss: 8.203E+00; val_higgs_mass_loss: 1.112E+01; val_loss: 6.754E+01; val_mae_loss: 3.360E+01; val_neg_r2_loss: -8.380E-01; val_nu_mass_loss: 4.831E-02; val_w0_mass_mae_loss: 1.490E+01; val_w1_mass_mae_loss: 1.893E+01; val_w_mass_mmd0_loss: 1.721E-02; val_w_mass_mmd1_loss: 2.497E-02; w0_mass_mae_loss: 1.509E+01; w1_mass_mae_loss: 1.878E+01; w_mass_mmd0_loss: 2.667E-02; w_mass_mmd1_loss: 2.386E-02
# Epoch 236; dinu_pt_loss: 8.894E+00; higgs_mass_loss: 1.113E+01; loss: 6.685E+01; mae_loss: 3.322E+01; neg_r2_loss: -8.386E-01; nu_mass_loss: 4.819E-02; val_dinu_pt_loss: 7.973E+00; val_higgs_mass_loss: 1.126E+01; val_loss: 6.757E+01; val_mae_loss: 3.359E+01; val_neg_r2_loss: -8.374E-01; val_nu_mass_loss: 4.796E-02; val_w0_mass_mae_loss: 1.490E+01; val_w1_mass_mae_loss: 1.907E+01; val_w_mass_mmd0_loss: 2.363E-02; val_w_mass_mmd1_loss: 2.545E-02; w0_mass_mae_loss: 1.509E+01; w1_mass_mae_loss: 1.887E+01; w_mass_mmd0_loss: 2.795E-02; w_mass_mmd1_loss: 2.396E-02
# Epoch 237; dinu_pt_loss: 8.868E+00; higgs_mass_loss: 1.110E+01; loss: 6.680E+01; mae_loss: 3.320E+01; neg_r2_loss: -8.387E-01; nu_mass_loss: 4.825E-02; val_dinu_pt_loss: 8.078E+00; val_higgs_mass_loss: 1.075E+01; val_loss: 6.753E+01; val_mae_loss: 3.359E+01; val_neg_r2_loss: -8.383E-01; val_nu_mass_loss: 4.838E-02; val_w0_mass_mae_loss: 1.490E+01; val_w1_mass_mae_loss: 1.867E+01; val_w_mass_mmd0_loss: 1.958E-02; val_w_mass_mmd1_loss: 2.526E-02; w0_mass_mae_loss: 1.510E+01; w1_mass_mae_loss: 1.885E+01; w_mass_mmd0_loss: 2.544E-02; w_mass_mmd1_loss: 2.373E-02
# Epoch 238; dinu_pt_loss: 8.925E+00; higgs_mass_loss: 1.108E+01; loss: 6.679E+01; mae_loss: 3.320E+01; neg_r2_loss: -8.389E-01; nu_mass_loss: 4.821E-02; val_dinu_pt_loss: 8.215E+00; val_higgs_mass_loss: 1.085E+01; val_loss: 6.760E+01; val_mae_loss: 3.359E+01; val_neg_r2_loss: -8.376E-01; val_nu_mass_loss: 4.806E-02; val_w0_mass_mae_loss: 1.494E+01; val_w1_mass_mae_loss: 1.876E+01; val_w_mass_mmd0_loss: 2.781E-02; val_w_mass_mmd1_loss: 2.442E-02; w0_mass_mae_loss: 1.509E+01; w1_mass_mae_loss: 1.879E+01; w_mass_mmd0_loss: 2.534E-02; w_mass_mmd1_loss: 2.386E-02
# Epoch 239; dinu_pt_loss: 8.904E+00; higgs_mass_loss: 1.112E+01; loss: 6.680E+01; mae_loss: 3.319E+01; neg_r2_loss: -8.389E-01; nu_mass_loss: 4.820E-02; val_dinu_pt_loss: 8.189E+00; val_higgs_mass_loss: 1.090E+01; val_loss: 6.760E+01; val_mae_loss: 3.361E+01; val_neg_r2_loss: -8.383E-01; val_nu_mass_loss: 4.843E-02; val_w0_mass_mae_loss: 1.493E+01; val_w1_mass_mae_loss: 1.878E+01; val_w_mass_mmd0_loss: 2.359E-02; val_w_mass_mmd1_loss: 2.477E-02; w0_mass_mae_loss: 1.510E+01; w1_mass_mae_loss: 1.882E+01; w_mass_mmd0_loss: 2.737E-02; w_mass_mmd1_loss: 2.365E-02
# Epoch 240; dinu_pt_loss: 8.876E+00; higgs_mass_loss: 1.118E+01; loss: 6.677E+01; mae_loss: 3.319E+01; neg_r2_loss: -8.389E-01; nu_mass_loss: 4.826E-02; val_dinu_pt_loss: 8.035E+00; val_higgs_mass_loss: 1.106E+01; val_loss: 6.756E+01; val_mae_loss: 3.361E+01; val_neg_r2_loss: -8.375E-01; val_nu_mass_loss: 4.803E-02; val_w0_mass_mae_loss: 1.496E+01; val_w1_mass_mae_loss: 1.885E+01; val_w_mass_mmd0_loss: 1.793E-02; val_w_mass_mmd1_loss: 2.478E-02; w0_mass_mae_loss: 1.509E+01; w1_mass_mae_loss: 1.888E+01; w_mass_mmd0_loss: 2.558E-02; w_mass_mmd1_loss: 2.361E-02
# Epoch 241; dinu_pt_loss: 8.894E+00; higgs_mass_loss: 1.112E+01; loss: 6.675E+01; mae_loss: 3.318E+01; neg_r2_loss: -8.390E-01; nu_mass_loss: 4.826E-02; val_dinu_pt_loss: 8.147E+00; val_higgs_mass_loss: 1.093E+01; val_loss: 6.760E+01; val_mae_loss: 3.359E+01; val_neg_r2_loss: -8.379E-01; val_nu_mass_loss: 4.831E-02; val_w0_mass_mae_loss: 1.498E+01; val_w1_mass_mae_loss: 1.886E+01; val_w_mass_mmd0_loss: 2.786E-02; val_w_mass_mmd1_loss: 2.493E-02; w0_mass_mae_loss: 1.510E+01; w1_mass_mae_loss: 1.884E+01; w_mass_mmd0_loss: 2.574E-02; w_mass_mmd1_loss: 2.355E-02
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752125811.511383   68850 service.cc:145] XLA service 0x7dead4073bb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752125811.511409   68850 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752125819.776060   68985 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1752125819.873687   68983 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_15', 64 bytes spill stores, 36 bytes spill loads
#
# I0000 00:00:1752125819.955154   69002 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752125819.985915   68981 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752125819.988417   69001 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1752125829.979299   68850 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_21', 8 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1752125829.996450   68850 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# I0000 00:00:1752125838.868134   69338 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1752125838.888046   69339 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 12 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1752125839.123690   69323 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 272 bytes spill stores, 272 bytes spill loads
#
# I0000 00:00:1752125839.174029   69324 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 272 bytes spill stores, 272 bytes spill loads
#
# I0000 00:00:1752125839.209083   69322 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_18', 24 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1752125839.620317   69332 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_18', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752125839.814956   69334 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 144 bytes spill stores, 152 bytes spill loads
#
# I0000 00:00:1752125849.713301   68846 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_21', 8 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1752125852.369168   69739 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_10', 24 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1752125852.394907   69754 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_10', 8 bytes spill stores, 8 bytes spill loads

# %%
pred_y = model.predict(test_x)
# Out:
# 2189/2189 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# I0000 00:00:1752126397.876564  106536 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752126402.836384  106660 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 8 bytes spill stores, 8 bytes spill loads

# %%
label_lead_w_px = test_y[:, 0]
label_lead_w_py = test_y[:, 1]
label_lead_w_pz = test_y[:, 2]
label_lead_w_energy = test_y[:, 3]
label_sublead_w_px = test_y[:, 4]
label_sublead_w_py = test_y[:, 5]
label_sublead_w_pz = test_y[:, 6]
label_sublead_w_energy = test_y[:, 7]

pred_lead_w_px = pred_y[:, 0]
pred_lead_w_py = pred_y[:, 1]
pred_lead_w_pz = pred_y[:, 2]
pred_lead_w_energy = pred_y[:, 3]
pred_sublead_w_px = pred_y[:, 4]
pred_sublead_w_py = pred_y[:, 5]
pred_sublead_w_pz = pred_y[:, 6]
pred_sublead_w_energy = pred_y[:, 7]

# %%
# px

# lead
plt.hist(label_lead_w_px, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_px, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_0}_{x}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_px,
	pred_lead_w_px,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_0}_{x}$", loc='right')
plt.show()

# sublead px
plt.hist(label_sublead_w_px, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_px, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_1}_{x}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_px,
	pred_sublead_w_px,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_1}_{x}$", loc='right')
plt.show()

# %%
# py

# lead
plt.hist(label_lead_w_py, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_py, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_0}_{y}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_py,
	pred_lead_w_py,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_0}_{y}$", loc='right')
plt.show()

# sublead py
plt.hist(label_sublead_w_py, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_py, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_1}_{y}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_py,
	pred_sublead_w_py,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_1}_{y}$", loc='right')
plt.show()

# %%
# pz

# lead
plt.hist(label_lead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_0}_{z}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_pz,
	pred_lead_w_pz,
	bins=(51, 51),
	range=([-1000, 1000], [-1000, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_0}_{z}$", loc='right')
plt.show()

# sublead pz
plt.hist(label_sublead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_1}_{z}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_pz,
	pred_sublead_w_pz,
	bins=(51, 51),
	range=([-1000, 1000], [-1000, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_1}_{z}$", loc='right')
plt.show()

# %%
# energy

# lead
plt.hist(label_lead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$E^{\ell_0}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_energy,
	pred_lead_w_energy,
	bins=(51, 51),
	range=([0, 1000], [0, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$E^{\ell_0}$", loc='right')
plt.show()

# sublead energy
plt.hist(label_sublead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$E^{\ell_1}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_energy,
	pred_sublead_w_energy,
	bins=(51, 51),
	range=([0, 1000], [0, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$E^{\ell_1}$", loc='right')
plt.show()

# %%
# W inv mass

w_lead_pred = np.sqrt(
	np.square(pred_lead_w_energy)
	- np.square(pred_lead_w_px)
	- np.square(pred_lead_w_py)
	- np.square(pred_lead_w_pz)
)
w_sublead_pred = np.sqrt(
	np.square(pred_sublead_w_energy)
	- np.square(pred_sublead_w_px)
	- np.square(pred_sublead_w_py)
	- np.square(pred_sublead_w_pz)
)
w_lead_label = np.sqrt(
	np.square(label_lead_w_energy)
	- np.square(label_lead_w_px)
	- np.square(label_lead_w_py)
	- np.square(label_lead_w_pz)
)
w_sublead_label = np.sqrt(
	np.square(label_sublead_w_energy)
	- np.square(label_sublead_w_px)
	- np.square(label_sublead_w_py)
	- np.square(label_sublead_w_pz)
)

plt.hist(w_lead_pred, bins=np.linspace(0, 100, 51), label=r"Pred", histtype="step", linewidth=2, color="red")
plt.hist(w_lead_label, bins=np.linspace(0, 100, 51), label=r"Label", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.xlim(0, 100)
plt.show()

plt.hist2d(
	w_lead_pred,
	w_lead_label,
	bins=(51, 51),
	range=([0, 100], [0, 100]),
	cmap="viridis",
	cmin=1,
	norm = LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel("Pred")
plt.xlabel("Label")
plt.title(r"$m_{W_0}$", loc='right')
plt.show()


plt.hist(w_sublead_pred, bins=np.linspace(0, 100, 51), label="Pred", histtype="step", linewidth=2, color="red")
plt.hist(w_sublead_label, bins=np.linspace(0, 100, 51), label="Label", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.xlim(0, 100)
plt.show()

plt.hist2d(
	w_sublead_pred,
	w_sublead_label,
	bins=(51, 51),
	range=([0, 100], [0, 100]),
	cmap="viridis",
	cmin=1,
	norm = LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel("Pred")
plt.xlabel("Label")
plt.title(r"$m_{W_1}$", loc='right')
plt.show()

# %%
# WW* inv mass
ww_pred = np.sqrt(
	np.square(pred_lead_w_energy + pred_sublead_w_energy)
	- np.square(pred_lead_w_px + pred_sublead_w_px)
	- np.square(pred_lead_w_py + pred_sublead_w_py)
	- np.square(pred_lead_w_pz + pred_sublead_w_pz)
)
ww_label = np.sqrt(
	np.square(label_lead_w_energy + label_sublead_w_energy)
	- np.square(label_lead_w_px + label_sublead_w_px)
	- np.square(label_lead_w_py + label_sublead_w_py)
	- np.square(label_lead_w_pz + label_sublead_w_pz)
)
plt.hist(ww_pred, bins=np.linspace(100, 140, 51), label="Pred", histtype="step", linewidth=2, color="red")
plt.hist(ww_label, bins=np.linspace(100, 140, 51), label="Label", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.xlim(100, 140)
plt.show()

plt.hist2d(
	ww_pred,
	ww_label,
	bins=(51, 51),
	range=([100, 140], [100, 140]),
	cmap="viridis",
	cmin=1,
	norm = LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel("Pred")
plt.xlabel("Label")
plt.title(r"$m_{WW^\ast}$", loc='right')
plt.show()

# %%
def Bij(particles):
    # Ensure ROOT is properly initialized
    ROOT.gROOT.SetBatch(True)

    def cglmp(z_xp, z_xn, z_yp, z_yn):
        """
        This is a function to calculate Bij (CGLMP values).
        :param z_xp: Angle (xi) between positive lepton and x-axis.
        :param z_xn: Angle (xi) between negative lepton and x-axis.
        :param z_yp: Angle (xi) between positive lepton and y-axis.
        :param z_xn: Angle (xi) between negative lepton and y-axis.
        """
        # count expectation value, use (27) in Alan's paper
        tr_a = (np.divide(8, np.sqrt(3))) * (z_xp * z_xn + z_yp * z_yn)
        tr_b = (
            25
            * (np.square(z_xp) - np.square(z_yp))
            * (np.square(z_xn) - np.square(z_yn))
        )
        tr_c = 100 * (z_xp * z_yp * z_xn * z_yn)
        tr = tr_a + tr_b + tr_c

        return tr

    WpBoson = TLorentzVector(*particles[:4]) # (px, py, pz, energy)
    WpLepton = TLorentzVector(*particles[4:8])
    WnBoson = TLorentzVector(*particles[8:12])
    WnLepton = TLorentzVector(*particles[12:16])
    lab_lp = np.array([WpLepton.X(), WpLepton.Y(), WpLepton.Z(), WpLepton.T()])
    lab_ln = np.array([WnLepton.X(), WnLepton.Y(), WnLepton.Z(), WnLepton.T()])
    
    # construct Higgs 4-vector
    Higgs = WpBoson + WnBoson

    # construct a moving orthogonal basis (k,r,n)
    Beam_p = TLorentzVector(0, 0, 1, 1)  # spatial-axis

    # define boost vector
    Higgsb = Higgs.BoostVector()

    # (1) performs a boost transformation from the rod frame to the rawal one.
    # Perform boost transformation from the rod frame to the rawal one
    for vec in [WpBoson, WpLepton, WnBoson, WnLepton, Beam_p]:
        vec.Boost(-Higgsb)
    
    # momentum in Higgs rest frame - extract components properly
    higgs_rest_WpLepton = np.array([WpLepton.X(), WpLepton.Y(), WpLepton.Z(), WpLepton.T()])
    higgs_rest_WnLepton = np.array([WnLepton.X(), WnLepton.Y(), WnLepton.Z(), WnLepton.T()])

    # 2. Define (k,r,n) -> definitions are in Alan's paper
    k_per = TVector3(WpBoson.X(), WpBoson.Y(), WpBoson.Z())
    p_per = TVector3(Beam_p.X(), Beam_p.Y(), Beam_p.Z())  # in the Higgs rest frame
    k = k_per.Unit()  # normalized -> unit vector
    p = p_per.Unit()
    y = p.Dot(k)
    r_length = np.sqrt(1 - y * y)
    r = (1 / r_length) * (p - y * k)
    n = (1 / r_length) * (p.Cross(k))  # (1/sin)*sin = 1 -> unit vector

    # 3. Further boost to W+ and W- frame respectively
    WpkBoost = WpBoson.BoostVector()
    WpBoson.Boost(-WpkBoost)
    WpLepton.Boost(-WpkBoost)
    WnkBoost = WnBoson.BoostVector()
    WnBoson.Boost(-WnkBoost)
    WnLepton.Boost(-WnkBoost)

    # 4. Map all particle to (k,r,n) frame
    WpLp = WpLepton.Vect()  # momentum in (k,r,n)
    WnLp = WnLepton.Vect()
    # Mapping to n-r-k basis
    WpLp_k = TLorentzVector(WpLp.Dot(n), WpLp.Dot(r), WpLp.Dot(k), WpLepton.E())
    WnLp_k = TLorentzVector(WnLp.Dot(n), WnLp.Dot(r), WnLp.Dot(k), WnLepton.E())

    # 5. Calculate directional cosines
    # directional cosine from Wp
    WpLp_Vect_Mag = WpLp_k.Vect().Mag()
    cos_n_join_p = np.divide(WpLp_k.X(), WpLp_Vect_Mag)
    cos_r_join_p = np.divide(WpLp_k.Y(), WpLp_Vect_Mag)
    cos_k_join_p = np.divide(WpLp_k.Z(), WpLp_Vect_Mag)
    # directional cosine from Wn
    WnLp_Vect_Mag = WnLp_k.Vect().Mag()
    cos_n_join_n = np.divide(WnLp_k.X(), WnLp_Vect_Mag)
    cos_r_join_n = np.divide(WnLp_k.Y(), WnLp_Vect_Mag)
    cos_k_join_n = np.divide(WnLp_k.Z(), WnLp_Vect_Mag)

    # 6. Calculate Bij (CGLMP values)
    B_xy = cglmp(cos_n_join_p, cos_n_join_n, cos_r_join_p, cos_r_join_n)
    B_yz = cglmp(cos_r_join_p, cos_r_join_n, cos_k_join_p, cos_k_join_n)
    B_zx = cglmp(cos_n_join_p, cos_n_join_n, cos_k_join_p, cos_k_join_n)

    # Also fix the W rest frame arrays to extract components properly
    w_rest_WpLepton = np.array([WpLepton.X(), WpLepton.Y(), WpLepton.Z(), WpLepton.T()])
    w_rest_WnLepton = np.array([WnLepton.X(), WnLepton.Y(), WnLepton.Z(), WnLepton.T()])

    return (
        np.array([B_xy, B_yz, B_zx]),
        np.array([cos_n_join_p, cos_r_join_p, cos_k_join_p]),
        np.array([cos_n_join_n, cos_r_join_n, cos_k_join_n]),
        lab_lp,
        lab_ln,
        higgs_rest_WpLepton,
        higgs_rest_WnLepton,
        w_rest_WpLepton,
        w_rest_WnLepton,
    )


def result_generator(particles):
    with multiprocessing.Pool(WORKERS) as pool:
        # Retrieve the output from the pool
        results = list(pool.map(Bij, particles))

    # Unpack the results
    bij, xi_p, xi_n, lab_lp, lab_ln, h_rest_lp, h_rest_ln, w_rest_lp, w_rest_ln = zip(*results)

    bij = np.vstack(bij)  # Flatten the nested array
    xi_p = np.vstack(xi_p)
    xi_n = np.vstack(xi_n)
    lab_lp = np.vstack(lab_lp)
    lab_ln = np.vstack(lab_ln)
    h_rest_lp = np.vstack(h_rest_lp)
    h_rest_ln = np.vstack(h_rest_ln)
    w_rest_lp = np.vstack(w_rest_lp)
    w_rest_ln = np.vstack(w_rest_ln)
    mask = np.any(np.isnan(bij), axis=1)
    print("Number of NaN values in bij:", np.sum(mask))
    return (
        bij,
        xi_p,
        xi_n,
        mask,
        lab_lp,
        lab_ln,
        h_rest_lp,
        h_rest_ln,
        w_rest_lp,
        w_rest_ln,
    )

# %%
# mc20 truth

mc20_true_obs_kin = np.column_stack(
    (
        truth_lead_lep["px"],
        truth_lead_lep["py"],
        truth_lead_lep["pz"],
        truth_lead_lep["energy"],
        truth_sublead_lep["px"],
        truth_sublead_lep["py"],
        truth_sublead_lep["pz"],
        truth_sublead_lep["energy"],
        truth_lead_nu["px"] + truth_sublead_nu["px"],
        truth_lead_nu["py"] + truth_sublead_nu["py"],
    )
)
# trim the data
print("mc20 (true) obs_kin shape:", mc20_true_obs_kin.shape)
mc20_true_obs_kin = mc20_true_obs_kin[PRE_CUT_INST]
print("After selection ...\nmc20 (true) obs_kin shape:", mc20_true_obs_kin.shape)
# Out:
# mc20 (true) obs_kin shape: (2963488, 10)
# After selection ...
# mc20 (true) obs_kin shape: (700374, 10)

# %%
# mc20 truth (car)

mc20_car_obs_kin = np.column_stack(
    (
        truth_lead_lep_car["px"],
        truth_lead_lep_car["py"],
        truth_lead_lep_car["pz"],
        truth_lead_lep_car["energy"],
        truth_sublead_lep_car["px"],
        truth_sublead_lep_car["py"],
        truth_sublead_lep_car["pz"],
        truth_sublead_lep_car["energy"],
        truth_lead_nu_car["px"] + truth_sublead_nu_car["px"],
        truth_lead_nu_car["py"] + truth_sublead_nu_car["py"],
    )
)

print("mc20 (car) obs_kin shape:", mc20_car_obs_kin.shape)
mc20_car_obs_kin = mc20_car_obs_kin[PRE_CUT_INST]
print("After selection ...\nmc20 (car) obs_kin shape:", mc20_car_obs_kin.shape)
# Out:
# mc20 (car) obs_kin shape: (2963488, 10)
# After selection ...
# mc20 (car) obs_kin shape: (700374, 10)

# %%
# predictions from the model trained with mc16 data

mc20_true_pred_y = model.predict(mc20_true_obs_kin)  # ~truth
mc20_car_pred_y = model.predict(mc20_car_obs_kin)  # ~truth_car
# Out:
# 21887/21887 ━━━━━━━━━━━━━━━━━━━━ 26s 1ms/step
# 21887/21887 ━━━━━━━━━━━━━━━━━━━━ 23s 1ms/step

# %%
"""
CGLMP and xi:

ground truth for CAR
"""

mc20_truth_lead_lep_p4 = mc20_data["truth_lead_lep"]["p4"]
mc20_truth_sublead_lep_p4 = mc20_data["truth_sublead_lep"]["p4"]
mc20_truth_lead_w = mc20_data["lead_w"]["p4"]
mc20_truth_sublead_w = mc20_data["sublead_w"]["p4"]

mc20_particles = np.concatenate(
    [
        mc20_truth_lead_w[PRE_CUT_INST],
        mc20_truth_lead_lep_p4[PRE_CUT_INST],
        mc20_truth_sublead_w[PRE_CUT_INST],
        mc20_truth_sublead_lep_p4[PRE_CUT_INST],
    ],
    axis=1,
)
(
    truth_bij, 
    truth_xi_p, 
    truth_xi_n, 
    truth_mask,
    truth_lab_lp, 
    truth_lab_ln,
    truth_h_rest_lp, 
    truth_h_rest_ln, 
    truth_w_rest_lp, 
    truth_w_rest_ln
) = result_generator(mc20_particles)
# Out:
# Number of NaN values in bij: 0

# %%
"""
CGLMP and xi:

ground truth for CAR
"""

mc20_truth_lead_lep_car_p4 = mc20_data["truth_lead_lep_car"]["p4"]
mc20_truth_sublead_lep_car_p4 = mc20_data["truth_sublead_lep_car"]["p4"]

mc20_particles = np.concatenate(
    [
        mc20_truth_lead_w[PRE_CUT_INST],
        mc20_truth_lead_lep_car_p4[PRE_CUT_INST],
        mc20_truth_sublead_w[PRE_CUT_INST],
        mc20_truth_sublead_lep_car_p4[PRE_CUT_INST],
    ],
    axis=1,
)
(
    truth_bij_car, 
    truth_xi_p_car, 
    truth_xi_n_car, 
    truth_mask_car,
    truth_lab_lp_car, 
    truth_lab_ln_car,
    truth_h_rest_lp_car, 
    truth_h_rest_ln_car, 
    truth_w_rest_lp_car, 
    truth_w_rest_ln_car
) = result_generator(mc20_particles)
# Out:
# Number of NaN values in bij: 0

# %%
"""
CGLMP and xi:

[Use for comapring the CAR results]
pred(SM) with truth lep
"""

mc20_particles = np.concatenate(
    [
        mc20_true_pred_y[:, 0:4],
        mc20_truth_lead_lep_p4[PRE_CUT_INST],
        mc20_true_pred_y[:, 4:8],
        mc20_truth_sublead_lep_p4[PRE_CUT_INST],
    ],
    axis=1,
)
(
    bij, 
    xi_p, 
    xi_n, 
    mask,
    lab_lp, 
    lab_ln, 
    h_rest_lp, 
    h_rest_ln, 
    w_rest_lp, 
    w_rest_ln,
    
) = result_generator(mc20_particles)
# Out:
# Number of NaN values in bij: 0

# %%
"""
CGLMP and xi:

[Use for comapring the CAR results]
pred(SM) with truth lep
"""

mc20_particles = np.concatenate(
    [
        mc20_true_pred_y[:, 0:4],
        mc20_truth_lead_lep_p4[PRE_CUT_INST],
        mc20_true_pred_y[:, 4:8],
        mc20_truth_sublead_lep_p4[PRE_CUT_INST],
    ],
    axis=1,
)
(
    bij, 
    xi_p, 
    xi_n, 
    mask,
    lab_lp, 
    lab_ln, 
    h_rest_lp, 
    h_rest_ln, 
    w_rest_lp, 
    w_rest_ln,
    
) = result_generator(mc20_particles)
# Out:
# Number of NaN values in bij: 0

# %%
"""
CGLMP and xi:

pred(CAR) with car lep
"""

mc20_truth_lead_lep_car_p4 = mc20_data["truth_lead_lep_car"]["p4"]
mc20_truth_sublead_lep_car_p4 = mc20_data["truth_sublead_lep_car"]["p4"]

mc20_particles = np.concatenate(
    [
        mc20_car_pred_y[:, 0:4],
        mc20_truth_lead_lep_car_p4[PRE_CUT_INST],
        mc20_car_pred_y[:, 4:8],
        mc20_truth_sublead_lep_car_p4[PRE_CUT_INST],
    ],
    axis=1,
)
(
    bij_car, 
    xi_p_car, 
    xi_n_car, 
    mask_car, 
    lab_lp_car, 
    lab_ln_car, 
    h_rest_lp_car, 
    h_rest_ln_car, 
    w_rest_lp_car, 
    w_rest_ln_car
) = result_generator(mc20_particles)
# Out:
# Number of NaN values in bij: 0

# %%
# trim out nan values 

mask = ~truth_mask & ~truth_mask_car & ~mask & ~mask_car

# %%
# variables for plotting
bij = bij[mask]
bij_car = bij_car[mask]
xi_p = xi_p[mask]
xi_p_car = xi_p_car[mask]
xi_n = xi_n[mask]
xi_n_car = xi_n_car[mask]
lab_lp = lab_lp[mask]
lab_ln = lab_ln[mask]
lab_lp_car = lab_lp_car[mask]
lab_ln_car = lab_ln_car[mask]
h_rest_lp = h_rest_lp[mask]
h_rest_ln = h_rest_ln[mask]
h_rest_lp_car = h_rest_lp_car[mask]
h_rest_ln_car = h_rest_ln_car[mask]
w_rest_lp = w_rest_lp[mask]
w_rest_ln = w_rest_ln[mask]
w_rest_lp_car = w_rest_lp_car[mask]
w_rest_ln_car = w_rest_ln_car[mask]


truth_bij = truth_bij[mask]
truth_bij_car = truth_bij_car[mask]
truth_xi_p = truth_xi_p[mask]
truth_xi_p_car = truth_xi_p_car[mask]
truth_xi_n = truth_xi_n[mask]
truth_xi_n_car = truth_xi_n_car[mask]
truth_lab_lp = truth_lab_lp[mask]
truth_lab_ln = truth_lab_ln[mask]
truth_lab_lp_car = truth_lab_lp_car[mask]
truth_lab_ln_car = truth_lab_ln_car[mask]
truth_h_rest_lp = truth_h_rest_lp[mask]
truth_h_rest_ln = truth_h_rest_ln[mask]
truth_h_rest_lp_car = truth_h_rest_lp_car[mask]
truth_h_rest_ln_car = truth_h_rest_ln_car[mask]
truth_w_rest_lp = truth_w_rest_lp[mask]
truth_w_rest_ln = truth_w_rest_ln[mask]
truth_w_rest_lp_car = truth_w_rest_lp_car[mask]
truth_w_rest_ln_car = truth_w_rest_ln_car[mask]

# %%
"""
Xi comparison:

Pred CAR vs pred SM 
"""

print("CAR (pred ~ truth_car) vs SM (pred ~ truth)")

# xi
xi_plot_true = [
    xi_p[:, 0],
    xi_p[:, 1],
    xi_p[:, 2],
    xi_n[:, 0],
    xi_n[:, 1],
    xi_n[:, 2],
]
xi_plot_pred = [
    xi_p_car[:, 0],
    xi_p_car[:, 1],
    xi_p_car[:, 2],
    xi_n_car[:, 0],
    xi_n_car[:, 1],
    xi_n_car[:, 2],
]
xi_plot_ranges = [[-1, 1]] * 6
xi_plot_labels = [
    r"$\xi^{(0)}_{n}$",
    r"$\xi^{(0)}_{r}$",
    r"$\xi^{(0)}_{k}$",
    r"$\xi^{(1)}_{n}$",
    r"$\xi^{(1)}_{r}$",
    r"$\xi^{(1)}_{k}$",
]
plot.hist_1d_grid(
    xi_plot_true,
    xi_plot_pred,
    title=xi_plot_labels,
    legend_lst=["Pred(Sep)", "Pred(SM)"],
    ranges=xi_plot_ranges,
    xlabel="",
)
plot.hist_2d_grid(
    xi_plot_true,
    xi_plot_pred,
    title=xi_plot_labels,
    ranges=xi_plot_ranges,
    xlabel="Pred(Sep)",
    ylabel="Pred(SM)",
)

# bij
bij_plot_true = [
    bij[:, 0],
    bij[:, 1],
    bij[:, 2],
]
bij_plot_pred = [
    bij_car[:, 0],
    bij_car[:, 1],
    bij_car[:, 2],
]
bij_plot_ranges = [[-30, 30]] * 3
bij_plot_labels = [
    r"$B_{xy}$",
    r"$B_{yz}$",
    r"$B_{zx}$",
]

plot.hist_1d3plot(
    bij_plot_true,
    bij_plot_pred,
    ranges=bij_plot_ranges,
    xlabel=bij_plot_labels,
    title=bij_plot_labels,
    row1_ylabel="Counts",
    row1_legend=["Pred(Sep)", "Pred(SM)"],
    xpad=1,
)

emd = [
    sp.stats.wasserstein_distance(bij[:, i], bij_car[:, i]) for i in range(3)
]

kl_lst = []
for i in range(3):
    # Create histograms
    p, bin_edges = np.histogram(bij[..., i], bins=101, density=True)
    q, _ = np.histogram(bij_car[..., i], bins=bin_edges, density=True)

    # Normalize histograms
    kl = np.sum(sp.special.kl_div(p, q+1e-10))
    kl_lst.append(kl)
    
mean_true = [np.mean(bij[:, i]) for i in range(3)]
mean_car = [np.mean(bij_car[:, i]) for i in range(3)]

print(
    rf"""
Bxy -> EMD:{emd[0]:.3f}, kl: {10*kl_lst[0]:.3f} with SM mean:{mean_true[0]:.3f}, Sep mean {mean_car[0]:.3f}
Byz -> EMD:{emd[1]:.3f}, kl: {10*kl_lst[1]:.3f} with SM mean:{mean_true[1]:.3f}, Sep mean {mean_car[1]:.3f}
Bzx -> EMD:{emd[2]:.3f}, kl: {10*kl_lst[2]:.3f} with SM mean:{mean_true[2]:.3f}, Sep mean {mean_car[2]:.3f}
"""
)
# Out:
# CAR (pred ~ truth_car) vs SM (pred ~ truth)
# Bxy -> EMD:0.969, kl: 0.175 with SM mean:2.391, Sep mean 1.422
# Byz -> EMD:0.655, kl: 0.301 with SM mean:1.448, Sep mean 0.802
# Bzx -> EMD:1.373, kl: 0.369 with SM mean:0.464, Sep mean -0.909

# %%
bins_edges = np.linspace(0, 1000, 51)
plt.hist(truth_lab_lp_car[:,3], bins=bins_edges, label=r"True $E^{\ell_0}$ (LAB_CAR)", histtype="step", linewidth=2, color="blue")
plt.hist(truth_lab_lp[:,3], bins=bins_edges, label=r"True $E^{\ell_0}$ (LAB_SM)", histtype="step", linewidth=2, color="red")
plt.hist(lab_lp_car[:,3], bins=bins_edges, label=r"Pred $E^{\ell_0}$ (LAB_CAR)", histtype="bar", linewidth=2, color="tab:blue", alpha=0.5)
plt.hist(lab_lp[:,3], bins=bins_edges, label=r"Pred $E^{\ell_0}$ (LAB_SM)", histtype="bar", linewidth=2, color="tab:red", alpha=0.5)
plt.semilogy()
plt.legend()
plt.show()

bins_edges = np.linspace(0, 160, 51)
plt.hist(truth_h_rest_lp_car[:,3], bins=bins_edges, label=r"True $E^{\ell_0}$ (H_CAR)", histtype="step", linewidth=2, color="blue")
plt.hist(truth_h_rest_lp[:,3], bins=bins_edges, label=r"True $E^{\ell_0}$ (H_SM)", histtype="step", linewidth=2, color="red")
plt.hist(h_rest_lp_car[:,3], bins=bins_edges, label=r"Pred $E^{\ell_0}$ (H_CAR)", histtype="bar", linewidth=2, color="tab:blue", alpha=0.5)
plt.hist(h_rest_lp[:,3], bins=bins_edges, label=r"Pred $E^{\ell_0}$ (H_SM)", histtype="bar", linewidth=2, color="tab:red", alpha=0.5)
plt.semilogy()
plt.legend()
plt.show()

bins_edges = np.linspace(0, 160, 51)
plt.hist(truth_w_rest_lp_car[:,3], bins=bins_edges, label=r"True $E^{\ell_0}$ (W_CAR)", histtype="step", linewidth=2, color="blue")
plt.hist(truth_w_rest_lp[:,3], bins=bins_edges, label=r"True $E^{\ell_0}$ (W_SM)", histtype="step", linewidth=2, color="red")
plt.hist(w_rest_lp_car[:,3], bins=bins_edges, label=r"Pred $E^{\ell_0}$ (W_CAR)", histtype="bar", linewidth=2, color="tab:blue", alpha=0.5)
plt.hist(w_rest_lp[:,3], bins=bins_edges, label=r"Pred $E^{\ell_0}$ (W_SM)", histtype="bar", linewidth=2, color="tab:red", alpha=0.5)
plt.semilogy()
plt.legend()
plt.show()

bins_edges = np.linspace(0, 1000, 51)
plt.hist(truth_lab_ln_car[:,3], bins=bins_edges, label=r"True $E^{\ell_1}$ (LAB_CAR)", histtype="step", linewidth=2, color="blue")
plt.hist(truth_lab_ln[:,3], bins=bins_edges, label=r"True $E^{\ell_1}$ (LAB_SM)", histtype="step", linewidth=2, color="red")
plt.hist(lab_ln_car[:,3], bins=bins_edges, label=r"Pred $E^{\ell_1}$ (LAB_CAR)", histtype="bar", linewidth=2, color="tab:blue", alpha=0.5)
plt.hist(lab_ln[:,3], bins=bins_edges, label=r"Pred $E^{\ell_1}$ (LAB_SM)", histtype="bar", linewidth=2, color="tab:red", alpha=0.5)
plt.semilogy()
plt.legend()
plt.show()

bins_edges = np.linspace(0, 160, 51)
plt.hist(truth_h_rest_ln_car[:,3], bins=bins_edges, label=r"True $E^{\ell_1}$ (H_CAR)", histtype="step", linewidth=2, color="blue")
plt.hist(truth_h_rest_ln[:,3], bins=bins_edges, label=r"True $E^{\ell_1}$ (H_SM)", histtype="step", linewidth=2, color="red")
plt.hist(h_rest_ln_car[:,3], bins=bins_edges, label=r"Pred $E^{\ell_1}$ (H_CAR)", histtype="bar", linewidth=2, color="tab:blue", alpha=0.5)
plt.hist(h_rest_ln[:,3], bins=bins_edges, label=r"Pred $E^{\ell_1}$ (H_SM)", histtype="bar", linewidth=2, color="tab:red", alpha=0.5)
plt.semilogy()
plt.legend()
plt.show()

bins_edges = np.linspace(0, 160, 51)
plt.hist(truth_w_rest_ln_car[:,3], bins=bins_edges, label=r"True $E^{\ell_1}$ (W_CAR)", histtype="step", linewidth=2, color="blue")
plt.hist(truth_w_rest_ln[:,3], bins=bins_edges, label=r"True $E^{\ell_1}$ (W_SM)", histtype="step", linewidth=2, color="red")
plt.hist(w_rest_ln_car[:,3], bins=bins_edges, label=r"Pred $E^{\ell_1}$ (W_CAR)", histtype="bar", linewidth=2, color="tab:blue", alpha=0.5)
plt.hist(w_rest_ln[:,3], bins=bins_edges, label=r"Pred $E^{\ell_1}$ (W_SM)", histtype="bar", linewidth=2, color="tab:red", alpha=0.5)
plt.semilogy()
plt.legend()
plt.show()
