# %%
import time
t_start = time.time()

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"  # suppress tensorflow information messages

import sys
import numpy as np
from scipy import stats
import scipy as sp
import multiprocessing
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm, Normalize
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbModelCheckpoint

HOME_PATH = os.path.abspath("/root/work/QE-mls") # path to QE_mls
sys.path.append(HOME_PATH + "/qe")
print("Home path:", HOME_PATH)

# custom modules
import paper_plot as pp
# Import the W boson regressor module
import nn
nn.BATCH_SIZE = 512
# Out:
# Home path: /root/work/QE-mls

# %%
# ROOT need to be imported after tensorflow
import ROOT
from ROOT import TLorentzVector, TVector3

# some global variables
dir_name = HOME_PATH + "/14th_trial/reg_main/ww_resregressor_result/"
plot = pp.Plotter()
WORKERS = 16

# %%
import h5py


def load_particles_from_h5(filename="mc20_truth.h5"):
    """
    Load particle data from an HDF5 file

    Args:
        filename: Path to the HDF5 file

    Returns:
        Dictionary with the loaded data
    """
    result = {}

    with h5py.File(filename, "r") as f:
        # For each group in the file
        for group_name in f.keys():
            group_data = {}

            # Load datasets (numpy arrays)
            for dataset_name in f[group_name].keys():
                group_data[dataset_name] = f[group_name][dataset_name][:]

            # Load attributes (scalars)
            for attr_name, attr_value in f[group_name].attrs.items():
                group_data[attr_name] = attr_value

            result[group_name] = group_data

    return result

# %%
mc20_data = load_particles_from_h5("/root/data/mc20_truth.h5")
mc20_data.keys()
# Out:
# dict_keys(['higgs', 'lead_w', 'sublead_w', 'truth_dilep', 'truth_dilep_car', 'truth_lead_lep', 'truth_lead_lep_car', 'truth_lead_nu', 'truth_lead_nu_car', 'truth_sublead_lep', 'truth_sublead_lep_car', 'truth_sublead_nu', 'truth_sublead_nu_car'])

# %%
# SM truth
truth_lead_lep = mc20_data["truth_lead_lep"]
truth_sublead_lep = mc20_data["truth_sublead_lep"]
truth_lead_nu = mc20_data["truth_lead_nu"]
truth_sublead_nu = mc20_data["truth_sublead_nu"]
truth_lead_lep_p4 = mc20_data["truth_lead_lep"]["p4"]
truth_sublead_lep_p4 = mc20_data["truth_sublead_lep"]["p4"]
truth_lead_nu_p4 = mc20_data["truth_lead_nu"]["p4"]
truth_sublead_nu_p4 = mc20_data["truth_sublead_nu"]["p4"]
truth_met_pt = np.sqrt(np.square((truth_lead_nu_p4 + truth_sublead_nu_p4)[...,0:2]).sum(axis=-1))

# CAR truth
truth_lead_lep_car = mc20_data["truth_lead_lep_car"]
truth_sublead_lep_car = mc20_data["truth_sublead_lep_car"]
truth_lead_nu_car = mc20_data["truth_lead_nu_car"]
truth_sublead_nu_car = mc20_data["truth_sublead_nu_car"]
truth_lead_lep_car_p4 = mc20_data["truth_lead_lep_car"]["p4"]
truth_sublead_lep_car_p4 = mc20_data["truth_sublead_lep_car"]["p4"]
truth_lead_nu_car_p4 = mc20_data["truth_lead_nu_car"]["p4"]
truth_sublead_nu_car_p4 = mc20_data["truth_sublead_nu_car"]["p4"]
truth_met_pt_car = np.sqrt(np.square((truth_lead_nu_car_p4 + truth_sublead_nu_car_p4)[...,0:2]).sum(axis=-1))

# W bosons (SM and CAR use the same W bosons data)
w_lead_p4 = mc20_data["lead_w"]["p4"]
w_sublead_p4 = mc20_data["sublead_w"]["p4"]

# %%
print("Truth: pre-cut")
cut_pre_pt_lead = truth_lead_lep["pt"] > 22
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = truth_sublead_lep["pt"] > 15
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.square(truth_lead_lep["energy"] + truth_sublead_lep["energy"])
    - np.square(truth_lead_lep["px"] + truth_sublead_lep["px"])
    - np.square(truth_lead_lep["py"] + truth_sublead_lep["py"])
    - np.square(truth_lead_lep["pz"] + truth_sublead_lep["pz"])
    > 10**2
)
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = truth_met_pt > 20
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print("Total", len(truth_lead_lep["energy"]) - np.sum(PRE_CUT * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# CAR
print("")
print("CAR: pre-cut")
cut_pre_pt_lead = truth_lead_lep_car["pt"] > 22
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = truth_sublead_lep_car["pt"] > 15
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.square(truth_lead_lep_car["energy"] + truth_sublead_lep_car["energy"])
    - np.square(truth_lead_lep_car["px"] + truth_sublead_lep_car["px"])
    - np.square(truth_lead_lep_car["py"] + truth_sublead_lep_car["py"])
    - np.square(truth_lead_lep_car["pz"] + truth_sublead_lep_car["pz"])
    > 10**2
)
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = truth_met_pt_car > 20
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT_CAR = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print("Total", len(truth_lead_lep_car["energy"]) - np.sum(PRE_CUT_CAR * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)
# Out:
# Truth: pre-cut
# 260653
# 1174171
# 148392
# 287355
# Total 1502903
#
# CAR: pre-cut
# 336735
# 1292162
# 65248
# 441435
# Total 1634918

# %%
# force to use the same cuts for both truth and CAR

PRE_CUT_INST = PRE_CUT_CAR & PRE_CUT
print("Total", np.sum(PRE_CUT_INST * 1))
# Out:
# Total 700374

# %%
# training objects
lead_lep_px = truth_lead_lep_car["px"][PRE_CUT_INST]
lead_lep_py = truth_lead_lep_car["py"][PRE_CUT_INST]
lead_lep_pz = truth_lead_lep_car["pz"][PRE_CUT_INST]
lead_lep_energy = truth_lead_lep_car["energy"][PRE_CUT_INST]
sublead_lep_px = truth_sublead_lep_car["px"][PRE_CUT_INST]
sublead_lep_py = truth_sublead_lep_car["py"][PRE_CUT_INST]
sublead_lep_pz = truth_sublead_lep_car["pz"][PRE_CUT_INST]
sublead_lep_energy = truth_sublead_lep_car["energy"][PRE_CUT_INST]
lead_nu_px = truth_lead_nu_car["px"][PRE_CUT_INST]
lead_nu_py = truth_lead_nu_car["py"][PRE_CUT_INST]
sublead_nu_px = truth_sublead_nu_car["px"][PRE_CUT_INST]
sublead_nu_py = truth_sublead_nu_car["py"][PRE_CUT_INST]
met_px = lead_nu_px + sublead_nu_px
met_py = lead_nu_py + sublead_nu_py

np.random.seed(nn.SEED)
shuffle_ind = np.random.permutation(len(lead_lep_px))

train = np.column_stack(
    (
        lead_lep_px,
        lead_lep_py,
        lead_lep_pz,
        lead_lep_energy,
        sublead_lep_px,
        sublead_lep_py,
        sublead_lep_pz,
        sublead_lep_energy,
        met_px,
        met_py,
    )
)

# train = train[shuffle_ind]
print("Training objects shape:", train.shape)
# Out:
# Training objects shape: (700374, 10)

# %%
# target objects

w_lead = mc20_data["lead_w"]
w_sublead = mc20_data["sublead_w"]
target = np.column_stack(
    (
        w_lead["px"][PRE_CUT_INST],
        w_lead["py"][PRE_CUT_INST],
        w_lead["pz"][PRE_CUT_INST],
        w_lead["energy"][PRE_CUT_INST],
        w_sublead["px"][PRE_CUT_INST],
        w_sublead["py"][PRE_CUT_INST],
        w_sublead["pz"][PRE_CUT_INST],
        w_sublead["energy"][PRE_CUT_INST],
        w_lead["m"][PRE_CUT_INST],
        w_sublead["m"][PRE_CUT_INST],
    )
)

# target = target[shuffle_ind]
print("Target objects shape:", target.shape)
# Out:
# Target objects shape: (700374, 10)

# %%
# Train-test split
if len(train) == len(target):
	indices = np.arange(len(train))
else:
	sys.exit("Error: train and targe shapes do not match!")

train_idx, temp_idx = train_test_split(
	indices, train_size=0.8, random_state=nn.SEED
)
valid_idx, test_idx = train_test_split(
	temp_idx, train_size=0.5, random_state=nn.SEED
)

train_x, valid_x, test_x = train[train_idx], train[valid_idx], train[test_idx]
train_y, valid_y, test_y = target[train_idx], target[valid_idx], target[test_idx]

print("Train shape:", train_x.shape, "Valid shape:", valid_x.shape, "Test shape:", test_x.shape)
# Out:
# Train shape: (560299, 10) Valid shape: (70037, 10) Test shape: (70038, 10)

# %%
# W&B initialization
wandb.init(
    project='PcRes regressor ll training', 
    name='batch_size: %d' % nn.BATCH_SIZE)
config = wandb.config
config.batch_size = nn.BATCH_SIZE

# Create datasets
train_dataset = (
	tf.data.Dataset.from_tensor_slices((train_x, train_y))
	.cache()
	.batch(nn.BATCH_SIZE)
	.prefetch(tf.data.AUTOTUNE)
)
valid_dataset = (
	tf.data.Dataset.from_tensor_slices((valid_x, valid_y))
	.cache()
	.batch(nn.BATCH_SIZE)
	.prefetch(tf.data.AUTOTUNE)
)

# Build and train model
base_model = nn.build_model(input_shape=train_x.shape[-1])
model = nn.CustomModel(base_model)
model.summary()
model.compile(
	optimizer=tf.keras.optimizers.Adam(learning_rate=nn.LEARNING_RATE),
	loss_weights=nn.LOSS_WEIGHTS,
)

callbacks = [
	tf.keras.callbacks.EarlyStopping(
		monitor="val_loss", patience=10, restore_best_weights=True
	),
	nn.EpochUpdater(),
	nn.LambdaTracker(),
	WandbMetricsLogger(), 
    # WandbModelCheckpoint(
    #     "best_val_loss.weights.h5",
    #     monitor="val_loss",
    # ),
]

history = model.fit(
	train_dataset,
	validation_data=valid_dataset,
	epochs=nn.EPOCHS,
	callbacks=callbacks,
	verbose=0,
)
# Out:
# wandb: Currently logged in as: yygarypeng (nthu-expt-hep) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/root/work/QE-mls/14th_trial/reg_main/wandb/run-20250709_055335-31zaq0ov</code>
# Syncing run <strong><a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training/runs/31zaq0ov' target="_blank">batch_size: 512</a></strong> to <a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training' target="_blank">https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training</a>
#  View run at <a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training/runs/31zaq0ov' target="_blank">https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training/runs/31zaq0ov</a>
# Model: "custom_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional (Functional)         │ (None, 8)              │       990,822 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 990,822 (3.78 MB)
#  Trainable params: 979,238 (3.74 MB)
#  Non-trainable params: 11,584 (45.25 KB)
# Epoch 0; dinu_pt_loss: 6.206E+01; higgs_mass_loss: 5.958E+01; loss: 1.339E+02; mae_loss: 5.502E+01; neg_r2_loss: -6.474E-01; nu_mass_loss: 5.793E-03; val_dinu_pt_loss: 6.187E+01; val_higgs_mass_loss: 4.742E+01; val_loss: 1.235E+02; val_mae_loss: 5.490E+01; val_neg_r2_loss: -6.523E-01; val_nu_mass_loss: 8.163E-03; val_w0_mass_mae_loss: 4.303E+01; val_w1_mass_mae_loss: 2.209E+01; val_w_mass_mmd0_loss: 1.449E+00; val_w_mass_mmd1_loss: 2.625E-01; w0_mass_mae_loss: 5.011E+01; w1_mass_mae_loss: 2.704E+01; w_mass_mmd0_loss: 1.998E+00; w_mass_mmd1_loss: 9.825E-01
# Epoch 1; dinu_pt_loss: 6.080E+01; higgs_mass_loss: 4.218E+01; loss: 1.201E+02; mae_loss: 5.449E+01; neg_r2_loss: -6.489E-01; nu_mass_loss: 8.757E-03; val_dinu_pt_loss: 5.948E+01; val_higgs_mass_loss: 4.024E+01; val_loss: 1.183E+02; val_mae_loss: 5.418E+01; val_neg_r2_loss: -6.551E-01; val_nu_mass_loss: 9.997E-03; val_w0_mass_mae_loss: 3.642E+01; val_w1_mass_mae_loss: 2.049E+01; val_w_mass_mmd0_loss: 1.100E+00; val_w_mass_mmd1_loss: 1.415E-01; w0_mass_mae_loss: 3.769E+01; w1_mass_mae_loss: 2.057E+01; w_mass_mmd0_loss: 1.204E+00; w_mass_mmd1_loss: 1.915E-01
# Epoch 2; dinu_pt_loss: 5.828E+01; higgs_mass_loss: 3.576E+01; loss: 1.154E+02; mae_loss: 5.374E+01; neg_r2_loss: -6.514E-01; nu_mass_loss: 1.054E-02; val_dinu_pt_loss: 5.622E+01; val_higgs_mass_loss: 3.501E+01; val_loss: 1.143E+02; val_mae_loss: 5.330E+01; val_neg_r2_loss: -6.580E-01; val_nu_mass_loss: 1.185E-02; val_w0_mass_mae_loss: 3.084E+01; val_w1_mass_mae_loss: 2.066E+01; val_w_mass_mmd0_loss: 8.563E-01; val_w_mass_mmd1_loss: 1.060E-01; w0_mass_mae_loss: 3.223E+01; w1_mass_mae_loss: 2.000E+01; w_mass_mmd0_loss: 8.674E-01; w_mass_mmd1_loss: 1.220E-01
# Epoch 3; dinu_pt_loss: 5.560E+01; higgs_mass_loss: 3.110E+01; loss: 1.117E+02; mae_loss: 5.287E+01; neg_r2_loss: -6.546E-01; nu_mass_loss: 1.235E-02; val_dinu_pt_loss: 5.375E+01; val_higgs_mass_loss: 2.973E+01; val_loss: 1.106E+02; val_mae_loss: 5.241E+01; val_neg_r2_loss: -6.617E-01; val_nu_mass_loss: 1.352E-02; val_w0_mass_mae_loss: 2.704E+01; val_w1_mass_mae_loss: 2.008E+01; val_w_mass_mmd0_loss: 6.354E-01; val_w_mass_mmd1_loss: 9.318E-02; w0_mass_mae_loss: 2.805E+01; w1_mass_mae_loss: 1.999E+01; w_mass_mmd0_loss: 6.489E-01; w_mass_mmd1_loss: 1.027E-01
# Epoch 4; dinu_pt_loss: 5.391E+01; higgs_mass_loss: 2.694E+01; loss: 1.091E+02; mae_loss: 5.208E+01; neg_r2_loss: -6.581E-01; nu_mass_loss: 1.383E-02; val_dinu_pt_loss: 5.291E+01; val_higgs_mass_loss: 2.482E+01; val_loss: 1.079E+02; val_mae_loss: 5.166E+01; val_neg_r2_loss: -6.652E-01; val_nu_mass_loss: 1.479E-02; val_w0_mass_mae_loss: 2.416E+01; val_w1_mass_mae_loss: 1.973E+01; val_w_mass_mmd0_loss: 4.830E-01; val_w_mass_mmd1_loss: 9.112E-02; w0_mass_mae_loss: 2.532E+01; w1_mass_mae_loss: 1.980E+01; w_mass_mmd0_loss: 5.240E-01; w_mass_mmd1_loss: 9.389E-02
# Epoch 5; dinu_pt_loss: 5.286E+01; higgs_mass_loss: 2.350E+01; loss: 1.070E+02; mae_loss: 5.145E+01; neg_r2_loss: -6.609E-01; nu_mass_loss: 1.495E-02; val_dinu_pt_loss: 5.158E+01; val_higgs_mass_loss: 2.165E+01; val_loss: 1.061E+02; val_mae_loss: 5.103E+01; val_neg_r2_loss: -6.680E-01; val_nu_mass_loss: 1.580E-02; val_w0_mass_mae_loss: 2.257E+01; val_w1_mass_mae_loss: 1.987E+01; val_w_mass_mmd0_loss: 4.186E-01; val_w_mass_mmd1_loss: 8.859E-02; w0_mass_mae_loss: 2.318E+01; w1_mass_mae_loss: 1.971E+01; w_mass_mmd0_loss: 4.214E-01; w_mass_mmd1_loss: 9.170E-02
# Epoch 6; dinu_pt_loss: 5.140E+01; higgs_mass_loss: 2.103E+01; loss: 1.053E+02; mae_loss: 5.086E+01; neg_r2_loss: -6.636E-01; nu_mass_loss: 1.591E-02; val_dinu_pt_loss: 5.008E+01; val_higgs_mass_loss: 1.912E+01; val_loss: 1.037E+02; val_mae_loss: 5.049E+01; val_neg_r2_loss: -6.703E-01; val_nu_mass_loss: 1.675E-02; val_w0_mass_mae_loss: 2.033E+01; val_w1_mass_mae_loss: 2.008E+01; val_w_mass_mmd0_loss: 2.528E-01; val_w_mass_mmd1_loss: 9.070E-02; w0_mass_mae_loss: 2.163E+01; w1_mass_mae_loss: 2.000E+01; w_mass_mmd0_loss: 3.610E-01; w_mass_mmd1_loss: 9.003E-02
# Epoch 7; dinu_pt_loss: 4.990E+01; higgs_mass_loss: 2.005E+01; loss: 1.039E+02; mae_loss: 5.032E+01; neg_r2_loss: -6.666E-01; nu_mass_loss: 1.681E-02; val_dinu_pt_loss: 4.761E+01; val_higgs_mass_loss: 1.941E+01; val_loss: 1.023E+02; val_mae_loss: 4.986E+01; val_neg_r2_loss: -6.744E-01; val_nu_mass_loss: 1.765E-02; val_w0_mass_mae_loss: 2.005E+01; val_w1_mass_mae_loss: 2.149E+01; val_w_mass_mmd0_loss: 2.319E-01; val_w_mass_mmd1_loss: 8.597E-02; w0_mass_mae_loss: 2.048E+01; w1_mass_mae_loss: 2.066E+01; w_mass_mmd0_loss: 3.142E-01; w_mass_mmd1_loss: 8.955E-02
# Epoch 8; dinu_pt_loss: 4.718E+01; higgs_mass_loss: 1.933E+01; loss: 1.024E+02; mae_loss: 4.972E+01; neg_r2_loss: -6.696E-01; nu_mass_loss: 1.758E-02; val_dinu_pt_loss: 4.415E+01; val_higgs_mass_loss: 1.951E+01; val_loss: 1.009E+02; val_mae_loss: 4.925E+01; val_neg_r2_loss: -6.773E-01; val_nu_mass_loss: 1.823E-02; val_w0_mass_mae_loss: 1.888E+01; val_w1_mass_mae_loss: 2.175E+01; val_w_mass_mmd0_loss: 2.164E-01; val_w_mass_mmd1_loss: 8.821E-02; w0_mass_mae_loss: 1.958E+01; w1_mass_mae_loss: 2.074E+01; w_mass_mmd0_loss: 2.788E-01; w_mass_mmd1_loss: 8.851E-02
# Epoch 9; dinu_pt_loss: 4.368E+01; higgs_mass_loss: 1.966E+01; loss: 1.008E+02; mae_loss: 4.906E+01; neg_r2_loss: -6.735E-01; nu_mass_loss: 1.842E-02; val_dinu_pt_loss: 4.136E+01; val_higgs_mass_loss: 1.815E+01; val_loss: 9.891E+01; val_mae_loss: 4.859E+01; val_neg_r2_loss: -6.810E-01; val_nu_mass_loss: 1.938E-02; val_w0_mass_mae_loss: 1.765E+01; val_w1_mass_mae_loss: 2.131E+01; val_w_mass_mmd0_loss: 1.258E-01; val_w_mass_mmd1_loss: 8.998E-02; w0_mass_mae_loss: 1.891E+01; w1_mass_mae_loss: 2.146E+01; w_mass_mmd0_loss: 2.517E-01; w_mass_mmd1_loss: 8.849E-02
# Epoch 10; dinu_pt_loss: 4.018E+01; higgs_mass_loss: 1.980E+01; loss: 9.932E+01; mae_loss: 4.840E+01; neg_r2_loss: -6.773E-01; nu_mass_loss: 1.941E-02; val_dinu_pt_loss: 3.788E+01; val_higgs_mass_loss: 1.860E+01; val_loss: 9.726E+01; val_mae_loss: 4.793E+01; val_neg_r2_loss: -6.854E-01; val_nu_mass_loss: 2.018E-02; val_w0_mass_mae_loss: 1.774E+01; val_w1_mass_mae_loss: 2.138E+01; val_w_mass_mmd0_loss: 8.530E-02; val_w_mass_mmd1_loss: 8.844E-02; w0_mass_mae_loss: 1.838E+01; w1_mass_mae_loss: 2.179E+01; w_mass_mmd0_loss: 2.260E-01; w_mass_mmd1_loss: 8.964E-02
# Epoch 11; dinu_pt_loss: 3.799E+01; higgs_mass_loss: 1.855E+01; loss: 9.777E+01; mae_loss: 4.771E+01; neg_r2_loss: -6.823E-01; nu_mass_loss: 2.044E-02; val_dinu_pt_loss: 3.640E+01; val_higgs_mass_loss: 1.734E+01; val_loss: 9.588E+01; val_mae_loss: 4.727E+01; val_neg_r2_loss: -6.902E-01; val_nu_mass_loss: 2.116E-02; val_w0_mass_mae_loss: 1.723E+01; val_w1_mass_mae_loss: 2.087E+01; val_w_mass_mmd0_loss: 7.917E-02; val_w_mass_mmd1_loss: 8.803E-02; w0_mass_mae_loss: 1.816E+01; w1_mass_mae_loss: 2.114E+01; w_mass_mmd0_loss: 2.045E-01; w_mass_mmd1_loss: 8.922E-02
# Epoch 12; dinu_pt_loss: 3.599E+01; higgs_mass_loss: 1.808E+01; loss: 9.629E+01; mae_loss: 4.703E+01; neg_r2_loss: -6.877E-01; nu_mass_loss: 2.149E-02; val_dinu_pt_loss: 3.418E+01; val_higgs_mass_loss: 1.771E+01; val_loss: 9.451E+01; val_mae_loss: 4.662E+01; val_neg_r2_loss: -6.958E-01; val_nu_mass_loss: 2.209E-02; val_w0_mass_mae_loss: 1.781E+01; val_w1_mass_mae_loss: 2.062E+01; val_w_mass_mmd0_loss: 7.031E-02; val_w_mass_mmd1_loss: 8.806E-02; w0_mass_mae_loss: 1.819E+01; w1_mass_mae_loss: 2.075E+01; w_mass_mmd0_loss: 1.897E-01; w_mass_mmd1_loss: 9.042E-02
# Epoch 13; dinu_pt_loss: 3.471E+01; higgs_mass_loss: 1.771E+01; loss: 9.487E+01; mae_loss: 4.636E+01; neg_r2_loss: -6.935E-01; nu_mass_loss: 2.260E-02; val_dinu_pt_loss: 3.286E+01; val_higgs_mass_loss: 1.723E+01; val_loss: 9.312E+01; val_mae_loss: 4.592E+01; val_neg_r2_loss: -7.019E-01; val_nu_mass_loss: 2.326E-02; val_w0_mass_mae_loss: 1.834E+01; val_w1_mass_mae_loss: 1.995E+01; val_w_mass_mmd0_loss: 6.877E-02; val_w_mass_mmd1_loss: 9.173E-02; w0_mass_mae_loss: 1.839E+01; w1_mass_mae_loss: 2.050E+01; w_mass_mmd0_loss: 1.771E-01; w_mass_mmd1_loss: 9.106E-02
# Epoch 14; dinu_pt_loss: 3.363E+01; higgs_mass_loss: 1.715E+01; loss: 9.341E+01; mae_loss: 4.568E+01; neg_r2_loss: -6.995E-01; nu_mass_loss: 2.379E-02; val_dinu_pt_loss: 3.237E+01; val_higgs_mass_loss: 1.727E+01; val_loss: 9.210E+01; val_mae_loss: 4.528E+01; val_neg_r2_loss: -7.077E-01; val_nu_mass_loss: 2.440E-02; val_w0_mass_mae_loss: 1.826E+01; val_w1_mass_mae_loss: 1.998E+01; val_w_mass_mmd0_loss: 9.924E-02; val_w_mass_mmd1_loss: 9.217E-02; w0_mass_mae_loss: 1.850E+01; w1_mass_mae_loss: 1.996E+01; w_mass_mmd0_loss: 1.640E-01; w_mass_mmd1_loss: 9.369E-02
# Epoch 15; dinu_pt_loss: 3.248E+01; higgs_mass_loss: 1.691E+01; loss: 9.196E+01; mae_loss: 4.498E+01; neg_r2_loss: -7.057E-01; nu_mass_loss: 2.494E-02; val_dinu_pt_loss: 3.029E+01; val_higgs_mass_loss: 1.627E+01; val_loss: 9.113E+01; val_mae_loss: 4.461E+01; val_neg_r2_loss: -7.124E-01; val_nu_mass_loss: 2.522E-02; val_w0_mass_mae_loss: 1.806E+01; val_w1_mass_mae_loss: 1.926E+01; val_w_mass_mmd0_loss: 1.364E-01; val_w_mass_mmd1_loss: 1.007E-01; w0_mass_mae_loss: 1.864E+01; w1_mass_mae_loss: 1.957E+01; w_mass_mmd0_loss: 1.542E-01; w_mass_mmd1_loss: 9.500E-02
# Epoch 16; dinu_pt_loss: 3.125E+01; higgs_mass_loss: 1.661E+01; loss: 9.050E+01; mae_loss: 4.427E+01; neg_r2_loss: -7.120E-01; nu_mass_loss: 2.618E-02; val_dinu_pt_loss: 2.965E+01; val_higgs_mass_loss: 1.619E+01; val_loss: 8.929E+01; val_mae_loss: 4.382E+01; val_neg_r2_loss: -7.208E-01; val_nu_mass_loss: 2.673E-02; val_w0_mass_mae_loss: 1.818E+01; val_w1_mass_mae_loss: 1.909E+01; val_w_mass_mmd0_loss: 1.044E-01; val_w_mass_mmd1_loss: 1.001E-01; w0_mass_mae_loss: 1.861E+01; w1_mass_mae_loss: 1.932E+01; w_mass_mmd0_loss: 1.473E-01; w_mass_mmd1_loss: 9.646E-02
# Epoch 17; dinu_pt_loss: 3.034E+01; higgs_mass_loss: 1.652E+01; loss: 8.907E+01; mae_loss: 4.358E+01; neg_r2_loss: -7.188E-01; nu_mass_loss: 2.747E-02; val_dinu_pt_loss: 2.819E+01; val_higgs_mass_loss: 1.615E+01; val_loss: 8.807E+01; val_mae_loss: 4.320E+01; val_neg_r2_loss: -7.267E-01; val_nu_mass_loss: 2.789E-02; val_w0_mass_mae_loss: 1.806E+01; val_w1_mass_mae_loss: 1.908E+01; val_w_mass_mmd0_loss: 1.090E-01; val_w_mass_mmd1_loss: 9.980E-02; w0_mass_mae_loss: 1.861E+01; w1_mass_mae_loss: 1.913E+01; w_mass_mmd0_loss: 1.404E-01; w_mass_mmd1_loss: 9.667E-02
# Epoch 18; dinu_pt_loss: 2.890E+01; higgs_mass_loss: 1.609E+01; loss: 8.771E+01; mae_loss: 4.293E+01; neg_r2_loss: -7.252E-01; nu_mass_loss: 2.877E-02; val_dinu_pt_loss: 2.790E+01; val_higgs_mass_loss: 1.559E+01; val_loss: 8.725E+01; val_mae_loss: 4.258E+01; val_neg_r2_loss: -7.332E-01; val_nu_mass_loss: 2.919E-02; val_w0_mass_mae_loss: 1.778E+01; val_w1_mass_mae_loss: 1.883E+01; val_w_mass_mmd0_loss: 1.604E-01; val_w_mass_mmd1_loss: 1.008E-01; w0_mass_mae_loss: 1.835E+01; w1_mass_mae_loss: 1.896E+01; w_mass_mmd0_loss: 1.337E-01; w_mass_mmd1_loss: 9.734E-02
# Epoch 19; dinu_pt_loss: 2.811E+01; higgs_mass_loss: 1.570E+01; loss: 8.644E+01; mae_loss: 4.232E+01; neg_r2_loss: -7.320E-01; nu_mass_loss: 3.011E-02; val_dinu_pt_loss: 2.660E+01; val_higgs_mass_loss: 1.565E+01; val_loss: 8.587E+01; val_mae_loss: 4.196E+01; val_neg_r2_loss: -7.401E-01; val_nu_mass_loss: 3.042E-02; val_w0_mass_mae_loss: 1.795E+01; val_w1_mass_mae_loss: 1.872E+01; val_w_mass_mmd0_loss: 1.443E-01; val_w_mass_mmd1_loss: 9.999E-02; w0_mass_mae_loss: 1.813E+01; w1_mass_mae_loss: 1.878E+01; w_mass_mmd0_loss: 1.278E-01; w_mass_mmd1_loss: 9.675E-02
# Epoch 20; dinu_pt_loss: 2.684E+01; higgs_mass_loss: 1.534E+01; loss: 8.523E+01; mae_loss: 4.175E+01; neg_r2_loss: -7.384E-01; nu_mass_loss: 3.136E-02; val_dinu_pt_loss: 2.485E+01; val_higgs_mass_loss: 1.511E+01; val_loss: 8.471E+01; val_mae_loss: 4.141E+01; val_neg_r2_loss: -7.459E-01; val_nu_mass_loss: 3.154E-02; val_w0_mass_mae_loss: 1.751E+01; val_w1_mass_mae_loss: 1.858E+01; val_w_mass_mmd0_loss: 1.379E-01; val_w_mass_mmd1_loss: 9.800E-02; w0_mass_mae_loss: 1.796E+01; w1_mass_mae_loss: 1.866E+01; w_mass_mmd0_loss: 1.189E-01; w_mass_mmd1_loss: 9.604E-02
# Epoch 21; dinu_pt_loss: 2.612E+01; higgs_mass_loss: 1.512E+01; loss: 8.417E+01; mae_loss: 4.123E+01; neg_r2_loss: -7.448E-01; nu_mass_loss: 3.265E-02; val_dinu_pt_loss: 2.467E+01; val_higgs_mass_loss: 1.511E+01; val_loss: 8.414E+01; val_mae_loss: 4.092E+01; val_neg_r2_loss: -7.525E-01; val_nu_mass_loss: 3.282E-02; val_w0_mass_mae_loss: 1.743E+01; val_w1_mass_mae_loss: 1.854E+01; val_w_mass_mmd0_loss: 1.894E-01; val_w_mass_mmd1_loss: 9.816E-02; w0_mass_mae_loss: 1.784E+01; w1_mass_mae_loss: 1.858E+01; w_mass_mmd0_loss: 1.175E-01; w_mass_mmd1_loss: 9.485E-02
# Epoch 22; dinu_pt_loss: 2.533E+01; higgs_mass_loss: 1.475E+01; loss: 8.314E+01; mae_loss: 4.075E+01; neg_r2_loss: -7.508E-01; nu_mass_loss: 3.387E-02; val_dinu_pt_loss: 2.325E+01; val_higgs_mass_loss: 1.471E+01; val_loss: 8.319E+01; val_mae_loss: 4.047E+01; val_neg_r2_loss: -7.576E-01; val_nu_mass_loss: 3.380E-02; val_w0_mass_mae_loss: 1.729E+01; val_w1_mass_mae_loss: 1.843E+01; val_w_mass_mmd0_loss: 1.831E-01; val_w_mass_mmd1_loss: 9.785E-02; w0_mass_mae_loss: 1.762E+01; w1_mass_mae_loss: 1.849E+01; w_mass_mmd0_loss: 1.116E-01; w_mass_mmd1_loss: 9.441E-02
# Epoch 23; dinu_pt_loss: 2.432E+01; higgs_mass_loss: 1.446E+01; loss: 8.218E+01; mae_loss: 4.029E+01; neg_r2_loss: -7.563E-01; nu_mass_loss: 3.497E-02; val_dinu_pt_loss: 2.261E+01; val_higgs_mass_loss: 1.409E+01; val_loss: 8.185E+01; val_mae_loss: 4.000E+01; val_neg_r2_loss: -7.631E-01; val_nu_mass_loss: 3.487E-02; val_w0_mass_mae_loss: 1.686E+01; val_w1_mass_mae_loss: 1.824E+01; val_w_mass_mmd0_loss: 1.327E-01; val_w_mass_mmd1_loss: 9.724E-02; w0_mass_mae_loss: 1.739E+01; w1_mass_mae_loss: 1.839E+01; w_mass_mmd0_loss: 1.059E-01; w_mass_mmd1_loss: 9.379E-02
# Epoch 24; dinu_pt_loss: 2.348E+01; higgs_mass_loss: 1.423E+01; loss: 8.130E+01; mae_loss: 3.986E+01; neg_r2_loss: -7.617E-01; nu_mass_loss: 3.602E-02; val_dinu_pt_loss: 2.098E+01; val_higgs_mass_loss: 1.418E+01; val_loss: 8.149E+01; val_mae_loss: 3.958E+01; val_neg_r2_loss: -7.675E-01; val_nu_mass_loss: 3.555E-02; val_w0_mass_mae_loss: 1.683E+01; val_w1_mass_mae_loss: 1.825E+01; val_w_mass_mmd0_loss: 1.927E-01; val_w_mass_mmd1_loss: 9.895E-02; w0_mass_mae_loss: 1.723E+01; w1_mass_mae_loss: 1.831E+01; w_mass_mmd0_loss: 1.047E-01; w_mass_mmd1_loss: 9.314E-02
# Epoch 25; dinu_pt_loss: 2.289E+01; higgs_mass_loss: 1.399E+01; loss: 8.042E+01; mae_loss: 3.943E+01; neg_r2_loss: -7.671E-01; nu_mass_loss: 3.686E-02; val_dinu_pt_loss: 2.061E+01; val_higgs_mass_loss: 1.385E+01; val_loss: 7.997E+01; val_mae_loss: 3.912E+01; val_neg_r2_loss: -7.734E-01; val_nu_mass_loss: 3.678E-02; val_w0_mass_mae_loss: 1.666E+01; val_w1_mass_mae_loss: 1.816E+01; val_w_mass_mmd0_loss: 1.156E-01; val_w_mass_mmd1_loss: 9.968E-02; w0_mass_mae_loss: 1.712E+01; w1_mass_mae_loss: 1.828E+01; w_mass_mmd0_loss: 1.024E-01; w_mass_mmd1_loss: 9.186E-02
# Epoch 26; dinu_pt_loss: 2.198E+01; higgs_mass_loss: 1.375E+01; loss: 7.955E+01; mae_loss: 3.900E+01; neg_r2_loss: -7.721E-01; nu_mass_loss: 3.775E-02; val_dinu_pt_loss: 1.940E+01; val_higgs_mass_loss: 1.371E+01; val_loss: 7.901E+01; val_mae_loss: 3.872E+01; val_neg_r2_loss: -7.774E-01; val_nu_mass_loss: 3.750E-02; val_w0_mass_mae_loss: 1.638E+01; val_w1_mass_mae_loss: 1.821E+01; val_w_mass_mmd0_loss: 1.000E-01; val_w_mass_mmd1_loss: 9.682E-02; w0_mass_mae_loss: 1.697E+01; w1_mass_mae_loss: 1.824E+01; w_mass_mmd0_loss: 1.018E-01; w_mass_mmd1_loss: 9.163E-02
# Epoch 27; dinu_pt_loss: 2.111E+01; higgs_mass_loss: 1.363E+01; loss: 7.873E+01; mae_loss: 3.860E+01; neg_r2_loss: -7.767E-01; nu_mass_loss: 3.851E-02; val_dinu_pt_loss: 1.847E+01; val_higgs_mass_loss: 1.385E+01; val_loss: 7.844E+01; val_mae_loss: 3.826E+01; val_neg_r2_loss: -7.840E-01; val_nu_mass_loss: 3.837E-02; val_w0_mass_mae_loss: 1.646E+01; val_w1_mass_mae_loss: 1.812E+01; val_w_mass_mmd0_loss: 1.465E-01; val_w_mass_mmd1_loss: 9.458E-02; w0_mass_mae_loss: 1.683E+01; w1_mass_mae_loss: 1.821E+01; w_mass_mmd0_loss: 9.928E-02; w_mass_mmd1_loss: 9.013E-02
# Epoch 28; dinu_pt_loss: 2.044E+01; higgs_mass_loss: 1.353E+01; loss: 7.795E+01; mae_loss: 3.824E+01; neg_r2_loss: -7.811E-01; nu_mass_loss: 3.931E-02; val_dinu_pt_loss: 1.864E+01; val_higgs_mass_loss: 1.404E+01; val_loss: 7.765E+01; val_mae_loss: 3.794E+01; val_neg_r2_loss: -7.884E-01; val_nu_mass_loss: 3.911E-02; val_w0_mass_mae_loss: 1.662E+01; val_w1_mass_mae_loss: 1.814E+01; val_w_mass_mmd0_loss: 1.293E-01; val_w_mass_mmd1_loss: 9.293E-02; w0_mass_mae_loss: 1.676E+01; w1_mass_mae_loss: 1.818E+01; w_mass_mmd0_loss: 9.484E-02; w_mass_mmd1_loss: 8.877E-02
# Epoch 29; dinu_pt_loss: 1.963E+01; higgs_mass_loss: 1.345E+01; loss: 7.723E+01; mae_loss: 3.789E+01; neg_r2_loss: -7.851E-01; nu_mass_loss: 3.993E-02; val_dinu_pt_loss: 1.733E+01; val_higgs_mass_loss: 1.352E+01; val_loss: 7.653E+01; val_mae_loss: 3.759E+01; val_neg_r2_loss: -7.915E-01; val_nu_mass_loss: 3.934E-02; val_w0_mass_mae_loss: 1.623E+01; val_w1_mass_mae_loss: 1.825E+01; val_w_mass_mmd0_loss: 7.711E-02; val_w_mass_mmd1_loss: 9.206E-02; w0_mass_mae_loss: 1.670E+01; w1_mass_mae_loss: 1.822E+01; w_mass_mmd0_loss: 9.451E-02; w_mass_mmd1_loss: 8.635E-02
# Epoch 30; dinu_pt_loss: 1.892E+01; higgs_mass_loss: 1.312E+01; loss: 7.653E+01; mae_loss: 3.756E+01; neg_r2_loss: -7.889E-01; nu_mass_loss: 4.057E-02; val_dinu_pt_loss: 1.688E+01; val_higgs_mass_loss: 1.323E+01; val_loss: 7.638E+01; val_mae_loss: 3.729E+01; val_neg_r2_loss: -7.939E-01; val_nu_mass_loss: 3.992E-02; val_w0_mass_mae_loss: 1.603E+01; val_w1_mass_mae_loss: 1.814E+01; val_w_mass_mmd0_loss: 1.357E-01; val_w_mass_mmd1_loss: 8.926E-02; w0_mass_mae_loss: 1.652E+01; w1_mass_mae_loss: 1.821E+01; w_mass_mmd0_loss: 9.107E-02; w_mass_mmd1_loss: 8.506E-02
# Epoch 31; dinu_pt_loss: 1.820E+01; higgs_mass_loss: 1.307E+01; loss: 7.587E+01; mae_loss: 3.724E+01; neg_r2_loss: -7.927E-01; nu_mass_loss: 4.124E-02; val_dinu_pt_loss: 1.587E+01; val_higgs_mass_loss: 1.360E+01; val_loss: 7.592E+01; val_mae_loss: 3.693E+01; val_neg_r2_loss: -7.987E-01; val_nu_mass_loss: 4.085E-02; val_w0_mass_mae_loss: 1.611E+01; val_w1_mass_mae_loss: 1.815E+01; val_w_mass_mmd0_loss: 1.662E-01; val_w_mass_mmd1_loss: 9.139E-02; w0_mass_mae_loss: 1.649E+01; w1_mass_mae_loss: 1.821E+01; w_mass_mmd0_loss: 9.115E-02; w_mass_mmd1_loss: 8.281E-02
# Epoch 32; dinu_pt_loss: 1.752E+01; higgs_mass_loss: 1.288E+01; loss: 7.523E+01; mae_loss: 3.694E+01; neg_r2_loss: -7.963E-01; nu_mass_loss: 4.178E-02; val_dinu_pt_loss: 1.506E+01; val_higgs_mass_loss: 1.321E+01; val_loss: 7.503E+01; val_mae_loss: 3.666E+01; val_neg_r2_loss: -8.012E-01; val_nu_mass_loss: 4.116E-02; val_w0_mass_mae_loss: 1.598E+01; val_w1_mass_mae_loss: 1.823E+01; val_w_mass_mmd0_loss: 1.271E-01; val_w_mass_mmd1_loss: 8.502E-02; w0_mass_mae_loss: 1.640E+01; w1_mass_mae_loss: 1.819E+01; w_mass_mmd0_loss: 8.814E-02; w_mass_mmd1_loss: 8.107E-02
# Epoch 33; dinu_pt_loss: 1.687E+01; higgs_mass_loss: 1.273E+01; loss: 7.461E+01; mae_loss: 3.664E+01; neg_r2_loss: -7.995E-01; nu_mass_loss: 4.227E-02; val_dinu_pt_loss: 1.485E+01; val_higgs_mass_loss: 1.307E+01; val_loss: 7.435E+01; val_mae_loss: 3.637E+01; val_neg_r2_loss: -8.043E-01; val_nu_mass_loss: 4.127E-02; val_w0_mass_mae_loss: 1.597E+01; val_w1_mass_mae_loss: 1.818E+01; val_w_mass_mmd0_loss: 1.194E-01; val_w_mass_mmd1_loss: 8.273E-02; w0_mass_mae_loss: 1.636E+01; w1_mass_mae_loss: 1.822E+01; w_mass_mmd0_loss: 8.763E-02; w_mass_mmd1_loss: 7.916E-02
# Epoch 34; dinu_pt_loss: 1.608E+01; higgs_mass_loss: 1.263E+01; loss: 7.403E+01; mae_loss: 3.636E+01; neg_r2_loss: -8.025E-01; nu_mass_loss: 4.263E-02; val_dinu_pt_loss: 1.361E+01; val_higgs_mass_loss: 1.295E+01; val_loss: 7.342E+01; val_mae_loss: 3.606E+01; val_neg_r2_loss: -8.074E-01; val_nu_mass_loss: 4.183E-02; val_w0_mass_mae_loss: 1.584E+01; val_w1_mass_mae_loss: 1.810E+01; val_w_mass_mmd0_loss: 8.125E-02; val_w_mass_mmd1_loss: 8.160E-02; w0_mass_mae_loss: 1.627E+01; w1_mass_mae_loss: 1.823E+01; w_mass_mmd0_loss: 8.608E-02; w_mass_mmd1_loss: 7.774E-02
# Epoch 35; dinu_pt_loss: 1.556E+01; higgs_mass_loss: 1.267E+01; loss: 7.345E+01; mae_loss: 3.608E+01; neg_r2_loss: -8.054E-01; nu_mass_loss: 4.310E-02; val_dinu_pt_loss: 1.341E+01; val_higgs_mass_loss: 1.323E+01; val_loss: 7.291E+01; val_mae_loss: 3.576E+01; val_neg_r2_loss: -8.120E-01; val_nu_mass_loss: 4.288E-02; val_w0_mass_mae_loss: 1.603E+01; val_w1_mass_mae_loss: 1.809E+01; val_w_mass_mmd0_loss: 9.305E-02; val_w_mass_mmd1_loss: 8.173E-02; w0_mass_mae_loss: 1.624E+01; w1_mass_mae_loss: 1.818E+01; w_mass_mmd0_loss: 8.545E-02; w_mass_mmd1_loss: 7.625E-02
# Epoch 36; dinu_pt_loss: 1.490E+01; higgs_mass_loss: 1.254E+01; loss: 7.291E+01; mae_loss: 3.582E+01; neg_r2_loss: -8.083E-01; nu_mass_loss: 4.348E-02; val_dinu_pt_loss: 1.256E+01; val_higgs_mass_loss: 1.292E+01; val_loss: 7.253E+01; val_mae_loss: 3.557E+01; val_neg_r2_loss: -8.128E-01; val_nu_mass_loss: 4.253E-02; val_w0_mass_mae_loss: 1.571E+01; val_w1_mass_mae_loss: 1.819E+01; val_w_mass_mmd0_loss: 9.575E-02; val_w_mass_mmd1_loss: 7.910E-02; w0_mass_mae_loss: 1.618E+01; w1_mass_mae_loss: 1.824E+01; w_mass_mmd0_loss: 8.455E-02; w_mass_mmd1_loss: 7.416E-02
# Epoch 37; dinu_pt_loss: 1.435E+01; higgs_mass_loss: 1.250E+01; loss: 7.241E+01; mae_loss: 3.559E+01; neg_r2_loss: -8.109E-01; nu_mass_loss: 4.390E-02; val_dinu_pt_loss: 1.142E+01; val_higgs_mass_loss: 1.305E+01; val_loss: 7.211E+01; val_mae_loss: 3.537E+01; val_neg_r2_loss: -8.149E-01; val_nu_mass_loss: 4.294E-02; val_w0_mass_mae_loss: 1.579E+01; val_w1_mass_mae_loss: 1.820E+01; val_w_mass_mmd0_loss: 9.339E-02; val_w_mass_mmd1_loss: 7.810E-02; w0_mass_mae_loss: 1.611E+01; w1_mass_mae_loss: 1.830E+01; w_mass_mmd0_loss: 8.281E-02; w_mass_mmd1_loss: 7.180E-02
# Epoch 38; dinu_pt_loss: 1.386E+01; higgs_mass_loss: 1.245E+01; loss: 7.197E+01; mae_loss: 3.538E+01; neg_r2_loss: -8.134E-01; nu_mass_loss: 4.422E-02; val_dinu_pt_loss: 1.155E+01; val_higgs_mass_loss: 1.268E+01; val_loss: 7.138E+01; val_mae_loss: 3.513E+01; val_neg_r2_loss: -8.186E-01; val_nu_mass_loss: 4.384E-02; val_w0_mass_mae_loss: 1.577E+01; val_w1_mass_mae_loss: 1.815E+01; val_w_mass_mmd0_loss: 6.373E-02; val_w_mass_mmd1_loss: 7.543E-02; w0_mass_mae_loss: 1.601E+01; w1_mass_mae_loss: 1.837E+01; w_mass_mmd0_loss: 8.111E-02; w_mass_mmd1_loss: 6.991E-02
# Epoch 39; dinu_pt_loss: 1.347E+01; higgs_mass_loss: 1.239E+01; loss: 7.160E+01; mae_loss: 3.520E+01; neg_r2_loss: -8.157E-01; nu_mass_loss: 4.453E-02; val_dinu_pt_loss: 1.123E+01; val_higgs_mass_loss: 1.272E+01; val_loss: 7.121E+01; val_mae_loss: 3.492E+01; val_neg_r2_loss: -8.216E-01; val_nu_mass_loss: 4.429E-02; val_w0_mass_mae_loss: 1.567E+01; val_w1_mass_mae_loss: 1.825E+01; val_w_mass_mmd0_loss: 9.985E-02; val_w_mass_mmd1_loss: 7.239E-02; w0_mass_mae_loss: 1.595E+01; w1_mass_mae_loss: 1.837E+01; w_mass_mmd0_loss: 8.148E-02; w_mass_mmd1_loss: 6.844E-02
# Epoch 40; dinu_pt_loss: 1.307E+01; higgs_mass_loss: 1.229E+01; loss: 7.125E+01; mae_loss: 3.505E+01; neg_r2_loss: -8.179E-01; nu_mass_loss: 4.488E-02; val_dinu_pt_loss: 1.033E+01; val_higgs_mass_loss: 1.248E+01; val_loss: 7.088E+01; val_mae_loss: 3.484E+01; val_neg_r2_loss: -8.214E-01; val_nu_mass_loss: 4.402E-02; val_w0_mass_mae_loss: 1.561E+01; val_w1_mass_mae_loss: 1.828E+01; val_w_mass_mmd0_loss: 7.748E-02; val_w_mass_mmd1_loss: 7.250E-02; w0_mass_mae_loss: 1.591E+01; w1_mass_mae_loss: 1.836E+01; w_mass_mmd0_loss: 7.723E-02; w_mass_mmd1_loss: 6.731E-02
# Epoch 41; dinu_pt_loss: 1.270E+01; higgs_mass_loss: 1.223E+01; loss: 7.099E+01; mae_loss: 3.492E+01; neg_r2_loss: -8.197E-01; nu_mass_loss: 4.523E-02; val_dinu_pt_loss: 1.015E+01; val_higgs_mass_loss: 1.255E+01; val_loss: 7.061E+01; val_mae_loss: 3.468E+01; val_neg_r2_loss: -8.243E-01; val_nu_mass_loss: 4.444E-02; val_w0_mass_mae_loss: 1.548E+01; val_w1_mass_mae_loss: 1.832E+01; val_w_mass_mmd0_loss: 8.433E-02; val_w_mass_mmd1_loss: 7.174E-02; w0_mass_mae_loss: 1.581E+01; w1_mass_mae_loss: 1.843E+01; w_mass_mmd0_loss: 7.845E-02; w_mass_mmd1_loss: 6.604E-02
# Epoch 42; dinu_pt_loss: 1.237E+01; higgs_mass_loss: 1.215E+01; loss: 7.074E+01; mae_loss: 3.481E+01; neg_r2_loss: -8.213E-01; nu_mass_loss: 4.552E-02; val_dinu_pt_loss: 1.013E+01; val_higgs_mass_loss: 1.216E+01; val_loss: 7.009E+01; val_mae_loss: 3.457E+01; val_neg_r2_loss: -8.262E-01; val_nu_mass_loss: 4.515E-02; val_w0_mass_mae_loss: 1.544E+01; val_w1_mass_mae_loss: 1.820E+01; val_w_mass_mmd0_loss: 4.942E-02; val_w_mass_mmd1_loss: 6.994E-02; w0_mass_mae_loss: 1.577E+01; w1_mass_mae_loss: 1.846E+01; w_mass_mmd0_loss: 7.656E-02; w_mass_mmd1_loss: 6.471E-02
# Epoch 43; dinu_pt_loss: 1.219E+01; higgs_mass_loss: 1.211E+01; loss: 7.056E+01; mae_loss: 3.472E+01; neg_r2_loss: -8.227E-01; nu_mass_loss: 4.580E-02; val_dinu_pt_loss: 1.006E+01; val_higgs_mass_loss: 1.237E+01; val_loss: 7.005E+01; val_mae_loss: 3.451E+01; val_neg_r2_loss: -8.273E-01; val_nu_mass_loss: 4.517E-02; val_w0_mass_mae_loss: 1.546E+01; val_w1_mass_mae_loss: 1.824E+01; val_w_mass_mmd0_loss: 5.910E-02; val_w_mass_mmd1_loss: 7.048E-02; w0_mass_mae_loss: 1.574E+01; w1_mass_mae_loss: 1.849E+01; w_mass_mmd0_loss: 7.655E-02; w_mass_mmd1_loss: 6.375E-02
# Epoch 44; dinu_pt_loss: 1.188E+01; higgs_mass_loss: 1.206E+01; loss: 7.039E+01; mae_loss: 3.464E+01; neg_r2_loss: -8.241E-01; nu_mass_loss: 4.604E-02; val_dinu_pt_loss: 9.565E+00; val_higgs_mass_loss: 1.255E+01; val_loss: 7.017E+01; val_mae_loss: 3.439E+01; val_neg_r2_loss: -8.289E-01; val_nu_mass_loss: 4.575E-02; val_w0_mass_mae_loss: 1.543E+01; val_w1_mass_mae_loss: 1.822E+01; val_w_mass_mmd0_loss: 1.044E-01; val_w_mass_mmd1_loss: 6.840E-02; w0_mass_mae_loss: 1.571E+01; w1_mass_mae_loss: 1.849E+01; w_mass_mmd0_loss: 7.627E-02; w_mass_mmd1_loss: 6.297E-02
# Epoch 45; dinu_pt_loss: 1.173E+01; higgs_mass_loss: 1.203E+01; loss: 7.026E+01; mae_loss: 3.458E+01; neg_r2_loss: -8.252E-01; nu_mass_loss: 4.624E-02; val_dinu_pt_loss: 8.987E+00; val_higgs_mass_loss: 1.208E+01; val_loss: 6.998E+01; val_mae_loss: 3.434E+01; val_neg_r2_loss: -8.298E-01; val_nu_mass_loss: 4.557E-02; val_w0_mass_mae_loss: 1.542E+01; val_w1_mass_mae_loss: 1.815E+01; val_w_mass_mmd0_loss: 9.574E-02; val_w_mass_mmd1_loss: 6.836E-02; w0_mass_mae_loss: 1.565E+01; w1_mass_mae_loss: 1.856E+01; w_mass_mmd0_loss: 7.683E-02; w_mass_mmd1_loss: 6.208E-02
# Epoch 46; dinu_pt_loss: 1.151E+01; higgs_mass_loss: 1.193E+01; loss: 7.014E+01; mae_loss: 3.453E+01; neg_r2_loss: -8.259E-01; nu_mass_loss: 4.642E-02; val_dinu_pt_loss: 8.905E+00; val_higgs_mass_loss: 1.211E+01; val_loss: 6.972E+01; val_mae_loss: 3.429E+01; val_neg_r2_loss: -8.307E-01; val_nu_mass_loss: 4.603E-02; val_w0_mass_mae_loss: 1.531E+01; val_w1_mass_mae_loss: 1.822E+01; val_w_mass_mmd0_loss: 7.861E-02; val_w_mass_mmd1_loss: 6.483E-02; w0_mass_mae_loss: 1.563E+01; w1_mass_mae_loss: 1.853E+01; w_mass_mmd0_loss: 7.384E-02; w_mass_mmd1_loss: 6.110E-02
# Epoch 47; dinu_pt_loss: 1.147E+01; higgs_mass_loss: 1.180E+01; loss: 7.005E+01; mae_loss: 3.448E+01; neg_r2_loss: -8.266E-01; nu_mass_loss: 4.651E-02; val_dinu_pt_loss: 8.905E+00; val_higgs_mass_loss: 1.212E+01; val_loss: 6.962E+01; val_mae_loss: 3.430E+01; val_neg_r2_loss: -8.296E-01; val_nu_mass_loss: 4.550E-02; val_w0_mass_mae_loss: 1.531E+01; val_w1_mass_mae_loss: 1.837E+01; val_w_mass_mmd0_loss: 6.155E-02; val_w_mass_mmd1_loss: 6.627E-02; w0_mass_mae_loss: 1.561E+01; w1_mass_mae_loss: 1.850E+01; w_mass_mmd0_loss: 7.542E-02; w_mass_mmd1_loss: 6.057E-02
# Epoch 48; dinu_pt_loss: 1.125E+01; higgs_mass_loss: 1.183E+01; loss: 6.996E+01; mae_loss: 3.444E+01; neg_r2_loss: -8.271E-01; nu_mass_loss: 4.667E-02; val_dinu_pt_loss: 8.672E+00; val_higgs_mass_loss: 1.216E+01; val_loss: 6.956E+01; val_mae_loss: 3.421E+01; val_neg_r2_loss: -8.316E-01; val_nu_mass_loss: 4.649E-02; val_w0_mass_mae_loss: 1.525E+01; val_w1_mass_mae_loss: 1.831E+01; val_w_mass_mmd0_loss: 7.520E-02; val_w_mass_mmd1_loss: 6.643E-02; w0_mass_mae_loss: 1.557E+01; w1_mass_mae_loss: 1.857E+01; w_mass_mmd0_loss: 7.346E-02; w_mass_mmd1_loss: 5.990E-02
# Epoch 49; dinu_pt_loss: 1.119E+01; higgs_mass_loss: 1.179E+01; loss: 6.988E+01; mae_loss: 3.441E+01; neg_r2_loss: -8.277E-01; nu_mass_loss: 4.672E-02; val_dinu_pt_loss: 8.592E+00; val_higgs_mass_loss: 1.218E+01; val_loss: 7.004E+01; val_mae_loss: 3.420E+01; val_neg_r2_loss: -8.318E-01; val_nu_mass_loss: 4.625E-02; val_w0_mass_mae_loss: 1.517E+01; val_w1_mass_mae_loss: 1.827E+01; val_w_mass_mmd0_loss: 1.400E-01; val_w_mass_mmd1_loss: 6.387E-02; w0_mass_mae_loss: 1.554E+01; w1_mass_mae_loss: 1.868E+01; w_mass_mmd0_loss: 7.414E-02; w_mass_mmd1_loss: 5.869E-02
# Epoch 50; dinu_pt_loss: 1.100E+01; higgs_mass_loss: 1.175E+01; loss: 6.980E+01; mae_loss: 3.437E+01; neg_r2_loss: -8.283E-01; nu_mass_loss: 4.694E-02; val_dinu_pt_loss: 8.244E+00; val_higgs_mass_loss: 1.197E+01; val_loss: 6.959E+01; val_mae_loss: 3.415E+01; val_neg_r2_loss: -8.324E-01; val_nu_mass_loss: 4.653E-02; val_w0_mass_mae_loss: 1.527E+01; val_w1_mass_mae_loss: 1.838E+01; val_w_mass_mmd0_loss: 9.860E-02; val_w_mass_mmd1_loss: 6.207E-02; w0_mass_mae_loss: 1.554E+01; w1_mass_mae_loss: 1.861E+01; w_mass_mmd0_loss: 7.399E-02; w_mass_mmd1_loss: 5.808E-02
# Epoch 51; dinu_pt_loss: 1.095E+01; higgs_mass_loss: 1.177E+01; loss: 6.974E+01; mae_loss: 3.435E+01; neg_r2_loss: -8.287E-01; nu_mass_loss: 4.700E-02; val_dinu_pt_loss: 7.900E+00; val_higgs_mass_loss: 1.187E+01; val_loss: 6.942E+01; val_mae_loss: 3.414E+01; val_neg_r2_loss: -8.322E-01; val_nu_mass_loss: 4.631E-02; val_w0_mass_mae_loss: 1.528E+01; val_w1_mass_mae_loss: 1.834E+01; val_w_mass_mmd0_loss: 7.920E-02; val_w_mass_mmd1_loss: 6.249E-02; w0_mass_mae_loss: 1.554E+01; w1_mass_mae_loss: 1.866E+01; w_mass_mmd0_loss: 7.253E-02; w_mass_mmd1_loss: 5.778E-02
# Epoch 52; dinu_pt_loss: 1.095E+01; higgs_mass_loss: 1.172E+01; loss: 6.966E+01; mae_loss: 3.431E+01; neg_r2_loss: -8.291E-01; nu_mass_loss: 4.698E-02; val_dinu_pt_loss: 8.483E+00; val_higgs_mass_loss: 1.220E+01; val_loss: 6.940E+01; val_mae_loss: 3.414E+01; val_neg_r2_loss: -8.322E-01; val_nu_mass_loss: 4.600E-02; val_w0_mass_mae_loss: 1.518E+01; val_w1_mass_mae_loss: 1.861E+01; val_w_mass_mmd0_loss: 7.745E-02; val_w_mass_mmd1_loss: 6.229E-02; w0_mass_mae_loss: 1.552E+01; w1_mass_mae_loss: 1.867E+01; w_mass_mmd0_loss: 7.177E-02; w_mass_mmd1_loss: 5.700E-02
# Epoch 53; dinu_pt_loss: 1.085E+01; higgs_mass_loss: 1.164E+01; loss: 6.959E+01; mae_loss: 3.429E+01; neg_r2_loss: -8.295E-01; nu_mass_loss: 4.715E-02; val_dinu_pt_loss: 8.408E+00; val_higgs_mass_loss: 1.180E+01; val_loss: 6.924E+01; val_mae_loss: 3.411E+01; val_neg_r2_loss: -8.320E-01; val_nu_mass_loss: 4.584E-02; val_w0_mass_mae_loss: 1.520E+01; val_w1_mass_mae_loss: 1.836E+01; val_w_mass_mmd0_loss: 6.663E-02; val_w_mass_mmd1_loss: 6.135E-02; w0_mass_mae_loss: 1.552E+01; w1_mass_mae_loss: 1.863E+01; w_mass_mmd0_loss: 7.043E-02; w_mass_mmd1_loss: 5.634E-02
# Epoch 54; dinu_pt_loss: 1.084E+01; higgs_mass_loss: 1.168E+01; loss: 6.953E+01; mae_loss: 3.426E+01; neg_r2_loss: -8.296E-01; nu_mass_loss: 4.727E-02; val_dinu_pt_loss: 8.483E+00; val_higgs_mass_loss: 1.169E+01; val_loss: 6.922E+01; val_mae_loss: 3.412E+01; val_neg_r2_loss: -8.324E-01; val_nu_mass_loss: 4.607E-02; val_w0_mass_mae_loss: 1.528E+01; val_w1_mass_mae_loss: 1.832E+01; val_w_mass_mmd0_loss: 6.235E-02; val_w_mass_mmd1_loss: 5.968E-02; w0_mass_mae_loss: 1.550E+01; w1_mass_mae_loss: 1.869E+01; w_mass_mmd0_loss: 7.074E-02; w_mass_mmd1_loss: 5.567E-02
# Epoch 55; dinu_pt_loss: 1.077E+01; higgs_mass_loss: 1.159E+01; loss: 6.948E+01; mae_loss: 3.424E+01; neg_r2_loss: -8.299E-01; nu_mass_loss: 4.716E-02; val_dinu_pt_loss: 8.024E+00; val_higgs_mass_loss: 1.188E+01; val_loss: 6.922E+01; val_mae_loss: 3.409E+01; val_neg_r2_loss: -8.333E-01; val_nu_mass_loss: 4.682E-02; val_w0_mass_mae_loss: 1.523E+01; val_w1_mass_mae_loss: 1.839E+01; val_w_mass_mmd0_loss: 7.039E-02; val_w_mass_mmd1_loss: 5.920E-02; w0_mass_mae_loss: 1.548E+01; w1_mass_mae_loss: 1.873E+01; w_mass_mmd0_loss: 7.010E-02; w_mass_mmd1_loss: 5.507E-02
# Epoch 56; dinu_pt_loss: 1.079E+01; higgs_mass_loss: 1.164E+01; loss: 6.943E+01; mae_loss: 3.421E+01; neg_r2_loss: -8.303E-01; nu_mass_loss: 4.723E-02; val_dinu_pt_loss: 8.028E+00; val_higgs_mass_loss: 1.180E+01; val_loss: 6.950E+01; val_mae_loss: 3.402E+01; val_neg_r2_loss: -8.332E-01; val_nu_mass_loss: 4.638E-02; val_w0_mass_mae_loss: 1.509E+01; val_w1_mass_mae_loss: 1.843E+01; val_w_mass_mmd0_loss: 1.238E-01; val_w_mass_mmd1_loss: 5.861E-02; w0_mass_mae_loss: 1.547E+01; w1_mass_mae_loss: 1.875E+01; w_mass_mmd0_loss: 7.136E-02; w_mass_mmd1_loss: 5.438E-02
# Epoch 57; dinu_pt_loss: 1.082E+01; higgs_mass_loss: 1.155E+01; loss: 6.938E+01; mae_loss: 3.419E+01; neg_r2_loss: -8.304E-01; nu_mass_loss: 4.730E-02; val_dinu_pt_loss: 8.071E+00; val_higgs_mass_loss: 1.196E+01; val_loss: 6.927E+01; val_mae_loss: 3.401E+01; val_neg_r2_loss: -8.343E-01; val_nu_mass_loss: 4.685E-02; val_w0_mass_mae_loss: 1.510E+01; val_w1_mass_mae_loss: 1.847E+01; val_w_mass_mmd0_loss: 9.860E-02; val_w_mass_mmd1_loss: 5.795E-02; w0_mass_mae_loss: 1.545E+01; w1_mass_mae_loss: 1.874E+01; w_mass_mmd0_loss: 7.053E-02; w_mass_mmd1_loss: 5.379E-02
# Epoch 58; dinu_pt_loss: 1.076E+01; higgs_mass_loss: 1.156E+01; loss: 6.931E+01; mae_loss: 3.417E+01; neg_r2_loss: -8.308E-01; nu_mass_loss: 4.744E-02; val_dinu_pt_loss: 8.053E+00; val_higgs_mass_loss: 1.178E+01; val_loss: 6.938E+01; val_mae_loss: 3.403E+01; val_neg_r2_loss: -8.346E-01; val_nu_mass_loss: 4.710E-02; val_w0_mass_mae_loss: 1.516E+01; val_w1_mass_mae_loss: 1.818E+01; val_w_mass_mmd0_loss: 1.056E-01; val_w_mass_mmd1_loss: 5.937E-02; w0_mass_mae_loss: 1.545E+01; w1_mass_mae_loss: 1.874E+01; w_mass_mmd0_loss: 6.912E-02; w_mass_mmd1_loss: 5.315E-02
# Epoch 59; dinu_pt_loss: 1.069E+01; higgs_mass_loss: 1.148E+01; loss: 6.928E+01; mae_loss: 3.415E+01; neg_r2_loss: -8.310E-01; nu_mass_loss: 4.739E-02; val_dinu_pt_loss: 8.071E+00; val_higgs_mass_loss: 1.172E+01; val_loss: 6.919E+01; val_mae_loss: 3.395E+01; val_neg_r2_loss: -8.346E-01; val_nu_mass_loss: 4.694E-02; val_w0_mass_mae_loss: 1.509E+01; val_w1_mass_mae_loss: 1.832E+01; val_w_mass_mmd0_loss: 1.021E-01; val_w_mass_mmd1_loss: 5.830E-02; w0_mass_mae_loss: 1.544E+01; w1_mass_mae_loss: 1.872E+01; w_mass_mmd0_loss: 6.992E-02; w_mass_mmd1_loss: 5.292E-02
# Epoch 60; dinu_pt_loss: 1.074E+01; higgs_mass_loss: 1.157E+01; loss: 6.921E+01; mae_loss: 3.412E+01; neg_r2_loss: -8.312E-01; nu_mass_loss: 4.739E-02; val_dinu_pt_loss: 8.173E+00; val_higgs_mass_loss: 1.165E+01; val_loss: 6.908E+01; val_mae_loss: 3.395E+01; val_neg_r2_loss: -8.340E-01; val_nu_mass_loss: 4.645E-02; val_w0_mass_mae_loss: 1.507E+01; val_w1_mass_mae_loss: 1.836E+01; val_w_mass_mmd0_loss: 8.777E-02; val_w_mass_mmd1_loss: 5.847E-02; w0_mass_mae_loss: 1.542E+01; w1_mass_mae_loss: 1.881E+01; w_mass_mmd0_loss: 6.848E-02; w_mass_mmd1_loss: 5.227E-02
# Epoch 61; dinu_pt_loss: 1.070E+01; higgs_mass_loss: 1.162E+01; loss: 6.917E+01; mae_loss: 3.410E+01; neg_r2_loss: -8.313E-01; nu_mass_loss: 4.744E-02; val_dinu_pt_loss: 7.864E+00; val_higgs_mass_loss: 1.173E+01; val_loss: 6.886E+01; val_mae_loss: 3.394E+01; val_neg_r2_loss: -8.346E-01; val_nu_mass_loss: 4.682E-02; val_w0_mass_mae_loss: 1.512E+01; val_w1_mass_mae_loss: 1.857E+01; val_w_mass_mmd0_loss: 6.642E-02; val_w_mass_mmd1_loss: 5.689E-02; w0_mass_mae_loss: 1.542E+01; w1_mass_mae_loss: 1.885E+01; w_mass_mmd0_loss: 6.848E-02; w_mass_mmd1_loss: 5.208E-02
# Epoch 62; dinu_pt_loss: 1.077E+01; higgs_mass_loss: 1.147E+01; loss: 6.913E+01; mae_loss: 3.409E+01; neg_r2_loss: -8.316E-01; nu_mass_loss: 4.749E-02; val_dinu_pt_loss: 7.869E+00; val_higgs_mass_loss: 1.162E+01; val_loss: 6.903E+01; val_mae_loss: 3.395E+01; val_neg_r2_loss: -8.348E-01; val_nu_mass_loss: 4.714E-02; val_w0_mass_mae_loss: 1.509E+01; val_w1_mass_mae_loss: 1.847E+01; val_w_mass_mmd0_loss: 8.518E-02; val_w_mass_mmd1_loss: 5.521E-02; w0_mass_mae_loss: 1.541E+01; w1_mass_mae_loss: 1.877E+01; w_mass_mmd0_loss: 6.801E-02; w_mass_mmd1_loss: 5.161E-02
# Epoch 63; dinu_pt_loss: 1.068E+01; higgs_mass_loss: 1.145E+01; loss: 6.908E+01; mae_loss: 3.407E+01; neg_r2_loss: -8.318E-01; nu_mass_loss: 4.754E-02; val_dinu_pt_loss: 7.962E+00; val_higgs_mass_loss: 1.165E+01; val_loss: 6.878E+01; val_mae_loss: 3.393E+01; val_neg_r2_loss: -8.348E-01; val_nu_mass_loss: 4.711E-02; val_w0_mass_mae_loss: 1.508E+01; val_w1_mass_mae_loss: 1.845E+01; val_w_mass_mmd0_loss: 5.856E-02; val_w_mass_mmd1_loss: 5.555E-02; w0_mass_mae_loss: 1.540E+01; w1_mass_mae_loss: 1.875E+01; w_mass_mmd0_loss: 6.835E-02; w_mass_mmd1_loss: 5.072E-02
# Epoch 64; dinu_pt_loss: 1.062E+01; higgs_mass_loss: 1.148E+01; loss: 6.905E+01; mae_loss: 3.405E+01; neg_r2_loss: -8.319E-01; nu_mass_loss: 4.754E-02; val_dinu_pt_loss: 7.781E+00; val_higgs_mass_loss: 1.191E+01; val_loss: 6.905E+01; val_mae_loss: 3.388E+01; val_neg_r2_loss: -8.352E-01; val_nu_mass_loss: 4.727E-02; val_w0_mass_mae_loss: 1.507E+01; val_w1_mass_mae_loss: 1.859E+01; val_w_mass_mmd0_loss: 1.048E-01; val_w_mass_mmd1_loss: 5.536E-02; w0_mass_mae_loss: 1.539E+01; w1_mass_mae_loss: 1.883E+01; w_mass_mmd0_loss: 6.770E-02; w_mass_mmd1_loss: 5.061E-02
# Epoch 65; dinu_pt_loss: 1.069E+01; higgs_mass_loss: 1.141E+01; loss: 6.900E+01; mae_loss: 3.403E+01; neg_r2_loss: -8.321E-01; nu_mass_loss: 4.754E-02; val_dinu_pt_loss: 7.904E+00; val_higgs_mass_loss: 1.168E+01; val_loss: 6.913E+01; val_mae_loss: 3.389E+01; val_neg_r2_loss: -8.357E-01; val_nu_mass_loss: 4.714E-02; val_w0_mass_mae_loss: 1.499E+01; val_w1_mass_mae_loss: 1.856E+01; val_w_mass_mmd0_loss: 1.127E-01; val_w_mass_mmd1_loss: 5.534E-02; w0_mass_mae_loss: 1.536E+01; w1_mass_mae_loss: 1.882E+01; w_mass_mmd0_loss: 6.805E-02; w_mass_mmd1_loss: 5.037E-02
# Epoch 66; dinu_pt_loss: 1.070E+01; higgs_mass_loss: 1.135E+01; loss: 6.895E+01; mae_loss: 3.401E+01; neg_r2_loss: -8.323E-01; nu_mass_loss: 4.762E-02; val_dinu_pt_loss: 8.054E+00; val_higgs_mass_loss: 1.191E+01; val_loss: 6.900E+01; val_mae_loss: 3.394E+01; val_neg_r2_loss: -8.343E-01; val_nu_mass_loss: 4.674E-02; val_w0_mass_mae_loss: 1.506E+01; val_w1_mass_mae_loss: 1.891E+01; val_w_mass_mmd0_loss: 8.847E-02; val_w_mass_mmd1_loss: 5.158E-02; w0_mass_mae_loss: 1.535E+01; w1_mass_mae_loss: 1.877E+01; w_mass_mmd0_loss: 6.656E-02; w_mass_mmd1_loss: 4.986E-02
# Epoch 67; dinu_pt_loss: 1.068E+01; higgs_mass_loss: 1.144E+01; loss: 6.891E+01; mae_loss: 3.400E+01; neg_r2_loss: -8.324E-01; nu_mass_loss: 4.756E-02; val_dinu_pt_loss: 8.146E+00; val_higgs_mass_loss: 1.169E+01; val_loss: 6.869E+01; val_mae_loss: 3.387E+01; val_neg_r2_loss: -8.354E-01; val_nu_mass_loss: 4.679E-02; val_w0_mass_mae_loss: 1.510E+01; val_w1_mass_mae_loss: 1.867E+01; val_w_mass_mmd0_loss: 6.621E-02; val_w_mass_mmd1_loss: 5.208E-02; w0_mass_mae_loss: 1.534E+01; w1_mass_mae_loss: 1.887E+01; w_mass_mmd0_loss: 6.583E-02; w_mass_mmd1_loss: 4.928E-02
# Epoch 68; dinu_pt_loss: 1.060E+01; higgs_mass_loss: 1.143E+01; loss: 6.887E+01; mae_loss: 3.398E+01; neg_r2_loss: -8.327E-01; nu_mass_loss: 4.766E-02; val_dinu_pt_loss: 8.268E+00; val_higgs_mass_loss: 1.135E+01; val_loss: 6.875E+01; val_mae_loss: 3.384E+01; val_neg_r2_loss: -8.357E-01; val_nu_mass_loss: 4.731E-02; val_w0_mass_mae_loss: 1.496E+01; val_w1_mass_mae_loss: 1.838E+01; val_w_mass_mmd0_loss: 8.290E-02; val_w_mass_mmd1_loss: 5.224E-02; w0_mass_mae_loss: 1.536E+01; w1_mass_mae_loss: 1.883E+01; w_mass_mmd0_loss: 6.580E-02; w_mass_mmd1_loss: 4.934E-02
# Epoch 69; dinu_pt_loss: 1.060E+01; higgs_mass_loss: 1.138E+01; loss: 6.885E+01; mae_loss: 3.396E+01; neg_r2_loss: -8.326E-01; nu_mass_loss: 4.767E-02; val_dinu_pt_loss: 8.023E+00; val_higgs_mass_loss: 1.160E+01; val_loss: 6.888E+01; val_mae_loss: 3.393E+01; val_neg_r2_loss: -8.351E-01; val_nu_mass_loss: 4.693E-02; val_w0_mass_mae_loss: 1.510E+01; val_w1_mass_mae_loss: 1.852E+01; val_w_mass_mmd0_loss: 7.278E-02; val_w_mass_mmd1_loss: 5.371E-02; w0_mass_mae_loss: 1.533E+01; w1_mass_mae_loss: 1.880E+01; w_mass_mmd0_loss: 6.538E-02; w_mass_mmd1_loss: 4.919E-02
# Epoch 70; dinu_pt_loss: 1.057E+01; higgs_mass_loss: 1.139E+01; loss: 6.881E+01; mae_loss: 3.395E+01; neg_r2_loss: -8.328E-01; nu_mass_loss: 4.769E-02; val_dinu_pt_loss: 7.536E+00; val_higgs_mass_loss: 1.163E+01; val_loss: 6.912E+01; val_mae_loss: 3.382E+01; val_neg_r2_loss: -8.358E-01; val_nu_mass_loss: 4.719E-02; val_w0_mass_mae_loss: 1.498E+01; val_w1_mass_mae_loss: 1.848E+01; val_w_mass_mmd0_loss: 1.309E-01; val_w_mass_mmd1_loss: 5.230E-02; w0_mass_mae_loss: 1.533E+01; w1_mass_mae_loss: 1.883E+01; w_mass_mmd0_loss: 6.457E-02; w_mass_mmd1_loss: 4.910E-02
# Epoch 71; dinu_pt_loss: 1.055E+01; higgs_mass_loss: 1.129E+01; loss: 6.875E+01; mae_loss: 3.392E+01; neg_r2_loss: -8.331E-01; nu_mass_loss: 4.770E-02; val_dinu_pt_loss: 8.065E+00; val_higgs_mass_loss: 1.157E+01; val_loss: 6.862E+01; val_mae_loss: 3.383E+01; val_neg_r2_loss: -8.367E-01; val_nu_mass_loss: 4.731E-02; val_w0_mass_mae_loss: 1.507E+01; val_w1_mass_mae_loss: 1.856E+01; val_w_mass_mmd0_loss: 6.962E-02; val_w_mass_mmd1_loss: 5.116E-02; w0_mass_mae_loss: 1.534E+01; w1_mass_mae_loss: 1.880E+01; w_mass_mmd0_loss: 6.452E-02; w_mass_mmd1_loss: 4.815E-02
# Epoch 72; dinu_pt_loss: 1.059E+01; higgs_mass_loss: 1.126E+01; loss: 6.872E+01; mae_loss: 3.391E+01; neg_r2_loss: -8.332E-01; nu_mass_loss: 4.768E-02; val_dinu_pt_loss: 7.674E+00; val_higgs_mass_loss: 1.173E+01; val_loss: 6.886E+01; val_mae_loss: 3.383E+01; val_neg_r2_loss: -8.354E-01; val_nu_mass_loss: 4.714E-02; val_w0_mass_mae_loss: 1.504E+01; val_w1_mass_mae_loss: 1.871E+01; val_w_mass_mmd0_loss: 9.952E-02; val_w_mass_mmd1_loss: 5.139E-02; w0_mass_mae_loss: 1.534E+01; w1_mass_mae_loss: 1.875E+01; w_mass_mmd0_loss: 6.421E-02; w_mass_mmd1_loss: 4.808E-02
# Epoch 73; dinu_pt_loss: 1.059E+01; higgs_mass_loss: 1.123E+01; loss: 6.869E+01; mae_loss: 3.390E+01; neg_r2_loss: -8.333E-01; nu_mass_loss: 4.776E-02; val_dinu_pt_loss: 7.590E+00; val_higgs_mass_loss: 1.157E+01; val_loss: 6.870E+01; val_mae_loss: 3.377E+01; val_neg_r2_loss: -8.370E-01; val_nu_mass_loss: 4.756E-02; val_w0_mass_mae_loss: 1.494E+01; val_w1_mass_mae_loss: 1.850E+01; val_w_mass_mmd0_loss: 9.098E-02; val_w_mass_mmd1_loss: 5.303E-02; w0_mass_mae_loss: 1.533E+01; w1_mass_mae_loss: 1.875E+01; w_mass_mmd0_loss: 6.372E-02; w_mass_mmd1_loss: 4.783E-02
# Epoch 74; dinu_pt_loss: 1.054E+01; higgs_mass_loss: 1.130E+01; loss: 6.865E+01; mae_loss: 3.388E+01; neg_r2_loss: -8.335E-01; nu_mass_loss: 4.771E-02; val_dinu_pt_loss: 7.660E+00; val_higgs_mass_loss: 1.187E+01; val_loss: 6.866E+01; val_mae_loss: 3.379E+01; val_neg_r2_loss: -8.356E-01; val_nu_mass_loss: 4.716E-02; val_w0_mass_mae_loss: 1.502E+01; val_w1_mass_mae_loss: 1.887E+01; val_w_mass_mmd0_loss: 8.528E-02; val_w_mass_mmd1_loss: 4.993E-02; w0_mass_mae_loss: 1.532E+01; w1_mass_mae_loss: 1.883E+01; w_mass_mmd0_loss: 6.340E-02; w_mass_mmd1_loss: 4.734E-02
# Epoch 75; dinu_pt_loss: 1.048E+01; higgs_mass_loss: 1.137E+01; loss: 6.863E+01; mae_loss: 3.387E+01; neg_r2_loss: -8.335E-01; nu_mass_loss: 4.774E-02; val_dinu_pt_loss: 7.532E+00; val_higgs_mass_loss: 1.148E+01; val_loss: 6.880E+01; val_mae_loss: 3.376E+01; val_neg_r2_loss: -8.365E-01; val_nu_mass_loss: 4.709E-02; val_w0_mass_mae_loss: 1.498E+01; val_w1_mass_mae_loss: 1.846E+01; val_w_mass_mmd0_loss: 1.088E-01; val_w_mass_mmd1_loss: 5.076E-02; w0_mass_mae_loss: 1.533E+01; w1_mass_mae_loss: 1.891E+01; w_mass_mmd0_loss: 6.345E-02; w_mass_mmd1_loss: 4.721E-02
# Epoch 76; dinu_pt_loss: 1.056E+01; higgs_mass_loss: 1.119E+01; loss: 6.860E+01; mae_loss: 3.386E+01; neg_r2_loss: -8.336E-01; nu_mass_loss: 4.778E-02; val_dinu_pt_loss: 8.050E+00; val_higgs_mass_loss: 1.142E+01; val_loss: 6.855E+01; val_mae_loss: 3.376E+01; val_neg_r2_loss: -8.367E-01; val_nu_mass_loss: 4.694E-02; val_w0_mass_mae_loss: 1.500E+01; val_w1_mass_mae_loss: 1.860E+01; val_w_mass_mmd0_loss: 7.996E-02; val_w_mass_mmd1_loss: 5.011E-02; w0_mass_mae_loss: 1.531E+01; w1_mass_mae_loss: 1.880E+01; w_mass_mmd0_loss: 6.334E-02; w_mass_mmd1_loss: 4.711E-02
# Epoch 77; dinu_pt_loss: 1.048E+01; higgs_mass_loss: 1.136E+01; loss: 6.856E+01; mae_loss: 3.384E+01; neg_r2_loss: -8.337E-01; nu_mass_loss: 4.775E-02; val_dinu_pt_loss: 7.853E+00; val_higgs_mass_loss: 1.182E+01; val_loss: 6.875E+01; val_mae_loss: 3.376E+01; val_neg_r2_loss: -8.369E-01; val_nu_mass_loss: 4.747E-02; val_w0_mass_mae_loss: 1.499E+01; val_w1_mass_mae_loss: 1.881E+01; val_w_mass_mmd0_loss: 1.019E-01; val_w_mass_mmd1_loss: 5.030E-02; w0_mass_mae_loss: 1.530E+01; w1_mass_mae_loss: 1.890E+01; w_mass_mmd0_loss: 6.205E-02; w_mass_mmd1_loss: 4.713E-02
# Epoch 78; dinu_pt_loss: 1.050E+01; higgs_mass_loss: 1.121E+01; loss: 6.855E+01; mae_loss: 3.384E+01; neg_r2_loss: -8.338E-01; nu_mass_loss: 4.785E-02; val_dinu_pt_loss: 7.894E+00; val_higgs_mass_loss: 1.153E+01; val_loss: 6.856E+01; val_mae_loss: 3.381E+01; val_neg_r2_loss: -8.359E-01; val_nu_mass_loss: 4.738E-02; val_w0_mass_mae_loss: 1.502E+01; val_w1_mass_mae_loss: 1.877E+01; val_w_mass_mmd0_loss: 6.854E-02; val_w_mass_mmd1_loss: 4.851E-02; w0_mass_mae_loss: 1.530E+01; w1_mass_mae_loss: 1.881E+01; w_mass_mmd0_loss: 6.280E-02; w_mass_mmd1_loss: 4.668E-02
# Epoch 79; dinu_pt_loss: 1.045E+01; higgs_mass_loss: 1.129E+01; loss: 6.851E+01; mae_loss: 3.382E+01; neg_r2_loss: -8.341E-01; nu_mass_loss: 4.780E-02; val_dinu_pt_loss: 7.831E+00; val_higgs_mass_loss: 1.165E+01; val_loss: 6.861E+01; val_mae_loss: 3.377E+01; val_neg_r2_loss: -8.371E-01; val_nu_mass_loss: 4.766E-02; val_w0_mass_mae_loss: 1.503E+01; val_w1_mass_mae_loss: 1.860E+01; val_w_mass_mmd0_loss: 8.464E-02; val_w_mass_mmd1_loss: 4.925E-02; w0_mass_mae_loss: 1.530E+01; w1_mass_mae_loss: 1.885E+01; w_mass_mmd0_loss: 6.246E-02; w_mass_mmd1_loss: 4.638E-02
# Epoch 80; dinu_pt_loss: 1.052E+01; higgs_mass_loss: 1.135E+01; loss: 6.848E+01; mae_loss: 3.381E+01; neg_r2_loss: -8.341E-01; nu_mass_loss: 4.778E-02; val_dinu_pt_loss: 8.023E+00; val_higgs_mass_loss: 1.166E+01; val_loss: 6.891E+01; val_mae_loss: 3.382E+01; val_neg_r2_loss: -8.365E-01; val_nu_mass_loss: 4.741E-02; val_w0_mass_mae_loss: 1.503E+01; val_w1_mass_mae_loss: 1.865E+01; val_w_mass_mmd0_loss: 1.112E-01; val_w_mass_mmd1_loss: 4.788E-02; w0_mass_mae_loss: 1.531E+01; w1_mass_mae_loss: 1.890E+01; w_mass_mmd0_loss: 6.113E-02; w_mass_mmd1_loss: 4.608E-02
# Epoch 81; dinu_pt_loss: 1.041E+01; higgs_mass_loss: 1.130E+01; loss: 6.845E+01; mae_loss: 3.380E+01; neg_r2_loss: -8.342E-01; nu_mass_loss: 4.785E-02; val_dinu_pt_loss: 7.541E+00; val_higgs_mass_loss: 1.223E+01; val_loss: 6.903E+01; val_mae_loss: 3.375E+01; val_neg_r2_loss: -8.368E-01; val_nu_mass_loss: 4.745E-02; val_w0_mass_mae_loss: 1.499E+01; val_w1_mass_mae_loss: 1.898E+01; val_w_mass_mmd0_loss: 1.413E-01; val_w_mass_mmd1_loss: 4.913E-02; w0_mass_mae_loss: 1.529E+01; w1_mass_mae_loss: 1.886E+01; w_mass_mmd0_loss: 6.131E-02; w_mass_mmd1_loss: 4.578E-02
# Epoch 82; dinu_pt_loss: 1.045E+01; higgs_mass_loss: 1.135E+01; loss: 6.842E+01; mae_loss: 3.378E+01; neg_r2_loss: -8.342E-01; nu_mass_loss: 4.786E-02; val_dinu_pt_loss: 7.913E+00; val_higgs_mass_loss: 1.153E+01; val_loss: 6.865E+01; val_mae_loss: 3.372E+01; val_neg_r2_loss: -8.371E-01; val_nu_mass_loss: 4.724E-02; val_w0_mass_mae_loss: 1.493E+01; val_w1_mass_mae_loss: 1.857E+01; val_w_mass_mmd0_loss: 1.013E-01; val_w_mass_mmd1_loss: 4.913E-02; w0_mass_mae_loss: 1.527E+01; w1_mass_mae_loss: 1.894E+01; w_mass_mmd0_loss: 6.076E-02; w_mass_mmd1_loss: 4.553E-02
# Epoch 83; dinu_pt_loss: 1.052E+01; higgs_mass_loss: 1.123E+01; loss: 6.840E+01; mae_loss: 3.377E+01; neg_r2_loss: -8.345E-01; nu_mass_loss: 4.785E-02; val_dinu_pt_loss: 7.910E+00; val_higgs_mass_loss: 1.159E+01; val_loss: 6.845E+01; val_mae_loss: 3.374E+01; val_neg_r2_loss: -8.366E-01; val_nu_mass_loss: 4.717E-02; val_w0_mass_mae_loss: 1.505E+01; val_w1_mass_mae_loss: 1.868E+01; val_w_mass_mmd0_loss: 7.394E-02; val_w_mass_mmd1_loss: 4.819E-02; w0_mass_mae_loss: 1.528E+01; w1_mass_mae_loss: 1.887E+01; w_mass_mmd0_loss: 6.289E-02; w_mass_mmd1_loss: 4.540E-02
# Epoch 84; dinu_pt_loss: 1.040E+01; higgs_mass_loss: 1.138E+01; loss: 6.837E+01; mae_loss: 3.376E+01; neg_r2_loss: -8.347E-01; nu_mass_loss: 4.782E-02; val_dinu_pt_loss: 7.896E+00; val_higgs_mass_loss: 1.163E+01; val_loss: 6.858E+01; val_mae_loss: 3.372E+01; val_neg_r2_loss: -8.375E-01; val_nu_mass_loss: 4.743E-02; val_w0_mass_mae_loss: 1.495E+01; val_w1_mass_mae_loss: 1.869E+01; val_w_mass_mmd0_loss: 9.334E-02; val_w_mass_mmd1_loss: 4.853E-02; w0_mass_mae_loss: 1.528E+01; w1_mass_mae_loss: 1.895E+01; w_mass_mmd0_loss: 6.136E-02; w_mass_mmd1_loss: 4.543E-02
# Epoch 85; dinu_pt_loss: 1.044E+01; higgs_mass_loss: 1.141E+01; loss: 6.835E+01; mae_loss: 3.375E+01; neg_r2_loss: -8.346E-01; nu_mass_loss: 4.785E-02; val_dinu_pt_loss: 7.694E+00; val_higgs_mass_loss: 1.137E+01; val_loss: 6.853E+01; val_mae_loss: 3.372E+01; val_neg_r2_loss: -8.377E-01; val_nu_mass_loss: 4.777E-02; val_w0_mass_mae_loss: 1.496E+01; val_w1_mass_mae_loss: 1.851E+01; val_w_mass_mmd0_loss: 8.765E-02; val_w_mass_mmd1_loss: 4.851E-02; w0_mass_mae_loss: 1.526E+01; w1_mass_mae_loss: 1.899E+01; w_mass_mmd0_loss: 6.031E-02; w_mass_mmd1_loss: 4.507E-02
# Epoch 86; dinu_pt_loss: 1.038E+01; higgs_mass_loss: 1.130E+01; loss: 6.831E+01; mae_loss: 3.373E+01; neg_r2_loss: -8.348E-01; nu_mass_loss: 4.789E-02; val_dinu_pt_loss: 7.632E+00; val_higgs_mass_loss: 1.126E+01; val_loss: 6.846E+01; val_mae_loss: 3.372E+01; val_neg_r2_loss: -8.365E-01; val_nu_mass_loss: 4.747E-02; val_w0_mass_mae_loss: 1.496E+01; val_w1_mass_mae_loss: 1.847E+01; val_w_mass_mmd0_loss: 7.647E-02; val_w_mass_mmd1_loss: 4.973E-02; w0_mass_mae_loss: 1.527E+01; w1_mass_mae_loss: 1.888E+01; w_mass_mmd0_loss: 5.957E-02; w_mass_mmd1_loss: 4.489E-02
# Epoch 87; dinu_pt_loss: 1.036E+01; higgs_mass_loss: 1.124E+01; loss: 6.828E+01; mae_loss: 3.372E+01; neg_r2_loss: -8.348E-01; nu_mass_loss: 4.783E-02; val_dinu_pt_loss: 7.722E+00; val_higgs_mass_loss: 1.164E+01; val_loss: 6.852E+01; val_mae_loss: 3.372E+01; val_neg_r2_loss: -8.369E-01; val_nu_mass_loss: 4.725E-02; val_w0_mass_mae_loss: 1.497E+01; val_w1_mass_mae_loss: 1.872E+01; val_w_mass_mmd0_loss: 8.883E-02; val_w_mass_mmd1_loss: 4.715E-02; w0_mass_mae_loss: 1.527E+01; w1_mass_mae_loss: 1.888E+01; w_mass_mmd0_loss: 5.954E-02; w_mass_mmd1_loss: 4.484E-02
# Epoch 88; dinu_pt_loss: 1.040E+01; higgs_mass_loss: 1.127E+01; loss: 6.826E+01; mae_loss: 3.371E+01; neg_r2_loss: -8.351E-01; nu_mass_loss: 4.782E-02; val_dinu_pt_loss: 7.643E+00; val_higgs_mass_loss: 1.128E+01; val_loss: 6.877E+01; val_mae_loss: 3.373E+01; val_neg_r2_loss: -8.371E-01; val_nu_mass_loss: 4.756E-02; val_w0_mass_mae_loss: 1.499E+01; val_w1_mass_mae_loss: 1.834E+01; val_w_mass_mmd0_loss: 1.156E-01; val_w_mass_mmd1_loss: 4.876E-02; w0_mass_mae_loss: 1.528E+01; w1_mass_mae_loss: 1.888E+01; w_mass_mmd0_loss: 5.971E-02; w_mass_mmd1_loss: 4.476E-02
# Epoch 89; dinu_pt_loss: 1.041E+01; higgs_mass_loss: 1.130E+01; loss: 6.823E+01; mae_loss: 3.370E+01; neg_r2_loss: -8.351E-01; nu_mass_loss: 4.785E-02; val_dinu_pt_loss: 7.692E+00; val_higgs_mass_loss: 1.179E+01; val_loss: 6.862E+01; val_mae_loss: 3.370E+01; val_neg_r2_loss: -8.367E-01; val_nu_mass_loss: 4.711E-02; val_w0_mass_mae_loss: 1.499E+01; val_w1_mass_mae_loss: 1.889E+01; val_w_mass_mmd0_loss: 1.053E-01; val_w_mass_mmd1_loss: 4.813E-02; w0_mass_mae_loss: 1.529E+01; w1_mass_mae_loss: 1.895E+01; w_mass_mmd0_loss: 5.857E-02; w_mass_mmd1_loss: 4.456E-02
# Epoch 90; dinu_pt_loss: 1.040E+01; higgs_mass_loss: 1.121E+01; loss: 6.820E+01; mae_loss: 3.369E+01; neg_r2_loss: -8.353E-01; nu_mass_loss: 4.797E-02; val_dinu_pt_loss: 8.003E+00; val_higgs_mass_loss: 1.116E+01; val_loss: 6.857E+01; val_mae_loss: 3.374E+01; val_neg_r2_loss: -8.367E-01; val_nu_mass_loss: 4.759E-02; val_w0_mass_mae_loss: 1.496E+01; val_w1_mass_mae_loss: 1.845E+01; val_w_mass_mmd0_loss: 8.957E-02; val_w_mass_mmd1_loss: 4.737E-02; w0_mass_mae_loss: 1.525E+01; w1_mass_mae_loss: 1.887E+01; w_mass_mmd0_loss: 5.920E-02; w_mass_mmd1_loss: 4.451E-02
# Epoch 91; dinu_pt_loss: 1.040E+01; higgs_mass_loss: 1.112E+01; loss: 6.818E+01; mae_loss: 3.368E+01; neg_r2_loss: -8.353E-01; nu_mass_loss: 4.789E-02; val_dinu_pt_loss: 7.652E+00; val_higgs_mass_loss: 1.161E+01; val_loss: 6.875E+01; val_mae_loss: 3.371E+01; val_neg_r2_loss: -8.368E-01; val_nu_mass_loss: 4.723E-02; val_w0_mass_mae_loss: 1.497E+01; val_w1_mass_mae_loss: 1.880E+01; val_w_mass_mmd0_loss: 1.201E-01; val_w_mass_mmd1_loss: 4.599E-02; w0_mass_mae_loss: 1.527E+01; w1_mass_mae_loss: 1.880E+01; w_mass_mmd0_loss: 5.852E-02; w_mass_mmd1_loss: 4.430E-02
# Epoch 92; dinu_pt_loss: 1.039E+01; higgs_mass_loss: 1.132E+01; loss: 6.814E+01; mae_loss: 3.366E+01; neg_r2_loss: -8.356E-01; nu_mass_loss: 4.792E-02; val_dinu_pt_loss: 7.725E+00; val_higgs_mass_loss: 1.168E+01; val_loss: 6.871E+01; val_mae_loss: 3.371E+01; val_neg_r2_loss: -8.369E-01; val_nu_mass_loss: 4.741E-02; val_w0_mass_mae_loss: 1.502E+01; val_w1_mass_mae_loss: 1.864E+01; val_w_mass_mmd0_loss: 1.139E-01; val_w_mass_mmd1_loss: 4.706E-02; w0_mass_mae_loss: 1.527E+01; w1_mass_mae_loss: 1.897E+01; w_mass_mmd0_loss: 5.779E-02; w_mass_mmd1_loss: 4.389E-02
# Epoch 93; dinu_pt_loss: 1.036E+01; higgs_mass_loss: 1.125E+01; loss: 6.813E+01; mae_loss: 3.365E+01; neg_r2_loss: -8.356E-01; nu_mass_loss: 4.795E-02; val_dinu_pt_loss: 7.641E+00; val_higgs_mass_loss: 1.155E+01; val_loss: 6.875E+01; val_mae_loss: 3.369E+01; val_neg_r2_loss: -8.370E-01; val_nu_mass_loss: 4.741E-02; val_w0_mass_mae_loss: 1.494E+01; val_w1_mass_mae_loss: 1.869E+01; val_w_mass_mmd0_loss: 1.230E-01; val_w_mass_mmd1_loss: 4.707E-02; w0_mass_mae_loss: 1.526E+01; w1_mass_mae_loss: 1.894E+01; w_mass_mmd0_loss: 5.857E-02; w_mass_mmd1_loss: 4.436E-02
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752040420.012713  137964 service.cc:145] XLA service 0x701f08073250 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752040420.012738  137964 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752040429.698699  138217 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_15', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1752040429.774049  138209 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752040429.780926  138200 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752040430.045385  138203 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1752040430.304029  138216 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1752040439.695369  137964 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_29', 8 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1752040439.713766  137964 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# I0000 00:00:1752040452.588570  138785 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 12 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1752040453.063092  138798 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_18', 24 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1752040453.080212  138800 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 128 bytes spill stores, 128 bytes spill loads
#
# I0000 00:00:1752040453.117316  138793 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1752040460.516649  137965 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_31', 8 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1752040463.491155  139614 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_10', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752040463.589881  139613 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_10', 24 bytes spill stores, 24 bytes spill loads

# %%
pred_y = model.predict(test_x)
# Out:
# 2189/2189 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# I0000 00:00:1752041264.234051  182680 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752041266.844899  182826 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 8 bytes spill stores, 8 bytes spill loads

# %%
label_lead_w_px = test_y[:, 0]
label_lead_w_py = test_y[:, 1]
label_lead_w_pz = test_y[:, 2]
label_lead_w_energy = test_y[:, 3]
label_sublead_w_px = test_y[:, 4]
label_sublead_w_py = test_y[:, 5]
label_sublead_w_pz = test_y[:, 6]
label_sublead_w_energy = test_y[:, 7]

pred_lead_w_px = pred_y[:, 0]
pred_lead_w_py = pred_y[:, 1]
pred_lead_w_pz = pred_y[:, 2]
pred_lead_w_energy = pred_y[:, 3]
pred_sublead_w_px = pred_y[:, 4]
pred_sublead_w_py = pred_y[:, 5]
pred_sublead_w_pz = pred_y[:, 6]
pred_sublead_w_energy = pred_y[:, 7]

# %%
# px

# lead
plt.hist(label_lead_w_px, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_px, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_0}_{x}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_px,
	pred_lead_w_px,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_0}_{x}$", loc='right')
plt.show()

# sublead px
plt.hist(label_sublead_w_px, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_px, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_1}_{x}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_px,
	pred_sublead_w_px,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_1}_{x}$", loc='right')
plt.show()

# %%
# py

# lead
plt.hist(label_lead_w_py, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_py, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_0}_{y}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_py,
	pred_lead_w_py,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_0}_{y}$", loc='right')
plt.show()

# sublead py
plt.hist(label_sublead_w_py, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_py, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_1}_{y}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_py,
	pred_sublead_w_py,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_1}_{y}$", loc='right')
plt.show()

# %%
# pz

# lead
plt.hist(label_lead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_0}_{z}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_pz,
	pred_lead_w_pz,
	bins=(51, 51),
	range=([-1000, 1000], [-1000, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_0}_{z}$", loc='right')
plt.show()

# sublead pz
plt.hist(label_sublead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_1}_{z}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_pz,
	pred_sublead_w_pz,
	bins=(51, 51),
	range=([-1000, 1000], [-1000, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_1}_{z}$", loc='right')
plt.show()

# %%
# energy

# lead
plt.hist(label_lead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$E^{\ell_0}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_energy,
	pred_lead_w_energy,
	bins=(51, 51),
	range=([0, 1000], [0, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$E^{\ell_0}$", loc='right')
plt.show()

# sublead energy
plt.hist(label_sublead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$E^{\ell_1}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_energy,
	pred_sublead_w_energy,
	bins=(51, 51),
	range=([0, 1000], [0, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$E^{\ell_1}$", loc='right')
plt.show()

# %%
# W inv mass

w_lead_pred = np.sqrt(
	np.square(pred_lead_w_energy)
	- np.square(pred_lead_w_px)
	- np.square(pred_lead_w_py)
	- np.square(pred_lead_w_pz)
)
w_sublead_pred = np.sqrt(
	np.square(pred_sublead_w_energy)
	- np.square(pred_sublead_w_px)
	- np.square(pred_sublead_w_py)
	- np.square(pred_sublead_w_pz)
)
w_lead_label = np.sqrt(
	np.square(label_lead_w_energy)
	- np.square(label_lead_w_px)
	- np.square(label_lead_w_py)
	- np.square(label_lead_w_pz)
)
w_sublead_label = np.sqrt(
	np.square(label_sublead_w_energy)
	- np.square(label_sublead_w_px)
	- np.square(label_sublead_w_py)
	- np.square(label_sublead_w_pz)
)

plt.hist(w_lead_pred, bins=np.linspace(0, 100, 51), label=r"Pred", histtype="step", linewidth=2, color="red")
plt.hist(w_lead_label, bins=np.linspace(0, 100, 51), label=r"Label", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.xlim(0, 100)
plt.show()

plt.hist2d(
	w_lead_pred,
	w_lead_label,
	bins=(51, 51),
	range=([0, 100], [0, 100]),
	cmap="viridis",
	cmin=1,
	norm = LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel("Pred")
plt.xlabel("Label")
plt.title(r"$m_{W_0}$", loc='right')
plt.show()


plt.hist(w_sublead_pred, bins=np.linspace(0, 100, 51), label="Pred", histtype="step", linewidth=2, color="red")
plt.hist(w_sublead_label, bins=np.linspace(0, 100, 51), label="Label", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.xlim(0, 100)
plt.show()

plt.hist2d(
	w_sublead_pred,
	w_sublead_label,
	bins=(51, 51),
	range=([0, 100], [0, 100]),
	cmap="viridis",
	cmin=1,
	norm = LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel("Pred")
plt.xlabel("Label")
plt.title(r"$m_{W_1}$", loc='right')
plt.show()

# %%
# WW* inv mass
ww_pred = np.sqrt(
	np.square(pred_lead_w_energy + pred_sublead_w_energy)
	- np.square(pred_lead_w_px + pred_sublead_w_px)
	- np.square(pred_lead_w_py + pred_sublead_w_py)
	- np.square(pred_lead_w_pz + pred_sublead_w_pz)
)
ww_label = np.sqrt(
	np.square(label_lead_w_energy + label_sublead_w_energy)
	- np.square(label_lead_w_px + label_sublead_w_px)
	- np.square(label_lead_w_py + label_sublead_w_py)
	- np.square(label_lead_w_pz + label_sublead_w_pz)
)
plt.hist(ww_pred, bins=np.linspace(100, 140, 51), label="Pred", histtype="step", linewidth=2, color="red")
plt.hist(ww_label, bins=np.linspace(100, 140, 51), label="Label", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.xlim(100, 140)
plt.show()

plt.hist2d(
	ww_pred,
	ww_label,
	bins=(51, 51),
	range=([100, 140], [100, 140]),
	cmap="viridis",
	cmin=1,
	norm = LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel("Pred")
plt.xlabel("Label")
plt.title(r"$m_{WW^\ast}$", loc='right')
plt.show()
