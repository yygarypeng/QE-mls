# %%
import time
t_start = time.time()

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"  # suppress tensorflow information messages

import sys
import numpy as np
from scipy import stats
import scipy as sp
import multiprocessing
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm, Normalize
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbModelCheckpoint

HOME_PATH = os.path.abspath("/root/work/QE-mls") # path to QE_mls
sys.path.append(HOME_PATH + "/qe")
print("Home path:", HOME_PATH)

# custom modules
import paper_plot as pp
# Import the W boson regressor module
import nn
nn.BATCH_SIZE = 512
# Out:
# Home path: /root/work/QE-mls

# %%
# ROOT need to be imported after tensorflow
import ROOT
from ROOT import TLorentzVector, TVector3

# some global variables
dir_name = HOME_PATH + "/14th_trial/reg_main/ww_resregressor_result/"
plot = pp.Plotter()
WORKERS = 16

# %%
import h5py


def load_particles_from_h5(filename="mc20_truth.h5"):
    """
    Load particle data from an HDF5 file

    Args:
        filename: Path to the HDF5 file

    Returns:
        Dictionary with the loaded data
    """
    result = {}

    with h5py.File(filename, "r") as f:
        # For each group in the file
        for group_name in f.keys():
            group_data = {}

            # Load datasets (numpy arrays)
            for dataset_name in f[group_name].keys():
                group_data[dataset_name] = f[group_name][dataset_name][:]

            # Load attributes (scalars)
            for attr_name, attr_value in f[group_name].attrs.items():
                group_data[attr_name] = attr_value

            result[group_name] = group_data

    return result

# %%
mc20_data = load_particles_from_h5("/root/data/mc20_truth.h5")
mc20_data.keys()
# Out:
# dict_keys(['higgs', 'lead_w', 'sublead_w', 'truth_dilep', 'truth_dilep_car', 'truth_lead_lep', 'truth_lead_lep_car', 'truth_lead_nu', 'truth_lead_nu_car', 'truth_sublead_lep', 'truth_sublead_lep_car', 'truth_sublead_nu', 'truth_sublead_nu_car'])

# %%
# SM truth
truth_lead_lep = mc20_data["truth_lead_lep"]
truth_sublead_lep = mc20_data["truth_sublead_lep"]
truth_lead_nu = mc20_data["truth_lead_nu"]
truth_sublead_nu = mc20_data["truth_sublead_nu"]
truth_lead_lep_p4 = mc20_data["truth_lead_lep"]["p4"]
truth_sublead_lep_p4 = mc20_data["truth_sublead_lep"]["p4"]
truth_lead_nu_p4 = mc20_data["truth_lead_nu"]["p4"]
truth_sublead_nu_p4 = mc20_data["truth_sublead_nu"]["p4"]
truth_met_pt = np.sqrt(np.square((truth_lead_nu_p4 + truth_sublead_nu_p4)[...,0:2]).sum(axis=-1))

# CAR truth
truth_lead_lep_car = mc20_data["truth_lead_lep_car"]
truth_sublead_lep_car = mc20_data["truth_sublead_lep_car"]
truth_lead_nu_car = mc20_data["truth_lead_nu_car"]
truth_sublead_nu_car = mc20_data["truth_sublead_nu_car"]
truth_lead_lep_car_p4 = mc20_data["truth_lead_lep_car"]["p4"]
truth_sublead_lep_car_p4 = mc20_data["truth_sublead_lep_car"]["p4"]
truth_lead_nu_car_p4 = mc20_data["truth_lead_nu_car"]["p4"]
truth_sublead_nu_car_p4 = mc20_data["truth_sublead_nu_car"]["p4"]
truth_met_pt_car = np.sqrt(np.square((truth_lead_nu_car_p4 + truth_sublead_nu_car_p4)[...,0:2]).sum(axis=-1))

# W bosons (SM and CAR use the same W bosons data)
w_lead_p4 = mc20_data["lead_w"]["p4"]
w_sublead_p4 = mc20_data["sublead_w"]["p4"]

# %%
print("Truth: pre-cut")
cut_pre_pt_lead = truth_lead_lep["pt"] > 22
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = truth_sublead_lep["pt"] > 15
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.square(truth_lead_lep["energy"] + truth_sublead_lep["energy"])
    - np.square(truth_lead_lep["px"] + truth_sublead_lep["px"])
    - np.square(truth_lead_lep["py"] + truth_sublead_lep["py"])
    - np.square(truth_lead_lep["pz"] + truth_sublead_lep["pz"])
    > 10**2
)
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = truth_met_pt > 20
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print("Total", len(truth_lead_lep["energy"]) - np.sum(PRE_CUT * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# CAR
print("")
print("CAR: pre-cut")
cut_pre_pt_lead = truth_lead_lep_car["pt"] > 22
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = truth_sublead_lep_car["pt"] > 15
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.square(truth_lead_lep_car["energy"] + truth_sublead_lep_car["energy"])
    - np.square(truth_lead_lep_car["px"] + truth_sublead_lep_car["px"])
    - np.square(truth_lead_lep_car["py"] + truth_sublead_lep_car["py"])
    - np.square(truth_lead_lep_car["pz"] + truth_sublead_lep_car["pz"])
    > 10**2
)
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = truth_met_pt_car > 20
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT_CAR = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print("Total", len(truth_lead_lep_car["energy"]) - np.sum(PRE_CUT_CAR * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)
# Out:
# Truth: pre-cut
# 260653
# 1174171
# 148392
# 287355
# Total 1502903
#
# CAR: pre-cut
# 336735
# 1292162
# 65248
# 441435
# Total 1634918

# %%
# force to use the same cuts for both truth and CAR

PRE_CUT_INST = PRE_CUT_CAR & PRE_CUT
print("Total", np.sum(PRE_CUT_INST * 1))
# Out:
# Total 700374

# %%
# training objects
lead_lep_px = truth_lead_lep_car["px"][PRE_CUT_INST]
lead_lep_py = truth_lead_lep_car["py"][PRE_CUT_INST]
lead_lep_pz = truth_lead_lep_car["pz"][PRE_CUT_INST]
lead_lep_energy = truth_lead_lep_car["energy"][PRE_CUT_INST]
sublead_lep_px = truth_sublead_lep_car["px"][PRE_CUT_INST]
sublead_lep_py = truth_sublead_lep_car["py"][PRE_CUT_INST]
sublead_lep_pz = truth_sublead_lep_car["pz"][PRE_CUT_INST]
sublead_lep_energy = truth_sublead_lep_car["energy"][PRE_CUT_INST]
lead_nu_px = truth_lead_nu_car["px"][PRE_CUT_INST]
lead_nu_py = truth_lead_nu_car["py"][PRE_CUT_INST]
sublead_nu_px = truth_sublead_nu_car["px"][PRE_CUT_INST]
sublead_nu_py = truth_sublead_nu_car["py"][PRE_CUT_INST]
met_px = lead_nu_px + sublead_nu_px
met_py = lead_nu_py + sublead_nu_py

np.random.seed(nn.SEED)
shuffle_ind = np.random.permutation(len(lead_lep_px))

train = np.column_stack(
    (
        lead_lep_px,
        lead_lep_py,
        lead_lep_pz,
        lead_lep_energy,
        sublead_lep_px,
        sublead_lep_py,
        sublead_lep_pz,
        sublead_lep_energy,
        met_px,
        met_py,
    )
)

# train = train[shuffle_ind]
print("Training objects shape:", train.shape)
# Out:
# Training objects shape: (700374, 10)

# %%
# target objects

w_lead = mc20_data["lead_w"]
w_sublead = mc20_data["sublead_w"]
target = np.column_stack(
    (
        w_lead["px"][PRE_CUT_INST],
        w_lead["py"][PRE_CUT_INST],
        w_lead["pz"][PRE_CUT_INST],
        w_lead["energy"][PRE_CUT_INST],
        w_sublead["px"][PRE_CUT_INST],
        w_sublead["py"][PRE_CUT_INST],
        w_sublead["pz"][PRE_CUT_INST],
        w_sublead["energy"][PRE_CUT_INST],
        w_lead["m"][PRE_CUT_INST],
        w_sublead["m"][PRE_CUT_INST],
    )
)

# target = target[shuffle_ind]
print("Target objects shape:", target.shape)
# Out:
# Target objects shape: (700374, 10)

# %%
# Train-test split
if len(train) == len(target):
	indices = np.arange(len(train))
else:
	sys.exit("Error: train and targe shapes do not match!")

train_idx, temp_idx = train_test_split(
	indices, train_size=0.8, random_state=nn.SEED
)
valid_idx, test_idx = train_test_split(
	temp_idx, train_size=0.5, random_state=nn.SEED
)

train_x, valid_x, test_x = train[train_idx], train[valid_idx], train[test_idx]
train_y, valid_y, test_y = target[train_idx], target[valid_idx], target[test_idx]

print("Train shape:", train_x.shape, "Valid shape:", valid_x.shape, "Test shape:", test_x.shape)
# Out:
# Train shape: (560299, 10) Valid shape: (70037, 10) Test shape: (70038, 10)

# %%
# W&B initialization
wandb.init(
    project='PcRes regressor ll training', 
    name='New batch_size: %d' % nn.BATCH_SIZE)
config = wandb.config
config.batch_size = nn.BATCH_SIZE

# Create datasets
train_dataset = (
	tf.data.Dataset.from_tensor_slices((train_x, train_y))
	.cache()
	.batch(nn.BATCH_SIZE)
	.prefetch(tf.data.AUTOTUNE)
)
valid_dataset = (
	tf.data.Dataset.from_tensor_slices((valid_x, valid_y))
	.cache()
	.batch(nn.BATCH_SIZE)
	.prefetch(tf.data.AUTOTUNE)
)

# Build and train model
base_model = nn.build_model(input_shape=train_x.shape[-1])
model = nn.CustomModel(base_model)
model.summary()
model.compile(
	optimizer=tf.keras.optimizers.Adam(learning_rate=nn.LEARNING_RATE),
	loss_weights=nn.LOSS_WEIGHTS,
)

callbacks = [
	tf.keras.callbacks.EarlyStopping(
		monitor="val_loss", patience=10, restore_best_weights=True
	),
	nn.EpochUpdater(),
	nn.LambdaTracker(),
	WandbMetricsLogger(), 
    # WandbModelCheckpoint(
    #     "best_val_loss.weights.h5",
    #     monitor="val_loss",
    # ),
]

history = model.fit(
	train_dataset,
	validation_data=valid_dataset,
	epochs=nn.EPOCHS,
	callbacks=callbacks,
	verbose=0,
)
# Out:
# wandb: Currently logged in as: yygarypeng (nthu-expt-hep) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/root/work/QE-mls/14th_trial/reg_main/wandb/run-20250710_055413-4qd9kzek</code>
# Syncing run <strong><a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training/runs/4qd9kzek' target="_blank">New batch_size: 512</a></strong> to <a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training' target="_blank">https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training</a>
#  View run at <a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training/runs/4qd9kzek' target="_blank">https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20ll%20training/runs/4qd9kzek</a>
# Model: "custom_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional (Functional)         │ (None, 8)              │       990,822 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 990,822 (3.78 MB)
#  Trainable params: 979,238 (3.74 MB)
#  Non-trainable params: 11,584 (45.25 KB)
# Epoch 0; dinu_pt_loss: 6.189E+01; higgs_mass_loss: 5.309E+01; loss: 1.839E+02; mae_loss: 5.496E+01; neg_r2_loss: -6.476E-01; nu_mass_loss: 6.603E-03; val_dinu_pt_loss: 6.116E+01; val_higgs_mass_loss: 3.882E+01; val_loss: 1.594E+02; val_mae_loss: 5.474E+01; val_neg_r2_loss: -6.528E-01; val_nu_mass_loss: 9.439E-03; val_w0_mass_mae_loss: 3.451E+01; val_w1_mass_mae_loss: 2.183E+01; val_w_mass_mmd0_loss: 1.188E+00; val_w_mass_mmd1_loss: 1.954E-01; w0_mass_mae_loss: 4.422E+01; w1_mass_mae_loss: 2.603E+01; w_mass_mmd0_loss: 1.812E+00; w_mass_mmd1_loss: 7.964E-01
# Epoch 1; dinu_pt_loss: 6.088E+01; higgs_mass_loss: 3.043E+01; loss: 1.489E+02; mae_loss: 5.442E+01; neg_r2_loss: -6.486E-01; nu_mass_loss: 1.012E-02; val_dinu_pt_loss: 6.007E+01; val_higgs_mass_loss: 2.487E+01; val_loss: 1.412E+02; val_mae_loss: 5.419E+01; val_neg_r2_loss: -6.541E-01; val_nu_mass_loss: 1.171E-02; val_w0_mass_mae_loss: 2.723E+01; val_w1_mass_mae_loss: 1.931E+01; val_w_mass_mmd0_loss: 8.760E-01; val_w_mass_mmd1_loss: 1.170E-01; w0_mass_mae_loss: 3.026E+01; w1_mass_mae_loss: 1.979E+01; w_mass_mmd0_loss: 1.066E+00; w_mass_mmd1_loss: 1.400E-01
# Epoch 2; dinu_pt_loss: 6.008E+01; higgs_mass_loss: 1.980E+01; loss: 1.352E+02; mae_loss: 5.393E+01; neg_r2_loss: -6.498E-01; nu_mass_loss: 1.231E-02; val_dinu_pt_loss: 5.890E+01; val_higgs_mass_loss: 1.511E+01; val_loss: 1.290E+02; val_mae_loss: 5.360E+01; val_neg_r2_loss: -6.558E-01; val_nu_mass_loss: 1.397E-02; val_w0_mass_mae_loss: 2.227E+01; val_w1_mass_mae_loss: 1.860E+01; val_w_mass_mmd0_loss: 7.034E-01; val_w_mass_mmd1_loss: 1.282E-01; w0_mass_mae_loss: 2.458E+01; w1_mass_mae_loss: 1.856E+01; w_mass_mmd0_loss: 8.322E-01; w_mass_mmd1_loss: 1.171E-01
# Epoch 3; dinu_pt_loss: 5.977E+01; higgs_mass_loss: 1.230E+01; loss: 1.255E+02; mae_loss: 5.345E+01; neg_r2_loss: -6.513E-01; nu_mass_loss: 1.419E-02; val_dinu_pt_loss: 5.986E+01; val_higgs_mass_loss: 8.485E+00; val_loss: 1.208E+02; val_mae_loss: 5.325E+01; val_neg_r2_loss: -6.572E-01; val_nu_mass_loss: 1.544E-02; val_w0_mass_mae_loss: 1.957E+01; val_w1_mass_mae_loss: 1.843E+01; val_w_mass_mmd0_loss: 5.915E-01; val_w_mass_mmd1_loss: 1.373E-01; w0_mass_mae_loss: 2.074E+01; w1_mass_mae_loss: 1.835E+01; w_mass_mmd0_loss: 6.586E-01; w_mass_mmd1_loss: 1.262E-01
# Epoch 4; dinu_pt_loss: 5.913E+01; higgs_mass_loss: 7.873E+00; loss: 1.186E+02; mae_loss: 5.292E+01; neg_r2_loss: -6.534E-01; nu_mass_loss: 1.575E-02; val_dinu_pt_loss: 5.790E+01; val_higgs_mass_loss: 5.923E+00; val_loss: 1.154E+02; val_mae_loss: 5.250E+01; val_neg_r2_loss: -6.601E-01; val_nu_mass_loss: 1.661E-02; val_w0_mass_mae_loss: 1.813E+01; val_w1_mass_mae_loss: 1.856E+01; val_w_mass_mmd0_loss: 4.571E-01; val_w_mass_mmd1_loss: 1.060E-01; w0_mass_mae_loss: 1.850E+01; w1_mass_mae_loss: 1.857E+01; w_mass_mmd0_loss: 4.961E-01; w_mass_mmd1_loss: 1.173E-01
# Epoch 5; dinu_pt_loss: 5.813E+01; higgs_mass_loss: 6.164E+00; loss: 1.144E+02; mae_loss: 5.220E+01; neg_r2_loss: -6.566E-01; nu_mass_loss: 1.680E-02; val_dinu_pt_loss: 5.699E+01; val_higgs_mass_loss: 4.290E+00; val_loss: 1.112E+02; val_mae_loss: 5.190E+01; val_neg_r2_loss: -6.630E-01; val_nu_mass_loss: 1.729E-02; val_w0_mass_mae_loss: 1.722E+01; val_w1_mass_mae_loss: 1.874E+01; val_w_mass_mmd0_loss: 3.045E-01; val_w_mass_mmd1_loss: 9.007E-02; w0_mass_mae_loss: 1.750E+01; w1_mass_mae_loss: 1.876E+01; w_mass_mmd0_loss: 3.845E-01; w_mass_mmd1_loss: 9.866E-02
# Epoch 6; dinu_pt_loss: 5.798E+01; higgs_mass_loss: 5.479E+00; loss: 1.118E+02; mae_loss: 5.151E+01; neg_r2_loss: -6.603E-01; nu_mass_loss: 1.757E-02; val_dinu_pt_loss: 5.677E+01; val_higgs_mass_loss: 3.879E+00; val_loss: 1.094E+02; val_mae_loss: 5.126E+01; val_neg_r2_loss: -6.668E-01; val_nu_mass_loss: 1.796E-02; val_w0_mass_mae_loss: 1.690E+01; val_w1_mass_mae_loss: 1.884E+01; val_w_mass_mmd0_loss: 2.844E-01; val_w_mass_mmd1_loss: 8.909E-02; w0_mass_mae_loss: 1.695E+01; w1_mass_mae_loss: 1.882E+01; w_mass_mmd0_loss: 3.281E-01; w_mass_mmd1_loss: 9.003E-02
# Epoch 7; dinu_pt_loss: 5.707E+01; higgs_mass_loss: 4.906E+00; loss: 1.102E+02; mae_loss: 5.114E+01; neg_r2_loss: -6.629E-01; nu_mass_loss: 1.799E-02; val_dinu_pt_loss: 5.666E+01; val_higgs_mass_loss: 3.594E+00; val_loss: 1.082E+02; val_mae_loss: 5.097E+01; val_neg_r2_loss: -6.693E-01; val_nu_mass_loss: 1.829E-02; val_w0_mass_mae_loss: 1.685E+01; val_w1_mass_mae_loss: 1.891E+01; val_w_mass_mmd0_loss: 2.516E-01; val_w_mass_mmd1_loss: 8.110E-02; w0_mass_mae_loss: 1.690E+01; w1_mass_mae_loss: 1.881E+01; w_mass_mmd0_loss: 2.979E-01; w_mass_mmd1_loss: 8.517E-02
# Epoch 8; dinu_pt_loss: 5.568E+01; higgs_mass_loss: 4.555E+00; loss: 1.090E+02; mae_loss: 5.079E+01; neg_r2_loss: -6.653E-01; nu_mass_loss: 1.854E-02; val_dinu_pt_loss: 5.444E+01; val_higgs_mass_loss: 3.399E+00; val_loss: 1.072E+02; val_mae_loss: 5.062E+01; val_neg_r2_loss: -6.719E-01; val_nu_mass_loss: 1.887E-02; val_w0_mass_mae_loss: 1.720E+01; val_w1_mass_mae_loss: 1.888E+01; val_w_mass_mmd0_loss: 2.459E-01; val_w_mass_mmd1_loss: 7.798E-02; w0_mass_mae_loss: 1.699E+01; w1_mass_mae_loss: 1.885E+01; w_mass_mmd0_loss: 2.813E-01; w_mass_mmd1_loss: 8.059E-02
# Epoch 9; dinu_pt_loss: 5.502E+01; higgs_mass_loss: 4.273E+00; loss: 1.081E+02; mae_loss: 5.053E+01; neg_r2_loss: -6.675E-01; nu_mass_loss: 1.908E-02; val_dinu_pt_loss: 5.421E+01; val_higgs_mass_loss: 2.970E+00; val_loss: 1.060E+02; val_mae_loss: 5.044E+01; val_neg_r2_loss: -6.736E-01; val_nu_mass_loss: 1.926E-02; val_w0_mass_mae_loss: 1.723E+01; val_w1_mass_mae_loss: 1.909E+01; val_w_mass_mmd0_loss: 1.987E-01; val_w_mass_mmd1_loss: 6.745E-02; w0_mass_mae_loss: 1.713E+01; w1_mass_mae_loss: 1.893E+01; w_mass_mmd0_loss: 2.697E-01; w_mass_mmd1_loss: 7.472E-02
# Epoch 10; dinu_pt_loss: 5.472E+01; higgs_mass_loss: 4.041E+00; loss: 1.073E+02; mae_loss: 5.030E+01; neg_r2_loss: -6.697E-01; nu_mass_loss: 1.954E-02; val_dinu_pt_loss: 5.493E+01; val_higgs_mass_loss: 2.743E+00; val_loss: 1.051E+02; val_mae_loss: 5.016E+01; val_neg_r2_loss: -6.766E-01; val_nu_mass_loss: 1.988E-02; val_w0_mass_mae_loss: 1.677E+01; val_w1_mass_mae_loss: 1.899E+01; val_w_mass_mmd0_loss: 1.800E-01; val_w_mass_mmd1_loss: 7.310E-02; w0_mass_mae_loss: 1.707E+01; w1_mass_mae_loss: 1.896E+01; w_mass_mmd0_loss: 2.544E-01; w_mass_mmd1_loss: 7.219E-02
# Epoch 11; dinu_pt_loss: 5.451E+01; higgs_mass_loss: 3.832E+00; loss: 1.064E+02; mae_loss: 5.003E+01; neg_r2_loss: -6.723E-01; nu_mass_loss: 2.009E-02; val_dinu_pt_loss: 5.465E+01; val_higgs_mass_loss: 2.684E+00; val_loss: 1.044E+02; val_mae_loss: 4.989E+01; val_neg_r2_loss: -6.794E-01; val_nu_mass_loss: 2.051E-02; val_w0_mass_mae_loss: 1.708E+01; val_w1_mass_mae_loss: 1.907E+01; val_w_mass_mmd0_loss: 1.759E-01; val_w_mass_mmd1_loss: 6.927E-02; w0_mass_mae_loss: 1.715E+01; w1_mass_mae_loss: 1.907E+01; w_mass_mmd0_loss: 2.397E-01; w_mass_mmd1_loss: 6.877E-02
# Epoch 12; dinu_pt_loss: 5.518E+01; higgs_mass_loss: 3.598E+00; loss: 1.055E+02; mae_loss: 4.979E+01; neg_r2_loss: -6.752E-01; nu_mass_loss: 2.062E-02; val_dinu_pt_loss: 5.499E+01; val_higgs_mass_loss: 2.595E+00; val_loss: 1.036E+02; val_mae_loss: 4.962E+01; val_neg_r2_loss: -6.825E-01; val_nu_mass_loss: 2.108E-02; val_w0_mass_mae_loss: 1.724E+01; val_w1_mass_mae_loss: 1.931E+01; val_w_mass_mmd0_loss: 1.589E-01; val_w_mass_mmd1_loss: 6.187E-02; w0_mass_mae_loss: 1.698E+01; w1_mass_mae_loss: 1.903E+01; w_mass_mmd0_loss: 2.205E-01; w_mass_mmd1_loss: 6.880E-02
# Epoch 13; dinu_pt_loss: 5.444E+01; higgs_mass_loss: 3.478E+00; loss: 1.047E+02; mae_loss: 4.951E+01; neg_r2_loss: -6.780E-01; nu_mass_loss: 2.127E-02; val_dinu_pt_loss: 5.486E+01; val_higgs_mass_loss: 2.491E+00; val_loss: 1.028E+02; val_mae_loss: 4.940E+01; val_neg_r2_loss: -6.845E-01; val_nu_mass_loss: 2.154E-02; val_w0_mass_mae_loss: 1.685E+01; val_w1_mass_mae_loss: 1.933E+01; val_w_mass_mmd0_loss: 1.235E-01; val_w_mass_mmd1_loss: 6.283E-02; w0_mass_mae_loss: 1.722E+01; w1_mass_mae_loss: 1.927E+01; w_mass_mmd0_loss: 2.153E-01; w_mass_mmd1_loss: 6.430E-02
# Epoch 14; dinu_pt_loss: 5.456E+01; higgs_mass_loss: 3.341E+00; loss: 1.039E+02; mae_loss: 4.923E+01; neg_r2_loss: -6.808E-01; nu_mass_loss: 2.183E-02; val_dinu_pt_loss: 5.318E+01; val_higgs_mass_loss: 2.518E+00; val_loss: 1.023E+02; val_mae_loss: 4.907E+01; val_neg_r2_loss: -6.875E-01; val_nu_mass_loss: 2.210E-02; val_w0_mass_mae_loss: 1.703E+01; val_w1_mass_mae_loss: 1.941E+01; val_w_mass_mmd0_loss: 1.426E-01; val_w_mass_mmd1_loss: 6.017E-02; w0_mass_mae_loss: 1.700E+01; w1_mass_mae_loss: 1.932E+01; w_mass_mmd0_loss: 1.983E-01; w_mass_mmd1_loss: 6.314E-02
# Epoch 15; dinu_pt_loss: 5.380E+01; higgs_mass_loss: 3.242E+00; loss: 1.031E+02; mae_loss: 4.895E+01; neg_r2_loss: -6.835E-01; nu_mass_loss: 2.241E-02; val_dinu_pt_loss: 5.409E+01; val_higgs_mass_loss: 2.397E+00; val_loss: 1.012E+02; val_mae_loss: 4.872E+01; val_neg_r2_loss: -6.915E-01; val_nu_mass_loss: 2.297E-02; val_w0_mass_mae_loss: 1.710E+01; val_w1_mass_mae_loss: 1.970E+01; val_w_mass_mmd0_loss: 1.169E-01; val_w_mass_mmd1_loss: 5.597E-02; w0_mass_mae_loss: 1.712E+01; w1_mass_mae_loss: 1.954E+01; w_mass_mmd0_loss: 1.898E-01; w_mass_mmd1_loss: 5.894E-02
# Epoch 16; dinu_pt_loss: 5.373E+01; higgs_mass_loss: 3.109E+00; loss: 1.023E+02; mae_loss: 4.861E+01; neg_r2_loss: -6.875E-01; nu_mass_loss: 2.327E-02; val_dinu_pt_loss: 5.381E+01; val_higgs_mass_loss: 2.273E+00; val_loss: 1.004E+02; val_mae_loss: 4.842E+01; val_neg_r2_loss: -6.948E-01; val_nu_mass_loss: 2.362E-02; val_w0_mass_mae_loss: 1.713E+01; val_w1_mass_mae_loss: 1.954E+01; val_w_mass_mmd0_loss: 1.076E-01; val_w_mass_mmd1_loss: 5.886E-02; w0_mass_mae_loss: 1.722E+01; w1_mass_mae_loss: 1.945E+01; w_mass_mmd0_loss: 1.879E-01; w_mass_mmd1_loss: 6.067E-02
# Epoch 17; dinu_pt_loss: 5.363E+01; higgs_mass_loss: 3.045E+00; loss: 1.016E+02; mae_loss: 4.830E+01; neg_r2_loss: -6.911E-01; nu_mass_loss: 2.395E-02; val_dinu_pt_loss: 5.363E+01; val_higgs_mass_loss: 2.153E+00; val_loss: 9.961E+01; val_mae_loss: 4.808E+01; val_neg_r2_loss: -6.991E-01; val_nu_mass_loss: 2.438E-02; val_w0_mass_mae_loss: 1.706E+01; val_w1_mass_mae_loss: 1.958E+01; val_w_mass_mmd0_loss: 1.013E-01; val_w_mass_mmd1_loss: 6.029E-02; w0_mass_mae_loss: 1.724E+01; w1_mass_mae_loss: 1.950E+01; w_mass_mmd0_loss: 1.788E-01; w_mass_mmd1_loss: 6.097E-02
# Epoch 18; dinu_pt_loss: 5.318E+01; higgs_mass_loss: 2.979E+00; loss: 1.008E+02; mae_loss: 4.795E+01; neg_r2_loss: -6.950E-01; nu_mass_loss: 2.469E-02; val_dinu_pt_loss: 5.305E+01; val_higgs_mass_loss: 2.552E+00; val_loss: 9.952E+01; val_mae_loss: 4.768E+01; val_neg_r2_loss: -7.035E-01; val_nu_mass_loss: 2.510E-02; val_w0_mass_mae_loss: 1.681E+01; val_w1_mass_mae_loss: 1.954E+01; val_w_mass_mmd0_loss: 1.370E-01; val_w_mass_mmd1_loss: 6.372E-02; w0_mass_mae_loss: 1.724E+01; w1_mass_mae_loss: 1.951E+01; w_mass_mmd0_loss: 1.738E-01; w_mass_mmd1_loss: 6.193E-02
# Epoch 19; dinu_pt_loss: 5.348E+01; higgs_mass_loss: 2.903E+00; loss: 9.988E+01; mae_loss: 4.757E+01; neg_r2_loss: -7.001E-01; nu_mass_loss: 2.558E-02; val_dinu_pt_loss: 5.256E+01; val_higgs_mass_loss: 2.186E+00; val_loss: 9.831E+01; val_mae_loss: 4.736E+01; val_neg_r2_loss: -7.075E-01; val_nu_mass_loss: 2.586E-02; val_w0_mass_mae_loss: 1.690E+01; val_w1_mass_mae_loss: 1.961E+01; val_w_mass_mmd0_loss: 1.167E-01; val_w_mass_mmd1_loss: 5.990E-02; w0_mass_mae_loss: 1.708E+01; w1_mass_mae_loss: 1.950E+01; w_mass_mmd0_loss: 1.668E-01; w_mass_mmd1_loss: 6.248E-02
# Epoch 20; dinu_pt_loss: 5.309E+01; higgs_mass_loss: 2.853E+00; loss: 9.906E+01; mae_loss: 4.721E+01; neg_r2_loss: -7.046E-01; nu_mass_loss: 2.630E-02; val_dinu_pt_loss: 5.271E+01; val_higgs_mass_loss: 2.126E+00; val_loss: 9.736E+01; val_mae_loss: 4.705E+01; val_neg_r2_loss: -7.111E-01; val_nu_mass_loss: 2.641E-02; val_w0_mass_mae_loss: 1.688E+01; val_w1_mass_mae_loss: 1.969E+01; val_w_mass_mmd0_loss: 8.597E-02; val_w_mass_mmd1_loss: 5.694E-02; w0_mass_mae_loss: 1.703E+01; w1_mass_mae_loss: 1.954E+01; w_mass_mmd0_loss: 1.609E-01; w_mass_mmd1_loss: 6.140E-02
# Epoch 21; dinu_pt_loss: 5.211E+01; higgs_mass_loss: 2.800E+00; loss: 9.825E+01; mae_loss: 4.686E+01; neg_r2_loss: -7.086E-01; nu_mass_loss: 2.704E-02; val_dinu_pt_loss: 5.130E+01; val_higgs_mass_loss: 2.093E+00; val_loss: 9.682E+01; val_mae_loss: 4.676E+01; val_neg_r2_loss: -7.140E-01; val_nu_mass_loss: 2.713E-02; val_w0_mass_mae_loss: 1.698E+01; val_w1_mass_mae_loss: 1.958E+01; val_w_mass_mmd0_loss: 9.339E-02; val_w_mass_mmd1_loss: 5.823E-02; w0_mass_mae_loss: 1.715E+01; w1_mass_mae_loss: 1.954E+01; w_mass_mmd0_loss: 1.574E-01; w_mass_mmd1_loss: 6.011E-02
# Epoch 22; dinu_pt_loss: 5.276E+01; higgs_mass_loss: 2.723E+00; loss: 9.740E+01; mae_loss: 4.647E+01; neg_r2_loss: -7.134E-01; nu_mass_loss: 2.795E-02; val_dinu_pt_loss: 5.269E+01; val_higgs_mass_loss: 2.268E+00; val_loss: 9.617E+01; val_mae_loss: 4.629E+01; val_neg_r2_loss: -7.199E-01; val_nu_mass_loss: 2.800E-02; val_w0_mass_mae_loss: 1.694E+01; val_w1_mass_mae_loss: 1.972E+01; val_w_mass_mmd0_loss: 1.028E-01; val_w_mass_mmd1_loss: 6.153E-02; w0_mass_mae_loss: 1.700E+01; w1_mass_mae_loss: 1.952E+01; w_mass_mmd0_loss: 1.559E-01; w_mass_mmd1_loss: 6.284E-02
# Epoch 23; dinu_pt_loss: 5.272E+01; higgs_mass_loss: 2.688E+00; loss: 9.662E+01; mae_loss: 4.609E+01; neg_r2_loss: -7.180E-01; nu_mass_loss: 2.875E-02; val_dinu_pt_loss: 5.270E+01; val_higgs_mass_loss: 2.085E+00; val_loss: 9.520E+01; val_mae_loss: 4.595E+01; val_neg_r2_loss: -7.249E-01; val_nu_mass_loss: 2.923E-02; val_w0_mass_mae_loss: 1.677E+01; val_w1_mass_mae_loss: 1.952E+01; val_w_mass_mmd0_loss: 8.792E-02; val_w_mass_mmd1_loss: 6.516E-02; w0_mass_mae_loss: 1.694E+01; w1_mass_mae_loss: 1.944E+01; w_mass_mmd0_loss: 1.539E-01; w_mass_mmd1_loss: 6.456E-02
# Epoch 24; dinu_pt_loss: 5.204E+01; higgs_mass_loss: 2.675E+00; loss: 9.582E+01; mae_loss: 4.571E+01; neg_r2_loss: -7.224E-01; nu_mass_loss: 2.957E-02; val_dinu_pt_loss: 5.152E+01; val_higgs_mass_loss: 2.347E+00; val_loss: 9.474E+01; val_mae_loss: 4.556E+01; val_neg_r2_loss: -7.278E-01; val_nu_mass_loss: 2.947E-02; val_w0_mass_mae_loss: 1.671E+01; val_w1_mass_mae_loss: 1.950E+01; val_w_mass_mmd0_loss: 9.205E-02; val_w_mass_mmd1_loss: 6.617E-02; w0_mass_mae_loss: 1.695E+01; w1_mass_mae_loss: 1.946E+01; w_mass_mmd0_loss: 1.513E-01; w_mass_mmd1_loss: 6.417E-02
# Epoch 25; dinu_pt_loss: 5.212E+01; higgs_mass_loss: 2.669E+00; loss: 9.502E+01; mae_loss: 4.533E+01; neg_r2_loss: -7.268E-01; nu_mass_loss: 3.023E-02; val_dinu_pt_loss: 5.161E+01; val_higgs_mass_loss: 2.598E+00; val_loss: 9.448E+01; val_mae_loss: 4.509E+01; val_neg_r2_loss: -7.336E-01; val_nu_mass_loss: 3.023E-02; val_w0_mass_mae_loss: 1.651E+01; val_w1_mass_mae_loss: 1.956E+01; val_w_mass_mmd0_loss: 1.484E-01; val_w_mass_mmd1_loss: 6.366E-02; w0_mass_mae_loss: 1.675E+01; w1_mass_mae_loss: 1.941E+01; w_mass_mmd0_loss: 1.457E-01; w_mass_mmd1_loss: 6.456E-02
# Epoch 26; dinu_pt_loss: 5.132E+01; higgs_mass_loss: 2.671E+00; loss: 9.423E+01; mae_loss: 4.494E+01; neg_r2_loss: -7.314E-01; nu_mass_loss: 3.094E-02; val_dinu_pt_loss: 5.032E+01; val_higgs_mass_loss: 2.167E+00; val_loss: 9.286E+01; val_mae_loss: 4.474E+01; val_neg_r2_loss: -7.376E-01; val_nu_mass_loss: 3.094E-02; val_w0_mass_mae_loss: 1.653E+01; val_w1_mass_mae_loss: 1.958E+01; val_w_mass_mmd0_loss: 8.981E-02; val_w_mass_mmd1_loss: 6.088E-02; w0_mass_mae_loss: 1.673E+01; w1_mass_mae_loss: 1.945E+01; w_mass_mmd0_loss: 1.455E-01; w_mass_mmd1_loss: 6.365E-02
# Epoch 27; dinu_pt_loss: 5.157E+01; higgs_mass_loss: 2.667E+00; loss: 9.345E+01; mae_loss: 4.456E+01; neg_r2_loss: -7.360E-01; nu_mass_loss: 3.169E-02; val_dinu_pt_loss: 5.089E+01; val_higgs_mass_loss: 2.363E+00; val_loss: 9.253E+01; val_mae_loss: 4.438E+01; val_neg_r2_loss: -7.420E-01; val_nu_mass_loss: 3.153E-02; val_w0_mass_mae_loss: 1.642E+01; val_w1_mass_mae_loss: 1.948E+01; val_w_mass_mmd0_loss: 1.105E-01; val_w_mass_mmd1_loss: 6.663E-02; w0_mass_mae_loss: 1.655E+01; w1_mass_mae_loss: 1.937E+01; w_mass_mmd0_loss: 1.429E-01; w_mass_mmd1_loss: 6.567E-02
# Epoch 28; dinu_pt_loss: 5.099E+01; higgs_mass_loss: 2.670E+00; loss: 9.264E+01; mae_loss: 4.416E+01; neg_r2_loss: -7.406E-01; nu_mass_loss: 3.247E-02; val_dinu_pt_loss: 5.033E+01; val_higgs_mass_loss: 2.193E+00; val_loss: 9.166E+01; val_mae_loss: 4.408E+01; val_neg_r2_loss: -7.449E-01; val_nu_mass_loss: 3.219E-02; val_w0_mass_mae_loss: 1.645E+01; val_w1_mass_mae_loss: 1.940E+01; val_w_mass_mmd0_loss: 9.749E-02; val_w_mass_mmd1_loss: 6.740E-02; w0_mass_mae_loss: 1.652E+01; w1_mass_mae_loss: 1.935E+01; w_mass_mmd0_loss: 1.411E-01; w_mass_mmd1_loss: 6.602E-02
# Epoch 29; dinu_pt_loss: 5.053E+01; higgs_mass_loss: 2.680E+00; loss: 9.184E+01; mae_loss: 4.378E+01; neg_r2_loss: -7.449E-01; nu_mass_loss: 3.301E-02; val_dinu_pt_loss: 5.036E+01; val_higgs_mass_loss: 2.084E+00; val_loss: 9.061E+01; val_mae_loss: 4.359E+01; val_neg_r2_loss: -7.520E-01; val_nu_mass_loss: 3.323E-02; val_w0_mass_mae_loss: 1.637E+01; val_w1_mass_mae_loss: 1.940E+01; val_w_mass_mmd0_loss: 1.065E-01; val_w_mass_mmd1_loss: 6.078E-02; w0_mass_mae_loss: 1.646E+01; w1_mass_mae_loss: 1.935E+01; w_mass_mmd0_loss: 1.370E-01; w_mass_mmd1_loss: 6.349E-02
# Epoch 30; dinu_pt_loss: 5.088E+01; higgs_mass_loss: 2.653E+00; loss: 9.101E+01; mae_loss: 4.337E+01; neg_r2_loss: -7.503E-01; nu_mass_loss: 3.397E-02; val_dinu_pt_loss: 4.989E+01; val_higgs_mass_loss: 2.056E+00; val_loss: 8.974E+01; val_mae_loss: 4.319E+01; val_neg_r2_loss: -7.579E-01; val_nu_mass_loss: 3.447E-02; val_w0_mass_mae_loss: 1.632E+01; val_w1_mass_mae_loss: 1.940E+01; val_w_mass_mmd0_loss: 9.967E-02; val_w_mass_mmd1_loss: 6.327E-02; w0_mass_mae_loss: 1.633E+01; w1_mass_mae_loss: 1.931E+01; w_mass_mmd0_loss: 1.370E-01; w_mass_mmd1_loss: 6.497E-02
# Epoch 31; dinu_pt_loss: 5.028E+01; higgs_mass_loss: 2.660E+00; loss: 9.023E+01; mae_loss: 4.298E+01; neg_r2_loss: -7.551E-01; nu_mass_loss: 3.480E-02; val_dinu_pt_loss: 5.015E+01; val_higgs_mass_loss: 2.273E+00; val_loss: 8.892E+01; val_mae_loss: 4.275E+01; val_neg_r2_loss: -7.613E-01; val_nu_mass_loss: 3.453E-02; val_w0_mass_mae_loss: 1.610E+01; val_w1_mass_mae_loss: 1.945E+01; val_w_mass_mmd0_loss: 8.054E-02; val_w_mass_mmd1_loss: 6.309E-02; w0_mass_mae_loss: 1.634E+01; w1_mass_mae_loss: 1.928E+01; w_mass_mmd0_loss: 1.370E-01; w_mass_mmd1_loss: 6.576E-02
# Epoch 32; dinu_pt_loss: 4.973E+01; higgs_mass_loss: 2.688E+00; loss: 8.950E+01; mae_loss: 4.259E+01; neg_r2_loss: -7.594E-01; nu_mass_loss: 3.548E-02; val_dinu_pt_loss: 4.963E+01; val_higgs_mass_loss: 2.324E+00; val_loss: 8.843E+01; val_mae_loss: 4.235E+01; val_neg_r2_loss: -7.678E-01; val_nu_mass_loss: 3.572E-02; val_w0_mass_mae_loss: 1.598E+01; val_w1_mass_mae_loss: 1.924E+01; val_w_mass_mmd0_loss: 1.093E-01; val_w_mass_mmd1_loss: 6.714E-02; w0_mass_mae_loss: 1.623E+01; w1_mass_mae_loss: 1.920E+01; w_mass_mmd0_loss: 1.353E-01; w_mass_mmd1_loss: 6.717E-02
# Epoch 33; dinu_pt_loss: 4.910E+01; higgs_mass_loss: 2.674E+00; loss: 8.873E+01; mae_loss: 4.222E+01; neg_r2_loss: -7.642E-01; nu_mass_loss: 3.624E-02; val_dinu_pt_loss: 4.737E+01; val_higgs_mass_loss: 2.417E+00; val_loss: 8.783E+01; val_mae_loss: 4.208E+01; val_neg_r2_loss: -7.678E-01; val_nu_mass_loss: 3.533E-02; val_w0_mass_mae_loss: 1.598E+01; val_w1_mass_mae_loss: 1.934E+01; val_w_mass_mmd0_loss: 8.813E-02; val_w_mass_mmd1_loss: 6.688E-02; w0_mass_mae_loss: 1.614E+01; w1_mass_mae_loss: 1.914E+01; w_mass_mmd0_loss: 1.346E-01; w_mass_mmd1_loss: 6.843E-02
# Epoch 34; dinu_pt_loss: 4.798E+01; higgs_mass_loss: 2.688E+00; loss: 8.797E+01; mae_loss: 4.184E+01; neg_r2_loss: -7.683E-01; nu_mass_loss: 3.678E-02; val_dinu_pt_loss: 4.699E+01; val_higgs_mass_loss: 2.587E+00; val_loss: 8.733E+01; val_mae_loss: 4.171E+01; val_neg_r2_loss: -7.718E-01; val_nu_mass_loss: 3.585E-02; val_w0_mass_mae_loss: 1.589E+01; val_w1_mass_mae_loss: 1.929E+01; val_w_mass_mmd0_loss: 9.518E-02; val_w_mass_mmd1_loss: 6.882E-02; w0_mass_mae_loss: 1.613E+01; w1_mass_mae_loss: 1.915E+01; w_mass_mmd0_loss: 1.318E-01; w_mass_mmd1_loss: 6.844E-02
# Epoch 35; dinu_pt_loss: 4.789E+01; higgs_mass_loss: 2.697E+00; loss: 8.729E+01; mae_loss: 4.149E+01; neg_r2_loss: -7.728E-01; nu_mass_loss: 3.752E-02; val_dinu_pt_loss: 4.727E+01; val_higgs_mass_loss: 2.394E+00; val_loss: 8.686E+01; val_mae_loss: 4.151E+01; val_neg_r2_loss: -7.758E-01; val_nu_mass_loss: 3.678E-02; val_w0_mass_mae_loss: 1.593E+01; val_w1_mass_mae_loss: 1.912E+01; val_w_mass_mmd0_loss: 1.104E-01; val_w_mass_mmd1_loss: 7.054E-02; w0_mass_mae_loss: 1.600E+01; w1_mass_mae_loss: 1.910E+01; w_mass_mmd0_loss: 1.312E-01; w_mass_mmd1_loss: 7.026E-02
# Epoch 36; dinu_pt_loss: 4.750E+01; higgs_mass_loss: 2.705E+00; loss: 8.664E+01; mae_loss: 4.116E+01; neg_r2_loss: -7.770E-01; nu_mass_loss: 3.814E-02; val_dinu_pt_loss: 4.653E+01; val_higgs_mass_loss: 2.300E+00; val_loss: 8.549E+01; val_mae_loss: 4.095E+01; val_neg_r2_loss: -7.827E-01; val_nu_mass_loss: 3.783E-02; val_w0_mass_mae_loss: 1.576E+01; val_w1_mass_mae_loss: 1.919E+01; val_w_mass_mmd0_loss: 9.064E-02; val_w_mass_mmd1_loss: 7.059E-02; w0_mass_mae_loss: 1.595E+01; w1_mass_mae_loss: 1.905E+01; w_mass_mmd0_loss: 1.309E-01; w_mass_mmd1_loss: 6.993E-02
# Epoch 37; dinu_pt_loss: 4.617E+01; higgs_mass_loss: 2.736E+00; loss: 8.589E+01; mae_loss: 4.078E+01; neg_r2_loss: -7.804E-01; nu_mass_loss: 3.856E-02; val_dinu_pt_loss: 4.566E+01; val_higgs_mass_loss: 2.334E+00; val_loss: 8.485E+01; val_mae_loss: 4.063E+01; val_neg_r2_loss: -7.850E-01; val_nu_mass_loss: 3.788E-02; val_w0_mass_mae_loss: 1.568E+01; val_w1_mass_mae_loss: 1.915E+01; val_w_mass_mmd0_loss: 9.069E-02; val_w_mass_mmd1_loss: 6.744E-02; w0_mass_mae_loss: 1.585E+01; w1_mass_mae_loss: 1.902E+01; w_mass_mmd0_loss: 1.278E-01; w_mass_mmd1_loss: 7.043E-02
# Epoch 38; dinu_pt_loss: 4.478E+01; higgs_mass_loss: 2.759E+00; loss: 8.521E+01; mae_loss: 4.043E+01; neg_r2_loss: -7.837E-01; nu_mass_loss: 3.908E-02; val_dinu_pt_loss: 4.341E+01; val_higgs_mass_loss: 2.560E+00; val_loss: 8.434E+01; val_mae_loss: 4.020E+01; val_neg_r2_loss: -7.884E-01; val_nu_mass_loss: 3.849E-02; val_w0_mass_mae_loss: 1.549E+01; val_w1_mass_mae_loss: 1.900E+01; val_w_mass_mmd0_loss: 1.008E-01; val_w_mass_mmd1_loss: 7.231E-02; w0_mass_mae_loss: 1.581E+01; w1_mass_mae_loss: 1.899E+01; w_mass_mmd0_loss: 1.285E-01; w_mass_mmd1_loss: 7.052E-02
# Epoch 39; dinu_pt_loss: 4.352E+01; higgs_mass_loss: 2.768E+00; loss: 8.447E+01; mae_loss: 4.007E+01; neg_r2_loss: -7.867E-01; nu_mass_loss: 3.951E-02; val_dinu_pt_loss: 4.226E+01; val_higgs_mass_loss: 2.770E+00; val_loss: 8.407E+01; val_mae_loss: 3.993E+01; val_neg_r2_loss: -7.892E-01; val_nu_mass_loss: 3.845E-02; val_w0_mass_mae_loss: 1.548E+01; val_w1_mass_mae_loss: 1.905E+01; val_w_mass_mmd0_loss: 1.094E-01; val_w_mass_mmd1_loss: 7.137E-02; w0_mass_mae_loss: 1.571E+01; w1_mass_mae_loss: 1.894E+01; w_mass_mmd0_loss: 1.230E-01; w_mass_mmd1_loss: 7.168E-02
# Epoch 40; dinu_pt_loss: 4.253E+01; higgs_mass_loss: 2.773E+00; loss: 8.381E+01; mae_loss: 3.975E+01; neg_r2_loss: -7.898E-01; nu_mass_loss: 3.994E-02; val_dinu_pt_loss: 4.122E+01; val_higgs_mass_loss: 2.662E+00; val_loss: 8.323E+01; val_mae_loss: 3.959E+01; val_neg_r2_loss: -7.933E-01; val_nu_mass_loss: 3.921E-02; val_w0_mass_mae_loss: 1.523E+01; val_w1_mass_mae_loss: 1.904E+01; val_w_mass_mmd0_loss: 1.041E-01; val_w_mass_mmd1_loss: 7.012E-02; w0_mass_mae_loss: 1.557E+01; w1_mass_mae_loss: 1.894E+01; w_mass_mmd0_loss: 1.212E-01; w_mass_mmd1_loss: 7.142E-02
# Epoch 41; dinu_pt_loss: 4.078E+01; higgs_mass_loss: 2.803E+00; loss: 8.317E+01; mae_loss: 3.941E+01; neg_r2_loss: -7.923E-01; nu_mass_loss: 4.036E-02; val_dinu_pt_loss: 3.923E+01; val_higgs_mass_loss: 2.638E+00; val_loss: 8.239E+01; val_mae_loss: 3.918E+01; val_neg_r2_loss: -7.961E-01; val_nu_mass_loss: 3.965E-02; val_w0_mass_mae_loss: 1.519E+01; val_w1_mass_mae_loss: 1.899E+01; val_w_mass_mmd0_loss: 1.021E-01; val_w_mass_mmd1_loss: 7.040E-02; w0_mass_mae_loss: 1.549E+01; w1_mass_mae_loss: 1.889E+01; w_mass_mmd0_loss: 1.194E-01; w_mass_mmd1_loss: 7.268E-02
# Epoch 42; dinu_pt_loss: 3.895E+01; higgs_mass_loss: 2.840E+00; loss: 8.252E+01; mae_loss: 3.908E+01; neg_r2_loss: -7.949E-01; nu_mass_loss: 4.074E-02; val_dinu_pt_loss: 3.723E+01; val_higgs_mass_loss: 2.747E+00; val_loss: 8.179E+01; val_mae_loss: 3.890E+01; val_neg_r2_loss: -7.987E-01; val_nu_mass_loss: 4.001E-02; val_w0_mass_mae_loss: 1.527E+01; val_w1_mass_mae_loss: 1.897E+01; val_w_mass_mmd0_loss: 8.619E-02; val_w_mass_mmd1_loss: 6.958E-02; w0_mass_mae_loss: 1.547E+01; w1_mass_mae_loss: 1.885E+01; w_mass_mmd0_loss: 1.180E-01; w_mass_mmd1_loss: 7.283E-02
# Epoch 43; dinu_pt_loss: 3.716E+01; higgs_mass_loss: 2.854E+00; loss: 8.185E+01; mae_loss: 3.875E+01; neg_r2_loss: -7.974E-01; nu_mass_loss: 4.117E-02; val_dinu_pt_loss: 3.538E+01; val_higgs_mass_loss: 2.726E+00; val_loss: 8.119E+01; val_mae_loss: 3.856E+01; val_neg_r2_loss: -8.000E-01; val_nu_mass_loss: 3.983E-02; val_w0_mass_mae_loss: 1.512E+01; val_w1_mass_mae_loss: 1.884E+01; val_w_mass_mmd0_loss: 9.450E-02; val_w_mass_mmd1_loss: 7.305E-02; w0_mass_mae_loss: 1.538E+01; w1_mass_mae_loss: 1.883E+01; w_mass_mmd0_loss: 1.156E-01; w_mass_mmd1_loss: 7.266E-02
# Epoch 44; dinu_pt_loss: 3.602E+01; higgs_mass_loss: 2.858E+00; loss: 8.123E+01; mae_loss: 3.844E+01; neg_r2_loss: -8.002E-01; nu_mass_loss: 4.167E-02; val_dinu_pt_loss: 3.406E+01; val_higgs_mass_loss: 2.696E+00; val_loss: 8.017E+01; val_mae_loss: 3.812E+01; val_neg_r2_loss: -8.057E-01; val_nu_mass_loss: 4.128E-02; val_w0_mass_mae_loss: 1.507E+01; val_w1_mass_mae_loss: 1.881E+01; val_w_mass_mmd0_loss: 7.969E-02; val_w_mass_mmd1_loss: 7.406E-02; w0_mass_mae_loss: 1.528E+01; w1_mass_mae_loss: 1.877E+01; w_mass_mmd0_loss: 1.130E-01; w_mass_mmd1_loss: 7.328E-02
# Epoch 45; dinu_pt_loss: 3.429E+01; higgs_mass_loss: 2.874E+00; loss: 8.063E+01; mae_loss: 3.815E+01; neg_r2_loss: -8.022E-01; nu_mass_loss: 4.200E-02; val_dinu_pt_loss: 3.305E+01; val_higgs_mass_loss: 2.838E+00; val_loss: 7.997E+01; val_mae_loss: 3.789E+01; val_neg_r2_loss: -8.073E-01; val_nu_mass_loss: 4.154E-02; val_w0_mass_mae_loss: 1.489E+01; val_w1_mass_mae_loss: 1.872E+01; val_w_mass_mmd0_loss: 9.526E-02; val_w_mass_mmd1_loss: 7.339E-02; w0_mass_mae_loss: 1.522E+01; w1_mass_mae_loss: 1.872E+01; w_mass_mmd0_loss: 1.088E-01; w_mass_mmd1_loss: 7.330E-02
# Epoch 46; dinu_pt_loss: 3.354E+01; higgs_mass_loss: 2.879E+00; loss: 8.011E+01; mae_loss: 3.788E+01; neg_r2_loss: -8.049E-01; nu_mass_loss: 4.251E-02; val_dinu_pt_loss: 3.189E+01; val_higgs_mass_loss: 2.807E+00; val_loss: 7.955E+01; val_mae_loss: 3.763E+01; val_neg_r2_loss: -8.097E-01; val_nu_mass_loss: 4.197E-02; val_w0_mass_mae_loss: 1.490E+01; val_w1_mass_mae_loss: 1.861E+01; val_w_mass_mmd0_loss: 1.121E-01; val_w_mass_mmd1_loss: 7.288E-02; w0_mass_mae_loss: 1.514E+01; w1_mass_mae_loss: 1.865E+01; w_mass_mmd0_loss: 1.090E-01; w_mass_mmd1_loss: 7.317E-02
# Epoch 47; dinu_pt_loss: 3.262E+01; higgs_mass_loss: 2.893E+00; loss: 7.966E+01; mae_loss: 3.766E+01; neg_r2_loss: -8.068E-01; nu_mass_loss: 4.285E-02; val_dinu_pt_loss: 3.152E+01; val_higgs_mass_loss: 2.990E+00; val_loss: 7.931E+01; val_mae_loss: 3.749E+01; val_neg_r2_loss: -8.099E-01; val_nu_mass_loss: 4.194E-02; val_w0_mass_mae_loss: 1.485E+01; val_w1_mass_mae_loss: 1.866E+01; val_w_mass_mmd0_loss: 9.388E-02; val_w_mass_mmd1_loss: 7.278E-02; w0_mass_mae_loss: 1.505E+01; w1_mass_mae_loss: 1.857E+01; w_mass_mmd0_loss: 1.065E-01; w_mass_mmd1_loss: 7.346E-02
# Epoch 48; dinu_pt_loss: 3.110E+01; higgs_mass_loss: 2.911E+00; loss: 7.921E+01; mae_loss: 3.743E+01; neg_r2_loss: -8.086E-01; nu_mass_loss: 4.327E-02; val_dinu_pt_loss: 2.948E+01; val_higgs_mass_loss: 2.767E+00; val_loss: 7.830E+01; val_mae_loss: 3.714E+01; val_neg_r2_loss: -8.136E-01; val_nu_mass_loss: 4.295E-02; val_w0_mass_mae_loss: 1.470E+01; val_w1_mass_mae_loss: 1.855E+01; val_w_mass_mmd0_loss: 8.180E-02; val_w_mass_mmd1_loss: 7.423E-02; w0_mass_mae_loss: 1.504E+01; w1_mass_mae_loss: 1.854E+01; w_mass_mmd0_loss: 1.057E-01; w_mass_mmd1_loss: 7.318E-02
# Epoch 49; dinu_pt_loss: 3.034E+01; higgs_mass_loss: 2.916E+00; loss: 7.877E+01; mae_loss: 3.722E+01; neg_r2_loss: -8.106E-01; nu_mass_loss: 4.358E-02; val_dinu_pt_loss: 2.830E+01; val_higgs_mass_loss: 2.782E+00; val_loss: 7.810E+01; val_mae_loss: 3.698E+01; val_neg_r2_loss: -8.147E-01; val_nu_mass_loss: 4.302E-02; val_w0_mass_mae_loss: 1.480E+01; val_w1_mass_mae_loss: 1.855E+01; val_w_mass_mmd0_loss: 9.847E-02; val_w_mass_mmd1_loss: 7.129E-02; w0_mass_mae_loss: 1.503E+01; w1_mass_mae_loss: 1.850E+01; w_mass_mmd0_loss: 1.040E-01; w_mass_mmd1_loss: 7.204E-02
# Epoch 50; dinu_pt_loss: 2.941E+01; higgs_mass_loss: 2.943E+00; loss: 7.841E+01; mae_loss: 3.703E+01; neg_r2_loss: -8.122E-01; nu_mass_loss: 4.382E-02; val_dinu_pt_loss: 2.793E+01; val_higgs_mass_loss: 3.104E+00; val_loss: 7.806E+01; val_mae_loss: 3.681E+01; val_neg_r2_loss: -8.161E-01; val_nu_mass_loss: 4.301E-02; val_w0_mass_mae_loss: 1.466E+01; val_w1_mass_mae_loss: 1.850E+01; val_w_mass_mmd0_loss: 9.661E-02; val_w_mass_mmd1_loss: 7.077E-02; w0_mass_mae_loss: 1.500E+01; w1_mass_mae_loss: 1.846E+01; w_mass_mmd0_loss: 1.042E-01; w_mass_mmd1_loss: 7.129E-02
# Epoch 51; dinu_pt_loss: 2.847E+01; higgs_mass_loss: 2.951E+00; loss: 7.805E+01; mae_loss: 3.685E+01; neg_r2_loss: -8.136E-01; nu_mass_loss: 4.415E-02; val_dinu_pt_loss: 2.666E+01; val_higgs_mass_loss: 3.082E+00; val_loss: 7.773E+01; val_mae_loss: 3.660E+01; val_neg_r2_loss: -8.176E-01; val_nu_mass_loss: 4.341E-02; val_w0_mass_mae_loss: 1.468E+01; val_w1_mass_mae_loss: 1.846E+01; val_w_mass_mmd0_loss: 1.110E-01; val_w_mass_mmd1_loss: 6.960E-02; w0_mass_mae_loss: 1.496E+01; w1_mass_mae_loss: 1.842E+01; w_mass_mmd0_loss: 1.046E-01; w_mass_mmd1_loss: 7.038E-02
# Epoch 52; dinu_pt_loss: 2.714E+01; higgs_mass_loss: 2.949E+00; loss: 7.772E+01; mae_loss: 3.670E+01; neg_r2_loss: -8.147E-01; nu_mass_loss: 4.442E-02; val_dinu_pt_loss: 2.578E+01; val_higgs_mass_loss: 2.964E+00; val_loss: 7.736E+01; val_mae_loss: 3.645E+01; val_neg_r2_loss: -8.199E-01; val_nu_mass_loss: 4.399E-02; val_w0_mass_mae_loss: 1.475E+01; val_w1_mass_mae_loss: 1.840E+01; val_w_mass_mmd0_loss: 1.179E-01; val_w_mass_mmd1_loss: 6.945E-02; w0_mass_mae_loss: 1.498E+01; w1_mass_mae_loss: 1.836E+01; w_mass_mmd0_loss: 1.017E-01; w_mass_mmd1_loss: 6.998E-02
# Epoch 53; dinu_pt_loss: 2.638E+01; higgs_mass_loss: 2.962E+00; loss: 7.742E+01; mae_loss: 3.654E+01; neg_r2_loss: -8.160E-01; nu_mass_loss: 4.466E-02; val_dinu_pt_loss: 2.455E+01; val_higgs_mass_loss: 3.109E+00; val_loss: 7.712E+01; val_mae_loss: 3.630E+01; val_neg_r2_loss: -8.197E-01; val_nu_mass_loss: 4.364E-02; val_w0_mass_mae_loss: 1.465E+01; val_w1_mass_mae_loss: 1.834E+01; val_w_mass_mmd0_loss: 1.063E-01; val_w_mass_mmd1_loss: 6.871E-02; w0_mass_mae_loss: 1.495E+01; w1_mass_mae_loss: 1.830E+01; w_mass_mmd0_loss: 1.022E-01; w_mass_mmd1_loss: 6.905E-02
# Epoch 54; dinu_pt_loss: 2.564E+01; higgs_mass_loss: 2.960E+00; loss: 7.711E+01; mae_loss: 3.640E+01; neg_r2_loss: -8.171E-01; nu_mass_loss: 4.483E-02; val_dinu_pt_loss: 2.438E+01; val_higgs_mass_loss: 2.955E+00; val_loss: 7.676E+01; val_mae_loss: 3.618E+01; val_neg_r2_loss: -8.209E-01; val_nu_mass_loss: 4.380E-02; val_w0_mass_mae_loss: 1.462E+01; val_w1_mass_mae_loss: 1.838E+01; val_w_mass_mmd0_loss: 1.148E-01; val_w_mass_mmd1_loss: 6.472E-02; w0_mass_mae_loss: 1.493E+01; w1_mass_mae_loss: 1.829E+01; w_mass_mmd0_loss: 1.012E-01; w_mass_mmd1_loss: 6.745E-02
# Epoch 55; dinu_pt_loss: 2.459E+01; higgs_mass_loss: 2.954E+00; loss: 7.684E+01; mae_loss: 3.628E+01; neg_r2_loss: -8.179E-01; nu_mass_loss: 4.508E-02; val_dinu_pt_loss: 2.259E+01; val_higgs_mass_loss: 3.080E+00; val_loss: 7.667E+01; val_mae_loss: 3.603E+01; val_neg_r2_loss: -8.221E-01; val_nu_mass_loss: 4.454E-02; val_w0_mass_mae_loss: 1.454E+01; val_w1_mass_mae_loss: 1.821E+01; val_w_mass_mmd0_loss: 1.252E-01; val_w_mass_mmd1_loss: 6.682E-02; w0_mass_mae_loss: 1.491E+01; w1_mass_mae_loss: 1.824E+01; w_mass_mmd0_loss: 1.005E-01; w_mass_mmd1_loss: 6.652E-02
# Epoch 56; dinu_pt_loss: 2.389E+01; higgs_mass_loss: 2.980E+00; loss: 7.660E+01; mae_loss: 3.614E+01; neg_r2_loss: -8.187E-01; nu_mass_loss: 4.519E-02; val_dinu_pt_loss: 2.205E+01; val_higgs_mass_loss: 3.024E+00; val_loss: 7.626E+01; val_mae_loss: 3.597E+01; val_neg_r2_loss: -8.219E-01; val_nu_mass_loss: 4.420E-02; val_w0_mass_mae_loss: 1.462E+01; val_w1_mass_mae_loss: 1.824E+01; val_w_mass_mmd0_loss: 9.819E-02; val_w_mass_mmd1_loss: 6.319E-02; w0_mass_mae_loss: 1.490E+01; w1_mass_mae_loss: 1.821E+01; w_mass_mmd0_loss: 1.010E-01; w_mass_mmd1_loss: 6.507E-02
# Epoch 57; dinu_pt_loss: 2.295E+01; higgs_mass_loss: 2.999E+00; loss: 7.635E+01; mae_loss: 3.602E+01; neg_r2_loss: -8.196E-01; nu_mass_loss: 4.533E-02; val_dinu_pt_loss: 2.195E+01; val_higgs_mass_loss: 2.913E+00; val_loss: 7.584E+01; val_mae_loss: 3.577E+01; val_neg_r2_loss: -8.248E-01; val_nu_mass_loss: 4.467E-02; val_w0_mass_mae_loss: 1.447E+01; val_w1_mass_mae_loss: 1.822E+01; val_w_mass_mmd0_loss: 1.126E-01; val_w_mass_mmd1_loss: 6.099E-02; w0_mass_mae_loss: 1.492E+01; w1_mass_mae_loss: 1.818E+01; w_mass_mmd0_loss: 1.005E-01; w_mass_mmd1_loss: 6.329E-02
# Epoch 58; dinu_pt_loss: 2.199E+01; higgs_mass_loss: 2.979E+00; loss: 7.605E+01; mae_loss: 3.589E+01; neg_r2_loss: -8.202E-01; nu_mass_loss: 4.547E-02; val_dinu_pt_loss: 2.035E+01; val_higgs_mass_loss: 2.996E+00; val_loss: 7.565E+01; val_mae_loss: 3.566E+01; val_neg_r2_loss: -8.235E-01; val_nu_mass_loss: 4.458E-02; val_w0_mass_mae_loss: 1.445E+01; val_w1_mass_mae_loss: 1.811E+01; val_w_mass_mmd0_loss: 1.070E-01; val_w_mass_mmd1_loss: 6.035E-02; w0_mass_mae_loss: 1.488E+01; w1_mass_mae_loss: 1.814E+01; w_mass_mmd0_loss: 9.941E-02; w_mass_mmd1_loss: 6.176E-02
# Epoch 59; dinu_pt_loss: 2.119E+01; higgs_mass_loss: 2.984E+00; loss: 7.580E+01; mae_loss: 3.577E+01; neg_r2_loss: -8.210E-01; nu_mass_loss: 4.556E-02; val_dinu_pt_loss: 1.957E+01; val_higgs_mass_loss: 3.187E+00; val_loss: 7.563E+01; val_mae_loss: 3.557E+01; val_neg_r2_loss: -8.240E-01; val_nu_mass_loss: 4.425E-02; val_w0_mass_mae_loss: 1.448E+01; val_w1_mass_mae_loss: 1.812E+01; val_w_mass_mmd0_loss: 1.043E-01; val_w_mass_mmd1_loss: 5.830E-02; w0_mass_mae_loss: 1.489E+01; w1_mass_mae_loss: 1.811E+01; w_mass_mmd0_loss: 9.828E-02; w_mass_mmd1_loss: 6.043E-02
# Epoch 60; dinu_pt_loss: 2.043E+01; higgs_mass_loss: 3.003E+00; loss: 7.560E+01; mae_loss: 3.566E+01; neg_r2_loss: -8.215E-01; nu_mass_loss: 4.569E-02; val_dinu_pt_loss: 1.880E+01; val_higgs_mass_loss: 3.041E+00; val_loss: 7.521E+01; val_mae_loss: 3.547E+01; val_neg_r2_loss: -8.253E-01; val_nu_mass_loss: 4.491E-02; val_w0_mass_mae_loss: 1.447E+01; val_w1_mass_mae_loss: 1.809E+01; val_w_mass_mmd0_loss: 9.574E-02; val_w_mass_mmd1_loss: 5.815E-02; w0_mass_mae_loss: 1.490E+01; w1_mass_mae_loss: 1.808E+01; w_mass_mmd0_loss: 9.897E-02; w_mass_mmd1_loss: 5.936E-02
# Epoch 61; dinu_pt_loss: 1.957E+01; higgs_mass_loss: 2.999E+00; loss: 7.537E+01; mae_loss: 3.556E+01; neg_r2_loss: -8.223E-01; nu_mass_loss: 4.582E-02; val_dinu_pt_loss: 1.766E+01; val_higgs_mass_loss: 3.108E+00; val_loss: 7.503E+01; val_mae_loss: 3.534E+01; val_neg_r2_loss: -8.266E-01; val_nu_mass_loss: 4.551E-02; val_w0_mass_mae_loss: 1.454E+01; val_w1_mass_mae_loss: 1.806E+01; val_w_mass_mmd0_loss: 9.759E-02; val_w_mass_mmd1_loss: 5.748E-02; w0_mass_mae_loss: 1.490E+01; w1_mass_mae_loss: 1.805E+01; w_mass_mmd0_loss: 9.797E-02; w_mass_mmd1_loss: 5.855E-02
# Epoch 62; dinu_pt_loss: 1.880E+01; higgs_mass_loss: 3.000E+00; loss: 7.518E+01; mae_loss: 3.547E+01; neg_r2_loss: -8.228E-01; nu_mass_loss: 4.599E-02; val_dinu_pt_loss: 1.658E+01; val_higgs_mass_loss: 3.132E+00; val_loss: 7.475E+01; val_mae_loss: 3.520E+01; val_neg_r2_loss: -8.275E-01; val_nu_mass_loss: 4.557E-02; val_w0_mass_mae_loss: 1.444E+01; val_w1_mass_mae_loss: 1.793E+01; val_w_mass_mmd0_loss: 9.386E-02; val_w_mass_mmd1_loss: 5.811E-02; w0_mass_mae_loss: 1.487E+01; w1_mass_mae_loss: 1.799E+01; w_mass_mmd0_loss: 9.725E-02; w_mass_mmd1_loss: 5.821E-02
# Epoch 63; dinu_pt_loss: 1.816E+01; higgs_mass_loss: 3.010E+00; loss: 7.499E+01; mae_loss: 3.537E+01; neg_r2_loss: -8.233E-01; nu_mass_loss: 4.606E-02; val_dinu_pt_loss: 1.649E+01; val_higgs_mass_loss: 2.909E+00; val_loss: 7.442E+01; val_mae_loss: 3.519E+01; val_neg_r2_loss: -8.264E-01; val_nu_mass_loss: 4.529E-02; val_w0_mass_mae_loss: 1.446E+01; val_w1_mass_mae_loss: 1.793E+01; val_w_mass_mmd0_loss: 8.600E-02; val_w_mass_mmd1_loss: 5.605E-02; w0_mass_mae_loss: 1.488E+01; w1_mass_mae_loss: 1.796E+01; w_mass_mmd0_loss: 9.803E-02; w_mass_mmd1_loss: 5.754E-02
# Epoch 64; dinu_pt_loss: 1.738E+01; higgs_mass_loss: 3.019E+00; loss: 7.479E+01; mae_loss: 3.526E+01; neg_r2_loss: -8.239E-01; nu_mass_loss: 4.625E-02; val_dinu_pt_loss: 1.537E+01; val_higgs_mass_loss: 3.155E+00; val_loss: 7.458E+01; val_mae_loss: 3.508E+01; val_neg_r2_loss: -8.275E-01; val_nu_mass_loss: 4.528E-02; val_w0_mass_mae_loss: 1.439E+01; val_w1_mass_mae_loss: 1.781E+01; val_w_mass_mmd0_loss: 1.004E-01; val_w_mass_mmd1_loss: 5.711E-02; w0_mass_mae_loss: 1.490E+01; w1_mass_mae_loss: 1.788E+01; w_mass_mmd0_loss: 9.731E-02; w_mass_mmd1_loss: 5.728E-02
# Epoch 65; dinu_pt_loss: 1.675E+01; higgs_mass_loss: 3.009E+00; loss: 7.460E+01; mae_loss: 3.518E+01; neg_r2_loss: -8.244E-01; nu_mass_loss: 4.630E-02; val_dinu_pt_loss: 1.448E+01; val_higgs_mass_loss: 3.302E+00; val_loss: 7.443E+01; val_mae_loss: 3.497E+01; val_neg_r2_loss: -8.285E-01; val_nu_mass_loss: 4.567E-02; val_w0_mass_mae_loss: 1.439E+01; val_w1_mass_mae_loss: 1.778E+01; val_w_mass_mmd0_loss: 9.407E-02; val_w_mass_mmd1_loss: 5.450E-02; w0_mass_mae_loss: 1.488E+01; w1_mass_mae_loss: 1.782E+01; w_mass_mmd0_loss: 9.545E-02; w_mass_mmd1_loss: 5.730E-02
# Epoch 66; dinu_pt_loss: 1.629E+01; higgs_mass_loss: 3.018E+00; loss: 7.444E+01; mae_loss: 3.510E+01; neg_r2_loss: -8.249E-01; nu_mass_loss: 4.640E-02; val_dinu_pt_loss: 1.419E+01; val_higgs_mass_loss: 3.120E+00; val_loss: 7.423E+01; val_mae_loss: 3.493E+01; val_neg_r2_loss: -8.283E-01; val_nu_mass_loss: 4.572E-02; val_w0_mass_mae_loss: 1.437E+01; val_w1_mass_mae_loss: 1.774E+01; val_w_mass_mmd0_loss: 1.010E-01; val_w_mass_mmd1_loss: 5.573E-02; w0_mass_mae_loss: 1.488E+01; w1_mass_mae_loss: 1.779E+01; w_mass_mmd0_loss: 9.610E-02; w_mass_mmd1_loss: 5.675E-02
# Epoch 67; dinu_pt_loss: 1.602E+01; higgs_mass_loss: 3.010E+00; loss: 7.430E+01; mae_loss: 3.504E+01; neg_r2_loss: -8.253E-01; nu_mass_loss: 4.647E-02; val_dinu_pt_loss: 1.389E+01; val_higgs_mass_loss: 2.952E+00; val_loss: 7.383E+01; val_mae_loss: 3.484E+01; val_neg_r2_loss: -8.298E-01; val_nu_mass_loss: 4.615E-02; val_w0_mass_mae_loss: 1.454E+01; val_w1_mass_mae_loss: 1.773E+01; val_w_mass_mmd0_loss: 9.302E-02; val_w_mass_mmd1_loss: 5.566E-02; w0_mass_mae_loss: 1.487E+01; w1_mass_mae_loss: 1.778E+01; w_mass_mmd0_loss: 9.556E-02; w_mass_mmd1_loss: 5.647E-02
# Epoch 68; dinu_pt_loss: 1.562E+01; higgs_mass_loss: 2.990E+00; loss: 7.414E+01; mae_loss: 3.498E+01; neg_r2_loss: -8.258E-01; nu_mass_loss: 4.667E-02; val_dinu_pt_loss: 1.361E+01; val_higgs_mass_loss: 3.155E+00; val_loss: 7.423E+01; val_mae_loss: 3.480E+01; val_neg_r2_loss: -8.294E-01; val_nu_mass_loss: 4.609E-02; val_w0_mass_mae_loss: 1.440E+01; val_w1_mass_mae_loss: 1.769E+01; val_w_mass_mmd0_loss: 1.286E-01; val_w_mass_mmd1_loss: 5.511E-02; w0_mass_mae_loss: 1.489E+01; w1_mass_mae_loss: 1.776E+01; w_mass_mmd0_loss: 9.337E-02; w_mass_mmd1_loss: 5.615E-02
# Epoch 69; dinu_pt_loss: 1.532E+01; higgs_mass_loss: 2.969E+00; loss: 7.403E+01; mae_loss: 3.493E+01; neg_r2_loss: -8.261E-01; nu_mass_loss: 4.667E-02; val_dinu_pt_loss: 1.351E+01; val_higgs_mass_loss: 2.896E+00; val_loss: 7.373E+01; val_mae_loss: 3.480E+01; val_neg_r2_loss: -8.297E-01; val_nu_mass_loss: 4.621E-02; val_w0_mass_mae_loss: 1.451E+01; val_w1_mass_mae_loss: 1.768E+01; val_w_mass_mmd0_loss: 9.870E-02; val_w_mass_mmd1_loss: 5.608E-02; w0_mass_mae_loss: 1.489E+01; w1_mass_mae_loss: 1.775E+01; w_mass_mmd0_loss: 9.350E-02; w_mass_mmd1_loss: 5.627E-02
# Epoch 70; dinu_pt_loss: 1.506E+01; higgs_mass_loss: 2.954E+00; loss: 7.392E+01; mae_loss: 3.488E+01; neg_r2_loss: -8.266E-01; nu_mass_loss: 4.680E-02; val_dinu_pt_loss: 1.305E+01; val_higgs_mass_loss: 3.004E+00; val_loss: 7.375E+01; val_mae_loss: 3.474E+01; val_neg_r2_loss: -8.298E-01; val_nu_mass_loss: 4.591E-02; val_w0_mass_mae_loss: 1.446E+01; val_w1_mass_mae_loss: 1.765E+01; val_w_mass_mmd0_loss: 1.016E-01; val_w_mass_mmd1_loss: 5.577E-02; w0_mass_mae_loss: 1.489E+01; w1_mass_mae_loss: 1.774E+01; w_mass_mmd0_loss: 9.312E-02; w_mass_mmd1_loss: 5.627E-02
# Epoch 71; dinu_pt_loss: 1.490E+01; higgs_mass_loss: 2.943E+00; loss: 7.383E+01; mae_loss: 3.485E+01; neg_r2_loss: -8.269E-01; nu_mass_loss: 4.685E-02; val_dinu_pt_loss: 1.279E+01; val_higgs_mass_loss: 2.922E+00; val_loss: 7.360E+01; val_mae_loss: 3.467E+01; val_neg_r2_loss: -8.307E-01; val_nu_mass_loss: 4.643E-02; val_w0_mass_mae_loss: 1.451E+01; val_w1_mass_mae_loss: 1.766E+01; val_w_mass_mmd0_loss: 1.115E-01; val_w_mass_mmd1_loss: 5.593E-02; w0_mass_mae_loss: 1.488E+01; w1_mass_mae_loss: 1.773E+01; w_mass_mmd0_loss: 9.245E-02; w_mass_mmd1_loss: 5.579E-02
# Epoch 72; dinu_pt_loss: 1.462E+01; higgs_mass_loss: 2.924E+00; loss: 7.372E+01; mae_loss: 3.481E+01; neg_r2_loss: -8.272E-01; nu_mass_loss: 4.691E-02; val_dinu_pt_loss: 1.263E+01; val_higgs_mass_loss: 2.853E+00; val_loss: 7.322E+01; val_mae_loss: 3.461E+01; val_neg_r2_loss: -8.315E-01; val_nu_mass_loss: 4.637E-02; val_w0_mass_mae_loss: 1.453E+01; val_w1_mass_mae_loss: 1.760E+01; val_w_mass_mmd0_loss: 8.601E-02; val_w_mass_mmd1_loss: 5.668E-02; w0_mass_mae_loss: 1.488E+01; w1_mass_mae_loss: 1.771E+01; w_mass_mmd0_loss: 9.179E-02; w_mass_mmd1_loss: 5.614E-02
# Epoch 73; dinu_pt_loss: 1.458E+01; higgs_mass_loss: 2.908E+00; loss: 7.363E+01; mae_loss: 3.477E+01; neg_r2_loss: -8.274E-01; nu_mass_loss: 4.697E-02; val_dinu_pt_loss: 1.235E+01; val_higgs_mass_loss: 3.089E+00; val_loss: 7.368E+01; val_mae_loss: 3.460E+01; val_neg_r2_loss: -8.309E-01; val_nu_mass_loss: 4.602E-02; val_w0_mass_mae_loss: 1.447E+01; val_w1_mass_mae_loss: 1.759E+01; val_w_mass_mmd0_loss: 1.170E-01; val_w_mass_mmd1_loss: 5.700E-02; w0_mass_mae_loss: 1.489E+01; w1_mass_mae_loss: 1.769E+01; w_mass_mmd0_loss: 9.076E-02; w_mass_mmd1_loss: 5.628E-02
# Epoch 74; dinu_pt_loss: 1.442E+01; higgs_mass_loss: 2.890E+00; loss: 7.353E+01; mae_loss: 3.474E+01; neg_r2_loss: -8.278E-01; nu_mass_loss: 4.704E-02; val_dinu_pt_loss: 1.221E+01; val_higgs_mass_loss: 2.964E+00; val_loss: 7.351E+01; val_mae_loss: 3.459E+01; val_neg_r2_loss: -8.311E-01; val_nu_mass_loss: 4.651E-02; val_w0_mass_mae_loss: 1.446E+01; val_w1_mass_mae_loss: 1.759E+01; val_w_mass_mmd0_loss: 1.153E-01; val_w_mass_mmd1_loss: 5.683E-02; w0_mass_mae_loss: 1.486E+01; w1_mass_mae_loss: 1.768E+01; w_mass_mmd0_loss: 8.930E-02; w_mass_mmd1_loss: 5.611E-02
# Epoch 75; dinu_pt_loss: 1.421E+01; higgs_mass_loss: 2.879E+00; loss: 7.346E+01; mae_loss: 3.471E+01; neg_r2_loss: -8.280E-01; nu_mass_loss: 4.713E-02; val_dinu_pt_loss: 1.217E+01; val_higgs_mass_loss: 2.871E+00; val_loss: 7.327E+01; val_mae_loss: 3.459E+01; val_neg_r2_loss: -8.325E-01; val_nu_mass_loss: 4.697E-02; val_w0_mass_mae_loss: 1.443E+01; val_w1_mass_mae_loss: 1.759E+01; val_w_mass_mmd0_loss: 9.589E-02; val_w_mass_mmd1_loss: 5.648E-02; w0_mass_mae_loss: 1.487E+01; w1_mass_mae_loss: 1.767E+01; w_mass_mmd0_loss: 8.991E-02; w_mass_mmd1_loss: 5.627E-02
# Epoch 76; dinu_pt_loss: 1.417E+01; higgs_mass_loss: 2.859E+00; loss: 7.337E+01; mae_loss: 3.468E+01; neg_r2_loss: -8.283E-01; nu_mass_loss: 4.712E-02; val_dinu_pt_loss: 1.230E+01; val_higgs_mass_loss: 2.962E+00; val_loss: 7.332E+01; val_mae_loss: 3.452E+01; val_neg_r2_loss: -8.315E-01; val_nu_mass_loss: 4.616E-02; val_w0_mass_mae_loss: 1.450E+01; val_w1_mass_mae_loss: 1.762E+01; val_w_mass_mmd0_loss: 1.097E-01; val_w_mass_mmd1_loss: 5.459E-02; w0_mass_mae_loss: 1.487E+01; w1_mass_mae_loss: 1.768E+01; w_mass_mmd0_loss: 8.861E-02; w_mass_mmd1_loss: 5.559E-02
# Epoch 77; dinu_pt_loss: 1.406E+01; higgs_mass_loss: 2.853E+00; loss: 7.331E+01; mae_loss: 3.465E+01; neg_r2_loss: -8.284E-01; nu_mass_loss: 4.720E-02; val_dinu_pt_loss: 1.197E+01; val_higgs_mass_loss: 2.875E+00; val_loss: 7.321E+01; val_mae_loss: 3.451E+01; val_neg_r2_loss: -8.319E-01; val_nu_mass_loss: 4.640E-02; val_w0_mass_mae_loss: 1.450E+01; val_w1_mass_mae_loss: 1.762E+01; val_w_mass_mmd0_loss: 1.072E-01; val_w_mass_mmd1_loss: 5.680E-02; w0_mass_mae_loss: 1.488E+01; w1_mass_mae_loss: 1.766E+01; w_mass_mmd0_loss: 8.961E-02; w_mass_mmd1_loss: 5.575E-02
# Epoch 78; dinu_pt_loss: 1.388E+01; higgs_mass_loss: 2.827E+00; loss: 7.323E+01; mae_loss: 3.462E+01; neg_r2_loss: -8.287E-01; nu_mass_loss: 4.725E-02; val_dinu_pt_loss: 1.170E+01; val_higgs_mass_loss: 2.973E+00; val_loss: 7.332E+01; val_mae_loss: 3.446E+01; val_neg_r2_loss: -8.336E-01; val_nu_mass_loss: 4.726E-02; val_w0_mass_mae_loss: 1.437E+01; val_w1_mass_mae_loss: 1.755E+01; val_w_mass_mmd0_loss: 1.212E-01; val_w_mass_mmd1_loss: 5.831E-02; w0_mass_mae_loss: 1.485E+01; w1_mass_mae_loss: 1.765E+01; w_mass_mmd0_loss: 8.868E-02; w_mass_mmd1_loss: 5.582E-02
# Epoch 79; dinu_pt_loss: 1.379E+01; higgs_mass_loss: 2.804E+00; loss: 7.313E+01; mae_loss: 3.459E+01; neg_r2_loss: -8.291E-01; nu_mass_loss: 4.729E-02; val_dinu_pt_loss: 1.185E+01; val_higgs_mass_loss: 2.843E+00; val_loss: 7.323E+01; val_mae_loss: 3.448E+01; val_neg_r2_loss: -8.321E-01; val_nu_mass_loss: 4.678E-02; val_w0_mass_mae_loss: 1.453E+01; val_w1_mass_mae_loss: 1.758E+01; val_w_mass_mmd0_loss: 1.230E-01; val_w_mass_mmd1_loss: 5.593E-02; w0_mass_mae_loss: 1.485E+01; w1_mass_mae_loss: 1.765E+01; w_mass_mmd0_loss: 8.749E-02; w_mass_mmd1_loss: 5.564E-02
# Epoch 80; dinu_pt_loss: 1.369E+01; higgs_mass_loss: 2.797E+00; loss: 7.310E+01; mae_loss: 3.458E+01; neg_r2_loss: -8.291E-01; nu_mass_loss: 4.731E-02; val_dinu_pt_loss: 1.155E+01; val_higgs_mass_loss: 2.785E+00; val_loss: 7.303E+01; val_mae_loss: 3.445E+01; val_neg_r2_loss: -8.332E-01; val_nu_mass_loss: 4.711E-02; val_w0_mass_mae_loss: 1.455E+01; val_w1_mass_mae_loss: 1.757E+01; val_w_mass_mmd0_loss: 1.105E-01; val_w_mass_mmd1_loss: 5.818E-02; w0_mass_mae_loss: 1.486E+01; w1_mass_mae_loss: 1.764E+01; w_mass_mmd0_loss: 8.712E-02; w_mass_mmd1_loss: 5.611E-02
# Epoch 81; dinu_pt_loss: 1.358E+01; higgs_mass_loss: 2.775E+00; loss: 7.301E+01; mae_loss: 3.455E+01; neg_r2_loss: -8.293E-01; nu_mass_loss: 4.736E-02; val_dinu_pt_loss: 1.162E+01; val_higgs_mass_loss: 2.951E+00; val_loss: 7.329E+01; val_mae_loss: 3.442E+01; val_neg_r2_loss: -8.330E-01; val_nu_mass_loss: 4.718E-02; val_w0_mass_mae_loss: 1.441E+01; val_w1_mass_mae_loss: 1.754E+01; val_w_mass_mmd0_loss: 1.303E-01; val_w_mass_mmd1_loss: 5.657E-02; w0_mass_mae_loss: 1.487E+01; w1_mass_mae_loss: 1.764E+01; w_mass_mmd0_loss: 8.517E-02; w_mass_mmd1_loss: 5.610E-02
# ...
# Epoch 98; dinu_pt_loss: 1.282E+01; higgs_mass_loss: 2.551E+00; loss: 7.216E+01; mae_loss: 3.426E+01; neg_r2_loss: -8.318E-01; nu_mass_loss: 4.775E-02; val_dinu_pt_loss: 1.060E+01; val_higgs_mass_loss: 2.550E+00; val_loss: 7.240E+01; val_mae_loss: 3.425E+01; val_neg_r2_loss: -8.344E-01; val_nu_mass_loss: 4.740E-02; val_w0_mass_mae_loss: 1.449E+01; val_w1_mass_mae_loss: 1.752E+01; val_w_mass_mmd0_loss: 1.134E-01; val_w_mass_mmd1_loss: 5.549E-02; w0_mass_mae_loss: 1.486E+01; w1_mass_mae_loss: 1.760E+01; w_mass_mmd0_loss: 7.991E-02; w_mass_mmd1_loss: 5.456E-02
# Epoch 99; dinu_pt_loss: 1.276E+01; higgs_mass_loss: 2.535E+00; loss: 7.211E+01; mae_loss: 3.425E+01; neg_r2_loss: -8.319E-01; nu_mass_loss: 4.772E-02; val_dinu_pt_loss: 1.075E+01; val_higgs_mass_loss: 2.714E+00; val_loss: 7.252E+01; val_mae_loss: 3.422E+01; val_neg_r2_loss: -8.356E-01; val_nu_mass_loss: 4.762E-02; val_w0_mass_mae_loss: 1.444E+01; val_w1_mass_mae_loss: 1.747E+01; val_w_mass_mmd0_loss: 1.129E-01; val_w_mass_mmd1_loss: 5.843E-02; w0_mass_mae_loss: 1.484E+01; w1_mass_mae_loss: 1.758E+01; w_mass_mmd0_loss: 7.841E-02; w_mass_mmd1_loss: 5.453E-02
# Epoch 100; dinu_pt_loss: 1.274E+01; higgs_mass_loss: 2.534E+00; loss: 7.209E+01; mae_loss: 3.425E+01; neg_r2_loss: -8.320E-01; nu_mass_loss: 4.784E-02; val_dinu_pt_loss: 1.074E+01; val_higgs_mass_loss: 2.667E+00; val_loss: 7.233E+01; val_mae_loss: 3.422E+01; val_neg_r2_loss: -8.354E-01; val_nu_mass_loss: 4.765E-02; val_w0_mass_mae_loss: 1.448E+01; val_w1_mass_mae_loss: 1.744E+01; val_w_mass_mmd0_loss: 9.362E-02; val_w_mass_mmd1_loss: 5.897E-02; w0_mass_mae_loss: 1.484E+01; w1_mass_mae_loss: 1.760E+01; w_mass_mmd0_loss: 7.719E-02; w_mass_mmd1_loss: 5.479E-02
# Epoch 101; dinu_pt_loss: 1.276E+01; higgs_mass_loss: 2.528E+00; loss: 7.205E+01; mae_loss: 3.423E+01; neg_r2_loss: -8.322E-01; nu_mass_loss: 4.782E-02; val_dinu_pt_loss: 1.062E+01; val_higgs_mass_loss: 2.670E+00; val_loss: 7.246E+01; val_mae_loss: 3.422E+01; val_neg_r2_loss: -8.346E-01; val_nu_mass_loss: 4.721E-02; val_w0_mass_mae_loss: 1.449E+01; val_w1_mass_mae_loss: 1.750E+01; val_w_mass_mmd0_loss: 1.120E-01; val_w_mass_mmd1_loss: 5.658E-02; w0_mass_mae_loss: 1.485E+01; w1_mass_mae_loss: 1.758E+01; w_mass_mmd0_loss: 7.736E-02; w_mass_mmd1_loss: 5.506E-02
# Epoch 102; dinu_pt_loss: 1.271E+01; higgs_mass_loss: 2.504E+00; loss: 7.201E+01; mae_loss: 3.423E+01; neg_r2_loss: -8.323E-01; nu_mass_loss: 4.783E-02; val_dinu_pt_loss: 1.066E+01; val_higgs_mass_loss: 2.841E+00; val_loss: 7.287E+01; val_mae_loss: 3.421E+01; val_neg_r2_loss: -8.348E-01; val_nu_mass_loss: 4.745E-02; val_w0_mass_mae_loss: 1.441E+01; val_w1_mass_mae_loss: 1.747E+01; val_w_mass_mmd0_loss: 1.463E-01; val_w_mass_mmd1_loss: 5.657E-02; w0_mass_mae_loss: 1.486E+01; w1_mass_mae_loss: 1.759E+01; w_mass_mmd0_loss: 7.729E-02; w_mass_mmd1_loss: 5.451E-02
# Epoch 103; dinu_pt_loss: 1.275E+01; higgs_mass_loss: 2.502E+00; loss: 7.199E+01; mae_loss: 3.422E+01; neg_r2_loss: -8.323E-01; nu_mass_loss: 4.778E-02; val_dinu_pt_loss: 1.058E+01; val_higgs_mass_loss: 2.684E+00; val_loss: 7.220E+01; val_mae_loss: 3.417E+01; val_neg_r2_loss: -8.352E-01; val_nu_mass_loss: 4.764E-02; val_w0_mass_mae_loss: 1.454E+01; val_w1_mass_mae_loss: 1.748E+01; val_w_mass_mmd0_loss: 9.011E-02; val_w_mass_mmd1_loss: 5.532E-02; w0_mass_mae_loss: 1.485E+01; w1_mass_mae_loss: 1.758E+01; w_mass_mmd0_loss: 7.692E-02; w_mass_mmd1_loss: 5.451E-02
# Epoch 104; dinu_pt_loss: 1.276E+01; higgs_mass_loss: 2.486E+00; loss: 7.194E+01; mae_loss: 3.420E+01; neg_r2_loss: -8.325E-01; nu_mass_loss: 4.789E-02; val_dinu_pt_loss: 1.082E+01; val_higgs_mass_loss: 2.512E+00; val_loss: 7.230E+01; val_mae_loss: 3.421E+01; val_neg_r2_loss: -8.351E-01; val_nu_mass_loss: 4.765E-02; val_w0_mass_mae_loss: 1.457E+01; val_w1_mass_mae_loss: 1.747E+01; val_w_mass_mmd0_loss: 1.111E-01; val_w_mass_mmd1_loss: 5.827E-02; w0_mass_mae_loss: 1.487E+01; w1_mass_mae_loss: 1.759E+01; w_mass_mmd0_loss: 7.673E-02; w_mass_mmd1_loss: 5.480E-02
# Epoch 105; dinu_pt_loss: 1.264E+01; higgs_mass_loss: 2.491E+00; loss: 7.190E+01; mae_loss: 3.418E+01; neg_r2_loss: -8.326E-01; nu_mass_loss: 4.788E-02; val_dinu_pt_loss: 1.063E+01; val_higgs_mass_loss: 2.546E+00; val_loss: 7.234E+01; val_mae_loss: 3.421E+01; val_neg_r2_loss: -8.353E-01; val_nu_mass_loss: 4.771E-02; val_w0_mass_mae_loss: 1.448E+01; val_w1_mass_mae_loss: 1.747E+01; val_w_mass_mmd0_loss: 1.152E-01; val_w_mass_mmd1_loss: 5.802E-02; w0_mass_mae_loss: 1.485E+01; w1_mass_mae_loss: 1.759E+01; w_mass_mmd0_loss: 7.612E-02; w_mass_mmd1_loss: 5.478E-02
# Epoch 106; dinu_pt_loss: 1.267E+01; higgs_mass_loss: 2.480E+00; loss: 7.187E+01; mae_loss: 3.418E+01; neg_r2_loss: -8.326E-01; nu_mass_loss: 4.796E-02; val_dinu_pt_loss: 1.069E+01; val_higgs_mass_loss: 2.602E+00; val_loss: 7.242E+01; val_mae_loss: 3.420E+01; val_neg_r2_loss: -8.357E-01; val_nu_mass_loss: 4.741E-02; val_w0_mass_mae_loss: 1.455E+01; val_w1_mass_mae_loss: 1.758E+01; val_w_mass_mmd0_loss: 1.202E-01; val_w_mass_mmd1_loss: 5.639E-02; w0_mass_mae_loss: 1.483E+01; w1_mass_mae_loss: 1.757E+01; w_mass_mmd0_loss: 7.504E-02; w_mass_mmd1_loss: 5.433E-02
# Epoch 107; dinu_pt_loss: 1.267E+01; higgs_mass_loss: 2.458E+00; loss: 7.183E+01; mae_loss: 3.417E+01; neg_r2_loss: -8.328E-01; nu_mass_loss: 4.791E-02; val_dinu_pt_loss: 1.056E+01; val_higgs_mass_loss: 2.668E+00; val_loss: 7.243E+01; val_mae_loss: 3.418E+01; val_neg_r2_loss: -8.350E-01; val_nu_mass_loss: 4.728E-02; val_w0_mass_mae_loss: 1.449E+01; val_w1_mass_mae_loss: 1.747E+01; val_w_mass_mmd0_loss: 1.199E-01; val_w_mass_mmd1_loss: 5.544E-02; w0_mass_mae_loss: 1.484E+01; w1_mass_mae_loss: 1.759E+01; w_mass_mmd0_loss: 7.405E-02; w_mass_mmd1_loss: 5.412E-02
# Epoch 108; dinu_pt_loss: 1.265E+01; higgs_mass_loss: 2.450E+00; loss: 7.181E+01; mae_loss: 3.417E+01; neg_r2_loss: -8.329E-01; nu_mass_loss: 4.791E-02; val_dinu_pt_loss: 1.051E+01; val_higgs_mass_loss: 2.755E+00; val_loss: 7.245E+01; val_mae_loss: 3.420E+01; val_neg_r2_loss: -8.352E-01; val_nu_mass_loss: 4.754E-02; val_w0_mass_mae_loss: 1.445E+01; val_w1_mass_mae_loss: 1.752E+01; val_w_mass_mmd0_loss: 1.055E-01; val_w_mass_mmd1_loss: 5.505E-02; w0_mass_mae_loss: 1.484E+01; w1_mass_mae_loss: 1.759E+01; w_mass_mmd0_loss: 7.416E-02; w_mass_mmd1_loss: 5.394E-02
# Epoch 109; dinu_pt_loss: 1.258E+01; higgs_mass_loss: 2.442E+00; loss: 7.176E+01; mae_loss: 3.415E+01; neg_r2_loss: -8.330E-01; nu_mass_loss: 4.793E-02; val_dinu_pt_loss: 1.080E+01; val_higgs_mass_loss: 2.471E+00; val_loss: 7.216E+01; val_mae_loss: 3.419E+01; val_neg_r2_loss: -8.358E-01; val_nu_mass_loss: 4.807E-02; val_w0_mass_mae_loss: 1.451E+01; val_w1_mass_mae_loss: 1.749E+01; val_w_mass_mmd0_loss: 1.059E-01; val_w_mass_mmd1_loss: 5.856E-02; w0_mass_mae_loss: 1.484E+01; w1_mass_mae_loss: 1.759E+01; w_mass_mmd0_loss: 7.363E-02; w_mass_mmd1_loss: 5.392E-02
# Epoch 110; dinu_pt_loss: 1.260E+01; higgs_mass_loss: 2.433E+00; loss: 7.174E+01; mae_loss: 3.414E+01; neg_r2_loss: -8.331E-01; nu_mass_loss: 4.790E-02; val_dinu_pt_loss: 1.039E+01; val_higgs_mass_loss: 2.801E+00; val_loss: 7.260E+01; val_mae_loss: 3.417E+01; val_neg_r2_loss: -8.353E-01; val_nu_mass_loss: 4.780E-02; val_w0_mass_mae_loss: 1.451E+01; val_w1_mass_mae_loss: 1.751E+01; val_w_mass_mmd0_loss: 1.267E-01; val_w_mass_mmd1_loss: 5.591E-02; w0_mass_mae_loss: 1.484E+01; w1_mass_mae_loss: 1.759E+01; w_mass_mmd0_loss: 7.451E-02; w_mass_mmd1_loss: 5.383E-02
# Epoch 111; dinu_pt_loss: 1.247E+01; higgs_mass_loss: 2.422E+00; loss: 7.171E+01; mae_loss: 3.413E+01; neg_r2_loss: -8.331E-01; nu_mass_loss: 4.790E-02; val_dinu_pt_loss: 1.055E+01; val_higgs_mass_loss: 2.708E+00; val_loss: 7.267E+01; val_mae_loss: 3.415E+01; val_neg_r2_loss: -8.355E-01; val_nu_mass_loss: 4.753E-02; val_w0_mass_mae_loss: 1.450E+01; val_w1_mass_mae_loss: 1.745E+01; val_w_mass_mmd0_loss: 1.507E-01; val_w_mass_mmd1_loss: 5.705E-02; w0_mass_mae_loss: 1.484E+01; w1_mass_mae_loss: 1.759E+01; w_mass_mmd0_loss: 7.403E-02; w_mass_mmd1_loss: 5.379E-02
# Epoch 112; dinu_pt_loss: 1.245E+01; higgs_mass_loss: 2.417E+00; loss: 7.167E+01; mae_loss: 3.412E+01; neg_r2_loss: -8.332E-01; nu_mass_loss: 4.793E-02; val_dinu_pt_loss: 1.047E+01; val_higgs_mass_loss: 2.721E+00; val_loss: 7.237E+01; val_mae_loss: 3.411E+01; val_neg_r2_loss: -8.355E-01; val_nu_mass_loss: 4.776E-02; val_w0_mass_mae_loss: 1.451E+01; val_w1_mass_mae_loss: 1.747E+01; val_w_mass_mmd0_loss: 1.208E-01; val_w_mass_mmd1_loss: 5.638E-02; w0_mass_mae_loss: 1.485E+01; w1_mass_mae_loss: 1.760E+01; w_mass_mmd0_loss: 7.313E-02; w_mass_mmd1_loss: 5.352E-02
# Epoch 113; dinu_pt_loss: 1.247E+01; higgs_mass_loss: 2.408E+00; loss: 7.163E+01; mae_loss: 3.410E+01; neg_r2_loss: -8.334E-01; nu_mass_loss: 4.795E-02; val_dinu_pt_loss: 1.063E+01; val_higgs_mass_loss: 2.720E+00; val_loss: 7.233E+01; val_mae_loss: 3.414E+01; val_neg_r2_loss: -8.348E-01; val_nu_mass_loss: 4.722E-02; val_w0_mass_mae_loss: 1.446E+01; val_w1_mass_mae_loss: 1.750E+01; val_w_mass_mmd0_loss: 1.122E-01; val_w_mass_mmd1_loss: 5.415E-02; w0_mass_mae_loss: 1.483E+01; w1_mass_mae_loss: 1.759E+01; w_mass_mmd0_loss: 7.391E-02; w_mass_mmd1_loss: 5.331E-02
# Epoch 114; dinu_pt_loss: 1.250E+01; higgs_mass_loss: 2.397E+00; loss: 7.161E+01; mae_loss: 3.410E+01; neg_r2_loss: -8.334E-01; nu_mass_loss: 4.796E-02; val_dinu_pt_loss: 1.034E+01; val_higgs_mass_loss: 2.661E+00; val_loss: 7.228E+01; val_mae_loss: 3.414E+01; val_neg_r2_loss: -8.357E-01; val_nu_mass_loss: 4.767E-02; val_w0_mass_mae_loss: 1.458E+01; val_w1_mass_mae_loss: 1.749E+01; val_w_mass_mmd0_loss: 1.122E-01; val_w_mass_mmd1_loss: 5.541E-02; w0_mass_mae_loss: 1.483E+01; w1_mass_mae_loss: 1.759E+01; w_mass_mmd0_loss: 7.262E-02; w_mass_mmd1_loss: 5.324E-02
# Epoch 115; dinu_pt_loss: 1.250E+01; higgs_mass_loss: 2.384E+00; loss: 7.156E+01; mae_loss: 3.409E+01; neg_r2_loss: -8.336E-01; nu_mass_loss: 4.801E-02; val_dinu_pt_loss: 1.032E+01; val_higgs_mass_loss: 2.721E+00; val_loss: 7.232E+01; val_mae_loss: 3.414E+01; val_neg_r2_loss: -8.358E-01; val_nu_mass_loss: 4.773E-02; val_w0_mass_mae_loss: 1.448E+01; val_w1_mass_mae_loss: 1.751E+01; val_w_mass_mmd0_loss: 1.114E-01; val_w_mass_mmd1_loss: 5.334E-02; w0_mass_mae_loss: 1.484E+01; w1_mass_mae_loss: 1.758E+01; w_mass_mmd0_loss: 7.228E-02; w_mass_mmd1_loss: 5.328E-02
# Epoch 116; dinu_pt_loss: 1.249E+01; higgs_mass_loss: 2.385E+00; loss: 7.154E+01; mae_loss: 3.408E+01; neg_r2_loss: -8.337E-01; nu_mass_loss: 4.797E-02; val_dinu_pt_loss: 1.042E+01; val_higgs_mass_loss: 2.547E+00; val_loss: 7.220E+01; val_mae_loss: 3.414E+01; val_neg_r2_loss: -8.361E-01; val_nu_mass_loss: 4.761E-02; val_w0_mass_mae_loss: 1.447E+01; val_w1_mass_mae_loss: 1.745E+01; val_w_mass_mmd0_loss: 1.154E-01; val_w_mass_mmd1_loss: 5.792E-02; w0_mass_mae_loss: 1.485E+01; w1_mass_mae_loss: 1.758E+01; w_mass_mmd0_loss: 7.205E-02; w_mass_mmd1_loss: 5.332E-02
# Epoch 117; dinu_pt_loss: 1.248E+01; higgs_mass_loss: 2.375E+00; loss: 7.151E+01; mae_loss: 3.407E+01; neg_r2_loss: -8.339E-01; nu_mass_loss: 4.787E-02; val_dinu_pt_loss: 1.046E+01; val_higgs_mass_loss: 2.753E+00; val_loss: 7.251E+01; val_mae_loss: 3.415E+01; val_neg_r2_loss: -8.354E-01; val_nu_mass_loss: 4.728E-02; val_w0_mass_mae_loss: 1.450E+01; val_w1_mass_mae_loss: 1.750E+01; val_w_mass_mmd0_loss: 1.257E-01; val_w_mass_mmd1_loss: 5.576E-02; w0_mass_mae_loss: 1.484E+01; w1_mass_mae_loss: 1.759E+01; w_mass_mmd0_loss: 7.169E-02; w_mass_mmd1_loss: 5.320E-02
# Epoch 118; dinu_pt_loss: 1.241E+01; higgs_mass_loss: 2.368E+00; loss: 7.147E+01; mae_loss: 3.406E+01; neg_r2_loss: -8.339E-01; nu_mass_loss: 4.799E-02; val_dinu_pt_loss: 1.051E+01; val_higgs_mass_loss: 2.645E+00; val_loss: 7.226E+01; val_mae_loss: 3.413E+01; val_neg_r2_loss: -8.359E-01; val_nu_mass_loss: 4.733E-02; val_w0_mass_mae_loss: 1.445E+01; val_w1_mass_mae_loss: 1.748E+01; val_w_mass_mmd0_loss: 1.152E-01; val_w_mass_mmd1_loss: 5.483E-02; w0_mass_mae_loss: 1.484E+01; w1_mass_mae_loss: 1.759E+01; w_mass_mmd0_loss: 7.095E-02; w_mass_mmd1_loss: 5.335E-02
# Epoch 119; dinu_pt_loss: 1.239E+01; higgs_mass_loss: 2.363E+00; loss: 7.145E+01; mae_loss: 3.405E+01; neg_r2_loss: -8.340E-01; nu_mass_loss: 4.808E-02; val_dinu_pt_loss: 1.038E+01; val_higgs_mass_loss: 2.852E+00; val_loss: 7.250E+01; val_mae_loss: 3.413E+01; val_neg_r2_loss: -8.351E-01; val_nu_mass_loss: 4.725E-02; val_w0_mass_mae_loss: 1.449E+01; val_w1_mass_mae_loss: 1.752E+01; val_w_mass_mmd0_loss: 1.216E-01; val_w_mass_mmd1_loss: 5.308E-02; w0_mass_mae_loss: 1.483E+01; w1_mass_mae_loss: 1.760E+01; w_mass_mmd0_loss: 7.099E-02; w_mass_mmd1_loss: 5.267E-02
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752126857.740754  114290 service.cc:145] XLA service 0x751544062360 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752126857.740780  114290 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752126865.459616  114425 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752126865.654192  114438 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1752126865.841235  114439 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_15', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1752126865.990465  114439 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752126866.115650  114421 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1752126874.498534  114290 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_31', 8 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1752126874.516090  114290 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# I0000 00:00:1752126886.919734  114792 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 12 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1752126886.956759  114785 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_18', 24 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1752126887.215200  114781 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1752126887.532322  114789 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 128 bytes spill stores, 128 bytes spill loads
#
# I0000 00:00:1752126897.409164  114299 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_31', 8 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1752126899.936128  115198 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_10', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752126899.989480  115176 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_10', 24 bytes spill stores, 24 bytes spill loads

# %%
pred_y = model.predict(test_x)
# Out:
# 2189/2189 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
# I0000 00:00:1752127854.581578  141781 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752127859.969298  141909 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 8 bytes spill stores, 8 bytes spill loads

# %%
label_lead_w_px = test_y[:, 0]
label_lead_w_py = test_y[:, 1]
label_lead_w_pz = test_y[:, 2]
label_lead_w_energy = test_y[:, 3]
label_sublead_w_px = test_y[:, 4]
label_sublead_w_py = test_y[:, 5]
label_sublead_w_pz = test_y[:, 6]
label_sublead_w_energy = test_y[:, 7]

pred_lead_w_px = pred_y[:, 0]
pred_lead_w_py = pred_y[:, 1]
pred_lead_w_pz = pred_y[:, 2]
pred_lead_w_energy = pred_y[:, 3]
pred_sublead_w_px = pred_y[:, 4]
pred_sublead_w_py = pred_y[:, 5]
pred_sublead_w_pz = pred_y[:, 6]
pred_sublead_w_energy = pred_y[:, 7]

# %%
# px

# lead
plt.hist(label_lead_w_px, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_px, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_0}_{x}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_px,
	pred_lead_w_px,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_0}_{x}$", loc='right')
plt.show()

# sublead px
plt.hist(label_sublead_w_px, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_px, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_1}_{x}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_px,
	pred_sublead_w_px,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_1}_{x}$", loc='right')
plt.show()

# %%
# py

# lead
plt.hist(label_lead_w_py, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_py, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_0}_{y}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_py,
	pred_lead_w_py,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_0}_{y}$", loc='right')
plt.show()

# sublead py
plt.hist(label_sublead_w_py, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_py, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_1}_{y}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_py,
	pred_sublead_w_py,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_1}_{y}$", loc='right')
plt.show()

# %%
# pz

# lead
plt.hist(label_lead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_0}_{z}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_pz,
	pred_lead_w_pz,
	bins=(51, 51),
	range=([-1000, 1000], [-1000, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_0}_{z}$", loc='right')
plt.show()

# sublead pz
plt.hist(label_sublead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_1}_{z}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_pz,
	pred_sublead_w_pz,
	bins=(51, 51),
	range=([-1000, 1000], [-1000, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_1}_{z}$", loc='right')
plt.show()

# %%
# energy

# lead
plt.hist(label_lead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$E^{\ell_0}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_energy,
	pred_lead_w_energy,
	bins=(51, 51),
	range=([0, 1000], [0, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$E^{\ell_0}$", loc='right')
plt.show()

# sublead energy
plt.hist(label_sublead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$E^{\ell_1}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_energy,
	pred_sublead_w_energy,
	bins=(51, 51),
	range=([0, 1000], [0, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$E^{\ell_1}$", loc='right')
plt.show()

# %%
# W inv mass

w_lead_pred = np.sqrt(
	np.square(pred_lead_w_energy)
	- np.square(pred_lead_w_px)
	- np.square(pred_lead_w_py)
	- np.square(pred_lead_w_pz)
)
w_sublead_pred = np.sqrt(
	np.square(pred_sublead_w_energy)
	- np.square(pred_sublead_w_px)
	- np.square(pred_sublead_w_py)
	- np.square(pred_sublead_w_pz)
)
w_lead_label = np.sqrt(
	np.square(label_lead_w_energy)
	- np.square(label_lead_w_px)
	- np.square(label_lead_w_py)
	- np.square(label_lead_w_pz)
)
w_sublead_label = np.sqrt(
	np.square(label_sublead_w_energy)
	- np.square(label_sublead_w_px)
	- np.square(label_sublead_w_py)
	- np.square(label_sublead_w_pz)
)

plt.hist(w_lead_pred, bins=np.linspace(0, 100, 51), label=r"Pred", histtype="step", linewidth=2, color="red")
plt.hist(w_lead_label, bins=np.linspace(0, 100, 51), label=r"Label", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.xlim(0, 100)
plt.show()

plt.hist2d(
	w_lead_pred,
	w_lead_label,
	bins=(51, 51),
	range=([0, 100], [0, 100]),
	cmap="viridis",
	cmin=1,
	norm = LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel("Pred")
plt.xlabel("Label")
plt.title(r"$m_{W_0}$", loc='right')
plt.show()


plt.hist(w_sublead_pred, bins=np.linspace(0, 100, 51), label="Pred", histtype="step", linewidth=2, color="red")
plt.hist(w_sublead_label, bins=np.linspace(0, 100, 51), label="Label", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.xlim(0, 100)
plt.show()

plt.hist2d(
	w_sublead_pred,
	w_sublead_label,
	bins=(51, 51),
	range=([0, 100], [0, 100]),
	cmap="viridis",
	cmin=1,
	norm = LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel("Pred")
plt.xlabel("Label")
plt.title(r"$m_{W_1}$", loc='right')
plt.show()

# %%
# WW* inv mass
ww_pred = np.sqrt(
	np.square(pred_lead_w_energy + pred_sublead_w_energy)
	- np.square(pred_lead_w_px + pred_sublead_w_px)
	- np.square(pred_lead_w_py + pred_sublead_w_py)
	- np.square(pred_lead_w_pz + pred_sublead_w_pz)
)
ww_label = np.sqrt(
	np.square(label_lead_w_energy + label_sublead_w_energy)
	- np.square(label_lead_w_px + label_sublead_w_px)
	- np.square(label_lead_w_py + label_sublead_w_py)
	- np.square(label_lead_w_pz + label_sublead_w_pz)
)
plt.hist(ww_pred, bins=np.linspace(100, 140, 51), label="Pred", histtype="step", linewidth=2, color="red")
plt.hist(ww_label, bins=np.linspace(100, 140, 51), label="Label", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.xlim(100, 140)
plt.show()

plt.hist2d(
	ww_pred,
	ww_label,
	bins=(51, 51),
	range=([100, 140], [100, 140]),
	cmap="viridis",
	cmin=1,
	norm = LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel("Pred")
plt.xlabel("Label")
plt.title(r"$m_{WW^\ast}$", loc='right')
plt.show()
