# %%
import time
t_start = time.time()

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"  # suppress tensorflow information messages

import sys
import numpy as np
from scipy import stats
import scipy as sp
import multiprocessing
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm, Normalize
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbModelCheckpoint

HOME_PATH = os.path.abspath("/root/work/QE-mls") # path to QE_mls
sys.path.append(HOME_PATH + "/qe")
print("Home path:", HOME_PATH)

# custom modules
import paper_plot as pp
# Import the W boson regressor module
import nn
nn.BATCH_SIZE = 1024
# Out:
# Home path: /root/work/QE-mls

# %%
# ROOT need to be imported after tensorflow
import ROOT
from ROOT import TLorentzVector, TVector3

# some global variables
dir_name = HOME_PATH + "/14th_trial/reg_main/ww_resregressor_result/"
plot = pp.Plotter()
WORKERS = 16

# %%
import h5py


def load_particles_from_h5(filename="mc20_truth.h5"):
    """
    Load particle data from an HDF5 file

    Args:
        filename: Path to the HDF5 file

    Returns:
        Dictionary with the loaded data
    """
    result = {}

    with h5py.File(filename, "r") as f:
        # For each group in the file
        for group_name in f.keys():
            group_data = {}

            # Load datasets (numpy arrays)
            for dataset_name in f[group_name].keys():
                group_data[dataset_name] = f[group_name][dataset_name][:]

            # Load attributes (scalars)
            for attr_name, attr_value in f[group_name].attrs.items():
                group_data[attr_name] = attr_value

            result[group_name] = group_data

    return result

# %%
mc20_data = load_particles_from_h5("/root/data/mc20_truth.h5")
mc20_data.keys()
# Out:
# dict_keys(['higgs', 'lead_w', 'sublead_w', 'truth_dilep', 'truth_dilep_car', 'truth_lead_lep', 'truth_lead_lep_car', 'truth_lead_nu', 'truth_lead_nu_car', 'truth_sublead_lep', 'truth_sublead_lep_car', 'truth_sublead_nu', 'truth_sublead_nu_car'])

# %%
# SM truth
truth_lead_lep = mc20_data["truth_lead_lep"]
truth_sublead_lep = mc20_data["truth_sublead_lep"]
truth_lead_nu = mc20_data["truth_lead_nu"]
truth_sublead_nu = mc20_data["truth_sublead_nu"]
truth_lead_lep_p4 = mc20_data["truth_lead_lep"]["p4"]
truth_sublead_lep_p4 = mc20_data["truth_sublead_lep"]["p4"]
truth_lead_nu_p4 = mc20_data["truth_lead_nu"]["p4"]
truth_sublead_nu_p4 = mc20_data["truth_sublead_nu"]["p4"]
truth_met_pt = np.sqrt(np.square((truth_lead_nu_p4 + truth_sublead_nu_p4)[...,0:2]).sum(axis=-1))

# CAR truth
truth_lead_lep_car = mc20_data["truth_lead_lep_car"]
truth_sublead_lep_car = mc20_data["truth_sublead_lep_car"]
truth_lead_nu_car = mc20_data["truth_lead_nu_car"]
truth_sublead_nu_car = mc20_data["truth_sublead_nu_car"]
truth_lead_lep_car_p4 = mc20_data["truth_lead_lep_car"]["p4"]
truth_sublead_lep_car_p4 = mc20_data["truth_sublead_lep_car"]["p4"]
truth_lead_nu_car_p4 = mc20_data["truth_lead_nu_car"]["p4"]
truth_sublead_nu_car_p4 = mc20_data["truth_sublead_nu_car"]["p4"]
truth_met_pt_car = np.sqrt(np.square((truth_lead_nu_car_p4 + truth_sublead_nu_car_p4)[...,0:2]).sum(axis=-1))

# W bosons (SM and CAR use the same W bosons data)
w_lead_p4 = mc20_data["lead_w"]["p4"]
w_sublead_p4 = mc20_data["sublead_w"]["p4"]

# %%
print("Truth: pre-cut")
cut_pre_pt_lead = truth_lead_lep["pt"] > 22
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = truth_sublead_lep["pt"] > 15
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.square(truth_lead_lep["energy"] + truth_sublead_lep["energy"])
    - np.square(truth_lead_lep["px"] + truth_sublead_lep["px"])
    - np.square(truth_lead_lep["py"] + truth_sublead_lep["py"])
    - np.square(truth_lead_lep["pz"] + truth_sublead_lep["pz"])
    > 10**2
)
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = truth_met_pt > 20
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print("Total", len(truth_lead_lep["energy"]) - np.sum(PRE_CUT * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# CAR
print("")
print("CAR: pre-cut")
cut_pre_pt_lead = truth_lead_lep_car["pt"] > 22
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = truth_sublead_lep_car["pt"] > 15
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.square(truth_lead_lep_car["energy"] + truth_sublead_lep_car["energy"])
    - np.square(truth_lead_lep_car["px"] + truth_sublead_lep_car["px"])
    - np.square(truth_lead_lep_car["py"] + truth_sublead_lep_car["py"])
    - np.square(truth_lead_lep_car["pz"] + truth_sublead_lep_car["pz"])
    > 10**2
)
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = truth_met_pt_car > 20
print(len(truth_lead_lep_car["energy"]) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT_CAR = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print("Total", len(truth_lead_lep_car["energy"]) - np.sum(PRE_CUT_CAR * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)
# Out:
# Truth: pre-cut
# 260653
# 1174171
# 148392
# 287355
# Total 1502903
#
# CAR: pre-cut
# 336735
# 1292162
# 65248
# 441435
# Total 1634918

# %%
# force to use the same cuts for both truth and CAR

PRE_CUT_INST = PRE_CUT_CAR & PRE_CUT
print("Total", np.sum(PRE_CUT_INST * 1))
# Out:
# Total 700374

# %%
# training objects
lead_lep_px = np.concatenate([truth_lead_lep["px"][PRE_CUT_INST], truth_lead_lep_car["px"][PRE_CUT_INST]])
lead_lep_py = np.concatenate([truth_lead_lep["py"][PRE_CUT_INST], truth_lead_lep_car["py"][PRE_CUT_INST]])
lead_lep_pz = np.concatenate([truth_lead_lep["pz"][PRE_CUT_INST], truth_lead_lep_car["pz"][PRE_CUT_INST]])
lead_lep_energy = np.concatenate([truth_lead_lep["energy"][PRE_CUT_INST], truth_lead_lep_car["energy"][PRE_CUT_INST]])
sublead_lep_px = np.concatenate([truth_sublead_lep["px"][PRE_CUT_INST], truth_sublead_lep_car["px"][PRE_CUT_INST]])
sublead_lep_py = np.concatenate([truth_sublead_lep["py"][PRE_CUT_INST], truth_sublead_lep_car["py"][PRE_CUT_INST]])
sublead_lep_pz = np.concatenate([truth_sublead_lep["pz"][PRE_CUT_INST], truth_sublead_lep_car["pz"][PRE_CUT_INST]])
sublead_lep_energy = np.concatenate([truth_sublead_lep["energy"][PRE_CUT_INST], truth_sublead_lep_car["energy"][PRE_CUT_INST]])
lead_nu_px = np.concatenate([truth_lead_nu["px"][PRE_CUT_INST], truth_lead_nu_car["px"][PRE_CUT_INST]])
lead_nu_py = np.concatenate([truth_lead_nu["py"][PRE_CUT_INST], truth_lead_nu_car["py"][PRE_CUT_INST]])
sublead_nu_px = np.concatenate([truth_sublead_nu["px"][PRE_CUT_INST], truth_sublead_nu_car["px"][PRE_CUT_INST]])
sublead_nu_py = np.concatenate([truth_sublead_nu["py"][PRE_CUT_INST], truth_sublead_nu_car["py"][PRE_CUT_INST]])
met_px = lead_nu_px + sublead_nu_px
met_py = lead_nu_py + sublead_nu_py

np.random.seed(nn.SEED)
shuffle_ind = np.random.permutation(len(lead_lep_px))

train = np.column_stack(
    (
        lead_lep_px,
        lead_lep_py,
        lead_lep_pz,
        lead_lep_energy,
        sublead_lep_px,
        sublead_lep_py,
        sublead_lep_pz,
        sublead_lep_energy,
        met_px,
        met_py,
    )
)

train = train[shuffle_ind]
print("Training objects shape:", train.shape)
# Out:
# Training objects shape: (1400748, 10)

# %%
# target objects

w_lead = mc20_data["lead_w"]
w_sublead = mc20_data["sublead_w"]
target = np.column_stack(
    (
        np.concatenate([w_lead["px"][PRE_CUT_INST], w_lead["px"][PRE_CUT_INST]]),
        np.concatenate([w_lead["py"][PRE_CUT_INST], w_lead["py"][PRE_CUT_INST]]),
        np.concatenate([w_lead["pz"][PRE_CUT_INST], w_lead["pz"][PRE_CUT_INST]]),
        np.concatenate([w_lead["energy"][PRE_CUT_INST], w_lead["energy"][PRE_CUT_INST]]),
        np.concatenate([w_sublead["px"][PRE_CUT_INST], w_sublead["px"][PRE_CUT_INST]]),
        np.concatenate([w_sublead["py"][PRE_CUT_INST], w_sublead["py"][PRE_CUT_INST]]),
        np.concatenate([w_sublead["pz"][PRE_CUT_INST], w_sublead["pz"][PRE_CUT_INST]]),
        np.concatenate([w_sublead["energy"][PRE_CUT_INST], w_sublead["energy"][PRE_CUT_INST]]),
        np.concatenate([w_lead["m"][PRE_CUT_INST], w_lead["m"][PRE_CUT_INST]]),
        np.concatenate([w_sublead["m"][PRE_CUT_INST], w_sublead["m"][PRE_CUT_INST]]),
    )
)

target = target[shuffle_ind]
print("Target objects shape:", target.shape)
# Out:
# Target objects shape: (1400748, 10)

# %%
# Train-test split
if len(train) == len(target):
	indices = np.arange(len(train))
else:
	sys.exit("Error: train and targe shapes do not match!")

train_idx, temp_idx = train_test_split(
	indices, train_size=0.8, random_state=nn.SEED
)
valid_idx, test_idx = train_test_split(
	temp_idx, train_size=0.5, random_state=nn.SEED
)

train_x, valid_x, test_x = train[train_idx], train[valid_idx], train[test_idx]
train_y, valid_y, test_y = target[train_idx], target[valid_idx], target[test_idx]

print("Train shape:", train_x.shape, "Valid shape:", valid_x.shape, "Test shape:", test_x.shape)
# Out:
# Train shape: (1120598, 10) Valid shape: (140075, 10) Test shape: (140075, 10)

# %%
# W&B initialization
wandb.init(
    project='PcRes regressor mixing training', 
    name='mae batch_size: %d' % nn.BATCH_SIZE)
config = wandb.config
config.batch_size = nn.BATCH_SIZE

# Create datasets
train_dataset = (
	tf.data.Dataset.from_tensor_slices((train_x, train_y))
	.cache()
	.batch(nn.BATCH_SIZE)
	.prefetch(tf.data.AUTOTUNE)
)
valid_dataset = (
	tf.data.Dataset.from_tensor_slices((valid_x, valid_y))
	.cache()
	.batch(nn.BATCH_SIZE)
	.prefetch(tf.data.AUTOTUNE)
)

# Build and train model
base_model = nn.build_model(input_shape=train_x.shape[-1])
model = nn.CustomModel(base_model)
model.summary()
model.compile(
	optimizer=tf.keras.optimizers.Adam(learning_rate=nn.LEARNING_RATE),
	loss_weights=nn.LOSS_WEIGHTS,
)

callbacks = [
	tf.keras.callbacks.EarlyStopping(
		monitor="val_loss", patience=10, restore_best_weights=True
	),
	nn.EpochUpdater(),
	nn.LambdaTracker(),
	WandbMetricsLogger(), 
    # WandbModelCheckpoint(
    #     "best_val_loss.weights.h5",
    #     monitor="val_loss",
    # ),
]

history = model.fit(
	train_dataset,
	validation_data=valid_dataset,
	epochs=nn.EPOCHS,
	callbacks=callbacks,
	verbose=0,
)
# Out:
# wandb: Currently logged in as: yygarypeng (nthu-expt-hep) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/root/work/QE-mls/14th_trial/reg_main/wandb/run-20250705_020749-aoxb8pro</code>
# Syncing run <strong><a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20mixing%20training/runs/aoxb8pro' target="_blank">mae batch_size: 1024</a></strong> to <a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20mixing%20training' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20mixing%20training' target="_blank">https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20mixing%20training</a>
#  View run at <a href='https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20mixing%20training/runs/aoxb8pro' target="_blank">https://wandb.ai/nthu-expt-hep/PcRes%20regressor%20mixing%20training/runs/aoxb8pro</a>
# Model: "custom_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional (Functional)         │ (None, 8)              │     1,020,134 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,020,134 (3.89 MB)
#  Trainable params: 1,008,294 (3.85 MB)
#  Non-trainable params: 11,840 (46.25 KB)
# Epoch 0; dinu_pt_loss: 6.357E+01; higgs_mass_loss: 5.339E+01; loss: 1.778E+02; mae_loss: 5.233E+01; neg_r2_loss: -6.703E-01; nu_mass_loss: 6.945E-03; val_dinu_pt_loss: 6.275E+01; val_higgs_mass_loss: 3.700E+01; val_loss: 1.513E+02; val_mae_loss: 5.205E+01; val_neg_r2_loss: -6.699E-01; val_nu_mass_loss: 9.747E-03; val_w0_mass_mae_loss: 3.344E+01; val_w1_mass_mae_loss: 2.017E+01; val_w_mass_mmd0_loss: 1.107E+00; val_w_mass_mmd1_loss: 1.643E-01; w0_mass_mae_loss: 4.276E+01; w1_mass_mae_loss: 2.535E+01; w_mass_mmd0_loss: 1.720E+00; w_mass_mmd1_loss: 7.483E-01
# Epoch 1; dinu_pt_loss: 6.190E+01; higgs_mass_loss: 3.027E+01; loss: 1.424E+02; mae_loss: 5.177E+01; neg_r2_loss: -6.712E-01; nu_mass_loss: 1.023E-02; val_dinu_pt_loss: 6.096E+01; val_higgs_mass_loss: 2.441E+01; val_loss: 1.350E+02; val_mae_loss: 5.153E+01; val_neg_r2_loss: -6.711E-01; val_nu_mass_loss: 1.184E-02; val_w0_mass_mae_loss: 2.614E+01; val_w1_mass_mae_loss: 1.848E+01; val_w_mass_mmd0_loss: 8.372E-01; val_w_mass_mmd1_loss: 1.092E-01; w0_mass_mae_loss: 2.880E+01; w1_mass_mae_loss: 1.910E+01; w_mass_mmd0_loss: 9.421E-01; w_mass_mmd1_loss: 1.269E-01
# Epoch 2; dinu_pt_loss: 6.049E+01; higgs_mass_loss: 1.953E+01; loss: 1.285E+02; mae_loss: 5.132E+01; neg_r2_loss: -6.722E-01; nu_mass_loss: 1.222E-02; val_dinu_pt_loss: 5.987E+01; val_higgs_mass_loss: 1.453E+01; val_loss: 1.227E+02; val_mae_loss: 5.115E+01; val_neg_r2_loss: -6.721E-01; val_nu_mass_loss: 1.365E-02; val_w0_mass_mae_loss: 2.130E+01; val_w1_mass_mae_loss: 1.768E+01; val_w_mass_mmd0_loss: 6.332E-01; val_w_mass_mmd1_loss: 1.039E-01; w0_mass_mae_loss: 2.323E+01; w1_mass_mae_loss: 1.788E+01; w_mass_mmd0_loss: 6.997E-01; w_mass_mmd1_loss: 9.823E-02
# Epoch 3; dinu_pt_loss: 5.934E+01; higgs_mass_loss: 1.155E+01; loss: 1.184E+02; mae_loss: 5.096E+01; neg_r2_loss: -6.733E-01; nu_mass_loss: 1.390E-02; val_dinu_pt_loss: 5.867E+01; val_higgs_mass_loss: 7.742E+00; val_loss: 1.142E+02; val_mae_loss: 5.087E+01; val_neg_r2_loss: -6.731E-01; val_nu_mass_loss: 1.497E-02; val_w0_mass_mae_loss: 1.864E+01; val_w1_mass_mae_loss: 1.754E+01; val_w_mass_mmd0_loss: 4.918E-01; val_w_mass_mmd1_loss: 1.020E-01; w0_mass_mae_loss: 1.961E+01; w1_mass_mae_loss: 1.761E+01; w_mass_mmd0_loss: 5.212E-01; w_mass_mmd1_loss: 9.882E-02
# Epoch 4; dinu_pt_loss: 5.825E+01; higgs_mass_loss: 6.488E+00; loss: 1.115E+02; mae_loss: 5.061E+01; neg_r2_loss: -6.747E-01; nu_mass_loss: 1.537E-02; val_dinu_pt_loss: 5.718E+01; val_higgs_mass_loss: 4.585E+00; val_loss: 1.086E+02; val_mae_loss: 5.033E+01; val_neg_r2_loss: -6.751E-01; val_nu_mass_loss: 1.612E-02; val_w0_mass_mae_loss: 1.669E+01; val_w1_mass_mae_loss: 1.794E+01; val_w_mass_mmd0_loss: 3.381E-01; val_w_mass_mmd1_loss: 8.139E-02; w0_mass_mae_loss: 1.734E+01; w1_mass_mae_loss: 1.784E+01; w_mass_mmd0_loss: 3.848E-01; w_mass_mmd1_loss: 9.194E-02
# Epoch 5; dinu_pt_loss: 5.641E+01; higgs_mass_loss: 4.645E+00; loss: 1.076E+02; mae_loss: 4.996E+01; neg_r2_loss: -6.771E-01; nu_mass_loss: 1.636E-02; val_dinu_pt_loss: 5.503E+01; val_higgs_mass_loss: 3.404E+00; val_loss: 1.052E+02; val_mae_loss: 4.963E+01; val_neg_r2_loss: -6.777E-01; val_nu_mass_loss: 1.678E-02; val_w0_mass_mae_loss: 1.582E+01; val_w1_mass_mae_loss: 1.803E+01; val_w_mass_mmd0_loss: 2.396E-01; val_w_mass_mmd1_loss: 7.140E-02; w0_mass_mae_loss: 1.616E+01; w1_mass_mae_loss: 1.806E+01; w_mass_mmd0_loss: 3.027E-01; w_mass_mmd1_loss: 7.908E-02
# Epoch 6; dinu_pt_loss: 5.454E+01; higgs_mass_loss: 4.009E+00; loss: 1.052E+02; mae_loss: 4.923E+01; neg_r2_loss: -6.801E-01; nu_mass_loss: 1.695E-02; val_dinu_pt_loss: 5.327E+01; val_higgs_mass_loss: 2.994E+00; val_loss: 1.031E+02; val_mae_loss: 4.886E+01; val_neg_r2_loss: -6.811E-01; val_nu_mass_loss: 1.736E-02; val_w0_mass_mae_loss: 1.558E+01; val_w1_mass_mae_loss: 1.806E+01; val_w_mass_mmd0_loss: 2.311E-01; val_w_mass_mmd1_loss: 6.632E-02; w0_mass_mae_loss: 1.571E+01; w1_mass_mae_loss: 1.812E+01; w_mass_mmd0_loss: 2.699E-01; w_mass_mmd1_loss: 7.034E-02
# Epoch 7; dinu_pt_loss: 5.288E+01; higgs_mass_loss: 3.685E+00; loss: 1.032E+02; mae_loss: 4.852E+01; neg_r2_loss: -6.835E-01; nu_mass_loss: 1.756E-02; val_dinu_pt_loss: 5.210E+01; val_higgs_mass_loss: 2.616E+00; val_loss: 1.015E+02; val_mae_loss: 4.823E+01; val_neg_r2_loss: -6.845E-01; val_nu_mass_loss: 1.805E-02; val_w0_mass_mae_loss: 1.529E+01; val_w1_mass_mae_loss: 1.824E+01; val_w_mass_mmd0_loss: 2.458E-01; val_w_mass_mmd1_loss: 6.013E-02; w0_mass_mae_loss: 1.547E+01; w1_mass_mae_loss: 1.822E+01; w_mass_mmd0_loss: 2.508E-01; w_mass_mmd1_loss: 6.301E-02
# Epoch 8; dinu_pt_loss: 5.148E+01; higgs_mass_loss: 3.478E+00; loss: 1.015E+02; mae_loss: 4.793E+01; neg_r2_loss: -6.868E-01; nu_mass_loss: 1.822E-02; val_dinu_pt_loss: 5.081E+01; val_higgs_mass_loss: 2.414E+00; val_loss: 9.967E+01; val_mae_loss: 4.772E+01; val_neg_r2_loss: -6.874E-01; val_nu_mass_loss: 1.860E-02; val_w0_mass_mae_loss: 1.523E+01; val_w1_mass_mae_loss: 1.837E+01; val_w_mass_mmd0_loss: 1.763E-01; val_w_mass_mmd1_loss: 5.016E-02; w0_mass_mae_loss: 1.529E+01; w1_mass_mae_loss: 1.836E+01; w_mass_mmd0_loss: 2.155E-01; w_mass_mmd1_loss: 5.483E-02
# Epoch 9; dinu_pt_loss: 5.063E+01; higgs_mass_loss: 3.229E+00; loss: 1.001E+02; mae_loss: 4.752E+01; neg_r2_loss: -6.895E-01; nu_mass_loss: 1.879E-02; val_dinu_pt_loss: 4.959E+01; val_higgs_mass_loss: 2.220E+00; val_loss: 9.821E+01; val_mae_loss: 4.735E+01; val_neg_r2_loss: -6.898E-01; val_nu_mass_loss: 1.900E-02; val_w0_mass_mae_loss: 1.502E+01; val_w1_mass_mae_loss: 1.839E+01; val_w_mass_mmd0_loss: 1.165E-01; val_w_mass_mmd1_loss: 4.624E-02; w0_mass_mae_loss: 1.519E+01; w1_mass_mae_loss: 1.845E+01; w_mass_mmd0_loss: 1.857E-01; w_mass_mmd1_loss: 4.917E-02
# Epoch 10; dinu_pt_loss: 5.019E+01; higgs_mass_loss: 3.014E+00; loss: 9.905E+01; mae_loss: 4.717E+01; neg_r2_loss: -6.922E-01; nu_mass_loss: 1.936E-02; val_dinu_pt_loss: 4.978E+01; val_higgs_mass_loss: 2.125E+00; val_loss: 9.731E+01; val_mae_loss: 4.696E+01; val_neg_r2_loss: -6.934E-01; val_nu_mass_loss: 1.987E-02; val_w0_mass_mae_loss: 1.489E+01; val_w1_mass_mae_loss: 1.838E+01; val_w_mass_mmd0_loss: 1.108E-01; val_w_mass_mmd1_loss: 4.598E-02; w0_mass_mae_loss: 1.504E+01; w1_mass_mae_loss: 1.842E+01; w_mass_mmd0_loss: 1.646E-01; w_mass_mmd1_loss: 4.778E-02
# Epoch 11; dinu_pt_loss: 4.916E+01; higgs_mass_loss: 2.831E+00; loss: 9.802E+01; mae_loss: 4.680E+01; neg_r2_loss: -6.952E-01; nu_mass_loss: 2.006E-02; val_dinu_pt_loss: 4.861E+01; val_higgs_mass_loss: 2.042E+00; val_loss: 9.640E+01; val_mae_loss: 4.659E+01; val_neg_r2_loss: -6.961E-01; val_nu_mass_loss: 2.047E-02; val_w0_mass_mae_loss: 1.482E+01; val_w1_mass_mae_loss: 1.833E+01; val_w_mass_mmd0_loss: 1.016E-01; val_w_mass_mmd1_loss: 4.543E-02; w0_mass_mae_loss: 1.494E+01; w1_mass_mae_loss: 1.835E+01; w_mass_mmd0_loss: 1.506E-01; w_mass_mmd1_loss: 4.856E-02
# Epoch 12; dinu_pt_loss: 4.839E+01; higgs_mass_loss: 2.704E+00; loss: 9.706E+01; mae_loss: 4.642E+01; neg_r2_loss: -6.982E-01; nu_mass_loss: 2.069E-02; val_dinu_pt_loss: 4.798E+01; val_higgs_mass_loss: 2.325E+00; val_loss: 9.591E+01; val_mae_loss: 4.621E+01; val_neg_r2_loss: -6.997E-01; val_nu_mass_loss: 2.130E-02; val_w0_mass_mae_loss: 1.464E+01; val_w1_mass_mae_loss: 1.818E+01; val_w_mass_mmd0_loss: 9.749E-02; val_w_mass_mmd1_loss: 4.845E-02; w0_mass_mae_loss: 1.484E+01; w1_mass_mae_loss: 1.831E+01; w_mass_mmd0_loss: 1.409E-01; w_mass_mmd1_loss: 4.867E-02
# Epoch 13; dinu_pt_loss: 4.717E+01; higgs_mass_loss: 2.602E+00; loss: 9.610E+01; mae_loss: 4.601E+01; neg_r2_loss: -7.014E-01; nu_mass_loss: 2.140E-02; val_dinu_pt_loss: 4.651E+01; val_higgs_mass_loss: 2.101E+00; val_loss: 9.472E+01; val_mae_loss: 4.581E+01; val_neg_r2_loss: -7.018E-01; val_nu_mass_loss: 2.154E-02; val_w0_mass_mae_loss: 1.473E+01; val_w1_mass_mae_loss: 1.831E+01; val_w_mass_mmd0_loss: 7.650E-02; val_w_mass_mmd1_loss: 4.779E-02; w0_mass_mae_loss: 1.480E+01; w1_mass_mae_loss: 1.829E+01; w_mass_mmd0_loss: 1.347E-01; w_mass_mmd1_loss: 4.939E-02
# Epoch 14; dinu_pt_loss: 4.652E+01; higgs_mass_loss: 2.523E+00; loss: 9.518E+01; mae_loss: 4.561E+01; neg_r2_loss: -7.049E-01; nu_mass_loss: 2.213E-02; val_dinu_pt_loss: 4.563E+01; val_higgs_mass_loss: 2.021E+00; val_loss: 9.374E+01; val_mae_loss: 4.536E+01; val_neg_r2_loss: -7.059E-01; val_nu_mass_loss: 2.249E-02; val_w0_mass_mae_loss: 1.460E+01; val_w1_mass_mae_loss: 1.822E+01; val_w_mass_mmd0_loss: 7.306E-02; val_w_mass_mmd1_loss: 5.043E-02; w0_mass_mae_loss: 1.475E+01; w1_mass_mae_loss: 1.826E+01; w_mass_mmd0_loss: 1.296E-01; w_mass_mmd1_loss: 5.076E-02
# Epoch 15; dinu_pt_loss: 4.533E+01; higgs_mass_loss: 2.448E+00; loss: 9.422E+01; mae_loss: 4.518E+01; neg_r2_loss: -7.085E-01; nu_mass_loss: 2.295E-02; val_dinu_pt_loss: 4.442E+01; val_higgs_mass_loss: 2.047E+00; val_loss: 9.282E+01; val_mae_loss: 4.491E+01; val_neg_r2_loss: -7.099E-01; val_nu_mass_loss: 2.339E-02; val_w0_mass_mae_loss: 1.459E+01; val_w1_mass_mae_loss: 1.812E+01; val_w_mass_mmd0_loss: 6.604E-02; val_w_mass_mmd1_loss: 5.286E-02; w0_mass_mae_loss: 1.475E+01; w1_mass_mae_loss: 1.816E+01; w_mass_mmd0_loss: 1.218E-01; w_mass_mmd1_loss: 5.327E-02
# Epoch 16; dinu_pt_loss: 4.474E+01; higgs_mass_loss: 2.381E+00; loss: 9.326E+01; mae_loss: 4.475E+01; neg_r2_loss: -7.126E-01; nu_mass_loss: 2.379E-02; val_dinu_pt_loss: 4.396E+01; val_higgs_mass_loss: 1.681E+00; val_loss: 9.165E+01; val_mae_loss: 4.454E+01; val_neg_r2_loss: -7.139E-01; val_nu_mass_loss: 2.427E-02; val_w0_mass_mae_loss: 1.450E+01; val_w1_mass_mae_loss: 1.819E+01; val_w_mass_mmd0_loss: 6.019E-02; val_w_mass_mmd1_loss: 5.087E-02; w0_mass_mae_loss: 1.468E+01; w1_mass_mae_loss: 1.814E+01; w_mass_mmd0_loss: 1.183E-01; w_mass_mmd1_loss: 5.378E-02
# Epoch 17; dinu_pt_loss: 4.410E+01; higgs_mass_loss: 2.341E+00; loss: 9.229E+01; mae_loss: 4.430E+01; neg_r2_loss: -7.172E-01; nu_mass_loss: 2.468E-02; val_dinu_pt_loss: 4.353E+01; val_higgs_mass_loss: 1.926E+00; val_loss: 9.088E+01; val_mae_loss: 4.405E+01; val_neg_r2_loss: -7.186E-01; val_nu_mass_loss: 2.502E-02; val_w0_mass_mae_loss: 1.437E+01; val_w1_mass_mae_loss: 1.810E+01; val_w_mass_mmd0_loss: 5.431E-02; val_w_mass_mmd1_loss: 5.261E-02; w0_mass_mae_loss: 1.470E+01; w1_mass_mae_loss: 1.810E+01; w_mass_mmd0_loss: 1.136E-01; w_mass_mmd1_loss: 5.579E-02
# Epoch 18; dinu_pt_loss: 4.365E+01; higgs_mass_loss: 2.314E+00; loss: 9.129E+01; mae_loss: 4.382E+01; neg_r2_loss: -7.223E-01; nu_mass_loss: 2.566E-02; val_dinu_pt_loss: 4.241E+01; val_higgs_mass_loss: 1.708E+00; val_loss: 8.973E+01; val_mae_loss: 4.359E+01; val_neg_r2_loss: -7.233E-01; val_nu_mass_loss: 2.593E-02; val_w0_mass_mae_loss: 1.440E+01; val_w1_mass_mae_loss: 1.810E+01; val_w_mass_mmd0_loss: 5.050E-02; val_w_mass_mmd1_loss: 5.450E-02; w0_mass_mae_loss: 1.466E+01; w1_mass_mae_loss: 1.806E+01; w_mass_mmd0_loss: 1.106E-01; w_mass_mmd1_loss: 5.610E-02
# Epoch 19; dinu_pt_loss: 4.318E+01; higgs_mass_loss: 2.274E+00; loss: 9.024E+01; mae_loss: 4.333E+01; neg_r2_loss: -7.277E-01; nu_mass_loss: 2.664E-02; val_dinu_pt_loss: 4.296E+01; val_higgs_mass_loss: 1.580E+00; val_loss: 8.863E+01; val_mae_loss: 4.310E+01; val_neg_r2_loss: -7.297E-01; val_nu_mass_loss: 2.709E-02; val_w0_mass_mae_loss: 1.429E+01; val_w1_mass_mae_loss: 1.802E+01; val_w_mass_mmd0_loss: 5.108E-02; val_w_mass_mmd1_loss: 5.521E-02; w0_mass_mae_loss: 1.459E+01; w1_mass_mae_loss: 1.803E+01; w_mass_mmd0_loss: 1.079E-01; w_mass_mmd1_loss: 5.625E-02
# Epoch 20; dinu_pt_loss: 4.262E+01; higgs_mass_loss: 2.254E+00; loss: 8.920E+01; mae_loss: 4.283E+01; neg_r2_loss: -7.332E-01; nu_mass_loss: 2.761E-02; val_dinu_pt_loss: 4.244E+01; val_higgs_mass_loss: 1.726E+00; val_loss: 8.776E+01; val_mae_loss: 4.260E+01; val_neg_r2_loss: -7.348E-01; val_nu_mass_loss: 2.792E-02; val_w0_mass_mae_loss: 1.415E+01; val_w1_mass_mae_loss: 1.798E+01; val_w_mass_mmd0_loss: 4.850E-02; val_w_mass_mmd1_loss: 5.682E-02; w0_mass_mae_loss: 1.448E+01; w1_mass_mae_loss: 1.797E+01; w_mass_mmd0_loss: 1.048E-01; w_mass_mmd1_loss: 5.740E-02
# Epoch 21; dinu_pt_loss: 4.233E+01; higgs_mass_loss: 2.243E+00; loss: 8.816E+01; mae_loss: 4.232E+01; neg_r2_loss: -7.388E-01; nu_mass_loss: 2.857E-02; val_dinu_pt_loss: 4.168E+01; val_higgs_mass_loss: 1.639E+00; val_loss: 8.671E+01; val_mae_loss: 4.209E+01; val_neg_r2_loss: -7.408E-01; val_nu_mass_loss: 2.905E-02; val_w0_mass_mae_loss: 1.419E+01; val_w1_mass_mae_loss: 1.784E+01; val_w_mass_mmd0_loss: 5.394E-02; val_w_mass_mmd1_loss: 5.695E-02; w0_mass_mae_loss: 1.440E+01; w1_mass_mae_loss: 1.790E+01; w_mass_mmd0_loss: 1.015E-01; w_mass_mmd1_loss: 5.791E-02
# Epoch 22; dinu_pt_loss: 4.181E+01; higgs_mass_loss: 2.238E+00; loss: 8.713E+01; mae_loss: 4.181E+01; neg_r2_loss: -7.445E-01; nu_mass_loss: 2.960E-02; val_dinu_pt_loss: 4.101E+01; val_higgs_mass_loss: 1.654E+00; val_loss: 8.580E+01; val_mae_loss: 4.162E+01; val_neg_r2_loss: -7.457E-01; val_nu_mass_loss: 2.991E-02; val_w0_mass_mae_loss: 1.413E+01; val_w1_mass_mae_loss: 1.781E+01; val_w_mass_mmd0_loss: 5.512E-02; val_w_mass_mmd1_loss: 5.868E-02; w0_mass_mae_loss: 1.433E+01; w1_mass_mae_loss: 1.783E+01; w_mass_mmd0_loss: 9.932E-02; w_mass_mmd1_loss: 5.901E-02
# Epoch 23; dinu_pt_loss: 4.117E+01; higgs_mass_loss: 2.235E+00; loss: 8.608E+01; mae_loss: 4.130E+01; neg_r2_loss: -7.502E-01; nu_mass_loss: 3.057E-02; val_dinu_pt_loss: 4.038E+01; val_higgs_mass_loss: 1.665E+00; val_loss: 8.478E+01; val_mae_loss: 4.113E+01; val_neg_r2_loss: -7.511E-01; val_nu_mass_loss: 3.089E-02; val_w0_mass_mae_loss: 1.410E+01; val_w1_mass_mae_loss: 1.776E+01; val_w_mass_mmd0_loss: 4.875E-02; val_w_mass_mmd1_loss: 5.784E-02; w0_mass_mae_loss: 1.432E+01; w1_mass_mae_loss: 1.781E+01; w_mass_mmd0_loss: 9.645E-02; w_mass_mmd1_loss: 5.869E-02
# Epoch 24; dinu_pt_loss: 4.068E+01; higgs_mass_loss: 2.225E+00; loss: 8.505E+01; mae_loss: 4.080E+01; neg_r2_loss: -7.560E-01; nu_mass_loss: 3.155E-02; val_dinu_pt_loss: 4.003E+01; val_higgs_mass_loss: 1.627E+00; val_loss: 8.387E+01; val_mae_loss: 4.067E+01; val_neg_r2_loss: -7.563E-01; val_nu_mass_loss: 3.173E-02; val_w0_mass_mae_loss: 1.407E+01; val_w1_mass_mae_loss: 1.770E+01; val_w_mass_mmd0_loss: 5.331E-02; val_w_mass_mmd1_loss: 5.923E-02; w0_mass_mae_loss: 1.424E+01; w1_mass_mae_loss: 1.776E+01; w_mass_mmd0_loss: 9.312E-02; w_mass_mmd1_loss: 5.961E-02
# Epoch 25; dinu_pt_loss: 4.010E+01; higgs_mass_loss: 2.227E+00; loss: 8.407E+01; mae_loss: 4.031E+01; neg_r2_loss: -7.617E-01; nu_mass_loss: 3.251E-02; val_dinu_pt_loss: 3.940E+01; val_higgs_mass_loss: 1.697E+00; val_loss: 8.288E+01; val_mae_loss: 4.015E+01; val_neg_r2_loss: -7.623E-01; val_nu_mass_loss: 3.254E-02; val_w0_mass_mae_loss: 1.408E+01; val_w1_mass_mae_loss: 1.761E+01; val_w_mass_mmd0_loss: 5.213E-02; val_w_mass_mmd1_loss: 5.888E-02; w0_mass_mae_loss: 1.422E+01; w1_mass_mae_loss: 1.769E+01; w_mass_mmd0_loss: 9.071E-02; w_mass_mmd1_loss: 6.049E-02
# Epoch 26; dinu_pt_loss: 3.954E+01; higgs_mass_loss: 2.225E+00; loss: 8.311E+01; mae_loss: 3.985E+01; neg_r2_loss: -7.671E-01; nu_mass_loss: 3.345E-02; val_dinu_pt_loss: 3.912E+01; val_higgs_mass_loss: 1.901E+00; val_loss: 8.215E+01; val_mae_loss: 3.969E+01; val_neg_r2_loss: -7.673E-01; val_nu_mass_loss: 3.349E-02; val_w0_mass_mae_loss: 1.394E+01; val_w1_mass_mae_loss: 1.752E+01; val_w_mass_mmd0_loss: 4.811E-02; val_w_mass_mmd1_loss: 6.062E-02; w0_mass_mae_loss: 1.417E+01; w1_mass_mae_loss: 1.762E+01; w_mass_mmd0_loss: 8.789E-02; w_mass_mmd1_loss: 6.063E-02
# Epoch 27; dinu_pt_loss: 3.901E+01; higgs_mass_loss: 2.222E+00; loss: 8.221E+01; mae_loss: 3.941E+01; neg_r2_loss: -7.723E-01; nu_mass_loss: 3.437E-02; val_dinu_pt_loss: 3.842E+01; val_higgs_mass_loss: 1.698E+00; val_loss: 8.106E+01; val_mae_loss: 3.925E+01; val_neg_r2_loss: -7.731E-01; val_nu_mass_loss: 3.442E-02; val_w0_mass_mae_loss: 1.389E+01; val_w1_mass_mae_loss: 1.759E+01; val_w_mass_mmd0_loss: 4.764E-02; val_w_mass_mmd1_loss: 5.976E-02; w0_mass_mae_loss: 1.412E+01; w1_mass_mae_loss: 1.757E+01; w_mass_mmd0_loss: 8.516E-02; w_mass_mmd1_loss: 6.061E-02
# Epoch 28; dinu_pt_loss: 3.824E+01; higgs_mass_loss: 2.220E+00; loss: 8.137E+01; mae_loss: 3.900E+01; neg_r2_loss: -7.771E-01; nu_mass_loss: 3.518E-02; val_dinu_pt_loss: 3.735E+01; val_higgs_mass_loss: 1.897E+00; val_loss: 8.057E+01; val_mae_loss: 3.885E+01; val_neg_r2_loss: -7.775E-01; val_nu_mass_loss: 3.520E-02; val_w0_mass_mae_loss: 1.384E+01; val_w1_mass_mae_loss: 1.752E+01; val_w_mass_mmd0_loss: 6.233E-02; val_w_mass_mmd1_loss: 5.841E-02; w0_mass_mae_loss: 1.405E+01; w1_mass_mae_loss: 1.753E+01; w_mass_mmd0_loss: 8.233E-02; w_mass_mmd1_loss: 6.024E-02
# Epoch 29; dinu_pt_loss: 3.727E+01; higgs_mass_loss: 2.232E+00; loss: 8.056E+01; mae_loss: 3.861E+01; neg_r2_loss: -7.815E-01; nu_mass_loss: 3.598E-02; val_dinu_pt_loss: 3.691E+01; val_higgs_mass_loss: 1.718E+00; val_loss: 7.950E+01; val_mae_loss: 3.843E+01; val_neg_r2_loss: -7.826E-01; val_nu_mass_loss: 3.609E-02; val_w0_mass_mae_loss: 1.375E+01; val_w1_mass_mae_loss: 1.743E+01; val_w_mass_mmd0_loss: 5.603E-02; val_w_mass_mmd1_loss: 5.883E-02; w0_mass_mae_loss: 1.403E+01; w1_mass_mae_loss: 1.748E+01; w_mass_mmd0_loss: 7.933E-02; w_mass_mmd1_loss: 5.920E-02
# Epoch 30; dinu_pt_loss: 3.632E+01; higgs_mass_loss: 2.247E+00; loss: 7.981E+01; mae_loss: 3.824E+01; neg_r2_loss: -7.855E-01; nu_mass_loss: 3.673E-02; val_dinu_pt_loss: 3.573E+01; val_higgs_mass_loss: 1.709E+00; val_loss: 7.858E+01; val_mae_loss: 3.806E+01; val_neg_r2_loss: -7.862E-01; val_nu_mass_loss: 3.678E-02; val_w0_mass_mae_loss: 1.373E+01; val_w1_mass_mae_loss: 1.740E+01; val_w_mass_mmd0_loss: 3.819E-02; val_w_mass_mmd1_loss: 5.570E-02; w0_mass_mae_loss: 1.392E+01; w1_mass_mae_loss: 1.742E+01; w_mass_mmd0_loss: 7.819E-02; w_mass_mmd1_loss: 5.839E-02
# Epoch 31; dinu_pt_loss: 3.508E+01; higgs_mass_loss: 2.261E+00; loss: 7.906E+01; mae_loss: 3.787E+01; neg_r2_loss: -7.892E-01; nu_mass_loss: 3.738E-02; val_dinu_pt_loss: 3.395E+01; val_higgs_mass_loss: 2.125E+00; val_loss: 7.846E+01; val_mae_loss: 3.773E+01; val_neg_r2_loss: -7.879E-01; val_nu_mass_loss: 3.687E-02; val_w0_mass_mae_loss: 1.361E+01; val_w1_mass_mae_loss: 1.733E+01; val_w_mass_mmd0_loss: 5.093E-02; val_w_mass_mmd1_loss: 5.899E-02; w0_mass_mae_loss: 1.384E+01; w1_mass_mae_loss: 1.730E+01; w_mass_mmd0_loss: 7.559E-02; w_mass_mmd1_loss: 5.747E-02
# Epoch 32; dinu_pt_loss: 3.367E+01; higgs_mass_loss: 2.270E+00; loss: 7.834E+01; mae_loss: 3.751E+01; neg_r2_loss: -7.925E-01; nu_mass_loss: 3.806E-02; val_dinu_pt_loss: 3.226E+01; val_higgs_mass_loss: 1.686E+00; val_loss: 7.722E+01; val_mae_loss: 3.739E+01; val_neg_r2_loss: -7.922E-01; val_nu_mass_loss: 3.794E-02; val_w0_mass_mae_loss: 1.358E+01; val_w1_mass_mae_loss: 1.715E+01; val_w_mass_mmd0_loss: 3.787E-02; val_w_mass_mmd1_loss: 5.668E-02; w0_mass_mae_loss: 1.377E+01; w1_mass_mae_loss: 1.722E+01; w_mass_mmd0_loss: 7.388E-02; w_mass_mmd1_loss: 5.656E-02
# Epoch 33; dinu_pt_loss: 3.207E+01; higgs_mass_loss: 2.293E+00; loss: 7.762E+01; mae_loss: 3.715E+01; neg_r2_loss: -7.955E-01; nu_mass_loss: 3.862E-02; val_dinu_pt_loss: 3.076E+01; val_higgs_mass_loss: 1.755E+00; val_loss: 7.653E+01; val_mae_loss: 3.701E+01; val_neg_r2_loss: -7.955E-01; val_nu_mass_loss: 3.844E-02; val_w0_mass_mae_loss: 1.346E+01; val_w1_mass_mae_loss: 1.707E+01; val_w_mass_mmd0_loss: 4.029E-02; val_w_mass_mmd1_loss: 5.426E-02; w0_mass_mae_loss: 1.367E+01; w1_mass_mae_loss: 1.709E+01; w_mass_mmd0_loss: 7.264E-02; w_mass_mmd1_loss: 5.489E-02
# Epoch 34; dinu_pt_loss: 3.019E+01; higgs_mass_loss: 2.336E+00; loss: 7.693E+01; mae_loss: 3.680E+01; neg_r2_loss: -7.980E-01; nu_mass_loss: 3.907E-02; val_dinu_pt_loss: 2.899E+01; val_higgs_mass_loss: 1.950E+00; val_loss: 7.595E+01; val_mae_loss: 3.664E+01; val_neg_r2_loss: -7.971E-01; val_nu_mass_loss: 3.873E-02; val_w0_mass_mae_loss: 1.323E+01; val_w1_mass_mae_loss: 1.676E+01; val_w_mass_mmd0_loss: 3.745E-02; val_w_mass_mmd1_loss: 5.296E-02; w0_mass_mae_loss: 1.353E+01; w1_mass_mae_loss: 1.690E+01; w_mass_mmd0_loss: 7.056E-02; w_mass_mmd1_loss: 5.414E-02
# Epoch 35; dinu_pt_loss: 2.863E+01; higgs_mass_loss: 2.361E+00; loss: 7.620E+01; mae_loss: 3.644E+01; neg_r2_loss: -8.008E-01; nu_mass_loss: 3.964E-02; val_dinu_pt_loss: 2.729E+01; val_higgs_mass_loss: 1.738E+00; val_loss: 7.513E+01; val_mae_loss: 3.635E+01; val_neg_r2_loss: -7.994E-01; val_nu_mass_loss: 3.940E-02; val_w0_mass_mae_loss: 1.325E+01; val_w1_mass_mae_loss: 1.663E+01; val_w_mass_mmd0_loss: 3.649E-02; val_w_mass_mmd1_loss: 5.053E-02; w0_mass_mae_loss: 1.341E+01; w1_mass_mae_loss: 1.671E+01; w_mass_mmd0_loss: 6.889E-02; w_mass_mmd1_loss: 5.154E-02
# Epoch 36; dinu_pt_loss: 2.711E+01; higgs_mass_loss: 2.387E+00; loss: 7.555E+01; mae_loss: 3.611E+01; neg_r2_loss: -8.035E-01; nu_mass_loss: 4.014E-02; val_dinu_pt_loss: 2.577E+01; val_higgs_mass_loss: 2.001E+00; val_loss: 7.461E+01; val_mae_loss: 3.597E+01; val_neg_r2_loss: -8.041E-01; val_nu_mass_loss: 4.014E-02; val_w0_mass_mae_loss: 1.313E+01; val_w1_mass_mae_loss: 1.646E+01; val_w_mass_mmd0_loss: 3.474E-02; val_w_mass_mmd1_loss: 4.886E-02; w0_mass_mae_loss: 1.333E+01; w1_mass_mae_loss: 1.651E+01; w_mass_mmd0_loss: 6.741E-02; w_mass_mmd1_loss: 5.024E-02
# Epoch 37; dinu_pt_loss: 2.596E+01; higgs_mass_loss: 2.396E+00; loss: 7.494E+01; mae_loss: 3.581E+01; neg_r2_loss: -8.060E-01; nu_mass_loss: 4.062E-02; val_dinu_pt_loss: 2.437E+01; val_higgs_mass_loss: 2.011E+00; val_loss: 7.407E+01; val_mae_loss: 3.569E+01; val_neg_r2_loss: -8.049E-01; val_nu_mass_loss: 4.016E-02; val_w0_mass_mae_loss: 1.305E+01; val_w1_mass_mae_loss: 1.624E+01; val_w_mass_mmd0_loss: 3.656E-02; val_w_mass_mmd1_loss: 4.816E-02; w0_mass_mae_loss: 1.324E+01; w1_mass_mae_loss: 1.631E+01; w_mass_mmd0_loss: 6.567E-02; w_mass_mmd1_loss: 4.894E-02
# Epoch 38; dinu_pt_loss: 2.476E+01; higgs_mass_loss: 2.396E+00; loss: 7.439E+01; mae_loss: 3.554E+01; neg_r2_loss: -8.082E-01; nu_mass_loss: 4.110E-02; val_dinu_pt_loss: 2.338E+01; val_higgs_mass_loss: 2.037E+00; val_loss: 7.349E+01; val_mae_loss: 3.540E+01; val_neg_r2_loss: -8.077E-01; val_nu_mass_loss: 4.055E-02; val_w0_mass_mae_loss: 1.303E+01; val_w1_mass_mae_loss: 1.602E+01; val_w_mass_mmd0_loss: 3.525E-02; val_w_mass_mmd1_loss: 4.736E-02; w0_mass_mae_loss: 1.319E+01; w1_mass_mae_loss: 1.614E+01; w_mass_mmd0_loss: 6.507E-02; w_mass_mmd1_loss: 4.833E-02
# Epoch 39; dinu_pt_loss: 2.391E+01; higgs_mass_loss: 2.411E+00; loss: 7.388E+01; mae_loss: 3.529E+01; neg_r2_loss: -8.103E-01; nu_mass_loss: 4.153E-02; val_dinu_pt_loss: 2.250E+01; val_higgs_mass_loss: 2.135E+00; val_loss: 7.308E+01; val_mae_loss: 3.516E+01; val_neg_r2_loss: -8.095E-01; val_nu_mass_loss: 4.090E-02; val_w0_mass_mae_loss: 1.302E+01; val_w1_mass_mae_loss: 1.590E+01; val_w_mass_mmd0_loss: 3.142E-02; val_w_mass_mmd1_loss: 4.615E-02; w0_mass_mae_loss: 1.316E+01; w1_mass_mae_loss: 1.599E+01; w_mass_mmd0_loss: 6.378E-02; w_mass_mmd1_loss: 4.702E-02
# Epoch 40; dinu_pt_loss: 2.317E+01; higgs_mass_loss: 2.415E+00; loss: 7.343E+01; mae_loss: 3.507E+01; neg_r2_loss: -8.122E-01; nu_mass_loss: 4.188E-02; val_dinu_pt_loss: 2.178E+01; val_higgs_mass_loss: 2.069E+00; val_loss: 7.263E+01; val_mae_loss: 3.496E+01; val_neg_r2_loss: -8.109E-01; val_nu_mass_loss: 4.112E-02; val_w0_mass_mae_loss: 1.296E+01; val_w1_mass_mae_loss: 1.578E+01; val_w_mass_mmd0_loss: 3.700E-02; val_w_mass_mmd1_loss: 4.340E-02; w0_mass_mae_loss: 1.313E+01; w1_mass_mae_loss: 1.585E+01; w_mass_mmd0_loss: 6.320E-02; w_mass_mmd1_loss: 4.583E-02
# Epoch 41; dinu_pt_loss: 2.262E+01; higgs_mass_loss: 2.423E+00; loss: 7.300E+01; mae_loss: 3.486E+01; neg_r2_loss: -8.141E-01; nu_mass_loss: 4.222E-02; val_dinu_pt_loss: 2.143E+01; val_higgs_mass_loss: 2.108E+00; val_loss: 7.229E+01; val_mae_loss: 3.480E+01; val_neg_r2_loss: -8.122E-01; val_nu_mass_loss: 4.130E-02; val_w0_mass_mae_loss: 1.302E+01; val_w1_mass_mae_loss: 1.571E+01; val_w_mass_mmd0_loss: 3.084E-02; val_w_mass_mmd1_loss: 4.252E-02; w0_mass_mae_loss: 1.311E+01; w1_mass_mae_loss: 1.576E+01; w_mass_mmd0_loss: 6.243E-02; w_mass_mmd1_loss: 4.442E-02
# Epoch 42; dinu_pt_loss: 2.204E+01; higgs_mass_loss: 2.411E+00; loss: 7.262E+01; mae_loss: 3.469E+01; neg_r2_loss: -8.157E-01; nu_mass_loss: 4.257E-02; val_dinu_pt_loss: 2.068E+01; val_higgs_mass_loss: 2.120E+00; val_loss: 7.194E+01; val_mae_loss: 3.458E+01; val_neg_r2_loss: -8.153E-01; val_nu_mass_loss: 4.205E-02; val_w0_mass_mae_loss: 1.294E+01; val_w1_mass_mae_loss: 1.565E+01; val_w_mass_mmd0_loss: 4.182E-02; val_w_mass_mmd1_loss: 4.168E-02; w0_mass_mae_loss: 1.309E+01; w1_mass_mae_loss: 1.570E+01; w_mass_mmd0_loss: 6.089E-02; w_mass_mmd1_loss: 4.303E-02
# Epoch 43; dinu_pt_loss: 2.149E+01; higgs_mass_loss: 2.410E+00; loss: 7.227E+01; mae_loss: 3.452E+01; neg_r2_loss: -8.172E-01; nu_mass_loss: 4.290E-02; val_dinu_pt_loss: 2.044E+01; val_higgs_mass_loss: 2.151E+00; val_loss: 7.155E+01; val_mae_loss: 3.441E+01; val_neg_r2_loss: -8.168E-01; val_nu_mass_loss: 4.255E-02; val_w0_mass_mae_loss: 1.293E+01; val_w1_mass_mae_loss: 1.558E+01; val_w_mass_mmd0_loss: 3.180E-02; val_w_mass_mmd1_loss: 4.004E-02; w0_mass_mae_loss: 1.308E+01; w1_mass_mae_loss: 1.566E+01; w_mass_mmd0_loss: 6.038E-02; w_mass_mmd1_loss: 4.186E-02
# Epoch 44; dinu_pt_loss: 2.119E+01; higgs_mass_loss: 2.400E+00; loss: 7.198E+01; mae_loss: 3.439E+01; neg_r2_loss: -8.186E-01; nu_mass_loss: 4.318E-02; val_dinu_pt_loss: 1.994E+01; val_higgs_mass_loss: 2.101E+00; val_loss: 7.123E+01; val_mae_loss: 3.428E+01; val_neg_r2_loss: -8.181E-01; val_nu_mass_loss: 4.258E-02; val_w0_mass_mae_loss: 1.294E+01; val_w1_mass_mae_loss: 1.558E+01; val_w_mass_mmd0_loss: 3.171E-02; val_w_mass_mmd1_loss: 3.803E-02; w0_mass_mae_loss: 1.306E+01; w1_mass_mae_loss: 1.561E+01; w_mass_mmd0_loss: 6.048E-02; w_mass_mmd1_loss: 4.061E-02
# Epoch 45; dinu_pt_loss: 2.069E+01; higgs_mass_loss: 2.388E+00; loss: 7.168E+01; mae_loss: 3.425E+01; neg_r2_loss: -8.200E-01; nu_mass_loss: 4.341E-02; val_dinu_pt_loss: 1.966E+01; val_higgs_mass_loss: 2.099E+00; val_loss: 7.101E+01; val_mae_loss: 3.415E+01; val_neg_r2_loss: -8.192E-01; val_nu_mass_loss: 4.284E-02; val_w0_mass_mae_loss: 1.302E+01; val_w1_mass_mae_loss: 1.550E+01; val_w_mass_mmd0_loss: 3.903E-02; val_w_mass_mmd1_loss: 3.753E-02; w0_mass_mae_loss: 1.305E+01; w1_mass_mae_loss: 1.556E+01; w_mass_mmd0_loss: 5.945E-02; w_mass_mmd1_loss: 3.958E-02
# Epoch 46; dinu_pt_loss: 2.047E+01; higgs_mass_loss: 2.381E+00; loss: 7.145E+01; mae_loss: 3.414E+01; neg_r2_loss: -8.212E-01; nu_mass_loss: 4.365E-02; val_dinu_pt_loss: 1.933E+01; val_higgs_mass_loss: 2.054E+00; val_loss: 7.082E+01; val_mae_loss: 3.408E+01; val_neg_r2_loss: -8.197E-01; val_nu_mass_loss: 4.314E-02; val_w0_mass_mae_loss: 1.295E+01; val_w1_mass_mae_loss: 1.547E+01; val_w_mass_mmd0_loss: 3.814E-02; val_w_mass_mmd1_loss: 3.682E-02; w0_mass_mae_loss: 1.300E+01; w1_mass_mae_loss: 1.552E+01; w_mass_mmd0_loss: 5.933E-02; w_mass_mmd1_loss: 3.864E-02
# Epoch 47; dinu_pt_loss: 2.006E+01; higgs_mass_loss: 2.366E+00; loss: 7.123E+01; mae_loss: 3.404E+01; neg_r2_loss: -8.223E-01; nu_mass_loss: 4.387E-02; val_dinu_pt_loss: 1.889E+01; val_higgs_mass_loss: 2.189E+00; val_loss: 7.075E+01; val_mae_loss: 3.398E+01; val_neg_r2_loss: -8.205E-01; val_nu_mass_loss: 4.306E-02; val_w0_mass_mae_loss: 1.282E+01; val_w1_mass_mae_loss: 1.544E+01; val_w_mass_mmd0_loss: 3.916E-02; val_w_mass_mmd1_loss: 3.569E-02; w0_mass_mae_loss: 1.302E+01; w1_mass_mae_loss: 1.550E+01; w_mass_mmd0_loss: 5.921E-02; w_mass_mmd1_loss: 3.787E-02
# Epoch 48; dinu_pt_loss: 1.976E+01; higgs_mass_loss: 2.357E+00; loss: 7.103E+01; mae_loss: 3.395E+01; neg_r2_loss: -8.233E-01; nu_mass_loss: 4.400E-02; val_dinu_pt_loss: 1.865E+01; val_higgs_mass_loss: 2.026E+00; val_loss: 7.033E+01; val_mae_loss: 3.388E+01; val_neg_r2_loss: -8.230E-01; val_nu_mass_loss: 4.350E-02; val_w0_mass_mae_loss: 1.287E+01; val_w1_mass_mae_loss: 1.542E+01; val_w_mass_mmd0_loss: 3.367E-02; val_w_mass_mmd1_loss: 3.507E-02; w0_mass_mae_loss: 1.299E+01; w1_mass_mae_loss: 1.547E+01; w_mass_mmd0_loss: 5.866E-02; w_mass_mmd1_loss: 3.725E-02
# Epoch 49; dinu_pt_loss: 1.948E+01; higgs_mass_loss: 2.344E+00; loss: 7.084E+01; mae_loss: 3.387E+01; neg_r2_loss: -8.242E-01; nu_mass_loss: 4.427E-02; val_dinu_pt_loss: 1.826E+01; val_higgs_mass_loss: 2.052E+00; val_loss: 7.025E+01; val_mae_loss: 3.380E+01; val_neg_r2_loss: -8.230E-01; val_nu_mass_loss: 4.344E-02; val_w0_mass_mae_loss: 1.287E+01; val_w1_mass_mae_loss: 1.537E+01; val_w_mass_mmd0_loss: 3.952E-02; val_w_mass_mmd1_loss: 3.458E-02; w0_mass_mae_loss: 1.298E+01; w1_mass_mae_loss: 1.545E+01; w_mass_mmd0_loss: 5.773E-02; w_mass_mmd1_loss: 3.625E-02
# Epoch 50; dinu_pt_loss: 1.921E+01; higgs_mass_loss: 2.335E+00; loss: 7.069E+01; mae_loss: 3.380E+01; neg_r2_loss: -8.250E-01; nu_mass_loss: 4.437E-02; val_dinu_pt_loss: 1.802E+01; val_higgs_mass_loss: 2.021E+00; val_loss: 7.001E+01; val_mae_loss: 3.373E+01; val_neg_r2_loss: -8.234E-01; val_nu_mass_loss: 4.353E-02; val_w0_mass_mae_loss: 1.287E+01; val_w1_mass_mae_loss: 1.537E+01; val_w_mass_mmd0_loss: 3.427E-02; val_w_mass_mmd1_loss: 3.330E-02; w0_mass_mae_loss: 1.296E+01; w1_mass_mae_loss: 1.542E+01; w_mass_mmd0_loss: 5.823E-02; w_mass_mmd1_loss: 3.583E-02
# Epoch 51; dinu_pt_loss: 1.891E+01; higgs_mass_loss: 2.320E+00; loss: 7.053E+01; mae_loss: 3.373E+01; neg_r2_loss: -8.256E-01; nu_mass_loss: 4.454E-02; val_dinu_pt_loss: 1.762E+01; val_higgs_mass_loss: 2.099E+00; val_loss: 6.999E+01; val_mae_loss: 3.368E+01; val_neg_r2_loss: -8.242E-01; val_nu_mass_loss: 4.349E-02; val_w0_mass_mae_loss: 1.274E+01; val_w1_mass_mae_loss: 1.534E+01; val_w_mass_mmd0_loss: 3.211E-02; val_w_mass_mmd1_loss: 3.323E-02; w0_mass_mae_loss: 1.294E+01; w1_mass_mae_loss: 1.541E+01; w_mass_mmd0_loss: 5.747E-02; w_mass_mmd1_loss: 3.481E-02
# Epoch 52; dinu_pt_loss: 1.867E+01; higgs_mass_loss: 2.309E+00; loss: 7.039E+01; mae_loss: 3.367E+01; neg_r2_loss: -8.264E-01; nu_mass_loss: 4.466E-02; val_dinu_pt_loss: 1.756E+01; val_higgs_mass_loss: 2.097E+00; val_loss: 7.000E+01; val_mae_loss: 3.363E+01; val_neg_r2_loss: -8.252E-01; val_nu_mass_loss: 4.375E-02; val_w0_mass_mae_loss: 1.276E+01; val_w1_mass_mae_loss: 1.534E+01; val_w_mass_mmd0_loss: 4.883E-02; val_w_mass_mmd1_loss: 3.223E-02; w0_mass_mae_loss: 1.291E+01; w1_mass_mae_loss: 1.539E+01; w_mass_mmd0_loss: 5.717E-02; w_mass_mmd1_loss: 3.444E-02
# Epoch 53; dinu_pt_loss: 1.855E+01; higgs_mass_loss: 2.298E+00; loss: 7.027E+01; mae_loss: 3.362E+01; neg_r2_loss: -8.270E-01; nu_mass_loss: 4.470E-02; val_dinu_pt_loss: 1.729E+01; val_higgs_mass_loss: 1.982E+00; val_loss: 6.963E+01; val_mae_loss: 3.355E+01; val_neg_r2_loss: -8.270E-01; val_nu_mass_loss: 4.431E-02; val_w0_mass_mae_loss: 1.275E+01; val_w1_mass_mae_loss: 1.530E+01; val_w_mass_mmd0_loss: 3.649E-02; val_w_mass_mmd1_loss: 3.240E-02; w0_mass_mae_loss: 1.291E+01; w1_mass_mae_loss: 1.538E+01; w_mass_mmd0_loss: 5.635E-02; w_mass_mmd1_loss: 3.393E-02
# Epoch 54; dinu_pt_loss: 1.833E+01; higgs_mass_loss: 2.293E+00; loss: 7.016E+01; mae_loss: 3.357E+01; neg_r2_loss: -8.275E-01; nu_mass_loss: 4.483E-02; val_dinu_pt_loss: 1.732E+01; val_higgs_mass_loss: 1.897E+00; val_loss: 6.943E+01; val_mae_loss: 3.351E+01; val_neg_r2_loss: -8.273E-01; val_nu_mass_loss: 4.446E-02; val_w0_mass_mae_loss: 1.283E+01; val_w1_mass_mae_loss: 1.533E+01; val_w_mass_mmd0_loss: 3.236E-02; val_w_mass_mmd1_loss: 3.134E-02; w0_mass_mae_loss: 1.289E+01; w1_mass_mae_loss: 1.536E+01; w_mass_mmd0_loss: 5.663E-02; w_mass_mmd1_loss: 3.354E-02
# Epoch 55; dinu_pt_loss: 1.812E+01; higgs_mass_loss: 2.276E+00; loss: 7.004E+01; mae_loss: 3.353E+01; neg_r2_loss: -8.281E-01; nu_mass_loss: 4.496E-02; val_dinu_pt_loss: 1.654E+01; val_higgs_mass_loss: 2.065E+00; val_loss: 6.965E+01; val_mae_loss: 3.348E+01; val_neg_r2_loss: -8.269E-01; val_nu_mass_loss: 4.408E-02; val_w0_mass_mae_loss: 1.272E+01; val_w1_mass_mae_loss: 1.530E+01; val_w_mass_mmd0_loss: 4.824E-02; val_w_mass_mmd1_loss: 3.047E-02; w0_mass_mae_loss: 1.286E+01; w1_mass_mae_loss: 1.535E+01; w_mass_mmd0_loss: 5.590E-02; w_mass_mmd1_loss: 3.302E-02
# Epoch 56; dinu_pt_loss: 1.789E+01; higgs_mass_loss: 2.261E+00; loss: 6.995E+01; mae_loss: 3.349E+01; neg_r2_loss: -8.285E-01; nu_mass_loss: 4.500E-02; val_dinu_pt_loss: 1.678E+01; val_higgs_mass_loss: 1.947E+00; val_loss: 6.941E+01; val_mae_loss: 3.345E+01; val_neg_r2_loss: -8.269E-01; val_nu_mass_loss: 4.404E-02; val_w0_mass_mae_loss: 1.273E+01; val_w1_mass_mae_loss: 1.529E+01; val_w_mass_mmd0_loss: 3.979E-02; val_w_mass_mmd1_loss: 3.085E-02; w0_mass_mae_loss: 1.286E+01; w1_mass_mae_loss: 1.533E+01; w_mass_mmd0_loss: 5.602E-02; w_mass_mmd1_loss: 3.286E-02
# Epoch 57; dinu_pt_loss: 1.769E+01; higgs_mass_loss: 2.256E+00; loss: 6.986E+01; mae_loss: 3.345E+01; neg_r2_loss: -8.289E-01; nu_mass_loss: 4.508E-02; val_dinu_pt_loss: 1.627E+01; val_higgs_mass_loss: 1.941E+00; val_loss: 6.925E+01; val_mae_loss: 3.342E+01; val_neg_r2_loss: -8.267E-01; val_nu_mass_loss: 4.412E-02; val_w0_mass_mae_loss: 1.271E+01; val_w1_mass_mae_loss: 1.530E+01; val_w_mass_mmd0_loss: 2.842E-02; val_w_mass_mmd1_loss: 2.931E-02; w0_mass_mae_loss: 1.285E+01; w1_mass_mae_loss: 1.532E+01; w_mass_mmd0_loss: 5.562E-02; w_mass_mmd1_loss: 3.216E-02
# Epoch 58; dinu_pt_loss: 1.752E+01; higgs_mass_loss: 2.244E+00; loss: 6.977E+01; mae_loss: 3.342E+01; neg_r2_loss: -8.293E-01; nu_mass_loss: 4.513E-02; val_dinu_pt_loss: 1.641E+01; val_higgs_mass_loss: 1.858E+00; val_loss: 6.905E+01; val_mae_loss: 3.337E+01; val_neg_r2_loss: -8.286E-01; val_nu_mass_loss: 4.461E-02; val_w0_mass_mae_loss: 1.273E+01; val_w1_mass_mae_loss: 1.526E+01; val_w_mass_mmd0_loss: 2.806E-02; val_w_mass_mmd1_loss: 2.919E-02; w0_mass_mae_loss: 1.283E+01; w1_mass_mae_loss: 1.533E+01; w_mass_mmd0_loss: 5.503E-02; w_mass_mmd1_loss: 3.157E-02
# Epoch 59; dinu_pt_loss: 1.739E+01; higgs_mass_loss: 2.231E+00; loss: 6.969E+01; mae_loss: 3.338E+01; neg_r2_loss: -8.296E-01; nu_mass_loss: 4.523E-02; val_dinu_pt_loss: 1.650E+01; val_higgs_mass_loss: 1.780E+00; val_loss: 6.899E+01; val_mae_loss: 3.336E+01; val_neg_r2_loss: -8.287E-01; val_nu_mass_loss: 4.469E-02; val_w0_mass_mae_loss: 1.273E+01; val_w1_mass_mae_loss: 1.526E+01; val_w_mass_mmd0_loss: 3.279E-02; val_w_mass_mmd1_loss: 2.860E-02; w0_mass_mae_loss: 1.283E+01; w1_mass_mae_loss: 1.531E+01; w_mass_mmd0_loss: 5.546E-02; w_mass_mmd1_loss: 3.137E-02
# Epoch 60; dinu_pt_loss: 1.729E+01; higgs_mass_loss: 2.213E+00; loss: 6.961E+01; mae_loss: 3.336E+01; neg_r2_loss: -8.300E-01; nu_mass_loss: 4.530E-02; val_dinu_pt_loss: 1.599E+01; val_higgs_mass_loss: 1.916E+00; val_loss: 6.909E+01; val_mae_loss: 3.333E+01; val_neg_r2_loss: -8.281E-01; val_nu_mass_loss: 4.452E-02; val_w0_mass_mae_loss: 1.278E+01; val_w1_mass_mae_loss: 1.526E+01; val_w_mass_mmd0_loss: 3.456E-02; val_w_mass_mmd1_loss: 2.832E-02; w0_mass_mae_loss: 1.282E+01; w1_mass_mae_loss: 1.530E+01; w_mass_mmd0_loss: 5.356E-02; w_mass_mmd1_loss: 3.103E-02
# Epoch 61; dinu_pt_loss: 1.711E+01; higgs_mass_loss: 2.207E+00; loss: 6.955E+01; mae_loss: 3.333E+01; neg_r2_loss: -8.303E-01; nu_mass_loss: 4.533E-02; val_dinu_pt_loss: 1.571E+01; val_higgs_mass_loss: 1.942E+00; val_loss: 6.909E+01; val_mae_loss: 3.331E+01; val_neg_r2_loss: -8.294E-01; val_nu_mass_loss: 4.465E-02; val_w0_mass_mae_loss: 1.273E+01; val_w1_mass_mae_loss: 1.527E+01; val_w_mass_mmd0_loss: 3.636E-02; val_w_mass_mmd1_loss: 2.925E-02; w0_mass_mae_loss: 1.283E+01; w1_mass_mae_loss: 1.530E+01; w_mass_mmd0_loss: 5.457E-02; w_mass_mmd1_loss: 3.077E-02
# Epoch 62; dinu_pt_loss: 1.705E+01; higgs_mass_loss: 2.191E+00; loss: 6.948E+01; mae_loss: 3.330E+01; neg_r2_loss: -8.306E-01; nu_mass_loss: 4.541E-02; val_dinu_pt_loss: 1.600E+01; val_higgs_mass_loss: 1.837E+00; val_loss: 6.891E+01; val_mae_loss: 3.327E+01; val_neg_r2_loss: -8.304E-01; val_nu_mass_loss: 4.503E-02; val_w0_mass_mae_loss: 1.262E+01; val_w1_mass_mae_loss: 1.523E+01; val_w_mass_mmd0_loss: 3.706E-02; val_w_mass_mmd1_loss: 2.917E-02; w0_mass_mae_loss: 1.281E+01; w1_mass_mae_loss: 1.529E+01; w_mass_mmd0_loss: 5.402E-02; w_mass_mmd1_loss: 3.101E-02
# Epoch 63; dinu_pt_loss: 1.706E+01; higgs_mass_loss: 2.169E+00; loss: 6.940E+01; mae_loss: 3.328E+01; neg_r2_loss: -8.309E-01; nu_mass_loss: 4.542E-02; val_dinu_pt_loss: 1.565E+01; val_higgs_mass_loss: 1.980E+00; val_loss: 6.903E+01; val_mae_loss: 3.324E+01; val_neg_r2_loss: -8.300E-01; val_nu_mass_loss: 4.479E-02; val_w0_mass_mae_loss: 1.258E+01; val_w1_mass_mae_loss: 1.520E+01; val_w_mass_mmd0_loss: 4.248E-02; val_w_mass_mmd1_loss: 2.856E-02; w0_mass_mae_loss: 1.279E+01; w1_mass_mae_loss: 1.529E+01; w_mass_mmd0_loss: 5.187E-02; w_mass_mmd1_loss: 3.045E-02
# Epoch 64; dinu_pt_loss: 1.689E+01; higgs_mass_loss: 2.164E+00; loss: 6.936E+01; mae_loss: 3.326E+01; neg_r2_loss: -8.312E-01; nu_mass_loss: 4.553E-02; val_dinu_pt_loss: 1.534E+01; val_higgs_mass_loss: 1.863E+00; val_loss: 6.884E+01; val_mae_loss: 3.325E+01; val_neg_r2_loss: -8.294E-01; val_nu_mass_loss: 4.458E-02; val_w0_mass_mae_loss: 1.264E+01; val_w1_mass_mae_loss: 1.524E+01; val_w_mass_mmd0_loss: 3.079E-02; val_w_mass_mmd1_loss: 2.848E-02; w0_mass_mae_loss: 1.279E+01; w1_mass_mae_loss: 1.528E+01; w_mass_mmd0_loss: 5.338E-02; w_mass_mmd1_loss: 3.036E-02
# Epoch 65; dinu_pt_loss: 1.675E+01; higgs_mass_loss: 2.153E+00; loss: 6.929E+01; mae_loss: 3.323E+01; neg_r2_loss: -8.314E-01; nu_mass_loss: 4.549E-02; val_dinu_pt_loss: 1.563E+01; val_higgs_mass_loss: 1.802E+00; val_loss: 6.883E+01; val_mae_loss: 3.324E+01; val_neg_r2_loss: -8.309E-01; val_nu_mass_loss: 4.523E-02; val_w0_mass_mae_loss: 1.267E+01; val_w1_mass_mae_loss: 1.521E+01; val_w_mass_mmd0_loss: 3.875E-02; val_w_mass_mmd1_loss: 2.929E-02; w0_mass_mae_loss: 1.277E+01; w1_mass_mae_loss: 1.527E+01; w_mass_mmd0_loss: 5.318E-02; w_mass_mmd1_loss: 3.041E-02
# Epoch 66; dinu_pt_loss: 1.671E+01; higgs_mass_loss: 2.135E+00; loss: 6.924E+01; mae_loss: 3.322E+01; neg_r2_loss: -8.315E-01; nu_mass_loss: 4.558E-02; val_dinu_pt_loss: 1.519E+01; val_higgs_mass_loss: 1.883E+00; val_loss: 6.888E+01; val_mae_loss: 3.322E+01; val_neg_r2_loss: -8.300E-01; val_nu_mass_loss: 4.467E-02; val_w0_mass_mae_loss: 1.261E+01; val_w1_mass_mae_loss: 1.518E+01; val_w_mass_mmd0_loss: 4.006E-02; val_w_mass_mmd1_loss: 2.852E-02; w0_mass_mae_loss: 1.278E+01; w1_mass_mae_loss: 1.527E+01; w_mass_mmd0_loss: 5.328E-02; w_mass_mmd1_loss: 3.025E-02
# Epoch 67; dinu_pt_loss: 1.657E+01; higgs_mass_loss: 2.127E+00; loss: 6.919E+01; mae_loss: 3.320E+01; neg_r2_loss: -8.317E-01; nu_mass_loss: 4.561E-02; val_dinu_pt_loss: 1.545E+01; val_higgs_mass_loss: 1.696E+00; val_loss: 6.862E+01; val_mae_loss: 3.323E+01; val_neg_r2_loss: -8.300E-01; val_nu_mass_loss: 4.485E-02; val_w0_mass_mae_loss: 1.269E+01; val_w1_mass_mae_loss: 1.523E+01; val_w_mass_mmd0_loss: 3.153E-02; val_w_mass_mmd1_loss: 2.744E-02; w0_mass_mae_loss: 1.279E+01; w1_mass_mae_loss: 1.526E+01; w_mass_mmd0_loss: 5.171E-02; w_mass_mmd1_loss: 3.027E-02
# Epoch 68; dinu_pt_loss: 1.659E+01; higgs_mass_loss: 2.112E+00; loss: 6.913E+01; mae_loss: 3.318E+01; neg_r2_loss: -8.319E-01; nu_mass_loss: 4.563E-02; val_dinu_pt_loss: 1.526E+01; val_higgs_mass_loss: 1.905E+00; val_loss: 6.875E+01; val_mae_loss: 3.317E+01; val_neg_r2_loss: -8.308E-01; val_nu_mass_loss: 4.497E-02; val_w0_mass_mae_loss: 1.260E+01; val_w1_mass_mae_loss: 1.520E+01; val_w_mass_mmd0_loss: 3.625E-02; val_w_mass_mmd1_loss: 2.722E-02; w0_mass_mae_loss: 1.277E+01; w1_mass_mae_loss: 1.525E+01; w_mass_mmd0_loss: 5.186E-02; w_mass_mmd1_loss: 3.013E-02
# Epoch 69; dinu_pt_loss: 1.651E+01; higgs_mass_loss: 2.098E+00; loss: 6.909E+01; mae_loss: 3.317E+01; neg_r2_loss: -8.320E-01; nu_mass_loss: 4.560E-02; val_dinu_pt_loss: 1.544E+01; val_higgs_mass_loss: 1.758E+00; val_loss: 6.863E+01; val_mae_loss: 3.317E+01; val_neg_r2_loss: -8.314E-01; val_nu_mass_loss: 4.509E-02; val_w0_mass_mae_loss: 1.267E+01; val_w1_mass_mae_loss: 1.521E+01; val_w_mass_mmd0_loss: 3.798E-02; val_w_mass_mmd1_loss: 2.765E-02; w0_mass_mae_loss: 1.276E+01; w1_mass_mae_loss: 1.525E+01; w_mass_mmd0_loss: 5.161E-02; w_mass_mmd1_loss: 2.960E-02
# Epoch 70; dinu_pt_loss: 1.638E+01; higgs_mass_loss: 2.092E+00; loss: 6.905E+01; mae_loss: 3.315E+01; neg_r2_loss: -8.322E-01; nu_mass_loss: 4.564E-02; val_dinu_pt_loss: 1.507E+01; val_higgs_mass_loss: 1.794E+00; val_loss: 6.868E+01; val_mae_loss: 3.315E+01; val_neg_r2_loss: -8.310E-01; val_nu_mass_loss: 4.496E-02; val_w0_mass_mae_loss: 1.255E+01; val_w1_mass_mae_loss: 1.517E+01; val_w_mass_mmd0_loss: 4.489E-02; val_w_mass_mmd1_loss: 2.816E-02; w0_mass_mae_loss: 1.275E+01; w1_mass_mae_loss: 1.525E+01; w_mass_mmd0_loss: 5.167E-02; w_mass_mmd1_loss: 2.986E-02
# Epoch 71; dinu_pt_loss: 1.621E+01; higgs_mass_loss: 2.082E+00; loss: 6.900E+01; mae_loss: 3.314E+01; neg_r2_loss: -8.324E-01; nu_mass_loss: 4.569E-02; val_dinu_pt_loss: 1.495E+01; val_higgs_mass_loss: 1.779E+00; val_loss: 6.862E+01; val_mae_loss: 3.314E+01; val_neg_r2_loss: -8.313E-01; val_nu_mass_loss: 4.534E-02; val_w0_mass_mae_loss: 1.258E+01; val_w1_mass_mae_loss: 1.520E+01; val_w_mass_mmd0_loss: 4.060E-02; val_w_mass_mmd1_loss: 2.781E-02; w0_mass_mae_loss: 1.275E+01; w1_mass_mae_loss: 1.525E+01; w_mass_mmd0_loss: 5.103E-02; w_mass_mmd1_loss: 2.964E-02
# Epoch 72; dinu_pt_loss: 1.623E+01; higgs_mass_loss: 2.061E+00; loss: 6.895E+01; mae_loss: 3.312E+01; neg_r2_loss: -8.326E-01; nu_mass_loss: 4.572E-02; val_dinu_pt_loss: 1.492E+01; val_higgs_mass_loss: 1.730E+00; val_loss: 6.860E+01; val_mae_loss: 3.314E+01; val_neg_r2_loss: -8.317E-01; val_nu_mass_loss: 4.517E-02; val_w0_mass_mae_loss: 1.264E+01; val_w1_mass_mae_loss: 1.519E+01; val_w_mass_mmd0_loss: 4.486E-02; val_w_mass_mmd1_loss: 2.773E-02; w0_mass_mae_loss: 1.273E+01; w1_mass_mae_loss: 1.524E+01; w_mass_mmd0_loss: 5.085E-02; w_mass_mmd1_loss: 2.942E-02
# Epoch 73; dinu_pt_loss: 1.621E+01; higgs_mass_loss: 2.053E+00; loss: 6.892E+01; mae_loss: 3.311E+01; neg_r2_loss: -8.327E-01; nu_mass_loss: 4.576E-02; val_dinu_pt_loss: 1.490E+01; val_higgs_mass_loss: 1.698E+00; val_loss: 6.848E+01; val_mae_loss: 3.313E+01; val_neg_r2_loss: -8.313E-01; val_nu_mass_loss: 4.498E-02; val_w0_mass_mae_loss: 1.258E+01; val_w1_mass_mae_loss: 1.519E+01; val_w_mass_mmd0_loss: 3.709E-02; val_w_mass_mmd1_loss: 2.769E-02; w0_mass_mae_loss: 1.275E+01; w1_mass_mae_loss: 1.525E+01; w_mass_mmd0_loss: 5.061E-02; w_mass_mmd1_loss: 2.932E-02
# Epoch 74; dinu_pt_loss: 1.622E+01; higgs_mass_loss: 2.036E+00; loss: 6.887E+01; mae_loss: 3.310E+01; neg_r2_loss: -8.329E-01; nu_mass_loss: 4.573E-02; val_dinu_pt_loss: 1.469E+01; val_higgs_mass_loss: 1.765E+00; val_loss: 6.845E+01; val_mae_loss: 3.311E+01; val_neg_r2_loss: -8.315E-01; val_nu_mass_loss: 4.507E-02; val_w0_mass_mae_loss: 1.258E+01; val_w1_mass_mae_loss: 1.515E+01; val_w_mass_mmd0_loss: 3.169E-02; val_w_mass_mmd1_loss: 2.779E-02; w0_mass_mae_loss: 1.275E+01; w1_mass_mae_loss: 1.524E+01; w_mass_mmd0_loss: 5.016E-02; w_mass_mmd1_loss: 2.928E-02
# Epoch 75; dinu_pt_loss: 1.601E+01; higgs_mass_loss: 2.033E+00; loss: 6.884E+01; mae_loss: 3.308E+01; neg_r2_loss: -8.329E-01; nu_mass_loss: 4.573E-02; val_dinu_pt_loss: 1.467E+01; val_higgs_mass_loss: 1.803E+00; val_loss: 6.859E+01; val_mae_loss: 3.311E+01; val_neg_r2_loss: -8.317E-01; val_nu_mass_loss: 4.536E-02; val_w0_mass_mae_loss: 1.251E+01; val_w1_mass_mae_loss: 1.516E+01; val_w_mass_mmd0_loss: 4.184E-02; val_w_mass_mmd1_loss: 2.795E-02; w0_mass_mae_loss: 1.274E+01; w1_mass_mae_loss: 1.523E+01; w_mass_mmd0_loss: 5.069E-02; w_mass_mmd1_loss: 2.902E-02
# Epoch 76; dinu_pt_loss: 1.592E+01; higgs_mass_loss: 2.023E+00; loss: 6.880E+01; mae_loss: 3.307E+01; neg_r2_loss: -8.331E-01; nu_mass_loss: 4.577E-02; val_dinu_pt_loss: 1.469E+01; val_higgs_mass_loss: 1.793E+00; val_loss: 6.843E+01; val_mae_loss: 3.309E+01; val_neg_r2_loss: -8.327E-01; val_nu_mass_loss: 4.573E-02; val_w0_mass_mae_loss: 1.252E+01; val_w1_mass_mae_loss: 1.515E+01; val_w_mass_mmd0_loss: 3.133E-02; val_w_mass_mmd1_loss: 2.754E-02; w0_mass_mae_loss: 1.274E+01; w1_mass_mae_loss: 1.523E+01; w_mass_mmd0_loss: 5.027E-02; w_mass_mmd1_loss: 2.928E-02
# Epoch 77; dinu_pt_loss: 1.595E+01; higgs_mass_loss: 2.017E+00; loss: 6.877E+01; mae_loss: 3.306E+01; neg_r2_loss: -8.332E-01; nu_mass_loss: 4.586E-02; val_dinu_pt_loss: 1.446E+01; val_higgs_mass_loss: 1.838E+00; val_loss: 6.853E+01; val_mae_loss: 3.307E+01; val_neg_r2_loss: -8.323E-01; val_nu_mass_loss: 4.522E-02; val_w0_mass_mae_loss: 1.251E+01; val_w1_mass_mae_loss: 1.512E+01; val_w_mass_mmd0_loss: 3.888E-02; val_w_mass_mmd1_loss: 2.844E-02; w0_mass_mae_loss: 1.274E+01; w1_mass_mae_loss: 1.523E+01; w_mass_mmd0_loss: 4.913E-02; w_mass_mmd1_loss: 2.915E-02
# Epoch 78; dinu_pt_loss: 1.595E+01; higgs_mass_loss: 2.001E+00; loss: 6.873E+01; mae_loss: 3.306E+01; neg_r2_loss: -8.333E-01; nu_mass_loss: 4.586E-02; val_dinu_pt_loss: 1.454E+01; val_higgs_mass_loss: 1.618E+00; val_loss: 6.827E+01; val_mae_loss: 3.308E+01; val_neg_r2_loss: -8.318E-01; val_nu_mass_loss: 4.533E-02; val_w0_mass_mae_loss: 1.259E+01; val_w1_mass_mae_loss: 1.516E+01; val_w_mass_mmd0_loss: 3.505E-02; val_w_mass_mmd1_loss: 2.693E-02; w0_mass_mae_loss: 1.272E+01; w1_mass_mae_loss: 1.522E+01; w_mass_mmd0_loss: 4.883E-02; w_mass_mmd1_loss: 2.874E-02
# Epoch 79; dinu_pt_loss: 1.584E+01; higgs_mass_loss: 1.995E+00; loss: 6.870E+01; mae_loss: 3.304E+01; neg_r2_loss: -8.334E-01; nu_mass_loss: 4.589E-02; val_dinu_pt_loss: 1.446E+01; val_higgs_mass_loss: 1.678E+00; val_loss: 6.826E+01; val_mae_loss: 3.306E+01; val_neg_r2_loss: -8.317E-01; val_nu_mass_loss: 4.513E-02; val_w0_mass_mae_loss: 1.266E+01; val_w1_mass_mae_loss: 1.517E+01; val_w_mass_mmd0_loss: 3.178E-02; val_w_mass_mmd1_loss: 2.624E-02; w0_mass_mae_loss: 1.273E+01; w1_mass_mae_loss: 1.522E+01; w_mass_mmd0_loss: 4.882E-02; w_mass_mmd1_loss: 2.901E-02
# Epoch 80; dinu_pt_loss: 1.577E+01; higgs_mass_loss: 1.992E+00; loss: 6.866E+01; mae_loss: 3.302E+01; neg_r2_loss: -8.335E-01; nu_mass_loss: 4.583E-02; val_dinu_pt_loss: 1.462E+01; val_higgs_mass_loss: 1.559E+00; val_loss: 6.826E+01; val_mae_loss: 3.311E+01; val_neg_r2_loss: -8.318E-01; val_nu_mass_loss: 4.533E-02; val_w0_mass_mae_loss: 1.261E+01; val_w1_mass_mae_loss: 1.519E+01; val_w_mass_mmd0_loss: 3.454E-02; val_w_mass_mmd1_loss: 2.672E-02; w0_mass_mae_loss: 1.271E+01; w1_mass_mae_loss: 1.521E+01; w_mass_mmd0_loss: 4.870E-02; w_mass_mmd1_loss: 2.926E-02
# Epoch 81; dinu_pt_loss: 1.566E+01; higgs_mass_loss: 1.974E+00; loss: 6.863E+01; mae_loss: 3.302E+01; neg_r2_loss: -8.336E-01; nu_mass_loss: 4.590E-02; val_dinu_pt_loss: 1.442E+01; val_higgs_mass_loss: 1.857E+00; val_loss: 6.850E+01; val_mae_loss: 3.306E+01; val_neg_r2_loss: -8.321E-01; val_nu_mass_loss: 4.541E-02; val_w0_mass_mae_loss: 1.254E+01; val_w1_mass_mae_loss: 1.512E+01; val_w_mass_mmd0_loss: 3.684E-02; val_w_mass_mmd1_loss: 2.766E-02; w0_mass_mae_loss: 1.272E+01; w1_mass_mae_loss: 1.522E+01; w_mass_mmd0_loss: 4.885E-02; w_mass_mmd1_loss: 2.861E-02
# ...
# Epoch 103; dinu_pt_loss: 1.496E+01; higgs_mass_loss: 1.818E+00; loss: 6.807E+01; mae_loss: 3.284E+01; neg_r2_loss: -8.353E-01; nu_mass_loss: 4.620E-02; val_dinu_pt_loss: 1.376E+01; val_higgs_mass_loss: 1.481E+00; val_loss: 6.783E+01; val_mae_loss: 3.297E+01; val_neg_r2_loss: -8.327E-01; val_nu_mass_loss: 4.545E-02; val_w0_mass_mae_loss: 1.259E+01; val_w1_mass_mae_loss: 1.513E+01; val_w_mass_mmd0_loss: 2.490E-02; val_w_mass_mmd1_loss: 2.545E-02; w0_mass_mae_loss: 1.269E+01; w1_mass_mae_loss: 1.518E+01; w_mass_mmd0_loss: 4.400E-02; w_mass_mmd1_loss: 2.745E-02
# Epoch 104; dinu_pt_loss: 1.492E+01; higgs_mass_loss: 1.814E+00; loss: 6.806E+01; mae_loss: 3.284E+01; neg_r2_loss: -8.352E-01; nu_mass_loss: 4.614E-02; val_dinu_pt_loss: 1.383E+01; val_higgs_mass_loss: 1.588E+00; val_loss: 6.804E+01; val_mae_loss: 3.299E+01; val_neg_r2_loss: -8.328E-01; val_nu_mass_loss: 4.548E-02; val_w0_mass_mae_loss: 1.259E+01; val_w1_mass_mae_loss: 1.515E+01; val_w_mass_mmd0_loss: 3.632E-02; val_w_mass_mmd1_loss: 2.400E-02; w0_mass_mae_loss: 1.268E+01; w1_mass_mae_loss: 1.518E+01; w_mass_mmd0_loss: 4.390E-02; w_mass_mmd1_loss: 2.736E-02
# Epoch 105; dinu_pt_loss: 1.500E+01; higgs_mass_loss: 1.811E+00; loss: 6.802E+01; mae_loss: 3.282E+01; neg_r2_loss: -8.355E-01; nu_mass_loss: 4.610E-02; val_dinu_pt_loss: 1.359E+01; val_higgs_mass_loss: 1.490E+00; val_loss: 6.784E+01; val_mae_loss: 3.297E+01; val_neg_r2_loss: -8.327E-01; val_nu_mass_loss: 4.550E-02; val_w0_mass_mae_loss: 1.256E+01; val_w1_mass_mae_loss: 1.513E+01; val_w_mass_mmd0_loss: 2.576E-02; val_w_mass_mmd1_loss: 2.473E-02; w0_mass_mae_loss: 1.267E+01; w1_mass_mae_loss: 1.518E+01; w_mass_mmd0_loss: 4.357E-02; w_mass_mmd1_loss: 2.737E-02
# Epoch 106; dinu_pt_loss: 1.490E+01; higgs_mass_loss: 1.803E+00; loss: 6.801E+01; mae_loss: 3.282E+01; neg_r2_loss: -8.355E-01; nu_mass_loss: 4.615E-02; val_dinu_pt_loss: 1.368E+01; val_higgs_mass_loss: 1.698E+00; val_loss: 6.808E+01; val_mae_loss: 3.298E+01; val_neg_r2_loss: -8.321E-01; val_nu_mass_loss: 4.542E-02; val_w0_mass_mae_loss: 1.260E+01; val_w1_mass_mae_loss: 1.516E+01; val_w_mass_mmd0_loss: 2.900E-02; val_w_mass_mmd1_loss: 2.471E-02; w0_mass_mae_loss: 1.267E+01; w1_mass_mae_loss: 1.517E+01; w_mass_mmd0_loss: 4.413E-02; w_mass_mmd1_loss: 2.757E-02
# Epoch 107; dinu_pt_loss: 1.488E+01; higgs_mass_loss: 1.809E+00; loss: 6.800E+01; mae_loss: 3.281E+01; neg_r2_loss: -8.355E-01; nu_mass_loss: 4.613E-02; val_dinu_pt_loss: 1.356E+01; val_higgs_mass_loss: 1.527E+00; val_loss: 6.790E+01; val_mae_loss: 3.295E+01; val_neg_r2_loss: -8.331E-01; val_nu_mass_loss: 4.535E-02; val_w0_mass_mae_loss: 1.252E+01; val_w1_mass_mae_loss: 1.513E+01; val_w_mass_mmd0_loss: 3.461E-02; val_w_mass_mmd1_loss: 2.544E-02; w0_mass_mae_loss: 1.268E+01; w1_mass_mae_loss: 1.517E+01; w_mass_mmd0_loss: 4.404E-02; w_mass_mmd1_loss: 2.741E-02
# Epoch 108; dinu_pt_loss: 1.481E+01; higgs_mass_loss: 1.802E+00; loss: 6.797E+01; mae_loss: 3.280E+01; neg_r2_loss: -8.356E-01; nu_mass_loss: 4.613E-02; val_dinu_pt_loss: 1.354E+01; val_higgs_mass_loss: 1.579E+00; val_loss: 6.795E+01; val_mae_loss: 3.295E+01; val_neg_r2_loss: -8.325E-01; val_nu_mass_loss: 4.553E-02; val_w0_mass_mae_loss: 1.256E+01; val_w1_mass_mae_loss: 1.514E+01; val_w_mass_mmd0_loss: 3.359E-02; val_w_mass_mmd1_loss: 2.461E-02; w0_mass_mae_loss: 1.269E+01; w1_mass_mae_loss: 1.517E+01; w_mass_mmd0_loss: 4.336E-02; w_mass_mmd1_loss: 2.781E-02
# Epoch 109; dinu_pt_loss: 1.491E+01; higgs_mass_loss: 1.794E+00; loss: 6.795E+01; mae_loss: 3.280E+01; neg_r2_loss: -8.357E-01; nu_mass_loss: 4.613E-02; val_dinu_pt_loss: 1.357E+01; val_higgs_mass_loss: 1.561E+00; val_loss: 6.796E+01; val_mae_loss: 3.299E+01; val_neg_r2_loss: -8.321E-01; val_nu_mass_loss: 4.550E-02; val_w0_mass_mae_loss: 1.262E+01; val_w1_mass_mae_loss: 1.515E+01; val_w_mass_mmd0_loss: 2.863E-02; val_w_mass_mmd1_loss: 2.464E-02; w0_mass_mae_loss: 1.268E+01; w1_mass_mae_loss: 1.517E+01; w_mass_mmd0_loss: 4.252E-02; w_mass_mmd1_loss: 2.723E-02
# Epoch 110; dinu_pt_loss: 1.486E+01; higgs_mass_loss: 1.794E+00; loss: 6.794E+01; mae_loss: 3.279E+01; neg_r2_loss: -8.357E-01; nu_mass_loss: 4.616E-02; val_dinu_pt_loss: 1.306E+01; val_higgs_mass_loss: 1.640E+00; val_loss: 6.794E+01; val_mae_loss: 3.294E+01; val_neg_r2_loss: -8.322E-01; val_nu_mass_loss: 4.534E-02; val_w0_mass_mae_loss: 1.257E+01; val_w1_mass_mae_loss: 1.514E+01; val_w_mass_mmd0_loss: 2.736E-02; val_w_mass_mmd1_loss: 2.484E-02; w0_mass_mae_loss: 1.269E+01; w1_mass_mae_loss: 1.517E+01; w_mass_mmd0_loss: 4.262E-02; w_mass_mmd1_loss: 2.735E-02
# Epoch 111; dinu_pt_loss: 1.472E+01; higgs_mass_loss: 1.788E+00; loss: 6.794E+01; mae_loss: 3.279E+01; neg_r2_loss: -8.357E-01; nu_mass_loss: 4.617E-02; val_dinu_pt_loss: 1.349E+01; val_higgs_mass_loss: 1.596E+00; val_loss: 6.805E+01; val_mae_loss: 3.296E+01; val_neg_r2_loss: -8.325E-01; val_nu_mass_loss: 4.543E-02; val_w0_mass_mae_loss: 1.253E+01; val_w1_mass_mae_loss: 1.512E+01; val_w_mass_mmd0_loss: 4.144E-02; val_w_mass_mmd1_loss: 2.465E-02; w0_mass_mae_loss: 1.269E+01; w1_mass_mae_loss: 1.516E+01; w_mass_mmd0_loss: 4.342E-02; w_mass_mmd1_loss: 2.766E-02
# Epoch 112; dinu_pt_loss: 1.477E+01; higgs_mass_loss: 1.782E+00; loss: 6.790E+01; mae_loss: 3.278E+01; neg_r2_loss: -8.359E-01; nu_mass_loss: 4.619E-02; val_dinu_pt_loss: 1.360E+01; val_higgs_mass_loss: 1.463E+00; val_loss: 6.784E+01; val_mae_loss: 3.296E+01; val_neg_r2_loss: -8.323E-01; val_nu_mass_loss: 4.523E-02; val_w0_mass_mae_loss: 1.258E+01; val_w1_mass_mae_loss: 1.512E+01; val_w_mass_mmd0_loss: 3.278E-02; val_w_mass_mmd1_loss: 2.442E-02; w0_mass_mae_loss: 1.268E+01; w1_mass_mae_loss: 1.516E+01; w_mass_mmd0_loss: 4.329E-02; w_mass_mmd1_loss: 2.707E-02
# Epoch 113; dinu_pt_loss: 1.486E+01; higgs_mass_loss: 1.773E+00; loss: 6.788E+01; mae_loss: 3.277E+01; neg_r2_loss: -8.359E-01; nu_mass_loss: 4.620E-02; val_dinu_pt_loss: 1.358E+01; val_higgs_mass_loss: 1.454E+00; val_loss: 6.773E+01; val_mae_loss: 3.294E+01; val_neg_r2_loss: -8.326E-01; val_nu_mass_loss: 4.519E-02; val_w0_mass_mae_loss: 1.258E+01; val_w1_mass_mae_loss: 1.512E+01; val_w_mass_mmd0_loss: 2.609E-02; val_w_mass_mmd1_loss: 2.424E-02; w0_mass_mae_loss: 1.267E+01; w1_mass_mae_loss: 1.516E+01; w_mass_mmd0_loss: 4.257E-02; w_mass_mmd1_loss: 2.706E-02
# Epoch 114; dinu_pt_loss: 1.480E+01; higgs_mass_loss: 1.773E+00; loss: 6.787E+01; mae_loss: 3.277E+01; neg_r2_loss: -8.359E-01; nu_mass_loss: 4.622E-02; val_dinu_pt_loss: 1.346E+01; val_higgs_mass_loss: 1.492E+00; val_loss: 6.781E+01; val_mae_loss: 3.295E+01; val_neg_r2_loss: -8.327E-01; val_nu_mass_loss: 4.552E-02; val_w0_mass_mae_loss: 1.260E+01; val_w1_mass_mae_loss: 1.514E+01; val_w_mass_mmd0_loss: 2.913E-02; val_w_mass_mmd1_loss: 2.374E-02; w0_mass_mae_loss: 1.267E+01; w1_mass_mae_loss: 1.516E+01; w_mass_mmd0_loss: 4.261E-02; w_mass_mmd1_loss: 2.728E-02
# Epoch 115; dinu_pt_loss: 1.474E+01; higgs_mass_loss: 1.761E+00; loss: 6.784E+01; mae_loss: 3.276E+01; neg_r2_loss: -8.360E-01; nu_mass_loss: 4.624E-02; val_dinu_pt_loss: 1.340E+01; val_higgs_mass_loss: 1.467E+00; val_loss: 6.776E+01; val_mae_loss: 3.293E+01; val_neg_r2_loss: -8.329E-01; val_nu_mass_loss: 4.563E-02; val_w0_mass_mae_loss: 1.258E+01; val_w1_mass_mae_loss: 1.511E+01; val_w_mass_mmd0_loss: 2.903E-02; val_w_mass_mmd1_loss: 2.531E-02; w0_mass_mae_loss: 1.267E+01; w1_mass_mae_loss: 1.517E+01; w_mass_mmd0_loss: 4.277E-02; w_mass_mmd1_loss: 2.712E-02
# Epoch 116; dinu_pt_loss: 1.471E+01; higgs_mass_loss: 1.764E+00; loss: 6.784E+01; mae_loss: 3.276E+01; neg_r2_loss: -8.360E-01; nu_mass_loss: 4.624E-02; val_dinu_pt_loss: 1.325E+01; val_higgs_mass_loss: 1.554E+00; val_loss: 6.789E+01; val_mae_loss: 3.296E+01; val_neg_r2_loss: -8.316E-01; val_nu_mass_loss: 4.512E-02; val_w0_mass_mae_loss: 1.253E+01; val_w1_mass_mae_loss: 1.517E+01; val_w_mass_mmd0_loss: 2.890E-02; val_w_mass_mmd1_loss: 2.359E-02; w0_mass_mae_loss: 1.267E+01; w1_mass_mae_loss: 1.516E+01; w_mass_mmd0_loss: 4.257E-02; w_mass_mmd1_loss: 2.725E-02
# Epoch 117; dinu_pt_loss: 1.464E+01; higgs_mass_loss: 1.755E+00; loss: 6.780E+01; mae_loss: 3.275E+01; neg_r2_loss: -8.360E-01; nu_mass_loss: 4.621E-02; val_dinu_pt_loss: 1.326E+01; val_higgs_mass_loss: 1.554E+00; val_loss: 6.787E+01; val_mae_loss: 3.295E+01; val_neg_r2_loss: -8.330E-01; val_nu_mass_loss: 4.568E-02; val_w0_mass_mae_loss: 1.255E+01; val_w1_mass_mae_loss: 1.514E+01; val_w_mass_mmd0_loss: 2.775E-02; val_w_mass_mmd1_loss: 2.382E-02; w0_mass_mae_loss: 1.267E+01; w1_mass_mae_loss: 1.517E+01; w_mass_mmd0_loss: 4.211E-02; w_mass_mmd1_loss: 2.669E-02
# Epoch 118; dinu_pt_loss: 1.465E+01; higgs_mass_loss: 1.752E+00; loss: 6.778E+01; mae_loss: 3.274E+01; neg_r2_loss: -8.362E-01; nu_mass_loss: 4.619E-02; val_dinu_pt_loss: 1.326E+01; val_higgs_mass_loss: 1.511E+00; val_loss: 6.782E+01; val_mae_loss: 3.294E+01; val_neg_r2_loss: -8.326E-01; val_nu_mass_loss: 4.532E-02; val_w0_mass_mae_loss: 1.253E+01; val_w1_mass_mae_loss: 1.511E+01; val_w_mass_mmd0_loss: 3.003E-02; val_w_mass_mmd1_loss: 2.416E-02; w0_mass_mae_loss: 1.267E+01; w1_mass_mae_loss: 1.515E+01; w_mass_mmd0_loss: 4.201E-02; w_mass_mmd1_loss: 2.695E-02
# Epoch 119; dinu_pt_loss: 1.466E+01; higgs_mass_loss: 1.752E+00; loss: 6.777E+01; mae_loss: 3.273E+01; neg_r2_loss: -8.362E-01; nu_mass_loss: 4.624E-02; val_dinu_pt_loss: 1.347E+01; val_higgs_mass_loss: 1.468E+00; val_loss: 6.780E+01; val_mae_loss: 3.295E+01; val_neg_r2_loss: -8.323E-01; val_nu_mass_loss: 4.557E-02; val_w0_mass_mae_loss: 1.259E+01; val_w1_mass_mae_loss: 1.513E+01; val_w_mass_mmd0_loss: 2.969E-02; val_w_mass_mmd1_loss: 2.450E-02; w0_mass_mae_loss: 1.266E+01; w1_mass_mae_loss: 1.516E+01; w_mass_mmd0_loss: 4.232E-02; w_mass_mmd1_loss: 2.674E-02
# Epoch 120; dinu_pt_loss: 1.457E+01; higgs_mass_loss: 1.752E+00; loss: 6.776E+01; mae_loss: 3.272E+01; neg_r2_loss: -8.363E-01; nu_mass_loss: 4.621E-02; val_dinu_pt_loss: 1.306E+01; val_higgs_mass_loss: 1.622E+00; val_loss: 6.798E+01; val_mae_loss: 3.295E+01; val_neg_r2_loss: -8.326E-01; val_nu_mass_loss: 4.558E-02; val_w0_mass_mae_loss: 1.251E+01; val_w1_mass_mae_loss: 1.510E+01; val_w_mass_mmd0_loss: 3.250E-02; val_w_mass_mmd1_loss: 2.437E-02; w0_mass_mae_loss: 1.266E+01; w1_mass_mae_loss: 1.516E+01; w_mass_mmd0_loss: 4.265E-02; w_mass_mmd1_loss: 2.688E-02
# Epoch 121; dinu_pt_loss: 1.454E+01; higgs_mass_loss: 1.742E+00; loss: 6.774E+01; mae_loss: 3.272E+01; neg_r2_loss: -8.362E-01; nu_mass_loss: 4.624E-02; val_dinu_pt_loss: 1.317E+01; val_higgs_mass_loss: 1.509E+00; val_loss: 6.775E+01; val_mae_loss: 3.292E+01; val_neg_r2_loss: -8.324E-01; val_nu_mass_loss: 4.518E-02; val_w0_mass_mae_loss: 1.256E+01; val_w1_mass_mae_loss: 1.512E+01; val_w_mass_mmd0_loss: 2.662E-02; val_w_mass_mmd1_loss: 2.422E-02; w0_mass_mae_loss: 1.266E+01; w1_mass_mae_loss: 1.515E+01; w_mass_mmd0_loss: 4.239E-02; w_mass_mmd1_loss: 2.701E-02
# Epoch 122; dinu_pt_loss: 1.457E+01; higgs_mass_loss: 1.738E+00; loss: 6.772E+01; mae_loss: 3.271E+01; neg_r2_loss: -8.364E-01; nu_mass_loss: 4.626E-02; val_dinu_pt_loss: 1.296E+01; val_higgs_mass_loss: 1.734E+00; val_loss: 6.804E+01; val_mae_loss: 3.292E+01; val_neg_r2_loss: -8.323E-01; val_nu_mass_loss: 4.536E-02; val_w0_mass_mae_loss: 1.253E+01; val_w1_mass_mae_loss: 1.513E+01; val_w_mass_mmd0_loss: 3.289E-02; val_w_mass_mmd1_loss: 2.439E-02; w0_mass_mae_loss: 1.265E+01; w1_mass_mae_loss: 1.515E+01; w_mass_mmd0_loss: 4.250E-02; w_mass_mmd1_loss: 2.689E-02
# Epoch 123; dinu_pt_loss: 1.456E+01; higgs_mass_loss: 1.732E+00; loss: 6.770E+01; mae_loss: 3.271E+01; neg_r2_loss: -8.364E-01; nu_mass_loss: 4.630E-02; val_dinu_pt_loss: 1.326E+01; val_higgs_mass_loss: 1.475E+00; val_loss: 6.774E+01; val_mae_loss: 3.290E+01; val_neg_r2_loss: -8.330E-01; val_nu_mass_loss: 4.541E-02; val_w0_mass_mae_loss: 1.254E+01; val_w1_mass_mae_loss: 1.511E+01; val_w_mass_mmd0_loss: 3.238E-02; val_w_mass_mmd1_loss: 2.406E-02; w0_mass_mae_loss: 1.265E+01; w1_mass_mae_loss: 1.516E+01; w_mass_mmd0_loss: 4.161E-02; w_mass_mmd1_loss: 2.660E-02
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751681274.824318 2766850 service.cc:145] XLA service 0x7c2e1c013380 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751681274.824337 2766850 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751681282.792862 2766998 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1751681282.838113 2767013 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_15', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1751681283.184964 2767026 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1751681283.219077 2767005 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1751681283.267006 2767020 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1751681283.272301 2767006 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1751681283.387217 2767015 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1751681291.814454 2766850 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_26', 8 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1751681291.832687 2766850 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# I0000 00:00:1751681303.888114 2767413 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_18', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1751681303.889159 2767407 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_18', 24 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1751681304.061401 2767398 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 240 bytes spill stores, 240 bytes spill loads
#
# I0000 00:00:1751681304.415340 2767406 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_19', 176 bytes spill stores, 168 bytes spill loads
#
# I0000 00:00:1751681304.475787 2767420 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_17', 240 bytes spill stores, 240 bytes spill loads
#
# I0000 00:00:1751681312.183687 2766852 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_33', 8 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1751681314.983847 2767876 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_10', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1751681314.989803 2767878 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_10', 24 bytes spill stores, 24 bytes spill loads

# %%
pred_y = model.predict(test_x)
# Out:
# 4378/4378 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# I0000 00:00:1751682029.820542 2792647 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 8 bytes spill stores, 8 bytes spill loads

# %%
label_lead_w_px = test_y[:, 0]
label_lead_w_py = test_y[:, 1]
label_lead_w_pz = test_y[:, 2]
label_lead_w_energy = test_y[:, 3]
label_sublead_w_px = test_y[:, 4]
label_sublead_w_py = test_y[:, 5]
label_sublead_w_pz = test_y[:, 6]
label_sublead_w_energy = test_y[:, 7]

pred_lead_w_px = pred_y[:, 0]
pred_lead_w_py = pred_y[:, 1]
pred_lead_w_pz = pred_y[:, 2]
pred_lead_w_energy = pred_y[:, 3]
pred_sublead_w_px = pred_y[:, 4]
pred_sublead_w_py = pred_y[:, 5]
pred_sublead_w_pz = pred_y[:, 6]
pred_sublead_w_energy = pred_y[:, 7]

# %%
# px

# lead
plt.hist(label_lead_w_px, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_px, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_0}_{x}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_px,
	pred_lead_w_px,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_0}_{x}$", loc='right')
plt.show()

# sublead px
plt.hist(label_sublead_w_px, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_px, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_1}_{x}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_px,
	pred_sublead_w_px,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_1}_{x}$", loc='right')
plt.show()

# %%
# py

# lead
plt.hist(label_lead_w_py, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_py, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_0}_{y}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_py,
	pred_lead_w_py,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_0}_{y}$", loc='right')
plt.show()

# sublead py
plt.hist(label_sublead_w_py, bins=np.linspace(-200, 200, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_py, bins=np.linspace(-200, 200, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_1}_{y}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_py,
	pred_sublead_w_py,
	bins=(51, 51),
	range=([-200, 200], [-200, 200]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_1}_{y}$", loc='right')
plt.show()

# %%
# pz

# lead
plt.hist(label_lead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_0}_{z}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_pz,
	pred_lead_w_pz,
	bins=(51, 51),
	range=([-1000, 1000], [-1000, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_0}_{z}$", loc='right')
plt.show()

# sublead pz
plt.hist(label_sublead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_pz, bins=np.linspace(-1000, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$p^{\ell_1}_{z}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_pz,
	pred_sublead_w_pz,
	bins=(51, 51),
	range=([-1000, 1000], [-1000, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$p^{\ell_1}_{z}$", loc='right')
plt.show()

# %%
# energy

# lead
plt.hist(label_lead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$E^{\ell_0}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_energy,
	pred_lead_w_energy,
	bins=(51, 51),
	range=([0, 1000], [0, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$E^{\ell_0}$", loc='right')
plt.show()

# sublead energy
plt.hist(label_sublead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_energy, bins=np.linspace(0, 1000, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$E^{\ell_1}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_energy,
	pred_sublead_w_energy,
	bins=(51, 51),
	range=([0, 1000], [0, 1000]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$E^{\ell_1}$", loc='right')
plt.show()

# %%
# W inv mass

w_lead_pred = np.sqrt(
	np.square(pred_lead_w_energy)
	- np.square(pred_lead_w_px)
	- np.square(pred_lead_w_py)
	- np.square(pred_lead_w_pz)
)
w_sublead_pred = np.sqrt(
	np.square(pred_sublead_w_energy)
	- np.square(pred_sublead_w_px)
	- np.square(pred_sublead_w_py)
	- np.square(pred_sublead_w_pz)
)
w_lead_label = np.sqrt(
	np.square(label_lead_w_energy)
	- np.square(label_lead_w_px)
	- np.square(label_lead_w_py)
	- np.square(label_lead_w_pz)
)
w_sublead_label = np.sqrt(
	np.square(label_sublead_w_energy)
	- np.square(label_sublead_w_px)
	- np.square(label_sublead_w_py)
	- np.square(label_sublead_w_pz)
)

plt.hist(w_lead_pred, bins=np.linspace(0, 100, 51), label=r"Pred", histtype="step", linewidth=2, color="red")
plt.hist(w_lead_label, bins=np.linspace(0, 100, 51), label=r"Label", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.xlim(0, 100)
plt.show()

plt.hist2d(
	w_lead_pred,
	w_lead_label,
	bins=(51, 51),
	range=([0, 100], [0, 100]),
	cmap="viridis",
	cmin=1,
	norm = LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel("Pred")
plt.xlabel("Label")
plt.title(r"$m_{W_0}$", loc='right')
plt.show()


plt.hist(w_sublead_pred, bins=np.linspace(0, 100, 51), label="Pred", histtype="step", linewidth=2, color="red")
plt.hist(w_sublead_label, bins=np.linspace(0, 100, 51), label="Label", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.xlim(0, 100)
plt.show()

plt.hist2d(
	w_sublead_pred,
	w_sublead_label,
	bins=(51, 51),
	range=([0, 100], [0, 100]),
	cmap="viridis",
	cmin=1,
	norm = LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel("Pred")
plt.xlabel("Label")
plt.title(r"$m_{W_1}$", loc='right')
plt.show()

# %%
# WW* inv mass
ww_pred = np.sqrt(
	np.square(pred_lead_w_energy + pred_sublead_w_energy)
	- np.square(pred_lead_w_px + pred_sublead_w_px)
	- np.square(pred_lead_w_py + pred_sublead_w_py)
	- np.square(pred_lead_w_pz + pred_sublead_w_pz)
)
ww_label = np.sqrt(
	np.square(label_lead_w_energy + label_sublead_w_energy)
	- np.square(label_lead_w_px + label_sublead_w_px)
	- np.square(label_lead_w_py + label_sublead_w_py)
	- np.square(label_lead_w_pz + label_sublead_w_pz)
)
plt.hist(ww_pred, bins=np.linspace(100, 140, 51), label="Pred", histtype="step", linewidth=2, color="red")
plt.hist(ww_label, bins=np.linspace(100, 140, 51), label="Label", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.xlim(100, 140)
plt.show()

plt.hist2d(
	ww_pred,
	ww_label,
	bins=(51, 51),
	range=([100, 140], [100, 140]),
	cmap="viridis",
	cmin=1,
	norm = LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel("Pred")
plt.xlabel("Label")
plt.title(r"$m_{WW^\ast}$", loc='right')
plt.show()

# %%
def Bij(particles):
    # Ensure ROOT is properly initialized
    ROOT.gROOT.SetBatch(True)

    def cglmp(z_xp, z_xn, z_yp, z_yn):
        """
        This is a function to calculate Bij (CGLMP values).
        :param z_xp: Angle (xi) between positive lepton and x-axis.
        :param z_xn: Angle (xi) between negative lepton and x-axis.
        :param z_yp: Angle (xi) between positive lepton and y-axis.
        :param z_xn: Angle (xi) between negative lepton and y-axis.
        """
        # count expectation value, use (27) in Alan's paper
        tr_a = (np.divide(8, np.sqrt(3))) * (z_xp * z_xn + z_yp * z_yn)
        tr_b = (
            25
            * (np.square(z_xp) - np.square(z_yp))
            * (np.square(z_xn) - np.square(z_yn))
        )
        tr_c = 100 * (z_xp * z_yp * z_xn * z_yn)
        tr = tr_a + tr_b + tr_c

        return tr

    WpBoson = TLorentzVector(*particles[:4]) # (px, py, pz, energy)
    WpLepton = TLorentzVector(*particles[4:8])
    WnBoson = TLorentzVector(*particles[8:12])
    WnLepton = TLorentzVector(*particles[12:16])
    lab_lp = np.array([WpLepton.X(), WpLepton.Y(), WpLepton.Z(), WpLepton.T()])
    lab_ln = np.array([WnLepton.X(), WnLepton.Y(), WnLepton.Z(), WnLepton.T()])
    
    # construct Higgs 4-vector
    Higgs = WpBoson + WnBoson

    # construct a moving orthogonal basis (k,r,n)
    Beam_p = TLorentzVector(0, 0, 1, 1)  # spatial-axis

    # define boost vector
    Higgsb = Higgs.BoostVector()

    # (1) performs a boost transformation from the rod frame to the rawal one.
    # Perform boost transformation from the rod frame to the rawal one
    for vec in [WpBoson, WpLepton, WnBoson, WnLepton, Beam_p]:
        vec.Boost(-Higgsb)
    
    # momentum in Higgs rest frame - extract components properly
    higgs_rest_WpLepton = np.array([WpLepton.X(), WpLepton.Y(), WpLepton.Z(), WpLepton.T()])
    higgs_rest_WnLepton = np.array([WnLepton.X(), WnLepton.Y(), WnLepton.Z(), WnLepton.T()])

    # 2. Define (k,r,n) -> definitions are in Alan's paper
    k_per = TVector3(WpBoson.X(), WpBoson.Y(), WpBoson.Z())
    p_per = TVector3(Beam_p.X(), Beam_p.Y(), Beam_p.Z())  # in the Higgs rest frame
    k = k_per.Unit()  # normalized -> unit vector
    p = p_per.Unit()
    y = p.Dot(k)
    r_length = np.sqrt(1 - y * y)
    r = (1 / r_length) * (p - y * k)
    n = (1 / r_length) * (p.Cross(k))  # (1/sin)*sin = 1 -> unit vector

    # 3. Further boost to W+ and W- frame respectively
    WpkBoost = WpBoson.BoostVector()
    WpBoson.Boost(-WpkBoost)
    WpLepton.Boost(-WpkBoost)
    WnkBoost = WnBoson.BoostVector()
    WnBoson.Boost(-WnkBoost)
    WnLepton.Boost(-WnkBoost)

    # 4. Map all particle to (k,r,n) frame
    WpLp = WpLepton.Vect()  # momentum in (k,r,n)
    WnLp = WnLepton.Vect()
    # Mapping to n-r-k basis
    WpLp_k = TLorentzVector(WpLp.Dot(n), WpLp.Dot(r), WpLp.Dot(k), WpLepton.E())
    WnLp_k = TLorentzVector(WnLp.Dot(n), WnLp.Dot(r), WnLp.Dot(k), WnLepton.E())

    # 5. Calculate directional cosines
    # directional cosine from Wp
    WpLp_Vect_Mag = WpLp_k.Vect().Mag()
    cos_n_join_p = np.divide(WpLp_k.X(), WpLp_Vect_Mag)
    cos_r_join_p = np.divide(WpLp_k.Y(), WpLp_Vect_Mag)
    cos_k_join_p = np.divide(WpLp_k.Z(), WpLp_Vect_Mag)
    # directional cosine from Wn
    WnLp_Vect_Mag = WnLp_k.Vect().Mag()
    cos_n_join_n = np.divide(WnLp_k.X(), WnLp_Vect_Mag)
    cos_r_join_n = np.divide(WnLp_k.Y(), WnLp_Vect_Mag)
    cos_k_join_n = np.divide(WnLp_k.Z(), WnLp_Vect_Mag)

    # 6. Calculate Bij (CGLMP values)
    B_xy = cglmp(cos_n_join_p, cos_n_join_n, cos_r_join_p, cos_r_join_n)
    B_yz = cglmp(cos_r_join_p, cos_r_join_n, cos_k_join_p, cos_k_join_n)
    B_zx = cglmp(cos_n_join_p, cos_n_join_n, cos_k_join_p, cos_k_join_n)

    # Also fix the W rest frame arrays to extract components properly
    w_rest_WpLepton = np.array([WpLepton.X(), WpLepton.Y(), WpLepton.Z(), WpLepton.T()])
    w_rest_WnLepton = np.array([WnLepton.X(), WnLepton.Y(), WnLepton.Z(), WnLepton.T()])

    return (
        np.array([B_xy, B_yz, B_zx]),
        np.array([cos_n_join_p, cos_r_join_p, cos_k_join_p]),
        np.array([cos_n_join_n, cos_r_join_n, cos_k_join_n]),
        lab_lp,
        lab_ln,
        higgs_rest_WpLepton,
        higgs_rest_WnLepton,
        w_rest_WpLepton,
        w_rest_WnLepton,
    )


def result_generator(particles):
    with multiprocessing.Pool(WORKERS) as pool:
        # Retrieve the output from the pool
        results = list(pool.map(Bij, particles))

    # Unpack the results
    bij, xi_p, xi_n, lab_lp, lab_ln, h_rest_lp, h_rest_ln, w_rest_lp, w_rest_ln = zip(*results)

    bij = np.vstack(bij)  # Flatten the nested array
    xi_p = np.vstack(xi_p)
    xi_n = np.vstack(xi_n)
    lab_lp = np.vstack(lab_lp)
    lab_ln = np.vstack(lab_ln)
    h_rest_lp = np.vstack(h_rest_lp)
    h_rest_ln = np.vstack(h_rest_ln)
    w_rest_lp = np.vstack(w_rest_lp)
    w_rest_ln = np.vstack(w_rest_ln)
    mask = np.any(np.isnan(bij), axis=1)
    print("Number of NaN values in bij:", np.sum(mask))
    return (
        bij,
        xi_p,
        xi_n,
        mask,
        lab_lp,
        lab_ln,
        h_rest_lp,
        h_rest_ln,
        w_rest_lp,
        w_rest_ln,
    )

# %%
# mc20 truth

mc20_true_obs_kin = np.column_stack(
    (
        truth_lead_lep["px"],
        truth_lead_lep["py"],
        truth_lead_lep["pz"],
        truth_lead_lep["energy"],
        truth_sublead_lep["px"],
        truth_sublead_lep["py"],
        truth_sublead_lep["pz"],
        truth_sublead_lep["energy"],
        truth_lead_nu["px"] + truth_sublead_nu["px"],
        truth_lead_nu["py"] + truth_sublead_nu["py"],
    )
)
# trim the data
print("mc20 (true) obs_kin shape:", mc20_true_obs_kin.shape)
mc20_true_obs_kin = mc20_true_obs_kin[PRE_CUT_INST]
print("After selection ...\nmc20 (true) obs_kin shape:", mc20_true_obs_kin.shape)
# Out:
# mc20 (true) obs_kin shape: (2963488, 10)
# After selection ...
# mc20 (true) obs_kin shape: (700374, 10)

# %%
# mc20 truth (car)

mc20_car_obs_kin = np.column_stack(
    (
        truth_lead_lep_car["px"],
        truth_lead_lep_car["py"],
        truth_lead_lep_car["pz"],
        truth_lead_lep_car["energy"],
        truth_sublead_lep_car["px"],
        truth_sublead_lep_car["py"],
        truth_sublead_lep_car["pz"],
        truth_sublead_lep_car["energy"],
        truth_lead_nu_car["px"] + truth_sublead_nu_car["px"],
        truth_lead_nu_car["py"] + truth_sublead_nu_car["py"],
    )
)

print("mc20 (car) obs_kin shape:", mc20_car_obs_kin.shape)
mc20_car_obs_kin = mc20_car_obs_kin[PRE_CUT_INST]
print("After selection ...\nmc20 (car) obs_kin shape:", mc20_car_obs_kin.shape)
# Out:
# mc20 (car) obs_kin shape: (2963488, 10)
# After selection ...
# mc20 (car) obs_kin shape: (700374, 10)

# %%
# predictions from the model trained with mc16 data

mc20_true_pred_y = model.predict(mc20_true_obs_kin)  # ~truth
mc20_car_pred_y = model.predict(mc20_car_obs_kin)  # ~truth_car
# Out:
# 21887/21887 ━━━━━━━━━━━━━━━━━━━━ 20s 893us/step
# 21887/21887 ━━━━━━━━━━━━━━━━━━━━ 20s 912us/step
# I0000 00:00:1751682060.916525 2793232 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 8 bytes spill stores, 8 bytes spill loads

# %%
"""
CGLMP and xi:

ground truth for CAR
"""

mc20_truth_lead_lep_p4 = mc20_data["truth_lead_lep"]["p4"]
mc20_truth_sublead_lep_p4 = mc20_data["truth_sublead_lep"]["p4"]
mc20_truth_lead_w = mc20_data["lead_w"]["p4"]
mc20_truth_sublead_w = mc20_data["sublead_w"]["p4"]

mc20_particles = np.concatenate(
    [
        mc20_truth_lead_w[PRE_CUT_INST],
        mc20_truth_lead_lep_p4[PRE_CUT_INST],
        mc20_truth_sublead_w[PRE_CUT_INST],
        mc20_truth_sublead_lep_p4[PRE_CUT_INST],
    ],
    axis=1,
)
(
    truth_bij, 
    truth_xi_p, 
    truth_xi_n, 
    truth_mask,
    truth_lab_lp, 
    truth_lab_ln,
    truth_h_rest_lp, 
    truth_h_rest_ln, 
    truth_w_rest_lp, 
    truth_w_rest_ln
) = result_generator(mc20_particles)
# Out:
# Number of NaN values in bij: 0

# %%
"""
CGLMP and xi:

ground truth for CAR
"""

mc20_truth_lead_lep_car_p4 = mc20_data["truth_lead_lep_car"]["p4"]
mc20_truth_sublead_lep_car_p4 = mc20_data["truth_sublead_lep_car"]["p4"]

mc20_particles = np.concatenate(
    [
        mc20_truth_lead_w[PRE_CUT_INST],
        mc20_truth_lead_lep_car_p4[PRE_CUT_INST],
        mc20_truth_sublead_w[PRE_CUT_INST],
        mc20_truth_sublead_lep_car_p4[PRE_CUT_INST],
    ],
    axis=1,
)
(
    truth_bij_car, 
    truth_xi_p_car, 
    truth_xi_n_car, 
    truth_mask_car,
    truth_lab_lp_car, 
    truth_lab_ln_car,
    truth_h_rest_lp_car, 
    truth_h_rest_ln_car, 
    truth_w_rest_lp_car, 
    truth_w_rest_ln_car
) = result_generator(mc20_particles)
# Out:
# Number of NaN values in bij: 0

# %%
"""
CGLMP and xi:

[Use for comapring the CAR results]
pred(SM) with truth lep
"""

mc20_particles = np.concatenate(
    [
        mc20_true_pred_y[:, 0:4],
        mc20_truth_lead_lep_p4[PRE_CUT_INST],
        mc20_true_pred_y[:, 4:8],
        mc20_truth_sublead_lep_p4[PRE_CUT_INST],
    ],
    axis=1,
)
(
    bij, 
    xi_p, 
    xi_n, 
    mask,
    lab_lp, 
    lab_ln, 
    h_rest_lp, 
    h_rest_ln, 
    w_rest_lp, 
    w_rest_ln,
    
) = result_generator(mc20_particles)
# Out:
# Number of NaN values in bij: 0

# %%
"""
CGLMP and xi:

[Use for comapring the CAR results]
pred(SM) with truth lep
"""

mc20_particles = np.concatenate(
    [
        mc20_true_pred_y[:, 0:4],
        mc20_truth_lead_lep_p4[PRE_CUT_INST],
        mc20_true_pred_y[:, 4:8],
        mc20_truth_sublead_lep_p4[PRE_CUT_INST],
    ],
    axis=1,
)
(
    bij, 
    xi_p, 
    xi_n, 
    mask,
    lab_lp, 
    lab_ln, 
    h_rest_lp, 
    h_rest_ln, 
    w_rest_lp, 
    w_rest_ln,
    
) = result_generator(mc20_particles)
# Out:
# Number of NaN values in bij: 0

# %%
"""
CGLMP and xi:

pred(CAR) with car lep
"""

mc20_truth_lead_lep_car_p4 = mc20_data["truth_lead_lep_car"]["p4"]
mc20_truth_sublead_lep_car_p4 = mc20_data["truth_sublead_lep_car"]["p4"]

mc20_particles = np.concatenate(
    [
        mc20_car_pred_y[:, 0:4],
        mc20_truth_lead_lep_car_p4[PRE_CUT_INST],
        mc20_car_pred_y[:, 4:8],
        mc20_truth_sublead_lep_car_p4[PRE_CUT_INST],
    ],
    axis=1,
)
(
    bij_car, 
    xi_p_car, 
    xi_n_car, 
    mask_car, 
    lab_lp_car, 
    lab_ln_car, 
    h_rest_lp_car, 
    h_rest_ln_car, 
    w_rest_lp_car, 
    w_rest_ln_car
) = result_generator(mc20_particles)
# Out:
# Number of NaN values in bij: 0

# %%
# trim out nan values 

mask = ~truth_mask & ~truth_mask_car & ~mask & ~mask_car

# %%
# variables for plotting
bij = bij[mask]
bij_car = bij_car[mask]
xi_p = xi_p[mask]
xi_p_car = xi_p_car[mask]
xi_n = xi_n[mask]
xi_n_car = xi_n_car[mask]
lab_lp = lab_lp[mask]
lab_ln = lab_ln[mask]
lab_lp_car = lab_lp_car[mask]
lab_ln_car = lab_ln_car[mask]
h_rest_lp = h_rest_lp[mask]
h_rest_ln = h_rest_ln[mask]
h_rest_lp_car = h_rest_lp_car[mask]
h_rest_ln_car = h_rest_ln_car[mask]
w_rest_lp = w_rest_lp[mask]
w_rest_ln = w_rest_ln[mask]
w_rest_lp_car = w_rest_lp_car[mask]
w_rest_ln_car = w_rest_ln_car[mask]


truth_bij = truth_bij[mask]
truth_bij_car = truth_bij_car[mask]
truth_xi_p = truth_xi_p[mask]
truth_xi_p_car = truth_xi_p_car[mask]
truth_xi_n = truth_xi_n[mask]
truth_xi_n_car = truth_xi_n_car[mask]
truth_lab_lp = truth_lab_lp[mask]
truth_lab_ln = truth_lab_ln[mask]
truth_lab_lp_car = truth_lab_lp_car[mask]
truth_lab_ln_car = truth_lab_ln_car[mask]
truth_h_rest_lp = truth_h_rest_lp[mask]
truth_h_rest_ln = truth_h_rest_ln[mask]
truth_h_rest_lp_car = truth_h_rest_lp_car[mask]
truth_h_rest_ln_car = truth_h_rest_ln_car[mask]
truth_w_rest_lp = truth_w_rest_lp[mask]
truth_w_rest_ln = truth_w_rest_ln[mask]
truth_w_rest_lp_car = truth_w_rest_lp_car[mask]
truth_w_rest_ln_car = truth_w_rest_ln_car[mask]

# %%
"""
Xi comparison:

Pred CAR vs pred SM 
"""

print("CAR (pred ~ truth_car) vs SM (pred ~ truth)")

# xi
xi_plot_true = [
    xi_p[:, 0],
    xi_p[:, 1],
    xi_p[:, 2],
    xi_n[:, 0],
    xi_n[:, 1],
    xi_n[:, 2],
]
xi_plot_pred = [
    xi_p_car[:, 0],
    xi_p_car[:, 1],
    xi_p_car[:, 2],
    xi_n_car[:, 0],
    xi_n_car[:, 1],
    xi_n_car[:, 2],
]
xi_plot_ranges = [[-1, 1]] * 6
xi_plot_labels = [
    r"$\xi^{(0)}_{n}$",
    r"$\xi^{(0)}_{r}$",
    r"$\xi^{(0)}_{k}$",
    r"$\xi^{(1)}_{n}$",
    r"$\xi^{(1)}_{r}$",
    r"$\xi^{(1)}_{k}$",
]
plot.hist_1d_grid(
    xi_plot_true,
    xi_plot_pred,
    title=xi_plot_labels,
    legend_lst=["Pred(Sep)", "Pred(SM)"],
    ranges=xi_plot_ranges,
    xlabel="",
)
plot.hist_2d_grid(
    xi_plot_true,
    xi_plot_pred,
    title=xi_plot_labels,
    ranges=xi_plot_ranges,
    xlabel="Pred(Sep)",
    ylabel="Pred(SM)",
)

# bij
bij_plot_true = [
    bij[:, 0],
    bij[:, 1],
    bij[:, 2],
]
bij_plot_pred = [
    bij_car[:, 0],
    bij_car[:, 1],
    bij_car[:, 2],
]
bij_plot_ranges = [[-30, 30]] * 3
bij_plot_labels = [
    r"$B_{xy}$",
    r"$B_{yz}$",
    r"$B_{zx}$",
]

plot.hist_1d3plot(
    bij_plot_true,
    bij_plot_pred,
    ranges=bij_plot_ranges,
    xlabel=bij_plot_labels,
    title=bij_plot_labels,
    row1_ylabel="Counts",
    row1_legend=["Pred(Sep)", "Pred(SM)"],
    xpad=1,
)

emd = [
    sp.stats.wasserstein_distance(bij[:, i], bij_car[:, i]) for i in range(3)
]

kl_lst = []
for i in range(3):
    # Create histograms
    p, bin_edges = np.histogram(bij[..., i], bins=101, density=True)
    q, _ = np.histogram(bij_car[..., i], bins=bin_edges, density=True)

    # Normalize histograms
    kl = np.sum(sp.special.kl_div(p, q+1e-10))
    kl_lst.append(kl)
    
mean_true = [np.mean(bij[:, i]) for i in range(3)]
mean_car = [np.mean(bij_car[:, i]) for i in range(3)]

print(
    rf"""
Bxy -> EMD:{emd[0]:.3f}, kl: {10*kl_lst[0]:.3f} with SM mean:{mean_true[0]:.3f}, Sep mean {mean_car[0]:.3f}
Byz -> EMD:{emd[1]:.3f}, kl: {10*kl_lst[1]:.3f} with SM mean:{mean_true[1]:.3f}, Sep mean {mean_car[1]:.3f}
Bzx -> EMD:{emd[2]:.3f}, kl: {10*kl_lst[2]:.3f} with SM mean:{mean_true[2]:.3f}, Sep mean {mean_car[2]:.3f}
"""
)
# Out:
# CAR (pred ~ truth_car) vs SM (pred ~ truth)
# Bxy -> EMD:2.003, kl: 0.326 with SM mean:5.013, Sep mean 3.010
# Byz -> EMD:0.343, kl: 0.201 with SM mean:0.858, Sep mean 0.537
# Bzx -> EMD:2.116, kl: 0.741 with SM mean:2.663, Sep mean 0.548

# %%
bins_edges = np.linspace(0, 1000, 51)
plt.hist(truth_lab_lp_car[:,3], bins=bins_edges, label=r"True $E^{\ell_0}$ (LAB_CAR)", histtype="step", linewidth=2, color="blue")
plt.hist(truth_lab_lp[:,3], bins=bins_edges, label=r"True $E^{\ell_0}$ (LAB_SM)", histtype="step", linewidth=2, color="red")
plt.hist(lab_lp_car[:,3], bins=bins_edges, label=r"Pred $E^{\ell_0}$ (LAB_CAR)", histtype="bar", linewidth=2, color="tab:blue", alpha=0.5)
plt.hist(lab_lp[:,3], bins=bins_edges, label=r"Pred $E^{\ell_0}$ (LAB_SM)", histtype="bar", linewidth=2, color="tab:red", alpha=0.5)
plt.semilogy()
plt.legend()
plt.show()

bins_edges = np.linspace(0, 160, 51)
plt.hist(truth_h_rest_lp_car[:,3], bins=bins_edges, label=r"True $E^{\ell_0}$ (H_CAR)", histtype="step", linewidth=2, color="blue")
plt.hist(truth_h_rest_lp[:,3], bins=bins_edges, label=r"True $E^{\ell_0}$ (H_SM)", histtype="step", linewidth=2, color="red")
plt.hist(h_rest_lp_car[:,3], bins=bins_edges, label=r"Pred $E^{\ell_0}$ (H_CAR)", histtype="bar", linewidth=2, color="tab:blue", alpha=0.5)
plt.hist(h_rest_lp[:,3], bins=bins_edges, label=r"Pred $E^{\ell_0}$ (H_SM)", histtype="bar", linewidth=2, color="tab:red", alpha=0.5)
plt.semilogy()
plt.legend()
plt.show()

bins_edges = np.linspace(0, 160, 51)
plt.hist(truth_w_rest_lp_car[:,3], bins=bins_edges, label=r"True $E^{\ell_0}$ (W_CAR)", histtype="step", linewidth=2, color="blue")
plt.hist(truth_w_rest_lp[:,3], bins=bins_edges, label=r"True $E^{\ell_0}$ (W_SM)", histtype="step", linewidth=2, color="red")
plt.hist(w_rest_lp_car[:,3], bins=bins_edges, label=r"Pred $E^{\ell_0}$ (W_CAR)", histtype="bar", linewidth=2, color="tab:blue", alpha=0.5)
plt.hist(w_rest_lp[:,3], bins=bins_edges, label=r"Pred $E^{\ell_0}$ (W_SM)", histtype="bar", linewidth=2, color="tab:red", alpha=0.5)
plt.semilogy()
plt.legend()
plt.show()

bins_edges = np.linspace(0, 1000, 51)
plt.hist(truth_lab_ln_car[:,3], bins=bins_edges, label=r"True $E^{\ell_1}$ (LAB_CAR)", histtype="step", linewidth=2, color="blue")
plt.hist(truth_lab_ln[:,3], bins=bins_edges, label=r"True $E^{\ell_1}$ (LAB_SM)", histtype="step", linewidth=2, color="red")
plt.hist(lab_ln_car[:,3], bins=bins_edges, label=r"Pred $E^{\ell_1}$ (LAB_CAR)", histtype="bar", linewidth=2, color="tab:blue", alpha=0.5)
plt.hist(lab_ln[:,3], bins=bins_edges, label=r"Pred $E^{\ell_1}$ (LAB_SM)", histtype="bar", linewidth=2, color="tab:red", alpha=0.5)
plt.semilogy()
plt.legend()
plt.show()

bins_edges = np.linspace(0, 160, 51)
plt.hist(truth_h_rest_ln_car[:,3], bins=bins_edges, label=r"True $E^{\ell_1}$ (H_CAR)", histtype="step", linewidth=2, color="blue")
plt.hist(truth_h_rest_ln[:,3], bins=bins_edges, label=r"True $E^{\ell_1}$ (H_SM)", histtype="step", linewidth=2, color="red")
plt.hist(h_rest_ln_car[:,3], bins=bins_edges, label=r"Pred $E^{\ell_1}$ (H_CAR)", histtype="bar", linewidth=2, color="tab:blue", alpha=0.5)
plt.hist(h_rest_ln[:,3], bins=bins_edges, label=r"Pred $E^{\ell_1}$ (H_SM)", histtype="bar", linewidth=2, color="tab:red", alpha=0.5)
plt.semilogy()
plt.legend()
plt.show()

bins_edges = np.linspace(0, 160, 51)
plt.hist(truth_w_rest_ln_car[:,3], bins=bins_edges, label=r"True $E^{\ell_1}$ (W_CAR)", histtype="step", linewidth=2, color="blue")
plt.hist(truth_w_rest_ln[:,3], bins=bins_edges, label=r"True $E^{\ell_1}$ (W_SM)", histtype="step", linewidth=2, color="red")
plt.hist(w_rest_ln_car[:,3], bins=bins_edges, label=r"Pred $E^{\ell_1}$ (W_CAR)", histtype="bar", linewidth=2, color="tab:blue", alpha=0.5)
plt.hist(w_rest_ln[:,3], bins=bins_edges, label=r"Pred $E^{\ell_1}$ (W_SM)", histtype="bar", linewidth=2, color="tab:red", alpha=0.5)
plt.semilogy()
plt.legend()
plt.show()
