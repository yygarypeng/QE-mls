# %%
import time
t_start = time.time()

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"  # suppress tensorflow information messages

import sys
import numpy as np
from scipy import stats
import scipy as sp
import multiprocessing
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm, Normalize
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbModelCheckpoint

HOME_PATH = os.path.abspath("/root/work/QE-mls") # path to QE_mls
sys.path.append(HOME_PATH + "/qe")
print("Home path:", HOME_PATH)

# custom modules
import paper_plot as pp
# Import the W boson regressor module
import nn
nn.BATCH_SIZE = 1024
# Out:
# Home path: /root/work/QE-mls
# Testing NN...

# %%
# ROOT need to be imported after tensorflow
import ROOT
from ROOT import TLorentzVector, TVector3

# some global variables
dir_name = HOME_PATH + "/14th_trial/reg_main/ww_resregressor_result/"
plot = pp.Plotter()
WORKERS = 20

# %%
import h5py


def load_particles_from_h5(filename="mc20_truth.h5"):
    """
    Load particle data from an HDF5 file

    Args:
        filename: Path to the HDF5 file

    Returns:
        Dictionary with the loaded data
    """
    result = {}

    with h5py.File(filename, "r") as f:
        # For each group in the file
        for group_name in f.keys():
            group_data = {}

            # Load datasets (numpy arrays)
            for dataset_name in f[group_name].keys():
                group_data[dataset_name] = f[group_name][dataset_name][:]

            # Load attributes (scalars)
            for attr_name, attr_value in f[group_name].attrs.items():
                group_data[attr_name] = attr_value

            result[group_name] = group_data

    return result

# %%
mc20_data = load_particles_from_h5("/root/data/mc20_truth.h5")
# mc20_data.keys()
mc20_data_LL = load_particles_from_h5("/root/data/mc20_truth_LL.h5")

# %%
# SM truth
truth_lead_lep = mc20_data["truth_lead_lep"]
truth_sublead_lep = mc20_data["truth_sublead_lep"]
truth_lead_nu = mc20_data["truth_lead_nu"]
truth_sublead_nu = mc20_data["truth_sublead_nu"]
truth_lead_lep_p4 = mc20_data["truth_lead_lep"]["p4"]
truth_sublead_lep_p4 = mc20_data["truth_sublead_lep"]["p4"]
truth_lead_nu_p4 = mc20_data["truth_lead_nu"]["p4"]
truth_sublead_nu_p4 = mc20_data["truth_sublead_nu"]["p4"]
truth_met_pt = np.sqrt(np.square((truth_lead_nu_p4 + truth_sublead_nu_p4)[...,0:2]).sum(axis=-1))

# LL truth
truth_lead_lep_ll = mc20_data_LL["truth_lead_lep"]
truth_sublead_lep_ll = mc20_data_LL["truth_sublead_lep"]
truth_lead_nu_ll = mc20_data_LL["truth_lead_nu"]
truth_sublead_nu_ll = mc20_data_LL["truth_sublead_nu"]
truth_lead_lep_ll_p4 = mc20_data_LL["truth_lead_lep"]["p4"]
truth_sublead_lep_ll_p4 = mc20_data_LL["truth_sublead_lep"]["p4"]
truth_lead_nu_ll_p4 = mc20_data_LL["truth_lead_nu"]["p4"]
truth_sublead_nu_ll_p4 = mc20_data_LL["truth_sublead_nu"]["p4"]
truth_met_pt_ll = np.sqrt(np.square((truth_lead_nu_ll_p4 + truth_sublead_nu_ll_p4)[...,0:2]).sum(axis=-1))

# W bosons (SM and LL use the same W bosons data)
w_lead_p4 = mc20_data["lead_w"]["p4"]
w_sublead_p4 = mc20_data["sublead_w"]["p4"]
w_lead_p4_ll = mc20_data_LL["lead_w"]["p4"]
w_sublead_p4_ll = mc20_data_LL["sublead_w"]["p4"]

# %%
print("Truth: pre-cut")
cut_pre_pt_lead = truth_lead_lep["pt"] > 22
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = truth_sublead_lep["pt"] > 15
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.square(truth_lead_lep["energy"] + truth_sublead_lep["energy"])
    - np.square(truth_lead_lep["px"] + truth_sublead_lep["px"])
    - np.square(truth_lead_lep["py"] + truth_sublead_lep["py"])
    - np.square(truth_lead_lep["pz"] + truth_sublead_lep["pz"])
    > 10**2
)
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = truth_met_pt > 20
print(len(truth_lead_lep["energy"]) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print("Total", len(truth_lead_lep["energy"]) - np.sum(PRE_CUT * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# LL
print("")
print("LL: pre-cut")
cut_pre_pt_lead = truth_lead_lep_ll["pt"] > 22
print(len(truth_lead_lep_ll["energy"]) - np.sum(cut_pre_pt_lead * 1))
cut_pre_pt_sub = truth_sublead_lep_ll["pt"] > 15
print(len(truth_lead_lep_ll["energy"]) - np.sum(cut_pre_pt_sub * 1))
cut_pre_dilep_m = (
    np.square(truth_lead_lep_ll["energy"] + truth_sublead_lep_ll["energy"])
    - np.square(truth_lead_lep_ll["px"] + truth_sublead_lep_ll["px"])
    - np.square(truth_lead_lep_ll["py"] + truth_sublead_lep_ll["py"])
    - np.square(truth_lead_lep_ll["pz"] + truth_sublead_lep_ll["pz"])
    > 10**2
)
print(len(truth_lead_lep_ll["energy"]) - np.sum(cut_pre_dilep_m * 1))
cut_pre_pt_miss = truth_met_pt_ll > 20
print(len(truth_lead_lep_ll["energy"]) - np.sum(cut_pre_pt_miss * 1))
PRE_CUT_LL = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss
print("Total", len(truth_lead_lep_ll["energy"]) - np.sum(PRE_CUT_LL * 1))
del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)
# Out:
# Truth: pre-cut
# 260653
# 1174171
# 148392
# 287355
# Total 1502903
#
# LL: pre-cut
# 183962
# 681205
# 28618
# 242126
# Total 847915

# %%
# training objects
lead_lep_px = truth_lead_lep_ll["px"][PRE_CUT_LL]
lead_lep_py = truth_lead_lep_ll["py"][PRE_CUT_LL]
lead_lep_pz = truth_lead_lep_ll["pz"][PRE_CUT_LL]
lead_lep_energy = truth_lead_lep_ll["energy"][PRE_CUT_LL]
sublead_lep_px = truth_sublead_lep_ll["px"][PRE_CUT_LL]
sublead_lep_py = truth_sublead_lep_ll["py"][PRE_CUT_LL]
sublead_lep_pz = truth_sublead_lep_ll["pz"][PRE_CUT_LL]
sublead_lep_energy = truth_sublead_lep_ll["energy"][PRE_CUT_LL]
lead_nu_px = truth_lead_nu_ll["px"][PRE_CUT_LL]
lead_nu_py = truth_lead_nu_ll["py"][PRE_CUT_LL]
sublead_nu_px = truth_sublead_nu_ll["px"][PRE_CUT_LL]
sublead_nu_py = truth_sublead_nu_ll["py"][PRE_CUT_LL]
met_px = lead_nu_px + sublead_nu_px
met_py = lead_nu_py + sublead_nu_py

# training objects (SM)
lead_lep_px_sm = truth_lead_lep["px"][PRE_CUT]
lead_lep_py_sm = truth_lead_lep["py"][PRE_CUT]
lead_lep_pz_sm = truth_lead_lep["pz"][PRE_CUT]
lead_lep_energy_sm = truth_lead_lep["energy"][PRE_CUT]
sublead_lep_px_sm = truth_sublead_lep["px"][PRE_CUT]
sublead_lep_py_sm = truth_sublead_lep["py"][PRE_CUT]
sublead_lep_pz_sm = truth_sublead_lep["pz"][PRE_CUT]
sublead_lep_energy_sm = truth_sublead_lep["energy"][PRE_CUT]
lead_nu_px_sm = truth_lead_nu["px"][PRE_CUT]
lead_nu_py_sm = truth_lead_nu["py"][PRE_CUT]
sublead_nu_px_sm = truth_sublead_nu["px"][PRE_CUT]
sublead_nu_py_sm = truth_sublead_nu["py"][PRE_CUT]
met_px_sm = lead_nu_px + sublead_nu_px
met_py_sm = lead_nu_py + sublead_nu_py


train = np.column_stack(
    (
        lead_lep_px,
        lead_lep_py,
        lead_lep_pz,
        lead_lep_energy,
        sublead_lep_px,
        sublead_lep_py,
        sublead_lep_pz,
        sublead_lep_energy,
        met_px,
        met_py,
    )
)

train_sm = np.column_stack(
    (
        np.random.choice(lead_lep_px_sm, size=(len(train))),
        np.random.choice(lead_lep_py_sm, size=(len(train))),
        np.random.choice(lead_lep_pz_sm, size=(len(train))),
        np.random.choice(lead_lep_energy_sm, size=(len(train))),
        np.random.choice(sublead_lep_px_sm, size=(len(train))),
        np.random.choice(sublead_lep_py_sm, size=(len(train))),
        np.random.choice(sublead_lep_pz_sm, size=(len(train))),
        np.random.choice(sublead_lep_energy_sm, size=(len(train))),
        np.random.choice(met_px_sm, size=(len(train))),
        np.random.choice(met_py_sm, size=(len(train))),
    )
)

# train = train[shuffle_ind]
print("Training objects shape:", train.shape)
print("Training objects SM shape:", train_sm.shape)
# Out:
# Training objects shape: (649710, 10)
# Training objects SM shape: (649710, 10)

# %%
# Ensure ROOT is properly initialized
ROOT.gROOT.SetBatch(True)

def w_rest_booster(particles):

    WpBoson = TLorentzVector(*particles[:4]) # (px, py, pz, energy)
    WpLepton = TLorentzVector(*particles[4:8])
    WnBoson = TLorentzVector(*particles[8:12])
    WnLepton = TLorentzVector(*particles[12:16])
    
    # construct Higgs 4-vector
    Higgs = WpBoson + WnBoson

    # construct a moving orthogonal basis (k,r,n)
    Beam_p = TLorentzVector(0, 0, 1, 1)  # spatial-axis

    # define boost vector
    Higgsb = Higgs.BoostVector()

    # (1) performs a boost transformation from the rod frame to the rawal one.
    # Perform boost transformation from the rod frame to the rawal one
    for vec in [WpBoson, WpLepton, WnBoson, WnLepton, Beam_p]:
        vec.Boost(-Higgsb)

    # 2. Define (k,r,n) -> definitions are in Alan's paper
    k_per = TVector3(WpBoson.X(), WpBoson.Y(), WpBoson.Z())
    p_per = TVector3(Beam_p.X(), Beam_p.Y(), Beam_p.Z())  # in the Higgs rest frame
    k = k_per.Unit()  # normalized -> unit vector
    p = p_per.Unit()
    y = p.Dot(k)
    r_length = np.sqrt(1 - y * y)
    r = (1 / r_length) * (p - y * k)
    n = (1 / r_length) * (p.Cross(k))  # (1/sin)*sin = 1 -> unit vector

    # 3. Further boost to W+ and W- frame respectively
    WpkBoost = WpBoson.BoostVector()
    WpBoson.Boost(-WpkBoost)
    WpLepton.Boost(-WpkBoost)
    WnkBoost = WnBoson.BoostVector()
    WnBoson.Boost(-WnkBoost)
    WnLepton.Boost(-WnkBoost)

    # 4. Map all particle to (k,r,n) frame
    WpLp = WpLepton.Vect()  # momentum in (k,r,n)
    WnLp = WnLepton.Vect()
    # Mapping to n-r-k basis
    WpLp_k = TLorentzVector(WpLp.Dot(n), WpLp.Dot(r), WpLp.Dot(k), WpLepton.E())
    WnLp_k = TLorentzVector(WnLp.Dot(n), WnLp.Dot(r), WnLp.Dot(k), WnLepton.E())

    # Also fix the W rest frame arrays to extract components properly
    w_rest_WpLepton = np.array([WpLp_k.X(), WpLp_k.Y(), WpLp_k.Z(), WpLp_k.T()])
    w_rest_WnLepton = np.array([WnLp_k.X(), WnLp_k.Y(), WnLp_k.Z(), WnLp_k.T()])

    return (
        w_rest_WpLepton,
        w_rest_WnLepton,
    )


def result_generator(particles):
    with multiprocessing.Pool(WORKERS) as pool:
        # Retrieve the output from the pool
        results = list(pool.map(w_rest_booster, particles))

    # Unpack the results
    w_rest_lp, w_rest_ln = zip(*results)
    w_rest_lp = np.vstack(w_rest_lp)
    w_rest_ln = np.vstack(w_rest_ln)
    return (w_rest_lp, w_rest_ln,)

# %%
particles = np.concatenate(
    [
        w_lead_p4_ll[PRE_CUT_LL],
        truth_lead_lep_ll_p4[PRE_CUT_LL],
        w_sublead_p4_ll[PRE_CUT_LL],
        truth_sublead_lep_ll_p4[PRE_CUT_LL],
    ],
    axis=1,
)

w_rest_lep_lead_p4, w_rest_lep_sublead_p4 = result_generator(particles)


particles = np.concatenate(
    [
        w_lead_p4[PRE_CUT],
        truth_lead_lep_p4[PRE_CUT],
        w_sublead_p4[PRE_CUT],
        truth_sublead_lep_p4[PRE_CUT],
    ],
    axis=1,
)

w_rest_lep_lead_p4_sm, w_rest_lep_sublead_p4_sm = result_generator(particles)

# %%
def theta(p4):
    p3_mag = np.sqrt(np.sum(np.square(p4[:, 0:3]), axis=1))  # Calculate the magnitude of the spatial components
    pz = p4[:, 2]  # Extract the pz component
    return np.arccos(np.divide(pz, p3_mag)) / np.pi  # Normalize to [0, 1]

def phi(p4):
    phi = np.arctan2(p4[:, 1], p4[:, 0])  # Calculate the azimuthal angle
    return phi / np.pi  # normalize to [-1, 1]

lead_theta = theta(w_rest_lep_lead_p4)
lead_phi = phi(w_rest_lep_lead_p4)
sublead_theta = theta(w_rest_lep_sublead_p4)
sublead_phi = phi(w_rest_lep_sublead_p4)

target = np.concatenate(
	[
		np.column_stack([lead_theta, lead_phi]),
		np.column_stack([sublead_theta, sublead_phi]),
	],
	axis=1,
)
print("Target objects shape:", target.shape)

lead_theta_sm = theta(w_rest_lep_lead_p4_sm)
lead_phi_sm = phi(w_rest_lep_lead_p4_sm)
sublead_theta_sm = theta(w_rest_lep_sublead_p4_sm)
sublead_phi_sm = phi(w_rest_lep_sublead_p4_sm)

target_sm = np.concatenate(
	[
		np.column_stack([lead_theta_sm, lead_phi_sm]),
		np.column_stack([sublead_theta_sm, sublead_phi_sm]),
	],
	axis=1,
)
print("Target objects shape:", target_sm.shape)
# Out:
# Target objects shape: (649710, 4)
# Target objects shape: (1460585, 4)

# %%
# Train-test split
if len(train) == len(target):
	indices = np.arange(len(train))
else:
	sys.exit("Error: train and targe shapes do not match!")

train_idx, temp_idx = train_test_split(
	indices, train_size=0.8, random_state=nn.SEED
)
valid_idx, test_idx = train_test_split(
	temp_idx, train_size=0.5, random_state=nn.SEED
)

train_x, valid_x, test_x = train[train_idx], train[valid_idx], train[test_idx]
train_y, valid_y, test_y = target[train_idx], target[valid_idx], target[test_idx]

print("Train training shape:", train_x.shape, "Valid training shape:", valid_x.shape, "Test training shape:", test_x.shape)
print("Train target shape:", train_y.shape, "Valid target shape:", valid_y.shape, "Test target shape:", test_y.shape)
# Out:
# Train training shape: (519768, 10) Valid training shape: (64971, 10) Test training shape: (64971, 10)
# Train target shape: (519768, 4) Valid target shape: (64971, 4) Test target shape: (64971, 4)

# %%
# W&B initialization
# wandb.init(
#     project='PcRes regressor w-rest training', 
#     name='MMD MMD batch_size: %d' % nn.BATCH_SIZE)
# config = wandb.config
# config.batch_size = nn.BATCH_SIZE

# Create datasets
train_dataset = (
	tf.data.Dataset.from_tensor_slices((train_x, train_y))
	.cache()
	.batch(nn.BATCH_SIZE)
	.prefetch(tf.data.AUTOTUNE)
)
valid_dataset = (
	tf.data.Dataset.from_tensor_slices((valid_x, valid_y))
	.cache()
	.batch(nn.BATCH_SIZE)
	.prefetch(tf.data.AUTOTUNE)
)

# Build and train model
base_model = nn.build_model(input_shape=train_x.shape[-1])
model = nn.CustomModel(base_model)
model.summary()
model.compile(
	optimizer=tf.keras.optimizers.Adam(learning_rate=nn.LEARNING_RATE),
	loss_weights=nn.LOSS_WEIGHTS,
)

callbacks = [
	tf.keras.callbacks.EarlyStopping(
		monitor="val_loss", patience=10, restore_best_weights=True
	),
	nn.EpochUpdater(),
	nn.LambdaTracker(),
	# WandbMetricsLogger(), 
]

history = model.fit(
	train_dataset,
	validation_data=valid_dataset,
	epochs=nn.EPOCHS,
	callbacks=callbacks,
	verbose=0,
)
# Out:
# Model: "custom_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional (Functional)         │ (None, 4)              │       424,972 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 424,972 (1.62 MB)
#  Trainable params: 418,620 (1.60 MB)
#  Non-trainable params: 6,352 (24.81 KB)
# Epoch 0; loss: 3.327E+00; mae_loss: 4.155E-01; neg_r2_loss: 2.165E-01; phi_mmd0_loss: 6.486E-01; phi_mmd1_loss: 7.487E-01; theta_mmd0_loss: 6.273E-01; theta_mmd1_loss: 4.715E-01; val_loss: 1.806E+00; val_mae_loss: 3.680E-01; val_neg_r2_loss: -1.133E-02; val_phi_mmd0_loss: 4.305E-01; val_phi_mmd1_loss: 4.492E-01; val_theta_mmd0_loss: 1.084E-01; val_theta_mmd1_loss: 8.176E-02
# Epoch 1; loss: 1.110E+00; mae_loss: 4.389E-01; neg_r2_loss: 5.090E-01; phi_mmd0_loss: 9.047E-02; phi_mmd1_loss: 5.140E-02; theta_mmd0_loss: 4.274E-02; theta_mmd1_loss: 4.797E-02; val_loss: 1.242E+00; val_mae_loss: 3.647E-01; val_neg_r2_loss: 1.289E-01; val_phi_mmd0_loss: 1.597E-01; val_phi_mmd1_loss: 9.779E-02; val_theta_mmd0_loss: 1.356E-01; val_theta_mmd1_loss: 1.198E-01
# Epoch 2; loss: 9.247E-01; mae_loss: 4.301E-01; neg_r2_loss: 5.123E-01; phi_mmd0_loss: 2.077E-02; phi_mmd1_loss: 1.254E-02; theta_mmd0_loss: 8.939E-03; theta_mmd1_loss: 2.238E-02; val_loss: 1.130E+00; val_mae_loss: 3.557E-01; val_neg_r2_loss: 8.414E-02; val_phi_mmd0_loss: 9.161E-02; val_phi_mmd1_loss: 6.964E-02; val_theta_mmd0_loss: 1.408E-01; val_theta_mmd1_loss: 1.166E-01
# Epoch 3; loss: 8.693E-01; mae_loss: 4.112E-01; neg_r2_loss: 3.998E-01; phi_mmd0_loss: 1.382E-02; phi_mmd1_loss: 1.086E-02; theta_mmd0_loss: 6.573E-03; theta_mmd1_loss: 1.566E-02; val_loss: 9.704E-01; val_mae_loss: 3.463E-01; val_neg_r2_loss: 3.498E-02; val_phi_mmd0_loss: 4.772E-02; val_phi_mmd1_loss: 4.384E-02; val_theta_mmd0_loss: 8.913E-02; val_theta_mmd1_loss: 9.704E-02
# Epoch 4; loss: 8.302E-01; mae_loss: 3.959E-01; neg_r2_loss: 3.083E-01; phi_mmd0_loss: 1.187E-02; phi_mmd1_loss: 9.337E-03; theta_mmd0_loss: 5.128E-03; theta_mmd1_loss: 1.199E-02; val_loss: 8.490E-01; val_mae_loss: 3.480E-01; val_neg_r2_loss: 4.925E-02; val_phi_mmd0_loss: 2.992E-02; val_phi_mmd1_loss: 2.585E-02; val_theta_mmd0_loss: 4.238E-02; val_theta_mmd1_loss: 5.488E-02
# Epoch 5; loss: 8.064E-01; mae_loss: 3.868E-01; neg_r2_loss: 2.554E-01; phi_mmd0_loss: 1.041E-02; phi_mmd1_loss: 8.929E-03; theta_mmd0_loss: 4.231E-03; theta_mmd1_loss: 9.179E-03; val_loss: 8.085E-01; val_mae_loss: 3.496E-01; val_neg_r2_loss: 5.724E-02; val_phi_mmd0_loss: 2.724E-02; val_phi_mmd1_loss: 2.278E-02; val_theta_mmd0_loss: 2.534E-02; val_theta_mmd1_loss: 3.394E-02
# Epoch 6; loss: 7.910E-01; mae_loss: 3.807E-01; neg_r2_loss: 2.200E-01; phi_mmd0_loss: 9.828E-03; phi_mmd1_loss: 8.584E-03; theta_mmd0_loss: 3.747E-03; theta_mmd1_loss: 7.544E-03; val_loss: 7.853E-01; val_mae_loss: 3.501E-01; val_neg_r2_loss: 5.836E-02; val_phi_mmd0_loss: 2.383E-02; val_phi_mmd1_loss: 2.174E-02; val_theta_mmd0_loss: 1.714E-02; val_theta_mmd1_loss: 2.235E-02
# Epoch 7; loss: 7.800E-01; mae_loss: 3.762E-01; neg_r2_loss: 1.947E-01; phi_mmd0_loss: 9.170E-03; phi_mmd1_loss: 8.235E-03; theta_mmd0_loss: 3.932E-03; theta_mmd1_loss: 6.181E-03; val_loss: 7.716E-01; val_mae_loss: 3.512E-01; val_neg_r2_loss: 6.261E-02; val_phi_mmd0_loss: 2.219E-02; val_phi_mmd1_loss: 2.025E-02; val_theta_mmd0_loss: 1.119E-02; val_theta_mmd1_loss: 1.555E-02
# Epoch 8; loss: 7.704E-01; mae_loss: 3.722E-01; neg_r2_loss: 1.731E-01; phi_mmd0_loss: 8.694E-03; phi_mmd1_loss: 7.932E-03; theta_mmd0_loss: 3.799E-03; theta_mmd1_loss: 5.599E-03; val_loss: 7.635E-01; val_mae_loss: 3.510E-01; val_neg_r2_loss: 5.892E-02; val_phi_mmd0_loss: 2.167E-02; val_phi_mmd1_loss: 1.984E-02; val_theta_mmd0_loss: 8.748E-03; val_theta_mmd1_loss: 1.128E-02
# Epoch 9; loss: 7.628E-01; mae_loss: 3.689E-01; neg_r2_loss: 1.561E-01; phi_mmd0_loss: 8.433E-03; phi_mmd1_loss: 7.876E-03; theta_mmd0_loss: 3.744E-03; theta_mmd1_loss: 5.008E-03; val_loss: 7.618E-01; val_mae_loss: 3.496E-01; val_neg_r2_loss: 5.513E-02; val_phi_mmd0_loss: 2.090E-02; val_phi_mmd1_loss: 2.007E-02; val_theta_mmd0_loss: 9.442E-03; val_theta_mmd1_loss: 1.209E-02
# Epoch 10; loss: 7.564E-01; mae_loss: 3.660E-01; neg_r2_loss: 1.431E-01; phi_mmd0_loss: 8.312E-03; phi_mmd1_loss: 7.645E-03; theta_mmd0_loss: 3.653E-03; theta_mmd1_loss: 4.650E-03; val_loss: 7.581E-01; val_mae_loss: 3.485E-01; val_neg_r2_loss: 5.172E-02; val_phi_mmd0_loss: 2.181E-02; val_phi_mmd1_loss: 2.015E-02; val_theta_mmd0_loss: 8.320E-03; val_theta_mmd1_loss: 1.075E-02
# Epoch 11; loss: 7.498E-01; mae_loss: 3.632E-01; neg_r2_loss: 1.310E-01; phi_mmd0_loss: 7.807E-03; phi_mmd1_loss: 7.627E-03; theta_mmd0_loss: 3.729E-03; theta_mmd1_loss: 4.337E-03; val_loss: 7.561E-01; val_mae_loss: 3.449E-01; val_neg_r2_loss: 3.707E-02; val_phi_mmd0_loss: 2.290E-02; val_phi_mmd1_loss: 2.203E-02; val_theta_mmd0_loss: 1.050E-02; val_theta_mmd1_loss: 1.084E-02
# Epoch 12; loss: 7.415E-01; mae_loss: 3.595E-01; neg_r2_loss: 1.187E-01; phi_mmd0_loss: 7.444E-03; phi_mmd1_loss: 7.545E-03; theta_mmd0_loss: 3.533E-03; theta_mmd1_loss: 4.050E-03; val_loss: 7.570E-01; val_mae_loss: 3.389E-01; val_neg_r2_loss: 1.679E-02; val_phi_mmd0_loss: 2.396E-02; val_phi_mmd1_loss: 2.378E-02; val_theta_mmd0_loss: 1.722E-02; val_theta_mmd1_loss: 1.430E-02
# Epoch 13; loss: 7.315E-01; mae_loss: 3.547E-01; neg_r2_loss: 1.061E-01; phi_mmd0_loss: 7.273E-03; phi_mmd1_loss: 7.321E-03; theta_mmd0_loss: 3.593E-03; theta_mmd1_loss: 3.967E-03; val_loss: 7.382E-01; val_mae_loss: 3.345E-01; val_neg_r2_loss: 8.590E-03; val_phi_mmd0_loss: 2.041E-02; val_phi_mmd1_loss: 2.302E-02; val_theta_mmd0_loss: 1.417E-02; val_theta_mmd1_loss: 1.156E-02
# Epoch 14; loss: 7.189E-01; mae_loss: 3.485E-01; neg_r2_loss: 9.179E-02; phi_mmd0_loss: 7.224E-03; phi_mmd1_loss: 7.230E-03; theta_mmd0_loss: 3.559E-03; theta_mmd1_loss: 3.925E-03; val_loss: 7.332E-01; val_mae_loss: 3.270E-01; val_neg_r2_loss: -1.033E-02; val_phi_mmd0_loss: 2.849E-02; val_phi_mmd1_loss: 2.149E-02; val_theta_mmd0_loss: 1.667E-02; val_theta_mmd1_loss: 1.255E-02
# Epoch 15; loss: 7.064E-01; mae_loss: 3.425E-01; neg_r2_loss: 7.887E-02; phi_mmd0_loss: 6.712E-03; phi_mmd1_loss: 7.146E-03; theta_mmd0_loss: 3.445E-03; theta_mmd1_loss: 4.078E-03; val_loss: 7.211E-01; val_mae_loss: 3.221E-01; val_neg_r2_loss: -7.910E-03; val_phi_mmd0_loss: 2.209E-02; val_phi_mmd1_loss: 2.018E-02; val_theta_mmd0_loss: 1.746E-02; val_theta_mmd1_loss: 1.711E-02
# Epoch 16; loss: 6.964E-01; mae_loss: 3.380E-01; neg_r2_loss: 7.035E-02; phi_mmd0_loss: 6.493E-03; phi_mmd1_loss: 6.956E-03; theta_mmd0_loss: 3.144E-03; theta_mmd1_loss: 3.876E-03; val_loss: 7.038E-01; val_mae_loss: 3.188E-01; val_neg_r2_loss: -1.097E-02; val_phi_mmd0_loss: 1.584E-02; val_phi_mmd1_loss: 1.896E-02; val_theta_mmd0_loss: 1.496E-02; val_theta_mmd1_loss: 1.651E-02
# Epoch 17; loss: 6.891E-01; mae_loss: 3.347E-01; neg_r2_loss: 6.434E-02; phi_mmd0_loss: 6.415E-03; phi_mmd1_loss: 6.927E-03; theta_mmd0_loss: 2.876E-03; theta_mmd1_loss: 3.568E-03; val_loss: 7.001E-01; val_mae_loss: 3.168E-01; val_neg_r2_loss: -8.742E-03; val_phi_mmd0_loss: 1.749E-02; val_phi_mmd1_loss: 1.797E-02; val_theta_mmd0_loss: 1.478E-02; val_theta_mmd1_loss: 1.627E-02
# Epoch 18; loss: 6.830E-01; mae_loss: 3.318E-01; neg_r2_loss: 6.031E-02; phi_mmd0_loss: 6.179E-03; phi_mmd1_loss: 6.795E-03; theta_mmd0_loss: 2.803E-03; theta_mmd1_loss: 3.599E-03; val_loss: 6.991E-01; val_mae_loss: 3.141E-01; val_neg_r2_loss: -1.159E-02; val_phi_mmd0_loss: 1.548E-02; val_phi_mmd1_loss: 1.922E-02; val_theta_mmd0_loss: 1.738E-02; val_theta_mmd1_loss: 1.882E-02
# Epoch 19; loss: 6.777E-01; mae_loss: 3.293E-01; neg_r2_loss: 5.482E-02; phi_mmd0_loss: 6.281E-03; phi_mmd1_loss: 6.732E-03; theta_mmd0_loss: 2.616E-03; theta_mmd1_loss: 3.569E-03; val_loss: 6.872E-01; val_mae_loss: 3.124E-01; val_neg_r2_loss: -1.268E-02; val_phi_mmd0_loss: 1.464E-02; val_phi_mmd1_loss: 1.521E-02; val_theta_mmd0_loss: 1.548E-02; val_theta_mmd1_loss: 1.707E-02
# Epoch 20; loss: 6.731E-01; mae_loss: 3.272E-01; neg_r2_loss: 5.168E-02; phi_mmd0_loss: 6.151E-03; phi_mmd1_loss: 6.737E-03; theta_mmd0_loss: 2.532E-03; theta_mmd1_loss: 3.236E-03; val_loss: 6.816E-01; val_mae_loss: 3.133E-01; val_neg_r2_loss: 4.575E-03; val_phi_mmd0_loss: 1.019E-02; val_phi_mmd1_loss: 1.321E-02; val_theta_mmd0_loss: 1.550E-02; val_theta_mmd1_loss: 1.615E-02
# Epoch 21; loss: 6.683E-01; mae_loss: 3.248E-01; neg_r2_loss: 4.662E-02; phi_mmd0_loss: 6.214E-03; phi_mmd1_loss: 6.745E-03; theta_mmd0_loss: 2.525E-03; theta_mmd1_loss: 3.204E-03; val_loss: 6.763E-01; val_mae_loss: 3.104E-01; val_neg_r2_loss: -5.506E-03; val_phi_mmd0_loss: 1.121E-02; val_phi_mmd1_loss: 1.521E-02; val_theta_mmd0_loss: 1.344E-02; val_theta_mmd1_loss: 1.557E-02
# Epoch 22; loss: 6.644E-01; mae_loss: 3.229E-01; neg_r2_loss: 4.323E-02; phi_mmd0_loss: 6.231E-03; phi_mmd1_loss: 6.622E-03; theta_mmd0_loss: 2.487E-03; theta_mmd1_loss: 3.222E-03; val_loss: 6.712E-01; val_mae_loss: 3.083E-01; val_neg_r2_loss: -9.468E-03; val_phi_mmd0_loss: 9.725E-03; val_phi_mmd1_loss: 1.422E-02; val_theta_mmd0_loss: 1.329E-02; val_theta_mmd1_loss: 1.739E-02
# Epoch 23; loss: 6.596E-01; mae_loss: 3.206E-01; neg_r2_loss: 3.806E-02; phi_mmd0_loss: 6.268E-03; phi_mmd1_loss: 6.597E-03; theta_mmd0_loss: 2.452E-03; theta_mmd1_loss: 3.135E-03; val_loss: 6.659E-01; val_mae_loss: 3.060E-01; val_neg_r2_loss: -1.741E-02; val_phi_mmd0_loss: 1.153E-02; val_phi_mmd1_loss: 1.556E-02; val_theta_mmd0_loss: 1.219E-02; val_theta_mmd1_loss: 1.466E-02
# Epoch 24; loss: 6.552E-01; mae_loss: 3.185E-01; neg_r2_loss: 3.300E-02; phi_mmd0_loss: 6.111E-03; phi_mmd1_loss: 6.585E-03; theta_mmd0_loss: 2.509E-03; theta_mmd1_loss: 2.986E-03; val_loss: 6.590E-01; val_mae_loss: 3.054E-01; val_neg_r2_loss: -1.043E-02; val_phi_mmd0_loss: 9.391E-03; val_phi_mmd1_loss: 1.286E-02; val_theta_mmd0_loss: 1.382E-02; val_theta_mmd1_loss: 1.217E-02
# Epoch 25; loss: 6.503E-01; mae_loss: 3.162E-01; neg_r2_loss: 2.709E-02; phi_mmd0_loss: 6.051E-03; phi_mmd1_loss: 6.543E-03; theta_mmd0_loss: 2.361E-03; theta_mmd1_loss: 2.919E-03; val_loss: 6.544E-01; val_mae_loss: 3.019E-01; val_neg_r2_loss: -2.345E-02; val_phi_mmd0_loss: 1.018E-02; val_phi_mmd1_loss: 1.420E-02; val_theta_mmd0_loss: 1.352E-02; val_theta_mmd1_loss: 1.272E-02
# Epoch 26; loss: 6.456E-01; mae_loss: 3.139E-01; neg_r2_loss: 2.015E-02; phi_mmd0_loss: 6.060E-03; phi_mmd1_loss: 6.514E-03; theta_mmd0_loss: 2.414E-03; theta_mmd1_loss: 2.907E-03; val_loss: 6.480E-01; val_mae_loss: 3.028E-01; val_neg_r2_loss: -1.099E-02; val_phi_mmd0_loss: 6.125E-03; val_phi_mmd1_loss: 1.081E-02; val_theta_mmd0_loss: 1.512E-02; val_theta_mmd1_loss: 1.047E-02
# Epoch 27; loss: 6.408E-01; mae_loss: 3.117E-01; neg_r2_loss: 1.422E-02; phi_mmd0_loss: 5.941E-03; phi_mmd1_loss: 6.357E-03; theta_mmd0_loss: 2.305E-03; theta_mmd1_loss: 2.773E-03; val_loss: 6.434E-01; val_mae_loss: 2.981E-01; val_neg_r2_loss: -3.137E-02; val_phi_mmd0_loss: 8.283E-03; val_phi_mmd1_loss: 1.292E-02; val_theta_mmd0_loss: 1.340E-02; val_theta_mmd1_loss: 1.269E-02
# Epoch 28; loss: 6.362E-01; mae_loss: 3.094E-01; neg_r2_loss: 7.142E-03; phi_mmd0_loss: 5.913E-03; phi_mmd1_loss: 6.296E-03; theta_mmd0_loss: 2.303E-03; theta_mmd1_loss: 2.813E-03; val_loss: 6.420E-01; val_mae_loss: 2.948E-01; val_neg_r2_loss: -4.828E-02; val_phi_mmd0_loss: 1.011E-02; val_phi_mmd1_loss: 1.430E-02; val_theta_mmd0_loss: 1.447E-02; val_theta_mmd1_loss: 1.345E-02
# Epoch 29; loss: 6.323E-01; mae_loss: 3.075E-01; neg_r2_loss: 1.443E-03; phi_mmd0_loss: 5.916E-03; phi_mmd1_loss: 6.353E-03; theta_mmd0_loss: 2.205E-03; theta_mmd1_loss: 2.833E-03; val_loss: 6.359E-01; val_mae_loss: 2.946E-01; val_neg_r2_loss: -4.513E-02; val_phi_mmd0_loss: 8.876E-03; val_phi_mmd1_loss: 1.208E-02; val_theta_mmd0_loss: 1.233E-02; val_theta_mmd1_loss: 1.342E-02
# Epoch 30; loss: 6.279E-01; mae_loss: 3.054E-01; neg_r2_loss: -4.777E-03; phi_mmd0_loss: 5.774E-03; phi_mmd1_loss: 6.261E-03; theta_mmd0_loss: 2.183E-03; theta_mmd1_loss: 2.844E-03; val_loss: 6.297E-01; val_mae_loss: 2.944E-01; val_neg_r2_loss: -3.826E-02; val_phi_mmd0_loss: 7.560E-03; val_phi_mmd1_loss: 9.266E-03; val_theta_mmd0_loss: 1.042E-02; val_theta_mmd1_loss: 1.373E-02
# Epoch 31; loss: 6.246E-01; mae_loss: 3.038E-01; neg_r2_loss: -9.754E-03; phi_mmd0_loss: 5.776E-03; phi_mmd1_loss: 6.233E-03; theta_mmd0_loss: 2.236E-03; theta_mmd1_loss: 2.855E-03; val_loss: 6.244E-01; val_mae_loss: 2.911E-01; val_neg_r2_loss: -5.281E-02; val_phi_mmd0_loss: 8.040E-03; val_phi_mmd1_loss: 1.065E-02; val_theta_mmd0_loss: 1.029E-02; val_theta_mmd1_loss: 1.316E-02
# Epoch 32; loss: 6.211E-01; mae_loss: 3.021E-01; neg_r2_loss: -1.384E-02; phi_mmd0_loss: 5.683E-03; phi_mmd1_loss: 6.284E-03; theta_mmd0_loss: 2.109E-03; theta_mmd1_loss: 2.850E-03; val_loss: 6.259E-01; val_mae_loss: 2.884E-01; val_neg_r2_loss: -6.628E-02; val_phi_mmd0_loss: 9.314E-03; val_phi_mmd1_loss: 1.304E-02; val_theta_mmd0_loss: 1.312E-02; val_theta_mmd1_loss: 1.357E-02
# Epoch 33; loss: 6.180E-01; mae_loss: 3.006E-01; neg_r2_loss: -1.738E-02; phi_mmd0_loss: 5.718E-03; phi_mmd1_loss: 6.300E-03; theta_mmd0_loss: 2.066E-03; theta_mmd1_loss: 2.721E-03; val_loss: 6.226E-01; val_mae_loss: 2.882E-01; val_neg_r2_loss: -5.992E-02; val_phi_mmd0_loss: 7.689E-03; val_phi_mmd1_loss: 1.158E-02; val_theta_mmd0_loss: 1.369E-02; val_theta_mmd1_loss: 1.315E-02
# Epoch 34; loss: 6.149E-01; mae_loss: 2.991E-01; neg_r2_loss: -2.143E-02; phi_mmd0_loss: 5.610E-03; phi_mmd1_loss: 6.315E-03; theta_mmd0_loss: 2.126E-03; theta_mmd1_loss: 2.718E-03; val_loss: 6.173E-01; val_mae_loss: 2.871E-01; val_neg_r2_loss: -6.390E-02; val_phi_mmd0_loss: 8.503E-03; val_phi_mmd1_loss: 1.077E-02; val_theta_mmd0_loss: 1.079E-02; val_theta_mmd1_loss: 1.301E-02
# Epoch 35; loss: 6.123E-01; mae_loss: 2.978E-01; neg_r2_loss: -2.385E-02; phi_mmd0_loss: 5.461E-03; phi_mmd1_loss: 6.370E-03; theta_mmd0_loss: 2.023E-03; theta_mmd1_loss: 2.750E-03; val_loss: 6.195E-01; val_mae_loss: 2.874E-01; val_neg_r2_loss: -5.880E-02; val_phi_mmd0_loss: 8.134E-03; val_phi_mmd1_loss: 1.088E-02; val_theta_mmd0_loss: 1.303E-02; val_theta_mmd1_loss: 1.275E-02
# Epoch 36; loss: 6.096E-01; mae_loss: 2.966E-01; neg_r2_loss: -2.597E-02; phi_mmd0_loss: 5.428E-03; phi_mmd1_loss: 6.250E-03; theta_mmd0_loss: 2.055E-03; theta_mmd1_loss: 2.596E-03; val_loss: 6.110E-01; val_mae_loss: 2.855E-01; val_neg_r2_loss: -6.423E-02; val_phi_mmd0_loss: 7.237E-03; val_phi_mmd1_loss: 1.098E-02; val_theta_mmd0_loss: 1.075E-02; val_theta_mmd1_loss: 1.096E-02
# Epoch 37; loss: 6.073E-01; mae_loss: 2.955E-01; neg_r2_loss: -2.822E-02; phi_mmd0_loss: 5.455E-03; phi_mmd1_loss: 6.292E-03; theta_mmd0_loss: 2.007E-03; theta_mmd1_loss: 2.490E-03; val_loss: 6.090E-01; val_mae_loss: 2.858E-01; val_neg_r2_loss: -5.712E-02; val_phi_mmd0_loss: 6.168E-03; val_phi_mmd1_loss: 9.142E-03; val_theta_mmd0_loss: 1.041E-02; val_theta_mmd1_loss: 1.172E-02
# Epoch 38; loss: 6.048E-01; mae_loss: 2.943E-01; neg_r2_loss: -3.113E-02; phi_mmd0_loss: 5.358E-03; phi_mmd1_loss: 6.248E-03; theta_mmd0_loss: 1.957E-03; theta_mmd1_loss: 2.576E-03; val_loss: 6.038E-01; val_mae_loss: 2.842E-01; val_neg_r2_loss: -6.531E-02; val_phi_mmd0_loss: 7.369E-03; val_phi_mmd1_loss: 9.640E-03; val_theta_mmd0_loss: 8.516E-03; val_theta_mmd1_loss: 9.904E-03
# Epoch 39; loss: 6.034E-01; mae_loss: 2.936E-01; neg_r2_loss: -3.288E-02; phi_mmd0_loss: 5.370E-03; phi_mmd1_loss: 6.264E-03; theta_mmd0_loss: 1.955E-03; theta_mmd1_loss: 2.554E-03; val_loss: 6.051E-01; val_mae_loss: 2.845E-01; val_neg_r2_loss: -5.919E-02; val_phi_mmd0_loss: 6.716E-03; val_phi_mmd1_loss: 1.012E-02; val_theta_mmd0_loss: 1.019E-02; val_theta_mmd1_loss: 9.052E-03
# Epoch 40; loss: 6.009E-01; mae_loss: 2.924E-01; neg_r2_loss: -3.542E-02; phi_mmd0_loss: 5.258E-03; phi_mmd1_loss: 6.267E-03; theta_mmd0_loss: 1.951E-03; theta_mmd1_loss: 2.490E-03; val_loss: 6.018E-01; val_mae_loss: 2.836E-01; val_neg_r2_loss: -6.106E-02; val_phi_mmd0_loss: 6.129E-03; val_phi_mmd1_loss: 9.000E-03; val_theta_mmd0_loss: 9.182E-03; val_theta_mmd1_loss: 1.024E-02
# Epoch 41; loss: 5.989E-01; mae_loss: 2.915E-01; neg_r2_loss: -3.748E-02; phi_mmd0_loss: 5.312E-03; phi_mmd1_loss: 6.252E-03; theta_mmd0_loss: 1.943E-03; theta_mmd1_loss: 2.474E-03; val_loss: 5.979E-01; val_mae_loss: 2.821E-01; val_neg_r2_loss: -6.800E-02; val_phi_mmd0_loss: 7.125E-03; val_phi_mmd1_loss: 8.927E-03; val_theta_mmd0_loss: 9.397E-03; val_theta_mmd1_loss: 8.197E-03
# Epoch 42; loss: 5.977E-01; mae_loss: 2.909E-01; neg_r2_loss: -3.841E-02; phi_mmd0_loss: 5.284E-03; phi_mmd1_loss: 6.191E-03; theta_mmd0_loss: 1.947E-03; theta_mmd1_loss: 2.389E-03; val_loss: 5.987E-01; val_mae_loss: 2.819E-01; val_neg_r2_loss: -6.753E-02; val_phi_mmd0_loss: 6.362E-03; val_phi_mmd1_loss: 9.201E-03; val_theta_mmd0_loss: 9.419E-03; val_theta_mmd1_loss: 1.004E-02
# Epoch 43; loss: 5.958E-01; mae_loss: 2.900E-01; neg_r2_loss: -4.148E-02; phi_mmd0_loss: 5.269E-03; phi_mmd1_loss: 6.239E-03; theta_mmd0_loss: 1.903E-03; theta_mmd1_loss: 2.310E-03; val_loss: 5.955E-01; val_mae_loss: 2.817E-01; val_neg_r2_loss: -6.627E-02; val_phi_mmd0_loss: 6.590E-03; val_phi_mmd1_loss: 8.646E-03; val_theta_mmd0_loss: 8.614E-03; val_theta_mmd1_loss: 8.157E-03
# Epoch 44; loss: 5.940E-01; mae_loss: 2.893E-01; neg_r2_loss: -4.265E-02; phi_mmd0_loss: 5.162E-03; phi_mmd1_loss: 6.172E-03; theta_mmd0_loss: 1.910E-03; theta_mmd1_loss: 2.238E-03; val_loss: 5.927E-01; val_mae_loss: 2.804E-01; val_neg_r2_loss: -7.128E-02; val_phi_mmd0_loss: 7.318E-03; val_phi_mmd1_loss: 9.167E-03; val_theta_mmd0_loss: 7.084E-03; val_theta_mmd1_loss: 8.223E-03
# Epoch 45; loss: 5.931E-01; mae_loss: 2.887E-01; neg_r2_loss: -4.384E-02; phi_mmd0_loss: 5.136E-03; phi_mmd1_loss: 6.198E-03; theta_mmd0_loss: 1.919E-03; theta_mmd1_loss: 2.392E-03; val_loss: 5.906E-01; val_mae_loss: 2.804E-01; val_neg_r2_loss: -6.963E-02; val_phi_mmd0_loss: 6.571E-03; val_phi_mmd1_loss: 9.056E-03; val_theta_mmd0_loss: 6.888E-03; val_theta_mmd1_loss: 7.228E-03
# Epoch 46; loss: 5.914E-01; mae_loss: 2.879E-01; neg_r2_loss: -4.608E-02; phi_mmd0_loss: 5.226E-03; phi_mmd1_loss: 6.151E-03; theta_mmd0_loss: 1.896E-03; theta_mmd1_loss: 2.287E-03; val_loss: 5.915E-01; val_mae_loss: 2.803E-01; val_neg_r2_loss: -7.016E-02; val_phi_mmd0_loss: 6.582E-03; val_phi_mmd1_loss: 8.902E-03; val_theta_mmd0_loss: 8.338E-03; val_theta_mmd1_loss: 7.216E-03
# Epoch 47; loss: 5.903E-01; mae_loss: 2.874E-01; neg_r2_loss: -4.757E-02; phi_mmd0_loss: 5.187E-03; phi_mmd1_loss: 6.122E-03; theta_mmd0_loss: 1.834E-03; theta_mmd1_loss: 2.338E-03; val_loss: 5.877E-01; val_mae_loss: 2.796E-01; val_neg_r2_loss: -7.002E-02; val_phi_mmd0_loss: 6.206E-03; val_phi_mmd1_loss: 7.963E-03; val_theta_mmd0_loss: 7.531E-03; val_theta_mmd1_loss: 6.814E-03
# Epoch 48; loss: 5.892E-01; mae_loss: 2.869E-01; neg_r2_loss: -4.803E-02; phi_mmd0_loss: 5.131E-03; phi_mmd1_loss: 6.174E-03; theta_mmd0_loss: 1.864E-03; theta_mmd1_loss: 2.216E-03; val_loss: 5.871E-01; val_mae_loss: 2.802E-01; val_neg_r2_loss: -6.704E-02; val_phi_mmd0_loss: 6.377E-03; val_phi_mmd1_loss: 8.214E-03; val_theta_mmd0_loss: 6.953E-03; val_theta_mmd1_loss: 5.263E-03
# Epoch 49; loss: 5.875E-01; mae_loss: 2.860E-01; neg_r2_loss: -5.127E-02; phi_mmd0_loss: 5.164E-03; phi_mmd1_loss: 6.198E-03; theta_mmd0_loss: 1.792E-03; theta_mmd1_loss: 2.213E-03; val_loss: 5.868E-01; val_mae_loss: 2.795E-01; val_neg_r2_loss: -6.886E-02; val_phi_mmd0_loss: 5.996E-03; val_phi_mmd1_loss: 8.722E-03; val_theta_mmd0_loss: 7.194E-03; val_theta_mmd1_loss: 5.965E-03
# Epoch 50; loss: 5.864E-01; mae_loss: 2.856E-01; neg_r2_loss: -5.234E-02; phi_mmd0_loss: 5.069E-03; phi_mmd1_loss: 6.209E-03; theta_mmd0_loss: 1.751E-03; theta_mmd1_loss: 2.200E-03; val_loss: 5.850E-01; val_mae_loss: 2.782E-01; val_neg_r2_loss: -7.371E-02; val_phi_mmd0_loss: 6.806E-03; val_phi_mmd1_loss: 8.500E-03; val_theta_mmd0_loss: 7.045E-03; val_theta_mmd1_loss: 6.300E-03
# Epoch 51; loss: 5.854E-01; mae_loss: 2.850E-01; neg_r2_loss: -5.346E-02; phi_mmd0_loss: 5.090E-03; phi_mmd1_loss: 6.152E-03; theta_mmd0_loss: 1.811E-03; theta_mmd1_loss: 2.229E-03; val_loss: 5.819E-01; val_mae_loss: 2.777E-01; val_neg_r2_loss: -7.603E-02; val_phi_mmd0_loss: 6.448E-03; val_phi_mmd1_loss: 8.082E-03; val_theta_mmd0_loss: 5.941E-03; val_theta_mmd1_loss: 5.945E-03
# Epoch 52; loss: 5.841E-01; mae_loss: 2.845E-01; neg_r2_loss: -5.535E-02; phi_mmd0_loss: 5.072E-03; phi_mmd1_loss: 6.112E-03; theta_mmd0_loss: 1.790E-03; theta_mmd1_loss: 2.220E-03; val_loss: 5.823E-01; val_mae_loss: 2.773E-01; val_neg_r2_loss: -7.845E-02; val_phi_mmd0_loss: 6.975E-03; val_phi_mmd1_loss: 9.104E-03; val_theta_mmd0_loss: 5.982E-03; val_theta_mmd1_loss: 5.630E-03
# Epoch 53; loss: 5.829E-01; mae_loss: 2.839E-01; neg_r2_loss: -5.726E-02; phi_mmd0_loss: 5.029E-03; phi_mmd1_loss: 6.102E-03; theta_mmd0_loss: 1.793E-03; theta_mmd1_loss: 2.128E-03; val_loss: 5.800E-01; val_mae_loss: 2.776E-01; val_neg_r2_loss: -7.364E-02; val_phi_mmd0_loss: 6.003E-03; val_phi_mmd1_loss: 7.514E-03; val_theta_mmd0_loss: 5.986E-03; val_theta_mmd1_loss: 5.213E-03
# Epoch 54; loss: 5.820E-01; mae_loss: 2.834E-01; neg_r2_loss: -5.807E-02; phi_mmd0_loss: 5.058E-03; phi_mmd1_loss: 6.112E-03; theta_mmd0_loss: 1.792E-03; theta_mmd1_loss: 2.133E-03; val_loss: 5.793E-01; val_mae_loss: 2.774E-01; val_neg_r2_loss: -7.365E-02; val_phi_mmd0_loss: 5.933E-03; val_phi_mmd1_loss: 7.875E-03; val_theta_mmd0_loss: 5.823E-03; val_theta_mmd1_loss: 5.004E-03
# Epoch 55; loss: 5.817E-01; mae_loss: 2.833E-01; neg_r2_loss: -5.778E-02; phi_mmd0_loss: 5.038E-03; phi_mmd1_loss: 6.153E-03; theta_mmd0_loss: 1.713E-03; theta_mmd1_loss: 2.140E-03; val_loss: 5.783E-01; val_mae_loss: 2.768E-01; val_neg_r2_loss: -7.516E-02; val_phi_mmd0_loss: 6.020E-03; val_phi_mmd1_loss: 7.565E-03; val_theta_mmd0_loss: 6.342E-03; val_theta_mmd1_loss: 4.848E-03
# Epoch 56; loss: 5.806E-01; mae_loss: 2.829E-01; neg_r2_loss: -5.917E-02; phi_mmd0_loss: 4.974E-03; phi_mmd1_loss: 6.129E-03; theta_mmd0_loss: 1.749E-03; theta_mmd1_loss: 2.054E-03; val_loss: 5.787E-01; val_mae_loss: 2.769E-01; val_neg_r2_loss: -7.367E-02; val_phi_mmd0_loss: 5.844E-03; val_phi_mmd1_loss: 7.870E-03; val_theta_mmd0_loss: 6.579E-03; val_theta_mmd1_loss: 4.573E-03
# Epoch 57; loss: 5.797E-01; mae_loss: 2.824E-01; neg_r2_loss: -6.039E-02; phi_mmd0_loss: 5.026E-03; phi_mmd1_loss: 6.073E-03; theta_mmd0_loss: 1.780E-03; theta_mmd1_loss: 2.078E-03; val_loss: 5.789E-01; val_mae_loss: 2.762E-01; val_neg_r2_loss: -7.778E-02; val_phi_mmd0_loss: 6.268E-03; val_phi_mmd1_loss: 8.250E-03; val_theta_mmd0_loss: 6.648E-03; val_theta_mmd1_loss: 5.275E-03
# Epoch 58; loss: 5.788E-01; mae_loss: 2.820E-01; neg_r2_loss: -6.096E-02; phi_mmd0_loss: 4.974E-03; phi_mmd1_loss: 6.075E-03; theta_mmd0_loss: 1.683E-03; theta_mmd1_loss: 2.063E-03; val_loss: 5.767E-01; val_mae_loss: 2.759E-01; val_neg_r2_loss: -7.706E-02; val_phi_mmd0_loss: 6.577E-03; val_phi_mmd1_loss: 7.974E-03; val_theta_mmd0_loss: 5.475E-03; val_theta_mmd1_loss: 4.835E-03
# Epoch 59; loss: 5.784E-01; mae_loss: 2.818E-01; neg_r2_loss: -6.124E-02; phi_mmd0_loss: 4.982E-03; phi_mmd1_loss: 6.130E-03; theta_mmd0_loss: 1.742E-03; theta_mmd1_loss: 2.065E-03; val_loss: 5.757E-01; val_mae_loss: 2.756E-01; val_neg_r2_loss: -7.956E-02; val_phi_mmd0_loss: 6.685E-03; val_phi_mmd1_loss: 7.951E-03; val_theta_mmd0_loss: 5.675E-03; val_theta_mmd1_loss: 4.247E-03
# Epoch 60; loss: 5.773E-01; mae_loss: 2.813E-01; neg_r2_loss: -6.320E-02; phi_mmd0_loss: 4.973E-03; phi_mmd1_loss: 6.137E-03; theta_mmd0_loss: 1.689E-03; theta_mmd1_loss: 2.029E-03; val_loss: 5.760E-01; val_mae_loss: 2.753E-01; val_neg_r2_loss: -7.961E-02; val_phi_mmd0_loss: 6.293E-03; val_phi_mmd1_loss: 8.020E-03; val_theta_mmd0_loss: 6.147E-03; val_theta_mmd1_loss: 4.912E-03
# Epoch 61; loss: 5.763E-01; mae_loss: 2.808E-01; neg_r2_loss: -6.486E-02; phi_mmd0_loss: 4.978E-03; phi_mmd1_loss: 6.096E-03; theta_mmd0_loss: 1.689E-03; theta_mmd1_loss: 1.991E-03; val_loss: 5.748E-01; val_mae_loss: 2.748E-01; val_neg_r2_loss: -8.133E-02; val_phi_mmd0_loss: 6.138E-03; val_phi_mmd1_loss: 8.253E-03; val_theta_mmd0_loss: 5.855E-03; val_theta_mmd1_loss: 5.085E-03
# Epoch 62; loss: 5.758E-01; mae_loss: 2.805E-01; neg_r2_loss: -6.535E-02; phi_mmd0_loss: 4.943E-03; phi_mmd1_loss: 6.095E-03; theta_mmd0_loss: 1.707E-03; theta_mmd1_loss: 1.996E-03; val_loss: 5.751E-01; val_mae_loss: 2.748E-01; val_neg_r2_loss: -8.197E-02; val_phi_mmd0_loss: 6.402E-03; val_phi_mmd1_loss: 8.029E-03; val_theta_mmd0_loss: 5.786E-03; val_theta_mmd1_loss: 5.409E-03
# Epoch 63; loss: 5.753E-01; mae_loss: 2.803E-01; neg_r2_loss: -6.532E-02; phi_mmd0_loss: 4.931E-03; phi_mmd1_loss: 6.054E-03; theta_mmd0_loss: 1.685E-03; theta_mmd1_loss: 1.972E-03; val_loss: 5.755E-01; val_mae_loss: 2.749E-01; val_neg_r2_loss: -8.217E-02; val_phi_mmd0_loss: 6.149E-03; val_phi_mmd1_loss: 8.227E-03; val_theta_mmd0_loss: 6.138E-03; val_theta_mmd1_loss: 5.151E-03
# Epoch 64; loss: 5.745E-01; mae_loss: 2.799E-01; neg_r2_loss: -6.684E-02; phi_mmd0_loss: 4.873E-03; phi_mmd1_loss: 6.092E-03; theta_mmd0_loss: 1.718E-03; theta_mmd1_loss: 1.964E-03; val_loss: 5.739E-01; val_mae_loss: 2.747E-01; val_neg_r2_loss: -8.081E-02; val_phi_mmd0_loss: 5.924E-03; val_phi_mmd1_loss: 7.652E-03; val_theta_mmd0_loss: 6.218E-03; val_theta_mmd1_loss: 4.769E-03
# Epoch 65; loss: 5.738E-01; mae_loss: 2.796E-01; neg_r2_loss: -6.777E-02; phi_mmd0_loss: 4.868E-03; phi_mmd1_loss: 6.123E-03; theta_mmd0_loss: 1.686E-03; theta_mmd1_loss: 1.894E-03; val_loss: 5.717E-01; val_mae_loss: 2.737E-01; val_neg_r2_loss: -8.577E-02; val_phi_mmd0_loss: 6.372E-03; val_phi_mmd1_loss: 8.033E-03; val_theta_mmd0_loss: 4.956E-03; val_theta_mmd1_loss: 5.049E-03
# Epoch 66; loss: 5.730E-01; mae_loss: 2.793E-01; neg_r2_loss: -6.843E-02; phi_mmd0_loss: 4.869E-03; phi_mmd1_loss: 6.063E-03; theta_mmd0_loss: 1.647E-03; theta_mmd1_loss: 1.848E-03; val_loss: 5.717E-01; val_mae_loss: 2.743E-01; val_neg_r2_loss: -8.099E-02; val_phi_mmd0_loss: 5.770E-03; val_phi_mmd1_loss: 7.343E-03; val_theta_mmd0_loss: 5.724E-03; val_theta_mmd1_loss: 4.323E-03
# Epoch 67; loss: 5.725E-01; mae_loss: 2.790E-01; neg_r2_loss: -6.921E-02; phi_mmd0_loss: 4.870E-03; phi_mmd1_loss: 6.105E-03; theta_mmd0_loss: 1.656E-03; theta_mmd1_loss: 1.900E-03; val_loss: 5.715E-01; val_mae_loss: 2.736E-01; val_neg_r2_loss: -8.458E-02; val_phi_mmd0_loss: 6.185E-03; val_phi_mmd1_loss: 8.251E-03; val_theta_mmd0_loss: 5.445E-03; val_theta_mmd1_loss: 4.303E-03
# Epoch 68; loss: 5.718E-01; mae_loss: 2.787E-01; neg_r2_loss: -7.031E-02; phi_mmd0_loss: 4.854E-03; phi_mmd1_loss: 6.090E-03; theta_mmd0_loss: 1.608E-03; theta_mmd1_loss: 1.875E-03; val_loss: 5.701E-01; val_mae_loss: 2.735E-01; val_neg_r2_loss: -8.652E-02; val_phi_mmd0_loss: 6.774E-03; val_phi_mmd1_loss: 8.823E-03; val_theta_mmd0_loss: 3.759E-03; val_theta_mmd1_loss: 3.805E-03
# Epoch 69; loss: 5.716E-01; mae_loss: 2.785E-01; neg_r2_loss: -7.066E-02; phi_mmd0_loss: 4.861E-03; phi_mmd1_loss: 6.105E-03; theta_mmd0_loss: 1.638E-03; theta_mmd1_loss: 1.855E-03; val_loss: 5.694E-01; val_mae_loss: 2.737E-01; val_neg_r2_loss: -8.466E-02; val_phi_mmd0_loss: 5.753E-03; val_phi_mmd1_loss: 7.730E-03; val_theta_mmd0_loss: 4.488E-03; val_theta_mmd1_loss: 4.082E-03
# Epoch 70; loss: 5.706E-01; mae_loss: 2.781E-01; neg_r2_loss: -7.229E-02; phi_mmd0_loss: 4.842E-03; phi_mmd1_loss: 6.149E-03; theta_mmd0_loss: 1.624E-03; theta_mmd1_loss: 1.906E-03; val_loss: 5.707E-01; val_mae_loss: 2.733E-01; val_neg_r2_loss: -8.549E-02; val_phi_mmd0_loss: 6.047E-03; val_phi_mmd1_loss: 8.602E-03; val_theta_mmd0_loss: 5.133E-03; val_theta_mmd1_loss: 4.271E-03
# Epoch 71; loss: 5.703E-01; mae_loss: 2.780E-01; neg_r2_loss: -7.235E-02; phi_mmd0_loss: 4.845E-03; phi_mmd1_loss: 6.086E-03; theta_mmd0_loss: 1.585E-03; theta_mmd1_loss: 1.861E-03; val_loss: 5.676E-01; val_mae_loss: 2.731E-01; val_neg_r2_loss: -8.485E-02; val_phi_mmd0_loss: 6.122E-03; val_phi_mmd1_loss: 7.632E-03; val_theta_mmd0_loss: 4.376E-03; val_theta_mmd1_loss: 3.302E-03
# Epoch 72; loss: 5.695E-01; mae_loss: 2.776E-01; neg_r2_loss: -7.350E-02; phi_mmd0_loss: 4.780E-03; phi_mmd1_loss: 6.107E-03; theta_mmd0_loss: 1.614E-03; theta_mmd1_loss: 1.813E-03; val_loss: 5.683E-01; val_mae_loss: 2.731E-01; val_neg_r2_loss: -8.488E-02; val_phi_mmd0_loss: 5.974E-03; val_phi_mmd1_loss: 7.535E-03; val_theta_mmd0_loss: 4.822E-03; val_theta_mmd1_loss: 3.898E-03
# Epoch 73; loss: 5.690E-01; mae_loss: 2.773E-01; neg_r2_loss: -7.484E-02; phi_mmd0_loss: 4.784E-03; phi_mmd1_loss: 6.140E-03; theta_mmd0_loss: 1.590E-03; theta_mmd1_loss: 1.830E-03; val_loss: 5.675E-01; val_mae_loss: 2.729E-01; val_neg_r2_loss: -8.419E-02; val_phi_mmd0_loss: 5.962E-03; val_phi_mmd1_loss: 7.549E-03; val_theta_mmd0_loss: 4.072E-03; val_theta_mmd1_loss: 4.126E-03
# Epoch 74; loss: 5.688E-01; mae_loss: 2.773E-01; neg_r2_loss: -7.428E-02; phi_mmd0_loss: 4.807E-03; phi_mmd1_loss: 6.104E-03; theta_mmd0_loss: 1.590E-03; theta_mmd1_loss: 1.816E-03; val_loss: 5.671E-01; val_mae_loss: 2.721E-01; val_neg_r2_loss: -8.902E-02; val_phi_mmd0_loss: 6.377E-03; val_phi_mmd1_loss: 7.821E-03; val_theta_mmd0_loss: 4.500E-03; val_theta_mmd1_loss: 4.132E-03
# Epoch 75; loss: 5.681E-01; mae_loss: 2.769E-01; neg_r2_loss: -7.616E-02; phi_mmd0_loss: 4.796E-03; phi_mmd1_loss: 6.144E-03; theta_mmd0_loss: 1.588E-03; theta_mmd1_loss: 1.819E-03; val_loss: 5.681E-01; val_mae_loss: 2.729E-01; val_neg_r2_loss: -8.357E-02; val_phi_mmd0_loss: 5.416E-03; val_phi_mmd1_loss: 7.480E-03; val_theta_mmd0_loss: 5.194E-03; val_theta_mmd1_loss: 4.265E-03
# Epoch 76; loss: 5.677E-01; mae_loss: 2.767E-01; neg_r2_loss: -7.667E-02; phi_mmd0_loss: 4.846E-03; phi_mmd1_loss: 6.152E-03; theta_mmd0_loss: 1.587E-03; theta_mmd1_loss: 1.800E-03; val_loss: 5.680E-01; val_mae_loss: 2.718E-01; val_neg_r2_loss: -9.122E-02; val_phi_mmd0_loss: 6.285E-03; val_phi_mmd1_loss: 8.532E-03; val_theta_mmd0_loss: 4.968E-03; val_theta_mmd1_loss: 4.545E-03
# Epoch 77; loss: 5.672E-01; mae_loss: 2.765E-01; neg_r2_loss: -7.750E-02; phi_mmd0_loss: 4.768E-03; phi_mmd1_loss: 6.148E-03; theta_mmd0_loss: 1.558E-03; theta_mmd1_loss: 1.801E-03; val_loss: 5.687E-01; val_mae_loss: 2.712E-01; val_neg_r2_loss: -9.606E-02; val_phi_mmd0_loss: 7.593E-03; val_phi_mmd1_loss: 9.547E-03; val_theta_mmd0_loss: 4.867E-03; val_theta_mmd1_loss: 4.263E-03
# Epoch 78; loss: 5.668E-01; mae_loss: 2.762E-01; neg_r2_loss: -7.805E-02; phi_mmd0_loss: 4.799E-03; phi_mmd1_loss: 6.166E-03; theta_mmd0_loss: 1.569E-03; theta_mmd1_loss: 1.764E-03; val_loss: 5.675E-01; val_mae_loss: 2.725E-01; val_neg_r2_loss: -8.446E-02; val_phi_mmd0_loss: 5.818E-03; val_phi_mmd1_loss: 7.395E-03; val_theta_mmd0_loss: 4.910E-03; val_theta_mmd1_loss: 4.452E-03
# Epoch 79; loss: 5.663E-01; mae_loss: 2.760E-01; neg_r2_loss: -7.917E-02; phi_mmd0_loss: 4.805E-03; phi_mmd1_loss: 6.159E-03; theta_mmd0_loss: 1.547E-03; theta_mmd1_loss: 1.803E-03; val_loss: 5.648E-01; val_mae_loss: 2.713E-01; val_neg_r2_loss: -9.336E-02; val_phi_mmd0_loss: 6.021E-03; val_phi_mmd1_loss: 8.576E-03; val_theta_mmd0_loss: 4.273E-03; val_theta_mmd1_loss: 3.268E-03
# Epoch 80; loss: 5.661E-01; mae_loss: 2.759E-01; neg_r2_loss: -7.894E-02; phi_mmd0_loss: 4.816E-03; phi_mmd1_loss: 6.184E-03; theta_mmd0_loss: 1.580E-03; theta_mmd1_loss: 1.718E-03; val_loss: 5.654E-01; val_mae_loss: 2.712E-01; val_neg_r2_loss: -9.185E-02; val_phi_mmd0_loss: 6.456E-03; val_phi_mmd1_loss: 7.450E-03; val_theta_mmd0_loss: 4.606E-03; val_theta_mmd1_loss: 4.478E-03
# Epoch 81; loss: 5.657E-01; mae_loss: 2.758E-01; neg_r2_loss: -7.992E-02; phi_mmd0_loss: 4.786E-03; phi_mmd1_loss: 6.143E-03; theta_mmd0_loss: 1.583E-03; theta_mmd1_loss: 1.713E-03; val_loss: 5.653E-01; val_mae_loss: 2.714E-01; val_neg_r2_loss: -9.424E-02; val_phi_mmd0_loss: 6.684E-03; val_phi_mmd1_loss: 8.229E-03; val_theta_mmd0_loss: 3.855E-03; val_theta_mmd1_loss: 3.731E-03
# Epoch 82; loss: 5.654E-01; mae_loss: 2.756E-01; neg_r2_loss: -7.970E-02; phi_mmd0_loss: 4.799E-03; phi_mmd1_loss: 6.125E-03; theta_mmd0_loss: 1.555E-03; theta_mmd1_loss: 1.744E-03; val_loss: 5.630E-01; val_mae_loss: 2.717E-01; val_neg_r2_loss: -8.866E-02; val_phi_mmd0_loss: 5.623E-03; val_phi_mmd1_loss: 7.491E-03; val_theta_mmd0_loss: 3.284E-03; val_theta_mmd1_loss: 3.172E-03
# Epoch 83; loss: 5.649E-01; mae_loss: 2.754E-01; neg_r2_loss: -8.075E-02; phi_mmd0_loss: 4.769E-03; phi_mmd1_loss: 6.138E-03; theta_mmd0_loss: 1.528E-03; theta_mmd1_loss: 1.718E-03; val_loss: 5.639E-01; val_mae_loss: 2.705E-01; val_neg_r2_loss: -9.592E-02; val_phi_mmd0_loss: 6.410E-03; val_phi_mmd1_loss: 8.052E-03; val_theta_mmd0_loss: 4.306E-03; val_theta_mmd1_loss: 4.040E-03
# Epoch 84; loss: 5.642E-01; mae_loss: 2.750E-01; neg_r2_loss: -8.227E-02; phi_mmd0_loss: 4.788E-03; phi_mmd1_loss: 6.116E-03; theta_mmd0_loss: 1.550E-03; theta_mmd1_loss: 1.707E-03; val_loss: 5.655E-01; val_mae_loss: 2.715E-01; val_neg_r2_loss: -8.876E-02; val_phi_mmd0_loss: 5.925E-03; val_phi_mmd1_loss: 7.504E-03; val_theta_mmd0_loss: 4.715E-03; val_theta_mmd1_loss: 4.251E-03
# Epoch 85; loss: 5.639E-01; mae_loss: 2.749E-01; neg_r2_loss: -8.222E-02; phi_mmd0_loss: 4.759E-03; phi_mmd1_loss: 6.143E-03; theta_mmd0_loss: 1.537E-03; theta_mmd1_loss: 1.739E-03; val_loss: 5.652E-01; val_mae_loss: 2.715E-01; val_neg_r2_loss: -8.786E-02; val_phi_mmd0_loss: 5.595E-03; val_phi_mmd1_loss: 7.659E-03; val_theta_mmd0_loss: 4.500E-03; val_theta_mmd1_loss: 4.314E-03
# Epoch 86; loss: 5.636E-01; mae_loss: 2.748E-01; neg_r2_loss: -8.220E-02; phi_mmd0_loss: 4.744E-03; phi_mmd1_loss: 6.122E-03; theta_mmd0_loss: 1.539E-03; theta_mmd1_loss: 1.687E-03; val_loss: 5.638E-01; val_mae_loss: 2.709E-01; val_neg_r2_loss: -9.211E-02; val_phi_mmd0_loss: 6.438E-03; val_phi_mmd1_loss: 8.520E-03; val_theta_mmd0_loss: 3.602E-03; val_theta_mmd1_loss: 3.390E-03
# Epoch 87; loss: 5.634E-01; mae_loss: 2.747E-01; neg_r2_loss: -8.262E-02; phi_mmd0_loss: 4.795E-03; phi_mmd1_loss: 6.106E-03; theta_mmd0_loss: 1.525E-03; theta_mmd1_loss: 1.708E-03; val_loss: 5.652E-01; val_mae_loss: 2.712E-01; val_neg_r2_loss: -9.005E-02; val_phi_mmd0_loss: 6.401E-03; val_phi_mmd1_loss: 8.550E-03; val_theta_mmd0_loss: 4.022E-03; val_theta_mmd1_loss: 3.851E-03
# Epoch 88; loss: 5.630E-01; mae_loss: 2.744E-01; neg_r2_loss: -8.325E-02; phi_mmd0_loss: 4.729E-03; phi_mmd1_loss: 6.129E-03; theta_mmd0_loss: 1.528E-03; theta_mmd1_loss: 1.703E-03; val_loss: 5.622E-01; val_mae_loss: 2.712E-01; val_neg_r2_loss: -8.824E-02; val_phi_mmd0_loss: 5.828E-03; val_phi_mmd1_loss: 7.589E-03; val_theta_mmd0_loss: 3.172E-03; val_theta_mmd1_loss: 3.211E-03
# Epoch 89; loss: 5.627E-01; mae_loss: 2.743E-01; neg_r2_loss: -8.349E-02; phi_mmd0_loss: 4.723E-03; phi_mmd1_loss: 6.108E-03; theta_mmd0_loss: 1.548E-03; theta_mmd1_loss: 1.677E-03; val_loss: 5.615E-01; val_mae_loss: 2.697E-01; val_neg_r2_loss: -9.927E-02; val_phi_mmd0_loss: 6.905E-03; val_phi_mmd1_loss: 8.792E-03; val_theta_mmd0_loss: 3.271E-03; val_theta_mmd1_loss: 3.158E-03
# Epoch 90; loss: 5.623E-01; mae_loss: 2.741E-01; neg_r2_loss: -8.432E-02; phi_mmd0_loss: 4.735E-03; phi_mmd1_loss: 6.190E-03; theta_mmd0_loss: 1.534E-03; theta_mmd1_loss: 1.649E-03; val_loss: 5.613E-01; val_mae_loss: 2.703E-01; val_neg_r2_loss: -9.423E-02; val_phi_mmd0_loss: 5.924E-03; val_phi_mmd1_loss: 8.007E-03; val_theta_mmd0_loss: 3.730E-03; val_theta_mmd1_loss: 3.051E-03
# Epoch 91; loss: 5.618E-01; mae_loss: 2.739E-01; neg_r2_loss: -8.471E-02; phi_mmd0_loss: 4.677E-03; phi_mmd1_loss: 6.163E-03; theta_mmd0_loss: 1.523E-03; theta_mmd1_loss: 1.662E-03; val_loss: 5.623E-01; val_mae_loss: 2.700E-01; val_neg_r2_loss: -9.616E-02; val_phi_mmd0_loss: 6.141E-03; val_phi_mmd1_loss: 8.301E-03; val_theta_mmd0_loss: 4.392E-03; val_theta_mmd1_loss: 3.485E-03
# Epoch 92; loss: 5.617E-01; mae_loss: 2.739E-01; neg_r2_loss: -8.434E-02; phi_mmd0_loss: 4.732E-03; phi_mmd1_loss: 6.109E-03; theta_mmd0_loss: 1.510E-03; theta_mmd1_loss: 1.674E-03; val_loss: 5.613E-01; val_mae_loss: 2.694E-01; val_neg_r2_loss: -9.820E-02; val_phi_mmd0_loss: 6.705E-03; val_phi_mmd1_loss: 8.535E-03; val_theta_mmd0_loss: 3.647E-03; val_theta_mmd1_loss: 3.474E-03
# Epoch 93; loss: 5.612E-01; mae_loss: 2.736E-01; neg_r2_loss: -8.577E-02; phi_mmd0_loss: 4.767E-03; phi_mmd1_loss: 6.166E-03; theta_mmd0_loss: 1.535E-03; theta_mmd1_loss: 1.618E-03; val_loss: 5.602E-01; val_mae_loss: 2.702E-01; val_neg_r2_loss: -9.175E-02; val_phi_mmd0_loss: 5.582E-03; val_phi_mmd1_loss: 7.532E-03; val_theta_mmd0_loss: 3.598E-03; val_theta_mmd1_loss: 3.135E-03
# Epoch 94; loss: 5.610E-01; mae_loss: 2.735E-01; neg_r2_loss: -8.564E-02; phi_mmd0_loss: 4.751E-03; phi_mmd1_loss: 6.146E-03; theta_mmd0_loss: 1.502E-03; theta_mmd1_loss: 1.612E-03; val_loss: 5.604E-01; val_mae_loss: 2.698E-01; val_neg_r2_loss: -9.471E-02; val_phi_mmd0_loss: 5.815E-03; val_phi_mmd1_loss: 7.542E-03; val_theta_mmd0_loss: 3.772E-03; val_theta_mmd1_loss: 3.649E-03
# Epoch 95; loss: 5.605E-01; mae_loss: 2.733E-01; neg_r2_loss: -8.694E-02; phi_mmd0_loss: 4.684E-03; phi_mmd1_loss: 6.093E-03; theta_mmd0_loss: 1.531E-03; theta_mmd1_loss: 1.637E-03; val_loss: 5.604E-01; val_mae_loss: 2.696E-01; val_neg_r2_loss: -9.638E-02; val_phi_mmd0_loss: 6.417E-03; val_phi_mmd1_loss: 8.165E-03; val_theta_mmd0_loss: 3.408E-03; val_theta_mmd1_loss: 3.273E-03
# Epoch 96; loss: 5.603E-01; mae_loss: 2.732E-01; neg_r2_loss: -8.662E-02; phi_mmd0_loss: 4.671E-03; phi_mmd1_loss: 6.109E-03; theta_mmd0_loss: 1.502E-03; theta_mmd1_loss: 1.644E-03; val_loss: 5.606E-01; val_mae_loss: 2.698E-01; val_neg_r2_loss: -9.428E-02; val_phi_mmd0_loss: 6.244E-03; val_phi_mmd1_loss: 8.267E-03; val_theta_mmd0_loss: 3.278E-03; val_theta_mmd1_loss: 3.292E-03
# Epoch 97; loss: 5.600E-01; mae_loss: 2.730E-01; neg_r2_loss: -8.684E-02; phi_mmd0_loss: 4.687E-03; phi_mmd1_loss: 6.094E-03; theta_mmd0_loss: 1.517E-03; theta_mmd1_loss: 1.654E-03; val_loss: 5.593E-01; val_mae_loss: 2.694E-01; val_neg_r2_loss: -9.640E-02; val_phi_mmd0_loss: 6.220E-03; val_phi_mmd1_loss: 7.774E-03; val_theta_mmd0_loss: 3.445E-03; val_theta_mmd1_loss: 2.955E-03
# Epoch 98; loss: 5.598E-01; mae_loss: 2.730E-01; neg_r2_loss: -8.664E-02; phi_mmd0_loss: 4.684E-03; phi_mmd1_loss: 6.115E-03; theta_mmd0_loss: 1.509E-03; theta_mmd1_loss: 1.570E-03; val_loss: 5.599E-01; val_mae_loss: 2.695E-01; val_neg_r2_loss: -9.505E-02; val_phi_mmd0_loss: 6.030E-03; val_phi_mmd1_loss: 8.298E-03; val_theta_mmd0_loss: 3.338E-03; val_theta_mmd1_loss: 3.134E-03
# Epoch 99; loss: 5.596E-01; mae_loss: 2.729E-01; neg_r2_loss: -8.720E-02; phi_mmd0_loss: 4.676E-03; phi_mmd1_loss: 6.065E-03; theta_mmd0_loss: 1.493E-03; theta_mmd1_loss: 1.614E-03; val_loss: 5.600E-01; val_mae_loss: 2.692E-01; val_neg_r2_loss: -9.699E-02; val_phi_mmd0_loss: 6.049E-03; val_phi_mmd1_loss: 8.185E-03; val_theta_mmd0_loss: 3.684E-03; val_theta_mmd1_loss: 3.734E-03
# Epoch 100; loss: 5.592E-01; mae_loss: 2.727E-01; neg_r2_loss: -8.784E-02; phi_mmd0_loss: 4.694E-03; phi_mmd1_loss: 6.095E-03; theta_mmd0_loss: 1.483E-03; theta_mmd1_loss: 1.597E-03; val_loss: 5.590E-01; val_mae_loss: 2.695E-01; val_neg_r2_loss: -9.503E-02; val_phi_mmd0_loss: 5.861E-03; val_phi_mmd1_loss: 8.015E-03; val_theta_mmd0_loss: 3.379E-03; val_theta_mmd1_loss: 2.887E-03
# Epoch 101; loss: 5.591E-01; mae_loss: 2.727E-01; neg_r2_loss: -8.735E-02; phi_mmd0_loss: 4.685E-03; phi_mmd1_loss: 6.037E-03; theta_mmd0_loss: 1.498E-03; theta_mmd1_loss: 1.601E-03; val_loss: 5.594E-01; val_mae_loss: 2.689E-01; val_neg_r2_loss: -9.856E-02; val_phi_mmd0_loss: 6.077E-03; val_phi_mmd1_loss: 8.397E-03; val_theta_mmd0_loss: 3.871E-03; val_theta_mmd1_loss: 3.302E-03
# Epoch 102; loss: 5.583E-01; mae_loss: 2.722E-01; neg_r2_loss: -8.962E-02; phi_mmd0_loss: 4.647E-03; phi_mmd1_loss: 6.143E-03; theta_mmd0_loss: 1.496E-03; theta_mmd1_loss: 1.601E-03; val_loss: 5.582E-01; val_mae_loss: 2.686E-01; val_neg_r2_loss: -1.002E-01; val_phi_mmd0_loss: 6.437E-03; val_phi_mmd1_loss: 8.133E-03; val_theta_mmd0_loss: 3.384E-03; val_theta_mmd1_loss: 3.047E-03
# Epoch 103; loss: 5.584E-01; mae_loss: 2.723E-01; neg_r2_loss: -8.899E-02; phi_mmd0_loss: 4.678E-03; phi_mmd1_loss: 6.089E-03; theta_mmd0_loss: 1.465E-03; theta_mmd1_loss: 1.600E-03; val_loss: 5.585E-01; val_mae_loss: 2.680E-01; val_neg_r2_loss: -1.027E-01; val_phi_mmd0_loss: 6.600E-03; val_phi_mmd1_loss: 9.312E-03; val_theta_mmd0_loss: 3.299E-03; val_theta_mmd1_loss: 3.220E-03
# Epoch 104; loss: 5.582E-01; mae_loss: 2.722E-01; neg_r2_loss: -8.916E-02; phi_mmd0_loss: 4.668E-03; phi_mmd1_loss: 6.045E-03; theta_mmd0_loss: 1.473E-03; theta_mmd1_loss: 1.596E-03; val_loss: 5.575E-01; val_mae_loss: 2.688E-01; val_neg_r2_loss: -9.745E-02; val_phi_mmd0_loss: 5.974E-03; val_phi_mmd1_loss: 8.160E-03; val_theta_mmd0_loss: 3.056E-03; val_theta_mmd1_loss: 2.660E-03
# Epoch 105; loss: 5.578E-01; mae_loss: 2.720E-01; neg_r2_loss: -8.950E-02; phi_mmd0_loss: 4.651E-03; phi_mmd1_loss: 6.015E-03; theta_mmd0_loss: 1.504E-03; theta_mmd1_loss: 1.605E-03; val_loss: 5.582E-01; val_mae_loss: 2.680E-01; val_neg_r2_loss: -1.038E-01; val_phi_mmd0_loss: 6.484E-03; val_phi_mmd1_loss: 8.988E-03; val_theta_mmd0_loss: 3.356E-03; val_theta_mmd1_loss: 3.484E-03
# Epoch 106; loss: 5.574E-01; mae_loss: 2.718E-01; neg_r2_loss: -9.046E-02; phi_mmd0_loss: 4.641E-03; phi_mmd1_loss: 6.043E-03; theta_mmd0_loss: 1.487E-03; theta_mmd1_loss: 1.564E-03; val_loss: 5.597E-01; val_mae_loss: 2.685E-01; val_neg_r2_loss: -1.001E-01; val_phi_mmd0_loss: 6.268E-03; val_phi_mmd1_loss: 9.257E-03; val_theta_mmd0_loss: 3.976E-03; val_theta_mmd1_loss: 3.106E-03
# Epoch 107; loss: 5.575E-01; mae_loss: 2.719E-01; neg_r2_loss: -8.990E-02; phi_mmd0_loss: 4.653E-03; phi_mmd1_loss: 6.087E-03; theta_mmd0_loss: 1.458E-03; theta_mmd1_loss: 1.547E-03; val_loss: 5.564E-01; val_mae_loss: 2.690E-01; val_neg_r2_loss: -9.530E-02; val_phi_mmd0_loss: 5.777E-03; val_phi_mmd1_loss: 6.933E-03; val_theta_mmd0_loss: 2.895E-03; val_theta_mmd1_loss: 2.824E-03
# Epoch 108; loss: 5.572E-01; mae_loss: 2.717E-01; neg_r2_loss: -9.056E-02; phi_mmd0_loss: 4.617E-03; phi_mmd1_loss: 6.045E-03; theta_mmd0_loss: 1.491E-03; theta_mmd1_loss: 1.597E-03; val_loss: 5.578E-01; val_mae_loss: 2.691E-01; val_neg_r2_loss: -9.472E-02; val_phi_mmd0_loss: 6.298E-03; val_phi_mmd1_loss: 7.297E-03; val_theta_mmd0_loss: 2.941E-03; val_theta_mmd1_loss: 3.045E-03
# Epoch 109; loss: 5.571E-01; mae_loss: 2.717E-01; neg_r2_loss: -9.002E-02; phi_mmd0_loss: 4.621E-03; phi_mmd1_loss: 6.045E-03; theta_mmd0_loss: 1.493E-03; theta_mmd1_loss: 1.577E-03; val_loss: 5.566E-01; val_mae_loss: 2.687E-01; val_neg_r2_loss: -9.652E-02; val_phi_mmd0_loss: 5.645E-03; val_phi_mmd1_loss: 7.825E-03; val_theta_mmd0_loss: 3.044E-03; val_theta_mmd1_loss: 2.660E-03
# Epoch 110; loss: 5.567E-01; mae_loss: 2.715E-01; neg_r2_loss: -9.081E-02; phi_mmd0_loss: 4.646E-03; phi_mmd1_loss: 6.063E-03; theta_mmd0_loss: 1.457E-03; theta_mmd1_loss: 1.544E-03; val_loss: 5.574E-01; val_mae_loss: 2.691E-01; val_neg_r2_loss: -9.273E-02; val_phi_mmd0_loss: 5.577E-03; val_phi_mmd1_loss: 7.865E-03; val_theta_mmd0_loss: 3.126E-03; val_theta_mmd1_loss: 2.614E-03
# Epoch 111; loss: 5.563E-01; mae_loss: 2.713E-01; neg_r2_loss: -9.143E-02; phi_mmd0_loss: 4.594E-03; phi_mmd1_loss: 6.007E-03; theta_mmd0_loss: 1.470E-03; theta_mmd1_loss: 1.557E-03; val_loss: 5.567E-01; val_mae_loss: 2.682E-01; val_neg_r2_loss: -1.006E-01; val_phi_mmd0_loss: 6.567E-03; val_phi_mmd1_loss: 8.559E-03; val_theta_mmd0_loss: 2.532E-03; val_theta_mmd1_loss: 2.566E-03
# Epoch 112; loss: 5.560E-01; mae_loss: 2.712E-01; neg_r2_loss: -9.202E-02; phi_mmd0_loss: 4.626E-03; phi_mmd1_loss: 6.056E-03; theta_mmd0_loss: 1.443E-03; theta_mmd1_loss: 1.556E-03; val_loss: 5.588E-01; val_mae_loss: 2.683E-01; val_neg_r2_loss: -9.829E-02; val_phi_mmd0_loss: 6.307E-03; val_phi_mmd1_loss: 7.919E-03; val_theta_mmd0_loss: 4.671E-03; val_theta_mmd1_loss: 3.279E-03
# Epoch 113; loss: 5.564E-01; mae_loss: 2.713E-01; neg_r2_loss: -9.068E-02; phi_mmd0_loss: 4.670E-03; phi_mmd1_loss: 6.008E-03; theta_mmd0_loss: 1.452E-03; theta_mmd1_loss: 1.548E-03; val_loss: 5.568E-01; val_mae_loss: 2.683E-01; val_neg_r2_loss: -9.838E-02; val_phi_mmd0_loss: 6.431E-03; val_phi_mmd1_loss: 7.870E-03; val_theta_mmd0_loss: 3.215E-03; val_theta_mmd1_loss: 2.739E-03
# Epoch 114; loss: 5.554E-01; mae_loss: 2.709E-01; neg_r2_loss: -9.332E-02; phi_mmd0_loss: 4.631E-03; phi_mmd1_loss: 5.993E-03; theta_mmd0_loss: 1.457E-03; theta_mmd1_loss: 1.578E-03; val_loss: 5.564E-01; val_mae_loss: 2.683E-01; val_neg_r2_loss: -9.778E-02; val_phi_mmd0_loss: 5.726E-03; val_phi_mmd1_loss: 8.029E-03; val_theta_mmd0_loss: 3.114E-03; val_theta_mmd1_loss: 2.896E-03
# Epoch 115; loss: 5.557E-01; mae_loss: 2.711E-01; neg_r2_loss: -9.209E-02; phi_mmd0_loss: 4.586E-03; phi_mmd1_loss: 6.005E-03; theta_mmd0_loss: 1.449E-03; theta_mmd1_loss: 1.558E-03; val_loss: 5.569E-01; val_mae_loss: 2.680E-01; val_neg_r2_loss: -1.008E-01; val_phi_mmd0_loss: 6.545E-03; val_phi_mmd1_loss: 7.385E-03; val_theta_mmd0_loss: 3.496E-03; val_theta_mmd1_loss: 3.392E-03
# Epoch 116; loss: 5.553E-01; mae_loss: 2.708E-01; neg_r2_loss: -9.356E-02; phi_mmd0_loss: 4.613E-03; phi_mmd1_loss: 6.059E-03; theta_mmd0_loss: 1.453E-03; theta_mmd1_loss: 1.529E-03; val_loss: 5.564E-01; val_mae_loss: 2.681E-01; val_neg_r2_loss: -9.778E-02; val_phi_mmd0_loss: 6.149E-03; val_phi_mmd1_loss: 7.377E-03; val_theta_mmd0_loss: 3.572E-03; val_theta_mmd1_loss: 3.030E-03
# Epoch 117; loss: 5.552E-01; mae_loss: 2.708E-01; neg_r2_loss: -9.239E-02; phi_mmd0_loss: 4.566E-03; phi_mmd1_loss: 5.996E-03; theta_mmd0_loss: 1.452E-03; theta_mmd1_loss: 1.555E-03; val_loss: 5.550E-01; val_mae_loss: 2.678E-01; val_neg_r2_loss: -1.005E-01; val_phi_mmd0_loss: 6.266E-03; val_phi_mmd1_loss: 7.944E-03; val_theta_mmd0_loss: 2.365E-03; val_theta_mmd1_loss: 2.737E-03
# Epoch 118; loss: 5.549E-01; mae_loss: 2.706E-01; neg_r2_loss: -9.276E-02; phi_mmd0_loss: 4.612E-03; phi_mmd1_loss: 6.058E-03; theta_mmd0_loss: 1.441E-03; theta_mmd1_loss: 1.519E-03; val_loss: 5.566E-01; val_mae_loss: 2.685E-01; val_neg_r2_loss: -9.574E-02; val_phi_mmd0_loss: 5.948E-03; val_phi_mmd1_loss: 7.512E-03; val_theta_mmd0_loss: 3.441E-03; val_theta_mmd1_loss: 2.776E-03
# Epoch 119; loss: 5.547E-01; mae_loss: 2.706E-01; neg_r2_loss: -9.270E-02; phi_mmd0_loss: 4.608E-03; phi_mmd1_loss: 5.956E-03; theta_mmd0_loss: 1.437E-03; theta_mmd1_loss: 1.533E-03; val_loss: 5.558E-01; val_mae_loss: 2.682E-01; val_neg_r2_loss: -9.746E-02; val_phi_mmd0_loss: 5.896E-03; val_phi_mmd1_loss: 7.344E-03; val_theta_mmd0_loss: 3.102E-03; val_theta_mmd1_loss: 3.055E-03
# Epoch 120; loss: 5.543E-01; mae_loss: 2.704E-01; neg_r2_loss: -9.362E-02; phi_mmd0_loss: 4.608E-03; phi_mmd1_loss: 5.970E-03; theta_mmd0_loss: 1.443E-03; theta_mmd1_loss: 1.517E-03; val_loss: 5.552E-01; val_mae_loss: 2.678E-01; val_neg_r2_loss: -9.911E-02; val_phi_mmd0_loss: 6.236E-03; val_phi_mmd1_loss: 7.933E-03; val_theta_mmd0_loss: 3.001E-03; val_theta_mmd1_loss: 2.544E-03
# Epoch 121; loss: 5.542E-01; mae_loss: 2.704E-01; neg_r2_loss: -9.391E-02; phi_mmd0_loss: 4.600E-03; phi_mmd1_loss: 5.948E-03; theta_mmd0_loss: 1.433E-03; theta_mmd1_loss: 1.499E-03; val_loss: 5.552E-01; val_mae_loss: 2.680E-01; val_neg_r2_loss: -9.637E-02; val_phi_mmd0_loss: 5.813E-03; val_phi_mmd1_loss: 7.174E-03; val_theta_mmd0_loss: 3.331E-03; val_theta_mmd1_loss: 2.899E-03
# Epoch 122; loss: 5.544E-01; mae_loss: 2.704E-01; neg_r2_loss: -9.342E-02; phi_mmd0_loss: 4.594E-03; phi_mmd1_loss: 6.010E-03; theta_mmd0_loss: 1.453E-03; theta_mmd1_loss: 1.541E-03; val_loss: 5.555E-01; val_mae_loss: 2.680E-01; val_neg_r2_loss: -9.709E-02; val_phi_mmd0_loss: 5.945E-03; val_phi_mmd1_loss: 8.134E-03; val_theta_mmd0_loss: 3.099E-03; val_theta_mmd1_loss: 2.363E-03
# Epoch 123; loss: 5.538E-01; mae_loss: 2.702E-01; neg_r2_loss: -9.422E-02; phi_mmd0_loss: 4.521E-03; phi_mmd1_loss: 5.985E-03; theta_mmd0_loss: 1.447E-03; theta_mmd1_loss: 1.508E-03; val_loss: 5.556E-01; val_mae_loss: 2.678E-01; val_neg_r2_loss: -9.800E-02; val_phi_mmd0_loss: 5.959E-03; val_phi_mmd1_loss: 7.955E-03; val_theta_mmd0_loss: 3.355E-03; val_theta_mmd1_loss: 2.668E-03
# Epoch 124; loss: 5.542E-01; mae_loss: 2.703E-01; neg_r2_loss: -9.317E-02; phi_mmd0_loss: 4.574E-03; phi_mmd1_loss: 5.944E-03; theta_mmd0_loss: 1.455E-03; theta_mmd1_loss: 1.526E-03; val_loss: 5.550E-01; val_mae_loss: 2.679E-01; val_neg_r2_loss: -9.803E-02; val_phi_mmd0_loss: 5.770E-03; val_phi_mmd1_loss: 7.561E-03; val_theta_mmd0_loss: 3.269E-03; val_theta_mmd1_loss: 2.572E-03
# Epoch 125; loss: 5.535E-01; mae_loss: 2.700E-01; neg_r2_loss: -9.522E-02; phi_mmd0_loss: 4.595E-03; phi_mmd1_loss: 6.009E-03; theta_mmd0_loss: 1.433E-03; theta_mmd1_loss: 1.486E-03; val_loss: 5.551E-01; val_mae_loss: 2.680E-01; val_neg_r2_loss: -9.688E-02; val_phi_mmd0_loss: 5.720E-03; val_phi_mmd1_loss: 7.941E-03; val_theta_mmd0_loss: 3.093E-03; val_theta_mmd1_loss: 2.417E-03
# Epoch 126; loss: 5.530E-01; mae_loss: 2.698E-01; neg_r2_loss: -9.615E-02; phi_mmd0_loss: 4.540E-03; phi_mmd1_loss: 5.918E-03; theta_mmd0_loss: 1.434E-03; theta_mmd1_loss: 1.505E-03; val_loss: 5.540E-01; val_mae_loss: 2.675E-01; val_neg_r2_loss: -9.881E-02; val_phi_mmd0_loss: 6.521E-03; val_phi_mmd1_loss: 7.176E-03; val_theta_mmd0_loss: 2.369E-03; val_theta_mmd1_loss: 2.905E-03
# Epoch 127; loss: 5.533E-01; mae_loss: 2.699E-01; neg_r2_loss: -9.464E-02; phi_mmd0_loss: 4.553E-03; phi_mmd1_loss: 5.972E-03; theta_mmd0_loss: 1.397E-03; theta_mmd1_loss: 1.525E-03; val_loss: 5.558E-01; val_mae_loss: 2.673E-01; val_neg_r2_loss: -1.005E-01; val_phi_mmd0_loss: 6.570E-03; val_phi_mmd1_loss: 8.228E-03; val_theta_mmd0_loss: 3.569E-03; val_theta_mmd1_loss: 2.854E-03
# Epoch 128; loss: 5.531E-01; mae_loss: 2.698E-01; neg_r2_loss: -9.538E-02; phi_mmd0_loss: 4.600E-03; phi_mmd1_loss: 5.935E-03; theta_mmd0_loss: 1.435E-03; theta_mmd1_loss: 1.512E-03; val_loss: 5.550E-01; val_mae_loss: 2.677E-01; val_neg_r2_loss: -9.834E-02; val_phi_mmd0_loss: 6.036E-03; val_phi_mmd1_loss: 7.415E-03; val_theta_mmd0_loss: 3.381E-03; val_theta_mmd1_loss: 2.798E-03
# Epoch 129; loss: 5.530E-01; mae_loss: 2.698E-01; neg_r2_loss: -9.524E-02; phi_mmd0_loss: 4.557E-03; phi_mmd1_loss: 5.961E-03; theta_mmd0_loss: 1.436E-03; theta_mmd1_loss: 1.518E-03; val_loss: 5.547E-01; val_mae_loss: 2.675E-01; val_neg_r2_loss: -9.909E-02; val_phi_mmd0_loss: 6.280E-03; val_phi_mmd1_loss: 7.750E-03; val_theta_mmd0_loss: 3.090E-03; val_theta_mmd1_loss: 2.715E-03
# Epoch 130; loss: 5.527E-01; mae_loss: 2.696E-01; neg_r2_loss: -9.577E-02; phi_mmd0_loss: 4.576E-03; phi_mmd1_loss: 5.993E-03; theta_mmd0_loss: 1.431E-03; theta_mmd1_loss: 1.502E-03; val_loss: 5.558E-01; val_mae_loss: 2.675E-01; val_neg_r2_loss: -1.002E-01; val_phi_mmd0_loss: 6.227E-03; val_phi_mmd1_loss: 8.031E-03; val_theta_mmd0_loss: 3.368E-03; val_theta_mmd1_loss: 3.138E-03
# Epoch 131; loss: 5.528E-01; mae_loss: 2.697E-01; neg_r2_loss: -9.519E-02; phi_mmd0_loss: 4.553E-03; phi_mmd1_loss: 5.951E-03; theta_mmd0_loss: 1.420E-03; theta_mmd1_loss: 1.483E-03; val_loss: 5.549E-01; val_mae_loss: 2.673E-01; val_neg_r2_loss: -9.900E-02; val_phi_mmd0_loss: 6.123E-03; val_phi_mmd1_loss: 8.156E-03; val_theta_mmd0_loss: 3.461E-03; val_theta_mmd1_loss: 2.670E-03
# Epoch 132; loss: 5.527E-01; mae_loss: 2.696E-01; neg_r2_loss: -9.573E-02; phi_mmd0_loss: 4.594E-03; phi_mmd1_loss: 5.963E-03; theta_mmd0_loss: 1.412E-03; theta_mmd1_loss: 1.463E-03; val_loss: 5.542E-01; val_mae_loss: 2.675E-01; val_neg_r2_loss: -9.797E-02; val_phi_mmd0_loss: 5.813E-03; val_phi_mmd1_loss: 7.557E-03; val_theta_mmd0_loss: 3.074E-03; val_theta_mmd1_loss: 2.725E-03
# Epoch 133; loss: 5.522E-01; mae_loss: 2.694E-01; neg_r2_loss: -9.623E-02; phi_mmd0_loss: 4.568E-03; phi_mmd1_loss: 5.880E-03; theta_mmd0_loss: 1.448E-03; theta_mmd1_loss: 1.483E-03; val_loss: 5.550E-01; val_mae_loss: 2.674E-01; val_neg_r2_loss: -1.001E-01; val_phi_mmd0_loss: 6.077E-03; val_phi_mmd1_loss: 8.550E-03; val_theta_mmd0_loss: 3.091E-03; val_theta_mmd1_loss: 2.357E-03
# Epoch 134; loss: 5.522E-01; mae_loss: 2.694E-01; neg_r2_loss: -9.632E-02; phi_mmd0_loss: 4.544E-03; phi_mmd1_loss: 5.939E-03; theta_mmd0_loss: 1.420E-03; theta_mmd1_loss: 1.508E-03; val_loss: 5.557E-01; val_mae_loss: 2.675E-01; val_neg_r2_loss: -9.903E-02; val_phi_mmd0_loss: 6.193E-03; val_phi_mmd1_loss: 8.203E-03; val_theta_mmd0_loss: 3.487E-03; val_theta_mmd1_loss: 2.868E-03
# Epoch 135; loss: 5.519E-01; mae_loss: 2.693E-01; neg_r2_loss: -9.634E-02; phi_mmd0_loss: 4.524E-03; phi_mmd1_loss: 5.873E-03; theta_mmd0_loss: 1.415E-03; theta_mmd1_loss: 1.498E-03; val_loss: 5.542E-01; val_mae_loss: 2.680E-01; val_neg_r2_loss: -9.470E-02; val_phi_mmd0_loss: 5.592E-03; val_phi_mmd1_loss: 7.135E-03; val_theta_mmd0_loss: 3.152E-03; val_theta_mmd1_loss: 2.381E-03
# Epoch 136; loss: 5.518E-01; mae_loss: 2.692E-01; neg_r2_loss: -9.655E-02; phi_mmd0_loss: 4.541E-03; phi_mmd1_loss: 5.927E-03; theta_mmd0_loss: 1.400E-03; theta_mmd1_loss: 1.502E-03; val_loss: 5.567E-01; val_mae_loss: 2.675E-01; val_neg_r2_loss: -1.002E-01; val_phi_mmd0_loss: 6.577E-03; val_phi_mmd1_loss: 7.537E-03; val_theta_mmd0_loss: 3.666E-03; val_theta_mmd1_loss: 3.957E-03
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752766344.444215 2059081 service.cc:145] XLA service 0x78879005f8f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752766344.444243 2059081 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 SUPER, Compute Capability 8.9
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752766352.453209 2059273 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_29', 16 bytes spill stores, 16 bytes spill loads
#
# I0000 00:00:1752766352.692311 2059260 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_33', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752766352.928863 2059267 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_33', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752766353.121131 2059266 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_31', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752766353.135522 2059263 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_31', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752766353.164131 2059268 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_33', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1752766353.186028 2059245 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_31', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1752766361.407004 2059081 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# I0000 00:00:1752766370.997013 2059659 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_31', 272 bytes spill stores, 272 bytes spill loads
#
# I0000 00:00:1752766371.067963 2059670 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_32', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1752766371.070936 2059648 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_32', 24 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1752766371.101723 2059676 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_33', 276 bytes spill stores, 272 bytes spill loads
#
# I0000 00:00:1752766371.124965 2059656 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_33', 272 bytes spill stores, 272 bytes spill loads
#
# I0000 00:00:1752766385.624068 2060131 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_18', 24 bytes spill stores, 24 bytes spill loads
#
# I0000 00:00:1752766385.686633 2060132 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_18', 8 bytes spill stores, 8 bytes spill loads

# %%
pred_y = model.predict(test_x)
pred_y_sm = model.predict(train_sm[test_idx])  # SM prediction
# Out:
# 2031/2031 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2031/2031 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# I0000 00:00:1752766793.599526 2083133 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_1', 8 bytes spill stores, 8 bytes spill loads

# %%
label_lead_w_theta = test_y[:, 0]
label_lead_w_phi = test_y[:, 1]
label_sublead_w_theta = test_y[:, 2]
label_sublead_w_phi = test_y[:, 3]

label_lead_w_theta_sm = target_sm[test_idx][:, 0]
label_lead_w_phi_sm = target_sm[test_idx][:, 1]
label_sublead_w_theta_sm = target_sm[test_idx][:, 2]
label_sublead_w_phi_sm = target_sm[test_idx][:, 3]

pred_lead_w_theta = pred_y[:, 0]
pred_lead_w_phi = pred_y[:, 1]
pred_sublead_w_theta = pred_y[:, 2]
pred_sublead_w_phi = pred_y[:, 3]

pred_lead_w_theta_sm = pred_y_sm[:, 0]
pred_lead_w_phi_sm = pred_y_sm[:, 1]
pred_sublead_w_theta_sm = pred_y_sm[:, 2]
pred_sublead_w_phi_sm = pred_y_sm[:, 3]

# %%
# theta

# lead
plt.hist(label_lead_w_theta, bins=np.linspace(0, 1, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_theta, bins=np.linspace(0, 1, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$\theta^{\ast}_{\ell_0}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_theta,
	pred_lead_w_theta,
	bins=(51, 51),
	range=([0, 1], [0, 1]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$\theta^{\ast}_{\ell_0}$", loc='right')
plt.show()

# sublead
plt.hist(label_sublead_w_theta, bins=np.linspace(0, 1, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_theta, bins=np.linspace(0, 1, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$\theta^{\ast}_{\ell_1}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_theta,
	pred_sublead_w_theta,
	bins=(51, 51),
	range=([0, 1], [0, 1]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$\theta^{\ast}_{\ell_1}$", loc='right')
plt.show()

# %%
# theta

# lead
plt.hist(label_lead_w_theta_sm, bins=np.linspace(0, 1, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_theta_sm, bins=np.linspace(0, 1, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"SM $\theta^{\ast}_{\ell_0}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_theta_sm,
	pred_lead_w_theta_sm,
	bins=(51, 51),
	range=([0, 1], [0, 1]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"SM $\theta^{\ast}_{\ell_0}$", loc='right')
plt.show()

# sublead
plt.hist(label_sublead_w_theta_sm, bins=np.linspace(0, 1, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_theta_sm, bins=np.linspace(0, 1, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"SM $\theta^{\ast}_{\ell_1}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_theta_sm,
	pred_sublead_w_theta_sm,
	bins=(51, 51),
	range=([0, 1], [0, 1]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"SM $\theta^{\ast}_{\ell_1}$", loc='right')
plt.show()

# %%
# phi

# lead
plt.hist(label_lead_w_phi, bins=np.linspace(-1, 1, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_phi, bins=np.linspace(-1, 1, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$\phi^{\ast}_{\ell_0}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_phi,
	pred_lead_w_phi,
	bins=(51, 51),
	range=([-1, 1], [-1, 1]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$\phi^{\ast}_{\ell_0}$", loc='right')
plt.show()

# sublead 
plt.hist(label_sublead_w_phi, bins=np.linspace(-1, 1, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_phi, bins=np.linspace(-1, 1, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"$\phi^{\ast}_{\ell_1}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_phi,
	pred_sublead_w_phi,
	bins=(51, 51),
	range=([-1, 1], [-1, 1]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"$\phi^{\ast}_{\ell_1}$", loc='right')
plt.show()

# %%
# phi

# lead
plt.hist(label_lead_w_phi_sm, bins=np.linspace(-1, 1, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_lead_w_phi_sm, bins=np.linspace(-1, 1, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"SM $\phi^{\ast}_{\ell_0}$", loc='right')
plt.show()

plt.hist2d(
	label_lead_w_phi_sm,
	pred_lead_w_phi_sm,
	bins=(51, 51),
	range=([-1, 1], [-1, 1]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"SM $\phi^{\ast}_{\ell_0}$", loc='right')
plt.show()

# sublead 
plt.hist(label_sublead_w_phi_sm, bins=np.linspace(-1, 1, 51), label=r"Label", histtype="step", linewidth=2, color="red")
plt.hist(pred_sublead_w_phi_sm, bins=np.linspace(-1, 1, 51), label=r"Pred", histtype="step", linewidth=2, color="blue")
plt.legend()
plt.title(r"SM $\phi^{\ast}_{\ell_1}$", loc='right')
plt.show()

plt.hist2d(
	label_sublead_w_phi_sm,
	pred_sublead_w_phi_sm,
	bins=(51, 51),
	range=([-1, 1], [-1, 1]),
	cmap="viridis",
	cmin=1,
	norm=LogNorm()
)
plt.colorbar(label="Counts")
plt.gca().set_aspect("equal", adjustable="box")
plt.ylabel(r"Pred")
plt.xlabel(r"Label")
plt.title(r"SM $\phi^{\ast}_{\ell_1}$", loc='right')
plt.show()

# %%
def xi_n(theta, phi):
    return np.sin(theta * np.pi) * np.cos(phi * np.pi)
def xi_r(theta, phi):
    return np.sin(theta * np.pi) * np.sin(phi * np.pi)
def xi_k(theta, phi):
    return np.cos(theta * np.pi)

# Calculate xi components for both predicted and truth values
lead_xi = {
    'n': xi_n(pred_lead_w_theta, pred_lead_w_phi),
    'r': xi_r(pred_lead_w_theta, pred_lead_w_phi),
    'k': xi_k(pred_lead_w_theta, pred_lead_w_phi)
}
sublead_xi = {
    'n': xi_n(pred_sublead_w_theta, pred_sublead_w_phi),
    'r': xi_r(pred_sublead_w_theta, pred_sublead_w_phi),
    'k': xi_k(pred_sublead_w_theta, pred_sublead_w_phi)
}
truth_lead_xi = {
    'n': xi_n(label_lead_w_theta, label_lead_w_phi),
    'r': xi_r(label_lead_w_theta, label_lead_w_phi),
    'k': xi_k(label_lead_w_theta, label_lead_w_phi)
}
truth_sublead_xi = {
    'n': xi_n(label_sublead_w_theta, label_sublead_w_phi),
    'r': xi_r(label_sublead_w_theta, label_sublead_w_phi),
    'k': xi_k(label_sublead_w_theta, label_sublead_w_phi)
}

bins_edges = np.linspace(-1, 1, 51)

# 1D histogram plots (2 rows, 3 columns)
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
components = ['n', 'r', 'k']

for i, component in enumerate(components):
    # Lead lepton (top row)
    axes[0, i].hist(lead_xi[component], bins=bins_edges, 
                    label=f"pred", alpha=0.7)
    axes[0, i].hist(truth_lead_xi[component], bins=bins_edges, 
                    label=f"true", 
                    histtype="step", linewidth=2, color="red")
    axes[0, i].legend()
    axes[0, i].set_title(f"$\\xi_{component}^{{(0)}}$", loc="right")
    
    # Sublead lepton (bottom row)
    axes[1, i].hist(sublead_xi[component], bins=bins_edges, 
                    label=f"pred", alpha=0.7)
    axes[1, i].hist(truth_sublead_xi[component], bins=bins_edges, 
                    label=f"true", 
                    histtype="step", linewidth=2, color="red")
    axes[1, i].legend()
    axes[1, i].set_title(f"$\\xi_{component}^{{(1)}}$", loc="right")

plt.tight_layout()
plt.show()

# 2D histogram plots (2 rows, 3 columns) with shared colorbar
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Create all 2D histograms and store them to find global min/max for colorbar
hist_data = []
for i, component in enumerate(components):
	# Lead lepton
	h1, _, _ = np.histogram2d(lead_xi[component], truth_lead_xi[component], 
								bins=(51, 51), range=([-1, 1], [-1, 1]))
	hist_data.append(h1)

	# Sublead lepton
	h2, _, _ = np.histogram2d(sublead_xi[component], truth_sublead_xi[component], 
								bins=(51, 51), range=([-1, 1], [-1, 1]))
	hist_data.append(h2)

	# Find global min/max for consistent colorbar
	vmin = max(1, min([h[h > 0].min() for h in hist_data if np.any(h > 0)]))
	vmax = max([h.max() for h in hist_data])

	for i, component in enumerate(components):
		# Lead lepton (top row)
		im1 = axes[0, i].hist2d(lead_xi[component], truth_lead_xi[component], 
							bins=(51, 51), range=([-1, 1], [-1, 1]),
							cmap="viridis", cmin=vmin, norm=LogNorm(vmin=vmin, vmax=vmax))
		axes[0, i].set_aspect("equal", adjustable="box")
		axes[0, i].set_ylabel("Truth")
		axes[0, i].set_xlabel("Pred")
		axes[0, i].set_title(f"$\\xi_{component}^{{(0)}}$", loc="right")
		
		# Sublead lepton (bottom row)
		im2 = axes[1, i].hist2d(sublead_xi[component], truth_sublead_xi[component], 
							bins=(51, 51), range=([-1, 1], [-1, 1]),
							cmap="viridis", cmin=vmin, norm=LogNorm(vmin=vmin, vmax=vmax))
		axes[1, i].set_aspect("equal", adjustable="box")
		axes[1, i].set_ylabel("Truth")
		axes[1, i].set_xlabel("Pred")
		axes[1, i].set_title(f"$\\xi_{component}^{{(1)}}$", loc="right")

	# # Add shared colorbar
	# fig.subplots_adjust(right=0.8)
	# cbar_ax = fig.add_axes([0.85, 0.15, 0.03, 0.7])
	# fig.colorbar(im1[3], cax=cbar_ax, label="Counts")

	plt.tight_layout()
	plt.show()

# %%
def xi_n(theta, phi):
    return np.sin(theta * np.pi) * np.cos(phi * np.pi)
def xi_r(theta, phi):
    return np.sin(theta * np.pi) * np.sin(phi * np.pi)
def xi_k(theta, phi):
    return np.cos(theta * np.pi)

# Calculate xi components for both predicted and truth values
lead_xi = {
    'n': xi_n(pred_lead_w_theta, pred_lead_w_phi),
    'r': xi_r(pred_lead_w_theta, pred_lead_w_phi),
    'k': xi_k(pred_lead_w_theta, pred_lead_w_phi)
}
sublead_xi = {
    'n': xi_n(pred_sublead_w_theta, pred_sublead_w_phi),
    'r': xi_r(pred_sublead_w_theta, pred_sublead_w_phi),
    'k': xi_k(pred_sublead_w_theta, pred_sublead_w_phi)
}
truth_lead_xi = {
    'n': xi_n(pred_lead_w_theta_sm, pred_lead_w_phi_sm),
    'r': xi_r(pred_lead_w_theta_sm, pred_lead_w_phi_sm),
    'k': xi_k(pred_lead_w_theta_sm, pred_lead_w_phi_sm)
}
truth_sublead_xi = {
    'n': xi_n(pred_sublead_w_theta_sm, pred_sublead_w_phi_sm),
    'r': xi_r(pred_sublead_w_theta_sm, pred_sublead_w_phi_sm),
    'k': xi_k(pred_sublead_w_theta_sm, pred_sublead_w_phi_sm)
}

bins_edges = np.linspace(-1, 1, 51)

# 1D histogram plots (2 rows, 3 columns)
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
components = ['n', 'r', 'k']

for i, component in enumerate(components):
    # Lead lepton (top row)
    axes[0, i].hist(lead_xi[component], bins=bins_edges, 
                    label=f"Pred(LL)", alpha=0.7)
    axes[0, i].hist(truth_lead_xi[component], bins=bins_edges, 
                    label=f"Pred(SM)", 
                    histtype="step", linewidth=2, color="red")
    axes[0, i].legend()
    axes[0, i].set_title(f"$\\xi_{component}^{{(0)}}$", loc="right")
    
    # Sublead lepton (bottom row)
    axes[1, i].hist(sublead_xi[component], bins=bins_edges, 
                    label=f"Pred(LL)", alpha=0.7)
    axes[1, i].hist(truth_sublead_xi[component], bins=bins_edges, 
                    label=f"Pred(SM)", 
                    histtype="step", linewidth=2, color="red")
    axes[1, i].legend()
    axes[1, i].set_title(f"$\\xi_{component}^{{(1)}}$", loc="right")

plt.tight_layout()
plt.show()

# 2D histogram plots (2 rows, 3 columns) with shared colorbar
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Create all 2D histograms and store them to find global min/max for colorbar
hist_data = []
for i, component in enumerate(components):
	# Lead lepton
	h1, _, _ = np.histogram2d(lead_xi[component], truth_lead_xi[component], 
								bins=(51, 51), range=([-1, 1], [-1, 1]))
	hist_data.append(h1)

	# Sublead lepton
	h2, _, _ = np.histogram2d(sublead_xi[component], truth_sublead_xi[component], 
								bins=(51, 51), range=([-1, 1], [-1, 1]))
	hist_data.append(h2)

	# Find global min/max for consistent colorbar
	vmin = max(1, min([h[h > 0].min() for h in hist_data if np.any(h > 0)]))
	vmax = max([h.max() for h in hist_data])

	for i, component in enumerate(components):
		# Lead lepton (top row)
		im1 = axes[0, i].hist2d(lead_xi[component], truth_lead_xi[component], 
							bins=(51, 51), range=([-1, 1], [-1, 1]),
							cmap="viridis", cmin=vmin, norm=LogNorm(vmin=vmin, vmax=vmax))
		axes[0, i].set_aspect("equal", adjustable="box")
		axes[0, i].set_ylabel("Pred(SM)")
		axes[0, i].set_xlabel("Pred(LL)")
		axes[0, i].set_title(f"$\\xi_{component}^{{(0)}}$", loc="right")
		
		# Sublead lepton (bottom row)
		im2 = axes[1, i].hist2d(sublead_xi[component], truth_sublead_xi[component], 
							bins=(51, 51), range=([-1, 1], [-1, 1]),
							cmap="viridis", cmin=vmin, norm=LogNorm(vmin=vmin, vmax=vmax))
		axes[1, i].set_aspect("equal", adjustable="box")
		axes[1, i].set_ylabel("Pred(SM)")
		axes[1, i].set_xlabel("Pred(LL)")
		axes[1, i].set_title(f"$\\xi_{component}^{{(1)}}$", loc="right")

	# # Add shared colorbar
	# fig.subplots_adjust(right=0.8)
	# cbar_ax = fig.add_axes([0.85, 0.15, 0.03, 0.7])
	# fig.colorbar(im1[3], cax=cbar_ax, label="Counts")

	plt.tight_layout()
	plt.show()
